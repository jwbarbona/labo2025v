# %% [markdown]
# <a href="https://colab.research.google.com/github/jwbarbona/labo2025v/blob/main/610_WorkFlow_8HT_65123b_gerencial_julio.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # 6 WorkFlow  Gerencial, futuro=JULIO

# %% [markdown]
# ### 6.1 Objetivo

# %% [markdown]
# Presentar un workflow/pipeline completo al que los estudiantes deberán enriquecer

# %% [markdown]
# #### 6.2  Seteo del ambiente en Google Colab

# %% [markdown]
# Esta parte se debe correr con el runtime en Python3
# <br>Ir al menu, Runtime -> Change Runtime Type -> Runtime type ->  **Python 3**

# %% [markdown]
# Conectar la virtual machine donde esta corriendo Google Colab con el  Google Drive, para poder tener persistencia de archivos

# %%
# primero establecer el Runtime de Python 3
from google.colab import drive
drive.mount('/content/.drive')
# Out:
# Mounted at /content/.drive

# %% [markdown]
# Para correr la siguiente celda es fundamental en Arranque en Frio haber copiado el archivo kaggle.json al Google Drive, en la carpeta indicada en el instructivo
#
# <br>los siguientes comando estan en shell script de Linux
# *   Crear las carpetas en el Google Drive
# *   "instalar" el archivo kaggle.json desde el Google Drive a la virtual machine para que pueda ser utilizado por la libreria  kaggle de Python
# *   Bajar el  **dataset_pequeno**  al  Google Drive  y tambien al disco local de la virtual machine que esta corriendo Google Colab
# *   Bajar el **dataset_historico** al Google Drive y tambien al disco local de la virtual machine que esta corriendo Google Colab

# %%
%%shell

mkdir -p "/content/.drive/My Drive/labo1"
mkdir -p "/content/buckets"
ln -s "/content/.drive/My Drive/labo1" /content/buckets/b1

mkdir -p ~/.kaggle
cp /content/buckets/b1/kaggle/kaggle.json  ~/.kaggle
chmod 600 ~/.kaggle/kaggle.json


mkdir -p /content/buckets/b1/exp
mkdir -p /content/buckets/b1/datasets
mkdir -p /content/datasets


webfiles="https://storage.googleapis.com/open-courses/austral2025-af91/"
destino_local="/content/datasets"
destino_bucket="/content/buckets/b1/datasets"


archivo="dataset_pequeno.csv"

if ! test -f $destino_bucket/$archivo; then
  wget  $webfiles/$archivo  -O $destino_bucket/$archivo
fi


if ! test -f $destino_local/$pequeno; then
  cp  $destino_bucket/$archivo  $destino_local/$archivo
fi

#-------

archivo="gerencial_competencia_2025.csv.gz"

if ! test -f $destino_bucket/$archivo; then
  wget  $webfiles/$archivo  -O $destino_bucket/$archivo
fi


if ! test -f $destino_local/$pequeno; then
  cp  $destino_bucket/$archivo  $destino_local/$archivo
fi
# Out:
# cp: cannot stat '/content/buckets/b1/kaggle/kaggle.json': No such file or directory
# chmod: cannot access '/root/.kaggle/kaggle.json': No such file or directory

# %% [markdown]
# ## 6.3  Workflow

# %% [markdown]
# ## Inicializacion

# %% [markdown]
# Esta parte se debe correr con el runtime en lenguaje **R** Ir al menu, Runtime -> Change Runtime Type -> Runtime type -> R

# %% [markdown]
# limpio el ambiente de R

# %%
format(Sys.time(), "%a %b %d %X %Y")
# Out:
# [1] "Wed Nov 19 02:38:49 AM 2025"

# %%
# limpio la memoria
rm(list=ls(all.names=TRUE)) # remove all objects
gc(full=TRUE, verbose=FALSE) # garbage collection
# Out:
#        used    (Mb) gc trigger (Mb) max used (Mb)
# Ncells  660352 35.3 1454491    77.7 1454491  77.7
# Vcells 1226511  9.4 8388608    64.0 1975136  15.1

# %%
principio <- Sys.time()

# %%
require("data.table")

if( !require("R.utils")) install.packages("R.utils")
require("R.utils")
# Out:
# Loading required package: data.table
#
# Loading required package: R.utils
#
# Warning message in library(package, lib.loc = lib.loc, character.only = TRUE, logical.return = TRUE, :
# “there is no package called ‘R.utils’”
# Installing package into ‘/usr/local/lib/R/site-library’
# (as ‘lib’ is unspecified)
#
# also installing the dependencies ‘R.oo’, ‘R.methodsS3’
#
#
# Loading required package: R.utils
#
# Loading required package: R.oo
#
# Loading required package: R.methodsS3
#
# R.methodsS3 v1.8.2 (2022-06-13 22:00:14 UTC) successfully loaded. See ?R.methodsS3 for help.
#
# R.oo v1.27.1 (2025-05-02 21:00:05 UTC) successfully loaded. See ?R.oo for help.
#
#
# Attaching package: ‘R.oo’
#
#
# The following object is masked from ‘package:R.methodsS3’:
#
#     throw
#
#
# The following objects are masked from ‘package:methods’:
#
#     getClasses, getMethods
#
#
# The following objects are masked from ‘package:base’:
#
#     attach, detach, load, save
#
#
# R.utils v2.13.0 (2025-02-24 21:20:02 UTC) successfully loaded. See ?R.utils for help.
#
#
# Attaching package: ‘R.utils’
#
#
# The following object is masked from ‘package:utils’:
#
#     timestamp
#
#
# The following objects are masked from ‘package:base’:
#
#     cat, commandArgs, getOption, isOpen, nullfile, parse, use, warnings

# %% [markdown]
# #### Parametros
# Si es gerente, no cambie nada
# <br>Si es Analista, cambie el nombre del dataset

# %%
PARAM <- list()
PARAM$semilla_primigenia <- 499999 # 100009, 200003, 499999, 700009, 999983

PARAM$experimento <- 65123
PARAM$dataset <- "gerencial_competencia_2025.csv.gz"

# %% [markdown]
# #### Carpeta del Experimento

# %%
# carpeta de trabajo

setwd("/content/buckets/b1/exp")
experimento_folder <- paste0("WF", PARAM$experimento)
dir.create(experimento_folder, showWarnings=FALSE)
setwd( paste0("/content/buckets/b1/exp/", experimento_folder ))

# %% [markdown]
# ### 6.3.1   Preprocesamiento del dataset

# %% [markdown]
# #### 6.3.1.1  DT incorporar dataset

# %%
# lectura del dataset
dataset <- fread(paste0("/content/datasets/", PARAM$dataset))

# %% [markdown]
# #### 6.3.1.2  CA  Catastrophe Analysis
# Se intentan reparar las variables que para un mes están con todos los valores en cero.

# %% [markdown]
# El método que se utiliza es **Machine Learning** se asigna NA also valores, si ha leido bien, es la "anti imputación de valores faltantes"
# <br> Usted podrá aplicar aquí otros métodos

# %%
dataset[ foto_mes==202006, internet:=NA]
dataset[ foto_mes==202006, mrentabilidad:=NA]
dataset[ foto_mes==202006, mrentabilidad_annual:=NA]
dataset[ foto_mes==202006, mcomisiones:=NA]
dataset[ foto_mes==202006, mactivos_margen:=NA]
dataset[ foto_mes==202006, mpasivos_margen:=NA]
dataset[ foto_mes==202006, mcuentas_saldo:=NA]
dataset[ foto_mes==202006, ctarjeta_visa_transacciones:=NA]
dataset[ foto_mes==202006, mtarjeta_visa_consumo:=NA]
dataset[ foto_mes==202006, mtarjeta_master_consumo:=NA]
dataset[ foto_mes==202006, ccallcenter_transacciones:=NA]
dataset[ foto_mes==202006, chomebanking_transacciones:=NA]
dataset[ foto_mes==202006, chomebanking_transacciones:=NA]

# %% [markdown]
# #### 6.3.1.3  DR  Data Drifting
# Se intenta corregir el data drifting, quizas ajustando por IPC ...
# <br>Esta parte podrá ser abordada por todos los Analistas y también la Gerenciapero se decide pedagogicamente no incluirla en esta primer version para reducir la carga cognitiva

# %%
# sin codigo en esta primera version del workflow

# %% [markdown]
# #### 6.3.1.3  FE_intra_manual Feature Engineering intra-mes
#
# Agrego campos nuevos dentro del mismo mes, SIN considerar la historia.

# %%
# esta funcion atributos presentes existe debido a que las modalidades poseen datasets con distinta cantidad de campos
atributos_presentes <- function( patributos )
{
  atributos <- unique( patributos )
  comun <- intersect( atributos, colnames(dataset) )

  return(  length( atributos ) == length( comun ) )
}

# el mes 1,2, ..12
if( atributos_presentes( c("foto_mes") ))
  dataset[, kmes := foto_mes %% 100]

# variable extraida de una tesis de maestria de Irlanda
if( atributos_presentes( c("mpayroll", "cliente_edad") ))
  dataset[, mpayroll_sobre_edad := mpayroll / cliente_edad]

# %%
# visualizo las columas del dataset a esta etapa
colnames(dataset)
# Out:
#  [1] "numero_de_cliente"           "foto_mes"
#  [3] "internet"                    "cliente_edad"
#  [5] "cliente_antiguedad"          "mrentabilidad"
#  [7] "mrentabilidad_annual"        "mcomisiones"
#  [9] "mactivos_margen"             "mpasivos_margen"
# [11] "cproductos"                  "mcuenta_corriente"
# [13] "mcaja_ahorro"                "cdescubierto_preacordado"
# [15] "mcuentas_saldo"              "ctarjeta_visa_transacciones"
# [17] "mtarjeta_visa_consumo"       "mtarjeta_master_consumo"
# [19] "mprestamos_personales"       "cpayroll_trx"
# [21] "mpayroll"                    "ccomisiones_mantenimiento"
# [23] "ccallcenter_transacciones"   "chomebanking_transacciones"
# [25] "ctrx_quarter"                "Master_status"
# [27] "Master_fechaalta"            "Master_mpagominimo"
# [29] "Visa_status"                 "Visa_fechaalta"
# [31] "Visa_mpagominimo"            "clase_ternaria"
# [33] "kmes"                        "mpayroll_sobre_edad"

# %% [markdown]
# #### 6.3.1.4  FE_rf Feature Engineering de nuevas variables a partir de hojas de Random Forest
#
# Esto se mostrará unicamente a la *modalidad Analista Sr*

# %%
# No se implementa Feature Engineering a partir de Random Forest

# %% [markdown]
# #### 6.3.1.5  FEhist Feature Engineering historico
#
# El Fature Engineering Histórico es la etapa que más aporta a la ganancia final, ya que enriquece cada registro del dataset con su historia.

# %% [markdown]
# Para cada campo del dataset original (*)
# se crean lo siguientes campos de a partir de la historia
# * lag1  lags de orden 1
# * delta1  =  valor actual - lag1
# * lag2  lags de orden 2
# * delta2  = valor actual - lag2
#
#
# (*) Excepto para los campos  <numero_de_cliente,  foto_mes,  clase_ternaria>

# %%
# Feature Engineering Historico

# todo es lagueable, menos la primary key y la clase
cols_lagueables <- copy( setdiff(
    colnames(dataset),
    c("numero_de_cliente", "foto_mes", "clase_ternaria")
) )

# https://rdrr.io/cran/data.table/man/shift.html

# lags de orden 1
dataset[,
    paste0(cols_lagueables, "_lag1") := shift(.SD, 1, NA, "lag"),
    by = numero_de_cliente,
    .SDcols = cols_lagueables
]

# lags de orden 2
dataset[,
    paste0(cols_lagueables, "_lag2") := shift(.SD, 2, NA, "lag"),
    by = numero_de_cliente,
    .SDcols = cols_lagueables
]

# agrego los delta lags
for (vcol in cols_lagueables)
{
    dataset[, paste0(vcol, "_delta1") := get(vcol) - get(paste0(vcol, "_lag1"))]
    dataset[, paste0(vcol, "_delta2") := get(vcol) - get(paste0(vcol, "_lag2"))]
}

# %% [markdown]
# Verificacion de los campos recien creados

# %%
ncol(dataset)
colnames(dataset)
# Out:
# [1] 158
#   [1] "numero_de_cliente"                  "foto_mes"
#   [3] "internet"                           "cliente_edad"
#   [5] "cliente_antiguedad"                 "mrentabilidad"
#   [7] "mrentabilidad_annual"               "mcomisiones"
#   [9] "mactivos_margen"                    "mpasivos_margen"
#  [11] "cproductos"                         "mcuenta_corriente"
#  [13] "mcaja_ahorro"                       "cdescubierto_preacordado"
#  [15] "mcuentas_saldo"                     "ctarjeta_visa_transacciones"
#  [17] "mtarjeta_visa_consumo"              "mtarjeta_master_consumo"
#  [19] "mprestamos_personales"              "cpayroll_trx"
#  [21] "mpayroll"                           "ccomisiones_mantenimiento"
#  [23] "ccallcenter_transacciones"          "chomebanking_transacciones"
#  [25] "ctrx_quarter"                       "Master_status"
#  [27] "Master_fechaalta"                   "Master_mpagominimo"
#  [29] "Visa_status"                        "Visa_fechaalta"
#  [31] "Visa_mpagominimo"                   "clase_ternaria"
#  [33] "kmes"                               "mpayroll_sobre_edad"
#  [35] "internet_lag1"                      "cliente_edad_lag1"
#  [37] "cliente_antiguedad_lag1"            "mrentabilidad_lag1"
#  [39] "mrentabilidad_annual_lag1"          "mcomisiones_lag1"
#  [41] "mactivos_margen_lag1"               "mpasivos_margen_lag1"
#  [43] "cproductos_lag1"                    "mcuenta_corriente_lag1"
#  [45] "mcaja_ahorro_lag1"                  "cdescubierto_preacordado_lag1"
#  [47] "mcuentas_saldo_lag1"                "ctarjeta_visa_transacciones_lag1"
#  [49] "mtarjeta_visa_consumo_lag1"         "mtarjeta_master_consumo_lag1"
#  [51] "mprestamos_personales_lag1"         "cpayroll_trx_lag1"
#  [53] "mpayroll_lag1"                      "ccomisiones_mantenimiento_lag1"
#  [55] "ccallcenter_transacciones_lag1"     "chomebanking_transacciones_lag1"
#  [57] "ctrx_quarter_lag1"                  "Master_status_lag1"
#  [59] "Master_fechaalta_lag1"              "Master_mpagominimo_lag1"
#  [61] "Visa_status_lag1"                   "Visa_fechaalta_lag1"
#  [63] "Visa_mpagominimo_lag1"              "kmes_lag1"
#  [65] "mpayroll_sobre_edad_lag1"           "internet_lag2"
#  [67] "cliente_edad_lag2"                  "cliente_antiguedad_lag2"
#  [69] "mrentabilidad_lag2"                 "mrentabilidad_annual_lag2"
#  [71] "mcomisiones_lag2"                   "mactivos_margen_lag2"
#  [73] "mpasivos_margen_lag2"               "cproductos_lag2"
#  [75] "mcuenta_corriente_lag2"             "mcaja_ahorro_lag2"
#  [77] "cdescubierto_preacordado_lag2"      "mcuentas_saldo_lag2"
#  [79] "ctarjeta_visa_transacciones_lag2"   "mtarjeta_visa_consumo_lag2"
#  [81] "mtarjeta_master_consumo_lag2"       "mprestamos_personales_lag2"
#  [83] "cpayroll_trx_lag2"                  "mpayroll_lag2"
#  [85] "ccomisiones_mantenimiento_lag2"     "ccallcenter_transacciones_lag2"
#  [87] "chomebanking_transacciones_lag2"    "ctrx_quarter_lag2"
#  [89] "Master_status_lag2"                 "Master_fechaalta_lag2"
#  [91] "Master_mpagominimo_lag2"            "Visa_status_lag2"
#  [93] "Visa_fechaalta_lag2"                "Visa_mpagominimo_lag2"
#  [95] "kmes_lag2"                          "mpayroll_sobre_edad_lag2"
#  [97] "internet_delta1"                    "internet_delta2"
#  [99] "cliente_edad_delta1"                "cliente_edad_delta2"
# [101] "cliente_antiguedad_delta1"          "cliente_antiguedad_delta2"
# [103] "mrentabilidad_delta1"               "mrentabilidad_delta2"
# [105] "mrentabilidad_annual_delta1"        "mrentabilidad_annual_delta2"
# [107] "mcomisiones_delta1"                 "mcomisiones_delta2"
# [109] "mactivos_margen_delta1"             "mactivos_margen_delta2"
# [111] "mpasivos_margen_delta1"             "mpasivos_margen_delta2"
# [113] "cproductos_delta1"                  "cproductos_delta2"
# [115] "mcuenta_corriente_delta1"           "mcuenta_corriente_delta2"
# [117] "mcaja_ahorro_delta1"                "mcaja_ahorro_delta2"
# [119] "cdescubierto_preacordado_delta1"    "cdescubierto_preacordado_delta2"
# [121] "mcuentas_saldo_delta1"              "mcuentas_saldo_delta2"
# [123] "ctarjeta_visa_transacciones_delta1" "ctarjeta_visa_transacciones_delta2"
# [125] "mtarjeta_visa_consumo_delta1"       "mtarjeta_visa_consumo_delta2"
# [127] "mtarjeta_master_consumo_delta1"     "mtarjeta_master_consumo_delta2"
# [129] "mprestamos_personales_delta1"       "mprestamos_personales_delta2"
# [131] "cpayroll_trx_delta1"                "cpayroll_trx_delta2"
# [133] "mpayroll_delta1"                    "mpayroll_delta2"
# [135] "ccomisiones_mantenimiento_delta1"   "ccomisiones_mantenimiento_delta2"
# [137] "ccallcenter_transacciones_delta1"   "ccallcenter_transacciones_delta2"
# [139] "chomebanking_transacciones_delta1"  "chomebanking_transacciones_delta2"
# [141] "ctrx_quarter_delta1"                "ctrx_quarter_delta2"
# [143] "Master_status_delta1"               "Master_status_delta2"
# [145] "Master_fechaalta_delta1"            "Master_fechaalta_delta2"
# [147] "Master_mpagominimo_delta1"          "Master_mpagominimo_delta2"
# [149] "Visa_status_delta1"                 "Visa_status_delta2"
# [151] "Visa_fechaalta_delta1"              "Visa_fechaalta_delta2"
# [153] "Visa_mpagominimo_delta1"            "Visa_mpagominimo_delta2"
# [155] "kmes_delta1"                        "kmes_delta2"
# [157] "mpayroll_sobre_edad_delta1"         "mpayroll_sobre_edad_delta2"

# %% [markdown]
# #### 6.3.1.6  FEhist Reduccion dimensionalidad con canaritos
#
# Esta etapa solo se mostrará a la *modalidad Anlista Sr* por algun canal secreto de forma de no confundir a los *Analista Jr*  nni distraer con detalles operativos a la estratégica *Modalidad Gerencial*

# %%
# No se implementa la reduccion de la dimensionalidad con canaritos

# %% [markdown]
# ### 6.3.2 Modelado

# %% [markdown]
# #### 6.3.2.1 Training Strategy
#
# Esta etapa de Workflow de  Training Strategy esta pensada para la *Modalidad Gerencial* que posee el dataset de [202005, 202109]
# <br> Si usted es un Analista, posee el periodo de [201901, 202109] y deberá experimentar en que meses le conviene experimentar
#
# <br> A la *Modalidad Gerencial* no se le complicada la vida con el undersampling de los continua, por eso PARAM$trainingstrategy$training_pct <- 1.0
# <br> Sin embargo, si usted es  *Analista SR* posee un dataset 50 veces ( filas x columnas) más grande que la *Modalidad Gerencial*  y por un tema de velocidad y experimentación más rápida puede llegar a necesitar activar el undersampling de la clase mayoritaria, a pesar de estar corriendo en Google Cloud.

# %% [markdown]
# Se hace una estrategia de entrenamiento muy sencilla, tomando todos los meses posibles, SIN eliminar nada x pandemia ni por ningun otro motivo
#
# * future = 202107  obviamente completo
#
# * final_train =  [ 202005, 202105 ]  SIN undersampling
#
# * training
#    * testing = NO HAY
#    * validation =  202105   completo, sin undersampling
#    * training = [ 202005, 202104 ]  donde se consideran el 100% de los CONTINUA

# %%
PARAM$trainingstrategy$validate <- c(202105)

PARAM$trainingstrategy$training <- c(
  202104, 202103, 202102, 202101,
  202012, 202011, 202010, 202009, 202008, 202007,
  202006, 202005
)

PARAM$trainingstrategy$training_pct <- 1.0


PARAM$trainingstrategy$positivos <- c( "BAJA+1", "BAJA+2")

# %%
# seteo la clase01   1={BAJA+1, BAJA+2}   0={CONTINUA}
dataset[, clase01 := ifelse( clase_ternaria %in% PARAM$trainingstrategy$positivos, 1, 0 )]

# %%
# los campos en los que se entrena
campos_buenos <- copy( setdiff(
    colnames(dataset), c("clase_ternaria","clase01","azar"))
)

# %%
# preparo para que se puede hacer undersampling de los CONTINUA
#  solamente por un tema de VELOCIDAD
set.seed(PARAM$semilla_primigenia, kind = "L'Ecuyer-CMRG")
dataset[, azar:=runif(nrow(dataset))]

# undersampling de los CONTINUA
dataset[, fold_train :=  foto_mes %in%  PARAM$trainingstrategy$training &
    (clase_ternaria %in% c("BAJA+1", "BAJA+2") |
     azar < PARAM$trainingstrategy$training_pct ) ]


if( !require("lightgbm")) install.packages("lightgbm")
require("lightgbm")

dtrain <- lgb.Dataset(
  data= data.matrix(dataset[fold_train == TRUE, campos_buenos, with = FALSE]),
  label= dataset[fold_train == TRUE, clase01],
  free_raw_data= TRUE
)
# Out:
# Loading required package: lightgbm
#
# Warning message in library(package, lib.loc = lib.loc, character.only = TRUE, logical.return = TRUE, :
# “there is no package called ‘lightgbm’”
# Installing package into ‘/usr/local/lib/R/site-library’
# (as ‘lib’ is unspecified)
#
# Loading required package: lightgbm

# %%
# datos de validation
dvalidate <- lgb.Dataset(
  data= data.matrix(dataset[foto_mes %in% PARAM$trainingstrategy$validate, campos_buenos, with = FALSE]),
  label= dataset[foto_mes %in% PARAM$trainingstrategy$validate, clase01],
  free_raw_data= TRUE
)

nrow(dvalidate)
# Out:
# [1] 16469

# %% [markdown]
# ####  6.3.2.2. Hyperparameter Tuning

# %% [markdown]
# * Clase binaria que se optimiza :  positivos = [ BAJA+1, BAJA+2 ]

# %% [markdown]
# * Metrica que se optimiza **AUC** Area Under Curve de la  ROC Curve
#
# es muy importante notar que intencionalmente  **NO** se está optimizando la funcion de ganancia del problema

# %% [markdown]
# * Cantidad de iteraciones inteligentes de la Optimizacion Bayesiana = **10**

# %% [markdown]
# * Parametros no default, fijos de LightGBM que no se optimizan
#   * max_bin = 31 , Alienigenas Ancestrales contruyeron las pirámides y dejaron a la humanidad en un jeroglifico  *max_bin=31*
#   * feature_fraction = 0.5  para poner algo que generalmente no falla
#   * learning_rate = 0.03  para que aprenda lento

# %% [markdown]
# * Parametros que se optimizan en la Bayesian Optimization
#   * num_leaves  [8, 256]
#   * min_data_in_leaf  [8, 8192]

# %%
# paquetes necesarios para la Bayesian Optimization
if(!require("DiceKriging")) install.packages("DiceKriging")
require("DiceKriging")

if(!require("mlrMBO")) install.packages("mlrMBO")
require("mlrMBO")
# Out:
# Loading required package: DiceKriging
#
# Warning message in library(package, lib.loc = lib.loc, character.only = TRUE, logical.return = TRUE, :
# “there is no package called ‘DiceKriging’”
# Installing package into ‘/usr/local/lib/R/site-library’
# (as ‘lib’ is unspecified)
#
# Loading required package: DiceKriging
#
# Loading required package: mlrMBO
#
# Warning message in library(package, lib.loc = lib.loc, character.only = TRUE, logical.return = TRUE, :
# “there is no package called ‘mlrMBO’”
# Installing package into ‘/usr/local/lib/R/site-library’
# (as ‘lib’ is unspecified)
#
# also installing the dependencies ‘XML’, ‘fastmatch’, ‘RcppArmadillo’, ‘mlr’, ‘ParamHelpers’, ‘smoof’, ‘BBmisc’, ‘checkmate’, ‘lhs’, ‘parallelMap’
#
#
# Loading required package: mlrMBO
#
# Loading required package: mlr
#
# Loading required package: ParamHelpers
#
#
# Attaching package: ‘ParamHelpers’
#
#
# The following object is masked from ‘package:R.utils’:
#
#     isVector
#
#
#
# Attaching package: ‘mlr’
#
#
# The following objects are masked from ‘package:R.utils’:
#
#     resample, setThreshold
#
#
# Loading required package: smoof
#
# Loading required package: checkmate
#
#
# Attaching package: ‘checkmate’
#
#
# The following object is masked from ‘package:DiceKriging’:
#
#     checkNames
#
#
# The following object is masked from ‘package:R.utils’:
#
#     asInt
#
#
#
# Attaching package: ‘smoof’
#
#
# The following objects are masked from ‘package:R.oo’:
#
#     getDescription, getName

# %% [markdown]
# Definición de la Bayesian Optimization
# <br> Si se desea optimizar un hiperparámetro que esta como fijo, debe QUITARSE de param_fijos y agregarse a PARAM$hipeparametertuning$hs

# %%
# valor ridiculamente bajo para que corra rapido en el aula y no molestar a la *Modalidad Gerencial*
PARAM$hipeparametertuning$num_interations <- 80

# parametros fijos del LightGBM
PARAM$lgbm$param_fijos <- list(
  objective= "binary",
  metric= "auc",
  first_metric_only= TRUE,
  boost_from_average= TRUE,
  feature_pre_filter= FALSE,
  verbosity= -100,
  force_row_wise= TRUE, # para evitar warning
  max_bin= 31,
  seed= PARAM$semilla_primigenia
  # learning_rate= 0.03,
  # feature_fraction= 0.5,
  # num_iterations= 2048,  # valor grande, lo limita early_stopping_rounds
  # early_stopping_rounds= 200
)


PARAM$hipeparametertuning$hs <- makeParamSet(
  # Núcleo del modelo (estructura de árboles)
  makeIntegerParam("num_leaves", lower = 2L, upper = 8192L),
  #makeIntegerParam("max_depth", lower = 3L, upper = 30L),
  makeNumericParam("min_child_weight", lower = 0.001, upper = 10.0),
  makeIntegerParam("min_data_in_leaf", lower = 2L, upper = 8192L),
  #makeNumericParam("min_gain_to_split", lower = 0.0, upper = 0.1),

  # Regularización
  #makeNumericParam("lambda_l1", lower = 0.0, upper = 1000L),
  makeNumericParam("lambda_l2", lower = 0.0, upper = 1000L),
  #makeNumericParam("scale_pos_weight", lower = 1.0, upper = 5.0),  # útil en desequilibrio

  # Control del aprendizaje
  makeNumericParam("learning_rate", lower = 0.005, upper = 0.1),
  makeIntegerParam("num_iterations", lower = 100L, upper = 5000L),
  #makeIntegerParam("early_stopping_rounds", lower = 50L, upper = 500L),

  # Submuestreo
  makeNumericParam("feature_fraction", lower = 0.05, upper = 1L),   # columnas
  makeNumericParam("bagging_fraction", lower = 0.5, upper = 1L)   # filas
  #makeIntegerParam("bagging_freq", lower = 0L, upper = 5L),         # cada N iteraciones

  # Opcionales útiles
  #makeNumericParam("max_delta_step", lower = 0.0, upper = 10.0),
  #makeNumericParam("path_smooth", lower = 0.0, upper = 10.0)
)
# Total: 8 hT

# %% [markdown]
# Función "señora caja negra"  que es llamada para verificar la realidad por la Bayesian Optimization

# %%
# En  x llegan los parmaetros de la bayesiana
#  devuelve la AUC en validate del modelo entrenado
#  en el parametro x llegan los hiperparámetros que se estan optimizando

EstimarGanancia_AUC_lightgbm <- function(x) {

  # x pisa (o agrega) a param_fijos
  param_completo <- modifyList(PARAM$lgbm$param_fijos, x)

  # entreno LightGBM
  modelo_train <- lgb.train(
    data= dtrain,
    valids= list(valid = dvalidate),
    eval= "auc",
    param= param_completo,
    verbose= -100
  )

  # recupero la AUC en validation
  AUC <- modelo_train$record_evals$valid$auc$eval[[modelo_train$best_iter]]

  # esta es la forma de devolver un parametro extra
  attr(AUC, "extras") <- list("num_iterations"= modelo_train$best_iter)

  # hago espacio en la memoria
  rm(modelo_train)
  gc(full= TRUE, verbose= FALSE)

  message(format(Sys.time(), "%a %b %d %X %Y"), " AUC ", AUC)

  return(AUC)
}

# %% [markdown]
# seteo de la Bayesian Optimization (complejo)
# <br> copiado y pegado de la documentación de la librería

# %%
configureMlr(show.learner.output = FALSE)

# configuro la busqueda bayesiana,  los hiperparametros que se van a optimizar
# por favor, no desesperarse por lo complejo
obj.fun <- makeSingleObjectiveFunction(
    fn= EstimarGanancia_AUC_lightgbm, # la funcion que voy a maximizar
    minimize= FALSE, # estoy Maximizando AUC
    noisy= FALSE,
    par.set= PARAM$hipeparametertuning$hs,
    has.simple.signature= FALSE # paso los parametros en una lista
)

# cada 600 segundos guardo el resultado intermedio
ctrl <- makeMBOControl(
    save.on.disk.at.time= 600,
    save.file.path= "HT.RDATA"
)

# indico la cantidad de iteraciones que va a tener la Bayesian Optimization
ctrl <- setMBOControlTermination(
    ctrl,
    iters= PARAM$hipeparametertuning$num_interations  # cantidad de iteraciones inteligentes
)

# defino el método estandar para la creacion de los puntos iniciales
#   los "No Inteligentes"
ctrl <- setMBOControlInfill(ctrl, crit = makeMBOInfillCritEI())

# mas configuraciones
surr.km <- makeLearner(
    "regr.km",
    predict.type= "se",
    covtype= "matern3_2",
    control= list(trace = TRUE)
)

# %% [markdown]
# Corrida de la Bayesian Optimization,  aqui se hace el trabajo pesado
# <br> por favor no se asuste con los warnings que pudieran aparecer
#
# Si corrío a medias y llegó a las iteraciones inteligentes, en el archivo binario HT.RDATA quedó lo ya procesado y es utilizado para retomar la corrida desde lo último que llegó a grabar.

# %%
# inicio la optimizacion bayesiana

if (!file.exists("HT.RDATA")) {
  bayesiana_salida <- mbo(obj.fun, learner= surr.km, control= ctrl)
} else {
  bayesiana_salida <- mboContinue("HT.RDATA") # retomo en caso que ya exista
}
# Out:
# Computing y column(s) for design. Not provided.
#
# Wed Nov 19 02:54:58 AM 2025 AUC 0.914471445856141
#
# Wed Nov 19 02:59:28 AM 2025 AUC 0.921022716215409
#
# Wed Nov 19 03:06:47 AM 2025 AUC 0.916607445195813
#
# Wed Nov 19 03:07:10 AM 2025 AUC 0.902142810647651
#
# Wed Nov 19 03:12:31 AM 2025 AUC 0.915181767973968
#
# Wed Nov 19 03:19:19 AM 2025 AUC 0.923475793685146
#
# Wed Nov 19 03:26:14 AM 2025 AUC 0.922196744127679
#
# Wed Nov 19 03:32:31 AM 2025 AUC 0.924606202383756
#
# Wed Nov 19 03:36:09 AM 2025 AUC 0.919100786555082
#
# Wed Nov 19 03:43:14 AM 2025 AUC 0.917318102846053
#
# Wed Nov 19 03:44:24 AM 2025 AUC 0.90830670883638
#
# Wed Nov 19 03:50:32 AM 2025 AUC 0.921748472824223
#
# Wed Nov 19 03:54:28 AM 2025 AUC 0.917545929354322
#
# Wed Nov 19 04:01:09 AM 2025 AUC 0.919023614100146
#
# Wed Nov 19 04:09:30 AM 2025 AUC 0.918132440011838
#
# Wed Nov 19 04:12:20 AM 2025 AUC 0.902087615565751
#
# Wed Nov 19 04:12:46 AM 2025 AUC 0.890127059414066
#
# Wed Nov 19 04:16:54 AM 2025 AUC 0.920498279054255
#
# Wed Nov 19 04:21:27 AM 2025 AUC 0.918794780994639
#
# Wed Nov 19 04:24:32 AM 2025 AUC 0.909092190214667
#
# Wed Nov 19 04:36:47 AM 2025 AUC 0.916812455500014
#
# Wed Nov 19 04:41:45 AM 2025 AUC 0.921711564258819
#
# Wed Nov 19 04:47:19 AM 2025 AUC 0.917490230973802
#
# Wed Nov 19 04:55:46 AM 2025 AUC 0.914450307314137
#
# Wed Nov 19 04:58:04 AM 2025 AUC 0.908166456287844
#
# Wed Nov 19 05:09:52 AM 2025 AUC 0.918054932024489
#
# Wed Nov 19 05:11:11 AM 2025 AUC 0.916957405502329
#
# Wed Nov 19 05:13:17 AM 2025 AUC 0.912190496514154
#
# Wed Nov 19 05:27:26 AM 2025 AUC 0.924432732126356
#
# Wed Nov 19 05:40:47 AM 2025 AUC 0.93046325618101
#
# Wed Nov 19 05:46:07 AM 2025 AUC 0.914178190527383
#
# Wed Nov 19 05:47:51 AM 2025 AUC 0.914916026303057
#
# [mbo] 0: num_leaves=7099; min_child_weight=4.97; min_data_in_leaf=4299; lambda_l2=180; learning_rate=0.0701; num_iterations=1110; feature_fraction=0.916; bagging_fraction=0.885 : y = 0.914 : 146.3 secs : initdesign
#
# [mbo] 0: num_leaves=6033; min_child_weight=7.58; min_data_in_leaf=2845; lambda_l2=97.9; learning_rate=0.0222; num_iterations=2229; feature_fraction=0.223; bagging_fraction=0.686 : y = 0.921 : 270.1 secs : initdesign
#
# [mbo] 0: num_leaves=2736; min_child_weight=6.29; min_data_in_leaf=3880; lambda_l2=630; learning_rate=0.0406; num_iterations=3662; feature_fraction=0.654; bagging_fraction=0.724 : y = 0.917 : 439.4 secs : initdesign
#
# [mbo] 0: num_leaves=5586; min_child_weight=1.79; min_data_in_leaf=2007; lambda_l2=489; learning_rate=0.0503; num_iterations=145; feature_fraction=0.57; bagging_fraction=0.827 : y = 0.902 : 22.9 secs : initdesign
#
# [mbo] 0: num_leaves=5233; min_child_weight=6.01; min_data_in_leaf=4852; lambda_l2=530; learning_rate=0.0344; num_iterations=2776; feature_fraction=0.755; bagging_fraction=0.573 : y = 0.915 : 321.3 secs : initdesign
#
# [mbo] 0: num_leaves=837; min_child_weight=4.3; min_data_in_leaf=2456; lambda_l2=323; learning_rate=0.0659; num_iterations=2513; feature_fraction=0.455; bagging_fraction=0.75 : y = 0.923 : 407.7 secs : initdesign
#
# [mbo] 0: num_leaves=4879; min_child_weight=4.44; min_data_in_leaf=3308; lambda_l2=603; learning_rate=0.0941; num_iterations=3419; feature_fraction=0.261; bagging_fraction=0.808 : y = 0.922 : 415.2 secs : initdesign
#
# [mbo] 0: num_leaves=3024; min_child_weight=3.35; min_data_in_leaf=25; lambda_l2=392; learning_rate=0.0851; num_iterations=2306; feature_fraction=0.794; bagging_fraction=0.985 : y = 0.925 : 376.3 secs : initdesign
#
# [mbo] 0: num_leaves=4382; min_child_weight=8.16; min_data_in_leaf=3698; lambda_l2=277; learning_rate=0.0709; num_iterations=1566; feature_fraction=0.351; bagging_fraction=0.716 : y = 0.919 : 218.7 secs : initdesign
#
# [mbo] 0: num_leaves=2325; min_child_weight=6.71; min_data_in_leaf=5041; lambda_l2=944; learning_rate=0.0622; num_iterations=3802; feature_fraction=0.231; bagging_fraction=0.67 : y = 0.917 : 424.4 secs : initdesign
#
# [mbo] 0: num_leaves=3429; min_child_weight=3.63; min_data_in_leaf=3412; lambda_l2=898; learning_rate=0.0462; num_iterations=547; feature_fraction=0.341; bagging_fraction=0.792 : y = 0.908 : 70.3 secs : initdesign
#
# [mbo] 0: num_leaves=643; min_child_weight=5.03; min_data_in_leaf=7012; lambda_l2=152; learning_rate=0.0879; num_iterations=2872; feature_fraction=0.316; bagging_fraction=0.53 : y = 0.922 : 368.3 secs : initdesign
#
# [mbo] 0: num_leaves=1799; min_child_weight=1.96; min_data_in_leaf=2675; lambda_l2=739; learning_rate=0.0982; num_iterations=1836; feature_fraction=0.631; bagging_fraction=0.696 : y = 0.918 : 235.9 secs : initdesign
#
# [mbo] 0: num_leaves=6263; min_child_weight=9.61; min_data_in_leaf=485; lambda_l2=714; learning_rate=0.0356; num_iterations=3056; feature_fraction=0.698; bagging_fraction=0.618 : y = 0.919 : 400.9 secs : initdesign
#
# [mbo] 0: num_leaves=3783; min_child_weight=5.43; min_data_in_leaf=5212; lambda_l2=217; learning_rate=0.0573; num_iterations=4122; feature_fraction=0.865; bagging_fraction=0.773 : y = 0.918 : 500.5 secs : initdesign
#
# [mbo] 0: num_leaves=4800; min_child_weight=9.25; min_data_in_leaf=6431; lambda_l2=796; learning_rate=0.00687; num_iterations=1987; feature_fraction=0.136; bagging_fraction=0.586 : y = 0.902 : 170.2 secs : initdesign
#
# [mbo] 0: num_leaves=3901; min_child_weight=0.241; min_data_in_leaf=5780; lambda_l2=660; learning_rate=0.012; num_iterations=337; feature_fraction=0.781; bagging_fraction=0.64 : y = 0.89 : 25.8 secs : initdesign
#
# [mbo] 0: num_leaves=7481; min_child_weight=2.44; min_data_in_leaf=1712; lambda_l2=243; learning_rate=0.0481; num_iterations=1449; feature_fraction=0.43; bagging_fraction=0.915 : y = 0.92 : 248.1 secs : initdesign
#
# [mbo] 0: num_leaves=7355; min_child_weight=1.39; min_data_in_leaf=7466; lambda_l2=912; learning_rate=0.0756; num_iterations=3564; feature_fraction=0.0613; bagging_fraction=0.902 : y = 0.919 : 273.0 secs : initdesign
#
# [mbo] 0: num_leaves=4339; min_child_weight=8.95; min_data_in_leaf=4364; lambda_l2=859; learning_rate=0.0264; num_iterations=1778; feature_fraction=0.851; bagging_fraction=0.951 : y = 0.909 : 184.8 secs : initdesign
#
# [mbo] 0: num_leaves=119; min_child_weight=5.74; min_data_in_leaf=1396; lambda_l2=842; learning_rate=0.0151; num_iterations=4943; feature_fraction=0.389; bagging_fraction=0.847 : y = 0.917 : 735.0 secs : initdesign
#
# [mbo] 0: num_leaves=8053; min_child_weight=2.58; min_data_in_leaf=8060; lambda_l2=19.9; learning_rate=0.0909; num_iterations=2593; feature_fraction=0.892; bagging_fraction=0.842 : y = 0.922 : 297.9 secs : initdesign
#
# [mbo] 0: num_leaves=6471; min_child_weight=0.729; min_data_in_leaf=6024; lambda_l2=466; learning_rate=0.0405; num_iterations=3301; feature_fraction=0.166; bagging_fraction=0.533 : y = 0.917 : 334.2 secs : initdesign
#
# [mbo] 0: num_leaves=5771; min_child_weight=1.09; min_data_in_leaf=6691; lambda_l2=572; learning_rate=0.0198; num_iterations=4837; feature_fraction=0.99; bagging_fraction=0.925 : y = 0.914 : 507.6 secs : initdesign
#
# [mbo] 0: num_leaves=3102; min_child_weight=7.49; min_data_in_leaf=553; lambda_l2=307; learning_rate=0.00826; num_iterations=1297; feature_fraction=0.179; bagging_fraction=0.747 : y = 0.908 : 137.3 secs : initdesign
#
# [mbo] 0: num_leaves=2091; min_child_weight=3.76; min_data_in_leaf=7400; lambda_l2=978; learning_rate=0.0929; num_iterations=4687; feature_fraction=0.592; bagging_fraction=0.562 : y = 0.918 : 708.0 secs : initdesign
#
# [mbo] 0: num_leaves=419; min_child_weight=8.11; min_data_in_leaf=1078; lambda_l2=420; learning_rate=0.0778; num_iterations=642; feature_fraction=0.721; bagging_fraction=0.6 : y = 0.917 : 79.6 secs : initdesign
#
# [mbo] 0: num_leaves=1701; min_child_weight=2.93; min_data_in_leaf=6304; lambda_l2=351; learning_rate=0.053; num_iterations=786; feature_fraction=0.505; bagging_fraction=0.98 : y = 0.912 : 126.2 secs : initdesign
#
# [mbo] 0: num_leaves=6912; min_child_weight=7.09; min_data_in_leaf=816; lambda_l2=544; learning_rate=0.0806; num_iterations=4327; feature_fraction=0.55; bagging_fraction=0.965 : y = 0.924 : 848.8 secs : initdesign
#
# [mbo] 0: num_leaves=1365; min_child_weight=0.501; min_data_in_leaf=2227; lambda_l2=53.8; learning_rate=0.0299; num_iterations=4476; feature_fraction=0.481; bagging_fraction=0.656 : y = 0.93 : 800.5 secs : initdesign
#
# [mbo] 0: num_leaves=1239; min_child_weight=9.79; min_data_in_leaf=7716; lambda_l2=756; learning_rate=0.0231; num_iterations=3985; feature_fraction=0.0887; bagging_fraction=0.862 : y = 0.914 : 320.3 secs : initdesign
#
# [mbo] 0: num_leaves=7728; min_child_weight=8.75; min_data_in_leaf=5567; lambda_l2=87.3; learning_rate=0.0587; num_iterations=872; feature_fraction=0.958; bagging_fraction=0.503 : y = 0.915 : 104.0 secs : initdesign
#
# Saved the current state after iteration 1 in the file HT.RDATA.
#
# Wed Nov 19 05:56:56 AM 2025 AUC 0.937929523429893
#
# [mbo] 1: num_leaves=1251; min_child_weight=2.13; min_data_in_leaf=110; lambda_l2=0.256; learning_rate=0.0616; num_iterations=4409; feature_fraction=0.266; bagging_fraction=0.85 : y = 0.938 : 543.7 secs : infill_ei
#
# Wed Nov 19 06:04:42 AM 2025 AUC 0.934409788419971
#
# [mbo] 2: num_leaves=594; min_child_weight=4.92; min_data_in_leaf=81; lambda_l2=0.0428; learning_rate=0.0966; num_iterations=4937; feature_fraction=0.136; bagging_fraction=0.922 : y = 0.934 : 465.3 secs : infill_ei
#
# Saved the current state after iteration 3 in the file HT.RDATA.
#
# Wed Nov 19 06:12:10 AM 2025 AUC 0.942964522815869
#
# [mbo] 3: num_leaves=1850; min_child_weight=0.956; min_data_in_leaf=6; lambda_l2=0.932; learning_rate=0.0497; num_iterations=4949; feature_fraction=0.0877; bagging_fraction=0.985 : y = 0.943 : 447.5 secs : infill_ei
#
# Wed Nov 19 06:19:51 AM 2025 AUC 0.931784247290072
#
# [mbo] 4: num_leaves=1887; min_child_weight=0.0133; min_data_in_leaf=2335; lambda_l2=0.261; learning_rate=0.0694; num_iterations=4948; feature_fraction=0.0921; bagging_fraction=1 : y = 0.932 : 459.5 secs : infill_ei
#
# Saved the current state after iteration 5 in the file HT.RDATA.
#
# Wed Nov 19 06:36:46 AM 2025 AUC 0.933255556920054
#
# [mbo] 5: num_leaves=2125; min_child_weight=0.396; min_data_in_leaf=6; lambda_l2=11.2; learning_rate=0.0414; num_iterations=5000; feature_fraction=0.489; bagging_fraction=0.938 : y = 0.933 : 1014.7 secs : infill_ei
#
# Saved the current state after iteration 6 in the file HT.RDATA.
#
# Wed Nov 19 06:43:07 AM 2025 AUC 0.933725973362753
#
# [mbo] 6: num_leaves=571; min_child_weight=2.73; min_data_in_leaf=12; lambda_l2=12.5; learning_rate=0.0458; num_iterations=4475; feature_fraction=0.0502; bagging_fraction=0.981 : y = 0.934 : 380.0 secs : infill_ei
#
# Wed Nov 19 06:51:15 AM 2025 AUC 0.93341157949199
#
# [mbo] 7: num_leaves=1753; min_child_weight=1.84; min_data_in_leaf=3; lambda_l2=91.7; learning_rate=0.0498; num_iterations=4946; feature_fraction=0.0985; bagging_fraction=0.606 : y = 0.933 : 487.1 secs : infill_ei
#
# Saved the current state after iteration 8 in the file HT.RDATA.
#
# Wed Nov 19 07:03:14 AM 2025 AUC 0.932674079248729
#
# [mbo] 8: num_leaves=4501; min_child_weight=0.171; min_data_in_leaf=4; lambda_l2=32; learning_rate=0.0541; num_iterations=4838; feature_fraction=0.206; bagging_fraction=0.914 : y = 0.933 : 718.0 secs : infill_ei
#
# Saved the current state after iteration 9 in the file HT.RDATA.
#
# Wed Nov 19 07:10:34 AM 2025 AUC 0.93175237171086
#
# [mbo] 9: num_leaves=2312; min_child_weight=9.37; min_data_in_leaf=6; lambda_l2=63.6; learning_rate=0.0557; num_iterations=4890; feature_fraction=0.0889; bagging_fraction=0.989 : y = 0.932 : 439.6 secs : infill_ei
#
# Wed Nov 19 07:17:45 AM 2025 AUC 0.937918115327859
#
# [mbo] 10: num_leaves=8047; min_child_weight=3.6; min_data_in_leaf=704; lambda_l2=0.743; learning_rate=0.0351; num_iterations=4963; feature_fraction=0.054; bagging_fraction=0.998 : y = 0.938 : 429.7 secs : infill_ei
#
# Saved the current state after iteration 11 in the file HT.RDATA.
#
# Wed Nov 19 07:24:47 AM 2025 AUC 0.932538188621559
#
# [mbo] 11: num_leaves=8185; min_child_weight=1.84; min_data_in_leaf=1831; lambda_l2=67; learning_rate=0.0449; num_iterations=4979; feature_fraction=0.0501; bagging_fraction=0.657 : y = 0.933 : 421.3 secs : infill_ei
#
# Wed Nov 19 07:30:21 AM 2025 AUC 0.933666919658106
#
# [mbo] 12: num_leaves=7818; min_child_weight=4.76; min_data_in_leaf=11; lambda_l2=1.19; learning_rate=0.098; num_iterations=3961; feature_fraction=0.054; bagging_fraction=0.852 : y = 0.934 : 333.9 secs : infill_ei
#
# Saved the current state after iteration 13 in the file HT.RDATA.
#
# Wed Nov 19 07:35:30 AM 2025 AUC 0.938120105840344
#
# [mbo] 13: num_leaves=774; min_child_weight=1.14; min_data_in_leaf=6; lambda_l2=2.17; learning_rate=0.0798; num_iterations=3564; feature_fraction=0.0547; bagging_fraction=0.928 : y = 0.938 : 308.3 secs : infill_ei
#
# Wed Nov 19 07:43:51 AM 2025 AUC 0.933286425902029
#
# [mbo] 14: num_leaves=5828; min_child_weight=2.05; min_data_in_leaf=39; lambda_l2=1.58; learning_rate=0.0934; num_iterations=4994; feature_fraction=0.148; bagging_fraction=0.999 : y = 0.933 : 499.4 secs : infill_ei
#
# Saved the current state after iteration 15 in the file HT.RDATA.
#
# Wed Nov 19 07:50:50 AM 2025 AUC 0.930986015680101
#
# [mbo] 15: num_leaves=8121; min_child_weight=8.06; min_data_in_leaf=807; lambda_l2=0.256; learning_rate=0.0651; num_iterations=4998; feature_fraction=0.0512; bagging_fraction=0.821 : y = 0.931 : 418.8 secs : infill_ei
#
# Wed Nov 19 07:57:30 AM 2025 AUC 0.920579813430557
#
# [mbo] 16: num_leaves=8168; min_child_weight=1.69; min_data_in_leaf=4; lambda_l2=800; learning_rate=0.0412; num_iterations=4854; feature_fraction=0.0502; bagging_fraction=0.948 : y = 0.921 : 398.9 secs : infill_ei
#
# Saved the current state after iteration 17 in the file HT.RDATA.
#
# Wed Nov 19 08:04:46 AM 2025 AUC 0.93380683667423
#
# [mbo] 17: num_leaves=2590; min_child_weight=1.25; min_data_in_leaf=176; lambda_l2=16.8; learning_rate=0.0477; num_iterations=4344; feature_fraction=0.0975; bagging_fraction=0.999 : y = 0.934 : 435.9 secs : infill_ei
#
# Wed Nov 19 08:16:43 AM 2025 AUC 0.929902581519277
#
# [mbo] 18: num_leaves=8165; min_child_weight=6.02; min_data_in_leaf=1678; lambda_l2=0.421; learning_rate=0.0135; num_iterations=4998; feature_fraction=0.874; bagging_fraction=0.977 : y = 0.93 : 716.4 secs : infill_ei
#
# Saved the current state after iteration 19 in the file HT.RDATA.
#
# Wed Nov 19 08:23:37 AM 2025 AUC 0.935268751396654
#
# [mbo] 19: num_leaves=809; min_child_weight=1.67; min_data_in_leaf=414; lambda_l2=1.85; learning_rate=0.0978; num_iterations=3768; feature_fraction=0.199; bagging_fraction=0.723 : y = 0.935 : 412.6 secs : infill_ei
#
# Wed Nov 19 08:26:39 AM 2025 AUC 0.925386650775852
#
# [mbo] 20: num_leaves=1401; min_child_weight=4.34; min_data_in_leaf=23; lambda_l2=1.29; learning_rate=0.0988; num_iterations=1334; feature_fraction=0.298; bagging_fraction=0.871 : y = 0.925 : 180.7 secs : infill_ei
#
# Wed Nov 19 08:37:47 AM 2025 AUC 0.937080626425593
#
# [mbo] 21: num_leaves=7328; min_child_weight=0.2; min_data_in_leaf=120; lambda_l2=0.73; learning_rate=0.0238; num_iterations=4325; feature_fraction=0.268; bagging_fraction=0.767 : y = 0.937 : 667.7 secs : infill_ei
#
# Saved the current state after iteration 22 in the file HT.RDATA.
#
# Wed Nov 19 08:45:40 AM 2025 AUC 0.939682680286598
#
# [mbo] 22: num_leaves=5986; min_child_weight=1.88; min_data_in_leaf=2; lambda_l2=0.999; learning_rate=0.0596; num_iterations=3556; feature_fraction=0.287; bagging_fraction=0.797 : y = 0.94 : 471.9 secs : infill_ei
#
# Wed Nov 19 08:55:08 AM 2025 AUC 0.931331278532838
#
# [mbo] 23: num_leaves=1556; min_child_weight=0.708; min_data_in_leaf=173; lambda_l2=0.446; learning_rate=0.0671; num_iterations=3353; feature_fraction=0.467; bagging_fraction=0.749 : y = 0.931 : 566.3 secs : infill_ei
#
# Saved the current state after iteration 24 in the file HT.RDATA.
#
# Wed Nov 19 09:04:35 AM 2025 AUC 0.93781879773368
#
# [mbo] 24: num_leaves=8174; min_child_weight=1.97; min_data_in_leaf=217; lambda_l2=0.404; learning_rate=0.048; num_iterations=3845; feature_fraction=0.355; bagging_fraction=0.887 : y = 0.938 : 566.1 secs : infill_ei
#
# Wed Nov 19 09:12:47 AM 2025 AUC 0.935503959618003
#
# [mbo] 25: num_leaves=7884; min_child_weight=3.48; min_data_in_leaf=97; lambda_l2=0.553; learning_rate=0.0303; num_iterations=3563; feature_fraction=0.282; bagging_fraction=0.71 : y = 0.936 : 491.5 secs : infill_ei
#
# Saved the current state after iteration 26 in the file HT.RDATA.
#
# Wed Nov 19 09:18:13 AM 2025 AUC 0.93702928996644
#
# [mbo] 26: num_leaves=6668; min_child_weight=0.632; min_data_in_leaf=14; lambda_l2=0.852; learning_rate=0.0584; num_iterations=3620; feature_fraction=0.0595; bagging_fraction=0.933 : y = 0.937 : 325.2 secs : infill_ei
#
# Wed Nov 19 09:27:15 AM 2025 AUC 0.934607417011091
#
# [mbo] 27: num_leaves=6529; min_child_weight=4.71; min_data_in_leaf=11; lambda_l2=0.374; learning_rate=0.082; num_iterations=3578; feature_fraction=0.422; bagging_fraction=0.942 : y = 0.935 : 541.0 secs : infill_ei
#
# Saved the current state after iteration 28 in the file HT.RDATA.
#
# Wed Nov 19 09:34:51 AM 2025 AUC 0.93146012297934
#
# [mbo] 28: num_leaves=5838; min_child_weight=5.8; min_data_in_leaf=367; lambda_l2=3.02; learning_rate=0.0405; num_iterations=4948; feature_fraction=0.0888; bagging_fraction=0.869 : y = 0.931 : 454.6 secs : infill_ei
#
# Wed Nov 19 09:44:18 AM 2025 AUC 0.932312039775354
#
# [mbo] 29: num_leaves=7217; min_child_weight=4.31; min_data_in_leaf=89; lambda_l2=0.866; learning_rate=0.0665; num_iterations=4189; feature_fraction=0.32; bagging_fraction=0.686 : y = 0.932 : 566.1 secs : infill_ei
#
# Saved the current state after iteration 30 in the file HT.RDATA.
#
# Wed Nov 19 09:49:11 AM 2025 AUC 0.931343357699697
#
# [mbo] 30: num_leaves=7218; min_child_weight=2.24; min_data_in_leaf=479; lambda_l2=2.09; learning_rate=0.0554; num_iterations=2961; feature_fraction=0.102; bagging_fraction=0.845 : y = 0.931 : 291.8 secs : infill_ei
#
# Wed Nov 19 09:56:03 AM 2025 AUC 0.929488198989511
#
# [mbo] 31: num_leaves=1504; min_child_weight=2.65; min_data_in_leaf=112; lambda_l2=397; learning_rate=0.088; num_iterations=4389; feature_fraction=0.09; bagging_fraction=0.999 : y = 0.929 : 411.0 secs : infill_ei
#
# Saved the current state after iteration 32 in the file HT.RDATA.
#
# Wed Nov 19 10:02:51 AM 2025 AUC 0.940790608313554
#
# [mbo] 32: num_leaves=2413; min_child_weight=1.26; min_data_in_leaf=23; lambda_l2=0.278; learning_rate=0.0175; num_iterations=3866; feature_fraction=0.112; bagging_fraction=0.798 : y = 0.941 : 407.1 secs : infill_ei
#
# Wed Nov 19 10:11:22 AM 2025 AUC 0.932731790823725
#
# [mbo] 33: num_leaves=5822; min_child_weight=0.149; min_data_in_leaf=17; lambda_l2=0.245; learning_rate=0.059; num_iterations=3755; feature_fraction=0.687; bagging_fraction=0.551 : y = 0.933 : 510.2 secs : infill_ei
#
# Saved the current state after iteration 34 in the file HT.RDATA.
#
# Wed Nov 19 10:19:51 AM 2025 AUC 0.927137123373255
#
# [mbo] 34: num_leaves=1618; min_child_weight=9.94; min_data_in_leaf=12; lambda_l2=3.59; learning_rate=0.0998; num_iterations=3586; feature_fraction=0.371; bagging_fraction=0.792 : y = 0.927 : 507.5 secs : infill_ei
#
# Wed Nov 19 10:33:32 AM 2025 AUC 0.935128498848117
#
# [mbo] 35: num_leaves=6466; min_child_weight=1.41; min_data_in_leaf=99; lambda_l2=1.71; learning_rate=0.0133; num_iterations=3817; feature_fraction=0.577; bagging_fraction=0.721 : y = 0.935 : 820.1 secs : infill_ei
#
# Saved the current state after iteration 36 in the file HT.RDATA.
#
# Wed Nov 19 10:41:57 AM 2025 AUC 0.927908847922618
#
# [mbo] 36: num_leaves=580; min_child_weight=1.66; min_data_in_leaf=4303; lambda_l2=0.18; learning_rate=0.00542; num_iterations=4996; feature_fraction=0.137; bagging_fraction=0.847 : y = 0.928 : 504.1 secs : infill_ei
#
# Wed Nov 19 10:50:37 AM 2025 AUC 0.933446810395331
#
# [mbo] 37: num_leaves=1883; min_child_weight=1.95; min_data_in_leaf=26; lambda_l2=25.5; learning_rate=0.0446; num_iterations=3710; feature_fraction=0.25; bagging_fraction=0.847 : y = 0.933 : 519.1 secs : infill_ei
#
# Saved the current state after iteration 38 in the file HT.RDATA.
#
# Wed Nov 19 11:04:39 AM 2025 AUC 0.930864217414266
#
# [mbo] 38: num_leaves=5564; min_child_weight=0.294; min_data_in_leaf=6; lambda_l2=71.3; learning_rate=0.064; num_iterations=3618; feature_fraction=0.529; bagging_fraction=0.84 : y = 0.931 : 840.6 secs : infill_ei
#
# Saved the current state after iteration 39 in the file HT.RDATA.
#
# Wed Nov 19 11:11:51 AM 2025 AUC 0.939791392788335
#
# [mbo] 39: num_leaves=5550; min_child_weight=0.497; min_data_in_leaf=12; lambda_l2=0.569; learning_rate=0.0088; num_iterations=4000; feature_fraction=0.0516; bagging_fraction=0.656 : y = 0.94 : 431.8 secs : infill_ei
#
# Wed Nov 19 11:25:15 AM 2025 AUC 0.922832913582285
#
# [mbo] 40: num_leaves=938; min_child_weight=0.509; min_data_in_leaf=612; lambda_l2=436; learning_rate=0.0992; num_iterations=4874; feature_fraction=0.867; bagging_fraction=0.531 : y = 0.923 : 802.8 secs : infill_ei
#
# Saved the current state after iteration 41 in the file HT.RDATA.
#
# Wed Nov 19 11:35:13 AM 2025 AUC 0.927294488074842
#
# [mbo] 41: num_leaves=4870; min_child_weight=8.01; min_data_in_leaf=17; lambda_l2=0.315; learning_rate=0.0987; num_iterations=3881; feature_fraction=0.45; bagging_fraction=0.574 : y = 0.927 : 597.6 secs : infill_ei
#
# Wed Nov 19 11:42:19 AM 2025 AUC 0.931918795787592
#
# [mbo] 42: num_leaves=8186; min_child_weight=9.08; min_data_in_leaf=1200; lambda_l2=1.94; learning_rate=0.0112; num_iterations=3892; feature_fraction=0.127; bagging_fraction=0.895 : y = 0.932 : 424.3 secs : infill_ei
#
# Saved the current state after iteration 43 in the file HT.RDATA.
#
# Wed Nov 19 11:48:14 AM 2025 AUC 0.941926049998356
#
# [mbo] 43: num_leaves=4487; min_child_weight=2.17; min_data_in_leaf=7; lambda_l2=0.263; learning_rate=0.016; num_iterations=3346; feature_fraction=0.102; bagging_fraction=0.748 : y = 0.942 : 353.6 secs : infill_ei
#
# Wed Nov 19 11:54:07 AM 2025 AUC 0.931289001448829
#
# [mbo] 44: num_leaves=7434; min_child_weight=1.93; min_data_in_leaf=2465; lambda_l2=0.892; learning_rate=0.00645; num_iterations=3742; feature_fraction=0.0752; bagging_fraction=0.893 : y = 0.931 : 351.8 secs : infill_ei
#
# Saved the current state after iteration 45 in the file HT.RDATA.
#
# Wed Nov 19 12:01:20 PM 2025 AUC 0.930986686744926
#
# [mbo] 45: num_leaves=824; min_child_weight=0.0624; min_data_in_leaf=910; lambda_l2=70.1; learning_rate=0.0981; num_iterations=4939; feature_fraction=0.0619; bagging_fraction=0.863 : y = 0.931 : 432.4 secs : infill_ei
#
# Wed Nov 19 12:09:38 PM 2025 AUC 0.938976049025312
#
# [mbo] 46: num_leaves=4316; min_child_weight=2.21; min_data_in_leaf=305; lambda_l2=0.0444; learning_rate=0.01; num_iterations=4741; feature_fraction=0.0982; bagging_fraction=0.753 : y = 0.939 : 496.6 secs : infill_ei
#
# Saved the current state after iteration 47 in the file HT.RDATA.
#
# Wed Nov 19 12:15:10 PM 2025 AUC 0.934690293517044
#
# [mbo] 47: num_leaves=2328; min_child_weight=1.18; min_data_in_leaf=1245; lambda_l2=1.2; learning_rate=0.0168; num_iterations=3493; feature_fraction=0.0729; bagging_fraction=0.541 : y = 0.935 : 331.2 secs : infill_ei
#
# Wed Nov 19 12:28:36 PM 2025 AUC 0.929271109518451
#
# [mbo] 48: num_leaves=8192; min_child_weight=1.17; min_data_in_leaf=7; lambda_l2=160; learning_rate=0.0255; num_iterations=4998; feature_fraction=0.262; bagging_fraction=0.989 : y = 0.929 : 805.1 secs : infill_ei
#
# Saved the current state after iteration 49 in the file HT.RDATA.
#
# Wed Nov 19 12:38:26 PM 2025 AUC 0.917834151696888
#
# [mbo] 49: num_leaves=8108; min_child_weight=8.38; min_data_in_leaf=99; lambda_l2=1e+03; learning_rate=0.0659; num_iterations=4128; feature_fraction=0.995; bagging_fraction=0.532 : y = 0.918 : 588.1 secs : infill_ei
#
# Wed Nov 19 12:46:26 PM 2025 AUC 0.939099860485623
#
# [mbo] 50: num_leaves=1656; min_child_weight=0.706; min_data_in_leaf=59; lambda_l2=0.32; learning_rate=0.0107; num_iterations=4807; feature_fraction=0.0698; bagging_fraction=0.52 : y = 0.939 : 479.6 secs : infill_ei
#
# Saved the current state after iteration 51 in the file HT.RDATA.
#
# Wed Nov 19 12:57:15 PM 2025 AUC 0.925098092900872
#
# [mbo] 51: num_leaves=8161; min_child_weight=4.94; min_data_in_leaf=933; lambda_l2=353; learning_rate=0.0918; num_iterations=4996; feature_fraction=0.222; bagging_fraction=0.976 : y = 0.925 : 647.6 secs : infill_ei
#
# Saved the current state after iteration 52 in the file HT.RDATA.
#
# Wed Nov 19 01:13:12 PM 2025 AUC 0.931081306885326
#
# [mbo] 52: num_leaves=2616; min_child_weight=9.99; min_data_in_leaf=1114; lambda_l2=0.697; learning_rate=0.0182; num_iterations=4992; feature_fraction=0.564; bagging_fraction=0.572 : y = 0.931 : 955.6 secs : infill_ei
#
# Saved the current state after iteration 53 in the file HT.RDATA.
#
# Wed Nov 19 01:14:48 PM 2025 AUC 0.932082535605022
#
# [mbo] 53: num_leaves=4920; min_child_weight=0.805; min_data_in_leaf=36; lambda_l2=0.402; learning_rate=0.0075; num_iterations=446; feature_fraction=0.341; bagging_fraction=0.525 : y = 0.932 : 93.7 secs : infill_ei
#
# Wed Nov 19 01:23:51 PM 2025 AUC 0.914982126188372
#
# [mbo] 54: num_leaves=18; min_child_weight=9.03; min_data_in_leaf=1876; lambda_l2=172; learning_rate=0.0062; num_iterations=4995; feature_fraction=0.822; bagging_fraction=0.566 : y = 0.915 : 542.6 secs : infill_ei
#
# Saved the current state after iteration 55 in the file HT.RDATA.
#
# Wed Nov 19 01:35:43 PM 2025 AUC 0.925151442554502
#
# [mbo] 55: num_leaves=2611; min_child_weight=9.44; min_data_in_leaf=24; lambda_l2=551; learning_rate=0.1; num_iterations=4969; feature_fraction=0.317; bagging_fraction=0.983 : y = 0.925 : 710.2 secs : infill_ei
#
# Saved the current state after iteration 56 in the file HT.RDATA.
#
# Wed Nov 19 01:43:57 PM 2025 AUC 0.921617279650832
#
# [mbo] 56: num_leaves=4448; min_child_weight=0.461; min_data_in_leaf=7191; lambda_l2=0.265; learning_rate=0.00531; num_iterations=4135; feature_fraction=0.261; bagging_fraction=0.573 : y = 0.922 : 493.5 secs : infill_ei
#
# Wed Nov 19 01:50:59 PM 2025 AUC 0.930879651905254
#
# [mbo] 57: num_leaves=8186; min_child_weight=0.494; min_data_in_leaf=3; lambda_l2=105; learning_rate=0.0916; num_iterations=3555; feature_fraction=0.109; bagging_fraction=0.633 : y = 0.931 : 420.0 secs : infill_ei
#
# Saved the current state after iteration 58 in the file HT.RDATA.
#
# Wed Nov 19 02:00:22 PM 2025 AUC 0.935981757773783
#
# [mbo] 58: num_leaves=5576; min_child_weight=1.2; min_data_in_leaf=34; lambda_l2=8.76; learning_rate=0.0211; num_iterations=3289; feature_fraction=0.334; bagging_fraction=0.798 : y = 0.936 : 562.3 secs : infill_ei
#
# Wed Nov 19 02:04:43 PM 2025 AUC 0.932201649611554
#
# [mbo] 59: num_leaves=4642; min_child_weight=1.95; min_data_in_leaf=5; lambda_l2=2.27; learning_rate=0.0713; num_iterations=2500; feature_fraction=0.134; bagging_fraction=0.605 : y = 0.932 : 259.7 secs : infill_ei
#
# Saved the current state after iteration 60 in the file HT.RDATA.
#
# Wed Nov 19 02:15:43 PM 2025 AUC 0.927249526731532
#
# [mbo] 60: num_leaves=8183; min_child_weight=8.56; min_data_in_leaf=913; lambda_l2=100; learning_rate=0.0367; num_iterations=4985; feature_fraction=0.241; bagging_fraction=0.962 : y = 0.927 : 658.9 secs : infill_ei
#
# Saved the current state after iteration 61 in the file HT.RDATA.
#
# Wed Nov 19 02:21:27 PM 2025 AUC 0.930490098774032
#
# [mbo] 61: num_leaves=4498; min_child_weight=1.55; min_data_in_leaf=6; lambda_l2=61; learning_rate=0.0162; num_iterations=3618; feature_fraction=0.0616; bagging_fraction=0.574 : y = 0.93 : 341.4 secs : infill_ei
#
# Wed Nov 19 02:33:10 PM 2025 AUC 0.929407000145621
#
# [mbo] 62: num_leaves=5291; min_child_weight=3.94; min_data_in_leaf=1043; lambda_l2=70.8; learning_rate=0.0359; num_iterations=4993; feature_fraction=0.27; bagging_fraction=0.896 : y = 0.929 : 701.7 secs : infill_ei
#
# Saved the current state after iteration 63 in the file HT.RDATA.

# %% [markdown]
# la bayesian optimization ha corrido, extraigo los mejores hiperparametros

# %%
# almaceno los resultados de la Bayesian Optimization
# y capturo los mejores hiperparametros encontrados

tb_bayesiana <- as.data.table(bayesiana_salida$opt.path)

# ordeno en forma descendente por AUC = y
setorder(tb_bayesiana, -y, -num_iterations)

# grabo para eventualmente poder utilizarlos en OTRA corrida
fwrite( tb_bayesiana,
  file="BO_log.txt",
  sep="\t"
)

# los mejores hiperparámetros son los que quedaron en el registro 1 de la tabla
PARAM$out$lgbm$mejores_hiperparametros <- tb_bayesiana[
  1, # el primero es el de mejor AUC
  setdiff(colnames(tb_bayesiana),
    c("y","dob","eol","error.message","exec.time","ei","error.model",
      "train.time","prop.type","propose.time","se","mean","iter")),
  with= FALSE
]

print(PARAM$out$lgbm$mejores_hiperparametros)

# %% [markdown]
# ### 6.3.3 Produccion

# %% [markdown]
# #### Final Training
# Construyo el modelo final, que es uno solo, no hace ningun tipo de particion < training, validation, testing>]

# %% [markdown]
# ##### Final Training Dataset
#
# Aqui esta la gran decision de en qué meses hago el Final Training
# <br> debo utilizar los mejores hiperparámetros que encontré en la optimización bayesiana

# %%
PARAM$trainingstrategy$final_train <- c(
  202105, 202104, 202103, 202102, 202101,
  202012, 202011, 202010, 202009, 202008, 202007,
  202006, 202005
)

dataset[, fold_final_train := foto_mes %in% PARAM$trainingstrategy$final_train ]

# creo el dfinal_train en formato  LightGBM
dfinal_train <- lgb.Dataset(
  data= data.matrix(dataset[fold_final_train == TRUE, campos_buenos, with= FALSE]),
  label= dataset[fold_final_train == TRUE, clase01],
  free_raw_data= TRUE
)

nrow( dfinal_train) # verifico el tamaño

# %% [markdown]
# ##### Final Training Hyperparameters

# %%
# uno los parametros fijos y los mejores encontrados de los variables
fijos <- copy(PARAM$lgbm$param_fijos)

# quito lo que optimice en la Bayesian Optimization
fijos$num_iterations <- NULL
fijos$early_stopping_rounds <- NULL

# agrego a los hiperparametros fijos los que encontre con la Bayesian Optimization
param_final <- c(fijos, PARAM$out$lgbm$mejores_hiperparametros)

# Para el entrenamiento final, removemos early_stopping_rounds
# ya que se entrena con todos los datos disponibles y la cantidad de iteraciones
# ya está optimizada en 'num_iterations'.
param_final$early_stopping_rounds <- NULL

# %% [markdown]
# ##### Training
# Genero el modelo final, siempre sobre TODOS los datos de  final_train, sin hacer ningun tipo de undersampling de la clase mayoritaria

# %%
final_model <- lgb.train(
  data= dfinal_train,
  param= param_final,
  verbose= -100
)

# %%
# grabo a disco el modelo en un formato para seres humanos ... ponele ...

lgb.save(final_model, "modelo.txt")

# %%
# ahora imprimo la importancia de variables

tb_importancia <- as.data.table(lgb.importance(final_model))
archivo_importancia <- "impo.txt"

fwrite( tb_importancia,
  file= archivo_importancia,
  sep= "\t"
)

# %% [markdown]
# #### Scoring

# %% [markdown]
# Aplico el modelo final a los datos del futuro

# %%
PARAM$trainingstrategy$future <- c(202107)

dfuture <- dataset[ foto_mes %in% PARAM$trainingstrategy$future ]

# %%
# aplico final_model   a dfuture

prediccion <- predict(
  final_model,
  data.matrix(dfuture[, campos_buenos, with= FALSE])
)

# %% [markdown]
# ##### Tabla Prediccion

# %%
tb_prediccion <- dfuture[, list(numero_de_cliente)]
tb_prediccion[, prob := prediccion]

# grabo las probabilidad del modelo
#  me va a ser util para hacer Ensembles de modelos
fwrite(tb_prediccion,
  file= "prediccion.txt",
  sep= "\t"
)

# %% [markdown]
# #### Curva de Ganancia

# %% [markdown]
# Genero las salidas

# %%
# asigno clase ternaria
tb_prediccion[, clase_ternaria := dfuture$clase_ternaria ]

# asigno ganancias
tb_prediccion[, ganancia := -3000.0 ]
tb_prediccion[clase_ternaria=="BAJA+2", ganancia := 117000.0 ]

# reordeno, y acumulada
setorder( tb_prediccion, -prob )
tb_prediccion[, gan_acum := cumsum(ganancia)]

# media movil de ancho 400
tb_prediccion[,
  gan_suavizada := frollmean(
    x= gan_acum,
    n= 400,
    align= "center",
    na.rm= TRUE,
    hasNA= TRUE
  )
]

# %%
tb_prediccion[, sum(!is.na(gan_suavizada) )]
tb_prediccion[, .N]

# %%
# Este es la ganancia a reportar
resultado <- list()
resultado$ganancia_suavizada_max <- max( tb_prediccion$gan_suavizada, na.rm=TRUE )
options(digits= 8)
resultado$envios <- which.max( tb_prediccion$gan_suavizada)
resultado

# %%
# grabo las ganancias
fwrite( tb_prediccion,
  file= "ganancias.txt",
  sep= "\t"
)

# %%
# genero el grafico

tb_prediccion[, envios:= .I]

pdf("curva_de_ganancia.pdf")

plot(
  x= tb_prediccion$envios,
  y= tb_prediccion$gan_acum,
  type= "l",
  col= "gray",
  xlim= c(0, 6000),
  ylim= c(0, 8000000),
  main= paste0("Mejor gan prom= ", as.integer(resultado$ganancia_suavizada_max), " envios= ", resultado$envios),
  xlab= "Envios",
  ylab= "Ganancia",
  panel.first= grid()
)

dev.off()

# %%
# grabo los parametros
if( !require("yaml")) install.packages("yaml")
require("yaml")

PARAM$resultado <- resultado

write_yaml( PARAM, file="PARAM.yml")

# %%
format(Sys.time(), "%a %b %d %X %Y")
fin <- Sys.time()

# Duración en segundos
secs <- as.numeric(difftime(fin, principio, units = "secs"))
secs <- round(secs)

# A hh:mm:ss
h <- secs %/% 3600
m <- (secs %% 3600) %/% 60
s <- secs %% 60
dur_hms <- sprintf("%02d:%02d:%02d", h, m, s)

cat(
  "Inicio: ", format(principio, "%a %b %d %X %Y"), "\n",
  "Fin:    ", format(fin,       "%a %b %d %X %Y"), "\n",
  "Duración (hh:mm:ss): ", dur_hms, "\n",
  sep = ""
)
