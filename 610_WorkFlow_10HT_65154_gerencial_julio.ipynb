# %% [markdown]
# <a href="https://colab.research.google.com/github/jwbarbona/labo2025v/blob/main/610_WorkFlow_10HT_65154_gerencial_julio.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # 6 WorkFlow  Gerencial, futuro=JULIO

# %% [markdown]
# ### 6.1 Objetivo

# %% [markdown]
# Presentar un workflow/pipeline completo al que los estudiantes deberán enriquecer

# %% [markdown]
# #### 6.2  Seteo del ambiente en Google Colab

# %% [markdown]
# Esta parte se debe correr con el runtime en Python3
# <br>Ir al menu, Runtime -> Change Runtime Type -> Runtime type ->  **Python 3**

# %% [markdown]
# Conectar la virtual machine donde esta corriendo Google Colab con el  Google Drive, para poder tener persistencia de archivos

# %%
# primero establecer el Runtime de Python 3
from google.colab import drive
drive.mount('/content/.drive')
# Out:
# Mounted at /content/.drive

# %% [markdown]
# Para correr la siguiente celda es fundamental en Arranque en Frio haber copiado el archivo kaggle.json al Google Drive, en la carpeta indicada en el instructivo
#
# <br>los siguientes comando estan en shell script de Linux
# *   Crear las carpetas en el Google Drive
# *   "instalar" el archivo kaggle.json desde el Google Drive a la virtual machine para que pueda ser utilizado por la libreria  kaggle de Python
# *   Bajar el  **dataset_pequeno**  al  Google Drive  y tambien al disco local de la virtual machine que esta corriendo Google Colab
# *   Bajar el **dataset_historico** al Google Drive y tambien al disco local de la virtual machine que esta corriendo Google Colab

# %%
%%shell

mkdir -p "/content/.drive/My Drive/labo1"
mkdir -p "/content/buckets"
ln -s "/content/.drive/My Drive/labo1" /content/buckets/b1

mkdir -p ~/.kaggle
cp /content/buckets/b1/kaggle/kaggle.json  ~/.kaggle
chmod 600 ~/.kaggle/kaggle.json


mkdir -p /content/buckets/b1/exp
mkdir -p /content/buckets/b1/datasets
mkdir -p /content/datasets


webfiles="https://storage.googleapis.com/open-courses/austral2025-af91/"
destino_local="/content/datasets"
destino_bucket="/content/buckets/b1/datasets"


archivo="dataset_pequeno.csv"

if ! test -f $destino_bucket/$archivo; then
  wget  $webfiles/$archivo  -O $destino_bucket/$archivo
fi


if ! test -f $destino_local/$pequeno; then
  cp  $destino_bucket/$archivo  $destino_local/$archivo
fi

#-------

archivo="gerencial_competencia_2025.csv.gz"

if ! test -f $destino_bucket/$archivo; then
  wget  $webfiles/$archivo  -O $destino_bucket/$archivo
fi


if ! test -f $destino_local/$pequeno; then
  cp  $destino_bucket/$archivo  $destino_local/$archivo
fi
# Out:
# cp: cannot stat '/content/buckets/b1/kaggle/kaggle.json': No such file or directory
# chmod: cannot access '/root/.kaggle/kaggle.json': No such file or directory

# %% [markdown]
# ## 6.3  Workflow

# %% [markdown]
# ## Inicializacion

# %% [markdown]
# Esta parte se debe correr con el runtime en lenguaje **R** Ir al menu, Runtime -> Change Runtime Type -> Runtime type -> R

# %% [markdown]
# limpio el ambiente de R

# %%
format(Sys.time(), "%a %b %d %X %Y")
# Out:
# [1] "Thu Nov 20 06:28:08 PM 2025"

# %%
# limpio la memoria
rm(list=ls(all.names=TRUE)) # remove all objects
gc(full=TRUE, verbose=FALSE) # garbage collection
# Out:
#        used    (Mb) gc trigger (Mb) max used (Mb)
# Ncells  660367 35.3 1454497    77.7 1454497  77.7
# Vcells 1226536  9.4 8388608    64.0 1975136  15.1

# %%
principio <- Sys.time()

# %%
require("data.table")

if( !require("R.utils")) install.packages("R.utils")
require("R.utils")
# Out:
# Loading required package: data.table
#
# Loading required package: R.utils
#
# Warning message in library(package, lib.loc = lib.loc, character.only = TRUE, logical.return = TRUE, :
# “there is no package called ‘R.utils’”
# Installing package into ‘/usr/local/lib/R/site-library’
# (as ‘lib’ is unspecified)
#
# also installing the dependencies ‘R.oo’, ‘R.methodsS3’
#
#
# Loading required package: R.utils
#
# Loading required package: R.oo
#
# Loading required package: R.methodsS3
#
# R.methodsS3 v1.8.2 (2022-06-13 22:00:14 UTC) successfully loaded. See ?R.methodsS3 for help.
#
# R.oo v1.27.1 (2025-05-02 21:00:05 UTC) successfully loaded. See ?R.oo for help.
#
#
# Attaching package: ‘R.oo’
#
#
# The following object is masked from ‘package:R.methodsS3’:
#
#     throw
#
#
# The following objects are masked from ‘package:methods’:
#
#     getClasses, getMethods
#
#
# The following objects are masked from ‘package:base’:
#
#     attach, detach, load, save
#
#
# R.utils v2.13.0 (2025-02-24 21:20:02 UTC) successfully loaded. See ?R.utils for help.
#
#
# Attaching package: ‘R.utils’
#
#
# The following object is masked from ‘package:utils’:
#
#     timestamp
#
#
# The following objects are masked from ‘package:base’:
#
#     cat, commandArgs, getOption, isOpen, nullfile, parse, use, warnings

# %% [markdown]
# #### Parametros
# Si es gerente, no cambie nada
# <br>Si es Analista, cambie el nombre del dataset

# %%
PARAM <- list()
PARAM$semilla_primigenia <- 700009 # 100009, 200003, 499999, 700009, 999983

PARAM$experimento <- 65154 # 10HT
PARAM$dataset <- "gerencial_competencia_2025.csv.gz"

# %% [markdown]
# #### Carpeta del Experimento

# %%
# carpeta de trabajo

setwd("/content/buckets/b1/exp")
experimento_folder <- paste0("WF", PARAM$experimento)
dir.create(experimento_folder, showWarnings=FALSE)
setwd( paste0("/content/buckets/b1/exp/", experimento_folder ))

# %% [markdown]
# ### 6.3.1   Preprocesamiento del dataset

# %% [markdown]
# #### 6.3.1.1  DT incorporar dataset

# %%
# lectura del dataset
dataset <- fread(paste0("/content/datasets/", PARAM$dataset))

# %% [markdown]
# #### 6.3.1.2  CA  Catastrophe Analysis
# Se intentan reparar las variables que para un mes están con todos los valores en cero.

# %% [markdown]
# El método que se utiliza es **Machine Learning** se asigna NA also valores, si ha leido bien, es la "anti imputación de valores faltantes"
# <br> Usted podrá aplicar aquí otros métodos

# %%
dataset[ foto_mes==202006, internet:=NA]
dataset[ foto_mes==202006, mrentabilidad:=NA]
dataset[ foto_mes==202006, mrentabilidad_annual:=NA]
dataset[ foto_mes==202006, mcomisiones:=NA]
dataset[ foto_mes==202006, mactivos_margen:=NA]
dataset[ foto_mes==202006, mpasivos_margen:=NA]
dataset[ foto_mes==202006, mcuentas_saldo:=NA]
dataset[ foto_mes==202006, ctarjeta_visa_transacciones:=NA]
dataset[ foto_mes==202006, mtarjeta_visa_consumo:=NA]
dataset[ foto_mes==202006, mtarjeta_master_consumo:=NA]
dataset[ foto_mes==202006, ccallcenter_transacciones:=NA]
dataset[ foto_mes==202006, chomebanking_transacciones:=NA]
dataset[ foto_mes==202006, chomebanking_transacciones:=NA]

# %% [markdown]
# #### 6.3.1.3  DR  Data Drifting
# Se intenta corregir el data drifting, quizas ajustando por IPC ...
# <br>Esta parte podrá ser abordada por todos los Analistas y también la Gerenciapero se decide pedagogicamente no incluirla en esta primer version para reducir la carga cognitiva

# %%
# sin codigo en esta primera version del workflow

# %% [markdown]
# #### 6.3.1.3  FE_intra_manual Feature Engineering intra-mes
#
# Agrego campos nuevos dentro del mismo mes, SIN considerar la historia.

# %%
# esta funcion atributos presentes existe debido a que las modalidades poseen datasets con distinta cantidad de campos
atributos_presentes <- function( patributos )
{
  atributos <- unique( patributos )
  comun <- intersect( atributos, colnames(dataset) )

  return(  length( atributos ) == length( comun ) )
}

# el mes 1,2, ..12
if( atributos_presentes( c("foto_mes") ))
  dataset[, kmes := foto_mes %% 100]

# variable extraida de una tesis de maestria de Irlanda
if( atributos_presentes( c("mpayroll", "cliente_edad") ))
  dataset[, mpayroll_sobre_edad := mpayroll / cliente_edad]

# %%
# visualizo las columas del dataset a esta etapa
colnames(dataset)
# Out:
#  [1] "numero_de_cliente"           "foto_mes"
#  [3] "internet"                    "cliente_edad"
#  [5] "cliente_antiguedad"          "mrentabilidad"
#  [7] "mrentabilidad_annual"        "mcomisiones"
#  [9] "mactivos_margen"             "mpasivos_margen"
# [11] "cproductos"                  "mcuenta_corriente"
# [13] "mcaja_ahorro"                "cdescubierto_preacordado"
# [15] "mcuentas_saldo"              "ctarjeta_visa_transacciones"
# [17] "mtarjeta_visa_consumo"       "mtarjeta_master_consumo"
# [19] "mprestamos_personales"       "cpayroll_trx"
# [21] "mpayroll"                    "ccomisiones_mantenimiento"
# [23] "ccallcenter_transacciones"   "chomebanking_transacciones"
# [25] "ctrx_quarter"                "Master_status"
# [27] "Master_fechaalta"            "Master_mpagominimo"
# [29] "Visa_status"                 "Visa_fechaalta"
# [31] "Visa_mpagominimo"            "clase_ternaria"
# [33] "kmes"                        "mpayroll_sobre_edad"

# %% [markdown]
# #### 6.3.1.4  FE_rf Feature Engineering de nuevas variables a partir de hojas de Random Forest
#
# Esto se mostrará unicamente a la *modalidad Analista Sr*

# %%
# No se implementa Feature Engineering a partir de Random Forest

# %% [markdown]
# #### 6.3.1.5  FEhist Feature Engineering historico
#
# El Fature Engineering Histórico es la etapa que más aporta a la ganancia final, ya que enriquece cada registro del dataset con su historia.

# %% [markdown]
# Para cada campo del dataset original (*)
# se crean lo siguientes campos de a partir de la historia
# * lag1  lags de orden 1
# * delta1  =  valor actual - lag1
# * lag2  lags de orden 2
# * delta2  = valor actual - lag2
#
#
# (*) Excepto para los campos  <numero_de_cliente,  foto_mes,  clase_ternaria>

# %%
# Feature Engineering Historico

# todo es lagueable, menos la primary key y la clase
cols_lagueables <- copy( setdiff(
    colnames(dataset),
    c("numero_de_cliente", "foto_mes", "clase_ternaria")
) )

# https://rdrr.io/cran/data.table/man/shift.html

# lags de orden 1
dataset[,
    paste0(cols_lagueables, "_lag1") := shift(.SD, 1, NA, "lag"),
    by = numero_de_cliente,
    .SDcols = cols_lagueables
]

# lags de orden 2
dataset[,
    paste0(cols_lagueables, "_lag2") := shift(.SD, 2, NA, "lag"),
    by = numero_de_cliente,
    .SDcols = cols_lagueables
]

# agrego los delta lags
for (vcol in cols_lagueables)
{
    dataset[, paste0(vcol, "_delta1") := get(vcol) - get(paste0(vcol, "_lag1"))]
    dataset[, paste0(vcol, "_delta2") := get(vcol) - get(paste0(vcol, "_lag2"))]
}

# %% [markdown]
# Verificacion de los campos recien creados

# %%
ncol(dataset)
colnames(dataset)
# Out:
# [1] 158
#   [1] "numero_de_cliente"                  "foto_mes"
#   [3] "internet"                           "cliente_edad"
#   [5] "cliente_antiguedad"                 "mrentabilidad"
#   [7] "mrentabilidad_annual"               "mcomisiones"
#   [9] "mactivos_margen"                    "mpasivos_margen"
#  [11] "cproductos"                         "mcuenta_corriente"
#  [13] "mcaja_ahorro"                       "cdescubierto_preacordado"
#  [15] "mcuentas_saldo"                     "ctarjeta_visa_transacciones"
#  [17] "mtarjeta_visa_consumo"              "mtarjeta_master_consumo"
#  [19] "mprestamos_personales"              "cpayroll_trx"
#  [21] "mpayroll"                           "ccomisiones_mantenimiento"
#  [23] "ccallcenter_transacciones"          "chomebanking_transacciones"
#  [25] "ctrx_quarter"                       "Master_status"
#  [27] "Master_fechaalta"                   "Master_mpagominimo"
#  [29] "Visa_status"                        "Visa_fechaalta"
#  [31] "Visa_mpagominimo"                   "clase_ternaria"
#  [33] "kmes"                               "mpayroll_sobre_edad"
#  [35] "internet_lag1"                      "cliente_edad_lag1"
#  [37] "cliente_antiguedad_lag1"            "mrentabilidad_lag1"
#  [39] "mrentabilidad_annual_lag1"          "mcomisiones_lag1"
#  [41] "mactivos_margen_lag1"               "mpasivos_margen_lag1"
#  [43] "cproductos_lag1"                    "mcuenta_corriente_lag1"
#  [45] "mcaja_ahorro_lag1"                  "cdescubierto_preacordado_lag1"
#  [47] "mcuentas_saldo_lag1"                "ctarjeta_visa_transacciones_lag1"
#  [49] "mtarjeta_visa_consumo_lag1"         "mtarjeta_master_consumo_lag1"
#  [51] "mprestamos_personales_lag1"         "cpayroll_trx_lag1"
#  [53] "mpayroll_lag1"                      "ccomisiones_mantenimiento_lag1"
#  [55] "ccallcenter_transacciones_lag1"     "chomebanking_transacciones_lag1"
#  [57] "ctrx_quarter_lag1"                  "Master_status_lag1"
#  [59] "Master_fechaalta_lag1"              "Master_mpagominimo_lag1"
#  [61] "Visa_status_lag1"                   "Visa_fechaalta_lag1"
#  [63] "Visa_mpagominimo_lag1"              "kmes_lag1"
#  [65] "mpayroll_sobre_edad_lag1"           "internet_lag2"
#  [67] "cliente_edad_lag2"                  "cliente_antiguedad_lag2"
#  [69] "mrentabilidad_lag2"                 "mrentabilidad_annual_lag2"
#  [71] "mcomisiones_lag2"                   "mactivos_margen_lag2"
#  [73] "mpasivos_margen_lag2"               "cproductos_lag2"
#  [75] "mcuenta_corriente_lag2"             "mcaja_ahorro_lag2"
#  [77] "cdescubierto_preacordado_lag2"      "mcuentas_saldo_lag2"
#  [79] "ctarjeta_visa_transacciones_lag2"   "mtarjeta_visa_consumo_lag2"
#  [81] "mtarjeta_master_consumo_lag2"       "mprestamos_personales_lag2"
#  [83] "cpayroll_trx_lag2"                  "mpayroll_lag2"
#  [85] "ccomisiones_mantenimiento_lag2"     "ccallcenter_transacciones_lag2"
#  [87] "chomebanking_transacciones_lag2"    "ctrx_quarter_lag2"
#  [89] "Master_status_lag2"                 "Master_fechaalta_lag2"
#  [91] "Master_mpagominimo_lag2"            "Visa_status_lag2"
#  [93] "Visa_fechaalta_lag2"                "Visa_mpagominimo_lag2"
#  [95] "kmes_lag2"                          "mpayroll_sobre_edad_lag2"
#  [97] "internet_delta1"                    "internet_delta2"
#  [99] "cliente_edad_delta1"                "cliente_edad_delta2"
# [101] "cliente_antiguedad_delta1"          "cliente_antiguedad_delta2"
# [103] "mrentabilidad_delta1"               "mrentabilidad_delta2"
# [105] "mrentabilidad_annual_delta1"        "mrentabilidad_annual_delta2"
# [107] "mcomisiones_delta1"                 "mcomisiones_delta2"
# [109] "mactivos_margen_delta1"             "mactivos_margen_delta2"
# [111] "mpasivos_margen_delta1"             "mpasivos_margen_delta2"
# [113] "cproductos_delta1"                  "cproductos_delta2"
# [115] "mcuenta_corriente_delta1"           "mcuenta_corriente_delta2"
# [117] "mcaja_ahorro_delta1"                "mcaja_ahorro_delta2"
# [119] "cdescubierto_preacordado_delta1"    "cdescubierto_preacordado_delta2"
# [121] "mcuentas_saldo_delta1"              "mcuentas_saldo_delta2"
# [123] "ctarjeta_visa_transacciones_delta1" "ctarjeta_visa_transacciones_delta2"
# [125] "mtarjeta_visa_consumo_delta1"       "mtarjeta_visa_consumo_delta2"
# [127] "mtarjeta_master_consumo_delta1"     "mtarjeta_master_consumo_delta2"
# [129] "mprestamos_personales_delta1"       "mprestamos_personales_delta2"
# [131] "cpayroll_trx_delta1"                "cpayroll_trx_delta2"
# [133] "mpayroll_delta1"                    "mpayroll_delta2"
# [135] "ccomisiones_mantenimiento_delta1"   "ccomisiones_mantenimiento_delta2"
# [137] "ccallcenter_transacciones_delta1"   "ccallcenter_transacciones_delta2"
# [139] "chomebanking_transacciones_delta1"  "chomebanking_transacciones_delta2"
# [141] "ctrx_quarter_delta1"                "ctrx_quarter_delta2"
# [143] "Master_status_delta1"               "Master_status_delta2"
# [145] "Master_fechaalta_delta1"            "Master_fechaalta_delta2"
# [147] "Master_mpagominimo_delta1"          "Master_mpagominimo_delta2"
# [149] "Visa_status_delta1"                 "Visa_status_delta2"
# [151] "Visa_fechaalta_delta1"              "Visa_fechaalta_delta2"
# [153] "Visa_mpagominimo_delta1"            "Visa_mpagominimo_delta2"
# [155] "kmes_delta1"                        "kmes_delta2"
# [157] "mpayroll_sobre_edad_delta1"         "mpayroll_sobre_edad_delta2"

# %% [markdown]
# #### 6.3.1.6  FEhist Reduccion dimensionalidad con canaritos
#
# Esta etapa solo se mostrará a la *modalidad Anlista Sr* por algun canal secreto de forma de no confundir a los *Analista Jr*  nni distraer con detalles operativos a la estratégica *Modalidad Gerencial*

# %%
# No se implementa la reduccion de la dimensionalidad con canaritos

# %% [markdown]
# ### 6.3.2 Modelado

# %% [markdown]
# #### 6.3.2.1 Training Strategy
#
# Esta etapa de Workflow de  Training Strategy esta pensada para la *Modalidad Gerencial* que posee el dataset de [202005, 202109]
# <br> Si usted es un Analista, posee el periodo de [201901, 202109] y deberá experimentar en que meses le conviene experimentar
#
# <br> A la *Modalidad Gerencial* no se le complicada la vida con el undersampling de los continua, por eso PARAM$trainingstrategy$training_pct <- 1.0
# <br> Sin embargo, si usted es  *Analista SR* posee un dataset 50 veces ( filas x columnas) más grande que la *Modalidad Gerencial*  y por un tema de velocidad y experimentación más rápida puede llegar a necesitar activar el undersampling de la clase mayoritaria, a pesar de estar corriendo en Google Cloud.

# %% [markdown]
# Se hace una estrategia de entrenamiento muy sencilla, tomando todos los meses posibles, SIN eliminar nada x pandemia ni por ningun otro motivo
#
# * future = 202107  obviamente completo
#
# * final_train =  [ 202005, 202105 ]  SIN undersampling
#
# * training
#    * testing = NO HAY
#    * validation =  202105   completo, sin undersampling
#    * training = [ 202005, 202104 ]  donde se consideran el 100% de los CONTINUA

# %%
PARAM$trainingstrategy$validate <- c(202105)

PARAM$trainingstrategy$training <- c(
  202104, 202103, 202102, 202101,
  202012, 202011, 202010, 202009, 202008, 202007,
  202006, 202005
)

PARAM$trainingstrategy$training_pct <- 1.0


PARAM$trainingstrategy$positivos <- c( "BAJA+1", "BAJA+2")

# %%
# seteo la clase01   1={BAJA+1, BAJA+2}   0={CONTINUA}
dataset[, clase01 := ifelse( clase_ternaria %in% PARAM$trainingstrategy$positivos, 1, 0 )]

# %%
# los campos en los que se entrena
campos_buenos <- copy( setdiff(
    colnames(dataset), c("clase_ternaria","clase01","azar"))
)

# %%
# preparo para que se puede hacer undersampling de los CONTINUA
#  solamente por un tema de VELOCIDAD
set.seed(PARAM$semilla_primigenia, kind = "L'Ecuyer-CMRG")
dataset[, azar:=runif(nrow(dataset))]

# undersampling de los CONTINUA
dataset[, fold_train :=  foto_mes %in%  PARAM$trainingstrategy$training &
    (clase_ternaria %in% c("BAJA+1", "BAJA+2") |
     azar < PARAM$trainingstrategy$training_pct ) ]


if( !require("lightgbm")) install.packages("lightgbm")
require("lightgbm")

dtrain <- lgb.Dataset(
  data= data.matrix(dataset[fold_train == TRUE, campos_buenos, with = FALSE]),
  label= dataset[fold_train == TRUE, clase01],
  free_raw_data= TRUE
)
# Out:
# Loading required package: lightgbm
#
# Warning message in library(package, lib.loc = lib.loc, character.only = TRUE, logical.return = TRUE, :
# “there is no package called ‘lightgbm’”
# Installing package into ‘/usr/local/lib/R/site-library’
# (as ‘lib’ is unspecified)
#
# Loading required package: lightgbm

# %%
# datos de validation
dvalidate <- lgb.Dataset(
  data= data.matrix(dataset[foto_mes %in% PARAM$trainingstrategy$validate, campos_buenos, with = FALSE]),
  label= dataset[foto_mes %in% PARAM$trainingstrategy$validate, clase01],
  free_raw_data= TRUE
)

nrow(dvalidate)
# Out:
# [1] 16469

# %% [markdown]
# ####  6.3.2.2. Hyperparameter Tuning

# %% [markdown]
# * Clase binaria que se optimiza :  positivos = [ BAJA+1, BAJA+2 ]

# %% [markdown]
# * Metrica que se optimiza **AUC** Area Under Curve de la  ROC Curve
#
# es muy importante notar que intencionalmente  **NO** se está optimizando la funcion de ganancia del problema

# %% [markdown]
# * Cantidad de iteraciones inteligentes de la Optimizacion Bayesiana = **10**

# %% [markdown]
# * Parametros no default, fijos de LightGBM que no se optimizan
#   * max_bin = 31 , Alienigenas Ancestrales contruyeron las pirámides y dejaron a la humanidad en un jeroglifico  *max_bin=31*
#   * feature_fraction = 0.5  para poner algo que generalmente no falla
#   * learning_rate = 0.03  para que aprenda lento

# %% [markdown]
# * Parametros que se optimizan en la Bayesian Optimization
#   * num_leaves  [8, 256]
#   * min_data_in_leaf  [8, 8192]

# %%
# paquetes necesarios para la Bayesian Optimization
if(!require("DiceKriging")) install.packages("DiceKriging")
require("DiceKriging")

if(!require("mlrMBO")) install.packages("mlrMBO")
require("mlrMBO")
# Out:
# Loading required package: DiceKriging
#
# Warning message in library(package, lib.loc = lib.loc, character.only = TRUE, logical.return = TRUE, :
# “there is no package called ‘DiceKriging’”
# Installing package into ‘/usr/local/lib/R/site-library’
# (as ‘lib’ is unspecified)
#
# Loading required package: DiceKriging
#
# Loading required package: mlrMBO
#
# Warning message in library(package, lib.loc = lib.loc, character.only = TRUE, logical.return = TRUE, :
# “there is no package called ‘mlrMBO’”
# Installing package into ‘/usr/local/lib/R/site-library’
# (as ‘lib’ is unspecified)
#
# also installing the dependencies ‘XML’, ‘fastmatch’, ‘RcppArmadillo’, ‘mlr’, ‘ParamHelpers’, ‘smoof’, ‘BBmisc’, ‘checkmate’, ‘lhs’, ‘parallelMap’
#
#
# Loading required package: mlrMBO
#
# Loading required package: mlr
#
# Loading required package: ParamHelpers
#
#
# Attaching package: ‘ParamHelpers’
#
#
# The following object is masked from ‘package:R.utils’:
#
#     isVector
#
#
#
# Attaching package: ‘mlr’
#
#
# The following objects are masked from ‘package:R.utils’:
#
#     resample, setThreshold
#
#
# Loading required package: smoof
#
# Loading required package: checkmate
#
#
# Attaching package: ‘checkmate’
#
#
# The following object is masked from ‘package:DiceKriging’:
#
#     checkNames
#
#
# The following object is masked from ‘package:R.utils’:
#
#     asInt
#
#
#
# Attaching package: ‘smoof’
#
#
# The following objects are masked from ‘package:R.oo’:
#
#     getDescription, getName

# %% [markdown]
# Definición de la Bayesian Optimization
# <br> Si se desea optimizar un hiperparámetro que esta como fijo, debe QUITARSE de param_fijos y agregarse a PARAM$hipeparametertuning$hs

# %%
# valor ridiculamente bajo para que corra rapido en el aula y no molestar a la *Modalidad Gerencial*
PARAM$hipeparametertuning$num_interations <- 90

# parametros fijos del LightGBM
PARAM$lgbm$param_fijos <- list(
  objective= "binary",
  metric= "auc",
  first_metric_only= TRUE,
  boost_from_average= TRUE,
  feature_pre_filter= FALSE,
  verbosity= -100,
  force_row_wise= TRUE, # para evitar warning
  max_bin= 31,
  seed= PARAM$semilla_primigenia
  # learning_rate= 0.03,
  # feature_fraction= 0.5,
  # num_iterations= 2048,  # valor grande, lo limita early_stopping_rounds
  # early_stopping_rounds= 200
)


PARAM$hipeparametertuning$hs <- makeParamSet(
  # Núcleo del modelo (estructura de árboles)
  makeIntegerParam("num_leaves", lower = 2L, upper = 8192L),
  #makeIntegerParam("max_depth", lower = 3L, upper = 30L),
  makeNumericParam("min_child_weight", lower = 0.001, upper = 10.0),
  makeIntegerParam("min_data_in_leaf", lower = 2L, upper = 8192L),
  #makeNumericParam("min_gain_to_split", lower = 0.0, upper = 0.1),

  # Regularización
  #makeNumericParam("lambda_l1", lower = 0.0, upper = 1000L),
  makeNumericParam("lambda_l2", lower = 0.0, upper = 1000L),
  makeNumericParam("scale_pos_weight", lower = 1.0, upper = 5.0),  # útil en desequilibrio

  # Control del aprendizaje
  makeNumericParam("learning_rate", lower = 0.005, upper = 0.1),
  makeIntegerParam("num_iterations", lower = 100L, upper = 5000L),
  makeIntegerParam("early_stopping_rounds", lower = 50L, upper = 500L),

  # Submuestreo
  makeNumericParam("feature_fraction", lower = 0.05, upper = 1L),   # columnas
  makeNumericParam("bagging_fraction", lower = 0.5, upper = 1L)   # filas
  #makeIntegerParam("bagging_freq", lower = 0L, upper = 5L),         # cada N iteraciones

  # Opcionales útiles
  #makeNumericParam("max_delta_step", lower = 0.0, upper = 10.0),
  #makeNumericParam("path_smooth", lower = 0.0, upper = 10.0)
)
# Total: 12 hT

# %% [markdown]
# Función "señora caja negra"  que es llamada para verificar la realidad por la Bayesian Optimization

# %%
# En  x llegan los parmaetros de la bayesiana
#  devuelve la AUC en validate del modelo entrenado
#  en el parametro x llegan los hiperparámetros que se estan optimizando

EstimarGanancia_AUC_lightgbm <- function(x) {

  # x pisa (o agrega) a param_fijos
  param_completo <- modifyList(PARAM$lgbm$param_fijos, x)

  # entreno LightGBM
  modelo_train <- lgb.train(
    data= dtrain,
    valids= list(valid = dvalidate),
    eval= "auc",
    param= param_completo,
    verbose= -100
  )

  # recupero la AUC en validation
  AUC <- modelo_train$record_evals$valid$auc$eval[[modelo_train$best_iter]]

  # esta es la forma de devolver un parametro extra
  attr(AUC, "extras") <- list("num_iterations"= modelo_train$best_iter)

  # hago espacio en la memoria
  rm(modelo_train)
  gc(full= TRUE, verbose= FALSE)

  message(format(Sys.time(), "%a %b %d %X %Y"), " AUC ", AUC)

  return(AUC)
}

# %% [markdown]
# seteo de la Bayesian Optimization (complejo)
# <br> copiado y pegado de la documentación de la librería

# %%
configureMlr(show.learner.output = FALSE)

# configuro la busqueda bayesiana,  los hiperparametros que se van a optimizar
# por favor, no desesperarse por lo complejo
obj.fun <- makeSingleObjectiveFunction(
    fn= EstimarGanancia_AUC_lightgbm, # la funcion que voy a maximizar
    minimize= FALSE, # estoy Maximizando AUC
    noisy= FALSE,
    par.set= PARAM$hipeparametertuning$hs,
    has.simple.signature= FALSE # paso los parametros en una lista
)

# cada 600 segundos guardo el resultado intermedio
ctrl <- makeMBOControl(
    save.on.disk.at.time= 600,
    save.file.path= "HT.RDATA"
)

# indico la cantidad de iteraciones que va a tener la Bayesian Optimization
ctrl <- setMBOControlTermination(
    ctrl,
    iters= PARAM$hipeparametertuning$num_interations  # cantidad de iteraciones inteligentes
)

# defino el método estandar para la creacion de los puntos iniciales
#   los "No Inteligentes"
ctrl <- setMBOControlInfill(ctrl, crit = makeMBOInfillCritEI())

# mas configuraciones
surr.km <- makeLearner(
    "regr.km",
    predict.type= "se",
    covtype= "matern3_2",
    control= list(trace = TRUE)
)

# %% [markdown]
# Corrida de la Bayesian Optimization,  aqui se hace el trabajo pesado
# <br> por favor no se asuste con los warnings que pudieran aparecer
#
# Si corrío a medias y llegó a las iteraciones inteligentes, en el archivo binario HT.RDATA quedó lo ya procesado y es utilizado para retomar la corrida desde lo último que llegó a grabar.

# %%
# inicio la optimizacion bayesiana

if (!file.exists("HT.RDATA")) {
  bayesiana_salida <- mbo(obj.fun, learner= surr.km, control= ctrl)
} else {
  bayesiana_salida <- mboContinue("HT.RDATA") # retomo en caso que ya exista
}
# Out:
# Computing y column(s) for design. Not provided.
#
# Thu Nov 20 06:44:15 PM 2025 AUC 0.915229749108994
#
# Thu Nov 20 06:49:25 PM 2025 AUC 0.924556208054254
#
# Thu Nov 20 06:55:28 PM 2025 AUC 0.918584402171834
#
# Thu Nov 20 07:04:27 PM 2025 AUC 0.92125322698298
#
# Thu Nov 20 07:12:03 PM 2025 AUC 0.927043845362506
#
# Thu Nov 20 07:16:35 PM 2025 AUC 0.923245618449988
#
# Thu Nov 20 07:22:04 PM 2025 AUC 0.926787163066739
#
# Thu Nov 20 07:22:59 PM 2025 AUC 0.911972400445855
#
# Thu Nov 20 07:28:19 PM 2025 AUC 0.928915445160918
#
# Thu Nov 20 07:39:42 PM 2025 AUC 0.926767702186799
#
# Thu Nov 20 07:42:45 PM 2025 AUC 0.918394826358621
#
# Thu Nov 20 07:45:58 PM 2025 AUC 0.919307138988933
#
# Thu Nov 20 07:48:08 PM 2025 AUC 0.915636078860854
#
# Thu Nov 20 07:51:36 PM 2025 AUC 0.921920600951973
#
# Thu Nov 20 07:54:31 PM 2025 AUC 0.919543689339934
#
# Thu Nov 20 07:58:33 PM 2025 AUC 0.922836939971238
#
# Thu Nov 20 08:01:51 PM 2025 AUC 0.926613021744514
#
# Thu Nov 20 08:07:51 PM 2025 AUC 0.918495486082451
#
# Thu Nov 20 08:10:09 PM 2025 AUC 0.918924296505967
#
# Thu Nov 20 08:10:55 PM 2025 AUC 0.914842544704661
#
# Thu Nov 20 08:26:28 PM 2025 AUC 0.922526236957016
#
# Thu Nov 20 08:32:15 PM 2025 AUC 0.917496941622058
#
# Thu Nov 20 08:34:56 PM 2025 AUC 0.927667600117839
#
# Thu Nov 20 08:38:41 PM 2025 AUC 0.918139150660093
#
# Thu Nov 20 08:41:28 PM 2025 AUC 0.927256237379787
#
# Thu Nov 20 08:41:48 PM 2025 AUC 0.90844729691733
#
# Thu Nov 20 08:50:45 PM 2025 AUC 0.933669268384995
#
# Thu Nov 20 08:56:10 PM 2025 AUC 0.915301553045326
#
# Thu Nov 20 08:59:55 PM 2025 AUC 0.915030107323398
#
# Thu Nov 20 09:01:19 PM 2025 AUC 0.909139164752454
#
# Thu Nov 20 09:08:52 PM 2025 AUC 0.929215411137931
#
# Thu Nov 20 09:16:30 PM 2025 AUC 0.92790784132538
#
# Thu Nov 20 09:17:14 PM 2025 AUC 0.913637983342829
#
# Thu Nov 20 09:18:45 PM 2025 AUC 0.910104155971571
#
# Thu Nov 20 09:22:51 PM 2025 AUC 0.920373125464293
#
# Thu Nov 20 09:25:14 PM 2025 AUC 0.908822422154803
#
# Thu Nov 20 09:28:02 PM 2025 AUC 0.917778117783956
#
# Thu Nov 20 09:30:42 PM 2025 AUC 0.918721299396243
#
# Thu Nov 20 09:38:18 PM 2025 AUC 0.918706200437668
#
# Thu Nov 20 09:41:10 PM 2025 AUC 0.919811444205322
#
# [mbo] 0: num_leaves=4026; min_child_weight=6.7; min_data_in_leaf=3992; lambda_l2=543; scale_pos_weight=3.91; learning_rate=0.0242; num_iterations=1327; early_stopping_rounds=196; feature_fraction=0.778; bagging_fraction=0.799 : y = 0.915 : 162.4 secs : initdesign
#
# [mbo] 0: num_leaves=6750; min_child_weight=3.53; min_data_in_leaf=4415; lambda_l2=481; scale_pos_weight=3.25; learning_rate=0.0763; num_iterations=2202; early_stopping_rounds=226; feature_fraction=0.325; bagging_fraction=0.587 : y = 0.925 : 310.1 secs : initdesign
#
# [mbo] 0: num_leaves=6071; min_child_weight=5.88; min_data_in_leaf=5482; lambda_l2=574; scale_pos_weight=2.5; learning_rate=0.0593; num_iterations=2065; early_stopping_rounds=280; feature_fraction=0.529; bagging_fraction=0.889 : y = 0.919 : 363.5 secs : initdesign
#
# [mbo] 0: num_leaves=3570; min_child_weight=5.27; min_data_in_leaf=5545; lambda_l2=737; scale_pos_weight=2.05; learning_rate=0.0685; num_iterations=3531; early_stopping_rounds=141; feature_fraction=0.43; bagging_fraction=0.635 : y = 0.921 : 538.6 secs : initdesign
#
# [mbo] 0: num_leaves=7017; min_child_weight=4.11; min_data_in_leaf=4639; lambda_l2=330; scale_pos_weight=4.12; learning_rate=0.0366; num_iterations=3969; early_stopping_rounds=402; feature_fraction=0.252; bagging_fraction=0.664 : y = 0.927 : 455.9 secs : initdesign
#
# [mbo] 0: num_leaves=7565; min_child_weight=7.42; min_data_in_leaf=3291; lambda_l2=521; scale_pos_weight=2.33; learning_rate=0.0612; num_iterations=2910; early_stopping_rounds=126; feature_fraction=0.213; bagging_fraction=0.678 : y = 0.923 : 271.9 secs : initdesign
#
# [mbo] 0: num_leaves=3354; min_child_weight=5.21; min_data_in_leaf=3703; lambda_l2=667; scale_pos_weight=4.6; learning_rate=0.0705; num_iterations=2326; early_stopping_rounds=356; feature_fraction=0.337; bagging_fraction=0.833 : y = 0.927 : 329.5 secs : initdesign
#
# [mbo] 0: num_leaves=840; min_child_weight=8.59; min_data_in_leaf=2032; lambda_l2=188; scale_pos_weight=2.78; learning_rate=0.0138; num_iterations=456; early_stopping_rounds=274; feature_fraction=0.231; bagging_fraction=0.818 : y = 0.912 : 54.5 secs : initdesign
#
# [mbo] 0: num_leaves=3242; min_child_weight=8.9; min_data_in_leaf=1788; lambda_l2=200; scale_pos_weight=3.62; learning_rate=0.0484; num_iterations=2764; early_stopping_rounds=370; feature_fraction=0.465; bagging_fraction=0.808 : y = 0.929 : 320.5 secs : initdesign
#
# [mbo] 0: num_leaves=4351; min_child_weight=2.43; min_data_in_leaf=1050; lambda_l2=799; scale_pos_weight=2.88; learning_rate=0.0401; num_iterations=4541; early_stopping_rounds=114; feature_fraction=0.359; bagging_fraction=0.552 : y = 0.927 : 682.8 secs : initdesign
#
# [mbo] 0: num_leaves=1788; min_child_weight=8.05; min_data_in_leaf=7911; lambda_l2=358; scale_pos_weight=4.53; learning_rate=0.0556; num_iterations=2468; early_stopping_rounds=159; feature_fraction=0.601; bagging_fraction=0.717 : y = 0.918 : 183.1 secs : initdesign
#
# [mbo] 0: num_leaves=5830; min_child_weight=1.07; min_data_in_leaf=7643; lambda_l2=292; scale_pos_weight=1.99; learning_rate=0.0722; num_iterations=1569; early_stopping_rounds=342; feature_fraction=0.296; bagging_fraction=0.942 : y = 0.919 : 193.0 secs : initdesign
#
# [mbo] 0: num_leaves=1331; min_child_weight=4.91; min_data_in_leaf=6875; lambda_l2=433; scale_pos_weight=1.79; learning_rate=0.051; num_iterations=1283; early_stopping_rounds=67; feature_fraction=0.641; bagging_fraction=0.931 : y = 0.916 : 130.2 secs : initdesign
#
# [mbo] 0: num_leaves=5094; min_child_weight=9.39; min_data_in_leaf=5763; lambda_l2=256; scale_pos_weight=2.58; learning_rate=0.0947; num_iterations=4129; early_stopping_rounds=100; feature_fraction=0.552; bagging_fraction=0.546 : y = 0.922 : 208.0 secs : initdesign
#
# [mbo] 0: num_leaves=4738; min_child_weight=6.21; min_data_in_leaf=4154; lambda_l2=857; scale_pos_weight=4.43; learning_rate=0.0637; num_iterations=1028; early_stopping_rounds=130; feature_fraction=0.499; bagging_fraction=0.697 : y = 0.92 : 174.9 secs : initdesign
#
# [mbo] 0: num_leaves=420; min_child_weight=3.17; min_data_in_leaf=3184; lambda_l2=128; scale_pos_weight=2.62; learning_rate=0.0179; num_iterations=1929; early_stopping_rounds=428; feature_fraction=0.269; bagging_fraction=0.642 : y = 0.923 : 241.4 secs : initdesign
#
# [mbo] 0: num_leaves=1504; min_child_weight=7.81; min_data_in_leaf=5190; lambda_l2=170; scale_pos_weight=3.82; learning_rate=0.0789; num_iterations=3887; early_stopping_rounds=481; feature_fraction=0.759; bagging_fraction=0.916 : y = 0.927 : 197.9 secs : initdesign
#
# [mbo] 0: num_leaves=5544; min_child_weight=6.41; min_data_in_leaf=6584; lambda_l2=801; scale_pos_weight=3.03; learning_rate=0.0167; num_iterations=4487; early_stopping_rounds=240; feature_fraction=0.0752; bagging_fraction=0.537 : y = 0.918 : 360.1 secs : initdesign
#
# [mbo] 0: num_leaves=5425; min_child_weight=0.358; min_data_in_leaf=6340; lambda_l2=413; scale_pos_weight=3.11; learning_rate=0.0928; num_iterations=1086; early_stopping_rounds=75; feature_fraction=0.419; bagging_fraction=0.594 : y = 0.919 : 138.4 secs : initdesign
#
# [mbo] 0: num_leaves=3784; min_child_weight=4.45; min_data_in_leaf=860; lambda_l2=949; scale_pos_weight=3.38; learning_rate=0.0351; num_iterations=536; early_stopping_rounds=390; feature_fraction=0.0737; bagging_fraction=0.981 : y = 0.915 : 46.1 secs : initdesign
#
# [mbo] 0: num_leaves=6855; min_child_weight=9.93; min_data_in_leaf=1566; lambda_l2=679; scale_pos_weight=2.23; learning_rate=0.0278; num_iterations=4804; early_stopping_rounds=260; feature_fraction=0.578; bagging_fraction=0.752 : y = 0.923 : 932.9 secs : initdesign
#
# [mbo] 0: num_leaves=6296; min_child_weight=4.73; min_data_in_leaf=7231; lambda_l2=301; scale_pos_weight=1.15; learning_rate=0.0419; num_iterations=3249; early_stopping_rounds=445; feature_fraction=0.669; bagging_fraction=0.71 : y = 0.917 : 346.4 secs : initdesign
#
# [mbo] 0: num_leaves=8183; min_child_weight=8.42; min_data_in_leaf=2776; lambda_l2=49.7; scale_pos_weight=3.46; learning_rate=0.0851; num_iterations=3473; early_stopping_rounds=323; feature_fraction=0.127; bagging_fraction=0.972 : y = 0.928 : 161.0 secs : initdesign
#
# [mbo] 0: num_leaves=2933; min_child_weight=9.12; min_data_in_leaf=1256; lambda_l2=716; scale_pos_weight=1.33; learning_rate=0.0862; num_iterations=1687; early_stopping_rounds=319; feature_fraction=0.921; bagging_fraction=0.855 : y = 0.918 : 225.4 secs : initdesign
#
# [mbo] 0: num_leaves=6472; min_child_weight=1.51; min_data_in_leaf=2620; lambda_l2=98.4; scale_pos_weight=3.77; learning_rate=0.0958; num_iterations=2658; early_stopping_rounds=190; feature_fraction=0.885; bagging_fraction=0.904 : y = 0.927 : 167.1 secs : initdesign
#
# [mbo] 0: num_leaves=4176; min_child_weight=2.85; min_data_in_leaf=3016; lambda_l2=629; scale_pos_weight=2.94; learning_rate=0.0651; num_iterations=185; early_stopping_rounds=412; feature_fraction=0.705; bagging_fraction=0.502 : y = 0.908 : 19.5 secs : initdesign
#
# [mbo] 0: num_leaves=2406; min_child_weight=3.91; min_data_in_leaf=774; lambda_l2=3.94; scale_pos_weight=4.87; learning_rate=0.00715; num_iterations=2991; early_stopping_rounds=490; feature_fraction=0.841; bagging_fraction=0.763 : y = 0.934 : 536.9 secs : initdesign
#
# [mbo] 0: num_leaves=1177; min_child_weight=1.48; min_data_in_leaf=6506; lambda_l2=995; scale_pos_weight=1.09; learning_rate=0.0459; num_iterations=3160; early_stopping_rounds=386; feature_fraction=0.817; bagging_fraction=0.605 : y = 0.915 : 324.9 secs : initdesign
#
# [mbo] 0: num_leaves=7627; min_child_weight=6.82; min_data_in_leaf=5090; lambda_l2=969; scale_pos_weight=3.59; learning_rate=0.0331; num_iterations=1953; early_stopping_rounds=442; feature_fraction=0.858; bagging_fraction=0.746 : y = 0.915 : 225.4 secs : initdesign
#
# [mbo] 0: num_leaves=5130; min_child_weight=5.62; min_data_in_leaf=3611; lambda_l2=625; scale_pos_weight=2.15; learning_rate=0.0295; num_iterations=764; early_stopping_rounds=57; feature_fraction=0.958; bagging_fraction=0.567 : y = 0.909 : 83.8 secs : initdesign
#
# [mbo] 0: num_leaves=2109; min_child_weight=2.08; min_data_in_leaf=2353; lambda_l2=54.9; scale_pos_weight=1.58; learning_rate=0.0546; num_iterations=4940; early_stopping_rounds=170; feature_fraction=0.502; bagging_fraction=0.617 : y = 0.929 : 453.0 secs : initdesign
#
# [mbo] 0: num_leaves=2484; min_child_weight=7.65; min_data_in_leaf=549; lambda_l2=904; scale_pos_weight=4.3; learning_rate=0.0449; num_iterations=4700; early_stopping_rounds=217; feature_fraction=0.107; bagging_fraction=0.957 : y = 0.928 : 458.7 secs : initdesign
#
# [mbo] 0: num_leaves=2856; min_child_weight=3.41; min_data_in_leaf=320; lambda_l2=124; scale_pos_weight=1.28; learning_rate=0.0207; num_iterations=318; early_stopping_rounds=251; feature_fraction=0.733; bagging_fraction=0.865 : y = 0.914 : 43.1 secs : initdesign
#
# [mbo] 0: num_leaves=147; min_child_weight=0.904; min_data_in_leaf=6967; lambda_l2=592; scale_pos_weight=4.76; learning_rate=0.0237; num_iterations=649; early_stopping_rounds=465; feature_fraction=0.395; bagging_fraction=0.779 : y = 0.91 : 91.5 secs : initdesign
#
# [mbo] 0: num_leaves=1847; min_child_weight=2.74; min_data_in_leaf=8105; lambda_l2=243; scale_pos_weight=4.37; learning_rate=0.0997; num_iterations=3286; early_stopping_rounds=349; feature_fraction=0.803; bagging_fraction=0.517 : y = 0.92 : 245.5 secs : initdesign
#
# [mbo] 0: num_leaves=775; min_child_weight=7.01; min_data_in_leaf=7477; lambda_l2=838; scale_pos_weight=4.93; learning_rate=0.00879; num_iterations=4372; early_stopping_rounds=179; feature_fraction=0.989; bagging_fraction=0.66 : y = 0.909 : 143.0 secs : initdesign
#
# [mbo] 0: num_leaves=249; min_child_weight=0.624; min_data_in_leaf=2108; lambda_l2=897; scale_pos_weight=1.47; learning_rate=0.0813; num_iterations=3724; early_stopping_rounds=87; feature_fraction=0.652; bagging_fraction=0.994 : y = 0.918 : 168.8 secs : initdesign
#
# [mbo] 0: num_leaves=7822; min_child_weight=1.96; min_data_in_leaf=27; lambda_l2=757; scale_pos_weight=1.89; learning_rate=0.0888; num_iterations=846; early_stopping_rounds=468; feature_fraction=0.93; bagging_fraction=0.875 : y = 0.919 : 159.5 secs : initdesign
#
# [mbo] 0: num_leaves=7227; min_child_weight=0.0727; min_data_in_leaf=6044; lambda_l2=384; scale_pos_weight=4.03; learning_rate=0.012; num_iterations=4206; early_stopping_rounds=292; feature_fraction=0.186; bagging_fraction=0.848 : y = 0.919 : 456.0 secs : initdesign
#
# [mbo] 0: num_leaves=4679; min_child_weight=9.68; min_data_in_leaf=4821; lambda_l2=457; scale_pos_weight=1.66; learning_rate=0.0749; num_iterations=1719; early_stopping_rounds=304; feature_fraction=0.162; bagging_fraction=0.732 : y = 0.92 : 172.3 secs : initdesign
#
# Saved the current state after iteration 1 in the file HT.RDATA.
#
# Thu Nov 20 09:44:36 PM 2025 AUC 0.933971247556485
#
# [mbo] 1: num_leaves=2835; min_child_weight=3.15; min_data_in_leaf=482; lambda_l2=39.6; scale_pos_weight=4.74; learning_rate=0.0382; num_iterations=3911; early_stopping_rounds=409; feature_fraction=0.2; bagging_fraction=0.679 : y = 0.934 : 204.5 secs : infill_ei
#
# Thu Nov 20 09:47:25 PM 2025 AUC 0.930630351322568
#
# [mbo] 2: num_leaves=3141; min_child_weight=3.72; min_data_in_leaf=1138; lambda_l2=2.28; scale_pos_weight=4.99; learning_rate=0.0611; num_iterations=3513; early_stopping_rounds=493; feature_fraction=0.608; bagging_fraction=0.746 : y = 0.931 : 168.2 secs : infill_ei
#
# Thu Nov 20 09:57:34 PM 2025 AUC 0.932196616625363
#
# [mbo] 3: num_leaves=2834; min_child_weight=4.77; min_data_in_leaf=557; lambda_l2=184; scale_pos_weight=4.17; learning_rate=0.028; num_iterations=4989; early_stopping_rounds=457; feature_fraction=0.327; bagging_fraction=0.725 : y = 0.932 : 608.2 secs : infill_ei
#
# Saved the current state after iteration 4 in the file HT.RDATA.
#
# Thu Nov 20 10:04:45 PM 2025 AUC 0.935909953837451
#
# [mbo] 4: num_leaves=2732; min_child_weight=3.74; min_data_in_leaf=235; lambda_l2=19.5; scale_pos_weight=4.55; learning_rate=0.0135; num_iterations=3106; early_stopping_rounds=424; feature_fraction=0.259; bagging_fraction=0.676 : y = 0.936 : 430.3 secs : infill_ei
#
# Thu Nov 20 10:14:33 PM 2025 AUC 0.932083206669848
#
# [mbo] 5: num_leaves=4313; min_child_weight=6.97; min_data_in_leaf=4; lambda_l2=59.7; scale_pos_weight=4.81; learning_rate=0.00671; num_iterations=3498; early_stopping_rounds=259; feature_fraction=0.307; bagging_fraction=0.62 : y = 0.932 : 587.2 secs : infill_ei
#
# Saved the current state after iteration 6 in the file HT.RDATA.
#
# Thu Nov 20 10:23:00 PM 2025 AUC 0.937497693214662
#
# [mbo] 6: num_leaves=3101; min_child_weight=3.33; min_data_in_leaf=65; lambda_l2=6.13; scale_pos_weight=4.18; learning_rate=0.00638; num_iterations=3453; early_stopping_rounds=499; feature_fraction=0.259; bagging_fraction=0.787 : y = 0.937 : 505.6 secs : infill_ei
#
# Thu Nov 20 10:26:00 PM 2025 AUC 0.930967561397399
#
# [mbo] 7: num_leaves=6422; min_child_weight=4.84; min_data_in_leaf=13; lambda_l2=12.8; scale_pos_weight=4.45; learning_rate=0.0389; num_iterations=3078; early_stopping_rounds=494; feature_fraction=0.0608; bagging_fraction=0.7 : y = 0.931 : 178.8 secs : infill_ei
#
# Saved the current state after iteration 8 in the file HT.RDATA.
#
# Thu Nov 20 10:34:26 PM 2025 AUC 0.939007253539699
#
# [mbo] 8: num_leaves=2232; min_child_weight=0.662; min_data_in_leaf=34; lambda_l2=1; scale_pos_weight=3.66; learning_rate=0.0051; num_iterations=3764; early_stopping_rounds=415; feature_fraction=0.131; bagging_fraction=0.721 : y = 0.939 : 505.8 secs : infill_ei
#
# Thu Nov 20 10:43:49 PM 2025 AUC 0.939264271367878
#
# [mbo] 9: num_leaves=478; min_child_weight=0.973; min_data_in_leaf=45; lambda_l2=0.918; scale_pos_weight=3.11; learning_rate=0.00532; num_iterations=3762; early_stopping_rounds=493; feature_fraction=0.237; bagging_fraction=0.702 : y = 0.939 : 562.0 secs : infill_ei
#
# Saved the current state after iteration 10 in the file HT.RDATA.
#
# Thu Nov 20 10:49:37 PM 2025 AUC 0.929602615542264
#
# [mbo] 10: num_leaves=2798; min_child_weight=0.607; min_data_in_leaf=832; lambda_l2=25.6; scale_pos_weight=3.53; learning_rate=0.0051; num_iterations=3847; early_stopping_rounds=465; feature_fraction=0.0601; bagging_fraction=0.624 : y = 0.93 : 346.4 secs : infill_ei
#
# Thu Nov 20 10:53:43 PM 2025 AUC 0.936354534284366
#
# [mbo] 11: num_leaves=1401; min_child_weight=1.34; min_data_in_leaf=8; lambda_l2=1.55; scale_pos_weight=3.78; learning_rate=0.0161; num_iterations=3908; early_stopping_rounds=306; feature_fraction=0.401; bagging_fraction=0.846 : y = 0.936 : 245.1 secs : infill_ei
#
# Thu Nov 20 10:55:11 PM 2025 AUC 0.935796879414348
#
# [mbo] 12: num_leaves=378; min_child_weight=0.538; min_data_in_leaf=3; lambda_l2=2.8; scale_pos_weight=3.49; learning_rate=0.0746; num_iterations=3862; early_stopping_rounds=322; feature_fraction=0.225; bagging_fraction=0.745 : y = 0.936 : 86.7 secs : infill_ei
#
# Saved the current state after iteration 13 in the file HT.RDATA.
#
# Thu Nov 20 11:09:01 PM 2025 AUC 0.924772290928076
#
# [mbo] 13: num_leaves=1395; min_child_weight=1.6; min_data_in_leaf=2; lambda_l2=393; scale_pos_weight=3.97; learning_rate=0.00744; num_iterations=3624; early_stopping_rounds=444; feature_fraction=0.536; bagging_fraction=0.724 : y = 0.925 : 829.3 secs : infill_ei
#
# Saved the current state after iteration 14 in the file HT.RDATA.
#
# Thu Nov 20 11:12:49 PM 2025 AUC 0.936299506968673
#
# [mbo] 14: num_leaves=3133; min_child_weight=4.63; min_data_in_leaf=2; lambda_l2=0.373; scale_pos_weight=1.58; learning_rate=0.0176; num_iterations=4379; early_stopping_rounds=449; feature_fraction=0.175; bagging_fraction=0.785 : y = 0.936 : 226.4 secs : infill_ei
#
# Thu Nov 20 11:17:31 PM 2025 AUC 0.935888479763034
#
# [mbo] 15: num_leaves=1710; min_child_weight=7.2; min_data_in_leaf=7; lambda_l2=1.81; scale_pos_weight=3.63; learning_rate=0.0141; num_iterations=3994; early_stopping_rounds=350; feature_fraction=0.495; bagging_fraction=0.729 : y = 0.936 : 281.7 secs : infill_ei
#
# Thu Nov 20 11:24:04 PM 2025 AUC 0.939317285489096
#
# [mbo] 16: num_leaves=2578; min_child_weight=1.41; min_data_in_leaf=151; lambda_l2=0.573; scale_pos_weight=3.23; learning_rate=0.0074; num_iterations=4097; early_stopping_rounds=179; feature_fraction=0.247; bagging_fraction=0.744 : y = 0.939 : 392.3 secs : infill_ei
#
# Saved the current state after iteration 17 in the file HT.RDATA.
#
# Thu Nov 20 11:28:20 PM 2025 AUC 0.936778982786516
#
# [mbo] 17: num_leaves=643; min_child_weight=0.755; min_data_in_leaf=13; lambda_l2=2.88; scale_pos_weight=2.5; learning_rate=0.0106; num_iterations=3860; early_stopping_rounds=204; feature_fraction=0.251; bagging_fraction=0.731 : y = 0.937 : 255.0 secs : infill_ei
#
# Thu Nov 20 11:35:58 PM 2025 AUC 0.935084208569632
#
# [mbo] 18: num_leaves=4906; min_child_weight=6.54; min_data_in_leaf=9; lambda_l2=10.9; scale_pos_weight=3.13; learning_rate=0.00946; num_iterations=4046; early_stopping_rounds=416; feature_fraction=0.243; bagging_fraction=0.756 : y = 0.935 : 456.6 secs : infill_ei
#
# Saved the current state after iteration 19 in the file HT.RDATA.
#
# Thu Nov 20 11:42:39 PM 2025 AUC 0.938995845437665
#
# [mbo] 19: num_leaves=1258; min_child_weight=1.74; min_data_in_leaf=56; lambda_l2=2.25; scale_pos_weight=4.02; learning_rate=0.00737; num_iterations=4928; early_stopping_rounds=386; feature_fraction=0.135; bagging_fraction=0.911 : y = 0.939 : 400.3 secs : infill_ei
#
# Thu Nov 20 11:43:34 PM 2025 AUC 0.93711048881033
#
# [mbo] 20: num_leaves=1818; min_child_weight=9.08; min_data_in_leaf=2; lambda_l2=0.707; scale_pos_weight=3.42; learning_rate=0.0731; num_iterations=4876; early_stopping_rounds=202; feature_fraction=0.118; bagging_fraction=0.87 : y = 0.937 : 53.0 secs : infill_ei
#
# Thu Nov 20 11:48:40 PM 2025 AUC 0.936124023516796
#
# [mbo] 21: num_leaves=1336; min_child_weight=3.2; min_data_in_leaf=185; lambda_l2=0.267; scale_pos_weight=3.72; learning_rate=0.00788; num_iterations=4584; early_stopping_rounds=177; feature_fraction=0.165; bagging_fraction=0.783 : y = 0.936 : 304.2 secs : infill_ei
#
# Saved the current state after iteration 22 in the file HT.RDATA.
#
# Thu Nov 20 11:50:09 PM 2025 AUC 0.934522862843074
#
# [mbo] 22: num_leaves=3468; min_child_weight=0.622; min_data_in_leaf=2; lambda_l2=2.22; scale_pos_weight=3.35; learning_rate=0.0568; num_iterations=4821; early_stopping_rounds=129; feature_fraction=0.237; bagging_fraction=0.835 : y = 0.935 : 88.3 secs : infill_ei
#
# Thu Nov 20 11:54:49 PM 2025 AUC 0.935996521199944
#
# [mbo] 23: num_leaves=1596; min_child_weight=4.36; min_data_in_leaf=638; lambda_l2=0.0225; scale_pos_weight=3.04; learning_rate=0.0187; num_iterations=4923; early_stopping_rounds=495; feature_fraction=0.176; bagging_fraction=0.916 : y = 0.936 : 278.7 secs : infill_ei
#
# Thu Nov 20 11:57:23 PM 2025 AUC 0.933733019543421
#
# [mbo] 24: num_leaves=2659; min_child_weight=8.51; min_data_in_leaf=18; lambda_l2=0.66; scale_pos_weight=4.52; learning_rate=0.0122; num_iterations=4655; early_stopping_rounds=130; feature_fraction=0.272; bagging_fraction=0.958 : y = 0.934 : 152.7 secs : infill_ei
#
# Fri Nov 21 12:08:33 AM 2025 AUC 0.933639070467846
#
# [mbo] 25: num_leaves=2401; min_child_weight=0.197; min_data_in_leaf=1358; lambda_l2=0.276; scale_pos_weight=1.18; learning_rate=0.00705; num_iterations=4266; early_stopping_rounds=390; feature_fraction=0.308; bagging_fraction=0.737 : y = 0.934 : 669.3 secs : infill_ei
#
# Saved the current state after iteration 26 in the file HT.RDATA.
#
# Fri Nov 21 12:10:18 AM 2025 AUC 0.933833008202425
#
# [mbo] 26: num_leaves=2627; min_child_weight=6.8; min_data_in_leaf=23; lambda_l2=97.8; scale_pos_weight=4.47; learning_rate=0.0955; num_iterations=4628; early_stopping_rounds=331; feature_fraction=0.123; bagging_fraction=0.948 : y = 0.934 : 103.7 secs : infill_ei
#
# Fri Nov 21 12:14:14 AM 2025 AUC 0.932609657025478
#
# [mbo] 27: num_leaves=4650; min_child_weight=9.64; min_data_in_leaf=114; lambda_l2=677; scale_pos_weight=4.82; learning_rate=0.0994; num_iterations=4995; early_stopping_rounds=172; feature_fraction=0.134; bagging_fraction=0.761 : y = 0.933 : 235.0 secs : infill_ei
#
# Fri Nov 21 12:17:34 AM 2025 AUC 0.936788377694074
#
# [mbo] 28: num_leaves=2204; min_child_weight=9.58; min_data_in_leaf=115; lambda_l2=0.161; scale_pos_weight=4.14; learning_rate=0.0268; num_iterations=4977; early_stopping_rounds=428; feature_fraction=0.942; bagging_fraction=0.732 : y = 0.937 : 198.7 secs : infill_ei
#
# Fri Nov 21 12:18:03 AM 2025 AUC 0.912770632055827
#
# [mbo] 29: num_leaves=3908; min_child_weight=1.01; min_data_in_leaf=3; lambda_l2=0.882; scale_pos_weight=4.46; learning_rate=0.00619; num_iterations=4896; early_stopping_rounds=76; feature_fraction=0.92; bagging_fraction=0.691 : y = 0.913 : 27.6 secs : infill_ei
#
# Fri Nov 21 12:22:01 AM 2025 AUC 0.938087223663893
#
# [mbo] 30: num_leaves=1902; min_child_weight=1.25; min_data_in_leaf=29; lambda_l2=0.0408; scale_pos_weight=3.81; learning_rate=0.00924; num_iterations=3449; early_stopping_rounds=484; feature_fraction=0.207; bagging_fraction=0.934 : y = 0.938 : 236.9 secs : infill_ei
#
# Saved the current state after iteration 31 in the file HT.RDATA.
#
# Fri Nov 21 12:24:49 AM 2025 AUC 0.93274454105541
#
# [mbo] 31: num_leaves=2064; min_child_weight=6.28; min_data_in_leaf=14; lambda_l2=0.105; scale_pos_weight=3.76; learning_rate=0.0754; num_iterations=4434; early_stopping_rounds=496; feature_fraction=0.998; bagging_fraction=0.99 : y = 0.933 : 167.5 secs : infill_ei
#
# Fri Nov 21 12:26:55 AM 2025 AUC 0.922972495065996
#
# [mbo] 32: num_leaves=3046; min_child_weight=3.44; min_data_in_leaf=3438; lambda_l2=0.362; scale_pos_weight=3.52; learning_rate=0.0913; num_iterations=4630; early_stopping_rounds=273; feature_fraction=0.332; bagging_fraction=0.956 : y = 0.923 : 124.2 secs : infill_ei
#
# Fri Nov 21 12:29:53 AM 2025 AUC 0.932474772995546
#
# [mbo] 33: num_leaves=1785; min_child_weight=9.53; min_data_in_leaf=7; lambda_l2=4.54; scale_pos_weight=3.03; learning_rate=0.0488; num_iterations=3992; early_stopping_rounds=386; feature_fraction=0.216; bagging_fraction=0.794 : y = 0.932 : 177.4 secs : infill_ei
#
# Fri Nov 21 12:32:28 AM 2025 AUC 0.930528013936674
#
# [mbo] 34: num_leaves=1688; min_child_weight=9.67; min_data_in_leaf=337; lambda_l2=1.78; scale_pos_weight=3.24; learning_rate=0.0448; num_iterations=4879; early_stopping_rounds=456; feature_fraction=0.731; bagging_fraction=0.875 : y = 0.931 : 153.7 secs : infill_ei
#
# Saved the current state after iteration 35 in the file HT.RDATA.
#
# Fri Nov 21 12:34:27 AM 2025 AUC 0.926115091643968
#
# [mbo] 35: num_leaves=4128; min_child_weight=9.68; min_data_in_leaf=1655; lambda_l2=0.493; scale_pos_weight=4.89; learning_rate=0.0781; num_iterations=3840; early_stopping_rounds=460; feature_fraction=0.943; bagging_fraction=0.735 : y = 0.926 : 118.0 secs : infill_ei
#
# Fri Nov 21 12:37:57 AM 2025 AUC 0.935505637280067
#
# [mbo] 36: num_leaves=6167; min_child_weight=2.21; min_data_in_leaf=38; lambda_l2=0.0906; scale_pos_weight=3.62; learning_rate=0.0121; num_iterations=4326; early_stopping_rounds=403; feature_fraction=0.241; bagging_fraction=0.77 : y = 0.936 : 208.0 secs : infill_ei
#
# Fri Nov 21 12:41:17 AM 2025 AUC 0.932828088626189
#
# [mbo] 37: num_leaves=4004; min_child_weight=3.97; min_data_in_leaf=8; lambda_l2=28.9; scale_pos_weight=3.52; learning_rate=0.0232; num_iterations=3507; early_stopping_rounds=127; feature_fraction=0.134; bagging_fraction=0.836 : y = 0.933 : 198.8 secs : infill_ei
#
# Fri Nov 21 12:49:07 AM 2025 AUC 0.932732797420964
#
# [mbo] 38: num_leaves=1026; min_child_weight=7.79; min_data_in_leaf=207; lambda_l2=13.3; scale_pos_weight=2.89; learning_rate=0.00962; num_iterations=4341; early_stopping_rounds=489; feature_fraction=0.926; bagging_fraction=0.638 : y = 0.933 : 468.9 secs : infill_ei
#
# Saved the current state after iteration 39 in the file HT.RDATA.
#
# Fri Nov 21 12:50:29 AM 2025 AUC 0.93313744951076
#
# [mbo] 39: num_leaves=3228; min_child_weight=4.36; min_data_in_leaf=16; lambda_l2=6.1; scale_pos_weight=4.11; learning_rate=0.0847; num_iterations=4124; early_stopping_rounds=184; feature_fraction=0.0875; bagging_fraction=0.713 : y = 0.933 : 81.2 secs : infill_ei
#
# Fri Nov 21 12:52:08 AM 2025 AUC 0.932658980290155
#
# [mbo] 40: num_leaves=2080; min_child_weight=7.79; min_data_in_leaf=5; lambda_l2=5.52; scale_pos_weight=4.86; learning_rate=0.0679; num_iterations=4703; early_stopping_rounds=195; feature_fraction=0.453; bagging_fraction=0.739 : y = 0.933 : 97.6 secs : infill_ei
#
# Fri Nov 21 12:55:55 AM 2025 AUC 0.934162165499349
#
# [mbo] 41: num_leaves=1276; min_child_weight=8.8; min_data_in_leaf=2030; lambda_l2=0.785; scale_pos_weight=4.63; learning_rate=0.0267; num_iterations=4988; early_stopping_rounds=422; feature_fraction=0.0771; bagging_fraction=0.888 : y = 0.934 : 226.0 secs : infill_ei
#
# Fri Nov 21 01:03:50 AM 2025 AUC 0.939162269514397
#
# [mbo] 42: num_leaves=2350; min_child_weight=2.33; min_data_in_leaf=13; lambda_l2=0.667; scale_pos_weight=3.01; learning_rate=0.00532; num_iterations=4374; early_stopping_rounds=340; feature_fraction=0.249; bagging_fraction=0.588 : y = 0.939 : 473.2 secs : infill_ei
#
# Saved the current state after iteration 43 in the file HT.RDATA.
#
# Fri Nov 21 01:05:39 AM 2025 AUC 0.932761653208462
#
# [mbo] 43: num_leaves=2218; min_child_weight=8.02; min_data_in_leaf=40; lambda_l2=0.291; scale_pos_weight=2.98; learning_rate=0.0734; num_iterations=4992; early_stopping_rounds=458; feature_fraction=0.0545; bagging_fraction=0.956 : y = 0.933 : 107.4 secs : infill_ei
#
# Fri Nov 21 01:11:09 AM 2025 AUC 0.933733690608246
#
# [mbo] 44: num_leaves=1006; min_child_weight=8.16; min_data_in_leaf=157; lambda_l2=0.19; scale_pos_weight=4.8; learning_rate=0.0153; num_iterations=4153; early_stopping_rounds=497; feature_fraction=0.894; bagging_fraction=0.998 : y = 0.934 : 329.1 secs : infill_ei
#
# Fri Nov 21 01:16:37 AM 2025 AUC 0.927247178004642
#
# [mbo] 45: num_leaves=6662; min_child_weight=6.01; min_data_in_leaf=6; lambda_l2=663; scale_pos_weight=4.77; learning_rate=0.0904; num_iterations=3792; early_stopping_rounds=468; feature_fraction=0.269; bagging_fraction=0.826 : y = 0.927 : 326.6 secs : infill_ei
#
# Saved the current state after iteration 46 in the file HT.RDATA.
#
# Fri Nov 21 01:19:15 AM 2025 AUC 0.931545683744595
#
# [mbo] 46: num_leaves=1966; min_child_weight=2.04; min_data_in_leaf=150; lambda_l2=4.87; scale_pos_weight=4.42; learning_rate=0.0323; num_iterations=4618; early_stopping_rounds=470; feature_fraction=0.999; bagging_fraction=0.814 : y = 0.932 : 156.4 secs : infill_ei
#
# Fri Nov 21 01:23:37 AM 2025 AUC 0.933239115831829
#
# [mbo] 47: num_leaves=6538; min_child_weight=9.9; min_data_in_leaf=11; lambda_l2=141; scale_pos_weight=3.29; learning_rate=0.0374; num_iterations=4865; early_stopping_rounds=181; feature_fraction=0.12; bagging_fraction=0.856 : y = 0.933 : 261.8 secs : infill_ei
#
# Fri Nov 21 01:28:49 AM 2025 AUC 0.925251095681094
#
# [mbo] 48: num_leaves=1679; min_child_weight=9.79; min_data_in_leaf=149; lambda_l2=128; scale_pos_weight=3.67; learning_rate=0.0254; num_iterations=4966; early_stopping_rounds=421; feature_fraction=0.98; bagging_fraction=0.898 : y = 0.925 : 310.3 secs : infill_ei
#
# Saved the current state after iteration 49 in the file HT.RDATA.
#
# Fri Nov 21 01:31:04 AM 2025 AUC 0.929139245280233
#
# [mbo] 49: num_leaves=3131; min_child_weight=8.43; min_data_in_leaf=83; lambda_l2=331; scale_pos_weight=4.39; learning_rate=0.0731; num_iterations=4651; early_stopping_rounds=184; feature_fraction=0.0853; bagging_fraction=0.781 : y = 0.929 : 133.9 secs : infill_ei
#
# Fri Nov 21 01:37:55 AM 2025 AUC 0.934330938302971
#
# [mbo] 50: num_leaves=3437; min_child_weight=6.2; min_data_in_leaf=284; lambda_l2=0.669; scale_pos_weight=2.73; learning_rate=0.00751; num_iterations=4994; early_stopping_rounds=220; feature_fraction=0.189; bagging_fraction=0.819 : y = 0.934 : 409.0 secs : infill_ei
#
# Fri Nov 21 01:41:00 AM 2025 AUC 0.939239777501746
#
# [mbo] 51: num_leaves=1073; min_child_weight=1.77; min_data_in_leaf=6; lambda_l2=0.323; scale_pos_weight=4.05; learning_rate=0.024; num_iterations=4147; early_stopping_rounds=420; feature_fraction=0.173; bagging_fraction=0.879 : y = 0.939 : 184.2 secs : infill_ei
#
# Saved the current state after iteration 52 in the file HT.RDATA.
#
# Fri Nov 21 01:49:11 AM 2025 AUC 0.930906494498275
#
# [mbo] 52: num_leaves=6659; min_child_weight=1.57; min_data_in_leaf=11; lambda_l2=141; scale_pos_weight=2.45; learning_rate=0.0382; num_iterations=3247; early_stopping_rounds=344; feature_fraction=0.277; bagging_fraction=0.708 : y = 0.931 : 488.8 secs : infill_ei
#
# Fri Nov 21 01:57:54 AM 2025 AUC 0.931201091956684
#
# [mbo] 53: num_leaves=7755; min_child_weight=9.88; min_data_in_leaf=2476; lambda_l2=0.477; scale_pos_weight=4.93; learning_rate=0.0154; num_iterations=4887; early_stopping_rounds=456; feature_fraction=0.445; bagging_fraction=0.861 : y = 0.931 : 521.9 secs : infill_ei
#
# Saved the current state after iteration 54 in the file HT.RDATA.
#
# Fri Nov 21 02:05:34 AM 2025 AUC 0.931657751570459
#
# [mbo] 54: num_leaves=6421; min_child_weight=8.89; min_data_in_leaf=182; lambda_l2=239; scale_pos_weight=4.77; learning_rate=0.0339; num_iterations=4495; early_stopping_rounds=435; feature_fraction=0.434; bagging_fraction=0.925 : y = 0.932 : 457.6 secs : infill_ei
#
# Fri Nov 21 02:07:46 AM 2025 AUC 0.929908621102707
#
# [mbo] 55: num_leaves=748; min_child_weight=8.91; min_data_in_leaf=35; lambda_l2=0.215; scale_pos_weight=3.01; learning_rate=0.0562; num_iterations=4845; early_stopping_rounds=373; feature_fraction=0.309; bagging_fraction=0.65 : y = 0.93 : 131.0 secs : infill_ei
#
# Fri Nov 21 02:11:02 AM 2025 AUC 0.92830074978073
#
# [mbo] 56: num_leaves=3840; min_child_weight=9.99; min_data_in_leaf=14; lambda_l2=752; scale_pos_weight=4.94; learning_rate=0.1; num_iterations=3761; early_stopping_rounds=95; feature_fraction=0.31; bagging_fraction=0.901 : y = 0.928 : 194.5 secs : infill_ei
#
# Saved the current state after iteration 57 in the file HT.RDATA.
#
# Fri Nov 21 02:14:24 AM 2025 AUC 0.932693875661083
#
# [mbo] 57: num_leaves=6946; min_child_weight=2.1; min_data_in_leaf=126; lambda_l2=0.602; scale_pos_weight=4.4; learning_rate=0.0356; num_iterations=2878; early_stopping_rounds=363; feature_fraction=0.481; bagging_fraction=0.824 : y = 0.933 : 200.2 secs : infill_ei
#
# Fri Nov 21 02:19:22 AM 2025 AUC 0.937530910923526
#
# [mbo] 58: num_leaves=2347; min_child_weight=2.03; min_data_in_leaf=6; lambda_l2=0.729; scale_pos_weight=3.42; learning_rate=0.00728; num_iterations=4062; early_stopping_rounds=156; feature_fraction=0.295; bagging_fraction=0.547 : y = 0.938 : 296.7 secs : infill_ei
#
# Fri Nov 21 02:23:09 AM 2025 AUC 0.929023486597829
#
# [mbo] 59: num_leaves=631; min_child_weight=2.32; min_data_in_leaf=1153; lambda_l2=20.9; scale_pos_weight=4.97; learning_rate=0.0488; num_iterations=2800; early_stopping_rounds=484; feature_fraction=0.814; bagging_fraction=0.997 : y = 0.929 : 225.2 secs : infill_ei
#
# Saved the current state after iteration 60 in the file HT.RDATA.
#
# Fri Nov 21 02:25:58 AM 2025 AUC 0.934768137036806
#
# [mbo] 60: num_leaves=112; min_child_weight=2.16; min_data_in_leaf=96; lambda_l2=0.83; scale_pos_weight=1.87; learning_rate=0.0311; num_iterations=4610; early_stopping_rounds=500; feature_fraction=0.12; bagging_fraction=0.869 : y = 0.935 : 167.3 secs : infill_ei
#
# Fri Nov 21 02:33:28 AM 2025 AUC 0.938898541037963
#
# [mbo] 61: num_leaves=2196; min_child_weight=0.972; min_data_in_leaf=55; lambda_l2=0.133; scale_pos_weight=4.02; learning_rate=0.00558; num_iterations=4067; early_stopping_rounds=306; feature_fraction=0.212; bagging_fraction=0.845 : y = 0.939 : 448.5 secs : infill_ei
#
# Saved the current state after iteration 62 in the file HT.RDATA.
#
# Fri Nov 21 02:36:40 AM 2025 AUC 0.934070229618251
#
# [mbo] 62: num_leaves=8163; min_child_weight=8.43; min_data_in_leaf=11; lambda_l2=2.63; scale_pos_weight=4.47; learning_rate=0.0329; num_iterations=4867; early_stopping_rounds=403; feature_fraction=0.227; bagging_fraction=0.813 : y = 0.934 : 190.2 secs : infill_ei
#
# Fri Nov 21 02:38:51 AM 2025 AUC 0.932367402623461
#
# [mbo] 63: num_leaves=2801; min_child_weight=2.2; min_data_in_leaf=9; lambda_l2=2.54; scale_pos_weight=1.83; learning_rate=0.0756; num_iterations=4151; early_stopping_rounds=500; feature_fraction=0.434; bagging_fraction=0.652 : y = 0.932 : 129.9 secs : infill_ei
#
# Fri Nov 21 02:40:03 AM 2025 AUC 0.92646337428842
#
# [mbo] 64: num_leaves=6482; min_child_weight=4.17; min_data_in_leaf=83; lambda_l2=1.46; scale_pos_weight=1.15; learning_rate=0.0757; num_iterations=4896; early_stopping_rounds=171; feature_fraction=0.228; bagging_fraction=0.511 : y = 0.926 : 70.7 secs : infill_ei
#
# Fri Nov 21 02:42:35 AM 2025 AUC 0.931342686634872
#
# [mbo] 65: num_leaves=7203; min_child_weight=8.71; min_data_in_leaf=847; lambda_l2=0.374; scale_pos_weight=4.74; learning_rate=0.0186; num_iterations=1806; early_stopping_rounds=97; feature_fraction=0.288; bagging_fraction=0.793 : y = 0.931 : 149.7 secs : infill_ei
#
# Fri Nov 21 02:47:07 AM 2025 AUC 0.927813892249805
#
# [mbo] 66: num_leaves=2068; min_child_weight=7.13; min_data_in_leaf=5973; lambda_l2=1.58; scale_pos_weight=4.01; learning_rate=0.03; num_iterations=4952; early_stopping_rounds=494; feature_fraction=0.921; bagging_fraction=0.749 : y = 0.928 : 270.8 secs : infill_ei
#
# Saved the current state after iteration 67 in the file HT.RDATA.
#
# Fri Nov 21 02:55:49 AM 2025 AUC 0.932317408293959
#
# [mbo] 67: num_leaves=6091; min_child_weight=9.13; min_data_in_leaf=1203; lambda_l2=0.215; scale_pos_weight=4.11; learning_rate=0.00903; num_iterations=4307; early_stopping_rounds=203; feature_fraction=0.416; bagging_fraction=0.717 : y = 0.932 : 519.0 secs : infill_ei
#
# Fri Nov 21 02:57:13 AM 2025 AUC 0.931483610248234
#
# [mbo] 68: num_leaves=4801; min_child_weight=9.99; min_data_in_leaf=12; lambda_l2=0.00692; scale_pos_weight=4.73; learning_rate=0.0656; num_iterations=4763; early_stopping_rounds=215; feature_fraction=0.11; bagging_fraction=0.861 : y = 0.931 : 81.7 secs : infill_ei
#
# Saved the current state after iteration 69 in the file HT.RDATA.
#
# Fri Nov 21 03:02:32 AM 2025 AUC 0.934827526273866
#
# [mbo] 69: num_leaves=4927; min_child_weight=9.91; min_data_in_leaf=5; lambda_l2=0.535; scale_pos_weight=4.64; learning_rate=0.0197; num_iterations=2604; early_stopping_rounds=462; feature_fraction=0.506; bagging_fraction=0.986 : y = 0.935 : 317.1 secs : infill_ei
#
# Fri Nov 21 03:07:30 AM 2025 AUC 0.932157023800656
#
# [mbo] 70: num_leaves=7046; min_child_weight=9.51; min_data_in_leaf=598; lambda_l2=4.49; scale_pos_weight=2.83; learning_rate=0.0252; num_iterations=2671; early_stopping_rounds=438; feature_fraction=0.431; bagging_fraction=0.995 : y = 0.932 : 296.0 secs : infill_ei
#
# Saved the current state after iteration 71 in the file HT.RDATA.
#
# Fri Nov 21 03:09:44 AM 2025 AUC 0.930951455841586
#
# [mbo] 71: num_leaves=2092; min_child_weight=8.37; min_data_in_leaf=5; lambda_l2=0.207; scale_pos_weight=4.52; learning_rate=0.0501; num_iterations=4574; early_stopping_rounds=500; feature_fraction=0.889; bagging_fraction=0.562 : y = 0.931 : 131.4 secs : infill_ei
#
# Fri Nov 21 03:10:32 AM 2025 AUC 0.929500613688783
#
# [mbo] 72: num_leaves=169; min_child_weight=9.46; min_data_in_leaf=8; lambda_l2=2.91; scale_pos_weight=3.31; learning_rate=0.0977; num_iterations=4390; early_stopping_rounds=107; feature_fraction=0.0877; bagging_fraction=0.912 : y = 0.93 : 46.7 secs : infill_ei
#
# Fri Nov 21 03:13:22 AM 2025 AUC 0.928257801631895
#
# [mbo] 73: num_leaves=1964; min_child_weight=3.89; min_data_in_leaf=14; lambda_l2=101; scale_pos_weight=2.84; learning_rate=0.0741; num_iterations=3523; early_stopping_rounds=203; feature_fraction=0.192; bagging_fraction=0.957 : y = 0.928 : 168.8 secs : infill_ei
#
# Fri Nov 21 03:15:47 AM 2025 AUC 0.926034228332491
#
# [mbo] 74: num_leaves=8188; min_child_weight=8.07; min_data_in_leaf=329; lambda_l2=155; scale_pos_weight=4.43; learning_rate=0.064; num_iterations=2661; early_stopping_rounds=196; feature_fraction=0.43; bagging_fraction=0.793 : y = 0.926 : 142.5 secs : infill_ei
#
# Fri Nov 21 03:19:20 AM 2025 AUC 0.932622407257163
#
# [mbo] 75: num_leaves=1170; min_child_weight=9.35; min_data_in_leaf=53; lambda_l2=0.485; scale_pos_weight=4.72; learning_rate=0.0244; num_iterations=4105; early_stopping_rounds=464; feature_fraction=0.625; bagging_fraction=0.76 : y = 0.933 : 210.9 secs : infill_ei
#
# Saved the current state after iteration 76 in the file HT.RDATA.
#
# Fri Nov 21 03:21:54 AM 2025 AUC 0.930813216487526
#
# [mbo] 76: num_leaves=1860; min_child_weight=0.0937; min_data_in_leaf=44; lambda_l2=1.16; scale_pos_weight=3.77; learning_rate=0.077; num_iterations=4945; early_stopping_rounds=464; feature_fraction=0.136; bagging_fraction=0.759 : y = 0.931 : 151.9 secs : infill_ei
#
# Fri Nov 21 03:27:07 AM 2025 AUC 0.929905601310992
#
# [mbo] 77: num_leaves=2492; min_child_weight=4.24; min_data_in_leaf=509; lambda_l2=663; scale_pos_weight=4.73; learning_rate=0.0832; num_iterations=4998; early_stopping_rounds=209; feature_fraction=0.158; bagging_fraction=0.802 : y = 0.93 : 311.3 secs : infill_ei
#
# Fri Nov 21 03:29:23 AM 2025 AUC 0.935643205569301
#
# [mbo] 78: num_leaves=2428; min_child_weight=9.18; min_data_in_leaf=161; lambda_l2=1.63; scale_pos_weight=4.3; learning_rate=0.0287; num_iterations=4184; early_stopping_rounds=369; feature_fraction=0.16; bagging_fraction=0.992 : y = 0.936 : 134.6 secs : infill_ei
#
# Saved the current state after iteration 79 in the file HT.RDATA.
#
# Fri Nov 21 03:34:21 AM 2025 AUC 0.937661433032092
#
# [mbo] 79: num_leaves=1981; min_child_weight=1.46; min_data_in_leaf=28; lambda_l2=0.927; scale_pos_weight=3.2; learning_rate=0.00984; num_iterations=4278; early_stopping_rounds=332; feature_fraction=0.233; bagging_fraction=0.718 : y = 0.938 : 296.2 secs : infill_ei
#
# Fri Nov 21 03:42:09 AM 2025 AUC 0.936461904656452
#
# [mbo] 80: num_leaves=2791; min_child_weight=1.93; min_data_in_leaf=18; lambda_l2=4; scale_pos_weight=1.94; learning_rate=0.011; num_iterations=4342; early_stopping_rounds=489; feature_fraction=0.472; bagging_fraction=0.9 : y = 0.936 : 466.4 secs : infill_ei
#
# Saved the current state after iteration 81 in the file HT.RDATA.
#
# Fri Nov 21 03:50:15 AM 2025 AUC 0.93281970031587
#
# [mbo] 81: num_leaves=1439; min_child_weight=1.68; min_data_in_leaf=1656; lambda_l2=1.2; scale_pos_weight=3.99; learning_rate=0.00592; num_iterations=3522; early_stopping_rounds=331; feature_fraction=0.25; bagging_fraction=0.563 : y = 0.933 : 484.2 secs : infill_ei
#
# Fri Nov 21 04:00:22 AM 2025 AUC 0.928577564021262
#
# [mbo] 82: num_leaves=7023; min_child_weight=9.32; min_data_in_leaf=727; lambda_l2=101; scale_pos_weight=4.93; learning_rate=0.00603; num_iterations=4371; early_stopping_rounds=440; feature_fraction=0.222; bagging_fraction=0.75 : y = 0.929 : 605.5 secs : infill_ei
#
# Saved the current state after iteration 83 in the file HT.RDATA.
#
# Fri Nov 21 04:03:32 AM 2025 AUC 0.934884566784036
#
# [mbo] 83: num_leaves=2008; min_child_weight=0.809; min_data_in_leaf=12; lambda_l2=2.27; scale_pos_weight=2.91; learning_rate=0.0273; num_iterations=4098; early_stopping_rounds=310; feature_fraction=0.368; bagging_fraction=0.57 : y = 0.935 : 188.6 secs : infill_ei
#
# Fri Nov 21 04:08:10 AM 2025 AUC 0.936779653851342
#
# [mbo] 84: num_leaves=5792; min_child_weight=1.12; min_data_in_leaf=338; lambda_l2=0.83; scale_pos_weight=3.25; learning_rate=0.0129; num_iterations=4068; early_stopping_rounds=104; feature_fraction=0.24; bagging_fraction=0.631 : y = 0.937 : 275.3 secs : infill_ei
#
# Fri Nov 21 04:20:43 AM 2025 AUC 0.93674308081835
#
# [mbo] 85: num_leaves=8044; min_child_weight=2.94; min_data_in_leaf=13; lambda_l2=0.472; scale_pos_weight=1.67; learning_rate=0.00522; num_iterations=4341; early_stopping_rounds=480; feature_fraction=0.408; bagging_fraction=0.601 : y = 0.937 : 751.2 secs : infill_ei
#
# Saved the current state after iteration 86 in the file HT.RDATA.
#
# Fri Nov 21 04:35:12 AM 2025 AUC 0.933754158085425
#
# [mbo] 86: num_leaves=3100; min_child_weight=5.1; min_data_in_leaf=8; lambda_l2=0.617; scale_pos_weight=1.27; learning_rate=0.00503; num_iterations=4676; early_stopping_rounds=498; feature_fraction=0.413; bagging_fraction=0.584 : y = 0.934 : 866.6 secs : infill_ei
#
# Saved the current state after iteration 87 in the file HT.RDATA.
#
# Fri Nov 21 04:37:14 AM 2025 AUC 0.928082989244844
#
# [mbo] 87: num_leaves=409; min_child_weight=0.599; min_data_in_leaf=14; lambda_l2=1.07; scale_pos_weight=1.97; learning_rate=0.075; num_iterations=3537; early_stopping_rounds=404; feature_fraction=0.54; bagging_fraction=0.959 : y = 0.928 : 120.0 secs : infill_ei
#
# Fri Nov 21 04:43:44 AM 2025 AUC 0.934876178473717
#
# [mbo] 88: num_leaves=2771; min_child_weight=7.27; min_data_in_leaf=4; lambda_l2=0.694; scale_pos_weight=4.67; learning_rate=0.0154; num_iterations=4523; early_stopping_rounds=423; feature_fraction=0.479; bagging_fraction=0.723 : y = 0.935 : 388.7 secs : infill_ei
#
# Fri Nov 21 04:49:36 AM 2025 AUC 0.933283406110314
#
# [mbo] 89: num_leaves=2678; min_child_weight=0.23; min_data_in_leaf=1781; lambda_l2=0.569; scale_pos_weight=4.16; learning_rate=0.0154; num_iterations=3571; early_stopping_rounds=99; feature_fraction=0.314; bagging_fraction=0.73 : y = 0.933 : 350.4 secs : infill_ei
#
# Saved the current state after iteration 90 in the file HT.RDATA.
#
# Fri Nov 21 04:57:52 AM 2025 AUC 0.938372761747158
#
# [mbo] 90: num_leaves=7889; min_child_weight=1.93; min_data_in_leaf=10; lambda_l2=0.262; scale_pos_weight=2.04; learning_rate=0.00501; num_iterations=4750; early_stopping_rounds=133; feature_fraction=0.324; bagging_fraction=0.807 : y = 0.938 : 494.2 secs : infill_ei
#
# Saved the final state in the file HT.RDATA

# %% [markdown]
# la bayesian optimization ha corrido, extraigo los mejores hiperparametros

# %%
# almaceno los resultados de la Bayesian Optimization
# y capturo los mejores hiperparametros encontrados

tb_bayesiana <- as.data.table(bayesiana_salida$opt.path)

# ordeno en forma descendente por AUC = y
setorder(tb_bayesiana, -y, -num_iterations)

# grabo para eventualmente poder utilizarlos en OTRA corrida
fwrite( tb_bayesiana,
  file="BO_log.txt",
  sep="\t"
)

# los mejores hiperparámetros son los que quedaron en el registro 1 de la tabla
PARAM$out$lgbm$mejores_hiperparametros <- tb_bayesiana[
  1, # el primero es el de mejor AUC
  setdiff(colnames(tb_bayesiana),
    c("y","dob","eol","error.message","exec.time","ei","error.model",
      "train.time","prop.type","propose.time","se","mean","iter")),
  with= FALSE
]

print(PARAM$out$lgbm$mejores_hiperparametros)
# Out:
#    num_leaves min_child_weight min_data_in_leaf lambda_l2 scale_pos_weight
#         <int>            <num>            <int>     <num>            <num>
# 1:       2578         1.406693              151 0.5733942         3.232353
#    learning_rate num_iterations early_stopping_rounds feature_fraction
#            <num>          <int>                 <int>            <num>
# 1:   0.007401558           4097                   179        0.2467329
#    bagging_fraction
#               <num>
# 1:        0.7440329

# %% [markdown]
# ### 6.3.3 Produccion

# %% [markdown]
# #### Final Training
# Construyo el modelo final, que es uno solo, no hace ningun tipo de particion < training, validation, testing>]

# %% [markdown]
# ##### Final Training Dataset
#
# Aqui esta la gran decision de en qué meses hago el Final Training
# <br> debo utilizar los mejores hiperparámetros que encontré en la optimización bayesiana

# %%
PARAM$trainingstrategy$final_train <- c(
  202105, 202104, 202103, 202102, 202101,
  202012, 202011, 202010, 202009, 202008, 202007,
  202006, 202005
)

dataset[, fold_final_train := foto_mes %in% PARAM$trainingstrategy$final_train ]

# creo el dfinal_train en formato  LightGBM
dfinal_train <- lgb.Dataset(
  data= data.matrix(dataset[fold_final_train == TRUE, campos_buenos, with= FALSE]),
  label= dataset[fold_final_train == TRUE, clase01],
  free_raw_data= TRUE
)

nrow( dfinal_train) # verifico el tamaño
# Out:
# [1] 207504

# %% [markdown]
# ##### Final Training Hyperparameters

# %%
# uno los parametros fijos y los mejores encontrados de los variables
fijos <- copy(PARAM$lgbm$param_fijos)

# quito lo que optimice en la Bayesian Optimization
fijos$num_iterations <- NULL
fijos$early_stopping_rounds <- NULL

# agrego a los hiperparametros fijos los que encontre con la Bayesian Optimization
param_final <- c(fijos, PARAM$out$lgbm$mejores_hiperparametros)

# Para el entrenamiento final, removemos early_stopping_rounds
# ya que se entrena con todos los datos disponibles y la cantidad de iteraciones
# ya está optimizada en 'num_iterations'.
param_final$early_stopping_rounds <- NULL

# %% [markdown]
# ##### Training
# Genero el modelo final, siempre sobre TODOS los datos de  final_train, sin hacer ningun tipo de undersampling de la clase mayoritaria

# %%
final_model <- lgb.train(
  data= dfinal_train,
  param= param_final,
  verbose= -100
)

# %%
# grabo a disco el modelo en un formato para seres humanos ... ponele ...

lgb.save(final_model, "modelo.txt")

# %%
# ahora imprimo la importancia de variables

tb_importancia <- as.data.table(lgb.importance(final_model))
archivo_importancia <- "impo.txt"

fwrite( tb_importancia,
  file= archivo_importancia,
  sep= "\t"
)

# %% [markdown]
# #### Scoring

# %% [markdown]
# Aplico el modelo final a los datos del futuro

# %%
PARAM$trainingstrategy$future <- c(202107)

dfuture <- dataset[ foto_mes %in% PARAM$trainingstrategy$future ]

# %%
# aplico final_model   a dfuture

prediccion <- predict(
  final_model,
  data.matrix(dfuture[, campos_buenos, with= FALSE])
)

# %% [markdown]
# ##### Tabla Prediccion

# %%
tb_prediccion <- dfuture[, list(numero_de_cliente)]
tb_prediccion[, prob := prediccion]

# grabo las probabilidad del modelo
#  me va a ser util para hacer Ensembles de modelos
fwrite(tb_prediccion,
  file= "prediccion.txt",
  sep= "\t"
)

# %% [markdown]
# #### Curva de Ganancia

# %% [markdown]
# Genero las salidas

# %%
# asigno clase ternaria
tb_prediccion[, clase_ternaria := dfuture$clase_ternaria ]

# asigno ganancias
tb_prediccion[, ganancia := -3000.0 ]
tb_prediccion[clase_ternaria=="BAJA+2", ganancia := 117000.0 ]

# reordeno, y acumulada
setorder( tb_prediccion, -prob )
tb_prediccion[, gan_acum := cumsum(ganancia)]

# media movil de ancho 400
tb_prediccion[,
  gan_suavizada := frollmean(
    x= gan_acum,
    n= 400,
    align= "center",
    na.rm= TRUE,
    hasNA= TRUE
  )
]

# %%
tb_prediccion[, sum(!is.na(gan_suavizada) )]
tb_prediccion[, .N]
# Out:
# [1] 16152
# [1] 16551

# %%
# Este es la ganancia a reportar
resultado <- list()
resultado$ganancia_suavizada_max <- max( tb_prediccion$gan_suavizada, na.rm=TRUE )
options(digits= 8)
resultado$envios <- which.max( tb_prediccion$gan_suavizada)
resultado
# Out:
# $ganancia_suavizada_max
# [1] 6648000
#
# $envios
# [1] 1661

# %%
# grabo las ganancias
fwrite( tb_prediccion,
  file= "ganancias.txt",
  sep= "\t"
)

# %%
# genero el grafico

tb_prediccion[, envios:= .I]

pdf("curva_de_ganancia.pdf")

plot(
  x= tb_prediccion$envios,
  y= tb_prediccion$gan_acum,
  type= "l",
  col= "gray",
  xlim= c(0, 6000),
  ylim= c(0, 8000000),
  main= paste0("Mejor gan prom= ", as.integer(resultado$ganancia_suavizada_max), " envios= ", resultado$envios),
  xlab= "Envios",
  ylab= "Ganancia",
  panel.first= grid()
)

dev.off()
# Out:
# agg_record_1782238528
#                     2

# %%
# grabo los parametros
if( !require("yaml")) install.packages("yaml")
require("yaml")

PARAM$resultado <- resultado

write_yaml( PARAM, file="PARAM.yml")
# Out:
# Loading required package: yaml

# %%
format(Sys.time(), "%a %b %d %X %Y")
fin <- Sys.time()

# Duración en segundos
secs <- as.numeric(difftime(fin, principio, units = "secs"))
secs <- round(secs)

# A hh:mm:ss
h <- secs %/% 3600
m <- (secs %% 3600) %/% 60
s <- secs %% 60
dur_hms <- sprintf("%02d:%02d:%02d", h, m, s)

cat(
  "Inicio: ", format(principio, "%a %b %d %X %Y"), "\n",
  "Fin:    ", format(fin,       "%a %b %d %X %Y"), "\n",
  "Duración (hh:mm:ss): ", dur_hms, "\n",
  sep = ""
)
# Out:
# [1] "Fri Nov 21 05:13:01 AM 2025"
# Inicio: Thu Nov 20 06:28:08 PM 2025
# Fin:    Fri Nov 21 05:13:01 AM 2025
# Duración (hh:mm:ss): 10:44:52
