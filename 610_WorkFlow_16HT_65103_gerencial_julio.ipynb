# %% [markdown]
# <a href="https://colab.research.google.com/github/jwbarbona/labo2025v/blob/main/610_WorkFlow_16HT_65103_gerencial_julio.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # 6 WorkFlow  Gerencial, futuro=JULIO

# %% [markdown]
# ### 6.1 Objetivo

# %% [markdown]
# Presentar un workflow/pipeline completo al que los estudiantes deberán enriquecer

# %% [markdown]
# #### 6.2  Seteo del ambiente en Google Colab

# %% [markdown]
# Esta parte se debe correr con el runtime en Python3
# <br>Ir al menu, Runtime -> Change Runtime Type -> Runtime type ->  **Python 3**

# %% [markdown]
# Conectar la virtual machine donde esta corriendo Google Colab con el  Google Drive, para poder tener persistencia de archivos

# %%
# primero establecer el Runtime de Python 3
from google.colab import drive
drive.mount('/content/.drive')
# Out:
# Mounted at /content/.drive

# %% [markdown]
# Para correr la siguiente celda es fundamental en Arranque en Frio haber copiado el archivo kaggle.json al Google Drive, en la carpeta indicada en el instructivo
#
# <br>los siguientes comando estan en shell script de Linux
# *   Crear las carpetas en el Google Drive
# *   "instalar" el archivo kaggle.json desde el Google Drive a la virtual machine para que pueda ser utilizado por la libreria  kaggle de Python
# *   Bajar el  **dataset_pequeno**  al  Google Drive  y tambien al disco local de la virtual machine que esta corriendo Google Colab
# *   Bajar el **dataset_historico** al Google Drive y tambien al disco local de la virtual machine que esta corriendo Google Colab

# %%
%%shell

mkdir -p "/content/.drive/My Drive/labo1"
mkdir -p "/content/buckets"
ln -s "/content/.drive/My Drive/labo1" /content/buckets/b1

mkdir -p ~/.kaggle
cp /content/buckets/b1/kaggle/kaggle.json  ~/.kaggle
chmod 600 ~/.kaggle/kaggle.json


mkdir -p /content/buckets/b1/exp
mkdir -p /content/buckets/b1/datasets
mkdir -p /content/datasets


webfiles="https://storage.googleapis.com/open-courses/austral2025-af91/"
destino_local="/content/datasets"
destino_bucket="/content/buckets/b1/datasets"


archivo="dataset_pequeno.csv"

if ! test -f $destino_bucket/$archivo; then
  wget  $webfiles/$archivo  -O $destino_bucket/$archivo
fi


if ! test -f $destino_local/$pequeno; then
  cp  $destino_bucket/$archivo  $destino_local/$archivo
fi

#-------

archivo="gerencial_competencia_2025.csv.gz"

if ! test -f $destino_bucket/$archivo; then
  wget  $webfiles/$archivo  -O $destino_bucket/$archivo
fi


if ! test -f $destino_local/$pequeno; then
  cp  $destino_bucket/$archivo  $destino_local/$archivo
fi
# Out:
# cp: cannot stat '/content/buckets/b1/kaggle/kaggle.json': No such file or directory
# chmod: cannot access '/root/.kaggle/kaggle.json': No such file or directory

# %% [markdown]
# ## 6.3  Workflow

# %% [markdown]
# ## Inicializacion

# %% [markdown]
# Esta parte se debe correr con el runtime en lenguaje **R** Ir al menu, Runtime -> Change Runtime Type -> Runtime type -> R

# %% [markdown]
# limpio el ambiente de R

# %%
format(Sys.time(), "%a %b %d %X %Y")
# Out:
# [1] "Wed Nov 19 02:13:40 AM 2025"

# %%
# limpio la memoria
rm(list=ls(all.names=TRUE)) # remove all objects
gc(full=TRUE, verbose=FALSE) # garbage collection
# Out:
#        used    (Mb) gc trigger (Mb) max used (Mb)
# Ncells  660352 35.3 1454500    77.7 1454500  77.7
# Vcells 1226511  9.4 8388608    64.0 1975136  15.1

# %%
principio <- Sys.time()

# %%
require("data.table")

if( !require("R.utils")) install.packages("R.utils")
require("R.utils")
# Out:
# Loading required package: data.table
#
# Loading required package: R.utils
#
# Warning message in library(package, lib.loc = lib.loc, character.only = TRUE, logical.return = TRUE, :
# “there is no package called ‘R.utils’”
# Installing package into ‘/usr/local/lib/R/site-library’
# (as ‘lib’ is unspecified)
#
# also installing the dependencies ‘R.oo’, ‘R.methodsS3’
#
#
# Loading required package: R.utils
#
# Loading required package: R.oo
#
# Loading required package: R.methodsS3
#
# R.methodsS3 v1.8.2 (2022-06-13 22:00:14 UTC) successfully loaded. See ?R.methodsS3 for help.
#
# R.oo v1.27.1 (2025-05-02 21:00:05 UTC) successfully loaded. See ?R.oo for help.
#
#
# Attaching package: ‘R.oo’
#
#
# The following object is masked from ‘package:R.methodsS3’:
#
#     throw
#
#
# The following objects are masked from ‘package:methods’:
#
#     getClasses, getMethods
#
#
# The following objects are masked from ‘package:base’:
#
#     attach, detach, load, save
#
#
# R.utils v2.13.0 (2025-02-24 21:20:02 UTC) successfully loaded. See ?R.utils for help.
#
#
# Attaching package: ‘R.utils’
#
#
# The following object is masked from ‘package:utils’:
#
#     timestamp
#
#
# The following objects are masked from ‘package:base’:
#
#     cat, commandArgs, getOption, isOpen, nullfile, parse, use, warnings

# %% [markdown]
# #### Parametros
# Si es gerente, no cambie nada
# <br>Si es Analista, cambie el nombre del dataset

# %%
PARAM <- list()
PARAM$semilla_primigenia <- 499999 # 100009, 200003, 499999, 700009, 999983

PARAM$experimento <- 65103
PARAM$dataset <- "gerencial_competencia_2025.csv.gz"

# %% [markdown]
# #### Carpeta del Experimento

# %%
# carpeta de trabajo

setwd("/content/buckets/b1/exp")
experimento_folder <- paste0("WF", PARAM$experimento)
dir.create(experimento_folder, showWarnings=FALSE)
setwd( paste0("/content/buckets/b1/exp/", experimento_folder ))

# %% [markdown]
# ### 6.3.1   Preprocesamiento del dataset

# %% [markdown]
# #### 6.3.1.1  DT incorporar dataset

# %%
# lectura del dataset
dataset <- fread(paste0("/content/datasets/", PARAM$dataset))

# %% [markdown]
# #### 6.3.1.2  CA  Catastrophe Analysis
# Se intentan reparar las variables que para un mes están con todos los valores en cero.

# %% [markdown]
# El método que se utiliza es **Machine Learning** se asigna NA also valores, si ha leido bien, es la "anti imputación de valores faltantes"
# <br> Usted podrá aplicar aquí otros métodos

# %%
dataset[ foto_mes==202006, internet:=NA]
dataset[ foto_mes==202006, mrentabilidad:=NA]
dataset[ foto_mes==202006, mrentabilidad_annual:=NA]
dataset[ foto_mes==202006, mcomisiones:=NA]
dataset[ foto_mes==202006, mactivos_margen:=NA]
dataset[ foto_mes==202006, mpasivos_margen:=NA]
dataset[ foto_mes==202006, mcuentas_saldo:=NA]
dataset[ foto_mes==202006, ctarjeta_visa_transacciones:=NA]
dataset[ foto_mes==202006, mtarjeta_visa_consumo:=NA]
dataset[ foto_mes==202006, mtarjeta_master_consumo:=NA]
dataset[ foto_mes==202006, ccallcenter_transacciones:=NA]
dataset[ foto_mes==202006, chomebanking_transacciones:=NA]
dataset[ foto_mes==202006, chomebanking_transacciones:=NA]

# %% [markdown]
# #### 6.3.1.3  DR  Data Drifting
# Se intenta corregir el data drifting, quizas ajustando por IPC ...
# <br>Esta parte podrá ser abordada por todos los Analistas y también la Gerenciapero se decide pedagogicamente no incluirla en esta primer version para reducir la carga cognitiva

# %%
# sin codigo en esta primera version del workflow

# %% [markdown]
# #### 6.3.1.3  FE_intra_manual Feature Engineering intra-mes
#
# Agrego campos nuevos dentro del mismo mes, SIN considerar la historia.

# %%
# esta funcion atributos presentes existe debido a que las modalidades poseen datasets con distinta cantidad de campos
atributos_presentes <- function( patributos )
{
  atributos <- unique( patributos )
  comun <- intersect( atributos, colnames(dataset) )

  return(  length( atributos ) == length( comun ) )
}

# el mes 1,2, ..12
if( atributos_presentes( c("foto_mes") ))
  dataset[, kmes := foto_mes %% 100]

# variable extraida de una tesis de maestria de Irlanda
if( atributos_presentes( c("mpayroll", "cliente_edad") ))
  dataset[, mpayroll_sobre_edad := mpayroll / cliente_edad]

# %%
# visualizo las columas del dataset a esta etapa
colnames(dataset)
# Out:
#  [1] "numero_de_cliente"           "foto_mes"
#  [3] "internet"                    "cliente_edad"
#  [5] "cliente_antiguedad"          "mrentabilidad"
#  [7] "mrentabilidad_annual"        "mcomisiones"
#  [9] "mactivos_margen"             "mpasivos_margen"
# [11] "cproductos"                  "mcuenta_corriente"
# [13] "mcaja_ahorro"                "cdescubierto_preacordado"
# [15] "mcuentas_saldo"              "ctarjeta_visa_transacciones"
# [17] "mtarjeta_visa_consumo"       "mtarjeta_master_consumo"
# [19] "mprestamos_personales"       "cpayroll_trx"
# [21] "mpayroll"                    "ccomisiones_mantenimiento"
# [23] "ccallcenter_transacciones"   "chomebanking_transacciones"
# [25] "ctrx_quarter"                "Master_status"
# [27] "Master_fechaalta"            "Master_mpagominimo"
# [29] "Visa_status"                 "Visa_fechaalta"
# [31] "Visa_mpagominimo"            "clase_ternaria"
# [33] "kmes"                        "mpayroll_sobre_edad"

# %% [markdown]
# #### 6.3.1.4  FE_rf Feature Engineering de nuevas variables a partir de hojas de Random Forest
#
# Esto se mostrará unicamente a la *modalidad Analista Sr*

# %%
# No se implementa Feature Engineering a partir de Random Forest

# %% [markdown]
# #### 6.3.1.5  FEhist Feature Engineering historico
#
# El Fature Engineering Histórico es la etapa que más aporta a la ganancia final, ya que enriquece cada registro del dataset con su historia.

# %% [markdown]
# Para cada campo del dataset original (*)
# se crean lo siguientes campos de a partir de la historia
# * lag1  lags de orden 1
# * delta1  =  valor actual - lag1
# * lag2  lags de orden 2
# * delta2  = valor actual - lag2
#
#
# (*) Excepto para los campos  <numero_de_cliente,  foto_mes,  clase_ternaria>

# %%
# Feature Engineering Historico

# todo es lagueable, menos la primary key y la clase
cols_lagueables <- copy( setdiff(
    colnames(dataset),
    c("numero_de_cliente", "foto_mes", "clase_ternaria")
) )

# https://rdrr.io/cran/data.table/man/shift.html

# lags de orden 1
dataset[,
    paste0(cols_lagueables, "_lag1") := shift(.SD, 1, NA, "lag"),
    by = numero_de_cliente,
    .SDcols = cols_lagueables
]

# lags de orden 2
dataset[,
    paste0(cols_lagueables, "_lag2") := shift(.SD, 2, NA, "lag"),
    by = numero_de_cliente,
    .SDcols = cols_lagueables
]

# agrego los delta lags
for (vcol in cols_lagueables)
{
    dataset[, paste0(vcol, "_delta1") := get(vcol) - get(paste0(vcol, "_lag1"))]
    dataset[, paste0(vcol, "_delta2") := get(vcol) - get(paste0(vcol, "_lag2"))]
}

# %% [markdown]
# Verificacion de los campos recien creados

# %%
ncol(dataset)
colnames(dataset)
# Out:
# [1] 158
#   [1] "numero_de_cliente"                  "foto_mes"
#   [3] "internet"                           "cliente_edad"
#   [5] "cliente_antiguedad"                 "mrentabilidad"
#   [7] "mrentabilidad_annual"               "mcomisiones"
#   [9] "mactivos_margen"                    "mpasivos_margen"
#  [11] "cproductos"                         "mcuenta_corriente"
#  [13] "mcaja_ahorro"                       "cdescubierto_preacordado"
#  [15] "mcuentas_saldo"                     "ctarjeta_visa_transacciones"
#  [17] "mtarjeta_visa_consumo"              "mtarjeta_master_consumo"
#  [19] "mprestamos_personales"              "cpayroll_trx"
#  [21] "mpayroll"                           "ccomisiones_mantenimiento"
#  [23] "ccallcenter_transacciones"          "chomebanking_transacciones"
#  [25] "ctrx_quarter"                       "Master_status"
#  [27] "Master_fechaalta"                   "Master_mpagominimo"
#  [29] "Visa_status"                        "Visa_fechaalta"
#  [31] "Visa_mpagominimo"                   "clase_ternaria"
#  [33] "kmes"                               "mpayroll_sobre_edad"
#  [35] "internet_lag1"                      "cliente_edad_lag1"
#  [37] "cliente_antiguedad_lag1"            "mrentabilidad_lag1"
#  [39] "mrentabilidad_annual_lag1"          "mcomisiones_lag1"
#  [41] "mactivos_margen_lag1"               "mpasivos_margen_lag1"
#  [43] "cproductos_lag1"                    "mcuenta_corriente_lag1"
#  [45] "mcaja_ahorro_lag1"                  "cdescubierto_preacordado_lag1"
#  [47] "mcuentas_saldo_lag1"                "ctarjeta_visa_transacciones_lag1"
#  [49] "mtarjeta_visa_consumo_lag1"         "mtarjeta_master_consumo_lag1"
#  [51] "mprestamos_personales_lag1"         "cpayroll_trx_lag1"
#  [53] "mpayroll_lag1"                      "ccomisiones_mantenimiento_lag1"
#  [55] "ccallcenter_transacciones_lag1"     "chomebanking_transacciones_lag1"
#  [57] "ctrx_quarter_lag1"                  "Master_status_lag1"
#  [59] "Master_fechaalta_lag1"              "Master_mpagominimo_lag1"
#  [61] "Visa_status_lag1"                   "Visa_fechaalta_lag1"
#  [63] "Visa_mpagominimo_lag1"              "kmes_lag1"
#  [65] "mpayroll_sobre_edad_lag1"           "internet_lag2"
#  [67] "cliente_edad_lag2"                  "cliente_antiguedad_lag2"
#  [69] "mrentabilidad_lag2"                 "mrentabilidad_annual_lag2"
#  [71] "mcomisiones_lag2"                   "mactivos_margen_lag2"
#  [73] "mpasivos_margen_lag2"               "cproductos_lag2"
#  [75] "mcuenta_corriente_lag2"             "mcaja_ahorro_lag2"
#  [77] "cdescubierto_preacordado_lag2"      "mcuentas_saldo_lag2"
#  [79] "ctarjeta_visa_transacciones_lag2"   "mtarjeta_visa_consumo_lag2"
#  [81] "mtarjeta_master_consumo_lag2"       "mprestamos_personales_lag2"
#  [83] "cpayroll_trx_lag2"                  "mpayroll_lag2"
#  [85] "ccomisiones_mantenimiento_lag2"     "ccallcenter_transacciones_lag2"
#  [87] "chomebanking_transacciones_lag2"    "ctrx_quarter_lag2"
#  [89] "Master_status_lag2"                 "Master_fechaalta_lag2"
#  [91] "Master_mpagominimo_lag2"            "Visa_status_lag2"
#  [93] "Visa_fechaalta_lag2"                "Visa_mpagominimo_lag2"
#  [95] "kmes_lag2"                          "mpayroll_sobre_edad_lag2"
#  [97] "internet_delta1"                    "internet_delta2"
#  [99] "cliente_edad_delta1"                "cliente_edad_delta2"
# [101] "cliente_antiguedad_delta1"          "cliente_antiguedad_delta2"
# [103] "mrentabilidad_delta1"               "mrentabilidad_delta2"
# [105] "mrentabilidad_annual_delta1"        "mrentabilidad_annual_delta2"
# [107] "mcomisiones_delta1"                 "mcomisiones_delta2"
# [109] "mactivos_margen_delta1"             "mactivos_margen_delta2"
# [111] "mpasivos_margen_delta1"             "mpasivos_margen_delta2"
# [113] "cproductos_delta1"                  "cproductos_delta2"
# [115] "mcuenta_corriente_delta1"           "mcuenta_corriente_delta2"
# [117] "mcaja_ahorro_delta1"                "mcaja_ahorro_delta2"
# [119] "cdescubierto_preacordado_delta1"    "cdescubierto_preacordado_delta2"
# [121] "mcuentas_saldo_delta1"              "mcuentas_saldo_delta2"
# [123] "ctarjeta_visa_transacciones_delta1" "ctarjeta_visa_transacciones_delta2"
# [125] "mtarjeta_visa_consumo_delta1"       "mtarjeta_visa_consumo_delta2"
# [127] "mtarjeta_master_consumo_delta1"     "mtarjeta_master_consumo_delta2"
# [129] "mprestamos_personales_delta1"       "mprestamos_personales_delta2"
# [131] "cpayroll_trx_delta1"                "cpayroll_trx_delta2"
# [133] "mpayroll_delta1"                    "mpayroll_delta2"
# [135] "ccomisiones_mantenimiento_delta1"   "ccomisiones_mantenimiento_delta2"
# [137] "ccallcenter_transacciones_delta1"   "ccallcenter_transacciones_delta2"
# [139] "chomebanking_transacciones_delta1"  "chomebanking_transacciones_delta2"
# [141] "ctrx_quarter_delta1"                "ctrx_quarter_delta2"
# [143] "Master_status_delta1"               "Master_status_delta2"
# [145] "Master_fechaalta_delta1"            "Master_fechaalta_delta2"
# [147] "Master_mpagominimo_delta1"          "Master_mpagominimo_delta2"
# [149] "Visa_status_delta1"                 "Visa_status_delta2"
# [151] "Visa_fechaalta_delta1"              "Visa_fechaalta_delta2"
# [153] "Visa_mpagominimo_delta1"            "Visa_mpagominimo_delta2"
# [155] "kmes_delta1"                        "kmes_delta2"
# [157] "mpayroll_sobre_edad_delta1"         "mpayroll_sobre_edad_delta2"

# %% [markdown]
# #### 6.3.1.6  FEhist Reduccion dimensionalidad con canaritos
#
# Esta etapa solo se mostrará a la *modalidad Anlista Sr* por algun canal secreto de forma de no confundir a los *Analista Jr*  nni distraer con detalles operativos a la estratégica *Modalidad Gerencial*

# %%
# No se implementa la reduccion de la dimensionalidad con canaritos

# %% [markdown]
# ### 6.3.2 Modelado

# %% [markdown]
# #### 6.3.2.1 Training Strategy
#
# Esta etapa de Workflow de  Training Strategy esta pensada para la *Modalidad Gerencial* que posee el dataset de [202005, 202109]
# <br> Si usted es un Analista, posee el periodo de [201901, 202109] y deberá experimentar en que meses le conviene experimentar
#
# <br> A la *Modalidad Gerencial* no se le complicada la vida con el undersampling de los continua, por eso PARAM$trainingstrategy$training_pct <- 1.0
# <br> Sin embargo, si usted es  *Analista SR* posee un dataset 50 veces ( filas x columnas) más grande que la *Modalidad Gerencial*  y por un tema de velocidad y experimentación más rápida puede llegar a necesitar activar el undersampling de la clase mayoritaria, a pesar de estar corriendo en Google Cloud.

# %% [markdown]
# Se hace una estrategia de entrenamiento muy sencilla, tomando todos los meses posibles, SIN eliminar nada x pandemia ni por ningun otro motivo
#
# * future = 202107  obviamente completo
#
# * final_train =  [ 202005, 202105 ]  SIN undersampling
#
# * training
#    * testing = NO HAY
#    * validation =  202105   completo, sin undersampling
#    * training = [ 202005, 202104 ]  donde se consideran el 100% de los CONTINUA

# %%
PARAM$trainingstrategy$validate <- c(202105)

PARAM$trainingstrategy$training <- c(
  202104, 202103, 202102, 202101,
  202012, 202011, 202010, 202009, 202008, 202007,
  202006, 202005
)

PARAM$trainingstrategy$training_pct <- 1.0


PARAM$trainingstrategy$positivos <- c( "BAJA+1", "BAJA+2")

# %%
# seteo la clase01   1={BAJA+1, BAJA+2}   0={CONTINUA}
dataset[, clase01 := ifelse( clase_ternaria %in% PARAM$trainingstrategy$positivos, 1, 0 )]

# %%
# los campos en los que se entrena
campos_buenos <- copy( setdiff(
    colnames(dataset), c("clase_ternaria","clase01","azar"))
)

# %%
# preparo para que se puede hacer undersampling de los CONTINUA
#  solamente por un tema de VELOCIDAD
set.seed(PARAM$semilla_primigenia, kind = "L'Ecuyer-CMRG")
dataset[, azar:=runif(nrow(dataset))]

# undersampling de los CONTINUA
dataset[, fold_train :=  foto_mes %in%  PARAM$trainingstrategy$training &
    (clase_ternaria %in% c("BAJA+1", "BAJA+2") |
     azar < PARAM$trainingstrategy$training_pct ) ]


if( !require("lightgbm")) install.packages("lightgbm")
require("lightgbm")

dtrain <- lgb.Dataset(
  data= data.matrix(dataset[fold_train == TRUE, campos_buenos, with = FALSE]),
  label= dataset[fold_train == TRUE, clase01],
  free_raw_data= TRUE
)
# Out:
# Loading required package: lightgbm
#
# Warning message in library(package, lib.loc = lib.loc, character.only = TRUE, logical.return = TRUE, :
# “there is no package called ‘lightgbm’”
# Installing package into ‘/usr/local/lib/R/site-library’
# (as ‘lib’ is unspecified)
#
# Loading required package: lightgbm

# %%
# datos de validation
dvalidate <- lgb.Dataset(
  data= data.matrix(dataset[foto_mes %in% PARAM$trainingstrategy$validate, campos_buenos, with = FALSE]),
  label= dataset[foto_mes %in% PARAM$trainingstrategy$validate, clase01],
  free_raw_data= TRUE
)

nrow(dvalidate)
# Out:
# [1] 16469

# %% [markdown]
# ####  6.3.2.2. Hyperparameter Tuning

# %% [markdown]
# * Clase binaria que se optimiza :  positivos = [ BAJA+1, BAJA+2 ]

# %% [markdown]
# * Metrica que se optimiza **AUC** Area Under Curve de la  ROC Curve
#
# es muy importante notar que intencionalmente  **NO** se está optimizando la funcion de ganancia del problema

# %% [markdown]
# * Cantidad de iteraciones inteligentes de la Optimizacion Bayesiana = **10**

# %% [markdown]
# * Parametros no default, fijos de LightGBM que no se optimizan
#   * max_bin = 31 , Alienigenas Ancestrales contruyeron las pirámides y dejaron a la humanidad en un jeroglifico  *max_bin=31*
#   * feature_fraction = 0.5  para poner algo que generalmente no falla
#   * learning_rate = 0.03  para que aprenda lento

# %% [markdown]
# * Parametros que se optimizan en la Bayesian Optimization
#   * num_leaves  [8, 256]
#   * min_data_in_leaf  [8, 8192]

# %%
# paquetes necesarios para la Bayesian Optimization
if(!require("DiceKriging")) install.packages("DiceKriging")
require("DiceKriging")

if(!require("mlrMBO")) install.packages("mlrMBO")
require("mlrMBO")
# Out:
# Loading required package: DiceKriging
#
# Warning message in library(package, lib.loc = lib.loc, character.only = TRUE, logical.return = TRUE, :
# “there is no package called ‘DiceKriging’”
# Installing package into ‘/usr/local/lib/R/site-library’
# (as ‘lib’ is unspecified)
#
# Loading required package: DiceKriging
#
# Loading required package: mlrMBO
#
# Warning message in library(package, lib.loc = lib.loc, character.only = TRUE, logical.return = TRUE, :
# “there is no package called ‘mlrMBO’”
# Installing package into ‘/usr/local/lib/R/site-library’
# (as ‘lib’ is unspecified)
#
# also installing the dependencies ‘XML’, ‘fastmatch’, ‘RcppArmadillo’, ‘mlr’, ‘ParamHelpers’, ‘smoof’, ‘BBmisc’, ‘checkmate’, ‘lhs’, ‘parallelMap’
#
#
# Loading required package: mlrMBO
#
# Loading required package: mlr
#
# Loading required package: ParamHelpers
#
#
# Attaching package: ‘ParamHelpers’
#
#
# The following object is masked from ‘package:R.utils’:
#
#     isVector
#
#
#
# Attaching package: ‘mlr’
#
#
# The following objects are masked from ‘package:R.utils’:
#
#     resample, setThreshold
#
#
# Loading required package: smoof
#
# Loading required package: checkmate
#
#
# Attaching package: ‘checkmate’
#
#
# The following object is masked from ‘package:DiceKriging’:
#
#     checkNames
#
#
# The following object is masked from ‘package:R.utils’:
#
#     asInt
#
#
#
# Attaching package: ‘smoof’
#
#
# The following objects are masked from ‘package:R.oo’:
#
#     getDescription, getName

# %% [markdown]
# Definición de la Bayesian Optimization
# <br> Si se desea optimizar un hiperparámetro que esta como fijo, debe QUITARSE de param_fijos y agregarse a PARAM$hipeparametertuning$hs

# %%
# valor ridiculamente bajo para que corra rapido en el aula y no molestar a la *Modalidad Gerencial*
PARAM$hipeparametertuning$num_interations <- 120

# parametros fijos del LightGBM
PARAM$lgbm$param_fijos <- list(
  objective= "binary",
  metric= "auc",
  first_metric_only= TRUE,
  boost_from_average= TRUE,
  feature_pre_filter= FALSE,
  verbosity= -100,
  force_row_wise= TRUE, # para evitar warning
  max_bin= 31,
  seed= PARAM$semilla_primigenia
  # learning_rate= 0.03,
  # feature_fraction= 0.5,
  # num_iterations= 2048,  # valor grande, lo limita early_stopping_rounds
  # early_stopping_rounds= 200
)


PARAM$hipeparametertuning$hs <- makeParamSet(
  # Núcleo del modelo (estructura de árboles)
  makeIntegerParam("num_leaves", lower = 2L, upper = 8192L),
  makeIntegerParam("max_depth", lower = 3L, upper = 30L),
  makeNumericParam("min_child_weight", lower = 0.001, upper = 10.0),
  makeIntegerParam("min_data_in_leaf", lower = 2L, upper = 8192L),
  makeNumericParam("min_gain_to_split", lower = 0.0, upper = 0.1),

  # Regularización
  makeNumericParam("lambda_l1", lower = 0.0, upper = 1000L),
  makeNumericParam("lambda_l2", lower = 0.0, upper = 1000L),
  makeNumericParam("scale_pos_weight", lower = 1.0, upper = 5.0),  # útil en desequilibrio

  # Control del aprendizaje
  makeNumericParam("learning_rate", lower = 0.005, upper = 0.1),
  makeIntegerParam("num_iterations", lower = 100L, upper = 5000L),
  makeIntegerParam("early_stopping_rounds", lower = 50L, upper = 500L),

  # Submuestreo
  makeNumericParam("feature_fraction", lower = 0.05, upper = 1L),   # columnas
  makeNumericParam("bagging_fraction", lower = 0.5, upper = 1L),   # filas
  makeIntegerParam("bagging_freq", lower = 0L, upper = 5L),         # cada N iteraciones

  # Opcionales útiles
  makeNumericParam("max_delta_step", lower = 0.0, upper = 10.0),
  makeNumericParam("path_smooth", lower = 0.0, upper = 10.0)
)
# Total: 16 hT

# %% [markdown]
# Función "señora caja negra"  que es llamada para verificar la realidad por la Bayesian Optimization

# %%
# En  x llegan los parmaetros de la bayesiana
#  devuelve la AUC en validate del modelo entrenado
#  en el parametro x llegan los hiperparámetros que se estan optimizando

EstimarGanancia_AUC_lightgbm <- function(x) {

  # x pisa (o agrega) a param_fijos
  param_completo <- modifyList(PARAM$lgbm$param_fijos, x)

  # entreno LightGBM
  modelo_train <- lgb.train(
    data= dtrain,
    valids= list(valid = dvalidate),
    eval= "auc",
    param= param_completo,
    verbose= -100
  )

  # recupero la AUC en validation
  AUC <- modelo_train$record_evals$valid$auc$eval[[modelo_train$best_iter]]

  # esta es la forma de devolver un parametro extra
  attr(AUC, "extras") <- list("num_iterations"= modelo_train$best_iter)

  # hago espacio en la memoria
  rm(modelo_train)
  gc(full= TRUE, verbose= FALSE)

  message(format(Sys.time(), "%a %b %d %X %Y"), " AUC ", AUC)

  return(AUC)
}

# %% [markdown]
# seteo de la Bayesian Optimization (complejo)
# <br> copiado y pegado de la documentación de la librería

# %%
configureMlr(show.learner.output = FALSE)

# configuro la busqueda bayesiana,  los hiperparametros que se van a optimizar
# por favor, no desesperarse por lo complejo
obj.fun <- makeSingleObjectiveFunction(
    fn= EstimarGanancia_AUC_lightgbm, # la funcion que voy a maximizar
    minimize= FALSE, # estoy Maximizando AUC
    noisy= FALSE,
    par.set= PARAM$hipeparametertuning$hs,
    has.simple.signature= FALSE # paso los parametros en una lista
)

# cada 600 segundos guardo el resultado intermedio
ctrl <- makeMBOControl(
    save.on.disk.at.time= 600,
    save.file.path= "HT.RDATA"
)

# indico la cantidad de iteraciones que va a tener la Bayesian Optimization
ctrl <- setMBOControlTermination(
    ctrl,
    iters= PARAM$hipeparametertuning$num_interations  # cantidad de iteraciones inteligentes
)

# defino el método estandar para la creacion de los puntos iniciales
#   los "No Inteligentes"
ctrl <- setMBOControlInfill(ctrl, crit = makeMBOInfillCritEI())

# mas configuraciones
surr.km <- makeLearner(
    "regr.km",
    predict.type= "se",
    covtype= "matern3_2",
    control= list(trace = TRUE)
)

# %% [markdown]
# Corrida de la Bayesian Optimization,  aqui se hace el trabajo pesado
# <br> por favor no se asuste con los warnings que pudieran aparecer
#
# Si corrío a medias y llegó a las iteraciones inteligentes, en el archivo binario HT.RDATA quedó lo ya procesado y es utilizado para retomar la corrida desde lo último que llegó a grabar.

# %%
# inicio la optimizacion bayesiana

if (!file.exists("HT.RDATA")) {
  bayesiana_salida <- mbo(obj.fun, learner= surr.km, control= ctrl)
} else {
  bayesiana_salida <- mboContinue("HT.RDATA") # retomo en caso que ya exista
}
# Out:
# Computing y column(s) for design. Not provided.
#
# Wed Nov 19 02:30:02 AM 2025 AUC 0.896664740710617
#
# Wed Nov 19 02:31:06 AM 2025 AUC 0.894176096805127
#
# Wed Nov 19 02:31:35 AM 2025 AUC 0.894545517991584
#
# Wed Nov 19 02:32:48 AM 2025 AUC 0.895749743821003
#
# Wed Nov 19 02:37:40 AM 2025 AUC 0.915537432331501
#
# Wed Nov 19 02:38:52 AM 2025 AUC 0.902693083804589
#
# Wed Nov 19 02:39:33 AM 2025 AUC 0.5
#
# Wed Nov 19 02:39:56 AM 2025 AUC 0.885242881847629
#
# Wed Nov 19 02:40:06 AM 2025 AUC 0.884239472167251
#
# Wed Nov 19 02:41:28 AM 2025 AUC 0.88390276539104
#
# Wed Nov 19 02:42:37 AM 2025 AUC 0.895335529057443
#
# Wed Nov 19 02:42:53 AM 2025 AUC 0.877686356379713
#
# Wed Nov 19 02:43:19 AM 2025 AUC 0.888671352041279
#
# Wed Nov 19 02:43:37 AM 2025 AUC 0.879361669716656
#
# Wed Nov 19 02:46:29 AM 2025 AUC 0.90930961521814
#
# Wed Nov 19 02:46:48 AM 2025 AUC 0.885211174034623
#
# Wed Nov 19 02:47:21 AM 2025 AUC 0.907007191801735
#
# Wed Nov 19 02:47:43 AM 2025 AUC 0.891392519908816
#
# Wed Nov 19 02:48:04 AM 2025 AUC 0.89280108497761
#
# Wed Nov 19 02:48:29 AM 2025 AUC 0.889135393368135
#
# Wed Nov 19 02:48:58 AM 2025 AUC 0.884708714246505
#
# Wed Nov 19 02:49:25 AM 2025 AUC 0.880688868175355
#
# Wed Nov 19 02:49:59 AM 2025 AUC 0.893107258304259
#
# Wed Nov 19 02:51:37 AM 2025 AUC 0.91166975020954
#
# Wed Nov 19 02:52:06 AM 2025 AUC 0.897202095869663
#
# Wed Nov 19 02:53:08 AM 2025 AUC 0.896799289208137
#
# Wed Nov 19 02:54:03 AM 2025 AUC 0.891185496410139
#
# Wed Nov 19 02:54:41 AM 2025 AUC 0.888798015527098
#
# Wed Nov 19 02:55:06 AM 2025 AUC 0.903566139142607
#
# Wed Nov 19 02:55:17 AM 2025 AUC 0.875564617167583
#
# Wed Nov 19 02:55:26 AM 2025 AUC 0.888119568988484
#
# Wed Nov 19 02:56:15 AM 2025 AUC 0.886782975622228
#
# Wed Nov 19 02:56:51 AM 2025 AUC 0.890922606764736
#
# Wed Nov 19 02:58:54 AM 2025 AUC 0.911520438285859
#
# Wed Nov 19 02:59:38 AM 2025 AUC 0.893082428905715
#
# Wed Nov 19 03:00:06 AM 2025 AUC 0.881745124210744
#
# Wed Nov 19 03:01:30 AM 2025 AUC 0.886221462129463
#
# Wed Nov 19 03:02:20 AM 2025 AUC 0.88651337532857
#
# Wed Nov 19 03:02:55 AM 2025 AUC 0.898493392360195
#
# Wed Nov 19 03:03:12 AM 2025 AUC 0.869002106472487
#
# Wed Nov 19 03:04:13 AM 2025 AUC 0.891854212508783
#
# Wed Nov 19 03:05:02 AM 2025 AUC 0.855810481898362
#
# Wed Nov 19 03:07:55 AM 2025 AUC 0.915684731060705
#
# Wed Nov 19 03:08:07 AM 2025 AUC 0.901333674234265
#
# Wed Nov 19 03:08:36 AM 2025 AUC 0.864769029553024
#
# Wed Nov 19 03:08:45 AM 2025 AUC 0.894894639467067
#
# Wed Nov 19 03:09:14 AM 2025 AUC 0.888014715109494
#
# Wed Nov 19 03:11:13 AM 2025 AUC 0.91324876574402
#
# Wed Nov 19 03:17:00 AM 2025 AUC 0.907191063563931
#
# Wed Nov 19 03:17:44 AM 2025 AUC 0.900948483024409
#
# Wed Nov 19 03:18:24 AM 2025 AUC 0.905867891494186
#
# Wed Nov 19 03:19:21 AM 2025 AUC 0.769421287115757
#
# Wed Nov 19 03:20:04 AM 2025 AUC 0.892356504530694
#
# Wed Nov 19 03:20:34 AM 2025 AUC 0.877130714704171
#
# Wed Nov 19 03:21:10 AM 2025 AUC 0.895698910660469
#
# Wed Nov 19 03:22:22 AM 2025 AUC 0.913115223843739
#
# Wed Nov 19 03:23:25 AM 2025 AUC 0.895569730681554
#
# Wed Nov 19 03:23:47 AM 2025 AUC 0.892171290638847
#
# Wed Nov 19 03:24:04 AM 2025 AUC 0.900832053277179
#
# Wed Nov 19 03:24:13 AM 2025 AUC 0.876179815846391
#
# Wed Nov 19 03:24:40 AM 2025 AUC 0.889393250027346
#
# Wed Nov 19 03:25:15 AM 2025 AUC 0.5
#
# Wed Nov 19 03:25:52 AM 2025 AUC 0.907992314965618
#
# Wed Nov 19 03:26:07 AM 2025 AUC 0.882111190073072
#
# [mbo] 0: num_leaves=6066; max_depth=6; min_child_weight=5.16; min_data_in_leaf=2527; min_gain_to_split=0.0335; lambda_l1=509; lambda_l2=362; scale_pos_weight=4.15; learning_rate=0.0446; num_iterations=3607; early_stopping_rounds=416; feature_fraction=0.482; bagging_fraction=0.713; bagging_freq=3; max_delta_step=8.89; path_smooth=6.39 : y = 0.897 : 89.7 secs : initdesign
#
# [mbo] 0: num_leaves=3597; max_depth=12; min_child_weight=3.52; min_data_in_leaf=3934; min_gain_to_split=0.0221; lambda_l1=308; lambda_l2=445; scale_pos_weight=2.64; learning_rate=0.0888; num_iterations=3212; early_stopping_rounds=277; feature_fraction=0.576; bagging_fraction=0.831; bagging_freq=3; max_delta_step=6.51; path_smooth=2.91 : y = 0.894 : 63.1 secs : initdesign
#
# [mbo] 0: num_leaves=3128; max_depth=19; min_child_weight=4.62; min_data_in_leaf=2224; min_gain_to_split=0.0674; lambda_l1=783; lambda_l2=508; scale_pos_weight=2.85; learning_rate=0.0225; num_iterations=3375; early_stopping_rounds=134; feature_fraction=0.272; bagging_fraction=0.668; bagging_freq=2; max_delta_step=5.99; path_smooth=5.59 : y = 0.895 : 29.2 secs : initdesign
#
# [mbo] 0: num_leaves=4340; max_depth=15; min_child_weight=7.91; min_data_in_leaf=1048; min_gain_to_split=0.0216; lambda_l1=427; lambda_l2=529; scale_pos_weight=3.89; learning_rate=0.0589; num_iterations=1282; early_stopping_rounds=376; feature_fraction=0.438; bagging_fraction=0.677; bagging_freq=2; max_delta_step=5.28; path_smooth=6.73 : y = 0.896 : 73.4 secs : initdesign
#
# [mbo] 0: num_leaves=3064; max_depth=15; min_child_weight=3.37; min_data_in_leaf=4380; min_gain_to_split=0.056; lambda_l1=18; lambda_l2=278; scale_pos_weight=3.02; learning_rate=0.0526; num_iterations=2387; early_stopping_rounds=268; feature_fraction=0.389; bagging_fraction=0.654; bagging_freq=4; max_delta_step=5.63; path_smooth=7.73 : y = 0.916 : 291.5 secs : initdesign
#
# [mbo] 0: num_leaves=4715; max_depth=20; min_child_weight=3.9; min_data_in_leaf=802; min_gain_to_split=0.0469; lambda_l1=461; lambda_l2=352; scale_pos_weight=3.55; learning_rate=0.034; num_iterations=2874; early_stopping_rounds=323; feature_fraction=0.557; bagging_fraction=0.88; bagging_freq=0; max_delta_step=4.54; path_smooth=7.04 : y = 0.903 : 72.6 secs : initdesign
#
# [mbo] 0: num_leaves=423; max_depth=13; min_child_weight=7.2; min_data_in_leaf=6436; min_gain_to_split=0.0398; lambda_l1=898; lambda_l2=720; scale_pos_weight=1.06; learning_rate=0.0509; num_iterations=2499; early_stopping_rounds=368; feature_fraction=0.409; bagging_fraction=0.7; bagging_freq=4; max_delta_step=1.47; path_smooth=1.79 : y = 0.5 : 40.9 secs : initdesign
#
# [mbo] 0: num_leaves=4845; max_depth=21; min_child_weight=2.07; min_data_in_leaf=5883; min_gain_to_split=0.0372; lambda_l1=544; lambda_l2=425; scale_pos_weight=3.08; learning_rate=0.0581; num_iterations=3634; early_stopping_rounds=192; feature_fraction=0.154; bagging_fraction=0.643; bagging_freq=5; max_delta_step=1.86; path_smooth=6.16 : y = 0.885 : 22.4 secs : initdesign
#
# [mbo] 0: num_leaves=1608; max_depth=13; min_child_weight=6.11; min_data_in_leaf=6970; min_gain_to_split=0.0442; lambda_l1=701; lambda_l2=400; scale_pos_weight=3.67; learning_rate=0.068; num_iterations=3279; early_stopping_rounds=174; feature_fraction=0.695; bagging_fraction=0.862; bagging_freq=4; max_delta_step=8.06; path_smooth=7.88 : y = 0.884 : 10.6 secs : initdesign
#
# [mbo] 0: num_leaves=1979; max_depth=18; min_child_weight=1.29; min_data_in_leaf=3422; min_gain_to_split=0.0667; lambda_l1=769; lambda_l2=576; scale_pos_weight=2.6; learning_rate=0.0144; num_iterations=2659; early_stopping_rounds=455; feature_fraction=0.593; bagging_fraction=0.659; bagging_freq=3; max_delta_step=3.84; path_smooth=7.3 : y = 0.884 : 81.9 secs : initdesign
#
# [mbo] 0: num_leaves=5288; max_depth=18; min_child_weight=9.58; min_data_in_leaf=7060; min_gain_to_split=0.0522; lambda_l1=292; lambda_l2=461; scale_pos_weight=3.43; learning_rate=0.0633; num_iterations=3809; early_stopping_rounds=337; feature_fraction=0.471; bagging_fraction=0.636; bagging_freq=3; max_delta_step=4.52; path_smooth=4.07 : y = 0.895 : 68.8 secs : initdesign
#
# [mbo] 0: num_leaves=6776; max_depth=13; min_child_weight=6.42; min_data_in_leaf=2330; min_gain_to_split=0.0651; lambda_l1=415; lambda_l2=786; scale_pos_weight=1.43; learning_rate=0.0714; num_iterations=1992; early_stopping_rounds=158; feature_fraction=0.81; bagging_fraction=0.874; bagging_freq=0; max_delta_step=3.22; path_smooth=4.32 : y = 0.878 : 15.8 secs : initdesign
#
# [mbo] 0: num_leaves=4868; max_depth=26; min_child_weight=3.13; min_data_in_leaf=7348; min_gain_to_split=0.00971; lambda_l1=151; lambda_l2=926; scale_pos_weight=3.19; learning_rate=0.0186; num_iterations=1489; early_stopping_rounds=188; feature_fraction=0.119; bagging_fraction=0.568; bagging_freq=4; max_delta_step=2.34; path_smooth=1.12 : y = 0.889 : 26.5 secs : initdesign
#
# [mbo] 0: num_leaves=5510; max_depth=19; min_child_weight=8.66; min_data_in_leaf=1345; min_gain_to_split=0.0425; lambda_l1=832; lambda_l2=485; scale_pos_weight=2.01; learning_rate=0.0433; num_iterations=1185; early_stopping_rounds=343; feature_fraction=0.746; bagging_fraction=0.708; bagging_freq=4; max_delta_step=5.52; path_smooth=9.77 : y = 0.879 : 17.9 secs : initdesign
#
# [mbo] 0: num_leaves=7430; max_depth=9; min_child_weight=8.16; min_data_in_leaf=4662; min_gain_to_split=0.0618; lambda_l1=120; lambda_l2=182; scale_pos_weight=4.06; learning_rate=0.00655; num_iterations=1451; early_stopping_rounds=401; feature_fraction=0.613; bagging_fraction=0.926; bagging_freq=1; max_delta_step=5.42; path_smooth=3.63 : y = 0.909 : 171.7 secs : initdesign
#
# [mbo] 0: num_leaves=1375; max_depth=24; min_child_weight=6.71; min_data_in_leaf=5963; min_gain_to_split=0.0933; lambda_l1=665; lambda_l2=860; scale_pos_weight=1.72; learning_rate=0.0618; num_iterations=207; early_stopping_rounds=117; feature_fraction=0.357; bagging_fraction=0.749; bagging_freq=2; max_delta_step=4.34; path_smooth=2.42 : y = 0.885 : 19.3 secs : initdesign
#
# [mbo] 0: num_leaves=3445; max_depth=10; min_child_weight=7.08; min_data_in_leaf=3136; min_gain_to_split=0.0605; lambda_l1=64.7; lambda_l2=811; scale_pos_weight=2.39; learning_rate=0.0553; num_iterations=424; early_stopping_rounds=74; feature_fraction=0.903; bagging_fraction=0.72; bagging_freq=5; max_delta_step=2.06; path_smooth=8.26 : y = 0.907 : 33.1 secs : initdesign
#
# [mbo] 0: num_leaves=2551; max_depth=28; min_child_weight=9.06; min_data_in_leaf=109; min_gain_to_split=0.0378; lambda_l1=813; lambda_l2=28.2; scale_pos_weight=3.24; learning_rate=0.0418; num_iterations=3869; early_stopping_rounds=385; feature_fraction=0.727; bagging_fraction=0.599; bagging_freq=5; max_delta_step=3.72; path_smooth=3.08 : y = 0.891 : 21.4 secs : initdesign
#
# [mbo] 0: num_leaves=5243; max_depth=4; min_child_weight=5.36; min_data_in_leaf=2106; min_gain_to_split=0.0289; lambda_l1=632; lambda_l2=379; scale_pos_weight=4.01; learning_rate=0.0939; num_iterations=2574; early_stopping_rounds=392; feature_fraction=0.647; bagging_fraction=0.884; bagging_freq=2; max_delta_step=6.27; path_smooth=3.55 : y = 0.893 : 21.2 secs : initdesign
#
# [mbo] 0: num_leaves=7358; max_depth=13; min_child_weight=2.41; min_data_in_leaf=1576; min_gain_to_split=0.0626; lambda_l1=572; lambda_l2=286; scale_pos_weight=2.52; learning_rate=0.0325; num_iterations=2311; early_stopping_rounds=154; feature_fraction=0.187; bagging_fraction=0.764; bagging_freq=2; max_delta_step=7.63; path_smooth=9.87 : y = 0.889 : 25.0 secs : initdesign
#
# [mbo] 0: num_leaves=313; max_depth=15; min_child_weight=0.315; min_data_in_leaf=6785; min_gain_to_split=0.0465; lambda_l1=269; lambda_l2=771; scale_pos_weight=2.2; learning_rate=0.0905; num_iterations=2058; early_stopping_rounds=207; feature_fraction=0.539; bagging_fraction=0.573; bagging_freq=2; max_delta_step=1.27; path_smooth=6.01 : y = 0.885 : 28.9 secs : initdesign
#
# [mbo] 0: num_leaves=2182; max_depth=16; min_child_weight=2.33; min_data_in_leaf=5630; min_gain_to_split=0.0721; lambda_l1=960; lambda_l2=1.33; scale_pos_weight=1.54; learning_rate=0.0237; num_iterations=3487; early_stopping_rounds=229; feature_fraction=0.289; bagging_fraction=0.989; bagging_freq=2; max_delta_step=3.41; path_smooth=1.3 : y = 0.881 : 27.0 secs : initdesign
#
# [mbo] 0: num_leaves=2070; max_depth=28; min_child_weight=3.72; min_data_in_leaf=3634; min_gain_to_split=0.0128; lambda_l1=922; lambda_l2=996; scale_pos_weight=3.61; learning_rate=0.0753; num_iterations=928; early_stopping_rounds=270; feature_fraction=0.125; bagging_fraction=0.892; bagging_freq=2; max_delta_step=0.232; path_smooth=7.49 : y = 0.893 : 34.1 secs : initdesign
#
# [mbo] 0: num_leaves=7230; max_depth=17; min_child_weight=3.08; min_data_in_leaf=5332; min_gain_to_split=0.0699; lambda_l1=11.7; lambda_l2=60.2; scale_pos_weight=1.37; learning_rate=0.0691; num_iterations=4249; early_stopping_rounds=256; feature_fraction=0.837; bagging_fraction=0.981; bagging_freq=5; max_delta_step=7.07; path_smooth=0.538 : y = 0.912 : 98.3 secs : initdesign
#
# [mbo] 0: num_leaves=5094; max_depth=20; min_child_weight=6.3; min_data_in_leaf=750; min_gain_to_split=0.0259; lambda_l1=334; lambda_l2=621; scale_pos_weight=2.89; learning_rate=0.0999; num_iterations=4801; early_stopping_rounds=217; feature_fraction=0.0988; bagging_fraction=0.535; bagging_freq=0; max_delta_step=5.15; path_smooth=9.31 : y = 0.897 : 28.7 secs : initdesign
#
# [mbo] 0: num_leaves=4096; max_depth=3; min_child_weight=9.2; min_data_in_leaf=5054; min_gain_to_split=0.0846; lambda_l1=559; lambda_l2=591; scale_pos_weight=4.71; learning_rate=0.0469; num_iterations=3077; early_stopping_rounds=480; feature_fraction=0.212; bagging_fraction=0.824; bagging_freq=5; max_delta_step=6.63; path_smooth=3.39 : y = 0.897 : 61.6 secs : initdesign
#
# [mbo] 0: num_leaves=7998; max_depth=25; min_child_weight=8.49; min_data_in_leaf=3319; min_gain_to_split=0.0763; lambda_l1=381; lambda_l2=128; scale_pos_weight=3.99; learning_rate=0.0739; num_iterations=1059; early_stopping_rounds=305; feature_fraction=0.0771; bagging_fraction=0.819; bagging_freq=3; max_delta_step=1.6; path_smooth=8.06 : y = 0.891 : 55.0 secs : initdesign
#
# [mbo] 0: num_leaves=1527; max_depth=7; min_child_weight=1.53; min_data_in_leaf=5672; min_gain_to_split=0.0957; lambda_l1=321; lambda_l2=483; scale_pos_weight=2.49; learning_rate=0.0107; num_iterations=4514; early_stopping_rounds=282; feature_fraction=0.234; bagging_fraction=0.757; bagging_freq=1; max_delta_step=0.921; path_smooth=9 : y = 0.889 : 38.4 secs : initdesign
#
# [mbo] 0: num_leaves=4580; max_depth=29; min_child_weight=2.94; min_data_in_leaf=4854; min_gain_to_split=0.081; lambda_l1=249; lambda_l2=240; scale_pos_weight=4.6; learning_rate=0.0608; num_iterations=525; early_stopping_rounds=177; feature_fraction=0.706; bagging_fraction=0.993; bagging_freq=4; max_delta_step=3.45; path_smooth=0.0768 : y = 0.904 : 25.2 secs : initdesign
#
# [mbo] 0: num_leaves=2741; max_depth=4; min_child_weight=5.49; min_data_in_leaf=4332; min_gain_to_split=0.0885; lambda_l1=887; lambda_l2=741; scale_pos_weight=2.13; learning_rate=0.0374; num_iterations=3007; early_stopping_rounds=123; feature_fraction=0.794; bagging_fraction=0.589; bagging_freq=4; max_delta_step=8.15; path_smooth=5.31 : y = 0.876 : 11.4 secs : initdesign
#
# [mbo] 0: num_leaves=5822; max_depth=17; min_child_weight=5.21; min_data_in_leaf=511; min_gain_to_split=0.0177; lambda_l1=580; lambda_l2=816; scale_pos_weight=4.25; learning_rate=0.0166; num_iterations=2209; early_stopping_rounds=61; feature_fraction=0.894; bagging_fraction=0.777; bagging_freq=3; max_delta_step=6.95; path_smooth=6.95 : y = 0.888 : 8.3 secs : initdesign
#
# [mbo] 0: num_leaves=5941; max_depth=24; min_child_weight=0.646; min_data_in_leaf=2978; min_gain_to_split=0.0782; lambda_l1=845; lambda_l2=332; scale_pos_weight=3.47; learning_rate=0.00641; num_iterations=4594; early_stopping_rounds=237; feature_fraction=0.916; bagging_fraction=0.557; bagging_freq=4; max_delta_step=2.86; path_smooth=7.64 : y = 0.887 : 49.6 secs : initdesign
#
# [mbo] 0: num_leaves=5402; max_depth=11; min_child_weight=5.79; min_data_in_leaf=7858; min_gain_to_split=0.0172; lambda_l1=608; lambda_l2=761; scale_pos_weight=3.28; learning_rate=0.0092; num_iterations=1642; early_stopping_rounds=346; feature_fraction=0.054; bagging_fraction=0.952; bagging_freq=1; max_delta_step=8.52; path_smooth=3.15 : y = 0.891 : 35.2 secs : initdesign
#
# [mbo] 0: num_leaves=6576; max_depth=14; min_child_weight=4.81; min_data_in_leaf=6172; min_gain_to_split=0.0513; lambda_l1=31.6; lambda_l2=536; scale_pos_weight=1.2; learning_rate=0.083; num_iterations=4737; early_stopping_rounds=299; feature_fraction=0.287; bagging_fraction=0.733; bagging_freq=0; max_delta_step=2.73; path_smooth=0.451 : y = 0.912 : 123.8 secs : initdesign
#
# [mbo] 0: num_leaves=610; max_depth=16; min_child_weight=8.02; min_data_in_leaf=1789; min_gain_to_split=0.0547; lambda_l1=687; lambda_l2=884; scale_pos_weight=4.43; learning_rate=0.0382; num_iterations=833; early_stopping_rounds=429; feature_fraction=0.787; bagging_fraction=0.959; bagging_freq=2; max_delta_step=4.75; path_smooth=8.74 : y = 0.893 : 43.6 secs : initdesign
#
# [mbo] 0: num_leaves=768; max_depth=22; min_child_weight=7.58; min_data_in_leaf=8186; min_gain_to_split=0.0269; lambda_l1=933; lambda_l2=853; scale_pos_weight=3.35; learning_rate=0.0205; num_iterations=4401; early_stopping_rounds=140; feature_fraction=0.75; bagging_fraction=0.584; bagging_freq=0; max_delta_step=6.2; path_smooth=3.95 : y = 0.882 : 27.8 secs : initdesign
#
# [mbo] 0: num_leaves=3787; max_depth=10; min_child_weight=9.22; min_data_in_leaf=2920; min_gain_to_split=0.0122; lambda_l1=366; lambda_l2=144; scale_pos_weight=1.8; learning_rate=0.0182; num_iterations=589; early_stopping_rounds=144; feature_fraction=0.545; bagging_fraction=0.944; bagging_freq=5; max_delta_step=3.04; path_smooth=2.53 : y = 0.886 : 84.0 secs : initdesign
#
# [mbo] 0: num_leaves=2384; max_depth=20; min_child_weight=7.46; min_data_in_leaf=7799; min_gain_to_split=0.0309; lambda_l1=452; lambda_l2=62.8; scale_pos_weight=2.98; learning_rate=0.0248; num_iterations=1717; early_stopping_rounds=289; feature_fraction=0.776; bagging_fraction=0.505; bagging_freq=4; max_delta_step=6.86; path_smooth=9.22 : y = 0.887 : 50.1 secs : initdesign
#
# [mbo] 0: num_leaves=4356; max_depth=7; min_child_weight=0.127; min_data_in_leaf=173; min_gain_to_split=0.0987; lambda_l1=970; lambda_l2=310; scale_pos_weight=3.82; learning_rate=0.0516; num_iterations=2717; early_stopping_rounds=219; feature_fraction=0.362; bagging_fraction=0.914; bagging_freq=3; max_delta_step=9.04; path_smooth=0.882 : y = 0.898 : 35.1 secs : initdesign
#
# [mbo] 0: num_leaves=838; max_depth=11; min_child_weight=1.91; min_data_in_leaf=7286; min_gain_to_split=0.0566; lambda_l1=396; lambda_l2=166; scale_pos_weight=1.97; learning_rate=0.0925; num_iterations=4626; early_stopping_rounds=103; feature_fraction=0.927; bagging_fraction=0.517; bagging_freq=1; max_delta_step=8.66; path_smooth=1.71 : y = 0.869 : 17.4 secs : initdesign
#
# [mbo] 0: num_leaves=1797; max_depth=4; min_child_weight=5.95; min_data_in_leaf=1245; min_gain_to_split=0.0771; lambda_l1=472; lambda_l2=901; scale_pos_weight=1.86; learning_rate=0.097; num_iterations=4099; early_stopping_rounds=490; feature_fraction=0.423; bagging_fraction=0.735; bagging_freq=1; max_delta_step=9.81; path_smooth=5.68 : y = 0.892 : 60.2 secs : initdesign
#
# [mbo] 0: num_leaves=6269; max_depth=29; min_child_weight=2.56; min_data_in_leaf=3798; min_gain_to_split=0.0892; lambda_l1=642; lambda_l2=841; scale_pos_weight=2.36; learning_rate=0.0278; num_iterations=644; early_stopping_rounds=433; feature_fraction=0.875; bagging_fraction=0.81; bagging_freq=0; max_delta_step=0.00611; path_smooth=0.7 : y = 0.856 : 49.8 secs : initdesign
#
# [mbo] 0: num_leaves=942; max_depth=22; min_child_weight=3.96; min_data_in_leaf=2034; min_gain_to_split=0.00822; lambda_l1=49.1; lambda_l2=662; scale_pos_weight=2.78; learning_rate=0.0844; num_iterations=2103; early_stopping_rounds=317; feature_fraction=0.145; bagging_fraction=0.962; bagging_freq=3; max_delta_step=9.63; path_smooth=4.43 : y = 0.916 : 172.4 secs : initdesign
#
# [mbo] 0: num_leaves=6826; max_depth=11; min_child_weight=6.97; min_data_in_leaf=2570; min_gain_to_split=0.0422; lambda_l1=169; lambda_l2=696; scale_pos_weight=4.67; learning_rate=0.0855; num_iterations=136; early_stopping_rounds=242; feature_fraction=0.835; bagging_fraction=0.682; bagging_freq=1; max_delta_step=0.463; path_smooth=1.05 : y = 0.901 : 12.2 secs : initdesign
#
# [mbo] 0: num_leaves=3266; max_depth=23; min_child_weight=9.97; min_data_in_leaf=3479; min_gain_to_split=0.0346; lambda_l1=524; lambda_l2=982; scale_pos_weight=1.44; learning_rate=0.0775; num_iterations=3703; early_stopping_rounds=458; feature_fraction=0.969; bagging_fraction=0.853; bagging_freq=5; max_delta_step=3.92; path_smooth=3.78 : y = 0.865 : 29.0 secs : initdesign
#
# [mbo] 0: num_leaves=4159; max_depth=8; min_child_weight=4.19; min_data_in_leaf=4898; min_gain_to_split=0.00693; lambda_l1=872; lambda_l2=918; scale_pos_weight=3.75; learning_rate=0.0871; num_iterations=758; early_stopping_rounds=52; feature_fraction=0.0851; bagging_fraction=0.773; bagging_freq=5; max_delta_step=5.94; path_smooth=5.03 : y = 0.895 : 9.1 secs : initdesign
#
# [mbo] 0: num_leaves=53; max_depth=28; min_child_weight=4.97; min_data_in_leaf=2779; min_gain_to_split=0.0826; lambda_l1=356; lambda_l2=609; scale_pos_weight=2.27; learning_rate=0.0667; num_iterations=4021; early_stopping_rounds=360; feature_fraction=0.985; bagging_fraction=0.609; bagging_freq=0; max_delta_step=0.593; path_smooth=8.52 : y = 0.888 : 29.2 secs : initdesign
#
# [mbo] 0: num_leaves=2661; max_depth=23; min_child_weight=1.83; min_data_in_leaf=6068; min_gain_to_split=0.0981; lambda_l1=101; lambda_l2=327; scale_pos_weight=4.88; learning_rate=0.0817; num_iterations=4166; early_stopping_rounds=415; feature_fraction=0.458; bagging_fraction=0.781; bagging_freq=4; max_delta_step=8.43; path_smooth=5.79 : y = 0.913 : 118.8 secs : initdesign
#
# [mbo] 0: num_leaves=8092; max_depth=3; min_child_weight=2.73; min_data_in_leaf=5471; min_gain_to_split=0.00578; lambda_l1=229; lambda_l2=35.5; scale_pos_weight=4.34; learning_rate=0.0494; num_iterations=3417; early_stopping_rounds=199; feature_fraction=0.331; bagging_fraction=0.524; bagging_freq=1; max_delta_step=7.76; path_smooth=9.6 : y = 0.907 : 346.8 secs : initdesign
#
# [mbo] 0: num_leaves=3552; max_depth=9; min_child_weight=0.933; min_data_in_leaf=4130; min_gain_to_split=0.0142; lambda_l1=137; lambda_l2=108; scale_pos_weight=1.66; learning_rate=0.0955; num_iterations=321; early_stopping_rounds=405; feature_fraction=0.515; bagging_fraction=0.839; bagging_freq=0; max_delta_step=4.18; path_smooth=6.72 : y = 0.901 : 43.9 secs : initdesign
#
# [mbo] 0: num_leaves=1713; max_depth=30; min_child_weight=9.75; min_data_in_leaf=5241; min_gain_to_split=0.0915; lambda_l1=203; lambda_l2=639; scale_pos_weight=3.81; learning_rate=0.04; num_iterations=1002; early_stopping_rounds=85; feature_fraction=0.858; bagging_fraction=0.844; bagging_freq=0; max_delta_step=9.13; path_smooth=5.41 : y = 0.906 : 40.4 secs : initdesign
#
# [mbo] 0: num_leaves=2905; max_depth=26; min_child_weight=8.88; min_data_in_leaf=1919; min_gain_to_split=0.0869; lambda_l1=750; lambda_l2=256; scale_pos_weight=1.26; learning_rate=0.0567; num_iterations=1346; early_stopping_rounds=451; feature_fraction=0.509; bagging_fraction=0.622; bagging_freq=1; max_delta_step=7.97; path_smooth=0.266 : y = 0.769 : 56.7 secs : initdesign
#
# [mbo] 0: num_leaves=5652; max_depth=18; min_child_weight=9.44; min_data_in_leaf=6841; min_gain_to_split=0.000129; lambda_l1=759; lambda_l2=229; scale_pos_weight=4.27; learning_rate=0.0299; num_iterations=4850; early_stopping_rounds=466; feature_fraction=0.665; bagging_fraction=0.931; bagging_freq=3; max_delta_step=2.29; path_smooth=1.46 : y = 0.892 : 43.3 secs : initdesign
#
# [mbo] 0: num_leaves=6323; max_depth=8; min_child_weight=7.69; min_data_in_leaf=6335; min_gain_to_split=0.0324; lambda_l1=945; lambda_l2=717; scale_pos_weight=1.61; learning_rate=0.0352; num_iterations=2812; early_stopping_rounds=247; feature_fraction=0.183; bagging_fraction=0.694; bagging_freq=1; max_delta_step=0.94; path_smooth=8.3 : y = 0.877 : 30.2 secs : initdesign
#
# [mbo] 0: num_leaves=3896; max_depth=26; min_child_weight=0.481; min_data_in_leaf=4549; min_gain_to_split=0.0238; lambda_l1=488; lambda_l2=409; scale_pos_weight=4.49; learning_rate=0.0457; num_iterations=373; early_stopping_rounds=495; feature_fraction=0.22; bagging_fraction=0.627; bagging_freq=5; max_delta_step=1.22; path_smooth=4.7 : y = 0.896 : 35.5 secs : initdesign
#
# [mbo] 0: num_leaves=1104; max_depth=21; min_child_weight=1.16; min_data_in_leaf=7978; min_gain_to_split=0.00245; lambda_l1=87.6; lambda_l2=199; scale_pos_weight=4.76; learning_rate=0.0727; num_iterations=1870; early_stopping_rounds=164; feature_fraction=0.979; bagging_fraction=0.917; bagging_freq=1; max_delta_step=9.91; path_smooth=2.15 : y = 0.913 : 71.9 secs : initdesign
#
# [mbo] 0: num_leaves=6525; max_depth=5; min_child_weight=4.5; min_data_in_leaf=1017; min_gain_to_split=0.0839; lambda_l1=812; lambda_l2=946; scale_pos_weight=4.52; learning_rate=0.0129; num_iterations=4334; early_stopping_rounds=441; feature_fraction=0.631; bagging_fraction=0.547; bagging_freq=1; max_delta_step=7.26; path_smooth=6.56 : y = 0.896 : 63.7 secs : initdesign
#
# [mbo] 0: num_leaves=7650; max_depth=6; min_child_weight=1.07; min_data_in_leaf=1496; min_gain_to_split=0.0952; lambda_l1=251; lambda_l2=547; scale_pos_weight=2.07; learning_rate=0.0957; num_iterations=3101; early_stopping_rounds=329; feature_fraction=0.951; bagging_fraction=0.803; bagging_freq=4; max_delta_step=2.53; path_smooth=8.83 : y = 0.892 : 21.9 secs : initdesign
#
# [mbo] 0: num_leaves=7706; max_depth=25; min_child_weight=0.227; min_data_in_leaf=285; min_gain_to_split=0.0709; lambda_l1=716; lambda_l2=80.3; scale_pos_weight=4.99; learning_rate=0.065; num_iterations=4996; early_stopping_rounds=69; feature_fraction=0.306; bagging_fraction=0.615; bagging_freq=0; max_delta_step=1.97; path_smooth=2.23 : y = 0.901 : 17.1 secs : initdesign
#
# [mbo] 0: num_leaves=7026; max_depth=30; min_child_weight=4.24; min_data_in_leaf=7561; min_gain_to_split=0.0497; lambda_l1=985; lambda_l2=204; scale_pos_weight=1.91; learning_rate=0.0117; num_iterations=2470; early_stopping_rounds=83; feature_fraction=0.618; bagging_fraction=0.972; bagging_freq=5; max_delta_step=7.38; path_smooth=4.69 : y = 0.876 : 9.1 secs : initdesign
#
# [mbo] 0: num_leaves=7112; max_depth=27; min_child_weight=8.42; min_data_in_leaf=4022; min_gain_to_split=0.00394; lambda_l1=619; lambda_l2=646; scale_pos_weight=2.69; learning_rate=0.0778; num_iterations=1620; early_stopping_rounds=475; feature_fraction=0.678; bagging_fraction=0.906; bagging_freq=0; max_delta_step=9.25; path_smooth=9.45 : y = 0.889 : 27.1 secs : initdesign
#
# [mbo] 0: num_leaves=1276; max_depth=9; min_child_weight=1.71; min_data_in_leaf=7463; min_gain_to_split=0.0189; lambda_l1=721; lambda_l2=686; scale_pos_weight=1.18; learning_rate=0.0316; num_iterations=1112; early_stopping_rounds=353; feature_fraction=0.343; bagging_fraction=0.51; bagging_freq=3; max_delta_step=9.46; path_smooth=1.98 : y = 0.5 : 34.4 secs : initdesign
#
# [mbo] 0: num_leaves=237; max_depth=6; min_child_weight=5.65; min_data_in_leaf=6625; min_gain_to_split=0.0739; lambda_l1=208; lambda_l2=112; scale_pos_weight=4.82; learning_rate=0.0798; num_iterations=1809; early_stopping_rounds=110; feature_fraction=0.251; bagging_fraction=0.794; bagging_freq=2; max_delta_step=0.662; path_smooth=4.94 : y = 0.908 : 37.4 secs : initdesign
#
# [mbo] 0: num_leaves=7889; max_depth=27; min_child_weight=6.84; min_data_in_leaf=604; min_gain_to_split=0.0586; lambda_l1=183; lambda_l2=954; scale_pos_weight=1.08; learning_rate=0.0262; num_iterations=3972; early_stopping_rounds=94; feature_fraction=0.4; bagging_fraction=0.552; bagging_freq=3; max_delta_step=4.89; path_smooth=2.77 : y = 0.882 : 14.4 secs : initdesign
#
# Saved the current state after iteration 1 in the file HT.RDATA.
#
# Wed Nov 19 03:26:56 AM 2025 AUC 0.912163989453545
#
# [mbo] 1: num_leaves=6479; max_depth=16; min_child_weight=2.11; min_data_in_leaf=5423; min_gain_to_split=0.0124; lambda_l1=35.2; lambda_l2=180; scale_pos_weight=1.57; learning_rate=0.0921; num_iterations=4868; early_stopping_rounds=201; feature_fraction=0.677; bagging_fraction=0.849; bagging_freq=0; max_delta_step=3.87; path_smooth=1.05 : y = 0.912 : 46.5 secs : infill_ei
#
# Wed Nov 19 03:30:26 AM 2025 AUC 0.91077958271847
#
# [mbo] 2: num_leaves=8138; max_depth=25; min_child_weight=9.08; min_data_in_leaf=3810; min_gain_to_split=0.0705; lambda_l1=71; lambda_l2=722; scale_pos_weight=1.52; learning_rate=0.0582; num_iterations=4208; early_stopping_rounds=80; feature_fraction=0.165; bagging_fraction=0.88; bagging_freq=1; max_delta_step=3.14; path_smooth=3.23 : y = 0.911 : 208.9 secs : infill_ei
#
# Wed Nov 19 03:31:25 AM 2025 AUC 0.906706890292309
#
# [mbo] 3: num_leaves=7106; max_depth=17; min_child_weight=6.52; min_data_in_leaf=2687; min_gain_to_split=0.0991; lambda_l1=75.8; lambda_l2=289; scale_pos_weight=1.37; learning_rate=0.036; num_iterations=4987; early_stopping_rounds=379; feature_fraction=0.749; bagging_fraction=0.939; bagging_freq=0; max_delta_step=4.48; path_smooth=4.03 : y = 0.907 : 57.6 secs : infill_ei
#
# Wed Nov 19 03:38:27 AM 2025 AUC 0.907623732610194
#
# [mbo] 4: num_leaves=4069; max_depth=25; min_child_weight=7.23; min_data_in_leaf=5320; min_gain_to_split=0.0761; lambda_l1=103; lambda_l2=5.38; scale_pos_weight=1.68; learning_rate=0.0846; num_iterations=3834; early_stopping_rounds=374; feature_fraction=0.372; bagging_fraction=0.946; bagging_freq=1; max_delta_step=0.327; path_smooth=2.44 : y = 0.908 : 420.0 secs : infill_ei
#
# Saved the current state after iteration 5 in the file HT.RDATA.
#
# Wed Nov 19 03:39:41 AM 2025 AUC 0.90632371227693
#
# [mbo] 5: num_leaves=4264; max_depth=18; min_child_weight=1.38; min_data_in_leaf=6046; min_gain_to_split=0.0526; lambda_l1=230; lambda_l2=124; scale_pos_weight=4.74; learning_rate=0.0394; num_iterations=3862; early_stopping_rounds=202; feature_fraction=0.562; bagging_fraction=0.75; bagging_freq=0; max_delta_step=2.83; path_smooth=6.58 : y = 0.906 : 71.7 secs : infill_ei
#
# Wed Nov 19 03:40:03 AM 2025 AUC 0.886796396918739
#
# [mbo] 6: num_leaves=6277; max_depth=26; min_child_weight=2.7; min_data_in_leaf=1005; min_gain_to_split=0.0765; lambda_l1=467; lambda_l2=147; scale_pos_weight=1.61; learning_rate=0.0913; num_iterations=4059; early_stopping_rounds=187; feature_fraction=0.234; bagging_fraction=0.808; bagging_freq=1; max_delta_step=2.98; path_smooth=8.69 : y = 0.887 : 20.0 secs : infill_ei
#
# Wed Nov 19 03:41:51 AM 2025 AUC 0.919348073943291
#
# [mbo] 7: num_leaves=4143; max_depth=8; min_child_weight=5.13; min_data_in_leaf=1409; min_gain_to_split=0.074; lambda_l1=6.15; lambda_l2=576; scale_pos_weight=2.96; learning_rate=0.08; num_iterations=796; early_stopping_rounds=93; feature_fraction=0.668; bagging_fraction=0.917; bagging_freq=3; max_delta_step=7.09; path_smooth=5.49 : y = 0.919 : 106.9 secs : infill_ei
#
# Wed Nov 19 03:44:05 AM 2025 AUC 0.911793897202264
#
# [mbo] 8: num_leaves=6789; max_depth=12; min_child_weight=5.2; min_data_in_leaf=5386; min_gain_to_split=0.0759; lambda_l1=17; lambda_l2=308; scale_pos_weight=1.39; learning_rate=0.082; num_iterations=4582; early_stopping_rounds=191; feature_fraction=0.408; bagging_fraction=0.979; bagging_freq=0; max_delta_step=5.81; path_smooth=3.51 : y = 0.912 : 132.1 secs : infill_ei
#
# Wed Nov 19 03:46:16 AM 2025 AUC 0.921238128024405
#
# [mbo] 9: num_leaves=201; max_depth=13; min_child_weight=7.83; min_data_in_leaf=1279; min_gain_to_split=0.0786; lambda_l1=5.86; lambda_l2=671; scale_pos_weight=3.06; learning_rate=0.0873; num_iterations=958; early_stopping_rounds=405; feature_fraction=0.761; bagging_fraction=0.872; bagging_freq=2; max_delta_step=7.82; path_smooth=8.59 : y = 0.921 : 129.0 secs : infill_ei
#
# Wed Nov 19 03:50:24 AM 2025 AUC 0.920138252775356
#
# [mbo] 10: num_leaves=2113; max_depth=24; min_child_weight=6.74; min_data_in_leaf=2441; min_gain_to_split=0.0847; lambda_l1=2.14; lambda_l2=942; scale_pos_weight=3.04; learning_rate=0.0816; num_iterations=1293; early_stopping_rounds=212; feature_fraction=0.571; bagging_fraction=0.925; bagging_freq=3; max_delta_step=7.47; path_smooth=5.17 : y = 0.92 : 245.6 secs : infill_ei
#
# Saved the current state after iteration 11 in the file HT.RDATA.
#
# Wed Nov 19 03:55:31 AM 2025 AUC 0.91928365172004
#
# [mbo] 11: num_leaves=1651; max_depth=10; min_child_weight=8.75; min_data_in_leaf=1641; min_gain_to_split=0.0716; lambda_l1=8.54; lambda_l2=821; scale_pos_weight=2.88; learning_rate=0.0426; num_iterations=2024; early_stopping_rounds=314; feature_fraction=0.397; bagging_fraction=0.732; bagging_freq=1; max_delta_step=8.12; path_smooth=8.55 : y = 0.919 : 304.4 secs : infill_ei
#
# Wed Nov 19 04:00:23 AM 2025 AUC 0.923447608962473
#
# [mbo] 12: num_leaves=1449; max_depth=12; min_child_weight=4.16; min_data_in_leaf=1592; min_gain_to_split=0.0219; lambda_l1=1.41; lambda_l2=476; scale_pos_weight=3.15; learning_rate=0.0692; num_iterations=1792; early_stopping_rounds=212; feature_fraction=0.392; bagging_fraction=0.838; bagging_freq=1; max_delta_step=9.8; path_smooth=7.48 : y = 0.923 : 291.0 secs : infill_ei
#
# Wed Nov 19 04:01:00 AM 2025 AUC 0.907078324673242
#
# [mbo] 13: num_leaves=602; max_depth=13; min_child_weight=4.83; min_data_in_leaf=3005; min_gain_to_split=0.0368; lambda_l1=132; lambda_l2=646; scale_pos_weight=2.95; learning_rate=0.0632; num_iterations=427; early_stopping_rounds=123; feature_fraction=0.636; bagging_fraction=0.989; bagging_freq=1; max_delta_step=5.17; path_smooth=8.23 : y = 0.907 : 35.2 secs : infill_ei
#
# Saved the current state after iteration 14 in the file HT.RDATA.
#
# Wed Nov 19 04:01:45 AM 2025 AUC 0.911347974625697
#
# [mbo] 14: num_leaves=3206; max_depth=9; min_child_weight=7.44; min_data_in_leaf=2130; min_gain_to_split=0.0236; lambda_l1=15.9; lambda_l2=690; scale_pos_weight=3.09; learning_rate=0.0255; num_iterations=400; early_stopping_rounds=450; feature_fraction=0.164; bagging_fraction=0.79; bagging_freq=5; max_delta_step=8.76; path_smooth=6.71 : y = 0.911 : 41.9 secs : infill_ei
#
# Wed Nov 19 04:06:28 AM 2025 AUC 0.925128290818021
#
# [mbo] 15: num_leaves=2620; max_depth=19; min_child_weight=3.07; min_data_in_leaf=364; min_gain_to_split=0.0641; lambda_l1=5.4; lambda_l2=479; scale_pos_weight=3.02; learning_rate=0.0708; num_iterations=1908; early_stopping_rounds=419; feature_fraction=0.602; bagging_fraction=0.965; bagging_freq=1; max_delta_step=9.58; path_smooth=7.13 : y = 0.925 : 281.6 secs : infill_ei
#
# Wed Nov 19 04:10:36 AM 2025 AUC 0.916531950402941
#
# [mbo] 16: num_leaves=4682; max_depth=26; min_child_weight=8.89; min_data_in_leaf=3737; min_gain_to_split=0.0948; lambda_l1=8.6; lambda_l2=992; scale_pos_weight=1.74; learning_rate=0.0992; num_iterations=3070; early_stopping_rounds=166; feature_fraction=0.523; bagging_fraction=0.825; bagging_freq=5; max_delta_step=3.17; path_smooth=2.24 : y = 0.917 : 246.3 secs : infill_ei
#
# Wed Nov 19 04:14:39 AM 2025 AUC 0.921671300369287
#
# [mbo] 17: num_leaves=2732; max_depth=15; min_child_weight=6.66; min_data_in_leaf=594; min_gain_to_split=0.0701; lambda_l1=20.9; lambda_l2=731; scale_pos_weight=3.09; learning_rate=0.0748; num_iterations=2011; early_stopping_rounds=353; feature_fraction=0.225; bagging_fraction=0.816; bagging_freq=3; max_delta_step=0.87; path_smooth=9.57 : y = 0.922 : 241.5 secs : infill_ei
#
# Saved the current state after iteration 18 in the file HT.RDATA.
#
# Wed Nov 19 04:15:31 AM 2025 AUC 0.920748250701766
#
# [mbo] 18: num_leaves=2873; max_depth=12; min_child_weight=9.76; min_data_in_leaf=505; min_gain_to_split=0.0908; lambda_l1=18.3; lambda_l2=153; scale_pos_weight=3.16; learning_rate=0.0688; num_iterations=387; early_stopping_rounds=251; feature_fraction=0.203; bagging_fraction=0.901; bagging_freq=1; max_delta_step=6.79; path_smooth=3.15 : y = 0.921 : 49.5 secs : infill_ei
#
# Wed Nov 19 04:18:27 AM 2025 AUC 0.920363730556735
#
# [mbo] 19: num_leaves=1758; max_depth=13; min_child_weight=5.44; min_data_in_leaf=135; min_gain_to_split=0.059; lambda_l1=20.8; lambda_l2=399; scale_pos_weight=3.02; learning_rate=0.096; num_iterations=1193; early_stopping_rounds=388; feature_fraction=0.342; bagging_fraction=0.67; bagging_freq=2; max_delta_step=5.24; path_smooth=1.94 : y = 0.92 : 173.7 secs : infill_ei
#
# Wed Nov 19 04:20:25 AM 2025 AUC 0.916335663941472
#
# [mbo] 20: num_leaves=3007; max_depth=5; min_child_weight=2.76; min_data_in_leaf=1914; min_gain_to_split=0.0899; lambda_l1=13.6; lambda_l2=294; scale_pos_weight=3.27; learning_rate=0.0772; num_iterations=1300; early_stopping_rounds=462; feature_fraction=0.8; bagging_fraction=0.661; bagging_freq=2; max_delta_step=7.73; path_smooth=7.68 : y = 0.916 : 115.3 secs : infill_ei
#
# Wed Nov 19 04:23:04 AM 2025 AUC 0.922716148302642
#
# [mbo] 21: num_leaves=3242; max_depth=25; min_child_weight=9.32; min_data_in_leaf=697; min_gain_to_split=0.0736; lambda_l1=0.968; lambda_l2=176; scale_pos_weight=3.1; learning_rate=0.06; num_iterations=3255; early_stopping_rounds=189; feature_fraction=0.702; bagging_fraction=0.783; bagging_freq=2; max_delta_step=5.15; path_smooth=7.09 : y = 0.923 : 156.8 secs : infill_ei
#
# Wed Nov 19 04:30:05 AM 2025 AUC 0.924179405154717
#
# [mbo] 22: num_leaves=1319; max_depth=5; min_child_weight=7; min_data_in_leaf=299; min_gain_to_split=0.0905; lambda_l1=2.25; lambda_l2=485; scale_pos_weight=3.16; learning_rate=0.0375; num_iterations=3353; early_stopping_rounds=261; feature_fraction=0.295; bagging_fraction=0.983; bagging_freq=3; max_delta_step=7.35; path_smooth=2.78 : y = 0.924 : 419.7 secs : infill_ei
#
# Saved the current state after iteration 23 in the file HT.RDATA.
#
# Wed Nov 19 04:34:44 AM 2025 AUC 0.926219106691926
#
# [mbo] 23: num_leaves=1499; max_depth=17; min_child_weight=3.38; min_data_in_leaf=897; min_gain_to_split=0.0867; lambda_l1=17.5; lambda_l2=220; scale_pos_weight=3.1; learning_rate=0.0572; num_iterations=2064; early_stopping_rounds=286; feature_fraction=0.42; bagging_fraction=0.9; bagging_freq=4; max_delta_step=5.14; path_smooth=4.22 : y = 0.926 : 276.3 secs : infill_ei
#
# Wed Nov 19 04:37:10 AM 2025 AUC 0.911680487246749
#
# [mbo] 24: num_leaves=2003; max_depth=17; min_child_weight=3.03; min_data_in_leaf=5657; min_gain_to_split=0.0796; lambda_l1=127; lambda_l2=296; scale_pos_weight=4.53; learning_rate=0.0577; num_iterations=2238; early_stopping_rounds=186; feature_fraction=0.498; bagging_fraction=0.779; bagging_freq=1; max_delta_step=7.46; path_smooth=2.61 : y = 0.912 : 144.7 secs : infill_ei
#
# Wed Nov 19 04:40:48 AM 2025 AUC 0.91531061242047
#
# [mbo] 25: num_leaves=7883; max_depth=27; min_child_weight=6.44; min_data_in_leaf=4197; min_gain_to_split=0.0768; lambda_l1=11.3; lambda_l2=779; scale_pos_weight=1.27; learning_rate=0.089; num_iterations=4869; early_stopping_rounds=293; feature_fraction=0.829; bagging_fraction=0.919; bagging_freq=1; max_delta_step=3.7; path_smooth=0.415 : y = 0.915 : 215.5 secs : infill_ei
#
# Saved the current state after iteration 26 in the file HT.RDATA.
#
# Wed Nov 19 04:43:52 AM 2025 AUC 0.922337332208629
#
# [mbo] 26: num_leaves=2267; max_depth=10; min_child_weight=0.431; min_data_in_leaf=2011; min_gain_to_split=0.0358; lambda_l1=14.9; lambda_l2=57.8; scale_pos_weight=4.92; learning_rate=0.0758; num_iterations=1035; early_stopping_rounds=295; feature_fraction=0.584; bagging_fraction=0.712; bagging_freq=2; max_delta_step=8.17; path_smooth=1.32 : y = 0.922 : 181.1 secs : infill_ei
#
# Wed Nov 19 04:52:22 AM 2025 AUC 0.921246851867137
#
# [mbo] 27: num_leaves=2157; max_depth=10; min_child_weight=7.68; min_data_in_leaf=3721; min_gain_to_split=0.0249; lambda_l1=10.4; lambda_l2=160; scale_pos_weight=4.85; learning_rate=0.0274; num_iterations=2723; early_stopping_rounds=227; feature_fraction=0.563; bagging_fraction=0.925; bagging_freq=3; max_delta_step=8.82; path_smooth=6.93 : y = 0.921 : 508.3 secs : infill_ei
#
# Saved the current state after iteration 28 in the file HT.RDATA.
#
# Wed Nov 19 04:53:06 AM 2025 AUC 0.911805305304298
#
# [mbo] 28: num_leaves=1241; max_depth=15; min_child_weight=5.1; min_data_in_leaf=876; min_gain_to_split=0.0725; lambda_l1=232; lambda_l2=187; scale_pos_weight=4.94; learning_rate=0.0306; num_iterations=2370; early_stopping_rounds=239; feature_fraction=0.988; bagging_fraction=0.717; bagging_freq=2; max_delta_step=9.65; path_smooth=2.14 : y = 0.912 : 41.7 secs : infill_ei
#
# Wed Nov 19 04:54:09 AM 2025 AUC 0.912220023366477
#
# [mbo] 29: num_leaves=1780; max_depth=19; min_child_weight=5.7; min_data_in_leaf=3477; min_gain_to_split=0.0687; lambda_l1=115; lambda_l2=231; scale_pos_weight=4.83; learning_rate=0.0772; num_iterations=3812; early_stopping_rounds=177; feature_fraction=0.591; bagging_fraction=0.572; bagging_freq=3; max_delta_step=6.42; path_smooth=0.947 : y = 0.912 : 61.0 secs : infill_ei
#
# Wed Nov 19 04:55:19 AM 2025 AUC 0.9088355079189
#
# [mbo] 30: num_leaves=5876; max_depth=13; min_child_weight=1.51; min_data_in_leaf=4908; min_gain_to_split=0.00664; lambda_l1=209; lambda_l2=83.6; scale_pos_weight=4.91; learning_rate=0.0738; num_iterations=2012; early_stopping_rounds=170; feature_fraction=0.447; bagging_fraction=0.635; bagging_freq=4; max_delta_step=9.05; path_smooth=6.85 : y = 0.909 : 68.2 secs : infill_ei
#
# Wed Nov 19 04:55:52 AM 2025 AUC 0.900586443551033
#
# [mbo] 31: num_leaves=2391; max_depth=24; min_child_weight=0.761; min_data_in_leaf=2783; min_gain_to_split=0.099; lambda_l1=151; lambda_l2=365; scale_pos_weight=1.83; learning_rate=0.0902; num_iterations=872; early_stopping_rounds=129; feature_fraction=0.723; bagging_fraction=0.995; bagging_freq=1; max_delta_step=2.58; path_smooth=4.43 : y = 0.901 : 30.7 secs : infill_ei
#
# Wed Nov 19 04:56:25 AM 2025 AUC 0.896663566347173
#
# [mbo] 32: num_leaves=6211; max_depth=19; min_child_weight=8.86; min_data_in_leaf=4631; min_gain_to_split=0.0972; lambda_l1=194; lambda_l2=990; scale_pos_weight=1.78; learning_rate=0.0699; num_iterations=326; early_stopping_rounds=156; feature_fraction=0.199; bagging_fraction=0.773; bagging_freq=0; max_delta_step=1.81; path_smooth=9.14 : y = 0.897 : 30.8 secs : infill_ei
#
# Wed Nov 19 04:56:48 AM 2025 AUC 0.910528604473721
#
# [mbo] 33: num_leaves=1611; max_depth=14; min_child_weight=3.69; min_data_in_leaf=4919; min_gain_to_split=0.0239; lambda_l1=6.64; lambda_l2=204; scale_pos_weight=4.83; learning_rate=0.0457; num_iterations=210; early_stopping_rounds=453; feature_fraction=0.952; bagging_fraction=0.726; bagging_freq=2; max_delta_step=7.15; path_smooth=4.93 : y = 0.911 : 21.3 secs : infill_ei
#
# Wed Nov 19 04:58:54 AM 2025 AUC 0.919806746751543
#
# [mbo] 34: num_leaves=8041; max_depth=23; min_child_weight=6.71; min_data_in_leaf=502; min_gain_to_split=0.0538; lambda_l1=9.47; lambda_l2=70.8; scale_pos_weight=1.27; learning_rate=0.0602; num_iterations=4583; early_stopping_rounds=134; feature_fraction=0.425; bagging_fraction=0.596; bagging_freq=0; max_delta_step=3.25; path_smooth=1.15 : y = 0.92 : 122.8 secs : infill_ei
#
# Wed Nov 19 05:06:33 AM 2025 AUC 0.924382066732028
#
# [mbo] 35: num_leaves=2499; max_depth=9; min_child_weight=5.09; min_data_in_leaf=1973; min_gain_to_split=0.089; lambda_l1=10.5; lambda_l2=550; scale_pos_weight=3.12; learning_rate=0.0722; num_iterations=3319; early_stopping_rounds=298; feature_fraction=0.532; bagging_fraction=0.915; bagging_freq=1; max_delta_step=3.84; path_smooth=2.94 : y = 0.924 : 456.0 secs : infill_ei
#
# Saved the current state after iteration 36 in the file HT.RDATA.
#
# Wed Nov 19 05:07:24 AM 2025 AUC 0.910249105973886
#
# [mbo] 36: num_leaves=1812; max_depth=13; min_child_weight=0.0959; min_data_in_leaf=2433; min_gain_to_split=0.0246; lambda_l1=126; lambda_l2=288; scale_pos_weight=4.83; learning_rate=0.0841; num_iterations=2431; early_stopping_rounds=80; feature_fraction=0.458; bagging_fraction=0.843; bagging_freq=1; max_delta_step=9.38; path_smooth=7.7 : y = 0.91 : 49.5 secs : infill_ei
#
# Wed Nov 19 05:08:43 AM 2025 AUC 0.911720415603868
#
# [mbo] 37: num_leaves=3189; max_depth=18; min_child_weight=4.79; min_data_in_leaf=35; min_gain_to_split=0.0641; lambda_l1=147; lambda_l2=506; scale_pos_weight=3.21; learning_rate=0.0887; num_iterations=2877; early_stopping_rounds=323; feature_fraction=0.385; bagging_fraction=0.897; bagging_freq=3; max_delta_step=8.39; path_smooth=5.62 : y = 0.912 : 75.4 secs : infill_ei
#
# Wed Nov 19 05:18:13 AM 2025 AUC 0.922708766589561
#
# [mbo] 38: num_leaves=7922; max_depth=16; min_child_weight=4.13; min_data_in_leaf=3136; min_gain_to_split=0.0681; lambda_l1=1.12; lambda_l2=679; scale_pos_weight=1.46; learning_rate=0.0934; num_iterations=4966; early_stopping_rounds=391; feature_fraction=0.312; bagging_fraction=0.872; bagging_freq=5; max_delta_step=0.552; path_smooth=0.0599 : y = 0.923 : 567.9 secs : infill_ei
#
# Saved the current state after iteration 39 in the file HT.RDATA.
#
# Wed Nov 19 05:22:39 AM 2025 AUC 0.922252778040611
#
# [mbo] 39: num_leaves=2054; max_depth=9; min_child_weight=7.66; min_data_in_leaf=2246; min_gain_to_split=0.0797; lambda_l1=1.94; lambda_l2=150; scale_pos_weight=3.06; learning_rate=0.0796; num_iterations=1896; early_stopping_rounds=413; feature_fraction=0.279; bagging_fraction=0.907; bagging_freq=2; max_delta_step=6.07; path_smooth=7.78 : y = 0.922 : 263.3 secs : infill_ei
#
# Wed Nov 19 05:26:43 AM 2025 AUC 0.922614481981574
#
# [mbo] 40: num_leaves=1759; max_depth=12; min_child_weight=4.58; min_data_in_leaf=425; min_gain_to_split=0.0968; lambda_l1=0.211; lambda_l2=424; scale_pos_weight=3.13; learning_rate=0.0335; num_iterations=1530; early_stopping_rounds=207; feature_fraction=0.894; bagging_fraction=0.867; bagging_freq=1; max_delta_step=7.02; path_smooth=3.76 : y = 0.923 : 242.0 secs : infill_ei
#
# Wed Nov 19 05:30:26 AM 2025 AUC 0.916681933391448
#
# [mbo] 41: num_leaves=2702; max_depth=14; min_child_weight=1.98; min_data_in_leaf=4484; min_gain_to_split=0.0603; lambda_l1=78.7; lambda_l2=40.5; scale_pos_weight=4.92; learning_rate=0.0306; num_iterations=2067; early_stopping_rounds=402; feature_fraction=0.229; bagging_fraction=0.886; bagging_freq=2; max_delta_step=5.19; path_smooth=2.77 : y = 0.917 : 220.1 secs : infill_ei
#
# Saved the current state after iteration 42 in the file HT.RDATA.
#
# Wed Nov 19 05:37:54 AM 2025 AUC 0.921459914949244
#
# [mbo] 42: num_leaves=5117; max_depth=23; min_child_weight=9.2; min_data_in_leaf=585; min_gain_to_split=0.0351; lambda_l1=6.81; lambda_l2=872; scale_pos_weight=1.59; learning_rate=0.0695; num_iterations=4126; early_stopping_rounds=476; feature_fraction=0.899; bagging_fraction=0.648; bagging_freq=4; max_delta_step=5.86; path_smooth=0.87 : y = 0.921 : 444.9 secs : infill_ei
#
# Wed Nov 19 05:46:35 AM 2025 AUC 0.923671744614201
#
# [mbo] 43: num_leaves=7715; max_depth=20; min_child_weight=6.58; min_data_in_leaf=377; min_gain_to_split=0.0556; lambda_l1=0.995; lambda_l2=884; scale_pos_weight=1.4; learning_rate=0.0936; num_iterations=4975; early_stopping_rounds=409; feature_fraction=0.346; bagging_fraction=0.552; bagging_freq=0; max_delta_step=3.82; path_smooth=1.97 : y = 0.924 : 519.2 secs : infill_ei
#
# Saved the current state after iteration 44 in the file HT.RDATA.
#
# Wed Nov 19 05:47:53 AM 2025 AUC 0.913520882530773
#
# [mbo] 44: num_leaves=1744; max_depth=7; min_child_weight=3.73; min_data_in_leaf=3431; min_gain_to_split=0.0878; lambda_l1=7.2; lambda_l2=463; scale_pos_weight=3.52; learning_rate=0.0456; num_iterations=820; early_stopping_rounds=146; feature_fraction=0.126; bagging_fraction=0.584; bagging_freq=1; max_delta_step=6.36; path_smooth=2.8 : y = 0.914 : 75.3 secs : infill_ei
#
# Wed Nov 19 05:53:28 AM 2025 AUC 0.917807309103867
#
# [mbo] 45: num_leaves=7930; max_depth=4; min_child_weight=9.65; min_data_in_leaf=3551; min_gain_to_split=0.0653; lambda_l1=3.83; lambda_l2=621; scale_pos_weight=1.64; learning_rate=0.0455; num_iterations=4887; early_stopping_rounds=405; feature_fraction=0.784; bagging_fraction=0.895; bagging_freq=5; max_delta_step=4.01; path_smooth=2.41 : y = 0.918 : 332.5 secs : infill_ei
#
# Wed Nov 19 05:54:06 AM 2025 AUC 0.907326954191102
#
# [mbo] 46: num_leaves=3464; max_depth=6; min_child_weight=1.97; min_data_in_leaf=2536; min_gain_to_split=0.0492; lambda_l1=88.3; lambda_l2=3.86; scale_pos_weight=4.83; learning_rate=0.0969; num_iterations=2800; early_stopping_rounds=386; feature_fraction=0.972; bagging_fraction=0.97; bagging_freq=3; max_delta_step=7.93; path_smooth=1.4 : y = 0.907 : 34.5 secs : infill_ei
#
# Wed Nov 19 05:56:16 AM 2025 AUC 0.915706540667535
#
# ...
#
# Wed Nov 19 08:51:27 AM 2025 AUC 0.920010750458505
#
# [mbo] 86: num_leaves=364; max_depth=15; min_child_weight=0.354; min_data_in_leaf=956; min_gain_to_split=0.0638; lambda_l1=28.3; lambda_l2=30.5; scale_pos_weight=3.67; learning_rate=0.0587; num_iterations=4140; early_stopping_rounds=146; feature_fraction=0.456; bagging_fraction=0.902; bagging_freq=0; max_delta_step=5.68; path_smooth=5.46 : y = 0.92 : 82.2 secs : infill_ei
#
# Wed Nov 19 08:54:52 AM 2025 AUC 0.930376353286104
#
# [mbo] 87: num_leaves=1757; max_depth=22; min_child_weight=2.49; min_data_in_leaf=1578; min_gain_to_split=0.0204; lambda_l1=2.72; lambda_l2=81.5; scale_pos_weight=3.61; learning_rate=0.0392; num_iterations=4552; early_stopping_rounds=384; feature_fraction=0.0753; bagging_fraction=0.921; bagging_freq=1; max_delta_step=0.53; path_smooth=5.5 : y = 0.93 : 202.5 secs : infill_ei
#
# Wed Nov 19 08:58:14 AM 2025 AUC 0.924669618009769
#
# [mbo] 88: num_leaves=2692; max_depth=18; min_child_weight=0.683; min_data_in_leaf=2788; min_gain_to_split=0.0133; lambda_l1=2.09; lambda_l2=21.9; scale_pos_weight=3.85; learning_rate=0.0519; num_iterations=1087; early_stopping_rounds=276; feature_fraction=0.486; bagging_fraction=0.766; bagging_freq=1; max_delta_step=4.33; path_smooth=3.57 : y = 0.925 : 199.1 secs : infill_ei
#
# Wed Nov 19 09:09:25 AM 2025 AUC 0.924315295781888
#
# [mbo] 89: num_leaves=1816; max_depth=15; min_child_weight=1.94; min_data_in_leaf=1593; min_gain_to_split=0.0358; lambda_l1=0.434; lambda_l2=696; scale_pos_weight=4.05; learning_rate=0.0336; num_iterations=4669; early_stopping_rounds=378; feature_fraction=0.378; bagging_fraction=0.856; bagging_freq=1; max_delta_step=1.16; path_smooth=7.01 : y = 0.924 : 667.7 secs : infill_ei
#
# Saved the current state after iteration 90 in the file HT.RDATA.
#
# Wed Nov 19 09:12:22 AM 2025 AUC 0.928307460428985
#
# [mbo] 90: num_leaves=1310; max_depth=20; min_child_weight=3.24; min_data_in_leaf=112; min_gain_to_split=0.00748; lambda_l1=5.79; lambda_l2=82.2; scale_pos_weight=3.94; learning_rate=0.0424; num_iterations=2340; early_stopping_rounds=104; feature_fraction=0.0971; bagging_fraction=0.762; bagging_freq=2; max_delta_step=2.2; path_smooth=3.6 : y = 0.928 : 173.7 secs : infill_ei
#
# Wed Nov 19 09:20:16 AM 2025 AUC 0.923671409081789
#
# [mbo] 91: num_leaves=3053; max_depth=10; min_child_weight=2.21; min_data_in_leaf=1135; min_gain_to_split=0.01; lambda_l1=2.45; lambda_l2=149; scale_pos_weight=3.73; learning_rate=0.0427; num_iterations=3654; early_stopping_rounds=448; feature_fraction=0.737; bagging_fraction=0.83; bagging_freq=1; max_delta_step=1.64; path_smooth=4.59 : y = 0.924 : 469.8 secs : infill_ei
#
# Saved the current state after iteration 92 in the file HT.RDATA.
#
# Wed Nov 19 09:25:03 AM 2025 AUC 0.924693440811076
#
# [mbo] 92: num_leaves=761; max_depth=13; min_child_weight=0.705; min_data_in_leaf=3306; min_gain_to_split=0.0024; lambda_l1=1.84; lambda_l2=73.8; scale_pos_weight=4.32; learning_rate=0.0242; num_iterations=3623; early_stopping_rounds=174; feature_fraction=0.306; bagging_fraction=0.912; bagging_freq=2; max_delta_step=3.36; path_smooth=3.33 : y = 0.925 : 282.5 secs : infill_ei
#
# Wed Nov 19 09:27:03 AM 2025 AUC 0.930244489047886
#
# [mbo] 93: num_leaves=1946; max_depth=15; min_child_weight=6.57; min_data_in_leaf=1438; min_gain_to_split=0.0551; lambda_l1=3.05; lambda_l2=5.14; scale_pos_weight=4.14; learning_rate=0.0428; num_iterations=3424; early_stopping_rounds=185; feature_fraction=0.2; bagging_fraction=0.902; bagging_freq=3; max_delta_step=1.48; path_smooth=4.91 : y = 0.93 : 116.7 secs : infill_ei
#
# Wed Nov 19 09:31:13 AM 2025 AUC 0.927891400237154
#
# [mbo] 94: num_leaves=4126; max_depth=10; min_child_weight=0.544; min_data_in_leaf=74; min_gain_to_split=0.0547; lambda_l1=0.478; lambda_l2=21.8; scale_pos_weight=4.21; learning_rate=0.0647; num_iterations=3371; early_stopping_rounds=278; feature_fraction=0.493; bagging_fraction=0.559; bagging_freq=1; max_delta_step=6.44; path_smooth=6.23 : y = 0.928 : 245.4 secs : infill_ei
#
# Saved the current state after iteration 95 in the file HT.RDATA.
#
# Wed Nov 19 09:36:53 AM 2025 AUC 0.922662463116599
#
# [mbo] 95: num_leaves=1484; max_depth=18; min_child_weight=0.686; min_data_in_leaf=1022; min_gain_to_split=0.0154; lambda_l1=0.229; lambda_l2=155; scale_pos_weight=4.12; learning_rate=0.0761; num_iterations=2562; early_stopping_rounds=255; feature_fraction=0.893; bagging_fraction=0.844; bagging_freq=0; max_delta_step=1.28; path_smooth=5.52 : y = 0.923 : 335.3 secs : infill_ei
#
# Wed Nov 19 09:39:54 AM 2025 AUC 0.933704163755923
#
# [mbo] 96: num_leaves=1652; max_depth=29; min_child_weight=3.08; min_data_in_leaf=201; min_gain_to_split=0.0308; lambda_l1=0.00297; lambda_l2=47; scale_pos_weight=3.82; learning_rate=0.0569; num_iterations=4441; early_stopping_rounds=338; feature_fraction=0.265; bagging_fraction=0.536; bagging_freq=0; max_delta_step=0.526; path_smooth=3.58 : y = 0.934 : 177.7 secs : infill_ei
#
# Wed Nov 19 09:47:15 AM 2025 AUC 0.925976181225083
#
# [mbo] 97: num_leaves=4266; max_depth=14; min_child_weight=0.167; min_data_in_leaf=1544; min_gain_to_split=0.0882; lambda_l1=3.51; lambda_l2=104; scale_pos_weight=4.08; learning_rate=0.0237; num_iterations=3351; early_stopping_rounds=104; feature_fraction=0.569; bagging_fraction=0.567; bagging_freq=0; max_delta_step=3.54; path_smooth=1.27 : y = 0.926 : 438.6 secs : infill_ei
#
# Saved the current state after iteration 98 in the file HT.RDATA.
#
# Wed Nov 19 09:52:44 AM 2025 AUC 0.928983222708297
#
# [mbo] 98: num_leaves=1942; max_depth=30; min_child_weight=8.22; min_data_in_leaf=1383; min_gain_to_split=0.0306; lambda_l1=0.378; lambda_l2=52.8; scale_pos_weight=3.67; learning_rate=0.0586; num_iterations=3218; early_stopping_rounds=243; feature_fraction=0.493; bagging_fraction=0.837; bagging_freq=0; max_delta_step=0.424; path_smooth=8.68 : y = 0.929 : 325.6 secs : infill_ei
#
# Wed Nov 19 09:57:34 AM 2025 AUC 0.930041827470576
#
# [mbo] 99: num_leaves=1672; max_depth=28; min_child_weight=1.17; min_data_in_leaf=293; min_gain_to_split=0.0162; lambda_l1=0.537; lambda_l2=537; scale_pos_weight=4.09; learning_rate=0.0505; num_iterations=3064; early_stopping_rounds=255; feature_fraction=0.0709; bagging_fraction=0.728; bagging_freq=0; max_delta_step=9.38; path_smooth=1.64 : y = 0.93 : 284.0 secs : infill_ei
#
# Saved the current state after iteration 100 in the file HT.RDATA.
#
# Wed Nov 19 10:02:05 AM 2025 AUC 0.929207693892438
#
# [mbo] 100: num_leaves=4571; max_depth=21; min_child_weight=8.02; min_data_in_leaf=1259; min_gain_to_split=0.0109; lambda_l1=3.06; lambda_l2=202; scale_pos_weight=4.19; learning_rate=0.0367; num_iterations=3898; early_stopping_rounds=240; feature_fraction=0.168; bagging_fraction=0.513; bagging_freq=0; max_delta_step=9.05; path_smooth=1.04 : y = 0.929 : 267.1 secs : infill_ei
#
# Wed Nov 19 10:09:09 AM 2025 AUC 0.924931333291727
#
# [mbo] 101: num_leaves=3608; max_depth=15; min_child_weight=5.13; min_data_in_leaf=2160; min_gain_to_split=0.046; lambda_l1=0.266; lambda_l2=73.2; scale_pos_weight=4.13; learning_rate=0.0545; num_iterations=4953; early_stopping_rounds=197; feature_fraction=0.294; bagging_fraction=0.86; bagging_freq=1; max_delta_step=9.91; path_smooth=1.96 : y = 0.925 : 420.1 secs : infill_ei
#
# Saved the current state after iteration 102 in the file HT.RDATA.
#
# Wed Nov 19 10:14:23 AM 2025 AUC 0.929871041472477
#
# [mbo] 102: num_leaves=1951; max_depth=30; min_child_weight=8.99; min_data_in_leaf=32; min_gain_to_split=0.0168; lambda_l1=0.121; lambda_l2=29.6; scale_pos_weight=4.23; learning_rate=0.018; num_iterations=3098; early_stopping_rounds=352; feature_fraction=0.628; bagging_fraction=0.658; bagging_freq=1; max_delta_step=5.81; path_smooth=3.56 : y = 0.93 : 309.3 secs : infill_ei
#
# Wed Nov 19 10:20:13 AM 2025 AUC 0.932040929585839
#
# [mbo] 103: num_leaves=1694; max_depth=17; min_child_weight=5.86; min_data_in_leaf=255; min_gain_to_split=0.0168; lambda_l1=0.553; lambda_l2=206; scale_pos_weight=4.26; learning_rate=0.0491; num_iterations=3919; early_stopping_rounds=407; feature_fraction=0.0645; bagging_fraction=0.603; bagging_freq=0; max_delta_step=2.24; path_smooth=4.14 : y = 0.932 : 344.4 secs : infill_ei
#
# Saved the current state after iteration 104 in the file HT.RDATA.
#
# Wed Nov 19 10:25:05 AM 2025 AUC 0.934375564113869
#
# [mbo] 104: num_leaves=4692; max_depth=10; min_child_weight=0.908; min_data_in_leaf=760; min_gain_to_split=0.0548; lambda_l1=1.09; lambda_l2=2.68; scale_pos_weight=4.29; learning_rate=0.0175; num_iterations=4320; early_stopping_rounds=309; feature_fraction=0.113; bagging_fraction=0.653; bagging_freq=0; max_delta_step=8; path_smooth=0.426 : y = 0.934 : 286.1 secs : infill_ei
#
# Wed Nov 19 10:28:46 AM 2025 AUC 0.920893536236494
#
# [mbo] 105: num_leaves=2271; max_depth=19; min_child_weight=0.701; min_data_in_leaf=1192; min_gain_to_split=0.0647; lambda_l1=15.6; lambda_l2=215; scale_pos_weight=4.13; learning_rate=0.0259; num_iterations=4013; early_stopping_rounds=327; feature_fraction=0.0693; bagging_fraction=0.631; bagging_freq=1; max_delta_step=4.35; path_smooth=2.6 : y = 0.921 : 217.2 secs : infill_ei
#
# Wed Nov 19 10:37:05 AM 2025 AUC 0.928439995732028
#
# [mbo] 106: num_leaves=3418; max_depth=23; min_child_weight=5.03; min_data_in_leaf=365; min_gain_to_split=0.0309; lambda_l1=1.36; lambda_l2=591; scale_pos_weight=4.44; learning_rate=0.0387; num_iterations=3133; early_stopping_rounds=387; feature_fraction=0.286; bagging_fraction=0.971; bagging_freq=3; max_delta_step=1.59; path_smooth=1.18 : y = 0.928 : 496.2 secs : infill_ei
#
# Saved the current state after iteration 107 in the file HT.RDATA.
#
# Wed Nov 19 10:42:20 AM 2025 AUC 0.928569511243356
#
# [mbo] 107: num_leaves=2426; max_depth=11; min_child_weight=3.52; min_data_in_leaf=205; min_gain_to_split=0.00635; lambda_l1=6.3; lambda_l2=53.4; scale_pos_weight=4.47; learning_rate=0.0238; num_iterations=3243; early_stopping_rounds=372; feature_fraction=0.346; bagging_fraction=0.867; bagging_freq=3; max_delta_step=6.8; path_smooth=5.26 : y = 0.929 : 309.6 secs : infill_ei
#
# Wed Nov 19 10:48:49 AM 2025 AUC 0.92928922826874
#
# [mbo] 108: num_leaves=6352; max_depth=9; min_child_weight=6.1; min_data_in_leaf=15; min_gain_to_split=0.075; lambda_l1=6.72; lambda_l2=265; scale_pos_weight=4.34; learning_rate=0.027; num_iterations=3883; early_stopping_rounds=185; feature_fraction=0.337; bagging_fraction=0.922; bagging_freq=0; max_delta_step=2.91; path_smooth=2.86 : y = 0.929 : 384.3 secs : infill_ei
#
# Saved the current state after iteration 109 in the file HT.RDATA.
#
# Wed Nov 19 10:52:55 AM 2025 AUC 0.934331273835384
#
# [mbo] 109: num_leaves=4239; max_depth=11; min_child_weight=8.83; min_data_in_leaf=90; min_gain_to_split=0.00356; lambda_l1=0.711; lambda_l2=30.3; scale_pos_weight=4.36; learning_rate=0.0445; num_iterations=4562; early_stopping_rounds=339; feature_fraction=0.398; bagging_fraction=0.85; bagging_freq=0; max_delta_step=5.73; path_smooth=0.13 : y = 0.934 : 240.9 secs : infill_ei
#
# Wed Nov 19 10:55:59 AM 2025 AUC 0.931140360589973
#
# [mbo] 110: num_leaves=5521; max_depth=14; min_child_weight=2.4; min_data_in_leaf=499; min_gain_to_split=0.0202; lambda_l1=6.58; lambda_l2=9.01; scale_pos_weight=4.33; learning_rate=0.0305; num_iterations=3774; early_stopping_rounds=184; feature_fraction=0.327; bagging_fraction=0.906; bagging_freq=0; max_delta_step=5.28; path_smooth=4.66 : y = 0.931 : 180.2 secs : infill_ei
#
# Wed Nov 19 11:02:34 AM 2025 AUC 0.929861311032507
#
# [mbo] 111: num_leaves=5025; max_depth=28; min_child_weight=4.52; min_data_in_leaf=216; min_gain_to_split=0.0509; lambda_l1=1.03; lambda_l2=382; scale_pos_weight=3.85; learning_rate=0.0562; num_iterations=2795; early_stopping_rounds=301; feature_fraction=0.22; bagging_fraction=0.852; bagging_freq=0; max_delta_step=3.66; path_smooth=6.68 : y = 0.93 : 388.9 secs : infill_ei
#
# Saved the current state after iteration 112 in the file HT.RDATA.
#
# Wed Nov 19 11:06:13 AM 2025 AUC 0.926389557157611
#
# [mbo] 112: num_leaves=4480; max_depth=8; min_child_weight=9.43; min_data_in_leaf=495; min_gain_to_split=0.0352; lambda_l1=0.759; lambda_l2=160; scale_pos_weight=4.33; learning_rate=0.0706; num_iterations=2024; early_stopping_rounds=406; feature_fraction=0.229; bagging_fraction=0.624; bagging_freq=3; max_delta_step=7.9; path_smooth=0.113 : y = 0.926 : 214.0 secs : infill_ei
#
# Wed Nov 19 11:13:06 AM 2025 AUC 0.926183204723759
#
# [mbo] 113: num_leaves=2330; max_depth=11; min_child_weight=8.84; min_data_in_leaf=234; min_gain_to_split=0.0145; lambda_l1=4.06; lambda_l2=541; scale_pos_weight=4.46; learning_rate=0.0313; num_iterations=3641; early_stopping_rounds=174; feature_fraction=0.149; bagging_fraction=0.766; bagging_freq=2; max_delta_step=1.45; path_smooth=4.78 : y = 0.926 : 409.0 secs : infill_ei
#
# Saved the current state after iteration 114 in the file HT.RDATA.
#
# Wed Nov 19 11:18:43 AM 2025 AUC 0.93002907723889
#
# [mbo] 114: num_leaves=5017; max_depth=23; min_child_weight=8.8; min_data_in_leaf=2027; min_gain_to_split=0.0275; lambda_l1=1.47; lambda_l2=94.3; scale_pos_weight=4.33; learning_rate=0.0402; num_iterations=2694; early_stopping_rounds=372; feature_fraction=0.183; bagging_fraction=0.685; bagging_freq=0; max_delta_step=0.699; path_smooth=1.3 : y = 0.93 : 330.0 secs : infill_ei
#
# Wed Nov 19 11:23:26 AM 2025 AUC 0.926973048023412
#
# [mbo] 115: num_leaves=2420; max_depth=26; min_child_weight=4.4; min_data_in_leaf=127; min_gain_to_split=0.0134; lambda_l1=0.487; lambda_l2=453; scale_pos_weight=4.33; learning_rate=0.0926; num_iterations=4654; early_stopping_rounds=277; feature_fraction=0.433; bagging_fraction=0.626; bagging_freq=0; max_delta_step=5.03; path_smooth=0.114 : y = 0.927 : 277.2 secs : infill_ei
#
# Saved the current state after iteration 116 in the file HT.RDATA.
#
# Wed Nov 19 11:26:08 AM 2025 AUC 0.922396721445688
#
# [mbo] 116: num_leaves=2983; max_depth=6; min_child_weight=3.67; min_data_in_leaf=192; min_gain_to_split=0.0374; lambda_l1=1.07; lambda_l2=40.2; scale_pos_weight=4.33; learning_rate=0.0136; num_iterations=1295; early_stopping_rounds=220; feature_fraction=0.248; bagging_fraction=0.742; bagging_freq=3; max_delta_step=1.09; path_smooth=1.28 : y = 0.922 : 156.0 secs : infill_ei
#
# Wed Nov 19 11:32:17 AM 2025 AUC 0.926520079266177
#
# [mbo] 117: num_leaves=966; max_depth=24; min_child_weight=9.18; min_data_in_leaf=234; min_gain_to_split=0.041; lambda_l1=1.73; lambda_l2=655; scale_pos_weight=4.32; learning_rate=0.0606; num_iterations=3998; early_stopping_rounds=448; feature_fraction=0.318; bagging_fraction=0.963; bagging_freq=2; max_delta_step=7.72; path_smooth=6.05 : y = 0.927 : 364.0 secs : infill_ei
#
# Wed Nov 19 11:38:02 AM 2025 AUC 0.928911754304378
#
# [mbo] 118: num_leaves=4560; max_depth=27; min_child_weight=6.9; min_data_in_leaf=1123; min_gain_to_split=0.0253; lambda_l1=0.561; lambda_l2=28.5; scale_pos_weight=4.45; learning_rate=0.0289; num_iterations=4607; early_stopping_rounds=396; feature_fraction=0.172; bagging_fraction=0.713; bagging_freq=1; max_delta_step=8.4; path_smooth=2.37 : y = 0.929 : 339.8 secs : infill_ei
#
# Saved the current state after iteration 119 in the file HT.RDATA.
#
# Wed Nov 19 11:39:42 AM 2025 AUC 0.921955831855313
#
# [mbo] 119: num_leaves=3890; max_depth=14; min_child_weight=5.82; min_data_in_leaf=356; min_gain_to_split=0.0231; lambda_l1=38.7; lambda_l2=128; scale_pos_weight=4.29; learning_rate=0.0549; num_iterations=3305; early_stopping_rounds=227; feature_fraction=0.0786; bagging_fraction=0.894; bagging_freq=0; max_delta_step=6.15; path_smooth=0.874 : y = 0.922 : 94.8 secs : infill_ei
#
# Wed Nov 19 11:49:16 AM 2025 AUC 0.923593230029614
#
# [mbo] 120: num_leaves=4905; max_depth=22; min_child_weight=5.98; min_data_in_leaf=3257; min_gain_to_split=0.0385; lambda_l1=0.321; lambda_l2=537; scale_pos_weight=2.36; learning_rate=0.0868; num_iterations=4134; early_stopping_rounds=440; feature_fraction=0.552; bagging_fraction=0.877; bagging_freq=1; max_delta_step=1.04; path_smooth=6.46 : y = 0.924 : 567.0 secs : infill_ei
#
# Saved the final state in the file HT.RDATA
#
# Saved the final state in the file HT.RDATA

# %% [markdown]
# la bayesian optimization ha corrido, extraigo los mejores hiperparametros

# %%
# almaceno los resultados de la Bayesian Optimization
# y capturo los mejores hiperparametros encontrados

tb_bayesiana <- as.data.table(bayesiana_salida$opt.path)

# ordeno en forma descendente por AUC = y
setorder(tb_bayesiana, -y, -num_iterations)

# grabo para eventualmente poder utilizarlos en OTRA corrida
fwrite( tb_bayesiana,
  file="BO_log.txt",
  sep="\t"
)

# los mejores hiperparámetros son los que quedaron en el registro 1 de la tabla
PARAM$out$lgbm$mejores_hiperparametros <- tb_bayesiana[
  1, # el primero es el de mejor AUC
  setdiff(colnames(tb_bayesiana),
    c("y","dob","eol","error.message","exec.time","ei","error.model",
      "train.time","prop.type","propose.time","se","mean","iter")),
  with= FALSE
]

print(PARAM$out$lgbm$mejores_hiperparametros)
# Out:
#    num_leaves max_depth min_child_weight min_data_in_leaf min_gain_to_split
#         <int>     <int>            <num>            <int>             <num>
# 1:       4692        10        0.9083445              760        0.05478071
#    lambda_l1 lambda_l2 scale_pos_weight learning_rate num_iterations
#        <num>     <num>            <num>         <num>          <int>
# 1:  1.089753  2.681015          4.28926    0.01751202           4320
#    early_stopping_rounds feature_fraction bagging_fraction bagging_freq
#                    <int>            <num>            <num>        <int>
# 1:                   309         0.112784        0.6525644            0
#    max_delta_step path_smooth
#             <num>       <num>
# 1:        7.99712   0.4258474

# %% [markdown]
# ### 6.3.3 Produccion

# %% [markdown]
# #### Final Training
# Construyo el modelo final, que es uno solo, no hace ningun tipo de particion < training, validation, testing>]

# %% [markdown]
# ##### Final Training Dataset
#
# Aqui esta la gran decision de en qué meses hago el Final Training
# <br> debo utilizar los mejores hiperparámetros que encontré en la optimización bayesiana

# %%
PARAM$trainingstrategy$final_train <- c(
  202105, 202104, 202103, 202102, 202101,
  202012, 202011, 202010, 202009, 202008, 202007,
  202006, 202005
)

dataset[, fold_final_train := foto_mes %in% PARAM$trainingstrategy$final_train ]

# creo el dfinal_train en formato  LightGBM
dfinal_train <- lgb.Dataset(
  data= data.matrix(dataset[fold_final_train == TRUE, campos_buenos, with= FALSE]),
  label= dataset[fold_final_train == TRUE, clase01],
  free_raw_data= TRUE
)

nrow( dfinal_train) # verifico el tamaño
# Out:
# [1] 207504

# %% [markdown]
# ##### Final Training Hyperparameters

# %%
# uno los parametros fijos y los mejores encontrados de los variables
fijos <- copy(PARAM$lgbm$param_fijos)

# quito lo que optimice en la Bayesian Optimization
fijos$num_iterations <- NULL
fijos$early_stopping_rounds <- NULL

# agrego a los hiperparametros fijos los que encontre con la Bayesian Optimization
param_final <- c(fijos, PARAM$out$lgbm$mejores_hiperparametros)

# Para el entrenamiento final, removemos early_stopping_rounds
# ya que se entrena con todos los datos disponibles y la cantidad de iteraciones
# ya está optimizada en 'num_iterations'.
param_final$early_stopping_rounds <- NULL

# %% [markdown]
# ##### Training
# Genero el modelo final, siempre sobre TODOS los datos de  final_train, sin hacer ningun tipo de undersampling de la clase mayoritaria

# %%
final_model <- lgb.train(
  data= dfinal_train,
  param= param_final,
  verbose= -100
)

# %%
# grabo a disco el modelo en un formato para seres humanos ... ponele ...

lgb.save(final_model, "modelo.txt")

# %%
# ahora imprimo la importancia de variables

tb_importancia <- as.data.table(lgb.importance(final_model))
archivo_importancia <- "impo.txt"

fwrite( tb_importancia,
  file= archivo_importancia,
  sep= "\t"
)

# %% [markdown]
# #### Scoring

# %% [markdown]
# Aplico el modelo final a los datos del futuro

# %%
PARAM$trainingstrategy$future <- c(202107)

dfuture <- dataset[ foto_mes %in% PARAM$trainingstrategy$future ]

# %%
# aplico final_model   a dfuture

prediccion <- predict(
  final_model,
  data.matrix(dfuture[, campos_buenos, with= FALSE])
)

# %% [markdown]
# ##### Tabla Prediccion

# %%
tb_prediccion <- dfuture[, list(numero_de_cliente)]
tb_prediccion[, prob := prediccion]

# grabo las probabilidad del modelo
#  me va a ser util para hacer Ensembles de modelos
fwrite(tb_prediccion,
  file= "prediccion.txt",
  sep= "\t"
)

# %% [markdown]
# #### Curva de Ganancia

# %% [markdown]
# Genero las salidas

# %%
# asigno clase ternaria
tb_prediccion[, clase_ternaria := dfuture$clase_ternaria ]

# asigno ganancias
tb_prediccion[, ganancia := -3000.0 ]
tb_prediccion[clase_ternaria=="BAJA+2", ganancia := 117000.0 ]

# reordeno, y acumulada
setorder( tb_prediccion, -prob )
tb_prediccion[, gan_acum := cumsum(ganancia)]

# media movil de ancho 400
tb_prediccion[,
  gan_suavizada := frollmean(
    x= gan_acum,
    n= 400,
    align= "center",
    na.rm= TRUE,
    hasNA= TRUE
  )
]

# %%
tb_prediccion[, sum(!is.na(gan_suavizada) )]
tb_prediccion[, .N]
# Out:
# [1] 16152
# [1] 16551

# %%
# Este es la ganancia a reportar
resultado <- list()
resultado$ganancia_suavizada_max <- max( tb_prediccion$gan_suavizada, na.rm=TRUE )
options(digits= 8)
resultado$envios <- which.max( tb_prediccion$gan_suavizada)
resultado
# Out:
# $ganancia_suavizada_max
# [1] 6354000
#
# $envios
# [1] 1621

# %%
# grabo las ganancias
fwrite( tb_prediccion,
  file= "ganancias.txt",
  sep= "\t"
)

# %%
# genero el grafico

tb_prediccion[, envios:= .I]

pdf("curva_de_ganancia.pdf")

plot(
  x= tb_prediccion$envios,
  y= tb_prediccion$gan_acum,
  type= "l",
  col= "gray",
  xlim= c(0, 6000),
  ylim= c(0, 8000000),
  main= paste0("Mejor gan prom= ", as.integer(resultado$ganancia_suavizada_max), " envios= ", resultado$envios),
  xlab= "Envios",
  ylab= "Ganancia",
  panel.first= grid()
)

dev.off()
# Out:
# agg_record_212055948
#                    2

# %%
# grabo los parametros
if( !require("yaml")) install.packages("yaml")
require("yaml")

PARAM$resultado <- resultado

write_yaml( PARAM, file="PARAM.yml")
# Out:
# Loading required package: yaml

# %%
format(Sys.time(), "%a %b %d %X %Y")
fin <- Sys.time()

# Duración en segundos
secs <- as.numeric(difftime(fin, principio, units = "secs"))
secs <- round(secs)

# A hh:mm:ss
h <- secs %/% 3600
m <- (secs %% 3600) %/% 60
s <- secs %% 60
dur_hms <- sprintf("%02d:%02d:%02d", h, m, s)

cat(
  "Inicio: ", format(principio, "%a %b %d %X %Y"), "\n",
  "Fin:    ", format(fin,       "%a %b %d %X %Y"), "\n",
  "Duración (hh:mm:ss): ", dur_hms, "\n",
  sep = ""
)
# Out:
# [1] "Wed Nov 19 11:58:49 AM 2025"
# Inicio: Wed Nov 19 02:13:40 AM 2025
# Fin:    Wed Nov 19 11:58:49 AM 2025
# Duración (hh:mm:ss): 09:45:08
