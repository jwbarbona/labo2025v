# %% [markdown]
# <a href="https://colab.research.google.com/github/jwbarbona/labo2025v/blob/main/610_WorkFlow_16H_115_gerencial_julio.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # 6 WorkFlow  Gerencial, futuro=JULIO

# %% [markdown]
# ### 6.1 Objetivo

# %% [markdown]
# Presentar un workflow/pipeline completo al que los estudiantes deberán enriquecer

# %% [markdown]
# #### 6.2  Seteo del ambiente en Google Colab

# %% [markdown]
# Esta parte se debe correr con el runtime en Python3
# <br>Ir al menu, Runtime -> Change Runtime Type -> Runtime type ->  **Python 3**

# %% [markdown]
# Conectar la virtual machine donde esta corriendo Google Colab con el  Google Drive, para poder tener persistencia de archivos

# %%
# primero establecer el Runtime de Python 3
from google.colab import drive
drive.mount('/content/.drive')
# Out:
# Mounted at /content/.drive

# %% [markdown]
# Para correr la siguiente celda es fundamental en Arranque en Frio haber copiado el archivo kaggle.json al Google Drive, en la carpeta indicada en el instructivo
#
# <br>los siguientes comando estan en shell script de Linux
# *   Crear las carpetas en el Google Drive
# *   "instalar" el archivo kaggle.json desde el Google Drive a la virtual machine para que pueda ser utilizado por la libreria  kaggle de Python
# *   Bajar el  **dataset_pequeno**  al  Google Drive  y tambien al disco local de la virtual machine que esta corriendo Google Colab
# *   Bajar el **dataset_historico** al Google Drive y tambien al disco local de la virtual machine que esta corriendo Google Colab

# %%
%%shell

mkdir -p "/content/.drive/My Drive/labo1"
mkdir -p "/content/buckets"
ln -s "/content/.drive/My Drive/labo1" /content/buckets/b1

mkdir -p ~/.kaggle
cp /content/buckets/b1/kaggle/kaggle.json  ~/.kaggle
chmod 600 ~/.kaggle/kaggle.json


mkdir -p /content/buckets/b1/exp
mkdir -p /content/buckets/b1/datasets
mkdir -p /content/datasets


webfiles="https://storage.googleapis.com/open-courses/austral2025-af91/"
destino_local="/content/datasets"
destino_bucket="/content/buckets/b1/datasets"


archivo="dataset_pequeno.csv"

if ! test -f $destino_bucket/$archivo; then
  wget  $webfiles/$archivo  -O $destino_bucket/$archivo
fi


if ! test -f $destino_local/$pequeno; then
  cp  $destino_bucket/$archivo  $destino_local/$archivo
fi

#-------

archivo="gerencial_competencia_2025.csv.gz"

if ! test -f $destino_bucket/$archivo; then
  wget  $webfiles/$archivo  -O $destino_bucket/$archivo
fi


if ! test -f $destino_local/$pequeno; then
  cp  $destino_bucket/$archivo  $destino_local/$archivo
fi
# Out:
# cp: cannot stat '/content/buckets/b1/kaggle/kaggle.json': No such file or directory
# chmod: cannot access '/root/.kaggle/kaggle.json': No such file or directory

# %% [markdown]
# ## 6.3  Workflow

# %% [markdown]
# ## Inicializacion

# %% [markdown]
# Esta parte se debe correr con el runtime en lenguaje **R** Ir al menu, Runtime -> Change Runtime Type -> Runtime type -> R

# %% [markdown]
# limpio el ambiente de R

# %%
format(Sys.time(), "%a %b %d %X %Y")
# Out:
# [1] "Mon Nov 17 09:19:08 PM 2025"

# %%
# limpio la memoria
rm(list=ls(all.names=TRUE)) # remove all objects
gc(full=TRUE, verbose=FALSE) # garbage collection
# Out:
#        used    (Mb) gc trigger (Mb) max used (Mb)
# Ncells  668422 35.7 1454477    77.7 1454477  77.7
# Vcells 1244645  9.5 8388608    64.0 1975136  15.1

# %%
principio <- Sys.time()

# %%
require("data.table")

if( !require("R.utils")) install.packages("R.utils")
require("R.utils")
# Out:
# Loading required package: data.table
#
# Loading required package: R.utils
#
# Warning message in library(package, lib.loc = lib.loc, character.only = TRUE, logical.return = TRUE, :
# “there is no package called ‘R.utils’”
# Installing package into ‘/usr/local/lib/R/site-library’
# (as ‘lib’ is unspecified)
#
# also installing the dependencies ‘R.oo’, ‘R.methodsS3’
#
#
# Loading required package: R.utils
#
# Loading required package: R.oo
#
# Loading required package: R.methodsS3
#
# R.methodsS3 v1.8.2 (2022-06-13 22:00:14 UTC) successfully loaded. See ?R.methodsS3 for help.
#
# R.oo v1.27.1 (2025-05-02 21:00:05 UTC) successfully loaded. See ?R.oo for help.
#
#
# Attaching package: ‘R.oo’
#
#
# The following object is masked from ‘package:R.methodsS3’:
#
#     throw
#
#
# The following objects are masked from ‘package:methods’:
#
#     getClasses, getMethods
#
#
# The following objects are masked from ‘package:base’:
#
#     attach, detach, load, save
#
#
# R.utils v2.13.0 (2025-02-24 21:20:02 UTC) successfully loaded. See ?R.utils for help.
#
#
# Attaching package: ‘R.utils’
#
#
# The following object is masked from ‘package:utils’:
#
#     timestamp
#
#
# The following objects are masked from ‘package:base’:
#
#     cat, commandArgs, getOption, isOpen, nullfile, parse, use, warnings

# %% [markdown]
# #### Parametros
# Si es gerente, no cambie nada
# <br>Si es Analista, cambie el nombre del dataset

# %%
PARAM <- list()
PARAM$semilla_primigenia <- 999983 # 100009, 200003, 499999, 700009, 999983

PARAM$experimento <- 63115
PARAM$dataset <- "gerencial_competencia_2025.csv.gz"

# %% [markdown]
# #### Carpeta del Experimento

# %%
# carpeta de trabajo

setwd("/content/buckets/b1/exp")
experimento_folder <- paste0("WF", PARAM$experimento)
dir.create(experimento_folder, showWarnings=FALSE)
setwd( paste0("/content/buckets/b1/exp/", experimento_folder ))

# %% [markdown]
# ### 6.3.1   Preprocesamiento del dataset

# %% [markdown]
# #### 6.3.1.1  DT incorporar dataset

# %%
# lectura del dataset
dataset <- fread(paste0("/content/datasets/", PARAM$dataset))

# %% [markdown]
# #### 6.3.1.2  CA  Catastrophe Analysis
# Se intentan reparar las variables que para un mes están con todos los valores en cero.

# %% [markdown]
# El método que se utiliza es **Machine Learning** se asigna NA also valores, si ha leido bien, es la "anti imputación de valores faltantes"
# <br> Usted podrá aplicar aquí otros métodos

# %%
dataset[ foto_mes==202006, internet:=NA]
dataset[ foto_mes==202006, mrentabilidad:=NA]
dataset[ foto_mes==202006, mrentabilidad_annual:=NA]
dataset[ foto_mes==202006, mcomisiones:=NA]
dataset[ foto_mes==202006, mactivos_margen:=NA]
dataset[ foto_mes==202006, mpasivos_margen:=NA]
dataset[ foto_mes==202006, mcuentas_saldo:=NA]
dataset[ foto_mes==202006, ctarjeta_visa_transacciones:=NA]
dataset[ foto_mes==202006, mtarjeta_visa_consumo:=NA]
dataset[ foto_mes==202006, mtarjeta_master_consumo:=NA]
dataset[ foto_mes==202006, ccallcenter_transacciones:=NA]
dataset[ foto_mes==202006, chomebanking_transacciones:=NA]
dataset[ foto_mes==202006, chomebanking_transacciones:=NA]

# %% [markdown]
# #### 6.3.1.3  DR  Data Drifting
# Se intenta corregir el data drifting, quizas ajustando por IPC ...
# <br>Esta parte podrá ser abordada por todos los Analistas y también la Gerenciapero se decide pedagogicamente no incluirla en esta primer version para reducir la carga cognitiva

# %%
# sin codigo en esta primera version del workflow

# %% [markdown]
# #### 6.3.1.3  FE_intra_manual Feature Engineering intra-mes
#
# Agrego campos nuevos dentro del mismo mes, SIN considerar la historia.

# %%
# esta funcion atributos presentes existe debido a que las modalidades poseen datasets con distinta cantidad de campos
atributos_presentes <- function( patributos )
{
  atributos <- unique( patributos )
  comun <- intersect( atributos, colnames(dataset) )

  return(  length( atributos ) == length( comun ) )
}

# el mes 1,2, ..12
if( atributos_presentes( c("foto_mes") ))
  dataset[, kmes := foto_mes %% 100]

# variable extraida de una tesis de maestria de Irlanda
if( atributos_presentes( c("mpayroll", "cliente_edad") ))
  dataset[, mpayroll_sobre_edad := mpayroll / cliente_edad]

# %%
# visualizo las columas del dataset a esta etapa
colnames(dataset)
# Out:
#  [1] "numero_de_cliente"           "foto_mes"
#  [3] "internet"                    "cliente_edad"
#  [5] "cliente_antiguedad"          "mrentabilidad"
#  [7] "mrentabilidad_annual"        "mcomisiones"
#  [9] "mactivos_margen"             "mpasivos_margen"
# [11] "cproductos"                  "mcuenta_corriente"
# [13] "mcaja_ahorro"                "cdescubierto_preacordado"
# [15] "mcuentas_saldo"              "ctarjeta_visa_transacciones"
# [17] "mtarjeta_visa_consumo"       "mtarjeta_master_consumo"
# [19] "mprestamos_personales"       "cpayroll_trx"
# [21] "mpayroll"                    "ccomisiones_mantenimiento"
# [23] "ccallcenter_transacciones"   "chomebanking_transacciones"
# [25] "ctrx_quarter"                "Master_status"
# [27] "Master_fechaalta"            "Master_mpagominimo"
# [29] "Visa_status"                 "Visa_fechaalta"
# [31] "Visa_mpagominimo"            "clase_ternaria"
# [33] "kmes"                        "mpayroll_sobre_edad"

# %% [markdown]
# #### 6.3.1.4  FE_rf Feature Engineering de nuevas variables a partir de hojas de Random Forest
#
# Esto se mostrará unicamente a la *modalidad Analista Sr*

# %%
# No se implementa Feature Engineering a partir de Random Forest

# %% [markdown]
# #### 6.3.1.5  FEhist Feature Engineering historico
#
# El Fature Engineering Histórico es la etapa que más aporta a la ganancia final, ya que enriquece cada registro del dataset con su historia.

# %% [markdown]
# Para cada campo del dataset original (*)
# se crean lo siguientes campos de a partir de la historia
# * lag1  lags de orden 1
# * delta1  =  valor actual - lag1
# * lag2  lags de orden 2
# * delta2  = valor actual - lag2
#
#
# (*) Excepto para los campos  <numero_de_cliente,  foto_mes,  clase_ternaria>

# %%
# Feature Engineering Historico

# todo es lagueable, menos la primary key y la clase
cols_lagueables <- copy( setdiff(
    colnames(dataset),
    c("numero_de_cliente", "foto_mes", "clase_ternaria")
) )

# https://rdrr.io/cran/data.table/man/shift.html

# lags de orden 1
dataset[,
    paste0(cols_lagueables, "_lag1") := shift(.SD, 1, NA, "lag"),
    by = numero_de_cliente,
    .SDcols = cols_lagueables
]

# lags de orden 2
dataset[,
    paste0(cols_lagueables, "_lag2") := shift(.SD, 2, NA, "lag"),
    by = numero_de_cliente,
    .SDcols = cols_lagueables
]

# agrego los delta lags
for (vcol in cols_lagueables)
{
    dataset[, paste0(vcol, "_delta1") := get(vcol) - get(paste0(vcol, "_lag1"))]
    dataset[, paste0(vcol, "_delta2") := get(vcol) - get(paste0(vcol, "_lag2"))]
}

# %% [markdown]
# Verificacion de los campos recien creados

# %%
ncol(dataset)
colnames(dataset)
# Out:
# [1] 158
#   [1] "numero_de_cliente"                  "foto_mes"
#   [3] "internet"                           "cliente_edad"
#   [5] "cliente_antiguedad"                 "mrentabilidad"
#   [7] "mrentabilidad_annual"               "mcomisiones"
#   [9] "mactivos_margen"                    "mpasivos_margen"
#  [11] "cproductos"                         "mcuenta_corriente"
#  [13] "mcaja_ahorro"                       "cdescubierto_preacordado"
#  [15] "mcuentas_saldo"                     "ctarjeta_visa_transacciones"
#  [17] "mtarjeta_visa_consumo"              "mtarjeta_master_consumo"
#  [19] "mprestamos_personales"              "cpayroll_trx"
#  [21] "mpayroll"                           "ccomisiones_mantenimiento"
#  [23] "ccallcenter_transacciones"          "chomebanking_transacciones"
#  [25] "ctrx_quarter"                       "Master_status"
#  [27] "Master_fechaalta"                   "Master_mpagominimo"
#  [29] "Visa_status"                        "Visa_fechaalta"
#  [31] "Visa_mpagominimo"                   "clase_ternaria"
#  [33] "kmes"                               "mpayroll_sobre_edad"
#  [35] "internet_lag1"                      "cliente_edad_lag1"
#  [37] "cliente_antiguedad_lag1"            "mrentabilidad_lag1"
#  [39] "mrentabilidad_annual_lag1"          "mcomisiones_lag1"
#  [41] "mactivos_margen_lag1"               "mpasivos_margen_lag1"
#  [43] "cproductos_lag1"                    "mcuenta_corriente_lag1"
#  [45] "mcaja_ahorro_lag1"                  "cdescubierto_preacordado_lag1"
#  [47] "mcuentas_saldo_lag1"                "ctarjeta_visa_transacciones_lag1"
#  [49] "mtarjeta_visa_consumo_lag1"         "mtarjeta_master_consumo_lag1"
#  [51] "mprestamos_personales_lag1"         "cpayroll_trx_lag1"
#  [53] "mpayroll_lag1"                      "ccomisiones_mantenimiento_lag1"
#  [55] "ccallcenter_transacciones_lag1"     "chomebanking_transacciones_lag1"
#  [57] "ctrx_quarter_lag1"                  "Master_status_lag1"
#  [59] "Master_fechaalta_lag1"              "Master_mpagominimo_lag1"
#  [61] "Visa_status_lag1"                   "Visa_fechaalta_lag1"
#  [63] "Visa_mpagominimo_lag1"              "kmes_lag1"
#  [65] "mpayroll_sobre_edad_lag1"           "internet_lag2"
#  [67] "cliente_edad_lag2"                  "cliente_antiguedad_lag2"
#  [69] "mrentabilidad_lag2"                 "mrentabilidad_annual_lag2"
#  [71] "mcomisiones_lag2"                   "mactivos_margen_lag2"
#  [73] "mpasivos_margen_lag2"               "cproductos_lag2"
#  [75] "mcuenta_corriente_lag2"             "mcaja_ahorro_lag2"
#  [77] "cdescubierto_preacordado_lag2"      "mcuentas_saldo_lag2"
#  [79] "ctarjeta_visa_transacciones_lag2"   "mtarjeta_visa_consumo_lag2"
#  [81] "mtarjeta_master_consumo_lag2"       "mprestamos_personales_lag2"
#  [83] "cpayroll_trx_lag2"                  "mpayroll_lag2"
#  [85] "ccomisiones_mantenimiento_lag2"     "ccallcenter_transacciones_lag2"
#  [87] "chomebanking_transacciones_lag2"    "ctrx_quarter_lag2"
#  [89] "Master_status_lag2"                 "Master_fechaalta_lag2"
#  [91] "Master_mpagominimo_lag2"            "Visa_status_lag2"
#  [93] "Visa_fechaalta_lag2"                "Visa_mpagominimo_lag2"
#  [95] "kmes_lag2"                          "mpayroll_sobre_edad_lag2"
#  [97] "internet_delta1"                    "internet_delta2"
#  [99] "cliente_edad_delta1"                "cliente_edad_delta2"
# [101] "cliente_antiguedad_delta1"          "cliente_antiguedad_delta2"
# [103] "mrentabilidad_delta1"               "mrentabilidad_delta2"
# [105] "mrentabilidad_annual_delta1"        "mrentabilidad_annual_delta2"
# [107] "mcomisiones_delta1"                 "mcomisiones_delta2"
# [109] "mactivos_margen_delta1"             "mactivos_margen_delta2"
# [111] "mpasivos_margen_delta1"             "mpasivos_margen_delta2"
# [113] "cproductos_delta1"                  "cproductos_delta2"
# [115] "mcuenta_corriente_delta1"           "mcuenta_corriente_delta2"
# [117] "mcaja_ahorro_delta1"                "mcaja_ahorro_delta2"
# [119] "cdescubierto_preacordado_delta1"    "cdescubierto_preacordado_delta2"
# [121] "mcuentas_saldo_delta1"              "mcuentas_saldo_delta2"
# [123] "ctarjeta_visa_transacciones_delta1" "ctarjeta_visa_transacciones_delta2"
# [125] "mtarjeta_visa_consumo_delta1"       "mtarjeta_visa_consumo_delta2"
# [127] "mtarjeta_master_consumo_delta1"     "mtarjeta_master_consumo_delta2"
# [129] "mprestamos_personales_delta1"       "mprestamos_personales_delta2"
# [131] "cpayroll_trx_delta1"                "cpayroll_trx_delta2"
# [133] "mpayroll_delta1"                    "mpayroll_delta2"
# [135] "ccomisiones_mantenimiento_delta1"   "ccomisiones_mantenimiento_delta2"
# [137] "ccallcenter_transacciones_delta1"   "ccallcenter_transacciones_delta2"
# [139] "chomebanking_transacciones_delta1"  "chomebanking_transacciones_delta2"
# [141] "ctrx_quarter_delta1"                "ctrx_quarter_delta2"
# [143] "Master_status_delta1"               "Master_status_delta2"
# [145] "Master_fechaalta_delta1"            "Master_fechaalta_delta2"
# [147] "Master_mpagominimo_delta1"          "Master_mpagominimo_delta2"
# [149] "Visa_status_delta1"                 "Visa_status_delta2"
# [151] "Visa_fechaalta_delta1"              "Visa_fechaalta_delta2"
# [153] "Visa_mpagominimo_delta1"            "Visa_mpagominimo_delta2"
# [155] "kmes_delta1"                        "kmes_delta2"
# [157] "mpayroll_sobre_edad_delta1"         "mpayroll_sobre_edad_delta2"

# %% [markdown]
# #### 6.3.1.6  FEhist Reduccion dimensionalidad con canaritos
#
# Esta etapa solo se mostrará a la *modalidad Anlista Sr* por algun canal secreto de forma de no confundir a los *Analista Jr*  nni distraer con detalles operativos a la estratégica *Modalidad Gerencial*

# %%
# No se implementa la reduccion de la dimensionalidad con canaritos

# %% [markdown]
# ### 6.3.2 Modelado

# %% [markdown]
# #### 6.3.2.1 Training Strategy
#
# Esta etapa de Workflow de  Training Strategy esta pensada para la *Modalidad Gerencial* que posee el dataset de [202005, 202109]
# <br> Si usted es un Analista, posee el periodo de [201901, 202109] y deberá experimentar en que meses le conviene experimentar
#
# <br> A la *Modalidad Gerencial* no se le complicada la vida con el undersampling de los continua, por eso PARAM$trainingstrategy$training_pct <- 1.0
# <br> Sin embargo, si usted es  *Analista SR* posee un dataset 50 veces ( filas x columnas) más grande que la *Modalidad Gerencial*  y por un tema de velocidad y experimentación más rápida puede llegar a necesitar activar el undersampling de la clase mayoritaria, a pesar de estar corriendo en Google Cloud.

# %% [markdown]
# Se hace una estrategia de entrenamiento muy sencilla, tomando todos los meses posibles, SIN eliminar nada x pandemia ni por ningun otro motivo
#
# * future = 202107  obviamente completo
#
# * final_train =  [ 202005, 202105 ]  SIN undersampling
#
# * training
#    * testing = NO HAY
#    * validation =  202105   completo, sin undersampling
#    * training = [ 202005, 202104 ]  donde se consideran el 100% de los CONTINUA

# %%
PARAM$trainingstrategy$validate <- c(202105)

PARAM$trainingstrategy$training <- c(
  202104, 202103, 202102, 202101,
  202012, 202011, 202010, 202009, 202008, 202007,
  202006, 202005
)

PARAM$trainingstrategy$training_pct <- 1.0


PARAM$trainingstrategy$positivos <- c( "BAJA+1", "BAJA+2")

# %%
# seteo la clase01   1={BAJA+1, BAJA+2}   0={CONTINUA}
dataset[, clase01 := ifelse( clase_ternaria %in% PARAM$trainingstrategy$positivos, 1, 0 )]

# %%
# los campos en los que se entrena
campos_buenos <- copy( setdiff(
    colnames(dataset), c("clase_ternaria","clase01","azar"))
)

# %%
# preparo para que se puede hacer undersampling de los CONTINUA
#  solamente por un tema de VELOCIDAD
set.seed(PARAM$semilla_primigenia, kind = "L'Ecuyer-CMRG")
dataset[, azar:=runif(nrow(dataset))]

# undersampling de los CONTINUA
dataset[, fold_train :=  foto_mes %in%  PARAM$trainingstrategy$training &
    (clase_ternaria %in% c("BAJA+1", "BAJA+2") |
     azar < PARAM$trainingstrategy$training_pct ) ]


if( !require("lightgbm")) install.packages("lightgbm")
require("lightgbm")

dtrain <- lgb.Dataset(
  data= data.matrix(dataset[fold_train == TRUE, campos_buenos, with = FALSE]),
  label= dataset[fold_train == TRUE, clase01],
  free_raw_data= TRUE
)
# Out:
# Loading required package: lightgbm
#
# Warning message in library(package, lib.loc = lib.loc, character.only = TRUE, logical.return = TRUE, :
# “there is no package called ‘lightgbm’”
# Installing package into ‘/usr/local/lib/R/site-library’
# (as ‘lib’ is unspecified)
#
# Loading required package: lightgbm

# %%
# datos de validation
dvalidate <- lgb.Dataset(
  data= data.matrix(dataset[foto_mes %in% PARAM$trainingstrategy$validate, campos_buenos, with = FALSE]),
  label= dataset[foto_mes %in% PARAM$trainingstrategy$validate, clase01],
  free_raw_data= TRUE
)

nrow(dvalidate)
# Out:
# [1] 16469

# %% [markdown]
# ####  6.3.2.2. Hyperparameter Tuning

# %% [markdown]
# * Clase binaria que se optimiza :  positivos = [ BAJA+1, BAJA+2 ]

# %% [markdown]
# * Metrica que se optimiza **AUC** Area Under Curve de la  ROC Curve
#
# es muy importante notar que intencionalmente  **NO** se está optimizando la funcion de ganancia del problema

# %% [markdown]
# * Cantidad de iteraciones inteligentes de la Optimizacion Bayesiana = **10**

# %% [markdown]
# * Parametros no default, fijos de LightGBM que no se optimizan
#   * max_bin = 31 , Alienigenas Ancestrales contruyeron las pirámides y dejaron a la humanidad en un jeroglifico  *max_bin=31*
#   * feature_fraction = 0.5  para poner algo que generalmente no falla
#   * learning_rate = 0.03  para que aprenda lento

# %% [markdown]
# * Parametros que se optimizan en la Bayesian Optimization
#   * num_leaves  [8, 256]
#   * min_data_in_leaf  [8, 8192]

# %%
# paquetes necesarios para la Bayesian Optimization
if(!require("DiceKriging")) install.packages("DiceKriging")
require("DiceKriging")

if(!require("mlrMBO")) install.packages("mlrMBO")
require("mlrMBO")
# Out:
# Loading required package: DiceKriging
#
# Warning message in library(package, lib.loc = lib.loc, character.only = TRUE, logical.return = TRUE, :
# “there is no package called ‘DiceKriging’”
# Installing package into ‘/usr/local/lib/R/site-library’
# (as ‘lib’ is unspecified)
#
# Loading required package: DiceKriging
#
# Loading required package: mlrMBO
#
# Warning message in library(package, lib.loc = lib.loc, character.only = TRUE, logical.return = TRUE, :
# “there is no package called ‘mlrMBO’”
# Installing package into ‘/usr/local/lib/R/site-library’
# (as ‘lib’ is unspecified)
#
# also installing the dependencies ‘XML’, ‘fastmatch’, ‘RcppArmadillo’, ‘mlr’, ‘ParamHelpers’, ‘smoof’, ‘BBmisc’, ‘checkmate’, ‘lhs’, ‘parallelMap’
#
#
# Loading required package: mlrMBO
#
# Loading required package: mlr
#
# Loading required package: ParamHelpers
#
#
# Attaching package: ‘ParamHelpers’
#
#
# The following object is masked from ‘package:R.utils’:
#
#     isVector
#
#
#
# Attaching package: ‘mlr’
#
#
# The following objects are masked from ‘package:R.utils’:
#
#     resample, setThreshold
#
#
# Loading required package: smoof
#
# Loading required package: checkmate
#
#
# Attaching package: ‘checkmate’
#
#
# The following object is masked from ‘package:DiceKriging’:
#
#     checkNames
#
#
# The following object is masked from ‘package:R.utils’:
#
#     asInt
#
#
#
# Attaching package: ‘smoof’
#
#
# The following objects are masked from ‘package:R.oo’:
#
#     getDescription, getName

# %% [markdown]
# Definición de la Bayesian Optimization
# <br> Si se desea optimizar un hiperparámetro que esta como fijo, debe QUITARSE de param_fijos y agregarse a PARAM$hipeparametertuning$hs

# %%
# valor ridiculamente bajo para que corra rapido en el aula y no molestar a la *Modalidad Gerencial*
PARAM$hipeparametertuning$num_interations <- 100

# parametros fijos del LightGBM
PARAM$lgbm$param_fijos <- list(
  objective= "binary",
  metric= "auc",
  first_metric_only= TRUE,
  boost_from_average= TRUE,
  feature_pre_filter= FALSE,
  verbosity= -100,
  force_row_wise= TRUE, # para evitar warning
  max_bin= 31,
  top_k= 20,
  min_data_in_bin= 3,
  seed= PARAM$semilla_primigenia
  # learning_rate= 0.03,
  # feature_fraction= 0.5,
  # num_iterations= 2048,  # valor grande, lo limita early_stopping_rounds
  # early_stopping_rounds= 200
)

PARAM$hipeparametertuning$hs <- makeParamSet(
  # Núcleo del modelo (estructura de árboles)
  makeIntegerParam("num_leaves", lower = 2L, upper = 63L),
  makeIntegerParam("max_depth", lower = 3L, upper = 30L),
  makeNumericParam("min_child_weight", lower = 0.001, upper = 10.0),
  makeIntegerParam("min_data_in_leaf", lower = 2L, upper = 8192L),
  makeNumericParam("min_gain_to_split", lower = 0.0, upper = 0.1),

  # Regularización
  makeNumericParam("lambda_l1", lower = 0.0, upper = 0.5),
  makeNumericParam("lambda_l2", lower = 0.0, upper = 0.5),
  makeNumericParam("scale_pos_weight", lower = 1.0, upper = 5.0),  # útil en desequilibrio

  # Control del aprendizaje
  makeNumericParam("learning_rate", lower = 0.005, upper = 0.1),
  makeIntegerParam("num_iterations", lower = 100L, upper = 5000L),
  makeIntegerParam("early_stopping_rounds", lower = 50L, upper = 500L),

  # Submuestreo
  makeNumericParam("feature_fraction", lower = 0.3, upper = 0.8),   # columnas
  makeNumericParam("bagging_fraction", lower = 0.5, upper = 0.9),   # filas
  makeIntegerParam("bagging_freq", lower = 1L, upper = 5L),         # cada N iteraciones

  # Opcionales útiles
  makeNumericParam("max_delta_step", lower = 0.0, upper = 10.0),
  makeNumericParam("path_smooth", lower = 0.0, upper = 10.0)
)
# Total: 16 hT

# %% [markdown]
# Función "señora caja negra"  que es llamada para verificar la realidad por la Bayesian Optimization

# %%
# En  x llegan los parmaetros de la bayesiana
#  devuelve la AUC en validate del modelo entrenado
#  en el parametro x llegan los hiperparámetros que se estan optimizando

EstimarGanancia_AUC_lightgbm <- function(x) {

  # x pisa (o agrega) a param_fijos
  param_completo <- modifyList(PARAM$lgbm$param_fijos, x)

  # entreno LightGBM
  modelo_train <- lgb.train(
    data= dtrain,
    valids= list(valid = dvalidate),
    eval= "auc",
    param= param_completo,
    verbose= -100
  )

  # recupero la AUC en validation
  AUC <- modelo_train$record_evals$valid$auc$eval[[modelo_train$best_iter]]

  # esta es la forma de devolver un parametro extra
  attr(AUC, "extras") <- list("num_iterations"= modelo_train$best_iter)

  # hago espacio en la memoria
  rm(modelo_train)
  gc(full= TRUE, verbose= FALSE)

  message(format(Sys.time(), "%a %b %d %X %Y"), " AUC ", AUC)

  return(AUC)
}

# %% [markdown]
# seteo de la Bayesian Optimization (complejo)
# <br> copiado y pegado de la documentación de la librería

# %%
configureMlr(show.learner.output = FALSE)

# configuro la busqueda bayesiana,  los hiperparametros que se van a optimizar
# por favor, no desesperarse por lo complejo
obj.fun <- makeSingleObjectiveFunction(
    fn= EstimarGanancia_AUC_lightgbm, # la funcion que voy a maximizar
    minimize= FALSE, # estoy Maximizando AUC
    noisy= FALSE,
    par.set= PARAM$hipeparametertuning$hs,
    has.simple.signature= FALSE # paso los parametros en una lista
)

# cada 600 segundos guardo el resultado intermedio
ctrl <- makeMBOControl(
    save.on.disk.at.time= 600,
    save.file.path= "HT.RDATA"
)

# indico la cantidad de iteraciones que va a tener la Bayesian Optimization
ctrl <- setMBOControlTermination(
    ctrl,
    iters= PARAM$hipeparametertuning$num_interations  # cantidad de iteraciones inteligentes
)

# defino el método estandar para la creacion de los puntos iniciales
#   los "No Inteligentes"
ctrl <- setMBOControlInfill(ctrl, crit = makeMBOInfillCritEI())

# mas configuraciones
surr.km <- makeLearner(
    "regr.km",
    predict.type= "se",
    covtype= "matern3_2",
    control= list(trace = TRUE)
)

# %% [markdown]
# Corrida de la Bayesian Optimization,  aqui se hace el trabajo pesado
# <br> por favor no se asuste con los warnings que pudieran aparecer
#
# Si corrío a medias y llegó a las iteraciones inteligentes, en el archivo binario HT.RDATA quedó lo ya procesado y es utilizado para retomar la corrida desde lo último que llegó a grabar.

# %%
# inicio la optimizacion bayesiana

if (!file.exists("HT.RDATA")) {
  bayesiana_salida <- mbo(obj.fun, learner= surr.km, control= ctrl)
} else {
  bayesiana_salida <- mboContinue("HT.RDATA") # retomo en caso que ya exista
}
# Out:
# Computing y column(s) for design. Not provided.
#
# Mon Nov 17 09:40:32 PM 2025 AUC 0.919259493386321
#
# Mon Nov 17 09:44:01 PM 2025 AUC 0.923777437324223
#
# Mon Nov 17 09:47:49 PM 2025 AUC 0.926675766305701
#
# Mon Nov 17 09:48:59 PM 2025 AUC 0.916750717536065
#
# Mon Nov 17 09:51:29 PM 2025 AUC 0.926814341192174
#
# Mon Nov 17 09:53:16 PM 2025 AUC 0.919172926023827
#
# Mon Nov 17 09:58:06 PM 2025 AUC 0.925829218028291
#
# Mon Nov 17 10:00:47 PM 2025 AUC 0.917562034910134
#
# Mon Nov 17 10:01:59 PM 2025 AUC 0.922314851536973
#
# Mon Nov 17 10:05:26 PM 2025 AUC 0.924488094974463
#
# Mon Nov 17 10:08:13 PM 2025 AUC 0.924690085486948
#
# Mon Nov 17 10:10:59 PM 2025 AUC 0.921106934851014
#
# Mon Nov 17 10:12:02 PM 2025 AUC 0.921975963800079
#
# Mon Nov 17 10:13:15 PM 2025 AUC 0.91565017122219
#
# Mon Nov 17 10:15:27 PM 2025 AUC 0.926090262245423
#
# Mon Nov 17 10:21:21 PM 2025 AUC 0.923855616376398
#
# Mon Nov 17 10:21:29 PM 2025 AUC 0.913116230440977
#
# Mon Nov 17 10:23:15 PM 2025 AUC 0.924387435250633
#
# Mon Nov 17 10:26:43 PM 2025 AUC 0.923567394033831
#
# Mon Nov 17 10:28:42 PM 2025 AUC 0.922406451885659
#
# Mon Nov 17 10:30:50 PM 2025 AUC 0.921913219238892
#
# Mon Nov 17 10:31:20 PM 2025 AUC 0.920384198033914
#
# Mon Nov 17 10:33:24 PM 2025 AUC 0.91580418059965
#
# Mon Nov 17 10:34:00 PM 2025 AUC 0.920020816430888
#
# Mon Nov 17 10:35:37 PM 2025 AUC 0.922305792161829
#
# Mon Nov 17 10:38:37 PM 2025 AUC 0.923492234773371
#
# Mon Nov 17 10:40:42 PM 2025 AUC 0.931200085359446
#
# Mon Nov 17 10:45:03 PM 2025 AUC 0.928089364360687
#
# Mon Nov 17 10:47:31 PM 2025 AUC 0.93319449002093
#
# Mon Nov 17 10:50:15 PM 2025 AUC 0.919157827065252
#
# Mon Nov 17 10:51:54 PM 2025 AUC 0.921161962166707
#
# Mon Nov 17 10:53:28 PM 2025 AUC 0.924447495552518
#
# Mon Nov 17 10:54:38 PM 2025 AUC 0.926590876605271
#
# Mon Nov 17 10:58:35 PM 2025 AUC 0.918479044994226
#
# Mon Nov 17 11:00:39 PM 2025 AUC 0.918278396611391
#
# Mon Nov 17 11:03:36 PM 2025 AUC 0.915887392638016
#
# Mon Nov 17 11:05:07 PM 2025 AUC 0.927549157176132
#
# Mon Nov 17 11:05:56 PM 2025 AUC 0.915616282448501
#
# Mon Nov 17 11:07:23 PM 2025 AUC 0.921891074099649
#
# Mon Nov 17 11:08:54 PM 2025 AUC 0.915959867639174
#
# Mon Nov 17 11:10:06 PM 2025 AUC 0.910662817438827
#
# Mon Nov 17 11:20:26 PM 2025 AUC 0.929882785106924
#
# Mon Nov 17 11:22:13 PM 2025 AUC 0.919923847563598
#
# Mon Nov 17 11:22:55 PM 2025 AUC 0.917277503424108
#
# Mon Nov 17 11:23:16 PM 2025 AUC 0.916197089055
#
# Mon Nov 17 11:27:12 PM 2025 AUC 0.922357128620982
#
# Mon Nov 17 11:29:12 PM 2025 AUC 0.911642236551693
#
# Mon Nov 17 11:33:34 PM 2025 AUC 0.924366632241041
#
# Mon Nov 17 11:36:42 PM 2025 AUC 0.934516823259644
#
# Mon Nov 17 11:38:41 PM 2025 AUC 0.920950912279077
#
# Mon Nov 17 11:44:23 PM 2025 AUC 0.920172477081459
#
# Mon Nov 17 11:46:06 PM 2025 AUC 0.922954376315706
#
# Mon Nov 17 11:46:30 PM 2025 AUC 0.90812719899555
#
# Mon Nov 17 11:47:15 PM 2025 AUC 0.914868716232857
#
# Mon Nov 17 11:49:38 PM 2025 AUC 0.921534403144878
#
# Mon Nov 17 11:50:27 PM 2025 AUC 0.915405232560871
#
# Mon Nov 17 11:51:03 PM 2025 AUC 0.875700507794754
#
# Mon Nov 17 11:52:33 PM 2025 AUC 0.915926314397897
#
# Mon Nov 17 11:53:41 PM 2025 AUC 0.923236894607256
#
# Mon Nov 17 11:55:08 PM 2025 AUC 0.92005134988045
#
# Mon Nov 17 11:55:41 PM 2025 AUC 0.915368659527879
#
# Mon Nov 17 11:57:41 PM 2025 AUC 0.917384538263781
#
# Mon Nov 17 11:58:12 PM 2025 AUC 0.921668280577572
#
# Tue Nov 18 12:02:06 AM 2025 AUC 0.927080082863085
#
# [mbo] 0: num_leaves=3; max_depth=26; min_child_weight=7.66; min_data_in_leaf=5918; min_gain_to_split=0.0394; lambda_l1=0.434; lambda_l2=0.267; scale_pos_weight=3.65; learning_rate=0.0618; num_iterations=2763; early_stopping_rounds=328; feature_fraction=0.6; bagging_fraction=0.85; bagging_freq=3; max_delta_step=4.21; path_smooth=7.9 : y = 0.919 : 195.6 secs : initdesign
#
# [mbo] 0: num_leaves=40; max_depth=25; min_child_weight=5.84; min_data_in_leaf=3942; min_gain_to_split=0.0322; lambda_l1=0.277; lambda_l2=0.359; scale_pos_weight=3.28; learning_rate=0.0715; num_iterations=2052; early_stopping_rounds=204; feature_fraction=0.579; bagging_fraction=0.653; bagging_freq=4; max_delta_step=3.6; path_smooth=3.48 : y = 0.924 : 208.9 secs : initdesign
#
# [mbo] 0: num_leaves=28; max_depth=12; min_child_weight=7.42; min_data_in_leaf=1402; min_gain_to_split=0.0532; lambda_l1=0.314; lambda_l2=0.387; scale_pos_weight=1.27; learning_rate=0.0286; num_iterations=2642; early_stopping_rounds=209; feature_fraction=0.537; bagging_fraction=0.663; bagging_freq=2; max_delta_step=3.39; path_smooth=3.08 : y = 0.927 : 228.6 secs : initdesign
#
# [mbo] 0: num_leaves=15; max_depth=6; min_child_weight=2.85; min_data_in_leaf=4233; min_gain_to_split=0.0311; lambda_l1=0.229; lambda_l2=0.168; scale_pos_weight=2.82; learning_rate=0.0511; num_iterations=3107; early_stopping_rounds=156; feature_fraction=0.418; bagging_fraction=0.636; bagging_freq=2; max_delta_step=3.88; path_smooth=3.24 : y = 0.917 : 70.2 secs : initdesign
#
# [mbo] 0: num_leaves=44; max_depth=22; min_child_weight=4.86; min_data_in_leaf=5474; min_gain_to_split=0.0445; lambda_l1=0.35; lambda_l2=0.237; scale_pos_weight=3.41; learning_rate=0.0883; num_iterations=4379; early_stopping_rounds=249; feature_fraction=0.431; bagging_fraction=0.692; bagging_freq=3; max_delta_step=1.49; path_smooth=6.1 : y = 0.927 : 149.8 secs : initdesign
#
# [mbo] 0: num_leaves=17; max_depth=14; min_child_weight=1.4; min_data_in_leaf=4174; min_gain_to_split=0.0785; lambda_l1=0.401; lambda_l2=0.189; scale_pos_weight=2.75; learning_rate=0.042; num_iterations=2937; early_stopping_rounds=218; feature_fraction=0.556; bagging_fraction=0.606; bagging_freq=4; max_delta_step=6.84; path_smooth=8.08 : y = 0.919 : 106.3 secs : initdesign
#
# [mbo] 0: num_leaves=29; max_depth=16; min_child_weight=4.05; min_data_in_leaf=4967; min_gain_to_split=0.0475; lambda_l1=0.252; lambda_l2=0.207; scale_pos_weight=4.74; learning_rate=0.0463; num_iterations=3197; early_stopping_rounds=481; feature_fraction=0.489; bagging_fraction=0.837; bagging_freq=2; max_delta_step=3.28; path_smooth=6.53 : y = 0.926 : 290.9 secs : initdesign
#
# [mbo] 0: num_leaves=8; max_depth=19; min_child_weight=7.94; min_data_in_leaf=5074; min_gain_to_split=0.0213; lambda_l1=0.301; lambda_l2=0.4; scale_pos_weight=2.89; learning_rate=0.0811; num_iterations=4195; early_stopping_rounds=230; feature_fraction=0.503; bagging_fraction=0.899; bagging_freq=3; max_delta_step=0.667; path_smooth=4.34 : y = 0.918 : 160.4 secs : initdesign
#
# [mbo] 0: num_leaves=54; max_depth=14; min_child_weight=4.24; min_data_in_leaf=5832; min_gain_to_split=0.0687; lambda_l1=0.327; lambda_l2=0.305; scale_pos_weight=3.56; learning_rate=0.0478; num_iterations=905; early_stopping_rounds=57; feature_fraction=0.407; bagging_fraction=0.615; bagging_freq=5; max_delta_step=4.33; path_smooth=9.69 : y = 0.922 : 71.9 secs : initdesign
#
# [mbo] 0: num_leaves=39; max_depth=25; min_child_weight=1.6; min_data_in_leaf=420; min_gain_to_split=0.088; lambda_l1=0.244; lambda_l2=0.185; scale_pos_weight=3.78; learning_rate=0.0442; num_iterations=4435; early_stopping_rounds=279; feature_fraction=0.545; bagging_fraction=0.623; bagging_freq=1; max_delta_step=7.42; path_smooth=4.39 : y = 0.924 : 207.6 secs : initdesign
#
# [mbo] 0: num_leaves=55; max_depth=26; min_child_weight=5.16; min_data_in_leaf=2842; min_gain_to_split=0.0526; lambda_l1=0.452; lambda_l2=0.252; scale_pos_weight=2.38; learning_rate=0.0118; num_iterations=4473; early_stopping_rounds=111; feature_fraction=0.569; bagging_fraction=0.876; bagging_freq=3; max_delta_step=6.21; path_smooth=9.29 : y = 0.925 : 166.8 secs : initdesign
#
# [mbo] 0: num_leaves=22; max_depth=15; min_child_weight=5.32; min_data_in_leaf=7829; min_gain_to_split=0.02; lambda_l1=0.151; lambda_l2=0.082; scale_pos_weight=2.98; learning_rate=0.092; num_iterations=1390; early_stopping_rounds=300; feature_fraction=0.391; bagging_fraction=0.607; bagging_freq=4; max_delta_step=6; path_smooth=3.82 : y = 0.921 : 165.3 secs : initdesign
#
# [mbo] 0: num_leaves=21; max_depth=12; min_child_weight=2.03; min_data_in_leaf=5265; min_gain_to_split=0.0753; lambda_l1=0.138; lambda_l2=0.244; scale_pos_weight=3.81; learning_rate=0.0538; num_iterations=838; early_stopping_rounds=432; feature_fraction=0.761; bagging_fraction=0.574; bagging_freq=1; max_delta_step=5.36; path_smooth=2.27 : y = 0.922 : 63.5 secs : initdesign
#
# [mbo] 0: num_leaves=6; max_depth=13; min_child_weight=2.75; min_data_in_leaf=3437; min_gain_to_split=0.0142; lambda_l1=0.479; lambda_l2=0.378; scale_pos_weight=3.22; learning_rate=0.0158; num_iterations=3047; early_stopping_rounds=359; feature_fraction=0.635; bagging_fraction=0.563; bagging_freq=3; max_delta_step=3.94; path_smooth=5.58 : y = 0.916 : 73.2 secs : initdesign
#
# [mbo] 0: num_leaves=35; max_depth=7; min_child_weight=1.52; min_data_in_leaf=3011; min_gain_to_split=0.0373; lambda_l1=0.329; lambda_l2=0.335; scale_pos_weight=1.13; learning_rate=0.0647; num_iterations=1476; early_stopping_rounds=362; feature_fraction=0.702; bagging_fraction=0.726; bagging_freq=2; max_delta_step=9.91; path_smooth=1.23 : y = 0.926 : 131.8 secs : initdesign
#
# [mbo] 0: num_leaves=46; max_depth=29; min_child_weight=3.42; min_data_in_leaf=5654; min_gain_to_split=0.0643; lambda_l1=0.192; lambda_l2=0.445; scale_pos_weight=2.36; learning_rate=0.0372; num_iterations=2384; early_stopping_rounds=337; feature_fraction=0.477; bagging_fraction=0.81; bagging_freq=4; max_delta_step=5.18; path_smooth=0.479 : y = 0.924 : 353.7 secs : initdesign
#
# [mbo] 0: num_leaves=23; max_depth=9; min_child_weight=9.89; min_data_in_leaf=1723; min_gain_to_split=0.012; lambda_l1=0.458; lambda_l2=0.474; scale_pos_weight=3.96; learning_rate=0.072; num_iterations=108; early_stopping_rounds=165; feature_fraction=0.641; bagging_fraction=0.64; bagging_freq=1; max_delta_step=2.47; path_smooth=4.9 : y = 0.913 : 7.9 secs : initdesign
#
# [mbo] 0: num_leaves=47; max_depth=10; min_child_weight=7.53; min_data_in_leaf=1956; min_gain_to_split=0.0973; lambda_l1=0.362; lambda_l2=0.157; scale_pos_weight=2.47; learning_rate=0.0734; num_iterations=786; early_stopping_rounds=290; feature_fraction=0.338; bagging_fraction=0.857; bagging_freq=3; max_delta_step=2.84; path_smooth=7.53 : y = 0.924 : 106.0 secs : initdesign
#
# [mbo] 0: num_leaves=63; max_depth=21; min_child_weight=5.26; min_data_in_leaf=3589; min_gain_to_split=0.0557; lambda_l1=0.422; lambda_l2=0.113; scale_pos_weight=3.91; learning_rate=0.0202; num_iterations=3545; early_stopping_rounds=260; feature_fraction=0.364; bagging_fraction=0.536; bagging_freq=4; max_delta_step=6.46; path_smooth=6.33 : y = 0.924 : 208.1 secs : initdesign
#
# [mbo] 0: num_leaves=12; max_depth=10; min_child_weight=8.83; min_data_in_leaf=1110; min_gain_to_split=0.0489; lambda_l1=0.169; lambda_l2=0.497; scale_pos_weight=3.32; learning_rate=0.0495; num_iterations=3965; early_stopping_rounds=265; feature_fraction=0.687; bagging_fraction=0.825; bagging_freq=3; max_delta_step=8.25; path_smooth=0.365 : y = 0.922 : 118.8 secs : initdesign
#
# [mbo] 0: num_leaves=24; max_depth=4; min_child_weight=6.82; min_data_in_leaf=5162; min_gain_to_split=0.0502; lambda_l1=0.342; lambda_l2=0.434; scale_pos_weight=4.05; learning_rate=0.0998; num_iterations=2274; early_stopping_rounds=236; feature_fraction=0.397; bagging_fraction=0.715; bagging_freq=4; max_delta_step=9.83; path_smooth=4.03 : y = 0.922 : 128.0 secs : initdesign
#
# [mbo] 0: num_leaves=31; max_depth=19; min_child_weight=1.77; min_data_in_leaf=1546; min_gain_to_split=0.0851; lambda_l1=0.0278; lambda_l2=0.0674; scale_pos_weight=2.22; learning_rate=0.0854; num_iterations=186; early_stopping_rounds=429; feature_fraction=0.468; bagging_fraction=0.883; bagging_freq=3; max_delta_step=7.83; path_smooth=1.27 : y = 0.92 : 30.7 secs : initdesign
#
# [mbo] 0: num_leaves=57; max_depth=5; min_child_weight=2.54; min_data_in_leaf=6799; min_gain_to_split=0.0164; lambda_l1=0.208; lambda_l2=0.15; scale_pos_weight=1.19; learning_rate=0.0389; num_iterations=4858; early_stopping_rounds=268; feature_fraction=0.453; bagging_fraction=0.628; bagging_freq=4; max_delta_step=8.94; path_smooth=7.12 : y = 0.916 : 123.6 secs : initdesign
#
# [mbo] 0: num_leaves=43; max_depth=30; min_child_weight=2.28; min_data_in_leaf=4861; min_gain_to_split=0.00309; lambda_l1=0.212; lambda_l2=0.0566; scale_pos_weight=3.72; learning_rate=0.0603; num_iterations=4067; early_stopping_rounds=126; feature_fraction=0.653; bagging_fraction=0.754; bagging_freq=4; max_delta_step=8.74; path_smooth=0.912 : y = 0.92 : 36.0 secs : initdesign
#
# [mbo] 0: num_leaves=26; max_depth=20; min_child_weight=4.19; min_data_in_leaf=581; min_gain_to_split=0.0632; lambda_l1=0.0131; lambda_l2=0.107; scale_pos_weight=1.76; learning_rate=0.0838; num_iterations=4256; early_stopping_rounds=244; feature_fraction=0.59; bagging_fraction=0.659; bagging_freq=4; max_delta_step=3.58; path_smooth=8.89 : y = 0.922 : 96.5 secs : initdesign
#
# [mbo] 0: num_leaves=23; max_depth=30; min_child_weight=6.09; min_data_in_leaf=3756; min_gain_to_split=0.0295; lambda_l1=0.357; lambda_l2=0.264; scale_pos_weight=1.58; learning_rate=0.0585; num_iterations=1709; early_stopping_rounds=377; feature_fraction=0.463; bagging_fraction=0.818; bagging_freq=2; max_delta_step=3.05; path_smooth=6.81 : y = 0.923 : 180.9 secs : initdesign
#
# [mbo] 0: num_leaves=34; max_depth=17; min_child_weight=9.16; min_data_in_leaf=2240; min_gain_to_split=0.071; lambda_l1=0.416; lambda_l2=0.317; scale_pos_weight=4.13; learning_rate=0.0565; num_iterations=3432; early_stopping_rounds=352; feature_fraction=0.779; bagging_fraction=0.511; bagging_freq=3; max_delta_step=7.21; path_smooth=2.07 : y = 0.931 : 124.7 secs : initdesign
#
# [mbo] 0: num_leaves=10; max_depth=9; min_child_weight=3.85; min_data_in_leaf=2805; min_gain_to_split=0.0841; lambda_l1=0.297; lambda_l2=0.457; scale_pos_weight=4.59; learning_rate=0.076; num_iterations=3918; early_stopping_rounds=304; feature_fraction=0.437; bagging_fraction=0.67; bagging_freq=2; max_delta_step=1.32; path_smooth=5.35 : y = 0.928 : 261.0 secs : initdesign
#
# [mbo] 0: num_leaves=30; max_depth=20; min_child_weight=5.72; min_data_in_leaf=277; min_gain_to_split=0.0431; lambda_l1=0.147; lambda_l2=0.0378; scale_pos_weight=2.51; learning_rate=0.0397; num_iterations=2229; early_stopping_rounds=418; feature_fraction=0.742; bagging_fraction=0.806; bagging_freq=1; max_delta_step=1.87; path_smooth=1.75 : y = 0.933 : 148.1 secs : initdesign
#
# [mbo] 0: num_leaves=18; max_depth=6; min_child_weight=8.49; min_data_in_leaf=1912; min_gain_to_split=0.00476; lambda_l1=0.0781; lambda_l2=0.286; scale_pos_weight=3.08; learning_rate=0.0221; num_iterations=1815; early_stopping_rounds=440; feature_fraction=0.612; bagging_fraction=0.684; bagging_freq=5; max_delta_step=0.334; path_smooth=1.08 : y = 0.919 : 163.8 secs : initdesign
#
# [mbo] 0: num_leaves=63; max_depth=25; min_child_weight=9.7; min_data_in_leaf=7367; min_gain_to_split=0.0351; lambda_l1=0.0532; lambda_l2=0.0881; scale_pos_weight=3; learning_rate=0.0781; num_iterations=1659; early_stopping_rounds=385; feature_fraction=0.799; bagging_fraction=0.712; bagging_freq=2; max_delta_step=4.67; path_smooth=3.39 : y = 0.921 : 99.0 secs : initdesign
#
# [mbo] 0: num_leaves=53; max_depth=7; min_child_weight=0.435; min_data_in_leaf=2549; min_gain_to_split=0.0742; lambda_l1=0.123; lambda_l2=0.409; scale_pos_weight=4.92; learning_rate=0.0342; num_iterations=2443; early_stopping_rounds=170; feature_fraction=0.661; bagging_fraction=0.576; bagging_freq=5; max_delta_step=6.64; path_smooth=5.64 : y = 0.924 : 94.5 secs : initdesign
#
# [mbo] 0: num_leaves=49; max_depth=23; min_child_weight=0.938; min_data_in_leaf=3254; min_gain_to_split=0.0568; lambda_l1=0.11; lambda_l2=0.486; scale_pos_weight=1.97; learning_rate=0.0635; num_iterations=3279; early_stopping_rounds=71; feature_fraction=0.754; bagging_fraction=0.785; bagging_freq=3; max_delta_step=9.57; path_smooth=8.97 : y = 0.927 : 69.4 secs : initdesign
#
# [mbo] 0: num_leaves=12; max_depth=13; min_child_weight=3.74; min_data_in_leaf=7432; min_gain_to_split=0.0104; lambda_l1=0.0968; lambda_l2=0.136; scale_pos_weight=2.76; learning_rate=0.0104; num_iterations=2096; early_stopping_rounds=413; feature_fraction=0.319; bagging_fraction=0.788; bagging_freq=2; max_delta_step=5.1; path_smooth=5.27 : y = 0.918 : 237.5 secs : initdesign
#
# [mbo] 0: num_leaves=52; max_depth=10; min_child_weight=6.17; min_data_in_leaf=6294; min_gain_to_split=0.0872; lambda_l1=0.0441; lambda_l2=0.429; scale_pos_weight=1.47; learning_rate=0.0323; num_iterations=3367; early_stopping_rounds=90; feature_fraction=0.562; bagging_fraction=0.593; bagging_freq=3; max_delta_step=2.8; path_smooth=9.97 : y = 0.918 : 124.0 secs : initdesign
#
# [mbo] 0: num_leaves=15; max_depth=28; min_child_weight=3.52; min_data_in_leaf=8058; min_gain_to_split=0.078; lambda_l1=0.226; lambda_l2=0.0727; scale_pos_weight=2.65; learning_rate=0.0183; num_iterations=1513; early_stopping_rounds=138; feature_fraction=0.382; bagging_fraction=0.598; bagging_freq=1; max_delta_step=0.239; path_smooth=5.06 : y = 0.916 : 176.4 secs : initdesign
#
# [mbo] 0: num_leaves=45; max_depth=8; min_child_weight=7.11; min_data_in_leaf=2418; min_gain_to_split=0.0264; lambda_l1=0.288; lambda_l2=0.0524; scale_pos_weight=3.16; learning_rate=0.0432; num_iterations=4129; early_stopping_rounds=54; feature_fraction=0.445; bagging_fraction=0.772; bagging_freq=2; max_delta_step=2.32; path_smooth=7.36 : y = 0.928 : 91.5 secs : initdesign
#
# [mbo] 0: num_leaves=32; max_depth=27; min_child_weight=0.201; min_data_in_leaf=6079; min_gain_to_split=0.0998; lambda_l1=0.467; lambda_l2=0.041; scale_pos_weight=4.56; learning_rate=0.067; num_iterations=454; early_stopping_rounds=466; feature_fraction=0.305; bagging_fraction=0.526; bagging_freq=1; max_delta_step=4.87; path_smooth=6.96 : y = 0.916 : 48.5 secs : initdesign
#
# [mbo] 0: num_leaves=55; max_depth=15; min_child_weight=6.71; min_data_in_leaf=4076; min_gain_to_split=0.0954; lambda_l1=0.0659; lambda_l2=0.198; scale_pos_weight=2.05; learning_rate=0.0947; num_iterations=966; early_stopping_rounds=479; feature_fraction=0.326; bagging_fraction=0.544; bagging_freq=5; max_delta_step=0.935; path_smooth=2.87 : y = 0.922 : 87.2 secs : initdesign
#
# [mbo] 0: num_leaves=10; max_depth=18; min_child_weight=8.61; min_data_in_leaf=7252; min_gain_to_split=0.0671; lambda_l1=0.495; lambda_l2=0.344; scale_pos_weight=1.52; learning_rate=0.0139; num_iterations=3689; early_stopping_rounds=148; feature_fraction=0.649; bagging_fraction=0.705; bagging_freq=4; max_delta_step=4.69; path_smooth=4.09 : y = 0.916 : 90.8 secs : initdesign
#
# [mbo] 0: num_leaves=49; max_depth=22; min_child_weight=6.48; min_data_in_leaf=5544; min_gain_to_split=0.0135; lambda_l1=0.00623; lambda_l2=0.293; scale_pos_weight=1.86; learning_rate=0.00551; num_iterations=691; early_stopping_rounds=93; feature_fraction=0.715; bagging_fraction=0.851; bagging_freq=1; max_delta_step=9.16; path_smooth=2.37 : y = 0.911 : 72.3 secs : initdesign
#
# [mbo] 0: num_leaves=33; max_depth=7; min_child_weight=1.9; min_data_in_leaf=648; min_gain_to_split=0.0605; lambda_l1=0.038; lambda_l2=0.00427; scale_pos_weight=4.5; learning_rate=0.00855; num_iterations=4718; early_stopping_rounds=456; feature_fraction=0.503; bagging_fraction=0.694; bagging_freq=2; max_delta_step=4.46; path_smooth=9.4 : y = 0.93 : 619.8 secs : initdesign
#
# [mbo] 0: num_leaves=38; max_depth=3; min_child_weight=7.21; min_data_in_leaf=2562; min_gain_to_split=0.0272; lambda_l1=0.474; lambda_l2=0.231; scale_pos_weight=3.44; learning_rate=0.027; num_iterations=2495; early_stopping_rounds=399; feature_fraction=0.792; bagging_fraction=0.824; bagging_freq=5; max_delta_step=5.9; path_smooth=8.27 : y = 0.92 : 106.8 secs : initdesign
#
# [mbo] 0: num_leaves=18; max_depth=14; min_child_weight=2.41; min_data_in_leaf=3470; min_gain_to_split=0.0234; lambda_l1=0.177; lambda_l2=0.395; scale_pos_weight=4.28; learning_rate=0.0775; num_iterations=285; early_stopping_rounds=286; feature_fraction=0.525; bagging_fraction=0.562; bagging_freq=1; max_delta_step=7.7; path_smooth=9.08 : y = 0.917 : 41.8 secs : initdesign
#
# [mbo] 0: num_leaves=4; max_depth=22; min_child_weight=8.02; min_data_in_leaf=6423; min_gain_to_split=0.0622; lambda_l1=0.0825; lambda_l2=0.222; scale_pos_weight=2.14; learning_rate=0.0906; num_iterations=1027; early_stopping_rounds=177; feature_fraction=0.708; bagging_fraction=0.522; bagging_freq=5; max_delta_step=9.48; path_smooth=3.71 : y = 0.916 : 21.2 secs : initdesign
#
# [mbo] 0: num_leaves=19; max_depth=20; min_child_weight=0.555; min_data_in_leaf=4723; min_gain_to_split=0.0699; lambda_l1=0.307; lambda_l2=0.275; scale_pos_weight=4.66; learning_rate=0.0249; num_iterations=3821; early_stopping_rounds=129; feature_fraction=0.588; bagging_fraction=0.863; bagging_freq=4; max_delta_step=0.559; path_smooth=8.55 : y = 0.922 : 236.0 secs : initdesign
#
# [mbo] 0: num_leaves=27; max_depth=16; min_child_weight=6.38; min_data_in_leaf=6564; min_gain_to_split=0.0589; lambda_l1=0.0217; lambda_l2=0.361; scale_pos_weight=1.01; learning_rate=0.096; num_iterations=4953; early_stopping_rounds=342; feature_fraction=0.532; bagging_fraction=0.649; bagging_freq=1; max_delta_step=5.7; path_smooth=2.61 : y = 0.912 : 120.5 secs : initdesign
#
# [mbo] 0: num_leaves=56; max_depth=4; min_child_weight=9.63; min_data_in_leaf=3090; min_gain_to_split=0.0334; lambda_l1=0.372; lambda_l2=0.127; scale_pos_weight=1.72; learning_rate=0.0934; num_iterations=4783; early_stopping_rounds=311; feature_fraction=0.512; bagging_fraction=0.893; bagging_freq=5; max_delta_step=9.31; path_smooth=0.274 : y = 0.924 : 261.3 secs : initdesign
#
# [mbo] 0: num_leaves=59; max_depth=29; min_child_weight=4.73; min_data_in_leaf=134; min_gain_to_split=0.0802; lambda_l1=0.127; lambda_l2=0.479; scale_pos_weight=3.59; learning_rate=0.0138; num_iterations=1624; early_stopping_rounds=498; feature_fraction=0.626; bagging_fraction=0.736; bagging_freq=1; max_delta_step=8.55; path_smooth=1.94 : y = 0.935 : 188.5 secs : initdesign
#
# [mbo] 0: num_leaves=14; max_depth=24; min_child_weight=8.32; min_data_in_leaf=6224; min_gain_to_split=0.0181; lambda_l1=0.0906; lambda_l2=0.452; scale_pos_weight=4.42; learning_rate=0.0301; num_iterations=2892; early_stopping_rounds=118; feature_fraction=0.309; bagging_fraction=0.799; bagging_freq=5; max_delta_step=7.63; path_smooth=8.41 : y = 0.921 : 119.0 secs : initdesign
#
# [mbo] 0: num_leaves=58; max_depth=24; min_child_weight=4.59; min_data_in_leaf=6660; min_gain_to_split=0.0927; lambda_l1=0.235; lambda_l2=0.00895; scale_pos_weight=2.59; learning_rate=0.00716; num_iterations=3598; early_stopping_rounds=403; feature_fraction=0.673; bagging_fraction=0.839; bagging_freq=2; max_delta_step=8.33; path_smooth=5.9 : y = 0.92 : 341.6 secs : initdesign
#
# [mbo] 0: num_leaves=36; max_depth=19; min_child_weight=3.21; min_data_in_leaf=7144; min_gain_to_split=0.0825; lambda_l1=0.387; lambda_l2=0.217; scale_pos_weight=1.08; learning_rate=0.087; num_iterations=1208; early_stopping_rounds=393; feature_fraction=0.733; bagging_fraction=0.765; bagging_freq=5; max_delta_step=2.15; path_smooth=7.7 : y = 0.923 : 103.9 secs : initdesign
#
# [mbo] 0: num_leaves=2; max_depth=4; min_child_weight=6.92; min_data_in_leaf=1161; min_gain_to_split=0.024; lambda_l1=0.397; lambda_l2=0.141; scale_pos_weight=1.93; learning_rate=0.0547; num_iterations=489; early_stopping_rounds=70; feature_fraction=0.619; bagging_fraction=0.742; bagging_freq=3; max_delta_step=6.89; path_smooth=1.47 : y = 0.908 : 23.6 secs : initdesign
#
# [mbo] 0: num_leaves=60; max_depth=9; min_child_weight=1.14; min_data_in_leaf=4590; min_gain_to_split=0.0722; lambda_l1=0.0572; lambda_l2=0.326; scale_pos_weight=1.68; learning_rate=0.0184; num_iterations=335; early_stopping_rounds=369; feature_fraction=0.354; bagging_fraction=0.749; bagging_freq=1; max_delta_step=2.5; path_smooth=5.94 : y = 0.915 : 45.0 secs : initdesign
#
# [mbo] 0: num_leaves=6; max_depth=30; min_child_weight=9.46; min_data_in_leaf=794; min_gain_to_split=0.0456; lambda_l1=0.441; lambda_l2=0.0975; scale_pos_weight=4.76; learning_rate=0.0488; num_iterations=1167; early_stopping_rounds=459; feature_fraction=0.482; bagging_fraction=0.776; bagging_freq=4; max_delta_step=5.54; path_smooth=8.74 : y = 0.922 : 143.5 secs : initdesign
#
# [mbo] 0: num_leaves=37; max_depth=11; min_child_weight=4.46; min_data_in_leaf=7805; min_gain_to_split=0.00724; lambda_l1=0.273; lambda_l2=0.0274; scale_pos_weight=4.23; learning_rate=0.0794; num_iterations=4553; early_stopping_rounds=445; feature_fraction=0.775; bagging_fraction=0.552; bagging_freq=3; max_delta_step=8.78; path_smooth=7.23 : y = 0.915 : 48.2 secs : initdesign
#
# [mbo] 0: num_leaves=41; max_depth=28; min_child_weight=3.07; min_data_in_leaf=1510; min_gain_to_split=0.00361; lambda_l1=0.104; lambda_l2=0.122; scale_pos_weight=4.12; learning_rate=0.0229; num_iterations=634; early_stopping_rounds=189; feature_fraction=0.728; bagging_fraction=0.584; bagging_freq=4; max_delta_step=0.0473; path_smooth=4.67 : y = 0.876 : 36.1 secs : initdesign
#
# [mbo] 0: num_leaves=8; max_depth=13; min_child_weight=5.51; min_data_in_leaf=7667; min_gain_to_split=0.00843; lambda_l1=0.377; lambda_l2=0.371; scale_pos_weight=4.35; learning_rate=0.0583; num_iterations=1914; early_stopping_rounds=224; feature_fraction=0.377; bagging_fraction=0.502; bagging_freq=3; max_delta_step=1.03; path_smooth=0.717 : y = 0.916 : 90.0 secs : initdesign
#
# [mbo] 0: num_leaves=42; max_depth=27; min_child_weight=8.25; min_data_in_leaf=76; min_gain_to_split=0.0912; lambda_l1=0.412; lambda_l2=0.417; scale_pos_weight=2.12; learning_rate=0.0697; num_iterations=1981; early_stopping_rounds=192; feature_fraction=0.342; bagging_fraction=0.538; bagging_freq=2; max_delta_step=7.18; path_smooth=4.72 : y = 0.923 : 68.5 secs : initdesign
#
# [mbo] 0: num_leaves=50; max_depth=3; min_child_weight=1.06; min_data_in_leaf=2079; min_gain_to_split=0.0422; lambda_l1=0.486; lambda_l2=0.343; scale_pos_weight=1.37; learning_rate=0.0309; num_iterations=4634; early_stopping_rounds=320; feature_fraction=0.694; bagging_fraction=0.515; bagging_freq=2; max_delta_step=1.14; path_smooth=0.00846 : y = 0.92 : 86.4 secs : initdesign
#
# [mbo] 0: num_leaves=5; max_depth=23; min_child_weight=0.0219; min_data_in_leaf=6969; min_gain_to_split=0.0942; lambda_l1=0.18; lambda_l2=0.175; scale_pos_weight=4.84; learning_rate=0.0825; num_iterations=2810; early_stopping_rounds=99; feature_fraction=0.675; bagging_fraction=0.759; bagging_freq=1; max_delta_step=6.35; path_smooth=2.78 : y = 0.915 : 33.7 secs : initdesign
#
# [mbo] 0: num_leaves=47; max_depth=6; min_child_weight=9.23; min_data_in_leaf=8101; min_gain_to_split=0.0893; lambda_l1=0.197; lambda_l2=0.0233; scale_pos_weight=2.27; learning_rate=0.0354; num_iterations=1269; early_stopping_rounds=147; feature_fraction=0.414; bagging_fraction=0.874; bagging_freq=5; max_delta_step=1.63; path_smooth=1.64 : y = 0.917 : 119.2 secs : initdesign
#
# [mbo] 0: num_leaves=62; max_depth=18; min_child_weight=8.98; min_data_in_leaf=4481; min_gain_to_split=0.0386; lambda_l1=0.26; lambda_l2=0.466; scale_pos_weight=4.94; learning_rate=0.0975; num_iterations=3701; early_stopping_rounds=84; feature_fraction=0.747; bagging_fraction=0.725; bagging_freq=5; max_delta_step=2.01; path_smooth=9.61 : y = 0.922 : 31.4 secs : initdesign
#
# [mbo] 0: num_leaves=25; max_depth=17; min_child_weight=0.73; min_data_in_leaf=994; min_gain_to_split=0.00133; lambda_l1=0.159; lambda_l2=0.303; scale_pos_weight=1.42; learning_rate=0.0682; num_iterations=2611; early_stopping_rounds=489; feature_fraction=0.361; bagging_fraction=0.677; bagging_freq=5; max_delta_step=7.98; path_smooth=6.67 : y = 0.927 : 233.9 secs : initdesign
#
# Saved the current state after iteration 1 in the file HT.RDATA.
#
# Tue Nov 18 12:03:50 AM 2025 AUC 0.927527347569303
#
# [mbo] 1: num_leaves=45; max_depth=19; min_child_weight=6.03; min_data_in_leaf=157; min_gain_to_split=0.0641; lambda_l1=0.281; lambda_l2=0.404; scale_pos_weight=3.8; learning_rate=0.0632; num_iterations=2615; early_stopping_rounds=440; feature_fraction=0.702; bagging_fraction=0.811; bagging_freq=2; max_delta_step=3.53; path_smooth=1.57 : y = 0.928 : 101.9 secs : infill_ei
#
# Tue Nov 18 12:08:46 AM 2025 AUC 0.929517054777009
#
# [mbo] 2: num_leaves=27; max_depth=25; min_child_weight=3.03; min_data_in_leaf=508; min_gain_to_split=0.0706; lambda_l1=0.106; lambda_l2=0.374; scale_pos_weight=2.84; learning_rate=0.028; num_iterations=1953; early_stopping_rounds=489; feature_fraction=0.557; bagging_fraction=0.706; bagging_freq=1; max_delta_step=3.04; path_smooth=2.14 : y = 0.93 : 294.2 secs : infill_ei
#
# Tue Nov 18 12:12:49 AM 2025 AUC 0.931055135357131
#
# [mbo] 3: num_leaves=37; max_depth=11; min_child_weight=9.56; min_data_in_leaf=413; min_gain_to_split=0.061; lambda_l1=0.117; lambda_l2=0.188; scale_pos_weight=4.19; learning_rate=0.0157; num_iterations=2848; early_stopping_rounds=458; feature_fraction=0.699; bagging_fraction=0.672; bagging_freq=1; max_delta_step=8.28; path_smooth=2.78 : y = 0.931 : 241.6 secs : infill_ei
#
# Saved the current state after iteration 4 in the file HT.RDATA.
#
# Tue Nov 18 12:17:35 AM 2025 AUC 0.932446252740461
#
# [mbo] 4: num_leaves=52; max_depth=28; min_child_weight=4.84; min_data_in_leaf=493; min_gain_to_split=0.073; lambda_l1=0.208; lambda_l2=0.454; scale_pos_weight=3.2; learning_rate=0.0289; num_iterations=1979; early_stopping_rounds=482; feature_fraction=0.46; bagging_fraction=0.713; bagging_freq=2; max_delta_step=9.32; path_smooth=3.13 : y = 0.932 : 283.8 secs : infill_ei
#
# Tue Nov 18 12:19:21 AM 2025 AUC 0.925411144641984
#
# [mbo] 5: num_leaves=49; max_depth=19; min_child_weight=7.64; min_data_in_leaf=240; min_gain_to_split=0.0509; lambda_l1=0.42; lambda_l2=0.0385; scale_pos_weight=1.31; learning_rate=0.0405; num_iterations=2486; early_stopping_rounds=447; feature_fraction=0.64; bagging_fraction=0.743; bagging_freq=1; max_delta_step=7.91; path_smooth=2.27 : y = 0.925 : 104.7 secs : infill_ei
#
# Tue Nov 18 12:22:34 AM 2025 AUC 0.932254328200358
#
# [mbo] 6: num_leaves=31; max_depth=18; min_child_weight=9.21; min_data_in_leaf=1118; min_gain_to_split=0.0495; lambda_l1=0.102; lambda_l2=0.37; scale_pos_weight=4.68; learning_rate=0.0341; num_iterations=1972; early_stopping_rounds=457; feature_fraction=0.71; bagging_fraction=0.774; bagging_freq=1; max_delta_step=5.16; path_smooth=2.68 : y = 0.932 : 191.5 secs : infill_ei
#
# Tue Nov 18 12:24:15 AM 2025 AUC 0.932664013276347
#
# [mbo] 7: num_leaves=41; max_depth=22; min_child_weight=2.17; min_data_in_leaf=291; min_gain_to_split=0.0468; lambda_l1=0.131; lambda_l2=0.0654; scale_pos_weight=2.78; learning_rate=0.046; num_iterations=3602; early_stopping_rounds=458; feature_fraction=0.724; bagging_fraction=0.768; bagging_freq=2; max_delta_step=8.12; path_smooth=4.16 : y = 0.933 : 99.6 secs : infill_ei
#
# Saved the current state after iteration 8 in the file HT.RDATA.
#
# Tue Nov 18 12:27:23 AM 2025 AUC 0.930487078982317
#
# [mbo] 8: num_leaves=36; max_depth=21; min_child_weight=7.65; min_data_in_leaf=151; min_gain_to_split=0.0725; lambda_l1=0.234; lambda_l2=0.425; scale_pos_weight=4.81; learning_rate=0.0281; num_iterations=4087; early_stopping_rounds=425; feature_fraction=0.683; bagging_fraction=0.685; bagging_freq=3; max_delta_step=5.19; path_smooth=3.86 : y = 0.93 : 185.3 secs : infill_ei
#
# Tue Nov 18 12:30:58 AM 2025 AUC 0.933388092223097
#
# [mbo] 9: num_leaves=49; max_depth=15; min_child_weight=2.61; min_data_in_leaf=86; min_gain_to_split=0.0743; lambda_l1=0.113; lambda_l2=0.48; scale_pos_weight=3.94; learning_rate=0.0508; num_iterations=1550; early_stopping_rounds=484; feature_fraction=0.555; bagging_fraction=0.75; bagging_freq=1; max_delta_step=9.29; path_smooth=5.57 : y = 0.933 : 213.4 secs : infill_ei
#
# Tue Nov 18 12:33:22 AM 2025 AUC 0.929061401760471
#
# [mbo] 10: num_leaves=37; max_depth=13; min_child_weight=6.05; min_data_in_leaf=1240; min_gain_to_split=0.055; lambda_l1=0.233; lambda_l2=0.226; scale_pos_weight=4.55; learning_rate=0.0601; num_iterations=3731; early_stopping_rounds=381; feature_fraction=0.482; bagging_fraction=0.587; bagging_freq=3; max_delta_step=3.47; path_smooth=3.57 : y = 0.929 : 142.4 secs : infill_ei
#
# Tue Nov 18 12:35:36 AM 2025 AUC 0.929348953038212
#
# [mbo] 11: num_leaves=60; max_depth=20; min_child_weight=3.91; min_data_in_leaf=230; min_gain_to_split=0.0761; lambda_l1=0.137; lambda_l2=0.163; scale_pos_weight=4.09; learning_rate=0.0187; num_iterations=2455; early_stopping_rounds=450; feature_fraction=0.717; bagging_fraction=0.746; bagging_freq=1; max_delta_step=9.6; path_smooth=7.15 : y = 0.929 : 132.3 secs : infill_ei
#
# Saved the current state after iteration 12 in the file HT.RDATA.
#
# Tue Nov 18 12:38:52 AM 2025 AUC 0.932100989887724
#
# [mbo] 12: num_leaves=48; max_depth=12; min_child_weight=3.83; min_data_in_leaf=291; min_gain_to_split=0.0427; lambda_l1=0.1; lambda_l2=0.257; scale_pos_weight=3.05; learning_rate=0.044; num_iterations=2274; early_stopping_rounds=464; feature_fraction=0.425; bagging_fraction=0.706; bagging_freq=1; max_delta_step=4.08; path_smooth=4.41 : y = 0.932 : 194.4 secs : infill_ei
#
# Tue Nov 18 12:42:44 AM 2025 AUC 0.928543004182747
#
# [mbo] 13: num_leaves=38; max_depth=13; min_child_weight=8.72; min_data_in_leaf=2202; min_gain_to_split=0.0578; lambda_l1=0.0859; lambda_l2=0.25; scale_pos_weight=3.03; learning_rate=0.0362; num_iterations=3546; early_stopping_rounds=456; feature_fraction=0.562; bagging_fraction=0.687; bagging_freq=1; max_delta_step=4.3; path_smooth=2.09 : y = 0.929 : 229.8 secs : infill_ei
#
# Tue Nov 18 12:45:26 AM 2025 AUC 0.930132756754435
#
# [mbo] 14: num_leaves=54; max_depth=15; min_child_weight=8.59; min_data_in_leaf=732; min_gain_to_split=0.04; lambda_l1=0.119; lambda_l2=0.00343; scale_pos_weight=3.82; learning_rate=0.0383; num_iterations=3784; early_stopping_rounds=457; feature_fraction=0.709; bagging_fraction=0.884; bagging_freq=1; max_delta_step=3.1; path_smooth=6 : y = 0.93 : 160.2 secs : infill_ei
#
# Tue Nov 18 12:49:00 AM 2025 AUC 0.925892633654304
#
# [mbo] 15: num_leaves=39; max_depth=19; min_child_weight=7.52; min_data_in_leaf=2283; min_gain_to_split=0.0777; lambda_l1=0.308; lambda_l2=0.493; scale_pos_weight=4.91; learning_rate=0.0442; num_iterations=2742; early_stopping_rounds=452; feature_fraction=0.646; bagging_fraction=0.666; bagging_freq=2; max_delta_step=9.5; path_smooth=5.08 : y = 0.926 : 212.4 secs : infill_ei
#
# Saved the current state after iteration 16 in the file HT.RDATA.
#
# Tue Nov 18 12:51:18 AM 2025 AUC 0.933234082845637
#
# [mbo] 16: num_leaves=57; max_depth=19; min_child_weight=7.85; min_data_in_leaf=463; min_gain_to_split=0.0612; lambda_l1=0.101; lambda_l2=0.377; scale_pos_weight=2.44; learning_rate=0.0599; num_iterations=1686; early_stopping_rounds=465; feature_fraction=0.512; bagging_fraction=0.84; bagging_freq=1; max_delta_step=9.05; path_smooth=1.61 : y = 0.933 : 136.0 secs : infill_ei
#
# Tue Nov 18 12:54:42 AM 2025 AUC 0.934625200228967
#
# [mbo] 17: num_leaves=46; max_depth=23; min_child_weight=6.76; min_data_in_leaf=43; min_gain_to_split=0.0492; lambda_l1=0.0483; lambda_l2=0.422; scale_pos_weight=2.96; learning_rate=0.0218; num_iterations=2064; early_stopping_rounds=458; feature_fraction=0.615; bagging_fraction=0.784; bagging_freq=1; max_delta_step=8.88; path_smooth=5.21 : y = 0.935 : 202.3 secs : infill_ei
#
# Tue Nov 18 12:57:59 AM 2025 AUC 0.928330612165466
#
# [mbo] 18: num_leaves=46; max_depth=15; min_child_weight=5.13; min_data_in_leaf=374; min_gain_to_split=0.042; lambda_l1=0.146; lambda_l2=0.262; scale_pos_weight=2.24; learning_rate=0.0435; num_iterations=3602; early_stopping_rounds=461; feature_fraction=0.358; bagging_fraction=0.775; bagging_freq=3; max_delta_step=6.07; path_smooth=7.15 : y = 0.928 : 195.6 secs : infill_ei
#
# Tue Nov 18 01:00:13 AM 2025 AUC 0.93364074812991
#
# [mbo] 19: num_leaves=52; max_depth=19; min_child_weight=4.95; min_data_in_leaf=77; min_gain_to_split=0.0552; lambda_l1=0.084; lambda_l2=0.205; scale_pos_weight=3.81; learning_rate=0.0284; num_iterations=2074; early_stopping_rounds=433; feature_fraction=0.748; bagging_fraction=0.763; bagging_freq=1; max_delta_step=8.82; path_smooth=1.17 : y = 0.934 : 131.3 secs : infill_ei
#
# Saved the current state after iteration 20 in the file HT.RDATA.
#
# Tue Nov 18 01:04:35 AM 2025 AUC 0.928763448977935
#
# [mbo] 20: num_leaves=52; max_depth=19; min_child_weight=1.14; min_data_in_leaf=440; min_gain_to_split=0.0493; lambda_l1=0.101; lambda_l2=0.42; scale_pos_weight=4.18; learning_rate=0.0549; num_iterations=1623; early_stopping_rounds=498; feature_fraction=0.508; bagging_fraction=0.654; bagging_freq=3; max_delta_step=8.23; path_smooth=2.88 : y = 0.929 : 259.7 secs : infill_ei
#
# Tue Nov 18 01:06:57 AM 2025 AUC 0.926377142458339
#
# [mbo] 21: num_leaves=44; max_depth=10; min_child_weight=9.69; min_data_in_leaf=144; min_gain_to_split=0.0753; lambda_l1=0.0746; lambda_l2=0.414; scale_pos_weight=4.82; learning_rate=0.0738; num_iterations=1827; early_stopping_rounds=495; feature_fraction=0.504; bagging_fraction=0.67; bagging_freq=1; max_delta_step=9.78; path_smooth=3.14 : y = 0.926 : 139.9 secs : infill_ei
#
# Tue Nov 18 01:08:36 AM 2025 AUC 0.926342582619824
#
# [mbo] 22: num_leaves=37; max_depth=20; min_child_weight=7.57; min_data_in_leaf=255; min_gain_to_split=0.0424; lambda_l1=0.0845; lambda_l2=0.338; scale_pos_weight=3.21; learning_rate=0.073; num_iterations=2893; early_stopping_rounds=341; feature_fraction=0.714; bagging_fraction=0.816; bagging_freq=1; max_delta_step=8.18; path_smooth=1.71 : y = 0.926 : 97.2 secs : infill_ei
#
# Tue Nov 18 01:13:14 AM 2025 AUC 0.930000556983805
#
# [mbo] 23: num_leaves=38; max_depth=26; min_child_weight=3.26; min_data_in_leaf=121; min_gain_to_split=0.0604; lambda_l1=0.118; lambda_l2=0.477; scale_pos_weight=4.18; learning_rate=0.0103; num_iterations=1774; early_stopping_rounds=486; feature_fraction=0.516; bagging_fraction=0.866; bagging_freq=1; max_delta_step=8.46; path_smooth=3.25 : y = 0.93 : 275.8 secs : infill_ei
#
# Saved the current state after iteration 24 in the file HT.RDATA.
#
# Tue Nov 18 01:15:06 AM 2025 AUC 0.926431163176794
#
# [mbo] 24: num_leaves=59; max_depth=24; min_child_weight=7.56; min_data_in_leaf=312; min_gain_to_split=0.0347; lambda_l1=0.118; lambda_l2=0.3; scale_pos_weight=2.16; learning_rate=0.0442; num_iterations=1947; early_stopping_rounds=458; feature_fraction=0.746; bagging_fraction=0.52; bagging_freq=1; max_delta_step=7.84; path_smooth=4.68 : y = 0.926 : 110.7 secs : infill_ei
#
# Tue Nov 18 01:18:39 AM 2025 AUC 0.929214404540693
#
# [mbo] 25: num_leaves=33; max_depth=22; min_child_weight=4.85; min_data_in_leaf=594; min_gain_to_split=0.0506; lambda_l1=0.0902; lambda_l2=0.255; scale_pos_weight=2.57; learning_rate=0.0202; num_iterations=3704; early_stopping_rounds=443; feature_fraction=0.745; bagging_fraction=0.747; bagging_freq=1; max_delta_step=2.82; path_smooth=3.61 : y = 0.929 : 210.2 secs : infill_ei
#
# Tue Nov 18 01:21:29 AM 2025 AUC 0.934639963655129
#
# [mbo] 26: num_leaves=46; max_depth=21; min_child_weight=5.08; min_data_in_leaf=91; min_gain_to_split=0.0511; lambda_l1=0.0964; lambda_l2=0.407; scale_pos_weight=2.56; learning_rate=0.0398; num_iterations=1902; early_stopping_rounds=470; feature_fraction=0.694; bagging_fraction=0.786; bagging_freq=2; max_delta_step=9.5; path_smooth=1.55 : y = 0.935 : 167.6 secs : infill_ei
#
# Tue Nov 18 01:22:50 AM 2025 AUC 0.928461805338858
#
# [mbo] 27: num_leaves=46; max_depth=17; min_child_weight=6.48; min_data_in_leaf=128; min_gain_to_split=0.0496; lambda_l1=0.0859; lambda_l2=0.26; scale_pos_weight=2.88; learning_rate=0.0653; num_iterations=2019; early_stopping_rounds=458; feature_fraction=0.678; bagging_fraction=0.82; bagging_freq=1; max_delta_step=8.56; path_smooth=6.64 : y = 0.928 : 79.0 secs : infill_ei
#
# Tue Nov 18 01:26:43 AM 2025 AUC 0.932642874734342
#
# [mbo] 28: num_leaves=56; max_depth=16; min_child_weight=7.67; min_data_in_leaf=14; min_gain_to_split=0.0745; lambda_l1=0.045; lambda_l2=0.495; scale_pos_weight=2.06; learning_rate=0.0324; num_iterations=1852; early_stopping_rounds=468; feature_fraction=0.57; bagging_fraction=0.854; bagging_freq=2; max_delta_step=8.83; path_smooth=2.25 : y = 0.933 : 231.4 secs : infill_ei
#
# Saved the current state after iteration 29 in the file HT.RDATA.
#
# Tue Nov 18 01:31:11 AM 2025 AUC 0.930852809312232
#
# [mbo] 29: num_leaves=63; max_depth=18; min_child_weight=9.53; min_data_in_leaf=290; min_gain_to_split=0.0668; lambda_l1=0.102; lambda_l2=0.419; scale_pos_weight=2.27; learning_rate=0.0272; num_iterations=1527; early_stopping_rounds=409; feature_fraction=0.57; bagging_fraction=0.745; bagging_freq=2; max_delta_step=8.91; path_smooth=1.55 : y = 0.931 : 264.8 secs : infill_ei
#
# Tue Nov 18 01:35:38 AM 2025 AUC 0.931865781666375
#
# [mbo] 30: num_leaves=33; max_depth=24; min_child_weight=6.94; min_data_in_leaf=73; min_gain_to_split=0.0441; lambda_l1=0.0842; lambda_l2=0.364; scale_pos_weight=2.9; learning_rate=0.0351; num_iterations=2015; early_stopping_rounds=474; feature_fraction=0.465; bagging_fraction=0.725; bagging_freq=2; max_delta_step=9.27; path_smooth=1.59 : y = 0.932 : 264.7 secs : infill_ei
#
# Tue Nov 18 01:36:29 AM 2025 AUC 0.920142614696722
#
# [mbo] 31: num_leaves=46; max_depth=11; min_child_weight=8.5; min_data_in_leaf=2210; min_gain_to_split=0.0754; lambda_l1=0.346; lambda_l2=0.463; scale_pos_weight=4.86; learning_rate=0.047; num_iterations=3904; early_stopping_rounds=299; feature_fraction=0.625; bagging_fraction=0.541; bagging_freq=5; max_delta_step=3.98; path_smooth=2.7 : y = 0.92 : 49.1 secs : infill_ei
#
# Tue Nov 18 01:39:23 AM 2025 AUC 0.933254885855229
#
# [mbo] 32: num_leaves=51; max_depth=26; min_child_weight=5.23; min_data_in_leaf=13; min_gain_to_split=0.0696; lambda_l1=0.0908; lambda_l2=0.41; scale_pos_weight=3.26; learning_rate=0.0384; num_iterations=1680; early_stopping_rounds=469; feature_fraction=0.657; bagging_fraction=0.849; bagging_freq=1; max_delta_step=9.72; path_smooth=2.93 : y = 0.933 : 171.9 secs : infill_ei
#
# Saved the current state after iteration 33 in the file HT.RDATA.
#
# Tue Nov 18 01:43:52 AM 2025 AUC 0.932034218937584
#
# [mbo] 33: num_leaves=56; max_depth=21; min_child_weight=2.19; min_data_in_leaf=333; min_gain_to_split=0.0595; lambda_l1=0.0879; lambda_l2=0.384; scale_pos_weight=2.37; learning_rate=0.0261; num_iterations=2134; early_stopping_rounds=481; feature_fraction=0.565; bagging_fraction=0.758; bagging_freq=1; max_delta_step=9.16; path_smooth=2.25 : y = 0.932 : 266.9 secs : infill_ei
#
# Tue Nov 18 01:49:59 AM 2025 AUC 0.92567151779429
#
# [mbo] 34: num_leaves=37; max_depth=16; min_child_weight=5.1; min_data_in_leaf=96; min_gain_to_split=0.0497; lambda_l1=0.129; lambda_l2=0.0332; scale_pos_weight=4.9; learning_rate=0.037; num_iterations=3286; early_stopping_rounds=415; feature_fraction=0.569; bagging_fraction=0.766; bagging_freq=1; max_delta_step=6.9; path_smooth=1.21 : y = 0.926 : 364.0 secs : infill_ei
#
# Saved the current state after iteration 35 in the file HT.RDATA.
#
# Tue Nov 18 01:55:39 AM 2025 AUC 0.929020131273701
#
# [mbo] 35: num_leaves=27; max_depth=11; min_child_weight=7.7; min_data_in_leaf=188; min_gain_to_split=0.0466; lambda_l1=0.124; lambda_l2=0.0491; scale_pos_weight=3.05; learning_rate=0.0417; num_iterations=2809; early_stopping_rounds=465; feature_fraction=0.429; bagging_fraction=0.774; bagging_freq=3; max_delta_step=1.91; path_smooth=3.57 : y = 0.929 : 338.0 secs : infill_ei
#
# Tue Nov 18 01:58:20 AM 2025 AUC 0.931526893929481
#
# [mbo] 36: num_leaves=38; max_depth=16; min_child_weight=7.88; min_data_in_leaf=85; min_gain_to_split=0.0528; lambda_l1=0.121; lambda_l2=0.342; scale_pos_weight=1.57; learning_rate=0.0226; num_iterations=1606; early_stopping_rounds=450; feature_fraction=0.644; bagging_fraction=0.765; bagging_freq=2; max_delta_step=5.44; path_smooth=1.31 : y = 0.932 : 158.9 secs : infill_ei
#
# Tue Nov 18 02:00:42 AM 2025 AUC 0.927598815973222
#
# [mbo] 37: num_leaves=36; max_depth=21; min_child_weight=4.86; min_data_in_leaf=726; min_gain_to_split=0.0606; lambda_l1=0.412; lambda_l2=0.373; scale_pos_weight=2.6; learning_rate=0.0658; num_iterations=2498; early_stopping_rounds=339; feature_fraction=0.537; bagging_fraction=0.535; bagging_freq=3; max_delta_step=7.96; path_smooth=4.14 : y = 0.928 : 139.6 secs : infill_ei
#
# Saved the current state after iteration 38 in the file HT.RDATA.
#
# Tue Nov 18 02:03:00 AM 2025 AUC 0.929688511839932
#
# [mbo] 38: num_leaves=54; max_depth=14; min_child_weight=4.19; min_data_in_leaf=168; min_gain_to_split=0.0484; lambda_l1=0.0816; lambda_l2=0.431; scale_pos_weight=3.67; learning_rate=0.0234; num_iterations=2518; early_stopping_rounds=442; feature_fraction=0.748; bagging_fraction=0.771; bagging_freq=2; max_delta_step=5.83; path_smooth=4.56 : y = 0.93 : 135.4 secs : infill_ei
#
# Tue Nov 18 02:04:56 AM 2025 AUC 0.928572531035071
#
# [mbo] 39: num_leaves=51; max_depth=25; min_child_weight=4.68; min_data_in_leaf=2386; min_gain_to_split=0.0598; lambda_l1=0.308; lambda_l2=0.0503; scale_pos_weight=3.99; learning_rate=0.0577; num_iterations=3994; early_stopping_rounds=442; feature_fraction=0.748; bagging_fraction=0.744; bagging_freq=3; max_delta_step=4.13; path_smooth=4.63 : y = 0.929 : 112.9 secs : infill_ei
#
# Tue Nov 18 02:07:43 AM 2025 AUC 0.934584936339435
#
# [mbo] 40: num_leaves=58; max_depth=19; min_child_weight=7.43; min_data_in_leaf=76; min_gain_to_split=0.0551; lambda_l1=0.259; lambda_l2=0.445; scale_pos_weight=2.5; learning_rate=0.0305; num_iterations=1934; early_stopping_rounds=443; feature_fraction=0.702; bagging_fraction=0.804; bagging_freq=1; max_delta_step=2.85; path_smooth=4.08 : y = 0.935 : 164.5 secs : infill_ei
#
# Tue Nov 18 02:09:45 AM 2025 AUC 0.929116093543752
#
# [mbo] 41: num_leaves=53; max_depth=5; min_child_weight=6.23; min_data_in_leaf=82; min_gain_to_split=0.0758; lambda_l1=0.272; lambda_l2=0.462; scale_pos_weight=3.32; learning_rate=0.023; num_iterations=1641; early_stopping_rounds=493; feature_fraction=0.689; bagging_fraction=0.749; bagging_freq=1; max_delta_step=5.73; path_smooth=2.66 : y = 0.929 : 119.7 secs : infill_ei
#
# Tue Nov 18 02:10:59 AM 2025 AUC 0.928316184271717
#
# [mbo] 42: num_leaves=39; max_depth=18; min_child_weight=8.54; min_data_in_leaf=915; min_gain_to_split=0.0607; lambda_l1=0.138; lambda_l2=0.0553; scale_pos_weight=3.21; learning_rate=0.0504; num_iterations=3406; early_stopping_rounds=484; feature_fraction=0.796; bagging_fraction=0.665; bagging_freq=2; max_delta_step=6.48; path_smooth=5.8 : y = 0.928 : 72.3 secs : infill_ei
#
# Saved the current state after iteration 43 in the file HT.RDATA.
#
# Tue Nov 18 02:14:13 AM 2025 AUC 0.930077393906329
#
# [mbo] 43: num_leaves=53; max_depth=27; min_child_weight=7.77; min_data_in_leaf=1231; min_gain_to_split=0.0543; lambda_l1=0.219; lambda_l2=0.435; scale_pos_weight=2.33; learning_rate=0.0348; num_iterations=1918; early_stopping_rounds=444; feature_fraction=0.697; bagging_fraction=0.78; bagging_freq=1; max_delta_step=7.89; path_smooth=1.47 : y = 0.93 : 192.0 secs : infill_ei
#
# Tue Nov 18 02:17:10 AM 2025 AUC 0.922901026662077
#
# [mbo] 44: num_leaves=56; max_depth=18; min_child_weight=6.71; min_data_in_leaf=79; min_gain_to_split=0.0631; lambda_l1=0.0367; lambda_l2=0.459; scale_pos_weight=3.06; learning_rate=0.0332; num_iterations=1762; early_stopping_rounds=479; feature_fraction=0.631; bagging_fraction=0.542; bagging_freq=1; max_delta_step=0.688; path_smooth=4.97 : y = 0.923 : 174.9 secs : infill_ei
#
# Tue Nov 18 02:19:54 AM 2025 AUC 0.932219768361844
#
# [mbo] 45: num_leaves=43; max_depth=18; min_child_weight=6.96; min_data_in_leaf=123; min_gain_to_split=0.0673; lambda_l1=0.31; lambda_l2=0.484; scale_pos_weight=3.08; learning_rate=0.0453; num_iterations=1589; early_stopping_rounds=491; feature_fraction=0.328; bagging_fraction=0.812; bagging_freq=1; max_delta_step=3.35; path_smooth=5.22 : y = 0.932 : 160.9 secs : infill_ei
#
# Tue Nov 18 02:23:46 AM 2025 AUC 0.932162727851673
#
# [mbo] 46: num_leaves=48; max_depth=16; min_child_weight=8.71; min_data_in_leaf=2; min_gain_to_split=0.0444; lambda_l1=0.00532; lambda_l2=0.369; scale_pos_weight=1.48; learning_rate=0.0301; num_iterations=2025; early_stopping_rounds=474; feature_fraction=0.472; bagging_fraction=0.846; bagging_freq=1; max_delta_step=2.96; path_smooth=2.48 : y = 0.932 : 230.2 secs : infill_ei
#
# Saved the current state after iteration 47 in the file HT.RDATA.
#
# Tue Nov 18 02:27:45 AM 2025 AUC 0.932555636307023
#
# ...
#
# Saved the current state after iteration 66 in the file HT.RDATA.
#
# Tue Nov 18 03:32:38 AM 2025 AUC 0.931166196585756
#
# [mbo] 66: num_leaves=53; max_depth=22; min_child_weight=9.27; min_data_in_leaf=57; min_gain_to_split=0.0386; lambda_l1=0.267; lambda_l2=0.263; scale_pos_weight=4.66; learning_rate=0.0211; num_iterations=4281; early_stopping_rounds=382; feature_fraction=0.645; bagging_fraction=0.618; bagging_freq=2; max_delta_step=8.06; path_smooth=5.8 : y = 0.931 : 187.8 secs : infill_ei
#
# Tue Nov 18 03:43:43 AM 2025 AUC 0.934262825223179
#
# [mbo] 67: num_leaves=47; max_depth=15; min_child_weight=9; min_data_in_leaf=199; min_gain_to_split=0.0519; lambda_l1=0.288; lambda_l2=0.128; scale_pos_weight=3.54; learning_rate=0.012; num_iterations=4479; early_stopping_rounds=488; feature_fraction=0.431; bagging_fraction=0.737; bagging_freq=2; max_delta_step=4.82; path_smooth=9.11 : y = 0.934 : 661.1 secs : infill_ei
#
# Saved the current state after iteration 68 in the file HT.RDATA.
#
# Tue Nov 18 03:51:27 AM 2025 AUC 0.932008718474213
#
# [mbo] 68: num_leaves=47; max_depth=19; min_child_weight=9.44; min_data_in_leaf=107; min_gain_to_split=0.0657; lambda_l1=0.271; lambda_l2=0.263; scale_pos_weight=3.45; learning_rate=0.0108; num_iterations=4588; early_stopping_rounds=443; feature_fraction=0.372; bagging_fraction=0.666; bagging_freq=2; max_delta_step=3.71; path_smooth=8.97 : y = 0.932 : 461.7 secs : infill_ei
#
# Tue Nov 18 03:55:05 AM 2025 AUC 0.932223123685971
#
# [mbo] 69: num_leaves=43; max_depth=21; min_child_weight=7.09; min_data_in_leaf=228; min_gain_to_split=0.0378; lambda_l1=0.166; lambda_l2=0.362; scale_pos_weight=4.5; learning_rate=0.0202; num_iterations=2221; early_stopping_rounds=409; feature_fraction=0.734; bagging_fraction=0.701; bagging_freq=2; max_delta_step=6.55; path_smooth=4.94 : y = 0.932 : 215.5 secs : infill_ei
#
# Saved the current state after iteration 70 in the file HT.RDATA.
#
# Tue Nov 18 03:59:55 AM 2025 AUC 0.930927968572692
#
# [mbo] 70: num_leaves=25; max_depth=16; min_child_weight=7.07; min_data_in_leaf=43; min_gain_to_split=0.0651; lambda_l1=0.276; lambda_l2=0.264; scale_pos_weight=4.05; learning_rate=0.0162; num_iterations=4983; early_stopping_rounds=474; feature_fraction=0.71; bagging_fraction=0.739; bagging_freq=1; max_delta_step=2.95; path_smooth=8.79 : y = 0.931 : 286.9 secs : infill_ei
#
# Tue Nov 18 04:00:59 AM 2025 AUC 0.921999786601385
#
# [mbo] 71: num_leaves=41; max_depth=23; min_child_weight=5.55; min_data_in_leaf=2563; min_gain_to_split=0.0568; lambda_l1=0.228; lambda_l2=0.238; scale_pos_weight=2.85; learning_rate=0.0842; num_iterations=3463; early_stopping_rounds=348; feature_fraction=0.654; bagging_fraction=0.506; bagging_freq=2; max_delta_step=9.03; path_smooth=3.45 : y = 0.922 : 60.1 secs : infill_ei
#
# Tue Nov 18 04:03:28 AM 2025 AUC 0.928963090763531
#
# [mbo] 72: num_leaves=51; max_depth=19; min_child_weight=6; min_data_in_leaf=281; min_gain_to_split=0.0365; lambda_l1=0.0943; lambda_l2=0.35; scale_pos_weight=2.02; learning_rate=0.0438; num_iterations=1592; early_stopping_rounds=454; feature_fraction=0.753; bagging_fraction=0.795; bagging_freq=1; max_delta_step=1.57; path_smooth=1.32 : y = 0.929 : 146.7 secs : infill_ei
#
# Tue Nov 18 04:05:58 AM 2025 AUC 0.930839052483309
#
# [mbo] 73: num_leaves=51; max_depth=23; min_child_weight=5.29; min_data_in_leaf=22; min_gain_to_split=0.055; lambda_l1=0.126; lambda_l2=0.361; scale_pos_weight=2.48; learning_rate=0.032; num_iterations=2483; early_stopping_rounds=478; feature_fraction=0.743; bagging_fraction=0.773; bagging_freq=1; max_delta_step=8.83; path_smooth=3.35 : y = 0.931 : 147.4 secs : infill_ei
#
# Saved the current state after iteration 74 in the file HT.RDATA.
#
# Tue Nov 18 04:09:57 AM 2025 AUC 0.932185879588154
#
# [mbo] 74: num_leaves=55; max_depth=16; min_child_weight=4.57; min_data_in_leaf=29; min_gain_to_split=0.0766; lambda_l1=0.0976; lambda_l2=0.391; scale_pos_weight=4.25; learning_rate=0.0136; num_iterations=1840; early_stopping_rounds=429; feature_fraction=0.543; bagging_fraction=0.699; bagging_freq=3; max_delta_step=9.26; path_smooth=1.7 : y = 0.932 : 235.3 secs : infill_ei
#
# Tue Nov 18 04:22:55 AM 2025 AUC 0.932506313042346
#
# [mbo] 75: num_leaves=51; max_depth=17; min_child_weight=7.81; min_data_in_leaf=312; min_gain_to_split=0.0648; lambda_l1=0.393; lambda_l2=0.134; scale_pos_weight=3.73; learning_rate=0.00524; num_iterations=4581; early_stopping_rounds=447; feature_fraction=0.555; bagging_fraction=0.701; bagging_freq=3; max_delta_step=4.91; path_smooth=4.9 : y = 0.933 : 773.8 secs : infill_ei
#
# Saved the current state after iteration 76 in the file HT.RDATA.
#
# Tue Nov 18 04:27:48 AM 2025 AUC 0.934071907280315
#
# [mbo] 76: num_leaves=50; max_depth=18; min_child_weight=7.67; min_data_in_leaf=353; min_gain_to_split=0.0474; lambda_l1=0.158; lambda_l2=0.232; scale_pos_weight=3.97; learning_rate=0.0217; num_iterations=1986; early_stopping_rounds=438; feature_fraction=0.404; bagging_fraction=0.795; bagging_freq=1; max_delta_step=3.42; path_smooth=1.52 : y = 0.934 : 288.8 secs : infill_ei
#
# Tue Nov 18 04:34:14 AM 2025 AUC 0.931275244619906
#
# [mbo] 77: num_leaves=56; max_depth=17; min_child_weight=9.94; min_data_in_leaf=308; min_gain_to_split=0.0797; lambda_l1=0.322; lambda_l2=0.486; scale_pos_weight=4.06; learning_rate=0.0163; num_iterations=3960; early_stopping_rounds=499; feature_fraction=0.41; bagging_fraction=0.781; bagging_freq=1; max_delta_step=1.15; path_smooth=2.11 : y = 0.931 : 381.7 secs : infill_ei
#
# Saved the current state after iteration 78 in the file HT.RDATA.
#
# Tue Nov 18 04:37:54 AM 2025 AUC 0.925704399970742
#
# [mbo] 78: num_leaves=52; max_depth=9; min_child_weight=8.19; min_data_in_leaf=1973; min_gain_to_split=0.0624; lambda_l1=0.358; lambda_l2=0.269; scale_pos_weight=4.61; learning_rate=0.0178; num_iterations=4420; early_stopping_rounds=393; feature_fraction=0.396; bagging_fraction=0.747; bagging_freq=1; max_delta_step=1.38; path_smooth=7.65 : y = 0.926 : 216.2 secs : infill_ei
#
# Tue Nov 18 04:41:03 AM 2025 AUC 0.930791742413109
#
# [mbo] 79: num_leaves=44; max_depth=15; min_child_weight=4.46; min_data_in_leaf=354; min_gain_to_split=0.0662; lambda_l1=0.106; lambda_l2=0.0746; scale_pos_weight=2.83; learning_rate=0.0517; num_iterations=4848; early_stopping_rounds=446; feature_fraction=0.642; bagging_fraction=0.795; bagging_freq=1; max_delta_step=0.704; path_smooth=8.84 : y = 0.931 : 184.8 secs : infill_ei
#
# Tue Nov 18 04:51:53 AM 2025 AUC 0.931427911867714
#
# [mbo] 80: num_leaves=28; max_depth=15; min_child_weight=2.9; min_data_in_leaf=21; min_gain_to_split=0.0421; lambda_l1=0.229; lambda_l2=0.118; scale_pos_weight=2.16; learning_rate=0.0111; num_iterations=4742; early_stopping_rounds=451; feature_fraction=0.457; bagging_fraction=0.714; bagging_freq=2; max_delta_step=4.22; path_smooth=8.23 : y = 0.931 : 644.7 secs : infill_ei
#
# Saved the current state after iteration 81 in the file HT.RDATA.
#
# Tue Nov 18 04:55:02 AM 2025 AUC 0.933245155415258
#
# [mbo] 81: num_leaves=50; max_depth=19; min_child_weight=2.68; min_data_in_leaf=473; min_gain_to_split=0.0493; lambda_l1=0.0763; lambda_l2=0.0777; scale_pos_weight=2.97; learning_rate=0.0206; num_iterations=3738; early_stopping_rounds=402; feature_fraction=0.747; bagging_fraction=0.822; bagging_freq=2; max_delta_step=2.44; path_smooth=8.36 : y = 0.933 : 185.7 secs : infill_ei
#
# Tue Nov 18 04:56:56 AM 2025 AUC 0.92711229397471
#
# [mbo] 82: num_leaves=13; max_depth=19; min_child_weight=4.86; min_data_in_leaf=6; min_gain_to_split=0.0908; lambda_l1=0.074; lambda_l2=0.443; scale_pos_weight=4.23; learning_rate=0.0271; num_iterations=1789; early_stopping_rounds=390; feature_fraction=0.686; bagging_fraction=0.749; bagging_freq=1; max_delta_step=7.99; path_smooth=4.95 : y = 0.927 : 110.2 secs : infill_ei
#
# Tue Nov 18 05:04:08 AM 2025 AUC 0.935626764481076
#
# [mbo] 83: num_leaves=61; max_depth=18; min_child_weight=5.81; min_data_in_leaf=101; min_gain_to_split=0.0413; lambda_l1=0.235; lambda_l2=0.0378; scale_pos_weight=3.41; learning_rate=0.0155; num_iterations=4510; early_stopping_rounds=367; feature_fraction=0.502; bagging_fraction=0.793; bagging_freq=2; max_delta_step=2.47; path_smooth=8.44 : y = 0.936 : 428.0 secs : infill_ei
#
# Saved the current state after iteration 84 in the file HT.RDATA.
#
# Tue Nov 18 05:15:57 AM 2025 AUC 0.930541099700772
#
# [mbo] 84: num_leaves=44; max_depth=22; min_child_weight=8.73; min_data_in_leaf=16; min_gain_to_split=0.0432; lambda_l1=0.171; lambda_l2=0.231; scale_pos_weight=4.19; learning_rate=0.00528; num_iterations=4516; early_stopping_rounds=484; feature_fraction=0.489; bagging_fraction=0.802; bagging_freq=1; max_delta_step=3.34; path_smooth=5.4 : y = 0.931 : 705.5 secs : infill_ei
#
# Saved the current state after iteration 85 in the file HT.RDATA.
#
# Tue Nov 18 05:19:49 AM 2025 AUC 0.932964650318185
#
# [mbo] 85: num_leaves=60; max_depth=16; min_child_weight=7.32; min_data_in_leaf=43; min_gain_to_split=0.0486; lambda_l1=0.413; lambda_l2=0.147; scale_pos_weight=3.69; learning_rate=0.0182; num_iterations=3885; early_stopping_rounds=426; feature_fraction=0.681; bagging_fraction=0.687; bagging_freq=1; max_delta_step=4.18; path_smooth=8.09 : y = 0.933 : 227.6 secs : infill_ei
#
# Tue Nov 18 05:22:38 AM 2025 AUC 0.930521974353244
#
# [mbo] 86: num_leaves=38; max_depth=19; min_child_weight=8; min_data_in_leaf=224; min_gain_to_split=0.0408; lambda_l1=0.304; lambda_l2=0.0561; scale_pos_weight=2.97; learning_rate=0.0296; num_iterations=4398; early_stopping_rounds=352; feature_fraction=0.757; bagging_fraction=0.819; bagging_freq=2; max_delta_step=2.3; path_smooth=7.95 : y = 0.931 : 164.5 secs : infill_ei
#
# Tue Nov 18 05:34:49 AM 2025 AUC 0.929489205586749
#
# [mbo] 87: num_leaves=30; max_depth=17; min_child_weight=9.7; min_data_in_leaf=178; min_gain_to_split=0.0507; lambda_l1=0.165; lambda_l2=0.261; scale_pos_weight=4.14; learning_rate=0.00694; num_iterations=4872; early_stopping_rounds=360; feature_fraction=0.517; bagging_fraction=0.691; bagging_freq=2; max_delta_step=3.73; path_smooth=3.36 : y = 0.929 : 726.9 secs : infill_ei
#
# Saved the current state after iteration 88 in the file HT.RDATA.
#
# Tue Nov 18 05:36:15 AM 2025 AUC 0.920398625927663
#
# [mbo] 88: num_leaves=43; max_depth=17; min_child_weight=8.96; min_data_in_leaf=2910; min_gain_to_split=0.0658; lambda_l1=0.447; lambda_l2=0.3; scale_pos_weight=3.95; learning_rate=0.0694; num_iterations=4216; early_stopping_rounds=263; feature_fraction=0.336; bagging_fraction=0.707; bagging_freq=3; max_delta_step=7.41; path_smooth=3.22 : y = 0.92 : 82.9 secs : infill_ei
#
# Tue Nov 18 05:41:00 AM 2025 AUC 0.930625653868789
#
# [mbo] 89: num_leaves=60; max_depth=15; min_child_weight=1.76; min_data_in_leaf=240; min_gain_to_split=0.0705; lambda_l1=0.251; lambda_l2=0.0269; scale_pos_weight=1.58; learning_rate=0.015; num_iterations=4297; early_stopping_rounds=424; feature_fraction=0.54; bagging_fraction=0.784; bagging_freq=2; max_delta_step=2.31; path_smooth=9.02 : y = 0.931 : 280.4 secs : infill_ei
#
# Tue Nov 18 05:47:42 AM 2025 AUC 0.933417283543008
#
# [mbo] 90: num_leaves=56; max_depth=19; min_child_weight=8.57; min_data_in_leaf=114; min_gain_to_split=0.0466; lambda_l1=0.0696; lambda_l2=0.0379; scale_pos_weight=4.02; learning_rate=0.0171; num_iterations=4798; early_stopping_rounds=325; feature_fraction=0.506; bagging_fraction=0.721; bagging_freq=2; max_delta_step=3.29; path_smooth=9.08 : y = 0.933 : 398.5 secs : infill_ei
#
# Saved the current state after iteration 91 in the file HT.RDATA.
#
# Tue Nov 18 05:52:51 AM 2025 AUC 0.93180941222103
#
# [mbo] 91: num_leaves=62; max_depth=23; min_child_weight=6.07; min_data_in_leaf=680; min_gain_to_split=0.0917; lambda_l1=0.21; lambda_l2=0.403; scale_pos_weight=2.51; learning_rate=0.0339; num_iterations=2652; early_stopping_rounds=482; feature_fraction=0.435; bagging_fraction=0.797; bagging_freq=1; max_delta_step=2.17; path_smooth=5.01 : y = 0.932 : 303.7 secs : infill_ei
#
# Tue Nov 18 05:56:43 AM 2025 AUC 0.927622303242115
#
# [mbo] 92: num_leaves=46; max_depth=13; min_child_weight=8.29; min_data_in_leaf=56; min_gain_to_split=0.0553; lambda_l1=0.0272; lambda_l2=0.138; scale_pos_weight=2.04; learning_rate=0.00528; num_iterations=2189; early_stopping_rounds=454; feature_fraction=0.665; bagging_fraction=0.761; bagging_freq=1; max_delta_step=2.29; path_smooth=4.81 : y = 0.928 : 228.6 secs : infill_ei
#
# Tue Nov 18 06:00:13 AM 2025 AUC 0.930354879211687
#
# [mbo] 93: num_leaves=50; max_depth=20; min_child_weight=8.87; min_data_in_leaf=661; min_gain_to_split=0.0487; lambda_l1=0.0222; lambda_l2=0.404; scale_pos_weight=4.12; learning_rate=0.0268; num_iterations=1508; early_stopping_rounds=451; feature_fraction=0.607; bagging_fraction=0.815; bagging_freq=3; max_delta_step=9.75; path_smooth=0.313 : y = 0.93 : 206.6 secs : infill_ei
#
# Saved the current state after iteration 94 in the file HT.RDATA.
#
# Tue Nov 18 06:03:06 AM 2025 AUC 0.93162017194023
#
# [mbo] 94: num_leaves=62; max_depth=20; min_child_weight=2.94; min_data_in_leaf=88; min_gain_to_split=0.043; lambda_l1=0.232; lambda_l2=0.174; scale_pos_weight=3.77; learning_rate=0.0496; num_iterations=4450; early_stopping_rounds=420; feature_fraction=0.355; bagging_fraction=0.73; bagging_freq=2; max_delta_step=2.07; path_smooth=8.39 : y = 0.932 : 167.7 secs : infill_ei
#
# Tue Nov 18 06:08:47 AM 2025 AUC 0.933405875440973
#
# [mbo] 95: num_leaves=53; max_depth=19; min_child_weight=2.97; min_data_in_leaf=68; min_gain_to_split=0.0514; lambda_l1=0.318; lambda_l2=0.0612; scale_pos_weight=3.78; learning_rate=0.0196; num_iterations=4786; early_stopping_rounds=471; feature_fraction=0.462; bagging_fraction=0.715; bagging_freq=2; max_delta_step=3.33; path_smooth=7.11 : y = 0.933 : 337.3 secs : infill_ei
#
# Tue Nov 18 06:12:07 AM 2025 AUC 0.930168658722601
#
# [mbo] 96: num_leaves=57; max_depth=25; min_child_weight=2.85; min_data_in_leaf=176; min_gain_to_split=0.0464; lambda_l1=0.17; lambda_l2=0.00037; scale_pos_weight=2.85; learning_rate=0.048; num_iterations=3904; early_stopping_rounds=392; feature_fraction=0.601; bagging_fraction=0.832; bagging_freq=1; max_delta_step=2.19; path_smooth=8.73 : y = 0.93 : 196.4 secs : infill_ei
#
# Saved the current state after iteration 97 in the file HT.RDATA.
#
# Tue Nov 18 06:15:46 AM 2025 AUC 0.934639292590304
#
# [mbo] 97: num_leaves=62; max_depth=20; min_child_weight=7.31; min_data_in_leaf=85; min_gain_to_split=0.065; lambda_l1=0.0273; lambda_l2=0.372; scale_pos_weight=3.69; learning_rate=0.0199; num_iterations=1910; early_stopping_rounds=426; feature_fraction=0.479; bagging_fraction=0.81; bagging_freq=1; max_delta_step=4.49; path_smooth=8.41 : y = 0.935 : 213.5 secs : infill_ei
#
# Tue Nov 18 06:21:26 AM 2025 AUC 0.933913200449077
#
# [mbo] 98: num_leaves=62; max_depth=18; min_child_weight=8.66; min_data_in_leaf=289; min_gain_to_split=0.055; lambda_l1=0.279; lambda_l2=0.131; scale_pos_weight=4.09; learning_rate=0.0159; num_iterations=4162; early_stopping_rounds=294; feature_fraction=0.492; bagging_fraction=0.799; bagging_freq=2; max_delta_step=3.03; path_smooth=9.44 : y = 0.934 : 335.4 secs : infill_ei
#
# Tue Nov 18 06:26:39 AM 2025 AUC 0.934210146634375
#
# [mbo] 99: num_leaves=57; max_depth=19; min_child_weight=8.1; min_data_in_leaf=17; min_gain_to_split=0.0552; lambda_l1=0.345; lambda_l2=0.27; scale_pos_weight=3.77; learning_rate=0.0174; num_iterations=3813; early_stopping_rounds=351; feature_fraction=0.553; bagging_fraction=0.717; bagging_freq=2; max_delta_step=1.63; path_smooth=6.74 : y = 0.934 : 308.6 secs : infill_ei
#
# Saved the current state after iteration 100 in the file HT.RDATA.
#
# Tue Nov 18 06:32:17 AM 2025 AUC 0.933826968618996
#
# [mbo] 100: num_leaves=57; max_depth=20; min_child_weight=8.19; min_data_in_leaf=35; min_gain_to_split=0.0762; lambda_l1=0.2; lambda_l2=0.299; scale_pos_weight=4.33; learning_rate=0.021; num_iterations=2033; early_stopping_rounds=500; feature_fraction=0.565; bagging_fraction=0.764; bagging_freq=1; max_delta_step=4.5; path_smooth=4.93 : y = 0.934 : 334.6 secs : infill_ei
#
# Saved the final state in the file HT.RDATA

# %% [markdown]
# la bayesian optimization ha corrido, extraigo los mejores hiperparametros

# %%
# almaceno los resultados de la Bayesian Optimization
# y capturo los mejores hiperparametros encontrados

tb_bayesiana <- as.data.table(bayesiana_salida$opt.path)

# ordeno en forma descendente por AUC = y
setorder(tb_bayesiana, -y, -num_iterations)

# grabo para eventualmente poder utilizarlos en OTRA corrida
fwrite( tb_bayesiana,
  file="BO_log.txt",
  sep="\t"
)

# los mejores hiperparámetros son los que quedaron en el registro 1 de la tabla
PARAM$out$lgbm$mejores_hiperparametros <- tb_bayesiana[
  1, # el primero es el de mejor AUC
  setdiff(colnames(tb_bayesiana),
    c("y","dob","eol","error.message","exec.time","ei","error.model",
      "train.time","prop.type","propose.time","se","mean","iter")),
  with= FALSE
]

print(PARAM$out$lgbm$mejores_hiperparametros)
# Out:
#    num_leaves max_depth min_child_weight min_data_in_leaf min_gain_to_split
#         <int>     <int>            <num>            <int>             <num>
# 1:         61        18         5.814584              101        0.04125749
#    lambda_l1  lambda_l2 scale_pos_weight learning_rate num_iterations
#        <num>      <num>            <num>         <num>          <int>
# 1: 0.2350734 0.03783412         3.408345    0.01548797           4510
#    early_stopping_rounds feature_fraction bagging_fraction bagging_freq
#                    <int>            <num>            <num>        <int>
# 1:                   367        0.5022729        0.7927669            2
#    max_delta_step path_smooth
#             <num>       <num>
# 1:       2.474649    8.441882

# %% [markdown]
# ### 6.3.3 Produccion

# %% [markdown]
# #### Final Training
# Construyo el modelo final, que es uno solo, no hace ningun tipo de particion < training, validation, testing>]

# %% [markdown]
# ##### Final Training Dataset
#
# Aqui esta la gran decision de en qué meses hago el Final Training
# <br> debo utilizar los mejores hiperparámetros que encontré en la optimización bayesiana

# %%
PARAM$trainingstrategy$final_train <- c(
  202105, 202104, 202103, 202102, 202101,
  202012, 202011, 202010, 202009, 202008, 202007,
  202006, 202005
)

dataset[, fold_final_train := foto_mes %in% PARAM$trainingstrategy$final_train ]

# creo el dfinal_train en formato  LightGBM
dfinal_train <- lgb.Dataset(
  data= data.matrix(dataset[fold_final_train == TRUE, campos_buenos, with= FALSE]),
  label= dataset[fold_final_train == TRUE, clase01],
  free_raw_data= TRUE
)

nrow( dfinal_train) # verifico el tamaño
# Out:
# [1] 207504

# %% [markdown]
# ##### Final Training Hyperparameters

# %%
# uno los parametros fijos y los mejores encontrados de los variables
fijos <- copy(PARAM$lgbm$param_fijos)

# quito lo que optimice en la Bayesian Optimization
fijos$num_iterations <- NULL
fijos$early_stopping_rounds <- NULL

# agrego a los hiperparametros fijos los que encontre con la Bayesian Optimization
param_final <- c(fijos, PARAM$out$lgbm$mejores_hiperparametros)

# Para el entrenamiento final, removemos early_stopping_rounds
# ya que se entrena con todos los datos disponibles y la cantidad de iteraciones
# ya está optimizada en 'num_iterations'.
param_final$early_stopping_rounds <- NULL

# %% [markdown]
# ##### Training
# Genero el modelo final, siempre sobre TODOS los datos de  final_train, sin hacer ningun tipo de undersampling de la clase mayoritaria

# %%
final_model <- lgb.train(
  data= dfinal_train,
  param= param_final,
  verbose= -100
)

# %%
# grabo a disco el modelo en un formato para seres humanos ... ponele ...

lgb.save(final_model, "modelo.txt")

# %%
# ahora imprimo la importancia de variables

tb_importancia <- as.data.table(lgb.importance(final_model))
archivo_importancia <- "impo.txt"

fwrite( tb_importancia,
  file= archivo_importancia,
  sep= "\t"
)

# %% [markdown]
# #### Scoring

# %% [markdown]
# Aplico el modelo final a los datos del futuro

# %%
PARAM$trainingstrategy$future <- c(202107)

dfuture <- dataset[ foto_mes %in% PARAM$trainingstrategy$future ]

# %%
# aplico final_model   a dfuture

prediccion <- predict(
  final_model,
  data.matrix(dfuture[, campos_buenos, with= FALSE])
)

# %% [markdown]
# ##### Tabla Prediccion

# %%
tb_prediccion <- dfuture[, list(numero_de_cliente)]
tb_prediccion[, prob := prediccion]

# grabo las probabilidad del modelo
#  me va a ser util para hacer Ensembles de modelos
fwrite(tb_prediccion,
  file= "prediccion.txt",
  sep= "\t"
)

# %% [markdown]
# #### Curva de Ganancia

# %% [markdown]
# Genero las salidas

# %%
# asigno clase ternaria
tb_prediccion[, clase_ternaria := dfuture$clase_ternaria ]

# asigno ganancias
tb_prediccion[, ganancia := -3000.0 ]
tb_prediccion[clase_ternaria=="BAJA+2", ganancia := 117000.0 ]

# reordeno, y acumulada
setorder( tb_prediccion, -prob )
tb_prediccion[, gan_acum := cumsum(ganancia)]

# media movil de ancho 400
tb_prediccion[,
  gan_suavizada := frollmean(
    x= gan_acum,
    n= 400,
    align= "center",
    na.rm= TRUE,
    hasNA= TRUE
  )
]

# %%
tb_prediccion[, sum(!is.na(gan_suavizada) )]
tb_prediccion[, .N]
# Out:
# [1] 16152
# [1] 16551

# %%
# Este es la ganancia a reportar
resultado <- list()
resultado$ganancia_suavizada_max <- max( tb_prediccion$gan_suavizada, na.rm=TRUE )
options(digits= 8)
resultado$envios <- which.max( tb_prediccion$gan_suavizada)
resultado
# Out:
# $ganancia_suavizada_max
# [1] 5769300
#
# $envios
# [1] 1073

# %%
# grabo las ganancias
fwrite( tb_prediccion,
  file= "ganancias.txt",
  sep= "\t"
)

# %%
# genero el grafico

tb_prediccion[, envios:= .I]

pdf("curva_de_ganancia.pdf")

plot(
  x= tb_prediccion$envios,
  y= tb_prediccion$gan_acum,
  type= "l",
  col= "gray",
  xlim= c(0, 6000),
  ylim= c(0, 8000000),
  main= paste0("Mejor gan prom= ", as.integer(resultado$ganancia_suavizada_max), " envios= ", resultado$envios),
  xlab= "Envios",
  ylab= "Ganancia",
  panel.first= grid()
)

dev.off()
# Out:
# agg_record_563316045
#                    2

# %%
# grabo los parametros
if( !require("yaml")) install.packages("yaml")
require("yaml")

PARAM$resultado <- resultado

write_yaml( PARAM, file="PARAM.yml")
# Out:
# Loading required package: yaml

# %%
format(Sys.time(), "%a %b %d %X %Y")
fin <- Sys.time()

# Duración en segundos
secs <- as.numeric(difftime(fin, principio, units = "secs"))
secs <- round(secs)

# A hh:mm:ss
h <- secs %/% 3600
m <- (secs %% 3600) %/% 60
s <- secs %% 60
dur_hms <- sprintf("%02d:%02d:%02d", h, m, s)

cat(
  "Inicio: ", format(principio, "%a %b %d %X %Y"), "\n",
  "Fin:    ", format(fin,       "%a %b %d %X %Y"), "\n",
  "Duración (hh:mm:ss): ", dur_hms, "\n",
  sep = ""
)
# Out:
# [1] "Tue Nov 18 06:46:41 AM 2025"
# Inicio: Mon Nov 17 09:19:15 PM 2025
# Fin:    Tue Nov 18 06:46:41 AM 2025
# Duración (hh:mm:ss): 09:27:26
