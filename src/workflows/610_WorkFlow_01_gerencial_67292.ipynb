# %% [markdown]
# <a href="https://colab.research.google.com/github/jwbarbona/labo2025v/blob/main/src/workflows/610_WorkFlow_01_gerencial_67292.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # 6 WorkFlow

# %% [markdown]
# ### 6.1 Objetivo

# %% [markdown]
# Presentar un workflow/pipeline completo al que los estudiantes deberán enriquecer

# %% [markdown]
# #### 6.2  Seteo del ambiente en Google Colab

# %% [markdown]
# Esta parte se debe correr con el runtime en Python3
# <br>Ir al menu, Runtime -> Change Runtime Type -> Runtime type ->  **Python 3**

# %% [markdown]
# Conectar la virtual machine donde esta corriendo Google Colab con el  Google Drive, para poder tener persistencia de archivos

# %%
# primero establecer el Runtime de Python 3
from google.colab import drive
drive.mount('/content/.drive')
# Out:
# Mounted at /content/.drive

# %% [markdown]
# Para correr la siguiente celda es fundamental en Arranque en Frio haber copiado el archivo kaggle.json al Google Drive, en la carpeta indicada en el instructivo
#
# <br>los siguientes comando estan en shell script de Linux
# *   Crear las carpetas en el Google Drive
# *   "instalar" el archivo kaggle.json desde el Google Drive a la virtual machine para que pueda ser utilizado por la libreria  kaggle de Python
# *   Bajar el  **dataset_pequeno**  al  Google Drive  y tambien al disco local de la virtual machine que esta corriendo Google Colab
# *   Bajar el **dataset_historico** al Google Drive y tambien al disco local de la virtual machine que esta corriendo Google Colab

# %%
%%shell

mkdir -p "/content/.drive/My Drive/labo1"
mkdir -p "/content/buckets"
ln -s "/content/.drive/My Drive/labo1" /content/buckets/b1

mkdir -p ~/.kaggle
cp /content/buckets/b1/kaggle/kaggle.json  ~/.kaggle
chmod 600 ~/.kaggle/kaggle.json


mkdir -p /content/buckets/b1/exp
mkdir -p /content/buckets/b1/datasets
mkdir -p /content/datasets


webfiles="https://storage.googleapis.com/open-courses/austral2025-af91/"
destino_local="/content/datasets"
destino_bucket="/content/buckets/b1/datasets"


archivo="dataset_pequeno.csv"

if ! test -f $destino_bucket/$archivo; then
  wget  $webfiles/$archivo  -O $destino_bucket/$archivo
fi


if ! test -f $destino_local/$pequeno; then
  cp  $destino_bucket/$archivo  $destino_local/$archivo
fi

#-------

archivo="gerencial_competencia_2025.csv.gz"

if ! test -f $destino_bucket/$archivo; then
  wget  $webfiles/$archivo  -O $destino_bucket/$archivo
fi


if ! test -f $destino_local/$pequeno; then
  cp  $destino_bucket/$archivo  $destino_local/$archivo
fi
# Out:
# cp: cannot stat '/content/buckets/b1/kaggle/kaggle.json': No such file or directory
# chmod: cannot access '/root/.kaggle/kaggle.json': No such file or directory

# %% [markdown]
# ## 6.3  Workflow

# %% [markdown]
# ## Inicializacion

# %% [markdown]
# Esta parte se debe correr con el runtime en lenguaje **R** Ir al menu, Runtime -> Change Runtime Type -> Runtime type -> R

# %% [markdown]
# limpio el ambiente de R

# %%
format(Sys.time(), "%a %b %d %X %Y")
# Out:
# [1] "Sun Nov 30 10:11:06 PM 2025"

# %%
# limpio la memoria
rm(list=ls(all.names=TRUE)) # remove all objects
gc(full=TRUE, verbose=FALSE) # garbage collection
# Out:
#        used    (Mb) gc trigger (Mb) max used (Mb)
# Ncells  660442 35.3 1454494    77.7 1437479  76.8
# Vcells 1226661  9.4 8388608    64.0 1975136  15.1

# %%
require("data.table")

if( !require("R.utils")) install.packages("R.utils")
require("R.utils")
# Out:
# Loading required package: data.table
#
# Loading required package: R.utils
#
# Warning message in library(package, lib.loc = lib.loc, character.only = TRUE, logical.return = TRUE, :
# “there is no package called ‘R.utils’”
# Installing package into ‘/usr/local/lib/R/site-library’
# (as ‘lib’ is unspecified)
#
# also installing the dependencies ‘R.oo’, ‘R.methodsS3’
#
#
# Loading required package: R.utils
#
# Loading required package: R.oo
#
# Loading required package: R.methodsS3
#
# R.methodsS3 v1.8.2 (2022-06-13 22:00:14 UTC) successfully loaded. See ?R.methodsS3 for help.
#
# R.oo v1.27.1 (2025-05-02 21:00:05 UTC) successfully loaded. See ?R.oo for help.
#
#
# Attaching package: ‘R.oo’
#
#
# The following object is masked from ‘package:R.methodsS3’:
#
#     throw
#
#
# The following objects are masked from ‘package:methods’:
#
#     getClasses, getMethods
#
#
# The following objects are masked from ‘package:base’:
#
#     attach, detach, load, save
#
#
# R.utils v2.13.0 (2025-02-24 21:20:02 UTC) successfully loaded. See ?R.utils for help.
#
#
# Attaching package: ‘R.utils’
#
#
# The following object is masked from ‘package:utils’:
#
#     timestamp
#
#
# The following objects are masked from ‘package:base’:
#
#     cat, commandArgs, getOption, isOpen, nullfile, parse, use, warnings

# %% [markdown]
# #### Parametros
# Si es gerente, no cambie nada
# <br>Si es Analista, cambie el nombre del dataset

# %%
PARAM <- list()
PARAM$semilla_primigenia <- 200003 # 100009, 200003, 499999, 700009, 999983


PARAM$experimento <- 67292
PARAM$dataset <- "gerencial_competencia_2025.csv.gz"

# %% [markdown]
# #### Carpeta del Experimento

# %%
# carpeta de trabajo

setwd("/content/buckets/b1/exp")
experimento_folder <- paste0("WF", PARAM$experimento)
dir.create(experimento_folder, showWarnings=FALSE)
setwd( paste0("/content/buckets/b1/exp/", experimento_folder ))

# %% [markdown]
# ### 6.3.1   Preprocesamiento del dataset

# %% [markdown]
# #### 6.3.1.1  DT incorporar dataset

# %%
# lectura del dataset
dataset <- fread(paste0("/content/datasets/", PARAM$dataset))

# %% [markdown]
# #### 6.3.1.2  CA  Catastrophe Analysis
# Se intentan reparar las variables que para un mes están con todos los valores en cero.

# %% [markdown]
# El método que se utiliza es **Machine Learning** se asigna NA also valores, si ha leido bien, es la "anti imputación de valores faltantes"
# <br> Usted podrá aplicar aquí otros métodos

# %%
dataset[ foto_mes==202006, internet:=NA]
dataset[ foto_mes==202006, mrentabilidad:=NA]
dataset[ foto_mes==202006, mrentabilidad_annual:=NA]
dataset[ foto_mes==202006, mcomisiones:=NA]
dataset[ foto_mes==202006, mactivos_margen:=NA]
dataset[ foto_mes==202006, mpasivos_margen:=NA]
dataset[ foto_mes==202006, mcuentas_saldo:=NA]
dataset[ foto_mes==202006, ctarjeta_visa_transacciones:=NA]
dataset[ foto_mes==202006, mtarjeta_visa_consumo:=NA]
dataset[ foto_mes==202006, mtarjeta_master_consumo:=NA]
dataset[ foto_mes==202006, ccallcenter_transacciones:=NA]
dataset[ foto_mes==202006, chomebanking_transacciones:=NA]
dataset[ foto_mes==202006, chomebanking_transacciones:=NA]

# %% [markdown]
# #### 6.3.1.3  DR  Data Drifting
# Se intenta corregir el data drifting, quizas ajustando por IPC ...
# <br>Esta parte podrá ser abordada por todos los Analistas y también la Gerenciapero se decide pedagogicamente no incluirla en esta primer version para reducir la carga cognitiva

# %%
# sin codigo en esta primera version del workflow

# %%
# meses que me interesan para el ajuste de variables monetarias
vfoto_mes <- c(
  201901, 201902, 201903, 201904, 201905, 201906,
  201907, 201908, 201909, 201910, 201911, 201912,
  202001, 202002, 202003, 202004, 202005, 202006,
  202007, 202008, 202009, 202010, 202011, 202012,
  202101, 202102, 202103, 202104, 202105, 202106,
  202107, 202108, 202109
)


# los valores que siguen fueron calculados por alumnos

# momento 1.0  31-dic-2020 a las 23:59
vIPC <- c(
  1.9903030878, 1.9174403544, 1.8296186587,
  1.7728862972, 1.7212488323, 1.6776304408,
  1.6431248196, 1.5814483345, 1.4947526791,
  1.4484037589, 1.3913580777, 1.3404220402,
  1.3154288912, 1.2921698342, 1.2472681797,
  1.2300475145, 1.2118694724, 1.1881073259,
  1.1693969743, 1.1375456949, 1.1065619600,
  1.0681100000, 1.0370000000, 1.0000000000,
  0.9680542110, 0.9344152616, 0.8882274350,
  0.8532444140, 0.8251880213, 0.8003763543,
  0.7763107219, 0.7566381305, 0.7289384687
)

vdolar_blue <- c(
   39.045455,  38.402500,  41.639474,
   44.274737,  46.095455,  45.063333,
   43.983333,  54.842857,  61.059524,
   65.545455,  66.750000,  72.368421,
   77.477273,  78.191667,  82.434211,
  101.087500, 126.236842, 125.857143,
  130.782609, 133.400000, 137.954545,
  170.619048, 160.400000, 153.052632,
  157.900000, 149.380952, 143.615385,
  146.250000, 153.550000, 162.000000,
  178.478261, 180.878788, 184.357143
)

vdolar_oficial <- c(
   38.430000,  39.428000,  42.542105,
   44.354211,  46.088636,  44.955000,
   43.751429,  54.650476,  58.790000,
   61.403182,  63.012632,  63.011579,
   62.983636,  63.580556,  65.200000,
   67.872000,  70.047895,  72.520952,
   75.324286,  77.488500,  79.430909,
   83.134762,  85.484737,  88.181667,
   91.474000,  93.997778,  96.635909,
   98.526000,  99.613158, 100.619048,
  101.619048, 102.569048, 103.781818
)

vUVA <- c(
  2.001408838932958,  1.950325472789153,  1.89323032351521,
  1.8247220405493787, 1.746027787673673,  1.6871348409529485,
  1.6361678865622313, 1.5927529755859773, 1.5549162794128493,
  1.4949100586391746, 1.4197729500774545, 1.3678188186372326,
  1.3136508617223726, 1.2690535173062818, 1.2381595983200178,
  1.211656735577568,  1.1770808941405335, 1.1570338657445522,
  1.1388769475653255, 1.1156993751209352, 1.093638313080772,
  1.0657171590878205, 1.0362173587708712, 1.0,
  0.9669867858358365, 0.9323750098728378, 0.8958202912590305,
  0.8631993702994263, 0.8253893405524657, 0.7928918905364516,
  0.7666323845128089, 0.7428976357662823, 0.721615762047849
)


tb_indices <- as.data.table( list(
  "IPC" = vIPC,
  "dolar_blue" = vdolar_blue,
  "dolar_oficial" = vdolar_oficial,
  "UVA" = vUVA
  )
)

tb_indices[[ 'foto_mes' ]] <- vfoto_mes

tb_indices

drift_UVA <- function(campos_monetarios) {
  cat( "inicio drift_UVA()\n")

  dataset[tb_indices,
    on = c("foto_mes"),
    (campos_monetarios) := .SD * i.UVA,
    .SDcols = campos_monetarios
  ]

  cat( "fin drift_UVA()\n")
}


drift_dolar_oficial <- function(campos_monetarios) {
  cat( "inicio drift_dolar_oficial()\n")

  dataset[tb_indices,
    on = c("foto_mes"),
    (campos_monetarios) := .SD / i.dolar_oficial,
    .SDcols = campos_monetarios
  ]

  cat( "fin drift_dolar_oficial()\n")
}


drift_dolar_blue <- function(campos_monetarios) {
  cat( "inicio drift_dolar_blue()\n")

  dataset[tb_indices,
    on = c("foto_mes"),
    (campos_monetarios) := .SD / i.dolar_blue,
    .SDcols = campos_monetarios
  ]

  cat( "fin drift_dolar_blue()\n")
}


drift_deflacion <- function(campos_monetarios) {
  cat( "inicio drift_deflacion()\n")

  dataset[tb_indices,
    on = c("foto_mes"),
    (campos_monetarios) := .SD * i.IPC,
    .SDcols = campos_monetarios
  ]

  cat( "fin drift_deflacion()\n")
}


drift_rank_simple <- function(campos_drift) {

  cat( "inicio drift_rank_simple()\n")
  for (campo in campos_drift)
  {
    cat(campo, " ")
    dataset[, paste0(campo, "_rank") :=
      (frank(get(campo), ties.method = "random") - 1) / (.N - 1), by = list(foto_mes)]
    dataset[, (campo) := NULL]
  }
  cat( "fin drift_rank_simple()\n")
}


# El cero se transforma en cero
# los positivos se rankean por su lado
# los negativos se rankean por su lado

drift_rank_cero_fijo <- function(campos_drift) {

  cat( "inicio drift_rank_cero_fijo()\n")
  for (campo in campos_drift)
  {
    cat(campo, " ")
    dataset[get(campo) == 0, paste0(campo, "_rank") := 0]
    dataset[get(campo) > 0, paste0(campo, "_rank") :=
      frank(get(campo), ties.method = "random") / .N, by = list(foto_mes)]

    dataset[get(campo) < 0, paste0(campo, "_rank") :=
      -frank(-get(campo), ties.method = "random") / .N, by = list(foto_mes)]
    dataset[, (campo) := NULL]
  }
  cat("\n")
  cat( "fin drift_rank_cero_fijo()\n")
}


drift_estandarizar <- function(campos_drift) {

  cat( "inicio drift_estandarizar()\n")
  for (campo in campos_drift)
  {
    cat(campo, " ")
    dataset[, paste0(campo, "_normal") :=
      (get(campo) -mean(campo, na.rm=TRUE)) / sd(get(campo), na.rm=TRUE),
      by = list(foto_mes)]

    dataset[, (campo) := NULL]
  }
  cat( "fin drift_estandarizar()\n")
}


# por como armé los nombres de campos,
#  estos son los campos que expresan variables monetarias
campos_monetarios <- colnames(dataset)
campos_monetarios <- campos_monetarios[campos_monetarios %like%
  "^(m|Visa_m|Master_m|vm_m)"]

campos_monetarios

# ejecuto el Data Drifting
setorder( dataset, numero_de_cliente, foto_mes )


PARAM$DR$metodo <- "deflacion"

switch(PARAM$DR$metodo,
  "ninguno"        = cat("No hay correccion del data drifting"),
  "rank_simple"    = drift_rank_simple(campos_monetarios),
  "rank_cero_fijo" = drift_rank_cero_fijo(campos_monetarios),
  "deflacion"      = drift_deflacion(campos_monetarios),
  "dolar_blue"     = drift_dolarblue(campos_monetarios),
  "dolar_oficial"  = drift_dolaroficial(campos_monetarios),
  "UVA"            = drift_UVA(campos_monetarios),
  "estandarizar"   = drift_estandarizar(campos_monetarios)
)


colnames(dataset)
# Out:
#    IPC       dolar_blue dolar_oficial UVA       foto_mes
# 1  1.9903031  39.04545   38.43000     2.0014088 201901
# 2  1.9174404  38.40250   39.42800     1.9503255 201902
# 3  1.8296187  41.63947   42.54210     1.8932303 201903
# 4  1.7728863  44.27474   44.35421     1.8247220 201904
# 5  1.7212488  46.09546   46.08864     1.7460278 201905
# 6  1.6776304  45.06333   44.95500     1.6871348 201906
# 7  1.6431248  43.98333   43.75143     1.6361679 201907
# 8  1.5814483  54.84286   54.65048     1.5927530 201908
# 9  1.4947527  61.05952   58.79000     1.5549163 201909
# 10 1.4484038  65.54546   61.40318     1.4949101 201910
# 11 1.3913581  66.75000   63.01263     1.4197730 201911
# 12 1.3404220  72.36842   63.01158     1.3678188 201912
# 13 1.3154289  77.47727   62.98364     1.3136509 202001
# 14 1.2921698  78.19167   63.58056     1.2690535 202002
# 15 1.2472682  82.43421   65.20000     1.2381596 202003
# 16 1.2300475 101.08750   67.87200     1.2116567 202004
# 17 1.2118695 126.23684   70.04789     1.1770809 202005
# 18 1.1881073 125.85714   72.52095     1.1570339 202006
# 19 1.1693970 130.78261   75.32429     1.1388769 202007
# 20 1.1375457 133.40000   77.48850     1.1156994 202008
# 21 1.1065620 137.95454   79.43091     1.0936383 202009
# 22 1.0681100 170.61905   83.13476     1.0657172 202010
# 23 1.0370000 160.40000   85.48474     1.0362174 202011
# 24 1.0000000 153.05263   88.18167     1.0000000 202012
# 25 0.9680542 157.90000   91.47400     0.9669868 202101
# 26 0.9344153 149.38095   93.99778     0.9323750 202102
# 27 0.8882274 143.61539   96.63591     0.8958203 202103
# 28 0.8532444 146.25000   98.52600     0.8631994 202104
# 29 0.8251880 153.55000   99.61316     0.8253893 202105
# 30 0.8003764 162.00000  100.61905     0.7928919 202106
# 31 0.7763107 178.47826  101.61905     0.7666324 202107
# 32 0.7566381 180.87879  102.56905     0.7428976 202108
# 33 0.7289385 184.35714  103.78182     0.7216158 202109
#  [1] "mrentabilidad"           "mrentabilidad_annual"
#  [3] "mcomisiones"             "mactivos_margen"
#  [5] "mpasivos_margen"         "mcuenta_corriente"
#  [7] "mcaja_ahorro"            "mcuentas_saldo"
#  [9] "mtarjeta_visa_consumo"   "mtarjeta_master_consumo"
# [11] "mprestamos_personales"   "mpayroll"
# [13] "Master_mpagominimo"      "Visa_mpagominimo"
# inicio drift_deflacion()
# fin drift_deflacion()
#  [1] "numero_de_cliente"           "foto_mes"
#  [3] "internet"                    "cliente_edad"
#  [5] "cliente_antiguedad"          "mrentabilidad"
#  [7] "mrentabilidad_annual"        "mcomisiones"
#  [9] "mactivos_margen"             "mpasivos_margen"
# [11] "cproductos"                  "mcuenta_corriente"
# [13] "mcaja_ahorro"                "cdescubierto_preacordado"
# [15] "mcuentas_saldo"              "ctarjeta_visa_transacciones"
# [17] "mtarjeta_visa_consumo"       "mtarjeta_master_consumo"
# [19] "mprestamos_personales"       "cpayroll_trx"
# [21] "mpayroll"                    "ccomisiones_mantenimiento"
# [23] "ccallcenter_transacciones"   "chomebanking_transacciones"
# [25] "ctrx_quarter"                "Master_status"
# [27] "Master_fechaalta"            "Master_mpagominimo"
# [29] "Visa_status"                 "Visa_fechaalta"
# [31] "Visa_mpagominimo"            "clase_ternaria"

# %% [markdown]
# #### 6.3.1.3  FE_intra_manual Feature Engineering intra-mes
#
# Agrego campos nuevos dentro del mismo mes, SIN considerar la historia.

# %%
# esta funcion atributos presentes existe debido a que las modalidades poseen datasets con distinta cantidad de campos
atributos_presentes <- function( patributos )
{
  atributos <- unique( patributos )
  comun <- intersect( atributos, colnames(dataset) )

  return(  length( atributos ) == length( comun ) )
}

# el mes 1,2, ..12
if( atributos_presentes( c("foto_mes") ))
  dataset[, kmes := foto_mes %% 100]

# variable extraida de una tesis de maestria de Irlanda
if( atributos_presentes( c("mpayroll", "cliente_edad") ))
  dataset[, mpayroll_sobre_edad := mpayroll / cliente_edad]

# %%
# visualizo las columas del dataset a esta etapa
colnames(dataset)
# Out:
#  [1] "numero_de_cliente"           "foto_mes"
#  [3] "internet"                    "cliente_edad"
#  [5] "cliente_antiguedad"          "mrentabilidad"
#  [7] "mrentabilidad_annual"        "mcomisiones"
#  [9] "mactivos_margen"             "mpasivos_margen"
# [11] "cproductos"                  "mcuenta_corriente"
# [13] "mcaja_ahorro"                "cdescubierto_preacordado"
# [15] "mcuentas_saldo"              "ctarjeta_visa_transacciones"
# [17] "mtarjeta_visa_consumo"       "mtarjeta_master_consumo"
# [19] "mprestamos_personales"       "cpayroll_trx"
# [21] "mpayroll"                    "ccomisiones_mantenimiento"
# [23] "ccallcenter_transacciones"   "chomebanking_transacciones"
# [25] "ctrx_quarter"                "Master_status"
# [27] "Master_fechaalta"            "Master_mpagominimo"
# [29] "Visa_status"                 "Visa_fechaalta"
# [31] "Visa_mpagominimo"            "clase_ternaria"
# [33] "kmes"                        "mpayroll_sobre_edad"

# %% [markdown]
# #### 6.3.1.4  FE_rf Feature Engineering de nuevas variables a partir de hojas de Random Forest
#
# Esto se mostrará unicamente a la *modalidad Analista Sr*

# %%
# No se implementa Feature Engineering a partir de Random Forest

# %% [markdown]
# #### 6.3.1.5  FEhist Feature Engineering historico
#
# El Fature Engineering Histórico es la etapa que más aporta a la ganancia final, ya que enriquece cada registro del dataset con su historia.

# %% [markdown]
# Para cada campo del dataset original (*)
# se crean lo siguientes campos de a partir de la historia
# * lag1  lags de orden 1
# * delta1  =  valor actual - lag1
# * lag2  lags de orden 2
# * delta2  = valor actual - lag2
#
#
# (*) Excepto para los campos  <numero_de_cliente,  foto_mes,  clase_ternaria>

# %%
# Feature Engineering Historico

# todo es lagueable, menos la primary key y la clase
cols_lagueables <- copy( setdiff(
    colnames(dataset),
    c("numero_de_cliente", "foto_mes", "clase_ternaria")
) )

# https://rdrr.io/cran/data.table/man/shift.html

# lags de orden 1
dataset[,
    paste0(cols_lagueables, "_lag1") := shift(.SD, 1, NA, "lag"),
    by = numero_de_cliente,
    .SDcols = cols_lagueables
]

# lags de orden 2
dataset[,
    paste0(cols_lagueables, "_lag2") := shift(.SD, 2, NA, "lag"),
    by = numero_de_cliente,
    .SDcols = cols_lagueables
]

# lags de orden 3
dataset[,
    paste0(cols_lagueables, "_lag3") := shift(.SD, 3, NA, "lag"),
    by = numero_de_cliente,
    .SDcols = cols_lagueables
]

# lags de orden 4
dataset[,
    paste0(cols_lagueables, "_lag4") := shift(.SD, 4, NA, "lag"),
    by = numero_de_cliente,
    .SDcols = cols_lagueables
]

# lags de orden 5
dataset[,
    paste0(cols_lagueables, "_lag5") := shift(.SD, 5, NA, "lag"),
    by = numero_de_cliente,
    .SDcols = cols_lagueables
]

# lags de orden 6
dataset[,
    paste0(cols_lagueables, "_lag6") := shift(.SD, 6, NA, "lag"),
    by = numero_de_cliente,
    .SDcols = cols_lagueables
]

# agrego los delta lags
for (vcol in cols_lagueables)
{
    dataset[, paste0(vcol, "_delta1") := get(vcol) - get(paste0(vcol, "_lag1"))]
    dataset[, paste0(vcol, "_delta2") := get(vcol) - get(paste0(vcol, "_lag2"))]
}

# %%
# Feature Engineering Historico

# todo es lagueable, menos la primary key y la clase
cols_lagueables <- copy( setdiff(
    colnames(dataset),
    c("numero_de_cliente", "foto_mes", "clase_ternaria")
) )

cols_promedio <- copy( setdiff(
    colnames(dataset),
    c("numero_de_cliente", "foto_mes", "clase_ternaria","cliente_edad", "cliente_antiguedad", "internet", "cdescubierto_preacordado", "thomebanking",
     "Master_fultimo_cierre", "Master_fechaalta", "Master_status", "Visa_status", "Visa_fultimo_cierre", "Visa_fechaalta")
) )



# Probando EMA

# función general para EMA(N)
emaN <- function(x, n) {
  alpha <- 2 / (n + 1)

  # si todos NA -> devolver NA
  if (all(is.na(x))) return(rep(NA_real_, length(x)))

  # primer EMA = primer valor no NA
  first_idx <- which(!is.na(x))[1]
  ema_vec <- rep(NA_real_, length(x))
  ema_vec[first_idx] <- x[first_idx]

  # recursión
  if (first_idx < length(x)) {
    for (i in (first_idx+1):length(x)) {
      ema_vec[i] <- alpha * x[i] + (1 - alpha) * ema_vec[i - 1]
    }
  }

  return(ema_vec)
}


# aplicar EMA3, EMA6 y EMA12 a todas las columnas de cols_promedio
dataset[
  , c(
      paste0(cols_promedio, "_ema3"),
      paste0(cols_promedio, "_ema6"),
      paste0(cols_promedio, "_ema12")
    ) := c(
      lapply(.SD, function(col) emaN(col, 3)),
      lapply(.SD, function(col) emaN(col, 6)),
      lapply(.SD, function(col) emaN(col, 12))
    ),
  by = numero_de_cliente,
  .SDcols = cols_promedio
]

# creo ratio ult 12 meses vs 6 meses, ult 6 vs ult 3 y actuales vs 3
for (vcol in cols_promedio)
{
    ema6 <- paste0(vcol, "_ema6")
    ema3 <- paste0(vcol, "_ema3")
    ema12 <- paste0(vcol, "_ema12")

    # Ratio EMA3 / EMA6  (aceleración)
    dataset[, paste0(vcol, "ema3_ema6_ratio") :=
              fifelse(get(ema6) == 0 | is.na(get(ema6)),
                      NA_real_, get(ema3) / get(ema6))]

    # Ratio actual / EMA6 - Cambios a mediano plazo
    dataset[, paste0(vcol, "actual_ema6_ratio") :=
              fifelse(get(ema6) == 0 | is.na(get(ema6)),
                      NA_real_, get(vcol) / get(ema6))]


    # Ratio actual / EMA3 - Cambios a corto plazo
    dataset[, paste0(vcol, "actual_ema3_ratio") :=
              fifelse(get(ema3) == 0 | is.na(get(ema3)),
                      NA_real_, get(vcol) / get(ema3))]

    # Ratio actual / EMA12 - Cambios a largo plazo
        dataset[, paste0(vcol, "actual_ema12_ratio") :=
              fifelse(get(ema12) == 0 | is.na(get(ema12)),
                      NA_real_, get(vcol) / get(ema12))]
}

#Elimino emas y dejo solo los ratios
cols_a_borrar <- grep("(_ema3|_ema6|_ema12)$", names(dataset), value = TRUE)
dataset[, (cols_a_borrar) := NULL]

# %%
# Las funciones frollmean y frollapply ya están disponibles a través de data.table,
# que es la librería más eficiente para este tipo de operaciones en R.

# Columnas para Rolling Window (normalmente, monetarias y de transacciones)
cols_rolling <- c("mrentabilidad", "mtarjeta_visa_consumo", "mcuentas_saldo", "cpayroll_trx")
# Puedes usar todas las cols_lagueables, pero las financieras son prioritarias

# Media móvil de los últimos 6 meses (Tendencia)
# frollmean es nativa de data.table y es muy eficiente.
dataset[,
    paste0(cols_rolling, "_mean6") := frollmean(.SD, 6, align = "right", fill = NA, na.rm=TRUE),
    by = numero_de_cliente,
    .SDcols = cols_rolling
]

# Desviación Estándar (SD) móvil de los últimos 6 meses (Volatilidad/Riesgo)
# frollapply con FUN = sd (función base de R) es la alternativa robusta a Rfast.
dataset[,
    paste0(cols_rolling, "_sd6") := frollapply(.SD, 6, FUN = sd, align = "right", fill = NA, na.rm=TRUE),
    by = numero_de_cliente,
    .SDcols = cols_rolling
]

# %% [markdown]
# Verificacion de los campos recien creados

# %%
ncol(dataset)
colnames(dataset)
# Out:
# [1] 1374
#    [1] "numero_de_cliente"
#    [2] "foto_mes"
#    [3] "internet"
#    [4] "cliente_edad"
#    [5] "cliente_antiguedad"
#    [6] "mrentabilidad"
#    [7] "mrentabilidad_annual"
#    [8] "mcomisiones"
#    [9] "mactivos_margen"
#   [10] "mpasivos_margen"
#   [11] "cproductos"
#   [12] "mcuenta_corriente"
#   [13] "mcaja_ahorro"
#   [14] "cdescubierto_preacordado"
#   [15] "mcuentas_saldo"
#   [16] "ctarjeta_visa_transacciones"
#   [17] "mtarjeta_visa_consumo"
#   [18] "mtarjeta_master_consumo"
#   [19] "mprestamos_personales"
#   [20] "cpayroll_trx"
#   [21] "mpayroll"
#   [22] "ccomisiones_mantenimiento"
#   [23] "ccallcenter_transacciones"
#   [24] "chomebanking_transacciones"
#   [25] "ctrx_quarter"
#   [26] "Master_status"
#   [27] "Master_fechaalta"
#   [28] "Master_mpagominimo"
#   [29] "Visa_status"
#   [30] "Visa_fechaalta"
#   [31] "Visa_mpagominimo"
#   [32] "clase_ternaria"
#   [33] "kmes"
#   [34] "mpayroll_sobre_edad"
#   [35] "internet_lag1"
#   [36] "cliente_edad_lag1"
#   [37] "cliente_antiguedad_lag1"
#   [38] "mrentabilidad_lag1"
#   [39] "mrentabilidad_annual_lag1"
#   [40] "mcomisiones_lag1"
#   [41] "mactivos_margen_lag1"
#   [42] "mpasivos_margen_lag1"
#   [43] "cproductos_lag1"
#   [44] "mcuenta_corriente_lag1"
#   [45] "mcaja_ahorro_lag1"
#   [46] "cdescubierto_preacordado_lag1"
#   [47] "mcuentas_saldo_lag1"
#   [48] "ctarjeta_visa_transacciones_lag1"
#   [49] "mtarjeta_visa_consumo_lag1"
#   [50] "mtarjeta_master_consumo_lag1"
#   [51] "mprestamos_personales_lag1"
#   [52] "cpayroll_trx_lag1"
#   [53] "mpayroll_lag1"
#   [54] "ccomisiones_mantenimiento_lag1"
#   [55] "ccallcenter_transacciones_lag1"
#   [56] "chomebanking_transacciones_lag1"
#   [57] "ctrx_quarter_lag1"
#   [58] "Master_status_lag1"
#   [59] "Master_fechaalta_lag1"
#   [60] "Master_mpagominimo_lag1"
#   [61] "Visa_status_lag1"
#   [62] "Visa_fechaalta_lag1"
#   [63] "Visa_mpagominimo_lag1"
#   [64] "kmes_lag1"
#   [65] "mpayroll_sobre_edad_lag1"
#   [66] "internet_lag2"
#   [67] "cliente_edad_lag2"
#   [68] "cliente_antiguedad_lag2"
#   [69] "mrentabilidad_lag2"
#   [70] "mrentabilidad_annual_lag2"
#   [71] "mcomisiones_lag2"
#   [72] "mactivos_margen_lag2"
#   [73] "mpasivos_margen_lag2"
#   [74] "cproductos_lag2"
#   [75] "mcuenta_corriente_lag2"
#   [76] "mcaja_ahorro_lag2"
#   [77] "cdescubierto_preacordado_lag2"
#   [78] "mcuentas_saldo_lag2"
#   [79] "ctarjeta_visa_transacciones_lag2"
#   [80] "mtarjeta_visa_consumo_lag2"
#   [81] "mtarjeta_master_consumo_lag2"
#   [82] "mprestamos_personales_lag2"
#   [83] "cpayroll_trx_lag2"
#   [84] "mpayroll_lag2"
#   [85] "ccomisiones_mantenimiento_lag2"
#   [86] "ccallcenter_transacciones_lag2"
#   [87] "chomebanking_transacciones_lag2"
#   [88] "ctrx_quarter_lag2"
#   [89] "Master_status_lag2"
#   [90] "Master_fechaalta_lag2"
#   [91] "Master_mpagominimo_lag2"
#   [92] "Visa_status_lag2"
#   [93] "Visa_fechaalta_lag2"
#   [94] "Visa_mpagominimo_lag2"
#   [95] "kmes_lag2"
#   [96] "mpayroll_sobre_edad_lag2"
#   [97] "internet_lag3"
#   [98] "cliente_edad_lag3"
#   [99] "cliente_antiguedad_lag3"
#  [100] "mrentabilidad_lag3"
#  [101] "mrentabilidad_annual_lag3"
#  [102] "mcomisiones_lag3"
#  [103] "mactivos_margen_lag3"
#  [104] "mpasivos_margen_lag3"
#  [105] "cproductos_lag3"
#  [106] "mcuenta_corriente_lag3"
#  [107] "mcaja_ahorro_lag3"
#  [108] "cdescubierto_preacordado_lag3"
#  [109] "mcuentas_saldo_lag3"
#  [110] "ctarjeta_visa_transacciones_lag3"
#  [111] "mtarjeta_visa_consumo_lag3"
#  [112] "mtarjeta_master_consumo_lag3"
#  [113] "mprestamos_personales_lag3"
#  [114] "cpayroll_trx_lag3"
#  [115] "mpayroll_lag3"
#  [116] "ccomisiones_mantenimiento_lag3"
#  [117] "ccallcenter_transacciones_lag3"
#  [118] "chomebanking_transacciones_lag3"
#  [119] "ctrx_quarter_lag3"
#  [120] "Master_status_lag3"
#  [121] "Master_fechaalta_lag3"
#  [122] "Master_mpagominimo_lag3"
#  [123] "Visa_status_lag3"
#  [124] "Visa_fechaalta_lag3"
#  [125] "Visa_mpagominimo_lag3"
#  [126] "kmes_lag3"
#  [127] "mpayroll_sobre_edad_lag3"
#  [128] "internet_lag4"
#  [129] "cliente_edad_lag4"
#  [130] "cliente_antiguedad_lag4"
#  [131] "mrentabilidad_lag4"
#  [132] "mrentabilidad_annual_lag4"
#  [133] "mcomisiones_lag4"
#  [134] "mactivos_margen_lag4"
#  [135] "mpasivos_margen_lag4"
#  [136] "cproductos_lag4"
#  [137] "mcuenta_corriente_lag4"
#  [138] "mcaja_ahorro_lag4"
#  [139] "cdescubierto_preacordado_lag4"
#  [140] "mcuentas_saldo_lag4"
#  [141] "ctarjeta_visa_transacciones_lag4"
#  [142] "mtarjeta_visa_consumo_lag4"
#  [143] "mtarjeta_master_consumo_lag4"
#  [144] "mprestamos_personales_lag4"
#  [145] "cpayroll_trx_lag4"
#  [146] "mpayroll_lag4"
#  [147] "ccomisiones_mantenimiento_lag4"
#  [148] "ccallcenter_transacciones_lag4"
#  [149] "chomebanking_transacciones_lag4"
#  [150] "ctrx_quarter_lag4"
#  [151] "Master_status_lag4"
#  [152] "Master_fechaalta_lag4"
#  [153] "Master_mpagominimo_lag4"
#  [154] "Visa_status_lag4"
#  [155] "Visa_fechaalta_lag4"
#  [156] "Visa_mpagominimo_lag4"
#  [157] "kmes_lag4"
#  [158] "mpayroll_sobre_edad_lag4"
#  [159] "internet_lag5"
#  [160] "cliente_edad_lag5"
#  [161] "cliente_antiguedad_lag5"
#  [162] "mrentabilidad_lag5"
#  [163] "mrentabilidad_annual_lag5"
#  [164] "mcomisiones_lag5"
#  [165] "mactivos_margen_lag5"
#  [166] "mpasivos_margen_lag5"
#  [167] "cproductos_lag5"
#  [168] "mcuenta_corriente_lag5"
#  [169] "mcaja_ahorro_lag5"
#  [170] "cdescubierto_preacordado_lag5"
#  [171] "mcuentas_saldo_lag5"
#  [172] "ctarjeta_visa_transacciones_lag5"
#  [173] "mtarjeta_visa_consumo_lag5"
#  [174] "mtarjeta_master_consumo_lag5"
#  [175] "mprestamos_personales_lag5"
#  [176] "cpayroll_trx_lag5"
#  [177] "mpayroll_lag5"
#  [178] "ccomisiones_mantenimiento_lag5"
#  [179] "ccallcenter_transacciones_lag5"
#  [180] "chomebanking_transacciones_lag5"
#  [181] "ctrx_quarter_lag5"
#  [182] "Master_status_lag5"
#  [183] "Master_fechaalta_lag5"
#  [184] "Master_mpagominimo_lag5"
#  [185] "Visa_status_lag5"
#  [186] "Visa_fechaalta_lag5"
#  [187] "Visa_mpagominimo_lag5"
#  [188] "kmes_lag5"
#  [189] "mpayroll_sobre_edad_lag5"
#  [190] "internet_lag6"
#  [191] "cliente_edad_lag6"
#  [192] "cliente_antiguedad_lag6"
#  [193] "mrentabilidad_lag6"
#  [194] "mrentabilidad_annual_lag6"
#  [195] "mcomisiones_lag6"
#  [196] "mactivos_margen_lag6"
#  [197] "mpasivos_margen_lag6"
#  [198] "cproductos_lag6"
#  [199] "mcuenta_corriente_lag6"
#  [200] "mcaja_ahorro_lag6"
#  [201] "cdescubierto_preacordado_lag6"
#  [202] "mcuentas_saldo_lag6"
#  [203] "ctarjeta_visa_transacciones_lag6"
#  [204] "mtarjeta_visa_consumo_lag6"
#  [205] "mtarjeta_master_consumo_lag6"
#  [206] "mprestamos_personales_lag6"
#  [207] "cpayroll_trx_lag6"
#  [208] "mpayroll_lag6"
#  [209] "ccomisiones_mantenimiento_lag6"
#  [210] "ccallcenter_transacciones_lag6"
#  [211] "chomebanking_transacciones_lag6"
#  [212] "ctrx_quarter_lag6"
#  [213] "Master_status_lag6"
#  [214] "Master_fechaalta_lag6"
#  [215] "Master_mpagominimo_lag6"
#  [216] "Visa_status_lag6"
#  [217] "Visa_fechaalta_lag6"
#  [218] "Visa_mpagominimo_lag6"
#  [219] "kmes_lag6"
#  [220] "mpayroll_sobre_edad_lag6"
#  [221] "internet_delta1"
#  [222] "internet_delta2"
#  [223] "cliente_edad_delta1"
#  [224] "cliente_edad_delta2"
#  [225] "cliente_antiguedad_delta1"
#  [226] "cliente_antiguedad_delta2"
#  [227] "mrentabilidad_delta1"
#  [228] "mrentabilidad_delta2"
#  [229] "mrentabilidad_annual_delta1"
#  [230] "mrentabilidad_annual_delta2"
#  [231] "mcomisiones_delta1"
#  [232] "mcomisiones_delta2"
#  [233] "mactivos_margen_delta1"
#  [234] "mactivos_margen_delta2"
#  [235] "mpasivos_margen_delta1"
#  [236] "mpasivos_margen_delta2"
#  [237] "cproductos_delta1"
#  [238] "cproductos_delta2"
#  [239] "mcuenta_corriente_delta1"
#  [240] "mcuenta_corriente_delta2"
#  [241] "mcaja_ahorro_delta1"
#  [242] "mcaja_ahorro_delta2"
#  [243] "cdescubierto_preacordado_delta1"
#  [244] "cdescubierto_preacordado_delta2"
#  [245] "mcuentas_saldo_delta1"
#  [246] "mcuentas_saldo_delta2"
#  [247] "ctarjeta_visa_transacciones_delta1"
#  [248] "ctarjeta_visa_transacciones_delta2"
#  [249] "mtarjeta_visa_consumo_delta1"
#  [250] "mtarjeta_visa_consumo_delta2"
#  [251] "mtarjeta_master_consumo_delta1"
#  [252] "mtarjeta_master_consumo_delta2"
#  [253] "mprestamos_personales_delta1"
#  [254] "mprestamos_personales_delta2"
#  [255] "cpayroll_trx_delta1"
#  [256] "cpayroll_trx_delta2"
#  [257] "mpayroll_delta1"
#  [258] "mpayroll_delta2"
#  [259] "ccomisiones_mantenimiento_delta1"
#  [260] "ccomisiones_mantenimiento_delta2"
#  [261] "ccallcenter_transacciones_delta1"
#  [262] "ccallcenter_transacciones_delta2"
#  [263] "chomebanking_transacciones_delta1"
#  [264] "chomebanking_transacciones_delta2"
#  [265] "ctrx_quarter_delta1"
#  [266] "ctrx_quarter_delta2"
#  [267] "Master_status_delta1"
#  [268] "Master_status_delta2"
#  [269] "Master_fechaalta_delta1"
#  [270] "Master_fechaalta_delta2"
#  [271] "Master_mpagominimo_delta1"
#  [272] "Master_mpagominimo_delta2"
#  [273] "Visa_status_delta1"
#  [274] "Visa_status_delta2"
#  [275] "Visa_fechaalta_delta1"
#  [276] "Visa_fechaalta_delta2"
#  [277] "Visa_mpagominimo_delta1"
#  [278] "Visa_mpagominimo_delta2"
#  [279] "kmes_delta1"
#  [280] "kmes_delta2"
#  [281] "mpayroll_sobre_edad_delta1"
#  [282] "mpayroll_sobre_edad_delta2"
#  [283] "mrentabilidadema3_ema6_ratio"
#  [284] "mrentabilidadactual_ema6_ratio"
#  [285] "mrentabilidadactual_ema3_ratio"
#  [286] "mrentabilidadactual_ema12_ratio"
#  [287] "mrentabilidad_annualema3_ema6_ratio"
#  [288] "mrentabilidad_annualactual_ema6_ratio"
#  [289] "mrentabilidad_annualactual_ema3_ratio"
#  [290] "mrentabilidad_annualactual_ema12_ratio"
#  [291] "mcomisionesema3_ema6_ratio"
#  [292] "mcomisionesactual_ema6_ratio"
#  [293] "mcomisionesactual_ema3_ratio"
#  [294] "mcomisionesactual_ema12_ratio"
#  [295] "mactivos_margenema3_ema6_ratio"
#  [296] "mactivos_margenactual_ema6_ratio"
#  [297] "mactivos_margenactual_ema3_ratio"
#  [298] "mactivos_margenactual_ema12_ratio"
#  [299] "mpasivos_margenema3_ema6_ratio"
#  [300] "mpasivos_margenactual_ema6_ratio"
#  [301] "mpasivos_margenactual_ema3_ratio"
#  [302] "mpasivos_margenactual_ema12_ratio"
#  [303] "cproductosema3_ema6_ratio"
#  [304] "cproductosactual_ema6_ratio"
#  [305] "cproductosactual_ema3_ratio"
#  [306] "cproductosactual_ema12_ratio"
#  [307] "mcuenta_corrienteema3_ema6_ratio"
#  [308] "mcuenta_corrienteactual_ema6_ratio"
#  [309] "mcuenta_corrienteactual_ema3_ratio"
#  [310] "mcuenta_corrienteactual_ema12_ratio"
#  [311] "mcaja_ahorroema3_ema6_ratio"
#  [312] "mcaja_ahorroactual_ema6_ratio"
#  [313] "mcaja_ahorroactual_ema3_ratio"
#  [314] "mcaja_ahorroactual_ema12_ratio"
#  [315] "mcuentas_saldoema3_ema6_ratio"
#  [316] "mcuentas_saldoactual_ema6_ratio"
#  [317] "mcuentas_saldoactual_ema3_ratio"
#  [318] "mcuentas_saldoactual_ema12_ratio"
#  [319] "ctarjeta_visa_transaccionesema3_ema6_ratio"
#  [320] "ctarjeta_visa_transaccionesactual_ema6_ratio"
#  [321] "ctarjeta_visa_transaccionesactual_ema3_ratio"
#  [322] "ctarjeta_visa_transaccionesactual_ema12_ratio"
#  [323] "mtarjeta_visa_consumoema3_ema6_ratio"
#  [324] "mtarjeta_visa_consumoactual_ema6_ratio"
#  [325] "mtarjeta_visa_consumoactual_ema3_ratio"
#  [326] "mtarjeta_visa_consumoactual_ema12_ratio"
#  [327] "mtarjeta_master_consumoema3_ema6_ratio"
#  [328] "mtarjeta_master_consumoactual_ema6_ratio"
#  [329] "mtarjeta_master_consumoactual_ema3_ratio"
#  [330] "mtarjeta_master_consumoactual_ema12_ratio"
#  [331] "mprestamos_personalesema3_ema6_ratio"
#  [332] "mprestamos_personalesactual_ema6_ratio"
#  [333] "mprestamos_personalesactual_ema3_ratio"
#  [334] "mprestamos_personalesactual_ema12_ratio"
#  [335] "cpayroll_trxema3_ema6_ratio"
#  [336] "cpayroll_trxactual_ema6_ratio"
#  [337] "cpayroll_trxactual_ema3_ratio"
#  [338] "cpayroll_trxactual_ema12_ratio"
#  [339] "mpayrollema3_ema6_ratio"
#  [340] "mpayrollactual_ema6_ratio"
#  [341] "mpayrollactual_ema3_ratio"
#  [342] "mpayrollactual_ema12_ratio"
#  [343] "ccomisiones_mantenimientoema3_ema6_ratio"
#  [344] "ccomisiones_mantenimientoactual_ema6_ratio"
#  [345] "ccomisiones_mantenimientoactual_ema3_ratio"
#  [346] "ccomisiones_mantenimientoactual_ema12_ratio"
#  [347] "ccallcenter_transaccionesema3_ema6_ratio"
#  [348] "ccallcenter_transaccionesactual_ema6_ratio"
#  [349] "ccallcenter_transaccionesactual_ema3_ratio"
#  [350] "ccallcenter_transaccionesactual_ema12_ratio"
#  [351] "chomebanking_transaccionesema3_ema6_ratio"
#  [352] "chomebanking_transaccionesactual_ema6_ratio"
#  [353] "chomebanking_transaccionesactual_ema3_ratio"
#  [354] "chomebanking_transaccionesactual_ema12_ratio"
#  [355] "ctrx_quarterema3_ema6_ratio"
#  [356] "ctrx_quarteractual_ema6_ratio"
#  [357] "ctrx_quarteractual_ema3_ratio"
#  [358] "ctrx_quarteractual_ema12_ratio"
#  [359] "Master_mpagominimoema3_ema6_ratio"
#  [360] "Master_mpagominimoactual_ema6_ratio"
#  [361] "Master_mpagominimoactual_ema3_ratio"
#  [362] "Master_mpagominimoactual_ema12_ratio"
#  [363] "Visa_mpagominimoema3_ema6_ratio"
#  [364] "Visa_mpagominimoactual_ema6_ratio"
#  [365] "Visa_mpagominimoactual_ema3_ratio"
#  [366] "Visa_mpagominimoactual_ema12_ratio"
#  [367] "kmesema3_ema6_ratio"
#  [368] "kmesactual_ema6_ratio"
#  [369] "kmesactual_ema3_ratio"
#  [370] "kmesactual_ema12_ratio"
#  [371] "mpayroll_sobre_edadema3_ema6_ratio"
#  [372] "mpayroll_sobre_edadactual_ema6_ratio"
#  [373] "mpayroll_sobre_edadactual_ema3_ratio"
#  [374] "mpayroll_sobre_edadactual_ema12_ratio"
#  [375] "internet_lag1ema3_ema6_ratio"
#  [376] "internet_lag1actual_ema6_ratio"
#  [377] "internet_lag1actual_ema3_ratio"
#  [378] "internet_lag1actual_ema12_ratio"
#  [379] "cliente_edad_lag1ema3_ema6_ratio"
#  [380] "cliente_edad_lag1actual_ema6_ratio"
#  [381] "cliente_edad_lag1actual_ema3_ratio"
#  [382] "cliente_edad_lag1actual_ema12_ratio"
#  [383] "cliente_antiguedad_lag1ema3_ema6_ratio"
#  [384] "cliente_antiguedad_lag1actual_ema6_ratio"
#  [385] "cliente_antiguedad_lag1actual_ema3_ratio"
#  [386] "cliente_antiguedad_lag1actual_ema12_ratio"
#  [387] "mrentabilidad_lag1ema3_ema6_ratio"
#  [388] "mrentabilidad_lag1actual_ema6_ratio"
#  [389] "mrentabilidad_lag1actual_ema3_ratio"
#  [390] "mrentabilidad_lag1actual_ema12_ratio"
#  [391] "mrentabilidad_annual_lag1ema3_ema6_ratio"
#  [392] "mrentabilidad_annual_lag1actual_ema6_ratio"
#  [393] "mrentabilidad_annual_lag1actual_ema3_ratio"
#  [394] "mrentabilidad_annual_lag1actual_ema12_ratio"
#  [395] "mcomisiones_lag1ema3_ema6_ratio"
#  [396] "mcomisiones_lag1actual_ema6_ratio"
#  [397] "mcomisiones_lag1actual_ema3_ratio"
#  [398] "mcomisiones_lag1actual_ema12_ratio"
#  [399] "mactivos_margen_lag1ema3_ema6_ratio"
#  [400] "mactivos_margen_lag1actual_ema6_ratio"
#  [401] "mactivos_margen_lag1actual_ema3_ratio"
#  [402] "mactivos_margen_lag1actual_ema12_ratio"
#  [403] "mpasivos_margen_lag1ema3_ema6_ratio"
#  [404] "mpasivos_margen_lag1actual_ema6_ratio"
#  [405] "mpasivos_margen_lag1actual_ema3_ratio"
#  [406] "mpasivos_margen_lag1actual_ema12_ratio"
#  [407] "cproductos_lag1ema3_ema6_ratio"
#  [408] "cproductos_lag1actual_ema6_ratio"
#  [409] "cproductos_lag1actual_ema3_ratio"
#  [410] "cproductos_lag1actual_ema12_ratio"
#  [411] "mcuenta_corriente_lag1ema3_ema6_ratio"
#  [412] "mcuenta_corriente_lag1actual_ema6_ratio"
#  [413] "mcuenta_corriente_lag1actual_ema3_ratio"
#  [414] "mcuenta_corriente_lag1actual_ema12_ratio"
#  [415] "mcaja_ahorro_lag1ema3_ema6_ratio"
#  [416] "mcaja_ahorro_lag1actual_ema6_ratio"
#  [417] "mcaja_ahorro_lag1actual_ema3_ratio"
#  [418] "mcaja_ahorro_lag1actual_ema12_ratio"
#  [419] "cdescubierto_preacordado_lag1ema3_ema6_ratio"
#  [420] "cdescubierto_preacordado_lag1actual_ema6_ratio"
#  [421] "cdescubierto_preacordado_lag1actual_ema3_ratio"
#  [422] "cdescubierto_preacordado_lag1actual_ema12_ratio"
#  [423] "mcuentas_saldo_lag1ema3_ema6_ratio"
#  [424] "mcuentas_saldo_lag1actual_ema6_ratio"
#  [425] "mcuentas_saldo_lag1actual_ema3_ratio"
#  [426] "mcuentas_saldo_lag1actual_ema12_ratio"
#  [427] "ctarjeta_visa_transacciones_lag1ema3_ema6_ratio"
#  [428] "ctarjeta_visa_transacciones_lag1actual_ema6_ratio"
#  [429] "ctarjeta_visa_transacciones_lag1actual_ema3_ratio"
#  [430] "ctarjeta_visa_transacciones_lag1actual_ema12_ratio"
#  [431] "mtarjeta_visa_consumo_lag1ema3_ema6_ratio"
#  [432] "mtarjeta_visa_consumo_lag1actual_ema6_ratio"
#  [433] "mtarjeta_visa_consumo_lag1actual_ema3_ratio"
#  [434] "mtarjeta_visa_consumo_lag1actual_ema12_ratio"
#  [435] "mtarjeta_master_consumo_lag1ema3_ema6_ratio"
#  [436] "mtarjeta_master_consumo_lag1actual_ema6_ratio"
#  [437] "mtarjeta_master_consumo_lag1actual_ema3_ratio"
#  [438] "mtarjeta_master_consumo_lag1actual_ema12_ratio"
#  [439] "mprestamos_personales_lag1ema3_ema6_ratio"
#  [440] "mprestamos_personales_lag1actual_ema6_ratio"
#  [441] "mprestamos_personales_lag1actual_ema3_ratio"
#  [442] "mprestamos_personales_lag1actual_ema12_ratio"
#  [443] "cpayroll_trx_lag1ema3_ema6_ratio"
#  [444] "cpayroll_trx_lag1actual_ema6_ratio"
#  [445] "cpayroll_trx_lag1actual_ema3_ratio"
#  [446] "cpayroll_trx_lag1actual_ema12_ratio"
#  [447] "mpayroll_lag1ema3_ema6_ratio"
#  [448] "mpayroll_lag1actual_ema6_ratio"
#  [449] "mpayroll_lag1actual_ema3_ratio"
#  [450] "mpayroll_lag1actual_ema12_ratio"
#  [451] "ccomisiones_mantenimiento_lag1ema3_ema6_ratio"
#  [452] "ccomisiones_mantenimiento_lag1actual_ema6_ratio"
#  [453] "ccomisiones_mantenimiento_lag1actual_ema3_ratio"
#  [454] "ccomisiones_mantenimiento_lag1actual_ema12_ratio"
#  [455] "ccallcenter_transacciones_lag1ema3_ema6_ratio"
#  [456] "ccallcenter_transacciones_lag1actual_ema6_ratio"
#  [457] "ccallcenter_transacciones_lag1actual_ema3_ratio"
#  [458] "ccallcenter_transacciones_lag1actual_ema12_ratio"
#  [459] "chomebanking_transacciones_lag1ema3_ema6_ratio"
#  [460] "chomebanking_transacciones_lag1actual_ema6_ratio"
#  [461] "chomebanking_transacciones_lag1actual_ema3_ratio"
#  [462] "chomebanking_transacciones_lag1actual_ema12_ratio"
#  [463] "ctrx_quarter_lag1ema3_ema6_ratio"
#  [464] "ctrx_quarter_lag1actual_ema6_ratio"
#  [465] "ctrx_quarter_lag1actual_ema3_ratio"
#  [466] "ctrx_quarter_lag1actual_ema12_ratio"
#  [467] "Master_status_lag1ema3_ema6_ratio"
#  [468] "Master_status_lag1actual_ema6_ratio"
#  [469] "Master_status_lag1actual_ema3_ratio"
#  [470] "Master_status_lag1actual_ema12_ratio"
#  [471] "Master_fechaalta_lag1ema3_ema6_ratio"
#  [472] "Master_fechaalta_lag1actual_ema6_ratio"
#  [473] "Master_fechaalta_lag1actual_ema3_ratio"
#  [474] "Master_fechaalta_lag1actual_ema12_ratio"
#  [475] "Master_mpagominimo_lag1ema3_ema6_ratio"
#  [476] "Master_mpagominimo_lag1actual_ema6_ratio"
#  [477] "Master_mpagominimo_lag1actual_ema3_ratio"
#  [478] "Master_mpagominimo_lag1actual_ema12_ratio"
#  [479] "Visa_status_lag1ema3_ema6_ratio"
#  [480] "Visa_status_lag1actual_ema6_ratio"
#  [481] "Visa_status_lag1actual_ema3_ratio"
#  [482] "Visa_status_lag1actual_ema12_ratio"
#  [483] "Visa_fechaalta_lag1ema3_ema6_ratio"
#  [484] "Visa_fechaalta_lag1actual_ema6_ratio"
#  [485] "Visa_fechaalta_lag1actual_ema3_ratio"
#  [486] "Visa_fechaalta_lag1actual_ema12_ratio"
#  [487] "Visa_mpagominimo_lag1ema3_ema6_ratio"
#  [488] "Visa_mpagominimo_lag1actual_ema6_ratio"
#  [489] "Visa_mpagominimo_lag1actual_ema3_ratio"
#  [490] "Visa_mpagominimo_lag1actual_ema12_ratio"
#  [491] "kmes_lag1ema3_ema6_ratio"
#  [492] "kmes_lag1actual_ema6_ratio"
#  [493] "kmes_lag1actual_ema3_ratio"
#  [494] "kmes_lag1actual_ema12_ratio"
#  [495] "mpayroll_sobre_edad_lag1ema3_ema6_ratio"
#  [496] "mpayroll_sobre_edad_lag1actual_ema6_ratio"
#  [497] "mpayroll_sobre_edad_lag1actual_ema3_ratio"
#  [498] "mpayroll_sobre_edad_lag1actual_ema12_ratio"
#  [499] "internet_lag2ema3_ema6_ratio"
#  [500] "internet_lag2actual_ema6_ratio"
#  [501] "internet_lag2actual_ema3_ratio"
#  [502] "internet_lag2actual_ema12_ratio"
#  [503] "cliente_edad_lag2ema3_ema6_ratio"
#  [504] "cliente_edad_lag2actual_ema6_ratio"
#  [505] "cliente_edad_lag2actual_ema3_ratio"
#  [506] "cliente_edad_lag2actual_ema12_ratio"
#  [507] "cliente_antiguedad_lag2ema3_ema6_ratio"
#  [508] "cliente_antiguedad_lag2actual_ema6_ratio"
#  [509] "cliente_antiguedad_lag2actual_ema3_ratio"
#  [510] "cliente_antiguedad_lag2actual_ema12_ratio"
#  [511] "mrentabilidad_lag2ema3_ema6_ratio"
#  [512] "mrentabilidad_lag2actual_ema6_ratio"
#  [513] "mrentabilidad_lag2actual_ema3_ratio"
#  [514] "mrentabilidad_lag2actual_ema12_ratio"
#  [515] "mrentabilidad_annual_lag2ema3_ema6_ratio"
#  [516] "mrentabilidad_annual_lag2actual_ema6_ratio"
#  [517] "mrentabilidad_annual_lag2actual_ema3_ratio"
#  [518] "mrentabilidad_annual_lag2actual_ema12_ratio"
#  [519] "mcomisiones_lag2ema3_ema6_ratio"
#  [520] "mcomisiones_lag2actual_ema6_ratio"
#  [521] "mcomisiones_lag2actual_ema3_ratio"
#  [522] "mcomisiones_lag2actual_ema12_ratio"
#  [523] "mactivos_margen_lag2ema3_ema6_ratio"
#  [524] "mactivos_margen_lag2actual_ema6_ratio"
#  [525] "mactivos_margen_lag2actual_ema3_ratio"
#  [526] "mactivos_margen_lag2actual_ema12_ratio"
#  [527] "mpasivos_margen_lag2ema3_ema6_ratio"
#  [528] "mpasivos_margen_lag2actual_ema6_ratio"
#  [529] "mpasivos_margen_lag2actual_ema3_ratio"
#  [530] "mpasivos_margen_lag2actual_ema12_ratio"
#  [531] "cproductos_lag2ema3_ema6_ratio"
#  [532] "cproductos_lag2actual_ema6_ratio"
#  [533] "cproductos_lag2actual_ema3_ratio"
#  [534] "cproductos_lag2actual_ema12_ratio"
#  [535] "mcuenta_corriente_lag2ema3_ema6_ratio"
#  [536] "mcuenta_corriente_lag2actual_ema6_ratio"
#  [537] "mcuenta_corriente_lag2actual_ema3_ratio"
#  [538] "mcuenta_corriente_lag2actual_ema12_ratio"
#  [539] "mcaja_ahorro_lag2ema3_ema6_ratio"
#  [540] "mcaja_ahorro_lag2actual_ema6_ratio"
#  [541] "mcaja_ahorro_lag2actual_ema3_ratio"
#  [542] "mcaja_ahorro_lag2actual_ema12_ratio"
#  [543] "cdescubierto_preacordado_lag2ema3_ema6_ratio"
#  [544] "cdescubierto_preacordado_lag2actual_ema6_ratio"
#  [545] "cdescubierto_preacordado_lag2actual_ema3_ratio"
#  [546] "cdescubierto_preacordado_lag2actual_ema12_ratio"
#  [547] "mcuentas_saldo_lag2ema3_ema6_ratio"
#  [548] "mcuentas_saldo_lag2actual_ema6_ratio"
#  [549] "mcuentas_saldo_lag2actual_ema3_ratio"
#  [550] "mcuentas_saldo_lag2actual_ema12_ratio"
#  [551] "ctarjeta_visa_transacciones_lag2ema3_ema6_ratio"
#  [552] "ctarjeta_visa_transacciones_lag2actual_ema6_ratio"
#  [553] "ctarjeta_visa_transacciones_lag2actual_ema3_ratio"
#  [554] "ctarjeta_visa_transacciones_lag2actual_ema12_ratio"
#  [555] "mtarjeta_visa_consumo_lag2ema3_ema6_ratio"
#  [556] "mtarjeta_visa_consumo_lag2actual_ema6_ratio"
#  [557] "mtarjeta_visa_consumo_lag2actual_ema3_ratio"
#  [558] "mtarjeta_visa_consumo_lag2actual_ema12_ratio"
#  [559] "mtarjeta_master_consumo_lag2ema3_ema6_ratio"
#  [560] "mtarjeta_master_consumo_lag2actual_ema6_ratio"
#  [561] "mtarjeta_master_consumo_lag2actual_ema3_ratio"
#  [562] "mtarjeta_master_consumo_lag2actual_ema12_ratio"
#  [563] "mprestamos_personales_lag2ema3_ema6_ratio"
#  [564] "mprestamos_personales_lag2actual_ema6_ratio"
#  [565] "mprestamos_personales_lag2actual_ema3_ratio"
#  [566] "mprestamos_personales_lag2actual_ema12_ratio"
#  [567] "cpayroll_trx_lag2ema3_ema6_ratio"
#  [568] "cpayroll_trx_lag2actual_ema6_ratio"
#  [569] "cpayroll_trx_lag2actual_ema3_ratio"
#  [570] "cpayroll_trx_lag2actual_ema12_ratio"
#  [571] "mpayroll_lag2ema3_ema6_ratio"
#  [572] "mpayroll_lag2actual_ema6_ratio"
#  [573] "mpayroll_lag2actual_ema3_ratio"
#  [574] "mpayroll_lag2actual_ema12_ratio"
#  [575] "ccomisiones_mantenimiento_lag2ema3_ema6_ratio"
#  [576] "ccomisiones_mantenimiento_lag2actual_ema6_ratio"
#  [577] "ccomisiones_mantenimiento_lag2actual_ema3_ratio"
#  [578] "ccomisiones_mantenimiento_lag2actual_ema12_ratio"
#  [579] "ccallcenter_transacciones_lag2ema3_ema6_ratio"
#  [580] "ccallcenter_transacciones_lag2actual_ema6_ratio"
#  [581] "ccallcenter_transacciones_lag2actual_ema3_ratio"
#  [582] "ccallcenter_transacciones_lag2actual_ema12_ratio"
#  [583] "chomebanking_transacciones_lag2ema3_ema6_ratio"
#  [584] "chomebanking_transacciones_lag2actual_ema6_ratio"
#  [585] "chomebanking_transacciones_lag2actual_ema3_ratio"
#  [586] "chomebanking_transacciones_lag2actual_ema12_ratio"
#  [587] "ctrx_quarter_lag2ema3_ema6_ratio"
#  [588] "ctrx_quarter_lag2actual_ema6_ratio"
#  [589] "ctrx_quarter_lag2actual_ema3_ratio"
#  [590] "ctrx_quarter_lag2actual_ema12_ratio"
#  [591] "Master_status_lag2ema3_ema6_ratio"
#  [592] "Master_status_lag2actual_ema6_ratio"
#  [593] "Master_status_lag2actual_ema3_ratio"
#  [594] "Master_status_lag2actual_ema12_ratio"
#  [595] "Master_fechaalta_lag2ema3_ema6_ratio"
#  [596] "Master_fechaalta_lag2actual_ema6_ratio"
#  [597] "Master_fechaalta_lag2actual_ema3_ratio"
#  [598] "Master_fechaalta_lag2actual_ema12_ratio"
#  [599] "Master_mpagominimo_lag2ema3_ema6_ratio"
#  [600] "Master_mpagominimo_lag2actual_ema6_ratio"
#  [601] "Master_mpagominimo_lag2actual_ema3_ratio"
#  [602] "Master_mpagominimo_lag2actual_ema12_ratio"
#  [603] "Visa_status_lag2ema3_ema6_ratio"
#  [604] "Visa_status_lag2actual_ema6_ratio"
#  [605] "Visa_status_lag2actual_ema3_ratio"
#  [606] "Visa_status_lag2actual_ema12_ratio"
#  [607] "Visa_fechaalta_lag2ema3_ema6_ratio"
#  [608] "Visa_fechaalta_lag2actual_ema6_ratio"
#  [609] "Visa_fechaalta_lag2actual_ema3_ratio"
#  [610] "Visa_fechaalta_lag2actual_ema12_ratio"
#  [611] "Visa_mpagominimo_lag2ema3_ema6_ratio"
#  [612] "Visa_mpagominimo_lag2actual_ema6_ratio"
#  [613] "Visa_mpagominimo_lag2actual_ema3_ratio"
#  [614] "Visa_mpagominimo_lag2actual_ema12_ratio"
#  [615] "kmes_lag2ema3_ema6_ratio"
#  [616] "kmes_lag2actual_ema6_ratio"
#  [617] "kmes_lag2actual_ema3_ratio"
#  [618] "kmes_lag2actual_ema12_ratio"
#  [619] "mpayroll_sobre_edad_lag2ema3_ema6_ratio"
#  [620] "mpayroll_sobre_edad_lag2actual_ema6_ratio"
#  [621] "mpayroll_sobre_edad_lag2actual_ema3_ratio"
#  [622] "mpayroll_sobre_edad_lag2actual_ema12_ratio"
#  [623] "internet_lag3ema3_ema6_ratio"
#  [624] "internet_lag3actual_ema6_ratio"
#  [625] "internet_lag3actual_ema3_ratio"
#  [626] "internet_lag3actual_ema12_ratio"
#  [627] "cliente_edad_lag3ema3_ema6_ratio"
#  [628] "cliente_edad_lag3actual_ema6_ratio"
#  [629] "cliente_edad_lag3actual_ema3_ratio"
#  [630] "cliente_edad_lag3actual_ema12_ratio"
#  [631] "cliente_antiguedad_lag3ema3_ema6_ratio"
#  [632] "cliente_antiguedad_lag3actual_ema6_ratio"
#  [633] "cliente_antiguedad_lag3actual_ema3_ratio"
#  [634] "cliente_antiguedad_lag3actual_ema12_ratio"
#  [635] "mrentabilidad_lag3ema3_ema6_ratio"
#  [636] "mrentabilidad_lag3actual_ema6_ratio"
#  [637] "mrentabilidad_lag3actual_ema3_ratio"
#  [638] "mrentabilidad_lag3actual_ema12_ratio"
#  [639] "mrentabilidad_annual_lag3ema3_ema6_ratio"
#  [640] "mrentabilidad_annual_lag3actual_ema6_ratio"
#  [641] "mrentabilidad_annual_lag3actual_ema3_ratio"
#  [642] "mrentabilidad_annual_lag3actual_ema12_ratio"
#  [643] "mcomisiones_lag3ema3_ema6_ratio"
#  [644] "mcomisiones_lag3actual_ema6_ratio"
#  [645] "mcomisiones_lag3actual_ema3_ratio"
#  [646] "mcomisiones_lag3actual_ema12_ratio"
#  [647] "mactivos_margen_lag3ema3_ema6_ratio"
#  [648] "mactivos_margen_lag3actual_ema6_ratio"
#  [649] "mactivos_margen_lag3actual_ema3_ratio"
#  [650] "mactivos_margen_lag3actual_ema12_ratio"
#  [651] "mpasivos_margen_lag3ema3_ema6_ratio"
#  [652] "mpasivos_margen_lag3actual_ema6_ratio"
#  [653] "mpasivos_margen_lag3actual_ema3_ratio"
#  [654] "mpasivos_margen_lag3actual_ema12_ratio"
#  [655] "cproductos_lag3ema3_ema6_ratio"
#  [656] "cproductos_lag3actual_ema6_ratio"
#  [657] "cproductos_lag3actual_ema3_ratio"
#  [658] "cproductos_lag3actual_ema12_ratio"
#  [659] "mcuenta_corriente_lag3ema3_ema6_ratio"
#  [660] "mcuenta_corriente_lag3actual_ema6_ratio"
#  [661] "mcuenta_corriente_lag3actual_ema3_ratio"
#  [662] "mcuenta_corriente_lag3actual_ema12_ratio"
#  [663] "mcaja_ahorro_lag3ema3_ema6_ratio"
#  [664] "mcaja_ahorro_lag3actual_ema6_ratio"
#  [665] "mcaja_ahorro_lag3actual_ema3_ratio"
#  [666] "mcaja_ahorro_lag3actual_ema12_ratio"
#  [667] "cdescubierto_preacordado_lag3ema3_ema6_ratio"
#  [668] "cdescubierto_preacordado_lag3actual_ema6_ratio"
#  [669] "cdescubierto_preacordado_lag3actual_ema3_ratio"
#  [670] "cdescubierto_preacordado_lag3actual_ema12_ratio"
#  [671] "mcuentas_saldo_lag3ema3_ema6_ratio"
#  [672] "mcuentas_saldo_lag3actual_ema6_ratio"
#  [673] "mcuentas_saldo_lag3actual_ema3_ratio"
#  [674] "mcuentas_saldo_lag3actual_ema12_ratio"
#  [675] "ctarjeta_visa_transacciones_lag3ema3_ema6_ratio"
#  [676] "ctarjeta_visa_transacciones_lag3actual_ema6_ratio"
#  [677] "ctarjeta_visa_transacciones_lag3actual_ema3_ratio"
#  [678] "ctarjeta_visa_transacciones_lag3actual_ema12_ratio"
#  [679] "mtarjeta_visa_consumo_lag3ema3_ema6_ratio"
#  [680] "mtarjeta_visa_consumo_lag3actual_ema6_ratio"
#  [681] "mtarjeta_visa_consumo_lag3actual_ema3_ratio"
#  [682] "mtarjeta_visa_consumo_lag3actual_ema12_ratio"
#  [683] "mtarjeta_master_consumo_lag3ema3_ema6_ratio"
#  [684] "mtarjeta_master_consumo_lag3actual_ema6_ratio"
#  [685] "mtarjeta_master_consumo_lag3actual_ema3_ratio"
#  [686] "mtarjeta_master_consumo_lag3actual_ema12_ratio"
#  [687] "mprestamos_personales_lag3ema3_ema6_ratio"
#  [688] "mprestamos_personales_lag3actual_ema6_ratio"
#  [689] "mprestamos_personales_lag3actual_ema3_ratio"
#  [690] "mprestamos_personales_lag3actual_ema12_ratio"
#  [691] "cpayroll_trx_lag3ema3_ema6_ratio"
#  [692] "cpayroll_trx_lag3actual_ema6_ratio"
#  [693] "cpayroll_trx_lag3actual_ema3_ratio"
#  [694] "cpayroll_trx_lag3actual_ema12_ratio"
#  [695] "mpayroll_lag3ema3_ema6_ratio"
#  [696] "mpayroll_lag3actual_ema6_ratio"
#  [697] "mpayroll_lag3actual_ema3_ratio"
#  [698] "mpayroll_lag3actual_ema12_ratio"
#  [699] "ccomisiones_mantenimiento_lag3ema3_ema6_ratio"
#  [700] "ccomisiones_mantenimiento_lag3actual_ema6_ratio"
#  [701] "ccomisiones_mantenimiento_lag3actual_ema3_ratio"
#  [702] "ccomisiones_mantenimiento_lag3actual_ema12_ratio"
#  [703] "ccallcenter_transacciones_lag3ema3_ema6_ratio"
#  [704] "ccallcenter_transacciones_lag3actual_ema6_ratio"
#  [705] "ccallcenter_transacciones_lag3actual_ema3_ratio"
#  [706] "ccallcenter_transacciones_lag3actual_ema12_ratio"
#  [707] "chomebanking_transacciones_lag3ema3_ema6_ratio"
#  [708] "chomebanking_transacciones_lag3actual_ema6_ratio"
#  [709] "chomebanking_transacciones_lag3actual_ema3_ratio"
#  [710] "chomebanking_transacciones_lag3actual_ema12_ratio"
#  [711] "ctrx_quarter_lag3ema3_ema6_ratio"
#  [712] "ctrx_quarter_lag3actual_ema6_ratio"
#  [713] "ctrx_quarter_lag3actual_ema3_ratio"
#  [714] "ctrx_quarter_lag3actual_ema12_ratio"
#  [715] "Master_status_lag3ema3_ema6_ratio"
#  [716] "Master_status_lag3actual_ema6_ratio"
#  [717] "Master_status_lag3actual_ema3_ratio"
#  [718] "Master_status_lag3actual_ema12_ratio"
#  [719] "Master_fechaalta_lag3ema3_ema6_ratio"
#  [720] "Master_fechaalta_lag3actual_ema6_ratio"
#  [721] "Master_fechaalta_lag3actual_ema3_ratio"
#  [722] "Master_fechaalta_lag3actual_ema12_ratio"
#  [723] "Master_mpagominimo_lag3ema3_ema6_ratio"
#  [724] "Master_mpagominimo_lag3actual_ema6_ratio"
#  [725] "Master_mpagominimo_lag3actual_ema3_ratio"
#  [726] "Master_mpagominimo_lag3actual_ema12_ratio"
#  [727] "Visa_status_lag3ema3_ema6_ratio"
#  [728] "Visa_status_lag3actual_ema6_ratio"
#  [729] "Visa_status_lag3actual_ema3_ratio"
#  [730] "Visa_status_lag3actual_ema12_ratio"
#  [731] "Visa_fechaalta_lag3ema3_ema6_ratio"
#  [732] "Visa_fechaalta_lag3actual_ema6_ratio"
#  [733] "Visa_fechaalta_lag3actual_ema3_ratio"
#  [734] "Visa_fechaalta_lag3actual_ema12_ratio"
#  [735] "Visa_mpagominimo_lag3ema3_ema6_ratio"
#  [736] "Visa_mpagominimo_lag3actual_ema6_ratio"
#  [737] "Visa_mpagominimo_lag3actual_ema3_ratio"
#  [738] "Visa_mpagominimo_lag3actual_ema12_ratio"
#  [739] "kmes_lag3ema3_ema6_ratio"
#  [740] "kmes_lag3actual_ema6_ratio"
#  [741] "kmes_lag3actual_ema3_ratio"
#  [742] "kmes_lag3actual_ema12_ratio"
#  [743] "mpayroll_sobre_edad_lag3ema3_ema6_ratio"
#  [744] "mpayroll_sobre_edad_lag3actual_ema6_ratio"
#  [745] "mpayroll_sobre_edad_lag3actual_ema3_ratio"
#  [746] "mpayroll_sobre_edad_lag3actual_ema12_ratio"
#  [747] "internet_lag4ema3_ema6_ratio"
#  [748] "internet_lag4actual_ema6_ratio"
#  [749] "internet_lag4actual_ema3_ratio"
#  [750] "internet_lag4actual_ema12_ratio"
#  [751] "cliente_edad_lag4ema3_ema6_ratio"
#  [752] "cliente_edad_lag4actual_ema6_ratio"
#  [753] "cliente_edad_lag4actual_ema3_ratio"
#  [754] "cliente_edad_lag4actual_ema12_ratio"
#  [755] "cliente_antiguedad_lag4ema3_ema6_ratio"
#  [756] "cliente_antiguedad_lag4actual_ema6_ratio"
#  [757] "cliente_antiguedad_lag4actual_ema3_ratio"
#  [758] "cliente_antiguedad_lag4actual_ema12_ratio"
#  [759] "mrentabilidad_lag4ema3_ema6_ratio"
#  [760] "mrentabilidad_lag4actual_ema6_ratio"
#  [761] "mrentabilidad_lag4actual_ema3_ratio"
#  [762] "mrentabilidad_lag4actual_ema12_ratio"
#  [763] "mrentabilidad_annual_lag4ema3_ema6_ratio"
#  [764] "mrentabilidad_annual_lag4actual_ema6_ratio"
#  [765] "mrentabilidad_annual_lag4actual_ema3_ratio"
#  [766] "mrentabilidad_annual_lag4actual_ema12_ratio"
#  [767] "mcomisiones_lag4ema3_ema6_ratio"
#  [768] "mcomisiones_lag4actual_ema6_ratio"
#  [769] "mcomisiones_lag4actual_ema3_ratio"
#  [770] "mcomisiones_lag4actual_ema12_ratio"
#  [771] "mactivos_margen_lag4ema3_ema6_ratio"
#  [772] "mactivos_margen_lag4actual_ema6_ratio"
#  [773] "mactivos_margen_lag4actual_ema3_ratio"
#  [774] "mactivos_margen_lag4actual_ema12_ratio"
# ...
# [1117] "mpayroll_sobre_edad_lag6actual_ema3_ratio"
# [1118] "mpayroll_sobre_edad_lag6actual_ema12_ratio"
# [1119] "internet_delta1ema3_ema6_ratio"
# [1120] "internet_delta1actual_ema6_ratio"
# [1121] "internet_delta1actual_ema3_ratio"
# [1122] "internet_delta1actual_ema12_ratio"
# [1123] "internet_delta2ema3_ema6_ratio"
# [1124] "internet_delta2actual_ema6_ratio"
# [1125] "internet_delta2actual_ema3_ratio"
# [1126] "internet_delta2actual_ema12_ratio"
# [1127] "cliente_edad_delta1ema3_ema6_ratio"
# [1128] "cliente_edad_delta1actual_ema6_ratio"
# [1129] "cliente_edad_delta1actual_ema3_ratio"
# [1130] "cliente_edad_delta1actual_ema12_ratio"
# [1131] "cliente_edad_delta2ema3_ema6_ratio"
# [1132] "cliente_edad_delta2actual_ema6_ratio"
# [1133] "cliente_edad_delta2actual_ema3_ratio"
# [1134] "cliente_edad_delta2actual_ema12_ratio"
# [1135] "cliente_antiguedad_delta1ema3_ema6_ratio"
# [1136] "cliente_antiguedad_delta1actual_ema6_ratio"
# [1137] "cliente_antiguedad_delta1actual_ema3_ratio"
# [1138] "cliente_antiguedad_delta1actual_ema12_ratio"
# [1139] "cliente_antiguedad_delta2ema3_ema6_ratio"
# [1140] "cliente_antiguedad_delta2actual_ema6_ratio"
# [1141] "cliente_antiguedad_delta2actual_ema3_ratio"
# [1142] "cliente_antiguedad_delta2actual_ema12_ratio"
# [1143] "mrentabilidad_delta1ema3_ema6_ratio"
# [1144] "mrentabilidad_delta1actual_ema6_ratio"
# [1145] "mrentabilidad_delta1actual_ema3_ratio"
# [1146] "mrentabilidad_delta1actual_ema12_ratio"
# [1147] "mrentabilidad_delta2ema3_ema6_ratio"
# [1148] "mrentabilidad_delta2actual_ema6_ratio"
# [1149] "mrentabilidad_delta2actual_ema3_ratio"
# [1150] "mrentabilidad_delta2actual_ema12_ratio"
# [1151] "mrentabilidad_annual_delta1ema3_ema6_ratio"
# [1152] "mrentabilidad_annual_delta1actual_ema6_ratio"
# [1153] "mrentabilidad_annual_delta1actual_ema3_ratio"
# [1154] "mrentabilidad_annual_delta1actual_ema12_ratio"
# [1155] "mrentabilidad_annual_delta2ema3_ema6_ratio"
# [1156] "mrentabilidad_annual_delta2actual_ema6_ratio"
# [1157] "mrentabilidad_annual_delta2actual_ema3_ratio"
# [1158] "mrentabilidad_annual_delta2actual_ema12_ratio"
# [1159] "mcomisiones_delta1ema3_ema6_ratio"
# [1160] "mcomisiones_delta1actual_ema6_ratio"
# [1161] "mcomisiones_delta1actual_ema3_ratio"
# [1162] "mcomisiones_delta1actual_ema12_ratio"
# [1163] "mcomisiones_delta2ema3_ema6_ratio"
# [1164] "mcomisiones_delta2actual_ema6_ratio"
# [1165] "mcomisiones_delta2actual_ema3_ratio"
# [1166] "mcomisiones_delta2actual_ema12_ratio"
# [1167] "mactivos_margen_delta1ema3_ema6_ratio"
# [1168] "mactivos_margen_delta1actual_ema6_ratio"
# [1169] "mactivos_margen_delta1actual_ema3_ratio"
# [1170] "mactivos_margen_delta1actual_ema12_ratio"
# [1171] "mactivos_margen_delta2ema3_ema6_ratio"
# [1172] "mactivos_margen_delta2actual_ema6_ratio"
# [1173] "mactivos_margen_delta2actual_ema3_ratio"
# [1174] "mactivos_margen_delta2actual_ema12_ratio"
# [1175] "mpasivos_margen_delta1ema3_ema6_ratio"
# [1176] "mpasivos_margen_delta1actual_ema6_ratio"
# [1177] "mpasivos_margen_delta1actual_ema3_ratio"
# [1178] "mpasivos_margen_delta1actual_ema12_ratio"
# [1179] "mpasivos_margen_delta2ema3_ema6_ratio"
# [1180] "mpasivos_margen_delta2actual_ema6_ratio"
# [1181] "mpasivos_margen_delta2actual_ema3_ratio"
# [1182] "mpasivos_margen_delta2actual_ema12_ratio"
# [1183] "cproductos_delta1ema3_ema6_ratio"
# [1184] "cproductos_delta1actual_ema6_ratio"
# [1185] "cproductos_delta1actual_ema3_ratio"
# [1186] "cproductos_delta1actual_ema12_ratio"
# [1187] "cproductos_delta2ema3_ema6_ratio"
# [1188] "cproductos_delta2actual_ema6_ratio"
# [1189] "cproductos_delta2actual_ema3_ratio"
# [1190] "cproductos_delta2actual_ema12_ratio"
# [1191] "mcuenta_corriente_delta1ema3_ema6_ratio"
# [1192] "mcuenta_corriente_delta1actual_ema6_ratio"
# [1193] "mcuenta_corriente_delta1actual_ema3_ratio"
# [1194] "mcuenta_corriente_delta1actual_ema12_ratio"
# [1195] "mcuenta_corriente_delta2ema3_ema6_ratio"
# [1196] "mcuenta_corriente_delta2actual_ema6_ratio"
# [1197] "mcuenta_corriente_delta2actual_ema3_ratio"
# [1198] "mcuenta_corriente_delta2actual_ema12_ratio"
# [1199] "mcaja_ahorro_delta1ema3_ema6_ratio"
# [1200] "mcaja_ahorro_delta1actual_ema6_ratio"
# [1201] "mcaja_ahorro_delta1actual_ema3_ratio"
# [1202] "mcaja_ahorro_delta1actual_ema12_ratio"
# [1203] "mcaja_ahorro_delta2ema3_ema6_ratio"
# [1204] "mcaja_ahorro_delta2actual_ema6_ratio"
# [1205] "mcaja_ahorro_delta2actual_ema3_ratio"
# [1206] "mcaja_ahorro_delta2actual_ema12_ratio"
# [1207] "cdescubierto_preacordado_delta1ema3_ema6_ratio"
# [1208] "cdescubierto_preacordado_delta1actual_ema6_ratio"
# [1209] "cdescubierto_preacordado_delta1actual_ema3_ratio"
# [1210] "cdescubierto_preacordado_delta1actual_ema12_ratio"
# [1211] "cdescubierto_preacordado_delta2ema3_ema6_ratio"
# [1212] "cdescubierto_preacordado_delta2actual_ema6_ratio"
# [1213] "cdescubierto_preacordado_delta2actual_ema3_ratio"
# [1214] "cdescubierto_preacordado_delta2actual_ema12_ratio"
# [1215] "mcuentas_saldo_delta1ema3_ema6_ratio"
# [1216] "mcuentas_saldo_delta1actual_ema6_ratio"
# [1217] "mcuentas_saldo_delta1actual_ema3_ratio"
# [1218] "mcuentas_saldo_delta1actual_ema12_ratio"
# [1219] "mcuentas_saldo_delta2ema3_ema6_ratio"
# [1220] "mcuentas_saldo_delta2actual_ema6_ratio"
# [1221] "mcuentas_saldo_delta2actual_ema3_ratio"
# [1222] "mcuentas_saldo_delta2actual_ema12_ratio"
# [1223] "ctarjeta_visa_transacciones_delta1ema3_ema6_ratio"
# [1224] "ctarjeta_visa_transacciones_delta1actual_ema6_ratio"
# [1225] "ctarjeta_visa_transacciones_delta1actual_ema3_ratio"
# [1226] "ctarjeta_visa_transacciones_delta1actual_ema12_ratio"
# [1227] "ctarjeta_visa_transacciones_delta2ema3_ema6_ratio"
# [1228] "ctarjeta_visa_transacciones_delta2actual_ema6_ratio"
# [1229] "ctarjeta_visa_transacciones_delta2actual_ema3_ratio"
# [1230] "ctarjeta_visa_transacciones_delta2actual_ema12_ratio"
# [1231] "mtarjeta_visa_consumo_delta1ema3_ema6_ratio"
# [1232] "mtarjeta_visa_consumo_delta1actual_ema6_ratio"
# [1233] "mtarjeta_visa_consumo_delta1actual_ema3_ratio"
# [1234] "mtarjeta_visa_consumo_delta1actual_ema12_ratio"
# [1235] "mtarjeta_visa_consumo_delta2ema3_ema6_ratio"
# [1236] "mtarjeta_visa_consumo_delta2actual_ema6_ratio"
# [1237] "mtarjeta_visa_consumo_delta2actual_ema3_ratio"
# [1238] "mtarjeta_visa_consumo_delta2actual_ema12_ratio"
# [1239] "mtarjeta_master_consumo_delta1ema3_ema6_ratio"
# [1240] "mtarjeta_master_consumo_delta1actual_ema6_ratio"
# [1241] "mtarjeta_master_consumo_delta1actual_ema3_ratio"
# [1242] "mtarjeta_master_consumo_delta1actual_ema12_ratio"
# [1243] "mtarjeta_master_consumo_delta2ema3_ema6_ratio"
# [1244] "mtarjeta_master_consumo_delta2actual_ema6_ratio"
# [1245] "mtarjeta_master_consumo_delta2actual_ema3_ratio"
# [1246] "mtarjeta_master_consumo_delta2actual_ema12_ratio"
# [1247] "mprestamos_personales_delta1ema3_ema6_ratio"
# [1248] "mprestamos_personales_delta1actual_ema6_ratio"
# [1249] "mprestamos_personales_delta1actual_ema3_ratio"
# [1250] "mprestamos_personales_delta1actual_ema12_ratio"
# [1251] "mprestamos_personales_delta2ema3_ema6_ratio"
# [1252] "mprestamos_personales_delta2actual_ema6_ratio"
# [1253] "mprestamos_personales_delta2actual_ema3_ratio"
# [1254] "mprestamos_personales_delta2actual_ema12_ratio"
# [1255] "cpayroll_trx_delta1ema3_ema6_ratio"
# [1256] "cpayroll_trx_delta1actual_ema6_ratio"
# [1257] "cpayroll_trx_delta1actual_ema3_ratio"
# [1258] "cpayroll_trx_delta1actual_ema12_ratio"
# [1259] "cpayroll_trx_delta2ema3_ema6_ratio"
# [1260] "cpayroll_trx_delta2actual_ema6_ratio"
# [1261] "cpayroll_trx_delta2actual_ema3_ratio"
# [1262] "cpayroll_trx_delta2actual_ema12_ratio"
# [1263] "mpayroll_delta1ema3_ema6_ratio"
# [1264] "mpayroll_delta1actual_ema6_ratio"
# [1265] "mpayroll_delta1actual_ema3_ratio"
# [1266] "mpayroll_delta1actual_ema12_ratio"
# [1267] "mpayroll_delta2ema3_ema6_ratio"
# [1268] "mpayroll_delta2actual_ema6_ratio"
# [1269] "mpayroll_delta2actual_ema3_ratio"
# [1270] "mpayroll_delta2actual_ema12_ratio"
# [1271] "ccomisiones_mantenimiento_delta1ema3_ema6_ratio"
# [1272] "ccomisiones_mantenimiento_delta1actual_ema6_ratio"
# [1273] "ccomisiones_mantenimiento_delta1actual_ema3_ratio"
# [1274] "ccomisiones_mantenimiento_delta1actual_ema12_ratio"
# [1275] "ccomisiones_mantenimiento_delta2ema3_ema6_ratio"
# [1276] "ccomisiones_mantenimiento_delta2actual_ema6_ratio"
# [1277] "ccomisiones_mantenimiento_delta2actual_ema3_ratio"
# [1278] "ccomisiones_mantenimiento_delta2actual_ema12_ratio"
# [1279] "ccallcenter_transacciones_delta1ema3_ema6_ratio"
# [1280] "ccallcenter_transacciones_delta1actual_ema6_ratio"
# [1281] "ccallcenter_transacciones_delta1actual_ema3_ratio"
# [1282] "ccallcenter_transacciones_delta1actual_ema12_ratio"
# [1283] "ccallcenter_transacciones_delta2ema3_ema6_ratio"
# [1284] "ccallcenter_transacciones_delta2actual_ema6_ratio"
# [1285] "ccallcenter_transacciones_delta2actual_ema3_ratio"
# [1286] "ccallcenter_transacciones_delta2actual_ema12_ratio"
# [1287] "chomebanking_transacciones_delta1ema3_ema6_ratio"
# [1288] "chomebanking_transacciones_delta1actual_ema6_ratio"
# [1289] "chomebanking_transacciones_delta1actual_ema3_ratio"
# [1290] "chomebanking_transacciones_delta1actual_ema12_ratio"
# [1291] "chomebanking_transacciones_delta2ema3_ema6_ratio"
# [1292] "chomebanking_transacciones_delta2actual_ema6_ratio"
# [1293] "chomebanking_transacciones_delta2actual_ema3_ratio"
# [1294] "chomebanking_transacciones_delta2actual_ema12_ratio"
# [1295] "ctrx_quarter_delta1ema3_ema6_ratio"
# [1296] "ctrx_quarter_delta1actual_ema6_ratio"
# [1297] "ctrx_quarter_delta1actual_ema3_ratio"
# [1298] "ctrx_quarter_delta1actual_ema12_ratio"
# [1299] "ctrx_quarter_delta2ema3_ema6_ratio"
# [1300] "ctrx_quarter_delta2actual_ema6_ratio"
# [1301] "ctrx_quarter_delta2actual_ema3_ratio"
# [1302] "ctrx_quarter_delta2actual_ema12_ratio"
# [1303] "Master_status_delta1ema3_ema6_ratio"
# [1304] "Master_status_delta1actual_ema6_ratio"
# [1305] "Master_status_delta1actual_ema3_ratio"
# [1306] "Master_status_delta1actual_ema12_ratio"
# [1307] "Master_status_delta2ema3_ema6_ratio"
# [1308] "Master_status_delta2actual_ema6_ratio"
# [1309] "Master_status_delta2actual_ema3_ratio"
# [1310] "Master_status_delta2actual_ema12_ratio"
# [1311] "Master_fechaalta_delta1ema3_ema6_ratio"
# [1312] "Master_fechaalta_delta1actual_ema6_ratio"
# [1313] "Master_fechaalta_delta1actual_ema3_ratio"
# [1314] "Master_fechaalta_delta1actual_ema12_ratio"
# [1315] "Master_fechaalta_delta2ema3_ema6_ratio"
# [1316] "Master_fechaalta_delta2actual_ema6_ratio"
# [1317] "Master_fechaalta_delta2actual_ema3_ratio"
# [1318] "Master_fechaalta_delta2actual_ema12_ratio"
# [1319] "Master_mpagominimo_delta1ema3_ema6_ratio"
# [1320] "Master_mpagominimo_delta1actual_ema6_ratio"
# [1321] "Master_mpagominimo_delta1actual_ema3_ratio"
# [1322] "Master_mpagominimo_delta1actual_ema12_ratio"
# [1323] "Master_mpagominimo_delta2ema3_ema6_ratio"
# [1324] "Master_mpagominimo_delta2actual_ema6_ratio"
# [1325] "Master_mpagominimo_delta2actual_ema3_ratio"
# [1326] "Master_mpagominimo_delta2actual_ema12_ratio"
# [1327] "Visa_status_delta1ema3_ema6_ratio"
# [1328] "Visa_status_delta1actual_ema6_ratio"
# [1329] "Visa_status_delta1actual_ema3_ratio"
# [1330] "Visa_status_delta1actual_ema12_ratio"
# [1331] "Visa_status_delta2ema3_ema6_ratio"
# [1332] "Visa_status_delta2actual_ema6_ratio"
# [1333] "Visa_status_delta2actual_ema3_ratio"
# [1334] "Visa_status_delta2actual_ema12_ratio"
# [1335] "Visa_fechaalta_delta1ema3_ema6_ratio"
# [1336] "Visa_fechaalta_delta1actual_ema6_ratio"
# [1337] "Visa_fechaalta_delta1actual_ema3_ratio"
# [1338] "Visa_fechaalta_delta1actual_ema12_ratio"
# [1339] "Visa_fechaalta_delta2ema3_ema6_ratio"
# [1340] "Visa_fechaalta_delta2actual_ema6_ratio"
# [1341] "Visa_fechaalta_delta2actual_ema3_ratio"
# [1342] "Visa_fechaalta_delta2actual_ema12_ratio"
# [1343] "Visa_mpagominimo_delta1ema3_ema6_ratio"
# [1344] "Visa_mpagominimo_delta1actual_ema6_ratio"
# [1345] "Visa_mpagominimo_delta1actual_ema3_ratio"
# [1346] "Visa_mpagominimo_delta1actual_ema12_ratio"
# [1347] "Visa_mpagominimo_delta2ema3_ema6_ratio"
# [1348] "Visa_mpagominimo_delta2actual_ema6_ratio"
# [1349] "Visa_mpagominimo_delta2actual_ema3_ratio"
# [1350] "Visa_mpagominimo_delta2actual_ema12_ratio"
# [1351] "kmes_delta1ema3_ema6_ratio"
# [1352] "kmes_delta1actual_ema6_ratio"
# [1353] "kmes_delta1actual_ema3_ratio"
# [1354] "kmes_delta1actual_ema12_ratio"
# [1355] "kmes_delta2ema3_ema6_ratio"
# [1356] "kmes_delta2actual_ema6_ratio"
# [1357] "kmes_delta2actual_ema3_ratio"
# [1358] "kmes_delta2actual_ema12_ratio"
# [1359] "mpayroll_sobre_edad_delta1ema3_ema6_ratio"
# [1360] "mpayroll_sobre_edad_delta1actual_ema6_ratio"
# [1361] "mpayroll_sobre_edad_delta1actual_ema3_ratio"
# [1362] "mpayroll_sobre_edad_delta1actual_ema12_ratio"
# [1363] "mpayroll_sobre_edad_delta2ema3_ema6_ratio"
# [1364] "mpayroll_sobre_edad_delta2actual_ema6_ratio"
# [1365] "mpayroll_sobre_edad_delta2actual_ema3_ratio"
# [1366] "mpayroll_sobre_edad_delta2actual_ema12_ratio"
# [1367] "mrentabilidad_mean6"
# [1368] "mtarjeta_visa_consumo_mean6"
# [1369] "mcuentas_saldo_mean6"
# [1370] "cpayroll_trx_mean6"
# [1371] "mrentabilidad_sd6"
# [1372] "mtarjeta_visa_consumo_sd6"
# [1373] "mcuentas_saldo_sd6"
# [1374] "cpayroll_trx_sd6"

# %% [markdown]
# #### 6.3.1.6  FEhist Reduccion dimensionalidad con canaritos
#
# Esta etapa solo se mostrará a la *modalidad Anlista Sr* por algun canal secreto de forma de no confundir a los *Analista Jr*  nni distraer con detalles operativos a la estratégica *Modalidad Gerencial*

# %%
# No se implementa la reduccion de la dimensionalidad con canaritos
if( !require("lightgbm")) install.packages("lightgbm")
require("lightgbm")
# Out:
# Loading required package: lightgbm
#
# Warning message in library(package, lib.loc = lib.loc, character.only = TRUE, logical.return = TRUE, :
# “there is no package called ‘lightgbm’”
# Installing package into ‘/usr/local/lib/R/site-library’
# (as ‘lib’ is unspecified)
#
# Loading required package: lightgbm

# %%
VPOS_CORTE <- c()

fganancia_lgbm_meseta <- function(probs, datos) {
  vlabels <- get_field(datos, "label")
  vpesos <- get_field(datos, "weight")

  tbl <- as.data.table(list(
    "prob" = probs,
    "gan" = ifelse(vlabels == 1 & vpesos > 1, PARAM$CN$train$gan1, PARAM$CN$train$gan0)
  ))

  setorder(tbl, -prob)
  tbl[, posicion := .I]
  tbl[, gan_acum := cumsum(gan)]
  setorder(tbl, -gan_acum) # voy por la meseta

  gan <- mean(tbl[1:500, gan_acum]) # meseta de tamaño 500

  pos_meseta <- tbl[1:500, median(posicion)]
  VPOS_CORTE <<- c(VPOS_CORTE, pos_meseta)

  return(list(
    "name" = "ganancia",
    "value" = gan,
    "higher_better" = TRUE
  ))
}


# Elimina del dataset las variables que estan por debajo
#  de la capa geologica de canaritos
# se llama varias veces, luego de agregar muchas variables nuevas,
#  para ir reduciendo la cantidad de variables
# y así hacer lugar a nuevas variables importantes

GVEZ <- 1

campitos <- c( "numero_de_cliente", "foto_mes", "clase_ternaria" )

CanaritosAsesinos <- function(
  canaritos_ratio,
  canaritos_desvios,
  canaritos_semilla) {

  cat( "inicio CanaritosAsesinos()\n")
  gc(verbose= FALSE)
  dataset[, clase01 := 0L ]
  dataset[ clase_ternaria %in% PARAM$CN$train$clase01_valor1,
      clase01 := 1L ]

  set.seed(canaritos_semilla, kind = "L'Ecuyer-CMRG")
  for (i in 1:(ncol(dataset) * canaritos_ratio)) {
    dataset[, paste0("canarito", i) := runif(nrow(dataset))]
  }

  campos_buenos <- setdiff(
    colnames(dataset),
    c( campitos, "clase01")
  )

  azar <- runif(nrow(dataset))

  dataset[, entrenamiento :=
    as.integer( foto_mes %in% PARAM$CN$train$training &
      (clase01 == 1 | azar < PARAM$CN$train$undersampling))]

  dtrain <- lgb.Dataset(
    data = data.matrix(dataset[entrenamiento == TRUE, campos_buenos, with = FALSE]),
    label = dataset[entrenamiento == TRUE, clase01],
    weight = dataset[
      entrenamiento == TRUE,
      ifelse(clase_ternaria %in% PARAM$CN$train$positivos, 1.0000001, 1.0)
    ],
    free_raw_data = FALSE
  )

  dvalid <- lgb.Dataset(
    data = data.matrix(dataset[foto_mes %in% PARAM$CN$train$validation, campos_buenos, with = FALSE]),
    label = dataset[foto_mes %in% PARAM$CN$train$validation, clase01],
    weight = dataset[
      foto_mes %in% PARAM$CN$train$validation,
      ifelse( clase_ternaria %in% PARAM$CN$train$positivos, 1.0000001, 1.0)
    ],
    free_raw_data = FALSE
  )


  param <- list(
    objective = "binary",
    metric = "custom",
    first_metric_only = TRUE,
    boost_from_average = TRUE,
    feature_pre_filter = FALSE,
    verbosity = -100,
    seed = canaritos_semilla,
    max_depth = -1, # -1 significa no limitar,  por ahora lo dejo fijo
    min_gain_to_split = 0.0, # por ahora, lo dejo fijo
    lambda_l1 = 0.0, # por ahora, lo dejo fijo
    lambda_l2 = 0.0, # por ahora, lo dejo fijo
    max_bin = 31, # por ahora, lo dejo fijo
    num_iterations = 9999, # un numero grande, lo limita early_stopping_rounds
    force_row_wise = TRUE, # para que los alumnos no se atemoricen con  warning
    learning_rate = 0.065,
    feature_fraction = 1.0, # lo seteo en 1
    min_data_in_leaf = 260,
    num_leaves = 60,
    early_stopping_rounds = 200,
    num_threads = 1
  )

  set.seed(canaritos_semilla, kind = "L'Ecuyer-CMRG")
  modelo <- lgb.train(
    data = dtrain,
    valids = list(valid = dvalid),
    eval = fganancia_lgbm_meseta,
    param = param,
    verbose = -100
  )

  tb_importancia <- lgb.importance(model = modelo)
  tb_importancia[, pos := .I]

  fwrite(tb_importancia,
    file = paste0("impo_", GVEZ, ".txt"),
    sep = "\t"
  )

  GVEZ <<- GVEZ + 1

  umbral <- tb_importancia[
    Feature %like% "canarito",
    median(pos) + canaritos_desvios * sd(pos)
  ] # Atencion corto en la mediana mas desvios!!

  col_utiles <- tb_importancia[
    pos < umbral & !(Feature %like% "canarito"),
    Feature
  ]

  col_utiles <- unique(c(
    col_utiles,
    c(campitos, "mes")
  ))

  col_inutiles <- setdiff(colnames(dataset), col_utiles)

  dataset[, (col_inutiles) := NULL]

  cat( "fin CanaritosAsesinos()\n")

  return( tb_importancia )
}


# Estos DOS parametros son los que se deben modificar
PARAM$CN$ratio <- 0.1 # baje a 0.1 de 0.2
PARAM$CN$desvios <- 2


# Parametros quasi fijos
# Parametros de un LightGBM que se genera para estimar la column importance
PARAM$CN$train$clase01_valor1 <- c( "BAJA+2", "BAJA+1")
PARAM$CN$train$positivos <- c( "BAJA+2")
PARAM$CN$train$training <- c( 202101, 202102, 202103)
PARAM$CN$train$validation <- c( 202105 )
PARAM$CN$train$undersampling <- 0.1
PARAM$CN$train$gan1 <- 117000
PARAM$CN$train$gan0 <-  -3000

# la llamada a Canaritos Asesinos
tb_importancia <- CanaritosAsesinos(
  canaritos_ratio = PARAM$CN$ratio,
  canaritos_desvios = PARAM$CN$desvios,
  canaritos_semilla = PARAM$semilla_primigenia
)


# grabo la importancia, ver el archivo directamente en la carpeta

fwrite( tb_importancia,
  file="canaritos.txt",
  sep="\t"
)

# verifico
ncol(dataset)
colnames(dataset)
# Out:
# inicio CanaritosAsesinos()
# fin CanaritosAsesinos()
# [1] 399
#   [1] "numero_de_cliente"
#   [2] "foto_mes"
#   [3] "mrentabilidad"
#   [4] "mrentabilidad_annual"
#   [5] "mactivos_margen"
#   [6] "mpasivos_margen"
#   [7] "cproductos"
#   [8] "mcuenta_corriente"
#   [9] "mcaja_ahorro"
#  [10] "mcuentas_saldo"
#  [11] "ctarjeta_visa_transacciones"
#  [12] "mtarjeta_visa_consumo"
#  [13] "mtarjeta_master_consumo"
#  [14] "cpayroll_trx"
#  [15] "ccallcenter_transacciones"
#  [16] "chomebanking_transacciones"
#  [17] "ctrx_quarter"
#  [18] "Master_status"
#  [19] "Master_mpagominimo"
#  [20] "Visa_status"
#  [21] "Visa_fechaalta"
#  [22] "Visa_mpagominimo"
#  [23] "clase_ternaria"
#  [24] "mpayroll_sobre_edad"
#  [25] "cliente_antiguedad_lag1"
#  [26] "mrentabilidad_lag1"
#  [27] "mactivos_margen_lag1"
#  [28] "mpasivos_margen_lag1"
#  [29] "cproductos_lag1"
#  [30] "mcuenta_corriente_lag1"
#  [31] "mcaja_ahorro_lag1"
#  [32] "mcuentas_saldo_lag1"
#  [33] "mprestamos_personales_lag1"
#  [34] "Visa_fechaalta_lag1"
#  [35] "Visa_mpagominimo_lag1"
#  [36] "mrentabilidad_annual_lag2"
#  [37] "mcomisiones_lag2"
#  [38] "mactivos_margen_lag2"
#  [39] "mpasivos_margen_lag2"
#  [40] "cproductos_lag2"
#  [41] "mcuenta_corriente_lag2"
#  [42] "mcaja_ahorro_lag2"
#  [43] "mcuentas_saldo_lag2"
#  [44] "ctarjeta_visa_transacciones_lag2"
#  [45] "mpayroll_lag2"
#  [46] "chomebanking_transacciones_lag2"
#  [47] "Visa_fechaalta_lag2"
#  [48] "Visa_mpagominimo_lag2"
#  [49] "cliente_edad_lag3"
#  [50] "mrentabilidad_lag3"
#  [51] "mrentabilidad_annual_lag3"
#  [52] "mactivos_margen_lag3"
#  [53] "mpasivos_margen_lag3"
#  [54] "mcaja_ahorro_lag3"
#  [55] "mcuentas_saldo_lag3"
#  [56] "chomebanking_transacciones_lag3"
#  [57] "ctrx_quarter_lag3"
#  [58] "Master_fechaalta_lag3"
#  [59] "Master_mpagominimo_lag3"
#  [60] "Visa_fechaalta_lag3"
#  [61] "Visa_mpagominimo_lag3"
#  [62] "cliente_edad_lag4"
#  [63] "cliente_antiguedad_lag4"
#  [64] "mrentabilidad_lag4"
#  [65] "mrentabilidad_annual_lag4"
#  [66] "mcomisiones_lag4"
#  [67] "mactivos_margen_lag4"
#  [68] "mpasivos_margen_lag4"
#  [69] "cproductos_lag4"
#  [70] "mcuenta_corriente_lag4"
#  [71] "mcuentas_saldo_lag4"
#  [72] "mprestamos_personales_lag4"
#  [73] "ccomisiones_mantenimiento_lag4"
#  [74] "chomebanking_transacciones_lag4"
#  [75] "ctrx_quarter_lag4"
#  [76] "Visa_fechaalta_lag4"
#  [77] "cliente_edad_lag5"
#  [78] "mrentabilidad_lag5"
#  [79] "mrentabilidad_annual_lag5"
#  [80] "mcomisiones_lag5"
#  [81] "mactivos_margen_lag5"
#  [82] "mpasivos_margen_lag5"
#  [83] "cproductos_lag5"
#  [84] "mcuenta_corriente_lag5"
#  [85] "mcuentas_saldo_lag5"
#  [86] "ccomisiones_mantenimiento_lag5"
#  [87] "ctrx_quarter_lag5"
#  [88] "Visa_fechaalta_lag5"
#  [89] "cliente_edad_lag6"
#  [90] "cliente_antiguedad_lag6"
#  [91] "mrentabilidad_lag6"
#  [92] "mrentabilidad_annual_lag6"
#  [93] "mcomisiones_lag6"
#  [94] "mactivos_margen_lag6"
#  [95] "mpasivos_margen_lag6"
#  [96] "mcuenta_corriente_lag6"
#  [97] "mcaja_ahorro_lag6"
#  [98] "mcuentas_saldo_lag6"
#  [99] "ctarjeta_visa_transacciones_lag6"
# [100] "mprestamos_personales_lag6"
# [101] "mpayroll_lag6"
# [102] "ccomisiones_mantenimiento_lag6"
# [103] "chomebanking_transacciones_lag6"
# [104] "Master_fechaalta_lag6"
# [105] "Visa_fechaalta_lag6"
# [106] "Visa_mpagominimo_lag6"
# [107] "mpayroll_sobre_edad_lag6"
# [108] "mrentabilidad_delta1"
# [109] "mrentabilidad_delta2"
# [110] "mrentabilidad_annual_delta1"
# [111] "mrentabilidad_annual_delta2"
# [112] "mcomisiones_delta1"
# [113] "mcomisiones_delta2"
# [114] "mactivos_margen_delta1"
# [115] "mactivos_margen_delta2"
# [116] "mpasivos_margen_delta2"
# [117] "mcuenta_corriente_delta1"
# [118] "mcuenta_corriente_delta2"
# [119] "mcaja_ahorro_delta1"
# [120] "mcaja_ahorro_delta2"
# [121] "mcuentas_saldo_delta1"
# [122] "mcuentas_saldo_delta2"
# [123] "ctarjeta_visa_transacciones_delta2"
# [124] "mtarjeta_visa_consumo_delta2"
# [125] "mprestamos_personales_delta1"
# [126] "ccomisiones_mantenimiento_delta2"
# [127] "ccallcenter_transacciones_delta1"
# [128] "ccallcenter_transacciones_delta2"
# [129] "chomebanking_transacciones_delta1"
# [130] "chomebanking_transacciones_delta2"
# [131] "ctrx_quarter_delta1"
# [132] "ctrx_quarter_delta2"
# [133] "Visa_status_delta2"
# [134] "Visa_mpagominimo_delta1"
# [135] "Visa_mpagominimo_delta2"
# [136] "cproductosactual_ema6_ratio"
# [137] "cproductosactual_ema3_ratio"
# [138] "cproductosactual_ema12_ratio"
# [139] "mcuenta_corrienteactual_ema3_ratio"
# [140] "mcuenta_corrienteactual_ema12_ratio"
# [141] "mcaja_ahorroema3_ema6_ratio"
# [142] "mcaja_ahorroactual_ema6_ratio"
# [143] "mcaja_ahorroactual_ema12_ratio"
# [144] "mprestamos_personalesactual_ema6_ratio"
# [145] "mprestamos_personalesactual_ema3_ratio"
# [146] "mprestamos_personalesactual_ema12_ratio"
# [147] "cpayroll_trxactual_ema6_ratio"
# [148] "cpayroll_trxactual_ema3_ratio"
# [149] "cpayroll_trxactual_ema12_ratio"
# [150] "mpayrollema3_ema6_ratio"
# [151] "mpayrollactual_ema6_ratio"
# [152] "mpayrollactual_ema12_ratio"
# [153] "ccomisiones_mantenimientoema3_ema6_ratio"
# [154] "ccomisiones_mantenimientoactual_ema6_ratio"
# [155] "ccomisiones_mantenimientoactual_ema3_ratio"
# [156] "ccomisiones_mantenimientoactual_ema12_ratio"
# [157] "ctrx_quarterema3_ema6_ratio"
# [158] "ctrx_quarteractual_ema6_ratio"
# [159] "ctrx_quarteractual_ema3_ratio"
# [160] "ctrx_quarteractual_ema12_ratio"
# [161] "Master_mpagominimoema3_ema6_ratio"
# [162] "Master_mpagominimoactual_ema6_ratio"
# [163] "Master_mpagominimoactual_ema3_ratio"
# [164] "Visa_mpagominimoactual_ema6_ratio"
# [165] "Visa_mpagominimoactual_ema3_ratio"
# [166] "Visa_mpagominimoactual_ema12_ratio"
# [167] "kmesactual_ema6_ratio"
# [168] "mpayroll_sobre_edadactual_ema3_ratio"
# [169] "cliente_edad_lag1ema3_ema6_ratio"
# [170] "cliente_edad_lag1actual_ema6_ratio"
# [171] "cliente_edad_lag1actual_ema3_ratio"
# [172] "cliente_edad_lag1actual_ema12_ratio"
# [173] "cliente_antiguedad_lag1ema3_ema6_ratio"
# [174] "mcuenta_corriente_lag1actual_ema3_ratio"
# [175] "mcuenta_corriente_lag1actual_ema12_ratio"
# [176] "mcaja_ahorro_lag1ema3_ema6_ratio"
# [177] "mcaja_ahorro_lag1actual_ema12_ratio"
# [178] "cpayroll_trx_lag1actual_ema3_ratio"
# [179] "mpayroll_lag1ema3_ema6_ratio"
# [180] "ccomisiones_mantenimiento_lag1ema3_ema6_ratio"
# [181] "ccomisiones_mantenimiento_lag1actual_ema6_ratio"
# [182] "ctrx_quarter_lag1ema3_ema6_ratio"
# [183] "ctrx_quarter_lag1actual_ema6_ratio"
# [184] "ctrx_quarter_lag1actual_ema3_ratio"
# [185] "Master_fechaalta_lag1actual_ema3_ratio"
# [186] "Master_mpagominimo_lag1ema3_ema6_ratio"
# [187] "Visa_mpagominimo_lag1ema3_ema6_ratio"
# [188] "Visa_mpagominimo_lag1actual_ema12_ratio"
# [189] "cliente_edad_lag2ema3_ema6_ratio"
# [190] "cliente_edad_lag2actual_ema12_ratio"
# [191] "cliente_antiguedad_lag2actual_ema12_ratio"
# [192] "mcuenta_corriente_lag2ema3_ema6_ratio"
# [193] "mcuenta_corriente_lag2actual_ema6_ratio"
# [194] "mcuenta_corriente_lag2actual_ema3_ratio"
# [195] "mcuenta_corriente_lag2actual_ema12_ratio"
# [196] "mcaja_ahorro_lag2ema3_ema6_ratio"
# [197] "mcaja_ahorro_lag2actual_ema3_ratio"
# [198] "mcaja_ahorro_lag2actual_ema12_ratio"
# [199] "ccomisiones_mantenimiento_lag2actual_ema12_ratio"
# [200] "ctrx_quarter_lag2ema3_ema6_ratio"
# [201] "ctrx_quarter_lag2actual_ema6_ratio"
# [202] "ctrx_quarter_lag2actual_ema3_ratio"
# [203] "ctrx_quarter_lag2actual_ema12_ratio"
# [204] "Master_fechaalta_lag2ema3_ema6_ratio"
# [205] "Master_fechaalta_lag2actual_ema6_ratio"
# [206] "Master_mpagominimo_lag2ema3_ema6_ratio"
# [207] "Visa_mpagominimo_lag2ema3_ema6_ratio"
# [208] "Visa_mpagominimo_lag2actual_ema6_ratio"
# [209] "Visa_mpagominimo_lag2actual_ema3_ratio"
# [210] "Visa_mpagominimo_lag2actual_ema12_ratio"
# [211] "cliente_edad_lag3ema3_ema6_ratio"
# [212] "cliente_antiguedad_lag3ema3_ema6_ratio"
# [213] "cliente_antiguedad_lag3actual_ema3_ratio"
# [214] "cproductos_lag3actual_ema3_ratio"
# [215] "mcuenta_corriente_lag3ema3_ema6_ratio"
# [216] "mcuenta_corriente_lag3actual_ema6_ratio"
# [217] "mcuenta_corriente_lag3actual_ema3_ratio"
# [218] "mcaja_ahorro_lag3actual_ema6_ratio"
# [219] "mcaja_ahorro_lag3actual_ema3_ratio"
# [220] "mcaja_ahorro_lag3actual_ema12_ratio"
# [221] "mprestamos_personales_lag3actual_ema12_ratio"
# [222] "cpayroll_trx_lag3actual_ema12_ratio"
# [223] "ccomisiones_mantenimiento_lag3ema3_ema6_ratio"
# [224] "ctrx_quarter_lag3ema3_ema6_ratio"
# [225] "ctrx_quarter_lag3actual_ema6_ratio"
# [226] "ctrx_quarter_lag3actual_ema3_ratio"
# [227] "Master_fechaalta_lag3actual_ema3_ratio"
# [228] "Master_fechaalta_lag3actual_ema12_ratio"
# [229] "Master_mpagominimo_lag3ema3_ema6_ratio"
# [230] "Master_mpagominimo_lag3actual_ema6_ratio"
# [231] "Visa_fechaalta_lag3ema3_ema6_ratio"
# [232] "Visa_fechaalta_lag3actual_ema6_ratio"
# [233] "Visa_mpagominimo_lag3actual_ema3_ratio"
# [234] "Visa_mpagominimo_lag3actual_ema12_ratio"
# [235] "kmes_lag3actual_ema12_ratio"
# [236] "cliente_edad_lag4ema3_ema6_ratio"
# [237] "cliente_edad_lag4actual_ema6_ratio"
# [238] "cliente_edad_lag4actual_ema12_ratio"
# [239] "cliente_antiguedad_lag4ema3_ema6_ratio"
# [240] "cliente_antiguedad_lag4actual_ema3_ratio"
# [241] "cproductos_lag4actual_ema3_ratio"
# [242] "cproductos_lag4actual_ema12_ratio"
# [243] "mcuenta_corriente_lag4ema3_ema6_ratio"
# [244] "mcuenta_corriente_lag4actual_ema6_ratio"
# [245] "mcuenta_corriente_lag4actual_ema3_ratio"
# [246] "mcuenta_corriente_lag4actual_ema12_ratio"
# [247] "mcaja_ahorro_lag4ema3_ema6_ratio"
# [248] "mcaja_ahorro_lag4actual_ema6_ratio"
# [249] "mcaja_ahorro_lag4actual_ema3_ratio"
# [250] "mcaja_ahorro_lag4actual_ema12_ratio"
# [251] "mprestamos_personales_lag4actual_ema6_ratio"
# [252] "cpayroll_trx_lag4ema3_ema6_ratio"
# [253] "cpayroll_trx_lag4actual_ema12_ratio"
# [254] "ctrx_quarter_lag4ema3_ema6_ratio"
# [255] "ctrx_quarter_lag4actual_ema6_ratio"
# [256] "ctrx_quarter_lag4actual_ema3_ratio"
# [257] "ctrx_quarter_lag4actual_ema12_ratio"
# [258] "Master_mpagominimo_lag4actual_ema6_ratio"
# [259] "Master_mpagominimo_lag4actual_ema3_ratio"
# [260] "Visa_fechaalta_lag4actual_ema3_ratio"
# [261] "Visa_mpagominimo_lag4ema3_ema6_ratio"
# [262] "Visa_mpagominimo_lag4actual_ema6_ratio"
# [263] "Visa_mpagominimo_lag4actual_ema12_ratio"
# [264] "cliente_edad_lag5actual_ema3_ratio"
# [265] "cliente_edad_lag5actual_ema12_ratio"
# [266] "cliente_antiguedad_lag5actual_ema6_ratio"
# [267] "cliente_antiguedad_lag5actual_ema12_ratio"
# [268] "cproductos_lag5actual_ema12_ratio"
# [269] "mcuenta_corriente_lag5ema3_ema6_ratio"
# [270] "mcuenta_corriente_lag5actual_ema3_ratio"
# [271] "mcuenta_corriente_lag5actual_ema12_ratio"
# [272] "mcaja_ahorro_lag5ema3_ema6_ratio"
# [273] "mcaja_ahorro_lag5actual_ema6_ratio"
# [274] "mcaja_ahorro_lag5actual_ema3_ratio"
# [275] "mcaja_ahorro_lag5actual_ema12_ratio"
# [276] "cpayroll_trx_lag5ema3_ema6_ratio"
# [277] "ctrx_quarter_lag5actual_ema6_ratio"
# [278] "ctrx_quarter_lag5actual_ema3_ratio"
# [279] "Master_fechaalta_lag5ema3_ema6_ratio"
# [280] "Master_fechaalta_lag5actual_ema6_ratio"
# [281] "Master_fechaalta_lag5actual_ema12_ratio"
# [282] "Visa_fechaalta_lag5actual_ema3_ratio"
# [283] "Visa_fechaalta_lag5actual_ema12_ratio"
# [284] "Visa_mpagominimo_lag5ema3_ema6_ratio"
# [285] "cliente_antiguedad_lag6ema3_ema6_ratio"
# [286] "cliente_antiguedad_lag6actual_ema6_ratio"
# [287] "cliente_antiguedad_lag6actual_ema3_ratio"
# [288] "mcuenta_corriente_lag6ema3_ema6_ratio"
# [289] "mcuenta_corriente_lag6actual_ema6_ratio"
# [290] "mcuenta_corriente_lag6actual_ema3_ratio"
# [291] "mcuenta_corriente_lag6actual_ema12_ratio"
# [292] "mcaja_ahorro_lag6ema3_ema6_ratio"
# [293] "mcaja_ahorro_lag6actual_ema6_ratio"
# [294] "mcaja_ahorro_lag6actual_ema3_ratio"
# [295] "mcaja_ahorro_lag6actual_ema12_ratio"
# [296] "mprestamos_personales_lag6ema3_ema6_ratio"
# [297] "mprestamos_personales_lag6actual_ema12_ratio"
# [298] "cpayroll_trx_lag6ema3_ema6_ratio"
# [299] "cpayroll_trx_lag6actual_ema3_ratio"
# [300] "cpayroll_trx_lag6actual_ema12_ratio"
# [301] "mpayroll_lag6ema3_ema6_ratio"
# [302] "ctrx_quarter_lag6ema3_ema6_ratio"
# [303] "ctrx_quarter_lag6actual_ema6_ratio"
# [304] "ctrx_quarter_lag6actual_ema3_ratio"
# [305] "Master_fechaalta_lag6actual_ema6_ratio"
# [306] "Master_mpagominimo_lag6actual_ema6_ratio"
# [307] "Visa_mpagominimo_lag6ema3_ema6_ratio"
# [308] "Visa_mpagominimo_lag6actual_ema3_ratio"
# [309] "Visa_mpagominimo_lag6actual_ema12_ratio"
# [310] "internet_delta1ema3_ema6_ratio"
# [311] "internet_delta1actual_ema3_ratio"
# [312] "cliente_edad_delta1ema3_ema6_ratio"
# [313] "mrentabilidad_delta1actual_ema6_ratio"
# [314] "mrentabilidad_delta1actual_ema3_ratio"
# [315] "mrentabilidad_delta1actual_ema12_ratio"
# [316] "mrentabilidad_annual_delta1ema3_ema6_ratio"
# [317] "mrentabilidad_annual_delta1actual_ema6_ratio"
# [318] "mrentabilidad_annual_delta1actual_ema3_ratio"
# [319] "mrentabilidad_annual_delta1actual_ema12_ratio"
# [320] "mcomisiones_delta1ema3_ema6_ratio"
# [321] "mcomisiones_delta1actual_ema6_ratio"
# [322] "mcomisiones_delta1actual_ema3_ratio"
# [323] "mcomisiones_delta1actual_ema12_ratio"
# [324] "mactivos_margen_delta1ema3_ema6_ratio"
# [325] "mactivos_margen_delta1actual_ema6_ratio"
# [326] "mactivos_margen_delta1actual_ema3_ratio"
# [327] "mactivos_margen_delta1actual_ema12_ratio"
# [328] "mpasivos_margen_delta1ema3_ema6_ratio"
# [329] "mpasivos_margen_delta1actual_ema6_ratio"
# [330] "mpasivos_margen_delta1actual_ema3_ratio"
# [331] "mpasivos_margen_delta1actual_ema12_ratio"
# [332] "cproductos_delta1ema3_ema6_ratio"
# [333] "cproductos_delta1actual_ema12_ratio"
# [334] "mcuenta_corriente_delta1ema3_ema6_ratio"
# [335] "mcuenta_corriente_delta1actual_ema6_ratio"
# [336] "mcuenta_corriente_delta1actual_ema12_ratio"
# [337] "mcuenta_corriente_delta2ema3_ema6_ratio"
# [338] "mcuenta_corriente_delta2actual_ema6_ratio"
# [339] "mcuenta_corriente_delta2actual_ema3_ratio"
# [340] "mcuenta_corriente_delta2actual_ema12_ratio"
# [341] "mcaja_ahorro_delta1ema3_ema6_ratio"
# [342] "mcaja_ahorro_delta1actual_ema6_ratio"
# [343] "mcaja_ahorro_delta1actual_ema3_ratio"
# [344] "mcaja_ahorro_delta1actual_ema12_ratio"
# [345] "mcaja_ahorro_delta2ema3_ema6_ratio"
# [346] "mcaja_ahorro_delta2actual_ema6_ratio"
# [347] "mcaja_ahorro_delta2actual_ema3_ratio"
# [348] "mcaja_ahorro_delta2actual_ema12_ratio"
# [349] "mcuentas_saldo_delta1ema3_ema6_ratio"
# [350] "mcuentas_saldo_delta1actual_ema6_ratio"
# [351] "mcuentas_saldo_delta1actual_ema3_ratio"
# [352] "mcuentas_saldo_delta1actual_ema12_ratio"
# [353] "ctarjeta_visa_transacciones_delta1actual_ema12_ratio"
# [354] "mtarjeta_visa_consumo_delta1ema3_ema6_ratio"
# [355] "mtarjeta_visa_consumo_delta1actual_ema6_ratio"
# [356] "mtarjeta_visa_consumo_delta1actual_ema3_ratio"
# [357] "mtarjeta_visa_consumo_delta1actual_ema12_ratio"
# [358] "mtarjeta_master_consumo_delta1ema3_ema6_ratio"
# [359] "mprestamos_personales_delta2actual_ema12_ratio"
# [360] "mpayroll_delta2ema3_ema6_ratio"
# [361] "ccomisiones_mantenimiento_delta1ema3_ema6_ratio"
# [362] "ccomisiones_mantenimiento_delta1actual_ema6_ratio"
# [363] "ccomisiones_mantenimiento_delta1actual_ema3_ratio"
# [364] "ccomisiones_mantenimiento_delta2ema3_ema6_ratio"
# [365] "ccomisiones_mantenimiento_delta2actual_ema6_ratio"
# [366] "ccomisiones_mantenimiento_delta2actual_ema3_ratio"
# [367] "ccomisiones_mantenimiento_delta2actual_ema12_ratio"
# [368] "ccallcenter_transacciones_delta1ema3_ema6_ratio"
# [369] "ccallcenter_transacciones_delta1actual_ema6_ratio"
# [370] "ccallcenter_transacciones_delta1actual_ema3_ratio"
# [371] "chomebanking_transacciones_delta1ema3_ema6_ratio"
# [372] "chomebanking_transacciones_delta1actual_ema3_ratio"
# [373] "chomebanking_transacciones_delta1actual_ema12_ratio"
# [374] "ctrx_quarter_delta1ema3_ema6_ratio"
# [375] "ctrx_quarter_delta1actual_ema6_ratio"
# [376] "ctrx_quarter_delta1actual_ema3_ratio"
# [377] "ctrx_quarter_delta2ema3_ema6_ratio"
# [378] "ctrx_quarter_delta2actual_ema6_ratio"
# [379] "ctrx_quarter_delta2actual_ema3_ratio"
# [380] "ctrx_quarter_delta2actual_ema12_ratio"
# [381] "Master_fechaalta_delta1ema3_ema6_ratio"
# [382] "Master_fechaalta_delta1actual_ema6_ratio"
# [383] "Master_fechaalta_delta2ema3_ema6_ratio"
# [384] "Master_mpagominimo_delta1actual_ema3_ratio"
# [385] "Master_mpagominimo_delta2ema3_ema6_ratio"
# [386] "Visa_fechaalta_delta1actual_ema6_ratio"
# [387] "Visa_fechaalta_delta2actual_ema6_ratio"
# [388] "Visa_mpagominimo_delta1ema3_ema6_ratio"
# [389] "Visa_mpagominimo_delta1actual_ema6_ratio"
# [390] "Visa_mpagominimo_delta1actual_ema3_ratio"
# [391] "Visa_mpagominimo_delta2actual_ema6_ratio"
# [392] "Visa_mpagominimo_delta2actual_ema12_ratio"
# [393] "mpayroll_sobre_edad_delta1actual_ema12_ratio"
# [394] "mrentabilidad_mean6"
# [395] "mtarjeta_visa_consumo_mean6"
# [396] "mcuentas_saldo_mean6"
# [397] "mrentabilidad_sd6"
# [398] "mtarjeta_visa_consumo_sd6"
# [399] "mcuentas_saldo_sd6"

# %% [markdown]
# ### 6.3.2 Modelado

# %% [markdown]
# #### 6.3.2.1 Training Strategy
#
# Esta etapa de Workflow de  Training Strategy esta pensada para la *Modalidad Gerencial* que posee el dataset de [202005, 202109]
# <br> Si usted es un Analista, posee el periodo de [201901, 202109] y deberá experimentar en que meses le conviene experimentar
#
# <br> A la *Modalidad Gerencial* no se le complicada la vida con el undersampling de los continua, por eso PARAM$trainingstrategy$training_pct <- 1.0
# <br> Sin embargo, si usted es  *Analista SR* posee un dataset 50 veces ( filas x columnas) más grande que la *Modalidad Gerencial*  y por un tema de velocidad y experimentación más rápida puede llegar a necesitar activar el undersampling de la clase mayoritaria, a pesar de estar corriendo en Google Cloud.

# %% [markdown]
# Se hace una estrategia de entrenamiento muy sencilla, tomando todos los meses posibles, SIN eliminar nada x pandemia ni por ningun otro motivo
#
# * future = 202109  obviamente completo
#
# * final_train =  [ 202005, 202107 ]  SIN undersampling
#
# * training
#    * testing = NO HAY
#    * validation =  202107   completo, sin undersampling
#    * training = [ 202005, 202106 ]  donde se consideran el 100% de los CONTINUA

# %%
PARAM$trainingstrategy$validate <- c(202106, 202107)

PARAM$trainingstrategy$training <- c(
  202105, 202104, 202103, 202102, 202101,
  202012, 202011, 202010, 202009, 202008, 202007,
  202006, 202005
)

PARAM$trainingstrategy$training_pct <- 0.5


PARAM$trainingstrategy$positivos <- c( "BAJA+1", "BAJA+2")

# %%
# seteo la clase01   1={BAJA+1, BAJA+2}   0={CONTINUA}
dataset[, clase01 := ifelse( clase_ternaria %in% PARAM$trainingstrategy$positivos, 1, 0 )]

# %%
# los campos en los que se entrena
campos_buenos <- copy( setdiff(
    colnames(dataset), c("clase_ternaria","clase01","azar"))
)

# %%
# preparo para que se puede hacer undersampling de los CONTINUA
# solamente por un tema de VELOCIDAD
set.seed(PARAM$semilla_primigenia, kind = "L'Ecuyer-CMRG")
dataset[, azar:=runif(nrow(dataset))]


# undersampling de los CONTINUA
dataset[, fold_train :=  foto_mes %in%  PARAM$trainingstrategy$training &
    (clase_ternaria %in% c("BAJA+1", "BAJA+2") |
     azar < PARAM$trainingstrategy$training_pct ) ]

# -----------------------------------------------------------------------------
# ESTRATEGIA DE PESOS POR TRIMESTRE (OPTIMIZACIÓN BAYESIANA)
# -----------------------------------------------------------------------------
# 1. Crear una columna que identifique el trimestre (ej. 2020Q2)
dataset[, anio := as.integer(substr(as.character(foto_mes), 1, 4))]
dataset[, mes := as.integer(substr(as.character(foto_mes), 5, 6))]

# Calcula el trimestre (1, 2, 3, o 4)
dataset[, trimestre := ceiling(mes / 3)]

# Combina Año y Trimestre para el ranking
dataset[, anio_trimestre := paste0(anio, "Q", trimestre)]

# 2. Obtener los valores únicos de trimestre ordenados
trimestres_unicos <- sort(unique(dataset$anio_trimestre))

# 3. Asignar peso: el trimestre más viejo tiene el peso 1, el siguiente 2, etc.
dataset[, peso_norm := match(anio_trimestre, trimestres_unicos)]


# 4. Verificar la asignación (¡AHORA VA AQUÍ!)
print("Distribución de pesos por trimestre en Optimización Bayesiana:")
print(dataset[, .(peso = unique(peso_norm)), by = anio_trimestre][order(anio_trimestre)])


# 5. Limpiar columnas temporales (opcional, pero buena práctica)
# NOTA: Ahora anio_trimestre ya se usó para la verificación, así que se puede eliminar
dataset[, c("anio", "mes", "trimestre", "anio_trimestre") := NULL]
if( !require("lightgbm")) install.packages("lightgbm")
require("lightgbm")

dtrain <- lgb.Dataset(
  data= data.matrix(dataset[fold_train == TRUE, campos_buenos, with = FALSE]),
  label= dataset[fold_train == TRUE, clase01],
  weight= dataset[fold_train == TRUE, peso_norm],  # ¡Peso por Trimestre!
  free_raw_data= TRUE
)
# Out:
# [1] "Distribución de pesos por trimestre en Optimización Bayesiana:"
#    anio_trimestre  peso
#            <char> <int>
# 1:         2020Q2     1
# 2:         2020Q3     2
# 3:         2020Q4     3
# 4:         2021Q1     4
# 5:         2021Q2     5
# 6:         2021Q3     6

# %%
# datos de validation
dvalidate <- lgb.Dataset(
  data= data.matrix(dataset[foto_mes %in% PARAM$trainingstrategy$validate, campos_buenos, with = FALSE]),
  label= dataset[foto_mes %in% PARAM$trainingstrategy$validate, clase01],
  free_raw_data= TRUE
)

nrow(dvalidate)
# Out:
# [1] 33058

# %% [markdown]
# ####  6.3.2.2. Hyperparameter Tuning

# %% [markdown]
# * Clase binaria que se optimiza :  positivos = [ BAJA+1, BAJA+2 ]

# %% [markdown]
# * Metrica que se optimiza **AUC** Area Under Curve de la  ROC Curve
#
# es muy importante notar que intencionalmente  **NO** se está optimizando la funcion de ganancia del problema

# %% [markdown]
# * Cantidad de iteraciones inteligentes de la Optimizacion Bayesiana = **10**

# %% [markdown]
# * Parametros no default, fijos de LightGBM que no se optimizan
#   * max_bin = 31 , Alienigenas Ancestrales contruyeron las pirámides y dejaron a la humanidad en un jeroglifico  *max_bin=31*
#   * feature_fraction = 0.5  para poner algo que generalmente no falla
#   * learning_rate = 0.03  para que aprenda lento

# %% [markdown]
# * Parametros que se optimizan en la Bayesian Optimization
#   * num_leaves  [8, 256]
#   * min_data_in_leaf  [8, 8192]

# %%
# paquetes necesarios para la Bayesian Optimization
#if(!require("DiceKriging")) install.packages("DiceKriging")
#require("DiceKriging")

#if(!require("mlrMBO")) install.packages("mlrMBO")
#require("mlrMBO")
# Out:
# Loading required package: DiceKriging
#
# Warning message in library(package, lib.loc = lib.loc, character.only = TRUE, logical.return = TRUE, :
# “there is no package called ‘DiceKriging’”
# Installing package into ‘/usr/local/lib/R/site-library’
# (as ‘lib’ is unspecified)
#
# Loading required package: DiceKriging
#
# Loading required package: mlrMBO
#
# Warning message in library(package, lib.loc = lib.loc, character.only = TRUE, logical.return = TRUE, :
# “there is no package called ‘mlrMBO’”
# Installing package into ‘/usr/local/lib/R/site-library’
# (as ‘lib’ is unspecified)
#
# also installing the dependencies ‘XML’, ‘fastmatch’, ‘RcppArmadillo’, ‘mlr’, ‘ParamHelpers’, ‘smoof’, ‘BBmisc’, ‘checkmate’, ‘lhs’, ‘parallelMap’
#
#
# Loading required package: mlrMBO
#
# Loading required package: mlr
#
# Loading required package: ParamHelpers
#
#
# Attaching package: ‘ParamHelpers’
#
#
# The following object is masked from ‘package:R.utils’:
#
#     isVector
#
#
#
# Attaching package: ‘mlr’
#
#
# The following objects are masked from ‘package:R.utils’:
#
#     resample, setThreshold
#
#
# Loading required package: smoof
#
# Loading required package: checkmate
#
#
# Attaching package: ‘checkmate’
#
#
# The following object is masked from ‘package:DiceKriging’:
#
#     checkNames
#
#
# The following object is masked from ‘package:R.utils’:
#
#     asInt
#
#
#
# Attaching package: ‘smoof’
#
#
# The following objects are masked from ‘package:R.oo’:
#
#     getDescription, getName

# %% [markdown]
# Definición de la Bayesian Optimization
# <br> Si se desea optimizar un hiperparámetro que esta como fijo, debe QUITARSE de param_fijos y agregarse a PARAM$hipeparametertuning$hs

# %%
# valor ridiculamente bajo para que corra rapido en el aula y no molestar a la *Modalidad Gerencial*
PARAM$hipeparametertuning$num_interations <- 10

# parametros fijos del LightGBM
PARAM$lgbm$param_fijos <- list(
  objective= "binary",
  metric= "auc",
  first_metric_only= TRUE,
  boost_from_average= TRUE,
  feature_pre_filter= FALSE,
  verbosity= -100,
  force_row_wise= TRUE, # para evitar warning
  seed= PARAM$semilla_primigenia,
  max_bin= 31,
  learning_rate= 0.01,
  feature_fraction= 0.5,
  num_iterations= 5000,  # valor grande, lo limita early_stopping_rounds
  early_stopping_rounds= 500
)

# --- 1. Definir los Hiperparámetros para el Modelo Final (SALTÁNDOSE MBO) ---
# Usamos valores fijos en lugar de los obtenidos por optimización
PARAM$out$lgbm$mejores_hiperparametros <- list(
  num_leaves = 8168L, # Valor por defecto común para LGBM
  min_data_in_leaf = 4L
)

# --- 2. Ensamblar el Conjunto de Parámetros Finales ---
# Combina los parámetros fijos (como learning_rate, early_stopping) con los "mejores"
param_final <- modifyList(
  PARAM$lgbm$param_fijos,
  PARAM$out$lgbm$mejores_hiperparametros
)

# %% [markdown]
# Función "señora caja negra"  que es llamada para verificar la realidad por la Bayesian Optimization

# %% [markdown]
# seteo de la Bayesian Optimization (complejo)
# <br> copiado y pegado de la documentación de la librería

# %% [markdown]
# Corrida de la Bayesian Optimization,  aqui se hace el trabajo pesado
# <br> por favor no se asuste con los warnings que pudieran aparecer
#
# Si corrío a medias y llegó a las iteraciones inteligentes, en el archivo binario HT.RDATA quedó lo ya procesado y es utilizado para retomar la corrida desde lo último que llegó a grabar.

# %% [markdown]
# la bayesian optimization ha corrido, extraigo los mejores hiperparametros

# %% [markdown]
# ### 6.3.3 Produccion

# %% [markdown]
# #### Final Training
# Construyo el modelo final, que es uno solo, no hace ningun tipo de particion < training, validation, testing>]

# %% [markdown]
# ##### Final Training Dataset
#
# Aqui esta la gran decision de en qué meses hago el Final Training
# <br> debo utilizar los mejores hiperparámetros que encontré en la optimización bayesiana

# %%
PARAM$trainingstrategy$final_train <- c( 202107,
  202106, 202105, 202104, 202103, 202102, 202101,
  202012, 202011, 202010, 202009, 202008, 202007,
  202006, 202005
)

dataset[, fold_final_train := foto_mes %in% PARAM$trainingstrategy$final_train ]

# creo el dfinal_train en formato  LightGBM
dfinal_train <- lgb.Dataset(
  data= data.matrix(dataset[fold_final_train == TRUE, campos_buenos, with= FALSE]),
  label= dataset[fold_final_train == TRUE, clase01],
   weight= dataset[fold_final_train == TRUE, peso_norm],  # ¡Peso por Trimestre!
  free_raw_data= TRUE
)
#dtrain <- lgb.Dataset(
 # data= data.matrix(dataset[fold_train == TRUE, campos_buenos, with = FALSE]),
  #label= dataset[fold_train == TRUE, clase01],
 # weight= dataset[fold_train == TRUE, peso_norm],  # ¡Peso por Trimestre!
 # free_raw_data= TRUE
nrow( dfinal_train) # verifico el tamaño
# Out:
# [1] 240562

# %% [markdown]
# ##### Final Training Hyperparameters

# %%
# uno los parametros fijos y los mejores encontrados de los variables
fijos <- copy(PARAM$lgbm$param_fijos)

# quito lo que optimice en la Bayesian Optimization
fijos$num_iterations <- NULL
fijos$early_stopping_rounds <- NULL

# agrego a los hiperparametros fijos los que encontre con la Bayesian Optimization
param_final <- c(fijos, PARAM$out$lgbm$mejores_hiperparametros)

# %% [markdown]
# ##### Training
# Genero el modelo final, siempre sobre TODOS los datos de  final_train, sin hacer ningun tipo de undersampling de la clase mayoritaria

# %%
final_model <- lgb.train(
  data= dfinal_train,
  param= param_final,
  verbose= -100
)

# %%
# grabo a disco el modelo en un formato para seres humanos ... ponele ...

lgb.save(final_model, "modelo.txt")

# %%
# ahora imprimo la importancia de variables

#tb_importancia <- as.data.table(lgb.importance(final_model))
#archivo_importancia <- "impo.txt"

#fwrite( tb_importancia,
#  file= archivo_importancia,
 # sep= "\t"
#)

# %% [markdown]
# #### Scoring

# %% [markdown]
# Aplico el modelo final a los datos del futuro

# %%
PARAM$trainingstrategy$future <- c(202109)

dfuture <- dataset[ foto_mes %in% PARAM$trainingstrategy$future ]

# %%
# aplico final_model   a dfuture

prediccion <- predict(
  final_model,
  data.matrix(dfuture[, campos_buenos, with= FALSE])
)

# %% [markdown]
# ##### Tabla Prediccion

# %%
tb_prediccion <- dfuture[, list(numero_de_cliente)]
tb_prediccion[, prob := prediccion]

# grabo las probabilidad del modelo
#  me va a ser util para hacer Ensembles de modelos
fwrite(tb_prediccion,
  file= "prediccion.txt",
  sep= "\t"
)

# %% [markdown]
# #### Kaggle Competition Submit

# %% [markdown]
# Genero las salidas y hago los submits a Kaggle
# <br>El notebook esta preparado para la Modalidad Gerencial, los analistas deben hacer cambios.
# <br> Los analistas deben cambiar **competencia** a SU competencia  "data-mining-analista-jr-2025-a"   o  la original "data-mining-analista-sr-2025-a"  para los Senior
# <br> Los cortes  dependen de la cantidad de registros, multiplicar por 2 para los Analistas Jr y por 10 para los Analista Sr
#
# Los Analista Sr luego de meditar cuidadosamente reducirán la cantidad de cortes

# %%
# genero archivos con los  "envios" mejores
# suba TODOS los archivos a Kaggle

PARAM$kaggle$competencia <- "labo-i-2025-virtual-gerencial"
PARAM$kaggle$cortes <- seq(800, 1300, by = 50)

# ordeno por probabilidad descendente
setorder(tb_prediccion, -prob)

dir.create("kaggle")

for (envios in PARAM$kaggle$cortes) {

  tb_prediccion[, Predicted := 0L] # seteo inicial a 0
  tb_prediccion[1:envios, Predicted := 1L] # marclo los primeros

  archivo_kaggle <- paste0("./kaggle/KA", PARAM$experimento, "_", envios, ".csv")

  # grabo el archivo
  fwrite(tb_prediccion[, list(numero_de_cliente, Predicted)],
    file= archivo_kaggle,
    sep= ","
  )

  # subida a Kaggle, armo la linea de comando
  comando <- "kaggle competitions submit"
  competencia <- paste("-c", PARAM$kaggle$competencia)
  arch <- paste( "-f", archivo_kaggle)

  mensaje <- paste0("-m 'envios=", envios,
  "  semilla=", PARAM$semilla_primigenia,
    "'" )

  linea <- paste( comando, competencia, arch, mensaje)

  salida <- system(linea, intern=TRUE) # el submit a Kaggle
  cat(salida, "\n")
}
# Out:
# Warning message in system(linea, intern = TRUE):
# “running command 'kaggle competitions submit -c labo-i-2025-virtual-gerencial -f ./kaggle/KA67295_800.csv -m 'envios=800  semilla=999983'' had status 1”
# Warning message in system(linea, intern = TRUE):
# “running command 'kaggle competitions submit -c labo-i-2025-virtual-gerencial -f ./kaggle/KA67295_850.csv -m 'envios=850  semilla=999983'' had status 1”
# Warning message in system(linea, intern = TRUE):
# “running command 'kaggle competitions submit -c labo-i-2025-virtual-gerencial -f ./kaggle/KA67295_900.csv -m 'envios=900  semilla=999983'' had status 1”
# Warning message in system(linea, intern = TRUE):
# “running command 'kaggle competitions submit -c labo-i-2025-virtual-gerencial -f ./kaggle/KA67295_950.csv -m 'envios=950  semilla=999983'' had status 1”
# Warning message in system(linea, intern = TRUE):
# “running command 'kaggle competitions submit -c labo-i-2025-virtual-gerencial -f ./kaggle/KA67295_1000.csv -m 'envios=1000  semilla=999983'' had status 1”
# Warning message in system(linea, intern = TRUE):
# “running command 'kaggle competitions submit -c labo-i-2025-virtual-gerencial -f ./kaggle/KA67295_1050.csv -m 'envios=1050  semilla=999983'' had status 1”
# Warning message in system(linea, intern = TRUE):
# “running command 'kaggle competitions submit -c labo-i-2025-virtual-gerencial -f ./kaggle/KA67295_1100.csv -m 'envios=1100  semilla=999983'' had status 1”
# Warning message in system(linea, intern = TRUE):
# “running command 'kaggle competitions submit -c labo-i-2025-virtual-gerencial -f ./kaggle/KA67295_1150.csv -m 'envios=1150  semilla=999983'' had status 1”
# Warning message in system(linea, intern = TRUE):
# “running command 'kaggle competitions submit -c labo-i-2025-virtual-gerencial -f ./kaggle/KA67295_1200.csv -m 'envios=1200  semilla=999983'' had status 1”
# Warning message in system(linea, intern = TRUE):
# “running command 'kaggle competitions submit -c labo-i-2025-virtual-gerencial -f ./kaggle/KA67295_1250.csv -m 'envios=1250  semilla=999983'' had status 1”
# Warning message in system(linea, intern = TRUE):
# “running command 'kaggle competitions submit -c labo-i-2025-virtual-gerencial -f ./kaggle/KA67295_1300.csv -m 'envios=1300  semilla=999983'' had status 1”

# %%
# grabo los parametros
if( !require("yaml")) install.packages("yaml")
require("yaml")

write_yaml( PARAM, file="PARAM.yml")
# Out:
# Loading required package: yaml

# %%
format(Sys.time(), "%a %b %d %X %Y")
# Out:
# [1] "Sun Nov 30 10:33:26 PM 2025"
