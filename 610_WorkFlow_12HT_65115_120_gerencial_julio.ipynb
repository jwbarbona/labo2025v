# %% [markdown]
# <a href="https://colab.research.google.com/github/jwbarbona/labo2025v/blob/main/610_WorkFlow_12HT_65115_120_gerencial_julio.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # 6 WorkFlow  Gerencial, futuro=JULIO

# %% [markdown]
# ### 6.1 Objetivo

# %% [markdown]
# Presentar un workflow/pipeline completo al que los estudiantes deberán enriquecer

# %% [markdown]
# #### 6.2  Seteo del ambiente en Google Colab

# %% [markdown]
# Esta parte se debe correr con el runtime en Python3
# <br>Ir al menu, Runtime -> Change Runtime Type -> Runtime type ->  **Python 3**

# %% [markdown]
# Conectar la virtual machine donde esta corriendo Google Colab con el  Google Drive, para poder tener persistencia de archivos

# %%
# primero establecer el Runtime de Python 3
from google.colab import drive
drive.mount('/content/.drive')
# Out:
# Mounted at /content/.drive

# %% [markdown]
# Para correr la siguiente celda es fundamental en Arranque en Frio haber copiado el archivo kaggle.json al Google Drive, en la carpeta indicada en el instructivo
#
# <br>los siguientes comando estan en shell script de Linux
# *   Crear las carpetas en el Google Drive
# *   "instalar" el archivo kaggle.json desde el Google Drive a la virtual machine para que pueda ser utilizado por la libreria  kaggle de Python
# *   Bajar el  **dataset_pequeno**  al  Google Drive  y tambien al disco local de la virtual machine que esta corriendo Google Colab
# *   Bajar el **dataset_historico** al Google Drive y tambien al disco local de la virtual machine que esta corriendo Google Colab

# %%
%%shell

mkdir -p "/content/.drive/My Drive/labo1"
mkdir -p "/content/buckets"
ln -s "/content/.drive/My Drive/labo1" /content/buckets/b1

mkdir -p ~/.kaggle
cp /content/buckets/b1/kaggle/kaggle.json  ~/.kaggle
chmod 600 ~/.kaggle/kaggle.json


mkdir -p /content/buckets/b1/exp
mkdir -p /content/buckets/b1/datasets
mkdir -p /content/datasets


webfiles="https://storage.googleapis.com/open-courses/austral2025-af91/"
destino_local="/content/datasets"
destino_bucket="/content/buckets/b1/datasets"


archivo="dataset_pequeno.csv"

if ! test -f $destino_bucket/$archivo; then
  wget  $webfiles/$archivo  -O $destino_bucket/$archivo
fi


if ! test -f $destino_local/$pequeno; then
  cp  $destino_bucket/$archivo  $destino_local/$archivo
fi

#-------

archivo="gerencial_competencia_2025.csv.gz"

if ! test -f $destino_bucket/$archivo; then
  wget  $webfiles/$archivo  -O $destino_bucket/$archivo
fi


if ! test -f $destino_local/$pequeno; then
  cp  $destino_bucket/$archivo  $destino_local/$archivo
fi
# Out:
# cp: cannot stat '/content/buckets/b1/kaggle/kaggle.json': No such file or directory
# chmod: cannot access '/root/.kaggle/kaggle.json': No such file or directory

# %% [markdown]
# ## 6.3  Workflow

# %% [markdown]
# ## Inicializacion

# %% [markdown]
# Esta parte se debe correr con el runtime en lenguaje **R** Ir al menu, Runtime -> Change Runtime Type -> Runtime type -> R

# %% [markdown]
# limpio el ambiente de R

# %%
format(Sys.time(), "%a %b %d %X %Y")
# Out:
# [1] "Thu Nov 20 12:49:15 AM 2025"

# %%
# limpio la memoria
rm(list=ls(all.names=TRUE)) # remove all objects
gc(full=TRUE, verbose=FALSE) # garbage collection
# Out:
#        used    (Mb) gc trigger (Mb) max used (Mb)
# Ncells  660352 35.3 1454497    77.7 1454497  77.7
# Vcells 1226511  9.4 8388608    64.0 1975136  15.1

# %%
principio <- Sys.time()

# %%
require("data.table")

if( !require("R.utils")) install.packages("R.utils")
require("R.utils")
# Out:
# Loading required package: data.table
#
# Loading required package: R.utils
#
# Warning message in library(package, lib.loc = lib.loc, character.only = TRUE, logical.return = TRUE, :
# “there is no package called ‘R.utils’”
# Installing package into ‘/usr/local/lib/R/site-library’
# (as ‘lib’ is unspecified)
#
# also installing the dependencies ‘R.oo’, ‘R.methodsS3’
#
#
# Loading required package: R.utils
#
# Loading required package: R.oo
#
# Loading required package: R.methodsS3
#
# R.methodsS3 v1.8.2 (2022-06-13 22:00:14 UTC) successfully loaded. See ?R.methodsS3 for help.
#
# R.oo v1.27.1 (2025-05-02 21:00:05 UTC) successfully loaded. See ?R.oo for help.
#
#
# Attaching package: ‘R.oo’
#
#
# The following object is masked from ‘package:R.methodsS3’:
#
#     throw
#
#
# The following objects are masked from ‘package:methods’:
#
#     getClasses, getMethods
#
#
# The following objects are masked from ‘package:base’:
#
#     attach, detach, load, save
#
#
# R.utils v2.13.0 (2025-02-24 21:20:02 UTC) successfully loaded. See ?R.utils for help.
#
#
# Attaching package: ‘R.utils’
#
#
# The following object is masked from ‘package:utils’:
#
#     timestamp
#
#
# The following objects are masked from ‘package:base’:
#
#     cat, commandArgs, getOption, isOpen, nullfile, parse, use, warnings

# %% [markdown]
# #### Parametros
# Si es gerente, no cambie nada
# <br>Si es Analista, cambie el nombre del dataset

# %%
PARAM <- list()
PARAM$semilla_primigenia <- 999983 # 100009, 200003, 499999, 700009, 999983

PARAM$experimento <- 65115 # 12HT
PARAM$dataset <- "gerencial_competencia_2025.csv.gz"

# %% [markdown]
# #### Carpeta del Experimento

# %%
# carpeta de trabajo

setwd("/content/buckets/b1/exp")
experimento_folder <- paste0("WF", PARAM$experimento)
dir.create(experimento_folder, showWarnings=FALSE)
setwd( paste0("/content/buckets/b1/exp/", experimento_folder ))

# %% [markdown]
# ### 6.3.1   Preprocesamiento del dataset

# %% [markdown]
# #### 6.3.1.1  DT incorporar dataset

# %%
# lectura del dataset
dataset <- fread(paste0("/content/datasets/", PARAM$dataset))

# %% [markdown]
# #### 6.3.1.2  CA  Catastrophe Analysis
# Se intentan reparar las variables que para un mes están con todos los valores en cero.

# %% [markdown]
# El método que se utiliza es **Machine Learning** se asigna NA also valores, si ha leido bien, es la "anti imputación de valores faltantes"
# <br> Usted podrá aplicar aquí otros métodos

# %%
dataset[ foto_mes==202006, internet:=NA]
dataset[ foto_mes==202006, mrentabilidad:=NA]
dataset[ foto_mes==202006, mrentabilidad_annual:=NA]
dataset[ foto_mes==202006, mcomisiones:=NA]
dataset[ foto_mes==202006, mactivos_margen:=NA]
dataset[ foto_mes==202006, mpasivos_margen:=NA]
dataset[ foto_mes==202006, mcuentas_saldo:=NA]
dataset[ foto_mes==202006, ctarjeta_visa_transacciones:=NA]
dataset[ foto_mes==202006, mtarjeta_visa_consumo:=NA]
dataset[ foto_mes==202006, mtarjeta_master_consumo:=NA]
dataset[ foto_mes==202006, ccallcenter_transacciones:=NA]
dataset[ foto_mes==202006, chomebanking_transacciones:=NA]
dataset[ foto_mes==202006, chomebanking_transacciones:=NA]

# %% [markdown]
# #### 6.3.1.3  DR  Data Drifting
# Se intenta corregir el data drifting, quizas ajustando por IPC ...
# <br>Esta parte podrá ser abordada por todos los Analistas y también la Gerenciapero se decide pedagogicamente no incluirla en esta primer version para reducir la carga cognitiva

# %%
# sin codigo en esta primera version del workflow

# %% [markdown]
# #### 6.3.1.3  FE_intra_manual Feature Engineering intra-mes
#
# Agrego campos nuevos dentro del mismo mes, SIN considerar la historia.

# %%
# esta funcion atributos presentes existe debido a que las modalidades poseen datasets con distinta cantidad de campos
atributos_presentes <- function( patributos )
{
  atributos <- unique( patributos )
  comun <- intersect( atributos, colnames(dataset) )

  return(  length( atributos ) == length( comun ) )
}

# el mes 1,2, ..12
if( atributos_presentes( c("foto_mes") ))
  dataset[, kmes := foto_mes %% 100]

# variable extraida de una tesis de maestria de Irlanda
if( atributos_presentes( c("mpayroll", "cliente_edad") ))
  dataset[, mpayroll_sobre_edad := mpayroll / cliente_edad]

# %%
# visualizo las columas del dataset a esta etapa
colnames(dataset)
# Out:
#  [1] "numero_de_cliente"           "foto_mes"
#  [3] "internet"                    "cliente_edad"
#  [5] "cliente_antiguedad"          "mrentabilidad"
#  [7] "mrentabilidad_annual"        "mcomisiones"
#  [9] "mactivos_margen"             "mpasivos_margen"
# [11] "cproductos"                  "mcuenta_corriente"
# [13] "mcaja_ahorro"                "cdescubierto_preacordado"
# [15] "mcuentas_saldo"              "ctarjeta_visa_transacciones"
# [17] "mtarjeta_visa_consumo"       "mtarjeta_master_consumo"
# [19] "mprestamos_personales"       "cpayroll_trx"
# [21] "mpayroll"                    "ccomisiones_mantenimiento"
# [23] "ccallcenter_transacciones"   "chomebanking_transacciones"
# [25] "ctrx_quarter"                "Master_status"
# [27] "Master_fechaalta"            "Master_mpagominimo"
# [29] "Visa_status"                 "Visa_fechaalta"
# [31] "Visa_mpagominimo"            "clase_ternaria"
# [33] "kmes"                        "mpayroll_sobre_edad"

# %% [markdown]
# #### 6.3.1.4  FE_rf Feature Engineering de nuevas variables a partir de hojas de Random Forest
#
# Esto se mostrará unicamente a la *modalidad Analista Sr*

# %%
# No se implementa Feature Engineering a partir de Random Forest

# %% [markdown]
# #### 6.3.1.5  FEhist Feature Engineering historico
#
# El Fature Engineering Histórico es la etapa que más aporta a la ganancia final, ya que enriquece cada registro del dataset con su historia.

# %% [markdown]
# Para cada campo del dataset original (*)
# se crean lo siguientes campos de a partir de la historia
# * lag1  lags de orden 1
# * delta1  =  valor actual - lag1
# * lag2  lags de orden 2
# * delta2  = valor actual - lag2
#
#
# (*) Excepto para los campos  <numero_de_cliente,  foto_mes,  clase_ternaria>

# %%
# Feature Engineering Historico

# todo es lagueable, menos la primary key y la clase
cols_lagueables <- copy( setdiff(
    colnames(dataset),
    c("numero_de_cliente", "foto_mes", "clase_ternaria")
) )

# https://rdrr.io/cran/data.table/man/shift.html

# lags de orden 1
dataset[,
    paste0(cols_lagueables, "_lag1") := shift(.SD, 1, NA, "lag"),
    by = numero_de_cliente,
    .SDcols = cols_lagueables
]

# lags de orden 2
dataset[,
    paste0(cols_lagueables, "_lag2") := shift(.SD, 2, NA, "lag"),
    by = numero_de_cliente,
    .SDcols = cols_lagueables
]

# agrego los delta lags
for (vcol in cols_lagueables)
{
    dataset[, paste0(vcol, "_delta1") := get(vcol) - get(paste0(vcol, "_lag1"))]
    dataset[, paste0(vcol, "_delta2") := get(vcol) - get(paste0(vcol, "_lag2"))]
}

# %% [markdown]
# Verificacion de los campos recien creados

# %%
ncol(dataset)
colnames(dataset)
# Out:
# [1] 158
#   [1] "numero_de_cliente"                  "foto_mes"
#   [3] "internet"                           "cliente_edad"
#   [5] "cliente_antiguedad"                 "mrentabilidad"
#   [7] "mrentabilidad_annual"               "mcomisiones"
#   [9] "mactivos_margen"                    "mpasivos_margen"
#  [11] "cproductos"                         "mcuenta_corriente"
#  [13] "mcaja_ahorro"                       "cdescubierto_preacordado"
#  [15] "mcuentas_saldo"                     "ctarjeta_visa_transacciones"
#  [17] "mtarjeta_visa_consumo"              "mtarjeta_master_consumo"
#  [19] "mprestamos_personales"              "cpayroll_trx"
#  [21] "mpayroll"                           "ccomisiones_mantenimiento"
#  [23] "ccallcenter_transacciones"          "chomebanking_transacciones"
#  [25] "ctrx_quarter"                       "Master_status"
#  [27] "Master_fechaalta"                   "Master_mpagominimo"
#  [29] "Visa_status"                        "Visa_fechaalta"
#  [31] "Visa_mpagominimo"                   "clase_ternaria"
#  [33] "kmes"                               "mpayroll_sobre_edad"
#  [35] "internet_lag1"                      "cliente_edad_lag1"
#  [37] "cliente_antiguedad_lag1"            "mrentabilidad_lag1"
#  [39] "mrentabilidad_annual_lag1"          "mcomisiones_lag1"
#  [41] "mactivos_margen_lag1"               "mpasivos_margen_lag1"
#  [43] "cproductos_lag1"                    "mcuenta_corriente_lag1"
#  [45] "mcaja_ahorro_lag1"                  "cdescubierto_preacordado_lag1"
#  [47] "mcuentas_saldo_lag1"                "ctarjeta_visa_transacciones_lag1"
#  [49] "mtarjeta_visa_consumo_lag1"         "mtarjeta_master_consumo_lag1"
#  [51] "mprestamos_personales_lag1"         "cpayroll_trx_lag1"
#  [53] "mpayroll_lag1"                      "ccomisiones_mantenimiento_lag1"
#  [55] "ccallcenter_transacciones_lag1"     "chomebanking_transacciones_lag1"
#  [57] "ctrx_quarter_lag1"                  "Master_status_lag1"
#  [59] "Master_fechaalta_lag1"              "Master_mpagominimo_lag1"
#  [61] "Visa_status_lag1"                   "Visa_fechaalta_lag1"
#  [63] "Visa_mpagominimo_lag1"              "kmes_lag1"
#  [65] "mpayroll_sobre_edad_lag1"           "internet_lag2"
#  [67] "cliente_edad_lag2"                  "cliente_antiguedad_lag2"
#  [69] "mrentabilidad_lag2"                 "mrentabilidad_annual_lag2"
#  [71] "mcomisiones_lag2"                   "mactivos_margen_lag2"
#  [73] "mpasivos_margen_lag2"               "cproductos_lag2"
#  [75] "mcuenta_corriente_lag2"             "mcaja_ahorro_lag2"
#  [77] "cdescubierto_preacordado_lag2"      "mcuentas_saldo_lag2"
#  [79] "ctarjeta_visa_transacciones_lag2"   "mtarjeta_visa_consumo_lag2"
#  [81] "mtarjeta_master_consumo_lag2"       "mprestamos_personales_lag2"
#  [83] "cpayroll_trx_lag2"                  "mpayroll_lag2"
#  [85] "ccomisiones_mantenimiento_lag2"     "ccallcenter_transacciones_lag2"
#  [87] "chomebanking_transacciones_lag2"    "ctrx_quarter_lag2"
#  [89] "Master_status_lag2"                 "Master_fechaalta_lag2"
#  [91] "Master_mpagominimo_lag2"            "Visa_status_lag2"
#  [93] "Visa_fechaalta_lag2"                "Visa_mpagominimo_lag2"
#  [95] "kmes_lag2"                          "mpayroll_sobre_edad_lag2"
#  [97] "internet_delta1"                    "internet_delta2"
#  [99] "cliente_edad_delta1"                "cliente_edad_delta2"
# [101] "cliente_antiguedad_delta1"          "cliente_antiguedad_delta2"
# [103] "mrentabilidad_delta1"               "mrentabilidad_delta2"
# [105] "mrentabilidad_annual_delta1"        "mrentabilidad_annual_delta2"
# [107] "mcomisiones_delta1"                 "mcomisiones_delta2"
# [109] "mactivos_margen_delta1"             "mactivos_margen_delta2"
# [111] "mpasivos_margen_delta1"             "mpasivos_margen_delta2"
# [113] "cproductos_delta1"                  "cproductos_delta2"
# [115] "mcuenta_corriente_delta1"           "mcuenta_corriente_delta2"
# [117] "mcaja_ahorro_delta1"                "mcaja_ahorro_delta2"
# [119] "cdescubierto_preacordado_delta1"    "cdescubierto_preacordado_delta2"
# [121] "mcuentas_saldo_delta1"              "mcuentas_saldo_delta2"
# [123] "ctarjeta_visa_transacciones_delta1" "ctarjeta_visa_transacciones_delta2"
# [125] "mtarjeta_visa_consumo_delta1"       "mtarjeta_visa_consumo_delta2"
# [127] "mtarjeta_master_consumo_delta1"     "mtarjeta_master_consumo_delta2"
# [129] "mprestamos_personales_delta1"       "mprestamos_personales_delta2"
# [131] "cpayroll_trx_delta1"                "cpayroll_trx_delta2"
# [133] "mpayroll_delta1"                    "mpayroll_delta2"
# [135] "ccomisiones_mantenimiento_delta1"   "ccomisiones_mantenimiento_delta2"
# [137] "ccallcenter_transacciones_delta1"   "ccallcenter_transacciones_delta2"
# [139] "chomebanking_transacciones_delta1"  "chomebanking_transacciones_delta2"
# [141] "ctrx_quarter_delta1"                "ctrx_quarter_delta2"
# [143] "Master_status_delta1"               "Master_status_delta2"
# [145] "Master_fechaalta_delta1"            "Master_fechaalta_delta2"
# [147] "Master_mpagominimo_delta1"          "Master_mpagominimo_delta2"
# [149] "Visa_status_delta1"                 "Visa_status_delta2"
# [151] "Visa_fechaalta_delta1"              "Visa_fechaalta_delta2"
# [153] "Visa_mpagominimo_delta1"            "Visa_mpagominimo_delta2"
# [155] "kmes_delta1"                        "kmes_delta2"
# [157] "mpayroll_sobre_edad_delta1"         "mpayroll_sobre_edad_delta2"

# %% [markdown]
# #### 6.3.1.6  FEhist Reduccion dimensionalidad con canaritos
#
# Esta etapa solo se mostrará a la *modalidad Anlista Sr* por algun canal secreto de forma de no confundir a los *Analista Jr*  nni distraer con detalles operativos a la estratégica *Modalidad Gerencial*

# %%
# No se implementa la reduccion de la dimensionalidad con canaritos

# %% [markdown]
# ### 6.3.2 Modelado

# %% [markdown]
# #### 6.3.2.1 Training Strategy
#
# Esta etapa de Workflow de  Training Strategy esta pensada para la *Modalidad Gerencial* que posee el dataset de [202005, 202109]
# <br> Si usted es un Analista, posee el periodo de [201901, 202109] y deberá experimentar en que meses le conviene experimentar
#
# <br> A la *Modalidad Gerencial* no se le complicada la vida con el undersampling de los continua, por eso PARAM$trainingstrategy$training_pct <- 1.0
# <br> Sin embargo, si usted es  *Analista SR* posee un dataset 50 veces ( filas x columnas) más grande que la *Modalidad Gerencial*  y por un tema de velocidad y experimentación más rápida puede llegar a necesitar activar el undersampling de la clase mayoritaria, a pesar de estar corriendo en Google Cloud.

# %% [markdown]
# Se hace una estrategia de entrenamiento muy sencilla, tomando todos los meses posibles, SIN eliminar nada x pandemia ni por ningun otro motivo
#
# * future = 202107  obviamente completo
#
# * final_train =  [ 202005, 202105 ]  SIN undersampling
#
# * training
#    * testing = NO HAY
#    * validation =  202105   completo, sin undersampling
#    * training = [ 202005, 202104 ]  donde se consideran el 100% de los CONTINUA

# %%
PARAM$trainingstrategy$validate <- c(202105)

PARAM$trainingstrategy$training <- c(
  202104, 202103, 202102, 202101,
  202012, 202011, 202010, 202009, 202008, 202007,
  202006, 202005
)

PARAM$trainingstrategy$training_pct <- 1.0


PARAM$trainingstrategy$positivos <- c( "BAJA+1", "BAJA+2")

# %%
# seteo la clase01   1={BAJA+1, BAJA+2}   0={CONTINUA}
dataset[, clase01 := ifelse( clase_ternaria %in% PARAM$trainingstrategy$positivos, 1, 0 )]

# %%
# los campos en los que se entrena
campos_buenos <- copy( setdiff(
    colnames(dataset), c("clase_ternaria","clase01","azar"))
)

# %%
# preparo para que se puede hacer undersampling de los CONTINUA
#  solamente por un tema de VELOCIDAD
set.seed(PARAM$semilla_primigenia, kind = "L'Ecuyer-CMRG")
dataset[, azar:=runif(nrow(dataset))]

# undersampling de los CONTINUA
dataset[, fold_train :=  foto_mes %in%  PARAM$trainingstrategy$training &
    (clase_ternaria %in% c("BAJA+1", "BAJA+2") |
     azar < PARAM$trainingstrategy$training_pct ) ]


if( !require("lightgbm")) install.packages("lightgbm")
require("lightgbm")

dtrain <- lgb.Dataset(
  data= data.matrix(dataset[fold_train == TRUE, campos_buenos, with = FALSE]),
  label= dataset[fold_train == TRUE, clase01],
  free_raw_data= TRUE
)
# Out:
# Loading required package: lightgbm
#
# Warning message in library(package, lib.loc = lib.loc, character.only = TRUE, logical.return = TRUE, :
# “there is no package called ‘lightgbm’”
# Installing package into ‘/usr/local/lib/R/site-library’
# (as ‘lib’ is unspecified)
#
# Loading required package: lightgbm

# %%
# datos de validation
dvalidate <- lgb.Dataset(
  data= data.matrix(dataset[foto_mes %in% PARAM$trainingstrategy$validate, campos_buenos, with = FALSE]),
  label= dataset[foto_mes %in% PARAM$trainingstrategy$validate, clase01],
  free_raw_data= TRUE
)

nrow(dvalidate)
# Out:
# [1] 16469

# %% [markdown]
# ####  6.3.2.2. Hyperparameter Tuning

# %% [markdown]
# * Clase binaria que se optimiza :  positivos = [ BAJA+1, BAJA+2 ]

# %% [markdown]
# * Metrica que se optimiza **AUC** Area Under Curve de la  ROC Curve
#
# es muy importante notar que intencionalmente  **NO** se está optimizando la funcion de ganancia del problema

# %% [markdown]
# * Cantidad de iteraciones inteligentes de la Optimizacion Bayesiana = **10**

# %% [markdown]
# * Parametros no default, fijos de LightGBM que no se optimizan
#   * max_bin = 31 , Alienigenas Ancestrales contruyeron las pirámides y dejaron a la humanidad en un jeroglifico  *max_bin=31*
#   * feature_fraction = 0.5  para poner algo que generalmente no falla
#   * learning_rate = 0.03  para que aprenda lento

# %% [markdown]
# * Parametros que se optimizan en la Bayesian Optimization
#   * num_leaves  [8, 256]
#   * min_data_in_leaf  [8, 8192]

# %%
# paquetes necesarios para la Bayesian Optimization
if(!require("DiceKriging")) install.packages("DiceKriging")
require("DiceKriging")

if(!require("mlrMBO")) install.packages("mlrMBO")
require("mlrMBO")
# Out:
# Loading required package: DiceKriging
#
# Warning message in library(package, lib.loc = lib.loc, character.only = TRUE, logical.return = TRUE, :
# “there is no package called ‘DiceKriging’”
# Installing package into ‘/usr/local/lib/R/site-library’
# (as ‘lib’ is unspecified)
#
# Loading required package: DiceKriging
#
# Loading required package: mlrMBO
#
# Warning message in library(package, lib.loc = lib.loc, character.only = TRUE, logical.return = TRUE, :
# “there is no package called ‘mlrMBO’”
# Installing package into ‘/usr/local/lib/R/site-library’
# (as ‘lib’ is unspecified)
#
# also installing the dependencies ‘XML’, ‘fastmatch’, ‘RcppArmadillo’, ‘mlr’, ‘ParamHelpers’, ‘smoof’, ‘BBmisc’, ‘checkmate’, ‘lhs’, ‘parallelMap’
#
#
# Loading required package: mlrMBO
#
# Loading required package: mlr
#
# Loading required package: ParamHelpers
#
#
# Attaching package: ‘ParamHelpers’
#
#
# The following object is masked from ‘package:R.utils’:
#
#     isVector
#
#
#
# Attaching package: ‘mlr’
#
#
# The following objects are masked from ‘package:R.utils’:
#
#     resample, setThreshold
#
#
# Loading required package: smoof
#
# Loading required package: checkmate
#
#
# Attaching package: ‘checkmate’
#
#
# The following object is masked from ‘package:DiceKriging’:
#
#     checkNames
#
#
# The following object is masked from ‘package:R.utils’:
#
#     asInt
#
#
#
# Attaching package: ‘smoof’
#
#
# The following objects are masked from ‘package:R.oo’:
#
#     getDescription, getName

# %% [markdown]
# Definición de la Bayesian Optimization
# <br> Si se desea optimizar un hiperparámetro que esta como fijo, debe QUITARSE de param_fijos y agregarse a PARAM$hipeparametertuning$hs

# %%
# valor ridiculamente bajo para que corra rapido en el aula y no molestar a la *Modalidad Gerencial*
PARAM$hipeparametertuning$num_interations <- 100

# parametros fijos del LightGBM
PARAM$lgbm$param_fijos <- list(
  objective= "binary",
  metric= "auc",
  first_metric_only= TRUE,
  boost_from_average= TRUE,
  feature_pre_filter= FALSE,
  verbosity= -100,
  force_row_wise= TRUE, # para evitar warning
  max_bin= 31,
  seed= PARAM$semilla_primigenia
  # learning_rate= 0.03,
  # feature_fraction= 0.5,
  # num_iterations= 2048,  # valor grande, lo limita early_stopping_rounds
  # early_stopping_rounds= 200
)


PARAM$hipeparametertuning$hs <- makeParamSet(
  # Núcleo del modelo (estructura de árboles)
  makeIntegerParam("num_leaves", lower = 2L, upper = 8192L),
  #makeIntegerParam("max_depth", lower = 3L, upper = 30L),
  makeNumericParam("min_child_weight", lower = 0.001, upper = 10.0),
  makeIntegerParam("min_data_in_leaf", lower = 2L, upper = 8192L),
  makeNumericParam("min_gain_to_split", lower = 0.0, upper = 0.1),

  # Regularización
  makeNumericParam("lambda_l1", lower = 0.0, upper = 1000L),
  makeNumericParam("lambda_l2", lower = 0.0, upper = 1000L),
  makeNumericParam("scale_pos_weight", lower = 1.0, upper = 5.0),  # útil en desequilibrio

  # Control del aprendizaje
  makeNumericParam("learning_rate", lower = 0.005, upper = 0.1),
  makeIntegerParam("num_iterations", lower = 100L, upper = 5000L),
  makeIntegerParam("early_stopping_rounds", lower = 50L, upper = 500L),

  # Submuestreo
  makeNumericParam("feature_fraction", lower = 0.05, upper = 1L),   # columnas
  makeNumericParam("bagging_fraction", lower = 0.5, upper = 1L)   # filas
  #makeIntegerParam("bagging_freq", lower = 0L, upper = 5L),         # cada N iteraciones

  # Opcionales útiles
  #makeNumericParam("max_delta_step", lower = 0.0, upper = 10.0),
  #makeNumericParam("path_smooth", lower = 0.0, upper = 10.0)
)
# Total: 16 hT

# %% [markdown]
# Función "señora caja negra"  que es llamada para verificar la realidad por la Bayesian Optimization

# %%
# En  x llegan los parmaetros de la bayesiana
#  devuelve la AUC en validate del modelo entrenado
#  en el parametro x llegan los hiperparámetros que se estan optimizando

EstimarGanancia_AUC_lightgbm <- function(x) {

  # x pisa (o agrega) a param_fijos
  param_completo <- modifyList(PARAM$lgbm$param_fijos, x)

  # entreno LightGBM
  modelo_train <- lgb.train(
    data= dtrain,
    valids= list(valid = dvalidate),
    eval= "auc",
    param= param_completo,
    verbose= -100
  )

  # recupero la AUC en validation
  AUC <- modelo_train$record_evals$valid$auc$eval[[modelo_train$best_iter]]

  # esta es la forma de devolver un parametro extra
  attr(AUC, "extras") <- list("num_iterations"= modelo_train$best_iter)

  # hago espacio en la memoria
  rm(modelo_train)
  gc(full= TRUE, verbose= FALSE)

  message(format(Sys.time(), "%a %b %d %X %Y"), " AUC ", AUC)

  return(AUC)
}

# %% [markdown]
# seteo de la Bayesian Optimization (complejo)
# <br> copiado y pegado de la documentación de la librería

# %%
configureMlr(show.learner.output = FALSE)

# configuro la busqueda bayesiana,  los hiperparametros que se van a optimizar
# por favor, no desesperarse por lo complejo
obj.fun <- makeSingleObjectiveFunction(
    fn= EstimarGanancia_AUC_lightgbm, # la funcion que voy a maximizar
    minimize= FALSE, # estoy Maximizando AUC
    noisy= FALSE,
    par.set= PARAM$hipeparametertuning$hs,
    has.simple.signature= FALSE # paso los parametros en una lista
)

# cada 600 segundos guardo el resultado intermedio
ctrl <- makeMBOControl(
    save.on.disk.at.time= 600,
    save.file.path= "HT.RDATA"
)

# indico la cantidad de iteraciones que va a tener la Bayesian Optimization
ctrl <- setMBOControlTermination(
    ctrl,
    iters= PARAM$hipeparametertuning$num_interations  # cantidad de iteraciones inteligentes
)

# defino el método estandar para la creacion de los puntos iniciales
#   los "No Inteligentes"
ctrl <- setMBOControlInfill(ctrl, crit = makeMBOInfillCritEI())

# mas configuraciones
surr.km <- makeLearner(
    "regr.km",
    predict.type= "se",
    covtype= "matern3_2",
    control= list(trace = TRUE)
)

# %% [markdown]
# Corrida de la Bayesian Optimization,  aqui se hace el trabajo pesado
# <br> por favor no se asuste con los warnings que pudieran aparecer
#
# Si corrío a medias y llegó a las iteraciones inteligentes, en el archivo binario HT.RDATA quedó lo ya procesado y es utilizado para retomar la corrida desde lo último que llegó a grabar.

# %%
# inicio la optimizacion bayesiana

if (!file.exists("HT.RDATA")) {
  bayesiana_salida <- mbo(obj.fun, learner= surr.km, control= ctrl)
} else {
  bayesiana_salida <- mboContinue("HT.RDATA") # retomo en caso que ya exista
}
# Out:
# Computing y column(s) for design. Not provided.
#
# Thu Nov 20 01:02:16 AM 2025 AUC 0.893186443953672
#
# Thu Nov 20 01:02:57 AM 2025 AUC 0.895714009619043
#
# Thu Nov 20 01:03:43 AM 2025 AUC 0.891990941966985
#
# Thu Nov 20 01:04:01 AM 2025 AUC 0.892209373567696
#
# Thu Nov 20 01:05:23 AM 2025 AUC 0.907741336720869
#
# Thu Nov 20 01:05:58 AM 2025 AUC 0.904815326315337
#
# Thu Nov 20 01:06:10 AM 2025 AUC 0.887284261046901
#
# Thu Nov 20 01:07:05 AM 2025 AUC 0.86325561060524
#
# Thu Nov 20 01:07:56 AM 2025 AUC 0.906103267481742
#
# Thu Nov 20 01:09:05 AM 2025 AUC 0.901431817464999
#
# Thu Nov 20 01:09:40 AM 2025 AUC 0.883298135983234
#
# Thu Nov 20 01:10:43 AM 2025 AUC 0.89771529269499
#
# Thu Nov 20 01:11:55 AM 2025 AUC 0.911224330931592
#
# Thu Nov 20 01:12:36 AM 2025 AUC 0.891548374714546
#
# Thu Nov 20 01:13:22 AM 2025 AUC 0.892520579880537
#
# Thu Nov 20 01:13:48 AM 2025 AUC 0.910991303670926
#
# Thu Nov 20 01:14:13 AM 2025 AUC 0.870667353837048
#
# Thu Nov 20 01:15:06 AM 2025 AUC 0.909157954567569
#
# Thu Nov 20 01:15:14 AM 2025 AUC 0.86415785726317
#
# Thu Nov 20 01:15:53 AM 2025 AUC 0.887011976493941
#
# Thu Nov 20 01:17:21 AM 2025 AUC 0.887074049990303
#
# Thu Nov 20 01:17:49 AM 2025 AUC 0.887759710475792
#
# Thu Nov 20 01:18:04 AM 2025 AUC 0.898048979679486
#
# Thu Nov 20 01:22:07 AM 2025 AUC 0.910296416044086
#
# Thu Nov 20 01:22:35 AM 2025 AUC 0.874058244400467
#
# Thu Nov 20 01:23:26 AM 2025 AUC 0.876543868514242
#
# Thu Nov 20 01:24:24 AM 2025 AUC 0.904764493154803
#
# Thu Nov 20 01:25:12 AM 2025 AUC 0.884094354398729
#
# Thu Nov 20 01:25:43 AM 2025 AUC 0.891121241953094
#
# Thu Nov 20 01:26:31 AM 2025 AUC 0.911465075437752
#
# Thu Nov 20 01:28:41 AM 2025 AUC 0.91597765085705
#
# Thu Nov 20 01:29:15 AM 2025 AUC 0.903372872472854
#
# Thu Nov 20 01:29:41 AM 2025 AUC 0.887068345939286
#
# Thu Nov 20 01:30:09 AM 2025 AUC 0.900225410674897
#
# Thu Nov 20 01:30:49 AM 2025 AUC 0.907171602683991
#
# Thu Nov 20 01:31:06 AM 2025 AUC 0.856079746659607
#
# Thu Nov 20 01:31:42 AM 2025 AUC 0.873170593402493
#
# Thu Nov 20 01:32:13 AM 2025 AUC 0.898163899530859
#
# Thu Nov 20 01:33:19 AM 2025 AUC 0.888270726340435
#
# Thu Nov 20 01:34:18 AM 2025 AUC 0.892613186826461
#
# Thu Nov 20 01:34:39 AM 2025 AUC 0.892180517780198
#
# Thu Nov 20 01:34:57 AM 2025 AUC 0.880093969207519
#
# Thu Nov 20 01:35:13 AM 2025 AUC 0.875344172372395
#
# Thu Nov 20 01:35:30 AM 2025 AUC 0.885712794991709
#
# Thu Nov 20 01:35:36 AM 2025 AUC 0.887854330616192
#
# Thu Nov 20 01:36:04 AM 2025 AUC 0.878703858421427
#
# Thu Nov 20 01:37:09 AM 2025 AUC 0.906070385305291
#
# Thu Nov 20 01:40:34 AM 2025 AUC 0.91271392707807
#
# [mbo] 0: num_leaves=5281; min_child_weight=5.57; min_data_in_leaf=5189; min_gain_to_split=0.0341; lambda_l1=519; lambda_l2=601; scale_pos_weight=3.61; learning_rate=0.0614; num_iterations=1702; early_stopping_rounds=404; feature_fraction=0.827; bagging_fraction=0.895 : y = 0.893 : 32.8 secs : initdesign
#
# [mbo] 0: num_leaves=6163; min_child_weight=3.72; min_data_in_leaf=3458; min_gain_to_split=0.0388; lambda_l1=657; lambda_l2=662; scale_pos_weight=4.2; learning_rate=0.0585; num_iterations=3216; early_stopping_rounds=266; feature_fraction=0.308; bagging_fraction=0.603 : y = 0.896 : 41.0 secs : initdesign
#
# [mbo] 0: num_leaves=3255; min_child_weight=2.93; min_data_in_leaf=1871; min_gain_to_split=0.0679; lambda_l1=699; lambda_l2=284; scale_pos_weight=2.79; learning_rate=0.0187; num_iterations=4255; early_stopping_rounds=299; feature_fraction=0.28; bagging_fraction=0.742 : y = 0.892 : 46.0 secs : initdesign
#
# [mbo] 0: num_leaves=5815; min_child_weight=4.88; min_data_in_leaf=5888; min_gain_to_split=0.06; lambda_l1=523; lambda_l2=95.3; scale_pos_weight=2.97; learning_rate=0.071; num_iterations=3048; early_stopping_rounds=131; feature_fraction=0.607; bagging_fraction=0.67 : y = 0.892 : 17.9 secs : initdesign
#
# [mbo] 0: num_leaves=3838; min_child_weight=7.68; min_data_in_leaf=3664; min_gain_to_split=0.0777; lambda_l1=183; lambda_l2=694; scale_pos_weight=3.58; learning_rate=0.0478; num_iterations=4148; early_stopping_rounds=168; feature_fraction=0.482; bagging_fraction=0.916 : y = 0.908 : 82.3 secs : initdesign
#
# [mbo] 0: num_leaves=2729; min_child_weight=5.17; min_data_in_leaf=1622; min_gain_to_split=0.0536; lambda_l1=327; lambda_l2=519; scale_pos_weight=3.86; learning_rate=0.0367; num_iterations=2033; early_stopping_rounds=289; feature_fraction=0.71; bagging_fraction=0.778 : y = 0.905 : 35.0 secs : initdesign
#
# [mbo] 0: num_leaves=5340; min_child_weight=9.48; min_data_in_leaf=3760; min_gain_to_split=0.0106; lambda_l1=709; lambda_l2=561; scale_pos_weight=2.85; learning_rate=0.0671; num_iterations=2516; early_stopping_rounds=62; feature_fraction=0.197; bagging_fraction=0.707 : y = 0.887 : 12.2 secs : initdesign
#
# [mbo] 0: num_leaves=4675; min_child_weight=4.53; min_data_in_leaf=6395; min_gain_to_split=0.0792; lambda_l1=875; lambda_l2=878; scale_pos_weight=1.44; learning_rate=0.0501; num_iterations=755; early_stopping_rounds=320; feature_fraction=0.549; bagging_fraction=0.535 : y = 0.863 : 54.3 secs : initdesign
#
# [mbo] 0: num_leaves=2041; min_child_weight=5.32; min_data_in_leaf=6108; min_gain_to_split=0.0299; lambda_l1=95.1; lambda_l2=672; scale_pos_weight=1.96; learning_rate=0.0662; num_iterations=1786; early_stopping_rounds=374; feature_fraction=0.636; bagging_fraction=0.8 : y = 0.906 : 51.6 secs : initdesign
#
# [mbo] 0: num_leaves=4782; min_child_weight=8.23; min_data_in_leaf=4240; min_gain_to_split=0.0268; lambda_l1=433; lambda_l2=172; scale_pos_weight=4.42; learning_rate=0.0108; num_iterations=3523; early_stopping_rounds=138; feature_fraction=0.679; bagging_fraction=0.691 : y = 0.901 : 69.0 secs : initdesign
#
# [mbo] 0: num_leaves=3168; min_child_weight=0.421; min_data_in_leaf=2677; min_gain_to_split=0.0705; lambda_l1=388; lambda_l2=482; scale_pos_weight=1.67; learning_rate=0.0112; num_iterations=471; early_stopping_rounds=434; feature_fraction=0.651; bagging_fraction=0.653 : y = 0.883 : 35.2 secs : initdesign
#
# [mbo] 0: num_leaves=323; min_child_weight=2.47; min_data_in_leaf=7076; min_gain_to_split=0.0194; lambda_l1=477; lambda_l2=309; scale_pos_weight=4.39; learning_rate=0.036; num_iterations=1471; early_stopping_rounds=325; feature_fraction=0.247; bagging_fraction=0.737 : y = 0.898 : 62.1 secs : initdesign
#
# [mbo] 0: num_leaves=3415; min_child_weight=5.81; min_data_in_leaf=4314; min_gain_to_split=0.0654; lambda_l1=209; lambda_l2=734; scale_pos_weight=4.74; learning_rate=0.0811; num_iterations=4337; early_stopping_rounds=350; feature_fraction=0.429; bagging_fraction=0.658 : y = 0.911 : 72.3 secs : initdesign
#
# [mbo] 0: num_leaves=7519; min_child_weight=3.49; min_data_in_leaf=1467; min_gain_to_split=0.0483; lambda_l1=681; lambda_l2=116; scale_pos_weight=1.74; learning_rate=0.0546; num_iterations=2671; early_stopping_rounds=471; feature_fraction=0.156; bagging_fraction=0.723 : y = 0.892 : 40.8 secs : initdesign
#
# [mbo] 0: num_leaves=5748; min_child_weight=3.17; min_data_in_leaf=7539; min_gain_to_split=0.0849; lambda_l1=492; lambda_l2=528; scale_pos_weight=3.08; learning_rate=0.0411; num_iterations=1836; early_stopping_rounds=210; feature_fraction=0.116; bagging_fraction=0.782 : y = 0.893 : 46.8 secs : initdesign
#
# [mbo] 0: num_leaves=4986; min_child_weight=5.89; min_data_in_leaf=957; min_gain_to_split=0.0817; lambda_l1=148; lambda_l2=77.9; scale_pos_weight=4.1; learning_rate=0.0686; num_iterations=4963; early_stopping_rounds=230; feature_fraction=0.8; bagging_fraction=0.762 : y = 0.911 : 25.8 secs : initdesign
#
# [mbo] 0: num_leaves=4348; min_child_weight=6.12; min_data_in_leaf=5310; min_gain_to_split=0.0328; lambda_l1=966; lambda_l2=616; scale_pos_weight=2.2; learning_rate=0.0822; num_iterations=2176; early_stopping_rounds=493; feature_fraction=0.695; bagging_fraction=0.95 : y = 0.871 : 24.6 secs : initdesign
#
# [mbo] 0: num_leaves=1139; min_child_weight=4.08; min_data_in_leaf=1356; min_gain_to_split=0.0164; lambda_l1=55.6; lambda_l2=411; scale_pos_weight=1.21; learning_rate=0.0884; num_iterations=639; early_stopping_rounds=228; feature_fraction=0.149; bagging_fraction=0.884 : y = 0.909 : 53.3 secs : initdesign
#
# [mbo] 0: num_leaves=737; min_child_weight=6.26; min_data_in_leaf=4470; min_gain_to_split=0.073; lambda_l1=951; lambda_l2=230; scale_pos_weight=2.06; learning_rate=0.0205; num_iterations=309; early_stopping_rounds=57; feature_fraction=0.85; bagging_fraction=0.988 : y = 0.864 : 7.9 secs : initdesign
#
# [mbo] 0: num_leaves=991; min_child_weight=7.06; min_data_in_leaf=2128; min_gain_to_split=0.0407; lambda_l1=598; lambda_l2=859; scale_pos_weight=2.5; learning_rate=0.0346; num_iterations=2134; early_stopping_rounds=206; feature_fraction=0.495; bagging_fraction=0.867 : y = 0.887 : 38.6 secs : initdesign
#
# [mbo] 0: num_leaves=8147; min_child_weight=1.89; min_data_in_leaf=3087; min_gain_to_split=0.0548; lambda_l1=780; lambda_l2=796; scale_pos_weight=3.32; learning_rate=0.0274; num_iterations=3883; early_stopping_rounds=395; feature_fraction=0.507; bagging_fraction=0.933 : y = 0.887 : 87.9 secs : initdesign
#
# [mbo] 0: num_leaves=1729; min_child_weight=7.74; min_data_in_leaf=7448; min_gain_to_split=0.0282; lambda_l1=980; lambda_l2=467; scale_pos_weight=3.69; learning_rate=0.0454; num_iterations=3815; early_stopping_rounds=265; feature_fraction=0.262; bagging_fraction=0.832 : y = 0.888 : 28.1 secs : initdesign
#
# [mbo] 0: num_leaves=1294; min_child_weight=6.69; min_data_in_leaf=3041; min_gain_to_split=0.00662; lambda_l1=354; lambda_l2=193; scale_pos_weight=3.43; learning_rate=0.0777; num_iterations=4814; early_stopping_rounds=149; feature_fraction=0.888; bagging_fraction=0.967 : y = 0.898 : 15.7 secs : initdesign
#
# [mbo] 0: num_leaves=4215; min_child_weight=1.09; min_data_in_leaf=519; min_gain_to_split=0.0445; lambda_l1=107; lambda_l2=780; scale_pos_weight=2.6; learning_rate=0.0215; num_iterations=4067; early_stopping_rounds=369; feature_fraction=0.566; bagging_fraction=0.593 : y = 0.91 : 242.3 secs : initdesign
#
# [mbo] 0: num_leaves=7735; min_child_weight=2.9; min_data_in_leaf=113; min_gain_to_split=0.00527; lambda_l1=755; lambda_l2=355; scale_pos_weight=2.31; learning_rate=0.0398; num_iterations=2578; early_stopping_rounds=444; feature_fraction=0.968; bagging_fraction=0.502 : y = 0.874 : 28.9 secs : initdesign
#
# [mbo] 0: num_leaves=7235; min_child_weight=4.35; min_data_in_leaf=7268; min_gain_to_split=0.0964; lambda_l1=913; lambda_l2=345; scale_pos_weight=2.4; learning_rate=0.0977; num_iterations=4619; early_stopping_rounds=381; feature_fraction=0.344; bagging_fraction=0.806 : y = 0.877 : 50.9 secs : initdesign
#
# [mbo] 0: num_leaves=5465; min_child_weight=8.34; min_data_in_leaf=6180; min_gain_to_split=0.0421; lambda_l1=208; lambda_l2=579; scale_pos_weight=3.11; learning_rate=0.0254; num_iterations=902; early_stopping_rounds=424; feature_fraction=0.815; bagging_fraction=0.639 : y = 0.905 : 57.5 secs : initdesign
#
# [mbo] 0: num_leaves=3623; min_child_weight=0.104; min_data_in_leaf=7941; min_gain_to_split=0.0229; lambda_l1=363; lambda_l2=644; scale_pos_weight=1.41; learning_rate=0.0956; num_iterations=2380; early_stopping_rounds=473; feature_fraction=0.296; bagging_fraction=0.861 : y = 0.884 : 47.8 secs : initdesign
#
# [mbo] 0: num_leaves=4056; min_child_weight=6.52; min_data_in_leaf=3339; min_gain_to_split=0.0605; lambda_l1=928; lambda_l2=152; scale_pos_weight=4.61; learning_rate=0.0736; num_iterations=595; early_stopping_rounds=256; feature_fraction=0.384; bagging_fraction=0.618 : y = 0.891 : 31.0 secs : initdesign
#
# [mbo] 0: num_leaves=7477; min_child_weight=4.6; min_data_in_leaf=348; min_gain_to_split=0.0756; lambda_l1=69.7; lambda_l2=375; scale_pos_weight=2.43; learning_rate=0.0758; num_iterations=1207; early_stopping_rounds=92; feature_fraction=0.18; bagging_fraction=0.565 : y = 0.911 : 48.6 secs : initdesign
#
# [mbo] 0: num_leaves=2816; min_child_weight=8.96; min_data_in_leaf=5529; min_gain_to_split=0.099; lambda_l1=29.1; lambda_l2=260; scale_pos_weight=4.9; learning_rate=0.0799; num_iterations=1596; early_stopping_rounds=244; feature_fraction=0.387; bagging_fraction=0.897 : y = 0.916 : 129.4 secs : initdesign
#
# [mbo] 0: num_leaves=6363; min_child_weight=9.68; min_data_in_leaf=2816; min_gain_to_split=0.0145; lambda_l1=259; lambda_l2=983; scale_pos_weight=3.95; learning_rate=0.0515; num_iterations=1381; early_stopping_rounds=104; feature_fraction=0.751; bagging_fraction=0.919 : y = 0.903 : 34.7 secs : initdesign
#
# [mbo] 0: num_leaves=2357; min_child_weight=8.66; min_data_in_leaf=2316; min_gain_to_split=0.0571; lambda_l1=627; lambda_l2=58.6; scale_pos_weight=1.84; learning_rate=0.0435; num_iterations=3293; early_stopping_rounds=309; feature_fraction=0.0766; bagging_fraction=0.943 : y = 0.887 : 25.5 secs : initdesign
#
# [mbo] 0: num_leaves=2179; min_child_weight=2.2; min_data_in_leaf=4076; min_gain_to_split=0.0642; lambda_l1=300; lambda_l2=218; scale_pos_weight=3.22; learning_rate=0.0905; num_iterations=2822; early_stopping_rounds=460; feature_fraction=0.774; bagging_fraction=0.555 : y = 0.9 : 27.9 secs : initdesign
#
# [mbo] 0: num_leaves=6654; min_child_weight=1.71; min_data_in_leaf=6717; min_gain_to_split=0.0944; lambda_l1=127; lambda_l2=897; scale_pos_weight=3.83; learning_rate=0.0628; num_iterations=3575; early_stopping_rounds=180; feature_fraction=0.88; bagging_fraction=0.53 : y = 0.907 : 40.3 secs : initdesign
#
# [mbo] 0: num_leaves=6738; min_child_weight=0.385; min_data_in_leaf=4766; min_gain_to_split=0.00976; lambda_l1=731; lambda_l2=841; scale_pos_weight=1.11; learning_rate=0.0308; num_iterations=122; early_stopping_rounds=199; feature_fraction=0.545; bagging_fraction=0.854 : y = 0.856 : 17.3 secs : initdesign
#
# [mbo] 0: num_leaves=6940; min_child_weight=9.24; min_data_in_leaf=8070; min_gain_to_split=0.0709; lambda_l1=571; lambda_l2=4.6; scale_pos_weight=1.29; learning_rate=0.0292; num_iterations=3740; early_stopping_rounds=156; feature_fraction=0.459; bagging_fraction=0.605 : y = 0.873 : 35.4 secs : initdesign
#
# [mbo] 0: num_leaves=4478; min_child_weight=1.53; min_data_in_leaf=2519; min_gain_to_split=0.0477; lambda_l1=854; lambda_l2=327; scale_pos_weight=4.99; learning_rate=0.0148; num_iterations=2924; early_stopping_rounds=188; feature_fraction=0.989; bagging_fraction=0.755 : y = 0.898 : 31.2 secs : initdesign
#
# [mbo] 0: num_leaves=10; min_child_weight=2.64; min_data_in_leaf=6639; min_gain_to_split=0.0899; lambda_l1=804; lambda_l2=751; scale_pos_weight=3.41; learning_rate=0.00671; num_iterations=4746; early_stopping_rounds=489; feature_fraction=0.413; bagging_fraction=0.628 : y = 0.888 : 66.3 secs : initdesign
#
# [mbo] 0: num_leaves=7928; min_child_weight=9.85; min_data_in_leaf=6916; min_gain_to_split=0.0503; lambda_l1=617; lambda_l2=832; scale_pos_weight=4.3; learning_rate=0.0869; num_iterations=3067; early_stopping_rounds=279; feature_fraction=0.109; bagging_fraction=0.841 : y = 0.893 : 58.7 secs : initdesign
#
# [mbo] 0: num_leaves=2524; min_child_weight=7.4; min_data_in_leaf=4846; min_gain_to_split=0.0226; lambda_l1=813; lambda_l2=945; scale_pos_weight=4.58; learning_rate=0.0922; num_iterations=1100; early_stopping_rounds=409; feature_fraction=0.955; bagging_fraction=0.516 : y = 0.892 : 21.0 secs : initdesign
#
# [mbo] 0: num_leaves=1635; min_child_weight=1.31; min_data_in_leaf=5018; min_gain_to_split=0.0878; lambda_l1=560; lambda_l2=935; scale_pos_weight=2.16; learning_rate=0.0842; num_iterations=994; early_stopping_rounds=112; feature_fraction=0.595; bagging_fraction=0.995 : y = 0.88 : 17.8 secs : initdesign
#
# [mbo] 0: num_leaves=400; min_child_weight=3.85; min_data_in_leaf=749; min_gain_to_split=0.00189; lambda_l1=275; lambda_l2=427; scale_pos_weight=1.04; learning_rate=0.0159; num_iterations=211; early_stopping_rounds=335; feature_fraction=0.939; bagging_fraction=0.714 : y = 0.875 : 16.1 secs : initdesign
#
# [mbo] 0: num_leaves=1367; min_child_weight=1.04; min_data_in_leaf=242; min_gain_to_split=0.0178; lambda_l1=890; lambda_l2=708; scale_pos_weight=2.74; learning_rate=0.0992; num_iterations=4590; early_stopping_rounds=119; feature_fraction=0.356; bagging_fraction=0.677 : y = 0.886 : 16.7 secs : initdesign
#
# [mbo] 0: num_leaves=3034; min_child_weight=9.14; min_data_in_leaf=1162; min_gain_to_split=0.0863; lambda_l1=400; lambda_l2=130; scale_pos_weight=4.82; learning_rate=0.00728; num_iterations=4483; early_stopping_rounds=72; feature_fraction=0.0613; bagging_fraction=0.576 : y = 0.888 : 6.1 secs : initdesign
#
# [mbo] 0: num_leaves=7152; min_child_weight=7.18; min_data_in_leaf=1945; min_gain_to_split=0.0933; lambda_l1=443; lambda_l2=441; scale_pos_weight=1.52; learning_rate=0.0535; num_iterations=3425; early_stopping_rounds=449; feature_fraction=0.908; bagging_fraction=0.819 : y = 0.879 : 28.1 secs : initdesign
#
# [mbo] 0: num_leaves=5985; min_child_weight=0.676; min_data_in_leaf=5672; min_gain_to_split=0.00347; lambda_l1=238; lambda_l2=28.9; scale_pos_weight=4; learning_rate=0.0578; num_iterations=1276; early_stopping_rounds=344; feature_fraction=0.21; bagging_fraction=0.976 : y = 0.906 : 65.2 secs : initdesign
#
# [mbo] 0: num_leaves=684; min_child_weight=7.98; min_data_in_leaf=7722; min_gain_to_split=0.0357; lambda_l1=16.3; lambda_l2=964; scale_pos_weight=1.77; learning_rate=0.0243; num_iterations=2255; early_stopping_rounds=78; feature_fraction=0.735; bagging_fraction=0.547 : y = 0.913 : 205.4 secs : initdesign
#
# Saved the current state after iteration 1 in the file HT.RDATA.
#
# Thu Nov 20 01:45:36 AM 2025 AUC 0.923509682458835
#
# [mbo] 1: num_leaves=3839; min_child_weight=5.72; min_data_in_leaf=4339; min_gain_to_split=0.0486; lambda_l1=2.48; lambda_l2=674; scale_pos_weight=4.04; learning_rate=0.0746; num_iterations=1865; early_stopping_rounds=289; feature_fraction=0.484; bagging_fraction=0.728 : y = 0.924 : 300.2 secs : infill_ei
#
# Thu Nov 20 01:48:55 AM 2025 AUC 0.92768102141435
#
# [mbo] 2: num_leaves=4309; min_child_weight=5.8; min_data_in_leaf=2253; min_gain_to_split=0.0449; lambda_l1=0.76; lambda_l2=353; scale_pos_weight=4.04; learning_rate=0.0752; num_iterations=1564; early_stopping_rounds=278; feature_fraction=0.269; bagging_fraction=0.693 : y = 0.928 : 197.9 secs : infill_ei
#
# Thu Nov 20 01:51:25 AM 2025 AUC 0.926192599631317
#
# [mbo] 3: num_leaves=5282; min_child_weight=3.85; min_data_in_leaf=1953; min_gain_to_split=0.0533; lambda_l1=1.91; lambda_l2=207; scale_pos_weight=3.71; learning_rate=0.0848; num_iterations=1705; early_stopping_rounds=371; feature_fraction=0.233; bagging_fraction=0.835 : y = 0.926 : 149.1 secs : infill_ei
#
# Saved the current state after iteration 4 in the file HT.RDATA.
#
# Thu Nov 20 01:54:43 AM 2025 AUC 0.926490216881441
#
# [mbo] 4: num_leaves=3348; min_child_weight=6.6; min_data_in_leaf=4166; min_gain_to_split=0.0278; lambda_l1=0.714; lambda_l2=362; scale_pos_weight=3.43; learning_rate=0.0873; num_iterations=2002; early_stopping_rounds=255; feature_fraction=0.16; bagging_fraction=0.668 : y = 0.926 : 195.4 secs : infill_ei
#
# Thu Nov 20 01:56:40 AM 2025 AUC 0.924923280513821
#
# [mbo] 5: num_leaves=3943; min_child_weight=7.23; min_data_in_leaf=1506; min_gain_to_split=0.0344; lambda_l1=1.67; lambda_l2=632; scale_pos_weight=3.47; learning_rate=0.0915; num_iterations=1517; early_stopping_rounds=245; feature_fraction=0.0559; bagging_fraction=0.772 : y = 0.925 : 116.2 secs : infill_ei
#
# Thu Nov 20 02:00:40 AM 2025 AUC 0.930444466365895
#
# [mbo] 6: num_leaves=4881; min_child_weight=4.02; min_data_in_leaf=1410; min_gain_to_split=0.0314; lambda_l1=0.755; lambda_l2=263; scale_pos_weight=3.74; learning_rate=0.0712; num_iterations=2820; early_stopping_rounds=344; feature_fraction=0.0722; bagging_fraction=0.679 : y = 0.93 : 239.6 secs : infill_ei
#
# Thu Nov 20 02:04:21 AM 2025 AUC 0.92787026169515
#
# [mbo] 7: num_leaves=3403; min_child_weight=3.38; min_data_in_leaf=1158; min_gain_to_split=0.0166; lambda_l1=0.106; lambda_l2=187; scale_pos_weight=3.81; learning_rate=0.0819; num_iterations=2750; early_stopping_rounds=355; feature_fraction=0.143; bagging_fraction=0.691 : y = 0.928 : 219.5 secs : infill_ei
#
# Saved the current state after iteration 8 in the file HT.RDATA.
#
# Thu Nov 20 02:07:08 AM 2025 AUC 0.928068896883508
#
# [mbo] 8: num_leaves=5542; min_child_weight=2.1; min_data_in_leaf=2076; min_gain_to_split=0.0298; lambda_l1=1.6; lambda_l2=35.5; scale_pos_weight=3.71; learning_rate=0.0698; num_iterations=2963; early_stopping_rounds=221; feature_fraction=0.113; bagging_fraction=0.824 : y = 0.928 : 165.8 secs : infill_ei
#
# Thu Nov 20 02:10:39 AM 2025 AUC 0.927836708453873
#
# [mbo] 9: num_leaves=2227; min_child_weight=3.4; min_data_in_leaf=2276; min_gain_to_split=0.0398; lambda_l1=0.0264; lambda_l2=305; scale_pos_weight=3.3; learning_rate=0.064; num_iterations=2632; early_stopping_rounds=302; feature_fraction=0.0672; bagging_fraction=0.573 : y = 0.928 : 210.3 secs : infill_ei
#
# Thu Nov 20 02:13:24 AM 2025 AUC 0.924092837792224
#
# [mbo] 10: num_leaves=4793; min_child_weight=4.34; min_data_in_leaf=2508; min_gain_to_split=0.0362; lambda_l1=0.993; lambda_l2=265; scale_pos_weight=3.95; learning_rate=0.029; num_iterations=1941; early_stopping_rounds=461; feature_fraction=0.0839; bagging_fraction=0.663 : y = 0.924 : 163.9 secs : infill_ei
#
# Thu Nov 20 02:15:30 AM 2025 AUC 0.921875639608662
#
# [mbo] 11: num_leaves=5585; min_child_weight=4.96; min_data_in_leaf=1870; min_gain_to_split=0.0295; lambda_l1=2.25; lambda_l2=94; scale_pos_weight=3.29; learning_rate=0.0895; num_iterations=3216; early_stopping_rounds=309; feature_fraction=0.0904; bagging_fraction=0.651 : y = 0.922 : 124.7 secs : infill_ei
#
# Saved the current state after iteration 12 in the file HT.RDATA.
#
# Thu Nov 20 02:19:07 AM 2025 AUC 0.929600266815375
#
# [mbo] 12: num_leaves=3824; min_child_weight=1.55; min_data_in_leaf=1187; min_gain_to_split=0.0312; lambda_l1=0.139; lambda_l2=377; scale_pos_weight=3.74; learning_rate=0.0674; num_iterations=2568; early_stopping_rounds=267; feature_fraction=0.0711; bagging_fraction=0.762 : y = 0.93 : 215.1 secs : infill_ei
#
# Thu Nov 20 02:21:51 AM 2025 AUC 0.929909627699945
#
# [mbo] 13: num_leaves=3851; min_child_weight=3.62; min_data_in_leaf=4341; min_gain_to_split=0.0516; lambda_l1=0.34; lambda_l2=146; scale_pos_weight=3.94; learning_rate=0.0641; num_iterations=2641; early_stopping_rounds=196; feature_fraction=0.0594; bagging_fraction=0.718 : y = 0.93 : 163.8 secs : infill_ei
#
# Thu Nov 20 02:23:12 AM 2025 AUC 0.92070865787706
#
# [mbo] 14: num_leaves=4862; min_child_weight=3.72; min_data_in_leaf=1315; min_gain_to_split=0.042; lambda_l1=14.6; lambda_l2=36.6; scale_pos_weight=4.22; learning_rate=0.0592; num_iterations=2548; early_stopping_rounds=150; feature_fraction=0.156; bagging_fraction=0.816 : y = 0.921 : 79.8 secs : infill_ei
#
# Thu Nov 20 02:27:10 AM 2025 AUC 0.928430936356883
#
# [mbo] 15: num_leaves=3428; min_child_weight=1.32; min_data_in_leaf=3127; min_gain_to_split=0.0736; lambda_l1=0.048; lambda_l2=300; scale_pos_weight=3.9; learning_rate=0.0689; num_iterations=2846; early_stopping_rounds=267; feature_fraction=0.0849; bagging_fraction=0.712 : y = 0.928 : 236.3 secs : infill_ei
#
# Saved the current state after iteration 16 in the file HT.RDATA.
#
# Thu Nov 20 02:30:25 AM 2025 AUC 0.923459688129333
#
# [mbo] 16: num_leaves=4116; min_child_weight=1.39; min_data_in_leaf=5204; min_gain_to_split=0.0258; lambda_l1=0.363; lambda_l2=221; scale_pos_weight=3.82; learning_rate=0.0673; num_iterations=3592; early_stopping_rounds=205; feature_fraction=0.266; bagging_fraction=0.542 : y = 0.923 : 193.8 secs : infill_ei
#
# Thu Nov 20 02:32:47 AM 2025 AUC 0.923164419606098
#
# [mbo] 17: num_leaves=2831; min_child_weight=5.38; min_data_in_leaf=6262; min_gain_to_split=0.0722; lambda_l1=0.693; lambda_l2=376; scale_pos_weight=3.81; learning_rate=0.066; num_iterations=1909; early_stopping_rounds=369; feature_fraction=0.0596; bagging_fraction=0.66 : y = 0.923 : 140.6 secs : infill_ei
#
# Thu Nov 20 02:36:17 AM 2025 AUC 0.925706748697631
#
# [mbo] 18: num_leaves=3612; min_child_weight=3.42; min_data_in_leaf=3623; min_gain_to_split=0.0175; lambda_l1=2.37; lambda_l2=576; scale_pos_weight=3.78; learning_rate=0.0684; num_iterations=2770; early_stopping_rounds=229; feature_fraction=0.0575; bagging_fraction=0.724 : y = 0.926 : 209.5 secs : infill_ei
#
# Thu Nov 20 02:39:54 AM 2025 AUC 0.92893624817051
#
# [mbo] 19: num_leaves=4493; min_child_weight=2.65; min_data_in_leaf=2454; min_gain_to_split=0.0399; lambda_l1=0.406; lambda_l2=255; scale_pos_weight=3.66; learning_rate=0.0626; num_iterations=2629; early_stopping_rounds=298; feature_fraction=0.239; bagging_fraction=0.661 : y = 0.929 : 215.1 secs : infill_ei
#
# Saved the current state after iteration 20 in the file HT.RDATA.
#
# Thu Nov 20 02:43:17 AM 2025 AUC 0.927139136567732
#
# [mbo] 20: num_leaves=4011; min_child_weight=7.41; min_data_in_leaf=2569; min_gain_to_split=0.0441; lambda_l1=0.441; lambda_l2=202; scale_pos_weight=3.75; learning_rate=0.0724; num_iterations=2558; early_stopping_rounds=479; feature_fraction=0.0544; bagging_fraction=0.785 : y = 0.927 : 201.5 secs : infill_ei
#
# Thu Nov 20 02:46:14 AM 2025 AUC 0.928398389712845
#
# [mbo] 21: num_leaves=4082; min_child_weight=0.829; min_data_in_leaf=3053; min_gain_to_split=0.0478; lambda_l1=0.738; lambda_l2=170; scale_pos_weight=3.71; learning_rate=0.0732; num_iterations=2128; early_stopping_rounds=259; feature_fraction=0.0751; bagging_fraction=0.786 : y = 0.928 : 175.9 secs : infill_ei
#
# Thu Nov 20 02:48:03 AM 2025 AUC 0.922302436837701
#
# [mbo] 22: num_leaves=3519; min_child_weight=7.56; min_data_in_leaf=1419; min_gain_to_split=0.0507; lambda_l1=1.85; lambda_l2=274; scale_pos_weight=3.63; learning_rate=0.0706; num_iterations=1400; early_stopping_rounds=359; feature_fraction=0.0501; bagging_fraction=0.531 : y = 0.922 : 108.5 secs : infill_ei
#
# Thu Nov 20 02:51:49 AM 2025 AUC 0.926902921749144
#
# [mbo] 23: num_leaves=1688; min_child_weight=6.85; min_data_in_leaf=4745; min_gain_to_split=0.032; lambda_l1=0.0507; lambda_l2=247; scale_pos_weight=3.6; learning_rate=0.0556; num_iterations=3258; early_stopping_rounds=162; feature_fraction=0.0827; bagging_fraction=0.799 : y = 0.927 : 224.9 secs : infill_ei
#
# Saved the current state after iteration 24 in the file HT.RDATA.
#
# Thu Nov 20 02:59:36 AM 2025 AUC 0.919639316077572
#
# [mbo] 24: num_leaves=1357; min_child_weight=3.16; min_data_in_leaf=6907; min_gain_to_split=0.045; lambda_l1=0.112; lambda_l2=91.9; scale_pos_weight=3.73; learning_rate=0.0113; num_iterations=3235; early_stopping_rounds=285; feature_fraction=0.421; bagging_fraction=0.724 : y = 0.92 : 466.1 secs : infill_ei
#
# Thu Nov 20 03:03:36 AM 2025 AUC 0.925546028671916
#
# [mbo] 25: num_leaves=1792; min_child_weight=5.45; min_data_in_leaf=1958; min_gain_to_split=0.0408; lambda_l1=2.81; lambda_l2=343; scale_pos_weight=3.82; learning_rate=0.0733; num_iterations=2895; early_stopping_rounds=405; feature_fraction=0.131; bagging_fraction=0.743 : y = 0.926 : 238.8 secs : infill_ei
#
# Saved the current state after iteration 26 in the file HT.RDATA.
#
# Thu Nov 20 03:07:23 AM 2025 AUC 0.926061406457925
#
# [mbo] 26: num_leaves=5090; min_child_weight=2.08; min_data_in_leaf=2478; min_gain_to_split=0.0306; lambda_l1=0.404; lambda_l2=227; scale_pos_weight=3.68; learning_rate=0.0636; num_iterations=2900; early_stopping_rounds=332; feature_fraction=0.0503; bagging_fraction=0.849 : y = 0.926 : 225.3 secs : infill_ei
#
# Thu Nov 20 03:08:42 AM 2025 AUC 0.916915799483146
#
# [mbo] 27: num_leaves=1975; min_child_weight=8.75; min_data_in_leaf=8096; min_gain_to_split=0.0475; lambda_l1=0.401; lambda_l2=254; scale_pos_weight=3.8; learning_rate=0.0706; num_iterations=2313; early_stopping_rounds=173; feature_fraction=0.715; bagging_fraction=0.739 : y = 0.917 : 78.2 secs : infill_ei
#
# Thu Nov 20 03:11:20 AM 2025 AUC 0.922768826891447
#
# [mbo] 28: num_leaves=3724; min_child_weight=2.97; min_data_in_leaf=1559; min_gain_to_split=0.0466; lambda_l1=5.62; lambda_l2=249; scale_pos_weight=3.64; learning_rate=0.0718; num_iterations=2659; early_stopping_rounds=121; feature_fraction=0.223; bagging_fraction=0.704 : y = 0.923 : 156.5 secs : infill_ei
#
# Thu Nov 20 03:14:24 AM 2025 AUC 0.925619845802724
#
# [mbo] 29: num_leaves=5422; min_child_weight=3.31; min_data_in_leaf=411; min_gain_to_split=0.0781; lambda_l1=11.1; lambda_l2=288; scale_pos_weight=3.91; learning_rate=0.0761; num_iterations=2506; early_stopping_rounds=370; feature_fraction=0.0511; bagging_fraction=0.679 : y = 0.926 : 182.5 secs : infill_ei
#
# Saved the current state after iteration 30 in the file HT.RDATA.
#
# Thu Nov 20 03:17:32 AM 2025 AUC 0.929149311252616
#
# [mbo] 30: num_leaves=4560; min_child_weight=3.35; min_data_in_leaf=1794; min_gain_to_split=0.0294; lambda_l1=1.29; lambda_l2=282; scale_pos_weight=3.65; learning_rate=0.072; num_iterations=2140; early_stopping_rounds=302; feature_fraction=0.0829; bagging_fraction=0.698 : y = 0.929 : 186.4 secs : infill_ei
#
# Thu Nov 20 03:21:46 AM 2025 AUC 0.924647472870527
#
# [mbo] 31: num_leaves=1353; min_child_weight=4.23; min_data_in_leaf=5210; min_gain_to_split=0.0353; lambda_l1=2.11; lambda_l2=259; scale_pos_weight=2.77; learning_rate=0.0706; num_iterations=3337; early_stopping_rounds=208; feature_fraction=0.191; bagging_fraction=0.693 : y = 0.925 : 252.5 secs : infill_ei
#
# Thu Nov 20 03:25:13 AM 2025 AUC 0.924044185592372
#
# [mbo] 32: num_leaves=851; min_child_weight=6.65; min_data_in_leaf=5003; min_gain_to_split=0.0545; lambda_l1=0.437; lambda_l2=173; scale_pos_weight=3.58; learning_rate=0.0277; num_iterations=2386; early_stopping_rounds=259; feature_fraction=0.107; bagging_fraction=0.607 : y = 0.924 : 206.3 secs : infill_ei
#
# Saved the current state after iteration 33 in the file HT.RDATA.
#
# Thu Nov 20 03:27:41 AM 2025 AUC 0.924826647178944
#
# [mbo] 33: num_leaves=2545; min_child_weight=5.28; min_data_in_leaf=4632; min_gain_to_split=0.0551; lambda_l1=0.991; lambda_l2=24.4; scale_pos_weight=3.78; learning_rate=0.0826; num_iterations=2792; early_stopping_rounds=234; feature_fraction=0.129; bagging_fraction=0.827 : y = 0.925 : 146.3 secs : infill_ei
#
# Thu Nov 20 03:32:07 AM 2025 AUC 0.92814070081984
#
# [mbo] 34: num_leaves=2261; min_child_weight=2.87; min_data_in_leaf=1135; min_gain_to_split=0.0656; lambda_l1=0.104; lambda_l2=282; scale_pos_weight=3.6; learning_rate=0.0652; num_iterations=2743; early_stopping_rounds=228; feature_fraction=0.158; bagging_fraction=0.72 : y = 0.928 : 264.1 secs : infill_ei
#
# Thu Nov 20 03:36:42 AM 2025 AUC 0.927133768049127
#
# [mbo] 35: num_leaves=6784; min_child_weight=4.19; min_data_in_leaf=1144; min_gain_to_split=0.0319; lambda_l1=1.62; lambda_l2=231; scale_pos_weight=4.2; learning_rate=0.0702; num_iterations=2693; early_stopping_rounds=461; feature_fraction=0.13; bagging_fraction=0.69 : y = 0.927 : 273.7 secs : infill_ei
#
# Saved the current state after iteration 36 in the file HT.RDATA.
#
# Thu Nov 20 03:39:37 AM 2025 AUC 0.925635615826124
#
# [mbo] 36: num_leaves=5729; min_child_weight=7.42; min_data_in_leaf=4006; min_gain_to_split=0.0505; lambda_l1=0.163; lambda_l2=368; scale_pos_weight=3.85; learning_rate=0.072; num_iterations=2206; early_stopping_rounds=225; feature_fraction=0.111; bagging_fraction=0.732 : y = 0.926 : 173.4 secs : infill_ei
#
# Thu Nov 20 03:43:23 AM 2025 AUC 0.93238552137375
#
# [mbo] 37: num_leaves=4174; min_child_weight=3.71; min_data_in_leaf=430; min_gain_to_split=0.0294; lambda_l1=1.97; lambda_l2=37.6; scale_pos_weight=4.09; learning_rate=0.0565; num_iterations=3778; early_stopping_rounds=469; feature_fraction=0.095; bagging_fraction=0.715 : y = 0.932 : 224.6 secs : infill_ei
#
# Thu Nov 20 03:46:31 AM 2025 AUC 0.924609893240297
#
# [mbo] 38: num_leaves=3701; min_child_weight=2.45; min_data_in_leaf=1122; min_gain_to_split=0.051; lambda_l1=8.5; lambda_l2=89; scale_pos_weight=4.01; learning_rate=0.05; num_iterations=3419; early_stopping_rounds=436; feature_fraction=0.251; bagging_fraction=0.74 : y = 0.925 : 185.9 secs : infill_ei
#
# Thu Nov 20 03:53:22 AM 2025 AUC 0.929298287643885
#
# [mbo] 39: num_leaves=3907; min_child_weight=7.53; min_data_in_leaf=47; min_gain_to_split=0.00498; lambda_l1=1.81; lambda_l2=136; scale_pos_weight=3.84; learning_rate=0.0169; num_iterations=4881; early_stopping_rounds=484; feature_fraction=0.0518; bagging_fraction=0.645 : y = 0.929 : 409.0 secs : infill_ei
#
# Saved the current state after iteration 40 in the file HT.RDATA.
#
# Thu Nov 20 03:57:42 AM 2025 AUC 0.929797559874081
#
# [mbo] 40: num_leaves=2350; min_child_weight=2.22; min_data_in_leaf=716; min_gain_to_split=0.0362; lambda_l1=0.978; lambda_l2=323; scale_pos_weight=3.83; learning_rate=0.0583; num_iterations=4597; early_stopping_rounds=256; feature_fraction=0.0664; bagging_fraction=0.678 : y = 0.93 : 259.1 secs : infill_ei
#
# Thu Nov 20 04:02:21 AM 2025 AUC 0.930774294727645
#
# [mbo] 41: num_leaves=4887; min_child_weight=6.45; min_data_in_leaf=85; min_gain_to_split=0.0312; lambda_l1=2.38; lambda_l2=245; scale_pos_weight=4.57; learning_rate=0.0541; num_iterations=4402; early_stopping_rounds=412; feature_fraction=0.339; bagging_fraction=0.677 : y = 0.931 : 277.4 secs : infill_ei
#
# Thu Nov 20 04:04:15 AM 2025 AUC 0.919393706351427
#
# [mbo] 42: num_leaves=1135; min_child_weight=6.63; min_data_in_leaf=5406; min_gain_to_split=0.0623; lambda_l1=0.662; lambda_l2=807; scale_pos_weight=2.92; learning_rate=0.0503; num_iterations=1517; early_stopping_rounds=198; feature_fraction=0.0613; bagging_fraction=0.643 : y = 0.919 : 112.2 secs : infill_ei
#
# Saved the current state after iteration 43 in the file HT.RDATA.
#
# Thu Nov 20 04:10:21 AM 2025 AUC 0.925096750771221
#
# [mbo] 43: num_leaves=4704; min_child_weight=3.54; min_data_in_leaf=4316; min_gain_to_split=0.0284; lambda_l1=1.18; lambda_l2=239; scale_pos_weight=4.61; learning_rate=0.0932; num_iterations=4869; early_stopping_rounds=487; feature_fraction=0.137; bagging_fraction=0.705 : y = 0.925 : 364.8 secs : infill_ei
#
# Thu Nov 20 04:13:27 AM 2025 AUC 0.91405169480777
#
# [mbo] 44: num_leaves=4337; min_child_weight=4.12; min_data_in_leaf=704; min_gain_to_split=0.0101; lambda_l1=67.1; lambda_l2=211; scale_pos_weight=4.26; learning_rate=0.0607; num_iterations=4379; early_stopping_rounds=498; feature_fraction=0.114; bagging_fraction=0.674 : y = 0.914 : 184.1 secs : infill_ei
#
# Thu Nov 20 04:17:20 AM 2025 AUC 0.927291132750715
#
# [mbo] 45: num_leaves=2374; min_child_weight=7.53; min_data_in_leaf=4710; min_gain_to_split=0.0102; lambda_l1=0.211; lambda_l2=73.2; scale_pos_weight=4.53; learning_rate=0.0438; num_iterations=4488; early_stopping_rounds=281; feature_fraction=0.14; bagging_fraction=0.699 : y = 0.927 : 230.4 secs : infill_ei
#
# Saved the current state after iteration 46 in the file HT.RDATA.
#
# Thu Nov 20 04:24:19 AM 2025 AUC 0.9272250328654
#
# [mbo] 46: num_leaves=3824; min_child_weight=8.4; min_data_in_leaf=890; min_gain_to_split=0.0318; lambda_l1=0.0338; lambda_l2=169; scale_pos_weight=2.22; learning_rate=0.0242; num_iterations=2954; early_stopping_rounds=171; feature_fraction=0.315; bagging_fraction=0.746 : y = 0.927 : 417.6 secs : infill_ei
#
# Thu Nov 20 04:28:49 AM 2025 AUC 0.928057153249061
#
# [mbo] 47: num_leaves=4067; min_child_weight=4.2; min_data_in_leaf=407; min_gain_to_split=0.0633; lambda_l1=0.739; lambda_l2=411; scale_pos_weight=2.72; learning_rate=0.0477; num_iterations=4120; early_stopping_rounds=251; feature_fraction=0.0678; bagging_fraction=0.709 : y = 0.928 : 268.2 secs : infill_ei
#
# Saved the current state after iteration 48 in the file HT.RDATA.
#
# Thu Nov 20 04:34:13 AM 2025 AUC 0.929785480707222
#
# [mbo] 48: num_leaves=2429; min_child_weight=7.73; min_data_in_leaf=1283; min_gain_to_split=0.0253; lambda_l1=0.335; lambda_l2=257; scale_pos_weight=3.45; learning_rate=0.032; num_iterations=4090; early_stopping_rounds=267; feature_fraction=0.0621; bagging_fraction=0.649 : y = 0.93 : 321.4 secs : infill_ei
#
# Thu Nov 20 04:35:56 AM 2025 AUC 0.932443904013572
#
# [mbo] 49: num_leaves=5054; min_child_weight=7.17; min_data_in_leaf=122; min_gain_to_split=0.0291; lambda_l1=1.96; lambda_l2=12.8; scale_pos_weight=3.94; learning_rate=0.0517; num_iterations=3876; early_stopping_rounds=434; feature_fraction=0.134; bagging_fraction=0.779 : y = 0.932 : 101.9 secs : infill_ei
#
# Thu Nov 20 04:39:46 AM 2025 AUC 0.926946876495216
#
# [mbo] 50: num_leaves=3520; min_child_weight=4.04; min_data_in_leaf=55; min_gain_to_split=0.0371; lambda_l1=0.259; lambda_l2=522; scale_pos_weight=2.28; learning_rate=0.0478; num_iterations=2036; early_stopping_rounds=214; feature_fraction=0.172; bagging_fraction=0.649 : y = 0.927 : 228.5 secs : infill_ei
#
# Saved the current state after iteration 51 in the file HT.RDATA.
#
# Thu Nov 20 04:44:52 AM 2025 AUC 0.924286104461977
#
# [mbo] 51: num_leaves=1635; min_child_weight=5.06; min_data_in_leaf=126; min_gain_to_split=0.00935; lambda_l1=0.916; lambda_l2=59.9; scale_pos_weight=3.23; learning_rate=0.0181; num_iterations=4071; early_stopping_rounds=277; feature_fraction=0.888; bagging_fraction=0.67 : y = 0.924 : 304.3 secs : infill_ei
#
# Thu Nov 20 04:46:59 AM 2025 AUC 0.92014966087739
#
# [mbo] 52: num_leaves=2645; min_child_weight=6.48; min_data_in_leaf=4334; min_gain_to_split=0.0205; lambda_l1=0.158; lambda_l2=139; scale_pos_weight=2.53; learning_rate=0.0247; num_iterations=1620; early_stopping_rounds=181; feature_fraction=0.0649; bagging_fraction=0.903 : y = 0.92 : 124.8 secs : infill_ei
#
# Thu Nov 20 04:52:02 AM 2025 AUC 0.930908843225164
#
# [mbo] 53: num_leaves=3254; min_child_weight=8.84; min_data_in_leaf=2; min_gain_to_split=0.0337; lambda_l1=1.66; lambda_l2=27.6; scale_pos_weight=4.39; learning_rate=0.0199; num_iterations=4308; early_stopping_rounds=442; feature_fraction=0.151; bagging_fraction=0.708 : y = 0.931 : 302.1 secs : infill_ei
#
# Saved the current state after iteration 54 in the file HT.RDATA.
#
# Thu Nov 20 04:55:58 AM 2025 AUC 0.929624425149094
#
# [mbo] 54: num_leaves=2623; min_child_weight=4.77; min_data_in_leaf=119; min_gain_to_split=0.0307; lambda_l1=0.212; lambda_l2=425; scale_pos_weight=4.89; learning_rate=0.0952; num_iterations=1582; early_stopping_rounds=276; feature_fraction=0.312; bagging_fraction=0.702 : y = 0.93 : 234.7 secs : infill_ei
#
# Thu Nov 20 05:01:51 AM 2025 AUC 0.929167765535318
#
# [mbo] 55: num_leaves=2878; min_child_weight=7.93; min_data_in_leaf=3730; min_gain_to_split=0.0455; lambda_l1=0.0446; lambda_l2=164; scale_pos_weight=1.94; learning_rate=0.0362; num_iterations=4576; early_stopping_rounds=184; feature_fraction=0.0584; bagging_fraction=0.744 : y = 0.929 : 351.1 secs : infill_ei
#
# Thu Nov 20 05:07:43 AM 2025 AUC 0.924286775526803
#
# [mbo] 56: num_leaves=3173; min_child_weight=4.42; min_data_in_leaf=3486; min_gain_to_split=0.0722; lambda_l1=0.153; lambda_l2=298; scale_pos_weight=1.82; learning_rate=0.0473; num_iterations=2848; early_stopping_rounds=210; feature_fraction=0.651; bagging_fraction=0.658 : y = 0.924 : 350.4 secs : infill_ei
#
# Saved the current state after iteration 57 in the file HT.RDATA.
#
# Thu Nov 20 05:18:04 AM 2025 AUC 0.922528921216318
#
# [mbo] 57: num_leaves=3820; min_child_weight=6.4; min_data_in_leaf=147; min_gain_to_split=0.0328; lambda_l1=0.0162; lambda_l2=333; scale_pos_weight=2.39; learning_rate=0.00712; num_iterations=4400; early_stopping_rounds=460; feature_fraction=0.301; bagging_fraction=0.781 : y = 0.923 : 619.8 secs : infill_ei
#
# Saved the current state after iteration 58 in the file HT.RDATA.
#
# Thu Nov 20 05:21:07 AM 2025 AUC 0.92844033126444
#
# [mbo] 58: num_leaves=4421; min_child_weight=2.09; min_data_in_leaf=2694; min_gain_to_split=0.0337; lambda_l1=0.0777; lambda_l2=70; scale_pos_weight=4.98; learning_rate=0.0942; num_iterations=3522; early_stopping_rounds=310; feature_fraction=0.757; bagging_fraction=0.75 : y = 0.928 : 180.7 secs : infill_ei
#
# Thu Nov 20 05:26:25 AM 2025 AUC 0.924772290928076
#
# [mbo] 59: num_leaves=4289; min_child_weight=8.22; min_data_in_leaf=736; min_gain_to_split=0.0183; lambda_l1=0.22; lambda_l2=430; scale_pos_weight=4.74; learning_rate=0.0976; num_iterations=2866; early_stopping_rounds=375; feature_fraction=0.572; bagging_fraction=0.818 : y = 0.925 : 316.7 secs : infill_ei
#
# Thu Nov 20 05:31:02 AM 2025 AUC 0.930688733962389
#
# [mbo] 60: num_leaves=3782; min_child_weight=3.36; min_data_in_leaf=25; min_gain_to_split=0.0292; lambda_l1=0.0638; lambda_l2=57.8; scale_pos_weight=4.28; learning_rate=0.0299; num_iterations=4471; early_stopping_rounds=329; feature_fraction=0.302; bagging_fraction=0.606 : y = 0.931 : 275.3 secs : infill_ei
#
# Saved the current state after iteration 61 in the file HT.RDATA.
#
# Thu Nov 20 05:45:52 AM 2025 AUC 0.923340238590388
#
# [mbo] 61: num_leaves=6493; min_child_weight=6.2; min_data_in_leaf=1210; min_gain_to_split=0.0375; lambda_l1=0.213; lambda_l2=253; scale_pos_weight=1.32; learning_rate=0.0163; num_iterations=4882; early_stopping_rounds=174; feature_fraction=0.536; bagging_fraction=0.84 : y = 0.923 : 888.6 secs : infill_ei
#
# Saved the current state after iteration 62 in the file HT.RDATA.
#
# Thu Nov 20 05:50:08 AM 2025 AUC 0.924568622753527
#
# [mbo] 62: num_leaves=4125; min_child_weight=7.93; min_data_in_leaf=4071; min_gain_to_split=0.03; lambda_l1=0.694; lambda_l2=152; scale_pos_weight=3.82; learning_rate=0.0318; num_iterations=4949; early_stopping_rounds=257; feature_fraction=0.728; bagging_fraction=0.676 : y = 0.925 : 253.6 secs : infill_ei
#
# Thu Nov 20 05:54:36 AM 2025 AUC 0.93317502914099
#
# [mbo] 63: num_leaves=4645; min_child_weight=3.94; min_data_in_leaf=142; min_gain_to_split=0.0304; lambda_l1=0.00591; lambda_l2=103; scale_pos_weight=4.97; learning_rate=0.0827; num_iterations=4547; early_stopping_rounds=442; feature_fraction=0.0717; bagging_fraction=0.69 : y = 0.933 : 265.6 secs : infill_ei
#
# Thu Nov 20 05:55:53 AM 2025 AUC 0.924902477504229
#
# [mbo] 64: num_leaves=4416; min_child_weight=2.2; min_data_in_leaf=3511; min_gain_to_split=0.0408; lambda_l1=1.46; lambda_l2=18.4; scale_pos_weight=4.99; learning_rate=0.0957; num_iterations=904; early_stopping_rounds=414; feature_fraction=0.0744; bagging_fraction=0.728 : y = 0.925 : 75.1 secs : infill_ei
#
# Saved the current state after iteration 65 in the file HT.RDATA.
#
# Thu Nov 20 06:03:29 AM 2025 AUC 0.926323792804709
#
# [mbo] 65: num_leaves=1150; min_child_weight=5.91; min_data_in_leaf=245; min_gain_to_split=0.0308; lambda_l1=0.447; lambda_l2=174; scale_pos_weight=1.54; learning_rate=0.0308; num_iterations=4193; early_stopping_rounds=174; feature_fraction=0.451; bagging_fraction=0.748 : y = 0.926 : 452.6 secs : infill_ei
#
# Thu Nov 20 06:06:51 AM 2025 AUC 0.930484730255427
#
# [mbo] 66: num_leaves=4315; min_child_weight=1.02; min_data_in_leaf=58; min_gain_to_split=0.0357; lambda_l1=0.729; lambda_l2=49.8; scale_pos_weight=1.81; learning_rate=0.0681; num_iterations=3985; early_stopping_rounds=201; feature_fraction=0.465; bagging_fraction=0.763 : y = 0.93 : 199.9 secs : infill_ei
#
# Saved the current state after iteration 67 in the file HT.RDATA.
#
# Thu Nov 20 06:08:00 AM 2025 AUC 0.915639434184982
#
# [mbo] 67: num_leaves=3789; min_child_weight=1.31; min_data_in_leaf=2800; min_gain_to_split=0.0404; lambda_l1=0.002; lambda_l2=152; scale_pos_weight=1.14; learning_rate=0.0381; num_iterations=3748; early_stopping_rounds=53; feature_fraction=0.0883; bagging_fraction=0.723 : y = 0.916 : 66.4 secs : infill_ei
#
# Thu Nov 20 06:11:59 AM 2025 AUC 0.9241737011037
#
# [mbo] 68: num_leaves=4885; min_child_weight=1.84; min_data_in_leaf=77; min_gain_to_split=0.035; lambda_l1=0.45; lambda_l2=330; scale_pos_weight=2.84; learning_rate=0.0795; num_iterations=2167; early_stopping_rounds=220; feature_fraction=0.77; bagging_fraction=0.743 : y = 0.924 : 236.5 secs : infill_ei
#
# Thu Nov 20 06:15:34 AM 2025 AUC 0.92830444063727
#
# [mbo] 69: num_leaves=2685; min_child_weight=7.8; min_data_in_leaf=3685; min_gain_to_split=0.0431; lambda_l1=0.357; lambda_l2=187; scale_pos_weight=4.98; learning_rate=0.0595; num_iterations=4065; early_stopping_rounds=255; feature_fraction=0.146; bagging_fraction=0.679 : y = 0.928 : 213.1 secs : infill_ei
#
# Thu Nov 20 06:22:32 AM 2025 AUC 0.924934353083442
#
# [mbo] 70: num_leaves=3962; min_child_weight=9.02; min_data_in_leaf=2683; min_gain_to_split=0.0263; lambda_l1=0.0397; lambda_l2=94.3; scale_pos_weight=2.05; learning_rate=0.00884; num_iterations=4710; early_stopping_rounds=300; feature_fraction=0.0958; bagging_fraction=0.617 : y = 0.925 : 416.0 secs : infill_ei
#
# Saved the current state after iteration 71 in the file HT.RDATA.
#
# Thu Nov 20 06:28:48 AM 2025 AUC 0.930584383382019
#
# [mbo] 71: num_leaves=4355; min_child_weight=7.69; min_data_in_leaf=501; min_gain_to_split=0.0141; lambda_l1=0.0283; lambda_l2=385; scale_pos_weight=1.86; learning_rate=0.0588; num_iterations=4173; early_stopping_rounds=224; feature_fraction=0.0952; bagging_fraction=0.811 : y = 0.931 : 374.1 secs : infill_ei
#
# Thu Nov 20 06:31:41 AM 2025 AUC 0.931211828993893
#
# [mbo] 72: num_leaves=2969; min_child_weight=6.65; min_data_in_leaf=650; min_gain_to_split=0.0231; lambda_l1=0.623; lambda_l2=234; scale_pos_weight=4.99; learning_rate=0.0625; num_iterations=3902; early_stopping_rounds=259; feature_fraction=0.0661; bagging_fraction=0.857 : y = 0.931 : 170.4 secs : infill_ei
#
# Thu Nov 20 06:36:23 AM 2025 AUC 0.927073372214829
#
# [mbo] 73: num_leaves=3799; min_child_weight=2.77; min_data_in_leaf=61; min_gain_to_split=0.047; lambda_l1=0.0309; lambda_l2=729; scale_pos_weight=4.96; learning_rate=0.0707; num_iterations=2820; early_stopping_rounds=312; feature_fraction=0.117; bagging_fraction=0.632 : y = 0.927 : 279.3 secs : infill_ei
#
# Saved the current state after iteration 74 in the file HT.RDATA.
#
# Thu Nov 20 06:37:47 AM 2025 AUC 0.922552744017625
#
# [mbo] 74: num_leaves=6724; min_child_weight=2.28; min_data_in_leaf=261; min_gain_to_split=0.0678; lambda_l1=0.29; lambda_l2=238; scale_pos_weight=1.73; learning_rate=0.0701; num_iterations=745; early_stopping_rounds=223; feature_fraction=0.151; bagging_fraction=0.812 : y = 0.923 : 81.8 secs : infill_ei
#
# Thu Nov 20 06:40:32 AM 2025 AUC 0.929463034058553
#
# [mbo] 75: num_leaves=5818; min_child_weight=6.64; min_data_in_leaf=363; min_gain_to_split=0.0263; lambda_l1=0.264; lambda_l2=56.9; scale_pos_weight=1.92; learning_rate=0.0504; num_iterations=4654; early_stopping_rounds=214; feature_fraction=0.998; bagging_fraction=0.745 : y = 0.929 : 162.6 secs : infill_ei
#
# Thu Nov 20 06:42:45 AM 2025 AUC 0.931503742193
#
# [mbo] 76: num_leaves=4584; min_child_weight=2.17; min_data_in_leaf=3022; min_gain_to_split=0.0479; lambda_l1=0.118; lambda_l2=1.79; scale_pos_weight=4.97; learning_rate=0.0638; num_iterations=4700; early_stopping_rounds=238; feature_fraction=0.258; bagging_fraction=0.719 : y = 0.932 : 131.0 secs : infill_ei
#
# Thu Nov 20 06:49:05 AM 2025 AUC 0.923365739053758
#
# [mbo] 77: num_leaves=3630; min_child_weight=9; min_data_in_leaf=5984; min_gain_to_split=0.0539; lambda_l1=0.145; lambda_l2=142; scale_pos_weight=2.52; learning_rate=0.0361; num_iterations=4728; early_stopping_rounds=360; feature_fraction=0.0757; bagging_fraction=0.812 : y = 0.923 : 376.0 secs : infill_ei
#
# Saved the current state after iteration 78 in the file HT.RDATA.
#
# Thu Nov 20 06:51:06 AM 2025 AUC 0.929556983134128
#
# [mbo] 78: num_leaves=3586; min_child_weight=8.68; min_data_in_leaf=285; min_gain_to_split=0.0446; lambda_l1=0.0218; lambda_l2=61.3; scale_pos_weight=2.07; learning_rate=0.0564; num_iterations=4870; early_stopping_rounds=229; feature_fraction=0.206; bagging_fraction=0.83 : y = 0.93 : 118.9 secs : infill_ei
#
# Thu Nov 20 06:57:48 AM 2025 AUC 0.919456450912615
#
# [mbo] 79: num_leaves=4042; min_child_weight=8.56; min_data_in_leaf=6405; min_gain_to_split=0.0209; lambda_l1=0.0513; lambda_l2=931; scale_pos_weight=4.71; learning_rate=0.0192; num_iterations=4976; early_stopping_rounds=370; feature_fraction=0.091; bagging_fraction=0.581 : y = 0.919 : 400.3 secs : infill_ei
#
# Thu Nov 20 07:03:41 AM 2025 AUC 0.930154230828852
#
# [mbo] 80: num_leaves=6761; min_child_weight=3.98; min_data_in_leaf=46; min_gain_to_split=0.0528; lambda_l1=0.0927; lambda_l2=217; scale_pos_weight=4.96; learning_rate=0.0412; num_iterations=4680; early_stopping_rounds=361; feature_fraction=0.309; bagging_fraction=0.753 : y = 0.93 : 350.2 secs : infill_ei
#
# Saved the current state after iteration 81 in the file HT.RDATA.
#
# Thu Nov 20 07:06:38 AM 2025 AUC 0.929550608018285
#
# [mbo] 81: num_leaves=5671; min_child_weight=5.95; min_data_in_leaf=177; min_gain_to_split=0.0399; lambda_l1=0.558; lambda_l2=83; scale_pos_weight=4.84; learning_rate=0.0652; num_iterations=4510; early_stopping_rounds=310; feature_fraction=0.0773; bagging_fraction=0.791 : y = 0.93 : 174.2 secs : infill_ei
#
# Thu Nov 20 07:11:13 AM 2025 AUC 0.923240585463796
#
# [mbo] 82: num_leaves=6292; min_child_weight=0.931; min_data_in_leaf=5566; min_gain_to_split=0.048; lambda_l1=0.409; lambda_l2=42.5; scale_pos_weight=4.91; learning_rate=0.0161; num_iterations=4651; early_stopping_rounds=275; feature_fraction=0.168; bagging_fraction=0.666 : y = 0.923 : 271.1 secs : infill_ei
#
# Thu Nov 20 07:14:52 AM 2025 AUC 0.922459130474463
#
# [mbo] 83: num_leaves=624; min_child_weight=9.62; min_data_in_leaf=1674; min_gain_to_split=0.027; lambda_l1=0.13; lambda_l2=717; scale_pos_weight=1.53; learning_rate=0.0795; num_iterations=4339; early_stopping_rounds=164; feature_fraction=0.0916; bagging_fraction=0.513 : y = 0.922 : 217.3 secs : infill_ei
#
# Saved the current state after iteration 84 in the file HT.RDATA.
#
# Thu Nov 20 07:26:13 AM 2025 AUC 0.923190255601881
#
# [mbo] 84: num_leaves=6612; min_child_weight=8.71; min_data_in_leaf=418; min_gain_to_split=0.0326; lambda_l1=0.00177; lambda_l2=644; scale_pos_weight=2.13; learning_rate=0.0289; num_iterations=4572; early_stopping_rounds=356; feature_fraction=0.874; bagging_fraction=0.563 : y = 0.923 : 678.2 secs : infill_ei
#
# Saved the current state after iteration 85 in the file HT.RDATA.
#
# Thu Nov 20 07:33:24 AM 2025 AUC 0.922416182325629
#
# [mbo] 85: num_leaves=4030; min_child_weight=9.35; min_data_in_leaf=1792; min_gain_to_split=0.0424; lambda_l1=0.0468; lambda_l2=482; scale_pos_weight=1.63; learning_rate=0.064; num_iterations=4041; early_stopping_rounds=196; feature_fraction=0.489; bagging_fraction=0.652 : y = 0.922 : 428.2 secs : infill_ei
#
# Thu Nov 20 07:37:57 AM 2025 AUC 0.923531156533252
#
# [mbo] 86: num_leaves=5442; min_child_weight=3.1; min_data_in_leaf=6261; min_gain_to_split=0.0639; lambda_l1=1.29; lambda_l2=213; scale_pos_weight=5; learning_rate=0.068; num_iterations=1827; early_stopping_rounds=265; feature_fraction=0.426; bagging_fraction=0.729 : y = 0.924 : 270.6 secs : infill_ei
#
# Saved the current state after iteration 87 in the file HT.RDATA.
#
# Thu Nov 20 07:39:57 AM 2025 AUC 0.932773732375321
#
# [mbo] 87: num_leaves=6695; min_child_weight=1.73; min_data_in_leaf=188; min_gain_to_split=0.0628; lambda_l1=0.146; lambda_l2=6.39; scale_pos_weight=3.22; learning_rate=0.0455; num_iterations=4477; early_stopping_rounds=249; feature_fraction=0.78; bagging_fraction=0.728 : y = 0.933 : 116.5 secs : infill_ei
#
# Thu Nov 20 07:42:11 AM 2025 AUC 0.923547933153891
#
# [mbo] 88: num_leaves=5040; min_child_weight=0.268; min_data_in_leaf=499; min_gain_to_split=0.098; lambda_l1=0.0792; lambda_l2=95.6; scale_pos_weight=1.47; learning_rate=0.0802; num_iterations=3680; early_stopping_rounds=253; feature_fraction=0.992; bagging_fraction=0.761 : y = 0.924 : 132.4 secs : infill_ei
#
# Thu Nov 20 07:48:15 AM 2025 AUC 0.931690298214498
#
# [mbo] 89: num_leaves=1708; min_child_weight=9.36; min_data_in_leaf=32; min_gain_to_split=0.0241; lambda_l1=0.0384; lambda_l2=533; scale_pos_weight=4.98; learning_rate=0.0519; num_iterations=4424; early_stopping_rounds=388; feature_fraction=0.0599; bagging_fraction=0.948 : y = 0.932 : 361.6 secs : infill_ei
#
# Saved the current state after iteration 90 in the file HT.RDATA.
#
# Thu Nov 20 07:49:51 AM 2025 AUC 0.928287328484219
#
# [mbo] 90: num_leaves=7429; min_child_weight=3.4; min_data_in_leaf=35; min_gain_to_split=0.0629; lambda_l1=0.12; lambda_l2=39.5; scale_pos_weight=5; learning_rate=0.0585; num_iterations=455; early_stopping_rounds=357; feature_fraction=0.913; bagging_fraction=0.951 : y = 0.928 : 93.4 secs : infill_ei
#
# Thu Nov 20 07:54:06 AM 2025 AUC 0.924196181775356
#
# [mbo] 91: num_leaves=3271; min_child_weight=9.59; min_data_in_leaf=21; min_gain_to_split=0.0251; lambda_l1=0.484; lambda_l2=785; scale_pos_weight=2.22; learning_rate=0.0595; num_iterations=3090; early_stopping_rounds=254; feature_fraction=0.0703; bagging_fraction=0.766 : y = 0.924 : 253.8 secs : infill_ei
#
# Thu Nov 20 07:56:37 AM 2025 AUC 0.936807503041601
#
# [mbo] 92: num_leaves=6122; min_child_weight=2.66; min_data_in_leaf=13; min_gain_to_split=0.0183; lambda_l1=0.0416; lambda_l2=3.22; scale_pos_weight=1.8; learning_rate=0.0315; num_iterations=3652; early_stopping_rounds=243; feature_fraction=0.822; bagging_fraction=0.586 : y = 0.937 : 148.6 secs : infill_ei
#
# Thu Nov 20 08:03:12 AM 2025 AUC 0.928789956038543
#
# [mbo] 93: num_leaves=7503; min_child_weight=5.45; min_data_in_leaf=1227; min_gain_to_split=0.0289; lambda_l1=0.416; lambda_l2=46.4; scale_pos_weight=4.94; learning_rate=0.0217; num_iterations=3620; early_stopping_rounds=370; feature_fraction=0.83; bagging_fraction=0.74 : y = 0.929 : 391.6 secs : infill_ei
#
# Saved the current state after iteration 94 in the file HT.RDATA.
#
# Thu Nov 20 08:07:58 AM 2025 AUC 0.924448166617343
#
# [mbo] 94: num_leaves=4606; min_child_weight=8.97; min_data_in_leaf=5638; min_gain_to_split=0.0253; lambda_l1=0.452; lambda_l2=27.1; scale_pos_weight=4.91; learning_rate=0.0573; num_iterations=4768; early_stopping_rounds=472; feature_fraction=0.0908; bagging_fraction=0.754 : y = 0.924 : 283.6 secs : infill_ei
#
# Thu Nov 20 08:11:31 AM 2025 AUC 0.928681914601632
#
# [mbo] 95: num_leaves=8015; min_child_weight=2.87; min_data_in_leaf=31; min_gain_to_split=0.0326; lambda_l1=0.387; lambda_l2=116; scale_pos_weight=1.74; learning_rate=0.0597; num_iterations=4801; early_stopping_rounds=482; feature_fraction=0.0532; bagging_fraction=0.746 : y = 0.929 : 209.8 secs : infill_ei
#
# Thu Nov 20 08:11:57 AM 2025 AUC 0.914761681393184
#
# [mbo] 96: num_leaves=4586; min_child_weight=0.452; min_data_in_leaf=619; min_gain_to_split=0.0718; lambda_l1=0.0182; lambda_l2=889; scale_pos_weight=4.94; learning_rate=0.0932; num_iterations=136; early_stopping_rounds=280; feature_fraction=0.435; bagging_fraction=0.942 : y = 0.915 : 23.6 secs : infill_ei
#
# Thu Nov 20 08:19:24 AM 2025 AUC 0.926248969076662
#
# [mbo] 97: num_leaves=8129; min_child_weight=1.11; min_data_in_leaf=11; min_gain_to_split=0.0267; lambda_l1=0.0441; lambda_l2=179; scale_pos_weight=1.74; learning_rate=0.0378; num_iterations=3326; early_stopping_rounds=251; feature_fraction=0.925; bagging_fraction=0.64 : y = 0.926 : 445.0 secs : infill_ei
#
# Saved the current state after iteration 98 in the file HT.RDATA.
#
# Thu Nov 20 08:26:47 AM 2025 AUC 0.930750471926339
#
# [mbo] 98: num_leaves=5923; min_child_weight=7.52; min_data_in_leaf=604; min_gain_to_split=0.0358; lambda_l1=0.362; lambda_l2=1.16; scale_pos_weight=1.25; learning_rate=0.00982; num_iterations=3994; early_stopping_rounds=239; feature_fraction=0.901; bagging_fraction=0.523 : y = 0.931 : 440.1 secs : infill_ei
#
# Thu Nov 20 08:29:57 AM 2025 AUC 0.920470765396408
#
# [mbo] 99: num_leaves=6092; min_child_weight=3.19; min_data_in_leaf=7296; min_gain_to_split=0.0808; lambda_l1=0.367; lambda_l2=2.15; scale_pos_weight=1.86; learning_rate=0.0136; num_iterations=4013; early_stopping_rounds=311; feature_fraction=0.888; bagging_fraction=0.545 : y = 0.92 : 187.1 secs : infill_ei
#
# Saved the current state after iteration 100 in the file HT.RDATA.
#
# Thu Nov 20 08:34:46 AM 2025 AUC 0.928499384969087
#
# [mbo] 100: num_leaves=5583; min_child_weight=4.46; min_data_in_leaf=520; min_gain_to_split=0.0191; lambda_l1=0.0886; lambda_l2=169; scale_pos_weight=1.86; learning_rate=0.0482; num_iterations=4839; early_stopping_rounds=297; feature_fraction=0.669; bagging_fraction=0.607 : y = 0.928 : 287.0 secs : infill_ei
#
# Thu Nov 20 08:36:05 AM 2025 AUC 0.934901007872261
#
# [mbo] 101: num_leaves=4989; min_child_weight=3.16; min_data_in_leaf=468; min_gain_to_split=0.0344; lambda_l1=0.247; lambda_l2=3.8; scale_pos_weight=4.73; learning_rate=0.0875; num_iterations=1101; early_stopping_rounds=317; feature_fraction=0.979; bagging_fraction=0.793 : y = 0.935 : 75.8 secs : infill_ei
#
# Thu Nov 20 08:43:37 AM 2025 AUC 0.924341131777671
#
# [mbo] 102: num_leaves=6260; min_child_weight=0.417; min_data_in_leaf=982; min_gain_to_split=0.083; lambda_l1=1.05; lambda_l2=136; scale_pos_weight=2.14; learning_rate=0.00887; num_iterations=4486; early_stopping_rounds=228; feature_fraction=0.99; bagging_fraction=0.548 : y = 0.924 : 449.2 secs : infill_ei
#
# Saved the current state after iteration 103 in the file HT.RDATA.
#
# Thu Nov 20 08:47:28 AM 2025 AUC 0.932130181207635
#
# [mbo] 103: num_leaves=5969; min_child_weight=2.74; min_data_in_leaf=20; min_gain_to_split=0.0322; lambda_l1=0.0993; lambda_l2=5.57; scale_pos_weight=3.86; learning_rate=0.0166; num_iterations=2660; early_stopping_rounds=238; feature_fraction=0.758; bagging_fraction=0.6 : y = 0.932 : 228.4 secs : infill_ei
#
# Thu Nov 20 08:49:48 AM 2025 AUC 0.928066212624206
#
# [mbo] 104: num_leaves=5346; min_child_weight=0.99; min_data_in_leaf=3825; min_gain_to_split=0.0811; lambda_l1=0.559; lambda_l2=0.0969; scale_pos_weight=3.08; learning_rate=0.0502; num_iterations=1065; early_stopping_rounds=189; feature_fraction=0.852; bagging_fraction=0.758 : y = 0.928 : 136.6 secs : infill_ei
#
# Thu Nov 20 08:50:22 AM 2025 AUC 0.915061311837785
#
# [mbo] 105: num_leaves=4704; min_child_weight=3.64; min_data_in_leaf=171; min_gain_to_split=0.0822; lambda_l1=111; lambda_l2=649; scale_pos_weight=4.99; learning_rate=0.0714; num_iterations=298; early_stopping_rounds=266; feature_fraction=0.97; bagging_fraction=0.545 : y = 0.915 : 31.2 secs : infill_ei
#
# Thu Nov 20 08:59:17 AM 2025 AUC 0.922447386840016
#
# [mbo] 106: num_leaves=3337; min_child_weight=8.54; min_data_in_leaf=172; min_gain_to_split=0.045; lambda_l1=0.00748; lambda_l2=824; scale_pos_weight=4.55; learning_rate=0.0234; num_iterations=4935; early_stopping_rounds=492; feature_fraction=0.985; bagging_fraction=0.977 : y = 0.922 : 532.4 secs : infill_ei
#
# Saved the current state after iteration 107 in the file HT.RDATA.
#
# Thu Nov 20 09:06:30 AM 2025 AUC 0.920920378829515
#
# [mbo] 107: num_leaves=7696; min_child_weight=8.83; min_data_in_leaf=8120; min_gain_to_split=0.0467; lambda_l1=0.75; lambda_l2=631; scale_pos_weight=4.98; learning_rate=0.0537; num_iterations=4091; early_stopping_rounds=487; feature_fraction=0.968; bagging_fraction=0.958 : y = 0.921 : 429.9 secs : infill_ei
#
# Thu Nov 20 09:06:59 AM 2025 AUC 0.918140828322157
#
# [mbo] 108: num_leaves=6269; min_child_weight=0.897; min_data_in_leaf=3482; min_gain_to_split=0.0538; lambda_l1=0.143; lambda_l2=3.04; scale_pos_weight=3.86; learning_rate=0.0791; num_iterations=188; early_stopping_rounds=387; feature_fraction=0.952; bagging_fraction=0.786 : y = 0.918 : 26.4 secs : infill_ei
#
# Thu Nov 20 09:08:57 AM 2025 AUC 0.92734515346917
#
# [mbo] 109: num_leaves=6568; min_child_weight=6.17; min_data_in_leaf=149; min_gain_to_split=0.00752; lambda_l1=0.38; lambda_l2=0.143; scale_pos_weight=1.5; learning_rate=0.059; num_iterations=4066; early_stopping_rounds=409; feature_fraction=0.946; bagging_fraction=0.78 : y = 0.927 : 114.9 secs : infill_ei
#
# Thu Nov 20 09:11:10 AM 2025 AUC 0.92676300473302
#
# [mbo] 110: num_leaves=5615; min_child_weight=9.84; min_data_in_leaf=84; min_gain_to_split=0.0339; lambda_l1=1.55; lambda_l2=95.8; scale_pos_weight=4.86; learning_rate=0.0719; num_iterations=814; early_stopping_rounds=291; feature_fraction=0.925; bagging_fraction=0.903 : y = 0.927 : 131.0 secs : infill_ei
#
# Saved the current state after iteration 111 in the file HT.RDATA.
#
# Thu Nov 20 09:14:44 AM 2025 AUC 0.931389325640246
#
# [mbo] 111: num_leaves=5417; min_child_weight=8.52; min_data_in_leaf=460; min_gain_to_split=0.0279; lambda_l1=0.342; lambda_l2=58.7; scale_pos_weight=4.81; learning_rate=0.0438; num_iterations=4374; early_stopping_rounds=474; feature_fraction=0.0773; bagging_fraction=0.968 : y = 0.931 : 211.0 secs : infill_ei
#
# Thu Nov 20 09:20:17 AM 2025 AUC 0.927922269219129
#
# [mbo] 112: num_leaves=6226; min_child_weight=3.97; min_data_in_leaf=3047; min_gain_to_split=0.0914; lambda_l1=0.491; lambda_l2=0.101; scale_pos_weight=4.98; learning_rate=0.0218; num_iterations=4798; early_stopping_rounds=472; feature_fraction=0.77; bagging_fraction=0.892 : y = 0.928 : 329.2 secs : infill_ei
#
# Thu Nov 20 09:20:54 AM 2025 AUC 0.920719394914268
#
# [mbo] 113: num_leaves=5122; min_child_weight=0.12; min_data_in_leaf=770; min_gain_to_split=0.0738; lambda_l1=25.7; lambda_l2=12.8; scale_pos_weight=4.97; learning_rate=0.098; num_iterations=1262; early_stopping_rounds=257; feature_fraction=0.8; bagging_fraction=0.703 : y = 0.921 : 34.7 secs : infill_ei
#
# Thu Nov 20 09:27:58 AM 2025 AUC 0.923533505260142
#
# [mbo] 114: num_leaves=607; min_child_weight=9.22; min_data_in_leaf=5281; min_gain_to_split=0.0714; lambda_l1=0.145; lambda_l2=667; scale_pos_weight=4.41; learning_rate=0.0616; num_iterations=4569; early_stopping_rounds=475; feature_fraction=0.837; bagging_fraction=0.797 : y = 0.924 : 420.2 secs : infill_ei
#
# Saved the current state after iteration 115 in the file HT.RDATA.
#
# Thu Nov 20 09:29:44 AM 2025 AUC 0.91262903737764
#
# [mbo] 115: num_leaves=7376; min_child_weight=9.92; min_data_in_leaf=16; min_gain_to_split=0.0655; lambda_l1=126; lambda_l2=955; scale_pos_weight=4.86; learning_rate=0.068; num_iterations=1356; early_stopping_rounds=447; feature_fraction=0.114; bagging_fraction=0.76 : y = 0.913 : 102.3 secs : infill_ei
#
# Thu Nov 20 09:32:05 AM 2025 AUC 0.927024048950153
#
# [mbo] 116: num_leaves=1879; min_child_weight=5.1; min_data_in_leaf=3027; min_gain_to_split=0.0322; lambda_l1=0.0977; lambda_l2=0.487; scale_pos_weight=5; learning_rate=0.0608; num_iterations=4722; early_stopping_rounds=485; feature_fraction=0.941; bagging_fraction=0.903 : y = 0.927 : 137.8 secs : infill_ei
#
# Thu Nov 20 09:34:07 AM 2025 AUC 0.910250112571125
#
# [mbo] 117: num_leaves=7761; min_child_weight=9.64; min_data_in_leaf=4311; min_gain_to_split=0.0678; lambda_l1=86.2; lambda_l2=883; scale_pos_weight=5; learning_rate=0.0364; num_iterations=4888; early_stopping_rounds=500; feature_fraction=0.952; bagging_fraction=0.891 : y = 0.91 : 118.2 secs : infill_ei
#
# Thu Nov 20 09:37:59 AM 2025 AUC 0.925269885496209
#
# [mbo] 118: num_leaves=5960; min_child_weight=3.32; min_data_in_leaf=880; min_gain_to_split=0.062; lambda_l1=0.0419; lambda_l2=579; scale_pos_weight=4.99; learning_rate=0.0804; num_iterations=4827; early_stopping_rounds=499; feature_fraction=0.903; bagging_fraction=0.886 : y = 0.925 : 228.6 secs : infill_ei
#
# Saved the current state after iteration 119 in the file HT.RDATA.
#
# Thu Nov 20 09:39:53 AM 2025 AUC 0.911068811658275
#
# [mbo] 119: num_leaves=4938; min_child_weight=0.084; min_data_in_leaf=99; min_gain_to_split=0.0448; lambda_l1=169; lambda_l2=293; scale_pos_weight=4.97; learning_rate=0.0547; num_iterations=1555; early_stopping_rounds=248; feature_fraction=0.115; bagging_fraction=0.556 : y = 0.911 : 110.6 secs : infill_ei
#
# Thu Nov 20 09:41:35 AM 2025 AUC 0.921988378499351
#
# [mbo] 120: num_leaves=34; min_child_weight=9.99; min_data_in_leaf=5782; min_gain_to_split=0.0189; lambda_l1=1.27; lambda_l2=324; scale_pos_weight=3.36; learning_rate=0.051; num_iterations=4838; early_stopping_rounds=232; feature_fraction=0.0554; bagging_fraction=0.997 : y = 0.922 : 100.6 secs : infill_ei
#
# Saved the final state in the file HT.RDATA

# %% [markdown]
# la bayesian optimization ha corrido, extraigo los mejores hiperparametros

# %%
# almaceno los resultados de la Bayesian Optimization
# y capturo los mejores hiperparametros encontrados

tb_bayesiana <- as.data.table(bayesiana_salida$opt.path)

# ordeno en forma descendente por AUC = y
setorder(tb_bayesiana, -y, -num_iterations)

# grabo para eventualmente poder utilizarlos en OTRA corrida
fwrite( tb_bayesiana,
  file="BO_log.txt",
  sep="\t"
)

# los mejores hiperparámetros son los que quedaron en el registro 1 de la tabla
PARAM$out$lgbm$mejores_hiperparametros <- tb_bayesiana[
  1, # el primero es el de mejor AUC
  setdiff(colnames(tb_bayesiana),
    c("y","dob","eol","error.message","exec.time","ei","error.model",
      "train.time","prop.type","propose.time","se","mean","iter")),
  with= FALSE
]

print(PARAM$out$lgbm$mejores_hiperparametros)
# Out:
#    num_leaves min_child_weight min_data_in_leaf min_gain_to_split  lambda_l1
#         <int>            <num>            <int>             <num>      <num>
# 1:       6122           2.6602               13        0.01832206 0.04155568
#    lambda_l2 scale_pos_weight learning_rate num_iterations
#        <num>            <num>         <num>          <int>
# 1:  3.223371         1.799775    0.03145256           3652
#    early_stopping_rounds feature_fraction bagging_fraction
#                    <int>            <num>            <num>
# 1:                   243         0.822448        0.5856066

# %% [markdown]
# ### 6.3.3 Produccion

# %% [markdown]
# #### Final Training
# Construyo el modelo final, que es uno solo, no hace ningun tipo de particion < training, validation, testing>]

# %% [markdown]
# ##### Final Training Dataset
#
# Aqui esta la gran decision de en qué meses hago el Final Training
# <br> debo utilizar los mejores hiperparámetros que encontré en la optimización bayesiana

# %%
PARAM$trainingstrategy$final_train <- c(
  202105, 202104, 202103, 202102, 202101,
  202012, 202011, 202010, 202009, 202008, 202007,
  202006, 202005
)

dataset[, fold_final_train := foto_mes %in% PARAM$trainingstrategy$final_train ]

# creo el dfinal_train en formato  LightGBM
dfinal_train <- lgb.Dataset(
  data= data.matrix(dataset[fold_final_train == TRUE, campos_buenos, with= FALSE]),
  label= dataset[fold_final_train == TRUE, clase01],
  free_raw_data= TRUE
)

nrow( dfinal_train) # verifico el tamaño
# Out:
# [1] 207504

# %% [markdown]
# ##### Final Training Hyperparameters

# %%
# uno los parametros fijos y los mejores encontrados de los variables
fijos <- copy(PARAM$lgbm$param_fijos)

# quito lo que optimice en la Bayesian Optimization
fijos$num_iterations <- NULL
fijos$early_stopping_rounds <- NULL

# agrego a los hiperparametros fijos los que encontre con la Bayesian Optimization
param_final <- c(fijos, PARAM$out$lgbm$mejores_hiperparametros)

# Para el entrenamiento final, removemos early_stopping_rounds
# ya que se entrena con todos los datos disponibles y la cantidad de iteraciones
# ya está optimizada en 'num_iterations'.
param_final$early_stopping_rounds <- NULL

# %% [markdown]
# ##### Training
# Genero el modelo final, siempre sobre TODOS los datos de  final_train, sin hacer ningun tipo de undersampling de la clase mayoritaria

# %%
final_model <- lgb.train(
  data= dfinal_train,
  param= param_final,
  verbose= -100
)

# %%
# grabo a disco el modelo en un formato para seres humanos ... ponele ...

lgb.save(final_model, "modelo.txt")

# %%
# ahora imprimo la importancia de variables

tb_importancia <- as.data.table(lgb.importance(final_model))
archivo_importancia <- "impo.txt"

fwrite( tb_importancia,
  file= archivo_importancia,
  sep= "\t"
)

# %% [markdown]
# #### Scoring

# %% [markdown]
# Aplico el modelo final a los datos del futuro

# %%
PARAM$trainingstrategy$future <- c(202107)

dfuture <- dataset[ foto_mes %in% PARAM$trainingstrategy$future ]

# %%
# aplico final_model   a dfuture

prediccion <- predict(
  final_model,
  data.matrix(dfuture[, campos_buenos, with= FALSE])
)

# %% [markdown]
# ##### Tabla Prediccion

# %%
tb_prediccion <- dfuture[, list(numero_de_cliente)]
tb_prediccion[, prob := prediccion]

# grabo las probabilidad del modelo
#  me va a ser util para hacer Ensembles de modelos
fwrite(tb_prediccion,
  file= "prediccion.txt",
  sep= "\t"
)

# %% [markdown]
# #### Curva de Ganancia

# %% [markdown]
# Genero las salidas

# %%
# asigno clase ternaria
tb_prediccion[, clase_ternaria := dfuture$clase_ternaria ]

# asigno ganancias
tb_prediccion[, ganancia := -3000.0 ]
tb_prediccion[clase_ternaria=="BAJA+2", ganancia := 117000.0 ]

# reordeno, y acumulada
setorder( tb_prediccion, -prob )
tb_prediccion[, gan_acum := cumsum(ganancia)]

# media movil de ancho 400
tb_prediccion[,
  gan_suavizada := frollmean(
    x= gan_acum,
    n= 400,
    align= "center",
    na.rm= TRUE,
    hasNA= TRUE
  )
]

# %%
tb_prediccion[, sum(!is.na(gan_suavizada) )]
tb_prediccion[, .N]
# Out:
# [1] 16152
# [1] 16551

# %%
# Este es la ganancia a reportar
resultado <- list()
resultado$ganancia_suavizada_max <- max( tb_prediccion$gan_suavizada, na.rm=TRUE )
options(digits= 8)
resultado$envios <- which.max( tb_prediccion$gan_suavizada)
resultado
# Out:
# $ganancia_suavizada_max
# [1] 5747700
#
# $envios
# [1] 1026

# %%
# grabo las ganancias
fwrite( tb_prediccion,
  file= "ganancias.txt",
  sep= "\t"
)

# %%
# genero el grafico

tb_prediccion[, envios:= .I]

pdf("curva_de_ganancia.pdf")

plot(
  x= tb_prediccion$envios,
  y= tb_prediccion$gan_acum,
  type= "l",
  col= "gray",
  xlim= c(0, 6000),
  ylim= c(0, 8000000),
  main= paste0("Mejor gan prom= ", as.integer(resultado$ganancia_suavizada_max), " envios= ", resultado$envios),
  xlab= "Envios",
  ylab= "Ganancia",
  panel.first= grid()
)

dev.off()
# Out:
# agg_record_1731000362
#                     2

# %%
# grabo los parametros
if( !require("yaml")) install.packages("yaml")
require("yaml")

PARAM$resultado <- resultado

write_yaml( PARAM, file="PARAM.yml")
# Out:
# Loading required package: yaml

# %%
format(Sys.time(), "%a %b %d %X %Y")
fin <- Sys.time()

# Duración en segundos
secs <- as.numeric(difftime(fin, principio, units = "secs"))
secs <- round(secs)

# A hh:mm:ss
h <- secs %/% 3600
m <- (secs %% 3600) %/% 60
s <- secs %% 60
dur_hms <- sprintf("%02d:%02d:%02d", h, m, s)

cat(
  "Inicio: ", format(principio, "%a %b %d %X %Y"), "\n",
  "Fin:    ", format(fin,       "%a %b %d %X %Y"), "\n",
  "Duración (hh:mm:ss): ", dur_hms, "\n",
  sep = ""
)
# Out:
# [1] "Thu Nov 20 09:47:49 AM 2025"
# Inicio: Thu Nov 20 12:49:15 AM 2025
# Fin:    Thu Nov 20 09:47:49 AM 2025
# Duración (hh:mm:ss): 08:58:34
