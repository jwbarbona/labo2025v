# %% [markdown]
# <a href="https://colab.research.google.com/github/jwbarbona/labo2025v/blob/main/610_WorkFlow_12HT_65114_gerencial_julio.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # 6 WorkFlow  Gerencial, futuro=JULIO

# %% [markdown]
# ### 6.1 Objetivo

# %% [markdown]
# Presentar un workflow/pipeline completo al que los estudiantes deberán enriquecer

# %% [markdown]
# #### 6.2  Seteo del ambiente en Google Colab

# %% [markdown]
# Esta parte se debe correr con el runtime en Python3
# <br>Ir al menu, Runtime -> Change Runtime Type -> Runtime type ->  **Python 3**

# %% [markdown]
# Conectar la virtual machine donde esta corriendo Google Colab con el  Google Drive, para poder tener persistencia de archivos

# %%
# primero establecer el Runtime de Python 3
from google.colab import drive
drive.mount('/content/.drive')
# Out:
# Mounted at /content/.drive

# %% [markdown]
# Para correr la siguiente celda es fundamental en Arranque en Frio haber copiado el archivo kaggle.json al Google Drive, en la carpeta indicada en el instructivo
#
# <br>los siguientes comando estan en shell script de Linux
# *   Crear las carpetas en el Google Drive
# *   "instalar" el archivo kaggle.json desde el Google Drive a la virtual machine para que pueda ser utilizado por la libreria  kaggle de Python
# *   Bajar el  **dataset_pequeno**  al  Google Drive  y tambien al disco local de la virtual machine que esta corriendo Google Colab
# *   Bajar el **dataset_historico** al Google Drive y tambien al disco local de la virtual machine que esta corriendo Google Colab

# %%
%%shell

mkdir -p "/content/.drive/My Drive/labo1"
mkdir -p "/content/buckets"
ln -s "/content/.drive/My Drive/labo1" /content/buckets/b1

mkdir -p ~/.kaggle
cp /content/buckets/b1/kaggle/kaggle.json  ~/.kaggle
chmod 600 ~/.kaggle/kaggle.json


mkdir -p /content/buckets/b1/exp
mkdir -p /content/buckets/b1/datasets
mkdir -p /content/datasets


webfiles="https://storage.googleapis.com/open-courses/austral2025-af91/"
destino_local="/content/datasets"
destino_bucket="/content/buckets/b1/datasets"


archivo="dataset_pequeno.csv"

if ! test -f $destino_bucket/$archivo; then
  wget  $webfiles/$archivo  -O $destino_bucket/$archivo
fi


if ! test -f $destino_local/$pequeno; then
  cp  $destino_bucket/$archivo  $destino_local/$archivo
fi

#-------

archivo="gerencial_competencia_2025.csv.gz"

if ! test -f $destino_bucket/$archivo; then
  wget  $webfiles/$archivo  -O $destino_bucket/$archivo
fi


if ! test -f $destino_local/$pequeno; then
  cp  $destino_bucket/$archivo  $destino_local/$archivo
fi
# Out:
# cp: cannot stat '/content/buckets/b1/kaggle/kaggle.json': No such file or directory
# chmod: cannot access '/root/.kaggle/kaggle.json': No such file or directory

# %% [markdown]
# ## 6.3  Workflow

# %% [markdown]
# ## Inicializacion

# %% [markdown]
# Esta parte se debe correr con el runtime en lenguaje **R** Ir al menu, Runtime -> Change Runtime Type -> Runtime type -> R

# %% [markdown]
# limpio el ambiente de R

# %%
format(Sys.time(), "%a %b %d %X %Y")
# Out:
# [1] "Thu Nov 20 11:12:25 AM 2025"

# %%
# limpio la memoria
rm(list=ls(all.names=TRUE)) # remove all objects
gc(full=TRUE, verbose=FALSE) # garbage collection
# Out:
#        used    (Mb) gc trigger (Mb) max used (Mb)
# Ncells  660355 35.3 1454494    77.7 1454494  77.7
# Vcells 1226516  9.4 8388608    64.0 1975136  15.1

# %%
principio <- Sys.time()

# %%
require("data.table")

if( !require("R.utils")) install.packages("R.utils")
require("R.utils")
# Out:
# Loading required package: data.table
#
# Loading required package: R.utils
#
# Warning message in library(package, lib.loc = lib.loc, character.only = TRUE, logical.return = TRUE, :
# “there is no package called ‘R.utils’”
# Installing package into ‘/usr/local/lib/R/site-library’
# (as ‘lib’ is unspecified)
#
# also installing the dependencies ‘R.oo’, ‘R.methodsS3’
#
#
# Loading required package: R.utils
#
# Loading required package: R.oo
#
# Loading required package: R.methodsS3
#
# R.methodsS3 v1.8.2 (2022-06-13 22:00:14 UTC) successfully loaded. See ?R.methodsS3 for help.
#
# R.oo v1.27.1 (2025-05-02 21:00:05 UTC) successfully loaded. See ?R.oo for help.
#
#
# Attaching package: ‘R.oo’
#
#
# The following object is masked from ‘package:R.methodsS3’:
#
#     throw
#
#
# The following objects are masked from ‘package:methods’:
#
#     getClasses, getMethods
#
#
# The following objects are masked from ‘package:base’:
#
#     attach, detach, load, save
#
#
# R.utils v2.13.0 (2025-02-24 21:20:02 UTC) successfully loaded. See ?R.utils for help.
#
#
# Attaching package: ‘R.utils’
#
#
# The following object is masked from ‘package:utils’:
#
#     timestamp
#
#
# The following objects are masked from ‘package:base’:
#
#     cat, commandArgs, getOption, isOpen, nullfile, parse, use, warnings

# %% [markdown]
# #### Parametros
# Si es gerente, no cambie nada
# <br>Si es Analista, cambie el nombre del dataset

# %%
PARAM <- list()
PARAM$semilla_primigenia <- 700009 # 100009, 200003, 499999, 700009, 999983

PARAM$experimento <- 65116 # 12HT corri de nuevo de 120 a 100
PARAM$dataset <- "gerencial_competencia_2025.csv.gz"

# %% [markdown]
# #### Carpeta del Experimento

# %%
# carpeta de trabajo

setwd("/content/buckets/b1/exp")
experimento_folder <- paste0("WF", PARAM$experimento)
dir.create(experimento_folder, showWarnings=FALSE)
setwd( paste0("/content/buckets/b1/exp/", experimento_folder ))

# %% [markdown]
# ### 6.3.1   Preprocesamiento del dataset

# %% [markdown]
# #### 6.3.1.1  DT incorporar dataset

# %%
# lectura del dataset
dataset <- fread(paste0("/content/datasets/", PARAM$dataset))

# %% [markdown]
# #### 6.3.1.2  CA  Catastrophe Analysis
# Se intentan reparar las variables que para un mes están con todos los valores en cero.

# %% [markdown]
# El método que se utiliza es **Machine Learning** se asigna NA also valores, si ha leido bien, es la "anti imputación de valores faltantes"
# <br> Usted podrá aplicar aquí otros métodos

# %%
dataset[ foto_mes==202006, internet:=NA]
dataset[ foto_mes==202006, mrentabilidad:=NA]
dataset[ foto_mes==202006, mrentabilidad_annual:=NA]
dataset[ foto_mes==202006, mcomisiones:=NA]
dataset[ foto_mes==202006, mactivos_margen:=NA]
dataset[ foto_mes==202006, mpasivos_margen:=NA]
dataset[ foto_mes==202006, mcuentas_saldo:=NA]
dataset[ foto_mes==202006, ctarjeta_visa_transacciones:=NA]
dataset[ foto_mes==202006, mtarjeta_visa_consumo:=NA]
dataset[ foto_mes==202006, mtarjeta_master_consumo:=NA]
dataset[ foto_mes==202006, ccallcenter_transacciones:=NA]
dataset[ foto_mes==202006, chomebanking_transacciones:=NA]
dataset[ foto_mes==202006, chomebanking_transacciones:=NA]

# %% [markdown]
# #### 6.3.1.3  DR  Data Drifting
# Se intenta corregir el data drifting, quizas ajustando por IPC ...
# <br>Esta parte podrá ser abordada por todos los Analistas y también la Gerenciapero se decide pedagogicamente no incluirla en esta primer version para reducir la carga cognitiva

# %%
# sin codigo en esta primera version del workflow

# %% [markdown]
# #### 6.3.1.3  FE_intra_manual Feature Engineering intra-mes
#
# Agrego campos nuevos dentro del mismo mes, SIN considerar la historia.

# %%
# esta funcion atributos presentes existe debido a que las modalidades poseen datasets con distinta cantidad de campos
atributos_presentes <- function( patributos )
{
  atributos <- unique( patributos )
  comun <- intersect( atributos, colnames(dataset) )

  return(  length( atributos ) == length( comun ) )
}

# el mes 1,2, ..12
if( atributos_presentes( c("foto_mes") ))
  dataset[, kmes := foto_mes %% 100]

# variable extraida de una tesis de maestria de Irlanda
if( atributos_presentes( c("mpayroll", "cliente_edad") ))
  dataset[, mpayroll_sobre_edad := mpayroll / cliente_edad]

# %%
# visualizo las columas del dataset a esta etapa
colnames(dataset)
# Out:
#  [1] "numero_de_cliente"           "foto_mes"
#  [3] "internet"                    "cliente_edad"
#  [5] "cliente_antiguedad"          "mrentabilidad"
#  [7] "mrentabilidad_annual"        "mcomisiones"
#  [9] "mactivos_margen"             "mpasivos_margen"
# [11] "cproductos"                  "mcuenta_corriente"
# [13] "mcaja_ahorro"                "cdescubierto_preacordado"
# [15] "mcuentas_saldo"              "ctarjeta_visa_transacciones"
# [17] "mtarjeta_visa_consumo"       "mtarjeta_master_consumo"
# [19] "mprestamos_personales"       "cpayroll_trx"
# [21] "mpayroll"                    "ccomisiones_mantenimiento"
# [23] "ccallcenter_transacciones"   "chomebanking_transacciones"
# [25] "ctrx_quarter"                "Master_status"
# [27] "Master_fechaalta"            "Master_mpagominimo"
# [29] "Visa_status"                 "Visa_fechaalta"
# [31] "Visa_mpagominimo"            "clase_ternaria"
# [33] "kmes"                        "mpayroll_sobre_edad"

# %% [markdown]
# #### 6.3.1.4  FE_rf Feature Engineering de nuevas variables a partir de hojas de Random Forest
#
# Esto se mostrará unicamente a la *modalidad Analista Sr*

# %%
# No se implementa Feature Engineering a partir de Random Forest

# %% [markdown]
# #### 6.3.1.5  FEhist Feature Engineering historico
#
# El Fature Engineering Histórico es la etapa que más aporta a la ganancia final, ya que enriquece cada registro del dataset con su historia.

# %% [markdown]
# Para cada campo del dataset original (*)
# se crean lo siguientes campos de a partir de la historia
# * lag1  lags de orden 1
# * delta1  =  valor actual - lag1
# * lag2  lags de orden 2
# * delta2  = valor actual - lag2
#
#
# (*) Excepto para los campos  <numero_de_cliente,  foto_mes,  clase_ternaria>

# %%
# Feature Engineering Historico

# todo es lagueable, menos la primary key y la clase
cols_lagueables <- copy( setdiff(
    colnames(dataset),
    c("numero_de_cliente", "foto_mes", "clase_ternaria")
) )

# https://rdrr.io/cran/data.table/man/shift.html

# lags de orden 1
dataset[,
    paste0(cols_lagueables, "_lag1") := shift(.SD, 1, NA, "lag"),
    by = numero_de_cliente,
    .SDcols = cols_lagueables
]

# lags de orden 2
dataset[,
    paste0(cols_lagueables, "_lag2") := shift(.SD, 2, NA, "lag"),
    by = numero_de_cliente,
    .SDcols = cols_lagueables
]

# agrego los delta lags
for (vcol in cols_lagueables)
{
    dataset[, paste0(vcol, "_delta1") := get(vcol) - get(paste0(vcol, "_lag1"))]
    dataset[, paste0(vcol, "_delta2") := get(vcol) - get(paste0(vcol, "_lag2"))]
}

# %% [markdown]
# Verificacion de los campos recien creados

# %%
ncol(dataset)
colnames(dataset)
# Out:
# [1] 158
#   [1] "numero_de_cliente"                  "foto_mes"
#   [3] "internet"                           "cliente_edad"
#   [5] "cliente_antiguedad"                 "mrentabilidad"
#   [7] "mrentabilidad_annual"               "mcomisiones"
#   [9] "mactivos_margen"                    "mpasivos_margen"
#  [11] "cproductos"                         "mcuenta_corriente"
#  [13] "mcaja_ahorro"                       "cdescubierto_preacordado"
#  [15] "mcuentas_saldo"                     "ctarjeta_visa_transacciones"
#  [17] "mtarjeta_visa_consumo"              "mtarjeta_master_consumo"
#  [19] "mprestamos_personales"              "cpayroll_trx"
#  [21] "mpayroll"                           "ccomisiones_mantenimiento"
#  [23] "ccallcenter_transacciones"          "chomebanking_transacciones"
#  [25] "ctrx_quarter"                       "Master_status"
#  [27] "Master_fechaalta"                   "Master_mpagominimo"
#  [29] "Visa_status"                        "Visa_fechaalta"
#  [31] "Visa_mpagominimo"                   "clase_ternaria"
#  [33] "kmes"                               "mpayroll_sobre_edad"
#  [35] "internet_lag1"                      "cliente_edad_lag1"
#  [37] "cliente_antiguedad_lag1"            "mrentabilidad_lag1"
#  [39] "mrentabilidad_annual_lag1"          "mcomisiones_lag1"
#  [41] "mactivos_margen_lag1"               "mpasivos_margen_lag1"
#  [43] "cproductos_lag1"                    "mcuenta_corriente_lag1"
#  [45] "mcaja_ahorro_lag1"                  "cdescubierto_preacordado_lag1"
#  [47] "mcuentas_saldo_lag1"                "ctarjeta_visa_transacciones_lag1"
#  [49] "mtarjeta_visa_consumo_lag1"         "mtarjeta_master_consumo_lag1"
#  [51] "mprestamos_personales_lag1"         "cpayroll_trx_lag1"
#  [53] "mpayroll_lag1"                      "ccomisiones_mantenimiento_lag1"
#  [55] "ccallcenter_transacciones_lag1"     "chomebanking_transacciones_lag1"
#  [57] "ctrx_quarter_lag1"                  "Master_status_lag1"
#  [59] "Master_fechaalta_lag1"              "Master_mpagominimo_lag1"
#  [61] "Visa_status_lag1"                   "Visa_fechaalta_lag1"
#  [63] "Visa_mpagominimo_lag1"              "kmes_lag1"
#  [65] "mpayroll_sobre_edad_lag1"           "internet_lag2"
#  [67] "cliente_edad_lag2"                  "cliente_antiguedad_lag2"
#  [69] "mrentabilidad_lag2"                 "mrentabilidad_annual_lag2"
#  [71] "mcomisiones_lag2"                   "mactivos_margen_lag2"
#  [73] "mpasivos_margen_lag2"               "cproductos_lag2"
#  [75] "mcuenta_corriente_lag2"             "mcaja_ahorro_lag2"
#  [77] "cdescubierto_preacordado_lag2"      "mcuentas_saldo_lag2"
#  [79] "ctarjeta_visa_transacciones_lag2"   "mtarjeta_visa_consumo_lag2"
#  [81] "mtarjeta_master_consumo_lag2"       "mprestamos_personales_lag2"
#  [83] "cpayroll_trx_lag2"                  "mpayroll_lag2"
#  [85] "ccomisiones_mantenimiento_lag2"     "ccallcenter_transacciones_lag2"
#  [87] "chomebanking_transacciones_lag2"    "ctrx_quarter_lag2"
#  [89] "Master_status_lag2"                 "Master_fechaalta_lag2"
#  [91] "Master_mpagominimo_lag2"            "Visa_status_lag2"
#  [93] "Visa_fechaalta_lag2"                "Visa_mpagominimo_lag2"
#  [95] "kmes_lag2"                          "mpayroll_sobre_edad_lag2"
#  [97] "internet_delta1"                    "internet_delta2"
#  [99] "cliente_edad_delta1"                "cliente_edad_delta2"
# [101] "cliente_antiguedad_delta1"          "cliente_antiguedad_delta2"
# [103] "mrentabilidad_delta1"               "mrentabilidad_delta2"
# [105] "mrentabilidad_annual_delta1"        "mrentabilidad_annual_delta2"
# [107] "mcomisiones_delta1"                 "mcomisiones_delta2"
# [109] "mactivos_margen_delta1"             "mactivos_margen_delta2"
# [111] "mpasivos_margen_delta1"             "mpasivos_margen_delta2"
# [113] "cproductos_delta1"                  "cproductos_delta2"
# [115] "mcuenta_corriente_delta1"           "mcuenta_corriente_delta2"
# [117] "mcaja_ahorro_delta1"                "mcaja_ahorro_delta2"
# [119] "cdescubierto_preacordado_delta1"    "cdescubierto_preacordado_delta2"
# [121] "mcuentas_saldo_delta1"              "mcuentas_saldo_delta2"
# [123] "ctarjeta_visa_transacciones_delta1" "ctarjeta_visa_transacciones_delta2"
# [125] "mtarjeta_visa_consumo_delta1"       "mtarjeta_visa_consumo_delta2"
# [127] "mtarjeta_master_consumo_delta1"     "mtarjeta_master_consumo_delta2"
# [129] "mprestamos_personales_delta1"       "mprestamos_personales_delta2"
# [131] "cpayroll_trx_delta1"                "cpayroll_trx_delta2"
# [133] "mpayroll_delta1"                    "mpayroll_delta2"
# [135] "ccomisiones_mantenimiento_delta1"   "ccomisiones_mantenimiento_delta2"
# [137] "ccallcenter_transacciones_delta1"   "ccallcenter_transacciones_delta2"
# [139] "chomebanking_transacciones_delta1"  "chomebanking_transacciones_delta2"
# [141] "ctrx_quarter_delta1"                "ctrx_quarter_delta2"
# [143] "Master_status_delta1"               "Master_status_delta2"
# [145] "Master_fechaalta_delta1"            "Master_fechaalta_delta2"
# [147] "Master_mpagominimo_delta1"          "Master_mpagominimo_delta2"
# [149] "Visa_status_delta1"                 "Visa_status_delta2"
# [151] "Visa_fechaalta_delta1"              "Visa_fechaalta_delta2"
# [153] "Visa_mpagominimo_delta1"            "Visa_mpagominimo_delta2"
# [155] "kmes_delta1"                        "kmes_delta2"
# [157] "mpayroll_sobre_edad_delta1"         "mpayroll_sobre_edad_delta2"

# %% [markdown]
# #### 6.3.1.6  FEhist Reduccion dimensionalidad con canaritos
#
# Esta etapa solo se mostrará a la *modalidad Anlista Sr* por algun canal secreto de forma de no confundir a los *Analista Jr*  nni distraer con detalles operativos a la estratégica *Modalidad Gerencial*

# %%
# No se implementa la reduccion de la dimensionalidad con canaritos

# %% [markdown]
# ### 6.3.2 Modelado

# %% [markdown]
# #### 6.3.2.1 Training Strategy
#
# Esta etapa de Workflow de  Training Strategy esta pensada para la *Modalidad Gerencial* que posee el dataset de [202005, 202109]
# <br> Si usted es un Analista, posee el periodo de [201901, 202109] y deberá experimentar en que meses le conviene experimentar
#
# <br> A la *Modalidad Gerencial* no se le complicada la vida con el undersampling de los continua, por eso PARAM$trainingstrategy$training_pct <- 1.0
# <br> Sin embargo, si usted es  *Analista SR* posee un dataset 50 veces ( filas x columnas) más grande que la *Modalidad Gerencial*  y por un tema de velocidad y experimentación más rápida puede llegar a necesitar activar el undersampling de la clase mayoritaria, a pesar de estar corriendo en Google Cloud.

# %% [markdown]
# Se hace una estrategia de entrenamiento muy sencilla, tomando todos los meses posibles, SIN eliminar nada x pandemia ni por ningun otro motivo
#
# * future = 202107  obviamente completo
#
# * final_train =  [ 202005, 202105 ]  SIN undersampling
#
# * training
#    * testing = NO HAY
#    * validation =  202105   completo, sin undersampling
#    * training = [ 202005, 202104 ]  donde se consideran el 100% de los CONTINUA

# %%
PARAM$trainingstrategy$validate <- c(202105)

PARAM$trainingstrategy$training <- c(
  202104, 202103, 202102, 202101,
  202012, 202011, 202010, 202009, 202008, 202007,
  202006, 202005
)

PARAM$trainingstrategy$training_pct <- 1.0


PARAM$trainingstrategy$positivos <- c( "BAJA+1", "BAJA+2")

# %%
# seteo la clase01   1={BAJA+1, BAJA+2}   0={CONTINUA}
dataset[, clase01 := ifelse( clase_ternaria %in% PARAM$trainingstrategy$positivos, 1, 0 )]

# %%
# los campos en los que se entrena
campos_buenos <- copy( setdiff(
    colnames(dataset), c("clase_ternaria","clase01","azar"))
)

# %%
# preparo para que se puede hacer undersampling de los CONTINUA
#  solamente por un tema de VELOCIDAD
set.seed(PARAM$semilla_primigenia, kind = "L'Ecuyer-CMRG")
dataset[, azar:=runif(nrow(dataset))]

# undersampling de los CONTINUA
dataset[, fold_train :=  foto_mes %in%  PARAM$trainingstrategy$training &
    (clase_ternaria %in% c("BAJA+1", "BAJA+2") |
     azar < PARAM$trainingstrategy$training_pct ) ]


if( !require("lightgbm")) install.packages("lightgbm")
require("lightgbm")

dtrain <- lgb.Dataset(
  data= data.matrix(dataset[fold_train == TRUE, campos_buenos, with = FALSE]),
  label= dataset[fold_train == TRUE, clase01],
  free_raw_data= TRUE
)
# Out:
# Loading required package: lightgbm
#
# Warning message in library(package, lib.loc = lib.loc, character.only = TRUE, logical.return = TRUE, :
# “there is no package called ‘lightgbm’”
# Installing package into ‘/usr/local/lib/R/site-library’
# (as ‘lib’ is unspecified)
#
# Loading required package: lightgbm

# %%
# datos de validation
dvalidate <- lgb.Dataset(
  data= data.matrix(dataset[foto_mes %in% PARAM$trainingstrategy$validate, campos_buenos, with = FALSE]),
  label= dataset[foto_mes %in% PARAM$trainingstrategy$validate, clase01],
  free_raw_data= TRUE
)

nrow(dvalidate)
# Out:
# [1] 16469

# %% [markdown]
# ####  6.3.2.2. Hyperparameter Tuning

# %% [markdown]
# * Clase binaria que se optimiza :  positivos = [ BAJA+1, BAJA+2 ]

# %% [markdown]
# * Metrica que se optimiza **AUC** Area Under Curve de la  ROC Curve
#
# es muy importante notar que intencionalmente  **NO** se está optimizando la funcion de ganancia del problema

# %% [markdown]
# * Cantidad de iteraciones inteligentes de la Optimizacion Bayesiana = **10**

# %% [markdown]
# * Parametros no default, fijos de LightGBM que no se optimizan
#   * max_bin = 31 , Alienigenas Ancestrales contruyeron las pirámides y dejaron a la humanidad en un jeroglifico  *max_bin=31*
#   * feature_fraction = 0.5  para poner algo que generalmente no falla
#   * learning_rate = 0.03  para que aprenda lento

# %% [markdown]
# * Parametros que se optimizan en la Bayesian Optimization
#   * num_leaves  [8, 256]
#   * min_data_in_leaf  [8, 8192]

# %%
# paquetes necesarios para la Bayesian Optimization
if(!require("DiceKriging")) install.packages("DiceKriging")
require("DiceKriging")

if(!require("mlrMBO")) install.packages("mlrMBO")
require("mlrMBO")
# Out:
# Loading required package: DiceKriging
#
# Warning message in library(package, lib.loc = lib.loc, character.only = TRUE, logical.return = TRUE, :
# “there is no package called ‘DiceKriging’”
# Installing package into ‘/usr/local/lib/R/site-library’
# (as ‘lib’ is unspecified)
#
# Loading required package: DiceKriging
#
# Loading required package: mlrMBO
#
# Warning message in library(package, lib.loc = lib.loc, character.only = TRUE, logical.return = TRUE, :
# “there is no package called ‘mlrMBO’”
# Installing package into ‘/usr/local/lib/R/site-library’
# (as ‘lib’ is unspecified)
#
# also installing the dependencies ‘XML’, ‘fastmatch’, ‘RcppArmadillo’, ‘mlr’, ‘ParamHelpers’, ‘smoof’, ‘BBmisc’, ‘checkmate’, ‘lhs’, ‘parallelMap’
#
#
# Loading required package: mlrMBO
#
# Loading required package: mlr
#
# Loading required package: ParamHelpers
#
#
# Attaching package: ‘ParamHelpers’
#
#
# The following object is masked from ‘package:R.utils’:
#
#     isVector
#
#
#
# Attaching package: ‘mlr’
#
#
# The following objects are masked from ‘package:R.utils’:
#
#     resample, setThreshold
#
#
# Loading required package: smoof
#
# Loading required package: checkmate
#
#
# Attaching package: ‘checkmate’
#
#
# The following object is masked from ‘package:DiceKriging’:
#
#     checkNames
#
#
# The following object is masked from ‘package:R.utils’:
#
#     asInt
#
#
#
# Attaching package: ‘smoof’
#
#
# The following objects are masked from ‘package:R.oo’:
#
#     getDescription, getName

# %% [markdown]
# Definición de la Bayesian Optimization
# <br> Si se desea optimizar un hiperparámetro que esta como fijo, debe QUITARSE de param_fijos y agregarse a PARAM$hipeparametertuning$hs

# %%
# valor ridiculamente bajo para que corra rapido en el aula y no molestar a la *Modalidad Gerencial*
PARAM$hipeparametertuning$num_interations <- 100

# parametros fijos del LightGBM
PARAM$lgbm$param_fijos <- list(
  objective= "binary",
  metric= "auc",
  first_metric_only= TRUE,
  boost_from_average= TRUE,
  feature_pre_filter= FALSE,
  verbosity= -100,
  force_row_wise= TRUE, # para evitar warning
  max_bin= 31,
  seed= PARAM$semilla_primigenia
  # learning_rate= 0.03,
  # feature_fraction= 0.5,
  # num_iterations= 2048,  # valor grande, lo limita early_stopping_rounds
  # early_stopping_rounds= 200
)


PARAM$hipeparametertuning$hs <- makeParamSet(
  # Núcleo del modelo (estructura de árboles)
  makeIntegerParam("num_leaves", lower = 2L, upper = 8192L),
  #makeIntegerParam("max_depth", lower = 3L, upper = 30L),
  makeNumericParam("min_child_weight", lower = 0.001, upper = 10.0),
  makeIntegerParam("min_data_in_leaf", lower = 2L, upper = 8192L),
  makeNumericParam("min_gain_to_split", lower = 0.0, upper = 0.1),

  # Regularización
  makeNumericParam("lambda_l1", lower = 0.0, upper = 1000L),
  makeNumericParam("lambda_l2", lower = 0.0, upper = 1000L),
  makeNumericParam("scale_pos_weight", lower = 1.0, upper = 5.0),  # útil en desequilibrio

  # Control del aprendizaje
  makeNumericParam("learning_rate", lower = 0.005, upper = 0.1),
  makeIntegerParam("num_iterations", lower = 100L, upper = 5000L),
  makeIntegerParam("early_stopping_rounds", lower = 50L, upper = 500L),

  # Submuestreo
  makeNumericParam("feature_fraction", lower = 0.05, upper = 1L),   # columnas
  makeNumericParam("bagging_fraction", lower = 0.5, upper = 1L)   # filas
  #makeIntegerParam("bagging_freq", lower = 0L, upper = 5L),         # cada N iteraciones

  # Opcionales útiles
  #makeNumericParam("max_delta_step", lower = 0.0, upper = 10.0),
  #makeNumericParam("path_smooth", lower = 0.0, upper = 10.0)
)
# Total: 12 hT

# %% [markdown]
# Función "señora caja negra"  que es llamada para verificar la realidad por la Bayesian Optimization

# %%
# En  x llegan los parmaetros de la bayesiana
#  devuelve la AUC en validate del modelo entrenado
#  en el parametro x llegan los hiperparámetros que se estan optimizando

EstimarGanancia_AUC_lightgbm <- function(x) {

  # x pisa (o agrega) a param_fijos
  param_completo <- modifyList(PARAM$lgbm$param_fijos, x)

  # entreno LightGBM
  modelo_train <- lgb.train(
    data= dtrain,
    valids= list(valid = dvalidate),
    eval= "auc",
    param= param_completo,
    verbose= -100
  )

  # recupero la AUC en validation
  AUC <- modelo_train$record_evals$valid$auc$eval[[modelo_train$best_iter]]

  # esta es la forma de devolver un parametro extra
  attr(AUC, "extras") <- list("num_iterations"= modelo_train$best_iter)

  # hago espacio en la memoria
  rm(modelo_train)
  gc(full= TRUE, verbose= FALSE)

  message(format(Sys.time(), "%a %b %d %X %Y"), " AUC ", AUC)

  return(AUC)
}

# %% [markdown]
# seteo de la Bayesian Optimization (complejo)
# <br> copiado y pegado de la documentación de la librería

# %%
configureMlr(show.learner.output = FALSE)

# configuro la busqueda bayesiana,  los hiperparametros que se van a optimizar
# por favor, no desesperarse por lo complejo
obj.fun <- makeSingleObjectiveFunction(
    fn= EstimarGanancia_AUC_lightgbm, # la funcion que voy a maximizar
    minimize= FALSE, # estoy Maximizando AUC
    noisy= FALSE,
    par.set= PARAM$hipeparametertuning$hs,
    has.simple.signature= FALSE # paso los parametros en una lista
)

# cada 600 segundos guardo el resultado intermedio
ctrl <- makeMBOControl(
    save.on.disk.at.time= 600,
    save.file.path= "HT.RDATA"
)

# indico la cantidad de iteraciones que va a tener la Bayesian Optimization
ctrl <- setMBOControlTermination(
    ctrl,
    iters= PARAM$hipeparametertuning$num_interations  # cantidad de iteraciones inteligentes
)

# defino el método estandar para la creacion de los puntos iniciales
#   los "No Inteligentes"
ctrl <- setMBOControlInfill(ctrl, crit = makeMBOInfillCritEI())

# mas configuraciones
surr.km <- makeLearner(
    "regr.km",
    predict.type= "se",
    covtype= "matern3_2",
    control= list(trace = TRUE)
)

# %% [markdown]
# Corrida de la Bayesian Optimization,  aqui se hace el trabajo pesado
# <br> por favor no se asuste con los warnings que pudieran aparecer
#
# Si corrío a medias y llegó a las iteraciones inteligentes, en el archivo binario HT.RDATA quedó lo ya procesado y es utilizado para retomar la corrida desde lo último que llegó a grabar.

# %%
# inicio la optimizacion bayesiana

if (!file.exists("HT.RDATA")) {
  bayesiana_salida <- mbo(obj.fun, learner= surr.km, control= ctrl)
} else {
  bayesiana_salida <- mboContinue("HT.RDATA") # retomo en caso que ya exista
}
# Out:
# Computing y column(s) for design. Not provided.
#
# Thu Nov 20 11:37:39 AM 2025 AUC 0.904162715772506
#
# Thu Nov 20 11:39:05 AM 2025 AUC 0.895542720322326
#
# Thu Nov 20 11:40:42 AM 2025 AUC 0.884886881957684
#
# Thu Nov 20 11:42:43 AM 2025 AUC 0.898152994727444
#
# Thu Nov 20 11:44:01 AM 2025 AUC 0.899331720093493
#
# Thu Nov 20 11:45:47 AM 2025 AUC 0.90117060548166
#
# Thu Nov 20 11:46:32 AM 2025 AUC 0.90012642861313
#
# Thu Nov 20 11:47:58 AM 2025 AUC 0.90471131126738
#
# Thu Nov 20 11:49:09 AM 2025 AUC 0.896138625887399
#
# Thu Nov 20 11:49:48 AM 2025 AUC 0.890311434474882
#
# Thu Nov 20 11:51:42 AM 2025 AUC 0.88696936387752
#
# Thu Nov 20 11:53:57 AM 2025 AUC 0.890660891482778
#
# Thu Nov 20 11:54:18 AM 2025 AUC 0.889797231052317
#
# Thu Nov 20 11:55:35 AM 2025 AUC 0.886463380999068
#
# Thu Nov 20 11:59:24 AM 2025 AUC 0.892502964428867
#
# Thu Nov 20 11:59:49 AM 2025 AUC 0.867678766636536
#
# Thu Nov 20 12:03:01 PM 2025 AUC 0.904686817401248
#
# Thu Nov 20 12:03:33 PM 2025 AUC 0.880323137845439
#
# Thu Nov 20 12:04:13 PM 2025 AUC 0.879360327587005
#
# Thu Nov 20 12:08:21 PM 2025 AUC 0.90581806493089
#
# Thu Nov 20 12:11:53 PM 2025 AUC 0.914194296083196
#
# Thu Nov 20 12:13:01 PM 2025 AUC 0.87891524384147
#
# Thu Nov 20 12:19:14 PM 2025 AUC 0.909343839524242
#
# Thu Nov 20 12:20:04 PM 2025 AUC 0.912438454967188
#
# Thu Nov 20 12:20:25 PM 2025 AUC 0.891940444338864
#
# Thu Nov 20 12:21:20 PM 2025 AUC 0.901675078464255
#
# Thu Nov 20 12:22:05 PM 2025 AUC 0.851747687678377
#
# Thu Nov 20 12:25:28 PM 2025 AUC 0.914144301753694
#
# Thu Nov 20 12:26:24 PM 2025 AUC 0.891276761226411
#
# Thu Nov 20 12:27:00 PM 2025 AUC 0.874781652282392
#
# Thu Nov 20 12:29:00 PM 2025 AUC 0.892634660900878
#
# Thu Nov 20 12:29:45 PM 2025 AUC 0.869765274945325
#
# Thu Nov 20 12:31:34 PM 2025 AUC 0.883016624288923
#
# Thu Nov 20 12:33:26 PM 2025 AUC 0.909834723444119
#
# Thu Nov 20 12:34:42 PM 2025 AUC 0.880020152076711
#
# Thu Nov 20 12:35:21 PM 2025 AUC 0.894485122157285
#
# Thu Nov 20 12:39:35 PM 2025 AUC 0.910752404593036
#
# Thu Nov 20 12:44:08 PM 2025 AUC 0.914035253719545
#
# Thu Nov 20 12:45:14 PM 2025 AUC 0.858596407521563
#
# Thu Nov 20 12:46:44 PM 2025 AUC 0.895420418757872
#
# Thu Nov 20 12:47:36 PM 2025 AUC 0.891221901676924
#
# Thu Nov 20 12:48:25 PM 2025 AUC 0.883489389458511
#
# Thu Nov 20 12:50:06 PM 2025 AUC 0.888031995028752
#
# Thu Nov 20 12:51:21 PM 2025 AUC 0.893187115018498
#
# Thu Nov 20 12:52:02 PM 2025 AUC 0.882307308768334
#
# Thu Nov 20 12:54:05 PM 2025 AUC 0.84122522344781
#
# Thu Nov 20 12:54:41 PM 2025 AUC 0.899156907706441
#
# Thu Nov 20 12:57:24 PM 2025 AUC 0.905638387323854
#
# [mbo] 0: num_leaves=5039; min_child_weight=8.33; min_data_in_leaf=2174; min_gain_to_split=0.0346; lambda_l1=265; lambda_l2=590; scale_pos_weight=3.91; learning_rate=0.0561; num_iterations=800; early_stopping_rounds=293; feature_fraction=0.49; bagging_fraction=0.574 : y = 0.904 : 170.9 secs : initdesign
#
# [mbo] 0: num_leaves=4407; min_child_weight=3.54; min_data_in_leaf=1721; min_gain_to_split=0.0137; lambda_l1=509; lambda_l2=610; scale_pos_weight=3.1; learning_rate=0.0246; num_iterations=2320; early_stopping_rounds=178; feature_fraction=0.612; bagging_fraction=0.804 : y = 0.896 : 86.9 secs : initdesign
#
# [mbo] 0: num_leaves=3964; min_child_weight=4.51; min_data_in_leaf=4035; min_gain_to_split=0.0454; lambda_l1=615; lambda_l2=669; scale_pos_weight=2.59; learning_rate=0.0668; num_iterations=2166; early_stopping_rounds=431; feature_fraction=0.269; bagging_fraction=0.859 : y = 0.885 : 96.8 secs : initdesign
#
# [mbo] 0: num_leaves=3531; min_child_weight=7.35; min_data_in_leaf=1931; min_gain_to_split=0.0661; lambda_l1=359; lambda_l2=551; scale_pos_weight=2.85; learning_rate=0.0479; num_iterations=3498; early_stopping_rounds=317; feature_fraction=0.433; bagging_fraction=0.918 : y = 0.898 : 121.0 secs : initdesign
#
# [mbo] 0: num_leaves=2896; min_child_weight=2.76; min_data_in_leaf=6859; min_gain_to_split=0.0292; lambda_l1=274; lambda_l2=635; scale_pos_weight=2.58; learning_rate=0.0457; num_iterations=2007; early_stopping_rounds=412; feature_fraction=0.866; bagging_fraction=0.7 : y = 0.899 : 77.7 secs : initdesign
#
# [mbo] 0: num_leaves=5234; min_child_weight=8.83; min_data_in_leaf=5620; min_gain_to_split=0.0384; lambda_l1=385; lambda_l2=399; scale_pos_weight=4.39; learning_rate=0.0859; num_iterations=2067; early_stopping_rounds=335; feature_fraction=0.182; bagging_fraction=0.743 : y = 0.901 : 106.3 secs : initdesign
#
# [mbo] 0: num_leaves=5559; min_child_weight=3.25; min_data_in_leaf=4738; min_gain_to_split=0.0193; lambda_l1=340; lambda_l2=783; scale_pos_weight=3.7; learning_rate=0.0506; num_iterations=318; early_stopping_rounds=221; feature_fraction=0.632; bagging_fraction=0.787 : y = 0.9 : 45.0 secs : initdesign
#
# [mbo] 0: num_leaves=1434; min_child_weight=9.07; min_data_in_leaf=5355; min_gain_to_split=0.0482; lambda_l1=189; lambda_l2=157; scale_pos_weight=2.74; learning_rate=0.0578; num_iterations=281; early_stopping_rounds=204; feature_fraction=0.536; bagging_fraction=0.558 : y = 0.905 : 85.6 secs : initdesign
#
# [mbo] 0: num_leaves=5328; min_child_weight=5.01; min_data_in_leaf=1286; min_gain_to_split=0.0512; lambda_l1=479; lambda_l2=867; scale_pos_weight=3.2; learning_rate=0.0409; num_iterations=3305; early_stopping_rounds=375; feature_fraction=0.645; bagging_fraction=0.771 : y = 0.896 : 71.3 secs : initdesign
#
# [mbo] 0: num_leaves=7453; min_child_weight=7.05; min_data_in_leaf=6053; min_gain_to_split=0.0567; lambda_l1=296; lambda_l2=234; scale_pos_weight=1.73; learning_rate=0.0737; num_iterations=1899; early_stopping_rounds=273; feature_fraction=0.753; bagging_fraction=0.611 : y = 0.89 : 38.7 secs : initdesign
#
# [mbo] 0: num_leaves=3720; min_child_weight=7.74; min_data_in_leaf=7425; min_gain_to_split=0.0104; lambda_l1=706; lambda_l2=508; scale_pos_weight=3.58; learning_rate=0.0795; num_iterations=4567; early_stopping_rounds=381; feature_fraction=0.42; bagging_fraction=0.544 : y = 0.887 : 114.2 secs : initdesign
#
# [mbo] 0: num_leaves=7092; min_child_weight=8.7; min_data_in_leaf=5020; min_gain_to_split=0.0842; lambda_l1=430; lambda_l2=806; scale_pos_weight=3.29; learning_rate=0.063; num_iterations=1389; early_stopping_rounds=477; feature_fraction=0.238; bagging_fraction=0.644 : y = 0.891 : 134.8 secs : initdesign
#
# [mbo] 0: num_leaves=3307; min_child_weight=2.04; min_data_in_leaf=6332; min_gain_to_split=0.0629; lambda_l1=412; lambda_l2=896; scale_pos_weight=2.42; learning_rate=0.0943; num_iterations=2834; early_stopping_rounds=61; feature_fraction=0.769; bagging_fraction=0.839 : y = 0.89 : 21.3 secs : initdesign
#
# [mbo] 0: num_leaves=3082; min_child_weight=7.2; min_data_in_leaf=7120; min_gain_to_split=0.067; lambda_l1=248; lambda_l2=15.3; scale_pos_weight=1.34; learning_rate=0.034; num_iterations=2669; early_stopping_rounds=166; feature_fraction=0.449; bagging_fraction=0.916 : y = 0.886 : 76.6 secs : initdesign
#
# [mbo] 0: num_leaves=2557; min_child_weight=6.18; min_data_in_leaf=5154; min_gain_to_split=0.0368; lambda_l1=570; lambda_l2=726; scale_pos_weight=4.14; learning_rate=0.02; num_iterations=1486; early_stopping_rounds=466; feature_fraction=0.121; bagging_fraction=0.877 : y = 0.893 : 229.2 secs : initdesign
#
# [mbo] 0: num_leaves=1194; min_child_weight=5.85; min_data_in_leaf=2847; min_gain_to_split=0.00397; lambda_l1=784; lambda_l2=958; scale_pos_weight=2; learning_rate=0.0394; num_iterations=200; early_stopping_rounds=245; feature_fraction=0.921; bagging_fraction=0.659 : y = 0.868 : 25.5 secs : initdesign
#
# [mbo] 0: num_leaves=1845; min_child_weight=2.1; min_data_in_leaf=2703; min_gain_to_split=0.0282; lambda_l1=212; lambda_l2=827; scale_pos_weight=3.35; learning_rate=0.0623; num_iterations=2478; early_stopping_rounds=279; feature_fraction=0.343; bagging_fraction=0.845 : y = 0.905 : 191.4 secs : initdesign
#
# [mbo] 0: num_leaves=6882; min_child_weight=9.22; min_data_in_leaf=6302; min_gain_to_split=0.0588; lambda_l1=941; lambda_l2=433; scale_pos_weight=3.42; learning_rate=0.0778; num_iterations=465; early_stopping_rounds=236; feature_fraction=0.8; bagging_fraction=0.59 : y = 0.88 : 31.8 secs : initdesign
#
# [mbo] 0: num_leaves=7899; min_child_weight=7.51; min_data_in_leaf=4265; min_gain_to_split=0.069; lambda_l1=877; lambda_l2=256; scale_pos_weight=1.52; learning_rate=0.0174; num_iterations=2385; early_stopping_rounds=58; feature_fraction=0.289; bagging_fraction=0.794 : y = 0.879 : 40.5 secs : initdesign
#
# [mbo] 0: num_leaves=7248; min_child_weight=2.54; min_data_in_leaf=3560; min_gain_to_split=0.0559; lambda_l1=6.68; lambda_l2=875; scale_pos_weight=1.89; learning_rate=0.0113; num_iterations=1251; early_stopping_rounds=362; feature_fraction=0.712; bagging_fraction=0.726 : y = 0.906 : 247.5 secs : initdesign
#
# [mbo] 0: num_leaves=3003; min_child_weight=5.56; min_data_in_leaf=1168; min_gain_to_split=0.0766; lambda_l1=46.8; lambda_l2=311; scale_pos_weight=1.98; learning_rate=0.0716; num_iterations=4003; early_stopping_rounds=393; feature_fraction=0.511; bagging_fraction=0.573 : y = 0.914 : 212.3 secs : initdesign
#
# [mbo] 0: num_leaves=2320; min_child_weight=6.67; min_data_in_leaf=7664; min_gain_to_split=0.0774; lambda_l1=654; lambda_l2=758; scale_pos_weight=2.1; learning_rate=0.0538; num_iterations=3387; early_stopping_rounds=211; feature_fraction=0.391; bagging_fraction=0.623 : y = 0.879 : 67.8 secs : initdesign
#
# [mbo] 0: num_leaves=4234; min_child_weight=6.62; min_data_in_leaf=2506; min_gain_to_split=0.0406; lambda_l1=172; lambda_l2=340; scale_pos_weight=3.04; learning_rate=0.0155; num_iterations=4431; early_stopping_rounds=142; feature_fraction=0.207; bagging_fraction=0.991 : y = 0.909 : 373.1 secs : initdesign
#
# [mbo] 0: num_leaves=6072; min_child_weight=1.37; min_data_in_leaf=4492; min_gain_to_split=0.061; lambda_l1=107; lambda_l2=468; scale_pos_weight=4.77; learning_rate=0.0972; num_iterations=3653; early_stopping_rounds=101; feature_fraction=0.667; bagging_fraction=0.635 : y = 0.912 : 50.4 secs : initdesign
#
# [mbo] 0: num_leaves=2095; min_child_weight=3.94; min_data_in_leaf=3640; min_gain_to_split=0.0925; lambda_l1=470; lambda_l2=107; scale_pos_weight=2.94; learning_rate=0.0839; num_iterations=852; early_stopping_rounds=149; feature_fraction=0.81; bagging_fraction=0.687 : y = 0.892 : 20.7 secs : initdesign
#
# [mbo] 0: num_leaves=149; min_child_weight=9.53; min_data_in_leaf=613; min_gain_to_split=0.012; lambda_l1=541; lambda_l2=316; scale_pos_weight=4.61; learning_rate=0.0324; num_iterations=3088; early_stopping_rounds=295; feature_fraction=0.735; bagging_fraction=0.896 : y = 0.902 : 54.9 secs : initdesign
#
# [mbo] 0: num_leaves=5715; min_child_weight=4.01; min_data_in_leaf=5813; min_gain_to_split=0.0215; lambda_l1=725; lambda_l2=540; scale_pos_weight=1.65; learning_rate=0.0433; num_iterations=3216; early_stopping_rounds=306; feature_fraction=0.922; bagging_fraction=0.734 : y = 0.852 : 45.1 secs : initdesign
#
# [mbo] 0: num_leaves=7814; min_child_weight=5.78; min_data_in_leaf=3338; min_gain_to_split=0.0533; lambda_l1=104; lambda_l2=46; scale_pos_weight=3.97; learning_rate=0.0651; num_iterations=1691; early_stopping_rounds=400; feature_fraction=0.0537; bagging_fraction=0.902 : y = 0.914 : 203.0 secs : initdesign
#
# [mbo] 0: num_leaves=4779; min_child_weight=3.64; min_data_in_leaf=4290; min_gain_to_split=0.025; lambda_l1=746; lambda_l2=852; scale_pos_weight=4.89; learning_rate=0.0498; num_iterations=2601; early_stopping_rounds=73; feature_fraction=0.254; bagging_fraction=0.533 : y = 0.891 : 56.5 secs : initdesign
#
# [mbo] 0: num_leaves=6314; min_child_weight=0.636; min_data_in_leaf=6551; min_gain_to_split=0.0874; lambda_l1=456; lambda_l2=174; scale_pos_weight=1.28; learning_rate=0.0748; num_iterations=918; early_stopping_rounds=79; feature_fraction=0.352; bagging_fraction=0.987 : y = 0.875 : 35.1 secs : initdesign
#
# [mbo] 0: num_leaves=2600; min_child_weight=0.0748; min_data_in_leaf=3208; min_gain_to_split=0.0331; lambda_l1=813; lambda_l2=946; scale_pos_weight=4.93; learning_rate=0.0266; num_iterations=4378; early_stopping_rounds=423; feature_fraction=0.168; bagging_fraction=0.928 : y = 0.893 : 120.0 secs : initdesign
#
# [mbo] 0: num_leaves=186; min_child_weight=6.39; min_data_in_leaf=893; min_gain_to_split=0.0167; lambda_l1=678; lambda_l2=931; scale_pos_weight=2.31; learning_rate=0.0884; num_iterations=3942; early_stopping_rounds=357; feature_fraction=0.85; bagging_fraction=0.599 : y = 0.87 : 45.0 secs : initdesign
#
# [mbo] 0: num_leaves=7634; min_child_weight=10; min_data_in_leaf=3862; min_gain_to_split=0.0424; lambda_l1=635; lambda_l2=137; scale_pos_weight=2.19; learning_rate=0.0294; num_iterations=2897; early_stopping_rounds=438; feature_fraction=0.311; bagging_fraction=0.519 : y = 0.883 : 109.3 secs : initdesign
#
# [mbo] 0: num_leaves=650; min_child_weight=0.884; min_data_in_leaf=8145; min_gain_to_split=0.0148; lambda_l1=29.2; lambda_l2=98.9; scale_pos_weight=1.12; learning_rate=0.0923; num_iterations=1566; early_stopping_rounds=184; feature_fraction=0.372; bagging_fraction=0.668 : y = 0.91 : 111.7 secs : initdesign
#
# [mbo] 0: num_leaves=5941; min_child_weight=0.443; min_data_in_leaf=2368; min_gain_to_split=0.089; lambda_l1=991; lambda_l2=442; scale_pos_weight=1.78; learning_rate=0.0222; num_iterations=3721; early_stopping_rounds=127; feature_fraction=0.571; bagging_fraction=0.525 : y = 0.88 : 76.6 secs : initdesign
#
# [mbo] 0: num_leaves=3841; min_child_weight=3.12; min_data_in_leaf=192; min_gain_to_split=0.0713; lambda_l1=766; lambda_l2=991; scale_pos_weight=4.24; learning_rate=0.0381; num_iterations=1110; early_stopping_rounds=155; feature_fraction=0.9; bagging_fraction=0.95 : y = 0.894 : 38.7 secs : initdesign
#
# [mbo] 0: num_leaves=1655; min_child_weight=8.32; min_data_in_leaf=804; min_gain_to_split=0.0975; lambda_l1=136; lambda_l2=210; scale_pos_weight=4.3; learning_rate=0.01; num_iterations=3000; early_stopping_rounds=197; feature_fraction=0.97; bagging_fraction=0.648 : y = 0.911 : 253.9 secs : initdesign
#
# [mbo] 0: num_leaves=1281; min_child_weight=4.18; min_data_in_leaf=7248; min_gain_to_split=0.0743; lambda_l1=66.2; lambda_l2=360; scale_pos_weight=4.48; learning_rate=0.0366; num_iterations=4846; early_stopping_rounds=457; feature_fraction=0.21; bagging_fraction=0.759 : y = 0.914 : 273.3 secs : initdesign
#
# [mbo] 0: num_leaves=701; min_child_weight=4.66; min_data_in_leaf=5763; min_gain_to_split=0.0943; lambda_l1=972; lambda_l2=688; scale_pos_weight=1.2; learning_rate=0.0702; num_iterations=1766; early_stopping_rounds=452; feature_fraction=0.134; bagging_fraction=0.872 : y = 0.859 : 65.6 secs : initdesign
#
# [mbo] 0: num_leaves=2035; min_child_weight=1.66; min_data_in_leaf=2930; min_gain_to_split=0.0266; lambda_l1=897; lambda_l2=201; scale_pos_weight=3.82; learning_rate=0.00727; num_iterations=4778; early_stopping_rounds=115; feature_fraction=0.999; bagging_fraction=0.948 : y = 0.895 : 90.0 secs : initdesign
#
# [mbo] 0: num_leaves=8130; min_child_weight=1.74; min_data_in_leaf=6819; min_gain_to_split=0.0817; lambda_l1=796; lambda_l2=567; scale_pos_weight=4.07; learning_rate=0.0992; num_iterations=4126; early_stopping_rounds=348; feature_fraction=0.0939; bagging_fraction=0.959 : y = 0.891 : 51.8 secs : initdesign
#
# [mbo] 0: num_leaves=6786; min_child_weight=2.41; min_data_in_leaf=1500; min_gain_to_split=0.00473; lambda_l1=328; lambda_l2=271; scale_pos_weight=1.42; learning_rate=0.0809; num_iterations=4936; early_stopping_rounds=96; feature_fraction=0.554; bagging_fraction=0.826 : y = 0.883 : 49.0 secs : initdesign
#
# [mbo] 0: num_leaves=1011; min_child_weight=0.227; min_data_in_leaf=396; min_gain_to_split=0.00767; lambda_l1=862; lambda_l2=653; scale_pos_weight=2.78; learning_rate=0.0133; num_iterations=1135; early_stopping_rounds=482; feature_fraction=0.693; bagging_fraction=0.69 : y = 0.888 : 101.2 secs : initdesign
#
# [mbo] 0: num_leaves=6510; min_child_weight=5.24; min_data_in_leaf=7956; min_gain_to_split=0.1; lambda_l1=846; lambda_l2=69.6; scale_pos_weight=4.67; learning_rate=0.028; num_iterations=580; early_stopping_rounds=255; feature_fraction=0.594; bagging_fraction=0.819 : y = 0.893 : 74.8 secs : initdesign
#
# [mbo] 0: num_leaves=469; min_child_weight=8.06; min_data_in_leaf=1538; min_gain_to_split=0.0793; lambda_l1=926; lambda_l2=479; scale_pos_weight=4.5; learning_rate=0.0867; num_iterations=4633; early_stopping_rounds=112; feature_fraction=0.0704; bagging_fraction=0.711 : y = 0.882 : 41.8 secs : initdesign
#
# [mbo] 0: num_leaves=4887; min_child_weight=4.94; min_data_in_leaf=54; min_gain_to_split=0.091; lambda_l1=602; lambda_l2=383; scale_pos_weight=1.05; learning_rate=0.00679; num_iterations=3795; early_stopping_rounds=499; feature_fraction=0.946; bagging_fraction=0.973 : y = 0.841 : 122.5 secs : initdesign
#
# [mbo] 0: num_leaves=6482; min_child_weight=1.13; min_data_in_leaf=7811; min_gain_to_split=0.000739; lambda_l1=555; lambda_l2=38; scale_pos_weight=3.63; learning_rate=0.0914; num_iterations=4282; early_stopping_rounds=330; feature_fraction=0.837; bagging_fraction=0.506 : y = 0.899 : 35.6 secs : initdesign
#
# [mbo] 0: num_leaves=4503; min_child_weight=9.72; min_data_in_leaf=4942; min_gain_to_split=0.0472; lambda_l1=150; lambda_l2=747; scale_pos_weight=2.4; learning_rate=0.0594; num_iterations=697; early_stopping_rounds=264; feature_fraction=0.484; bagging_fraction=0.767 : y = 0.906 : 163.1 secs : initdesign
#
# Saved the current state after iteration 1 in the file HT.RDATA.
#
# Thu Nov 20 01:06:19 PM 2025 AUC 0.926761662603369
#
# [mbo] 1: num_leaves=4833; min_child_weight=3.03; min_data_in_leaf=3305; min_gain_to_split=0.0537; lambda_l1=3.41; lambda_l2=164; scale_pos_weight=3.87; learning_rate=0.0449; num_iterations=3888; early_stopping_rounds=347; feature_fraction=0.593; bagging_fraction=0.636 : y = 0.927 : 532.3 secs : infill_ei
#
# Thu Nov 20 01:13:38 PM 2025 AUC 0.919734271750385
#
# [mbo] 2: num_leaves=4408; min_child_weight=5.56; min_data_in_leaf=5264; min_gain_to_split=0.0675; lambda_l1=7.46; lambda_l2=89; scale_pos_weight=3.47; learning_rate=0.0683; num_iterations=3590; early_stopping_rounds=252; feature_fraction=0.43; bagging_fraction=0.627 : y = 0.92 : 437.0 secs : infill_ei
#
# Saved the current state after iteration 3 in the file HT.RDATA.
#
# Thu Nov 20 01:22:43 PM 2025 AUC 0.928467173857462
#
# [mbo] 3: num_leaves=5733; min_child_weight=3.11; min_data_in_leaf=2572; min_gain_to_split=0.0204; lambda_l1=4.25; lambda_l2=49.2; scale_pos_weight=4.14; learning_rate=0.0441; num_iterations=4710; early_stopping_rounds=438; feature_fraction=0.591; bagging_fraction=0.713 : y = 0.928 : 543.1 secs : infill_ei
#
# Thu Nov 20 01:33:22 PM 2025 AUC 0.920408356367634
#
# [mbo] 4: num_leaves=7561; min_child_weight=2; min_data_in_leaf=1716; min_gain_to_split=0.0444; lambda_l1=26.6; lambda_l2=68.2; scale_pos_weight=4.09; learning_rate=0.0189; num_iterations=4691; early_stopping_rounds=378; feature_fraction=0.551; bagging_fraction=0.698 : y = 0.92 : 637.0 secs : infill_ei
#
# Saved the current state after iteration 5 in the file HT.RDATA.
#
# Thu Nov 20 01:42:55 PM 2025 AUC 0.928767475366888
#
# [mbo] 5: num_leaves=4407; min_child_weight=2.83; min_data_in_leaf=2569; min_gain_to_split=0.00945; lambda_l1=0.284; lambda_l2=171; scale_pos_weight=4.07; learning_rate=0.089; num_iterations=4018; early_stopping_rounds=458; feature_fraction=0.74; bagging_fraction=0.705 : y = 0.929 : 571.7 secs : infill_ei
#
# Thu Nov 20 01:50:25 PM 2025 AUC 0.925364505636609
#
# [mbo] 6: num_leaves=3668; min_child_weight=5.43; min_data_in_leaf=3674; min_gain_to_split=0.0124; lambda_l1=3.74; lambda_l2=36.2; scale_pos_weight=4.09; learning_rate=0.0473; num_iterations=3559; early_stopping_rounds=482; feature_fraction=0.786; bagging_fraction=0.668 : y = 0.925 : 448.0 secs : infill_ei
#
# Saved the current state after iteration 7 in the file HT.RDATA.
#
# Thu Nov 20 01:59:35 PM 2025 AUC 0.928918464952633
#
# [mbo] 7: num_leaves=4238; min_child_weight=3.3; min_data_in_leaf=2525; min_gain_to_split=0.0208; lambda_l1=0.326; lambda_l2=107; scale_pos_weight=3.95; learning_rate=0.0811; num_iterations=4831; early_stopping_rounds=401; feature_fraction=0.624; bagging_fraction=0.719 : y = 0.929 : 547.3 secs : infill_ei
#
# Thu Nov 20 02:05:52 PM 2025 AUC 0.928974498865565
#
# [mbo] 8: num_leaves=4523; min_child_weight=2.1; min_data_in_leaf=2386; min_gain_to_split=0.0305; lambda_l1=6.95; lambda_l2=100; scale_pos_weight=4.3; learning_rate=0.0761; num_iterations=4161; early_stopping_rounds=472; feature_fraction=0.569; bagging_fraction=0.721 : y = 0.929 : 374.7 secs : infill_ei
#
# Saved the current state after iteration 9 in the file HT.RDATA.
#
# Thu Nov 20 02:14:53 PM 2025 AUC 0.927251204393596
#
# [mbo] 9: num_leaves=4668; min_child_weight=3.03; min_data_in_leaf=3371; min_gain_to_split=0.0356; lambda_l1=0.304; lambda_l2=196; scale_pos_weight=4.1; learning_rate=0.0563; num_iterations=4577; early_stopping_rounds=421; feature_fraction=0.669; bagging_fraction=0.877 : y = 0.927 : 538.4 secs : infill_ei
#
# Thu Nov 20 02:30:42 PM 2025 AUC 0.927828655675967
#
# [mbo] 10: num_leaves=4795; min_child_weight=4.45; min_data_in_leaf=2927; min_gain_to_split=0.0134; lambda_l1=0.33; lambda_l2=232; scale_pos_weight=4.16; learning_rate=0.0692; num_iterations=4742; early_stopping_rounds=480; feature_fraction=0.492; bagging_fraction=0.516 : y = 0.928 : 946.7 secs : infill_ei
#
# Saved the current state after iteration 11 in the file HT.RDATA.
#
# Thu Nov 20 02:43:40 PM 2025 AUC 0.926261719308347
#
# [mbo] 11: num_leaves=5084; min_child_weight=0.674; min_data_in_leaf=4701; min_gain_to_split=0.0188; lambda_l1=0.109; lambda_l2=96.1; scale_pos_weight=4.08; learning_rate=0.0796; num_iterations=4644; early_stopping_rounds=455; feature_fraction=0.517; bagging_fraction=0.668 : y = 0.926 : 775.7 secs : infill_ei
#
# Saved the current state after iteration 12 in the file HT.RDATA.
#
# Thu Nov 20 02:55:38 PM 2025 AUC 0.928642992841752
#
# [mbo] 12: num_leaves=4712; min_child_weight=3.28; min_data_in_leaf=1454; min_gain_to_split=0.0329; lambda_l1=0.0186; lambda_l2=151; scale_pos_weight=4.14; learning_rate=0.0621; num_iterations=4681; early_stopping_rounds=438; feature_fraction=0.735; bagging_fraction=0.667 : y = 0.929 : 715.6 secs : infill_ei
#
# Saved the current state after iteration 13 in the file HT.RDATA.
#
# Thu Nov 20 03:03:51 PM 2025 AUC 0.926220784353989
#
# [mbo] 13: num_leaves=5052; min_child_weight=3.5; min_data_in_leaf=1652; min_gain_to_split=0.0113; lambda_l1=3.07; lambda_l2=182; scale_pos_weight=4.16; learning_rate=0.0706; num_iterations=3968; early_stopping_rounds=393; feature_fraction=0.346; bagging_fraction=0.704 : y = 0.926 : 489.5 secs : infill_ei
#
# Thu Nov 20 03:16:39 PM 2025 AUC 0.925177614082698
#
# [mbo] 14: num_leaves=5315; min_child_weight=7.66; min_data_in_leaf=2724; min_gain_to_split=0.0374; lambda_l1=1.52; lambda_l2=234; scale_pos_weight=4.18; learning_rate=0.071; num_iterations=4281; early_stopping_rounds=494; feature_fraction=0.62; bagging_fraction=0.825 : y = 0.925 : 765.9 secs : infill_ei
#
# Saved the current state after iteration 15 in the file HT.RDATA.
#
# Thu Nov 20 03:18:09 PM 2025 AUC 0.912700170249146
#
# [mbo] 15: num_leaves=4899; min_child_weight=3.04; min_data_in_leaf=1073; min_gain_to_split=0.0204; lambda_l1=61.6; lambda_l2=91.1; scale_pos_weight=3.93; learning_rate=0.0778; num_iterations=4256; early_stopping_rounds=481; feature_fraction=0.665; bagging_fraction=0.695 : y = 0.913 : 88.4 secs : infill_ei
#
# Thu Nov 20 03:26:06 PM 2025 AUC 0.922733260455693
#
# [mbo] 16: num_leaves=5504; min_child_weight=4.56; min_data_in_leaf=3163; min_gain_to_split=0.0264; lambda_l1=0.0431; lambda_l2=296; scale_pos_weight=4.44; learning_rate=0.0821; num_iterations=2059; early_stopping_rounds=319; feature_fraction=0.936; bagging_fraction=0.772 : y = 0.923 : 475.5 secs : infill_ei
#
# Thu Nov 20 03:36:00 PM 2025 AUC 0.927930657529448
#
# [mbo] 17: num_leaves=1841; min_child_weight=4.33; min_data_in_leaf=2852; min_gain_to_split=0.0464; lambda_l1=0.0415; lambda_l2=181; scale_pos_weight=4.26; learning_rate=0.0932; num_iterations=4414; early_stopping_rounds=329; feature_fraction=0.631; bagging_fraction=0.601 : y = 0.928 : 590.5 secs : infill_ei
#
# Saved the current state after iteration 18 in the file HT.RDATA.
#
# Thu Nov 20 03:44:29 PM 2025 AUC 0.926899901957429
#
# [mbo] 18: num_leaves=4227; min_child_weight=4.52; min_data_in_leaf=2761; min_gain_to_split=0.0636; lambda_l1=0.00965; lambda_l2=222; scale_pos_weight=4.32; learning_rate=0.0638; num_iterations=4484; early_stopping_rounds=216; feature_fraction=0.674; bagging_fraction=0.664 : y = 0.927 : 506.4 secs : infill_ei
#
# Thu Nov 20 04:01:13 PM 2025 AUC 0.925220226699119
#
# [mbo] 19: num_leaves=2284; min_child_weight=1.08; min_data_in_leaf=2170; min_gain_to_split=0.0221; lambda_l1=0.0565; lambda_l2=578; scale_pos_weight=4.54; learning_rate=0.0355; num_iterations=4168; early_stopping_rounds=360; feature_fraction=0.61; bagging_fraction=0.651 : y = 0.925 : 1000.6 secs : infill_ei
#
# Saved the current state after iteration 20 in the file HT.RDATA.
#
# Thu Nov 20 04:09:07 PM 2025 AUC 0.927750476623792
#
# [mbo] 20: num_leaves=4866; min_child_weight=2.95; min_data_in_leaf=3364; min_gain_to_split=0.0901; lambda_l1=0.0832; lambda_l2=114; scale_pos_weight=4.29; learning_rate=0.0712; num_iterations=4777; early_stopping_rounds=446; feature_fraction=0.774; bagging_fraction=0.674 : y = 0.928 : 472.7 secs : infill_ei
#
# Thu Nov 20 04:18:42 PM 2025 AUC 0.926021478100806
#
# [mbo] 21: num_leaves=2510; min_child_weight=2.77; min_data_in_leaf=2782; min_gain_to_split=0.0755; lambda_l1=0.0156; lambda_l2=550; scale_pos_weight=4.03; learning_rate=0.0926; num_iterations=1609; early_stopping_rounds=386; feature_fraction=0.544; bagging_fraction=0.74 : y = 0.926 : 572.0 secs : infill_ei
#
# Saved the current state after iteration 22 in the file HT.RDATA.
#
# Thu Nov 20 04:23:14 PM 2025 AUC 0.924452193006297
#
# [mbo] 22: num_leaves=3198; min_child_weight=2.93; min_data_in_leaf=2650; min_gain_to_split=0.0484; lambda_l1=0.117; lambda_l2=213; scale_pos_weight=4.35; learning_rate=0.0353; num_iterations=1056; early_stopping_rounds=458; feature_fraction=0.297; bagging_fraction=0.608 : y = 0.924 : 269.4 secs : infill_ei
#
# Thu Nov 20 04:41:48 PM 2025 AUC 0.925479928786601
#
# [mbo] 23: num_leaves=6303; min_child_weight=2.62; min_data_in_leaf=2627; min_gain_to_split=0.0534; lambda_l1=0.0859; lambda_l2=612; scale_pos_weight=4.43; learning_rate=0.0605; num_iterations=4191; early_stopping_rounds=477; feature_fraction=0.564; bagging_fraction=0.671 : y = 0.925 : 1111.5 secs : infill_ei
#
# Saved the current state after iteration 24 in the file HT.RDATA.
#
# Thu Nov 20 04:49:05 PM 2025 AUC 0.927065654969336
#
# [mbo] 24: num_leaves=3560; min_child_weight=2.59; min_data_in_leaf=2801; min_gain_to_split=0.0636; lambda_l1=0.0742; lambda_l2=212; scale_pos_weight=4.26; learning_rate=0.0929; num_iterations=3919; early_stopping_rounds=421; feature_fraction=0.189; bagging_fraction=0.739 : y = 0.927 : 433.4 secs : infill_ei
#
# Thu Nov 20 05:02:36 PM 2025 AUC 0.928083995842082
#
# [mbo] 25: num_leaves=1959; min_child_weight=2.63; min_data_in_leaf=2865; min_gain_to_split=0.0846; lambda_l1=0.632; lambda_l2=263; scale_pos_weight=4.87; learning_rate=0.0549; num_iterations=2282; early_stopping_rounds=425; feature_fraction=0.556; bagging_fraction=0.739 : y = 0.928 : 808.5 secs : infill_ei
#
# Saved the current state after iteration 26 in the file HT.RDATA.
#
# Thu Nov 20 05:13:26 PM 2025 AUC 0.928700368884335
#
# [mbo] 26: num_leaves=3835; min_child_weight=3.84; min_data_in_leaf=1404; min_gain_to_split=0.0978; lambda_l1=0.159; lambda_l2=199; scale_pos_weight=4.37; learning_rate=0.0388; num_iterations=4912; early_stopping_rounds=423; feature_fraction=0.296; bagging_fraction=0.825 : y = 0.929 : 648.2 secs : infill_ei
#
# Saved the current state after iteration 27 in the file HT.RDATA.
#
# Thu Nov 20 05:25:42 PM 2025 AUC 0.927157926382847
#
# [mbo] 27: num_leaves=2926; min_child_weight=4.42; min_data_in_leaf=2293; min_gain_to_split=0.0535; lambda_l1=0.267; lambda_l2=260; scale_pos_weight=4.45; learning_rate=0.07; num_iterations=2864; early_stopping_rounds=456; feature_fraction=0.573; bagging_fraction=0.701 : y = 0.927 : 733.9 secs : infill_ei
#
# Saved the current state after iteration 28 in the file HT.RDATA.
#
# Thu Nov 20 05:37:44 PM 2025 AUC 0.928954031388386
#
# [mbo] 28: num_leaves=3887; min_child_weight=5.8; min_data_in_leaf=2645; min_gain_to_split=0.0908; lambda_l1=0.487; lambda_l2=5.46; scale_pos_weight=4.66; learning_rate=0.0284; num_iterations=3392; early_stopping_rounds=361; feature_fraction=0.452; bagging_fraction=0.811 : y = 0.929 : 719.4 secs : infill_ei
#
# Saved the current state after iteration 29 in the file HT.RDATA.
#
# Thu Nov 20 05:47:45 PM 2025 AUC 0.927969243756916
#
# [mbo] 29: num_leaves=1913; min_child_weight=0.781; min_data_in_leaf=1960; min_gain_to_split=0.0764; lambda_l1=0.573; lambda_l2=38.4; scale_pos_weight=4.48; learning_rate=0.0464; num_iterations=4517; early_stopping_rounds=349; feature_fraction=0.478; bagging_fraction=0.77 : y = 0.928 : 598.3 secs : infill_ei
#
# Saved the current state after iteration 30 in the file HT.RDATA.
#
# Thu Nov 20 05:57:04 PM 2025 AUC 0.92874231043593
#
# [mbo] 30: num_leaves=4802; min_child_weight=1.85; min_data_in_leaf=2223; min_gain_to_split=0.0975; lambda_l1=0.21; lambda_l2=354; scale_pos_weight=4.82; learning_rate=0.0412; num_iterations=2097; early_stopping_rounds=287; feature_fraction=0.296; bagging_fraction=0.792 : y = 0.929 : 556.3 secs : infill_ei
#
# Thu Nov 20 06:03:32 PM 2025 AUC 0.927888044913027
#
# [mbo] 31: num_leaves=4969; min_child_weight=1.2; min_data_in_leaf=2592; min_gain_to_split=0.0892; lambda_l1=0.291; lambda_l2=57; scale_pos_weight=4.78; learning_rate=0.0446; num_iterations=1016; early_stopping_rounds=381; feature_fraction=0.536; bagging_fraction=0.75 : y = 0.928 : 385.7 secs : infill_ei
#
# Saved the current state after iteration 32 in the file HT.RDATA.
#
# Thu Nov 20 06:14:42 PM 2025 AUC 0.925429598924686
#
# [mbo] 32: num_leaves=3971; min_child_weight=1.96; min_data_in_leaf=2018; min_gain_to_split=0.0983; lambda_l1=0.992; lambda_l2=422; scale_pos_weight=4.68; learning_rate=0.0263; num_iterations=2424; early_stopping_rounds=316; feature_fraction=0.616; bagging_fraction=0.834 : y = 0.925 : 666.4 secs : infill_ei
#
# Saved the current state after iteration 33 in the file HT.RDATA.
#
# Thu Nov 20 06:30:33 PM 2025 AUC 0.928479253024321
#
# [mbo] 33: num_leaves=4443; min_child_weight=2.29; min_data_in_leaf=2605; min_gain_to_split=0.0549; lambda_l1=0.328; lambda_l2=203; scale_pos_weight=4.86; learning_rate=0.0525; num_iterations=3443; early_stopping_rounds=440; feature_fraction=0.483; bagging_fraction=0.738 : y = 0.928 : 948.4 secs : infill_ei
#
# Saved the current state after iteration 34 in the file HT.RDATA.
#
# Thu Nov 20 06:36:52 PM 2025 AUC 0.927108267585757
#
# [mbo] 34: num_leaves=3125; min_child_weight=3.16; min_data_in_leaf=2688; min_gain_to_split=0.0987; lambda_l1=0.452; lambda_l2=85.3; scale_pos_weight=4.76; learning_rate=0.0535; num_iterations=1398; early_stopping_rounds=243; feature_fraction=0.279; bagging_fraction=0.755 : y = 0.927 : 375.9 secs : infill_ei
#
# Thu Nov 20 06:50:16 PM 2025 AUC 0.928295716794538
#
# [mbo] 35: num_leaves=556; min_child_weight=6.26; min_data_in_leaf=2536; min_gain_to_split=0.0934; lambda_l1=0.0925; lambda_l2=66; scale_pos_weight=3.98; learning_rate=0.0416; num_iterations=4731; early_stopping_rounds=364; feature_fraction=0.508; bagging_fraction=0.747 : y = 0.928 : 801.8 secs : infill_ei
#
# Saved the current state after iteration 36 in the file HT.RDATA.
#
# Thu Nov 20 06:54:37 PM 2025 AUC 0.924800140118336
#
# [mbo] 36: num_leaves=5541; min_child_weight=2.5; min_data_in_leaf=1958; min_gain_to_split=0.0841; lambda_l1=0.156; lambda_l2=132; scale_pos_weight=4.89; learning_rate=0.0895; num_iterations=4243; early_stopping_rounds=103; feature_fraction=0.337; bagging_fraction=0.781 : y = 0.925 : 256.5 secs : infill_ei
#
# Thu Nov 20 07:04:08 PM 2025 AUC 0.926267423359364
#
# [mbo] 37: num_leaves=4801; min_child_weight=2.18; min_data_in_leaf=2655; min_gain_to_split=0.0948; lambda_l1=0.089; lambda_l2=116; scale_pos_weight=4.7; learning_rate=0.0748; num_iterations=3637; early_stopping_rounds=402; feature_fraction=0.33; bagging_fraction=0.768 : y = 0.926 : 568.3 secs : infill_ei
#
# Saved the current state after iteration 38 in the file HT.RDATA.
#
# Thu Nov 20 07:11:07 PM 2025 AUC 0.926001681688453
#
# [mbo] 38: num_leaves=3747; min_child_weight=4.66; min_data_in_leaf=2411; min_gain_to_split=0.0891; lambda_l1=1.11; lambda_l2=321; scale_pos_weight=4.97; learning_rate=0.0346; num_iterations=2276; early_stopping_rounds=265; feature_fraction=0.115; bagging_fraction=0.774 : y = 0.926 : 414.5 secs : infill_ei
#
# Thu Nov 20 07:21:11 PM 2025 AUC 0.929696564617839
#
# [mbo] 39: num_leaves=3793; min_child_weight=1.47; min_data_in_leaf=2688; min_gain_to_split=0.00672; lambda_l1=0.307; lambda_l2=82.6; scale_pos_weight=4.71; learning_rate=0.0437; num_iterations=4999; early_stopping_rounds=462; feature_fraction=0.671; bagging_fraction=0.615 : y = 0.93 : 601.3 secs : infill_ei
#
# Saved the current state after iteration 40 in the file HT.RDATA.
#
# Thu Nov 20 07:26:24 PM 2025 AUC 0.926166092570708
#
# [mbo] 40: num_leaves=6167; min_child_weight=2.24; min_data_in_leaf=2661; min_gain_to_split=0.0855; lambda_l1=0.749; lambda_l2=153; scale_pos_weight=4.35; learning_rate=0.0425; num_iterations=1142; early_stopping_rounds=138; feature_fraction=0.297; bagging_fraction=0.951 : y = 0.926 : 307.8 secs : infill_ei
#
# Thu Nov 20 07:42:37 PM 2025 AUC 0.927583717014647
#
# [mbo] 41: num_leaves=2453; min_child_weight=3.1; min_data_in_leaf=2739; min_gain_to_split=0.0803; lambda_l1=0.0444; lambda_l2=168; scale_pos_weight=4.25; learning_rate=0.047; num_iterations=4141; early_stopping_rounds=486; feature_fraction=0.475; bagging_fraction=0.766 : y = 0.928 : 970.2 secs : infill_ei
#
# Saved the current state after iteration 42 in the file HT.RDATA.
#
# Thu Nov 20 07:54:08 PM 2025 AUC 0.931579236985872
#
# [mbo] 42: num_leaves=5587; min_child_weight=8.44; min_data_in_leaf=1912; min_gain_to_split=0.0958; lambda_l1=0.335; lambda_l2=13.9; scale_pos_weight=3.83; learning_rate=0.0273; num_iterations=2375; early_stopping_rounds=306; feature_fraction=0.398; bagging_fraction=0.741 : y = 0.932 : 688.4 secs : infill_ei
#
# Saved the current state after iteration 43 in the file HT.RDATA.
#
# Thu Nov 20 08:04:54 PM 2025 AUC 0.928296387859364
#
# [mbo] 43: num_leaves=5512; min_child_weight=8.94; min_data_in_leaf=1792; min_gain_to_split=0.0999; lambda_l1=1.36; lambda_l2=191; scale_pos_weight=4.02; learning_rate=0.0375; num_iterations=3532; early_stopping_rounds=235; feature_fraction=0.306; bagging_fraction=0.878 : y = 0.928 : 643.4 secs : infill_ei
#
# Saved the current state after iteration 44 in the file HT.RDATA.
#
# Thu Nov 20 08:09:55 PM 2025 AUC 0.925040716858289
#
# [mbo] 44: num_leaves=2070; min_child_weight=8.19; min_data_in_leaf=2022; min_gain_to_split=0.0994; lambda_l1=0.493; lambda_l2=195; scale_pos_weight=3.11; learning_rate=0.0327; num_iterations=1474; early_stopping_rounds=388; feature_fraction=0.152; bagging_fraction=0.734 : y = 0.925 : 297.5 secs : infill_ei
#
# Thu Nov 20 08:15:16 PM 2025 AUC 0.932294927622303
#
# [mbo] 45: num_leaves=5472; min_child_weight=7.23; min_data_in_leaf=1680; min_gain_to_split=0.087; lambda_l1=0.122; lambda_l2=12.7; scale_pos_weight=3.51; learning_rate=0.034; num_iterations=1996; early_stopping_rounds=352; feature_fraction=0.0787; bagging_fraction=0.873 : y = 0.932 : 317.8 secs : infill_ei
#
# Saved the current state after iteration 46 in the file HT.RDATA.
#
# Thu Nov 20 08:28:16 PM 2025 AUC 0.928524549900045
#
# [mbo] 46: num_leaves=3797; min_child_weight=3.13; min_data_in_leaf=1495; min_gain_to_split=0.0957; lambda_l1=0.505; lambda_l2=191; scale_pos_weight=3.12; learning_rate=0.0297; num_iterations=4500; early_stopping_rounds=147; feature_fraction=0.31; bagging_fraction=0.832 : y = 0.929 : 777.6 secs : infill_ei
#
# Saved the current state after iteration 47 in the file HT.RDATA.
#
# Thu Nov 20 08:34:25 PM 2025 AUC 0.928232972233351
#
# [mbo] 47: num_leaves=5455; min_child_weight=2.43; min_data_in_leaf=1290; min_gain_to_split=0.0978; lambda_l1=0.223; lambda_l2=85.1; scale_pos_weight=3.64; learning_rate=0.0377; num_iterations=2038; early_stopping_rounds=403; feature_fraction=0.131; bagging_fraction=0.826 : y = 0.928 : 365.4 secs : infill_ei
#
# Thu Nov 20 08:43:22 PM 2025 AUC 0.933479692571782
#
# [mbo] 48: num_leaves=7391; min_child_weight=6.93; min_data_in_leaf=824; min_gain_to_split=0.0895; lambda_l1=0.0385; lambda_l2=33.2; scale_pos_weight=3.18; learning_rate=0.0297; num_iterations=4988; early_stopping_rounds=236; feature_fraction=0.14; bagging_fraction=0.889 : y = 0.933 : 533.1 secs : infill_ei
#
# Saved the current state after iteration 49 in the file HT.RDATA.
#
# Thu Nov 20 08:47:15 PM 2025 AUC 0.929036236829514
#
# [mbo] 49: num_leaves=7060; min_child_weight=8.19; min_data_in_leaf=985; min_gain_to_split=0.0816; lambda_l1=1.28; lambda_l2=24.4; scale_pos_weight=2.5; learning_rate=0.0869; num_iterations=1745; early_stopping_rounds=97; feature_fraction=0.14; bagging_fraction=0.748 : y = 0.929 : 228.3 secs : infill_ei
#
# Thu Nov 20 08:55:26 PM 2025 AUC 0.932774403440147
#
# [mbo] 50: num_leaves=6285; min_child_weight=8.43; min_data_in_leaf=209; min_gain_to_split=0.0837; lambda_l1=0.334; lambda_l2=82.5; scale_pos_weight=2.92; learning_rate=0.0268; num_iterations=2298; early_stopping_rounds=125; feature_fraction=0.266; bagging_fraction=0.898 : y = 0.933 : 488.6 secs : infill_ei
#
# Saved the current state after iteration 51 in the file HT.RDATA.
#
# Thu Nov 20 08:59:10 PM 2025 AUC 0.932377804128257
#
# [mbo] 51: num_leaves=6937; min_child_weight=3.2; min_data_in_leaf=274; min_gain_to_split=0.094; lambda_l1=0.384; lambda_l2=1.68; scale_pos_weight=2.65; learning_rate=0.0364; num_iterations=4331; early_stopping_rounds=157; feature_fraction=0.118; bagging_fraction=0.805 : y = 0.932 : 219.8 secs : infill_ei
#
# Thu Nov 20 09:03:30 PM 2025 AUC 0.92934257792237
#
# [mbo] 52: num_leaves=6713; min_child_weight=5.62; min_data_in_leaf=1974; min_gain_to_split=0.0435; lambda_l1=0.316; lambda_l2=49.8; scale_pos_weight=2.85; learning_rate=0.0384; num_iterations=4022; early_stopping_rounds=90; feature_fraction=0.0554; bagging_fraction=0.766 : y = 0.929 : 256.3 secs : infill_ei
#
# Thu Nov 20 09:07:30 PM 2025 AUC 0.926787163066739
#
# [mbo] 53: num_leaves=5640; min_child_weight=0.875; min_data_in_leaf=1541; min_gain_to_split=0.0665; lambda_l1=0.0107; lambda_l2=6.76; scale_pos_weight=2.6; learning_rate=0.0911; num_iterations=2462; early_stopping_rounds=205; feature_fraction=0.379; bagging_fraction=0.904 : y = 0.927 : 236.3 secs : infill_ei
#
# Saved the current state after iteration 54 in the file HT.RDATA.
#
# Thu Nov 20 09:14:11 PM 2025 AUC 0.929866679551111
#
# [mbo] 54: num_leaves=7163; min_child_weight=9; min_data_in_leaf=270; min_gain_to_split=0.0746; lambda_l1=0.0373; lambda_l2=136; scale_pos_weight=1.7; learning_rate=0.0631; num_iterations=4437; early_stopping_rounds=55; feature_fraction=0.191; bagging_fraction=0.782 : y = 0.93 : 395.9 secs : infill_ei
#
# Thu Nov 20 09:16:10 PM 2025 AUC 0.930894750863828
#
# [mbo] 55: num_leaves=3003; min_child_weight=8.17; min_data_in_leaf=832; min_gain_to_split=0.0617; lambda_l1=0.236; lambda_l2=2.83; scale_pos_weight=2.34; learning_rate=0.0393; num_iterations=4106; early_stopping_rounds=164; feature_fraction=0.105; bagging_fraction=0.915 : y = 0.931 : 116.6 secs : infill_ei
#
# Thu Nov 20 09:26:27 PM 2025 AUC 0.930362931989593
#
# [mbo] 56: num_leaves=6009; min_child_weight=7.37; min_data_in_leaf=1509; min_gain_to_split=0.0948; lambda_l1=0.287; lambda_l2=55.8; scale_pos_weight=2.34; learning_rate=0.0261; num_iterations=3310; early_stopping_rounds=165; feature_fraction=0.304; bagging_fraction=0.887 : y = 0.93 : 614.0 secs : infill_ei
#
# Saved the current state after iteration 57 in the file HT.RDATA.
#
# Thu Nov 20 09:29:12 PM 2025 AUC 0.92961905663049
#
# [mbo] 57: num_leaves=4866; min_child_weight=8.98; min_data_in_leaf=35; min_gain_to_split=0.0562; lambda_l1=0.637; lambda_l2=0.355; scale_pos_weight=1.58; learning_rate=0.0626; num_iterations=909; early_stopping_rounds=235; feature_fraction=0.236; bagging_fraction=0.842 : y = 0.93 : 160.5 secs : infill_ei
#
# Thu Nov 20 09:35:54 PM 2025 AUC 0.924193833048466
#
# [mbo] 58: num_leaves=6453; min_child_weight=1.52; min_data_in_leaf=1339; min_gain_to_split=0.0914; lambda_l1=0.133; lambda_l2=520; scale_pos_weight=4.99; learning_rate=0.094; num_iterations=1431; early_stopping_rounds=199; feature_fraction=0.495; bagging_fraction=0.501 : y = 0.924 : 396.5 secs : infill_ei
#
# Thu Nov 20 09:47:07 PM 2025 AUC 0.928522872237981
#
# [mbo] 59: num_leaves=3899; min_child_weight=7.38; min_data_in_leaf=42; min_gain_to_split=0.0564; lambda_l1=0.241; lambda_l2=80.8; scale_pos_weight=1.56; learning_rate=0.0284; num_iterations=4960; early_stopping_rounds=170; feature_fraction=0.177; bagging_fraction=0.636 : y = 0.929 : 670.8 secs : infill_ei
#
# Saved the current state after iteration 60 in the file HT.RDATA.
#
# Thu Nov 20 09:50:30 PM 2025 AUC 0.932479470449325
#
# [mbo] 60: num_leaves=5892; min_child_weight=7.86; min_data_in_leaf=18; min_gain_to_split=0.0743; lambda_l1=0.363; lambda_l2=22.5; scale_pos_weight=2.51; learning_rate=0.046; num_iterations=2980; early_stopping_rounds=84; feature_fraction=0.399; bagging_fraction=0.599 : y = 0.932 : 197.6 secs : infill_ei
#
# Thu Nov 20 09:54:25 PM 2025 AUC 0.933074704949573
#
# [mbo] 61: num_leaves=7277; min_child_weight=7.68; min_data_in_leaf=308; min_gain_to_split=0.0798; lambda_l1=0.161; lambda_l2=3.08; scale_pos_weight=2.91; learning_rate=0.0396; num_iterations=2911; early_stopping_rounds=334; feature_fraction=0.296; bagging_fraction=0.943 : y = 0.933 : 229.9 secs : infill_ei
#
# Thu Nov 20 09:58:54 PM 2025 AUC 0.929866344018698
#
# [mbo] 62: num_leaves=1474; min_child_weight=6.39; min_data_in_leaf=70; min_gain_to_split=0.0437; lambda_l1=0.162; lambda_l2=174; scale_pos_weight=2.05; learning_rate=0.0843; num_iterations=1603; early_stopping_rounds=67; feature_fraction=0.296; bagging_fraction=0.796 : y = 0.93 : 265.8 secs : infill_ei
#
# Saved the current state after iteration 63 in the file HT.RDATA.
#
# Thu Nov 20 10:05:51 PM 2025 AUC 0.931424556543587
#
# [mbo] 63: num_leaves=6737; min_child_weight=6.98; min_data_in_leaf=930; min_gain_to_split=0.0773; lambda_l1=0.109; lambda_l2=143; scale_pos_weight=3.24; learning_rate=0.037; num_iterations=4871; early_stopping_rounds=99; feature_fraction=0.148; bagging_fraction=0.568 : y = 0.931 : 413.4 secs : infill_ei
#
# Thu Nov 20 10:08:15 PM 2025 AUC 0.934100763067813
#
# [mbo] 64: num_leaves=5020; min_child_weight=5.69; min_data_in_leaf=86; min_gain_to_split=0.0805; lambda_l1=0.339; lambda_l2=2.85; scale_pos_weight=2.81; learning_rate=0.0408; num_iterations=4156; early_stopping_rounds=90; feature_fraction=0.101; bagging_fraction=0.906 : y = 0.934 : 141.6 secs : infill_ei
#
# Thu Nov 20 10:11:32 PM 2025 AUC 0.922379609292637
#
# [mbo] 65: num_leaves=102; min_child_weight=8.81; min_data_in_leaf=178; min_gain_to_split=0.0932; lambda_l1=0.198; lambda_l2=123; scale_pos_weight=1.33; learning_rate=0.0466; num_iterations=2238; early_stopping_rounds=52; feature_fraction=0.831; bagging_fraction=0.635 : y = 0.922 : 193.0 secs : infill_ei
#
# Saved the current state after iteration 66 in the file HT.RDATA.
#
# Thu Nov 20 10:13:46 PM 2025 AUC 0.929990155479009
#
# [mbo] 66: num_leaves=4125; min_child_weight=4.77; min_data_in_leaf=19; min_gain_to_split=0.0275; lambda_l1=0.0393; lambda_l2=0.954; scale_pos_weight=2.62; learning_rate=0.0916; num_iterations=1904; early_stopping_rounds=275; feature_fraction=0.183; bagging_fraction=0.909 : y = 0.93 : 127.6 secs : infill_ei
#
# Thu Nov 20 10:16:56 PM 2025 AUC 0.93373167741377
#
# [mbo] 67: num_leaves=7974; min_child_weight=9.81; min_data_in_leaf=12; min_gain_to_split=0.0684; lambda_l1=0.201; lambda_l2=1.42; scale_pos_weight=3.37; learning_rate=0.0481; num_iterations=1355; early_stopping_rounds=456; feature_fraction=0.142; bagging_fraction=0.865 : y = 0.934 : 185.5 secs : infill_ei
#
# Thu Nov 20 10:20:18 PM 2025 AUC 0.928582261475041
#
# [mbo] 68: num_leaves=210; min_child_weight=3.34; min_data_in_leaf=66; min_gain_to_split=0.0367; lambda_l1=0.166; lambda_l2=63.5; scale_pos_weight=2.33; learning_rate=0.0956; num_iterations=4477; early_stopping_rounds=366; feature_fraction=0.266; bagging_fraction=0.823 : y = 0.929 : 196.1 secs : infill_ei
#
# Thu Nov 20 10:26:14 PM 2025 AUC 0.930626324933615
#
# [mbo] 69: num_leaves=7407; min_child_weight=8.98; min_data_in_leaf=65; min_gain_to_split=0.0851; lambda_l1=0.304; lambda_l2=89.9; scale_pos_weight=3.52; learning_rate=0.0506; num_iterations=1850; early_stopping_rounds=344; feature_fraction=0.13; bagging_fraction=0.661 : y = 0.931 : 351.8 secs : infill_ei
#
# Saved the current state after iteration 70 in the file HT.RDATA.
#
# Thu Nov 20 10:29:49 PM 2025 AUC 0.933923937486285
#
# [mbo] 70: num_leaves=5817; min_child_weight=6.54; min_data_in_leaf=433; min_gain_to_split=0.0945; lambda_l1=0.424; lambda_l2=4.97; scale_pos_weight=3.14; learning_rate=0.0388; num_iterations=4708; early_stopping_rounds=316; feature_fraction=0.111; bagging_fraction=0.848 : y = 0.934 : 211.3 secs : infill_ei
#
# Thu Nov 20 10:33:02 PM 2025 AUC 0.925886929603287
#
# [mbo] 71: num_leaves=2190; min_child_weight=0.91; min_data_in_leaf=16; min_gain_to_split=0.0189; lambda_l1=0.155; lambda_l2=175; scale_pos_weight=2.48; learning_rate=0.0676; num_iterations=4893; early_stopping_rounds=54; feature_fraction=0.441; bagging_fraction=0.932 : y = 0.926 : 188.5 secs : infill_ei
#
# Thu Nov 20 10:36:09 PM 2025 AUC 0.923120800392439
#
# [mbo] 72: num_leaves=251; min_child_weight=1.02; min_data_in_leaf=691; min_gain_to_split=0.0441; lambda_l1=0.0911; lambda_l2=420; scale_pos_weight=2.75; learning_rate=0.0984; num_iterations=4664; early_stopping_rounds=59; feature_fraction=0.724; bagging_fraction=0.527 : y = 0.923 : 182.8 secs : infill_ei
#
# Thu Nov 20 10:38:04 PM 2025 AUC 0.926328490258488
#
# [mbo] 73: num_leaves=5800; min_child_weight=7.52; min_data_in_leaf=57; min_gain_to_split=0.0833; lambda_l1=0.0732; lambda_l2=0.000383; scale_pos_weight=2.5; learning_rate=0.0394; num_iterations=335; early_stopping_rounds=51; feature_fraction=0.266; bagging_fraction=0.801 : y = 0.926 : 108.6 secs : infill_ei
#
# Saved the current state after iteration 74 in the file HT.RDATA.
#
# Thu Nov 20 10:48:09 PM 2025 AUC 0.931570177610727
#
# [mbo] 74: num_leaves=55; min_child_weight=9.2; min_data_in_leaf=50; min_gain_to_split=0.0329; lambda_l1=0.347; lambda_l2=160; scale_pos_weight=3.9; learning_rate=0.0438; num_iterations=1838; early_stopping_rounds=491; feature_fraction=0.422; bagging_fraction=0.888 : y = 0.932 : 600.4 secs : infill_ei
#
# Saved the current state after iteration 75 in the file HT.RDATA.
#
# Thu Nov 20 10:51:05 PM 2025 AUC 0.925522205870609
#
# [mbo] 75: num_leaves=224; min_child_weight=9.71; min_data_in_leaf=1741; min_gain_to_split=0.0592; lambda_l1=0.253; lambda_l2=677; scale_pos_weight=4.68; learning_rate=0.0951; num_iterations=717; early_stopping_rounds=425; feature_fraction=0.282; bagging_fraction=0.993 : y = 0.926 : 171.0 secs : infill_ei
#
# Thu Nov 20 10:55:04 PM 2025 AUC 0.933525996044744
#
# [mbo] 76: num_leaves=610; min_child_weight=9.66; min_data_in_leaf=6; min_gain_to_split=0.0731; lambda_l1=0.32; lambda_l2=13.4; scale_pos_weight=4.01; learning_rate=0.0293; num_iterations=4858; early_stopping_rounds=68; feature_fraction=0.294; bagging_fraction=0.813 : y = 0.934 : 235.5 secs : infill_ei
#
# Thu Nov 20 11:03:07 PM 2025 AUC 0.930111282680018
#
# [mbo] 77: num_leaves=202; min_child_weight=8.09; min_data_in_leaf=137; min_gain_to_split=0.034; lambda_l1=0.0128; lambda_l2=195; scale_pos_weight=4.43; learning_rate=0.0404; num_iterations=1484; early_stopping_rounds=236; feature_fraction=0.357; bagging_fraction=0.929 : y = 0.93 : 478.0 secs : infill_ei
#
# Saved the current state after iteration 78 in the file HT.RDATA.
#
# Thu Nov 20 11:04:42 PM 2025 AUC 0.927566940394009
#
# [mbo] 78: num_leaves=628; min_child_weight=9.67; min_data_in_leaf=17; min_gain_to_split=0.067; lambda_l1=0.247; lambda_l2=6.63; scale_pos_weight=2.3; learning_rate=0.0909; num_iterations=4210; early_stopping_rounds=64; feature_fraction=0.345; bagging_fraction=0.868 : y = 0.928 : 89.7 secs : infill_ei

# %% [markdown]
# la bayesian optimization ha corrido, extraigo los mejores hiperparametros

# %%
# almaceno los resultados de la Bayesian Optimization
# y capturo los mejores hiperparametros encontrados

tb_bayesiana <- as.data.table(bayesiana_salida$opt.path)

# ordeno en forma descendente por AUC = y
setorder(tb_bayesiana, -y, -num_iterations)

# grabo para eventualmente poder utilizarlos en OTRA corrida
fwrite( tb_bayesiana,
  file="BO_log.txt",
  sep="\t"
)

# los mejores hiperparámetros son los que quedaron en el registro 1 de la tabla
PARAM$out$lgbm$mejores_hiperparametros <- tb_bayesiana[
  1, # el primero es el de mejor AUC
  setdiff(colnames(tb_bayesiana),
    c("y","dob","eol","error.message","exec.time","ei","error.model",
      "train.time","prop.type","propose.time","se","mean","iter")),
  with= FALSE
]

print(PARAM$out$lgbm$mejores_hiperparametros)

# %% [markdown]
# ### 6.3.3 Produccion

# %% [markdown]
# #### Final Training
# Construyo el modelo final, que es uno solo, no hace ningun tipo de particion < training, validation, testing>]

# %% [markdown]
# ##### Final Training Dataset
#
# Aqui esta la gran decision de en qué meses hago el Final Training
# <br> debo utilizar los mejores hiperparámetros que encontré en la optimización bayesiana

# %%
PARAM$trainingstrategy$final_train <- c(
  202105, 202104, 202103, 202102, 202101,
  202012, 202011, 202010, 202009, 202008, 202007,
  202006, 202005
)

dataset[, fold_final_train := foto_mes %in% PARAM$trainingstrategy$final_train ]

# creo el dfinal_train en formato  LightGBM
dfinal_train <- lgb.Dataset(
  data= data.matrix(dataset[fold_final_train == TRUE, campos_buenos, with= FALSE]),
  label= dataset[fold_final_train == TRUE, clase01],
  free_raw_data= TRUE
)

nrow( dfinal_train) # verifico el tamaño

# %% [markdown]
# ##### Final Training Hyperparameters

# %%
# uno los parametros fijos y los mejores encontrados de los variables
fijos <- copy(PARAM$lgbm$param_fijos)

# quito lo que optimice en la Bayesian Optimization
fijos$num_iterations <- NULL
fijos$early_stopping_rounds <- NULL

# agrego a los hiperparametros fijos los que encontre con la Bayesian Optimization
param_final <- c(fijos, PARAM$out$lgbm$mejores_hiperparametros)

# Para el entrenamiento final, removemos early_stopping_rounds
# ya que se entrena con todos los datos disponibles y la cantidad de iteraciones
# ya está optimizada en 'num_iterations'.
param_final$early_stopping_rounds <- NULL

# %% [markdown]
# ##### Training
# Genero el modelo final, siempre sobre TODOS los datos de  final_train, sin hacer ningun tipo de undersampling de la clase mayoritaria

# %%
final_model <- lgb.train(
  data= dfinal_train,
  param= param_final,
  verbose= -100
)

# %%
# grabo a disco el modelo en un formato para seres humanos ... ponele ...

lgb.save(final_model, "modelo.txt")

# %%
# ahora imprimo la importancia de variables

tb_importancia <- as.data.table(lgb.importance(final_model))
archivo_importancia <- "impo.txt"

fwrite( tb_importancia,
  file= archivo_importancia,
  sep= "\t"
)

# %% [markdown]
# #### Scoring

# %% [markdown]
# Aplico el modelo final a los datos del futuro

# %%
PARAM$trainingstrategy$future <- c(202107)

dfuture <- dataset[ foto_mes %in% PARAM$trainingstrategy$future ]

# %%
# aplico final_model   a dfuture

prediccion <- predict(
  final_model,
  data.matrix(dfuture[, campos_buenos, with= FALSE])
)

# %% [markdown]
# ##### Tabla Prediccion

# %%
tb_prediccion <- dfuture[, list(numero_de_cliente)]
tb_prediccion[, prob := prediccion]

# grabo las probabilidad del modelo
#  me va a ser util para hacer Ensembles de modelos
fwrite(tb_prediccion,
  file= "prediccion.txt",
  sep= "\t"
)

# %% [markdown]
# #### Curva de Ganancia

# %% [markdown]
# Genero las salidas

# %%
# asigno clase ternaria
tb_prediccion[, clase_ternaria := dfuture$clase_ternaria ]

# asigno ganancias
tb_prediccion[, ganancia := -3000.0 ]
tb_prediccion[clase_ternaria=="BAJA+2", ganancia := 117000.0 ]

# reordeno, y acumulada
setorder( tb_prediccion, -prob )
tb_prediccion[, gan_acum := cumsum(ganancia)]

# media movil de ancho 400
tb_prediccion[,
  gan_suavizada := frollmean(
    x= gan_acum,
    n= 400,
    align= "center",
    na.rm= TRUE,
    hasNA= TRUE
  )
]

# %%
tb_prediccion[, sum(!is.na(gan_suavizada) )]
tb_prediccion[, .N]

# %%
# Este es la ganancia a reportar
resultado <- list()
resultado$ganancia_suavizada_max <- max( tb_prediccion$gan_suavizada, na.rm=TRUE )
options(digits= 8)
resultado$envios <- which.max( tb_prediccion$gan_suavizada)
resultado

# %%
# grabo las ganancias
fwrite( tb_prediccion,
  file= "ganancias.txt",
  sep= "\t"
)

# %%
# genero el grafico

tb_prediccion[, envios:= .I]

pdf("curva_de_ganancia.pdf")

plot(
  x= tb_prediccion$envios,
  y= tb_prediccion$gan_acum,
  type= "l",
  col= "gray",
  xlim= c(0, 6000),
  ylim= c(0, 8000000),
  main= paste0("Mejor gan prom= ", as.integer(resultado$ganancia_suavizada_max), " envios= ", resultado$envios),
  xlab= "Envios",
  ylab= "Ganancia",
  panel.first= grid()
)

dev.off()

# %%
# grabo los parametros
if( !require("yaml")) install.packages("yaml")
require("yaml")

PARAM$resultado <- resultado

write_yaml( PARAM, file="PARAM.yml")

# %%
format(Sys.time(), "%a %b %d %X %Y")
fin <- Sys.time()

# Duración en segundos
secs <- as.numeric(difftime(fin, principio, units = "secs"))
secs <- round(secs)

# A hh:mm:ss
h <- secs %/% 3600
m <- (secs %% 3600) %/% 60
s <- secs %% 60
dur_hms <- sprintf("%02d:%02d:%02d", h, m, s)

cat(
  "Inicio: ", format(principio, "%a %b %d %X %Y"), "\n",
  "Fin:    ", format(fin,       "%a %b %d %X %Y"), "\n",
  "Duración (hh:mm:ss): ", dur_hms, "\n",
  sep = ""
)
