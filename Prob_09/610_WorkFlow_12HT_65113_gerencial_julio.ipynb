# %% [markdown]
# <a href="https://colab.research.google.com/github/jwbarbona/labo2025v/blob/main/610_WorkFlow_12HT_65113_gerencial_julio.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # 6 WorkFlow  Gerencial, futuro=JULIO

# %% [markdown]
# ### 6.1 Objetivo

# %% [markdown]
# Presentar un workflow/pipeline completo al que los estudiantes deberán enriquecer

# %% [markdown]
# #### 6.2  Seteo del ambiente en Google Colab

# %% [markdown]
# Esta parte se debe correr con el runtime en Python3
# <br>Ir al menu, Runtime -> Change Runtime Type -> Runtime type ->  **Python 3**

# %% [markdown]
# Conectar la virtual machine donde esta corriendo Google Colab con el  Google Drive, para poder tener persistencia de archivos

# %%
# primero establecer el Runtime de Python 3
from google.colab import drive
drive.mount('/content/.drive')
# Out:
# Mounted at /content/.drive

# %% [markdown]
# Para correr la siguiente celda es fundamental en Arranque en Frio haber copiado el archivo kaggle.json al Google Drive, en la carpeta indicada en el instructivo
#
# <br>los siguientes comando estan en shell script de Linux
# *   Crear las carpetas en el Google Drive
# *   "instalar" el archivo kaggle.json desde el Google Drive a la virtual machine para que pueda ser utilizado por la libreria  kaggle de Python
# *   Bajar el  **dataset_pequeno**  al  Google Drive  y tambien al disco local de la virtual machine que esta corriendo Google Colab
# *   Bajar el **dataset_historico** al Google Drive y tambien al disco local de la virtual machine que esta corriendo Google Colab

# %%
%%shell

mkdir -p "/content/.drive/My Drive/labo1"
mkdir -p "/content/buckets"
ln -s "/content/.drive/My Drive/labo1" /content/buckets/b1

mkdir -p ~/.kaggle
cp /content/buckets/b1/kaggle/kaggle.json  ~/.kaggle
chmod 600 ~/.kaggle/kaggle.json


mkdir -p /content/buckets/b1/exp
mkdir -p /content/buckets/b1/datasets
mkdir -p /content/datasets


webfiles="https://storage.googleapis.com/open-courses/austral2025-af91/"
destino_local="/content/datasets"
destino_bucket="/content/buckets/b1/datasets"


archivo="dataset_pequeno.csv"

if ! test -f $destino_bucket/$archivo; then
  wget  $webfiles/$archivo  -O $destino_bucket/$archivo
fi


if ! test -f $destino_local/$pequeno; then
  cp  $destino_bucket/$archivo  $destino_local/$archivo
fi

#-------

archivo="gerencial_competencia_2025.csv.gz"

if ! test -f $destino_bucket/$archivo; then
  wget  $webfiles/$archivo  -O $destino_bucket/$archivo
fi


if ! test -f $destino_local/$pequeno; then
  cp  $destino_bucket/$archivo  $destino_local/$archivo
fi
# Out:
# cp: cannot stat '/content/buckets/b1/kaggle/kaggle.json': No such file or directory
# chmod: cannot access '/root/.kaggle/kaggle.json': No such file or directory

# %% [markdown]
# ## 6.3  Workflow

# %% [markdown]
# ## Inicializacion

# %% [markdown]
# Esta parte se debe correr con el runtime en lenguaje **R** Ir al menu, Runtime -> Change Runtime Type -> Runtime type -> R

# %% [markdown]
# limpio el ambiente de R

# %%
format(Sys.time(), "%a %b %d %X %Y")
# Out:
# [1] "Thu Nov 20 12:58:17 AM 2025"

# %%
# limpio la memoria
rm(list=ls(all.names=TRUE)) # remove all objects
gc(full=TRUE, verbose=FALSE) # garbage collection
# Out:
#        used    (Mb) gc trigger (Mb) max used (Mb)
# Ncells  660442 35.3 1454497    77.7 1437475  76.8
# Vcells 1226661  9.4 8388608    64.0 1975136  15.1

# %%
principio <- Sys.time()

# %%
require("data.table")

if( !require("R.utils")) install.packages("R.utils")
require("R.utils")
# Out:
# Loading required package: data.table
#
# Loading required package: R.utils
#
# Warning message in library(package, lib.loc = lib.loc, character.only = TRUE, logical.return = TRUE, :
# “there is no package called ‘R.utils’”
# Installing package into ‘/usr/local/lib/R/site-library’
# (as ‘lib’ is unspecified)
#
# also installing the dependencies ‘R.oo’, ‘R.methodsS3’
#
#
# Loading required package: R.utils
#
# Loading required package: R.oo
#
# Loading required package: R.methodsS3
#
# R.methodsS3 v1.8.2 (2022-06-13 22:00:14 UTC) successfully loaded. See ?R.methodsS3 for help.
#
# R.oo v1.27.1 (2025-05-02 21:00:05 UTC) successfully loaded. See ?R.oo for help.
#
#
# Attaching package: ‘R.oo’
#
#
# The following object is masked from ‘package:R.methodsS3’:
#
#     throw
#
#
# The following objects are masked from ‘package:methods’:
#
#     getClasses, getMethods
#
#
# The following objects are masked from ‘package:base’:
#
#     attach, detach, load, save
#
#
# R.utils v2.13.0 (2025-02-24 21:20:02 UTC) successfully loaded. See ?R.utils for help.
#
#
# Attaching package: ‘R.utils’
#
#
# The following object is masked from ‘package:utils’:
#
#     timestamp
#
#
# The following objects are masked from ‘package:base’:
#
#     cat, commandArgs, getOption, isOpen, nullfile, parse, use, warnings

# %% [markdown]
# #### Parametros
# Si es gerente, no cambie nada
# <br>Si es Analista, cambie el nombre del dataset

# %%
PARAM <- list()
PARAM$semilla_primigenia <- 499999 # 100009, 200003, 499999, 700009, 999983

PARAM$experimento <- 65113 # 12HT
PARAM$dataset <- "gerencial_competencia_2025.csv.gz"

# %% [markdown]
# #### Carpeta del Experimento

# %%
# carpeta de trabajo

setwd("/content/buckets/b1/exp")
experimento_folder <- paste0("WF", PARAM$experimento)
dir.create(experimento_folder, showWarnings=FALSE)
setwd( paste0("/content/buckets/b1/exp/", experimento_folder ))

# %% [markdown]
# ### 6.3.1   Preprocesamiento del dataset

# %% [markdown]
# #### 6.3.1.1  DT incorporar dataset

# %%
# lectura del dataset
dataset <- fread(paste0("/content/datasets/", PARAM$dataset))

# %% [markdown]
# #### 6.3.1.2  CA  Catastrophe Analysis
# Se intentan reparar las variables que para un mes están con todos los valores en cero.

# %% [markdown]
# El método que se utiliza es **Machine Learning** se asigna NA also valores, si ha leido bien, es la "anti imputación de valores faltantes"
# <br> Usted podrá aplicar aquí otros métodos

# %%
dataset[ foto_mes==202006, internet:=NA]
dataset[ foto_mes==202006, mrentabilidad:=NA]
dataset[ foto_mes==202006, mrentabilidad_annual:=NA]
dataset[ foto_mes==202006, mcomisiones:=NA]
dataset[ foto_mes==202006, mactivos_margen:=NA]
dataset[ foto_mes==202006, mpasivos_margen:=NA]
dataset[ foto_mes==202006, mcuentas_saldo:=NA]
dataset[ foto_mes==202006, ctarjeta_visa_transacciones:=NA]
dataset[ foto_mes==202006, mtarjeta_visa_consumo:=NA]
dataset[ foto_mes==202006, mtarjeta_master_consumo:=NA]
dataset[ foto_mes==202006, ccallcenter_transacciones:=NA]
dataset[ foto_mes==202006, chomebanking_transacciones:=NA]
dataset[ foto_mes==202006, chomebanking_transacciones:=NA]

# %% [markdown]
# #### 6.3.1.3  DR  Data Drifting
# Se intenta corregir el data drifting, quizas ajustando por IPC ...
# <br>Esta parte podrá ser abordada por todos los Analistas y también la Gerenciapero se decide pedagogicamente no incluirla en esta primer version para reducir la carga cognitiva

# %%
# sin codigo en esta primera version del workflow

# %% [markdown]
# #### 6.3.1.3  FE_intra_manual Feature Engineering intra-mes
#
# Agrego campos nuevos dentro del mismo mes, SIN considerar la historia.

# %%
# esta funcion atributos presentes existe debido a que las modalidades poseen datasets con distinta cantidad de campos
atributos_presentes <- function( patributos )
{
  atributos <- unique( patributos )
  comun <- intersect( atributos, colnames(dataset) )

  return(  length( atributos ) == length( comun ) )
}

# el mes 1,2, ..12
if( atributos_presentes( c("foto_mes") ))
  dataset[, kmes := foto_mes %% 100]

# variable extraida de una tesis de maestria de Irlanda
if( atributos_presentes( c("mpayroll", "cliente_edad") ))
  dataset[, mpayroll_sobre_edad := mpayroll / cliente_edad]

# %%
# visualizo las columas del dataset a esta etapa
colnames(dataset)
# Out:
#  [1] "numero_de_cliente"           "foto_mes"
#  [3] "internet"                    "cliente_edad"
#  [5] "cliente_antiguedad"          "mrentabilidad"
#  [7] "mrentabilidad_annual"        "mcomisiones"
#  [9] "mactivos_margen"             "mpasivos_margen"
# [11] "cproductos"                  "mcuenta_corriente"
# [13] "mcaja_ahorro"                "cdescubierto_preacordado"
# [15] "mcuentas_saldo"              "ctarjeta_visa_transacciones"
# [17] "mtarjeta_visa_consumo"       "mtarjeta_master_consumo"
# [19] "mprestamos_personales"       "cpayroll_trx"
# [21] "mpayroll"                    "ccomisiones_mantenimiento"
# [23] "ccallcenter_transacciones"   "chomebanking_transacciones"
# [25] "ctrx_quarter"                "Master_status"
# [27] "Master_fechaalta"            "Master_mpagominimo"
# [29] "Visa_status"                 "Visa_fechaalta"
# [31] "Visa_mpagominimo"            "clase_ternaria"
# [33] "kmes"                        "mpayroll_sobre_edad"

# %% [markdown]
# #### 6.3.1.4  FE_rf Feature Engineering de nuevas variables a partir de hojas de Random Forest
#
# Esto se mostrará unicamente a la *modalidad Analista Sr*

# %%
# No se implementa Feature Engineering a partir de Random Forest

# %% [markdown]
# #### 6.3.1.5  FEhist Feature Engineering historico
#
# El Fature Engineering Histórico es la etapa que más aporta a la ganancia final, ya que enriquece cada registro del dataset con su historia.

# %% [markdown]
# Para cada campo del dataset original (*)
# se crean lo siguientes campos de a partir de la historia
# * lag1  lags de orden 1
# * delta1  =  valor actual - lag1
# * lag2  lags de orden 2
# * delta2  = valor actual - lag2
#
#
# (*) Excepto para los campos  <numero_de_cliente,  foto_mes,  clase_ternaria>

# %%
# Feature Engineering Historico

# todo es lagueable, menos la primary key y la clase
cols_lagueables <- copy( setdiff(
    colnames(dataset),
    c("numero_de_cliente", "foto_mes", "clase_ternaria")
) )

# https://rdrr.io/cran/data.table/man/shift.html

# lags de orden 1
dataset[,
    paste0(cols_lagueables, "_lag1") := shift(.SD, 1, NA, "lag"),
    by = numero_de_cliente,
    .SDcols = cols_lagueables
]

# lags de orden 2
dataset[,
    paste0(cols_lagueables, "_lag2") := shift(.SD, 2, NA, "lag"),
    by = numero_de_cliente,
    .SDcols = cols_lagueables
]

# agrego los delta lags
for (vcol in cols_lagueables)
{
    dataset[, paste0(vcol, "_delta1") := get(vcol) - get(paste0(vcol, "_lag1"))]
    dataset[, paste0(vcol, "_delta2") := get(vcol) - get(paste0(vcol, "_lag2"))]
}

# %% [markdown]
# Verificacion de los campos recien creados

# %%
ncol(dataset)
colnames(dataset)
# Out:
# [1] 158
#   [1] "numero_de_cliente"                  "foto_mes"
#   [3] "internet"                           "cliente_edad"
#   [5] "cliente_antiguedad"                 "mrentabilidad"
#   [7] "mrentabilidad_annual"               "mcomisiones"
#   [9] "mactivos_margen"                    "mpasivos_margen"
#  [11] "cproductos"                         "mcuenta_corriente"
#  [13] "mcaja_ahorro"                       "cdescubierto_preacordado"
#  [15] "mcuentas_saldo"                     "ctarjeta_visa_transacciones"
#  [17] "mtarjeta_visa_consumo"              "mtarjeta_master_consumo"
#  [19] "mprestamos_personales"              "cpayroll_trx"
#  [21] "mpayroll"                           "ccomisiones_mantenimiento"
#  [23] "ccallcenter_transacciones"          "chomebanking_transacciones"
#  [25] "ctrx_quarter"                       "Master_status"
#  [27] "Master_fechaalta"                   "Master_mpagominimo"
#  [29] "Visa_status"                        "Visa_fechaalta"
#  [31] "Visa_mpagominimo"                   "clase_ternaria"
#  [33] "kmes"                               "mpayroll_sobre_edad"
#  [35] "internet_lag1"                      "cliente_edad_lag1"
#  [37] "cliente_antiguedad_lag1"            "mrentabilidad_lag1"
#  [39] "mrentabilidad_annual_lag1"          "mcomisiones_lag1"
#  [41] "mactivos_margen_lag1"               "mpasivos_margen_lag1"
#  [43] "cproductos_lag1"                    "mcuenta_corriente_lag1"
#  [45] "mcaja_ahorro_lag1"                  "cdescubierto_preacordado_lag1"
#  [47] "mcuentas_saldo_lag1"                "ctarjeta_visa_transacciones_lag1"
#  [49] "mtarjeta_visa_consumo_lag1"         "mtarjeta_master_consumo_lag1"
#  [51] "mprestamos_personales_lag1"         "cpayroll_trx_lag1"
#  [53] "mpayroll_lag1"                      "ccomisiones_mantenimiento_lag1"
#  [55] "ccallcenter_transacciones_lag1"     "chomebanking_transacciones_lag1"
#  [57] "ctrx_quarter_lag1"                  "Master_status_lag1"
#  [59] "Master_fechaalta_lag1"              "Master_mpagominimo_lag1"
#  [61] "Visa_status_lag1"                   "Visa_fechaalta_lag1"
#  [63] "Visa_mpagominimo_lag1"              "kmes_lag1"
#  [65] "mpayroll_sobre_edad_lag1"           "internet_lag2"
#  [67] "cliente_edad_lag2"                  "cliente_antiguedad_lag2"
#  [69] "mrentabilidad_lag2"                 "mrentabilidad_annual_lag2"
#  [71] "mcomisiones_lag2"                   "mactivos_margen_lag2"
#  [73] "mpasivos_margen_lag2"               "cproductos_lag2"
#  [75] "mcuenta_corriente_lag2"             "mcaja_ahorro_lag2"
#  [77] "cdescubierto_preacordado_lag2"      "mcuentas_saldo_lag2"
#  [79] "ctarjeta_visa_transacciones_lag2"   "mtarjeta_visa_consumo_lag2"
#  [81] "mtarjeta_master_consumo_lag2"       "mprestamos_personales_lag2"
#  [83] "cpayroll_trx_lag2"                  "mpayroll_lag2"
#  [85] "ccomisiones_mantenimiento_lag2"     "ccallcenter_transacciones_lag2"
#  [87] "chomebanking_transacciones_lag2"    "ctrx_quarter_lag2"
#  [89] "Master_status_lag2"                 "Master_fechaalta_lag2"
#  [91] "Master_mpagominimo_lag2"            "Visa_status_lag2"
#  [93] "Visa_fechaalta_lag2"                "Visa_mpagominimo_lag2"
#  [95] "kmes_lag2"                          "mpayroll_sobre_edad_lag2"
#  [97] "internet_delta1"                    "internet_delta2"
#  [99] "cliente_edad_delta1"                "cliente_edad_delta2"
# [101] "cliente_antiguedad_delta1"          "cliente_antiguedad_delta2"
# [103] "mrentabilidad_delta1"               "mrentabilidad_delta2"
# [105] "mrentabilidad_annual_delta1"        "mrentabilidad_annual_delta2"
# [107] "mcomisiones_delta1"                 "mcomisiones_delta2"
# [109] "mactivos_margen_delta1"             "mactivos_margen_delta2"
# [111] "mpasivos_margen_delta1"             "mpasivos_margen_delta2"
# [113] "cproductos_delta1"                  "cproductos_delta2"
# [115] "mcuenta_corriente_delta1"           "mcuenta_corriente_delta2"
# [117] "mcaja_ahorro_delta1"                "mcaja_ahorro_delta2"
# [119] "cdescubierto_preacordado_delta1"    "cdescubierto_preacordado_delta2"
# [121] "mcuentas_saldo_delta1"              "mcuentas_saldo_delta2"
# [123] "ctarjeta_visa_transacciones_delta1" "ctarjeta_visa_transacciones_delta2"
# [125] "mtarjeta_visa_consumo_delta1"       "mtarjeta_visa_consumo_delta2"
# [127] "mtarjeta_master_consumo_delta1"     "mtarjeta_master_consumo_delta2"
# [129] "mprestamos_personales_delta1"       "mprestamos_personales_delta2"
# [131] "cpayroll_trx_delta1"                "cpayroll_trx_delta2"
# [133] "mpayroll_delta1"                    "mpayroll_delta2"
# [135] "ccomisiones_mantenimiento_delta1"   "ccomisiones_mantenimiento_delta2"
# [137] "ccallcenter_transacciones_delta1"   "ccallcenter_transacciones_delta2"
# [139] "chomebanking_transacciones_delta1"  "chomebanking_transacciones_delta2"
# [141] "ctrx_quarter_delta1"                "ctrx_quarter_delta2"
# [143] "Master_status_delta1"               "Master_status_delta2"
# [145] "Master_fechaalta_delta1"            "Master_fechaalta_delta2"
# [147] "Master_mpagominimo_delta1"          "Master_mpagominimo_delta2"
# [149] "Visa_status_delta1"                 "Visa_status_delta2"
# [151] "Visa_fechaalta_delta1"              "Visa_fechaalta_delta2"
# [153] "Visa_mpagominimo_delta1"            "Visa_mpagominimo_delta2"
# [155] "kmes_delta1"                        "kmes_delta2"
# [157] "mpayroll_sobre_edad_delta1"         "mpayroll_sobre_edad_delta2"

# %% [markdown]
# #### 6.3.1.6  FEhist Reduccion dimensionalidad con canaritos
#
# Esta etapa solo se mostrará a la *modalidad Anlista Sr* por algun canal secreto de forma de no confundir a los *Analista Jr*  nni distraer con detalles operativos a la estratégica *Modalidad Gerencial*

# %%
# No se implementa la reduccion de la dimensionalidad con canaritos

# %% [markdown]
# ### 6.3.2 Modelado

# %% [markdown]
# #### 6.3.2.1 Training Strategy
#
# Esta etapa de Workflow de  Training Strategy esta pensada para la *Modalidad Gerencial* que posee el dataset de [202005, 202109]
# <br> Si usted es un Analista, posee el periodo de [201901, 202109] y deberá experimentar en que meses le conviene experimentar
#
# <br> A la *Modalidad Gerencial* no se le complicada la vida con el undersampling de los continua, por eso PARAM$trainingstrategy$training_pct <- 1.0
# <br> Sin embargo, si usted es  *Analista SR* posee un dataset 50 veces ( filas x columnas) más grande que la *Modalidad Gerencial*  y por un tema de velocidad y experimentación más rápida puede llegar a necesitar activar el undersampling de la clase mayoritaria, a pesar de estar corriendo en Google Cloud.

# %% [markdown]
# Se hace una estrategia de entrenamiento muy sencilla, tomando todos los meses posibles, SIN eliminar nada x pandemia ni por ningun otro motivo
#
# * future = 202107  obviamente completo
#
# * final_train =  [ 202005, 202105 ]  SIN undersampling
#
# * training
#    * testing = NO HAY
#    * validation =  202105   completo, sin undersampling
#    * training = [ 202005, 202104 ]  donde se consideran el 100% de los CONTINUA

# %%
PARAM$trainingstrategy$validate <- c(202105)

PARAM$trainingstrategy$training <- c(
  202104, 202103, 202102, 202101,
  202012, 202011, 202010, 202009, 202008, 202007,
  202006, 202005
)

PARAM$trainingstrategy$training_pct <- 1.0


PARAM$trainingstrategy$positivos <- c( "BAJA+1", "BAJA+2")

# %%
# seteo la clase01   1={BAJA+1, BAJA+2}   0={CONTINUA}
dataset[, clase01 := ifelse( clase_ternaria %in% PARAM$trainingstrategy$positivos, 1, 0 )]

# %%
# los campos en los que se entrena
campos_buenos <- copy( setdiff(
    colnames(dataset), c("clase_ternaria","clase01","azar"))
)

# %%
# preparo para que se puede hacer undersampling de los CONTINUA
#  solamente por un tema de VELOCIDAD
set.seed(PARAM$semilla_primigenia, kind = "L'Ecuyer-CMRG")
dataset[, azar:=runif(nrow(dataset))]

# undersampling de los CONTINUA
dataset[, fold_train :=  foto_mes %in%  PARAM$trainingstrategy$training &
    (clase_ternaria %in% c("BAJA+1", "BAJA+2") |
     azar < PARAM$trainingstrategy$training_pct ) ]


if( !require("lightgbm")) install.packages("lightgbm")
require("lightgbm")

dtrain <- lgb.Dataset(
  data= data.matrix(dataset[fold_train == TRUE, campos_buenos, with = FALSE]),
  label= dataset[fold_train == TRUE, clase01],
  free_raw_data= TRUE
)
# Out:
# Loading required package: lightgbm
#
# Warning message in library(package, lib.loc = lib.loc, character.only = TRUE, logical.return = TRUE, :
# “there is no package called ‘lightgbm’”
# Installing package into ‘/usr/local/lib/R/site-library’
# (as ‘lib’ is unspecified)
#
# Loading required package: lightgbm

# %%
# datos de validation
dvalidate <- lgb.Dataset(
  data= data.matrix(dataset[foto_mes %in% PARAM$trainingstrategy$validate, campos_buenos, with = FALSE]),
  label= dataset[foto_mes %in% PARAM$trainingstrategy$validate, clase01],
  free_raw_data= TRUE
)

nrow(dvalidate)
# Out:
# [1] 16469

# %% [markdown]
# ####  6.3.2.2. Hyperparameter Tuning

# %% [markdown]
# * Clase binaria que se optimiza :  positivos = [ BAJA+1, BAJA+2 ]

# %% [markdown]
# * Metrica que se optimiza **AUC** Area Under Curve de la  ROC Curve
#
# es muy importante notar que intencionalmente  **NO** se está optimizando la funcion de ganancia del problema

# %% [markdown]
# * Cantidad de iteraciones inteligentes de la Optimizacion Bayesiana = **10**

# %% [markdown]
# * Parametros no default, fijos de LightGBM que no se optimizan
#   * max_bin = 31 , Alienigenas Ancestrales contruyeron las pirámides y dejaron a la humanidad en un jeroglifico  *max_bin=31*
#   * feature_fraction = 0.5  para poner algo que generalmente no falla
#   * learning_rate = 0.03  para que aprenda lento

# %% [markdown]
# * Parametros que se optimizan en la Bayesian Optimization
#   * num_leaves  [8, 256]
#   * min_data_in_leaf  [8, 8192]

# %%
# paquetes necesarios para la Bayesian Optimization
if(!require("DiceKriging")) install.packages("DiceKriging")
require("DiceKriging")

if(!require("mlrMBO")) install.packages("mlrMBO")
require("mlrMBO")
# Out:
# Loading required package: DiceKriging
#
# Warning message in library(package, lib.loc = lib.loc, character.only = TRUE, logical.return = TRUE, :
# “there is no package called ‘DiceKriging’”
# Installing package into ‘/usr/local/lib/R/site-library’
# (as ‘lib’ is unspecified)
#
# Loading required package: DiceKriging
#
# Loading required package: mlrMBO
#
# Warning message in library(package, lib.loc = lib.loc, character.only = TRUE, logical.return = TRUE, :
# “there is no package called ‘mlrMBO’”
# Installing package into ‘/usr/local/lib/R/site-library’
# (as ‘lib’ is unspecified)
#
# also installing the dependencies ‘XML’, ‘fastmatch’, ‘RcppArmadillo’, ‘mlr’, ‘ParamHelpers’, ‘smoof’, ‘BBmisc’, ‘checkmate’, ‘lhs’, ‘parallelMap’
#
#
# Loading required package: mlrMBO
#
# Loading required package: mlr
#
# Loading required package: ParamHelpers
#
#
# Attaching package: ‘ParamHelpers’
#
#
# The following object is masked from ‘package:R.utils’:
#
#     isVector
#
#
#
# Attaching package: ‘mlr’
#
#
# The following objects are masked from ‘package:R.utils’:
#
#     resample, setThreshold
#
#
# Loading required package: smoof
#
# Loading required package: checkmate
#
#
# Attaching package: ‘checkmate’
#
#
# The following object is masked from ‘package:DiceKriging’:
#
#     checkNames
#
#
# The following object is masked from ‘package:R.utils’:
#
#     asInt
#
#
#
# Attaching package: ‘smoof’
#
#
# The following objects are masked from ‘package:R.oo’:
#
#     getDescription, getName

# %% [markdown]
# Definición de la Bayesian Optimization
# <br> Si se desea optimizar un hiperparámetro que esta como fijo, debe QUITARSE de param_fijos y agregarse a PARAM$hipeparametertuning$hs

# %%
# valor ridiculamente bajo para que corra rapido en el aula y no molestar a la *Modalidad Gerencial*
PARAM$hipeparametertuning$num_interations <- 100

# parametros fijos del LightGBM
PARAM$lgbm$param_fijos <- list(
  objective= "binary",
  metric= "auc",
  first_metric_only= TRUE,
  boost_from_average= TRUE,
  feature_pre_filter= FALSE,
  verbosity= -100,
  force_row_wise= TRUE, # para evitar warning
  max_bin= 31,
  seed= PARAM$semilla_primigenia
  # learning_rate= 0.03,
  # feature_fraction= 0.5,
  # num_iterations= 2048,  # valor grande, lo limita early_stopping_rounds
  # early_stopping_rounds= 200
)


PARAM$hipeparametertuning$hs <- makeParamSet(
  # Núcleo del modelo (estructura de árboles)
  makeIntegerParam("num_leaves", lower = 2L, upper = 8192L),
  #makeIntegerParam("max_depth", lower = 3L, upper = 30L),
  makeNumericParam("min_child_weight", lower = 0.001, upper = 10.0),
  makeIntegerParam("min_data_in_leaf", lower = 2L, upper = 8192L),
  makeNumericParam("min_gain_to_split", lower = 0.0, upper = 0.1),

  # Regularización
  makeNumericParam("lambda_l1", lower = 0.0, upper = 1000L),
  makeNumericParam("lambda_l2", lower = 0.0, upper = 1000L),
  makeNumericParam("scale_pos_weight", lower = 1.0, upper = 5.0),  # útil en desequilibrio

  # Control del aprendizaje
  makeNumericParam("learning_rate", lower = 0.005, upper = 0.1),
  makeIntegerParam("num_iterations", lower = 100L, upper = 5000L),
  makeIntegerParam("early_stopping_rounds", lower = 50L, upper = 500L),

  # Submuestreo
  makeNumericParam("feature_fraction", lower = 0.05, upper = 1L),   # columnas
  makeNumericParam("bagging_fraction", lower = 0.5, upper = 1L)   # filas
  #makeIntegerParam("bagging_freq", lower = 0L, upper = 5L),         # cada N iteraciones

  # Opcionales útiles
  #makeNumericParam("max_delta_step", lower = 0.0, upper = 10.0),
  #makeNumericParam("path_smooth", lower = 0.0, upper = 10.0)
)
# Total: 12 hT

# %% [markdown]
# Función "señora caja negra"  que es llamada para verificar la realidad por la Bayesian Optimization

# %%
# En  x llegan los parmaetros de la bayesiana
#  devuelve la AUC en validate del modelo entrenado
#  en el parametro x llegan los hiperparámetros que se estan optimizando

EstimarGanancia_AUC_lightgbm <- function(x) {

  # x pisa (o agrega) a param_fijos
  param_completo <- modifyList(PARAM$lgbm$param_fijos, x)

  # entreno LightGBM
  modelo_train <- lgb.train(
    data= dtrain,
    valids= list(valid = dvalidate),
    eval= "auc",
    param= param_completo,
    verbose= -100
  )

  # recupero la AUC en validation
  AUC <- modelo_train$record_evals$valid$auc$eval[[modelo_train$best_iter]]

  # esta es la forma de devolver un parametro extra
  attr(AUC, "extras") <- list("num_iterations"= modelo_train$best_iter)

  # hago espacio en la memoria
  rm(modelo_train)
  gc(full= TRUE, verbose= FALSE)

  message(format(Sys.time(), "%a %b %d %X %Y"), " AUC ", AUC)

  return(AUC)
}

# %% [markdown]
# seteo de la Bayesian Optimization (complejo)
# <br> copiado y pegado de la documentación de la librería

# %%
configureMlr(show.learner.output = FALSE)

# configuro la busqueda bayesiana,  los hiperparametros que se van a optimizar
# por favor, no desesperarse por lo complejo
obj.fun <- makeSingleObjectiveFunction(
    fn= EstimarGanancia_AUC_lightgbm, # la funcion que voy a maximizar
    minimize= FALSE, # estoy Maximizando AUC
    noisy= FALSE,
    par.set= PARAM$hipeparametertuning$hs,
    has.simple.signature= FALSE # paso los parametros en una lista
)

# cada 600 segundos guardo el resultado intermedio
ctrl <- makeMBOControl(
    save.on.disk.at.time= 600,
    save.file.path= "HT.RDATA"
)

# indico la cantidad de iteraciones que va a tener la Bayesian Optimization
ctrl <- setMBOControlTermination(
    ctrl,
    iters= PARAM$hipeparametertuning$num_interations  # cantidad de iteraciones inteligentes
)

# defino el método estandar para la creacion de los puntos iniciales
#   los "No Inteligentes"
ctrl <- setMBOControlInfill(ctrl, crit = makeMBOInfillCritEI())

# mas configuraciones
surr.km <- makeLearner(
    "regr.km",
    predict.type= "se",
    covtype= "matern3_2",
    control= list(trace = TRUE)
)

# %% [markdown]
# Corrida de la Bayesian Optimization,  aqui se hace el trabajo pesado
# <br> por favor no se asuste con los warnings que pudieran aparecer
#
# Si corrío a medias y llegó a las iteraciones inteligentes, en el archivo binario HT.RDATA quedó lo ya procesado y es utilizado para retomar la corrida desde lo último que llegó a grabar.

# %%
# inicio la optimizacion bayesiana

if (!file.exists("HT.RDATA")) {
  bayesiana_salida <- mbo(obj.fun, learner= surr.km, control= ctrl)
} else {
  bayesiana_salida <- mboContinue("HT.RDATA") # retomo en caso que ya exista
}
# Out:
# Computing y column(s) for design. Not provided.
#
# Thu Nov 20 01:12:22 AM 2025 AUC 0.870617359507546
#
# Thu Nov 20 01:13:04 AM 2025 AUC 0.893090313917415
#
# Thu Nov 20 01:13:29 AM 2025 AUC 0.888432788495801
#
# Thu Nov 20 01:14:14 AM 2025 AUC 0.892373281151333
#
# Thu Nov 20 01:16:03 AM 2025 AUC 0.900103612409062
#
# Thu Nov 20 01:17:00 AM 2025 AUC 0.885049111879257
#
# Thu Nov 20 01:17:50 AM 2025 AUC 0.889587523294338
#
# Thu Nov 20 01:19:36 AM 2025 AUC 0.912107284475788
#
# Thu Nov 20 01:19:55 AM 2025 AUC 0.879351100445654
#
# Thu Nov 20 01:20:57 AM 2025 AUC 0.899770260956979
#
# Thu Nov 20 01:21:46 AM 2025 AUC 0.893519963171962
#
# Thu Nov 20 01:22:02 AM 2025 AUC 0.882737125789088
#
# Thu Nov 20 01:22:14 AM 2025 AUC 0.896201370448587
#
# Thu Nov 20 01:22:35 AM 2025 AUC 0.880248314117392
#
# Thu Nov 20 01:23:27 AM 2025 AUC 0.897042046908773
#
# Thu Nov 20 01:23:55 AM 2025 AUC 0.903922810097378
#
# Thu Nov 20 01:24:33 AM 2025 AUC 0.905476492934694
#
# Thu Nov 20 01:25:30 AM 2025 AUC 0.907613834404017
#
# Thu Nov 20 01:30:43 AM 2025 AUC 0.915601183489926
#
# Thu Nov 20 01:30:49 AM 2025 AUC 0.893246168723145
#
# Thu Nov 20 01:31:23 AM 2025 AUC 0.893304551362966
#
# Thu Nov 20 01:31:41 AM 2025 AUC 0.886829614627603
#
# Thu Nov 20 01:33:28 AM 2025 AUC 0.913160520719462
#
# Thu Nov 20 01:34:25 AM 2025 AUC 0.881409424031771
#
# Thu Nov 20 01:34:53 AM 2025 AUC 0.893049378963057
#
# Thu Nov 20 01:35:56 AM 2025 AUC 0.912358933785363
#
# Thu Nov 20 01:40:04 AM 2025 AUC 0.910899032257415
#
# Thu Nov 20 01:40:54 AM 2025 AUC 0.756058373244914
#
# Thu Nov 20 01:41:14 AM 2025 AUC 0.880103531881283
#
# Thu Nov 20 01:41:24 AM 2025 AUC 0.876984925870824
#
# Thu Nov 20 01:41:52 AM 2025 AUC 0.888313506723063
#
# Thu Nov 20 01:42:19 AM 2025 AUC 0.893904483316993
#
# Thu Nov 20 01:42:52 AM 2025 AUC 0.864953572380045
#
# Thu Nov 20 01:48:46 AM 2025 AUC 0.916233997620404
#
# Thu Nov 20 01:48:59 AM 2025 AUC 0.892828263103044
#
# Thu Nov 20 01:49:24 AM 2025 AUC 0.883424463936641
#
# Thu Nov 20 01:49:58 AM 2025 AUC 0.899774958410757
#
# Thu Nov 20 01:50:20 AM 2025 AUC 0.903784235210906
#
# Thu Nov 20 01:50:28 AM 2025 AUC 0.868976438242911
#
# Thu Nov 20 01:51:04 AM 2025 AUC 0.896154899209418
#
# Thu Nov 20 01:51:51 AM 2025 AUC 0.895084718578899
#
# Thu Nov 20 01:52:20 AM 2025 AUC 0.885854054137484
#
# Thu Nov 20 01:54:20 AM 2025 AUC 0.910222598913278
#
# Thu Nov 20 01:54:53 AM 2025 AUC 0.901967662728187
#
# Thu Nov 20 01:55:05 AM 2025 AUC 0.861095117399436
#
# Thu Nov 20 01:55:39 AM 2025 AUC 0.865780324245102
#
# Thu Nov 20 01:56:16 AM 2025 AUC 0.914967027229797
#
# Thu Nov 20 01:58:02 AM 2025 AUC 0.896931992277386
#
# [mbo] 0: num_leaves=3205; min_child_weight=5.32; min_data_in_leaf=4974; min_gain_to_split=0.0299; lambda_l1=707; lambda_l2=675; scale_pos_weight=2.17; learning_rate=0.0527; num_iterations=4290; early_stopping_rounds=296; feature_fraction=0.575; bagging_fraction=0.765 : y = 0.871 : 56.3 secs : initdesign
#
# [mbo] 0: num_leaves=3585; min_child_weight=4.63; min_data_in_leaf=6811; min_gain_to_split=0.0335; lambda_l1=457; lambda_l2=454; scale_pos_weight=2.99; learning_rate=0.0465; num_iterations=3186; early_stopping_rounds=309; feature_fraction=0.607; bagging_fraction=0.759 : y = 0.893 : 41.2 secs : initdesign
#
# [mbo] 0: num_leaves=2569; min_child_weight=1.49; min_data_in_leaf=5964; min_gain_to_split=0.0474; lambda_l1=294; lambda_l2=713; scale_pos_weight=1.51; learning_rate=0.0695; num_iterations=641; early_stopping_rounds=222; feature_fraction=0.308; bagging_fraction=0.745 : y = 0.888 : 25.2 secs : initdesign
#
# [mbo] 0: num_leaves=5502; min_child_weight=1.83; min_data_in_leaf=3095; min_gain_to_split=0.0856; lambda_l1=540; lambda_l2=395; scale_pos_weight=3.51; learning_rate=0.0728; num_iterations=2954; early_stopping_rounds=246; feature_fraction=0.55; bagging_fraction=0.732 : y = 0.892 : 45.4 secs : initdesign
#
# [mbo] 0: num_leaves=4838; min_child_weight=2.92; min_data_in_leaf=7340; min_gain_to_split=0.0553; lambda_l1=434; lambda_l2=410; scale_pos_weight=4.38; learning_rate=0.0218; num_iterations=2082; early_stopping_rounds=388; feature_fraction=0.424; bagging_fraction=0.544 : y = 0.9 : 108.7 secs : initdesign
#
# [mbo] 0: num_leaves=222; min_child_weight=9.15; min_data_in_leaf=3848; min_gain_to_split=0.0566; lambda_l1=495; lambda_l2=535; scale_pos_weight=1.92; learning_rate=0.0713; num_iterations=1689; early_stopping_rounds=396; feature_fraction=0.463; bagging_fraction=0.672 : y = 0.885 : 56.9 secs : initdesign
#
# [mbo] 0: num_leaves=7323; min_child_weight=2.85; min_data_in_leaf=2941; min_gain_to_split=0.0372; lambda_l1=875; lambda_l2=293; scale_pos_weight=3.7; learning_rate=0.0546; num_iterations=3003; early_stopping_rounds=361; feature_fraction=0.48; bagging_fraction=0.963 : y = 0.89 : 50.2 secs : initdesign
#
# [mbo] 0: num_leaves=2033; min_child_weight=7.79; min_data_in_leaf=3703; min_gain_to_split=0.0957; lambda_l1=178; lambda_l2=915; scale_pos_weight=3.98; learning_rate=0.0479; num_iterations=3605; early_stopping_rounds=372; feature_fraction=0.365; bagging_fraction=0.71 : y = 0.912 : 105.5 secs : initdesign
#
# [mbo] 0: num_leaves=7959; min_child_weight=4.97; min_data_in_leaf=5797; min_gain_to_split=0.0509; lambda_l1=787; lambda_l2=768; scale_pos_weight=3.18; learning_rate=0.00911; num_iterations=2580; early_stopping_rounds=111; feature_fraction=0.632; bagging_fraction=0.845 : y = 0.879 : 19.2 secs : initdesign
#
# [mbo] 0: num_leaves=6533; min_child_weight=4.38; min_data_in_leaf=1026; min_gain_to_split=0.0399; lambda_l1=343; lambda_l2=730; scale_pos_weight=4.07; learning_rate=0.0284; num_iterations=852; early_stopping_rounds=356; feature_fraction=0.0865; bagging_fraction=0.884 : y = 0.9 : 62.8 secs : initdesign
#
# [mbo] 0: num_leaves=2864; min_child_weight=6.72; min_data_in_leaf=6411; min_gain_to_split=0.0164; lambda_l1=559; lambda_l2=203; scale_pos_weight=3.35; learning_rate=0.0348; num_iterations=2242; early_stopping_rounds=232; feature_fraction=0.391; bagging_fraction=0.869 : y = 0.894 : 48.7 secs : initdesign
#
# [mbo] 0: num_leaves=3818; min_child_weight=1.1; min_data_in_leaf=2288; min_gain_to_split=0.0442; lambda_l1=744; lambda_l2=798; scale_pos_weight=3.46; learning_rate=0.0589; num_iterations=3856; early_stopping_rounds=176; feature_fraction=0.769; bagging_fraction=0.62 : y = 0.883 : 16.1 secs : initdesign
#
# [mbo] 0: num_leaves=7356; min_child_weight=3.53; min_data_in_leaf=2858; min_gain_to_split=0.0321; lambda_l1=751; lambda_l2=2.5; scale_pos_weight=3.88; learning_rate=0.0617; num_iterations=3943; early_stopping_rounds=144; feature_fraction=0.912; bagging_fraction=0.692 : y = 0.896 : 11.6 secs : initdesign
#
# [mbo] 0: num_leaves=3647; min_child_weight=2.61; min_data_in_leaf=8060; min_gain_to_split=0.066; lambda_l1=640; lambda_l2=511; scale_pos_weight=2.09; learning_rate=0.0651; num_iterations=1817; early_stopping_rounds=313; feature_fraction=0.804; bagging_fraction=0.903 : y = 0.88 : 21.5 secs : initdesign
#
# [mbo] 0: num_leaves=4388; min_child_weight=8.79; min_data_in_leaf=4438; min_gain_to_split=0.039; lambda_l1=722; lambda_l2=843; scale_pos_weight=4.08; learning_rate=0.0784; num_iterations=2014; early_stopping_rounds=444; feature_fraction=0.384; bagging_fraction=0.566 : y = 0.897 : 51.5 secs : initdesign
#
# [mbo] 0: num_leaves=5782; min_child_weight=0.899; min_data_in_leaf=1933; min_gain_to_split=0.06; lambda_l1=126; lambda_l2=156; scale_pos_weight=1.45; learning_rate=0.037; num_iterations=2549; early_stopping_rounds=90; feature_fraction=0.718; bagging_fraction=0.829 : y = 0.904 : 28.1 secs : initdesign
#
# [mbo] 0: num_leaves=2245; min_child_weight=5.43; min_data_in_leaf=2592; min_gain_to_split=0.067; lambda_l1=237; lambda_l2=959; scale_pos_weight=4.99; learning_rate=0.0768; num_iterations=4880; early_stopping_rounds=325; feature_fraction=0.655; bagging_fraction=0.995 : y = 0.905 : 38.2 secs : initdesign
#
# [mbo] 0: num_leaves=5120; min_child_weight=8.04; min_data_in_leaf=4267; min_gain_to_split=0.0828; lambda_l1=191; lambda_l2=284; scale_pos_weight=3.58; learning_rate=0.0641; num_iterations=2426; early_stopping_rounds=260; feature_fraction=0.241; bagging_fraction=0.94 : y = 0.908 : 56.9 secs : initdesign
#
# [mbo] 0: num_leaves=3951; min_child_weight=8.48; min_data_in_leaf=7154; min_gain_to_split=0.0252; lambda_l1=14; lambda_l2=774; scale_pos_weight=1.59; learning_rate=0.033; num_iterations=2662; early_stopping_rounds=205; feature_fraction=0.295; bagging_fraction=0.653 : y = 0.916 : 312.5 secs : initdesign
#
# [mbo] 0: num_leaves=1405; min_child_weight=6.29; min_data_in_leaf=1327; min_gain_to_split=0.0625; lambda_l1=814; lambda_l2=588; scale_pos_weight=3.16; learning_rate=0.0815; num_iterations=3070; early_stopping_rounds=52; feature_fraction=0.158; bagging_fraction=0.611 : y = 0.893 : 6.2 secs : initdesign
#
# [mbo] 0: num_leaves=979; min_child_weight=1.34; min_data_in_leaf=1871; min_gain_to_split=0.0723; lambda_l1=609; lambda_l2=333; scale_pos_weight=2.42; learning_rate=0.0134; num_iterations=1928; early_stopping_rounds=181; feature_fraction=0.169; bagging_fraction=0.518 : y = 0.893 : 34.5 secs : initdesign
#
# [mbo] 0: num_leaves=4704; min_child_weight=9.54; min_data_in_leaf=2454; min_gain_to_split=0.0996; lambda_l1=283; lambda_l2=116; scale_pos_weight=1.32; learning_rate=0.0826; num_iterations=3986; early_stopping_rounds=159; feature_fraction=0.254; bagging_fraction=0.557 : y = 0.887 : 17.4 secs : initdesign
#
# [mbo] 0: num_leaves=6210; min_child_weight=7.27; min_data_in_leaf=4516; min_gain_to_split=0.0134; lambda_l1=42.2; lambda_l2=572; scale_pos_weight=2.31; learning_rate=0.0516; num_iterations=1431; early_stopping_rounds=102; feature_fraction=0.681; bagging_fraction=0.973 : y = 0.913 : 106.9 secs : initdesign
#
# [mbo] 0: num_leaves=392; min_child_weight=0.0647; min_data_in_leaf=5357; min_gain_to_split=0.00549; lambda_l1=843; lambda_l2=866; scale_pos_weight=2.85; learning_rate=0.0154; num_iterations=1363; early_stopping_rounds=445; feature_fraction=0.7; bagging_fraction=0.634 : y = 0.881 : 57.1 secs : initdesign
#
# [mbo] 0: num_leaves=2109; min_child_weight=6.61; min_data_in_leaf=3322; min_gain_to_split=0.0223; lambda_l1=330; lambda_l2=650; scale_pos_weight=2.67; learning_rate=0.00667; num_iterations=4673; early_stopping_rounds=279; feature_fraction=0.202; bagging_fraction=0.957 : y = 0.893 : 28.6 secs : initdesign
#
# [mbo] 0: num_leaves=5930; min_child_weight=7.43; min_data_in_leaf=1485; min_gain_to_split=0.000428; lambda_l1=149; lambda_l2=239; scale_pos_weight=4.57; learning_rate=0.0994; num_iterations=3694; early_stopping_rounds=347; feature_fraction=0.488; bagging_fraction=0.706 : y = 0.912 : 62.4 secs : initdesign
#
# [mbo] 0: num_leaves=6441; min_child_weight=2.36; min_data_in_leaf=2133; min_gain_to_split=0.0705; lambda_l1=94.1; lambda_l2=259; scale_pos_weight=3.04; learning_rate=0.0249; num_iterations=4271; early_stopping_rounds=460; feature_fraction=0.0508; bagging_fraction=0.725 : y = 0.911 : 248.3 secs : initdesign
#
# [mbo] 0: num_leaves=6727; min_child_weight=2; min_data_in_leaf=4638; min_gain_to_split=0.0245; lambda_l1=869; lambda_l2=690; scale_pos_weight=1.02; learning_rate=0.0404; num_iterations=1161; early_stopping_rounds=492; feature_fraction=0.327; bagging_fraction=0.816 : y = 0.756 : 50.1 secs : initdesign
#
# [mbo] 0: num_leaves=549; min_child_weight=3.72; min_data_in_leaf=953; min_gain_to_split=0.0978; lambda_l1=599; lambda_l2=956; scale_pos_weight=2.52; learning_rate=0.0858; num_iterations=2774; early_stopping_rounds=337; feature_fraction=0.885; bagging_fraction=0.857 : y = 0.88 : 19.7 secs : initdesign
#
# [mbo] 0: num_leaves=8130; min_child_weight=6.18; min_data_in_leaf=7680; min_gain_to_split=0.0112; lambda_l1=931; lambda_l2=474; scale_pos_weight=3.31; learning_rate=0.0904; num_iterations=1103; early_stopping_rounds=117; feature_fraction=0.841; bagging_fraction=0.589 : y = 0.877 : 10.1 secs : initdesign
#
# [mbo] 0: num_leaves=5281; min_child_weight=3.81; min_data_in_leaf=6245; min_gain_to_split=0.0888; lambda_l1=671; lambda_l2=830; scale_pos_weight=2.63; learning_rate=0.0669; num_iterations=4432; early_stopping_rounds=191; feature_fraction=0.278; bagging_fraction=0.801 : y = 0.888 : 27.7 secs : initdesign
#
# [mbo] 0: num_leaves=3066; min_child_weight=3.19; min_data_in_leaf=6521; min_gain_to_split=0.0743; lambda_l1=979; lambda_l2=40.7; scale_pos_weight=4.8; learning_rate=0.0229; num_iterations=778; early_stopping_rounds=286; feature_fraction=0.852; bagging_fraction=0.537 : y = 0.894 : 27.0 secs : initdesign
#
# [mbo] 0: num_leaves=5440; min_child_weight=7.07; min_data_in_leaf=460; min_gain_to_split=0.0797; lambda_l1=941; lambda_l2=430; scale_pos_weight=1.71; learning_rate=0.0187; num_iterations=3555; early_stopping_rounds=417; feature_fraction=0.794; bagging_fraction=0.784 : y = 0.865 : 32.8 secs : initdesign
#
# [mbo] 0: num_leaves=6072; min_child_weight=7.51; min_data_in_leaf=549; min_gain_to_split=0.0628; lambda_l1=32.3; lambda_l2=937; scale_pos_weight=2.8; learning_rate=0.0315; num_iterations=2333; early_stopping_rounds=167; feature_fraction=0.522; bagging_fraction=0.595 : y = 0.916 : 354.0 secs : initdesign
#
# [mbo] 0: num_leaves=7588; min_child_weight=0.758; min_data_in_leaf=3979; min_gain_to_split=0.0494; lambda_l1=475; lambda_l2=365; scale_pos_weight=3.8; learning_rate=0.0117; num_iterations=165; early_stopping_rounds=274; feature_fraction=0.757; bagging_fraction=0.892 : y = 0.893 : 13.5 secs : initdesign
#
# [mbo] 0: num_leaves=7027; min_child_weight=4.08; min_data_in_leaf=4817; min_gain_to_split=0.0523; lambda_l1=369; lambda_l2=211; scale_pos_weight=1.38; learning_rate=0.0761; num_iterations=300; early_stopping_rounds=212; feature_fraction=0.215; bagging_fraction=0.501 : y = 0.883 : 25.2 secs : initdesign
#
# [mbo] 0: num_leaves=1651; min_child_weight=8.16; min_data_in_leaf=7947; min_gain_to_split=0.00256; lambda_l1=403; lambda_l2=610; scale_pos_weight=4.67; learning_rate=0.0571; num_iterations=960; early_stopping_rounds=488; feature_fraction=0.945; bagging_fraction=0.581 : y = 0.9 : 34.2 secs : initdesign
#
# [mbo] 0: num_leaves=1167; min_child_weight=5.13; min_data_in_leaf=7195; min_gain_to_split=0.0185; lambda_l1=106; lambda_l2=87.5; scale_pos_weight=2.07; learning_rate=0.0922; num_iterations=578; early_stopping_rounds=256; feature_fraction=0.88; bagging_fraction=0.913 : y = 0.904 : 22.0 secs : initdesign
#
# [mbo] 0: num_leaves=2528; min_child_weight=5.67; min_data_in_leaf=156; min_gain_to_split=0.0834; lambda_l1=903; lambda_l2=79.7; scale_pos_weight=2.42; learning_rate=0.0965; num_iterations=4743; early_stopping_rounds=134; feature_fraction=0.739; bagging_fraction=0.98 : y = 0.869 : 7.1 secs : initdesign
#
# [mbo] 0: num_leaves=4448; min_child_weight=4.36; min_data_in_leaf=3454; min_gain_to_split=0.00961; lambda_l1=660; lambda_l2=879; scale_pos_weight=4.28; learning_rate=0.0486; num_iterations=4930; early_stopping_rounds=464; feature_fraction=0.978; bagging_fraction=0.921 : y = 0.896 : 36.1 secs : initdesign
#
# [mbo] 0: num_leaves=158; min_child_weight=9.67; min_data_in_leaf=5181; min_gain_to_split=0.0275; lambda_l1=253; lambda_l2=45.7; scale_pos_weight=1.88; learning_rate=0.0203; num_iterations=3353; early_stopping_rounds=78; feature_fraction=0.433; bagging_fraction=0.524 : y = 0.895 : 47.8 secs : initdesign
#
# [mbo] 0: num_leaves=6923; min_child_weight=0.242; min_data_in_leaf=7805; min_gain_to_split=0.0912; lambda_l1=394; lambda_l2=352; scale_pos_weight=1.81; learning_rate=0.0419; num_iterations=4138; early_stopping_rounds=434; feature_fraction=0.987; bagging_fraction=0.643 : y = 0.886 : 28.3 secs : initdesign
#
# [mbo] 0: num_leaves=801; min_child_weight=2.15; min_data_in_leaf=6009; min_gain_to_split=0.0427; lambda_l1=215; lambda_l2=985; scale_pos_weight=4.65; learning_rate=0.0288; num_iterations=1609; early_stopping_rounds=141; feature_fraction=0.118; bagging_fraction=0.803 : y = 0.91 : 120.0 secs : initdesign
#
# [mbo] 0: num_leaves=1736; min_child_weight=9.36; min_data_in_leaf=1690; min_gain_to_split=0.0925; lambda_l1=501; lambda_l2=129; scale_pos_weight=4.45; learning_rate=0.095; num_iterations=319; early_stopping_rounds=406; feature_fraction=0.593; bagging_fraction=0.771 : y = 0.902 : 32.8 secs : initdesign
#
# [mbo] 0: num_leaves=4212; min_child_weight=9.94; min_data_in_leaf=6886; min_gain_to_split=0.0778; lambda_l1=982; lambda_l2=628; scale_pos_weight=1.22; learning_rate=0.0429; num_iterations=420; early_stopping_rounds=67; feature_fraction=0.542; bagging_fraction=0.839 : y = 0.861 : 12.0 secs : initdesign
#
# [mbo] 0: num_leaves=1282; min_child_weight=5.89; min_data_in_leaf=688; min_gain_to_split=0.0202; lambda_l1=808; lambda_l2=561; scale_pos_weight=1.12; learning_rate=0.0872; num_iterations=3402; early_stopping_rounds=479; feature_fraction=0.105; bagging_fraction=0.933 : y = 0.866 : 34.1 secs : initdesign
#
# [mbo] 0: num_leaves=3347; min_child_weight=0.444; min_data_in_leaf=266; min_gain_to_split=0.0754; lambda_l1=64.8; lambda_l2=499; scale_pos_weight=4.22; learning_rate=0.0893; num_iterations=4525; early_stopping_rounds=69; feature_fraction=0.937; bagging_fraction=0.661 : y = 0.915 : 37.1 secs : initdesign
#
# [mbo] 0: num_leaves=7763; min_child_weight=8.65; min_data_in_leaf=5592; min_gain_to_split=0.00704; lambda_l1=564; lambda_l2=172; scale_pos_weight=4.84; learning_rate=0.00873; num_iterations=1313; early_stopping_rounds=413; feature_fraction=0.148; bagging_fraction=0.68 : y = 0.897 : 106.0 secs : initdesign
#
# Saved the current state after iteration 1 in the file HT.RDATA.
#
# Thu Nov 20 01:59:27 AM 2025 AUC 0.916424580030856
#
# [mbo] 1: num_leaves=6011; min_child_weight=3.79; min_data_in_leaf=6694; min_gain_to_split=0.0734; lambda_l1=2.46; lambda_l2=670; scale_pos_weight=2.4; learning_rate=0.0711; num_iterations=2554; early_stopping_rounds=61; feature_fraction=0.0864; bagging_fraction=0.594 : y = 0.916 : 83.3 secs : infill_ei
#
# Thu Nov 20 02:02:42 AM 2025 AUC 0.919846339576249
#
# [mbo] 2: num_leaves=1753; min_child_weight=5.17; min_data_in_leaf=3179; min_gain_to_split=0.0378; lambda_l1=0.72; lambda_l2=688; scale_pos_weight=2.8; learning_rate=0.0524; num_iterations=1867; early_stopping_rounds=183; feature_fraction=0.182; bagging_fraction=0.564 : y = 0.92 : 193.9 secs : infill_ei
#
# Thu Nov 20 02:05:46 AM 2025 AUC 0.925251095681094
#
# [mbo] 3: num_leaves=5447; min_child_weight=4.54; min_data_in_leaf=2402; min_gain_to_split=0.0492; lambda_l1=0.594; lambda_l2=313; scale_pos_weight=4.16; learning_rate=0.0417; num_iterations=3638; early_stopping_rounds=134; feature_fraction=0.221; bagging_fraction=0.656 : y = 0.925 : 183.6 secs : infill_ei
#
# Thu Nov 20 02:11:25 AM 2025 AUC 0.927333409834723
#
# [mbo] 4: num_leaves=3324; min_child_weight=6.54; min_data_in_leaf=1128; min_gain_to_split=0.05; lambda_l1=0.915; lambda_l2=435; scale_pos_weight=4.34; learning_rate=0.046; num_iterations=2150; early_stopping_rounds=89; feature_fraction=0.548; bagging_fraction=0.567 : y = 0.927 : 337.1 secs : infill_ei
#
# Saved the current state after iteration 5 in the file HT.RDATA.
#
# Thu Nov 20 02:13:09 AM 2025 AUC 0.921410591684567
#
# [mbo] 5: num_leaves=3089; min_child_weight=2.61; min_data_in_leaf=2812; min_gain_to_split=0.0463; lambda_l1=0.12; lambda_l2=326; scale_pos_weight=4.17; learning_rate=0.0478; num_iterations=822; early_stopping_rounds=94; feature_fraction=0.635; bagging_fraction=0.545 : y = 0.921 : 103.2 secs : infill_ei
#
# Thu Nov 20 02:19:47 AM 2025 AUC 0.92337077203995
#
# [mbo] 6: num_leaves=2348; min_child_weight=2.08; min_data_in_leaf=1022; min_gain_to_split=0.0346; lambda_l1=0.633; lambda_l2=366; scale_pos_weight=4.06; learning_rate=0.0119; num_iterations=2692; early_stopping_rounds=114; feature_fraction=0.332; bagging_fraction=0.619 : y = 0.923 : 396.4 secs : infill_ei
#
# Thu Nov 20 02:22:44 AM 2025 AUC 0.921336774553759
#
# [mbo] 7: num_leaves=3007; min_child_weight=6.95; min_data_in_leaf=1174; min_gain_to_split=0.036; lambda_l1=0.261; lambda_l2=899; scale_pos_weight=4.2; learning_rate=0.0463; num_iterations=1741; early_stopping_rounds=72; feature_fraction=0.143; bagging_fraction=0.638 : y = 0.921 : 176.0 secs : infill_ei
#
# Saved the current state after iteration 8 in the file HT.RDATA.
#
# Thu Nov 20 02:25:33 AM 2025 AUC 0.927508222221775
#
# [mbo] 8: num_leaves=6663; min_child_weight=6.76; min_data_in_leaf=1479; min_gain_to_split=0.0471; lambda_l1=0.962; lambda_l2=198; scale_pos_weight=4.4; learning_rate=0.0378; num_iterations=2924; early_stopping_rounds=52; feature_fraction=0.929; bagging_fraction=0.799 : y = 0.928 : 167.4 secs : infill_ei
#
# Thu Nov 20 02:31:44 AM 2025 AUC 0.921826987408811
#
# [mbo] 9: num_leaves=4102; min_child_weight=6.81; min_data_in_leaf=2088; min_gain_to_split=0.0493; lambda_l1=0.15; lambda_l2=464; scale_pos_weight=4.35; learning_rate=0.0177; num_iterations=2738; early_stopping_rounds=241; feature_fraction=0.911; bagging_fraction=0.779 : y = 0.922 : 370.1 secs : infill_ei
#
# Thu Nov 20 02:35:58 AM 2025 AUC 0.926487532622139
#
# [mbo] 10: num_leaves=6896; min_child_weight=5.51; min_data_in_leaf=369; min_gain_to_split=0.0535; lambda_l1=1.7; lambda_l2=247; scale_pos_weight=4.79; learning_rate=0.0502; num_iterations=2606; early_stopping_rounds=70; feature_fraction=0.59; bagging_fraction=0.626 : y = 0.926 : 252.9 secs : infill_ei
#
# Saved the current state after iteration 11 in the file HT.RDATA.
#
# Thu Nov 20 02:38:15 AM 2025 AUC 0.93106117494056
#
# [mbo] 11: num_leaves=6734; min_child_weight=6.54; min_data_in_leaf=666; min_gain_to_split=0.0605; lambda_l1=0.153; lambda_l2=26; scale_pos_weight=4.08; learning_rate=0.0347; num_iterations=2652; early_stopping_rounds=119; feature_fraction=0.633; bagging_fraction=0.598 : y = 0.931 : 136.4 secs : infill_ei
#
# Thu Nov 20 02:39:04 AM 2025 AUC 0.927340456015392
#
# [mbo] 12: num_leaves=8146; min_child_weight=9.36; min_data_in_leaf=612; min_gain_to_split=0.0714; lambda_l1=0.152; lambda_l2=24.4; scale_pos_weight=4.17; learning_rate=0.0833; num_iterations=1588; early_stopping_rounds=64; feature_fraction=0.403; bagging_fraction=0.736 : y = 0.927 : 47.2 secs : infill_ei
#
# Thu Nov 20 02:44:36 AM 2025 AUC 0.927159268512498
#
# [mbo] 13: num_leaves=7997; min_child_weight=7.02; min_data_in_leaf=1552; min_gain_to_split=0.0946; lambda_l1=0.908; lambda_l2=368; scale_pos_weight=4.17; learning_rate=0.0331; num_iterations=2479; early_stopping_rounds=67; feature_fraction=0.604; bagging_fraction=0.564 : y = 0.927 : 330.3 secs : infill_ei
#
# Thu Nov 20 02:49:35 AM 2025 AUC 0.93123330306831
#
# [mbo] 14: num_leaves=5962; min_child_weight=3.56; min_data_in_leaf=151; min_gain_to_split=0.096; lambda_l1=0.418; lambda_l2=189; scale_pos_weight=4.35; learning_rate=0.0407; num_iterations=2716; early_stopping_rounds=116; feature_fraction=0.232; bagging_fraction=0.776 : y = 0.931 : 298.3 secs : infill_ei
#
# Saved the current state after iteration 15 in the file HT.RDATA.
#
# Thu Nov 20 02:51:21 AM 2025 AUC 0.930508553056734
#
# [mbo] 15: num_leaves=5826; min_child_weight=3.35; min_data_in_leaf=1007; min_gain_to_split=0.0862; lambda_l1=0.888; lambda_l2=1.07; scale_pos_weight=4.25; learning_rate=0.0469; num_iterations=2096; early_stopping_rounds=83; feature_fraction=0.293; bagging_fraction=0.725 : y = 0.931 : 104.3 secs : infill_ei
#
# Thu Nov 20 02:56:11 AM 2025 AUC 0.930498487084351
#
# [mbo] 16: num_leaves=5819; min_child_weight=6.64; min_data_in_leaf=29; min_gain_to_split=0.0855; lambda_l1=5.37; lambda_l2=38.1; scale_pos_weight=4.41; learning_rate=0.0134; num_iterations=3693; early_stopping_rounds=69; feature_fraction=0.281; bagging_fraction=0.738 : y = 0.93 : 289.1 secs : infill_ei
#
# Thu Nov 20 02:59:26 AM 2025 AUC 0.927494465392851
#
# [mbo] 17: num_leaves=1028; min_child_weight=5.84; min_data_in_leaf=142; min_gain_to_split=0.0985; lambda_l1=15.3; lambda_l2=142; scale_pos_weight=4.42; learning_rate=0.0291; num_iterations=3401; early_stopping_rounds=140; feature_fraction=0.076; bagging_fraction=0.521 : y = 0.927 : 193.9 secs : infill_ei
#
# Thu Nov 20 03:01:15 AM 2025 AUC 0.926135559121147
#
# [mbo] 18: num_leaves=7284; min_child_weight=6.86; min_data_in_leaf=99; min_gain_to_split=0.0931; lambda_l1=0.0616; lambda_l2=14.1; scale_pos_weight=4.37; learning_rate=0.0601; num_iterations=3118; early_stopping_rounds=469; feature_fraction=0.648; bagging_fraction=0.53 : y = 0.926 : 107.8 secs : infill_ei
#
# Saved the current state after iteration 19 in the file HT.RDATA.
#
# Thu Nov 20 03:03:13 AM 2025 AUC 0.929167765535318
#
# [mbo] 19: num_leaves=2877; min_child_weight=6.8; min_data_in_leaf=450; min_gain_to_split=0.0972; lambda_l1=1.08; lambda_l2=48.4; scale_pos_weight=4.35; learning_rate=0.0577; num_iterations=2670; early_stopping_rounds=84; feature_fraction=0.463; bagging_fraction=0.734 : y = 0.929 : 116.2 secs : infill_ei
#
# Thu Nov 20 03:04:58 AM 2025 AUC 0.929638853042843
#
# [mbo] 20: num_leaves=6630; min_child_weight=9.1; min_data_in_leaf=230; min_gain_to_split=0.0694; lambda_l1=1.44; lambda_l2=132; scale_pos_weight=4.25; learning_rate=0.0567; num_iterations=3217; early_stopping_rounds=95; feature_fraction=0.245; bagging_fraction=0.834 : y = 0.93 : 103.8 secs : infill_ei
#
# Thu Nov 20 03:05:37 AM 2025 AUC 0.912635076961069
#
# [mbo] 21: num_leaves=3487; min_child_weight=9.12; min_data_in_leaf=18; min_gain_to_split=0.0975; lambda_l1=0.0939; lambda_l2=511; scale_pos_weight=4.1; learning_rate=0.0295; num_iterations=304; early_stopping_rounds=408; feature_fraction=0.185; bagging_fraction=0.539 : y = 0.913 : 37.8 secs : infill_ei
#
# Thu Nov 20 03:08:50 AM 2025 AUC 0.929153002109157
#
# [mbo] 22: num_leaves=7893; min_child_weight=5.56; min_data_in_leaf=333; min_gain_to_split=0.0806; lambda_l1=1.95; lambda_l2=23.2; scale_pos_weight=4.38; learning_rate=0.0443; num_iterations=3257; early_stopping_rounds=133; feature_fraction=0.538; bagging_fraction=0.814 : y = 0.929 : 191.9 secs : infill_ei
#
# Thu Nov 20 03:10:11 AM 2025 AUC 0.928955373518037
#
# [mbo] 23: num_leaves=5851; min_child_weight=6.84; min_data_in_leaf=2162; min_gain_to_split=0.083; lambda_l1=2.64; lambda_l2=1.56; scale_pos_weight=4.38; learning_rate=0.0629; num_iterations=2765; early_stopping_rounds=86; feature_fraction=0.851; bagging_fraction=0.558 : y = 0.929 : 78.6 secs : infill_ei
#
# Thu Nov 20 03:15:13 AM 2025 AUC 0.927817583106346
#
# [mbo] 24: num_leaves=6116; min_child_weight=8.17; min_data_in_leaf=606; min_gain_to_split=0.0848; lambda_l1=5.16; lambda_l2=106; scale_pos_weight=4.42; learning_rate=0.0309; num_iterations=2738; early_stopping_rounds=328; feature_fraction=0.184; bagging_fraction=0.687 : y = 0.928 : 300.9 secs : infill_ei
#
# Saved the current state after iteration 25 in the file HT.RDATA.
#
# Thu Nov 20 03:18:10 AM 2025 AUC 0.928970808009024
#
# [mbo] 25: num_leaves=6143; min_child_weight=8.67; min_data_in_leaf=37; min_gain_to_split=0.0914; lambda_l1=1.42; lambda_l2=465; scale_pos_weight=4.43; learning_rate=0.0709; num_iterations=3877; early_stopping_rounds=96; feature_fraction=0.341; bagging_fraction=0.517 : y = 0.929 : 176.1 secs : infill_ei
#
# Thu Nov 20 03:19:43 AM 2025 AUC 0.927591098727728
#
# [mbo] 26: num_leaves=6240; min_child_weight=7.28; min_data_in_leaf=63; min_gain_to_split=0.0519; lambda_l1=1.09; lambda_l2=110; scale_pos_weight=4.28; learning_rate=0.0756; num_iterations=2530; early_stopping_rounds=84; feature_fraction=0.235; bagging_fraction=0.547 : y = 0.928 : 90.9 secs : infill_ei
#
# Thu Nov 20 03:22:35 AM 2025 AUC 0.93021462666315
#
# [mbo] 27: num_leaves=3852; min_child_weight=4.08; min_data_in_leaf=1284; min_gain_to_split=0.0995; lambda_l1=0.232; lambda_l2=54.7; scale_pos_weight=4.48; learning_rate=0.0356; num_iterations=3007; early_stopping_rounds=70; feature_fraction=0.308; bagging_fraction=0.535 : y = 0.93 : 170.8 secs : infill_ei
#
# Thu Nov 20 03:26:00 AM 2025 AUC 0.928939603494637
#
# [mbo] 28: num_leaves=6172; min_child_weight=8.35; min_data_in_leaf=107; min_gain_to_split=0.1; lambda_l1=2.39; lambda_l2=272; scale_pos_weight=4.4; learning_rate=0.0505; num_iterations=4966; early_stopping_rounds=132; feature_fraction=0.241; bagging_fraction=0.678 : y = 0.929 : 203.4 secs : infill_ei
#
# Saved the current state after iteration 29 in the file HT.RDATA.
#
# Thu Nov 20 03:27:13 AM 2025 AUC 0.921724314490504
#
# [mbo] 29: num_leaves=5886; min_child_weight=9.64; min_data_in_leaf=4298; min_gain_to_split=0.0971; lambda_l1=0.656; lambda_l2=38.6; scale_pos_weight=3.2; learning_rate=0.0249; num_iterations=1540; early_stopping_rounds=51; feature_fraction=0.642; bagging_fraction=0.643 : y = 0.922 : 72.3 secs : infill_ei
#
# Thu Nov 20 03:29:25 AM 2025 AUC 0.919937604392522
#
# [mbo] 30: num_leaves=41; min_child_weight=3.98; min_data_in_leaf=5669; min_gain_to_split=0.096; lambda_l1=1.62; lambda_l2=177; scale_pos_weight=4.47; learning_rate=0.0341; num_iterations=2884; early_stopping_rounds=64; feature_fraction=0.349; bagging_fraction=0.738 : y = 0.92 : 130.1 secs : infill_ei
#
# Thu Nov 20 03:32:36 AM 2025 AUC 0.924800140118336
#
# [mbo] 31: num_leaves=3622; min_child_weight=9.31; min_data_in_leaf=585; min_gain_to_split=0.0726; lambda_l1=2.54; lambda_l2=121; scale_pos_weight=4.35; learning_rate=0.0274; num_iterations=3058; early_stopping_rounds=51; feature_fraction=0.757; bagging_fraction=0.62 : y = 0.925 : 189.5 secs : infill_ei
#
# Thu Nov 20 03:35:12 AM 2025 AUC 0.926195283890619
#
# [mbo] 32: num_leaves=5537; min_child_weight=5.69; min_data_in_leaf=274; min_gain_to_split=0.0799; lambda_l1=3.14; lambda_l2=66.5; scale_pos_weight=3.71; learning_rate=0.0409; num_iterations=3767; early_stopping_rounds=60; feature_fraction=0.442; bagging_fraction=0.603 : y = 0.926 : 153.8 secs : infill_ei
#
# Thu Nov 20 03:36:36 AM 2025 AUC 0.923204347963218
#
# [mbo] 33: num_leaves=6146; min_child_weight=6.88; min_data_in_leaf=639; min_gain_to_split=0.0908; lambda_l1=20.5; lambda_l2=36.8; scale_pos_weight=4.4; learning_rate=0.0404; num_iterations=2915; early_stopping_rounds=90; feature_fraction=0.241; bagging_fraction=0.635 : y = 0.923 : 83.5 secs : infill_ei
#
# Saved the current state after iteration 34 in the file HT.RDATA.
#
# Thu Nov 20 03:38:08 AM 2025 AUC 0.927217986684732
#
# [mbo] 34: num_leaves=7492; min_child_weight=7.44; min_data_in_leaf=974; min_gain_to_split=0.0265; lambda_l1=0.25; lambda_l2=108; scale_pos_weight=2.85; learning_rate=0.0703; num_iterations=4500; early_stopping_rounds=198; feature_fraction=0.978; bagging_fraction=0.712 : y = 0.927 : 90.5 secs : infill_ei
#
# Thu Nov 20 03:40:26 AM 2025 AUC 0.928759087056569
#
# [mbo] 35: num_leaves=5747; min_child_weight=0.837; min_data_in_leaf=253; min_gain_to_split=0.0238; lambda_l1=0.0606; lambda_l2=29.7; scale_pos_weight=3.19; learning_rate=0.0821; num_iterations=2150; early_stopping_rounds=347; feature_fraction=0.57; bagging_fraction=0.929 : y = 0.929 : 136.2 secs : infill_ei
#
# Thu Nov 20 03:45:13 AM 2025 AUC 0.928002796998193
#
# [mbo] 36: num_leaves=5729; min_child_weight=1.66; min_data_in_leaf=1345; min_gain_to_split=0.0325; lambda_l1=0.00186; lambda_l2=170; scale_pos_weight=3.65; learning_rate=0.062; num_iterations=2001; early_stopping_rounds=309; feature_fraction=0.819; bagging_fraction=0.529 : y = 0.928 : 284.6 secs : infill_ei
#
# Thu Nov 20 03:53:37 AM 2025 AUC 0.928079633920716
#
# [mbo] 37: num_leaves=6618; min_child_weight=3.7; min_data_in_leaf=581; min_gain_to_split=0.0806; lambda_l1=0.192; lambda_l2=323; scale_pos_weight=4.15; learning_rate=0.0288; num_iterations=2435; early_stopping_rounds=287; feature_fraction=0.561; bagging_fraction=0.769 : y = 0.928 : 503.3 secs : infill_ei
#
# Saved the current state after iteration 38 in the file HT.RDATA.
#
# Thu Nov 20 03:58:58 AM 2025 AUC 0.931736266155047
#
# [mbo] 38: num_leaves=6630; min_child_weight=9.19; min_data_in_leaf=602; min_gain_to_split=0.0225; lambda_l1=0.126; lambda_l2=14.8; scale_pos_weight=2.95; learning_rate=0.0113; num_iterations=3964; early_stopping_rounds=385; feature_fraction=0.331; bagging_fraction=0.794 : y = 0.932 : 319.4 secs : infill_ei
#
# Thu Nov 20 04:04:18 AM 2025 AUC 0.926441229149177
#
# [mbo] 39: num_leaves=6591; min_child_weight=6.66; min_data_in_leaf=2953; min_gain_to_split=0.0245; lambda_l1=0.614; lambda_l2=82.3; scale_pos_weight=3.58; learning_rate=0.0906; num_iterations=2360; early_stopping_rounds=470; feature_fraction=0.558; bagging_fraction=0.815 : y = 0.926 : 319.3 secs : infill_ei
#
# Saved the current state after iteration 40 in the file HT.RDATA.
#
# Thu Nov 20 04:06:56 AM 2025 AUC 0.931781227498358
#
# [mbo] 40: num_leaves=5176; min_child_weight=6.58; min_data_in_leaf=253; min_gain_to_split=0.035; lambda_l1=0.118; lambda_l2=1.28; scale_pos_weight=2.75; learning_rate=0.0337; num_iterations=2367; early_stopping_rounds=255; feature_fraction=0.71; bagging_fraction=0.744 : y = 0.932 : 156.1 secs : infill_ei
#
# Thu Nov 20 04:10:20 AM 2025 AUC 0.926095630764027
#
# [mbo] 41: num_leaves=6363; min_child_weight=9.42; min_data_in_leaf=805; min_gain_to_split=0.0453; lambda_l1=0.072; lambda_l2=77.4; scale_pos_weight=2.78; learning_rate=0.0674; num_iterations=1956; early_stopping_rounds=343; feature_fraction=0.414; bagging_fraction=0.828 : y = 0.926 : 202.2 secs : infill_ei
#
# Thu Nov 20 04:16:19 AM 2025 AUC 0.929788500498937
#
# [mbo] 42: num_leaves=6436; min_child_weight=7.45; min_data_in_leaf=1195; min_gain_to_split=0.0283; lambda_l1=0.279; lambda_l2=12.5; scale_pos_weight=3.17; learning_rate=0.0173; num_iterations=4154; early_stopping_rounds=305; feature_fraction=0.667; bagging_fraction=0.772 : y = 0.93 : 357.5 secs : infill_ei
#
# Saved the current state after iteration 43 in the file HT.RDATA.
#
# Thu Nov 20 04:20:59 AM 2025 AUC 0.931188341724999
#
# [mbo] 43: num_leaves=4966; min_child_weight=5.43; min_data_in_leaf=492; min_gain_to_split=0.0013; lambda_l1=0.0262; lambda_l2=50.8; scale_pos_weight=2.68; learning_rate=0.02; num_iterations=2446; early_stopping_rounds=245; feature_fraction=0.714; bagging_fraction=0.529 : y = 0.931 : 278.7 secs : infill_ei
#
# Thu Nov 20 04:23:15 AM 2025 AUC 0.928843976756999
#
# [mbo] 44: num_leaves=1331; min_child_weight=0.721; min_data_in_leaf=1036; min_gain_to_split=0.0975; lambda_l1=0.0417; lambda_l2=89.1; scale_pos_weight=4.62; learning_rate=0.0837; num_iterations=3929; early_stopping_rounds=312; feature_fraction=0.656; bagging_fraction=0.531 : y = 0.929 : 134.8 secs : infill_ei
#
# Thu Nov 20 04:29:35 AM 2025 AUC 0.924611235369948
#
# [mbo] 45: num_leaves=7902; min_child_weight=5.57; min_data_in_leaf=2420; min_gain_to_split=0.0209; lambda_l1=0.256; lambda_l2=78.3; scale_pos_weight=2.75; learning_rate=0.0105; num_iterations=2149; early_stopping_rounds=298; feature_fraction=0.457; bagging_fraction=0.798 : y = 0.925 : 377.9 secs : infill_ei
#
# Saved the current state after iteration 46 in the file HT.RDATA.
#
# Thu Nov 20 04:35:00 AM 2025 AUC 0.928386310545985
#
# [mbo] 46: num_leaves=3010; min_child_weight=7.78; min_data_in_leaf=1272; min_gain_to_split=0.00924; lambda_l1=0.242; lambda_l2=48.7; scale_pos_weight=2.59; learning_rate=0.0631; num_iterations=4161; early_stopping_rounds=404; feature_fraction=0.586; bagging_fraction=0.59 : y = 0.928 : 323.6 secs : infill_ei
#
# Thu Nov 20 04:38:15 AM 2025 AUC 0.920795560771966
#
# [mbo] 47: num_leaves=5679; min_child_weight=9.11; min_data_in_leaf=152; min_gain_to_split=0.026; lambda_l1=0.0464; lambda_l2=262; scale_pos_weight=2.25; learning_rate=0.0232; num_iterations=2471; early_stopping_rounds=87; feature_fraction=0.795; bagging_fraction=0.673 : y = 0.921 : 194.0 secs : infill_ei
#
# Thu Nov 20 04:40:46 AM 2025 AUC 0.933207575785028
#
# [mbo] 48: num_leaves=5568; min_child_weight=2.71; min_data_in_leaf=183; min_gain_to_split=0.00209; lambda_l1=0.103; lambda_l2=3.34; scale_pos_weight=3; learning_rate=0.0969; num_iterations=2898; early_stopping_rounds=439; feature_fraction=0.83; bagging_fraction=0.67 : y = 0.933 : 149.5 secs : infill_ei
#
# Saved the current state after iteration 49 in the file HT.RDATA.
#
# Thu Nov 20 04:42:25 AM 2025 AUC 0.932917004715572
#
# [mbo] 49: num_leaves=6903; min_child_weight=2.11; min_data_in_leaf=19; min_gain_to_split=0.0092; lambda_l1=0.388; lambda_l2=0.241; scale_pos_weight=2.38; learning_rate=0.0449; num_iterations=2967; early_stopping_rounds=445; feature_fraction=0.898; bagging_fraction=0.62 : y = 0.933 : 97.5 secs : infill_ei
#
# Thu Nov 20 04:49:58 AM 2025 AUC 0.930507881991908
#
# [mbo] 50: num_leaves=2542; min_child_weight=2.43; min_data_in_leaf=1129; min_gain_to_split=0.0381; lambda_l1=0.462; lambda_l2=4.66; scale_pos_weight=2.68; learning_rate=0.0135; num_iterations=3033; early_stopping_rounds=500; feature_fraction=0.791; bagging_fraction=0.629 : y = 0.931 : 451.7 secs : infill_ei
#
# Thu Nov 20 04:52:17 AM 2025 AUC 0.923417075512912
#
# [mbo] 51: num_leaves=14; min_child_weight=4.33; min_data_in_leaf=209; min_gain_to_split=0.0237; lambda_l1=0.309; lambda_l2=2.96; scale_pos_weight=2.91; learning_rate=0.0767; num_iterations=2022; early_stopping_rounds=272; feature_fraction=0.728; bagging_fraction=0.57 : y = 0.923 : 137.3 secs : infill_ei
#
# Saved the current state after iteration 52 in the file HT.RDATA.
#
# Thu Nov 20 04:56:40 AM 2025 AUC 0.930661220304543
#
# [mbo] 52: num_leaves=4871; min_child_weight=3.17; min_data_in_leaf=715; min_gain_to_split=0.0109; lambda_l1=0.202; lambda_l2=58; scale_pos_weight=2.83; learning_rate=0.0474; num_iterations=2342; early_stopping_rounds=438; feature_fraction=0.248; bagging_fraction=0.686 : y = 0.931 : 260.9 secs : infill_ei
#
# Thu Nov 20 05:00:59 AM 2025 AUC 0.929162732549127
#
# [mbo] 53: num_leaves=4195; min_child_weight=4.84; min_data_in_leaf=129; min_gain_to_split=0.0215; lambda_l1=0.252; lambda_l2=42.5; scale_pos_weight=2.21; learning_rate=0.0249; num_iterations=3956; early_stopping_rounds=341; feature_fraction=0.779; bagging_fraction=0.974 : y = 0.929 : 257.9 secs : infill_ei
#
# Thu Nov 20 05:05:51 AM 2025 AUC 0.924731691506131
#
# [mbo] 54: num_leaves=5369; min_child_weight=4.04; min_data_in_leaf=262; min_gain_to_split=0.00509; lambda_l1=0.519; lambda_l2=213; scale_pos_weight=2.89; learning_rate=0.0411; num_iterations=2704; early_stopping_rounds=463; feature_fraction=0.906; bagging_fraction=0.894 : y = 0.925 : 289.4 secs : infill_ei
#
# Saved the current state after iteration 55 in the file HT.RDATA.
#
# Thu Nov 20 05:08:07 AM 2025 AUC 0.931953355626107
#
# [mbo] 55: num_leaves=4166; min_child_weight=1.23; min_data_in_leaf=912; min_gain_to_split=0.00936; lambda_l1=0.994; lambda_l2=21.3; scale_pos_weight=2.4; learning_rate=0.0407; num_iterations=3982; early_stopping_rounds=310; feature_fraction=0.657; bagging_fraction=0.654 : y = 0.932 : 134.6 secs : infill_ei
#
# Thu Nov 20 05:09:46 AM 2025 AUC 0.929563022717558
#
# [mbo] 56: num_leaves=5147; min_child_weight=1.54; min_data_in_leaf=755; min_gain_to_split=0.0447; lambda_l1=0.0646; lambda_l2=6.36; scale_pos_weight=2.62; learning_rate=0.0896; num_iterations=1033; early_stopping_rounds=330; feature_fraction=0.944; bagging_fraction=0.549 : y = 0.93 : 97.2 secs : infill_ei
#
# Thu Nov 20 05:13:08 AM 2025 AUC 0.934081973252698
#
# [mbo] 57: num_leaves=4409; min_child_weight=3.45; min_data_in_leaf=1665; min_gain_to_split=0.0797; lambda_l1=0.0615; lambda_l2=10.1; scale_pos_weight=2.37; learning_rate=0.0441; num_iterations=3558; early_stopping_rounds=408; feature_fraction=0.306; bagging_fraction=0.641 : y = 0.934 : 200.1 secs : infill_ei
#
# Thu Nov 20 05:16:49 AM 2025 AUC 0.931938592199945
#
# [mbo] 58: num_leaves=4016; min_child_weight=1.05; min_data_in_leaf=126; min_gain_to_split=0.078; lambda_l1=0.226; lambda_l2=25; scale_pos_weight=2.56; learning_rate=0.0294; num_iterations=3262; early_stopping_rounds=377; feature_fraction=0.755; bagging_fraction=0.53 : y = 0.932 : 219.7 secs : infill_ei
#
# Saved the current state after iteration 59 in the file HT.RDATA.
#
# Thu Nov 20 05:18:38 AM 2025 AUC 0.92654222440542
#
# [mbo] 59: num_leaves=6214; min_child_weight=1.25; min_data_in_leaf=2819; min_gain_to_split=0.0931; lambda_l1=0.0283; lambda_l2=9.46; scale_pos_weight=2.43; learning_rate=0.0985; num_iterations=3385; early_stopping_rounds=459; feature_fraction=0.661; bagging_fraction=0.646 : y = 0.927 : 106.5 secs : infill_ei
#
# Thu Nov 20 05:26:53 AM 2025 AUC 0.931641646014647
#
# [mbo] 60: num_leaves=5224; min_child_weight=4.34; min_data_in_leaf=327; min_gain_to_split=0.0708; lambda_l1=0.136; lambda_l2=32.8; scale_pos_weight=2.21; learning_rate=0.0183; num_iterations=3539; early_stopping_rounds=469; feature_fraction=0.34; bagging_fraction=0.645 : y = 0.932 : 494.1 secs : infill_ei
#
# Saved the current state after iteration 61 in the file HT.RDATA.
#
# Thu Nov 20 05:30:28 AM 2025 AUC 0.933214957498109
#
# [mbo] 61: num_leaves=1764; min_child_weight=2.54; min_data_in_leaf=799; min_gain_to_split=0.0922; lambda_l1=0.806; lambda_l2=3.35; scale_pos_weight=2.69; learning_rate=0.0218; num_iterations=4508; early_stopping_rounds=270; feature_fraction=0.319; bagging_fraction=0.656 : y = 0.933 : 213.1 secs : infill_ei
#
# Thu Nov 20 05:33:13 AM 2025 AUC 0.930682023314134
#
# [mbo] 62: num_leaves=224; min_child_weight=1.3; min_data_in_leaf=2513; min_gain_to_split=0.0733; lambda_l1=0.453; lambda_l2=21.7; scale_pos_weight=1.94; learning_rate=0.0375; num_iterations=1902; early_stopping_rounds=358; feature_fraction=0.0802; bagging_fraction=0.776 : y = 0.931 : 161.9 secs : infill_ei
#
# Thu Nov 20 05:36:47 AM 2025 AUC 0.928312493415176
#
# [mbo] 63: num_leaves=1909; min_child_weight=2.83; min_data_in_leaf=2495; min_gain_to_split=0.0825; lambda_l1=0.0834; lambda_l2=5.79; scale_pos_weight=2.03; learning_rate=0.043; num_iterations=4684; early_stopping_rounds=430; feature_fraction=0.182; bagging_fraction=0.744 : y = 0.928 : 211.3 secs : infill_ei
#
# Thu Nov 20 05:39:50 AM 2025 AUC 0.930866901673569
#
# [mbo] 64: num_leaves=2631; min_child_weight=0.12; min_data_in_leaf=1097; min_gain_to_split=0.0549; lambda_l1=0.338; lambda_l2=61.5; scale_pos_weight=2.4; learning_rate=0.096; num_iterations=3235; early_stopping_rounds=358; feature_fraction=0.405; bagging_fraction=0.87 : y = 0.931 : 181.9 secs : infill_ei
#
# Saved the current state after iteration 65 in the file HT.RDATA.
#
# Thu Nov 20 05:41:19 AM 2025 AUC 0.930675648198292
#
# [mbo] 65: num_leaves=3811; min_child_weight=2.05; min_data_in_leaf=768; min_gain_to_split=0.0847; lambda_l1=0.249; lambda_l2=0.226; scale_pos_weight=2.44; learning_rate=0.0462; num_iterations=2833; early_stopping_rounds=249; feature_fraction=0.622; bagging_fraction=0.834 : y = 0.931 : 86.5 secs : infill_ei
#
# Thu Nov 20 05:44:23 AM 2025 AUC 0.934371537724916
#
# [mbo] 66: num_leaves=4062; min_child_weight=2.34; min_data_in_leaf=342; min_gain_to_split=0.0275; lambda_l1=0.0293; lambda_l2=2.77; scale_pos_weight=2.29; learning_rate=0.0475; num_iterations=2832; early_stopping_rounds=356; feature_fraction=0.424; bagging_fraction=0.628 : y = 0.934 : 182.3 secs : infill_ei
#
# Thu Nov 20 05:50:29 AM 2025 AUC 0.934888593172989
#
# [mbo] 67: num_leaves=1681; min_child_weight=2.44; min_data_in_leaf=863; min_gain_to_split=0.018; lambda_l1=0.0714; lambda_l2=3.35; scale_pos_weight=2.53; learning_rate=0.0129; num_iterations=3401; early_stopping_rounds=321; feature_fraction=0.129; bagging_fraction=0.967 : y = 0.935 : 363.9 secs : infill_ei
#
# Saved the current state after iteration 68 in the file HT.RDATA.
#
# Thu Nov 20 05:55:57 AM 2025 AUC 0.919408805310002
#
# [mbo] 68: num_leaves=436; min_child_weight=0.585; min_data_in_leaf=1579; min_gain_to_split=0.0937; lambda_l1=0.0216; lambda_l2=783; scale_pos_weight=2.41; learning_rate=0.0221; num_iterations=3583; early_stopping_rounds=371; feature_fraction=0.118; bagging_fraction=0.984 : y = 0.919 : 326.8 secs : infill_ei
#
# Thu Nov 20 06:00:10 AM 2025 AUC 0.926944192235914
#
# [mbo] 69: num_leaves=4699; min_child_weight=4.63; min_data_in_leaf=417; min_gain_to_split=0.0783; lambda_l1=0.061; lambda_l2=615; scale_pos_weight=4.57; learning_rate=0.0948; num_iterations=4308; early_stopping_rounds=269; feature_fraction=0.144; bagging_fraction=0.907 : y = 0.927 : 250.5 secs : infill_ei
#
# Thu Nov 20 06:05:38 AM 2025 AUC 0.92789811088541
#
# [mbo] 70: num_leaves=2180; min_child_weight=8.38; min_data_in_leaf=546; min_gain_to_split=0.0452; lambda_l1=0.0482; lambda_l2=69.4; scale_pos_weight=2.56; learning_rate=0.00864; num_iterations=3783; early_stopping_rounds=264; feature_fraction=0.0655; bagging_fraction=0.964 : y = 0.928 : 327.0 secs : infill_ei
#
# Saved the current state after iteration 71 in the file HT.RDATA.
#
# Thu Nov 20 06:08:18 AM 2025 AUC 0.923875412788751
#
# [mbo] 71: num_leaves=1539; min_child_weight=2.16; min_data_in_leaf=7230; min_gain_to_split=0.0908; lambda_l1=1.07; lambda_l2=0.579; scale_pos_weight=2.4; learning_rate=0.0265; num_iterations=1535; early_stopping_rounds=382; feature_fraction=0.175; bagging_fraction=0.613 : y = 0.924 : 157.7 secs : infill_ei
#
# Thu Nov 20 06:10:30 AM 2025 AUC 0.936625980006295
#
# [mbo] 72: num_leaves=6472; min_child_weight=2.01; min_data_in_leaf=193; min_gain_to_split=0.0778; lambda_l1=0.435; lambda_l2=0.974; scale_pos_weight=2.72; learning_rate=0.0248; num_iterations=3615; early_stopping_rounds=278; feature_fraction=0.128; bagging_fraction=0.599 : y = 0.937 : 130.1 secs : infill_ei
#
# Thu Nov 20 06:12:43 AM 2025 AUC 0.920093291432046
#
# [mbo] 73: num_leaves=2827; min_child_weight=1.8; min_data_in_leaf=1016; min_gain_to_split=0.0348; lambda_l1=15.7; lambda_l2=2.87; scale_pos_weight=2.28; learning_rate=0.0324; num_iterations=3208; early_stopping_rounds=343; feature_fraction=0.106; bagging_fraction=0.83 : y = 0.92 : 130.7 secs : infill_ei
#
# Thu Nov 20 06:15:06 AM 2025 AUC 0.915060640772959
#
# [mbo] 74: num_leaves=946; min_child_weight=6.25; min_data_in_leaf=457; min_gain_to_split=0.0904; lambda_l1=96.7; lambda_l2=778; scale_pos_weight=4.97; learning_rate=0.0313; num_iterations=2372; early_stopping_rounds=186; feature_fraction=0.339; bagging_fraction=0.587 : y = 0.915 : 141.8 secs : infill_ei
#
# Thu Nov 20 06:16:35 AM 2025 AUC 0.910653758063683
#
# [mbo] 75: num_leaves=7319; min_child_weight=9.94; min_data_in_leaf=4307; min_gain_to_split=0.0266; lambda_l1=76.9; lambda_l2=961; scale_pos_weight=4.27; learning_rate=0.0973; num_iterations=3112; early_stopping_rounds=278; feature_fraction=0.592; bagging_fraction=0.858 : y = 0.911 : 87.2 secs : infill_ei
#
# Saved the current state after iteration 76 in the file HT.RDATA.
#
# Thu Nov 20 06:20:25 AM 2025 AUC 0.926921040499433
#
# [mbo] 76: num_leaves=1161; min_child_weight=2.76; min_data_in_leaf=2085; min_gain_to_split=0.0196; lambda_l1=0.0837; lambda_l2=26.8; scale_pos_weight=1.34; learning_rate=0.0939; num_iterations=2485; early_stopping_rounds=401; feature_fraction=0.561; bagging_fraction=0.933 : y = 0.927 : 226.8 secs : infill_ei
#
# Thu Nov 20 06:22:18 AM 2025 AUC 0.932330494058056
#
# [mbo] 77: num_leaves=1511; min_child_weight=1.22; min_data_in_leaf=934; min_gain_to_split=0.0873; lambda_l1=0.0586; lambda_l2=36.8; scale_pos_weight=4.72; learning_rate=0.0804; num_iterations=2596; early_stopping_rounds=239; feature_fraction=0.0612; bagging_fraction=0.974 : y = 0.932 : 111.0 secs : infill_ei
#
# Thu Nov 20 06:27:13 AM 2025 AUC 0.933286090369616
#
# [mbo] 78: num_leaves=562; min_child_weight=1.87; min_data_in_leaf=129; min_gain_to_split=0.079; lambda_l1=0.00114; lambda_l2=193; scale_pos_weight=4.48; learning_rate=0.0442; num_iterations=4875; early_stopping_rounds=375; feature_fraction=0.122; bagging_fraction=0.8 : y = 0.933 : 292.7 secs : infill_ei
#
# Saved the current state after iteration 79 in the file HT.RDATA.
#
# Thu Nov 20 06:29:01 AM 2025 AUC 0.932072805165052
#
# [mbo] 79: num_leaves=1107; min_child_weight=2.31; min_data_in_leaf=290; min_gain_to_split=0.0625; lambda_l1=0.219; lambda_l2=26; scale_pos_weight=4.22; learning_rate=0.0908; num_iterations=2826; early_stopping_rounds=391; feature_fraction=0.389; bagging_fraction=0.946 : y = 0.932 : 105.9 secs : infill_ei
#
# Thu Nov 20 06:30:37 AM 2025 AUC 0.909481743345889
#
# [mbo] 80: num_leaves=6743; min_child_weight=3.24; min_data_in_leaf=100; min_gain_to_split=0.0345; lambda_l1=164; lambda_l2=908; scale_pos_weight=4.36; learning_rate=0.0159; num_iterations=934; early_stopping_rounds=115; feature_fraction=0.972; bagging_fraction=0.502 : y = 0.909 : 94.4 secs : infill_ei
#
# Thu Nov 20 06:32:35 AM 2025 AUC 0.933053230875156
#
# [mbo] 81: num_leaves=582; min_child_weight=2.52; min_data_in_leaf=393; min_gain_to_split=0.0336; lambda_l1=0.0103; lambda_l2=19.4; scale_pos_weight=4.66; learning_rate=0.0435; num_iterations=4727; early_stopping_rounds=219; feature_fraction=0.29; bagging_fraction=0.993 : y = 0.933 : 115.7 secs : infill_ei
#
# Thu Nov 20 06:35:24 AM 2025 AUC 0.923574104682086
#
# [mbo] 82: num_leaves=832; min_child_weight=2.08; min_data_in_leaf=6020; min_gain_to_split=0.0589; lambda_l1=0.0144; lambda_l2=42.7; scale_pos_weight=1.02; learning_rate=0.0581; num_iterations=1875; early_stopping_rounds=193; feature_fraction=0.115; bagging_fraction=0.504 : y = 0.924 : 167.3 secs : infill_ei
#
# Thu Nov 20 06:39:21 AM 2025 AUC 0.925651385849524
#
# [mbo] 83: num_leaves=1710; min_child_weight=3.04; min_data_in_leaf=4236; min_gain_to_split=0.0767; lambda_l1=0.255; lambda_l2=88; scale_pos_weight=1.92; learning_rate=0.0523; num_iterations=1580; early_stopping_rounds=372; feature_fraction=0.391; bagging_fraction=0.724 : y = 0.926 : 234.3 secs : infill_ei
#
# Saved the current state after iteration 84 in the file HT.RDATA.
#
# Thu Nov 20 06:41:09 AM 2025 AUC 0.922652397144217
#
# [mbo] 84: num_leaves=5825; min_child_weight=2.44; min_data_in_leaf=1514; min_gain_to_split=0.073; lambda_l1=0.0636; lambda_l2=598; scale_pos_weight=4.47; learning_rate=0.0933; num_iterations=1355; early_stopping_rounds=61; feature_fraction=0.901; bagging_fraction=0.989 : y = 0.923 : 106.8 secs : infill_ei
#
# Thu Nov 20 06:42:49 AM 2025 AUC 0.928794653492322
#
# [mbo] 85: num_leaves=748; min_child_weight=2.43; min_data_in_leaf=80; min_gain_to_split=0.0127; lambda_l1=0.0323; lambda_l2=171; scale_pos_weight=4.46; learning_rate=0.0993; num_iterations=3766; early_stopping_rounds=117; feature_fraction=0.334; bagging_fraction=0.979 : y = 0.929 : 97.4 secs : infill_ei
#
# Thu Nov 20 06:45:38 AM 2025 AUC 0.930984338018037
#
# [mbo] 86: num_leaves=1264; min_child_weight=0.793; min_data_in_leaf=2228; min_gain_to_split=0.0906; lambda_l1=0.0184; lambda_l2=9.12; scale_pos_weight=4.33; learning_rate=0.057; num_iterations=3993; early_stopping_rounds=259; feature_fraction=0.226; bagging_fraction=0.963 : y = 0.931 : 166.8 secs : infill_ei
#
# Thu Nov 20 06:50:03 AM 2025 AUC 0.932544228204989
#
# [mbo] 87: num_leaves=1333; min_child_weight=4.85; min_data_in_leaf=918; min_gain_to_split=0.0135; lambda_l1=0.0388; lambda_l2=8.63; scale_pos_weight=4.7; learning_rate=0.0258; num_iterations=2162; early_stopping_rounds=342; feature_fraction=0.187; bagging_fraction=0.93 : y = 0.933 : 262.3 secs : infill_ei
#
# Saved the current state after iteration 88 in the file HT.RDATA.
#
# Thu Nov 20 07:00:34 AM 2025 AUC 0.933289781226156
#
# [mbo] 88: num_leaves=380; min_child_weight=1.39; min_data_in_leaf=490; min_gain_to_split=0.0521; lambda_l1=0.156; lambda_l2=2.27; scale_pos_weight=4.87; learning_rate=0.00841; num_iterations=4260; early_stopping_rounds=497; feature_fraction=0.556; bagging_fraction=0.961 : y = 0.933 : 629.5 secs : infill_ei
#
# Saved the current state after iteration 89 in the file HT.RDATA.
#
# Thu Nov 20 07:03:24 AM 2025 AUC 0.928474555570543
#
# [mbo] 89: num_leaves=2514; min_child_weight=0.416; min_data_in_leaf=50; min_gain_to_split=0.0544; lambda_l1=0.0805; lambda_l2=121; scale_pos_weight=1.38; learning_rate=0.0826; num_iterations=3324; early_stopping_rounds=299; feature_fraction=0.13; bagging_fraction=0.605 : y = 0.928 : 166.5 secs : infill_ei
#
# Thu Nov 20 07:10:53 AM 2025 AUC 0.931823840114779
#
# [mbo] 90: num_leaves=357; min_child_weight=8.96; min_data_in_leaf=85; min_gain_to_split=0.0435; lambda_l1=0.23; lambda_l2=327; scale_pos_weight=4.93; learning_rate=0.0255; num_iterations=4331; early_stopping_rounds=470; feature_fraction=0.125; bagging_fraction=0.933 : y = 0.932 : 446.3 secs : infill_ei
#
# Saved the current state after iteration 91 in the file HT.RDATA.
#
# Thu Nov 20 07:19:44 AM 2025 AUC 0.935641527907237
#
# [mbo] 91: num_leaves=512; min_child_weight=1.06; min_data_in_leaf=774; min_gain_to_split=0.0753; lambda_l1=0.233; lambda_l2=6.12; scale_pos_weight=4.78; learning_rate=0.00828; num_iterations=3155; early_stopping_rounds=251; feature_fraction=0.342; bagging_fraction=0.576 : y = 0.936 : 528.7 secs : infill_ei
#
# Thu Nov 20 07:21:46 AM 2025 AUC 0.927445477660587
#
# [mbo] 92: num_leaves=6393; min_child_weight=4.29; min_data_in_leaf=4178; min_gain_to_split=0.0329; lambda_l1=0.000131; lambda_l2=2.26; scale_pos_weight=1.37; learning_rate=0.0702; num_iterations=2862; early_stopping_rounds=258; feature_fraction=0.923; bagging_fraction=0.516 : y = 0.927 : 120.5 secs : infill_ei
#
# Saved the current state after iteration 93 in the file HT.RDATA.
#
# Thu Nov 20 07:22:27 AM 2025 AUC 0.910348759100478
#
# [mbo] 93: num_leaves=1061; min_child_weight=1.22; min_data_in_leaf=306; min_gain_to_split=0.0973; lambda_l1=136; lambda_l2=293; scale_pos_weight=4.63; learning_rate=0.0975; num_iterations=539; early_stopping_rounds=76; feature_fraction=0.071; bagging_fraction=0.957 : y = 0.91 : 38.5 secs : infill_ei
#
# Thu Nov 20 07:23:00 AM 2025 AUC 0.899679163906913
#
# [mbo] 94: num_leaves=163; min_child_weight=2.08; min_data_in_leaf=1342; min_gain_to_split=0.0226; lambda_l1=830; lambda_l2=72.2; scale_pos_weight=4.99; learning_rate=0.0399; num_iterations=2048; early_stopping_rounds=471; feature_fraction=0.87; bagging_fraction=0.869 : y = 0.9 : 30.5 secs : infill_ei
#
# Thu Nov 20 07:25:06 AM 2025 AUC 0.921635398401121
#
# [mbo] 95: num_leaves=5961; min_child_weight=4.56; min_data_in_leaf=5899; min_gain_to_split=0.0359; lambda_l1=0.0333; lambda_l2=5.68; scale_pos_weight=3.02; learning_rate=0.086; num_iterations=3486; early_stopping_rounds=333; feature_fraction=0.931; bagging_fraction=0.578 : y = 0.922 : 123.7 secs : infill_ei
#
# Thu Nov 20 07:28:31 AM 2025 AUC 0.91673192772095
#
# [mbo] 96: num_leaves=568; min_child_weight=0.127; min_data_in_leaf=3768; min_gain_to_split=0.0407; lambda_l1=56.7; lambda_l2=189; scale_pos_weight=5; learning_rate=0.0287; num_iterations=4056; early_stopping_rounds=456; feature_fraction=0.343; bagging_fraction=0.987 : y = 0.917 : 201.6 secs : infill_ei
#
# Thu Nov 20 07:29:14 AM 2025 AUC 0.905160421401868
#
# [mbo] 97: num_leaves=7927; min_child_weight=8.89; min_data_in_leaf=3786; min_gain_to_split=0.0156; lambda_l1=59.2; lambda_l2=742; scale_pos_weight=1.03; learning_rate=0.0883; num_iterations=1809; early_stopping_rounds=248; feature_fraction=0.745; bagging_fraction=0.507 : y = 0.905 : 41.6 secs : infill_ei
#
# Thu Nov 20 07:29:47 AM 2025 AUC 0.913200784608994
#
# [mbo] 98: num_leaves=7204; min_child_weight=8.18; min_data_in_leaf=1766; min_gain_to_split=0.0737; lambda_l1=84.5; lambda_l2=6.28; scale_pos_weight=4.46; learning_rate=0.0483; num_iterations=896; early_stopping_rounds=61; feature_fraction=0.995; bagging_fraction=0.908 : y = 0.913 : 30.2 secs : infill_ei
#
# Thu Nov 20 07:37:52 AM 2025 AUC 0.9319610728716
#
# [mbo] 99: num_leaves=2203; min_child_weight=3.73; min_data_in_leaf=1213; min_gain_to_split=0.00543; lambda_l1=0.056; lambda_l2=45.5; scale_pos_weight=4.93; learning_rate=0.00728; num_iterations=4689; early_stopping_rounds=228; feature_fraction=0.113; bagging_fraction=0.922 : y = 0.932 : 483.5 secs : infill_ei
#
# Saved the current state after iteration 100 in the file HT.RDATA.
#
# Thu Nov 20 07:42:06 AM 2025 AUC 0.927222684138511
#
# [mbo] 100: num_leaves=282; min_child_weight=2.11; min_data_in_leaf=284; min_gain_to_split=0.0697; lambda_l1=0.264; lambda_l2=333; scale_pos_weight=4.98; learning_rate=0.0162; num_iterations=2143; early_stopping_rounds=124; feature_fraction=0.167; bagging_fraction=0.911 : y = 0.927 : 251.4 secs : infill_ei
#
# Saved the final state in the file HT.RDATA

# %% [markdown]
# la bayesian optimization ha corrido, extraigo los mejores hiperparametros

# %%
# almaceno los resultados de la Bayesian Optimization
# y capturo los mejores hiperparametros encontrados

tb_bayesiana <- as.data.table(bayesiana_salida$opt.path)

# ordeno en forma descendente por AUC = y
setorder(tb_bayesiana, -y, -num_iterations)

# grabo para eventualmente poder utilizarlos en OTRA corrida
fwrite( tb_bayesiana,
  file="BO_log.txt",
  sep="\t"
)

# los mejores hiperparámetros son los que quedaron en el registro 1 de la tabla
PARAM$out$lgbm$mejores_hiperparametros <- tb_bayesiana[
  1, # el primero es el de mejor AUC
  setdiff(colnames(tb_bayesiana),
    c("y","dob","eol","error.message","exec.time","ei","error.model",
      "train.time","prop.type","propose.time","se","mean","iter")),
  with= FALSE
]

print(PARAM$out$lgbm$mejores_hiperparametros)
# Out:
#    num_leaves min_child_weight min_data_in_leaf min_gain_to_split lambda_l1
#         <int>            <num>            <int>             <num>     <num>
# 1:       6472         2.007873              193        0.07782993 0.4348449
#    lambda_l2 scale_pos_weight learning_rate num_iterations
#        <num>            <num>         <num>          <int>
# 1: 0.9743814         2.717511    0.02480619           3615
#    early_stopping_rounds feature_fraction bagging_fraction
#                    <int>            <num>            <num>
# 1:                   278        0.1279845        0.5985293

# %% [markdown]
# ### 6.3.3 Produccion

# %% [markdown]
# #### Final Training
# Construyo el modelo final, que es uno solo, no hace ningun tipo de particion < training, validation, testing>]

# %% [markdown]
# ##### Final Training Dataset
#
# Aqui esta la gran decision de en qué meses hago el Final Training
# <br> debo utilizar los mejores hiperparámetros que encontré en la optimización bayesiana

# %%
PARAM$trainingstrategy$final_train <- c(
  202105, 202104, 202103, 202102, 202101,
  202012, 202011, 202010, 202009, 202008, 202007,
  202006, 202005
)

dataset[, fold_final_train := foto_mes %in% PARAM$trainingstrategy$final_train ]

# creo el dfinal_train en formato  LightGBM
dfinal_train <- lgb.Dataset(
  data= data.matrix(dataset[fold_final_train == TRUE, campos_buenos, with= FALSE]),
  label= dataset[fold_final_train == TRUE, clase01],
  free_raw_data= TRUE
)

nrow( dfinal_train) # verifico el tamaño
# Out:
# [1] 207504

# %% [markdown]
# ##### Final Training Hyperparameters

# %%
# uno los parametros fijos y los mejores encontrados de los variables
fijos <- copy(PARAM$lgbm$param_fijos)

# quito lo que optimice en la Bayesian Optimization
fijos$num_iterations <- NULL
fijos$early_stopping_rounds <- NULL

# agrego a los hiperparametros fijos los que encontre con la Bayesian Optimization
param_final <- c(fijos, PARAM$out$lgbm$mejores_hiperparametros)

# Para el entrenamiento final, removemos early_stopping_rounds
# ya que se entrena con todos los datos disponibles y la cantidad de iteraciones
# ya está optimizada en 'num_iterations'.
param_final$early_stopping_rounds <- NULL

# %% [markdown]
# ##### Training
# Genero el modelo final, siempre sobre TODOS los datos de  final_train, sin hacer ningun tipo de undersampling de la clase mayoritaria

# %%
final_model <- lgb.train(
  data= dfinal_train,
  param= param_final,
  verbose= -100
)

# %%
# grabo a disco el modelo en un formato para seres humanos ... ponele ...

lgb.save(final_model, "modelo.txt")

# %%
# ahora imprimo la importancia de variables

tb_importancia <- as.data.table(lgb.importance(final_model))
archivo_importancia <- "impo.txt"

fwrite( tb_importancia,
  file= archivo_importancia,
  sep= "\t"
)

# %% [markdown]
# #### Scoring

# %% [markdown]
# Aplico el modelo final a los datos del futuro

# %%
PARAM$trainingstrategy$future <- c(202107)

dfuture <- dataset[ foto_mes %in% PARAM$trainingstrategy$future ]

# %%
# aplico final_model   a dfuture

prediccion <- predict(
  final_model,
  data.matrix(dfuture[, campos_buenos, with= FALSE])
)

# %% [markdown]
# ##### Tabla Prediccion

# %%
tb_prediccion <- dfuture[, list(numero_de_cliente)]
tb_prediccion[, prob := prediccion]

# grabo las probabilidad del modelo
#  me va a ser util para hacer Ensembles de modelos
fwrite(tb_prediccion,
  file= "prediccion.txt",
  sep= "\t"
)

# %% [markdown]
# #### Curva de Ganancia

# %% [markdown]
# Genero las salidas

# %%
# asigno clase ternaria
tb_prediccion[, clase_ternaria := dfuture$clase_ternaria ]

# asigno ganancias
tb_prediccion[, ganancia := -3000.0 ]
tb_prediccion[clase_ternaria=="BAJA+2", ganancia := 117000.0 ]

# reordeno, y acumulada
setorder( tb_prediccion, -prob )
tb_prediccion[, gan_acum := cumsum(ganancia)]

# media movil de ancho 400
tb_prediccion[,
  gan_suavizada := frollmean(
    x= gan_acum,
    n= 400,
    align= "center",
    na.rm= TRUE,
    hasNA= TRUE
  )
]

# %%
tb_prediccion[, sum(!is.na(gan_suavizada) )]
tb_prediccion[, .N]
# Out:
# [1] 16152
# [1] 16551

# %%
# Este es la ganancia a reportar
resultado <- list()
resultado$ganancia_suavizada_max <- max( tb_prediccion$gan_suavizada, na.rm=TRUE )
options(digits= 8)
resultado$envios <- which.max( tb_prediccion$gan_suavizada)
resultado
# Out:
# $ganancia_suavizada_max
# [1] 6015900
#
# $envios
# [1] 1589

# %%
# grabo las ganancias
fwrite( tb_prediccion,
  file= "ganancias.txt",
  sep= "\t"
)

# %%
# genero el grafico

tb_prediccion[, envios:= .I]

pdf("curva_de_ganancia.pdf")

plot(
  x= tb_prediccion$envios,
  y= tb_prediccion$gan_acum,
  type= "l",
  col= "gray",
  xlim= c(0, 6000),
  ylim= c(0, 8000000),
  main= paste0("Mejor gan prom= ", as.integer(resultado$ganancia_suavizada_max), " envios= ", resultado$envios),
  xlab= "Envios",
  ylab= "Ganancia",
  panel.first= grid()
)

dev.off()
# Out:
# agg_record_1976824002
#                     2

# %%
# grabo los parametros
if( !require("yaml")) install.packages("yaml")
require("yaml")

PARAM$resultado <- resultado

write_yaml( PARAM, file="PARAM.yml")
# Out:
# Loading required package: yaml

# %%
format(Sys.time(), "%a %b %d %X %Y")
fin <- Sys.time()

# Duración en segundos
secs <- as.numeric(difftime(fin, principio, units = "secs"))
secs <- round(secs)

# A hh:mm:ss
h <- secs %/% 3600
m <- (secs %% 3600) %/% 60
s <- secs %% 60
dur_hms <- sprintf("%02d:%02d:%02d", h, m, s)

cat(
  "Inicio: ", format(principio, "%a %b %d %X %Y"), "\n",
  "Fin:    ", format(fin,       "%a %b %d %X %Y"), "\n",
  "Duración (hh:mm:ss): ", dur_hms, "\n",
  sep = ""
)
# Out:
# [1] "Thu Nov 20 07:48:23 AM 2025"
# Inicio: Thu Nov 20 12:58:17 AM 2025
# Fin:    Thu Nov 20 07:48:23 AM 2025
# Duración (hh:mm:ss): 06:50:06
