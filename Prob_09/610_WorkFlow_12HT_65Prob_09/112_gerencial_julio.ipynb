# %% [markdown]
# <a href="https://colab.research.google.com/github/jwbarbona/labo2025v/blob/main/610_WorkFlow_12HT_65112_gerencial_julio.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # 6 WorkFlow  Gerencial, futuro=JULIO

# %% [markdown]
# ### 6.1 Objetivo

# %% [markdown]
# Presentar un workflow/pipeline completo al que los estudiantes deberán enriquecer

# %% [markdown]
# #### 6.2  Seteo del ambiente en Google Colab

# %% [markdown]
# Esta parte se debe correr con el runtime en Python3
# <br>Ir al menu, Runtime -> Change Runtime Type -> Runtime type ->  **Python 3**

# %% [markdown]
# Conectar la virtual machine donde esta corriendo Google Colab con el  Google Drive, para poder tener persistencia de archivos

# %%
# primero establecer el Runtime de Python 3
from google.colab import drive
drive.mount('/content/.drive')
# Out:
# Mounted at /content/.drive

# %% [markdown]
# Para correr la siguiente celda es fundamental en Arranque en Frio haber copiado el archivo kaggle.json al Google Drive, en la carpeta indicada en el instructivo
#
# <br>los siguientes comando estan en shell script de Linux
# *   Crear las carpetas en el Google Drive
# *   "instalar" el archivo kaggle.json desde el Google Drive a la virtual machine para que pueda ser utilizado por la libreria  kaggle de Python
# *   Bajar el  **dataset_pequeno**  al  Google Drive  y tambien al disco local de la virtual machine que esta corriendo Google Colab
# *   Bajar el **dataset_historico** al Google Drive y tambien al disco local de la virtual machine que esta corriendo Google Colab

# %%
%%shell

mkdir -p "/content/.drive/My Drive/labo1"
mkdir -p "/content/buckets"
ln -s "/content/.drive/My Drive/labo1" /content/buckets/b1

mkdir -p ~/.kaggle
cp /content/buckets/b1/kaggle/kaggle.json  ~/.kaggle
chmod 600 ~/.kaggle/kaggle.json


mkdir -p /content/buckets/b1/exp
mkdir -p /content/buckets/b1/datasets
mkdir -p /content/datasets


webfiles="https://storage.googleapis.com/open-courses/austral2025-af91/"
destino_local="/content/datasets"
destino_bucket="/content/buckets/b1/datasets"


archivo="dataset_pequeno.csv"

if ! test -f $destino_bucket/$archivo; then
  wget  $webfiles/$archivo  -O $destino_bucket/$archivo
fi


if ! test -f $destino_local/$pequeno; then
  cp  $destino_bucket/$archivo  $destino_local/$archivo
fi

#-------

archivo="gerencial_competencia_2025.csv.gz"

if ! test -f $destino_bucket/$archivo; then
  wget  $webfiles/$archivo  -O $destino_bucket/$archivo
fi


if ! test -f $destino_local/$pequeno; then
  cp  $destino_bucket/$archivo  $destino_local/$archivo
fi
# Out:
# cp: cannot stat '/content/buckets/b1/kaggle/kaggle.json': No such file or directory
# chmod: cannot access '/root/.kaggle/kaggle.json': No such file or directory

# %% [markdown]
# ## 6.3  Workflow

# %% [markdown]
# ## Inicializacion

# %% [markdown]
# Esta parte se debe correr con el runtime en lenguaje **R** Ir al menu, Runtime -> Change Runtime Type -> Runtime type -> R

# %% [markdown]
# limpio el ambiente de R

# %%
format(Sys.time(), "%a %b %d %X %Y")
# Out:
# [1] "Thu Nov 20 01:01:20 AM 2025"

# %%
# limpio la memoria
rm(list=ls(all.names=TRUE)) # remove all objects
gc(full=TRUE, verbose=FALSE) # garbage collection
# Out:
#        used    (Mb) gc trigger (Mb) max used (Mb)
# Ncells  660442 35.3 1454497    77.7 1437477  76.8
# Vcells 1226661  9.4 8388608    64.0 1975136  15.1

# %%
principio <- Sys.time()

# %%
require("data.table")

if( !require("R.utils")) install.packages("R.utils")
require("R.utils")
# Out:
# Loading required package: data.table
#
# Loading required package: R.utils
#
# Warning message in library(package, lib.loc = lib.loc, character.only = TRUE, logical.return = TRUE, :
# “there is no package called ‘R.utils’”
# Installing package into ‘/usr/local/lib/R/site-library’
# (as ‘lib’ is unspecified)
#
# also installing the dependencies ‘R.oo’, ‘R.methodsS3’
#
#
# Loading required package: R.utils
#
# Loading required package: R.oo
#
# Loading required package: R.methodsS3
#
# R.methodsS3 v1.8.2 (2022-06-13 22:00:14 UTC) successfully loaded. See ?R.methodsS3 for help.
#
# R.oo v1.27.1 (2025-05-02 21:00:05 UTC) successfully loaded. See ?R.oo for help.
#
#
# Attaching package: ‘R.oo’
#
#
# The following object is masked from ‘package:R.methodsS3’:
#
#     throw
#
#
# The following objects are masked from ‘package:methods’:
#
#     getClasses, getMethods
#
#
# The following objects are masked from ‘package:base’:
#
#     attach, detach, load, save
#
#
# R.utils v2.13.0 (2025-02-24 21:20:02 UTC) successfully loaded. See ?R.utils for help.
#
#
# Attaching package: ‘R.utils’
#
#
# The following object is masked from ‘package:utils’:
#
#     timestamp
#
#
# The following objects are masked from ‘package:base’:
#
#     cat, commandArgs, getOption, isOpen, nullfile, parse, use, warnings

# %% [markdown]
# #### Parametros
# Si es gerente, no cambie nada
# <br>Si es Analista, cambie el nombre del dataset

# %%
PARAM <- list()
PARAM$semilla_primigenia <- 200003 # 100009, 200003, 499999, 700009, 999983

PARAM$experimento <- 65112 # 12HT
PARAM$dataset <- "gerencial_competencia_2025.csv.gz"

# %% [markdown]
# #### Carpeta del Experimento

# %%
# carpeta de trabajo

setwd("/content/buckets/b1/exp")
experimento_folder <- paste0("WF", PARAM$experimento)
dir.create(experimento_folder, showWarnings=FALSE)
setwd( paste0("/content/buckets/b1/exp/", experimento_folder ))

# %% [markdown]
# ### 6.3.1   Preprocesamiento del dataset

# %% [markdown]
# #### 6.3.1.1  DT incorporar dataset

# %%
# lectura del dataset
dataset <- fread(paste0("/content/datasets/", PARAM$dataset))

# %% [markdown]
# #### 6.3.1.2  CA  Catastrophe Analysis
# Se intentan reparar las variables que para un mes están con todos los valores en cero.

# %% [markdown]
# El método que se utiliza es **Machine Learning** se asigna NA also valores, si ha leido bien, es la "anti imputación de valores faltantes"
# <br> Usted podrá aplicar aquí otros métodos

# %%
dataset[ foto_mes==202006, internet:=NA]
dataset[ foto_mes==202006, mrentabilidad:=NA]
dataset[ foto_mes==202006, mrentabilidad_annual:=NA]
dataset[ foto_mes==202006, mcomisiones:=NA]
dataset[ foto_mes==202006, mactivos_margen:=NA]
dataset[ foto_mes==202006, mpasivos_margen:=NA]
dataset[ foto_mes==202006, mcuentas_saldo:=NA]
dataset[ foto_mes==202006, ctarjeta_visa_transacciones:=NA]
dataset[ foto_mes==202006, mtarjeta_visa_consumo:=NA]
dataset[ foto_mes==202006, mtarjeta_master_consumo:=NA]
dataset[ foto_mes==202006, ccallcenter_transacciones:=NA]
dataset[ foto_mes==202006, chomebanking_transacciones:=NA]
dataset[ foto_mes==202006, chomebanking_transacciones:=NA]

# %% [markdown]
# #### 6.3.1.3  DR  Data Drifting
# Se intenta corregir el data drifting, quizas ajustando por IPC ...
# <br>Esta parte podrá ser abordada por todos los Analistas y también la Gerenciapero se decide pedagogicamente no incluirla en esta primer version para reducir la carga cognitiva

# %%
# sin codigo en esta primera version del workflow

# %% [markdown]
# #### 6.3.1.3  FE_intra_manual Feature Engineering intra-mes
#
# Agrego campos nuevos dentro del mismo mes, SIN considerar la historia.

# %%
# esta funcion atributos presentes existe debido a que las modalidades poseen datasets con distinta cantidad de campos
atributos_presentes <- function( patributos )
{
  atributos <- unique( patributos )
  comun <- intersect( atributos, colnames(dataset) )

  return(  length( atributos ) == length( comun ) )
}

# el mes 1,2, ..12
if( atributos_presentes( c("foto_mes") ))
  dataset[, kmes := foto_mes %% 100]

# variable extraida de una tesis de maestria de Irlanda
if( atributos_presentes( c("mpayroll", "cliente_edad") ))
  dataset[, mpayroll_sobre_edad := mpayroll / cliente_edad]

# %%
# visualizo las columas del dataset a esta etapa
colnames(dataset)
# Out:
#  [1] "numero_de_cliente"           "foto_mes"
#  [3] "internet"                    "cliente_edad"
#  [5] "cliente_antiguedad"          "mrentabilidad"
#  [7] "mrentabilidad_annual"        "mcomisiones"
#  [9] "mactivos_margen"             "mpasivos_margen"
# [11] "cproductos"                  "mcuenta_corriente"
# [13] "mcaja_ahorro"                "cdescubierto_preacordado"
# [15] "mcuentas_saldo"              "ctarjeta_visa_transacciones"
# [17] "mtarjeta_visa_consumo"       "mtarjeta_master_consumo"
# [19] "mprestamos_personales"       "cpayroll_trx"
# [21] "mpayroll"                    "ccomisiones_mantenimiento"
# [23] "ccallcenter_transacciones"   "chomebanking_transacciones"
# [25] "ctrx_quarter"                "Master_status"
# [27] "Master_fechaalta"            "Master_mpagominimo"
# [29] "Visa_status"                 "Visa_fechaalta"
# [31] "Visa_mpagominimo"            "clase_ternaria"
# [33] "kmes"                        "mpayroll_sobre_edad"

# %% [markdown]
# #### 6.3.1.4  FE_rf Feature Engineering de nuevas variables a partir de hojas de Random Forest
#
# Esto se mostrará unicamente a la *modalidad Analista Sr*

# %%
# No se implementa Feature Engineering a partir de Random Forest

# %% [markdown]
# #### 6.3.1.5  FEhist Feature Engineering historico
#
# El Fature Engineering Histórico es la etapa que más aporta a la ganancia final, ya que enriquece cada registro del dataset con su historia.

# %% [markdown]
# Para cada campo del dataset original (*)
# se crean lo siguientes campos de a partir de la historia
# * lag1  lags de orden 1
# * delta1  =  valor actual - lag1
# * lag2  lags de orden 2
# * delta2  = valor actual - lag2
#
#
# (*) Excepto para los campos  <numero_de_cliente,  foto_mes,  clase_ternaria>

# %%
# Feature Engineering Historico

# todo es lagueable, menos la primary key y la clase
cols_lagueables <- copy( setdiff(
    colnames(dataset),
    c("numero_de_cliente", "foto_mes", "clase_ternaria")
) )

# https://rdrr.io/cran/data.table/man/shift.html

# lags de orden 1
dataset[,
    paste0(cols_lagueables, "_lag1") := shift(.SD, 1, NA, "lag"),
    by = numero_de_cliente,
    .SDcols = cols_lagueables
]

# lags de orden 2
dataset[,
    paste0(cols_lagueables, "_lag2") := shift(.SD, 2, NA, "lag"),
    by = numero_de_cliente,
    .SDcols = cols_lagueables
]

# agrego los delta lags
for (vcol in cols_lagueables)
{
    dataset[, paste0(vcol, "_delta1") := get(vcol) - get(paste0(vcol, "_lag1"))]
    dataset[, paste0(vcol, "_delta2") := get(vcol) - get(paste0(vcol, "_lag2"))]
}

# %% [markdown]
# Verificacion de los campos recien creados

# %%
ncol(dataset)
colnames(dataset)
# Out:
# [1] 158
#   [1] "numero_de_cliente"                  "foto_mes"
#   [3] "internet"                           "cliente_edad"
#   [5] "cliente_antiguedad"                 "mrentabilidad"
#   [7] "mrentabilidad_annual"               "mcomisiones"
#   [9] "mactivos_margen"                    "mpasivos_margen"
#  [11] "cproductos"                         "mcuenta_corriente"
#  [13] "mcaja_ahorro"                       "cdescubierto_preacordado"
#  [15] "mcuentas_saldo"                     "ctarjeta_visa_transacciones"
#  [17] "mtarjeta_visa_consumo"              "mtarjeta_master_consumo"
#  [19] "mprestamos_personales"              "cpayroll_trx"
#  [21] "mpayroll"                           "ccomisiones_mantenimiento"
#  [23] "ccallcenter_transacciones"          "chomebanking_transacciones"
#  [25] "ctrx_quarter"                       "Master_status"
#  [27] "Master_fechaalta"                   "Master_mpagominimo"
#  [29] "Visa_status"                        "Visa_fechaalta"
#  [31] "Visa_mpagominimo"                   "clase_ternaria"
#  [33] "kmes"                               "mpayroll_sobre_edad"
#  [35] "internet_lag1"                      "cliente_edad_lag1"
#  [37] "cliente_antiguedad_lag1"            "mrentabilidad_lag1"
#  [39] "mrentabilidad_annual_lag1"          "mcomisiones_lag1"
#  [41] "mactivos_margen_lag1"               "mpasivos_margen_lag1"
#  [43] "cproductos_lag1"                    "mcuenta_corriente_lag1"
#  [45] "mcaja_ahorro_lag1"                  "cdescubierto_preacordado_lag1"
#  [47] "mcuentas_saldo_lag1"                "ctarjeta_visa_transacciones_lag1"
#  [49] "mtarjeta_visa_consumo_lag1"         "mtarjeta_master_consumo_lag1"
#  [51] "mprestamos_personales_lag1"         "cpayroll_trx_lag1"
#  [53] "mpayroll_lag1"                      "ccomisiones_mantenimiento_lag1"
#  [55] "ccallcenter_transacciones_lag1"     "chomebanking_transacciones_lag1"
#  [57] "ctrx_quarter_lag1"                  "Master_status_lag1"
#  [59] "Master_fechaalta_lag1"              "Master_mpagominimo_lag1"
#  [61] "Visa_status_lag1"                   "Visa_fechaalta_lag1"
#  [63] "Visa_mpagominimo_lag1"              "kmes_lag1"
#  [65] "mpayroll_sobre_edad_lag1"           "internet_lag2"
#  [67] "cliente_edad_lag2"                  "cliente_antiguedad_lag2"
#  [69] "mrentabilidad_lag2"                 "mrentabilidad_annual_lag2"
#  [71] "mcomisiones_lag2"                   "mactivos_margen_lag2"
#  [73] "mpasivos_margen_lag2"               "cproductos_lag2"
#  [75] "mcuenta_corriente_lag2"             "mcaja_ahorro_lag2"
#  [77] "cdescubierto_preacordado_lag2"      "mcuentas_saldo_lag2"
#  [79] "ctarjeta_visa_transacciones_lag2"   "mtarjeta_visa_consumo_lag2"
#  [81] "mtarjeta_master_consumo_lag2"       "mprestamos_personales_lag2"
#  [83] "cpayroll_trx_lag2"                  "mpayroll_lag2"
#  [85] "ccomisiones_mantenimiento_lag2"     "ccallcenter_transacciones_lag2"
#  [87] "chomebanking_transacciones_lag2"    "ctrx_quarter_lag2"
#  [89] "Master_status_lag2"                 "Master_fechaalta_lag2"
#  [91] "Master_mpagominimo_lag2"            "Visa_status_lag2"
#  [93] "Visa_fechaalta_lag2"                "Visa_mpagominimo_lag2"
#  [95] "kmes_lag2"                          "mpayroll_sobre_edad_lag2"
#  [97] "internet_delta1"                    "internet_delta2"
#  [99] "cliente_edad_delta1"                "cliente_edad_delta2"
# [101] "cliente_antiguedad_delta1"          "cliente_antiguedad_delta2"
# [103] "mrentabilidad_delta1"               "mrentabilidad_delta2"
# [105] "mrentabilidad_annual_delta1"        "mrentabilidad_annual_delta2"
# [107] "mcomisiones_delta1"                 "mcomisiones_delta2"
# [109] "mactivos_margen_delta1"             "mactivos_margen_delta2"
# [111] "mpasivos_margen_delta1"             "mpasivos_margen_delta2"
# [113] "cproductos_delta1"                  "cproductos_delta2"
# [115] "mcuenta_corriente_delta1"           "mcuenta_corriente_delta2"
# [117] "mcaja_ahorro_delta1"                "mcaja_ahorro_delta2"
# [119] "cdescubierto_preacordado_delta1"    "cdescubierto_preacordado_delta2"
# [121] "mcuentas_saldo_delta1"              "mcuentas_saldo_delta2"
# [123] "ctarjeta_visa_transacciones_delta1" "ctarjeta_visa_transacciones_delta2"
# [125] "mtarjeta_visa_consumo_delta1"       "mtarjeta_visa_consumo_delta2"
# [127] "mtarjeta_master_consumo_delta1"     "mtarjeta_master_consumo_delta2"
# [129] "mprestamos_personales_delta1"       "mprestamos_personales_delta2"
# [131] "cpayroll_trx_delta1"                "cpayroll_trx_delta2"
# [133] "mpayroll_delta1"                    "mpayroll_delta2"
# [135] "ccomisiones_mantenimiento_delta1"   "ccomisiones_mantenimiento_delta2"
# [137] "ccallcenter_transacciones_delta1"   "ccallcenter_transacciones_delta2"
# [139] "chomebanking_transacciones_delta1"  "chomebanking_transacciones_delta2"
# [141] "ctrx_quarter_delta1"                "ctrx_quarter_delta2"
# [143] "Master_status_delta1"               "Master_status_delta2"
# [145] "Master_fechaalta_delta1"            "Master_fechaalta_delta2"
# [147] "Master_mpagominimo_delta1"          "Master_mpagominimo_delta2"
# [149] "Visa_status_delta1"                 "Visa_status_delta2"
# [151] "Visa_fechaalta_delta1"              "Visa_fechaalta_delta2"
# [153] "Visa_mpagominimo_delta1"            "Visa_mpagominimo_delta2"
# [155] "kmes_delta1"                        "kmes_delta2"
# [157] "mpayroll_sobre_edad_delta1"         "mpayroll_sobre_edad_delta2"

# %% [markdown]
# #### 6.3.1.6  FEhist Reduccion dimensionalidad con canaritos
#
# Esta etapa solo se mostrará a la *modalidad Anlista Sr* por algun canal secreto de forma de no confundir a los *Analista Jr*  nni distraer con detalles operativos a la estratégica *Modalidad Gerencial*

# %%
# No se implementa la reduccion de la dimensionalidad con canaritos

# %% [markdown]
# ### 6.3.2 Modelado

# %% [markdown]
# #### 6.3.2.1 Training Strategy
#
# Esta etapa de Workflow de  Training Strategy esta pensada para la *Modalidad Gerencial* que posee el dataset de [202005, 202109]
# <br> Si usted es un Analista, posee el periodo de [201901, 202109] y deberá experimentar en que meses le conviene experimentar
#
# <br> A la *Modalidad Gerencial* no se le complicada la vida con el undersampling de los continua, por eso PARAM$trainingstrategy$training_pct <- 1.0
# <br> Sin embargo, si usted es  *Analista SR* posee un dataset 50 veces ( filas x columnas) más grande que la *Modalidad Gerencial*  y por un tema de velocidad y experimentación más rápida puede llegar a necesitar activar el undersampling de la clase mayoritaria, a pesar de estar corriendo en Google Cloud.

# %% [markdown]
# Se hace una estrategia de entrenamiento muy sencilla, tomando todos los meses posibles, SIN eliminar nada x pandemia ni por ningun otro motivo
#
# * future = 202107  obviamente completo
#
# * final_train =  [ 202005, 202105 ]  SIN undersampling
#
# * training
#    * testing = NO HAY
#    * validation =  202105   completo, sin undersampling
#    * training = [ 202005, 202104 ]  donde se consideran el 100% de los CONTINUA

# %%
PARAM$trainingstrategy$validate <- c(202105)

PARAM$trainingstrategy$training <- c(
  202104, 202103, 202102, 202101,
  202012, 202011, 202010, 202009, 202008, 202007,
  202006, 202005
)

PARAM$trainingstrategy$training_pct <- 1.0


PARAM$trainingstrategy$positivos <- c( "BAJA+1", "BAJA+2")

# %%
# seteo la clase01   1={BAJA+1, BAJA+2}   0={CONTINUA}
dataset[, clase01 := ifelse( clase_ternaria %in% PARAM$trainingstrategy$positivos, 1, 0 )]

# %%
# los campos en los que se entrena
campos_buenos <- copy( setdiff(
    colnames(dataset), c("clase_ternaria","clase01","azar"))
)

# %%
# preparo para que se puede hacer undersampling de los CONTINUA
#  solamente por un tema de VELOCIDAD
set.seed(PARAM$semilla_primigenia, kind = "L'Ecuyer-CMRG")
dataset[, azar:=runif(nrow(dataset))]

# undersampling de los CONTINUA
dataset[, fold_train :=  foto_mes %in%  PARAM$trainingstrategy$training &
    (clase_ternaria %in% c("BAJA+1", "BAJA+2") |
     azar < PARAM$trainingstrategy$training_pct ) ]


if( !require("lightgbm")) install.packages("lightgbm")
require("lightgbm")

dtrain <- lgb.Dataset(
  data= data.matrix(dataset[fold_train == TRUE, campos_buenos, with = FALSE]),
  label= dataset[fold_train == TRUE, clase01],
  free_raw_data= TRUE
)
# Out:
# Loading required package: lightgbm
#
# Warning message in library(package, lib.loc = lib.loc, character.only = TRUE, logical.return = TRUE, :
# “there is no package called ‘lightgbm’”
# Installing package into ‘/usr/local/lib/R/site-library’
# (as ‘lib’ is unspecified)
#
# Loading required package: lightgbm

# %%
# datos de validation
dvalidate <- lgb.Dataset(
  data= data.matrix(dataset[foto_mes %in% PARAM$trainingstrategy$validate, campos_buenos, with = FALSE]),
  label= dataset[foto_mes %in% PARAM$trainingstrategy$validate, clase01],
  free_raw_data= TRUE
)

nrow(dvalidate)
# Out:
# [1] 16469

# %% [markdown]
# ####  6.3.2.2. Hyperparameter Tuning

# %% [markdown]
# * Clase binaria que se optimiza :  positivos = [ BAJA+1, BAJA+2 ]

# %% [markdown]
# * Metrica que se optimiza **AUC** Area Under Curve de la  ROC Curve
#
# es muy importante notar que intencionalmente  **NO** se está optimizando la funcion de ganancia del problema

# %% [markdown]
# * Cantidad de iteraciones inteligentes de la Optimizacion Bayesiana = **10**

# %% [markdown]
# * Parametros no default, fijos de LightGBM que no se optimizan
#   * max_bin = 31 , Alienigenas Ancestrales contruyeron las pirámides y dejaron a la humanidad en un jeroglifico  *max_bin=31*
#   * feature_fraction = 0.5  para poner algo que generalmente no falla
#   * learning_rate = 0.03  para que aprenda lento

# %% [markdown]
# * Parametros que se optimizan en la Bayesian Optimization
#   * num_leaves  [8, 256]
#   * min_data_in_leaf  [8, 8192]

# %%
# paquetes necesarios para la Bayesian Optimization
if(!require("DiceKriging")) install.packages("DiceKriging")
require("DiceKriging")

if(!require("mlrMBO")) install.packages("mlrMBO")
require("mlrMBO")
# Out:
# Loading required package: DiceKriging
#
# Warning message in library(package, lib.loc = lib.loc, character.only = TRUE, logical.return = TRUE, :
# “there is no package called ‘DiceKriging’”
# Installing package into ‘/usr/local/lib/R/site-library’
# (as ‘lib’ is unspecified)
#
# Loading required package: DiceKriging
#
# Loading required package: mlrMBO
#
# Warning message in library(package, lib.loc = lib.loc, character.only = TRUE, logical.return = TRUE, :
# “there is no package called ‘mlrMBO’”
# Installing package into ‘/usr/local/lib/R/site-library’
# (as ‘lib’ is unspecified)
#
# also installing the dependencies ‘XML’, ‘fastmatch’, ‘RcppArmadillo’, ‘mlr’, ‘ParamHelpers’, ‘smoof’, ‘BBmisc’, ‘checkmate’, ‘lhs’, ‘parallelMap’
#
#
# Loading required package: mlrMBO
#
# Loading required package: mlr
#
# Loading required package: ParamHelpers
#
#
# Attaching package: ‘ParamHelpers’
#
#
# The following object is masked from ‘package:R.utils’:
#
#     isVector
#
#
#
# Attaching package: ‘mlr’
#
#
# The following objects are masked from ‘package:R.utils’:
#
#     resample, setThreshold
#
#
# Loading required package: smoof
#
# Loading required package: checkmate
#
#
# Attaching package: ‘checkmate’
#
#
# The following object is masked from ‘package:DiceKriging’:
#
#     checkNames
#
#
# The following object is masked from ‘package:R.utils’:
#
#     asInt
#
#
#
# Attaching package: ‘smoof’
#
#
# The following objects are masked from ‘package:R.oo’:
#
#     getDescription, getName

# %% [markdown]
# Definición de la Bayesian Optimization
# <br> Si se desea optimizar un hiperparámetro que esta como fijo, debe QUITARSE de param_fijos y agregarse a PARAM$hipeparametertuning$hs

# %%
# valor ridiculamente bajo para que corra rapido en el aula y no molestar a la *Modalidad Gerencial*
PARAM$hipeparametertuning$num_interations <- 100

# parametros fijos del LightGBM
PARAM$lgbm$param_fijos <- list(
  objective= "binary",
  metric= "auc",
  first_metric_only= TRUE,
  boost_from_average= TRUE,
  feature_pre_filter= FALSE,
  verbosity= -100,
  force_row_wise= TRUE, # para evitar warning
  max_bin= 31,
  seed= PARAM$semilla_primigenia
  # learning_rate= 0.03,
  # feature_fraction= 0.5,
  # num_iterations= 2048,  # valor grande, lo limita early_stopping_rounds
  # early_stopping_rounds= 200
)


PARAM$hipeparametertuning$hs <- makeParamSet(
  # Núcleo del modelo (estructura de árboles)
  makeIntegerParam("num_leaves", lower = 2L, upper = 8192L),
  #makeIntegerParam("max_depth", lower = 3L, upper = 30L),
  makeNumericParam("min_child_weight", lower = 0.001, upper = 10.0),
  makeIntegerParam("min_data_in_leaf", lower = 2L, upper = 8192L),
  makeNumericParam("min_gain_to_split", lower = 0.0, upper = 0.1),

  # Regularización
  makeNumericParam("lambda_l1", lower = 0.0, upper = 1000L),
  makeNumericParam("lambda_l2", lower = 0.0, upper = 1000L),
  makeNumericParam("scale_pos_weight", lower = 1.0, upper = 5.0),  # útil en desequilibrio

  # Control del aprendizaje
  makeNumericParam("learning_rate", lower = 0.005, upper = 0.1),
  makeIntegerParam("num_iterations", lower = 100L, upper = 5000L),
  makeIntegerParam("early_stopping_rounds", lower = 50L, upper = 500L),

  # Submuestreo
  makeNumericParam("feature_fraction", lower = 0.05, upper = 1L),   # columnas
  makeNumericParam("bagging_fraction", lower = 0.5, upper = 1L)   # filas
  #makeIntegerParam("bagging_freq", lower = 0L, upper = 5L),         # cada N iteraciones

  # Opcionales útiles
  #makeNumericParam("max_delta_step", lower = 0.0, upper = 10.0),
  #makeNumericParam("path_smooth", lower = 0.0, upper = 10.0)
)
# Total: 12 hT

# %% [markdown]
# Función "señora caja negra"  que es llamada para verificar la realidad por la Bayesian Optimization

# %%
# En  x llegan los parmaetros de la bayesiana
#  devuelve la AUC en validate del modelo entrenado
#  en el parametro x llegan los hiperparámetros que se estan optimizando

EstimarGanancia_AUC_lightgbm <- function(x) {

  # x pisa (o agrega) a param_fijos
  param_completo <- modifyList(PARAM$lgbm$param_fijos, x)

  # entreno LightGBM
  modelo_train <- lgb.train(
    data= dtrain,
    valids= list(valid = dvalidate),
    eval= "auc",
    param= param_completo,
    verbose= -100
  )

  # recupero la AUC en validation
  AUC <- modelo_train$record_evals$valid$auc$eval[[modelo_train$best_iter]]

  # esta es la forma de devolver un parametro extra
  attr(AUC, "extras") <- list("num_iterations"= modelo_train$best_iter)

  # hago espacio en la memoria
  rm(modelo_train)
  gc(full= TRUE, verbose= FALSE)

  message(format(Sys.time(), "%a %b %d %X %Y"), " AUC ", AUC)

  return(AUC)
}

# %% [markdown]
# seteo de la Bayesian Optimization (complejo)
# <br> copiado y pegado de la documentación de la librería

# %%
configureMlr(show.learner.output = FALSE)

# configuro la busqueda bayesiana,  los hiperparametros que se van a optimizar
# por favor, no desesperarse por lo complejo
obj.fun <- makeSingleObjectiveFunction(
    fn= EstimarGanancia_AUC_lightgbm, # la funcion que voy a maximizar
    minimize= FALSE, # estoy Maximizando AUC
    noisy= FALSE,
    par.set= PARAM$hipeparametertuning$hs,
    has.simple.signature= FALSE # paso los parametros en una lista
)

# cada 600 segundos guardo el resultado intermedio
ctrl <- makeMBOControl(
    save.on.disk.at.time= 600,
    save.file.path= "HT.RDATA"
)

# indico la cantidad de iteraciones que va a tener la Bayesian Optimization
ctrl <- setMBOControlTermination(
    ctrl,
    iters= PARAM$hipeparametertuning$num_interations  # cantidad de iteraciones inteligentes
)

# defino el método estandar para la creacion de los puntos iniciales
#   los "No Inteligentes"
ctrl <- setMBOControlInfill(ctrl, crit = makeMBOInfillCritEI())

# mas configuraciones
surr.km <- makeLearner(
    "regr.km",
    predict.type= "se",
    covtype= "matern3_2",
    control= list(trace = TRUE)
)

# %% [markdown]
# Corrida de la Bayesian Optimization,  aqui se hace el trabajo pesado
# <br> por favor no se asuste con los warnings que pudieran aparecer
#
# Si corrío a medias y llegó a las iteraciones inteligentes, en el archivo binario HT.RDATA quedó lo ya procesado y es utilizado para retomar la corrida desde lo último que llegó a grabar.

# %%
# inicio la optimizacion bayesiana

if (!file.exists("HT.RDATA")) {
  bayesiana_salida <- mbo(obj.fun, learner= surr.km, control= ctrl)
} else {
  bayesiana_salida <- mboContinue("HT.RDATA") # retomo en caso que ya exista
}
# Out:
# Computing y column(s) for design. Not provided.
#
# Thu Nov 20 01:15:20 AM 2025 AUC 0.886716372438294
#
# Thu Nov 20 01:15:44 AM 2025 AUC 0.885312840355691
#
# Thu Nov 20 01:16:45 AM 2025 AUC 0.898706287676096
#
# Thu Nov 20 01:17:15 AM 2025 AUC 0.899069837045328
#
# Thu Nov 20 01:17:39 AM 2025 AUC 0.890630022500804
#
# Thu Nov 20 01:18:13 AM 2025 AUC 0.896813549335679
#
# Thu Nov 20 01:18:23 AM 2025 AUC 0.890902139287557
#
# Thu Nov 20 01:18:52 AM 2025 AUC 0.88626474581071
#
# Thu Nov 20 01:19:31 AM 2025 AUC 0.889311044586218
#
# Thu Nov 20 01:20:49 AM 2025 AUC 0.904279816584562
#
# Thu Nov 20 01:22:06 AM 2025 AUC 0.903555234339192
#
# Thu Nov 20 01:23:32 AM 2025 AUC 0.909048235468594
#
# Thu Nov 20 01:24:07 AM 2025 AUC 0.903134812225996
#
# Thu Nov 20 01:24:31 AM 2025 AUC 0.865816226213268
#
# Thu Nov 20 01:25:13 AM 2025 AUC 0.884908691564514
#
# Thu Nov 20 01:25:26 AM 2025 AUC 0.881900307951648
#
# Thu Nov 20 01:27:00 AM 2025 AUC 0.911848588985545
#
# Thu Nov 20 01:27:29 AM 2025 AUC 0.887284764345521
#
# Thu Nov 20 01:29:43 AM 2025 AUC 0.893106587239434
#
# Thu Nov 20 01:30:31 AM 2025 AUC 0.893456715312156
#
# Thu Nov 20 01:30:47 AM 2025 AUC 0.8808871678313
#
# Thu Nov 20 01:31:28 AM 2025 AUC 0.901580122791442
#
# Thu Nov 20 01:32:01 AM 2025 AUC 0.882551744131035
#
# Thu Nov 20 01:32:45 AM 2025 AUC 0.892197462167043
#
# Thu Nov 20 01:32:52 AM 2025 AUC 0.881503037574933
#
# Thu Nov 20 01:34:42 AM 2025 AUC 0.900057980000926
#
# Thu Nov 20 01:35:00 AM 2025 AUC 0.883701613709586
#
# Thu Nov 20 01:35:51 AM 2025 AUC 0.893691084702473
#
# Thu Nov 20 01:36:15 AM 2025 AUC 0.894326247559841
#
# Thu Nov 20 01:36:57 AM 2025 AUC 0.888017567135003
#
# Thu Nov 20 01:39:10 AM 2025 AUC 0.919157827065252
#
# Thu Nov 20 01:39:33 AM 2025 AUC 0.896648802921011
#
# Thu Nov 20 01:41:12 AM 2025 AUC 0.887530038539253
#
# Thu Nov 20 01:41:37 AM 2025 AUC 0.870025815863838
#
# Thu Nov 20 01:42:33 AM 2025 AUC 0.91433186437243
#
# Thu Nov 20 01:42:49 AM 2025 AUC 0.905089959595187
#
# Thu Nov 20 01:43:17 AM 2025 AUC 0.865151536503578
#
# Thu Nov 20 01:43:45 AM 2025 AUC 0.89935319416791
#
# Thu Nov 20 01:44:42 AM 2025 AUC 0.902133247973887
#
# Thu Nov 20 01:45:08 AM 2025 AUC 0.855615369800338
#
# Thu Nov 20 01:45:25 AM 2025 AUC 0.884813232593082
#
# Thu Nov 20 01:45:37 AM 2025 AUC 0.875697823535451
#
# Thu Nov 20 01:47:30 AM 2025 AUC 0.902671106431552
#
# Thu Nov 20 01:48:23 AM 2025 AUC 0.915736403052271
#
# Thu Nov 20 01:48:32 AM 2025 AUC 0.894925843981454
#
# Thu Nov 20 01:49:07 AM 2025 AUC 0.902322823787101
#
# Thu Nov 20 01:49:32 AM 2025 AUC 0.869814262677589
#
# Thu Nov 20 01:50:18 AM 2025 AUC 0.886106374511884
#
# [mbo] 0: num_leaves=6215; min_child_weight=1.49; min_data_in_leaf=3146; min_gain_to_split=0.0619; lambda_l1=748; lambda_l2=797; scale_pos_weight=3.21; learning_rate=0.0833; num_iterations=2720; early_stopping_rounds=476; feature_fraction=0.27; bagging_fraction=0.684 : y = 0.887 : 54.9 secs : initdesign
#
# [mbo] 0: num_leaves=4450; min_child_weight=7.3; min_data_in_leaf=5296; min_gain_to_split=0.0483; lambda_l1=507; lambda_l2=791; scale_pos_weight=2.59; learning_rate=0.0514; num_iterations=1728; early_stopping_rounds=273; feature_fraction=0.72; bagging_fraction=0.864 : y = 0.885 : 23.8 secs : initdesign
#
# [mbo] 0: num_leaves=7873; min_child_weight=6.39; min_data_in_leaf=3454; min_gain_to_split=0.0042; lambda_l1=442; lambda_l2=723; scale_pos_weight=4.17; learning_rate=0.0735; num_iterations=2830; early_stopping_rounds=241; feature_fraction=0.464; bagging_fraction=0.922 : y = 0.899 : 61.9 secs : initdesign
#
# [mbo] 0: num_leaves=5165; min_child_weight=6.21; min_data_in_leaf=2773; min_gain_to_split=0.0105; lambda_l1=207; lambda_l2=424; scale_pos_weight=1.8; learning_rate=0.047; num_iterations=2091; early_stopping_rounds=293; feature_fraction=0.787; bagging_fraction=0.85 : y = 0.899 : 29.1 secs : initdesign
#
# [mbo] 0: num_leaves=2421; min_child_weight=5.11; min_data_in_leaf=5813; min_gain_to_split=0.0269; lambda_l1=423; lambda_l2=195; scale_pos_weight=2.07; learning_rate=0.0611; num_iterations=2239; early_stopping_rounds=390; feature_fraction=0.771; bagging_fraction=0.84 : y = 0.891 : 23.9 secs : initdesign
#
# [mbo] 0: num_leaves=1545; min_child_weight=4.23; min_data_in_leaf=1718; min_gain_to_split=0.0597; lambda_l1=615; lambda_l2=873; scale_pos_weight=3.97; learning_rate=0.0219; num_iterations=524; early_stopping_rounds=225; feature_fraction=0.827; bagging_fraction=0.639 : y = 0.897 : 34.4 secs : initdesign
#
# [mbo] 0: num_leaves=3948; min_child_weight=7.77; min_data_in_leaf=2713; min_gain_to_split=0.0419; lambda_l1=473; lambda_l2=449; scale_pos_weight=2.13; learning_rate=0.0568; num_iterations=4770; early_stopping_rounds=99; feature_fraction=0.0701; bagging_fraction=0.753 : y = 0.891 : 9.8 secs : initdesign
#
# [mbo] 0: num_leaves=4903; min_child_weight=3.3; min_data_in_leaf=1694; min_gain_to_split=0.00179; lambda_l1=668; lambda_l2=299; scale_pos_weight=2.87; learning_rate=0.0278; num_iterations=2391; early_stopping_rounds=368; feature_fraction=0.822; bagging_fraction=0.59 : y = 0.886 : 28.9 secs : initdesign
#
# [mbo] 0: num_leaves=7076; min_child_weight=6.63; min_data_in_leaf=5578; min_gain_to_split=0.082; lambda_l1=289; lambda_l2=531; scale_pos_weight=1.89; learning_rate=0.0945; num_iterations=2013; early_stopping_rounds=252; feature_fraction=0.321; bagging_fraction=0.635 : y = 0.889 : 39.2 secs : initdesign
#
# [mbo] 0: num_leaves=3156; min_child_weight=5.47; min_data_in_leaf=7915; min_gain_to_split=0.0755; lambda_l1=138; lambda_l2=829; scale_pos_weight=1.99; learning_rate=0.03; num_iterations=3812; early_stopping_rounds=343; feature_fraction=0.647; bagging_fraction=0.509 : y = 0.904 : 78.5 secs : initdesign
#
# [mbo] 0: num_leaves=4364; min_child_weight=3.45; min_data_in_leaf=2285; min_gain_to_split=0.0375; lambda_l1=340; lambda_l2=233; scale_pos_weight=4.53; learning_rate=0.0599; num_iterations=3222; early_stopping_rounds=360; feature_fraction=0.574; bagging_fraction=0.766 : y = 0.904 : 76.6 secs : initdesign
#
# [mbo] 0: num_leaves=6133; min_child_weight=7.97; min_data_in_leaf=5009; min_gain_to_split=0.0536; lambda_l1=163; lambda_l2=649; scale_pos_weight=4.03; learning_rate=0.0438; num_iterations=1539; early_stopping_rounds=265; feature_fraction=0.585; bagging_fraction=0.963 : y = 0.909 : 86.4 secs : initdesign
#
# [mbo] 0: num_leaves=5536; min_child_weight=0.359; min_data_in_leaf=3384; min_gain_to_split=0.0641; lambda_l1=178; lambda_l2=606; scale_pos_weight=2.67; learning_rate=0.0714; num_iterations=4586; early_stopping_rounds=307; feature_fraction=0.628; bagging_fraction=0.901 : y = 0.903 : 35.0 secs : initdesign
#
# [mbo] 0: num_leaves=75; min_child_weight=2.33; min_data_in_leaf=6030; min_gain_to_split=0.037; lambda_l1=908; lambda_l2=570; scale_pos_weight=1.61; learning_rate=0.0257; num_iterations=2891; early_stopping_rounds=230; feature_fraction=0.622; bagging_fraction=0.798 : y = 0.866 : 24.0 secs : initdesign
#
# [mbo] 0: num_leaves=2796; min_child_weight=5.27; min_data_in_leaf=2499; min_gain_to_split=0.051; lambda_l1=542; lambda_l2=759; scale_pos_weight=3.65; learning_rate=0.0645; num_iterations=1743; early_stopping_rounds=196; feature_fraction=0.113; bagging_fraction=0.706 : y = 0.885 : 41.4 secs : initdesign
#
# [mbo] 0: num_leaves=2354; min_child_weight=4.83; min_data_in_leaf=3601; min_gain_to_split=0.0725; lambda_l1=958; lambda_l2=280; scale_pos_weight=2.81; learning_rate=0.076; num_iterations=3761; early_stopping_rounds=187; feature_fraction=0.849; bagging_fraction=0.647 : y = 0.882 : 12.8 secs : initdesign
#
# [mbo] 0: num_leaves=493; min_child_weight=8.59; min_data_in_leaf=1888; min_gain_to_split=0.0237; lambda_l1=88.9; lambda_l2=118; scale_pos_weight=4.74; learning_rate=0.0501; num_iterations=2576; early_stopping_rounds=433; feature_fraction=0.383; bagging_fraction=0.746 : y = 0.912 : 94.9 secs : initdesign
#
# [mbo] 0: num_leaves=2024; min_child_weight=4.72; min_data_in_leaf=2172; min_gain_to_split=0.0143; lambda_l1=646; lambda_l2=739; scale_pos_weight=3.3; learning_rate=0.0548; num_iterations=4120; early_stopping_rounds=472; feature_fraction=0.761; bagging_fraction=0.947 : y = 0.887 : 28.9 secs : initdesign
#
# [mbo] 0: num_leaves=2946; min_child_weight=1.95; min_data_in_leaf=1163; min_gain_to_split=0.0697; lambda_l1=223; lambda_l2=165; scale_pos_weight=1.37; learning_rate=0.0111; num_iterations=4365; early_stopping_rounds=324; feature_fraction=0.548; bagging_fraction=0.825 : y = 0.893 : 134.0 secs : initdesign
#
# [mbo] 0: num_leaves=3564; min_child_weight=9.96; min_data_in_leaf=7324; min_gain_to_split=0.0205; lambda_l1=644; lambda_l2=686; scale_pos_weight=4.31; learning_rate=0.0336; num_iterations=2464; early_stopping_rounds=152; feature_fraction=0.391; bagging_fraction=0.569 : y = 0.893 : 47.2 secs : initdesign
#
# [mbo] 0: num_leaves=5921; min_child_weight=3.04; min_data_in_leaf=4865; min_gain_to_split=0.0558; lambda_l1=379; lambda_l2=960; scale_pos_weight=1.54; learning_rate=0.0857; num_iterations=1150; early_stopping_rounds=211; feature_fraction=0.869; bagging_fraction=0.804 : y = 0.881 : 16.9 secs : initdesign
#
# [mbo] 0: num_leaves=2078; min_child_weight=2.16; min_data_in_leaf=5688; min_gain_to_split=0.0747; lambda_l1=366; lambda_l2=264; scale_pos_weight=4.96; learning_rate=0.0689; num_iterations=3443; early_stopping_rounds=136; feature_fraction=0.301; bagging_fraction=0.601 : y = 0.902 : 40.4 secs : initdesign
#
# [mbo] 0: num_leaves=6361; min_child_weight=9.77; min_data_in_leaf=3879; min_gain_to_split=0.0872; lambda_l1=996; lambda_l2=46; scale_pos_weight=2.32; learning_rate=0.0384; num_iterations=2343; early_stopping_rounds=209; feature_fraction=0.362; bagging_fraction=0.607 : y = 0.883 : 33.1 secs : initdesign
#
# [mbo] 0: num_leaves=2566; min_child_weight=0.147; min_data_in_leaf=3053; min_gain_to_split=0.0273; lambda_l1=795; lambda_l2=324; scale_pos_weight=3.83; learning_rate=0.024; num_iterations=927; early_stopping_rounds=376; feature_fraction=0.167; bagging_fraction=0.677 : y = 0.892 : 44.2 secs : initdesign
#
# [mbo] 0: num_leaves=213; min_child_weight=7.04; min_data_in_leaf=522; min_gain_to_split=0.0783; lambda_l1=318; lambda_l2=512; scale_pos_weight=1.73; learning_rate=0.0327; num_iterations=100; early_stopping_rounds=156; feature_fraction=0.739; bagging_fraction=0.948 : y = 0.882 : 6.8 secs : initdesign
#
# [mbo] 0: num_leaves=7699; min_child_weight=5.75; min_data_in_leaf=4021; min_gain_to_split=0.0221; lambda_l1=312; lambda_l2=584; scale_pos_weight=3.15; learning_rate=0.0354; num_iterations=3964; early_stopping_rounds=454; feature_fraction=0.445; bagging_fraction=0.624 : y = 0.9 : 110.0 secs : initdesign
#
# [mbo] 0: num_leaves=7336; min_child_weight=3.88; min_data_in_leaf=6426; min_gain_to_split=0.0905; lambda_l1=572; lambda_l2=228; scale_pos_weight=1.48; learning_rate=0.015; num_iterations=204; early_stopping_rounds=411; feature_fraction=0.192; bagging_fraction=0.729 : y = 0.884 : 18.1 secs : initdesign
#
# [mbo] 0: num_leaves=6491; min_child_weight=2.59; min_data_in_leaf=7462; min_gain_to_split=0.0672; lambda_l1=778; lambda_l2=177; scale_pos_weight=4.45; learning_rate=0.0901; num_iterations=1228; early_stopping_rounds=384; feature_fraction=0.42; bagging_fraction=0.527 : y = 0.894 : 50.9 secs : initdesign
#
# [mbo] 0: num_leaves=6795; min_child_weight=1.15; min_data_in_leaf=235; min_gain_to_split=0.0807; lambda_l1=753; lambda_l2=488; scale_pos_weight=4.13; learning_rate=0.0147; num_iterations=820; early_stopping_rounds=74; feature_fraction=0.933; bagging_fraction=0.667 : y = 0.894 : 24.4 secs : initdesign
#
# [mbo] 0: num_leaves=1267; min_child_weight=6.85; min_data_in_leaf=6740; min_gain_to_split=0.0955; lambda_l1=816; lambda_l2=937; scale_pos_weight=2.46; learning_rate=0.0398; num_iterations=3064; early_stopping_rounds=400; feature_fraction=0.256; bagging_fraction=0.99 : y = 0.888 : 41.9 secs : initdesign
#
# [mbo] 0: num_leaves=3837; min_child_weight=5.87; min_data_in_leaf=840; min_gain_to_split=0.016; lambda_l1=2.25; lambda_l2=403; scale_pos_weight=1.14; learning_rate=0.0803; num_iterations=3295; early_stopping_rounds=169; feature_fraction=0.677; bagging_fraction=0.727 : y = 0.919 : 132.5 secs : initdesign
#
# [mbo] 0: num_leaves=5634; min_child_weight=9.32; min_data_in_leaf=1254; min_gain_to_split=0.0335; lambda_l1=534; lambda_l2=4.96; scale_pos_weight=4.75; learning_rate=0.0464; num_iterations=4442; early_stopping_rounds=109; feature_fraction=0.0946; bagging_fraction=0.576 : y = 0.897 : 22.9 secs : initdesign
#
# [mbo] 0: num_leaves=1008; min_child_weight=9.49; min_data_in_leaf=4310; min_gain_to_split=0.00662; lambda_l1=932; lambda_l2=348; scale_pos_weight=3.06; learning_rate=0.0197; num_iterations=1860; early_stopping_rounds=444; feature_fraction=0.514; bagging_fraction=0.782 : y = 0.888 : 99.4 secs : initdesign
#
# [mbo] 0: num_leaves=3667; min_child_weight=4.11; min_data_in_leaf=160; min_gain_to_split=0.0332; lambda_l1=862; lambda_l2=886; scale_pos_weight=2.19; learning_rate=0.0802; num_iterations=4073; early_stopping_rounds=423; feature_fraction=0.882; bagging_fraction=0.548 : y = 0.87 : 24.4 secs : initdesign
#
# [mbo] 0: num_leaves=7479; min_child_weight=8.19; min_data_in_leaf=6973; min_gain_to_split=0.066; lambda_l1=71.9; lambda_l2=37.4; scale_pos_weight=4.37; learning_rate=0.0974; num_iterations=3508; early_stopping_rounds=298; feature_fraction=0.173; bagging_fraction=0.873 : y = 0.914 : 56.9 secs : initdesign
#
# [mbo] 0: num_leaves=1041; min_child_weight=4.42; min_data_in_leaf=8109; min_gain_to_split=0.0178; lambda_l1=266; lambda_l2=141; scale_pos_weight=3.51; learning_rate=0.0681; num_iterations=3030; early_stopping_rounds=91; feature_fraction=0.91; bagging_fraction=0.927 : y = 0.905 : 15.6 secs : initdesign
#
# [mbo] 0: num_leaves=1414; min_child_weight=7.64; min_data_in_leaf=4478; min_gain_to_split=0.0307; lambda_l1=701; lambda_l2=992; scale_pos_weight=1.03; learning_rate=0.00665; num_iterations=3596; early_stopping_rounds=126; feature_fraction=0.237; bagging_fraction=0.519 : y = 0.865 : 27.8 secs : initdesign
#
# [mbo] 0: num_leaves=8140; min_child_weight=2.77; min_data_in_leaf=5159; min_gain_to_split=0.00242; lambda_l1=488; lambda_l2=394; scale_pos_weight=4.85; learning_rate=0.0541; num_iterations=798; early_stopping_rounds=340; feature_fraction=0.966; bagging_fraction=0.817 : y = 0.899 : 28.6 secs : initdesign
#
# [mbo] 0: num_leaves=836; min_child_weight=1.87; min_data_in_leaf=7754; min_gain_to_split=0.0928; lambda_l1=44.1; lambda_l2=552; scale_pos_weight=3.43; learning_rate=0.0079; num_iterations=672; early_stopping_rounds=322; feature_fraction=0.137; bagging_fraction=0.771 : y = 0.902 : 57.1 secs : initdesign
#
# [mbo] 0: num_leaves=4950; min_child_weight=0.512; min_data_in_leaf=7580; min_gain_to_split=0.00998; lambda_l1=838; lambda_l2=900; scale_pos_weight=1.29; learning_rate=0.0862; num_iterations=4598; early_stopping_rounds=175; feature_fraction=0.495; bagging_fraction=0.553 : y = 0.856 : 25.9 secs : initdesign
#
# [mbo] 0: num_leaves=5352; min_child_weight=8.78; min_data_in_leaf=1382; min_gain_to_split=0.0889; lambda_l1=593; lambda_l2=360; scale_pos_weight=2.55; learning_rate=0.0771; num_iterations=4826; early_stopping_rounds=280; feature_fraction=0.942; bagging_fraction=0.987 : y = 0.885 : 16.6 secs : initdesign
#
# [mbo] 0: num_leaves=617; min_child_weight=3.58; min_data_in_leaf=7067; min_gain_to_split=0.0995; lambda_l1=891; lambda_l2=705; scale_pos_weight=3.39; learning_rate=0.0415; num_iterations=503; early_stopping_rounds=86; feature_fraction=0.994; bagging_fraction=0.893 : y = 0.876 : 11.8 secs : initdesign
#
# [mbo] 0: num_leaves=3321; min_child_weight=1; min_data_in_leaf=931; min_gain_to_split=0.0415; lambda_l1=414; lambda_l2=938; scale_pos_weight=4.61; learning_rate=0.0179; num_iterations=4233; early_stopping_rounds=116; feature_fraction=0.335; bagging_fraction=0.532 : y = 0.903 : 112.8 secs : initdesign
#
# [mbo] 0: num_leaves=7555; min_child_weight=0.628; min_data_in_leaf=510; min_gain_to_split=0.0966; lambda_l1=26.3; lambda_l2=102; scale_pos_weight=2.39; learning_rate=0.093; num_iterations=321; early_stopping_rounds=442; feature_fraction=0.484; bagging_fraction=0.977 : y = 0.916 : 53.0 secs : initdesign
#
# [mbo] 0: num_leaves=4699; min_child_weight=8.37; min_data_in_leaf=4740; min_gain_to_split=0.085; lambda_l1=978; lambda_l2=465; scale_pos_weight=3.84; learning_rate=0.0989; num_iterations=1450; early_stopping_rounds=50; feature_fraction=0.0583; bagging_fraction=0.915 : y = 0.895 : 9.0 secs : initdesign
#
# [mbo] 0: num_leaves=1802; min_child_weight=9.02; min_data_in_leaf=4129; min_gain_to_split=0.0563; lambda_l1=235; lambda_l2=834; scale_pos_weight=3.72; learning_rate=0.0912; num_iterations=1418; early_stopping_rounds=500; feature_fraction=0.695; bagging_fraction=0.691 : y = 0.902 : 35.5 secs : initdesign
#
# [mbo] 0: num_leaves=6954; min_child_weight=7.24; min_data_in_leaf=6535; min_gain_to_split=0.0458; lambda_l1=115; lambda_l2=643; scale_pos_weight=1.21; learning_rate=0.0105; num_iterations=1071; early_stopping_rounds=62; feature_fraction=0.539; bagging_fraction=0.713 : y = 0.87 : 25.3 secs : initdesign
#
# [mbo] 0: num_leaves=4103; min_child_weight=1.41; min_data_in_leaf=6192; min_gain_to_split=0.0471; lambda_l1=712; lambda_l2=77.3; scale_pos_weight=3; learning_rate=0.0634; num_iterations=4928; early_stopping_rounds=488; feature_fraction=0.226; bagging_fraction=0.879 : y = 0.886 : 45.8 secs : initdesign
#
# Saved the current state after iteration 1 in the file HT.RDATA.
#
# Thu Nov 20 01:54:29 AM 2025 AUC 0.924772626460489
#
# [mbo] 1: num_leaves=4150; min_child_weight=7.23; min_data_in_leaf=1206; min_gain_to_split=0.0356; lambda_l1=1.3; lambda_l2=204; scale_pos_weight=2.62; learning_rate=0.0806; num_iterations=3213; early_stopping_rounds=365; feature_fraction=0.419; bagging_fraction=0.778 : y = 0.925 : 248.6 secs : infill_ei
#
# Thu Nov 20 01:56:39 AM 2025 AUC 0.927015996172246
#
# [mbo] 2: num_leaves=4149; min_child_weight=8.5; min_data_in_leaf=1391; min_gain_to_split=0.015; lambda_l1=1.13; lambda_l2=158; scale_pos_weight=2.74; learning_rate=0.0911; num_iterations=3788; early_stopping_rounds=166; feature_fraction=0.636; bagging_fraction=0.88 : y = 0.927 : 129.2 secs : infill_ei
#
# Thu Nov 20 01:58:49 AM 2025 AUC 0.92374187088847
#
# [mbo] 3: num_leaves=2741; min_child_weight=9.64; min_data_in_leaf=605; min_gain_to_split=0.0239; lambda_l1=1.64; lambda_l2=167; scale_pos_weight=2.27; learning_rate=0.0963; num_iterations=3319; early_stopping_rounds=278; feature_fraction=0.769; bagging_fraction=0.954 : y = 0.924 : 128.9 secs : infill_ei
#
# Thu Nov 20 02:03:43 AM 2025 AUC 0.928090370957925
#
# [mbo] 4: num_leaves=3539; min_child_weight=6.44; min_data_in_leaf=980; min_gain_to_split=0.00431; lambda_l1=0.333; lambda_l2=257; scale_pos_weight=3.33; learning_rate=0.084; num_iterations=4048; early_stopping_rounds=171; feature_fraction=0.338; bagging_fraction=0.891 : y = 0.928 : 293.6 secs : infill_ei
#
# Saved the current state after iteration 5 in the file HT.RDATA.
#
# Thu Nov 20 02:06:18 AM 2025 AUC 0.926670397787097
#
# [mbo] 5: num_leaves=3519; min_child_weight=6.88; min_data_in_leaf=1890; min_gain_to_split=0.0198; lambda_l1=0.155; lambda_l2=220; scale_pos_weight=3.28; learning_rate=0.0944; num_iterations=3172; early_stopping_rounds=152; feature_fraction=0.564; bagging_fraction=0.973 : y = 0.927 : 153.4 secs : infill_ei
#
# Thu Nov 20 02:10:57 AM 2025 AUC 0.925537975894009
#
# [mbo] 6: num_leaves=3111; min_child_weight=5.3; min_data_in_leaf=1871; min_gain_to_split=0.0203; lambda_l1=0.243; lambda_l2=222; scale_pos_weight=3.33; learning_rate=0.0868; num_iterations=4155; early_stopping_rounds=322; feature_fraction=0.802; bagging_fraction=0.711 : y = 0.926 : 276.7 secs : infill_ei
#
# Thu Nov 20 02:15:14 AM 2025 AUC 0.926333523244679
#
# [mbo] 7: num_leaves=3389; min_child_weight=9.7; min_data_in_leaf=1484; min_gain_to_split=0.0127; lambda_l1=0.382; lambda_l2=267; scale_pos_weight=3.62; learning_rate=0.0742; num_iterations=4329; early_stopping_rounds=176; feature_fraction=0.532; bagging_fraction=0.767 : y = 0.926 : 256.5 secs : infill_ei
#
# Saved the current state after iteration 8 in the file HT.RDATA.
#
# Thu Nov 20 02:19:12 AM 2025 AUC 0.923293935117426
#
# [mbo] 8: num_leaves=2377; min_child_weight=6.51; min_data_in_leaf=912; min_gain_to_split=0.0139; lambda_l1=0.488; lambda_l2=217; scale_pos_weight=2.98; learning_rate=0.0975; num_iterations=4314; early_stopping_rounds=130; feature_fraction=0.466; bagging_fraction=0.71 : y = 0.923 : 237.1 secs : infill_ei
#
# Thu Nov 20 02:22:42 AM 2025 AUC 0.926902921749144
#
# [mbo] 9: num_leaves=4148; min_child_weight=5.84; min_data_in_leaf=815; min_gain_to_split=0.0136; lambda_l1=0.527; lambda_l2=199; scale_pos_weight=3.53; learning_rate=0.0837; num_iterations=1748; early_stopping_rounds=287; feature_fraction=0.561; bagging_fraction=0.933 : y = 0.927 : 208.9 secs : infill_ei
#
# Thu Nov 20 02:27:02 AM 2025 AUC 0.927167321290404
#
# [mbo] 10: num_leaves=3548; min_child_weight=8.28; min_data_in_leaf=2544; min_gain_to_split=0.00714; lambda_l1=0.406; lambda_l2=335; scale_pos_weight=3.44; learning_rate=0.0836; num_iterations=3501; early_stopping_rounds=298; feature_fraction=0.487; bagging_fraction=0.89 : y = 0.927 : 258.0 secs : infill_ei
#
# Saved the current state after iteration 11 in the file HT.RDATA.
#
# Thu Nov 20 02:31:52 AM 2025 AUC 0.923833806769568
#
# [mbo] 11: num_leaves=4096; min_child_weight=5.67; min_data_in_leaf=4712; min_gain_to_split=0.00729; lambda_l1=1.07; lambda_l2=77.6; scale_pos_weight=3.69; learning_rate=0.071; num_iterations=3318; early_stopping_rounds=288; feature_fraction=0.49; bagging_fraction=0.936 : y = 0.924 : 288.7 secs : infill_ei
#
# Thu Nov 20 02:35:13 AM 2025 AUC 0.928079969453129
#
# [mbo] 12: num_leaves=5053; min_child_weight=6.92; min_data_in_leaf=421; min_gain_to_split=0.00601; lambda_l1=0.282; lambda_l2=189; scale_pos_weight=3.64; learning_rate=0.0883; num_iterations=3221; early_stopping_rounds=366; feature_fraction=0.671; bagging_fraction=0.651 : y = 0.928 : 199.9 secs : infill_ei
#
# Thu Nov 20 02:39:29 AM 2025 AUC 0.925407453785443
#
# [mbo] 13: num_leaves=6279; min_child_weight=4.73; min_data_in_leaf=1367; min_gain_to_split=0.0151; lambda_l1=0.93; lambda_l2=226; scale_pos_weight=3.37; learning_rate=0.0816; num_iterations=4221; early_stopping_rounds=269; feature_fraction=0.539; bagging_fraction=0.918 : y = 0.925 : 254.8 secs : infill_ei
#
# Saved the current state after iteration 14 in the file HT.RDATA.
#
# Thu Nov 20 02:41:46 AM 2025 AUC 0.925673530988767
#
# [mbo] 14: num_leaves=5022; min_child_weight=7.71; min_data_in_leaf=175; min_gain_to_split=0.008; lambda_l1=0.606; lambda_l2=230; scale_pos_weight=3.57; learning_rate=0.0858; num_iterations=3410; early_stopping_rounds=242; feature_fraction=0.794; bagging_fraction=0.789 : y = 0.926 : 136.0 secs : infill_ei
#
# Thu Nov 20 02:44:32 AM 2025 AUC 0.927271671870774
#
# [mbo] 15: num_leaves=4533; min_child_weight=4.92; min_data_in_leaf=1640; min_gain_to_split=0.0063; lambda_l1=0.523; lambda_l2=127; scale_pos_weight=3.33; learning_rate=0.0985; num_iterations=2185; early_stopping_rounds=470; feature_fraction=0.796; bagging_fraction=0.799 : y = 0.927 : 164.8 secs : infill_ei
#
# Thu Nov 20 02:47:17 AM 2025 AUC 0.92675327429305
#
# [mbo] 16: num_leaves=5793; min_child_weight=5.3; min_data_in_leaf=939; min_gain_to_split=0.00829; lambda_l1=0.669; lambda_l2=120; scale_pos_weight=3.85; learning_rate=0.0995; num_iterations=3499; early_stopping_rounds=454; feature_fraction=0.156; bagging_fraction=0.768 : y = 0.927 : 163.9 secs : infill_ei
#
# Thu Nov 20 02:50:24 AM 2025 AUC 0.931132307812067
#
# [mbo] 17: num_leaves=5412; min_child_weight=5.41; min_data_in_leaf=748; min_gain_to_split=0.00142; lambda_l1=0.395; lambda_l2=20.4; scale_pos_weight=3.61; learning_rate=0.0551; num_iterations=2888; early_stopping_rounds=483; feature_fraction=0.294; bagging_fraction=0.663 : y = 0.931 : 185.8 secs : infill_ei
#
# Saved the current state after iteration 18 in the file HT.RDATA.
#
# Thu Nov 20 02:56:53 AM 2025 AUC 0.928713790180845
#
# [mbo] 18: num_leaves=5659; min_child_weight=2.02; min_data_in_leaf=190; min_gain_to_split=0.00273; lambda_l1=0.388; lambda_l2=398; scale_pos_weight=4.47; learning_rate=0.0512; num_iterations=2251; early_stopping_rounds=227; feature_fraction=0.316; bagging_fraction=0.649 : y = 0.929 : 387.6 secs : infill_ei
#
# Thu Nov 20 03:01:26 AM 2025 AUC 0.929011742963382
#
# [mbo] 19: num_leaves=4702; min_child_weight=2.63; min_data_in_leaf=1460; min_gain_to_split=0.00108; lambda_l1=0.343; lambda_l2=74.7; scale_pos_weight=3.89; learning_rate=0.0577; num_iterations=3339; early_stopping_rounds=333; feature_fraction=0.296; bagging_fraction=0.587 : y = 0.929 : 271.8 secs : infill_ei
#
# Saved the current state after iteration 20 in the file HT.RDATA.
#
# Thu Nov 20 03:09:21 AM 2025 AUC 0.925751374508529
#
# [mbo] 20: num_leaves=5010; min_child_weight=2.33; min_data_in_leaf=70; min_gain_to_split=0.00129; lambda_l1=0.0279; lambda_l2=624; scale_pos_weight=3.93; learning_rate=0.0319; num_iterations=2470; early_stopping_rounds=488; feature_fraction=0.625; bagging_fraction=0.61 : y = 0.926 : 473.6 secs : infill_ei
#
# Thu Nov 20 03:16:49 AM 2025 AUC 0.927081424992736
#
# [mbo] 21: num_leaves=5649; min_child_weight=6.7; min_data_in_leaf=1468; min_gain_to_split=0.00554; lambda_l1=1.22; lambda_l2=402; scale_pos_weight=4.05; learning_rate=0.0565; num_iterations=3551; early_stopping_rounds=492; feature_fraction=0.219; bagging_fraction=0.516 : y = 0.927 : 446.9 secs : infill_ei
#
# Saved the current state after iteration 22 in the file HT.RDATA.
#
# Thu Nov 20 03:18:40 AM 2025 AUC 0.930481710463713
#
# [mbo] 22: num_leaves=6536; min_child_weight=3.87; min_data_in_leaf=1264; min_gain_to_split=0.000244; lambda_l1=0.585; lambda_l2=23.4; scale_pos_weight=4.4; learning_rate=0.072; num_iterations=883; early_stopping_rounds=425; feature_fraction=0.176; bagging_fraction=0.647 : y = 0.93 : 110.3 secs : infill_ei
#
# Thu Nov 20 03:23:01 AM 2025 AUC 0.928294039132474
#
# [mbo] 23: num_leaves=7313; min_child_weight=1.09; min_data_in_leaf=530; min_gain_to_split=0.0683; lambda_l1=1.43; lambda_l2=307; scale_pos_weight=4.49; learning_rate=0.0736; num_iterations=1524; early_stopping_rounds=423; feature_fraction=0.368; bagging_fraction=0.648 : y = 0.928 : 259.5 secs : infill_ei
#
# Thu Nov 20 03:25:34 AM 2025 AUC 0.924603518124454
#
# [mbo] 24: num_leaves=4672; min_child_weight=2.29; min_data_in_leaf=1269; min_gain_to_split=0.0633; lambda_l1=0.149; lambda_l2=3.72; scale_pos_weight=4.22; learning_rate=0.0702; num_iterations=1217; early_stopping_rounds=457; feature_fraction=0.48; bagging_fraction=0.556 : y = 0.925 : 151.8 secs : infill_ei
#
# Thu Nov 20 03:31:48 AM 2025 AUC 0.925916120923197
#
# [mbo] 25: num_leaves=6510; min_child_weight=2.62; min_data_in_leaf=2215; min_gain_to_split=0.00948; lambda_l1=0.741; lambda_l2=215; scale_pos_weight=4.48; learning_rate=0.0707; num_iterations=1915; early_stopping_rounds=466; feature_fraction=0.564; bagging_fraction=0.79 : y = 0.926 : 372.4 secs : infill_ei
#
# Saved the current state after iteration 26 in the file HT.RDATA.
#
# Thu Nov 20 03:34:56 AM 2025 AUC 0.933087790713671
#
# [mbo] 26: num_leaves=8003; min_child_weight=1.99; min_data_in_leaf=220; min_gain_to_split=0.034; lambda_l1=1.3; lambda_l2=87.7; scale_pos_weight=4.06; learning_rate=0.0526; num_iterations=1845; early_stopping_rounds=393; feature_fraction=0.0835; bagging_fraction=0.619 : y = 0.933 : 186.8 secs : infill_ei
#
# Thu Nov 20 03:37:50 AM 2025 AUC 0.926028524281474
#
# [mbo] 27: num_leaves=7960; min_child_weight=2.72; min_data_in_leaf=2; min_gain_to_split=0.0102; lambda_l1=0.654; lambda_l2=105; scale_pos_weight=3.88; learning_rate=0.0789; num_iterations=919; early_stopping_rounds=410; feature_fraction=0.35; bagging_fraction=0.581 : y = 0.926 : 171.3 secs : infill_ei
#
# Thu Nov 20 03:43:45 AM 2025 AUC 0.929703610798507
#
# [mbo] 28: num_leaves=7686; min_child_weight=7.5; min_data_in_leaf=599; min_gain_to_split=0.0269; lambda_l1=1.36; lambda_l2=123; scale_pos_weight=4.78; learning_rate=0.0186; num_iterations=2200; early_stopping_rounds=388; feature_fraction=0.301; bagging_fraction=0.897 : y = 0.93 : 352.8 secs : infill_ei
#
# Saved the current state after iteration 29 in the file HT.RDATA.
#
# Thu Nov 20 03:47:38 AM 2025 AUC 0.935802247932953
#
# [mbo] 29: num_leaves=7263; min_child_weight=1.63; min_data_in_leaf=301; min_gain_to_split=0.0358; lambda_l1=0.102; lambda_l2=18.8; scale_pos_weight=4.31; learning_rate=0.0454; num_iterations=3579; early_stopping_rounds=393; feature_fraction=0.101; bagging_fraction=0.955 : y = 0.936 : 231.3 secs : infill_ei
#
# Thu Nov 20 03:53:25 AM 2025 AUC 0.934474881708048
#
# [mbo] 30: num_leaves=6600; min_child_weight=2.85; min_data_in_leaf=170; min_gain_to_split=0.019; lambda_l1=4.17; lambda_l2=22.7; scale_pos_weight=4.5; learning_rate=0.0151; num_iterations=3852; early_stopping_rounds=361; feature_fraction=0.237; bagging_fraction=0.744 : y = 0.934 : 346.6 secs : infill_ei
#
# Thu Nov 20 03:58:51 AM 2025 AUC 0.929016104884748
#
# [mbo] 31: num_leaves=6792; min_child_weight=3.16; min_data_in_leaf=1829; min_gain_to_split=0.0861; lambda_l1=1.92; lambda_l2=15.1; scale_pos_weight=4.44; learning_rate=0.0142; num_iterations=3483; early_stopping_rounds=333; feature_fraction=0.0771; bagging_fraction=0.904 : y = 0.929 : 323.9 secs : infill_ei
#
# Saved the current state after iteration 32 in the file HT.RDATA.
#
# Thu Nov 20 04:01:06 AM 2025 AUC 0.927792418175388
#
# [mbo] 32: num_leaves=6530; min_child_weight=2.78; min_data_in_leaf=226; min_gain_to_split=0.043; lambda_l1=0.0196; lambda_l2=50.3; scale_pos_weight=4.36; learning_rate=0.0335; num_iterations=1423; early_stopping_rounds=379; feature_fraction=0.0517; bagging_fraction=0.908 : y = 0.928 : 133.6 secs : infill_ei
#
# Thu Nov 20 04:15:18 AM 2025 AUC 0.929105356506544
#
# [mbo] 33: num_leaves=8182; min_child_weight=1.98; min_data_in_leaf=305; min_gain_to_split=0.0904; lambda_l1=0.304; lambda_l2=258; scale_pos_weight=4.93; learning_rate=0.0235; num_iterations=4261; early_stopping_rounds=449; feature_fraction=0.595; bagging_fraction=0.534 : y = 0.929 : 850.6 secs : infill_ei
#
# Saved the current state after iteration 34 in the file HT.RDATA.
#
# Thu Nov 20 04:22:11 AM 2025 AUC 0.929781454318269
#
# [mbo] 34: num_leaves=8188; min_child_weight=0.558; min_data_in_leaf=119; min_gain_to_split=0.0603; lambda_l1=0.189; lambda_l2=554; scale_pos_weight=4.66; learning_rate=0.0493; num_iterations=3991; early_stopping_rounds=472; feature_fraction=0.115; bagging_fraction=0.732 : y = 0.93 : 410.8 secs : infill_ei
#
# Thu Nov 20 04:24:29 AM 2025 AUC 0.929859968902856
#
# [mbo] 35: num_leaves=7316; min_child_weight=8.7; min_data_in_leaf=804; min_gain_to_split=0.0715; lambda_l1=0.409; lambda_l2=9.86; scale_pos_weight=4.3; learning_rate=0.0466; num_iterations=4589; early_stopping_rounds=403; feature_fraction=0.0748; bagging_fraction=0.958 : y = 0.93 : 135.7 secs : infill_ei
#
# Thu Nov 20 04:28:39 AM 2025 AUC 0.929634491121477
#
# [mbo] 36: num_leaves=7815; min_child_weight=6.3; min_data_in_leaf=295; min_gain_to_split=0.0795; lambda_l1=0.681; lambda_l2=411; scale_pos_weight=4.92; learning_rate=0.0437; num_iterations=3064; early_stopping_rounds=153; feature_fraction=0.0619; bagging_fraction=0.537 : y = 0.93 : 248.8 secs : infill_ei
#
# Saved the current state after iteration 37 in the file HT.RDATA.
#
# Thu Nov 20 04:38:17 AM 2025 AUC 0.928935577105684
#
# [mbo] 37: num_leaves=7821; min_child_weight=2.69; min_data_in_leaf=828; min_gain_to_split=0.0286; lambda_l1=1.41; lambda_l2=347; scale_pos_weight=4.99; learning_rate=0.027; num_iterations=4649; early_stopping_rounds=196; feature_fraction=0.224; bagging_fraction=0.945 : y = 0.929 : 577.0 secs : infill_ei
#
# Thu Nov 20 04:43:29 AM 2025 AUC 0.927220335411621
#
# [mbo] 38: num_leaves=7602; min_child_weight=4.49; min_data_in_leaf=265; min_gain_to_split=0.0269; lambda_l1=1.72; lambda_l2=401; scale_pos_weight=4.86; learning_rate=0.0187; num_iterations=3174; early_stopping_rounds=385; feature_fraction=0.083; bagging_fraction=0.562 : y = 0.927 : 310.8 secs : infill_ei
#
# Saved the current state after iteration 39 in the file HT.RDATA.
#
# Thu Nov 20 04:46:48 AM 2025 AUC 0.927138129970493
#
# [mbo] 39: num_leaves=7922; min_child_weight=1.93; min_data_in_leaf=601; min_gain_to_split=0.0485; lambda_l1=3.92; lambda_l2=45.4; scale_pos_weight=4.48; learning_rate=0.0363; num_iterations=3486; early_stopping_rounds=191; feature_fraction=0.563; bagging_fraction=0.762 : y = 0.927 : 196.7 secs : infill_ei
#
# Thu Nov 20 04:54:16 AM 2025 AUC 0.922807748651327
#
# [mbo] 40: num_leaves=4501; min_child_weight=7.19; min_data_in_leaf=3613; min_gain_to_split=0.0948; lambda_l1=0.107; lambda_l2=552; scale_pos_weight=4.63; learning_rate=0.0244; num_iterations=3562; early_stopping_rounds=438; feature_fraction=0.998; bagging_fraction=0.565 : y = 0.923 : 446.2 secs : infill_ei
#
# Saved the current state after iteration 41 in the file HT.RDATA.
#
# Thu Nov 20 04:58:36 AM 2025 AUC 0.92711833355814
#
# [mbo] 41: num_leaves=5532; min_child_weight=8.34; min_data_in_leaf=91; min_gain_to_split=0.097; lambda_l1=0.196; lambda_l2=93; scale_pos_weight=4.11; learning_rate=0.0389; num_iterations=3908; early_stopping_rounds=409; feature_fraction=0.648; bagging_fraction=0.511 : y = 0.927 : 258.4 secs : infill_ei
#
# Thu Nov 20 05:05:21 AM 2025 AUC 0.926496591997284
#
# [mbo] 42: num_leaves=6505; min_child_weight=6.85; min_data_in_leaf=225; min_gain_to_split=0.0998; lambda_l1=0.237; lambda_l2=919; scale_pos_weight=4.42; learning_rate=0.046; num_iterations=3865; early_stopping_rounds=375; feature_fraction=0.125; bagging_fraction=0.588 : y = 0.926 : 403.9 secs : infill_ei
#
# Saved the current state after iteration 43 in the file HT.RDATA.
#
# Thu Nov 20 05:07:55 AM 2025 AUC 0.927364614349111
#
# [mbo] 43: num_leaves=6954; min_child_weight=3.44; min_data_in_leaf=637; min_gain_to_split=0.0911; lambda_l1=1.73; lambda_l2=49.1; scale_pos_weight=4.63; learning_rate=0.0503; num_iterations=3547; early_stopping_rounds=399; feature_fraction=0.164; bagging_fraction=0.614 : y = 0.927 : 152.1 secs : infill_ei
#
# Thu Nov 20 05:10:56 AM 2025 AUC 0.931505084322651
#
# [mbo] 44: num_leaves=8079; min_child_weight=8.99; min_data_in_leaf=851; min_gain_to_split=0.0584; lambda_l1=0.596; lambda_l2=11.8; scale_pos_weight=4.13; learning_rate=0.0219; num_iterations=3713; early_stopping_rounds=121; feature_fraction=0.0792; bagging_fraction=0.955 : y = 0.932 : 179.4 secs : infill_ei
#
# Thu Nov 20 05:18:47 AM 2025 AUC 0.927509228819013
#
# [mbo] 45: num_leaves=5792; min_child_weight=9.79; min_data_in_leaf=227; min_gain_to_split=0.0169; lambda_l1=0.905; lambda_l2=112; scale_pos_weight=3.9; learning_rate=0.0156; num_iterations=3976; early_stopping_rounds=439; feature_fraction=0.656; bagging_fraction=0.898 : y = 0.928 : 468.7 secs : infill_ei
#
# Saved the current state after iteration 46 in the file HT.RDATA.
#
# Thu Nov 20 05:30:01 AM 2025 AUC 0.925589312353163
#
# [mbo] 46: num_leaves=4916; min_child_weight=8.98; min_data_in_leaf=35; min_gain_to_split=0.0799; lambda_l1=1.01; lambda_l2=783; scale_pos_weight=4.42; learning_rate=0.0127; num_iterations=4839; early_stopping_rounds=74; feature_fraction=0.254; bagging_fraction=0.951 : y = 0.926 : 672.7 secs : infill_ei
#
# Saved the current state after iteration 47 in the file HT.RDATA.
#
# Thu Nov 20 05:34:32 AM 2025 AUC 0.928420534852087
#
# [mbo] 47: num_leaves=4057; min_child_weight=0.435; min_data_in_leaf=442; min_gain_to_split=0.00124; lambda_l1=0.411; lambda_l2=69.8; scale_pos_weight=4.19; learning_rate=0.0255; num_iterations=4955; early_stopping_rounds=482; feature_fraction=0.624; bagging_fraction=0.91 : y = 0.928 : 268.8 secs : infill_ei
#
# Thu Nov 20 05:47:02 AM 2025 AUC 0.926523770122718
#
# [mbo] 48: num_leaves=5382; min_child_weight=0.155; min_data_in_leaf=529; min_gain_to_split=0.0263; lambda_l1=0.166; lambda_l2=183; scale_pos_weight=4.41; learning_rate=0.00647; num_iterations=4433; early_stopping_rounds=295; feature_fraction=0.701; bagging_fraction=0.504 : y = 0.927 : 748.9 secs : infill_ei
#
# Saved the current state after iteration 49 in the file HT.RDATA.
#
# Thu Nov 20 05:48:27 AM 2025 AUC 0.920559010420966
#
# [mbo] 49: num_leaves=7970; min_child_weight=8.12; min_data_in_leaf=691; min_gain_to_split=0.0258; lambda_l1=0.872; lambda_l2=886; scale_pos_weight=4.29; learning_rate=0.0744; num_iterations=3096; early_stopping_rounds=96; feature_fraction=0.0761; bagging_fraction=0.925 : y = 0.921 : 83.9 secs : infill_ei
#
# Thu Nov 20 05:55:08 AM 2025 AUC 0.924987367204659
#
# [mbo] 50: num_leaves=5630; min_child_weight=0.235; min_data_in_leaf=97; min_gain_to_split=0.0951; lambda_l1=0.15; lambda_l2=847; scale_pos_weight=3.94; learning_rate=0.0503; num_iterations=2970; early_stopping_rounds=433; feature_fraction=0.857; bagging_fraction=0.5 : y = 0.925 : 398.4 secs : infill_ei
#
# Thu Nov 20 06:02:38 AM 2025 AUC 0.934418512262703
#
# [mbo] 51: num_leaves=7418; min_child_weight=0.34; min_data_in_leaf=375; min_gain_to_split=0.0117; lambda_l1=0.16; lambda_l2=19.4; scale_pos_weight=3.77; learning_rate=0.0107; num_iterations=3952; early_stopping_rounds=380; feature_fraction=0.0809; bagging_fraction=0.93 : y = 0.934 : 447.8 secs : infill_ei
#
# Saved the current state after iteration 52 in the file HT.RDATA.
#
# Thu Nov 20 06:14:52 AM 2025 AUC 0.924742093010927
#
# [mbo] 52: num_leaves=8111; min_child_weight=5.92; min_data_in_leaf=78; min_gain_to_split=0.0938; lambda_l1=0.575; lambda_l2=324; scale_pos_weight=4.18; learning_rate=0.00579; num_iterations=4469; early_stopping_rounds=104; feature_fraction=0.312; bagging_fraction=0.529 : y = 0.925 : 731.8 secs : infill_ei
#
# Saved the current state after iteration 53 in the file HT.RDATA.
#
# Thu Nov 20 06:21:34 AM 2025 AUC 0.930385077128836
#
# [mbo] 53: num_leaves=6767; min_child_weight=6.19; min_data_in_leaf=653; min_gain_to_split=0.00171; lambda_l1=0.717; lambda_l2=34; scale_pos_weight=4.24; learning_rate=0.026; num_iterations=4853; early_stopping_rounds=403; feature_fraction=0.285; bagging_fraction=0.748 : y = 0.93 : 398.9 secs : infill_ei
#
# Thu Nov 20 06:25:47 AM 2025 AUC 0.93347331745594
#
# [mbo] 54: num_leaves=7238; min_child_weight=0.405; min_data_in_leaf=221; min_gain_to_split=0.0121; lambda_l1=1.56; lambda_l2=5.11; scale_pos_weight=4.57; learning_rate=0.0222; num_iterations=3132; early_stopping_rounds=469; feature_fraction=0.554; bagging_fraction=0.914 : y = 0.933 : 252.2 secs : infill_ei
#
# Saved the current state after iteration 55 in the file HT.RDATA.
#
# Thu Nov 20 06:32:06 AM 2025 AUC 0.922087025028705
#
# [mbo] 55: num_leaves=5292; min_child_weight=7.27; min_data_in_leaf=8152; min_gain_to_split=0.0135; lambda_l1=0.116; lambda_l2=9.62; scale_pos_weight=4.96; learning_rate=0.00778; num_iterations=3524; early_stopping_rounds=487; feature_fraction=0.708; bagging_fraction=0.982 : y = 0.922 : 376.0 secs : infill_ei
#
# Thu Nov 20 06:42:25 AM 2025 AUC 0.92816620128321
#
# [mbo] 56: num_leaves=7926; min_child_weight=2.23; min_data_in_leaf=325; min_gain_to_split=0.078; lambda_l1=0.749; lambda_l2=302; scale_pos_weight=4.44; learning_rate=0.0249; num_iterations=4023; early_stopping_rounds=489; feature_fraction=0.456; bagging_fraction=0.979 : y = 0.928 : 617.7 secs : infill_ei
#
# Saved the current state after iteration 57 in the file HT.RDATA.
#
# Thu Nov 20 06:49:28 AM 2025 AUC 0.917009413026308
#
# [mbo] 57: num_leaves=6297; min_child_weight=8.22; min_data_in_leaf=4314; min_gain_to_split=0.0851; lambda_l1=0.635; lambda_l2=791; scale_pos_weight=4.79; learning_rate=0.00693; num_iterations=4491; early_stopping_rounds=464; feature_fraction=0.126; bagging_fraction=0.993 : y = 0.917 : 421.2 secs : infill_ei
#
# Thu Nov 20 06:54:31 AM 2025 AUC 0.928884576178943
#
# [mbo] 58: num_leaves=8189; min_child_weight=9.55; min_data_in_leaf=173; min_gain_to_split=0.0936; lambda_l1=0.0573; lambda_l2=239; scale_pos_weight=4.39; learning_rate=0.0437; num_iterations=2289; early_stopping_rounds=313; feature_fraction=0.289; bagging_fraction=0.644 : y = 0.929 : 301.9 secs : infill_ei
#
# Saved the current state after iteration 59 in the file HT.RDATA.
#
# Thu Nov 20 06:56:44 AM 2025 AUC 0.916409481072281
#
# [mbo] 59: num_leaves=1881; min_child_weight=8.8; min_data_in_leaf=8167; min_gain_to_split=0.00314; lambda_l1=1.31; lambda_l2=546; scale_pos_weight=4.03; learning_rate=0.0797; num_iterations=2548; early_stopping_rounds=318; feature_fraction=0.939; bagging_fraction=0.524 : y = 0.916 : 130.2 secs : infill_ei
#
# Thu Nov 20 07:01:57 AM 2025 AUC 0.923798240333815
#
# [mbo] 60: num_leaves=3575; min_child_weight=9.53; min_data_in_leaf=212; min_gain_to_split=0.0793; lambda_l1=1.67; lambda_l2=993; scale_pos_weight=4.99; learning_rate=0.0546; num_iterations=2752; early_stopping_rounds=310; feature_fraction=0.725; bagging_fraction=0.503 : y = 0.924 : 311.6 secs : infill_ei
#
# Thu Nov 20 07:05:06 AM 2025 AUC 0.932458667439733
#
# [mbo] 61: num_leaves=8180; min_child_weight=1.11; min_data_in_leaf=496; min_gain_to_split=0.051; lambda_l1=3.6; lambda_l2=0.498; scale_pos_weight=4.46; learning_rate=0.0176; num_iterations=2886; early_stopping_rounds=344; feature_fraction=0.116; bagging_fraction=0.938 : y = 0.932 : 186.9 secs : infill_ei
#
# Saved the current state after iteration 62 in the file HT.RDATA.
#
# Thu Nov 20 07:05:56 AM 2025 AUC 0.932621736192338
#
# [mbo] 62: num_leaves=6394; min_child_weight=9.24; min_data_in_leaf=462; min_gain_to_split=0.0726; lambda_l1=0.0433; lambda_l2=5.22; scale_pos_weight=4.93; learning_rate=0.0459; num_iterations=3604; early_stopping_rounds=58; feature_fraction=0.204; bagging_fraction=0.975 : y = 0.933 : 48.5 secs : infill_ei
#
# Thu Nov 20 07:10:24 AM 2025 AUC 0.937062507675304
#
# [mbo] 63: num_leaves=1812; min_child_weight=7.83; min_data_in_leaf=363; min_gain_to_split=0.025; lambda_l1=0.459; lambda_l2=2.46; scale_pos_weight=4.58; learning_rate=0.011; num_iterations=4054; early_stopping_rounds=155; feature_fraction=0.0728; bagging_fraction=0.999 : y = 0.937 : 265.3 secs : infill_ei
#
# Thu Nov 20 07:15:02 AM 2025 AUC 0.921564265529614
#
# [mbo] 64: num_leaves=3791; min_child_weight=9.98; min_data_in_leaf=5216; min_gain_to_split=0.0565; lambda_l1=0.434; lambda_l2=117; scale_pos_weight=4.99; learning_rate=0.0157; num_iterations=4190; early_stopping_rounds=101; feature_fraction=0.615; bagging_fraction=0.932 : y = 0.922 : 275.0 secs : infill_ei
#
# Thu Nov 20 07:17:41 AM 2025 AUC 0.93517245359419
#
# [mbo] 65: num_leaves=7995; min_child_weight=1.74; min_data_in_leaf=349; min_gain_to_split=0.00601; lambda_l1=0.058; lambda_l2=1.28; scale_pos_weight=4.67; learning_rate=0.0466; num_iterations=3684; early_stopping_rounds=359; feature_fraction=0.0859; bagging_fraction=0.856 : y = 0.935 : 157.8 secs : infill_ei
#
# Saved the current state after iteration 66 in the file HT.RDATA.
#
# Thu Nov 20 07:28:00 AM 2025 AUC 0.928582932539866
#
# [mbo] 66: num_leaves=3800; min_child_weight=0.327; min_data_in_leaf=28; min_gain_to_split=0.0952; lambda_l1=0.749; lambda_l2=645; scale_pos_weight=4.96; learning_rate=0.0206; num_iterations=3790; early_stopping_rounds=72; feature_fraction=0.493; bagging_fraction=0.622 : y = 0.929 : 616.5 secs : infill_ei
#
# Saved the current state after iteration 67 in the file HT.RDATA.
#
# Thu Nov 20 07:32:44 AM 2025 AUC 0.932888148928075
#
# [mbo] 67: num_leaves=4871; min_child_weight=7.98; min_data_in_leaf=1210; min_gain_to_split=0.0083; lambda_l1=1.51; lambda_l2=62.5; scale_pos_weight=4.5; learning_rate=0.0405; num_iterations=3890; early_stopping_rounds=338; feature_fraction=0.225; bagging_fraction=0.963 : y = 0.933 : 281.9 secs : infill_ei
#
# Thu Nov 20 07:34:30 AM 2025 AUC 0.923463378985873
#
# [mbo] 68: num_leaves=4997; min_child_weight=8.56; min_data_in_leaf=2581; min_gain_to_split=0.0236; lambda_l1=1.65; lambda_l2=18.2; scale_pos_weight=4.55; learning_rate=0.0324; num_iterations=4193; early_stopping_rounds=60; feature_fraction=0.404; bagging_fraction=0.943 : y = 0.923 : 104.5 secs : infill_ei
#
# Thu Nov 20 07:40:31 AM 2025 AUC 0.928381948624619
#
# [mbo] 69: num_leaves=1927; min_child_weight=0.68; min_data_in_leaf=110; min_gain_to_split=0.0801; lambda_l1=1.05; lambda_l2=638; scale_pos_weight=5; learning_rate=0.0318; num_iterations=4165; early_stopping_rounds=119; feature_fraction=0.0619; bagging_fraction=0.93 : y = 0.928 : 358.4 secs : infill_ei
#
# Saved the current state after iteration 70 in the file HT.RDATA.
#
# Thu Nov 20 07:49:38 AM 2025 AUC 0.916754408392605
#
# [mbo] 70: num_leaves=2011; min_child_weight=0.177; min_data_in_leaf=8037; min_gain_to_split=0.0963; lambda_l1=0.299; lambda_l2=299; scale_pos_weight=4.97; learning_rate=0.00581; num_iterations=4883; early_stopping_rounds=274; feature_fraction=0.238; bagging_fraction=0.949 : y = 0.917 : 545.6 secs : infill_ei
#
# Thu Nov 20 07:51:23 AM 2025 AUC 0.920402652316616
#
# [mbo] 71: num_leaves=7747; min_child_weight=0.0111; min_data_in_leaf=5939; min_gain_to_split=0.00614; lambda_l1=0.692; lambda_l2=395; scale_pos_weight=3.68; learning_rate=0.097; num_iterations=1340; early_stopping_rounds=458; feature_fraction=0.0513; bagging_fraction=0.623 : y = 0.92 : 102.2 secs : infill_ei
#
# Saved the current state after iteration 72 in the file HT.RDATA.
#
# Thu Nov 20 07:57:06 AM 2025 AUC 0.931428247400127
#
# [mbo] 72: num_leaves=5592; min_child_weight=0.219; min_data_in_leaf=219; min_gain_to_split=0.000523; lambda_l1=0.768; lambda_l2=12.2; scale_pos_weight=4.98; learning_rate=0.00893; num_iterations=1774; early_stopping_rounds=489; feature_fraction=0.936; bagging_fraction=0.559 : y = 0.931 : 341.0 secs : infill_ei
#
# Thu Nov 20 08:04:35 AM 2025 AUC 0.931773510252864
#
# [mbo] 73: num_leaves=4597; min_child_weight=5.64; min_data_in_leaf=73; min_gain_to_split=0.0954; lambda_l1=6.54; lambda_l2=4.57; scale_pos_weight=5; learning_rate=0.00505; num_iterations=3357; early_stopping_rounds=96; feature_fraction=0.624; bagging_fraction=0.892 : y = 0.932 : 447.6 secs : infill_ei
#
# Saved the current state after iteration 74 in the file HT.RDATA.
#
# Thu Nov 20 08:05:51 AM 2025 AUC 0.936350507895413
#
# [mbo] 74: num_leaves=6386; min_child_weight=9.77; min_data_in_leaf=208; min_gain_to_split=0.000813; lambda_l1=0.305; lambda_l2=2.58; scale_pos_weight=3.52; learning_rate=0.0615; num_iterations=3251; early_stopping_rounds=222; feature_fraction=0.0991; bagging_fraction=0.742 : y = 0.936 : 72.6 secs : infill_ei
#
# Thu Nov 20 08:07:51 AM 2025 AUC 0.928153115519112
#
# [mbo] 75: num_leaves=1722; min_child_weight=8.78; min_data_in_leaf=14; min_gain_to_split=0.0447; lambda_l1=0.0677; lambda_l2=38.3; scale_pos_weight=3.93; learning_rate=0.0489; num_iterations=3916; early_stopping_rounds=120; feature_fraction=0.0534; bagging_fraction=0.929 : y = 0.928 : 117.9 secs : infill_ei
#
# Thu Nov 20 08:09:37 AM 2025 AUC 0.933547805651574
#
# [mbo] 76: num_leaves=7335; min_child_weight=0.254; min_data_in_leaf=78; min_gain_to_split=0.0193; lambda_l1=0.086; lambda_l2=55.1; scale_pos_weight=4.95; learning_rate=0.0983; num_iterations=1625; early_stopping_rounds=186; feature_fraction=0.133; bagging_fraction=0.62 : y = 0.934 : 103.8 secs : infill_ei
#
# Thu Nov 20 08:15:25 AM 2025 AUC 0.927697126970162
#
# [mbo] 77: num_leaves=3972; min_child_weight=9.81; min_data_in_leaf=78; min_gain_to_split=0.00513; lambda_l1=1.33; lambda_l2=360; scale_pos_weight=3.07; learning_rate=0.0367; num_iterations=4231; early_stopping_rounds=252; feature_fraction=0.0512; bagging_fraction=0.54 : y = 0.928 : 346.6 secs : infill_ei
#
# Saved the current state after iteration 78 in the file HT.RDATA.
#
# Thu Nov 20 08:17:19 AM 2025 AUC 0.927030759598408
#
# [mbo] 78: num_leaves=6217; min_child_weight=0.129; min_data_in_leaf=1091; min_gain_to_split=0.0833; lambda_l1=0.0939; lambda_l2=179; scale_pos_weight=4.33; learning_rate=0.0938; num_iterations=1989; early_stopping_rounds=117; feature_fraction=0.0737; bagging_fraction=0.686 : y = 0.927 : 110.5 secs : infill_ei
#
# Thu Nov 20 08:22:00 AM 2025 AUC 0.935099978593032
#
# [mbo] 79: num_leaves=5729; min_child_weight=2.55; min_data_in_leaf=15; min_gain_to_split=0.0741; lambda_l1=0.821; lambda_l2=14.1; scale_pos_weight=3.91; learning_rate=0.0351; num_iterations=4752; early_stopping_rounds=186; feature_fraction=0.104; bagging_fraction=0.984 : y = 0.935 : 279.4 secs : infill_ei
#
# Thu Nov 20 08:24:51 AM 2025 AUC 0.920235557175059
#
# [mbo] 80: num_leaves=4198; min_child_weight=9.73; min_data_in_leaf=8010; min_gain_to_split=0.000902; lambda_l1=0.0826; lambda_l2=102; scale_pos_weight=4.09; learning_rate=0.0523; num_iterations=4916; early_stopping_rounds=406; feature_fraction=0.0744; bagging_fraction=0.509 : y = 0.92 : 168.4 secs : infill_ei
#
# Thu Nov 20 08:25:32 AM 2025 AUC 0.905062949235959
#
# [mbo] 81: num_leaves=7541; min_child_weight=0.588; min_data_in_leaf=799; min_gain_to_split=0.0982; lambda_l1=0.52; lambda_l2=816; scale_pos_weight=5; learning_rate=0.0126; num_iterations=230; early_stopping_rounds=491; feature_fraction=0.586; bagging_fraction=0.519 : y = 0.905 : 40.3 secs : infill_ei
#
# Saved the current state after iteration 82 in the file HT.RDATA.
#
# Thu Nov 20 08:28:05 AM 2025 AUC 0.931744654465366
#
# [mbo] 82: num_leaves=6246; min_child_weight=8.26; min_data_in_leaf=247; min_gain_to_split=0.00444; lambda_l1=0.876; lambda_l2=4.57; scale_pos_weight=2.93; learning_rate=0.0455; num_iterations=4329; early_stopping_rounds=246; feature_fraction=0.0923; bagging_fraction=0.996 : y = 0.932 : 151.1 secs : infill_ei
#
# Thu Nov 20 08:29:26 AM 2025 AUC 0.933179726594769
#
# [mbo] 83: num_leaves=7200; min_child_weight=7.39; min_data_in_leaf=248; min_gain_to_split=0.000277; lambda_l1=0.552; lambda_l2=12.2; scale_pos_weight=4.14; learning_rate=0.0669; num_iterations=2230; early_stopping_rounds=305; feature_fraction=0.0646; bagging_fraction=0.751 : y = 0.933 : 78.8 secs : infill_ei
#
# Thu Nov 20 08:32:00 AM 2025 AUC 0.93139100330231
#
# [mbo] 84: num_leaves=4527; min_child_weight=0.609; min_data_in_leaf=1820; min_gain_to_split=0.00905; lambda_l1=0.0263; lambda_l2=5.26; scale_pos_weight=4.9; learning_rate=0.0924; num_iterations=2959; early_stopping_rounds=480; feature_fraction=0.415; bagging_fraction=0.975 : y = 0.931 : 151.7 secs : infill_ei
#
# Thu Nov 20 08:32:46 AM 2025 AUC 0.928735264255262
#
# [mbo] 85: num_leaves=6304; min_child_weight=9.37; min_data_in_leaf=52; min_gain_to_split=0.0352; lambda_l1=0.241; lambda_l2=0.433; scale_pos_weight=3.61; learning_rate=0.0695; num_iterations=3867; early_stopping_rounds=192; feature_fraction=0.0749; bagging_fraction=0.654 : y = 0.929 : 43.8 secs : infill_ei
#
# Thu Nov 20 08:36:04 AM 2025 AUC 0.920547266786519
#
# [mbo] 86: num_leaves=4151; min_child_weight=0.487; min_data_in_leaf=5166; min_gain_to_split=0.0671; lambda_l1=1.32; lambda_l2=267; scale_pos_weight=4.92; learning_rate=0.098; num_iterations=1954; early_stopping_rounds=427; feature_fraction=0.854; bagging_fraction=0.606 : y = 0.921 : 195.7 secs : infill_ei
#
# Saved the current state after iteration 87 in the file HT.RDATA.
#
# Thu Nov 20 08:42:14 AM 2025 AUC 0.932561675890453
#
# [mbo] 87: num_leaves=4953; min_child_weight=0.723; min_data_in_leaf=23; min_gain_to_split=0.009; lambda_l1=0.363; lambda_l2=31.3; scale_pos_weight=3.94; learning_rate=0.0216; num_iterations=3608; early_stopping_rounds=181; feature_fraction=0.138; bagging_fraction=0.993 : y = 0.933 : 368.5 secs : infill_ei
#
# Thu Nov 20 08:45:52 AM 2025 AUC 0.929863995291809
#
# [mbo] 88: num_leaves=6714; min_child_weight=0.335; min_data_in_leaf=236; min_gain_to_split=0.024; lambda_l1=0.552; lambda_l2=411; scale_pos_weight=4.98; learning_rate=0.0897; num_iterations=2828; early_stopping_rounds=353; feature_fraction=0.102; bagging_fraction=0.974 : y = 0.93 : 213.9 secs : infill_ei
#
# Thu Nov 20 08:48:51 AM 2025 AUC 0.930825295654386
#
# [mbo] 89: num_leaves=5200; min_child_weight=0.15; min_data_in_leaf=942; min_gain_to_split=0.0131; lambda_l1=0.979; lambda_l2=170; scale_pos_weight=3.36; learning_rate=0.0871; num_iterations=2010; early_stopping_rounds=405; feature_fraction=0.0714; bagging_fraction=0.538 : y = 0.931 : 178.4 secs : infill_ei
#
# Saved the current state after iteration 90 in the file HT.RDATA.
#
# Thu Nov 20 08:55:37 AM 2025 AUC 0.929000334861348
#
# [mbo] 90: num_leaves=2174; min_child_weight=2.92; min_data_in_leaf=52; min_gain_to_split=0.0763; lambda_l1=0.0743; lambda_l2=205; scale_pos_weight=4.92; learning_rate=0.0238; num_iterations=3637; early_stopping_rounds=358; feature_fraction=0.775; bagging_fraction=0.513 : y = 0.929 : 403.5 secs : infill_ei
#
# Thu Nov 20 08:58:44 AM 2025 AUC 0.927336429626438
#
# [mbo] 91: num_leaves=5508; min_child_weight=9.57; min_data_in_leaf=4912; min_gain_to_split=0.00152; lambda_l1=1.95; lambda_l2=5.14; scale_pos_weight=4.94; learning_rate=0.0847; num_iterations=1332; early_stopping_rounds=452; feature_fraction=0.339; bagging_fraction=0.586 : y = 0.927 : 185.2 secs : infill_ei
#
# Thu Nov 20 09:02:05 AM 2025 AUC 0.926956942467599
#
# [mbo] 92: num_leaves=3569; min_child_weight=4.37; min_data_in_leaf=128; min_gain_to_split=0.0985; lambda_l1=0.945; lambda_l2=387; scale_pos_weight=4.95; learning_rate=0.0578; num_iterations=4059; early_stopping_rounds=149; feature_fraction=0.684; bagging_fraction=0.991 : y = 0.927 : 199.0 secs : infill_ei
#
# Saved the current state after iteration 93 in the file HT.RDATA.
#
# Thu Nov 20 09:04:29 AM 2025 AUC 0.931955368820583
#
# [mbo] 93: num_leaves=3107; min_child_weight=4.89; min_data_in_leaf=110; min_gain_to_split=0.012; lambda_l1=1.07; lambda_l2=41; scale_pos_weight=4.99; learning_rate=0.0419; num_iterations=3416; early_stopping_rounds=223; feature_fraction=0.112; bagging_fraction=0.993 : y = 0.932 : 140.9 secs : infill_ei
#
# Thu Nov 20 09:13:42 AM 2025 AUC 0.92566413608121
#
# [mbo] 94: num_leaves=3523; min_child_weight=9.92; min_data_in_leaf=153; min_gain_to_split=0.000336; lambda_l1=0.115; lambda_l2=884; scale_pos_weight=4.23; learning_rate=0.0307; num_iterations=3603; early_stopping_rounds=276; feature_fraction=0.347; bagging_fraction=0.961 : y = 0.926 : 550.9 secs : infill_ei
#
# Saved the current state after iteration 95 in the file HT.RDATA.
#
# Thu Nov 20 09:17:30 AM 2025 AUC 0.926052682615193
#
# [mbo] 95: num_leaves=4006; min_child_weight=7.32; min_data_in_leaf=5788; min_gain_to_split=0.017; lambda_l1=0.381; lambda_l2=69.3; scale_pos_weight=4.85; learning_rate=0.0865; num_iterations=4602; early_stopping_rounds=485; feature_fraction=0.864; bagging_fraction=0.503 : y = 0.926 : 224.4 secs : infill_ei
#
# Thu Nov 20 09:23:56 AM 2025 AUC 0.931732239766094
#
# [mbo] 96: num_leaves=772; min_child_weight=1.66; min_data_in_leaf=200; min_gain_to_split=0.0591; lambda_l1=9.39; lambda_l2=9.8; scale_pos_weight=4.69; learning_rate=0.00809; num_iterations=4443; early_stopping_rounds=246; feature_fraction=0.0577; bagging_fraction=0.946 : y = 0.932 : 383.5 secs : infill_ei
#
# Saved the current state after iteration 97 in the file HT.RDATA.
#
# Thu Nov 20 09:27:13 AM 2025 AUC 0.930821269265432
#
# [mbo] 97: num_leaves=6732; min_child_weight=0.755; min_data_in_leaf=22; min_gain_to_split=0.0118; lambda_l1=3.58; lambda_l2=90.7; scale_pos_weight=4.97; learning_rate=0.0478; num_iterations=1899; early_stopping_rounds=398; feature_fraction=0.21; bagging_fraction=0.6 : y = 0.931 : 195.5 secs : infill_ei
#
# Thu Nov 20 09:33:05 AM 2025 AUC 0.93354981884605
#
# [mbo] 98: num_leaves=7158; min_child_weight=10; min_data_in_leaf=346; min_gain_to_split=0.0126; lambda_l1=0.394; lambda_l2=8.42; scale_pos_weight=3.6; learning_rate=0.0158; num_iterations=2064; early_stopping_rounds=355; feature_fraction=0.839; bagging_fraction=0.528 : y = 0.934 : 349.5 secs : infill_ei
#
# Thu Nov 20 09:37:03 AM 2025 AUC 0.923667718225248
#
# [mbo] 99: num_leaves=3792; min_child_weight=0.132; min_data_in_leaf=1283; min_gain_to_split=0.0154; lambda_l1=3.26; lambda_l2=856; scale_pos_weight=4.86; learning_rate=0.0917; num_iterations=4999; early_stopping_rounds=420; feature_fraction=0.749; bagging_fraction=0.508 : y = 0.924 : 234.9 secs : infill_ei
#
# Saved the current state after iteration 100 in the file HT.RDATA.
#
# Thu Nov 20 09:47:46 AM 2025 AUC 0.932488865356882
#
# [mbo] 100: num_leaves=4287; min_child_weight=5.41; min_data_in_leaf=40; min_gain_to_split=0.00306; lambda_l1=1.01; lambda_l2=12.3; scale_pos_weight=4.6; learning_rate=0.00529; num_iterations=3273; early_stopping_rounds=450; feature_fraction=0.953; bagging_fraction=0.564 : y = 0.932 : 640.9 secs : infill_ei
#
# Saved the final state in the file HT.RDATA
#
# Saved the final state in the file HT.RDATA

# %% [markdown]
# la bayesian optimization ha corrido, extraigo los mejores hiperparametros

# %%
# almaceno los resultados de la Bayesian Optimization
# y capturo los mejores hiperparametros encontrados

tb_bayesiana <- as.data.table(bayesiana_salida$opt.path)

# ordeno en forma descendente por AUC = y
setorder(tb_bayesiana, -y, -num_iterations)

# grabo para eventualmente poder utilizarlos en OTRA corrida
fwrite( tb_bayesiana,
  file="BO_log.txt",
  sep="\t"
)

# los mejores hiperparámetros son los que quedaron en el registro 1 de la tabla
PARAM$out$lgbm$mejores_hiperparametros <- tb_bayesiana[
  1, # el primero es el de mejor AUC
  setdiff(colnames(tb_bayesiana),
    c("y","dob","eol","error.message","exec.time","ei","error.model",
      "train.time","prop.type","propose.time","se","mean","iter")),
  with= FALSE
]

print(PARAM$out$lgbm$mejores_hiperparametros)
# Out:
#    num_leaves min_child_weight min_data_in_leaf min_gain_to_split lambda_l1
#         <int>            <num>            <int>             <num>     <num>
# 1:       1812         7.832993              363        0.02504591 0.4585232
#    lambda_l2 scale_pos_weight learning_rate num_iterations
#        <num>            <num>         <num>          <int>
# 1:  2.456094         4.579206    0.01102522           4054
#    early_stopping_rounds feature_fraction bagging_fraction
#                    <int>            <num>            <num>
# 1:                   155       0.07278395        0.9993169

# %% [markdown]
# ### 6.3.3 Produccion

# %% [markdown]
# #### Final Training
# Construyo el modelo final, que es uno solo, no hace ningun tipo de particion < training, validation, testing>]

# %% [markdown]
# ##### Final Training Dataset
#
# Aqui esta la gran decision de en qué meses hago el Final Training
# <br> debo utilizar los mejores hiperparámetros que encontré en la optimización bayesiana

# %%
PARAM$trainingstrategy$final_train <- c(
  202105, 202104, 202103, 202102, 202101,
  202012, 202011, 202010, 202009, 202008, 202007,
  202006, 202005
)

dataset[, fold_final_train := foto_mes %in% PARAM$trainingstrategy$final_train ]

# creo el dfinal_train en formato  LightGBM
dfinal_train <- lgb.Dataset(
  data= data.matrix(dataset[fold_final_train == TRUE, campos_buenos, with= FALSE]),
  label= dataset[fold_final_train == TRUE, clase01],
  free_raw_data= TRUE
)

nrow( dfinal_train) # verifico el tamaño
# Out:
# [1] 207504

# %% [markdown]
# ##### Final Training Hyperparameters

# %%
# uno los parametros fijos y los mejores encontrados de los variables
fijos <- copy(PARAM$lgbm$param_fijos)

# quito lo que optimice en la Bayesian Optimization
fijos$num_iterations <- NULL
fijos$early_stopping_rounds <- NULL

# agrego a los hiperparametros fijos los que encontre con la Bayesian Optimization
param_final <- c(fijos, PARAM$out$lgbm$mejores_hiperparametros)

# Para el entrenamiento final, removemos early_stopping_rounds
# ya que se entrena con todos los datos disponibles y la cantidad de iteraciones
# ya está optimizada en 'num_iterations'.
param_final$early_stopping_rounds <- NULL

# %% [markdown]
# ##### Training
# Genero el modelo final, siempre sobre TODOS los datos de  final_train, sin hacer ningun tipo de undersampling de la clase mayoritaria

# %%
final_model <- lgb.train(
  data= dfinal_train,
  param= param_final,
  verbose= -100
)

# %%
# grabo a disco el modelo en un formato para seres humanos ... ponele ...

lgb.save(final_model, "modelo.txt")

# %%
# ahora imprimo la importancia de variables

tb_importancia <- as.data.table(lgb.importance(final_model))
archivo_importancia <- "impo.txt"

fwrite( tb_importancia,
  file= archivo_importancia,
  sep= "\t"
)

# %% [markdown]
# #### Scoring

# %% [markdown]
# Aplico el modelo final a los datos del futuro

# %%
PARAM$trainingstrategy$future <- c(202107)

dfuture <- dataset[ foto_mes %in% PARAM$trainingstrategy$future ]

# %%
# aplico final_model   a dfuture

prediccion <- predict(
  final_model,
  data.matrix(dfuture[, campos_buenos, with= FALSE])
)

# %% [markdown]
# ##### Tabla Prediccion

# %%
tb_prediccion <- dfuture[, list(numero_de_cliente)]
tb_prediccion[, prob := prediccion]

# grabo las probabilidad del modelo
#  me va a ser util para hacer Ensembles de modelos
fwrite(tb_prediccion,
  file= "prediccion.txt",
  sep= "\t"
)

# %% [markdown]
# #### Curva de Ganancia

# %% [markdown]
# Genero las salidas

# %%
# asigno clase ternaria
tb_prediccion[, clase_ternaria := dfuture$clase_ternaria ]

# asigno ganancias
tb_prediccion[, ganancia := -3000.0 ]
tb_prediccion[clase_ternaria=="BAJA+2", ganancia := 117000.0 ]

# reordeno, y acumulada
setorder( tb_prediccion, -prob )
tb_prediccion[, gan_acum := cumsum(ganancia)]

# media movil de ancho 400
tb_prediccion[,
  gan_suavizada := frollmean(
    x= gan_acum,
    n= 400,
    align= "center",
    na.rm= TRUE,
    hasNA= TRUE
  )
]

# %%
tb_prediccion[, sum(!is.na(gan_suavizada) )]
tb_prediccion[, .N]
# Out:
# [1] 16152
# [1] 16551

# %%
# Este es la ganancia a reportar
resultado <- list()
resultado$ganancia_suavizada_max <- max( tb_prediccion$gan_suavizada, na.rm=TRUE )
options(digits= 8)
resultado$envios <- which.max( tb_prediccion$gan_suavizada)
resultado
# Out:
# $ganancia_suavizada_max
# [1] 6620400
#
# $envios
# [1] 1667

# %%
# grabo las ganancias
fwrite( tb_prediccion,
  file= "ganancias.txt",
  sep= "\t"
)

# %%
# genero el grafico

tb_prediccion[, envios:= .I]

pdf("curva_de_ganancia.pdf")

plot(
  x= tb_prediccion$envios,
  y= tb_prediccion$gan_acum,
  type= "l",
  col= "gray",
  xlim= c(0, 6000),
  ylim= c(0, 8000000),
  main= paste0("Mejor gan prom= ", as.integer(resultado$ganancia_suavizada_max), " envios= ", resultado$envios),
  xlab= "Envios",
  ylab= "Ganancia",
  panel.first= grid()
)

dev.off()
# Out:
# agg_record_912038631
#                    2

# %%
# grabo los parametros
if( !require("yaml")) install.packages("yaml")
require("yaml")

PARAM$resultado <- resultado

write_yaml( PARAM, file="PARAM.yml")
# Out:
# Loading required package: yaml

# %%
format(Sys.time(), "%a %b %d %X %Y")
fin <- Sys.time()

# Duración en segundos
secs <- as.numeric(difftime(fin, principio, units = "secs"))
secs <- round(secs)

# A hh:mm:ss
h <- secs %/% 3600
m <- (secs %% 3600) %/% 60
s <- secs %% 60
dur_hms <- sprintf("%02d:%02d:%02d", h, m, s)

cat(
  "Inicio: ", format(principio, "%a %b %d %X %Y"), "\n",
  "Fin:    ", format(fin,       "%a %b %d %X %Y"), "\n",
  "Duración (hh:mm:ss): ", dur_hms, "\n",
  sep = ""
)
# Out:
# [1] "Thu Nov 20 09:57:00 AM 2025"
# Inicio: Thu Nov 20 01:01:20 AM 2025
# Fin:    Thu Nov 20 09:57:00 AM 2025
# Duración (hh:mm:ss): 08:55:40
