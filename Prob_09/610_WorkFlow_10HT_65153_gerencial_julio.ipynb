# %% [markdown]
# <a href="https://colab.research.google.com/github/jwbarbona/labo2025v/blob/main/610_WorkFlow_10HT_65153_gerencial_julio.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # 6 WorkFlow  Gerencial, futuro=JULIO

# %% [markdown]
# ### 6.1 Objetivo

# %% [markdown]
# Presentar un workflow/pipeline completo al que los estudiantes deberán enriquecer

# %% [markdown]
# #### 6.2  Seteo del ambiente en Google Colab

# %% [markdown]
# Esta parte se debe correr con el runtime en Python3
# <br>Ir al menu, Runtime -> Change Runtime Type -> Runtime type ->  **Python 3**

# %% [markdown]
# Conectar la virtual machine donde esta corriendo Google Colab con el  Google Drive, para poder tener persistencia de archivos

# %%
# primero establecer el Runtime de Python 3
from google.colab import drive
drive.mount('/content/.drive')
# Out:
# Mounted at /content/.drive

# %% [markdown]
# Para correr la siguiente celda es fundamental en Arranque en Frio haber copiado el archivo kaggle.json al Google Drive, en la carpeta indicada en el instructivo
#
# <br>los siguientes comando estan en shell script de Linux
# *   Crear las carpetas en el Google Drive
# *   "instalar" el archivo kaggle.json desde el Google Drive a la virtual machine para que pueda ser utilizado por la libreria  kaggle de Python
# *   Bajar el  **dataset_pequeno**  al  Google Drive  y tambien al disco local de la virtual machine que esta corriendo Google Colab
# *   Bajar el **dataset_historico** al Google Drive y tambien al disco local de la virtual machine que esta corriendo Google Colab

# %%
%%shell

mkdir -p "/content/.drive/My Drive/labo1"
mkdir -p "/content/buckets"
ln -s "/content/.drive/My Drive/labo1" /content/buckets/b1

mkdir -p ~/.kaggle
cp /content/buckets/b1/kaggle/kaggle.json  ~/.kaggle
chmod 600 ~/.kaggle/kaggle.json


mkdir -p /content/buckets/b1/exp
mkdir -p /content/buckets/b1/datasets
mkdir -p /content/datasets


webfiles="https://storage.googleapis.com/open-courses/austral2025-af91/"
destino_local="/content/datasets"
destino_bucket="/content/buckets/b1/datasets"


archivo="dataset_pequeno.csv"

if ! test -f $destino_bucket/$archivo; then
  wget  $webfiles/$archivo  -O $destino_bucket/$archivo
fi


if ! test -f $destino_local/$pequeno; then
  cp  $destino_bucket/$archivo  $destino_local/$archivo
fi

#-------

archivo="gerencial_competencia_2025.csv.gz"

if ! test -f $destino_bucket/$archivo; then
  wget  $webfiles/$archivo  -O $destino_bucket/$archivo
fi


if ! test -f $destino_local/$pequeno; then
  cp  $destino_bucket/$archivo  $destino_local/$archivo
fi
# Out:
# cp: cannot stat '/content/buckets/b1/kaggle/kaggle.json': No such file or directory
# chmod: cannot access '/root/.kaggle/kaggle.json': No such file or directory

# %% [markdown]
# ## 6.3  Workflow

# %% [markdown]
# ## Inicializacion

# %% [markdown]
# Esta parte se debe correr con el runtime en lenguaje **R** Ir al menu, Runtime -> Change Runtime Type -> Runtime type -> R

# %% [markdown]
# limpio el ambiente de R

# %%
format(Sys.time(), "%a %b %d %X %Y")
# Out:
# [1] "Thu Nov 20 06:20:16 PM 2025"

# %%
# limpio la memoria
rm(list=ls(all.names=TRUE)) # remove all objects
gc(full=TRUE, verbose=FALSE) # garbage collection
# Out:
#        used    (Mb) gc trigger (Mb) max used (Mb)
# Ncells  663518 35.5 1454502    77.7 1454502  77.7
# Vcells 1234025  9.5 8388608    64.0 1975136  15.1

# %%
principio <- Sys.time()

# %%
require("data.table")

if( !require("R.utils")) install.packages("R.utils")
require("R.utils")
# Out:
# Loading required package: data.table
#
# Loading required package: R.utils
#
# Warning message in library(package, lib.loc = lib.loc, character.only = TRUE, logical.return = TRUE, :
# “there is no package called ‘R.utils’”
# Installing package into ‘/usr/local/lib/R/site-library’
# (as ‘lib’ is unspecified)
#
# also installing the dependencies ‘R.oo’, ‘R.methodsS3’
#
#
# Loading required package: R.utils
#
# Loading required package: R.oo
#
# Loading required package: R.methodsS3
#
# R.methodsS3 v1.8.2 (2022-06-13 22:00:14 UTC) successfully loaded. See ?R.methodsS3 for help.
#
# R.oo v1.27.1 (2025-05-02 21:00:05 UTC) successfully loaded. See ?R.oo for help.
#
#
# Attaching package: ‘R.oo’
#
#
# The following object is masked from ‘package:R.methodsS3’:
#
#     throw
#
#
# The following objects are masked from ‘package:methods’:
#
#     getClasses, getMethods
#
#
# The following objects are masked from ‘package:base’:
#
#     attach, detach, load, save
#
#
# R.utils v2.13.0 (2025-02-24 21:20:02 UTC) successfully loaded. See ?R.utils for help.
#
#
# Attaching package: ‘R.utils’
#
#
# The following object is masked from ‘package:utils’:
#
#     timestamp
#
#
# The following objects are masked from ‘package:base’:
#
#     cat, commandArgs, getOption, isOpen, nullfile, parse, use, warnings

# %% [markdown]
# #### Parametros
# Si es gerente, no cambie nada
# <br>Si es Analista, cambie el nombre del dataset

# %%
PARAM <- list()
PARAM$semilla_primigenia <- 499999 # 100009, 200003, 499999, 700009, 999983

PARAM$experimento <- 65153 # 10HT
PARAM$dataset <- "gerencial_competencia_2025.csv.gz"

# %% [markdown]
# #### Carpeta del Experimento

# %%
# carpeta de trabajo

setwd("/content/buckets/b1/exp")
experimento_folder <- paste0("WF", PARAM$experimento)
dir.create(experimento_folder, showWarnings=FALSE)
setwd( paste0("/content/buckets/b1/exp/", experimento_folder ))

# %% [markdown]
# ### 6.3.1   Preprocesamiento del dataset

# %% [markdown]
# #### 6.3.1.1  DT incorporar dataset

# %%
# lectura del dataset
dataset <- fread(paste0("/content/datasets/", PARAM$dataset))

# %% [markdown]
# #### 6.3.1.2  CA  Catastrophe Analysis
# Se intentan reparar las variables que para un mes están con todos los valores en cero.

# %% [markdown]
# El método que se utiliza es **Machine Learning** se asigna NA also valores, si ha leido bien, es la "anti imputación de valores faltantes"
# <br> Usted podrá aplicar aquí otros métodos

# %%
dataset[ foto_mes==202006, internet:=NA]
dataset[ foto_mes==202006, mrentabilidad:=NA]
dataset[ foto_mes==202006, mrentabilidad_annual:=NA]
dataset[ foto_mes==202006, mcomisiones:=NA]
dataset[ foto_mes==202006, mactivos_margen:=NA]
dataset[ foto_mes==202006, mpasivos_margen:=NA]
dataset[ foto_mes==202006, mcuentas_saldo:=NA]
dataset[ foto_mes==202006, ctarjeta_visa_transacciones:=NA]
dataset[ foto_mes==202006, mtarjeta_visa_consumo:=NA]
dataset[ foto_mes==202006, mtarjeta_master_consumo:=NA]
dataset[ foto_mes==202006, ccallcenter_transacciones:=NA]
dataset[ foto_mes==202006, chomebanking_transacciones:=NA]
dataset[ foto_mes==202006, chomebanking_transacciones:=NA]

# %% [markdown]
# #### 6.3.1.3  DR  Data Drifting
# Se intenta corregir el data drifting, quizas ajustando por IPC ...
# <br>Esta parte podrá ser abordada por todos los Analistas y también la Gerenciapero se decide pedagogicamente no incluirla en esta primer version para reducir la carga cognitiva

# %%
# sin codigo en esta primera version del workflow

# %% [markdown]
# #### 6.3.1.3  FE_intra_manual Feature Engineering intra-mes
#
# Agrego campos nuevos dentro del mismo mes, SIN considerar la historia.

# %%
# esta funcion atributos presentes existe debido a que las modalidades poseen datasets con distinta cantidad de campos
atributos_presentes <- function( patributos )
{
  atributos <- unique( patributos )
  comun <- intersect( atributos, colnames(dataset) )

  return(  length( atributos ) == length( comun ) )
}

# el mes 1,2, ..12
if( atributos_presentes( c("foto_mes") ))
  dataset[, kmes := foto_mes %% 100]

# variable extraida de una tesis de maestria de Irlanda
if( atributos_presentes( c("mpayroll", "cliente_edad") ))
  dataset[, mpayroll_sobre_edad := mpayroll / cliente_edad]

# %%
# visualizo las columas del dataset a esta etapa
colnames(dataset)
# Out:
#  [1] "numero_de_cliente"           "foto_mes"
#  [3] "internet"                    "cliente_edad"
#  [5] "cliente_antiguedad"          "mrentabilidad"
#  [7] "mrentabilidad_annual"        "mcomisiones"
#  [9] "mactivos_margen"             "mpasivos_margen"
# [11] "cproductos"                  "mcuenta_corriente"
# [13] "mcaja_ahorro"                "cdescubierto_preacordado"
# [15] "mcuentas_saldo"              "ctarjeta_visa_transacciones"
# [17] "mtarjeta_visa_consumo"       "mtarjeta_master_consumo"
# [19] "mprestamos_personales"       "cpayroll_trx"
# [21] "mpayroll"                    "ccomisiones_mantenimiento"
# [23] "ccallcenter_transacciones"   "chomebanking_transacciones"
# [25] "ctrx_quarter"                "Master_status"
# [27] "Master_fechaalta"            "Master_mpagominimo"
# [29] "Visa_status"                 "Visa_fechaalta"
# [31] "Visa_mpagominimo"            "clase_ternaria"
# [33] "kmes"                        "mpayroll_sobre_edad"

# %% [markdown]
# #### 6.3.1.4  FE_rf Feature Engineering de nuevas variables a partir de hojas de Random Forest
#
# Esto se mostrará unicamente a la *modalidad Analista Sr*

# %%
# No se implementa Feature Engineering a partir de Random Forest

# %% [markdown]
# #### 6.3.1.5  FEhist Feature Engineering historico
#
# El Fature Engineering Histórico es la etapa que más aporta a la ganancia final, ya que enriquece cada registro del dataset con su historia.

# %% [markdown]
# Para cada campo del dataset original (*)
# se crean lo siguientes campos de a partir de la historia
# * lag1  lags de orden 1
# * delta1  =  valor actual - lag1
# * lag2  lags de orden 2
# * delta2  = valor actual - lag2
#
#
# (*) Excepto para los campos  <numero_de_cliente,  foto_mes,  clase_ternaria>

# %%
# Feature Engineering Historico

# todo es lagueable, menos la primary key y la clase
cols_lagueables <- copy( setdiff(
    colnames(dataset),
    c("numero_de_cliente", "foto_mes", "clase_ternaria")
) )

# https://rdrr.io/cran/data.table/man/shift.html

# lags de orden 1
dataset[,
    paste0(cols_lagueables, "_lag1") := shift(.SD, 1, NA, "lag"),
    by = numero_de_cliente,
    .SDcols = cols_lagueables
]

# lags de orden 2
dataset[,
    paste0(cols_lagueables, "_lag2") := shift(.SD, 2, NA, "lag"),
    by = numero_de_cliente,
    .SDcols = cols_lagueables
]

# agrego los delta lags
for (vcol in cols_lagueables)
{
    dataset[, paste0(vcol, "_delta1") := get(vcol) - get(paste0(vcol, "_lag1"))]
    dataset[, paste0(vcol, "_delta2") := get(vcol) - get(paste0(vcol, "_lag2"))]
}

# %% [markdown]
# Verificacion de los campos recien creados

# %%
ncol(dataset)
colnames(dataset)
# Out:
# [1] 158
#   [1] "numero_de_cliente"                  "foto_mes"
#   [3] "internet"                           "cliente_edad"
#   [5] "cliente_antiguedad"                 "mrentabilidad"
#   [7] "mrentabilidad_annual"               "mcomisiones"
#   [9] "mactivos_margen"                    "mpasivos_margen"
#  [11] "cproductos"                         "mcuenta_corriente"
#  [13] "mcaja_ahorro"                       "cdescubierto_preacordado"
#  [15] "mcuentas_saldo"                     "ctarjeta_visa_transacciones"
#  [17] "mtarjeta_visa_consumo"              "mtarjeta_master_consumo"
#  [19] "mprestamos_personales"              "cpayroll_trx"
#  [21] "mpayroll"                           "ccomisiones_mantenimiento"
#  [23] "ccallcenter_transacciones"          "chomebanking_transacciones"
#  [25] "ctrx_quarter"                       "Master_status"
#  [27] "Master_fechaalta"                   "Master_mpagominimo"
#  [29] "Visa_status"                        "Visa_fechaalta"
#  [31] "Visa_mpagominimo"                   "clase_ternaria"
#  [33] "kmes"                               "mpayroll_sobre_edad"
#  [35] "internet_lag1"                      "cliente_edad_lag1"
#  [37] "cliente_antiguedad_lag1"            "mrentabilidad_lag1"
#  [39] "mrentabilidad_annual_lag1"          "mcomisiones_lag1"
#  [41] "mactivos_margen_lag1"               "mpasivos_margen_lag1"
#  [43] "cproductos_lag1"                    "mcuenta_corriente_lag1"
#  [45] "mcaja_ahorro_lag1"                  "cdescubierto_preacordado_lag1"
#  [47] "mcuentas_saldo_lag1"                "ctarjeta_visa_transacciones_lag1"
#  [49] "mtarjeta_visa_consumo_lag1"         "mtarjeta_master_consumo_lag1"
#  [51] "mprestamos_personales_lag1"         "cpayroll_trx_lag1"
#  [53] "mpayroll_lag1"                      "ccomisiones_mantenimiento_lag1"
#  [55] "ccallcenter_transacciones_lag1"     "chomebanking_transacciones_lag1"
#  [57] "ctrx_quarter_lag1"                  "Master_status_lag1"
#  [59] "Master_fechaalta_lag1"              "Master_mpagominimo_lag1"
#  [61] "Visa_status_lag1"                   "Visa_fechaalta_lag1"
#  [63] "Visa_mpagominimo_lag1"              "kmes_lag1"
#  [65] "mpayroll_sobre_edad_lag1"           "internet_lag2"
#  [67] "cliente_edad_lag2"                  "cliente_antiguedad_lag2"
#  [69] "mrentabilidad_lag2"                 "mrentabilidad_annual_lag2"
#  [71] "mcomisiones_lag2"                   "mactivos_margen_lag2"
#  [73] "mpasivos_margen_lag2"               "cproductos_lag2"
#  [75] "mcuenta_corriente_lag2"             "mcaja_ahorro_lag2"
#  [77] "cdescubierto_preacordado_lag2"      "mcuentas_saldo_lag2"
#  [79] "ctarjeta_visa_transacciones_lag2"   "mtarjeta_visa_consumo_lag2"
#  [81] "mtarjeta_master_consumo_lag2"       "mprestamos_personales_lag2"
#  [83] "cpayroll_trx_lag2"                  "mpayroll_lag2"
#  [85] "ccomisiones_mantenimiento_lag2"     "ccallcenter_transacciones_lag2"
#  [87] "chomebanking_transacciones_lag2"    "ctrx_quarter_lag2"
#  [89] "Master_status_lag2"                 "Master_fechaalta_lag2"
#  [91] "Master_mpagominimo_lag2"            "Visa_status_lag2"
#  [93] "Visa_fechaalta_lag2"                "Visa_mpagominimo_lag2"
#  [95] "kmes_lag2"                          "mpayroll_sobre_edad_lag2"
#  [97] "internet_delta1"                    "internet_delta2"
#  [99] "cliente_edad_delta1"                "cliente_edad_delta2"
# [101] "cliente_antiguedad_delta1"          "cliente_antiguedad_delta2"
# [103] "mrentabilidad_delta1"               "mrentabilidad_delta2"
# [105] "mrentabilidad_annual_delta1"        "mrentabilidad_annual_delta2"
# [107] "mcomisiones_delta1"                 "mcomisiones_delta2"
# [109] "mactivos_margen_delta1"             "mactivos_margen_delta2"
# [111] "mpasivos_margen_delta1"             "mpasivos_margen_delta2"
# [113] "cproductos_delta1"                  "cproductos_delta2"
# [115] "mcuenta_corriente_delta1"           "mcuenta_corriente_delta2"
# [117] "mcaja_ahorro_delta1"                "mcaja_ahorro_delta2"
# [119] "cdescubierto_preacordado_delta1"    "cdescubierto_preacordado_delta2"
# [121] "mcuentas_saldo_delta1"              "mcuentas_saldo_delta2"
# [123] "ctarjeta_visa_transacciones_delta1" "ctarjeta_visa_transacciones_delta2"
# [125] "mtarjeta_visa_consumo_delta1"       "mtarjeta_visa_consumo_delta2"
# [127] "mtarjeta_master_consumo_delta1"     "mtarjeta_master_consumo_delta2"
# [129] "mprestamos_personales_delta1"       "mprestamos_personales_delta2"
# [131] "cpayroll_trx_delta1"                "cpayroll_trx_delta2"
# [133] "mpayroll_delta1"                    "mpayroll_delta2"
# [135] "ccomisiones_mantenimiento_delta1"   "ccomisiones_mantenimiento_delta2"
# [137] "ccallcenter_transacciones_delta1"   "ccallcenter_transacciones_delta2"
# [139] "chomebanking_transacciones_delta1"  "chomebanking_transacciones_delta2"
# [141] "ctrx_quarter_delta1"                "ctrx_quarter_delta2"
# [143] "Master_status_delta1"               "Master_status_delta2"
# [145] "Master_fechaalta_delta1"            "Master_fechaalta_delta2"
# [147] "Master_mpagominimo_delta1"          "Master_mpagominimo_delta2"
# [149] "Visa_status_delta1"                 "Visa_status_delta2"
# [151] "Visa_fechaalta_delta1"              "Visa_fechaalta_delta2"
# [153] "Visa_mpagominimo_delta1"            "Visa_mpagominimo_delta2"
# [155] "kmes_delta1"                        "kmes_delta2"
# [157] "mpayroll_sobre_edad_delta1"         "mpayroll_sobre_edad_delta2"

# %% [markdown]
# #### 6.3.1.6  FEhist Reduccion dimensionalidad con canaritos
#
# Esta etapa solo se mostrará a la *modalidad Anlista Sr* por algun canal secreto de forma de no confundir a los *Analista Jr*  nni distraer con detalles operativos a la estratégica *Modalidad Gerencial*

# %%
# No se implementa la reduccion de la dimensionalidad con canaritos

# %% [markdown]
# ### 6.3.2 Modelado

# %% [markdown]
# #### 6.3.2.1 Training Strategy
#
# Esta etapa de Workflow de  Training Strategy esta pensada para la *Modalidad Gerencial* que posee el dataset de [202005, 202109]
# <br> Si usted es un Analista, posee el periodo de [201901, 202109] y deberá experimentar en que meses le conviene experimentar
#
# <br> A la *Modalidad Gerencial* no se le complicada la vida con el undersampling de los continua, por eso PARAM$trainingstrategy$training_pct <- 1.0
# <br> Sin embargo, si usted es  *Analista SR* posee un dataset 50 veces ( filas x columnas) más grande que la *Modalidad Gerencial*  y por un tema de velocidad y experimentación más rápida puede llegar a necesitar activar el undersampling de la clase mayoritaria, a pesar de estar corriendo en Google Cloud.

# %% [markdown]
# Se hace una estrategia de entrenamiento muy sencilla, tomando todos los meses posibles, SIN eliminar nada x pandemia ni por ningun otro motivo
#
# * future = 202107  obviamente completo
#
# * final_train =  [ 202005, 202105 ]  SIN undersampling
#
# * training
#    * testing = NO HAY
#    * validation =  202105   completo, sin undersampling
#    * training = [ 202005, 202104 ]  donde se consideran el 100% de los CONTINUA

# %%
PARAM$trainingstrategy$validate <- c(202105)

PARAM$trainingstrategy$training <- c(
  202104, 202103, 202102, 202101,
  202012, 202011, 202010, 202009, 202008, 202007,
  202006, 202005
)

PARAM$trainingstrategy$training_pct <- 1.0


PARAM$trainingstrategy$positivos <- c( "BAJA+1", "BAJA+2")

# %%
# seteo la clase01   1={BAJA+1, BAJA+2}   0={CONTINUA}
dataset[, clase01 := ifelse( clase_ternaria %in% PARAM$trainingstrategy$positivos, 1, 0 )]

# %%
# los campos en los que se entrena
campos_buenos <- copy( setdiff(
    colnames(dataset), c("clase_ternaria","clase01","azar"))
)

# %%
# preparo para que se puede hacer undersampling de los CONTINUA
#  solamente por un tema de VELOCIDAD
set.seed(PARAM$semilla_primigenia, kind = "L'Ecuyer-CMRG")
dataset[, azar:=runif(nrow(dataset))]

# undersampling de los CONTINUA
dataset[, fold_train :=  foto_mes %in%  PARAM$trainingstrategy$training &
    (clase_ternaria %in% c("BAJA+1", "BAJA+2") |
     azar < PARAM$trainingstrategy$training_pct ) ]


if( !require("lightgbm")) install.packages("lightgbm")
require("lightgbm")

dtrain <- lgb.Dataset(
  data= data.matrix(dataset[fold_train == TRUE, campos_buenos, with = FALSE]),
  label= dataset[fold_train == TRUE, clase01],
  free_raw_data= TRUE
)
# Out:
# Loading required package: lightgbm
#
# Warning message in library(package, lib.loc = lib.loc, character.only = TRUE, logical.return = TRUE, :
# “there is no package called ‘lightgbm’”
# Installing package into ‘/usr/local/lib/R/site-library’
# (as ‘lib’ is unspecified)
#
# Loading required package: lightgbm

# %%
# datos de validation
dvalidate <- lgb.Dataset(
  data= data.matrix(dataset[foto_mes %in% PARAM$trainingstrategy$validate, campos_buenos, with = FALSE]),
  label= dataset[foto_mes %in% PARAM$trainingstrategy$validate, clase01],
  free_raw_data= TRUE
)

nrow(dvalidate)
# Out:
# [1] 16469

# %% [markdown]
# ####  6.3.2.2. Hyperparameter Tuning

# %% [markdown]
# * Clase binaria que se optimiza :  positivos = [ BAJA+1, BAJA+2 ]

# %% [markdown]
# * Metrica que se optimiza **AUC** Area Under Curve de la  ROC Curve
#
# es muy importante notar que intencionalmente  **NO** se está optimizando la funcion de ganancia del problema

# %% [markdown]
# * Cantidad de iteraciones inteligentes de la Optimizacion Bayesiana = **10**

# %% [markdown]
# * Parametros no default, fijos de LightGBM que no se optimizan
#   * max_bin = 31 , Alienigenas Ancestrales contruyeron las pirámides y dejaron a la humanidad en un jeroglifico  *max_bin=31*
#   * feature_fraction = 0.5  para poner algo que generalmente no falla
#   * learning_rate = 0.03  para que aprenda lento

# %% [markdown]
# * Parametros que se optimizan en la Bayesian Optimization
#   * num_leaves  [8, 256]
#   * min_data_in_leaf  [8, 8192]

# %%
# paquetes necesarios para la Bayesian Optimization
if(!require("DiceKriging")) install.packages("DiceKriging")
require("DiceKriging")

if(!require("mlrMBO")) install.packages("mlrMBO")
require("mlrMBO")
# Out:
# Loading required package: DiceKriging
#
# Warning message in library(package, lib.loc = lib.loc, character.only = TRUE, logical.return = TRUE, :
# “there is no package called ‘DiceKriging’”
# Installing package into ‘/usr/local/lib/R/site-library’
# (as ‘lib’ is unspecified)
#
# Loading required package: DiceKriging
#
# Loading required package: mlrMBO
#
# Warning message in library(package, lib.loc = lib.loc, character.only = TRUE, logical.return = TRUE, :
# “there is no package called ‘mlrMBO’”
# Installing package into ‘/usr/local/lib/R/site-library’
# (as ‘lib’ is unspecified)
#
# also installing the dependencies ‘XML’, ‘fastmatch’, ‘RcppArmadillo’, ‘mlr’, ‘ParamHelpers’, ‘smoof’, ‘BBmisc’, ‘checkmate’, ‘lhs’, ‘parallelMap’
#
#
# Loading required package: mlrMBO
#
# Loading required package: mlr
#
# Loading required package: ParamHelpers
#
#
# Attaching package: ‘ParamHelpers’
#
#
# The following object is masked from ‘package:R.utils’:
#
#     isVector
#
#
#
# Attaching package: ‘mlr’
#
#
# The following objects are masked from ‘package:R.utils’:
#
#     resample, setThreshold
#
#
# Loading required package: smoof
#
# Loading required package: checkmate
#
#
# Attaching package: ‘checkmate’
#
#
# The following object is masked from ‘package:DiceKriging’:
#
#     checkNames
#
#
# The following object is masked from ‘package:R.utils’:
#
#     asInt
#
#
#
# Attaching package: ‘smoof’
#
#
# The following objects are masked from ‘package:R.oo’:
#
#     getDescription, getName

# %% [markdown]
# Definición de la Bayesian Optimization
# <br> Si se desea optimizar un hiperparámetro que esta como fijo, debe QUITARSE de param_fijos y agregarse a PARAM$hipeparametertuning$hs

# %%
# valor ridiculamente bajo para que corra rapido en el aula y no molestar a la *Modalidad Gerencial*
PARAM$hipeparametertuning$num_interations <- 90

# parametros fijos del LightGBM
PARAM$lgbm$param_fijos <- list(
  objective= "binary",
  metric= "auc",
  first_metric_only= TRUE,
  boost_from_average= TRUE,
  feature_pre_filter= FALSE,
  verbosity= -100,
  force_row_wise= TRUE, # para evitar warning
  max_bin= 31,
  seed= PARAM$semilla_primigenia
  # learning_rate= 0.03,
  # feature_fraction= 0.5,
  # num_iterations= 2048,  # valor grande, lo limita early_stopping_rounds
  # early_stopping_rounds= 200
)


PARAM$hipeparametertuning$hs <- makeParamSet(
  # Núcleo del modelo (estructura de árboles)
  makeIntegerParam("num_leaves", lower = 2L, upper = 8192L),
  #makeIntegerParam("max_depth", lower = 3L, upper = 30L),
  makeNumericParam("min_child_weight", lower = 0.001, upper = 10.0),
  makeIntegerParam("min_data_in_leaf", lower = 2L, upper = 8192L),
  #makeNumericParam("min_gain_to_split", lower = 0.0, upper = 0.1),

  # Regularización
  #makeNumericParam("lambda_l1", lower = 0.0, upper = 1000L),
  makeNumericParam("lambda_l2", lower = 0.0, upper = 1000L),
  makeNumericParam("scale_pos_weight", lower = 1.0, upper = 5.0),  # útil en desequilibrio

  # Control del aprendizaje
  makeNumericParam("learning_rate", lower = 0.005, upper = 0.1),
  makeIntegerParam("num_iterations", lower = 100L, upper = 5000L),
  makeIntegerParam("early_stopping_rounds", lower = 50L, upper = 500L),

  # Submuestreo
  makeNumericParam("feature_fraction", lower = 0.05, upper = 1L),   # columnas
  makeNumericParam("bagging_fraction", lower = 0.5, upper = 1L)   # filas
  #makeIntegerParam("bagging_freq", lower = 0L, upper = 5L),         # cada N iteraciones

  # Opcionales útiles
  #makeNumericParam("max_delta_step", lower = 0.0, upper = 10.0),
  #makeNumericParam("path_smooth", lower = 0.0, upper = 10.0)
)
# Total: 12 hT

# %% [markdown]
# Función "señora caja negra"  que es llamada para verificar la realidad por la Bayesian Optimization

# %%
# En  x llegan los parmaetros de la bayesiana
#  devuelve la AUC en validate del modelo entrenado
#  en el parametro x llegan los hiperparámetros que se estan optimizando

EstimarGanancia_AUC_lightgbm <- function(x) {

  # x pisa (o agrega) a param_fijos
  param_completo <- modifyList(PARAM$lgbm$param_fijos, x)

  # entreno LightGBM
  modelo_train <- lgb.train(
    data= dtrain,
    valids= list(valid = dvalidate),
    eval= "auc",
    param= param_completo,
    verbose= -100
  )

  # recupero la AUC en validation
  AUC <- modelo_train$record_evals$valid$auc$eval[[modelo_train$best_iter]]

  # esta es la forma de devolver un parametro extra
  attr(AUC, "extras") <- list("num_iterations"= modelo_train$best_iter)

  # hago espacio en la memoria
  rm(modelo_train)
  gc(full= TRUE, verbose= FALSE)

  message(format(Sys.time(), "%a %b %d %X %Y"), " AUC ", AUC)

  return(AUC)
}

# %% [markdown]
# seteo de la Bayesian Optimization (complejo)
# <br> copiado y pegado de la documentación de la librería

# %%
configureMlr(show.learner.output = FALSE)

# configuro la busqueda bayesiana,  los hiperparametros que se van a optimizar
# por favor, no desesperarse por lo complejo
obj.fun <- makeSingleObjectiveFunction(
    fn= EstimarGanancia_AUC_lightgbm, # la funcion que voy a maximizar
    minimize= FALSE, # estoy Maximizando AUC
    noisy= FALSE,
    par.set= PARAM$hipeparametertuning$hs,
    has.simple.signature= FALSE # paso los parametros en una lista
)

# cada 600 segundos guardo el resultado intermedio
ctrl <- makeMBOControl(
    save.on.disk.at.time= 600,
    save.file.path= "HT.RDATA"
)

# indico la cantidad de iteraciones que va a tener la Bayesian Optimization
ctrl <- setMBOControlTermination(
    ctrl,
    iters= PARAM$hipeparametertuning$num_interations  # cantidad de iteraciones inteligentes
)

# defino el método estandar para la creacion de los puntos iniciales
#   los "No Inteligentes"
ctrl <- setMBOControlInfill(ctrl, crit = makeMBOInfillCritEI())

# mas configuraciones
surr.km <- makeLearner(
    "regr.km",
    predict.type= "se",
    covtype= "matern3_2",
    control= list(trace = TRUE)
)

# %% [markdown]
# Corrida de la Bayesian Optimization,  aqui se hace el trabajo pesado
# <br> por favor no se asuste con los warnings que pudieran aparecer
#
# Si corrío a medias y llegó a las iteraciones inteligentes, en el archivo binario HT.RDATA quedó lo ya procesado y es utilizado para retomar la corrida desde lo último que llegó a grabar.

# %%
# inicio la optimizacion bayesiana

if (!file.exists("HT.RDATA")) {
  bayesiana_salida <- mbo(obj.fun, learner= surr.km, control= ctrl)
} else {
  bayesiana_salida <- mboContinue("HT.RDATA") # retomo en caso que ya exista
}
# Out:
# Computing y column(s) for design. Not provided.
#
# Thu Nov 20 06:35:14 PM 2025 AUC 0.916058514168527
#
# Thu Nov 20 06:43:03 PM 2025 AUC 0.925324912811903
#
# Thu Nov 20 06:50:53 PM 2025 AUC 0.925912094534244
#
# Thu Nov 20 06:55:45 PM 2025 AUC 0.919020258776018
#
# Thu Nov 20 07:01:42 PM 2025 AUC 0.914038609043672
#
# Thu Nov 20 07:07:29 PM 2025 AUC 0.923194617523247
#
# Thu Nov 20 07:10:01 PM 2025 AUC 0.911797252526391
#
# Thu Nov 20 07:16:43 PM 2025 AUC 0.92009262036722
#
# Thu Nov 20 07:23:40 PM 2025 AUC 0.924634387106429
#
# Thu Nov 20 07:32:14 PM 2025 AUC 0.9240002308463
#
# Thu Nov 20 07:32:36 PM 2025 AUC 0.913459480099237
#
# Thu Nov 20 07:33:27 PM 2025 AUC 0.915324704781807
#
# Thu Nov 20 07:36:50 PM 2025 AUC 0.915675671685561
#
# Thu Nov 20 07:40:09 PM 2025 AUC 0.925054473687213
#
# Thu Nov 20 07:41:04 PM 2025 AUC 0.914488893541605
#
# Thu Nov 20 07:42:58 PM 2025 AUC 0.918530381453379
#
# Thu Nov 20 07:46:19 PM 2025 AUC 0.918985698937503
#
# Thu Nov 20 07:48:17 PM 2025 AUC 0.924723974260638
#
# Thu Nov 20 07:53:54 PM 2025 AUC 0.92691332325394
#
# Thu Nov 20 07:56:01 PM 2025 AUC 0.912618971405257
#
# Thu Nov 20 08:03:10 PM 2025 AUC 0.926389557157611
#
# Thu Nov 20 08:07:59 PM 2025 AUC 0.918712911085924
#
# Thu Nov 20 08:14:22 PM 2025 AUC 0.923420095304627
#
# Thu Nov 20 08:15:33 PM 2025 AUC 0.911404008538629
#
# Thu Nov 20 08:18:33 PM 2025 AUC 0.915461266473803
#
# Thu Nov 20 08:27:21 PM 2025 AUC 0.915774989279739
#
# Thu Nov 20 08:34:35 PM 2025 AUC 0.923227164167286
#
# Thu Nov 20 08:39:15 PM 2025 AUC 0.928785258584765
#
# Thu Nov 20 08:40:22 PM 2025 AUC 0.918763240947839
#
# Thu Nov 20 08:48:53 PM 2025 AUC 0.92584968550547
#
# Thu Nov 20 08:49:14 PM 2025 AUC 0.91486670303838
#
# Thu Nov 20 08:52:24 PM 2025 AUC 0.91712852703284
#
# Thu Nov 20 08:55:26 PM 2025 AUC 0.923156366828192
#
# Thu Nov 20 09:00:39 PM 2025 AUC 0.911646934005472
#
# Thu Nov 20 09:03:08 PM 2025 AUC 0.923954262905751
#
# Thu Nov 20 09:08:28 PM 2025 AUC 0.907990301771141
#
# Thu Nov 20 09:09:30 PM 2025 AUC 0.916410823201932
#
# Thu Nov 20 09:11:52 PM 2025 AUC 0.92928922826874
#
# Thu Nov 20 09:14:29 PM 2025 AUC 0.914170808814302
#
# Thu Nov 20 09:15:12 PM 2025 AUC 0.91156539962917
#
# [mbo] 0: num_leaves=4806; min_child_weight=4.37; min_data_in_leaf=3932; lambda_l2=579; scale_pos_weight=2.35; learning_rate=0.0644; num_iterations=2879; early_stopping_rounds=131; feature_fraction=0.668; bagging_fraction=0.666 : y = 0.916 : 119.3 secs : initdesign
#
# [mbo] 0: num_leaves=736; min_child_weight=7.65; min_data_in_leaf=3302; lambda_l2=377; scale_pos_weight=3.68; learning_rate=0.0815; num_iterations=3743; early_stopping_rounds=355; feature_fraction=0.577; bagging_fraction=0.937 : y = 0.925 : 469.4 secs : initdesign
#
# [mbo] 0: num_leaves=6567; min_child_weight=2.04; min_data_in_leaf=1526; lambda_l2=481; scale_pos_weight=2.04; learning_rate=0.043; num_iterations=3294; early_stopping_rounds=212; feature_fraction=0.331; bagging_fraction=0.703 : y = 0.926 : 469.6 secs : initdesign
#
# [mbo] 0: num_leaves=3308; min_child_weight=1.07; min_data_in_leaf=5362; lambda_l2=965; scale_pos_weight=3.82; learning_rate=0.0546; num_iterations=2653; early_stopping_rounds=320; feature_fraction=0.725; bagging_fraction=0.726 : y = 0.919 : 292.0 secs : initdesign
#
# [mbo] 0: num_leaves=5002; min_child_weight=5.11; min_data_in_leaf=5265; lambda_l2=792; scale_pos_weight=1.96; learning_rate=0.0246; num_iterations=2995; early_stopping_rounds=232; feature_fraction=0.409; bagging_fraction=0.75 : y = 0.914 : 357.1 secs : initdesign
#
# [mbo] 0: num_leaves=6818; min_child_weight=3.22; min_data_in_leaf=5053; lambda_l2=174; scale_pos_weight=2.69; learning_rate=0.0901; num_iterations=2008; early_stopping_rounds=393; feature_fraction=0.554; bagging_fraction=0.646 : y = 0.923 : 347.3 secs : initdesign
#
# [mbo] 0: num_leaves=4055; min_child_weight=5.73; min_data_in_leaf=2688; lambda_l2=354; scale_pos_weight=2.45; learning_rate=0.00844; num_iterations=1135; early_stopping_rounds=289; feature_fraction=0.351; bagging_fraction=0.593 : y = 0.912 : 152.2 secs : initdesign
#
# [mbo] 0: num_leaves=933; min_child_weight=6.32; min_data_in_leaf=3724; lambda_l2=744; scale_pos_weight=1.39; learning_rate=0.0478; num_iterations=4646; early_stopping_rounds=424; feature_fraction=0.117; bagging_fraction=0.715 : y = 0.92 : 401.5 secs : initdesign
#
# [mbo] 0: num_leaves=6529; min_child_weight=5.29; min_data_in_leaf=1712; lambda_l2=575; scale_pos_weight=3.22; learning_rate=0.0575; num_iterations=2765; early_stopping_rounds=454; feature_fraction=0.599; bagging_fraction=0.8 : y = 0.925 : 417.3 secs : initdesign
#
# [mbo] 0: num_leaves=214; min_child_weight=2.28; min_data_in_leaf=3666; lambda_l2=332; scale_pos_weight=2.9; learning_rate=0.038; num_iterations=3077; early_stopping_rounds=266; feature_fraction=0.514; bagging_fraction=0.683 : y = 0.924 : 514.5 secs : initdesign
#
# [mbo] 0: num_leaves=2001; min_child_weight=1.34; min_data_in_leaf=7002; lambda_l2=299; scale_pos_weight=4.48; learning_rate=0.0473; num_iterations=283; early_stopping_rounds=339; feature_fraction=0.0901; bagging_fraction=0.807 : y = 0.913 : 21.6 secs : initdesign
#
# [mbo] 0: num_leaves=5190; min_child_weight=8.06; min_data_in_leaf=3195; lambda_l2=656; scale_pos_weight=4.12; learning_rate=0.0706; num_iterations=421; early_stopping_rounds=147; feature_fraction=0.842; bagging_fraction=0.863 : y = 0.915 : 50.7 secs : initdesign
#
# [mbo] 0: num_leaves=2853; min_child_weight=4.9; min_data_in_leaf=7336; lambda_l2=890; scale_pos_weight=3.94; learning_rate=0.0202; num_iterations=2191; early_stopping_rounds=350; feature_fraction=0.161; bagging_fraction=0.695 : y = 0.916 : 203.3 secs : initdesign
#
# [mbo] 0: num_leaves=3526; min_child_weight=6.71; min_data_in_leaf=4873; lambda_l2=248; scale_pos_weight=2.78; learning_rate=0.0842; num_iterations=4474; early_stopping_rounds=465; feature_fraction=0.79; bagging_fraction=0.535 : y = 0.925 : 198.7 secs : initdesign
#
# [mbo] 0: num_leaves=2444; min_child_weight=7.98; min_data_in_leaf=2584; lambda_l2=843; scale_pos_weight=3.54; learning_rate=0.0517; num_iterations=487; early_stopping_rounds=404; feature_fraction=0.658; bagging_fraction=0.611 : y = 0.914 : 55.8 secs : initdesign
#
# [mbo] 0: num_leaves=5914; min_child_weight=2.81; min_data_in_leaf=856; lambda_l2=448; scale_pos_weight=1.18; learning_rate=0.0567; num_iterations=871; early_stopping_rounds=113; feature_fraction=0.293; bagging_fraction=0.779 : y = 0.919 : 113.9 secs : initdesign
#
# [mbo] 0: num_leaves=4669; min_child_weight=7.48; min_data_in_leaf=5956; lambda_l2=466; scale_pos_weight=2.12; learning_rate=0.0779; num_iterations=1737; early_stopping_rounds=436; feature_fraction=0.26; bagging_fraction=0.988 : y = 0.919 : 201.1 secs : initdesign
#
# [mbo] 0: num_leaves=2478; min_child_weight=1.62; min_data_in_leaf=6905; lambda_l2=26.9; scale_pos_weight=4.32; learning_rate=0.0965; num_iterations=1525; early_stopping_rounds=469; feature_fraction=0.986; bagging_fraction=0.857 : y = 0.925 : 117.5 secs : initdesign
#
# [mbo] 0: num_leaves=6018; min_child_weight=9.33; min_data_in_leaf=2055; lambda_l2=148; scale_pos_weight=4.04; learning_rate=0.0287; num_iterations=4203; early_stopping_rounds=187; feature_fraction=0.863; bagging_fraction=0.625 : y = 0.927 : 337.2 secs : initdesign
#
# [mbo] 0: num_leaves=7036; min_child_weight=3.87; min_data_in_leaf=6743; lambda_l2=307; scale_pos_weight=2.85; learning_rate=0.0187; num_iterations=1229; early_stopping_rounds=300; feature_fraction=0.821; bagging_fraction=0.623 : y = 0.913 : 126.8 secs : initdesign
#
# [mbo] 0: num_leaves=4280; min_child_weight=5.77; min_data_in_leaf=374; lambda_l2=272; scale_pos_weight=1.27; learning_rate=0.068; num_iterations=3968; early_stopping_rounds=372; feature_fraction=0.475; bagging_fraction=0.979 : y = 0.926 : 429.6 secs : initdesign
#
# [mbo] 0: num_leaves=4367; min_child_weight=6.9; min_data_in_leaf=4282; lambda_l2=724; scale_pos_weight=3.06; learning_rate=0.0804; num_iterations=4616; early_stopping_rounds=219; feature_fraction=0.966; bagging_fraction=0.844 : y = 0.919 : 288.2 secs : initdesign
#
# [mbo] 0: num_leaves=5546; min_child_weight=0.108; min_data_in_leaf=8074; lambda_l2=120; scale_pos_weight=1.8; learning_rate=0.0434; num_iterations=3864; early_stopping_rounds=411; feature_fraction=0.17; bagging_fraction=0.581 : y = 0.923 : 383.3 secs : initdesign
#
# [mbo] 0: num_leaves=2057; min_child_weight=0.835; min_data_in_leaf=5780; lambda_l2=201; scale_pos_weight=3.13; learning_rate=0.0152; num_iterations=1608; early_stopping_rounds=63; feature_fraction=0.63; bagging_fraction=0.918 : y = 0.911 : 71.4 secs : initdesign
#
# [mbo] 0: num_leaves=7708; min_child_weight=3.53; min_data_in_leaf=7443; lambda_l2=817; scale_pos_weight=2.59; learning_rate=0.0729; num_iterations=1418; early_stopping_rounds=171; feature_fraction=0.391; bagging_fraction=0.813 : y = 0.915 : 180.2 secs : initdesign
#
# [mbo] 0: num_leaves=179; min_child_weight=8.91; min_data_in_leaf=7972; lambda_l2=409; scale_pos_weight=3.43; learning_rate=0.0115; num_iterations=3442; early_stopping_rounds=203; feature_fraction=0.498; bagging_fraction=0.765 : y = 0.916 : 528.0 secs : initdesign
#
# [mbo] 0: num_leaves=2935; min_child_weight=0.651; min_data_in_leaf=624; lambda_l2=908; scale_pos_weight=4.29; learning_rate=0.0289; num_iterations=3256; early_stopping_rounds=280; feature_fraction=0.89; bagging_fraction=0.565 : y = 0.923 : 433.2 secs : initdesign
#
# [mbo] 0: num_leaves=6286; min_child_weight=2.57; min_data_in_leaf=3065; lambda_l2=191; scale_pos_weight=4.62; learning_rate=0.06; num_iterations=2480; early_stopping_rounds=326; feature_fraction=0.206; bagging_fraction=0.963 : y = 0.929 : 280.6 secs : initdesign
#
# [mbo] 0: num_leaves=1712; min_child_weight=4.54; min_data_in_leaf=1425; lambda_l2=528; scale_pos_weight=4.55; learning_rate=0.039; num_iterations=692; early_stopping_rounds=153; feature_fraction=0.129; bagging_fraction=0.509 : y = 0.919 : 66.9 secs : initdesign
#
# [mbo] 0: num_leaves=3094; min_child_weight=4.15; min_data_in_leaf=2269; lambda_l2=515; scale_pos_weight=1.64; learning_rate=0.0744; num_iterations=4067; early_stopping_rounds=174; feature_fraction=0.376; bagging_fraction=0.513 : y = 0.926 : 510.5 secs : initdesign
#
# [mbo] 0: num_leaves=1071; min_child_weight=9.07; min_data_in_leaf=1852; lambda_l2=88.9; scale_pos_weight=4.72; learning_rate=0.032; num_iterations=162; early_stopping_rounds=263; feature_fraction=0.701; bagging_fraction=0.907 : y = 0.915 : 20.8 secs : initdesign
#
# [mbo] 0: num_leaves=1492; min_child_weight=7.24; min_data_in_leaf=6514; lambda_l2=987; scale_pos_weight=1.48; learning_rate=0.0991; num_iterations=4380; early_stopping_rounds=103; feature_fraction=0.22; bagging_fraction=0.957 : y = 0.917 : 190.9 secs : initdesign
#
# [mbo] 0: num_leaves=7259; min_child_weight=9.78; min_data_in_leaf=4640; lambda_l2=637; scale_pos_weight=3.78; learning_rate=0.0869; num_iterations=2313; early_stopping_rounds=385; feature_fraction=0.0697; bagging_fraction=0.654 : y = 0.923 : 182.0 secs : initdesign
#
# [mbo] 0: num_leaves=8048; min_child_weight=8.27; min_data_in_leaf=1067; lambda_l2=768; scale_pos_weight=1.04; learning_rate=0.0134; num_iterations=2088; early_stopping_rounds=491; feature_fraction=0.437; bagging_fraction=0.883 : y = 0.912 : 312.5 secs : initdesign
#
# [mbo] 0: num_leaves=3714; min_child_weight=0.316; min_data_in_leaf=578; lambda_l2=616; scale_pos_weight=4.98; learning_rate=0.0928; num_iterations=3567; early_stopping_rounds=79; feature_fraction=0.912; bagging_fraction=0.949 : y = 0.924 : 149.1 secs : initdesign
#
# [mbo] 0: num_leaves=5482; min_child_weight=3.4; min_data_in_leaf=7621; lambda_l2=930; scale_pos_weight=1.51; learning_rate=0.00635; num_iterations=4880; early_stopping_rounds=121; feature_fraction=0.951; bagging_fraction=0.826 : y = 0.908 : 319.7 secs : initdesign
#
# [mbo] 0: num_leaves=1231; min_child_weight=9.68; min_data_in_leaf=4312; lambda_l2=858; scale_pos_weight=4.9; learning_rate=0.0935; num_iterations=1904; early_stopping_rounds=84; feature_fraction=0.752; bagging_fraction=0.559 : y = 0.916 : 62.0 secs : initdesign
#
# [mbo] 0: num_leaves=7382; min_child_weight=6.08; min_data_in_leaf=131; lambda_l2=24.9; scale_pos_weight=1.77; learning_rate=0.0349; num_iterations=834; early_stopping_rounds=249; feature_fraction=0.778; bagging_fraction=0.548 : y = 0.929 : 142.4 secs : initdesign
#
# [mbo] 0: num_leaves=557; min_child_weight=1.9; min_data_in_leaf=6159; lambda_l2=684; scale_pos_weight=2.25; learning_rate=0.0661; num_iterations=974; early_stopping_rounds=480; feature_fraction=0.545; bagging_fraction=0.758 : y = 0.914 : 156.8 secs : initdesign
#
# [mbo] 0: num_leaves=7926; min_child_weight=8.64; min_data_in_leaf=5635; lambda_l2=71.7; scale_pos_weight=3.31; learning_rate=0.0233; num_iterations=4826; early_stopping_rounds=55; feature_fraction=0.264; bagging_fraction=0.889 : y = 0.912 : 43.0 secs : initdesign
#
# Saved the current state after iteration 1 in the file HT.RDATA.
#
# Thu Nov 20 09:17:22 PM 2025 AUC 0.932654618368789
#
# [mbo] 1: num_leaves=7151; min_child_weight=3.74; min_data_in_leaf=413; lambda_l2=23.4; scale_pos_weight=3.85; learning_rate=0.0508; num_iterations=4216; early_stopping_rounds=273; feature_fraction=0.666; bagging_fraction=0.506 : y = 0.933 : 129.2 secs : infill_ei
#
# Thu Nov 20 09:20:23 PM 2025 AUC 0.934181290846877
#
# [mbo] 2: num_leaves=5074; min_child_weight=2.38; min_data_in_leaf=686; lambda_l2=13; scale_pos_weight=4.54; learning_rate=0.0668; num_iterations=3554; early_stopping_rounds=335; feature_fraction=0.283; bagging_fraction=0.543 : y = 0.934 : 179.8 secs : infill_ei
#
# Thu Nov 20 09:24:07 PM 2025 AUC 0.931767470669434
#
# [mbo] 3: num_leaves=5988; min_child_weight=2.23; min_data_in_leaf=15; lambda_l2=125; scale_pos_weight=4.83; learning_rate=0.0566; num_iterations=3630; early_stopping_rounds=359; feature_fraction=0.279; bagging_fraction=0.587 : y = 0.932 : 222.3 secs : infill_ei
#
# Thu Nov 20 09:26:49 PM 2025 AUC 0.927943743293546
#
# [mbo] 4: num_leaves=6582; min_child_weight=3.85; min_data_in_leaf=1454; lambda_l2=0.313; scale_pos_weight=4.64; learning_rate=0.0727; num_iterations=3524; early_stopping_rounds=322; feature_fraction=0.458; bagging_fraction=0.509 : y = 0.928 : 161.3 secs : infill_ei
#
# Saved the current state after iteration 5 in the file HT.RDATA.
#
# Thu Nov 20 09:29:05 PM 2025 AUC 0.931673857126272
#
# [mbo] 5: num_leaves=3261; min_child_weight=1.83; min_data_in_leaf=515; lambda_l2=19.1; scale_pos_weight=3.14; learning_rate=0.062; num_iterations=3503; early_stopping_rounds=308; feature_fraction=0.213; bagging_fraction=0.617 : y = 0.932 : 134.9 secs : infill_ei
#
# Thu Nov 20 09:34:38 PM 2025 AUC 0.928828877798424
#
# [mbo] 6: num_leaves=2317; min_child_weight=0.942; min_data_in_leaf=1115; lambda_l2=135; scale_pos_weight=4.99; learning_rate=0.0664; num_iterations=4094; early_stopping_rounds=352; feature_fraction=0.228; bagging_fraction=0.53 : y = 0.929 : 332.3 secs : infill_ei
#
# Thu Nov 20 09:37:00 PM 2025 AUC 0.933537404146778
#
# [mbo] 7: num_leaves=5382; min_child_weight=1.51; min_data_in_leaf=57; lambda_l2=17.6; scale_pos_weight=4.16; learning_rate=0.0647; num_iterations=3505; early_stopping_rounds=389; feature_fraction=0.169; bagging_fraction=0.71 : y = 0.934 : 140.9 secs : infill_ei
#
# Saved the current state after iteration 8 in the file HT.RDATA.
#
# Thu Nov 20 09:40:15 PM 2025 AUC 0.927756851739635
#
# [mbo] 8: num_leaves=5079; min_child_weight=2.82; min_data_in_leaf=399; lambda_l2=37; scale_pos_weight=3.53; learning_rate=0.0471; num_iterations=3885; early_stopping_rounds=290; feature_fraction=0.569; bagging_fraction=0.535 : y = 0.928 : 194.7 secs : infill_ei
#
# Thu Nov 20 09:41:48 PM 2025 AUC 0.932071798567813
#
# [mbo] 9: num_leaves=7797; min_child_weight=5.76; min_data_in_leaf=207; lambda_l2=8.64; scale_pos_weight=4.12; learning_rate=0.0622; num_iterations=4834; early_stopping_rounds=259; feature_fraction=0.132; bagging_fraction=0.518 : y = 0.932 : 91.5 secs : infill_ei
#
# Thu Nov 20 09:42:57 PM 2025 AUC 0.925835593144133
#
# [mbo] 10: num_leaves=8162; min_child_weight=2.69; min_data_in_leaf=487; lambda_l2=1.11; scale_pos_weight=4.82; learning_rate=0.0614; num_iterations=2897; early_stopping_rounds=242; feature_fraction=0.715; bagging_fraction=0.578 : y = 0.926 : 68.1 secs : infill_ei
#
# Thu Nov 20 09:45:12 PM 2025 AUC 0.93367832776014
#
# [mbo] 11: num_leaves=6032; min_child_weight=8.21; min_data_in_leaf=210; lambda_l2=38.9; scale_pos_weight=4.15; learning_rate=0.0656; num_iterations=3650; early_stopping_rounds=248; feature_fraction=0.227; bagging_fraction=0.685 : y = 0.934 : 134.8 secs : infill_ei
#
# Thu Nov 20 09:47:36 PM 2025 AUC 0.933853475679604
#
# [mbo] 12: num_leaves=5779; min_child_weight=6.29; min_data_in_leaf=1725; lambda_l2=10.6; scale_pos_weight=3.67; learning_rate=0.0623; num_iterations=4924; early_stopping_rounds=342; feature_fraction=0.153; bagging_fraction=0.516 : y = 0.934 : 142.6 secs : infill_ei
#
# Saved the current state after iteration 13 in the file HT.RDATA.
#
# Thu Nov 20 09:50:14 PM 2025 AUC 0.931891282129745
#
# [mbo] 13: num_leaves=4883; min_child_weight=6.56; min_data_in_leaf=282; lambda_l2=19.2; scale_pos_weight=4.81; learning_rate=0.0663; num_iterations=4264; early_stopping_rounds=358; feature_fraction=0.121; bagging_fraction=0.624 : y = 0.932 : 156.6 secs : infill_ei
#
# Thu Nov 20 09:54:31 PM 2025 AUC 0.931615810018864
#
# [mbo] 14: num_leaves=7158; min_child_weight=6.45; min_data_in_leaf=698; lambda_l2=254; scale_pos_weight=3.7; learning_rate=0.065; num_iterations=3793; early_stopping_rounds=344; feature_fraction=0.277; bagging_fraction=0.645 : y = 0.932 : 256.5 secs : infill_ei
#
# Thu Nov 20 09:56:24 PM 2025 AUC 0.933541430535731
#
# [mbo] 15: num_leaves=6471; min_child_weight=5.97; min_data_in_leaf=1048; lambda_l2=14.3; scale_pos_weight=3.48; learning_rate=0.0605; num_iterations=4133; early_stopping_rounds=292; feature_fraction=0.176; bagging_fraction=0.647 : y = 0.934 : 111.5 secs : infill_ei
#
# Thu Nov 20 09:58:52 PM 2025 AUC 0.927907170260554
#
# [mbo] 16: num_leaves=5625; min_child_weight=1.47; min_data_in_leaf=650; lambda_l2=89.1; scale_pos_weight=4.26; learning_rate=0.065; num_iterations=4007; early_stopping_rounds=297; feature_fraction=0.125; bagging_fraction=0.696 : y = 0.928 : 147.0 secs : infill_ei
#
# Saved the current state after iteration 17 in the file HT.RDATA.
#
# Thu Nov 20 10:00:45 PM 2025 AUC 0.930488085579555
#
# [mbo] 17: num_leaves=5390; min_child_weight=4.78; min_data_in_leaf=1456; lambda_l2=1.83; scale_pos_weight=2.49; learning_rate=0.0628; num_iterations=3376; early_stopping_rounds=348; feature_fraction=0.248; bagging_fraction=0.522 : y = 0.93 : 112.9 secs : infill_ei
#
# Thu Nov 20 10:03:12 PM 2025 AUC 0.929505982207387
#
# [mbo] 18: num_leaves=6196; min_child_weight=8.1; min_data_in_leaf=1356; lambda_l2=0.112; scale_pos_weight=4.15; learning_rate=0.0618; num_iterations=3740; early_stopping_rounds=409; feature_fraction=0.295; bagging_fraction=0.714 : y = 0.93 : 145.1 secs : infill_ei
#
# Thu Nov 20 10:05:06 PM 2025 AUC 0.929366065191264
#
# [mbo] 19: num_leaves=5177; min_child_weight=4.59; min_data_in_leaf=518; lambda_l2=1.24; scale_pos_weight=3.96; learning_rate=0.0723; num_iterations=4485; early_stopping_rounds=365; feature_fraction=0.236; bagging_fraction=0.644 : y = 0.929 : 112.7 secs : infill_ei
#
# Thu Nov 20 10:10:11 PM 2025 AUC 0.929440217854485
#
# [mbo] 20: num_leaves=6883; min_child_weight=5.86; min_data_in_leaf=134; lambda_l2=136; scale_pos_weight=3.25; learning_rate=0.0423; num_iterations=4167; early_stopping_rounds=321; feature_fraction=0.782; bagging_fraction=0.547 : y = 0.929 : 304.7 secs : infill_ei
#
# Saved the current state after iteration 21 in the file HT.RDATA.
#
# Thu Nov 20 10:14:02 PM 2025 AUC 0.930494460695398
#
# [mbo] 21: num_leaves=6521; min_child_weight=7.57; min_data_in_leaf=106; lambda_l2=310; scale_pos_weight=3.82; learning_rate=0.0583; num_iterations=4562; early_stopping_rounds=224; feature_fraction=0.219; bagging_fraction=0.502 : y = 0.93 : 229.5 secs : infill_ei
#
# Thu Nov 20 10:15:55 PM 2025 AUC 0.932950557956849
#
# [mbo] 22: num_leaves=6833; min_child_weight=7.92; min_data_in_leaf=1010; lambda_l2=4.89; scale_pos_weight=2.95; learning_rate=0.0573; num_iterations=4395; early_stopping_rounds=256; feature_fraction=0.737; bagging_fraction=0.503 : y = 0.933 : 112.8 secs : infill_ei
#
# Thu Nov 20 10:18:14 PM 2025 AUC 0.936176366573187
#
# [mbo] 23: num_leaves=4309; min_child_weight=2.81; min_data_in_leaf=56; lambda_l2=15.2; scale_pos_weight=4.19; learning_rate=0.0679; num_iterations=3193; early_stopping_rounds=345; feature_fraction=0.138; bagging_fraction=0.913 : y = 0.936 : 137.8 secs : infill_ei
#
# Thu Nov 20 10:20:29 PM 2025 AUC 0.935483492140824
#
# [mbo] 24: num_leaves=4332; min_child_weight=3.12; min_data_in_leaf=67; lambda_l2=27.9; scale_pos_weight=4.3; learning_rate=0.0679; num_iterations=3156; early_stopping_rounds=329; feature_fraction=0.0555; bagging_fraction=0.636 : y = 0.935 : 134.3 secs : infill_ei
#
# Saved the current state after iteration 25 in the file HT.RDATA.
#
# Thu Nov 20 10:23:51 PM 2025 AUC 0.930146178050946
#
# [mbo] 25: num_leaves=4147; min_child_weight=5.48; min_data_in_leaf=202; lambda_l2=45.8; scale_pos_weight=4.2; learning_rate=0.0651; num_iterations=3253; early_stopping_rounds=337; feature_fraction=0.331; bagging_fraction=0.685 : y = 0.93 : 199.8 secs : infill_ei
#
# Thu Nov 20 10:26:18 PM 2025 AUC 0.931472537678612
#
# [mbo] 26: num_leaves=4582; min_child_weight=3.03; min_data_in_leaf=1156; lambda_l2=1.63; scale_pos_weight=4.2; learning_rate=0.0639; num_iterations=2771; early_stopping_rounds=236; feature_fraction=0.15; bagging_fraction=0.523 : y = 0.931 : 146.4 secs : infill_ei
#
# Thu Nov 20 10:29:41 PM 2025 AUC 0.935710312051855
#
# [mbo] 27: num_leaves=2891; min_child_weight=2.55; min_data_in_leaf=93; lambda_l2=101; scale_pos_weight=3.9; learning_rate=0.0674; num_iterations=3386; early_stopping_rounds=416; feature_fraction=0.0786; bagging_fraction=0.877 : y = 0.936 : 202.6 secs : infill_ei
#
# Thu Nov 20 10:33:35 PM 2025 AUC 0.93472619548521
#
# [mbo] 28: num_leaves=4130; min_child_weight=2.41; min_data_in_leaf=297; lambda_l2=32.8; scale_pos_weight=4.85; learning_rate=0.0681; num_iterations=3043; early_stopping_rounds=427; feature_fraction=0.0952; bagging_fraction=0.865 : y = 0.935 : 232.5 secs : infill_ei
#
# Saved the current state after iteration 29 in the file HT.RDATA.
#
# Thu Nov 20 10:37:45 PM 2025 AUC 0.927580026158107
#
# [mbo] 29: num_leaves=2260; min_child_weight=2.4; min_data_in_leaf=2892; lambda_l2=335; scale_pos_weight=4.48; learning_rate=0.0679; num_iterations=3257; early_stopping_rounds=381; feature_fraction=0.24; bagging_fraction=0.923 : y = 0.928 : 248.8 secs : infill_ei
#
# Thu Nov 20 10:40:53 PM 2025 AUC 0.935202987043751
#
# [mbo] 30: num_leaves=7393; min_child_weight=6.36; min_data_in_leaf=1727; lambda_l2=8.34; scale_pos_weight=4.17; learning_rate=0.052; num_iterations=4011; early_stopping_rounds=265; feature_fraction=0.238; bagging_fraction=0.51 : y = 0.935 : 186.6 secs : infill_ei
#
# Thu Nov 20 10:44:26 PM 2025 AUC 0.932420416744678
#
# [mbo] 31: num_leaves=4227; min_child_weight=2.72; min_data_in_leaf=50; lambda_l2=217; scale_pos_weight=3.95; learning_rate=0.066; num_iterations=3268; early_stopping_rounds=374; feature_fraction=0.107; bagging_fraction=0.804 : y = 0.932 : 212.4 secs : infill_ei
#
# Saved the current state after iteration 32 in the file HT.RDATA.
#
# Thu Nov 20 10:46:36 PM 2025 AUC 0.936602157204988
#
# [mbo] 32: num_leaves=1789; min_child_weight=1.64; min_data_in_leaf=28; lambda_l2=15.9; scale_pos_weight=4.15; learning_rate=0.0704; num_iterations=3399; early_stopping_rounds=391; feature_fraction=0.0586; bagging_fraction=0.963 : y = 0.937 : 128.3 secs : infill_ei
#
# Thu Nov 20 10:48:20 PM 2025 AUC 0.933372993264522
#
# [mbo] 33: num_leaves=2596; min_child_weight=2.46; min_data_in_leaf=202; lambda_l2=2.6; scale_pos_weight=3.62; learning_rate=0.0762; num_iterations=2706; early_stopping_rounds=359; feature_fraction=0.277; bagging_fraction=0.862 : y = 0.933 : 102.3 secs : infill_ei
#
# Thu Nov 20 10:51:06 PM 2025 AUC 0.934628555553095
#
# [mbo] 34: num_leaves=7211; min_child_weight=2.71; min_data_in_leaf=35; lambda_l2=3.74; scale_pos_weight=3.13; learning_rate=0.0557; num_iterations=3367; early_stopping_rounds=484; feature_fraction=0.25; bagging_fraction=0.992 : y = 0.935 : 165.4 secs : infill_ei
#
# Thu Nov 20 10:53:20 PM 2025 AUC 0.931169551909884
#
# [mbo] 35: num_leaves=1819; min_child_weight=2.6; min_data_in_leaf=75; lambda_l2=9.8; scale_pos_weight=4.08; learning_rate=0.0697; num_iterations=3519; early_stopping_rounds=336; feature_fraction=0.0709; bagging_fraction=0.566 : y = 0.931 : 132.7 secs : infill_ei
#
# Thu Nov 20 10:55:31 PM 2025 AUC 0.92935230836234
#
# [mbo] 36: num_leaves=5286; min_child_weight=5.38; min_data_in_leaf=827; lambda_l2=3.03; scale_pos_weight=3.22; learning_rate=0.0683; num_iterations=2969; early_stopping_rounds=342; feature_fraction=0.0502; bagging_fraction=0.92 : y = 0.929 : 130.0 secs : infill_ei
#
# Saved the current state after iteration 37 in the file HT.RDATA.
#
# Thu Nov 20 10:57:45 PM 2025 AUC 0.933421980996786
#
# [mbo] 37: num_leaves=2990; min_child_weight=1.98; min_data_in_leaf=819; lambda_l2=0.601; scale_pos_weight=3.47; learning_rate=0.0685; num_iterations=3313; early_stopping_rounds=439; feature_fraction=0.328; bagging_fraction=0.998 : y = 0.933 : 132.8 secs : infill_ei
#
# Thu Nov 20 10:59:43 PM 2025 AUC 0.937455080598241
#
# [mbo] 38: num_leaves=2895; min_child_weight=0.713; min_data_in_leaf=16; lambda_l2=2.53; scale_pos_weight=3.31; learning_rate=0.0666; num_iterations=3221; early_stopping_rounds=347; feature_fraction=0.188; bagging_fraction=0.933 : y = 0.937 : 115.5 secs : infill_ei
#
# Thu Nov 20 11:02:12 PM 2025 AUC 0.934453072101218
#
# [mbo] 39: num_leaves=7262; min_child_weight=7.8; min_data_in_leaf=20; lambda_l2=3.23; scale_pos_weight=3.8; learning_rate=0.0537; num_iterations=2752; early_stopping_rounds=311; feature_fraction=0.348; bagging_fraction=0.583 : y = 0.934 : 147.7 secs : infill_ei
#
# Thu Nov 20 11:04:12 PM 2025 AUC 0.924636735833318
#
# [mbo] 40: num_leaves=7444; min_child_weight=7.01; min_data_in_leaf=1751; lambda_l2=1.23; scale_pos_weight=1.52; learning_rate=0.0522; num_iterations=4975; early_stopping_rounds=407; feature_fraction=0.11; bagging_fraction=0.572 : y = 0.925 : 119.0 secs : infill_ei
#
# Thu Nov 20 11:06:17 PM 2025 AUC 0.931297725291561
#
# [mbo] 41: num_leaves=8110; min_child_weight=8.39; min_data_in_leaf=926; lambda_l2=1.56; scale_pos_weight=4.11; learning_rate=0.0593; num_iterations=3461; early_stopping_rounds=266; feature_fraction=0.138; bagging_fraction=0.587 : y = 0.931 : 123.7 secs : infill_ei
#
# Saved the current state after iteration 42 in the file HT.RDATA.
#
# Thu Nov 20 11:07:53 PM 2025 AUC 0.933267300554501
#
# [mbo] 42: num_leaves=7189; min_child_weight=1.23; min_data_in_leaf=316; lambda_l2=14.4; scale_pos_weight=1.97; learning_rate=0.0662; num_iterations=2132; early_stopping_rounds=375; feature_fraction=0.0948; bagging_fraction=0.983 : y = 0.933 : 94.4 secs : infill_ei
#
# Thu Nov 20 11:11:27 PM 2025 AUC 0.933692755653889
#
# [mbo] 43: num_leaves=2329; min_child_weight=1.16; min_data_in_leaf=3; lambda_l2=53.1; scale_pos_weight=1.54; learning_rate=0.0689; num_iterations=3634; early_stopping_rounds=250; feature_fraction=0.0838; bagging_fraction=0.991 : y = 0.934 : 212.8 secs : infill_ei
#
# Thu Nov 20 11:14:07 PM 2025 AUC 0.934846987153806
#
# [mbo] 44: num_leaves=6803; min_child_weight=0.659; min_data_in_leaf=331; lambda_l2=7.75; scale_pos_weight=3.95; learning_rate=0.0544; num_iterations=2739; early_stopping_rounds=356; feature_fraction=0.145; bagging_fraction=0.913 : y = 0.935 : 158.8 secs : infill_ei
#
# Thu Nov 20 11:15:40 PM 2025 AUC 0.935347601513654
#
# [mbo] 45: num_leaves=6879; min_child_weight=6.64; min_data_in_leaf=122; lambda_l2=2.16; scale_pos_weight=4.71; learning_rate=0.0513; num_iterations=3399; early_stopping_rounds=148; feature_fraction=0.118; bagging_fraction=0.562 : y = 0.935 : 91.6 secs : infill_ei
#
# Thu Nov 20 11:18:31 PM 2025 AUC 0.937082975152483
#
# [mbo] 46: num_leaves=2998; min_child_weight=0.752; min_data_in_leaf=11; lambda_l2=17.6; scale_pos_weight=3.64; learning_rate=0.0675; num_iterations=3378; early_stopping_rounds=439; feature_fraction=0.076; bagging_fraction=0.952 : y = 0.937 : 170.6 secs : infill_ei
#
# Saved the current state after iteration 47 in the file HT.RDATA.
#
# Thu Nov 20 11:19:36 PM 2025 AUC 0.931007154222105
#
# [mbo] 47: num_leaves=6111; min_child_weight=7.21; min_data_in_leaf=5; lambda_l2=4.16; scale_pos_weight=3.64; learning_rate=0.0525; num_iterations=2808; early_stopping_rounds=53; feature_fraction=0.374; bagging_fraction=0.636 : y = 0.931 : 63.5 secs : infill_ei
#
# Thu Nov 20 11:21:34 PM 2025 AUC 0.93887639589872
#
# [mbo] 48: num_leaves=7090; min_child_weight=3.1; min_data_in_leaf=134; lambda_l2=2.64; scale_pos_weight=4.13; learning_rate=0.052; num_iterations=1823; early_stopping_rounds=357; feature_fraction=0.122; bagging_fraction=0.514 : y = 0.939 : 116.6 secs : infill_ei
#
# Thu Nov 20 11:24:05 PM 2025 AUC 0.933658195815374
#
# [mbo] 49: num_leaves=2219; min_child_weight=0.235; min_data_in_leaf=2; lambda_l2=98; scale_pos_weight=3.04; learning_rate=0.0866; num_iterations=3140; early_stopping_rounds=271; feature_fraction=0.113; bagging_fraction=0.977 : y = 0.934 : 149.5 secs : infill_ei
#
# Thu Nov 20 11:25:54 PM 2025 AUC 0.940457760160089
#
# [mbo] 50: num_leaves=6612; min_child_weight=3.32; min_data_in_leaf=3; lambda_l2=1.59; scale_pos_weight=1.99; learning_rate=0.0638; num_iterations=2414; early_stopping_rounds=363; feature_fraction=0.0635; bagging_fraction=0.517 : y = 0.94 : 107.1 secs : infill_ei
#
# Thu Nov 20 11:28:35 PM 2025 AUC 0.934814104977355
#
# [mbo] 51: num_leaves=7017; min_child_weight=4.02; min_data_in_leaf=137; lambda_l2=23.6; scale_pos_weight=2.54; learning_rate=0.0649; num_iterations=2058; early_stopping_rounds=486; feature_fraction=0.0623; bagging_fraction=0.553 : y = 0.935 : 160.1 secs : infill_ei
#
# Saved the current state after iteration 52 in the file HT.RDATA.
#
# Thu Nov 20 11:30:19 PM 2025 AUC 0.936104562636855
#
# [mbo] 52: num_leaves=6095; min_child_weight=5.97; min_data_in_leaf=11; lambda_l2=13.4; scale_pos_weight=3.37; learning_rate=0.0579; num_iterations=2287; early_stopping_rounds=266; feature_fraction=0.0542; bagging_fraction=0.516 : y = 0.936 : 102.4 secs : infill_ei
#
# Thu Nov 20 11:32:06 PM 2025 AUC 0.931175255960901
#
# [mbo] 53: num_leaves=7400; min_child_weight=0.633; min_data_in_leaf=97; lambda_l2=2.24; scale_pos_weight=1.33; learning_rate=0.079; num_iterations=3014; early_stopping_rounds=404; feature_fraction=0.277; bagging_fraction=0.501 : y = 0.931 : 106.5 secs : infill_ei
#
# Thu Nov 20 11:37:28 PM 2025 AUC 0.928886924905833
#
# [mbo] 54: num_leaves=1121; min_child_weight=0.42; min_data_in_leaf=12; lambda_l2=329; scale_pos_weight=3.51; learning_rate=0.0682; num_iterations=4041; early_stopping_rounds=450; feature_fraction=0.621; bagging_fraction=0.951 : y = 0.929 : 321.2 secs : infill_ei
#
# Thu Nov 20 11:40:32 PM 2025 AUC 0.931454754460736
#
# [mbo] 55: num_leaves=6803; min_child_weight=1.58; min_data_in_leaf=2; lambda_l2=316; scale_pos_weight=3.74; learning_rate=0.0649; num_iterations=1943; early_stopping_rounds=370; feature_fraction=0.0556; bagging_fraction=0.506 : y = 0.931 : 182.5 secs : infill_ei
#
# Saved the current state after iteration 56 in the file HT.RDATA.
#
# Thu Nov 20 11:42:53 PM 2025 AUC 0.932099983290486
#
# [mbo] 56: num_leaves=4923; min_child_weight=3.27; min_data_in_leaf=5; lambda_l2=2.66; scale_pos_weight=1.27; learning_rate=0.057; num_iterations=3584; early_stopping_rounds=427; feature_fraction=0.0831; bagging_fraction=0.722 : y = 0.932 : 138.9 secs : infill_ei
#
# Thu Nov 20 11:43:59 PM 2025 AUC 0.935664008578893
#
# [mbo] 57: num_leaves=4807; min_child_weight=0.886; min_data_in_leaf=5; lambda_l2=1.77; scale_pos_weight=1.4; learning_rate=0.0552; num_iterations=2419; early_stopping_rounds=131; feature_fraction=0.129; bagging_fraction=0.806 : y = 0.936 : 63.9 secs : infill_ei
#
# Thu Nov 20 11:47:34 PM 2025 AUC 0.934963081368623
#
# [mbo] 58: num_leaves=6515; min_child_weight=2.64; min_data_in_leaf=21; lambda_l2=46.3; scale_pos_weight=2.28; learning_rate=0.0503; num_iterations=2436; early_stopping_rounds=272; feature_fraction=0.067; bagging_fraction=0.515 : y = 0.935 : 213.2 secs : infill_ei
#
# Thu Nov 20 11:50:08 PM 2025 AUC 0.938643871936673
#
# [mbo] 59: num_leaves=3344; min_child_weight=0.385; min_data_in_leaf=6; lambda_l2=9.15; scale_pos_weight=1.09; learning_rate=0.0687; num_iterations=2398; early_stopping_rounds=407; feature_fraction=0.0687; bagging_fraction=0.69 : y = 0.939 : 152.5 secs : infill_ei
#
# Thu Nov 20 11:52:28 PM 2025 AUC 0.9337534870206
#
# [mbo] 60: num_leaves=5610; min_child_weight=2.88; min_data_in_leaf=79; lambda_l2=7.67; scale_pos_weight=4.96; learning_rate=0.0543; num_iterations=2286; early_stopping_rounds=477; feature_fraction=0.176; bagging_fraction=0.588 : y = 0.934 : 138.9 secs : infill_ei
#
# Saved the current state after iteration 61 in the file HT.RDATA.
#
# Thu Nov 20 11:54:51 PM 2025 AUC 0.93470673460527
#
# [mbo] 61: num_leaves=4755; min_child_weight=0.457; min_data_in_leaf=7; lambda_l2=8.98; scale_pos_weight=1.32; learning_rate=0.0684; num_iterations=2406; early_stopping_rounds=369; feature_fraction=0.118; bagging_fraction=0.55 : y = 0.935 : 142.2 secs : infill_ei
#
# Thu Nov 20 11:57:49 PM 2025 AUC 0.933841396512745
#
# [mbo] 62: num_leaves=2876; min_child_weight=0.0445; min_data_in_leaf=83; lambda_l2=26.6; scale_pos_weight=3.47; learning_rate=0.0927; num_iterations=3168; early_stopping_rounds=439; feature_fraction=0.0781; bagging_fraction=0.799 : y = 0.934 : 176.1 secs : infill_ei
#
# Fri Nov 21 12:00:22 AM 2025 AUC 0.937397033490832
#
# [mbo] 63: num_leaves=2800; min_child_weight=0.38; min_data_in_leaf=26; lambda_l2=3.73; scale_pos_weight=1.88; learning_rate=0.0606; num_iterations=2423; early_stopping_rounds=389; feature_fraction=0.0527; bagging_fraction=0.874 : y = 0.937 : 150.4 secs : infill_ei
#
# Fri Nov 21 12:01:17 AM 2025 AUC 0.934401064577239
#
# [mbo] 64: num_leaves=1826; min_child_weight=0.126; min_data_in_leaf=2401; lambda_l2=5.01; scale_pos_weight=2.04; learning_rate=0.0709; num_iterations=2521; early_stopping_rounds=94; feature_fraction=0.0886; bagging_fraction=0.848 : y = 0.934 : 53.3 secs : infill_ei
#
# Fri Nov 21 12:06:19 AM 2025 AUC 0.929963312885988
#
# [mbo] 65: num_leaves=2841; min_child_weight=0.133; min_data_in_leaf=2564; lambda_l2=48.1; scale_pos_weight=1.76; learning_rate=0.0594; num_iterations=2895; early_stopping_rounds=428; feature_fraction=0.185; bagging_fraction=0.83 : y = 0.93 : 300.0 secs : infill_ei
#
# Saved the current state after iteration 66 in the file HT.RDATA.
#
# Fri Nov 21 12:07:45 AM 2025 AUC 0.938874047171831
#
# [mbo] 66: num_leaves=5418; min_child_weight=0.48; min_data_in_leaf=157; lambda_l2=5.63; scale_pos_weight=1.09; learning_rate=0.0827; num_iterations=2381; early_stopping_rounds=143; feature_fraction=0.0975; bagging_fraction=0.882 : y = 0.939 : 84.8 secs : infill_ei
#
# Fri Nov 21 12:11:22 AM 2025 AUC 0.931344364296935
#
# [mbo] 67: num_leaves=2412; min_child_weight=0.311; min_data_in_leaf=21; lambda_l2=33.1; scale_pos_weight=1.13; learning_rate=0.0754; num_iterations=2147; early_stopping_rounds=407; feature_fraction=0.1; bagging_fraction=0.938 : y = 0.931 : 214.3 secs : infill_ei
#
# Fri Nov 21 12:12:46 AM 2025 AUC 0.934480921291478
#
# [mbo] 68: num_leaves=6710; min_child_weight=1.24; min_data_in_leaf=65; lambda_l2=4.48; scale_pos_weight=2.18; learning_rate=0.0798; num_iterations=2450; early_stopping_rounds=226; feature_fraction=0.117; bagging_fraction=0.719 : y = 0.934 : 82.7 secs : infill_ei
#
# Fri Nov 21 12:13:12 AM 2025 AUC 0.928094061814465
#
# [mbo] 69: num_leaves=4963; min_child_weight=0.157; min_data_in_leaf=1173; lambda_l2=0.396; scale_pos_weight=2.27; learning_rate=0.097; num_iterations=2700; early_stopping_rounds=82; feature_fraction=0.0573; bagging_fraction=0.906 : y = 0.928 : 24.8 secs : infill_ei
#
# Fri Nov 21 12:14:36 AM 2025 AUC 0.935670383694735
#
# [mbo] 70: num_leaves=3486; min_child_weight=0.731; min_data_in_leaf=7; lambda_l2=2.05; scale_pos_weight=2.54; learning_rate=0.071; num_iterations=2514; early_stopping_rounds=157; feature_fraction=0.0639; bagging_fraction=0.914 : y = 0.936 : 81.8 secs : infill_ei
#
# Fri Nov 21 12:16:33 AM 2025 AUC 0.932780778555989
#
# [mbo] 71: num_leaves=7508; min_child_weight=9.54; min_data_in_leaf=199; lambda_l2=2.5; scale_pos_weight=4.11; learning_rate=0.0428; num_iterations=2136; early_stopping_rounds=147; feature_fraction=0.781; bagging_fraction=0.501 : y = 0.933 : 115.9 secs : infill_ei
#
# Saved the current state after iteration 72 in the file HT.RDATA.
#
# Fri Nov 21 12:25:03 AM 2025 AUC 0.9263288257909
#
# [mbo] 72: num_leaves=2134; min_child_weight=0.0298; min_data_in_leaf=648; lambda_l2=627; scale_pos_weight=1.02; learning_rate=0.0827; num_iterations=3475; early_stopping_rounds=130; feature_fraction=0.334; bagging_fraction=0.685 : y = 0.926 : 507.8 secs : infill_ei
#
# Fri Nov 21 12:26:10 AM 2025 AUC 0.928611452794951
#
# [mbo] 73: num_leaves=4720; min_child_weight=0.0354; min_data_in_leaf=585; lambda_l2=0.303; scale_pos_weight=1.85; learning_rate=0.0663; num_iterations=2338; early_stopping_rounds=209; feature_fraction=0.277; bagging_fraction=0.851 : y = 0.929 : 64.9 secs : infill_ei
#
# Fri Nov 21 12:28:32 AM 2025 AUC 0.938166073780893
#
# [mbo] 74: num_leaves=4153; min_child_weight=1.32; min_data_in_leaf=6; lambda_l2=10.6; scale_pos_weight=2.52; learning_rate=0.084; num_iterations=2530; early_stopping_rounds=168; feature_fraction=0.0756; bagging_fraction=0.616 : y = 0.938 : 141.0 secs : infill_ei
#
# Saved the current state after iteration 75 in the file HT.RDATA.
#
# Fri Nov 21 12:28:56 AM 2025 AUC 0.92313187296206
#
# [mbo] 75: num_leaves=2698; min_child_weight=1; min_data_in_leaf=2375; lambda_l2=0.569; scale_pos_weight=1.22; learning_rate=0.0845; num_iterations=3612; early_stopping_rounds=56; feature_fraction=0.164; bagging_fraction=0.8 : y = 0.923 : 22.0 secs : infill_ei
#
# Fri Nov 21 12:30:30 AM 2025 AUC 0.929885804898639
#
# [mbo] 76: num_leaves=1877; min_child_weight=0.737; min_data_in_leaf=14; lambda_l2=3.22; scale_pos_weight=3.25; learning_rate=0.0871; num_iterations=1678; early_stopping_rounds=395; feature_fraction=0.13; bagging_fraction=0.654 : y = 0.93 : 92.3 secs : infill_ei
#
# Fri Nov 21 12:33:39 AM 2025 AUC 0.927807852666375
#
# [mbo] 77: num_leaves=5708; min_child_weight=6.15; min_data_in_leaf=1690; lambda_l2=165; scale_pos_weight=4.44; learning_rate=0.0513; num_iterations=4992; early_stopping_rounds=115; feature_fraction=0.53; bagging_fraction=0.526 : y = 0.928 : 187.9 secs : infill_ei
#
# Fri Nov 21 12:34:50 AM 2025 AUC 0.929100994585178
#
# [mbo] 78: num_leaves=6085; min_child_weight=0.308; min_data_in_leaf=22; lambda_l2=16.2; scale_pos_weight=4.6; learning_rate=0.0868; num_iterations=2159; early_stopping_rounds=186; feature_fraction=0.218; bagging_fraction=0.884 : y = 0.929 : 68.8 secs : infill_ei
#
# Fri Nov 21 12:36:38 AM 2025 AUC 0.934035334247324
#
# [mbo] 79: num_leaves=4592; min_child_weight=1.89; min_data_in_leaf=2; lambda_l2=3.25; scale_pos_weight=1.08; learning_rate=0.0872; num_iterations=2901; early_stopping_rounds=279; feature_fraction=0.221; bagging_fraction=0.67 : y = 0.934 : 106.6 secs : infill_ei
#
# Fri Nov 21 12:37:26 AM 2025 AUC 0.930788387088981
#
# [mbo] 80: num_leaves=7249; min_child_weight=4.43; min_data_in_leaf=3; lambda_l2=2.93; scale_pos_weight=2.68; learning_rate=0.0792; num_iterations=2498; early_stopping_rounds=152; feature_fraction=0.0835; bagging_fraction=0.584 : y = 0.931 : 46.2 secs : infill_ei
#
# Fri Nov 21 12:41:16 AM 2025 AUC 0.93188826233803
#
# [mbo] 81: num_leaves=4192; min_child_weight=0.943; min_data_in_leaf=43; lambda_l2=235; scale_pos_weight=3.12; learning_rate=0.0839; num_iterations=2548; early_stopping_rounds=331; feature_fraction=0.0515; bagging_fraction=0.794 : y = 0.932 : 227.4 secs : infill_ei
#
# Saved the current state after iteration 82 in the file HT.RDATA.
#
# Fri Nov 21 12:42:57 AM 2025 AUC 0.933476001715242
#
# [mbo] 82: num_leaves=3938; min_child_weight=0.99; min_data_in_leaf=79; lambda_l2=53.6; scale_pos_weight=1.77; learning_rate=0.0931; num_iterations=2846; early_stopping_rounds=108; feature_fraction=0.206; bagging_fraction=0.718 : y = 0.933 : 98.9 secs : infill_ei
#
# Fri Nov 21 12:46:37 AM 2025 AUC 0.929549601421047
#
# [mbo] 83: num_leaves=7171; min_child_weight=3.28; min_data_in_leaf=924; lambda_l2=193; scale_pos_weight=3.46; learning_rate=0.062; num_iterations=2650; early_stopping_rounds=401; feature_fraction=0.0531; bagging_fraction=0.523 : y = 0.93 : 217.6 secs : infill_ei
#
# Fri Nov 21 12:49:45 AM 2025 AUC 0.936693757553673
#
# [mbo] 84: num_leaves=7434; min_child_weight=3.03; min_data_in_leaf=99; lambda_l2=9.66; scale_pos_weight=1.34; learning_rate=0.0554; num_iterations=2111; early_stopping_rounds=331; feature_fraction=0.0505; bagging_fraction=0.827 : y = 0.937 : 185.5 secs : infill_ei
#
# Fri Nov 21 12:51:35 AM 2025 AUC 0.93580191240054
#
# [mbo] 85: num_leaves=6683; min_child_weight=3.31; min_data_in_leaf=105; lambda_l2=0.0581; scale_pos_weight=2.13; learning_rate=0.0605; num_iterations=2170; early_stopping_rounds=358; feature_fraction=0.0534; bagging_fraction=0.526 : y = 0.936 : 109.0 secs : infill_ei
#
# Saved the current state after iteration 86 in the file HT.RDATA.
#
# Fri Nov 21 12:52:17 AM 2025 AUC 0.931186328530522
#
# [mbo] 86: num_leaves=4095; min_child_weight=0.748; min_data_in_leaf=33; lambda_l2=60.5; scale_pos_weight=1.32; learning_rate=0.0809; num_iterations=366; early_stopping_rounds=146; feature_fraction=0.0985; bagging_fraction=0.581 : y = 0.931 : 40.3 secs : infill_ei
#
# Fri Nov 21 12:54:00 AM 2025 AUC 0.935399609037633
#
# [mbo] 87: num_leaves=7538; min_child_weight=3.99; min_data_in_leaf=5; lambda_l2=2.44; scale_pos_weight=4.03; learning_rate=0.0524; num_iterations=1948; early_stopping_rounds=283; feature_fraction=0.0617; bagging_fraction=0.889 : y = 0.935 : 100.6 secs : infill_ei
#
# Fri Nov 21 12:56:11 AM 2025 AUC 0.937935898545735
#
# [mbo] 88: num_leaves=7886; min_child_weight=3.75; min_data_in_leaf=259; lambda_l2=0.281; scale_pos_weight=4.88; learning_rate=0.0452; num_iterations=1503; early_stopping_rounds=403; feature_fraction=0.288; bagging_fraction=0.538 : y = 0.938 : 128.6 secs : infill_ei
#
# Fri Nov 21 12:57:20 AM 2025 AUC 0.927754167480333
#
# [mbo] 89: num_leaves=3987; min_child_weight=2.03; min_data_in_leaf=152; lambda_l2=0.193; scale_pos_weight=1.74; learning_rate=0.0838; num_iterations=2981; early_stopping_rounds=153; feature_fraction=0.0801; bagging_fraction=0.969 : y = 0.928 : 67.4 secs : infill_ei
#
# Fri Nov 21 12:58:38 AM 2025 AUC 0.935061392365564
#
# [mbo] 90: num_leaves=6614; min_child_weight=2.71; min_data_in_leaf=34; lambda_l2=0.967; scale_pos_weight=1.38; learning_rate=0.0657; num_iterations=1849; early_stopping_rounds=393; feature_fraction=0.129; bagging_fraction=0.738 : y = 0.935 : 76.9 secs : infill_ei
#
# Saved the final state in the file HT.RDATA

# %% [markdown]
# la bayesian optimization ha corrido, extraigo los mejores hiperparametros

# %%
# almaceno los resultados de la Bayesian Optimization
# y capturo los mejores hiperparametros encontrados

tb_bayesiana <- as.data.table(bayesiana_salida$opt.path)

# ordeno en forma descendente por AUC = y
setorder(tb_bayesiana, -y, -num_iterations)

# grabo para eventualmente poder utilizarlos en OTRA corrida
fwrite( tb_bayesiana,
  file="BO_log.txt",
  sep="\t"
)

# los mejores hiperparámetros son los que quedaron en el registro 1 de la tabla
PARAM$out$lgbm$mejores_hiperparametros <- tb_bayesiana[
  1, # el primero es el de mejor AUC
  setdiff(colnames(tb_bayesiana),
    c("y","dob","eol","error.message","exec.time","ei","error.model",
      "train.time","prop.type","propose.time","se","mean","iter")),
  with= FALSE
]

print(PARAM$out$lgbm$mejores_hiperparametros)
# Out:
#    num_leaves min_child_weight min_data_in_leaf lambda_l2 scale_pos_weight
#         <int>            <num>            <int>     <num>            <num>
# 1:       6612         3.320599                3  1.591367         1.988552
#    learning_rate num_iterations early_stopping_rounds feature_fraction
#            <num>          <int>                 <int>            <num>
# 1:    0.06383827           2414                   363       0.06349003
#    bagging_fraction
#               <num>
# 1:        0.5169506

# %% [markdown]
# ### 6.3.3 Produccion

# %% [markdown]
# #### Final Training
# Construyo el modelo final, que es uno solo, no hace ningun tipo de particion < training, validation, testing>]

# %% [markdown]
# ##### Final Training Dataset
#
# Aqui esta la gran decision de en qué meses hago el Final Training
# <br> debo utilizar los mejores hiperparámetros que encontré en la optimización bayesiana

# %%
PARAM$trainingstrategy$final_train <- c(
  202105, 202104, 202103, 202102, 202101,
  202012, 202011, 202010, 202009, 202008, 202007,
  202006, 202005
)

dataset[, fold_final_train := foto_mes %in% PARAM$trainingstrategy$final_train ]

# creo el dfinal_train en formato  LightGBM
dfinal_train <- lgb.Dataset(
  data= data.matrix(dataset[fold_final_train == TRUE, campos_buenos, with= FALSE]),
  label= dataset[fold_final_train == TRUE, clase01],
  free_raw_data= TRUE
)

nrow( dfinal_train) # verifico el tamaño
# Out:
# [1] 207504

# %% [markdown]
# ##### Final Training Hyperparameters

# %%
# uno los parametros fijos y los mejores encontrados de los variables
fijos <- copy(PARAM$lgbm$param_fijos)

# quito lo que optimice en la Bayesian Optimization
fijos$num_iterations <- NULL
fijos$early_stopping_rounds <- NULL

# agrego a los hiperparametros fijos los que encontre con la Bayesian Optimization
param_final <- c(fijos, PARAM$out$lgbm$mejores_hiperparametros)

# Para el entrenamiento final, removemos early_stopping_rounds
# ya que se entrena con todos los datos disponibles y la cantidad de iteraciones
# ya está optimizada en 'num_iterations'.
param_final$early_stopping_rounds <- NULL

# %% [markdown]
# ##### Training
# Genero el modelo final, siempre sobre TODOS los datos de  final_train, sin hacer ningun tipo de undersampling de la clase mayoritaria

# %%
final_model <- lgb.train(
  data= dfinal_train,
  param= param_final,
  verbose= -100
)

# %%
# grabo a disco el modelo en un formato para seres humanos ... ponele ...

lgb.save(final_model, "modelo.txt")

# %%
# ahora imprimo la importancia de variables

tb_importancia <- as.data.table(lgb.importance(final_model))
archivo_importancia <- "impo.txt"

fwrite( tb_importancia,
  file= archivo_importancia,
  sep= "\t"
)

# %% [markdown]
# #### Scoring

# %% [markdown]
# Aplico el modelo final a los datos del futuro

# %%
PARAM$trainingstrategy$future <- c(202107)

dfuture <- dataset[ foto_mes %in% PARAM$trainingstrategy$future ]

# %%
# aplico final_model   a dfuture

prediccion <- predict(
  final_model,
  data.matrix(dfuture[, campos_buenos, with= FALSE])
)

# %% [markdown]
# ##### Tabla Prediccion

# %%
tb_prediccion <- dfuture[, list(numero_de_cliente)]
tb_prediccion[, prob := prediccion]

# grabo las probabilidad del modelo
#  me va a ser util para hacer Ensembles de modelos
fwrite(tb_prediccion,
  file= "prediccion.txt",
  sep= "\t"
)

# %% [markdown]
# #### Curva de Ganancia

# %% [markdown]
# Genero las salidas

# %%
# asigno clase ternaria
tb_prediccion[, clase_ternaria := dfuture$clase_ternaria ]

# asigno ganancias
tb_prediccion[, ganancia := -3000.0 ]
tb_prediccion[clase_ternaria=="BAJA+2", ganancia := 117000.0 ]

# reordeno, y acumulada
setorder( tb_prediccion, -prob )
tb_prediccion[, gan_acum := cumsum(ganancia)]

# media movil de ancho 400
tb_prediccion[,
  gan_suavizada := frollmean(
    x= gan_acum,
    n= 400,
    align= "center",
    na.rm= TRUE,
    hasNA= TRUE
  )
]

# %%
tb_prediccion[, sum(!is.na(gan_suavizada) )]
tb_prediccion[, .N]
# Out:
# [1] 16152
# [1] 16551

# %%
# Este es la ganancia a reportar
resultado <- list()
resultado$ganancia_suavizada_max <- max( tb_prediccion$gan_suavizada, na.rm=TRUE )
options(digits= 8)
resultado$envios <- which.max( tb_prediccion$gan_suavizada)
resultado
# Out:
# $ganancia_suavizada_max
# [1] 6198000
#
# $envios
# [1] 1359

# %%
# grabo las ganancias
fwrite( tb_prediccion,
  file= "ganancias.txt",
  sep= "\t"
)

# %%
# genero el grafico

tb_prediccion[, envios:= .I]

pdf("curva_de_ganancia.pdf")

plot(
  x= tb_prediccion$envios,
  y= tb_prediccion$gan_acum,
  type= "l",
  col= "gray",
  xlim= c(0, 6000),
  ylim= c(0, 8000000),
  main= paste0("Mejor gan prom= ", as.integer(resultado$ganancia_suavizada_max), " envios= ", resultado$envios),
  xlab= "Envios",
  ylab= "Ganancia",
  panel.first= grid()
)

dev.off()
# Out:
# agg_record_2095439107
#                     2

# %%
# grabo los parametros
if( !require("yaml")) install.packages("yaml")
require("yaml")

PARAM$resultado <- resultado

write_yaml( PARAM, file="PARAM.yml")
# Out:
# Loading required package: yaml

# %%
format(Sys.time(), "%a %b %d %X %Y")
fin <- Sys.time()

# Duración en segundos
secs <- as.numeric(difftime(fin, principio, units = "secs"))
secs <- round(secs)

# A hh:mm:ss
h <- secs %/% 3600
m <- (secs %% 3600) %/% 60
s <- secs %% 60
dur_hms <- sprintf("%02d:%02d:%02d", h, m, s)

cat(
  "Inicio: ", format(principio, "%a %b %d %X %Y"), "\n",
  "Fin:    ", format(fin,       "%a %b %d %X %Y"), "\n",
  "Duración (hh:mm:ss): ", dur_hms, "\n",
  sep = ""
)
# Out:
# [1] "Fri Nov 21 01:03:19 AM 2025"
# Inicio: Thu Nov 20 06:20:17 PM 2025
# Fin:    Fri Nov 21 01:03:19 AM 2025
# Duración (hh:mm:ss): 06:43:02
