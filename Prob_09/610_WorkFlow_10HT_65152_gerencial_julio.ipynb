# %% [markdown]
# <a href="https://colab.research.google.com/github/jwbarbona/labo2025v/blob/main/610_WorkFlow_10HT_65152_gerencial_julio.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # 6 WorkFlow  Gerencial, futuro=JULIO

# %% [markdown]
# ### 6.1 Objetivo

# %% [markdown]
# Presentar un workflow/pipeline completo al que los estudiantes deberán enriquecer

# %% [markdown]
# #### 6.2  Seteo del ambiente en Google Colab

# %% [markdown]
# Esta parte se debe correr con el runtime en Python3
# <br>Ir al menu, Runtime -> Change Runtime Type -> Runtime type ->  **Python 3**

# %% [markdown]
# Conectar la virtual machine donde esta corriendo Google Colab con el  Google Drive, para poder tener persistencia de archivos

# %%
# primero establecer el Runtime de Python 3
from google.colab import drive
drive.mount('/content/.drive')
# Out:
# Mounted at /content/.drive

# %% [markdown]
# Para correr la siguiente celda es fundamental en Arranque en Frio haber copiado el archivo kaggle.json al Google Drive, en la carpeta indicada en el instructivo
#
# <br>los siguientes comando estan en shell script de Linux
# *   Crear las carpetas en el Google Drive
# *   "instalar" el archivo kaggle.json desde el Google Drive a la virtual machine para que pueda ser utilizado por la libreria  kaggle de Python
# *   Bajar el  **dataset_pequeno**  al  Google Drive  y tambien al disco local de la virtual machine que esta corriendo Google Colab
# *   Bajar el **dataset_historico** al Google Drive y tambien al disco local de la virtual machine que esta corriendo Google Colab

# %%
%%shell

mkdir -p "/content/.drive/My Drive/labo1"
mkdir -p "/content/buckets"
ln -s "/content/.drive/My Drive/labo1" /content/buckets/b1

mkdir -p ~/.kaggle
cp /content/buckets/b1/kaggle/kaggle.json  ~/.kaggle
chmod 600 ~/.kaggle/kaggle.json


mkdir -p /content/buckets/b1/exp
mkdir -p /content/buckets/b1/datasets
mkdir -p /content/datasets


webfiles="https://storage.googleapis.com/open-courses/austral2025-af91/"
destino_local="/content/datasets"
destino_bucket="/content/buckets/b1/datasets"


archivo="dataset_pequeno.csv"

if ! test -f $destino_bucket/$archivo; then
  wget  $webfiles/$archivo  -O $destino_bucket/$archivo
fi


if ! test -f $destino_local/$pequeno; then
  cp  $destino_bucket/$archivo  $destino_local/$archivo
fi

#-------

archivo="gerencial_competencia_2025.csv.gz"

if ! test -f $destino_bucket/$archivo; then
  wget  $webfiles/$archivo  -O $destino_bucket/$archivo
fi


if ! test -f $destino_local/$pequeno; then
  cp  $destino_bucket/$archivo  $destino_local/$archivo
fi
# Out:
# cp: cannot stat '/content/buckets/b1/kaggle/kaggle.json': No such file or directory
# chmod: cannot access '/root/.kaggle/kaggle.json': No such file or directory

# %% [markdown]
# ## 6.3  Workflow

# %% [markdown]
# ## Inicializacion

# %% [markdown]
# Esta parte se debe correr con el runtime en lenguaje **R** Ir al menu, Runtime -> Change Runtime Type -> Runtime type -> R

# %% [markdown]
# limpio el ambiente de R

# %%
format(Sys.time(), "%a %b %d %X %Y")
# Out:
# [1] "Thu Nov 20 06:24:45 PM 2025"

# %%
# limpio la memoria
rm(list=ls(all.names=TRUE)) # remove all objects
gc(full=TRUE, verbose=FALSE) # garbage collection
# Out:
#        used    (Mb) gc trigger (Mb) max used (Mb)
# Ncells  710109 38.0 1454494    77.7 1454494  77.7
# Vcells 1317355 10.1 8388608    64.0 2167712  16.6

# %%
principio <- Sys.time()

# %%
require("data.table")

if( !require("R.utils")) install.packages("R.utils")
require("R.utils")
# Out:
# Loading required package: data.table
#
# Loading required package: R.utils
#
# Warning message in library(package, lib.loc = lib.loc, character.only = TRUE, logical.return = TRUE, :
# “there is no package called ‘R.utils’”
# Installing package into ‘/usr/local/lib/R/site-library’
# (as ‘lib’ is unspecified)
#
# also installing the dependencies ‘R.oo’, ‘R.methodsS3’
#
#
# Loading required package: R.utils
#
# Loading required package: R.oo
#
# Loading required package: R.methodsS3
#
# R.methodsS3 v1.8.2 (2022-06-13 22:00:14 UTC) successfully loaded. See ?R.methodsS3 for help.
#
# R.oo v1.27.1 (2025-05-02 21:00:05 UTC) successfully loaded. See ?R.oo for help.
#
#
# Attaching package: ‘R.oo’
#
#
# The following object is masked from ‘package:R.methodsS3’:
#
#     throw
#
#
# The following objects are masked from ‘package:methods’:
#
#     getClasses, getMethods
#
#
# The following objects are masked from ‘package:base’:
#
#     attach, detach, load, save
#
#
# R.utils v2.13.0 (2025-02-24 21:20:02 UTC) successfully loaded. See ?R.utils for help.
#
#
# Attaching package: ‘R.utils’
#
#
# The following object is masked from ‘package:utils’:
#
#     timestamp
#
#
# The following objects are masked from ‘package:base’:
#
#     cat, commandArgs, getOption, isOpen, nullfile, parse, use, warnings

# %% [markdown]
# #### Parametros
# Si es gerente, no cambie nada
# <br>Si es Analista, cambie el nombre del dataset

# %%
PARAM <- list()
PARAM$semilla_primigenia <- 200003 # 100009, 200003, 499999, 700009, 999983

PARAM$experimento <- 65152 # 10HT
PARAM$dataset <- "gerencial_competencia_2025.csv.gz"

# %% [markdown]
# #### Carpeta del Experimento

# %%
# carpeta de trabajo

setwd("/content/buckets/b1/exp")
experimento_folder <- paste0("WF", PARAM$experimento)
dir.create(experimento_folder, showWarnings=FALSE)
setwd( paste0("/content/buckets/b1/exp/", experimento_folder ))

# %% [markdown]
# ### 6.3.1   Preprocesamiento del dataset

# %% [markdown]
# #### 6.3.1.1  DT incorporar dataset

# %%
# lectura del dataset
dataset <- fread(paste0("/content/datasets/", PARAM$dataset))

# %% [markdown]
# #### 6.3.1.2  CA  Catastrophe Analysis
# Se intentan reparar las variables que para un mes están con todos los valores en cero.

# %% [markdown]
# El método que se utiliza es **Machine Learning** se asigna NA also valores, si ha leido bien, es la "anti imputación de valores faltantes"
# <br> Usted podrá aplicar aquí otros métodos

# %%
dataset[ foto_mes==202006, internet:=NA]
dataset[ foto_mes==202006, mrentabilidad:=NA]
dataset[ foto_mes==202006, mrentabilidad_annual:=NA]
dataset[ foto_mes==202006, mcomisiones:=NA]
dataset[ foto_mes==202006, mactivos_margen:=NA]
dataset[ foto_mes==202006, mpasivos_margen:=NA]
dataset[ foto_mes==202006, mcuentas_saldo:=NA]
dataset[ foto_mes==202006, ctarjeta_visa_transacciones:=NA]
dataset[ foto_mes==202006, mtarjeta_visa_consumo:=NA]
dataset[ foto_mes==202006, mtarjeta_master_consumo:=NA]
dataset[ foto_mes==202006, ccallcenter_transacciones:=NA]
dataset[ foto_mes==202006, chomebanking_transacciones:=NA]
dataset[ foto_mes==202006, chomebanking_transacciones:=NA]

# %% [markdown]
# #### 6.3.1.3  DR  Data Drifting
# Se intenta corregir el data drifting, quizas ajustando por IPC ...
# <br>Esta parte podrá ser abordada por todos los Analistas y también la Gerenciapero se decide pedagogicamente no incluirla en esta primer version para reducir la carga cognitiva

# %%
# sin codigo en esta primera version del workflow

# %% [markdown]
# #### 6.3.1.3  FE_intra_manual Feature Engineering intra-mes
#
# Agrego campos nuevos dentro del mismo mes, SIN considerar la historia.

# %%
# esta funcion atributos presentes existe debido a que las modalidades poseen datasets con distinta cantidad de campos
atributos_presentes <- function( patributos )
{
  atributos <- unique( patributos )
  comun <- intersect( atributos, colnames(dataset) )

  return(  length( atributos ) == length( comun ) )
}

# el mes 1,2, ..12
if( atributos_presentes( c("foto_mes") ))
  dataset[, kmes := foto_mes %% 100]

# variable extraida de una tesis de maestria de Irlanda
if( atributos_presentes( c("mpayroll", "cliente_edad") ))
  dataset[, mpayroll_sobre_edad := mpayroll / cliente_edad]

# %%
# visualizo las columas del dataset a esta etapa
colnames(dataset)
# Out:
#  [1] "numero_de_cliente"           "foto_mes"
#  [3] "internet"                    "cliente_edad"
#  [5] "cliente_antiguedad"          "mrentabilidad"
#  [7] "mrentabilidad_annual"        "mcomisiones"
#  [9] "mactivos_margen"             "mpasivos_margen"
# [11] "cproductos"                  "mcuenta_corriente"
# [13] "mcaja_ahorro"                "cdescubierto_preacordado"
# [15] "mcuentas_saldo"              "ctarjeta_visa_transacciones"
# [17] "mtarjeta_visa_consumo"       "mtarjeta_master_consumo"
# [19] "mprestamos_personales"       "cpayroll_trx"
# [21] "mpayroll"                    "ccomisiones_mantenimiento"
# [23] "ccallcenter_transacciones"   "chomebanking_transacciones"
# [25] "ctrx_quarter"                "Master_status"
# [27] "Master_fechaalta"            "Master_mpagominimo"
# [29] "Visa_status"                 "Visa_fechaalta"
# [31] "Visa_mpagominimo"            "clase_ternaria"
# [33] "kmes"                        "mpayroll_sobre_edad"

# %% [markdown]
# #### 6.3.1.4  FE_rf Feature Engineering de nuevas variables a partir de hojas de Random Forest
#
# Esto se mostrará unicamente a la *modalidad Analista Sr*

# %%
# No se implementa Feature Engineering a partir de Random Forest

# %% [markdown]
# #### 6.3.1.5  FEhist Feature Engineering historico
#
# El Fature Engineering Histórico es la etapa que más aporta a la ganancia final, ya que enriquece cada registro del dataset con su historia.

# %% [markdown]
# Para cada campo del dataset original (*)
# se crean lo siguientes campos de a partir de la historia
# * lag1  lags de orden 1
# * delta1  =  valor actual - lag1
# * lag2  lags de orden 2
# * delta2  = valor actual - lag2
#
#
# (*) Excepto para los campos  <numero_de_cliente,  foto_mes,  clase_ternaria>

# %%
# Feature Engineering Historico

# todo es lagueable, menos la primary key y la clase
cols_lagueables <- copy( setdiff(
    colnames(dataset),
    c("numero_de_cliente", "foto_mes", "clase_ternaria")
) )

# https://rdrr.io/cran/data.table/man/shift.html

# lags de orden 1
dataset[,
    paste0(cols_lagueables, "_lag1") := shift(.SD, 1, NA, "lag"),
    by = numero_de_cliente,
    .SDcols = cols_lagueables
]

# lags de orden 2
dataset[,
    paste0(cols_lagueables, "_lag2") := shift(.SD, 2, NA, "lag"),
    by = numero_de_cliente,
    .SDcols = cols_lagueables
]

# agrego los delta lags
for (vcol in cols_lagueables)
{
    dataset[, paste0(vcol, "_delta1") := get(vcol) - get(paste0(vcol, "_lag1"))]
    dataset[, paste0(vcol, "_delta2") := get(vcol) - get(paste0(vcol, "_lag2"))]
}

# %% [markdown]
# Verificacion de los campos recien creados

# %%
ncol(dataset)
colnames(dataset)
# Out:
# [1] 158
#   [1] "numero_de_cliente"                  "foto_mes"
#   [3] "internet"                           "cliente_edad"
#   [5] "cliente_antiguedad"                 "mrentabilidad"
#   [7] "mrentabilidad_annual"               "mcomisiones"
#   [9] "mactivos_margen"                    "mpasivos_margen"
#  [11] "cproductos"                         "mcuenta_corriente"
#  [13] "mcaja_ahorro"                       "cdescubierto_preacordado"
#  [15] "mcuentas_saldo"                     "ctarjeta_visa_transacciones"
#  [17] "mtarjeta_visa_consumo"              "mtarjeta_master_consumo"
#  [19] "mprestamos_personales"              "cpayroll_trx"
#  [21] "mpayroll"                           "ccomisiones_mantenimiento"
#  [23] "ccallcenter_transacciones"          "chomebanking_transacciones"
#  [25] "ctrx_quarter"                       "Master_status"
#  [27] "Master_fechaalta"                   "Master_mpagominimo"
#  [29] "Visa_status"                        "Visa_fechaalta"
#  [31] "Visa_mpagominimo"                   "clase_ternaria"
#  [33] "kmes"                               "mpayroll_sobre_edad"
#  [35] "internet_lag1"                      "cliente_edad_lag1"
#  [37] "cliente_antiguedad_lag1"            "mrentabilidad_lag1"
#  [39] "mrentabilidad_annual_lag1"          "mcomisiones_lag1"
#  [41] "mactivos_margen_lag1"               "mpasivos_margen_lag1"
#  [43] "cproductos_lag1"                    "mcuenta_corriente_lag1"
#  [45] "mcaja_ahorro_lag1"                  "cdescubierto_preacordado_lag1"
#  [47] "mcuentas_saldo_lag1"                "ctarjeta_visa_transacciones_lag1"
#  [49] "mtarjeta_visa_consumo_lag1"         "mtarjeta_master_consumo_lag1"
#  [51] "mprestamos_personales_lag1"         "cpayroll_trx_lag1"
#  [53] "mpayroll_lag1"                      "ccomisiones_mantenimiento_lag1"
#  [55] "ccallcenter_transacciones_lag1"     "chomebanking_transacciones_lag1"
#  [57] "ctrx_quarter_lag1"                  "Master_status_lag1"
#  [59] "Master_fechaalta_lag1"              "Master_mpagominimo_lag1"
#  [61] "Visa_status_lag1"                   "Visa_fechaalta_lag1"
#  [63] "Visa_mpagominimo_lag1"              "kmes_lag1"
#  [65] "mpayroll_sobre_edad_lag1"           "internet_lag2"
#  [67] "cliente_edad_lag2"                  "cliente_antiguedad_lag2"
#  [69] "mrentabilidad_lag2"                 "mrentabilidad_annual_lag2"
#  [71] "mcomisiones_lag2"                   "mactivos_margen_lag2"
#  [73] "mpasivos_margen_lag2"               "cproductos_lag2"
#  [75] "mcuenta_corriente_lag2"             "mcaja_ahorro_lag2"
#  [77] "cdescubierto_preacordado_lag2"      "mcuentas_saldo_lag2"
#  [79] "ctarjeta_visa_transacciones_lag2"   "mtarjeta_visa_consumo_lag2"
#  [81] "mtarjeta_master_consumo_lag2"       "mprestamos_personales_lag2"
#  [83] "cpayroll_trx_lag2"                  "mpayroll_lag2"
#  [85] "ccomisiones_mantenimiento_lag2"     "ccallcenter_transacciones_lag2"
#  [87] "chomebanking_transacciones_lag2"    "ctrx_quarter_lag2"
#  [89] "Master_status_lag2"                 "Master_fechaalta_lag2"
#  [91] "Master_mpagominimo_lag2"            "Visa_status_lag2"
#  [93] "Visa_fechaalta_lag2"                "Visa_mpagominimo_lag2"
#  [95] "kmes_lag2"                          "mpayroll_sobre_edad_lag2"
#  [97] "internet_delta1"                    "internet_delta2"
#  [99] "cliente_edad_delta1"                "cliente_edad_delta2"
# [101] "cliente_antiguedad_delta1"          "cliente_antiguedad_delta2"
# [103] "mrentabilidad_delta1"               "mrentabilidad_delta2"
# [105] "mrentabilidad_annual_delta1"        "mrentabilidad_annual_delta2"
# [107] "mcomisiones_delta1"                 "mcomisiones_delta2"
# [109] "mactivos_margen_delta1"             "mactivos_margen_delta2"
# [111] "mpasivos_margen_delta1"             "mpasivos_margen_delta2"
# [113] "cproductos_delta1"                  "cproductos_delta2"
# [115] "mcuenta_corriente_delta1"           "mcuenta_corriente_delta2"
# [117] "mcaja_ahorro_delta1"                "mcaja_ahorro_delta2"
# [119] "cdescubierto_preacordado_delta1"    "cdescubierto_preacordado_delta2"
# [121] "mcuentas_saldo_delta1"              "mcuentas_saldo_delta2"
# [123] "ctarjeta_visa_transacciones_delta1" "ctarjeta_visa_transacciones_delta2"
# [125] "mtarjeta_visa_consumo_delta1"       "mtarjeta_visa_consumo_delta2"
# [127] "mtarjeta_master_consumo_delta1"     "mtarjeta_master_consumo_delta2"
# [129] "mprestamos_personales_delta1"       "mprestamos_personales_delta2"
# [131] "cpayroll_trx_delta1"                "cpayroll_trx_delta2"
# [133] "mpayroll_delta1"                    "mpayroll_delta2"
# [135] "ccomisiones_mantenimiento_delta1"   "ccomisiones_mantenimiento_delta2"
# [137] "ccallcenter_transacciones_delta1"   "ccallcenter_transacciones_delta2"
# [139] "chomebanking_transacciones_delta1"  "chomebanking_transacciones_delta2"
# [141] "ctrx_quarter_delta1"                "ctrx_quarter_delta2"
# [143] "Master_status_delta1"               "Master_status_delta2"
# [145] "Master_fechaalta_delta1"            "Master_fechaalta_delta2"
# [147] "Master_mpagominimo_delta1"          "Master_mpagominimo_delta2"
# [149] "Visa_status_delta1"                 "Visa_status_delta2"
# [151] "Visa_fechaalta_delta1"              "Visa_fechaalta_delta2"
# [153] "Visa_mpagominimo_delta1"            "Visa_mpagominimo_delta2"
# [155] "kmes_delta1"                        "kmes_delta2"
# [157] "mpayroll_sobre_edad_delta1"         "mpayroll_sobre_edad_delta2"

# %% [markdown]
# #### 6.3.1.6  FEhist Reduccion dimensionalidad con canaritos
#
# Esta etapa solo se mostrará a la *modalidad Anlista Sr* por algun canal secreto de forma de no confundir a los *Analista Jr*  nni distraer con detalles operativos a la estratégica *Modalidad Gerencial*

# %%
# No se implementa la reduccion de la dimensionalidad con canaritos

# %% [markdown]
# ### 6.3.2 Modelado

# %% [markdown]
# #### 6.3.2.1 Training Strategy
#
# Esta etapa de Workflow de  Training Strategy esta pensada para la *Modalidad Gerencial* que posee el dataset de [202005, 202109]
# <br> Si usted es un Analista, posee el periodo de [201901, 202109] y deberá experimentar en que meses le conviene experimentar
#
# <br> A la *Modalidad Gerencial* no se le complicada la vida con el undersampling de los continua, por eso PARAM$trainingstrategy$training_pct <- 1.0
# <br> Sin embargo, si usted es  *Analista SR* posee un dataset 50 veces ( filas x columnas) más grande que la *Modalidad Gerencial*  y por un tema de velocidad y experimentación más rápida puede llegar a necesitar activar el undersampling de la clase mayoritaria, a pesar de estar corriendo en Google Cloud.

# %% [markdown]
# Se hace una estrategia de entrenamiento muy sencilla, tomando todos los meses posibles, SIN eliminar nada x pandemia ni por ningun otro motivo
#
# * future = 202107  obviamente completo
#
# * final_train =  [ 202005, 202105 ]  SIN undersampling
#
# * training
#    * testing = NO HAY
#    * validation =  202105   completo, sin undersampling
#    * training = [ 202005, 202104 ]  donde se consideran el 100% de los CONTINUA

# %%
PARAM$trainingstrategy$validate <- c(202105)

PARAM$trainingstrategy$training <- c(
  202104, 202103, 202102, 202101,
  202012, 202011, 202010, 202009, 202008, 202007,
  202006, 202005
)

PARAM$trainingstrategy$training_pct <- 1.0


PARAM$trainingstrategy$positivos <- c( "BAJA+1", "BAJA+2")

# %%
# seteo la clase01   1={BAJA+1, BAJA+2}   0={CONTINUA}
dataset[, clase01 := ifelse( clase_ternaria %in% PARAM$trainingstrategy$positivos, 1, 0 )]

# %%
# los campos en los que se entrena
campos_buenos <- copy( setdiff(
    colnames(dataset), c("clase_ternaria","clase01","azar"))
)

# %%
# preparo para que se puede hacer undersampling de los CONTINUA
#  solamente por un tema de VELOCIDAD
set.seed(PARAM$semilla_primigenia, kind = "L'Ecuyer-CMRG")
dataset[, azar:=runif(nrow(dataset))]

# undersampling de los CONTINUA
dataset[, fold_train :=  foto_mes %in%  PARAM$trainingstrategy$training &
    (clase_ternaria %in% c("BAJA+1", "BAJA+2") |
     azar < PARAM$trainingstrategy$training_pct ) ]


if( !require("lightgbm")) install.packages("lightgbm")
require("lightgbm")

dtrain <- lgb.Dataset(
  data= data.matrix(dataset[fold_train == TRUE, campos_buenos, with = FALSE]),
  label= dataset[fold_train == TRUE, clase01],
  free_raw_data= TRUE
)
# Out:
# Loading required package: lightgbm
#
# Warning message in library(package, lib.loc = lib.loc, character.only = TRUE, logical.return = TRUE, :
# “there is no package called ‘lightgbm’”
# Installing package into ‘/usr/local/lib/R/site-library’
# (as ‘lib’ is unspecified)
#
# Loading required package: lightgbm

# %%
# datos de validation
dvalidate <- lgb.Dataset(
  data= data.matrix(dataset[foto_mes %in% PARAM$trainingstrategy$validate, campos_buenos, with = FALSE]),
  label= dataset[foto_mes %in% PARAM$trainingstrategy$validate, clase01],
  free_raw_data= TRUE
)

nrow(dvalidate)
# Out:
# [1] 16469

# %% [markdown]
# ####  6.3.2.2. Hyperparameter Tuning

# %% [markdown]
# * Clase binaria que se optimiza :  positivos = [ BAJA+1, BAJA+2 ]

# %% [markdown]
# * Metrica que se optimiza **AUC** Area Under Curve de la  ROC Curve
#
# es muy importante notar que intencionalmente  **NO** se está optimizando la funcion de ganancia del problema

# %% [markdown]
# * Cantidad de iteraciones inteligentes de la Optimizacion Bayesiana = **10**

# %% [markdown]
# * Parametros no default, fijos de LightGBM que no se optimizan
#   * max_bin = 31 , Alienigenas Ancestrales contruyeron las pirámides y dejaron a la humanidad en un jeroglifico  *max_bin=31*
#   * feature_fraction = 0.5  para poner algo que generalmente no falla
#   * learning_rate = 0.03  para que aprenda lento

# %% [markdown]
# * Parametros que se optimizan en la Bayesian Optimization
#   * num_leaves  [8, 256]
#   * min_data_in_leaf  [8, 8192]

# %%
# paquetes necesarios para la Bayesian Optimization
if(!require("DiceKriging")) install.packages("DiceKriging")
require("DiceKriging")

if(!require("mlrMBO")) install.packages("mlrMBO")
require("mlrMBO")
# Out:
# Loading required package: DiceKriging
#
# Warning message in library(package, lib.loc = lib.loc, character.only = TRUE, logical.return = TRUE, :
# “there is no package called ‘DiceKriging’”
# Installing package into ‘/usr/local/lib/R/site-library’
# (as ‘lib’ is unspecified)
#
# Loading required package: DiceKriging
#
# Loading required package: mlrMBO
#
# Warning message in library(package, lib.loc = lib.loc, character.only = TRUE, logical.return = TRUE, :
# “there is no package called ‘mlrMBO’”
# Installing package into ‘/usr/local/lib/R/site-library’
# (as ‘lib’ is unspecified)
#
# also installing the dependencies ‘XML’, ‘fastmatch’, ‘RcppArmadillo’, ‘mlr’, ‘ParamHelpers’, ‘smoof’, ‘BBmisc’, ‘checkmate’, ‘lhs’, ‘parallelMap’
#
#
# Loading required package: mlrMBO
#
# Loading required package: mlr
#
# Loading required package: ParamHelpers
#
#
# Attaching package: ‘ParamHelpers’
#
#
# The following object is masked from ‘package:R.utils’:
#
#     isVector
#
#
#
# Attaching package: ‘mlr’
#
#
# The following objects are masked from ‘package:R.utils’:
#
#     resample, setThreshold
#
#
# Loading required package: smoof
#
# Loading required package: checkmate
#
#
# Attaching package: ‘checkmate’
#
#
# The following object is masked from ‘package:DiceKriging’:
#
#     checkNames
#
#
# The following object is masked from ‘package:R.utils’:
#
#     asInt
#
#
#
# Attaching package: ‘smoof’
#
#
# The following objects are masked from ‘package:R.oo’:
#
#     getDescription, getName

# %% [markdown]
# Definición de la Bayesian Optimization
# <br> Si se desea optimizar un hiperparámetro que esta como fijo, debe QUITARSE de param_fijos y agregarse a PARAM$hipeparametertuning$hs

# %%
# valor ridiculamente bajo para que corra rapido en el aula y no molestar a la *Modalidad Gerencial*
PARAM$hipeparametertuning$num_interations <- 90

# parametros fijos del LightGBM
PARAM$lgbm$param_fijos <- list(
  objective= "binary",
  metric= "auc",
  first_metric_only= TRUE,
  boost_from_average= TRUE,
  feature_pre_filter= FALSE,
  verbosity= -100,
  force_row_wise= TRUE, # para evitar warning
  max_bin= 31,
  seed= PARAM$semilla_primigenia
  # learning_rate= 0.03,
  # feature_fraction= 0.5,
  # num_iterations= 2048,  # valor grande, lo limita early_stopping_rounds
  # early_stopping_rounds= 200
)


PARAM$hipeparametertuning$hs <- makeParamSet(
  # Núcleo del modelo (estructura de árboles)
  makeIntegerParam("num_leaves", lower = 2L, upper = 8192L),
  #makeIntegerParam("max_depth", lower = 3L, upper = 30L),
  makeNumericParam("min_child_weight", lower = 0.001, upper = 10.0),
  makeIntegerParam("min_data_in_leaf", lower = 2L, upper = 8192L),
  #makeNumericParam("min_gain_to_split", lower = 0.0, upper = 0.1),

  # Regularización
  #makeNumericParam("lambda_l1", lower = 0.0, upper = 1000L),
  makeNumericParam("lambda_l2", lower = 0.0, upper = 1000L),
  makeNumericParam("scale_pos_weight", lower = 1.0, upper = 5.0),  # útil en desequilibrio

  # Control del aprendizaje
  makeNumericParam("learning_rate", lower = 0.005, upper = 0.1),
  makeIntegerParam("num_iterations", lower = 100L, upper = 5000L),
  makeIntegerParam("early_stopping_rounds", lower = 50L, upper = 500L),

  # Submuestreo
  makeNumericParam("feature_fraction", lower = 0.05, upper = 1L),   # columnas
  makeNumericParam("bagging_fraction", lower = 0.5, upper = 1L)   # filas
  #makeIntegerParam("bagging_freq", lower = 0L, upper = 5L),         # cada N iteraciones

  # Opcionales útiles
  #makeNumericParam("max_delta_step", lower = 0.0, upper = 10.0),
  #makeNumericParam("path_smooth", lower = 0.0, upper = 10.0)
)
# Total: 12 hT

# %% [markdown]
# Función "señora caja negra"  que es llamada para verificar la realidad por la Bayesian Optimization

# %%
# En  x llegan los parmaetros de la bayesiana
#  devuelve la AUC en validate del modelo entrenado
#  en el parametro x llegan los hiperparámetros que se estan optimizando

EstimarGanancia_AUC_lightgbm <- function(x) {

  # x pisa (o agrega) a param_fijos
  param_completo <- modifyList(PARAM$lgbm$param_fijos, x)

  # entreno LightGBM
  modelo_train <- lgb.train(
    data= dtrain,
    valids= list(valid = dvalidate),
    eval= "auc",
    param= param_completo,
    verbose= -100
  )

  # recupero la AUC en validation
  AUC <- modelo_train$record_evals$valid$auc$eval[[modelo_train$best_iter]]

  # esta es la forma de devolver un parametro extra
  attr(AUC, "extras") <- list("num_iterations"= modelo_train$best_iter)

  # hago espacio en la memoria
  rm(modelo_train)
  gc(full= TRUE, verbose= FALSE)

  message(format(Sys.time(), "%a %b %d %X %Y"), " AUC ", AUC)

  return(AUC)
}

# %% [markdown]
# seteo de la Bayesian Optimization (complejo)
# <br> copiado y pegado de la documentación de la librería

# %%
configureMlr(show.learner.output = FALSE)

# configuro la busqueda bayesiana,  los hiperparametros que se van a optimizar
# por favor, no desesperarse por lo complejo
obj.fun <- makeSingleObjectiveFunction(
    fn= EstimarGanancia_AUC_lightgbm, # la funcion que voy a maximizar
    minimize= FALSE, # estoy Maximizando AUC
    noisy= FALSE,
    par.set= PARAM$hipeparametertuning$hs,
    has.simple.signature= FALSE # paso los parametros en una lista
)

# cada 600 segundos guardo el resultado intermedio
ctrl <- makeMBOControl(
    save.on.disk.at.time= 600,
    save.file.path= "HT.RDATA"
)

# indico la cantidad de iteraciones que va a tener la Bayesian Optimization
ctrl <- setMBOControlTermination(
    ctrl,
    iters= PARAM$hipeparametertuning$num_interations  # cantidad de iteraciones inteligentes
)

# defino el método estandar para la creacion de los puntos iniciales
#   los "No Inteligentes"
ctrl <- setMBOControlInfill(ctrl, crit = makeMBOInfillCritEI())

# mas configuraciones
surr.km <- makeLearner(
    "regr.km",
    predict.type= "se",
    covtype= "matern3_2",
    control= list(trace = TRUE)
)

# %% [markdown]
# Corrida de la Bayesian Optimization,  aqui se hace el trabajo pesado
# <br> por favor no se asuste con los warnings que pudieran aparecer
#
# Si corrío a medias y llegó a las iteraciones inteligentes, en el archivo binario HT.RDATA quedó lo ya procesado y es utilizado para retomar la corrida desde lo último que llegó a grabar.

# %%
# inicio la optimizacion bayesiana

if (!file.exists("HT.RDATA")) {
  bayesiana_salida <- mbo(obj.fun, learner= surr.km, control= ctrl)
} else {
  bayesiana_salida <- mboContinue("HT.RDATA") # retomo en caso que ya exista
}
# Out:
# Computing y column(s) for design. Not provided.
#
# Thu Nov 20 06:42:43 PM 2025 AUC 0.922238685679275
#
# Thu Nov 20 06:48:28 PM 2025 AUC 0.91603100051068
#
# Thu Nov 20 06:51:35 PM 2025 AUC 0.920648262042762
#
# Thu Nov 20 06:55:47 PM 2025 AUC 0.919464839222934
#
# Thu Nov 20 06:58:37 PM 2025 AUC 0.923437207457678
#
# Thu Nov 20 07:10:12 PM 2025 AUC 0.920532167827944
#
# Thu Nov 20 07:13:44 PM 2025 AUC 0.924593116619659
#
# Thu Nov 20 07:16:00 PM 2025 AUC 0.90995853490443
#
# Thu Nov 20 07:22:33 PM 2025 AUC 0.926161059584517
#
# Thu Nov 20 07:36:51 PM 2025 AUC 0.92542892785986
#
# Thu Nov 20 07:40:49 PM 2025 AUC 0.925263510380366
#
# Thu Nov 20 07:41:48 PM 2025 AUC 0.908097336610814
#
# Thu Nov 20 07:47:23 PM 2025 AUC 0.918943421853494
#
# Thu Nov 20 07:50:37 PM 2025 AUC 0.928032994915342
#
# Thu Nov 20 07:52:35 PM 2025 AUC 0.908333215896989
#
# Thu Nov 20 07:59:20 PM 2025 AUC 0.922507782674314
#
# Thu Nov 20 08:01:28 PM 2025 AUC 0.928534951404841
#
# Thu Nov 20 08:01:53 PM 2025 AUC 0.904553778799586
#
# Thu Nov 20 08:05:04 PM 2025 AUC 0.921023722812647
#
# Thu Nov 20 08:15:11 PM 2025 AUC 0.924620294745093
#
# Thu Nov 20 08:19:21 PM 2025 AUC 0.919159504727316
#
# Thu Nov 20 08:20:49 PM 2025 AUC 0.918354898001502
#
# Thu Nov 20 08:22:24 PM 2025 AUC 0.927865564241371
#
# Thu Nov 20 08:29:30 PM 2025 AUC 0.918128749155297
#
# Thu Nov 20 08:34:56 PM 2025 AUC 0.913178975002164
#
# Thu Nov 20 08:36:20 PM 2025 AUC 0.913943988903272
#
# Thu Nov 20 08:37:25 PM 2025 AUC 0.916686295312814
#
# Thu Nov 20 08:39:48 PM 2025 AUC 0.916741322628507
#
# Thu Nov 20 08:42:30 PM 2025 AUC 0.924106594621147
#
# Thu Nov 20 08:49:05 PM 2025 AUC 0.923826089524074
#
# Thu Nov 20 08:55:27 PM 2025 AUC 0.928023600007784
#
# Thu Nov 20 09:00:12 PM 2025 AUC 0.931425227608412
#
# Thu Nov 20 09:08:11 PM 2025 AUC 0.922032333245424
#
# Thu Nov 20 09:13:34 PM 2025 AUC 0.910669863619496
#
# Thu Nov 20 09:15:48 PM 2025 AUC 0.925354439664226
#
# Thu Nov 20 09:19:03 PM 2025 AUC 0.92054860891617
#
# Thu Nov 20 09:19:29 PM 2025 AUC 0.908004394132478
#
# Thu Nov 20 09:22:29 PM 2025 AUC 0.922421886376646
#
# Thu Nov 20 09:25:57 PM 2025 AUC 0.924341467310084
#
# Thu Nov 20 09:30:34 PM 2025 AUC 0.914195638212847
#
# [mbo] 0: num_leaves=797; min_child_weight=4.12; min_data_in_leaf=4289; lambda_l2=520; scale_pos_weight=4.07; learning_rate=0.0423; num_iterations=1803; early_stopping_rounds=283; feature_fraction=0.614; bagging_fraction=0.756 : y = 0.922 : 261.5 secs : initdesign
#
# [mbo] 0: num_leaves=6083; min_child_weight=1.05; min_data_in_leaf=4962; lambda_l2=852; scale_pos_weight=2.45; learning_rate=0.0482; num_iterations=3230; early_stopping_rounds=142; feature_fraction=0.508; bagging_fraction=0.655 : y = 0.916 : 345.2 secs : initdesign
#
# [mbo] 0: num_leaves=5199; min_child_weight=2.51; min_data_in_leaf=7910; lambda_l2=176; scale_pos_weight=3.07; learning_rate=0.0724; num_iterations=4029; early_stopping_rounds=319; feature_fraction=0.281; bagging_fraction=0.663 : y = 0.921 : 187.2 secs : initdesign
#
# [mbo] 0: num_leaves=1472; min_child_weight=6.12; min_data_in_leaf=5683; lambda_l2=294; scale_pos_weight=3.44; learning_rate=0.0304; num_iterations=2167; early_stopping_rounds=261; feature_fraction=0.82; bagging_fraction=0.948 : y = 0.919 : 252.1 secs : initdesign
#
# [mbo] 0: num_leaves=422; min_child_weight=4.86; min_data_in_leaf=4804; lambda_l2=153; scale_pos_weight=3.34; learning_rate=0.0635; num_iterations=976; early_stopping_rounds=215; feature_fraction=0.571; bagging_fraction=0.71 : y = 0.923 : 169.5 secs : initdesign
#
# [mbo] 0: num_leaves=5460; min_child_weight=4.47; min_data_in_leaf=4052; lambda_l2=440; scale_pos_weight=3.68; learning_rate=0.0186; num_iterations=3700; early_stopping_rounds=69; feature_fraction=0.574; bagging_fraction=0.828 : y = 0.921 : 695.2 secs : initdesign
#
# [mbo] 0: num_leaves=4568; min_child_weight=8.18; min_data_in_leaf=2978; lambda_l2=215; scale_pos_weight=2.68; learning_rate=0.0673; num_iterations=3004; early_stopping_rounds=359; feature_fraction=0.746; bagging_fraction=0.521 : y = 0.925 : 211.8 secs : initdesign
#
# [mbo] 0: num_leaves=5694; min_child_weight=3.75; min_data_in_leaf=6939; lambda_l2=885; scale_pos_weight=1.26; learning_rate=0.024; num_iterations=1330; early_stopping_rounds=139; feature_fraction=0.648; bagging_fraction=0.802 : y = 0.91 : 136.8 secs : initdesign
#
# [mbo] 0: num_leaves=1728; min_child_weight=5.39; min_data_in_leaf=3670; lambda_l2=593; scale_pos_weight=3.21; learning_rate=0.0852; num_iterations=2870; early_stopping_rounds=418; feature_fraction=0.303; bagging_fraction=0.699 : y = 0.926 : 393.1 secs : initdesign
#
# [mbo] 0: num_leaves=4952; min_child_weight=6.72; min_data_in_leaf=759; lambda_l2=635; scale_pos_weight=1.63; learning_rate=0.0393; num_iterations=4725; early_stopping_rounds=341; feature_fraction=0.432; bagging_fraction=0.787 : y = 0.925 : 857.6 secs : initdesign
#
# [mbo] 0: num_leaves=3023; min_child_weight=2.25; min_data_in_leaf=1875; lambda_l2=340; scale_pos_weight=1.89; learning_rate=0.0807; num_iterations=2273; early_stopping_rounds=466; feature_fraction=0.147; bagging_fraction=0.966 : y = 0.925 : 237.8 secs : initdesign
#
# [mbo] 0: num_leaves=3334; min_child_weight=3.63; min_data_in_leaf=5130; lambda_l2=717; scale_pos_weight=4.74; learning_rate=0.0157; num_iterations=400; early_stopping_rounds=193; feature_fraction=0.428; bagging_fraction=0.735 : y = 0.908 : 58.8 secs : initdesign
#
# [mbo] 0: num_leaves=7384; min_child_weight=5.11; min_data_in_leaf=7277; lambda_l2=927; scale_pos_weight=3.51; learning_rate=0.0709; num_iterations=2357; early_stopping_rounds=344; feature_fraction=0.373; bagging_fraction=0.74 : y = 0.919 : 335.6 secs : initdesign
#
# [mbo] 0: num_leaves=6944; min_child_weight=6.33; min_data_in_leaf=2634; lambda_l2=92.1; scale_pos_weight=3.16; learning_rate=0.0539; num_iterations=1976; early_stopping_rounds=175; feature_fraction=0.857; bagging_fraction=0.92 : y = 0.928 : 193.5 secs : initdesign
#
# [mbo] 0: num_leaves=2365; min_child_weight=9.58; min_data_in_leaf=6616; lambda_l2=553; scale_pos_weight=2.18; learning_rate=0.0107; num_iterations=859; early_stopping_rounds=266; feature_fraction=0.344; bagging_fraction=0.874 : y = 0.908 : 118.1 secs : initdesign
#
# [mbo] 0: num_leaves=1859; min_child_weight=1.85; min_data_in_leaf=1642; lambda_l2=308; scale_pos_weight=1.57; learning_rate=0.087; num_iterations=3373; early_stopping_rounds=427; feature_fraction=0.963; bagging_fraction=0.843 : y = 0.923 : 405.4 secs : initdesign
#
# [mbo] 0: num_leaves=5925; min_child_weight=7.17; min_data_in_leaf=3865; lambda_l2=129; scale_pos_weight=3.74; learning_rate=0.0504; num_iterations=3776; early_stopping_rounds=85; feature_fraction=0.082; bagging_fraction=0.89 : y = 0.929 : 128.1 secs : initdesign
#
# [mbo] 0: num_leaves=8059; min_child_weight=2.87; min_data_in_leaf=2268; lambda_l2=488; scale_pos_weight=2.23; learning_rate=0.0338; num_iterations=214; early_stopping_rounds=306; feature_fraction=0.876; bagging_fraction=0.589 : y = 0.905 : 24.8 secs : initdesign
#
# [mbo] 0: num_leaves=3214; min_child_weight=0.639; min_data_in_leaf=4428; lambda_l2=260; scale_pos_weight=2.52; learning_rate=0.0361; num_iterations=1560; early_stopping_rounds=393; feature_fraction=0.237; bagging_fraction=0.543 : y = 0.921 : 190.4 secs : initdesign
#
# [mbo] 0: num_leaves=3960; min_child_weight=7.48; min_data_in_leaf=1375; lambda_l2=609; scale_pos_weight=4.87; learning_rate=0.0202; num_iterations=4151; early_stopping_rounds=380; feature_fraction=0.724; bagging_fraction=0.765 : y = 0.925 : 607.6 secs : initdesign
#
# [mbo] 0: num_leaves=2224; min_child_weight=4.68; min_data_in_leaf=7433; lambda_l2=831; scale_pos_weight=1.95; learning_rate=0.0764; num_iterations=2671; early_stopping_rounds=104; feature_fraction=0.214; bagging_fraction=0.679 : y = 0.919 : 249.4 secs : initdesign
#
# [mbo] 0: num_leaves=3720; min_child_weight=5.86; min_data_in_leaf=413; lambda_l2=951; scale_pos_weight=2.03; learning_rate=0.075; num_iterations=598; early_stopping_rounds=160; feature_fraction=0.916; bagging_fraction=0.791 : y = 0.918 : 88.6 secs : initdesign
#
# [mbo] 0: num_leaves=923; min_child_weight=8.3; min_data_in_leaf=855; lambda_l2=62.1; scale_pos_weight=4.26; learning_rate=0.0616; num_iterations=4420; early_stopping_rounds=246; feature_fraction=0.173; bagging_fraction=0.557 : y = 0.928 : 95.0 secs : initdesign
#
# [mbo] 0: num_leaves=26; min_child_weight=3.48; min_data_in_leaf=4559; lambda_l2=758; scale_pos_weight=4.14; learning_rate=0.00914; num_iterations=4918; early_stopping_rounds=198; feature_fraction=0.107; bagging_fraction=0.879 : y = 0.918 : 426.0 secs : initdesign
#
# [mbo] 0: num_leaves=6328; min_child_weight=6.91; min_data_in_leaf=5987; lambda_l2=998; scale_pos_weight=1.18; learning_rate=0.0322; num_iterations=3103; early_stopping_rounds=224; feature_fraction=0.67; bagging_fraction=0.501 : y = 0.913 : 325.5 secs : initdesign
#
# [mbo] 0: num_leaves=4376; min_child_weight=0.915; min_data_in_leaf=7102; lambda_l2=120; scale_pos_weight=1.31; learning_rate=0.0443; num_iterations=775; early_stopping_rounds=165; feature_fraction=0.642; bagging_fraction=0.815 : y = 0.914 : 84.0 secs : initdesign
#
# [mbo] 0: num_leaves=3639; min_child_weight=8.85; min_data_in_leaf=2720; lambda_l2=733; scale_pos_weight=4.93; learning_rate=0.0477; num_iterations=518; early_stopping_rounds=238; feature_fraction=0.895; bagging_fraction=0.566 : y = 0.917 : 65.4 secs : initdesign
#
# [mbo] 0: num_leaves=4726; min_child_weight=9.18; min_data_in_leaf=7622; lambda_l2=690; scale_pos_weight=3.9; learning_rate=0.0934; num_iterations=1275; early_stopping_rounds=78; feature_fraction=0.457; bagging_fraction=0.929 : y = 0.917 : 142.8 secs : initdesign
#
# [mbo] 0: num_leaves=6548; min_child_weight=1.55; min_data_in_leaf=1054; lambda_l2=531; scale_pos_weight=4.32; learning_rate=0.0286; num_iterations=1826; early_stopping_rounds=400; feature_fraction=0.0698; bagging_fraction=0.908 : y = 0.924 : 161.7 secs : initdesign
#
# [mbo] 0: num_leaves=7973; min_child_weight=5.67; min_data_in_leaf=50; lambda_l2=915; scale_pos_weight=2.74; learning_rate=0.0591; num_iterations=3927; early_stopping_rounds=372; feature_fraction=0.949; bagging_fraction=0.959 : y = 0.924 : 395.7 secs : initdesign
#
# [mbo] 0: num_leaves=1150; min_child_weight=8.75; min_data_in_leaf=3236; lambda_l2=412; scale_pos_weight=4.61; learning_rate=0.0919; num_iterations=3444; early_stopping_rounds=454; feature_fraction=0.53; bagging_fraction=0.976 : y = 0.928 : 382.1 secs : initdesign
#
# [mbo] 0: num_leaves=1397; min_child_weight=0.0502; min_data_in_leaf=1579; lambda_l2=32.4; scale_pos_weight=2.93; learning_rate=0.0244; num_iterations=4282; early_stopping_rounds=109; feature_fraction=0.316; bagging_fraction=0.647 : y = 0.931 : 284.8 secs : initdesign
#
# [mbo] 0: num_leaves=7580; min_child_weight=3.04; min_data_in_leaf=5795; lambda_l2=667; scale_pos_weight=1.48; learning_rate=0.0824; num_iterations=4831; early_stopping_rounds=496; feature_fraction=0.126; bagging_fraction=0.715 : y = 0.922 : 478.8 secs : initdesign
#
# [mbo] 0: num_leaves=2589; min_child_weight=9.41; min_data_in_leaf=2221; lambda_l2=799; scale_pos_weight=1.79; learning_rate=0.00577; num_iterations=2762; early_stopping_rounds=468; feature_fraction=0.241; bagging_fraction=0.582 : y = 0.911 : 323.3 secs : initdesign
#
# [mbo] 0: num_leaves=6568; min_child_weight=2.35; min_data_in_leaf=6489; lambda_l2=1.44; scale_pos_weight=4.5; learning_rate=0.1; num_iterations=3636; early_stopping_rounds=440; feature_fraction=0.699; bagging_fraction=0.616 : y = 0.925 : 133.6 secs : initdesign
#
# [mbo] 0: num_leaves=268; min_child_weight=7.6; min_data_in_leaf=8053; lambda_l2=246; scale_pos_weight=2.82; learning_rate=0.0667; num_iterations=4576; early_stopping_rounds=120; feature_fraction=0.795; bagging_fraction=0.626 : y = 0.921 : 195.6 secs : initdesign
#
# [mbo] 0: num_leaves=6987; min_child_weight=7.81; min_data_in_leaf=5334; lambda_l2=378; scale_pos_weight=1.08; learning_rate=0.0901; num_iterations=238; early_stopping_rounds=480; feature_fraction=0.776; bagging_fraction=0.853 : y = 0.908 : 25.4 secs : initdesign
#
# [mbo] 0: num_leaves=2822; min_child_weight=0.385; min_data_in_leaf=3419; lambda_l2=811; scale_pos_weight=4.6; learning_rate=0.0969; num_iterations=1182; early_stopping_rounds=296; feature_fraction=0.401; bagging_fraction=0.536 : y = 0.922 : 179.8 secs : initdesign
#
# [mbo] 0: num_leaves=7326; min_child_weight=9.86; min_data_in_leaf=318; lambda_l2=374; scale_pos_weight=2.31; learning_rate=0.0566; num_iterations=1573; early_stopping_rounds=54; feature_fraction=0.491; bagging_fraction=0.611 : y = 0.924 : 208.8 secs : initdesign
#
# [mbo] 0: num_leaves=4155; min_child_weight=1.38; min_data_in_leaf=6160; lambda_l2=469; scale_pos_weight=3.88; learning_rate=0.0142; num_iterations=2475; early_stopping_rounds=324; feature_fraction=0.983; bagging_fraction=0.995 : y = 0.914 : 276.4 secs : initdesign
#
# Saved the current state after iteration 1 in the file HT.RDATA.
#
# Thu Nov 20 09:33:02 PM 2025 AUC 0.927547143981656
#
# [mbo] 1: num_leaves=2869; min_child_weight=2.88; min_data_in_leaf=1444; lambda_l2=27; scale_pos_weight=3.89; learning_rate=0.0539; num_iterations=3814; early_stopping_rounds=97; feature_fraction=0.405; bagging_fraction=0.946 : y = 0.928 : 146.2 secs : infill_ei
#
# Thu Nov 20 09:35:26 PM 2025 AUC 0.933927628342825
#
# [mbo] 2: num_leaves=6710; min_child_weight=6.87; min_data_in_leaf=748; lambda_l2=3.19; scale_pos_weight=4.97; learning_rate=0.0645; num_iterations=2369; early_stopping_rounds=273; feature_fraction=0.0671; bagging_fraction=0.824 : y = 0.934 : 143.2 secs : infill_ei
#
# Thu Nov 20 09:36:38 PM 2025 AUC 0.932475108527959
#
# [mbo] 3: num_leaves=5873; min_child_weight=2.11; min_data_in_leaf=718; lambda_l2=0.396; scale_pos_weight=4.97; learning_rate=0.0632; num_iterations=2145; early_stopping_rounds=69; feature_fraction=0.125; bagging_fraction=0.72 : y = 0.932 : 71.9 secs : infill_ei
#
# Thu Nov 20 09:38:56 PM 2025 AUC 0.929828428856056
#
# [mbo] 4: num_leaves=5469; min_child_weight=4.78; min_data_in_leaf=300; lambda_l2=8.23; scale_pos_weight=4.86; learning_rate=0.0424; num_iterations=2323; early_stopping_rounds=217; feature_fraction=0.0878; bagging_fraction=0.702 : y = 0.93 : 136.0 secs : infill_ei
#
# Thu Nov 20 09:40:39 PM 2025 AUC 0.929645563691098
#
# [mbo] 5: num_leaves=7253; min_child_weight=5.1; min_data_in_leaf=11; lambda_l2=64.8; scale_pos_weight=4.97; learning_rate=0.0777; num_iterations=2892; early_stopping_rounds=122; feature_fraction=0.248; bagging_fraction=0.851 : y = 0.93 : 102.1 secs : infill_ei
#
# Saved the current state after iteration 6 in the file HT.RDATA.
#
# Thu Nov 20 09:42:30 PM 2025 AUC 0.938670378997282
#
# [mbo] 6: num_leaves=3702; min_child_weight=8.1; min_data_in_leaf=549; lambda_l2=6.62; scale_pos_weight=5; learning_rate=0.0666; num_iterations=1966; early_stopping_rounds=249; feature_fraction=0.131; bagging_fraction=0.839 : y = 0.939 : 110.9 secs : infill_ei
#
# Thu Nov 20 09:43:58 PM 2025 AUC 0.929547252694157
#
# [mbo] 7: num_leaves=2727; min_child_weight=9.07; min_data_in_leaf=1153; lambda_l2=8.77; scale_pos_weight=4.94; learning_rate=0.0834; num_iterations=1955; early_stopping_rounds=256; feature_fraction=0.227; bagging_fraction=0.728 : y = 0.93 : 86.4 secs : infill_ei
#
# Thu Nov 20 09:45:47 PM 2025 AUC 0.927095181821659
#
# [mbo] 8: num_leaves=3767; min_child_weight=5.98; min_data_in_leaf=692; lambda_l2=10.5; scale_pos_weight=4.91; learning_rate=0.0623; num_iterations=2527; early_stopping_rounds=414; feature_fraction=0.128; bagging_fraction=0.827 : y = 0.927 : 108.3 secs : infill_ei
#
# Thu Nov 20 09:48:04 PM 2025 AUC 0.930120342055163
#
# [mbo] 9: num_leaves=3477; min_child_weight=7.52; min_data_in_leaf=535; lambda_l2=329; scale_pos_weight=4.94; learning_rate=0.0661; num_iterations=1967; early_stopping_rounds=97; feature_fraction=0.226; bagging_fraction=0.95 : y = 0.93 : 136.0 secs : infill_ei
#
# Thu Nov 20 09:51:00 PM 2025 AUC 0.92927714910188
#
# [mbo] 10: num_leaves=4215; min_child_weight=9.65; min_data_in_leaf=649; lambda_l2=128; scale_pos_weight=4.21; learning_rate=0.0614; num_iterations=4589; early_stopping_rounds=231; feature_fraction=0.0738; bagging_fraction=0.866 : y = 0.929 : 175.2 secs : infill_ei
#
# Saved the current state after iteration 11 in the file HT.RDATA.
#
# Thu Nov 20 09:52:10 PM 2025 AUC 0.929243260328191
#
# [mbo] 11: num_leaves=4638; min_child_weight=9.5; min_data_in_leaf=30; lambda_l2=0.119; scale_pos_weight=4.79; learning_rate=0.0639; num_iterations=1783; early_stopping_rounds=218; feature_fraction=0.0866; bagging_fraction=0.688 : y = 0.929 : 69.1 secs : infill_ei
#
# Thu Nov 20 09:56:13 PM 2025 AUC 0.928258472696721
#
# [mbo] 12: num_leaves=4581; min_child_weight=7.83; min_data_in_leaf=273; lambda_l2=153; scale_pos_weight=4.92; learning_rate=0.0814; num_iterations=4236; early_stopping_rounds=255; feature_fraction=0.442; bagging_fraction=0.979 : y = 0.928 : 242.1 secs : infill_ei
#
# Thu Nov 20 09:59:11 PM 2025 AUC 0.936759186374163
#
# [mbo] 13: num_leaves=1683; min_child_weight=9.39; min_data_in_leaf=422; lambda_l2=35.5; scale_pos_weight=4.08; learning_rate=0.0501; num_iterations=1882; early_stopping_rounds=143; feature_fraction=0.0673; bagging_fraction=0.855 : y = 0.937 : 176.2 secs : infill_ei
#
# Thu Nov 20 10:00:48 PM 2025 AUC 0.933380710510016
#
# [mbo] 14: num_leaves=1741; min_child_weight=9.83; min_data_in_leaf=490; lambda_l2=1.5; scale_pos_weight=4.89; learning_rate=0.0571; num_iterations=1009; early_stopping_rounds=244; feature_fraction=0.103; bagging_fraction=0.847 : y = 0.933 : 95.8 secs : infill_ei
#
# Thu Nov 20 10:01:28 PM 2025 AUC 0.929036236829514
#
# [mbo] 15: num_leaves=1345; min_child_weight=7.25; min_data_in_leaf=591; lambda_l2=1.66; scale_pos_weight=3.26; learning_rate=0.067; num_iterations=1818; early_stopping_rounds=211; feature_fraction=0.0555; bagging_fraction=0.859 : y = 0.929 : 39.6 secs : infill_ei
#
# Saved the current state after iteration 16 in the file HT.RDATA.
#
# Thu Nov 20 10:04:17 PM 2025 AUC 0.930999772509024
#
# [mbo] 16: num_leaves=2830; min_child_weight=8.23; min_data_in_leaf=34; lambda_l2=13; scale_pos_weight=4.96; learning_rate=0.0475; num_iterations=2007; early_stopping_rounds=185; feature_fraction=0.404; bagging_fraction=0.85 : y = 0.931 : 168.4 secs : infill_ei
#
# Thu Nov 20 10:06:02 PM 2025 AUC 0.929864330824222
#
# [mbo] 17: num_leaves=3589; min_child_weight=2.93; min_data_in_leaf=2616; lambda_l2=13.1; scale_pos_weight=4.9; learning_rate=0.0677; num_iterations=1997; early_stopping_rounds=156; feature_fraction=0.0727; bagging_fraction=0.89 : y = 0.93 : 103.6 secs : infill_ei
#
# Thu Nov 20 10:09:09 PM 2025 AUC 0.929728440197051
#
# [mbo] 18: num_leaves=5032; min_child_weight=9.09; min_data_in_leaf=790; lambda_l2=87.8; scale_pos_weight=4.62; learning_rate=0.0539; num_iterations=2106; early_stopping_rounds=155; feature_fraction=0.129; bagging_fraction=0.844 : y = 0.93 : 186.0 secs : infill_ei
#
# Thu Nov 20 10:12:09 PM 2025 AUC 0.93449333599075
#
# [mbo] 19: num_leaves=216; min_child_weight=8.99; min_data_in_leaf=860; lambda_l2=25.8; scale_pos_weight=3.71; learning_rate=0.044; num_iterations=2296; early_stopping_rounds=138; feature_fraction=0.243; bagging_fraction=0.81 : y = 0.934 : 179.2 secs : infill_ei
#
# Saved the current state after iteration 20 in the file HT.RDATA.
#
# Thu Nov 20 10:12:59 PM 2025 AUC 0.929321439380366
#
# [mbo] 20: num_leaves=3073; min_child_weight=7.97; min_data_in_leaf=2421; lambda_l2=2.18; scale_pos_weight=4.68; learning_rate=0.0669; num_iterations=1666; early_stopping_rounds=235; feature_fraction=0.0724; bagging_fraction=0.898 : y = 0.929 : 48.7 secs : infill_ei
#
# Thu Nov 20 10:15:41 PM 2025 AUC 0.933476337247654
#
# [mbo] 21: num_leaves=1309; min_child_weight=6.32; min_data_in_leaf=333; lambda_l2=54; scale_pos_weight=4.03; learning_rate=0.0331; num_iterations=3266; early_stopping_rounds=119; feature_fraction=0.0703; bagging_fraction=0.742 : y = 0.933 : 160.6 secs : infill_ei
#
# Thu Nov 20 10:19:00 PM 2025 AUC 0.925871159579887
#
# [mbo] 22: num_leaves=3834; min_child_weight=5.96; min_data_in_leaf=358; lambda_l2=67.8; scale_pos_weight=4.91; learning_rate=0.061; num_iterations=1974; early_stopping_rounds=272; feature_fraction=0.125; bagging_fraction=0.872 : y = 0.926 : 197.8 secs : infill_ei
#
# Thu Nov 20 10:22:22 PM 2025 AUC 0.935314719337203
#
# [mbo] 23: num_leaves=1293; min_child_weight=8.08; min_data_in_leaf=12; lambda_l2=46.7; scale_pos_weight=3.99; learning_rate=0.0535; num_iterations=2432; early_stopping_rounds=168; feature_fraction=0.0674; bagging_fraction=0.794 : y = 0.935 : 201.4 secs : infill_ei
#
# Saved the current state after iteration 24 in the file HT.RDATA.
#
# Thu Nov 20 10:26:12 PM 2025 AUC 0.933907831930472
#
# [mbo] 24: num_leaves=1626; min_child_weight=8.38; min_data_in_leaf=533; lambda_l2=132; scale_pos_weight=4.9; learning_rate=0.0366; num_iterations=3226; early_stopping_rounds=76; feature_fraction=0.0565; bagging_fraction=0.826 : y = 0.934 : 229.0 secs : infill_ei
#
# Thu Nov 20 10:27:39 PM 2025 AUC 0.926925737953212
#
# [mbo] 25: num_leaves=3785; min_child_weight=8.5; min_data_in_leaf=1208; lambda_l2=18.8; scale_pos_weight=4.94; learning_rate=0.0702; num_iterations=3013; early_stopping_rounds=185; feature_fraction=0.311; bagging_fraction=0.817 : y = 0.927 : 85.9 secs : infill_ei
#
# Thu Nov 20 10:29:42 PM 2025 AUC 0.930945080725743
#
# [mbo] 26: num_leaves=2402; min_child_weight=8.18; min_data_in_leaf=455; lambda_l2=141; scale_pos_weight=4.78; learning_rate=0.0479; num_iterations=1265; early_stopping_rounds=332; feature_fraction=0.0838; bagging_fraction=0.801 : y = 0.931 : 121.5 secs : infill_ei
#
# Thu Nov 20 10:35:00 PM 2025 AUC 0.928846996548714
#
# [mbo] 27: num_leaves=643; min_child_weight=9.29; min_data_in_leaf=457; lambda_l2=521; scale_pos_weight=4.24; learning_rate=0.0592; num_iterations=2476; early_stopping_rounds=237; feature_fraction=0.224; bagging_fraction=0.823 : y = 0.929 : 317.3 secs : infill_ei
#
# Saved the current state after iteration 28 in the file HT.RDATA.
#
# Thu Nov 20 10:37:21 PM 2025 AUC 0.935275462044909
#
# [mbo] 28: num_leaves=5976; min_child_weight=7.77; min_data_in_leaf=49; lambda_l2=1.22; scale_pos_weight=4.76; learning_rate=0.0239; num_iterations=2415; early_stopping_rounds=395; feature_fraction=0.138; bagging_fraction=0.799 : y = 0.935 : 139.3 secs : infill_ei
#
# Thu Nov 20 10:39:34 PM 2025 AUC 0.930959173087079
#
# [mbo] 29: num_leaves=1384; min_child_weight=9.77; min_data_in_leaf=99; lambda_l2=198; scale_pos_weight=3.66; learning_rate=0.0557; num_iterations=3113; early_stopping_rounds=122; feature_fraction=0.0589; bagging_fraction=0.895 : y = 0.931 : 132.1 secs : infill_ei
#
# Thu Nov 20 10:43:51 PM 2025 AUC 0.931885578078728
#
# [mbo] 30: num_leaves=3045; min_child_weight=1.66; min_data_in_leaf=482; lambda_l2=29.4; scale_pos_weight=3.81; learning_rate=0.00926; num_iterations=3973; early_stopping_rounds=62; feature_fraction=0.061; bagging_fraction=0.643 : y = 0.932 : 256.0 secs : infill_ei
#
# Thu Nov 20 10:45:33 PM 2025 AUC 0.935640185777586
#
# [mbo] 31: num_leaves=3638; min_child_weight=8.2; min_data_in_leaf=162; lambda_l2=1.4; scale_pos_weight=2.56; learning_rate=0.0185; num_iterations=1428; early_stopping_rounds=80; feature_fraction=0.0714; bagging_fraction=0.885 : y = 0.936 : 100.7 secs : infill_ei
#
# Saved the current state after iteration 32 in the file HT.RDATA.
#
# Thu Nov 20 10:47:23 PM 2025 AUC 0.926587856813556
#
# [mbo] 32: num_leaves=4080; min_child_weight=1.05; min_data_in_leaf=1786; lambda_l2=1.87; scale_pos_weight=4.71; learning_rate=0.0868; num_iterations=3448; early_stopping_rounds=205; feature_fraction=0.0777; bagging_fraction=0.652 : y = 0.927 : 108.7 secs : infill_ei
#
# Thu Nov 20 10:48:08 PM 2025 AUC 0.928380606494968
#
# [mbo] 33: num_leaves=2104; min_child_weight=8.08; min_data_in_leaf=932; lambda_l2=0.607; scale_pos_weight=3.62; learning_rate=0.0672; num_iterations=903; early_stopping_rounds=51; feature_fraction=0.112; bagging_fraction=0.788 : y = 0.928 : 43.4 secs : infill_ei
#
# Thu Nov 20 10:50:44 PM 2025 AUC 0.933173687011339
#
# [mbo] 34: num_leaves=5509; min_child_weight=7.77; min_data_in_leaf=356; lambda_l2=10.5; scale_pos_weight=4.14; learning_rate=0.0165; num_iterations=3057; early_stopping_rounds=99; feature_fraction=0.0808; bagging_fraction=0.975 : y = 0.933 : 155.4 secs : infill_ei
#
# Thu Nov 20 10:52:37 PM 2025 AUC 0.932821713510347
#
# [mbo] 35: num_leaves=4329; min_child_weight=7.37; min_data_in_leaf=30; lambda_l2=18.7; scale_pos_weight=3.65; learning_rate=0.0229; num_iterations=2933; early_stopping_rounds=101; feature_fraction=0.0695; bagging_fraction=0.637 : y = 0.933 : 112.7 secs : infill_ei
#
# Thu Nov 20 10:59:27 PM 2025 AUC 0.930272002705733
#
# [mbo] 36: num_leaves=5934; min_child_weight=6.64; min_data_in_leaf=34; lambda_l2=134; scale_pos_weight=2.67; learning_rate=0.0181; num_iterations=3746; early_stopping_rounds=113; feature_fraction=0.168; bagging_fraction=0.908 : y = 0.93 : 407.7 secs : infill_ei
#
# Saved the current state after iteration 37 in the file HT.RDATA.
#
# Thu Nov 20 11:06:15 PM 2025 AUC 0.935660317722352
#
# [mbo] 37: num_leaves=507; min_child_weight=9.39; min_data_in_leaf=15; lambda_l2=0.027; scale_pos_weight=4; learning_rate=0.00654; num_iterations=1955; early_stopping_rounds=413; feature_fraction=0.402; bagging_fraction=0.788 : y = 0.936 : 407.6 secs : infill_ei
#
# Thu Nov 20 11:11:06 PM 2025 AUC 0.936684698178529
#
# [mbo] 38: num_leaves=6054; min_child_weight=9.21; min_data_in_leaf=46; lambda_l2=0.513; scale_pos_weight=2.92; learning_rate=0.00718; num_iterations=2078; early_stopping_rounds=389; feature_fraction=0.138; bagging_fraction=0.892 : y = 0.937 : 288.8 secs : infill_ei
#
# Saved the current state after iteration 39 in the file HT.RDATA.
#
# Thu Nov 20 11:16:20 PM 2025 AUC 0.932770041518781
#
# [mbo] 39: num_leaves=3143; min_child_weight=8.68; min_data_in_leaf=63; lambda_l2=18.7; scale_pos_weight=2.96; learning_rate=0.014; num_iterations=2607; early_stopping_rounds=251; feature_fraction=0.41; bagging_fraction=0.911 : y = 0.933 : 312.5 secs : infill_ei
#
# Thu Nov 20 11:19:14 PM 2025 AUC 0.923130530832409
#
# [mbo] 40: num_leaves=5348; min_child_weight=8.13; min_data_in_leaf=493; lambda_l2=172; scale_pos_weight=4.42; learning_rate=0.0106; num_iterations=1813; early_stopping_rounds=256; feature_fraction=0.0728; bagging_fraction=0.945 : y = 0.923 : 173.4 secs : infill_ei
#
# Thu Nov 20 11:21:04 PM 2025 AUC 0.931784247290072
#
# [mbo] 41: num_leaves=6005; min_child_weight=8.21; min_data_in_leaf=547; lambda_l2=31.7; scale_pos_weight=5; learning_rate=0.0745; num_iterations=2585; early_stopping_rounds=141; feature_fraction=0.556; bagging_fraction=0.764 : y = 0.932 : 108.5 secs : infill_ei
#
# Thu Nov 20 11:23:23 PM 2025 AUC 0.934474881708048
#
# [mbo] 42: num_leaves=149; min_child_weight=9.35; min_data_in_leaf=251; lambda_l2=1.04; scale_pos_weight=3.5; learning_rate=0.0407; num_iterations=2159; early_stopping_rounds=380; feature_fraction=0.303; bagging_fraction=0.828 : y = 0.934 : 138.1 secs : infill_ei
#
# Saved the current state after iteration 43 in the file HT.RDATA.
#
# Thu Nov 20 11:26:54 PM 2025 AUC 0.933683696278744
#
# [mbo] 43: num_leaves=1858; min_child_weight=8.33; min_data_in_leaf=111; lambda_l2=73.8; scale_pos_weight=4.74; learning_rate=0.0383; num_iterations=2445; early_stopping_rounds=264; feature_fraction=0.0834; bagging_fraction=0.806 : y = 0.934 : 210.0 secs : infill_ei
#
# Thu Nov 20 11:30:30 PM 2025 AUC 0.930221001778993
#
# [mbo] 44: num_leaves=6491; min_child_weight=8.86; min_data_in_leaf=212; lambda_l2=7.45; scale_pos_weight=2.61; learning_rate=0.0346; num_iterations=3405; early_stopping_rounds=371; feature_fraction=0.0757; bagging_fraction=0.771 : y = 0.93 : 214.3 secs : infill_ei
#
# Thu Nov 20 11:32:39 PM 2025 AUC 0.934782564930555
#
# [mbo] 45: num_leaves=3557; min_child_weight=9.14; min_data_in_leaf=184; lambda_l2=3.03; scale_pos_weight=3.2; learning_rate=0.0247; num_iterations=2210; early_stopping_rounds=98; feature_fraction=0.0811; bagging_fraction=0.809 : y = 0.935 : 127.0 secs : infill_ei
#
# Thu Nov 20 11:35:26 PM 2025 AUC 0.937345697031679
#
# [mbo] 46: num_leaves=324; min_child_weight=8.83; min_data_in_leaf=243; lambda_l2=0.773; scale_pos_weight=4.39; learning_rate=0.0158; num_iterations=2158; early_stopping_rounds=125; feature_fraction=0.121; bagging_fraction=0.903 : y = 0.937 : 165.6 secs : infill_ei
#
# Saved the current state after iteration 47 in the file HT.RDATA.
#
# Thu Nov 20 11:38:04 PM 2025 AUC 0.934199409597167
#
# [mbo] 47: num_leaves=5575; min_child_weight=8.04; min_data_in_leaf=1139; lambda_l2=0.685; scale_pos_weight=3.03; learning_rate=0.0179; num_iterations=1156; early_stopping_rounds=247; feature_fraction=0.188; bagging_fraction=0.953 : y = 0.934 : 156.5 secs : infill_ei
#
# Thu Nov 20 11:44:37 PM 2025 AUC 0.92248060454888
#
# [mbo] 48: num_leaves=2074; min_child_weight=9.03; min_data_in_leaf=398; lambda_l2=25.1; scale_pos_weight=1.16; learning_rate=0.00698; num_iterations=1952; early_stopping_rounds=362; feature_fraction=0.581; bagging_fraction=0.807 : y = 0.922 : 391.6 secs : infill_ei
#
# Thu Nov 20 11:45:06 PM 2025 AUC 0.929180851299416
#
# [mbo] 49: num_leaves=6069; min_child_weight=7.53; min_data_in_leaf=117; lambda_l2=0.585; scale_pos_weight=1.73; learning_rate=0.0768; num_iterations=2015; early_stopping_rounds=76; feature_fraction=0.185; bagging_fraction=0.715 : y = 0.929 : 27.9 secs : infill_ei
#
# Thu Nov 20 11:47:31 PM 2025 AUC 0.934053788530026
#
# [mbo] 50: num_leaves=5590; min_child_weight=3.23; min_data_in_leaf=231; lambda_l2=0.565; scale_pos_weight=3.09; learning_rate=0.0204; num_iterations=916; early_stopping_rounds=110; feature_fraction=0.158; bagging_fraction=0.724 : y = 0.934 : 143.0 secs : infill_ei
#
# Saved the current state after iteration 51 in the file HT.RDATA.
#
# Thu Nov 20 11:48:59 PM 2025 AUC 0.927142156359447
#
# [mbo] 51: num_leaves=3847; min_child_weight=2.82; min_data_in_leaf=1791; lambda_l2=37.5; scale_pos_weight=2.57; learning_rate=0.0333; num_iterations=3025; early_stopping_rounds=57; feature_fraction=0.107; bagging_fraction=0.661 : y = 0.927 : 86.7 secs : infill_ei
#
# Thu Nov 20 11:50:52 PM 2025 AUC 0.9286101106653
#
# [mbo] 52: num_leaves=3115; min_child_weight=9.72; min_data_in_leaf=44; lambda_l2=0.58; scale_pos_weight=3.49; learning_rate=0.0423; num_iterations=1979; early_stopping_rounds=432; feature_fraction=0.2; bagging_fraction=0.932 : y = 0.929 : 110.5 secs : infill_ei
#
# Thu Nov 20 11:53:12 PM 2025 AUC 0.935429135889956
#
# [mbo] 53: num_leaves=1046; min_child_weight=8.42; min_data_in_leaf=23; lambda_l2=34.6; scale_pos_weight=4.81; learning_rate=0.0717; num_iterations=2266; early_stopping_rounds=124; feature_fraction=0.0562; bagging_fraction=0.911 : y = 0.935 : 138.4 secs : infill_ei
#
# Fri Nov 21 12:01:19 AM 2025 AUC 0.9373409995779
#
# [mbo] 54: num_leaves=7423; min_child_weight=2.16; min_data_in_leaf=350; lambda_l2=2.05; scale_pos_weight=3.67; learning_rate=0.0131; num_iterations=2899; early_stopping_rounds=300; feature_fraction=0.321; bagging_fraction=0.745 : y = 0.937 : 485.8 secs : infill_ei
#
# Saved the current state after iteration 55 in the file HT.RDATA.
#
# Fri Nov 21 12:07:05 AM 2025 AUC 0.930016998072031
#
# [mbo] 55: num_leaves=6899; min_child_weight=2.3; min_data_in_leaf=1481; lambda_l2=2.47; scale_pos_weight=4.77; learning_rate=0.00561; num_iterations=2193; early_stopping_rounds=166; feature_fraction=0.263; bagging_fraction=0.789 : y = 0.93 : 344.8 secs : infill_ei
#
# Fri Nov 21 12:09:25 AM 2025 AUC 0.935414036931382
#
# [mbo] 56: num_leaves=6169; min_child_weight=1.31; min_data_in_leaf=640; lambda_l2=0.296; scale_pos_weight=3.6; learning_rate=0.0237; num_iterations=2553; early_stopping_rounds=109; feature_fraction=0.304; bagging_fraction=0.728 : y = 0.935 : 137.4 secs : infill_ei
#
# Fri Nov 21 12:14:54 AM 2025 AUC 0.935603612744595
#
# [mbo] 57: num_leaves=5630; min_child_weight=7.77; min_data_in_leaf=218; lambda_l2=9.79; scale_pos_weight=3.33; learning_rate=0.0072; num_iterations=2064; early_stopping_rounds=407; feature_fraction=0.262; bagging_fraction=0.788 : y = 0.936 : 327.6 secs : infill_ei
#
# Saved the current state after iteration 58 in the file HT.RDATA.
#
# Fri Nov 21 12:16:33 AM 2025 AUC 0.93535196343502
#
# [mbo] 58: num_leaves=6915; min_child_weight=2.47; min_data_in_leaf=9; lambda_l2=2.52; scale_pos_weight=3.47; learning_rate=0.0425; num_iterations=3688; early_stopping_rounds=225; feature_fraction=0.222; bagging_fraction=0.772 : y = 0.935 : 96.5 secs : infill_ei
#
# Fri Nov 21 12:21:55 AM 2025 AUC 0.934705392475619
#
# [mbo] 59: num_leaves=7238; min_child_weight=7.04; min_data_in_leaf=177; lambda_l2=0.986; scale_pos_weight=3.67; learning_rate=0.00972; num_iterations=3297; early_stopping_rounds=237; feature_fraction=0.444; bagging_fraction=0.82 : y = 0.935 : 319.0 secs : infill_ei
#
# Fri Nov 21 12:23:59 AM 2025 AUC 0.934464480203252
#
# [mbo] 60: num_leaves=7526; min_child_weight=3.18; min_data_in_leaf=362; lambda_l2=3.26; scale_pos_weight=3.72; learning_rate=0.0666; num_iterations=2002; early_stopping_rounds=161; feature_fraction=0.347; bagging_fraction=0.721 : y = 0.934 : 122.9 secs : infill_ei
#
# Fri Nov 21 12:26:51 AM 2025 AUC 0.936605848061529
#
# [mbo] 61: num_leaves=6554; min_child_weight=2.75; min_data_in_leaf=215; lambda_l2=1.57; scale_pos_weight=3.77; learning_rate=0.0248; num_iterations=3907; early_stopping_rounds=144; feature_fraction=0.5; bagging_fraction=0.734 : y = 0.937 : 169.7 secs : infill_ei
#
# Saved the current state after iteration 62 in the file HT.RDATA.
#
# Fri Nov 21 12:35:07 AM 2025 AUC 0.934903692131564
#
# [mbo] 62: num_leaves=7204; min_child_weight=4.16; min_data_in_leaf=822; lambda_l2=1.17; scale_pos_weight=3.53; learning_rate=0.00692; num_iterations=2721; early_stopping_rounds=249; feature_fraction=0.306; bagging_fraction=0.777 : y = 0.935 : 494.8 secs : infill_ei
#
# Fri Nov 21 12:39:44 AM 2025 AUC 0.933458889562191
#
# [mbo] 63: num_leaves=575; min_child_weight=7.22; min_data_in_leaf=34; lambda_l2=3.15; scale_pos_weight=3.95; learning_rate=0.0319; num_iterations=3343; early_stopping_rounds=357; feature_fraction=0.58; bagging_fraction=0.684 : y = 0.933 : 275.4 secs : infill_ei
#
# Saved the current state after iteration 64 in the file HT.RDATA.
#
# Fri Nov 21 12:43:03 AM 2025 AUC 0.934513132403103
#
# [mbo] 64: num_leaves=6832; min_child_weight=1.41; min_data_in_leaf=9; lambda_l2=0.294; scale_pos_weight=2.97; learning_rate=0.0398; num_iterations=2761; early_stopping_rounds=326; feature_fraction=0.612; bagging_fraction=0.794 : y = 0.935 : 195.7 secs : infill_ei
#
# Fri Nov 21 12:48:49 AM 2025 AUC 0.936825957324304
#
# [mbo] 65: num_leaves=6393; min_child_weight=2.48; min_data_in_leaf=51; lambda_l2=3.46; scale_pos_weight=3.49; learning_rate=0.0197; num_iterations=2982; early_stopping_rounds=379; feature_fraction=0.443; bagging_fraction=0.654 : y = 0.937 : 344.7 secs : infill_ei
#
# Fri Nov 21 12:54:00 AM 2025 AUC 0.935882440179604
#
# [mbo] 66: num_leaves=8118; min_child_weight=6.33; min_data_in_leaf=24; lambda_l2=2.62; scale_pos_weight=3.84; learning_rate=0.0248; num_iterations=2761; early_stopping_rounds=351; feature_fraction=0.524; bagging_fraction=0.763 : y = 0.936 : 308.7 secs : infill_ei
#
# Saved the current state after iteration 67 in the file HT.RDATA.
#
# Fri Nov 21 12:58:34 AM 2025 AUC 0.93483658564901
#
# [mbo] 67: num_leaves=6750; min_child_weight=7.65; min_data_in_leaf=37; lambda_l2=0.33; scale_pos_weight=3.22; learning_rate=0.039; num_iterations=2175; early_stopping_rounds=397; feature_fraction=0.552; bagging_fraction=0.9 : y = 0.935 : 272.2 secs : infill_ei
#
# Fri Nov 21 01:02:34 AM 2025 AUC 0.937717466945024
#
# [mbo] 68: num_leaves=7963; min_child_weight=1.11; min_data_in_leaf=688; lambda_l2=1.01; scale_pos_weight=3.74; learning_rate=0.0412; num_iterations=3346; early_stopping_rounds=331; feature_fraction=0.527; bagging_fraction=0.72 : y = 0.938 : 238.0 secs : infill_ei
#
# Fri Nov 21 01:06:47 AM 2025 AUC 0.936651480469665
#
# [mbo] 69: num_leaves=7896; min_child_weight=3.28; min_data_in_leaf=365; lambda_l2=0.757; scale_pos_weight=3.82; learning_rate=0.0293; num_iterations=3180; early_stopping_rounds=298; feature_fraction=0.454; bagging_fraction=0.552 : y = 0.937 : 251.4 secs : infill_ei
#
# Saved the current state after iteration 70 in the file HT.RDATA.
#
# Fri Nov 21 01:11:09 AM 2025 AUC 0.93645687167026
#
# [mbo] 70: num_leaves=7693; min_child_weight=3.02; min_data_in_leaf=408; lambda_l2=2.56; scale_pos_weight=4.45; learning_rate=0.0312; num_iterations=4201; early_stopping_rounds=376; feature_fraction=0.506; bagging_fraction=0.82 : y = 0.936 : 259.6 secs : infill_ei
#
# Fri Nov 21 01:15:39 AM 2025 AUC 0.936989361609321
#
# [mbo] 71: num_leaves=8187; min_child_weight=2.14; min_data_in_leaf=23; lambda_l2=1.1; scale_pos_weight=3.99; learning_rate=0.0256; num_iterations=4134; early_stopping_rounds=468; feature_fraction=0.5; bagging_fraction=0.76 : y = 0.937 : 268.0 secs : infill_ei
#
# Fri Nov 21 01:18:19 AM 2025 AUC 0.932197287690188
#
# [mbo] 72: num_leaves=7462; min_child_weight=2.6; min_data_in_leaf=70; lambda_l2=2.53; scale_pos_weight=3.87; learning_rate=0.0432; num_iterations=4161; early_stopping_rounds=328; feature_fraction=0.743; bagging_fraction=0.712 : y = 0.932 : 157.1 secs : infill_ei
#
# Saved the current state after iteration 73 in the file HT.RDATA.
#
# Fri Nov 21 01:20:05 AM 2025 AUC 0.930786038362092
#
# [mbo] 73: num_leaves=8090; min_child_weight=2.43; min_data_in_leaf=24; lambda_l2=65.2; scale_pos_weight=4.2; learning_rate=0.0932; num_iterations=3228; early_stopping_rounds=142; feature_fraction=0.531; bagging_fraction=0.701 : y = 0.931 : 104.1 secs : infill_ei
#
# Fri Nov 21 01:23:49 AM 2025 AUC 0.935869689947919
#
# [mbo] 74: num_leaves=7752; min_child_weight=2.98; min_data_in_leaf=480; lambda_l2=0.21; scale_pos_weight=3.86; learning_rate=0.0275; num_iterations=3235; early_stopping_rounds=397; feature_fraction=0.425; bagging_fraction=0.774 : y = 0.936 : 222.2 secs : infill_ei
#
# Fri Nov 21 01:29:26 AM 2025 AUC 0.929242589263365
#
# [mbo] 75: num_leaves=7971; min_child_weight=0.684; min_data_in_leaf=211; lambda_l2=101; scale_pos_weight=3.52; learning_rate=0.0315; num_iterations=4851; early_stopping_rounds=306; feature_fraction=0.472; bagging_fraction=0.696 : y = 0.929 : 335.9 secs : infill_ei
#
# Saved the current state after iteration 76 in the file HT.RDATA.
#
# Fri Nov 21 01:32:10 AM 2025 AUC 0.937625866596339
#
# [mbo] 76: num_leaves=7916; min_child_weight=1.68; min_data_in_leaf=111; lambda_l2=0.292; scale_pos_weight=3.58; learning_rate=0.0325; num_iterations=4234; early_stopping_rounds=284; feature_fraction=0.406; bagging_fraction=0.621 : y = 0.938 : 162.0 secs : infill_ei
#
# Fri Nov 21 01:37:11 AM 2025 AUC 0.936772607670674
#
# [mbo] 77: num_leaves=855; min_child_weight=4.5; min_data_in_leaf=107; lambda_l2=2.74; scale_pos_weight=3.14; learning_rate=0.0118; num_iterations=3057; early_stopping_rounds=416; feature_fraction=0.335; bagging_fraction=0.672 : y = 0.937 : 298.7 secs : infill_ei
#
# Fri Nov 21 01:38:54 AM 2025 AUC 0.919176616880367
#
# [mbo] 78: num_leaves=932; min_child_weight=7.69; min_data_in_leaf=17; lambda_l2=36.6; scale_pos_weight=2.53; learning_rate=0.00711; num_iterations=887; early_stopping_rounds=134; feature_fraction=0.151; bagging_fraction=0.881 : y = 0.919 : 100.9 secs : infill_ei
#
# Fri Nov 21 01:46:53 AM 2025 AUC 0.930294147844976
#
# [mbo] 79: num_leaves=5808; min_child_weight=9.12; min_data_in_leaf=23; lambda_l2=26.6; scale_pos_weight=2.88; learning_rate=0.00582; num_iterations=2338; early_stopping_rounds=384; feature_fraction=0.465; bagging_fraction=0.95 : y = 0.93 : 477.4 secs : infill_ei
#
# Saved the current state after iteration 80 in the file HT.RDATA.
#
# Fri Nov 21 01:53:54 AM 2025 AUC 0.937455416130654
#
# [mbo] 80: num_leaves=431; min_child_weight=3.93; min_data_in_leaf=160; lambda_l2=6.4; scale_pos_weight=4.13; learning_rate=0.00821; num_iterations=2795; early_stopping_rounds=382; feature_fraction=0.239; bagging_fraction=0.791 : y = 0.937 : 419.2 secs : infill_ei
#
# Fri Nov 21 01:55:54 AM 2025 AUC 0.934834907986946
#
# [mbo] 81: num_leaves=6574; min_child_weight=9.55; min_data_in_leaf=78; lambda_l2=25.5; scale_pos_weight=2.74; learning_rate=0.0302; num_iterations=1694; early_stopping_rounds=63; feature_fraction=0.08; bagging_fraction=0.687 : y = 0.935 : 118.8 secs : infill_ei
#
# Fri Nov 21 01:58:54 AM 2025 AUC 0.938174797623625
#
# [mbo] 82: num_leaves=4754; min_child_weight=5.91; min_data_in_leaf=52; lambda_l2=0.103; scale_pos_weight=3.03; learning_rate=0.0319; num_iterations=2283; early_stopping_rounds=284; feature_fraction=0.441; bagging_fraction=0.651 : y = 0.938 : 178.5 secs : infill_ei
#
# Saved the current state after iteration 83 in the file HT.RDATA.
#
# Fri Nov 21 02:02:50 AM 2025 AUC 0.934998312271964
#
# [mbo] 83: num_leaves=5108; min_child_weight=5.94; min_data_in_leaf=35; lambda_l2=0.248; scale_pos_weight=4.26; learning_rate=0.0173; num_iterations=4234; early_stopping_rounds=307; feature_fraction=0.377; bagging_fraction=0.596 : y = 0.935 : 233.5 secs : infill_ei
#
# Fri Nov 21 02:06:20 AM 2025 AUC 0.931231625406246
#
# [mbo] 84: num_leaves=6308; min_child_weight=2.02; min_data_in_leaf=738; lambda_l2=0.164; scale_pos_weight=3.41; learning_rate=0.0261; num_iterations=3793; early_stopping_rounds=288; feature_fraction=0.763; bagging_fraction=0.651 : y = 0.931 : 208.4 secs : infill_ei
#
# Fri Nov 21 02:08:10 AM 2025 AUC 0.929856949111141
#
# [mbo] 85: num_leaves=416; min_child_weight=4.72; min_data_in_leaf=1084; lambda_l2=6.13; scale_pos_weight=1.38; learning_rate=0.0137; num_iterations=1002; early_stopping_rounds=280; feature_fraction=0.128; bagging_fraction=0.9 : y = 0.93 : 107.9 secs : infill_ei
#
# Fri Nov 21 02:12:10 AM 2025 AUC 0.935202315978926
#
# [mbo] 86: num_leaves=6874; min_child_weight=4.92; min_data_in_leaf=462; lambda_l2=1.04; scale_pos_weight=3.56; learning_rate=0.0206; num_iterations=1418; early_stopping_rounds=175; feature_fraction=0.741; bagging_fraction=0.671 : y = 0.935 : 238.0 secs : infill_ei
#
# Saved the current state after iteration 87 in the file HT.RDATA.
#
# Fri Nov 21 02:15:03 AM 2025 AUC 0.934285305894835
#
# [mbo] 87: num_leaves=7422; min_child_weight=6.26; min_data_in_leaf=224; lambda_l2=0.0932; scale_pos_weight=2.1; learning_rate=0.0232; num_iterations=1839; early_stopping_rounds=205; feature_fraction=0.285; bagging_fraction=0.643 : y = 0.934 : 171.1 secs : infill_ei
#
# Fri Nov 21 02:17:46 AM 2025 AUC 0.937125252236491
#
# [mbo] 88: num_leaves=485; min_child_weight=3.23; min_data_in_leaf=11; lambda_l2=0.435; scale_pos_weight=3.94; learning_rate=0.024; num_iterations=2894; early_stopping_rounds=186; feature_fraction=0.0913; bagging_fraction=0.687 : y = 0.937 : 160.5 secs : infill_ei
#
# Fri Nov 21 02:21:07 AM 2025 AUC 0.931184986400871
#
# [mbo] 89: num_leaves=643; min_child_weight=3.29; min_data_in_leaf=782; lambda_l2=0.246; scale_pos_weight=4.06; learning_rate=0.0183; num_iterations=1818; early_stopping_rounds=302; feature_fraction=0.128; bagging_fraction=0.809 : y = 0.931 : 199.6 secs : infill_ei
#
# Fri Nov 21 02:24:58 AM 2025 AUC 0.937046066587078
#
# [mbo] 90: num_leaves=1165; min_child_weight=4.1; min_data_in_leaf=27; lambda_l2=0.0452; scale_pos_weight=3.92; learning_rate=0.0176; num_iterations=3981; early_stopping_rounds=187; feature_fraction=0.282; bagging_fraction=0.623 : y = 0.937 : 229.0 secs : infill_ei
#
# Saved the final state in the file HT.RDATA
#
# Saved the final state in the file HT.RDATA

# %% [markdown]
# la bayesian optimization ha corrido, extraigo los mejores hiperparametros

# %%
# almaceno los resultados de la Bayesian Optimization
# y capturo los mejores hiperparametros encontrados

tb_bayesiana <- as.data.table(bayesiana_salida$opt.path)

# ordeno en forma descendente por AUC = y
setorder(tb_bayesiana, -y, -num_iterations)

# grabo para eventualmente poder utilizarlos en OTRA corrida
fwrite( tb_bayesiana,
  file="BO_log.txt",
  sep="\t"
)

# los mejores hiperparámetros son los que quedaron en el registro 1 de la tabla
PARAM$out$lgbm$mejores_hiperparametros <- tb_bayesiana[
  1, # el primero es el de mejor AUC
  setdiff(colnames(tb_bayesiana),
    c("y","dob","eol","error.message","exec.time","ei","error.model",
      "train.time","prop.type","propose.time","se","mean","iter")),
  with= FALSE
]

print(PARAM$out$lgbm$mejores_hiperparametros)
# Out:
#    num_leaves min_child_weight min_data_in_leaf lambda_l2 scale_pos_weight
#         <int>            <num>            <int>     <num>            <num>
# 1:       3702         8.099816              549  6.620882         4.998752
#    learning_rate num_iterations early_stopping_rounds feature_fraction
#            <num>          <int>                 <int>            <num>
# 1:    0.06662623           1966                   249        0.1310396
#    bagging_fraction
#               <num>
# 1:        0.8390043

# %% [markdown]
# ### 6.3.3 Produccion

# %% [markdown]
# #### Final Training
# Construyo el modelo final, que es uno solo, no hace ningun tipo de particion < training, validation, testing>]

# %% [markdown]
# ##### Final Training Dataset
#
# Aqui esta la gran decision de en qué meses hago el Final Training
# <br> debo utilizar los mejores hiperparámetros que encontré en la optimización bayesiana

# %%
PARAM$trainingstrategy$final_train <- c(
  202105, 202104, 202103, 202102, 202101,
  202012, 202011, 202010, 202009, 202008, 202007,
  202006, 202005
)

dataset[, fold_final_train := foto_mes %in% PARAM$trainingstrategy$final_train ]

# creo el dfinal_train en formato  LightGBM
dfinal_train <- lgb.Dataset(
  data= data.matrix(dataset[fold_final_train == TRUE, campos_buenos, with= FALSE]),
  label= dataset[fold_final_train == TRUE, clase01],
  free_raw_data= TRUE
)

nrow( dfinal_train) # verifico el tamaño
# Out:
# [1] 207504

# %% [markdown]
# ##### Final Training Hyperparameters

# %%
# uno los parametros fijos y los mejores encontrados de los variables
fijos <- copy(PARAM$lgbm$param_fijos)

# quito lo que optimice en la Bayesian Optimization
fijos$num_iterations <- NULL
fijos$early_stopping_rounds <- NULL

# agrego a los hiperparametros fijos los que encontre con la Bayesian Optimization
param_final <- c(fijos, PARAM$out$lgbm$mejores_hiperparametros)

# Para el entrenamiento final, removemos early_stopping_rounds
# ya que se entrena con todos los datos disponibles y la cantidad de iteraciones
# ya está optimizada en 'num_iterations'.
param_final$early_stopping_rounds <- NULL

# %% [markdown]
# ##### Training
# Genero el modelo final, siempre sobre TODOS los datos de  final_train, sin hacer ningun tipo de undersampling de la clase mayoritaria

# %%
final_model <- lgb.train(
  data= dfinal_train,
  param= param_final,
  verbose= -100
)

# %%
# grabo a disco el modelo en un formato para seres humanos ... ponele ...

lgb.save(final_model, "modelo.txt")

# %%
# ahora imprimo la importancia de variables

tb_importancia <- as.data.table(lgb.importance(final_model))
archivo_importancia <- "impo.txt"

fwrite( tb_importancia,
  file= archivo_importancia,
  sep= "\t"
)

# %% [markdown]
# #### Scoring

# %% [markdown]
# Aplico el modelo final a los datos del futuro

# %%
PARAM$trainingstrategy$future <- c(202107)

dfuture <- dataset[ foto_mes %in% PARAM$trainingstrategy$future ]

# %%
# aplico final_model   a dfuture

prediccion <- predict(
  final_model,
  data.matrix(dfuture[, campos_buenos, with= FALSE])
)

# %% [markdown]
# ##### Tabla Prediccion

# %%
tb_prediccion <- dfuture[, list(numero_de_cliente)]
tb_prediccion[, prob := prediccion]

# grabo las probabilidad del modelo
#  me va a ser util para hacer Ensembles de modelos
fwrite(tb_prediccion,
  file= "prediccion.txt",
  sep= "\t"
)

# %% [markdown]
# #### Curva de Ganancia

# %% [markdown]
# Genero las salidas

# %%
# asigno clase ternaria
tb_prediccion[, clase_ternaria := dfuture$clase_ternaria ]

# asigno ganancias
tb_prediccion[, ganancia := -3000.0 ]
tb_prediccion[clase_ternaria=="BAJA+2", ganancia := 117000.0 ]

# reordeno, y acumulada
setorder( tb_prediccion, -prob )
tb_prediccion[, gan_acum := cumsum(ganancia)]

# media movil de ancho 400
tb_prediccion[,
  gan_suavizada := frollmean(
    x= gan_acum,
    n= 400,
    align= "center",
    na.rm= TRUE,
    hasNA= TRUE
  )
]

# %%
tb_prediccion[, sum(!is.na(gan_suavizada) )]
tb_prediccion[, .N]
# Out:
# [1] 16152
# [1] 16551

# %%
# Este es la ganancia a reportar
resultado <- list()
resultado$ganancia_suavizada_max <- max( tb_prediccion$gan_suavizada, na.rm=TRUE )
options(digits= 8)
resultado$envios <- which.max( tb_prediccion$gan_suavizada)
resultado
# Out:
# $ganancia_suavizada_max
# [1] 5963100
#
# $envios
# [1] 1217

# %%
# grabo las ganancias
fwrite( tb_prediccion,
  file= "ganancias.txt",
  sep= "\t"
)

# %%
# genero el grafico

tb_prediccion[, envios:= .I]

pdf("curva_de_ganancia.pdf")

plot(
  x= tb_prediccion$envios,
  y= tb_prediccion$gan_acum,
  type= "l",
  col= "gray",
  xlim= c(0, 6000),
  ylim= c(0, 8000000),
  main= paste0("Mejor gan prom= ", as.integer(resultado$ganancia_suavizada_max), " envios= ", resultado$envios),
  xlab= "Envios",
  ylab= "Ganancia",
  panel.first= grid()
)

dev.off()
# Out:
# agg_record_2002940423
#                     2

# %%
# grabo los parametros
if( !require("yaml")) install.packages("yaml")
require("yaml")

PARAM$resultado <- resultado

write_yaml( PARAM, file="PARAM.yml")
# Out:
# Loading required package: yaml

# %%
format(Sys.time(), "%a %b %d %X %Y")
fin <- Sys.time()

# Duración en segundos
secs <- as.numeric(difftime(fin, principio, units = "secs"))
secs <- round(secs)

# A hh:mm:ss
h <- secs %/% 3600
m <- (secs %% 3600) %/% 60
s <- secs %% 60
dur_hms <- sprintf("%02d:%02d:%02d", h, m, s)

cat(
  "Inicio: ", format(principio, "%a %b %d %X %Y"), "\n",
  "Fin:    ", format(fin,       "%a %b %d %X %Y"), "\n",
  "Duración (hh:mm:ss): ", dur_hms, "\n",
  sep = ""
)
# Out:
# [1] "Fri Nov 21 02:29:23 AM 2025"
# Inicio: Thu Nov 20 06:24:46 PM 2025
# Fin:    Fri Nov 21 02:29:23 AM 2025
# Duración (hh:mm:ss): 08:04:38
