# %% [markdown]
# <a href="https://colab.research.google.com/github/jwbarbona/labo2025v/blob/main/610_WorkFlow_8HT_65124_gerencial_julio.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # 6 WorkFlow  Gerencial, futuro=JULIO

# %% [markdown]
# ### 6.1 Objetivo

# %% [markdown]
# Presentar un workflow/pipeline completo al que los estudiantes deberán enriquecer

# %% [markdown]
# #### 6.2  Seteo del ambiente en Google Colab

# %% [markdown]
# Esta parte se debe correr con el runtime en Python3
# <br>Ir al menu, Runtime -> Change Runtime Type -> Runtime type ->  **Python 3**

# %% [markdown]
# Conectar la virtual machine donde esta corriendo Google Colab con el  Google Drive, para poder tener persistencia de archivos

# %%
# primero establecer el Runtime de Python 3
from google.colab import drive
drive.mount('/content/.drive')
# Out:
# Mounted at /content/.drive

# %% [markdown]
# Para correr la siguiente celda es fundamental en Arranque en Frio haber copiado el archivo kaggle.json al Google Drive, en la carpeta indicada en el instructivo
#
# <br>los siguientes comando estan en shell script de Linux
# *   Crear las carpetas en el Google Drive
# *   "instalar" el archivo kaggle.json desde el Google Drive a la virtual machine para que pueda ser utilizado por la libreria  kaggle de Python
# *   Bajar el  **dataset_pequeno**  al  Google Drive  y tambien al disco local de la virtual machine que esta corriendo Google Colab
# *   Bajar el **dataset_historico** al Google Drive y tambien al disco local de la virtual machine que esta corriendo Google Colab

# %%
%%shell

mkdir -p "/content/.drive/My Drive/labo1"
mkdir -p "/content/buckets"
ln -s "/content/.drive/My Drive/labo1" /content/buckets/b1

mkdir -p ~/.kaggle
cp /content/buckets/b1/kaggle/kaggle.json  ~/.kaggle
chmod 600 ~/.kaggle/kaggle.json


mkdir -p /content/buckets/b1/exp
mkdir -p /content/buckets/b1/datasets
mkdir -p /content/datasets


webfiles="https://storage.googleapis.com/open-courses/austral2025-af91/"
destino_local="/content/datasets"
destino_bucket="/content/buckets/b1/datasets"


archivo="dataset_pequeno.csv"

if ! test -f $destino_bucket/$archivo; then
  wget  $webfiles/$archivo  -O $destino_bucket/$archivo
fi


if ! test -f $destino_local/$pequeno; then
  cp  $destino_bucket/$archivo  $destino_local/$archivo
fi

#-------

archivo="gerencial_competencia_2025.csv.gz"

if ! test -f $destino_bucket/$archivo; then
  wget  $webfiles/$archivo  -O $destino_bucket/$archivo
fi


if ! test -f $destino_local/$pequeno; then
  cp  $destino_bucket/$archivo  $destino_local/$archivo
fi
# Out:
# cp: cannot stat '/content/buckets/b1/kaggle/kaggle.json': No such file or directory
# chmod: cannot access '/root/.kaggle/kaggle.json': No such file or directory

# %% [markdown]
# ## 6.3  Workflow

# %% [markdown]
# ## Inicializacion

# %% [markdown]
# Esta parte se debe correr con el runtime en lenguaje **R** Ir al menu, Runtime -> Change Runtime Type -> Runtime type -> R

# %% [markdown]
# limpio el ambiente de R

# %%
format(Sys.time(), "%a %b %d %X %Y")
# Out:
# [1] "Wed Nov 19 02:49:15 AM 2025"

# %%
# limpio la memoria
rm(list=ls(all.names=TRUE)) # remove all objects
gc(full=TRUE, verbose=FALSE) # garbage collection
# Out:
#        used    (Mb) gc trigger (Mb) max used (Mb)
# Ncells  709769 38.0 1454497    77.7 1454497  77.7
# Vcells 1315742 10.1 8388608    64.0 2084062  16.0

# %%
principio <- Sys.time()

# %%
require("data.table")

if( !require("R.utils")) install.packages("R.utils")
require("R.utils")
# Out:
# Loading required package: data.table
#
# Loading required package: R.utils
#
# Warning message in library(package, lib.loc = lib.loc, character.only = TRUE, logical.return = TRUE, :
# “there is no package called ‘R.utils’”
# Installing package into ‘/usr/local/lib/R/site-library’
# (as ‘lib’ is unspecified)
#
# also installing the dependencies ‘R.oo’, ‘R.methodsS3’
#
#
# Loading required package: R.utils
#
# Loading required package: R.oo
#
# Loading required package: R.methodsS3
#
# R.methodsS3 v1.8.2 (2022-06-13 22:00:14 UTC) successfully loaded. See ?R.methodsS3 for help.
#
# R.oo v1.27.1 (2025-05-02 21:00:05 UTC) successfully loaded. See ?R.oo for help.
#
#
# Attaching package: ‘R.oo’
#
#
# The following object is masked from ‘package:R.methodsS3’:
#
#     throw
#
#
# The following objects are masked from ‘package:methods’:
#
#     getClasses, getMethods
#
#
# The following objects are masked from ‘package:base’:
#
#     attach, detach, load, save
#
#
# R.utils v2.13.0 (2025-02-24 21:20:02 UTC) successfully loaded. See ?R.utils for help.
#
#
# Attaching package: ‘R.utils’
#
#
# The following object is masked from ‘package:utils’:
#
#     timestamp
#
#
# The following objects are masked from ‘package:base’:
#
#     cat, commandArgs, getOption, isOpen, nullfile, parse, use, warnings

# %% [markdown]
# #### Parametros
# Si es gerente, no cambie nada
# <br>Si es Analista, cambie el nombre del dataset

# %%
PARAM <- list()
PARAM$semilla_primigenia <- 700009 # 100009, 200003, 499999, 700009, 999983

PARAM$experimento <- 65124
PARAM$dataset <- "gerencial_competencia_2025.csv.gz"

# %% [markdown]
# #### Carpeta del Experimento

# %%
# carpeta de trabajo

setwd("/content/buckets/b1/exp")
experimento_folder <- paste0("WF", PARAM$experimento)
dir.create(experimento_folder, showWarnings=FALSE)
setwd( paste0("/content/buckets/b1/exp/", experimento_folder ))

# %% [markdown]
# ### 6.3.1   Preprocesamiento del dataset

# %% [markdown]
# #### 6.3.1.1  DT incorporar dataset

# %%
# lectura del dataset
dataset <- fread(paste0("/content/datasets/", PARAM$dataset))

# %% [markdown]
# #### 6.3.1.2  CA  Catastrophe Analysis
# Se intentan reparar las variables que para un mes están con todos los valores en cero.

# %% [markdown]
# El método que se utiliza es **Machine Learning** se asigna NA also valores, si ha leido bien, es la "anti imputación de valores faltantes"
# <br> Usted podrá aplicar aquí otros métodos

# %%
dataset[ foto_mes==202006, internet:=NA]
dataset[ foto_mes==202006, mrentabilidad:=NA]
dataset[ foto_mes==202006, mrentabilidad_annual:=NA]
dataset[ foto_mes==202006, mcomisiones:=NA]
dataset[ foto_mes==202006, mactivos_margen:=NA]
dataset[ foto_mes==202006, mpasivos_margen:=NA]
dataset[ foto_mes==202006, mcuentas_saldo:=NA]
dataset[ foto_mes==202006, ctarjeta_visa_transacciones:=NA]
dataset[ foto_mes==202006, mtarjeta_visa_consumo:=NA]
dataset[ foto_mes==202006, mtarjeta_master_consumo:=NA]
dataset[ foto_mes==202006, ccallcenter_transacciones:=NA]
dataset[ foto_mes==202006, chomebanking_transacciones:=NA]
dataset[ foto_mes==202006, chomebanking_transacciones:=NA]

# %% [markdown]
# #### 6.3.1.3  DR  Data Drifting
# Se intenta corregir el data drifting, quizas ajustando por IPC ...
# <br>Esta parte podrá ser abordada por todos los Analistas y también la Gerenciapero se decide pedagogicamente no incluirla en esta primer version para reducir la carga cognitiva

# %%
# sin codigo en esta primera version del workflow

# %% [markdown]
# #### 6.3.1.3  FE_intra_manual Feature Engineering intra-mes
#
# Agrego campos nuevos dentro del mismo mes, SIN considerar la historia.

# %%
# esta funcion atributos presentes existe debido a que las modalidades poseen datasets con distinta cantidad de campos
atributos_presentes <- function( patributos )
{
  atributos <- unique( patributos )
  comun <- intersect( atributos, colnames(dataset) )

  return(  length( atributos ) == length( comun ) )
}

# el mes 1,2, ..12
if( atributos_presentes( c("foto_mes") ))
  dataset[, kmes := foto_mes %% 100]

# variable extraida de una tesis de maestria de Irlanda
if( atributos_presentes( c("mpayroll", "cliente_edad") ))
  dataset[, mpayroll_sobre_edad := mpayroll / cliente_edad]

# %%
# visualizo las columas del dataset a esta etapa
colnames(dataset)
# Out:
#  [1] "numero_de_cliente"           "foto_mes"
#  [3] "internet"                    "cliente_edad"
#  [5] "cliente_antiguedad"          "mrentabilidad"
#  [7] "mrentabilidad_annual"        "mcomisiones"
#  [9] "mactivos_margen"             "mpasivos_margen"
# [11] "cproductos"                  "mcuenta_corriente"
# [13] "mcaja_ahorro"                "cdescubierto_preacordado"
# [15] "mcuentas_saldo"              "ctarjeta_visa_transacciones"
# [17] "mtarjeta_visa_consumo"       "mtarjeta_master_consumo"
# [19] "mprestamos_personales"       "cpayroll_trx"
# [21] "mpayroll"                    "ccomisiones_mantenimiento"
# [23] "ccallcenter_transacciones"   "chomebanking_transacciones"
# [25] "ctrx_quarter"                "Master_status"
# [27] "Master_fechaalta"            "Master_mpagominimo"
# [29] "Visa_status"                 "Visa_fechaalta"
# [31] "Visa_mpagominimo"            "clase_ternaria"
# [33] "kmes"                        "mpayroll_sobre_edad"

# %% [markdown]
# #### 6.3.1.4  FE_rf Feature Engineering de nuevas variables a partir de hojas de Random Forest
#
# Esto se mostrará unicamente a la *modalidad Analista Sr*

# %%
# No se implementa Feature Engineering a partir de Random Forest

# %% [markdown]
# #### 6.3.1.5  FEhist Feature Engineering historico
#
# El Fature Engineering Histórico es la etapa que más aporta a la ganancia final, ya que enriquece cada registro del dataset con su historia.

# %% [markdown]
# Para cada campo del dataset original (*)
# se crean lo siguientes campos de a partir de la historia
# * lag1  lags de orden 1
# * delta1  =  valor actual - lag1
# * lag2  lags de orden 2
# * delta2  = valor actual - lag2
#
#
# (*) Excepto para los campos  <numero_de_cliente,  foto_mes,  clase_ternaria>

# %%
# Feature Engineering Historico

# todo es lagueable, menos la primary key y la clase
cols_lagueables <- copy( setdiff(
    colnames(dataset),
    c("numero_de_cliente", "foto_mes", "clase_ternaria")
) )

# https://rdrr.io/cran/data.table/man/shift.html

# lags de orden 1
dataset[,
    paste0(cols_lagueables, "_lag1") := shift(.SD, 1, NA, "lag"),
    by = numero_de_cliente,
    .SDcols = cols_lagueables
]

# lags de orden 2
dataset[,
    paste0(cols_lagueables, "_lag2") := shift(.SD, 2, NA, "lag"),
    by = numero_de_cliente,
    .SDcols = cols_lagueables
]

# agrego los delta lags
for (vcol in cols_lagueables)
{
    dataset[, paste0(vcol, "_delta1") := get(vcol) - get(paste0(vcol, "_lag1"))]
    dataset[, paste0(vcol, "_delta2") := get(vcol) - get(paste0(vcol, "_lag2"))]
}

# %% [markdown]
# Verificacion de los campos recien creados

# %%
ncol(dataset)
colnames(dataset)
# Out:
# [1] 158
#   [1] "numero_de_cliente"                  "foto_mes"
#   [3] "internet"                           "cliente_edad"
#   [5] "cliente_antiguedad"                 "mrentabilidad"
#   [7] "mrentabilidad_annual"               "mcomisiones"
#   [9] "mactivos_margen"                    "mpasivos_margen"
#  [11] "cproductos"                         "mcuenta_corriente"
#  [13] "mcaja_ahorro"                       "cdescubierto_preacordado"
#  [15] "mcuentas_saldo"                     "ctarjeta_visa_transacciones"
#  [17] "mtarjeta_visa_consumo"              "mtarjeta_master_consumo"
#  [19] "mprestamos_personales"              "cpayroll_trx"
#  [21] "mpayroll"                           "ccomisiones_mantenimiento"
#  [23] "ccallcenter_transacciones"          "chomebanking_transacciones"
#  [25] "ctrx_quarter"                       "Master_status"
#  [27] "Master_fechaalta"                   "Master_mpagominimo"
#  [29] "Visa_status"                        "Visa_fechaalta"
#  [31] "Visa_mpagominimo"                   "clase_ternaria"
#  [33] "kmes"                               "mpayroll_sobre_edad"
#  [35] "internet_lag1"                      "cliente_edad_lag1"
#  [37] "cliente_antiguedad_lag1"            "mrentabilidad_lag1"
#  [39] "mrentabilidad_annual_lag1"          "mcomisiones_lag1"
#  [41] "mactivos_margen_lag1"               "mpasivos_margen_lag1"
#  [43] "cproductos_lag1"                    "mcuenta_corriente_lag1"
#  [45] "mcaja_ahorro_lag1"                  "cdescubierto_preacordado_lag1"
#  [47] "mcuentas_saldo_lag1"                "ctarjeta_visa_transacciones_lag1"
#  [49] "mtarjeta_visa_consumo_lag1"         "mtarjeta_master_consumo_lag1"
#  [51] "mprestamos_personales_lag1"         "cpayroll_trx_lag1"
#  [53] "mpayroll_lag1"                      "ccomisiones_mantenimiento_lag1"
#  [55] "ccallcenter_transacciones_lag1"     "chomebanking_transacciones_lag1"
#  [57] "ctrx_quarter_lag1"                  "Master_status_lag1"
#  [59] "Master_fechaalta_lag1"              "Master_mpagominimo_lag1"
#  [61] "Visa_status_lag1"                   "Visa_fechaalta_lag1"
#  [63] "Visa_mpagominimo_lag1"              "kmes_lag1"
#  [65] "mpayroll_sobre_edad_lag1"           "internet_lag2"
#  [67] "cliente_edad_lag2"                  "cliente_antiguedad_lag2"
#  [69] "mrentabilidad_lag2"                 "mrentabilidad_annual_lag2"
#  [71] "mcomisiones_lag2"                   "mactivos_margen_lag2"
#  [73] "mpasivos_margen_lag2"               "cproductos_lag2"
#  [75] "mcuenta_corriente_lag2"             "mcaja_ahorro_lag2"
#  [77] "cdescubierto_preacordado_lag2"      "mcuentas_saldo_lag2"
#  [79] "ctarjeta_visa_transacciones_lag2"   "mtarjeta_visa_consumo_lag2"
#  [81] "mtarjeta_master_consumo_lag2"       "mprestamos_personales_lag2"
#  [83] "cpayroll_trx_lag2"                  "mpayroll_lag2"
#  [85] "ccomisiones_mantenimiento_lag2"     "ccallcenter_transacciones_lag2"
#  [87] "chomebanking_transacciones_lag2"    "ctrx_quarter_lag2"
#  [89] "Master_status_lag2"                 "Master_fechaalta_lag2"
#  [91] "Master_mpagominimo_lag2"            "Visa_status_lag2"
#  [93] "Visa_fechaalta_lag2"                "Visa_mpagominimo_lag2"
#  [95] "kmes_lag2"                          "mpayroll_sobre_edad_lag2"
#  [97] "internet_delta1"                    "internet_delta2"
#  [99] "cliente_edad_delta1"                "cliente_edad_delta2"
# [101] "cliente_antiguedad_delta1"          "cliente_antiguedad_delta2"
# [103] "mrentabilidad_delta1"               "mrentabilidad_delta2"
# [105] "mrentabilidad_annual_delta1"        "mrentabilidad_annual_delta2"
# [107] "mcomisiones_delta1"                 "mcomisiones_delta2"
# [109] "mactivos_margen_delta1"             "mactivos_margen_delta2"
# [111] "mpasivos_margen_delta1"             "mpasivos_margen_delta2"
# [113] "cproductos_delta1"                  "cproductos_delta2"
# [115] "mcuenta_corriente_delta1"           "mcuenta_corriente_delta2"
# [117] "mcaja_ahorro_delta1"                "mcaja_ahorro_delta2"
# [119] "cdescubierto_preacordado_delta1"    "cdescubierto_preacordado_delta2"
# [121] "mcuentas_saldo_delta1"              "mcuentas_saldo_delta2"
# [123] "ctarjeta_visa_transacciones_delta1" "ctarjeta_visa_transacciones_delta2"
# [125] "mtarjeta_visa_consumo_delta1"       "mtarjeta_visa_consumo_delta2"
# [127] "mtarjeta_master_consumo_delta1"     "mtarjeta_master_consumo_delta2"
# [129] "mprestamos_personales_delta1"       "mprestamos_personales_delta2"
# [131] "cpayroll_trx_delta1"                "cpayroll_trx_delta2"
# [133] "mpayroll_delta1"                    "mpayroll_delta2"
# [135] "ccomisiones_mantenimiento_delta1"   "ccomisiones_mantenimiento_delta2"
# [137] "ccallcenter_transacciones_delta1"   "ccallcenter_transacciones_delta2"
# [139] "chomebanking_transacciones_delta1"  "chomebanking_transacciones_delta2"
# [141] "ctrx_quarter_delta1"                "ctrx_quarter_delta2"
# [143] "Master_status_delta1"               "Master_status_delta2"
# [145] "Master_fechaalta_delta1"            "Master_fechaalta_delta2"
# [147] "Master_mpagominimo_delta1"          "Master_mpagominimo_delta2"
# [149] "Visa_status_delta1"                 "Visa_status_delta2"
# [151] "Visa_fechaalta_delta1"              "Visa_fechaalta_delta2"
# [153] "Visa_mpagominimo_delta1"            "Visa_mpagominimo_delta2"
# [155] "kmes_delta1"                        "kmes_delta2"
# [157] "mpayroll_sobre_edad_delta1"         "mpayroll_sobre_edad_delta2"

# %% [markdown]
# #### 6.3.1.6  FEhist Reduccion dimensionalidad con canaritos
#
# Esta etapa solo se mostrará a la *modalidad Anlista Sr* por algun canal secreto de forma de no confundir a los *Analista Jr*  nni distraer con detalles operativos a la estratégica *Modalidad Gerencial*

# %%
# No se implementa la reduccion de la dimensionalidad con canaritos

# %% [markdown]
# ### 6.3.2 Modelado

# %% [markdown]
# #### 6.3.2.1 Training Strategy
#
# Esta etapa de Workflow de  Training Strategy esta pensada para la *Modalidad Gerencial* que posee el dataset de [202005, 202109]
# <br> Si usted es un Analista, posee el periodo de [201901, 202109] y deberá experimentar en que meses le conviene experimentar
#
# <br> A la *Modalidad Gerencial* no se le complicada la vida con el undersampling de los continua, por eso PARAM$trainingstrategy$training_pct <- 1.0
# <br> Sin embargo, si usted es  *Analista SR* posee un dataset 50 veces ( filas x columnas) más grande que la *Modalidad Gerencial*  y por un tema de velocidad y experimentación más rápida puede llegar a necesitar activar el undersampling de la clase mayoritaria, a pesar de estar corriendo en Google Cloud.

# %% [markdown]
# Se hace una estrategia de entrenamiento muy sencilla, tomando todos los meses posibles, SIN eliminar nada x pandemia ni por ningun otro motivo
#
# * future = 202107  obviamente completo
#
# * final_train =  [ 202005, 202105 ]  SIN undersampling
#
# * training
#    * testing = NO HAY
#    * validation =  202105   completo, sin undersampling
#    * training = [ 202005, 202104 ]  donde se consideran el 100% de los CONTINUA

# %%
PARAM$trainingstrategy$validate <- c(202105)

PARAM$trainingstrategy$training <- c(
  202104, 202103, 202102, 202101,
  202012, 202011, 202010, 202009, 202008, 202007,
  202006, 202005
)

PARAM$trainingstrategy$training_pct <- 1.0


PARAM$trainingstrategy$positivos <- c( "BAJA+1", "BAJA+2")

# %%
# seteo la clase01   1={BAJA+1, BAJA+2}   0={CONTINUA}
dataset[, clase01 := ifelse( clase_ternaria %in% PARAM$trainingstrategy$positivos, 1, 0 )]

# %%
# los campos en los que se entrena
campos_buenos <- copy( setdiff(
    colnames(dataset), c("clase_ternaria","clase01","azar"))
)

# %%
# preparo para que se puede hacer undersampling de los CONTINUA
#  solamente por un tema de VELOCIDAD
set.seed(PARAM$semilla_primigenia, kind = "L'Ecuyer-CMRG")
dataset[, azar:=runif(nrow(dataset))]

# undersampling de los CONTINUA
dataset[, fold_train :=  foto_mes %in%  PARAM$trainingstrategy$training &
    (clase_ternaria %in% c("BAJA+1", "BAJA+2") |
     azar < PARAM$trainingstrategy$training_pct ) ]


if( !require("lightgbm")) install.packages("lightgbm")
require("lightgbm")

dtrain <- lgb.Dataset(
  data= data.matrix(dataset[fold_train == TRUE, campos_buenos, with = FALSE]),
  label= dataset[fold_train == TRUE, clase01],
  free_raw_data= TRUE
)
# Out:
# Loading required package: lightgbm
#
# Warning message in library(package, lib.loc = lib.loc, character.only = TRUE, logical.return = TRUE, :
# “there is no package called ‘lightgbm’”
# Installing package into ‘/usr/local/lib/R/site-library’
# (as ‘lib’ is unspecified)
#
# Loading required package: lightgbm

# %%
# datos de validation
dvalidate <- lgb.Dataset(
  data= data.matrix(dataset[foto_mes %in% PARAM$trainingstrategy$validate, campos_buenos, with = FALSE]),
  label= dataset[foto_mes %in% PARAM$trainingstrategy$validate, clase01],
  free_raw_data= TRUE
)

nrow(dvalidate)
# Out:
# [1] 16469

# %% [markdown]
# ####  6.3.2.2. Hyperparameter Tuning

# %% [markdown]
# * Clase binaria que se optimiza :  positivos = [ BAJA+1, BAJA+2 ]

# %% [markdown]
# * Metrica que se optimiza **AUC** Area Under Curve de la  ROC Curve
#
# es muy importante notar que intencionalmente  **NO** se está optimizando la funcion de ganancia del problema

# %% [markdown]
# * Cantidad de iteraciones inteligentes de la Optimizacion Bayesiana = **10**

# %% [markdown]
# * Parametros no default, fijos de LightGBM que no se optimizan
#   * max_bin = 31 , Alienigenas Ancestrales contruyeron las pirámides y dejaron a la humanidad en un jeroglifico  *max_bin=31*
#   * feature_fraction = 0.5  para poner algo que generalmente no falla
#   * learning_rate = 0.03  para que aprenda lento

# %% [markdown]
# * Parametros que se optimizan en la Bayesian Optimization
#   * num_leaves  [8, 256]
#   * min_data_in_leaf  [8, 8192]

# %%
# paquetes necesarios para la Bayesian Optimization
if(!require("DiceKriging")) install.packages("DiceKriging")
require("DiceKriging")

if(!require("mlrMBO")) install.packages("mlrMBO")
require("mlrMBO")
# Out:
# Loading required package: DiceKriging
#
# Warning message in library(package, lib.loc = lib.loc, character.only = TRUE, logical.return = TRUE, :
# “there is no package called ‘DiceKriging’”
# Installing package into ‘/usr/local/lib/R/site-library’
# (as ‘lib’ is unspecified)
#
# Loading required package: DiceKriging
#
# Loading required package: mlrMBO
#
# Warning message in library(package, lib.loc = lib.loc, character.only = TRUE, logical.return = TRUE, :
# “there is no package called ‘mlrMBO’”
# Installing package into ‘/usr/local/lib/R/site-library’
# (as ‘lib’ is unspecified)
#
# also installing the dependencies ‘XML’, ‘fastmatch’, ‘RcppArmadillo’, ‘mlr’, ‘ParamHelpers’, ‘smoof’, ‘BBmisc’, ‘checkmate’, ‘lhs’, ‘parallelMap’
#
#
# Loading required package: mlrMBO
#
# Loading required package: mlr
#
# Loading required package: ParamHelpers
#
#
# Attaching package: ‘ParamHelpers’
#
#
# The following object is masked from ‘package:R.utils’:
#
#     isVector
#
#
#
# Attaching package: ‘mlr’
#
#
# The following objects are masked from ‘package:R.utils’:
#
#     resample, setThreshold
#
#
# Loading required package: smoof
#
# Loading required package: checkmate
#
#
# Attaching package: ‘checkmate’
#
#
# The following object is masked from ‘package:DiceKriging’:
#
#     checkNames
#
#
# The following object is masked from ‘package:R.utils’:
#
#     asInt
#
#
#
# Attaching package: ‘smoof’
#
#
# The following objects are masked from ‘package:R.oo’:
#
#     getDescription, getName

# %% [markdown]
# Definición de la Bayesian Optimization
# <br> Si se desea optimizar un hiperparámetro que esta como fijo, debe QUITARSE de param_fijos y agregarse a PARAM$hipeparametertuning$hs

# %%
# valor ridiculamente bajo para que corra rapido en el aula y no molestar a la *Modalidad Gerencial*
PARAM$hipeparametertuning$num_interations <- 80

# parametros fijos del LightGBM
PARAM$lgbm$param_fijos <- list(
  objective= "binary",
  metric= "auc",
  first_metric_only= TRUE,
  boost_from_average= TRUE,
  feature_pre_filter= FALSE,
  verbosity= -100,
  force_row_wise= TRUE, # para evitar warning
  max_bin= 31,
  seed= PARAM$semilla_primigenia
  # learning_rate= 0.03,
  # feature_fraction= 0.5,
  # num_iterations= 2048,  # valor grande, lo limita early_stopping_rounds
  # early_stopping_rounds= 200
)


PARAM$hipeparametertuning$hs <- makeParamSet(
  # Núcleo del modelo (estructura de árboles)
  makeIntegerParam("num_leaves", lower = 2L, upper = 8192L),
  #makeIntegerParam("max_depth", lower = 3L, upper = 30L),
  makeNumericParam("min_child_weight", lower = 0.001, upper = 10.0),
  makeIntegerParam("min_data_in_leaf", lower = 2L, upper = 8192L),
  #makeNumericParam("min_gain_to_split", lower = 0.0, upper = 0.1),

  # Regularización
  #makeNumericParam("lambda_l1", lower = 0.0, upper = 1000L),
  makeNumericParam("lambda_l2", lower = 0.0, upper = 1000L),
  #makeNumericParam("scale_pos_weight", lower = 1.0, upper = 5.0),  # útil en desequilibrio

  # Control del aprendizaje
  makeNumericParam("learning_rate", lower = 0.005, upper = 0.1),
  makeIntegerParam("num_iterations", lower = 100L, upper = 5000L),
  #makeIntegerParam("early_stopping_rounds", lower = 50L, upper = 500L),

  # Submuestreo
  makeNumericParam("feature_fraction", lower = 0.05, upper = 1L),   # columnas
  makeNumericParam("bagging_fraction", lower = 0.5, upper = 1L)   # filas
  #makeIntegerParam("bagging_freq", lower = 0L, upper = 5L),         # cada N iteraciones

  # Opcionales útiles
  #makeNumericParam("max_delta_step", lower = 0.0, upper = 10.0),
  #makeNumericParam("path_smooth", lower = 0.0, upper = 10.0)
)
# Total: 8 hT

# %% [markdown]
# Función "señora caja negra"  que es llamada para verificar la realidad por la Bayesian Optimization

# %%
# En  x llegan los parmaetros de la bayesiana
#  devuelve la AUC en validate del modelo entrenado
#  en el parametro x llegan los hiperparámetros que se estan optimizando

EstimarGanancia_AUC_lightgbm <- function(x) {

  # x pisa (o agrega) a param_fijos
  param_completo <- modifyList(PARAM$lgbm$param_fijos, x)

  # entreno LightGBM
  modelo_train <- lgb.train(
    data= dtrain,
    valids= list(valid = dvalidate),
    eval= "auc",
    param= param_completo,
    verbose= -100
  )

  # recupero la AUC en validation
  AUC <- modelo_train$record_evals$valid$auc$eval[[modelo_train$best_iter]]

  # esta es la forma de devolver un parametro extra
  attr(AUC, "extras") <- list("num_iterations"= modelo_train$best_iter)

  # hago espacio en la memoria
  rm(modelo_train)
  gc(full= TRUE, verbose= FALSE)

  message(format(Sys.time(), "%a %b %d %X %Y"), " AUC ", AUC)

  return(AUC)
}

# %% [markdown]
# seteo de la Bayesian Optimization (complejo)
# <br> copiado y pegado de la documentación de la librería

# %%
configureMlr(show.learner.output = FALSE)

# configuro la busqueda bayesiana,  los hiperparametros que se van a optimizar
# por favor, no desesperarse por lo complejo
obj.fun <- makeSingleObjectiveFunction(
    fn= EstimarGanancia_AUC_lightgbm, # la funcion que voy a maximizar
    minimize= FALSE, # estoy Maximizando AUC
    noisy= FALSE,
    par.set= PARAM$hipeparametertuning$hs,
    has.simple.signature= FALSE # paso los parametros en una lista
)

# cada 600 segundos guardo el resultado intermedio
ctrl <- makeMBOControl(
    save.on.disk.at.time= 600,
    save.file.path= "HT.RDATA"
)

# indico la cantidad de iteraciones que va a tener la Bayesian Optimization
ctrl <- setMBOControlTermination(
    ctrl,
    iters= PARAM$hipeparametertuning$num_interations  # cantidad de iteraciones inteligentes
)

# defino el método estandar para la creacion de los puntos iniciales
#   los "No Inteligentes"
ctrl <- setMBOControlInfill(ctrl, crit = makeMBOInfillCritEI())

# mas configuraciones
surr.km <- makeLearner(
    "regr.km",
    predict.type= "se",
    covtype= "matern3_2",
    control= list(trace = TRUE)
)

# %% [markdown]
# Corrida de la Bayesian Optimization,  aqui se hace el trabajo pesado
# <br> por favor no se asuste con los warnings que pudieran aparecer
#
# Si corrío a medias y llegó a las iteraciones inteligentes, en el archivo binario HT.RDATA quedó lo ya procesado y es utilizado para retomar la corrida desde lo último que llegó a grabar.

# %%
# inicio la optimizacion bayesiana

if (!file.exists("HT.RDATA")) {
  bayesiana_salida <- mbo(obj.fun, learner= surr.km, control= ctrl)
} else {
  bayesiana_salida <- mboContinue("HT.RDATA") # retomo en caso que ya exista
}
# Out:
# Computing y column(s) for design. Not provided.
#
# Wed Nov 19 03:04:11 AM 2025 AUC 0.911463733308101
#
# Wed Nov 19 03:11:05 AM 2025 AUC 0.919162860051444
#
# Wed Nov 19 03:19:38 AM 2025 AUC 0.916401092761962
#
# Wed Nov 19 03:23:59 AM 2025 AUC 0.925435302975703
#
# Wed Nov 19 03:31:02 AM 2025 AUC 0.915647486962888
#
# Wed Nov 19 03:37:58 AM 2025 AUC 0.923793542880036
#
# Wed Nov 19 03:45:20 AM 2025 AUC 0.916161858151659
#
# Wed Nov 19 03:50:48 AM 2025 AUC 0.92227928510122
#
# Wed Nov 19 04:00:52 AM 2025 AUC 0.916454106883179
#
# Wed Nov 19 04:08:40 AM 2025 AUC 0.913215212502743
#
# Wed Nov 19 04:11:30 AM 2025 AUC 0.916706762789992
#
# Wed Nov 19 04:17:57 AM 2025 AUC 0.918712911085924
#
# Wed Nov 19 04:25:58 AM 2025 AUC 0.914950921673985
#
# Wed Nov 19 04:30:03 AM 2025 AUC 0.919296737484138
#
# Wed Nov 19 04:33:50 AM 2025 AUC 0.928820825020518
#
# Wed Nov 19 04:35:05 AM 2025 AUC 0.889079359455203
#
# Wed Nov 19 04:38:00 AM 2025 AUC 0.90660388184159
#
# Wed Nov 19 04:43:37 AM 2025 AUC 0.918867927060622
#
# Wed Nov 19 04:47:59 AM 2025 AUC 0.911459371386735
#
# Wed Nov 19 04:51:54 AM 2025 AUC 0.914610691807439
#
# Wed Nov 19 04:59:20 AM 2025 AUC 0.917022834322818
#
# Wed Nov 19 05:00:42 AM 2025 AUC 0.917108059555661
#
# Wed Nov 19 05:01:26 AM 2025 AUC 0.914258382774034
#
# Wed Nov 19 05:02:40 AM 2025 AUC 0.920666380793051
#
# Wed Nov 19 05:03:23 AM 2025 AUC 0.904825224521514
#
# Wed Nov 19 05:10:17 AM 2025 AUC 0.913586646883676
#
# Wed Nov 19 05:22:36 AM 2025 AUC 0.926269101021428
#
# Wed Nov 19 05:29:11 AM 2025 AUC 0.915301553045326
#
# Wed Nov 19 05:33:14 AM 2025 AUC 0.926000339558802
#
# Wed Nov 19 05:37:42 AM 2025 AUC 0.916661130381856
#
# Wed Nov 19 05:38:04 AM 2025 AUC 0.908611372267172
#
# Wed Nov 19 05:46:22 AM 2025 AUC 0.915301888577739
#
# [mbo] 0: num_leaves=4924; min_child_weight=8.77; min_data_in_leaf=4176; lambda_l2=243; learning_rate=0.0242; num_iterations=1256; feature_fraction=0.868; bagging_fraction=0.68 : y = 0.911 : 138.0 secs : initdesign
#
# [mbo] 0: num_leaves=1053; min_child_weight=5.58; min_data_in_leaf=3277; lambda_l2=319; learning_rate=0.0389; num_iterations=2584; feature_fraction=0.589; bagging_fraction=0.634 : y = 0.919 : 413.7 secs : initdesign
#
# [mbo] 0: num_leaves=3384; min_child_weight=7.21; min_data_in_leaf=6659; lambda_l2=649; learning_rate=0.0448; num_iterations=3454; feature_fraction=0.469; bagging_fraction=0.615 : y = 0.916 : 513.1 secs : initdesign
#
# [mbo] 0: num_leaves=1411; min_child_weight=6.56; min_data_in_leaf=5271; lambda_l2=67.4; learning_rate=0.0623; num_iterations=2192; feature_fraction=0.28; bagging_fraction=0.868 : y = 0.925 : 261.5 secs : initdesign
#
# [mbo] 0: num_leaves=7562; min_child_weight=2.76; min_data_in_leaf=4387; lambda_l2=599; learning_rate=0.0291; num_iterations=3885; feature_fraction=0.634; bagging_fraction=0.77 : y = 0.916 : 422.8 secs : initdesign
#
# [mbo] 0: num_leaves=6434; min_child_weight=4.5; min_data_in_leaf=3688; lambda_l2=299; learning_rate=0.0659; num_iterations=3286; feature_fraction=0.308; bagging_fraction=0.72 : y = 0.924 : 415.9 secs : initdesign
#
# [mbo] 0: num_leaves=3919; min_child_weight=6.66; min_data_in_leaf=5994; lambda_l2=975; learning_rate=0.0417; num_iterations=4192; feature_fraction=0.227; bagging_fraction=0.718 : y = 0.916 : 442.2 secs : initdesign
#
# [mbo] 0: num_leaves=2463; min_child_weight=5.71; min_data_in_leaf=1155; lambda_l2=276; learning_rate=0.0764; num_iterations=2451; feature_fraction=0.666; bagging_fraction=0.835 : y = 0.922 : 327.6 secs : initdesign
#
# [mbo] 0: num_leaves=3770; min_child_weight=3.57; min_data_in_leaf=5486; lambda_l2=412; learning_rate=0.0613; num_iterations=3581; feature_fraction=0.554; bagging_fraction=0.955 : y = 0.916 : 604.2 secs : initdesign
#
# [mbo] 0: num_leaves=1895; min_child_weight=4.06; min_data_in_leaf=3581; lambda_l2=477; learning_rate=0.00983; num_iterations=4544; feature_fraction=0.74; bagging_fraction=0.799 : y = 0.913 : 467.7 secs : initdesign
#
# [mbo] 0: num_leaves=6001; min_child_weight=8.48; min_data_in_leaf=5704; lambda_l2=111; learning_rate=0.0493; num_iterations=1566; feature_fraction=0.816; bagging_fraction=0.661 : y = 0.917 : 170.7 secs : initdesign
#
# [mbo] 0: num_leaves=3237; min_child_weight=9.25; min_data_in_leaf=1438; lambda_l2=896; learning_rate=0.0993; num_iterations=3099; feature_fraction=0.851; bagging_fraction=0.753 : y = 0.919 : 386.8 secs : initdesign
#
# [mbo] 0: num_leaves=7939; min_child_weight=7.51; min_data_in_leaf=4983; lambda_l2=563; learning_rate=0.0376; num_iterations=2978; feature_fraction=0.519; bagging_fraction=0.53 : y = 0.915 : 480.7 secs : initdesign
#
# [mbo] 0: num_leaves=2230; min_child_weight=4.99; min_data_in_leaf=3959; lambda_l2=752; learning_rate=0.0839; num_iterations=2265; feature_fraction=0.229; bagging_fraction=0.746 : y = 0.919 : 245.2 secs : initdesign
#
# [mbo] 0: num_leaves=5290; min_child_weight=2.02; min_data_in_leaf=2178; lambda_l2=0.477; learning_rate=0.0512; num_iterations=1373; feature_fraction=0.438; bagging_fraction=0.818 : y = 0.929 : 226.3 secs : initdesign
#
# [mbo] 0: num_leaves=890; min_child_weight=1.54; min_data_in_leaf=7790; lambda_l2=401; learning_rate=0.0058; num_iterations=650; feature_fraction=0.349; bagging_fraction=0.698 : y = 0.889 : 75.1 secs : initdesign
#
# [mbo] 0: num_leaves=5592; min_child_weight=7.85; min_data_in_leaf=6488; lambda_l2=966; learning_rate=0.0183; num_iterations=1156; feature_fraction=0.562; bagging_fraction=0.925 : y = 0.907 : 175.4 secs : initdesign
#
# [mbo] 0: num_leaves=6153; min_child_weight=5.19; min_data_in_leaf=8180; lambda_l2=745; learning_rate=0.0757; num_iterations=4774; feature_fraction=0.0527; bagging_fraction=0.982 : y = 0.919 : 337.5 secs : initdesign
#
# [mbo] 0: num_leaves=4623; min_child_weight=4.05; min_data_in_leaf=6158; lambda_l2=540; learning_rate=0.015; num_iterations=2779; feature_fraction=0.956; bagging_fraction=0.647 : y = 0.911 : 261.7 secs : initdesign
#
# [mbo] 0: num_leaves=7337; min_child_weight=0.304; min_data_in_leaf=2545; lambda_l2=524; learning_rate=0.0284; num_iterations=1794; feature_fraction=0.34; bagging_fraction=0.546 : y = 0.915 : 234.4 secs : initdesign
#
# [mbo] 0: num_leaves=1558; min_child_weight=6.2; min_data_in_leaf=7303; lambda_l2=701; learning_rate=0.094; num_iterations=4494; feature_fraction=0.767; bagging_fraction=0.995 : y = 0.917 : 446.7 secs : initdesign
#
# [mbo] 0: num_leaves=7067; min_child_weight=6.98; min_data_in_leaf=1626; lambda_l2=677; learning_rate=0.0899; num_iterations=894; feature_fraction=0.121; bagging_fraction=0.943 : y = 0.917 : 81.5 secs : initdesign
#
# [mbo] 0: num_leaves=172; min_child_weight=8.29; min_data_in_leaf=2857; lambda_l2=135; learning_rate=0.0583; num_iterations=394; feature_fraction=0.716; bagging_fraction=0.565 : y = 0.914 : 44.0 secs : initdesign
#
# [mbo] 0: num_leaves=598; min_child_weight=1.58; min_data_in_leaf=41; lambda_l2=364; learning_rate=0.0942; num_iterations=803; feature_fraction=0.107; bagging_fraction=0.904 : y = 0.921 : 73.9 secs : initdesign
#
# [mbo] 0: num_leaves=4282; min_child_weight=9.66; min_data_in_leaf=281; lambda_l2=910; learning_rate=0.0319; num_iterations=451; feature_fraction=0.909; bagging_fraction=0.609 : y = 0.905 : 43.1 secs : initdesign
#
# [mbo] 0: num_leaves=2751; min_child_weight=0.339; min_data_in_leaf=2023; lambda_l2=861; learning_rate=0.0134; num_iterations=4304; feature_fraction=0.169; bagging_fraction=0.848 : y = 0.914 : 414.3 secs : initdesign
#
# [mbo] 0: num_leaves=2859; min_child_weight=2.23; min_data_in_leaf=2736; lambda_l2=160; learning_rate=0.0537; num_iterations=4934; feature_fraction=0.407; bagging_fraction=0.585 : y = 0.926 : 738.8 secs : initdesign
#
# [mbo] 0: num_leaves=5754; min_child_weight=1.18; min_data_in_leaf=7433; lambda_l2=829; learning_rate=0.0818; num_iterations=4014; feature_fraction=0.69; bagging_fraction=0.515 : y = 0.915 : 395.7 secs : initdesign
#
# [mbo] 0: num_leaves=7849; min_child_weight=3.33; min_data_in_leaf=1009; lambda_l2=41.7; learning_rate=0.0856; num_iterations=1662; feature_fraction=0.911; bagging_fraction=0.56 : y = 0.926 : 242.6 secs : initdesign
#
# [mbo] 0: num_leaves=346; min_child_weight=3.01; min_data_in_leaf=559; lambda_l2=791; learning_rate=0.0696; num_iterations=2027; feature_fraction=0.981; bagging_fraction=0.882 : y = 0.917 : 267.8 secs : initdesign
#
# [mbo] 0: num_leaves=6886; min_child_weight=0.688; min_data_in_leaf=6997; lambda_l2=208; learning_rate=0.0707; num_iterations=218; feature_fraction=0.176; bagging_fraction=0.911 : y = 0.909 : 22.5 secs : initdesign
#
# [mbo] 0: num_leaves=4489; min_child_weight=9.77; min_data_in_leaf=4786; lambda_l2=458; learning_rate=0.0199; num_iterations=3658; feature_fraction=0.396; bagging_fraction=0.794 : y = 0.915 : 497.4 secs : initdesign
#
# Saved the current state after iteration 1 in the file HT.RDATA.
#
# Wed Nov 19 05:49:48 AM 2025 AUC 0.928552399090305
#
# [mbo] 1: num_leaves=4758; min_child_weight=2.73; min_data_in_leaf=2347; lambda_l2=0.37; learning_rate=0.0764; num_iterations=2192; feature_fraction=0.121; bagging_fraction=0.765 : y = 0.929 : 205.5 secs : infill_ei
#
# Wed Nov 19 05:56:34 AM 2025 AUC 0.931316179574263
#
# [mbo] 2: num_leaves=5391; min_child_weight=3.27; min_data_in_leaf=55; lambda_l2=0.351; learning_rate=0.051; num_iterations=3285; feature_fraction=0.285; bagging_fraction=0.771 : y = 0.931 : 405.3 secs : infill_ei
#
# Saved the current state after iteration 3 in the file HT.RDATA.
#
# Wed Nov 19 06:01:19 AM 2025 AUC 0.935990146084102
#
# [mbo] 3: num_leaves=1186; min_child_weight=5.6; min_data_in_leaf=904; lambda_l2=0.344; learning_rate=0.0577; num_iterations=3196; feature_fraction=0.108; bagging_fraction=0.801 : y = 0.936 : 284.3 secs : infill_ei
#
# Wed Nov 19 06:06:48 AM 2025 AUC 0.93016966531984
#
# [mbo] 4: num_leaves=1375; min_child_weight=6.12; min_data_in_leaf=1869; lambda_l2=2.78; learning_rate=0.0557; num_iterations=4257; feature_fraction=0.0556; bagging_fraction=0.963 : y = 0.93 : 328.8 secs : infill_ei
#
# Saved the current state after iteration 5 in the file HT.RDATA.
#
# Wed Nov 19 06:10:44 AM 2025 AUC 0.933013973582862
#
# [mbo] 5: num_leaves=1091; min_child_weight=2.7; min_data_in_leaf=138; lambda_l2=0.0112; learning_rate=0.0579; num_iterations=3056; feature_fraction=0.0518; bagging_fraction=0.621 : y = 0.933 : 235.3 secs : infill_ei
#
# Wed Nov 19 06:15:52 AM 2025 AUC 0.928792975830258
#
# [mbo] 6: num_leaves=270; min_child_weight=6.92; min_data_in_leaf=355; lambda_l2=0.0469; learning_rate=0.0588; num_iterations=3793; feature_fraction=0.0804; bagging_fraction=0.691 : y = 0.929 : 306.9 secs : infill_ei
#
# Wed Nov 19 06:19:58 AM 2025 AUC 0.931649698792553
#
# [mbo] 7: num_leaves=1961; min_child_weight=5.41; min_data_in_leaf=109; lambda_l2=2.14; learning_rate=0.053; num_iterations=2623; feature_fraction=0.121; bagging_fraction=0.846 : y = 0.932 : 245.2 secs : infill_ei
#
# Saved the current state after iteration 8 in the file HT.RDATA.
#
# Wed Nov 19 06:24:11 AM 2025 AUC 0.930967561397399
#
# [mbo] 8: num_leaves=842; min_child_weight=2.66; min_data_in_leaf=1811; lambda_l2=1.8; learning_rate=0.0592; num_iterations=3241; feature_fraction=0.0517; bagging_fraction=0.803 : y = 0.931 : 252.8 secs : infill_ei
#
# Wed Nov 19 06:30:10 AM 2025 AUC 0.927541775463051
#
# [mbo] 9: num_leaves=1368; min_child_weight=4.79; min_data_in_leaf=1230; lambda_l2=0.65; learning_rate=0.0599; num_iterations=3335; feature_fraction=0.205; bagging_fraction=0.577 : y = 0.928 : 358.0 secs : infill_ei
#
# Saved the current state after iteration 10 in the file HT.RDATA.
#
# Wed Nov 19 06:35:21 AM 2025 AUC 0.930495467292636
#
# [mbo] 10: num_leaves=5410; min_child_weight=1.36; min_data_in_leaf=452; lambda_l2=0.531; learning_rate=0.0574; num_iterations=2313; feature_fraction=0.619; bagging_fraction=0.635 : y = 0.93 : 310.9 secs : infill_ei
#
# Wed Nov 19 06:38:20 AM 2025 AUC 0.930808183501334
#
# [mbo] 11: num_leaves=2196; min_child_weight=5.04; min_data_in_leaf=1019; lambda_l2=1.72; learning_rate=0.0561; num_iterations=2264; feature_fraction=0.0526; bagging_fraction=0.773 : y = 0.931 : 177.5 secs : infill_ei
#
# Wed Nov 19 06:44:09 AM 2025 AUC 0.931478241729629
#
# [mbo] 12: num_leaves=650; min_child_weight=5.67; min_data_in_leaf=819; lambda_l2=1.64; learning_rate=0.0595; num_iterations=4573; feature_fraction=0.0573; bagging_fraction=0.795 : y = 0.931 : 348.3 secs : infill_ei
#
# Saved the current state after iteration 13 in the file HT.RDATA.
#
# Wed Nov 19 06:49:37 AM 2025 AUC 0.930360247730291
#
# [mbo] 13: num_leaves=1097; min_child_weight=5.77; min_data_in_leaf=67; lambda_l2=2.37; learning_rate=0.0948; num_iterations=3284; feature_fraction=0.178; bagging_fraction=0.802 : y = 0.93 : 327.6 secs : infill_ei
#
# Wed Nov 19 06:55:15 AM 2025 AUC 0.930558211853823
#
# [mbo] 14: num_leaves=4547; min_child_weight=5.91; min_data_in_leaf=1252; lambda_l2=0.156; learning_rate=0.0604; num_iterations=2971; feature_fraction=0.232; bagging_fraction=0.763 : y = 0.931 : 336.2 secs : infill_ei
#
# Saved the current state after iteration 15 in the file HT.RDATA.
#
# Wed Nov 19 07:00:29 AM 2025 AUC 0.928316855336542
#
# [mbo] 15: num_leaves=1207; min_child_weight=9.28; min_data_in_leaf=1718; lambda_l2=32; learning_rate=0.0585; num_iterations=3157; feature_fraction=0.155; bagging_fraction=0.839 : y = 0.928 : 313.5 secs : infill_ei
#
# Wed Nov 19 07:14:13 AM 2025 AUC 0.931965434792966
#
# [mbo] 16: num_leaves=5932; min_child_weight=0.0354; min_data_in_leaf=2; lambda_l2=0.0384; learning_rate=0.0759; num_iterations=4973; feature_fraction=0.523; bagging_fraction=0.725 : y = 0.932 : 822.6 secs : infill_ei
#
# Saved the current state after iteration 17 in the file HT.RDATA.
#
# Wed Nov 19 07:22:18 AM 2025 AUC 0.934252423718384
#
# [mbo] 17: num_leaves=6524; min_child_weight=0.8; min_data_in_leaf=8; lambda_l2=33.1; learning_rate=0.075; num_iterations=4062; feature_fraction=0.187; bagging_fraction=0.605 : y = 0.934 : 484.9 secs : infill_ei
#
# Wed Nov 19 07:28:31 AM 2025 AUC 0.931220552836625
#
# [mbo] 18: num_leaves=924; min_child_weight=1.98; min_data_in_leaf=609; lambda_l2=1.71; learning_rate=0.0637; num_iterations=3490; feature_fraction=0.188; bagging_fraction=0.734 : y = 0.931 : 372.0 secs : infill_ei
#
# Saved the current state after iteration 19 in the file HT.RDATA.
#
# Wed Nov 19 07:36:14 AM 2025 AUC 0.937954017296025
#
# [mbo] 19: num_leaves=7890; min_child_weight=1.39; min_data_in_leaf=4; lambda_l2=4.4; learning_rate=0.0727; num_iterations=5000; feature_fraction=0.107; bagging_fraction=0.625 : y = 0.938 : 462.8 secs : infill_ei
#
# Wed Nov 19 07:42:50 AM 2025 AUC 0.933501166646199
#
# [mbo] 20: num_leaves=8159; min_child_weight=1.88; min_data_in_leaf=608; lambda_l2=1.08; learning_rate=0.057; num_iterations=4186; feature_fraction=0.12; bagging_fraction=0.638 : y = 0.934 : 394.8 secs : infill_ei
#
# Saved the current state after iteration 21 in the file HT.RDATA.
#
# Wed Nov 19 07:49:47 AM 2025 AUC 0.931201091956684
#
# [mbo] 21: num_leaves=6890; min_child_weight=2.09; min_data_in_leaf=4; lambda_l2=251; learning_rate=0.0795; num_iterations=4989; feature_fraction=0.0579; bagging_fraction=0.602 : y = 0.931 : 416.5 secs : infill_ei
#
# Wed Nov 19 08:00:23 AM 2025 AUC 0.936543103500341
#
# [mbo] 22: num_leaves=8102; min_child_weight=0.61; min_data_in_leaf=140; lambda_l2=2.62; learning_rate=0.066; num_iterations=4994; feature_fraction=0.676; bagging_fraction=0.531 : y = 0.937 : 634.3 secs : infill_ei
#
# Saved the current state after iteration 23 in the file HT.RDATA.
#
# Wed Nov 19 08:09:12 AM 2025 AUC 0.938512007698456
#
# [mbo] 23: num_leaves=7504; min_child_weight=0.87; min_data_in_leaf=56; lambda_l2=2.9; learning_rate=0.0409; num_iterations=4995; feature_fraction=0.144; bagging_fraction=0.539 : y = 0.939 : 528.5 secs : infill_ei
#
# Wed Nov 19 08:21:19 AM 2025 AUC 0.93187618317117
#
# [mbo] 24: num_leaves=7738; min_child_weight=1.19; min_data_in_leaf=2034; lambda_l2=0.357; learning_rate=0.0798; num_iterations=4992; feature_fraction=0.418; bagging_fraction=0.587 : y = 0.932 : 726.4 secs : infill_ei
#
# Saved the current state after iteration 25 in the file HT.RDATA.
#
# Wed Nov 19 08:23:03 AM 2025 AUC 0.933378026250714
#
# [mbo] 25: num_leaves=7666; min_child_weight=1.58; min_data_in_leaf=45; lambda_l2=1.49; learning_rate=0.0648; num_iterations=632; feature_fraction=0.894; bagging_fraction=0.984 : y = 0.933 : 103.6 secs : infill_ei
#
# Wed Nov 19 08:31:13 AM 2025 AUC 0.930628673660504
#
# [mbo] 26: num_leaves=8173; min_child_weight=0.0382; min_data_in_leaf=5; lambda_l2=1.98; learning_rate=0.0527; num_iterations=2205; feature_fraction=0.529; bagging_fraction=0.979 : y = 0.931 : 489.1 secs : infill_ei
#
# Wed Nov 19 08:35:57 AM 2025 AUC 0.930665582225909
#
# [mbo] 27: num_leaves=8070; min_child_weight=0.374; min_data_in_leaf=324; lambda_l2=6.44; learning_rate=0.0812; num_iterations=1743; feature_fraction=1; bagging_fraction=0.842 : y = 0.931 : 283.1 secs : infill_ei
#
# Saved the current state after iteration 28 in the file HT.RDATA.
#
# Wed Nov 19 08:46:57 AM 2025 AUC 0.93231271084018
#
# [mbo] 28: num_leaves=6074; min_child_weight=1.18; min_data_in_leaf=2; lambda_l2=2.53; learning_rate=0.0427; num_iterations=4998; feature_fraction=0.297; bagging_fraction=0.585 : y = 0.932 : 658.9 secs : infill_ei
#
# Saved the current state after iteration 29 in the file HT.RDATA.
#
# Wed Nov 19 08:54:58 AM 2025 AUC 0.92324830270929
#
# [mbo] 29: num_leaves=7737; min_child_weight=5.91; min_data_in_leaf=113; lambda_l2=0.192; learning_rate=0.093; num_iterations=4971; feature_fraction=0.848; bagging_fraction=0.978 : y = 0.923 : 479.8 secs : infill_ei
#
# Wed Nov 19 08:55:56 AM 2025 AUC 0.934719484836955
#
# [mbo] 30: num_leaves=5145; min_child_weight=0.212; min_data_in_leaf=4; lambda_l2=2.68; learning_rate=0.0786; num_iterations=483; feature_fraction=0.0872; bagging_fraction=0.563 : y = 0.935 : 56.9 secs : infill_ei
#
# Wed Nov 19 09:05:17 AM 2025 AUC 0.937561779905501
#
# [mbo] 31: num_leaves=8145; min_child_weight=0.0262; min_data_in_leaf=9; lambda_l2=3.73; learning_rate=0.0635; num_iterations=4985; feature_fraction=0.0995; bagging_fraction=0.51 : y = 0.938 : 560.2 secs : infill_ei
#
# Saved the current state after iteration 32 in the file HT.RDATA.
#
# Wed Nov 19 09:05:29 AM 2025 AUC 0.907200794003902
#
# [mbo] 32: num_leaves=6597; min_child_weight=0.92; min_data_in_leaf=14; lambda_l2=84.3; learning_rate=0.0503; num_iterations=113; feature_fraction=0.082; bagging_fraction=0.759 : y = 0.907 : 11.2 secs : infill_ei
#
# Wed Nov 19 09:07:30 AM 2025 AUC 0.926042952175223
#
# [mbo] 33: num_leaves=3947; min_child_weight=0.718; min_data_in_leaf=680; lambda_l2=0.665; learning_rate=0.0955; num_iterations=1383; feature_fraction=0.0609; bagging_fraction=0.535 : y = 0.926 : 120.6 secs : infill_ei
#
# Wed Nov 19 09:14:10 AM 2025 AUC 0.93530834422136
#
# [mbo] 34: num_leaves=7124; min_child_weight=0.0303; min_data_in_leaf=8; lambda_l2=6.95; learning_rate=0.0763; num_iterations=2981; feature_fraction=0.158; bagging_fraction=0.696 : y = 0.935 : 398.9 secs : infill_ei
#
# Wed Nov 19 09:22:58 AM 2025 AUC 0.932188899379869
#
# [mbo] 35: num_leaves=7893; min_child_weight=0.621; min_data_in_leaf=51; lambda_l2=139; learning_rate=0.0315; num_iterations=4980; feature_fraction=0.0939; bagging_fraction=0.501 : y = 0.932 : 527.0 secs : infill_ei
#
# Saved the current state after iteration 36 in the file HT.RDATA.
#
# Wed Nov 19 09:26:07 AM 2025 AUC 0.926525112252369
#
# [mbo] 36: num_leaves=5981; min_child_weight=0.345; min_data_in_leaf=39; lambda_l2=5.51e-05; learning_rate=0.0753; num_iterations=1033; feature_fraction=0.524; bagging_fraction=0.738 : y = 0.927 : 188.5 secs : infill_ei
#
# Wed Nov 19 09:37:09 AM 2025 AUC 0.932832786079968
#
# [mbo] 37: num_leaves=7456; min_child_weight=0.304; min_data_in_leaf=46; lambda_l2=0.554; learning_rate=0.0634; num_iterations=4724; feature_fraction=0.358; bagging_fraction=0.874 : y = 0.933 : 661.7 secs : infill_ei
#
# Saved the current state after iteration 38 in the file HT.RDATA.
#
# Wed Nov 19 09:42:51 AM 2025 AUC 0.933699130769731
#
# [mbo] 38: num_leaves=2618; min_child_weight=1.16; min_data_in_leaf=37; lambda_l2=0.671; learning_rate=0.0802; num_iterations=3070; feature_fraction=0.941; bagging_fraction=0.669 : y = 0.934 : 340.7 secs : infill_ei
#
# Wed Nov 19 09:45:40 AM 2025 AUC 0.932781785153228
#
# [mbo] 39: num_leaves=5102; min_child_weight=4.09; min_data_in_leaf=62; lambda_l2=0.731; learning_rate=0.0551; num_iterations=1322; feature_fraction=0.739; bagging_fraction=0.997 : y = 0.933 : 168.8 secs : infill_ei
#
# Wed Nov 19 10:00:09 AM 2025 AUC 0.926609330887973
#
# [mbo] 40: num_leaves=7370; min_child_weight=0.527; min_data_in_leaf=24; lambda_l2=52.7; learning_rate=0.0587; num_iterations=4922; feature_fraction=0.614; bagging_fraction=0.588 : y = 0.927 : 867.6 secs : infill_ei
#
# Saved the current state after iteration 41 in the file HT.RDATA.
#
# Wed Nov 19 10:08:41 AM 2025 AUC 0.928065206026967
#
# [mbo] 41: num_leaves=7493; min_child_weight=4.94; min_data_in_leaf=4565; lambda_l2=0.284; learning_rate=0.0612; num_iterations=2994; feature_fraction=0.565; bagging_fraction=0.928 : y = 0.928 : 510.8 secs : infill_ei
#
# Wed Nov 19 10:15:10 AM 2025 AUC 0.92548831709692
#
# [mbo] 42: num_leaves=5649; min_child_weight=5.29; min_data_in_leaf=775; lambda_l2=0.934; learning_rate=0.0544; num_iterations=3479; feature_fraction=0.858; bagging_fraction=0.814 : y = 0.925 : 388.4 secs : infill_ei
#
# Saved the current state after iteration 43 in the file HT.RDATA.
#
# Wed Nov 19 10:20:35 AM 2025 AUC 0.938151981419557
#
# [mbo] 43: num_leaves=5025; min_child_weight=0.107; min_data_in_leaf=3; lambda_l2=0.98; learning_rate=0.0734; num_iterations=3289; feature_fraction=0.108; bagging_fraction=0.509 : y = 0.938 : 324.0 secs : infill_ei
#
# Wed Nov 19 10:25:41 AM 2025 AUC 0.934981535651325
#
# [mbo] 44: num_leaves=7131; min_child_weight=2.57; min_data_in_leaf=10; lambda_l2=7.85; learning_rate=0.0683; num_iterations=2949; feature_fraction=0.146; bagging_fraction=0.524 : y = 0.935 : 305.3 secs : infill_ei
#
# Saved the current state after iteration 45 in the file HT.RDATA.
#
# Wed Nov 19 10:33:06 AM 2025 AUC 0.932933445803798
#
# [mbo] 45: num_leaves=5294; min_child_weight=0.443; min_data_in_leaf=11; lambda_l2=0.847; learning_rate=0.0698; num_iterations=4957; feature_fraction=0.101; bagging_fraction=0.534 : y = 0.933 : 443.8 secs : infill_ei
#
# Wed Nov 19 10:42:47 AM 2025 AUC 0.928060508573189
#
# [mbo] 46: num_leaves=8153; min_child_weight=4.03; min_data_in_leaf=620; lambda_l2=151; learning_rate=0.0843; num_iterations=4668; feature_fraction=0.242; bagging_fraction=0.501 : y = 0.928 : 580.4 secs : infill_ei
#
# Saved the current state after iteration 47 in the file HT.RDATA.
#
# Wed Nov 19 10:50:03 AM 2025 AUC 0.930854486974296
#
# [mbo] 47: num_leaves=8165; min_child_weight=0.178; min_data_in_leaf=1385; lambda_l2=0.875; learning_rate=0.0707; num_iterations=3069; feature_fraction=0.952; bagging_fraction=0.728 : y = 0.931 : 435.3 secs : infill_ei
#
# Wed Nov 19 10:55:14 AM 2025 AUC 0.932519398806444
#
# [mbo] 48: num_leaves=2825; min_child_weight=0.0652; min_data_in_leaf=47; lambda_l2=0.234; learning_rate=0.0734; num_iterations=2446; feature_fraction=0.249; bagging_fraction=0.519 : y = 0.933 : 309.3 secs : infill_ei
#
# Saved the current state after iteration 49 in the file HT.RDATA.
#
# Wed Nov 19 11:01:58 AM 2025 AUC 0.923170459189528
#
# [mbo] 49: num_leaves=7822; min_child_weight=2; min_data_in_leaf=3976; lambda_l2=0.382; learning_rate=0.0424; num_iterations=4948; feature_fraction=0.066; bagging_fraction=0.521 : y = 0.923 : 402.6 secs : infill_ei
#
# Wed Nov 19 11:02:22 AM 2025 AUC 0.918214980985378
#
# [mbo] 50: num_leaves=7195; min_child_weight=4.78; min_data_in_leaf=6589; lambda_l2=0.202; learning_rate=0.072; num_iterations=193; feature_fraction=0.944; bagging_fraction=0.993 : y = 0.918 : 23.3 secs : infill_ei
#
# Wed Nov 19 11:12:28 AM 2025 AUC 0.928755396200028
#
# [mbo] 51: num_leaves=5050; min_child_weight=1.01; min_data_in_leaf=39; lambda_l2=22.3; learning_rate=0.0758; num_iterations=4294; feature_fraction=0.766; bagging_fraction=0.511 : y = 0.929 : 604.9 secs : infill_ei
#
# Saved the current state after iteration 52 in the file HT.RDATA.
#
# Wed Nov 19 11:19:44 AM 2025 AUC 0.935338206606096
#
# [mbo] 52: num_leaves=364; min_child_weight=4.61; min_data_in_leaf=536; lambda_l2=0.943; learning_rate=0.0575; num_iterations=2945; feature_fraction=0.411; bagging_fraction=0.998 : y = 0.935 : 435.1 secs : infill_ei
#
# Wed Nov 19 11:25:12 AM 2025 AUC 0.93534223299505
#
# [mbo] 53: num_leaves=8096; min_child_weight=0.773; min_data_in_leaf=2; lambda_l2=2.21; learning_rate=0.0352; num_iterations=3503; feature_fraction=0.0642; bagging_fraction=0.51 : y = 0.935 : 326.3 secs : infill_ei
#
# Saved the current state after iteration 54 in the file HT.RDATA.
#
# Wed Nov 19 11:31:50 AM 2025 AUC 0.937919792989923
#
# [mbo] 54: num_leaves=1529; min_child_weight=0.923; min_data_in_leaf=6; lambda_l2=1.52; learning_rate=0.0387; num_iterations=3986; feature_fraction=0.132; bagging_fraction=0.629 : y = 0.938 : 397.2 secs : infill_ei
#
# Wed Nov 19 11:39:42 AM 2025 AUC 0.933055915134458
#
# [mbo] 55: num_leaves=1181; min_child_weight=2.12; min_data_in_leaf=262; lambda_l2=0.219; learning_rate=0.0401; num_iterations=2970; feature_fraction=0.595; bagging_fraction=0.76 : y = 0.933 : 470.9 secs : infill_ei
#
# Saved the current state after iteration 56 in the file HT.RDATA.
#
# Wed Nov 19 11:45:58 AM 2025 AUC 0.927515939467269
#
# [mbo] 56: num_leaves=1952; min_child_weight=1.59; min_data_in_leaf=521; lambda_l2=0.0834; learning_rate=0.0651; num_iterations=3450; feature_fraction=0.697; bagging_fraction=0.975 : y = 0.928 : 375.8 secs : infill_ei
#
# Wed Nov 19 11:52:28 AM 2025 AUC 0.937196049575585
#
# [mbo] 57: num_leaves=195; min_child_weight=1.04; min_data_in_leaf=133; lambda_l2=2.49; learning_rate=0.0132; num_iterations=3918; feature_fraction=0.0993; bagging_fraction=0.685 : y = 0.937 : 388.6 secs : infill_ei
#
# Saved the current state after iteration 58 in the file HT.RDATA.
#
# Wed Nov 19 11:57:50 AM 2025 AUC 0.939950099619573
#
# [mbo] 58: num_leaves=481; min_child_weight=1.84; min_data_in_leaf=579; lambda_l2=0.127; learning_rate=0.0386; num_iterations=3654; feature_fraction=0.0976; bagging_fraction=0.931 : y = 0.94 : 321.0 secs : infill_ei
#
# Wed Nov 19 12:05:39 PM 2025 AUC 0.936366948983639
#
# [mbo] 59: num_leaves=359; min_child_weight=0.835; min_data_in_leaf=352; lambda_l2=2.63; learning_rate=0.0303; num_iterations=4740; feature_fraction=0.123; bagging_fraction=0.809 : y = 0.936 : 468.4 secs : infill_ei
#
# Saved the current state after iteration 60 in the file HT.RDATA.
#
# Wed Nov 19 12:10:01 PM 2025 AUC 0.92821955093684
#
# [mbo] 60: num_leaves=1068; min_child_weight=4.67; min_data_in_leaf=801; lambda_l2=0.542; learning_rate=0.0354; num_iterations=3257; feature_fraction=0.0524; bagging_fraction=0.849 : y = 0.928 : 260.6 secs : infill_ei
#
# Wed Nov 19 12:16:22 PM 2025 AUC 0.93607235152523
#
# [mbo] 61: num_leaves=1264; min_child_weight=0.526; min_data_in_leaf=48; lambda_l2=0.0537; learning_rate=0.0386; num_iterations=3897; feature_fraction=0.137; bagging_fraction=0.969 : y = 0.936 : 379.7 secs : infill_ei
#
# Saved the current state after iteration 62 in the file HT.RDATA.
#
# Wed Nov 19 12:21:18 PM 2025 AUC 0.934022248483226
#
# [mbo] 62: num_leaves=7896; min_child_weight=5.28; min_data_in_leaf=3; lambda_l2=23.4; learning_rate=0.0733; num_iterations=3410; feature_fraction=0.0725; bagging_fraction=0.943 : y = 0.934 : 295.6 secs : infill_ei
#
# Wed Nov 19 12:29:10 PM 2025 AUC 0.935220434729215
#
# [mbo] 63: num_leaves=957; min_child_weight=1.32; min_data_in_leaf=320; lambda_l2=2.56; learning_rate=0.02; num_iterations=4490; feature_fraction=0.141; bagging_fraction=0.583 : y = 0.935 : 471.2 secs : infill_ei
#
# Saved the current state after iteration 64 in the file HT.RDATA.
#
# Wed Nov 19 12:41:16 PM 2025 AUC 0.926824407164556
#
# [mbo] 64: num_leaves=634; min_child_weight=0.0339; min_data_in_leaf=38; lambda_l2=7.11; learning_rate=0.094; num_iterations=4466; feature_fraction=0.931; bagging_fraction=0.809 : y = 0.927 : 724.6 secs : infill_ei
#
# Saved the current state after iteration 65 in the file HT.RDATA.
#
# Wed Nov 19 12:46:05 PM 2025 AUC 0.916005835579723
#
# [mbo] 65: num_leaves=3; min_child_weight=1.32; min_data_in_leaf=205; lambda_l2=47.3; learning_rate=0.0396; num_iterations=4069; feature_fraction=0.108; bagging_fraction=0.681 : y = 0.916 : 288.0 secs : infill_ei
#
# Wed Nov 19 12:55:09 PM 2025 AUC 0.927640421992405
#
# [mbo] 66: num_leaves=6195; min_child_weight=3.63; min_data_in_leaf=469; lambda_l2=30.1; learning_rate=0.0726; num_iterations=3733; feature_fraction=0.352; bagging_fraction=0.854 : y = 0.928 : 542.5 secs : infill_ei
#
# Saved the current state after iteration 67 in the file HT.RDATA.
#
# Wed Nov 19 12:57:49 PM 2025 AUC 0.929652609871766
#
# [mbo] 67: num_leaves=355; min_child_weight=6.1; min_data_in_leaf=1211; lambda_l2=0.742; learning_rate=0.0701; num_iterations=1299; feature_fraction=0.645; bagging_fraction=0.997 : y = 0.93 : 159.3 secs : infill_ei
#
# Wed Nov 19 01:02:48 PM 2025 AUC 0.9339427273014
#
# [mbo] 68: num_leaves=71; min_child_weight=7.55; min_data_in_leaf=17; lambda_l2=0.219; learning_rate=0.0448; num_iterations=2338; feature_fraction=0.293; bagging_fraction=0.936 : y = 0.934 : 297.7 secs : infill_ei
#
# Wed Nov 19 01:09:09 PM 2025 AUC 0.927705515280482
#
# [mbo] 69: num_leaves=353; min_child_weight=7.76; min_data_in_leaf=5736; lambda_l2=0.125; learning_rate=0.0586; num_iterations=2902; feature_fraction=0.348; bagging_fraction=0.866 : y = 0.928 : 380.2 secs : infill_ei
#
# Saved the current state after iteration 70 in the file HT.RDATA.
#
# Wed Nov 19 01:17:54 PM 2025 AUC 0.931312824250135
#
# [mbo] 70: num_leaves=5917; min_child_weight=1.29; min_data_in_leaf=425; lambda_l2=194; learning_rate=0.0637; num_iterations=4793; feature_fraction=0.148; bagging_fraction=0.563 : y = 0.931 : 523.0 secs : infill_ei
#
# Wed Nov 19 01:27:44 PM 2025 AUC 0.938547238601796
#
# [mbo] 71: num_leaves=445; min_child_weight=1.61; min_data_in_leaf=7; lambda_l2=0.954; learning_rate=0.0148; num_iterations=3727; feature_fraction=0.374; bagging_fraction=0.807 : y = 0.939 : 588.6 secs : infill_ei
#
# Saved the current state after iteration 72 in the file HT.RDATA.
#
# Wed Nov 19 01:33:41 PM 2025 AUC 0.931958724144711
#
# [mbo] 72: num_leaves=5475; min_child_weight=1.79; min_data_in_leaf=876; lambda_l2=0.231; learning_rate=0.0228; num_iterations=2270; feature_fraction=0.356; bagging_fraction=0.966 : y = 0.932 : 356.1 secs : infill_ei
#
# Wed Nov 19 01:39:19 PM 2025 AUC 0.930734701902938
#
# [mbo] 73: num_leaves=55; min_child_weight=0.754; min_data_in_leaf=101; lambda_l2=1.36; learning_rate=0.00991; num_iterations=3220; feature_fraction=0.716; bagging_fraction=0.929 : y = 0.931 : 336.5 secs : infill_ei
#
# Saved the current state after iteration 74 in the file HT.RDATA.
#
# Wed Nov 19 01:47:07 PM 2025 AUC 0.935565697581952
#
# [mbo] 74: num_leaves=4993; min_child_weight=0.0158; min_data_in_leaf=81; lambda_l2=7.7; learning_rate=0.0374; num_iterations=3464; feature_fraction=0.164; bagging_fraction=0.851 : y = 0.936 : 466.5 secs : infill_ei
#
# Wed Nov 19 01:53:54 PM 2025 AUC 0.940000765013901
#
# [mbo] 75: num_leaves=3330; min_child_weight=0.00835; min_data_in_leaf=42; lambda_l2=0.251; learning_rate=0.0121; num_iterations=2962; feature_fraction=0.135; bagging_fraction=0.684 : y = 0.94 : 405.9 secs : infill_ei
#
# Saved the current state after iteration 76 in the file HT.RDATA.
#
# Wed Nov 19 02:03:48 PM 2025 AUC 0.939484716163066
#
# [mbo] 76: num_leaves=2671; min_child_weight=0.536; min_data_in_leaf=26; lambda_l2=0.225; learning_rate=0.0187; num_iterations=4137; feature_fraction=0.324; bagging_fraction=0.72 : y = 0.939 : 593.0 secs : infill_ei
#
# Wed Nov 19 02:15:31 PM 2025 AUC 0.929080527107999
#
# [mbo] 77: num_leaves=7256; min_child_weight=0.585; min_data_in_leaf=805; lambda_l2=142; learning_rate=0.086; num_iterations=4966; feature_fraction=0.284; bagging_fraction=0.752 : y = 0.929 : 701.2 secs : infill_ei
#
# Saved the current state after iteration 78 in the file HT.RDATA.
#
# Wed Nov 19 02:20:49 PM 2025 AUC 0.930705175050615
#
# [mbo] 78: num_leaves=6621; min_child_weight=1.37; min_data_in_leaf=52; lambda_l2=0.51; learning_rate=0.0841; num_iterations=3635; feature_fraction=0.105; bagging_fraction=0.628 : y = 0.931 : 316.4 secs : infill_ei
#
# Wed Nov 19 02:30:58 PM 2025 AUC 0.937680893912033
#
# [mbo] 79: num_leaves=6301; min_child_weight=0.185; min_data_in_leaf=344; lambda_l2=0.687; learning_rate=0.0093; num_iterations=4622; feature_fraction=0.172; bagging_fraction=0.811 : y = 0.938 : 607.2 secs : infill_ei
#
# Saved the current state after iteration 80 in the file HT.RDATA.
#
# Wed Nov 19 02:38:12 PM 2025 AUC 0.935787148974378
#
# [mbo] 80: num_leaves=5755; min_child_weight=0.142; min_data_in_leaf=703; lambda_l2=0.294; learning_rate=0.0191; num_iterations=3588; feature_fraction=0.158; bagging_fraction=0.76 : y = 0.936 : 431.6 secs : infill_ei
#
# Saved the final state in the file HT.RDATA

# %% [markdown]
# la bayesian optimization ha corrido, extraigo los mejores hiperparametros

# %%
# almaceno los resultados de la Bayesian Optimization
# y capturo los mejores hiperparametros encontrados

tb_bayesiana <- as.data.table(bayesiana_salida$opt.path)

# ordeno en forma descendente por AUC = y
setorder(tb_bayesiana, -y, -num_iterations)

# grabo para eventualmente poder utilizarlos en OTRA corrida
fwrite( tb_bayesiana,
  file="BO_log.txt",
  sep="\t"
)

# los mejores hiperparámetros son los que quedaron en el registro 1 de la tabla
PARAM$out$lgbm$mejores_hiperparametros <- tb_bayesiana[
  1, # el primero es el de mejor AUC
  setdiff(colnames(tb_bayesiana),
    c("y","dob","eol","error.message","exec.time","ei","error.model",
      "train.time","prop.type","propose.time","se","mean","iter")),
  with= FALSE
]

print(PARAM$out$lgbm$mejores_hiperparametros)
# Out:
# Error in as.data.table(bayesiana_salida$opt.path): could not find function "as.data.table"
# Traceback:

# %% [markdown]
# ### 6.3.3 Produccion

# %% [markdown]
# #### Final Training
# Construyo el modelo final, que es uno solo, no hace ningun tipo de particion < training, validation, testing>]

# %% [markdown]
# ##### Final Training Dataset
#
# Aqui esta la gran decision de en qué meses hago el Final Training
# <br> debo utilizar los mejores hiperparámetros que encontré en la optimización bayesiana

# %%
PARAM$trainingstrategy$final_train <- c(
  202105, 202104, 202103, 202102, 202101,
  202012, 202011, 202010, 202009, 202008, 202007,
  202006, 202005
)

dataset[, fold_final_train := foto_mes %in% PARAM$trainingstrategy$final_train ]

# creo el dfinal_train en formato  LightGBM
dfinal_train <- lgb.Dataset(
  data= data.matrix(dataset[fold_final_train == TRUE, campos_buenos, with= FALSE]),
  label= dataset[fold_final_train == TRUE, clase01],
  free_raw_data= TRUE
)

nrow( dfinal_train) # verifico el tamaño
# Out:
# [1] 207504

# %% [markdown]
# ##### Final Training Hyperparameters

# %%
# uno los parametros fijos y los mejores encontrados de los variables
fijos <- copy(PARAM$lgbm$param_fijos)

# quito lo que optimice en la Bayesian Optimization
fijos$num_iterations <- NULL
fijos$early_stopping_rounds <- NULL

# agrego a los hiperparametros fijos los que encontre con la Bayesian Optimization
param_final <- c(fijos, PARAM$out$lgbm$mejores_hiperparametros)

# Para el entrenamiento final, removemos early_stopping_rounds
# ya que se entrena con todos los datos disponibles y la cantidad de iteraciones
# ya está optimizada en 'num_iterations'.
param_final$early_stopping_rounds <- NULL

# %% [markdown]
# ##### Training
# Genero el modelo final, siempre sobre TODOS los datos de  final_train, sin hacer ningun tipo de undersampling de la clase mayoritaria

# %%
final_model <- lgb.train(
  data= dfinal_train,
  param= param_final,
  verbose= -100
)

# %%
# grabo a disco el modelo en un formato para seres humanos ... ponele ...

lgb.save(final_model, "modelo.txt")

# %%
# ahora imprimo la importancia de variables

tb_importancia <- as.data.table(lgb.importance(final_model))
archivo_importancia <- "impo.txt"

fwrite( tb_importancia,
  file= archivo_importancia,
  sep= "\t"
)

# %% [markdown]
# #### Scoring

# %% [markdown]
# Aplico el modelo final a los datos del futuro

# %%
PARAM$trainingstrategy$future <- c(202107)

dfuture <- dataset[ foto_mes %in% PARAM$trainingstrategy$future ]

# %%
# aplico final_model   a dfuture

prediccion <- predict(
  final_model,
  data.matrix(dfuture[, campos_buenos, with= FALSE])
)

# %% [markdown]
# ##### Tabla Prediccion

# %%
tb_prediccion <- dfuture[, list(numero_de_cliente)]
tb_prediccion[, prob := prediccion]

# grabo las probabilidad del modelo
#  me va a ser util para hacer Ensembles de modelos
fwrite(tb_prediccion,
  file= "prediccion.txt",
  sep= "\t"
)

# %% [markdown]
# #### Curva de Ganancia

# %% [markdown]
# Genero las salidas

# %%
# asigno clase ternaria
tb_prediccion[, clase_ternaria := dfuture$clase_ternaria ]

# asigno ganancias
tb_prediccion[, ganancia := -3000.0 ]
tb_prediccion[clase_ternaria=="BAJA+2", ganancia := 117000.0 ]

# reordeno, y acumulada
setorder( tb_prediccion, -prob )
tb_prediccion[, gan_acum := cumsum(ganancia)]

# media movil de ancho 400
tb_prediccion[,
  gan_suavizada := frollmean(
    x= gan_acum,
    n= 400,
    align= "center",
    na.rm= TRUE,
    hasNA= TRUE
  )
]

# %%
tb_prediccion[, sum(!is.na(gan_suavizada) )]
tb_prediccion[, .N]

# %%
# Este es la ganancia a reportar
resultado <- list()
resultado$ganancia_suavizada_max <- max( tb_prediccion$gan_suavizada, na.rm=TRUE )
options(digits= 8)
resultado$envios <- which.max( tb_prediccion$gan_suavizada)
resultado

# %%
# grabo las ganancias
fwrite( tb_prediccion,
  file= "ganancias.txt",
  sep= "\t"
)

# %%
# genero el grafico

tb_prediccion[, envios:= .I]

pdf("curva_de_ganancia.pdf")

plot(
  x= tb_prediccion$envios,
  y= tb_prediccion$gan_acum,
  type= "l",
  col= "gray",
  xlim= c(0, 6000),
  ylim= c(0, 8000000),
  main= paste0("Mejor gan prom= ", as.integer(resultado$ganancia_suavizada_max), " envios= ", resultado$envios),
  xlab= "Envios",
  ylab= "Ganancia",
  panel.first= grid()
)

dev.off()

# %%
# grabo los parametros
if( !require("yaml")) install.packages("yaml")
require("yaml")

PARAM$resultado <- resultado

write_yaml( PARAM, file="PARAM.yml")

# %%
format(Sys.time(), "%a %b %d %X %Y")
fin <- Sys.time()

# Duración en segundos
secs <- as.numeric(difftime(fin, principio, units = "secs"))
secs <- round(secs)

# A hh:mm:ss
h <- secs %/% 3600
m <- (secs %% 3600) %/% 60
s <- secs %% 60
dur_hms <- sprintf("%02d:%02d:%02d", h, m, s)

cat(
  "Inicio: ", format(principio, "%a %b %d %X %Y"), "\n",
  "Fin:    ", format(fin,       "%a %b %d %X %Y"), "\n",
  "Duración (hh:mm:ss): ", dur_hms, "\n",
  sep = ""
)
