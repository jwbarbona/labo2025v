# %% [markdown]
# <a href="https://colab.research.google.com/github/jwbarbona/labo2025v/blob/main/610_WorkFlow_12HT__123_gerencial_julio.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # 6 WorkFlow  Gerencial, futuro=JULIO

# %% [markdown]
# ### 6.1 Objetivo

# %% [markdown]
# Presentar un workflow/pipeline completo al que los estudiantes deberán enriquecer

# %% [markdown]
# #### 6.2  Seteo del ambiente en Google Colab

# %% [markdown]
# Esta parte se debe correr con el runtime en Python3
# <br>Ir al menu, Runtime -> Change Runtime Type -> Runtime type ->  **Python 3**

# %% [markdown]
# Conectar la virtual machine donde esta corriendo Google Colab con el  Google Drive, para poder tener persistencia de archivos

# %%
# primero establecer el Runtime de Python 3
from google.colab import drive
drive.mount('/content/.drive')
# Out:
# Mounted at /content/.drive

# %% [markdown]
# Para correr la siguiente celda es fundamental en Arranque en Frio haber copiado el archivo kaggle.json al Google Drive, en la carpeta indicada en el instructivo
#
# <br>los siguientes comando estan en shell script de Linux
# *   Crear las carpetas en el Google Drive
# *   "instalar" el archivo kaggle.json desde el Google Drive a la virtual machine para que pueda ser utilizado por la libreria  kaggle de Python
# *   Bajar el  **dataset_pequeno**  al  Google Drive  y tambien al disco local de la virtual machine que esta corriendo Google Colab
# *   Bajar el **dataset_historico** al Google Drive y tambien al disco local de la virtual machine que esta corriendo Google Colab

# %%
%%shell

mkdir -p "/content/.drive/My Drive/labo1"
mkdir -p "/content/buckets"
ln -s "/content/.drive/My Drive/labo1" /content/buckets/b1

mkdir -p ~/.kaggle
cp /content/buckets/b1/kaggle/kaggle.json  ~/.kaggle
chmod 600 ~/.kaggle/kaggle.json


mkdir -p /content/buckets/b1/exp
mkdir -p /content/buckets/b1/datasets
mkdir -p /content/datasets


webfiles="https://storage.googleapis.com/open-courses/austral2025-af91/"
destino_local="/content/datasets"
destino_bucket="/content/buckets/b1/datasets"


archivo="dataset_pequeno.csv"

if ! test -f $destino_bucket/$archivo; then
  wget  $webfiles/$archivo  -O $destino_bucket/$archivo
fi


if ! test -f $destino_local/$pequeno; then
  cp  $destino_bucket/$archivo  $destino_local/$archivo
fi

#-------

archivo="gerencial_competencia_2025.csv.gz"

if ! test -f $destino_bucket/$archivo; then
  wget  $webfiles/$archivo  -O $destino_bucket/$archivo
fi


if ! test -f $destino_local/$pequeno; then
  cp  $destino_bucket/$archivo  $destino_local/$archivo
fi
# Out:
# cp: cannot stat '/content/buckets/b1/kaggle/kaggle.json': No such file or directory
# chmod: cannot access '/root/.kaggle/kaggle.json': No such file or directory

# %% [markdown]
# ## 6.3  Workflow

# %% [markdown]
# ## Inicializacion

# %% [markdown]
# Esta parte se debe correr con el runtime en lenguaje **R** Ir al menu, Runtime -> Change Runtime Type -> Runtime type -> R

# %% [markdown]
# limpio el ambiente de R

# %%
format(Sys.time(), "%a %b %d %X %Y")
# Out:
# [1] "Tue Nov 18 03:00:52 AM 2025"

# %%
# limpio la memoria
rm(list=ls(all.names=TRUE)) # remove all objects
gc(full=TRUE, verbose=FALSE) # garbage collection
# Out:
#        used    (Mb) gc trigger (Mb) max used (Mb)
# Ncells  660443 35.3 1454471    77.7 1438386  76.9
# Vcells 1226662  9.4 8388608    64.0 1975136  15.1

# %%
principio <- Sys.time()

# %%
require("data.table")

if( !require("R.utils")) install.packages("R.utils")
require("R.utils")
# Out:
# Loading required package: data.table
#
# Loading required package: R.utils
#
# Warning message in library(package, lib.loc = lib.loc, character.only = TRUE, logical.return = TRUE, :
# “there is no package called ‘R.utils’”
# Installing package into ‘/usr/local/lib/R/site-library’
# (as ‘lib’ is unspecified)
#
# also installing the dependencies ‘R.oo’, ‘R.methodsS3’
#
#
# Loading required package: R.utils
#
# Loading required package: R.oo
#
# Loading required package: R.methodsS3
#
# R.methodsS3 v1.8.2 (2022-06-13 22:00:14 UTC) successfully loaded. See ?R.methodsS3 for help.
#
# R.oo v1.27.1 (2025-05-02 21:00:05 UTC) successfully loaded. See ?R.oo for help.
#
#
# Attaching package: ‘R.oo’
#
#
# The following object is masked from ‘package:R.methodsS3’:
#
#     throw
#
#
# The following objects are masked from ‘package:methods’:
#
#     getClasses, getMethods
#
#
# The following objects are masked from ‘package:base’:
#
#     attach, detach, load, save
#
#
# R.utils v2.13.0 (2025-02-24 21:20:02 UTC) successfully loaded. See ?R.utils for help.
#
#
# Attaching package: ‘R.utils’
#
#
# The following object is masked from ‘package:utils’:
#
#     timestamp
#
#
# The following objects are masked from ‘package:base’:
#
#     cat, commandArgs, getOption, isOpen, nullfile, parse, use, warnings

# %% [markdown]
# #### Parametros
# Si es gerente, no cambie nada
# <br>Si es Analista, cambie el nombre del dataset

# %%
PARAM <- list()
PARAM$semilla_primigenia <- 499999 # 100009, 200003, 499999, 700009, 999983

PARAM$experimento <- 63123
PARAM$dataset <- "gerencial_competencia_2025.csv.gz"

# %% [markdown]
# #### Carpeta del Experimento

# %%
# carpeta de trabajo

setwd("/content/buckets/b1/exp")
experimento_folder <- paste0("WF", PARAM$experimento)
dir.create(experimento_folder, showWarnings=FALSE)
setwd( paste0("/content/buckets/b1/exp/", experimento_folder ))

# %% [markdown]
# ### 6.3.1   Preprocesamiento del dataset

# %% [markdown]
# #### 6.3.1.1  DT incorporar dataset

# %%
# lectura del dataset
dataset <- fread(paste0("/content/datasets/", PARAM$dataset))

# %% [markdown]
# #### 6.3.1.2  CA  Catastrophe Analysis
# Se intentan reparar las variables que para un mes están con todos los valores en cero.

# %% [markdown]
# El método que se utiliza es **Machine Learning** se asigna NA also valores, si ha leido bien, es la "anti imputación de valores faltantes"
# <br> Usted podrá aplicar aquí otros métodos

# %%
dataset[ foto_mes==202006, internet:=NA]
dataset[ foto_mes==202006, mrentabilidad:=NA]
dataset[ foto_mes==202006, mrentabilidad_annual:=NA]
dataset[ foto_mes==202006, mcomisiones:=NA]
dataset[ foto_mes==202006, mactivos_margen:=NA]
dataset[ foto_mes==202006, mpasivos_margen:=NA]
dataset[ foto_mes==202006, mcuentas_saldo:=NA]
dataset[ foto_mes==202006, ctarjeta_visa_transacciones:=NA]
dataset[ foto_mes==202006, mtarjeta_visa_consumo:=NA]
dataset[ foto_mes==202006, mtarjeta_master_consumo:=NA]
dataset[ foto_mes==202006, ccallcenter_transacciones:=NA]
dataset[ foto_mes==202006, chomebanking_transacciones:=NA]
dataset[ foto_mes==202006, chomebanking_transacciones:=NA]

# %% [markdown]
# #### 6.3.1.3  DR  Data Drifting
# Se intenta corregir el data drifting, quizas ajustando por IPC ...
# <br>Esta parte podrá ser abordada por todos los Analistas y también la Gerenciapero se decide pedagogicamente no incluirla en esta primer version para reducir la carga cognitiva

# %%
# sin codigo en esta primera version del workflow

# %% [markdown]
# #### 6.3.1.3  FE_intra_manual Feature Engineering intra-mes
#
# Agrego campos nuevos dentro del mismo mes, SIN considerar la historia.

# %%
# esta funcion atributos presentes existe debido a que las modalidades poseen datasets con distinta cantidad de campos
atributos_presentes <- function( patributos )
{
  atributos <- unique( patributos )
  comun <- intersect( atributos, colnames(dataset) )

  return(  length( atributos ) == length( comun ) )
}

# el mes 1,2, ..12
if( atributos_presentes( c("foto_mes") ))
  dataset[, kmes := foto_mes %% 100]

# variable extraida de una tesis de maestria de Irlanda
if( atributos_presentes( c("mpayroll", "cliente_edad") ))
  dataset[, mpayroll_sobre_edad := mpayroll / cliente_edad]

# %%
# visualizo las columas del dataset a esta etapa
colnames(dataset)
# Out:
#  [1] "numero_de_cliente"           "foto_mes"
#  [3] "internet"                    "cliente_edad"
#  [5] "cliente_antiguedad"          "mrentabilidad"
#  [7] "mrentabilidad_annual"        "mcomisiones"
#  [9] "mactivos_margen"             "mpasivos_margen"
# [11] "cproductos"                  "mcuenta_corriente"
# [13] "mcaja_ahorro"                "cdescubierto_preacordado"
# [15] "mcuentas_saldo"              "ctarjeta_visa_transacciones"
# [17] "mtarjeta_visa_consumo"       "mtarjeta_master_consumo"
# [19] "mprestamos_personales"       "cpayroll_trx"
# [21] "mpayroll"                    "ccomisiones_mantenimiento"
# [23] "ccallcenter_transacciones"   "chomebanking_transacciones"
# [25] "ctrx_quarter"                "Master_status"
# [27] "Master_fechaalta"            "Master_mpagominimo"
# [29] "Visa_status"                 "Visa_fechaalta"
# [31] "Visa_mpagominimo"            "clase_ternaria"
# [33] "kmes"                        "mpayroll_sobre_edad"

# %% [markdown]
# #### 6.3.1.4  FE_rf Feature Engineering de nuevas variables a partir de hojas de Random Forest
#
# Esto se mostrará unicamente a la *modalidad Analista Sr*

# %%
# No se implementa Feature Engineering a partir de Random Forest

# %% [markdown]
# #### 6.3.1.5  FEhist Feature Engineering historico
#
# El Fature Engineering Histórico es la etapa que más aporta a la ganancia final, ya que enriquece cada registro del dataset con su historia.

# %% [markdown]
# Para cada campo del dataset original (*)
# se crean lo siguientes campos de a partir de la historia
# * lag1  lags de orden 1
# * delta1  =  valor actual - lag1
# * lag2  lags de orden 2
# * delta2  = valor actual - lag2
#
#
# (*) Excepto para los campos  <numero_de_cliente,  foto_mes,  clase_ternaria>

# %%
# Feature Engineering Historico

# todo es lagueable, menos la primary key y la clase
cols_lagueables <- copy( setdiff(
    colnames(dataset),
    c("numero_de_cliente", "foto_mes", "clase_ternaria")
) )

# https://rdrr.io/cran/data.table/man/shift.html

# lags de orden 1
dataset[,
    paste0(cols_lagueables, "_lag1") := shift(.SD, 1, NA, "lag"),
    by = numero_de_cliente,
    .SDcols = cols_lagueables
]

# lags de orden 2
dataset[,
    paste0(cols_lagueables, "_lag2") := shift(.SD, 2, NA, "lag"),
    by = numero_de_cliente,
    .SDcols = cols_lagueables
]

# agrego los delta lags
for (vcol in cols_lagueables)
{
    dataset[, paste0(vcol, "_delta1") := get(vcol) - get(paste0(vcol, "_lag1"))]
    dataset[, paste0(vcol, "_delta2") := get(vcol) - get(paste0(vcol, "_lag2"))]
}

# %% [markdown]
# Verificacion de los campos recien creados

# %%
ncol(dataset)
colnames(dataset)
# Out:
# [1] 158
#   [1] "numero_de_cliente"                  "foto_mes"
#   [3] "internet"                           "cliente_edad"
#   [5] "cliente_antiguedad"                 "mrentabilidad"
#   [7] "mrentabilidad_annual"               "mcomisiones"
#   [9] "mactivos_margen"                    "mpasivos_margen"
#  [11] "cproductos"                         "mcuenta_corriente"
#  [13] "mcaja_ahorro"                       "cdescubierto_preacordado"
#  [15] "mcuentas_saldo"                     "ctarjeta_visa_transacciones"
#  [17] "mtarjeta_visa_consumo"              "mtarjeta_master_consumo"
#  [19] "mprestamos_personales"              "cpayroll_trx"
#  [21] "mpayroll"                           "ccomisiones_mantenimiento"
#  [23] "ccallcenter_transacciones"          "chomebanking_transacciones"
#  [25] "ctrx_quarter"                       "Master_status"
#  [27] "Master_fechaalta"                   "Master_mpagominimo"
#  [29] "Visa_status"                        "Visa_fechaalta"
#  [31] "Visa_mpagominimo"                   "clase_ternaria"
#  [33] "kmes"                               "mpayroll_sobre_edad"
#  [35] "internet_lag1"                      "cliente_edad_lag1"
#  [37] "cliente_antiguedad_lag1"            "mrentabilidad_lag1"
#  [39] "mrentabilidad_annual_lag1"          "mcomisiones_lag1"
#  [41] "mactivos_margen_lag1"               "mpasivos_margen_lag1"
#  [43] "cproductos_lag1"                    "mcuenta_corriente_lag1"
#  [45] "mcaja_ahorro_lag1"                  "cdescubierto_preacordado_lag1"
#  [47] "mcuentas_saldo_lag1"                "ctarjeta_visa_transacciones_lag1"
#  [49] "mtarjeta_visa_consumo_lag1"         "mtarjeta_master_consumo_lag1"
#  [51] "mprestamos_personales_lag1"         "cpayroll_trx_lag1"
#  [53] "mpayroll_lag1"                      "ccomisiones_mantenimiento_lag1"
#  [55] "ccallcenter_transacciones_lag1"     "chomebanking_transacciones_lag1"
#  [57] "ctrx_quarter_lag1"                  "Master_status_lag1"
#  [59] "Master_fechaalta_lag1"              "Master_mpagominimo_lag1"
#  [61] "Visa_status_lag1"                   "Visa_fechaalta_lag1"
#  [63] "Visa_mpagominimo_lag1"              "kmes_lag1"
#  [65] "mpayroll_sobre_edad_lag1"           "internet_lag2"
#  [67] "cliente_edad_lag2"                  "cliente_antiguedad_lag2"
#  [69] "mrentabilidad_lag2"                 "mrentabilidad_annual_lag2"
#  [71] "mcomisiones_lag2"                   "mactivos_margen_lag2"
#  [73] "mpasivos_margen_lag2"               "cproductos_lag2"
#  [75] "mcuenta_corriente_lag2"             "mcaja_ahorro_lag2"
#  [77] "cdescubierto_preacordado_lag2"      "mcuentas_saldo_lag2"
#  [79] "ctarjeta_visa_transacciones_lag2"   "mtarjeta_visa_consumo_lag2"
#  [81] "mtarjeta_master_consumo_lag2"       "mprestamos_personales_lag2"
#  [83] "cpayroll_trx_lag2"                  "mpayroll_lag2"
#  [85] "ccomisiones_mantenimiento_lag2"     "ccallcenter_transacciones_lag2"
#  [87] "chomebanking_transacciones_lag2"    "ctrx_quarter_lag2"
#  [89] "Master_status_lag2"                 "Master_fechaalta_lag2"
#  [91] "Master_mpagominimo_lag2"            "Visa_status_lag2"
#  [93] "Visa_fechaalta_lag2"                "Visa_mpagominimo_lag2"
#  [95] "kmes_lag2"                          "mpayroll_sobre_edad_lag2"
#  [97] "internet_delta1"                    "internet_delta2"
#  [99] "cliente_edad_delta1"                "cliente_edad_delta2"
# [101] "cliente_antiguedad_delta1"          "cliente_antiguedad_delta2"
# [103] "mrentabilidad_delta1"               "mrentabilidad_delta2"
# [105] "mrentabilidad_annual_delta1"        "mrentabilidad_annual_delta2"
# [107] "mcomisiones_delta1"                 "mcomisiones_delta2"
# [109] "mactivos_margen_delta1"             "mactivos_margen_delta2"
# [111] "mpasivos_margen_delta1"             "mpasivos_margen_delta2"
# [113] "cproductos_delta1"                  "cproductos_delta2"
# [115] "mcuenta_corriente_delta1"           "mcuenta_corriente_delta2"
# [117] "mcaja_ahorro_delta1"                "mcaja_ahorro_delta2"
# [119] "cdescubierto_preacordado_delta1"    "cdescubierto_preacordado_delta2"
# [121] "mcuentas_saldo_delta1"              "mcuentas_saldo_delta2"
# [123] "ctarjeta_visa_transacciones_delta1" "ctarjeta_visa_transacciones_delta2"
# [125] "mtarjeta_visa_consumo_delta1"       "mtarjeta_visa_consumo_delta2"
# [127] "mtarjeta_master_consumo_delta1"     "mtarjeta_master_consumo_delta2"
# [129] "mprestamos_personales_delta1"       "mprestamos_personales_delta2"
# [131] "cpayroll_trx_delta1"                "cpayroll_trx_delta2"
# [133] "mpayroll_delta1"                    "mpayroll_delta2"
# [135] "ccomisiones_mantenimiento_delta1"   "ccomisiones_mantenimiento_delta2"
# [137] "ccallcenter_transacciones_delta1"   "ccallcenter_transacciones_delta2"
# [139] "chomebanking_transacciones_delta1"  "chomebanking_transacciones_delta2"
# [141] "ctrx_quarter_delta1"                "ctrx_quarter_delta2"
# [143] "Master_status_delta1"               "Master_status_delta2"
# [145] "Master_fechaalta_delta1"            "Master_fechaalta_delta2"
# [147] "Master_mpagominimo_delta1"          "Master_mpagominimo_delta2"
# [149] "Visa_status_delta1"                 "Visa_status_delta2"
# [151] "Visa_fechaalta_delta1"              "Visa_fechaalta_delta2"
# [153] "Visa_mpagominimo_delta1"            "Visa_mpagominimo_delta2"
# [155] "kmes_delta1"                        "kmes_delta2"
# [157] "mpayroll_sobre_edad_delta1"         "mpayroll_sobre_edad_delta2"

# %% [markdown]
# #### 6.3.1.6  FEhist Reduccion dimensionalidad con canaritos
#
# Esta etapa solo se mostrará a la *modalidad Anlista Sr* por algun canal secreto de forma de no confundir a los *Analista Jr*  nni distraer con detalles operativos a la estratégica *Modalidad Gerencial*

# %%
# No se implementa la reduccion de la dimensionalidad con canaritos

# %% [markdown]
# ### 6.3.2 Modelado

# %% [markdown]
# #### 6.3.2.1 Training Strategy
#
# Esta etapa de Workflow de  Training Strategy esta pensada para la *Modalidad Gerencial* que posee el dataset de [202005, 202109]
# <br> Si usted es un Analista, posee el periodo de [201901, 202109] y deberá experimentar en que meses le conviene experimentar
#
# <br> A la *Modalidad Gerencial* no se le complicada la vida con el undersampling de los continua, por eso PARAM$trainingstrategy$training_pct <- 1.0
# <br> Sin embargo, si usted es  *Analista SR* posee un dataset 50 veces ( filas x columnas) más grande que la *Modalidad Gerencial*  y por un tema de velocidad y experimentación más rápida puede llegar a necesitar activar el undersampling de la clase mayoritaria, a pesar de estar corriendo en Google Cloud.

# %% [markdown]
# Se hace una estrategia de entrenamiento muy sencilla, tomando todos los meses posibles, SIN eliminar nada x pandemia ni por ningun otro motivo
#
# * future = 202107  obviamente completo
#
# * final_train =  [ 202005, 202105 ]  SIN undersampling
#
# * training
#    * testing = NO HAY
#    * validation =  202105   completo, sin undersampling
#    * training = [ 202005, 202104 ]  donde se consideran el 100% de los CONTINUA

# %%
PARAM$trainingstrategy$validate <- c(202105)

PARAM$trainingstrategy$training <- c(
  202104, 202103, 202102, 202101,
  202012, 202011, 202010, 202009, 202008, 202007,
  202006, 202005
)

PARAM$trainingstrategy$training_pct <- 1.0


PARAM$trainingstrategy$positivos <- c( "BAJA+1", "BAJA+2")

# %%
# seteo la clase01   1={BAJA+1, BAJA+2}   0={CONTINUA}
dataset[, clase01 := ifelse( clase_ternaria %in% PARAM$trainingstrategy$positivos, 1, 0 )]

# %%
# los campos en los que se entrena
campos_buenos <- copy( setdiff(
    colnames(dataset), c("clase_ternaria","clase01","azar"))
)

# %%
# preparo para que se puede hacer undersampling de los CONTINUA
#  solamente por un tema de VELOCIDAD
set.seed(PARAM$semilla_primigenia, kind = "L'Ecuyer-CMRG")
dataset[, azar:=runif(nrow(dataset))]

# undersampling de los CONTINUA
dataset[, fold_train :=  foto_mes %in%  PARAM$trainingstrategy$training &
    (clase_ternaria %in% c("BAJA+1", "BAJA+2") |
     azar < PARAM$trainingstrategy$training_pct ) ]


if( !require("lightgbm")) install.packages("lightgbm")
require("lightgbm")

dtrain <- lgb.Dataset(
  data= data.matrix(dataset[fold_train == TRUE, campos_buenos, with = FALSE]),
  label= dataset[fold_train == TRUE, clase01],
  free_raw_data= TRUE
)
# Out:
# Loading required package: lightgbm
#
# Warning message in library(package, lib.loc = lib.loc, character.only = TRUE, logical.return = TRUE, :
# “there is no package called ‘lightgbm’”
# Installing package into ‘/usr/local/lib/R/site-library’
# (as ‘lib’ is unspecified)
#
# Loading required package: lightgbm

# %%
# datos de validation
dvalidate <- lgb.Dataset(
  data= data.matrix(dataset[foto_mes %in% PARAM$trainingstrategy$validate, campos_buenos, with = FALSE]),
  label= dataset[foto_mes %in% PARAM$trainingstrategy$validate, clase01],
  free_raw_data= TRUE
)

nrow(dvalidate)
# Out:
# [1] 16469

# %% [markdown]
# ####  6.3.2.2. Hyperparameter Tuning

# %% [markdown]
# * Clase binaria que se optimiza :  positivos = [ BAJA+1, BAJA+2 ]

# %% [markdown]
# * Metrica que se optimiza **AUC** Area Under Curve de la  ROC Curve
#
# es muy importante notar que intencionalmente  **NO** se está optimizando la funcion de ganancia del problema

# %% [markdown]
# * Cantidad de iteraciones inteligentes de la Optimizacion Bayesiana = **10**

# %% [markdown]
# * Parametros no default, fijos de LightGBM que no se optimizan
#   * max_bin = 31 , Alienigenas Ancestrales contruyeron las pirámides y dejaron a la humanidad en un jeroglifico  *max_bin=31*
#   * feature_fraction = 0.5  para poner algo que generalmente no falla
#   * learning_rate = 0.03  para que aprenda lento

# %% [markdown]
# * Parametros que se optimizan en la Bayesian Optimization
#   * num_leaves  [8, 256]
#   * min_data_in_leaf  [8, 8192]

# %%
# paquetes necesarios para la Bayesian Optimization
if(!require("DiceKriging")) install.packages("DiceKriging")
require("DiceKriging")

if(!require("mlrMBO")) install.packages("mlrMBO")
require("mlrMBO")
# Out:
# Loading required package: DiceKriging
#
# Warning message in library(package, lib.loc = lib.loc, character.only = TRUE, logical.return = TRUE, :
# “there is no package called ‘DiceKriging’”
# Installing package into ‘/usr/local/lib/R/site-library’
# (as ‘lib’ is unspecified)
#
# Loading required package: DiceKriging
#
# Loading required package: mlrMBO
#
# Warning message in library(package, lib.loc = lib.loc, character.only = TRUE, logical.return = TRUE, :
# “there is no package called ‘mlrMBO’”
# Installing package into ‘/usr/local/lib/R/site-library’
# (as ‘lib’ is unspecified)
#
# also installing the dependencies ‘XML’, ‘fastmatch’, ‘RcppArmadillo’, ‘mlr’, ‘ParamHelpers’, ‘smoof’, ‘BBmisc’, ‘checkmate’, ‘lhs’, ‘parallelMap’
#
#
# Loading required package: mlrMBO
#
# Loading required package: mlr
#
# Loading required package: ParamHelpers
#
#
# Attaching package: ‘ParamHelpers’
#
#
# The following object is masked from ‘package:R.utils’:
#
#     isVector
#
#
#
# Attaching package: ‘mlr’
#
#
# The following objects are masked from ‘package:R.utils’:
#
#     resample, setThreshold
#
#
# Loading required package: smoof
#
# Loading required package: checkmate
#
#
# Attaching package: ‘checkmate’
#
#
# The following object is masked from ‘package:DiceKriging’:
#
#     checkNames
#
#
# The following object is masked from ‘package:R.utils’:
#
#     asInt
#
#
#
# Attaching package: ‘smoof’
#
#
# The following objects are masked from ‘package:R.oo’:
#
#     getDescription, getName

# %% [markdown]
# Definición de la Bayesian Optimization
# <br> Si se desea optimizar un hiperparámetro que esta como fijo, debe QUITARSE de param_fijos y agregarse a PARAM$hipeparametertuning$hs

# %%
# valor ridiculamente bajo para que corra rapido en el aula y no molestar a la *Modalidad Gerencial*
PARAM$hipeparametertuning$num_interations <- 100

# parametros fijos del LightGBM
PARAM$lgbm$param_fijos <- list(
  objective= "binary",
  metric= "auc",
  first_metric_only= TRUE,
  boost_from_average= TRUE,
  feature_pre_filter= FALSE,
  verbosity= -100,
  force_row_wise= TRUE, # para evitar warning
  max_bin= 31,
  top_k= 20,
  min_data_in_bin= 3,
  seed= PARAM$semilla_primigenia
  # learning_rate= 0.03,
  # feature_fraction= 0.5,
  # num_iterations= 2048,  # valor grande, lo limita early_stopping_rounds
  # early_stopping_rounds= 200
)

PARAM$hipeparametertuning$hs <- makeParamSet(
  # Núcleo del modelo (estructura de árboles)
  makeIntegerParam("num_leaves", lower = 2L, upper = 63L),
  # makeIntegerParam("max_depth", lower = 3L, upper = 30L),
  makeNumericParam("min_child_weight", lower = 0.001, upper = 10.0),
  makeIntegerParam("min_data_in_leaf", lower = 2L, upper = 8192L),
  makeNumericParam("min_gain_to_split", lower = 0.0, upper = 0.1),

  # Regularización
  makeNumericParam("lambda_l1", lower = 0.0, upper = 0.5),
  makeNumericParam("lambda_l2", lower = 0.0, upper = 0.5),
  makeNumericParam("scale_pos_weight", lower = 1.0, upper = 5.0),  # útil en desequilibrio

  # Control del aprendizaje
  makeNumericParam("learning_rate", lower = 0.005, upper = 0.1),
  makeIntegerParam("num_iterations", lower = 100L, upper = 5000L),
  makeIntegerParam("early_stopping_rounds", lower = 50L, upper = 500L),

  # Submuestreo
  makeNumericParam("feature_fraction", lower = 0.3, upper = 0.8),   # columnas
  makeNumericParam("bagging_fraction", lower = 0.5, upper = 0.9)   # filas
  # makeIntegerParam("bagging_freq", lower = 1L, upper = 5L),         # cada N iteraciones

  # Opcionales útiles
  # makeNumericParam("max_delta_step", lower = 0.0, upper = 10.0),
  # makeNumericParam("path_smooth", lower = 0.0, upper = 10.0)
)
# Total: 12 hT

# %% [markdown]
# Función "señora caja negra"  que es llamada para verificar la realidad por la Bayesian Optimization

# %%
# En  x llegan los parmaetros de la bayesiana
#  devuelve la AUC en validate del modelo entrenado
#  en el parametro x llegan los hiperparámetros que se estan optimizando

EstimarGanancia_AUC_lightgbm <- function(x) {

  # x pisa (o agrega) a param_fijos
  param_completo <- modifyList(PARAM$lgbm$param_fijos, x)

  # entreno LightGBM
  modelo_train <- lgb.train(
    data= dtrain,
    valids= list(valid = dvalidate),
    eval= "auc",
    param= param_completo,
    verbose= -100
  )

  # recupero la AUC en validation
  AUC <- modelo_train$record_evals$valid$auc$eval[[modelo_train$best_iter]]

  # esta es la forma de devolver un parametro extra
  attr(AUC, "extras") <- list("num_iterations"= modelo_train$best_iter)

  # hago espacio en la memoria
  rm(modelo_train)
  gc(full= TRUE, verbose= FALSE)

  message(format(Sys.time(), "%a %b %d %X %Y"), " AUC ", AUC)

  return(AUC)
}

# %% [markdown]
# seteo de la Bayesian Optimization (complejo)
# <br> copiado y pegado de la documentación de la librería

# %%
configureMlr(show.learner.output = FALSE)

# configuro la busqueda bayesiana,  los hiperparametros que se van a optimizar
# por favor, no desesperarse por lo complejo
obj.fun <- makeSingleObjectiveFunction(
    fn= EstimarGanancia_AUC_lightgbm, # la funcion que voy a maximizar
    minimize= FALSE, # estoy Maximizando AUC
    noisy= FALSE,
    par.set= PARAM$hipeparametertuning$hs,
    has.simple.signature= FALSE # paso los parametros en una lista
)

# cada 600 segundos guardo el resultado intermedio
ctrl <- makeMBOControl(
    save.on.disk.at.time= 600,
    save.file.path= "HT.RDATA"
)

# indico la cantidad de iteraciones que va a tener la Bayesian Optimization
ctrl <- setMBOControlTermination(
    ctrl,
    iters= PARAM$hipeparametertuning$num_interations  # cantidad de iteraciones inteligentes
)

# defino el método estandar para la creacion de los puntos iniciales
#   los "No Inteligentes"
ctrl <- setMBOControlInfill(ctrl, crit = makeMBOInfillCritEI())

# mas configuraciones
surr.km <- makeLearner(
    "regr.km",
    predict.type= "se",
    covtype= "matern3_2",
    control= list(trace = TRUE)
)

# %% [markdown]
# Corrida de la Bayesian Optimization,  aqui se hace el trabajo pesado
# <br> por favor no se asuste con los warnings que pudieran aparecer
#
# Si corrío a medias y llegó a las iteraciones inteligentes, en el archivo binario HT.RDATA quedó lo ya procesado y es utilizado para retomar la corrida desde lo último que llegó a grabar.

# %%
# inicio la optimizacion bayesiana

if (!file.exists("HT.RDATA")) {
  bayesiana_salida <- mbo(obj.fun, learner= surr.km, control= ctrl)
} else {
  bayesiana_salida <- mboContinue("HT.RDATA") # retomo en caso que ya exista
}
# Out:
# Computing y column(s) for design. Not provided.
#
# Tue Nov 18 03:16:52 AM 2025 AUC 0.925543679945026
#
# Tue Nov 18 03:20:32 AM 2025 AUC 0.925404098461315
#
# Tue Nov 18 03:21:51 AM 2025 AUC 0.920920714361928
#
# Tue Nov 18 03:24:48 AM 2025 AUC 0.929570739963051
#
# Tue Nov 18 03:30:19 AM 2025 AUC 0.925371551817277
#
# Tue Nov 18 03:33:55 AM 2025 AUC 0.913640667602131
#
# Tue Nov 18 03:37:56 AM 2025 AUC 0.926850243160339
#
# Tue Nov 18 03:42:32 AM 2025 AUC 0.924687401227646
#
# Tue Nov 18 03:45:38 AM 2025 AUC 0.919664816540943
#
# Tue Nov 18 03:47:31 AM 2025 AUC 0.933863206119574
#
# Tue Nov 18 03:49:51 AM 2025 AUC 0.923893196006627
#
# Tue Nov 18 03:50:35 AM 2025 AUC 0.915877326665633
#
# Tue Nov 18 03:52:36 AM 2025 AUC 0.930547810349028
#
# Tue Nov 18 03:55:44 AM 2025 AUC 0.91895013250175
#
# Tue Nov 18 03:58:44 AM 2025 AUC 0.92922983903168
#
# Tue Nov 18 04:00:35 AM 2025 AUC 0.927963539705899
#
# Tue Nov 18 04:02:49 AM 2025 AUC 0.926320101948168
#
# Tue Nov 18 04:05:38 AM 2025 AUC 0.928887931503071
#
# Tue Nov 18 04:09:00 AM 2025 AUC 0.922266199337122
#
# Tue Nov 18 04:10:38 AM 2025 AUC 0.930079071568393
#
# Tue Nov 18 04:13:12 AM 2025 AUC 0.914841538107423
#
# Tue Nov 18 04:14:52 AM 2025 AUC 0.923589539173074
#
# Tue Nov 18 04:16:18 AM 2025 AUC 0.924881003429812
#
# Tue Nov 18 04:17:39 AM 2025 AUC 0.910696035147691
#
# Tue Nov 18 04:27:50 AM 2025 AUC 0.922529927813557
#
# Tue Nov 18 04:30:03 AM 2025 AUC 0.926503638177952
#
# Tue Nov 18 04:34:36 AM 2025 AUC 0.929684149918566
#
# Tue Nov 18 04:37:39 AM 2025 AUC 0.927922940283954
#
# Tue Nov 18 04:40:26 AM 2025 AUC 0.922969475274281
#
# Tue Nov 18 04:41:01 AM 2025 AUC 0.915541123188041
#
# Tue Nov 18 04:43:34 AM 2025 AUC 0.927284757634872
#
# Tue Nov 18 04:45:02 AM 2025 AUC 0.921128744457843
#
# Tue Nov 18 04:48:47 AM 2025 AUC 0.929026506389544
#
# Tue Nov 18 04:52:01 AM 2025 AUC 0.929711663576413
#
# Tue Nov 18 04:52:23 AM 2025 AUC 0.911009422421215
#
# Tue Nov 18 04:53:07 AM 2025 AUC 0.920305683449327
#
# Tue Nov 18 04:54:35 AM 2025 AUC 0.917064775874414
#
# Tue Nov 18 04:55:23 AM 2025 AUC 0.920363395024323
#
# Tue Nov 18 04:56:22 AM 2025 AUC 0.922829558258157
#
# Tue Nov 18 04:59:10 AM 2025 AUC 0.926562020817773
#
# Tue Nov 18 05:03:43 AM 2025 AUC 0.91253810809378
#
# Tue Nov 18 05:08:02 AM 2025 AUC 0.920557668291315
#
# Tue Nov 18 05:10:34 AM 2025 AUC 0.918416300433038
#
# Tue Nov 18 05:11:18 AM 2025 AUC 0.919508793969006
#
# Tue Nov 18 05:12:30 AM 2025 AUC 0.918025069639752
#
# Tue Nov 18 05:15:57 AM 2025 AUC 0.924811212687957
#
# Tue Nov 18 05:16:54 AM 2025 AUC 0.930054577702261
#
# Tue Nov 18 05:19:53 AM 2025 AUC 0.920937826514979
#
# [mbo] 0: num_leaves=26; min_child_weight=5.32; min_data_in_leaf=4974; min_gain_to_split=0.0299; lambda_l1=0.354; lambda_l2=0.338; scale_pos_weight=2.17; learning_rate=0.0527; num_iterations=4290; early_stopping_rounds=296; feature_fraction=0.576; bagging_fraction=0.712 : y = 0.926 : 184.6 secs : initdesign
#
# [mbo] 0: num_leaves=29; min_child_weight=4.63; min_data_in_leaf=6811; min_gain_to_split=0.0335; lambda_l1=0.229; lambda_l2=0.227; scale_pos_weight=2.99; learning_rate=0.0465; num_iterations=3186; early_stopping_rounds=309; feature_fraction=0.593; bagging_fraction=0.707 : y = 0.925 : 219.5 secs : initdesign
#
# [mbo] 0: num_leaves=21; min_child_weight=1.49; min_data_in_leaf=5964; min_gain_to_split=0.0474; lambda_l1=0.147; lambda_l2=0.357; scale_pos_weight=1.51; learning_rate=0.0695; num_iterations=641; early_stopping_rounds=222; feature_fraction=0.436; bagging_fraction=0.696 : y = 0.921 : 79.0 secs : initdesign
#
# [mbo] 0: num_leaves=43; min_child_weight=1.83; min_data_in_leaf=3095; min_gain_to_split=0.0856; lambda_l1=0.27; lambda_l2=0.198; scale_pos_weight=3.51; learning_rate=0.0728; num_iterations=2954; early_stopping_rounds=246; feature_fraction=0.563; bagging_fraction=0.685 : y = 0.93 : 177.1 secs : initdesign
#
# [mbo] 0: num_leaves=38; min_child_weight=2.92; min_data_in_leaf=7340; min_gain_to_split=0.0553; lambda_l1=0.217; lambda_l2=0.205; scale_pos_weight=4.38; learning_rate=0.0218; num_iterations=2082; early_stopping_rounds=388; feature_fraction=0.497; bagging_fraction=0.535 : y = 0.925 : 330.7 secs : initdesign
#
# [mbo] 0: num_leaves=3; min_child_weight=9.15; min_data_in_leaf=3848; min_gain_to_split=0.0566; lambda_l1=0.248; lambda_l2=0.267; scale_pos_weight=1.92; learning_rate=0.0713; num_iterations=1689; early_stopping_rounds=396; feature_fraction=0.517; bagging_fraction=0.638 : y = 0.914 : 216.2 secs : initdesign
#
# [mbo] 0: num_leaves=57; min_child_weight=2.85; min_data_in_leaf=2941; min_gain_to_split=0.0372; lambda_l1=0.438; lambda_l2=0.147; scale_pos_weight=3.7; learning_rate=0.0546; num_iterations=3003; early_stopping_rounds=361; feature_fraction=0.527; bagging_fraction=0.87 : y = 0.927 : 241.5 secs : initdesign
#
# [mbo] 0: num_leaves=17; min_child_weight=7.79; min_data_in_leaf=3703; min_gain_to_split=0.0957; lambda_l1=0.0888; lambda_l2=0.458; scale_pos_weight=3.98; learning_rate=0.0479; num_iterations=3605; early_stopping_rounds=372; feature_fraction=0.466; bagging_fraction=0.668 : y = 0.925 : 276.1 secs : initdesign
#
# [mbo] 0: num_leaves=62; min_child_weight=4.97; min_data_in_leaf=5797; min_gain_to_split=0.0509; lambda_l1=0.394; lambda_l2=0.384; scale_pos_weight=3.18; learning_rate=0.00911; num_iterations=2580; early_stopping_rounds=111; feature_fraction=0.606; bagging_fraction=0.776 : y = 0.92 : 185.1 secs : initdesign
#
# [mbo] 0: num_leaves=51; min_child_weight=4.38; min_data_in_leaf=1026; min_gain_to_split=0.0399; lambda_l1=0.172; lambda_l2=0.365; scale_pos_weight=4.07; learning_rate=0.0284; num_iterations=852; early_stopping_rounds=356; feature_fraction=0.319; bagging_fraction=0.807 : y = 0.934 : 113.2 secs : initdesign
#
# [mbo] 0: num_leaves=23; min_child_weight=6.72; min_data_in_leaf=6411; min_gain_to_split=0.0164; lambda_l1=0.28; lambda_l2=0.101; scale_pos_weight=3.35; learning_rate=0.0348; num_iterations=2242; early_stopping_rounds=232; feature_fraction=0.479; bagging_fraction=0.795 : y = 0.924 : 140.5 secs : initdesign
#
# [mbo] 0: num_leaves=30; min_child_weight=1.1; min_data_in_leaf=2288; min_gain_to_split=0.0442; lambda_l1=0.372; lambda_l2=0.399; scale_pos_weight=3.46; learning_rate=0.0589; num_iterations=3856; early_stopping_rounds=176; feature_fraction=0.678; bagging_fraction=0.596 : y = 0.916 : 43.5 secs : initdesign
#
# [mbo] 0: num_leaves=57; min_child_weight=3.53; min_data_in_leaf=2858; min_gain_to_split=0.0321; lambda_l1=0.375; lambda_l2=0.00125; scale_pos_weight=3.88; learning_rate=0.0617; num_iterations=3943; early_stopping_rounds=144; feature_fraction=0.754; bagging_fraction=0.654 : y = 0.931 : 120.9 secs : initdesign
#
# [mbo] 0: num_leaves=29; min_child_weight=2.61; min_data_in_leaf=8060; min_gain_to_split=0.066; lambda_l1=0.32; lambda_l2=0.255; scale_pos_weight=2.09; learning_rate=0.0651; num_iterations=1817; early_stopping_rounds=313; feature_fraction=0.697; bagging_fraction=0.822 : y = 0.919 : 188.5 secs : initdesign
#
# [mbo] 0: num_leaves=35; min_child_weight=8.79; min_data_in_leaf=4438; min_gain_to_split=0.039; lambda_l1=0.361; lambda_l2=0.421; scale_pos_weight=4.08; learning_rate=0.0784; num_iterations=2014; early_stopping_rounds=444; feature_fraction=0.476; bagging_fraction=0.553 : y = 0.929 : 180.0 secs : initdesign
#
# [mbo] 0: num_leaves=45; min_child_weight=0.899; min_data_in_leaf=1933; min_gain_to_split=0.06; lambda_l1=0.0629; lambda_l2=0.0782; scale_pos_weight=1.45; learning_rate=0.037; num_iterations=2549; early_stopping_rounds=90; feature_fraction=0.651; bagging_fraction=0.763 : y = 0.928 : 111.2 secs : initdesign
#
# [mbo] 0: num_leaves=18; min_child_weight=5.43; min_data_in_leaf=2592; min_gain_to_split=0.067; lambda_l1=0.118; lambda_l2=0.479; scale_pos_weight=4.99; learning_rate=0.0768; num_iterations=4880; early_stopping_rounds=325; feature_fraction=0.618; bagging_fraction=0.896 : y = 0.926 : 134.2 secs : initdesign
#
# [mbo] 0: num_leaves=40; min_child_weight=8.04; min_data_in_leaf=4267; min_gain_to_split=0.0828; lambda_l1=0.0957; lambda_l2=0.142; scale_pos_weight=3.58; learning_rate=0.0641; num_iterations=2426; early_stopping_rounds=260; feature_fraction=0.4; bagging_fraction=0.852 : y = 0.929 : 168.4 secs : initdesign
#
# [mbo] 0: num_leaves=31; min_child_weight=8.48; min_data_in_leaf=7154; min_gain_to_split=0.0252; lambda_l1=0.00701; lambda_l2=0.387; scale_pos_weight=1.59; learning_rate=0.033; num_iterations=2662; early_stopping_rounds=205; feature_fraction=0.429; bagging_fraction=0.623 : y = 0.922 : 201.7 secs : initdesign
#
# [mbo] 0: num_leaves=12; min_child_weight=6.29; min_data_in_leaf=1327; min_gain_to_split=0.0625; lambda_l1=0.407; lambda_l2=0.294; scale_pos_weight=3.16; learning_rate=0.0815; num_iterations=3070; early_stopping_rounds=52; feature_fraction=0.357; bagging_fraction=0.588 : y = 0.93 : 98.8 secs : initdesign
#
# [mbo] 0: num_leaves=9; min_child_weight=1.34; min_data_in_leaf=1871; min_gain_to_split=0.0723; lambda_l1=0.304; lambda_l2=0.167; scale_pos_weight=2.42; learning_rate=0.0134; num_iterations=1928; early_stopping_rounds=181; feature_fraction=0.363; bagging_fraction=0.514 : y = 0.915 : 153.2 secs : initdesign
#
# [mbo] 0: num_leaves=37; min_child_weight=9.54; min_data_in_leaf=2454; min_gain_to_split=0.0996; lambda_l1=0.141; lambda_l2=0.058; scale_pos_weight=1.32; learning_rate=0.0826; num_iterations=3986; early_stopping_rounds=159; feature_fraction=0.407; bagging_fraction=0.546 : y = 0.924 : 100.2 secs : initdesign
#
# [mbo] 0: num_leaves=48; min_child_weight=7.27; min_data_in_leaf=4516; min_gain_to_split=0.0134; lambda_l1=0.0211; lambda_l2=0.286; scale_pos_weight=2.31; learning_rate=0.0516; num_iterations=1431; early_stopping_rounds=102; feature_fraction=0.632; bagging_fraction=0.879 : y = 0.925 : 86.1 secs : initdesign
#
# [mbo] 0: num_leaves=4; min_child_weight=0.0647; min_data_in_leaf=5357; min_gain_to_split=0.00549; lambda_l1=0.422; lambda_l2=0.433; scale_pos_weight=2.85; learning_rate=0.0154; num_iterations=1363; early_stopping_rounds=445; feature_fraction=0.642; bagging_fraction=0.607 : y = 0.911 : 80.9 secs : initdesign
#
# [mbo] 0: num_leaves=17; min_child_weight=6.61; min_data_in_leaf=3322; min_gain_to_split=0.0223; lambda_l1=0.165; lambda_l2=0.325; scale_pos_weight=2.67; learning_rate=0.00667; num_iterations=4673; early_stopping_rounds=279; feature_fraction=0.38; bagging_fraction=0.866 : y = 0.923 : 611.0 secs : initdesign
#
# [mbo] 0: num_leaves=46; min_child_weight=7.43; min_data_in_leaf=1485; min_gain_to_split=0.000428; lambda_l1=0.0747; lambda_l2=0.119; scale_pos_weight=4.57; learning_rate=0.0994; num_iterations=3694; early_stopping_rounds=347; feature_fraction=0.531; bagging_fraction=0.665 : y = 0.927 : 133.1 secs : initdesign
#
# [mbo] 0: num_leaves=50; min_child_weight=2.36; min_data_in_leaf=2133; min_gain_to_split=0.0705; lambda_l1=0.047; lambda_l2=0.129; scale_pos_weight=3.04; learning_rate=0.0249; num_iterations=4271; early_stopping_rounds=460; feature_fraction=0.3; bagging_fraction=0.68 : y = 0.93 : 273.2 secs : initdesign
#
# [mbo] 0: num_leaves=52; min_child_weight=2; min_data_in_leaf=4638; min_gain_to_split=0.0245; lambda_l1=0.435; lambda_l2=0.345; scale_pos_weight=1.02; learning_rate=0.0404; num_iterations=1161; early_stopping_rounds=492; feature_fraction=0.446; bagging_fraction=0.753 : y = 0.928 : 182.9 secs : initdesign
#
# [mbo] 0: num_leaves=6; min_child_weight=3.72; min_data_in_leaf=953; min_gain_to_split=0.0978; lambda_l1=0.299; lambda_l2=0.478; scale_pos_weight=2.52; learning_rate=0.0858; num_iterations=2774; early_stopping_rounds=337; feature_fraction=0.739; bagging_fraction=0.786 : y = 0.923 : 167.0 secs : initdesign
#
# [mbo] 0: num_leaves=63; min_child_weight=6.18; min_data_in_leaf=7680; min_gain_to_split=0.0112; lambda_l1=0.465; lambda_l2=0.237; scale_pos_weight=3.31; learning_rate=0.0904; num_iterations=1103; early_stopping_rounds=117; feature_fraction=0.716; bagging_fraction=0.571 : y = 0.916 : 35.1 secs : initdesign
#
# [mbo] 0: num_leaves=41; min_child_weight=3.81; min_data_in_leaf=6245; min_gain_to_split=0.0888; lambda_l1=0.336; lambda_l2=0.415; scale_pos_weight=2.63; learning_rate=0.0669; num_iterations=4432; early_stopping_rounds=191; feature_fraction=0.42; bagging_fraction=0.741 : y = 0.927 : 153.2 secs : initdesign
#
# [mbo] 0: num_leaves=25; min_child_weight=3.19; min_data_in_leaf=6521; min_gain_to_split=0.0743; lambda_l1=0.489; lambda_l2=0.0204; scale_pos_weight=4.8; learning_rate=0.0229; num_iterations=778; early_stopping_rounds=286; feature_fraction=0.722; bagging_fraction=0.53 : y = 0.921 : 87.5 secs : initdesign
#
# [mbo] 0: num_leaves=43; min_child_weight=7.07; min_data_in_leaf=460; min_gain_to_split=0.0797; lambda_l1=0.471; lambda_l2=0.215; scale_pos_weight=1.71; learning_rate=0.0187; num_iterations=3555; early_stopping_rounds=417; feature_fraction=0.692; bagging_fraction=0.727 : y = 0.929 : 225.3 secs : initdesign
#
# [mbo] 0: num_leaves=47; min_child_weight=7.51; min_data_in_leaf=549; min_gain_to_split=0.0628; lambda_l1=0.0161; lambda_l2=0.469; scale_pos_weight=2.8; learning_rate=0.0315; num_iterations=2333; early_stopping_rounds=167; feature_fraction=0.548; bagging_fraction=0.576 : y = 0.93 : 193.9 secs : initdesign
#
# [mbo] 0: num_leaves=59; min_child_weight=0.758; min_data_in_leaf=3979; min_gain_to_split=0.0494; lambda_l1=0.238; lambda_l2=0.183; scale_pos_weight=3.8; learning_rate=0.0117; num_iterations=165; early_stopping_rounds=274; feature_fraction=0.672; bagging_fraction=0.813 : y = 0.911 : 22.2 secs : initdesign
#
# [mbo] 0: num_leaves=55; min_child_weight=4.08; min_data_in_leaf=4817; min_gain_to_split=0.0523; lambda_l1=0.184; lambda_l2=0.105; scale_pos_weight=1.38; learning_rate=0.0761; num_iterations=300; early_stopping_rounds=212; feature_fraction=0.387; bagging_fraction=0.501 : y = 0.92 : 44.1 secs : initdesign
#
# [mbo] 0: num_leaves=14; min_child_weight=8.16; min_data_in_leaf=7947; min_gain_to_split=0.00256; lambda_l1=0.202; lambda_l2=0.305; scale_pos_weight=4.67; learning_rate=0.0571; num_iterations=960; early_stopping_rounds=488; feature_fraction=0.771; bagging_fraction=0.565 : y = 0.917 : 87.6 secs : initdesign
#
# [mbo] 0: num_leaves=10; min_child_weight=5.13; min_data_in_leaf=7195; min_gain_to_split=0.0185; lambda_l1=0.0529; lambda_l2=0.0438; scale_pos_weight=2.07; learning_rate=0.0922; num_iterations=578; early_stopping_rounds=256; feature_fraction=0.737; bagging_fraction=0.83 : y = 0.92 : 48.1 secs : initdesign
#
# [mbo] 0: num_leaves=21; min_child_weight=5.67; min_data_in_leaf=156; min_gain_to_split=0.0834; lambda_l1=0.452; lambda_l2=0.0399; scale_pos_weight=2.42; learning_rate=0.0965; num_iterations=4743; early_stopping_rounds=134; feature_fraction=0.662; bagging_fraction=0.884 : y = 0.923 : 58.5 secs : initdesign
#
# [mbo] 0: num_leaves=35; min_child_weight=4.36; min_data_in_leaf=3454; min_gain_to_split=0.00961; lambda_l1=0.33; lambda_l2=0.44; scale_pos_weight=4.28; learning_rate=0.0486; num_iterations=4930; early_stopping_rounds=464; feature_fraction=0.789; bagging_fraction=0.837 : y = 0.927 : 168.2 secs : initdesign
#
# [mbo] 0: num_leaves=3; min_child_weight=9.67; min_data_in_leaf=5181; min_gain_to_split=0.0275; lambda_l1=0.126; lambda_l2=0.0229; scale_pos_weight=1.88; learning_rate=0.0203; num_iterations=3353; early_stopping_rounds=78; feature_fraction=0.502; bagging_fraction=0.519 : y = 0.913 : 273.5 secs : initdesign
#
# [mbo] 0: num_leaves=54; min_child_weight=0.242; min_data_in_leaf=7805; min_gain_to_split=0.0912; lambda_l1=0.197; lambda_l2=0.176; scale_pos_weight=1.81; learning_rate=0.0419; num_iterations=4138; early_stopping_rounds=434; feature_fraction=0.793; bagging_fraction=0.615 : y = 0.921 : 259.2 secs : initdesign
#
# [mbo] 0: num_leaves=8; min_child_weight=2.15; min_data_in_leaf=6009; min_gain_to_split=0.0427; lambda_l1=0.108; lambda_l2=0.493; scale_pos_weight=4.65; learning_rate=0.0288; num_iterations=1609; early_stopping_rounds=141; feature_fraction=0.336; bagging_fraction=0.742 : y = 0.918 : 151.8 secs : initdesign
#
# [mbo] 0: num_leaves=15; min_child_weight=9.36; min_data_in_leaf=1690; min_gain_to_split=0.0925; lambda_l1=0.25; lambda_l2=0.0645; scale_pos_weight=4.45; learning_rate=0.095; num_iterations=319; early_stopping_rounds=406; feature_fraction=0.586; bagging_fraction=0.717 : y = 0.92 : 44.1 secs : initdesign
#
# [mbo] 0: num_leaves=33; min_child_weight=9.94; min_data_in_leaf=6886; min_gain_to_split=0.0778; lambda_l1=0.491; lambda_l2=0.314; scale_pos_weight=1.22; learning_rate=0.0429; num_iterations=420; early_stopping_rounds=67; feature_fraction=0.559; bagging_fraction=0.771 : y = 0.918 : 71.4 secs : initdesign
#
# [mbo] 0: num_leaves=11; min_child_weight=5.89; min_data_in_leaf=688; min_gain_to_split=0.0202; lambda_l1=0.404; lambda_l2=0.281; scale_pos_weight=1.12; learning_rate=0.0872; num_iterations=3402; early_stopping_rounds=479; feature_fraction=0.329; bagging_fraction=0.847 : y = 0.925 : 207.3 secs : initdesign
#
# [mbo] 0: num_leaves=27; min_child_weight=0.444; min_data_in_leaf=266; min_gain_to_split=0.0754; lambda_l1=0.0324; lambda_l2=0.25; scale_pos_weight=4.22; learning_rate=0.0893; num_iterations=4525; early_stopping_rounds=69; feature_fraction=0.767; bagging_fraction=0.629 : y = 0.93 : 56.8 secs : initdesign
#
# [mbo] 0: num_leaves=60; min_child_weight=8.65; min_data_in_leaf=5592; min_gain_to_split=0.00704; lambda_l1=0.282; lambda_l2=0.0859; scale_pos_weight=4.84; learning_rate=0.00873; num_iterations=1313; early_stopping_rounds=413; feature_fraction=0.352; bagging_fraction=0.644 : y = 0.921 : 179.4 secs : initdesign
#
# Saved the current state after iteration 1 in the file HT.RDATA.
#
# Tue Nov 18 05:22:36 AM 2025 AUC 0.932543557140163
#
# [mbo] 1: num_leaves=50; min_child_weight=7.34; min_data_in_leaf=727; min_gain_to_split=0.053; lambda_l1=0.205; lambda_l2=0.408; scale_pos_weight=4.42; learning_rate=0.0299; num_iterations=2119; early_stopping_rounds=356; feature_fraction=0.321; bagging_fraction=0.753 : y = 0.933 : 160.6 secs : infill_ei
#
# Tue Nov 18 05:25:25 AM 2025 AUC 0.926154348936262
#
# [mbo] 2: num_leaves=50; min_child_weight=3.85; min_data_in_leaf=1268; min_gain_to_split=0.0343; lambda_l1=0.389; lambda_l2=0.249; scale_pos_weight=3.44; learning_rate=0.0407; num_iterations=1037; early_stopping_rounds=440; feature_fraction=0.455; bagging_fraction=0.624 : y = 0.926 : 168.7 secs : infill_ei
#
# Tue Nov 18 05:28:24 AM 2025 AUC 0.931287323786765
#
# [mbo] 3: num_leaves=46; min_child_weight=4.66; min_data_in_leaf=1628; min_gain_to_split=0.0815; lambda_l1=0.161; lambda_l2=0.405; scale_pos_weight=4.19; learning_rate=0.048; num_iterations=2352; early_stopping_rounds=341; feature_fraction=0.355; bagging_fraction=0.785 : y = 0.931 : 178.1 secs : infill_ei
#
# Tue Nov 18 05:30:54 AM 2025 AUC 0.932698237582449
#
# [mbo] 4: num_leaves=49; min_child_weight=4.84; min_data_in_leaf=782; min_gain_to_split=0.0467; lambda_l1=0.054; lambda_l2=0.4; scale_pos_weight=2.76; learning_rate=0.0231; num_iterations=1107; early_stopping_rounds=438; feature_fraction=0.323; bagging_fraction=0.878 : y = 0.933 : 148.2 secs : infill_ei
#
# Saved the current state after iteration 5 in the file HT.RDATA.
#
# Tue Nov 18 05:32:56 AM 2025 AUC 0.929514370517706
#
# [mbo] 5: num_leaves=50; min_child_weight=2.9; min_data_in_leaf=284; min_gain_to_split=0.0225; lambda_l1=0.162; lambda_l2=0.425; scale_pos_weight=3.84; learning_rate=0.0463; num_iterations=919; early_stopping_rounds=332; feature_fraction=0.332; bagging_fraction=0.745 : y = 0.93 : 120.8 secs : infill_ei
#
# Tue Nov 18 05:34:25 AM 2025 AUC 0.929802592860273
#
# [mbo] 6: num_leaves=41; min_child_weight=5.64; min_data_in_leaf=1208; min_gain_to_split=0.0602; lambda_l1=0.287; lambda_l2=0.249; scale_pos_weight=4.14; learning_rate=0.0661; num_iterations=3787; early_stopping_rounds=222; feature_fraction=0.334; bagging_fraction=0.831 : y = 0.93 : 88.5 secs : infill_ei
#
# Tue Nov 18 05:37:46 AM 2025 AUC 0.931697344395166
#
# [mbo] 7: num_leaves=49; min_child_weight=2.47; min_data_in_leaf=1030; min_gain_to_split=0.0724; lambda_l1=0.101; lambda_l2=0.283; scale_pos_weight=3.83; learning_rate=0.0306; num_iterations=3456; early_stopping_rounds=268; feature_fraction=0.481; bagging_fraction=0.845 : y = 0.932 : 199.5 secs : infill_ei
#
# Tue Nov 18 05:42:30 AM 2025 AUC 0.930990042069054
#
# [mbo] 8: num_leaves=46; min_child_weight=4.5; min_data_in_leaf=1384; min_gain_to_split=0.00982; lambda_l1=0.144; lambda_l2=0.38; scale_pos_weight=2.66; learning_rate=0.0292; num_iterations=2845; early_stopping_rounds=318; feature_fraction=0.351; bagging_fraction=0.788 : y = 0.931 : 283.3 secs : infill_ei
#
# Saved the current state after iteration 9 in the file HT.RDATA.
#
# Tue Nov 18 05:44:53 AM 2025 AUC 0.927960519914184
#
# [mbo] 9: num_leaves=50; min_child_weight=0.966; min_data_in_leaf=1318; min_gain_to_split=0.0739; lambda_l1=0.0709; lambda_l2=0.448; scale_pos_weight=1.94; learning_rate=0.0293; num_iterations=1033; early_stopping_rounds=429; feature_fraction=0.33; bagging_fraction=0.862 : y = 0.928 : 141.8 secs : infill_ei
#
# Tue Nov 18 05:48:07 AM 2025 AUC 0.932116759911124
#
# [mbo] 10: num_leaves=50; min_child_weight=5.67; min_data_in_leaf=764; min_gain_to_split=0.0653; lambda_l1=0.146; lambda_l2=0.351; scale_pos_weight=2.79; learning_rate=0.0272; num_iterations=1475; early_stopping_rounds=285; feature_fraction=0.303; bagging_fraction=0.811 : y = 0.932 : 192.5 secs : infill_ei
#
# Tue Nov 18 05:52:00 AM 2025 AUC 0.933867903573353
#
# [mbo] 11: num_leaves=51; min_child_weight=4.79; min_data_in_leaf=1815; min_gain_to_split=0.0342; lambda_l1=0.0508; lambda_l2=0.292; scale_pos_weight=4.87; learning_rate=0.0293; num_iterations=3533; early_stopping_rounds=369; feature_fraction=0.314; bagging_fraction=0.892 : y = 0.934 : 232.5 secs : infill_ei
#
# Tue Nov 18 05:55:49 AM 2025 AUC 0.930144164856469
#
# [mbo] 12: num_leaves=50; min_child_weight=5.53; min_data_in_leaf=2837; min_gain_to_split=0.0396; lambda_l1=0.112; lambda_l2=0.346; scale_pos_weight=4.17; learning_rate=0.0429; num_iterations=2718; early_stopping_rounds=470; feature_fraction=0.338; bagging_fraction=0.856 : y = 0.93 : 227.8 secs : infill_ei
#
# Saved the current state after iteration 13 in the file HT.RDATA.
#
# Tue Nov 18 05:57:34 AM 2025 AUC 0.923802266722768
#
# [mbo] 13: num_leaves=37; min_child_weight=4.83; min_data_in_leaf=2350; min_gain_to_split=0.052; lambda_l1=0.0582; lambda_l2=0.327; scale_pos_weight=4.27; learning_rate=0.0819; num_iterations=3533; early_stopping_rounds=178; feature_fraction=0.357; bagging_fraction=0.613 : y = 0.924 : 103.7 secs : infill_ei
#
# Tue Nov 18 06:02:25 AM 2025 AUC 0.936394798173898
#
# [mbo] 14: num_leaves=52; min_child_weight=4.72; min_data_in_leaf=725; min_gain_to_split=0.0332; lambda_l1=0.0505; lambda_l2=0.116; scale_pos_weight=4.68; learning_rate=0.0289; num_iterations=2751; early_stopping_rounds=396; feature_fraction=0.381; bagging_fraction=0.841 : y = 0.936 : 289.0 secs : infill_ei
#
# Tue Nov 18 06:04:32 AM 2025 AUC 0.93158628316654
#
# [mbo] 15: num_leaves=55; min_child_weight=4.55; min_data_in_leaf=86; min_gain_to_split=0.0449; lambda_l1=0.043; lambda_l2=0.031; scale_pos_weight=3.83; learning_rate=0.0427; num_iterations=4390; early_stopping_rounds=306; feature_fraction=0.615; bagging_fraction=0.77 : y = 0.932 : 124.8 secs : infill_ei
#
# Tue Nov 18 06:07:30 AM 2025 AUC 0.928637624323147
#
# [mbo] 16: num_leaves=53; min_child_weight=6.2; min_data_in_leaf=960; min_gain_to_split=0.009; lambda_l1=0.0168; lambda_l2=0.116; scale_pos_weight=4.28; learning_rate=0.0216; num_iterations=2389; early_stopping_rounds=427; feature_fraction=0.402; bagging_fraction=0.817 : y = 0.929 : 177.1 secs : infill_ei
#
# Saved the current state after iteration 17 in the file HT.RDATA.
#
# Tue Nov 18 06:11:52 AM 2025 AUC 0.9326364996185
#
# [mbo] 17: num_leaves=48; min_child_weight=5.5; min_data_in_leaf=209; min_gain_to_split=0.0636; lambda_l1=0.121; lambda_l2=0.0373; scale_pos_weight=4.41; learning_rate=0.031; num_iterations=2919; early_stopping_rounds=393; feature_fraction=0.519; bagging_fraction=0.866 : y = 0.933 : 261.0 secs : infill_ei
#
# Tue Nov 18 06:15:03 AM 2025 AUC 0.933615583198953
#
# [mbo] 18: num_leaves=51; min_child_weight=3.73; min_data_in_leaf=705; min_gain_to_split=0.04; lambda_l1=0.0262; lambda_l2=0.128; scale_pos_weight=4.45; learning_rate=0.0367; num_iterations=2766; early_stopping_rounds=295; feature_fraction=0.307; bagging_fraction=0.807 : y = 0.934 : 190.0 secs : infill_ei
#
# Tue Nov 18 06:18:26 AM 2025 AUC 0.932986124392602
#
# [mbo] 19: num_leaves=51; min_child_weight=4.32; min_data_in_leaf=775; min_gain_to_split=0.0403; lambda_l1=0.115; lambda_l2=0.111; scale_pos_weight=3.08; learning_rate=0.0251; num_iterations=3110; early_stopping_rounds=383; feature_fraction=0.356; bagging_fraction=0.847 : y = 0.933 : 201.4 secs : infill_ei
#
# Saved the current state after iteration 20 in the file HT.RDATA.
#
# Tue Nov 18 06:20:43 AM 2025 AUC 0.928058159846299
#
# [mbo] 20: num_leaves=52; min_child_weight=6.14; min_data_in_leaf=378; min_gain_to_split=0.0308; lambda_l1=0.261; lambda_l2=0.314; scale_pos_weight=4.8; learning_rate=0.0597; num_iterations=2800; early_stopping_rounds=427; feature_fraction=0.438; bagging_fraction=0.855 : y = 0.928 : 135.0 secs : infill_ei
#
# Tue Nov 18 06:25:58 AM 2025 AUC 0.930414268448746
#
# [mbo] 21: num_leaves=51; min_child_weight=4.68; min_data_in_leaf=2463; min_gain_to_split=0.0631; lambda_l1=0.239; lambda_l2=0.14; scale_pos_weight=4.72; learning_rate=0.0227; num_iterations=2630; early_stopping_rounds=283; feature_fraction=0.388; bagging_fraction=0.674 : y = 0.93 : 313.6 secs : infill_ei
#
# Tue Nov 18 06:29:25 AM 2025 AUC 0.933413257154054
#
# [mbo] 22: num_leaves=53; min_child_weight=4.54; min_data_in_leaf=359; min_gain_to_split=0.032; lambda_l1=0.038; lambda_l2=0.0305; scale_pos_weight=4.94; learning_rate=0.0315; num_iterations=3387; early_stopping_rounds=262; feature_fraction=0.566; bagging_fraction=0.727 : y = 0.933 : 205.9 secs : infill_ei
#
# Saved the current state after iteration 23 in the file HT.RDATA.
#
# Tue Nov 18 06:33:57 AM 2025 AUC 0.933255221387641
#
# [mbo] 23: num_leaves=51; min_child_weight=4.82; min_data_in_leaf=635; min_gain_to_split=0.0767; lambda_l1=0.149; lambda_l2=0.4; scale_pos_weight=4.81; learning_rate=0.0204; num_iterations=3496; early_stopping_rounds=290; feature_fraction=0.453; bagging_fraction=0.833 : y = 0.933 : 271.0 secs : infill_ei
#
# Tue Nov 18 06:38:53 AM 2025 AUC 0.932558991631151
#
# [mbo] 24: num_leaves=52; min_child_weight=4.41; min_data_in_leaf=120; min_gain_to_split=0.0513; lambda_l1=0.198; lambda_l2=0.261; scale_pos_weight=4.9; learning_rate=0.0314; num_iterations=2648; early_stopping_rounds=350; feature_fraction=0.474; bagging_fraction=0.837 : y = 0.933 : 294.6 secs : infill_ei
#
# Tue Nov 18 06:42:21 AM 2025 AUC 0.929312380005221
#
# [mbo] 25: num_leaves=52; min_child_weight=4.6; min_data_in_leaf=653; min_gain_to_split=0.0527; lambda_l1=0.0425; lambda_l2=0.322; scale_pos_weight=4.61; learning_rate=0.0129; num_iterations=1456; early_stopping_rounds=375; feature_fraction=0.368; bagging_fraction=0.755 : y = 0.929 : 206.6 secs : infill_ei
#
# Saved the current state after iteration 26 in the file HT.RDATA.
#
# Tue Nov 18 06:43:56 AM 2025 AUC 0.922604751541604
#
# [mbo] 26: num_leaves=50; min_child_weight=2.8; min_data_in_leaf=909; min_gain_to_split=0.0806; lambda_l1=0.094; lambda_l2=0.0486; scale_pos_weight=3.77; learning_rate=0.0649; num_iterations=4630; early_stopping_rounds=181; feature_fraction=0.603; bagging_fraction=0.782 : y = 0.923 : 92.9 secs : infill_ei
#
# Tue Nov 18 06:46:09 AM 2025 AUC 0.933521969655791
#
# [mbo] 27: num_leaves=57; min_child_weight=4.52; min_data_in_leaf=398; min_gain_to_split=0.0796; lambda_l1=0.0593; lambda_l2=0.483; scale_pos_weight=4.32; learning_rate=0.0302; num_iterations=2396; early_stopping_rounds=384; feature_fraction=0.674; bagging_fraction=0.636 : y = 0.934 : 131.6 secs : infill_ei
#
# Tue Nov 18 06:50:24 AM 2025 AUC 0.934682240739138
#
# [mbo] 28: num_leaves=52; min_child_weight=4.59; min_data_in_leaf=173; min_gain_to_split=0.066; lambda_l1=0.0599; lambda_l2=0.409; scale_pos_weight=4.75; learning_rate=0.0298; num_iterations=2258; early_stopping_rounds=382; feature_fraction=0.466; bagging_fraction=0.792 : y = 0.935 : 253.7 secs : infill_ei
#
# Tue Nov 18 06:51:53 AM 2025 AUC 0.925839955065499
#
# [mbo] 29: num_leaves=61; min_child_weight=5.72; min_data_in_leaf=3579; min_gain_to_split=0.0817; lambda_l1=0.463; lambda_l2=0.0779; scale_pos_weight=4.35; learning_rate=0.0661; num_iterations=2937; early_stopping_rounds=84; feature_fraction=0.494; bagging_fraction=0.884 : y = 0.926 : 86.4 secs : infill_ei
#
# Tue Nov 18 06:56:48 AM 2025 AUC 0.931857393356056
#
# [mbo] 30: num_leaves=54; min_child_weight=4.45; min_data_in_leaf=1051; min_gain_to_split=0.0443; lambda_l1=0.0308; lambda_l2=0.344; scale_pos_weight=4.68; learning_rate=0.0249; num_iterations=2842; early_stopping_rounds=424; feature_fraction=0.435; bagging_fraction=0.688 : y = 0.932 : 293.8 secs : infill_ei
#
# Saved the current state after iteration 31 in the file HT.RDATA.
#
# Tue Nov 18 07:00:02 AM 2025 AUC 0.925320886422949
#
# [mbo] 31: num_leaves=44; min_child_weight=7.23; min_data_in_leaf=3644; min_gain_to_split=0.093; lambda_l1=0.298; lambda_l2=0.197; scale_pos_weight=4.3; learning_rate=0.0528; num_iterations=3485; early_stopping_rounds=285; feature_fraction=0.592; bagging_fraction=0.629 : y = 0.925 : 192.4 secs : infill_ei
#
# Tue Nov 18 07:04:34 AM 2025 AUC 0.932312375307767
#
# [mbo] 32: num_leaves=53; min_child_weight=5.9; min_data_in_leaf=436; min_gain_to_split=0.031; lambda_l1=0.0627; lambda_l2=0.171; scale_pos_weight=3.98; learning_rate=0.0276; num_iterations=3867; early_stopping_rounds=403; feature_fraction=0.488; bagging_fraction=0.806 : y = 0.932 : 270.8 secs : infill_ei
#
# Tue Nov 18 07:06:38 AM 2025 AUC 0.926478808779407
#
# [mbo] 33: num_leaves=59; min_child_weight=4.23; min_data_in_leaf=3027; min_gain_to_split=0.06; lambda_l1=0.341; lambda_l2=0.158; scale_pos_weight=4.94; learning_rate=0.077; num_iterations=3689; early_stopping_rounds=89; feature_fraction=0.362; bagging_fraction=0.653 : y = 0.926 : 121.8 secs : infill_ei
#
# Tue Nov 18 07:09:12 AM 2025 AUC 0.933535726484714
#
# [mbo] 34: num_leaves=50; min_child_weight=4.82; min_data_in_leaf=813; min_gain_to_split=0.0359; lambda_l1=0.0328; lambda_l2=0.11; scale_pos_weight=4.83; learning_rate=0.0297; num_iterations=917; early_stopping_rounds=382; feature_fraction=0.586; bagging_fraction=0.813 : y = 0.934 : 153.0 secs : infill_ei
#
# Saved the current state after iteration 35 in the file HT.RDATA.
#
# Tue Nov 18 07:13:21 AM 2025 AUC 0.930608206183326
#
# [mbo] 35: num_leaves=51; min_child_weight=4.42; min_data_in_leaf=1188; min_gain_to_split=0.0294; lambda_l1=0.0231; lambda_l2=0.394; scale_pos_weight=3.77; learning_rate=0.0292; num_iterations=1788; early_stopping_rounds=254; feature_fraction=0.334; bagging_fraction=0.762 : y = 0.931 : 247.3 secs : infill_ei
#
# Tue Nov 18 07:16:36 AM 2025 AUC 0.932478128319674
#
# [mbo] 36: num_leaves=45; min_child_weight=4.7; min_data_in_leaf=454; min_gain_to_split=0.0714; lambda_l1=0.0966; lambda_l2=0.0981; scale_pos_weight=4.32; learning_rate=0.032; num_iterations=1426; early_stopping_rounds=442; feature_fraction=0.369; bagging_fraction=0.788 : y = 0.932 : 193.5 secs : infill_ei
#
# Tue Nov 18 07:21:22 AM 2025 AUC 0.93108533327428
#
# [mbo] 37: num_leaves=60; min_child_weight=4.75; min_data_in_leaf=786; min_gain_to_split=0.0749; lambda_l1=0.0672; lambda_l2=0.42; scale_pos_weight=4.53; learning_rate=0.0326; num_iterations=2500; early_stopping_rounds=450; feature_fraction=0.55; bagging_fraction=0.894 : y = 0.931 : 284.4 secs : infill_ei
#
# Saved the current state after iteration 38 in the file HT.RDATA.
#
# Tue Nov 18 07:24:25 AM 2025 AUC 0.930515599237402
#
# [mbo] 38: num_leaves=49; min_child_weight=4.59; min_data_in_leaf=1641; min_gain_to_split=0.0952; lambda_l1=0.0592; lambda_l2=0.214; scale_pos_weight=4.27; learning_rate=0.0278; num_iterations=2425; early_stopping_rounds=162; feature_fraction=0.652; bagging_fraction=0.866 : y = 0.931 : 181.6 secs : infill_ei
#
# Tue Nov 18 07:27:25 AM 2025 AUC 0.929803599457511
#
# [mbo] 39: num_leaves=52; min_child_weight=4.16; min_data_in_leaf=1270; min_gain_to_split=0.0791; lambda_l1=0.0448; lambda_l2=0.0354; scale_pos_weight=2.51; learning_rate=0.0322; num_iterations=2809; early_stopping_rounds=477; feature_fraction=0.634; bagging_fraction=0.892 : y = 0.93 : 178.6 secs : infill_ei
#
# Tue Nov 18 07:30:21 AM 2025 AUC 0.926189579839602
#
# [mbo] 40: num_leaves=52; min_child_weight=4.69; min_data_in_leaf=764; min_gain_to_split=0.0629; lambda_l1=0.0479; lambda_l2=0.311; scale_pos_weight=4.01; learning_rate=0.0346; num_iterations=3109; early_stopping_rounds=385; feature_fraction=0.492; bagging_fraction=0.811 : y = 0.926 : 174.3 secs : infill_ei
#
# Tue Nov 18 07:34:44 AM 2025 AUC 0.933016993374577
#
# [mbo] 41: num_leaves=53; min_child_weight=3.34; min_data_in_leaf=2099; min_gain_to_split=0.00923; lambda_l1=0.282; lambda_l2=0.0597; scale_pos_weight=4.54; learning_rate=0.0298; num_iterations=2957; early_stopping_rounds=437; feature_fraction=0.356; bagging_fraction=0.851 : y = 0.933 : 261.3 secs : infill_ei
#
# Saved the current state after iteration 42 in the file HT.RDATA.
#
# Tue Nov 18 07:37:37 AM 2025 AUC 0.932109378198043
#
# [mbo] 42: num_leaves=51; min_child_weight=2.76; min_data_in_leaf=710; min_gain_to_split=0.0185; lambda_l1=0.177; lambda_l2=0.0471; scale_pos_weight=4.1; learning_rate=0.0455; num_iterations=3449; early_stopping_rounds=260; feature_fraction=0.307; bagging_fraction=0.781 : y = 0.932 : 171.8 secs : infill_ei
#
# Tue Nov 18 07:41:00 AM 2025 AUC 0.928757073862092
#
# [mbo] 43: num_leaves=48; min_child_weight=5.53; min_data_in_leaf=391; min_gain_to_split=0.0739; lambda_l1=0.234; lambda_l2=0.492; scale_pos_weight=4.84; learning_rate=0.0263; num_iterations=2020; early_stopping_rounds=464; feature_fraction=0.678; bagging_fraction=0.661 : y = 0.929 : 201.7 secs : infill_ei
#
# Tue Nov 18 07:45:00 AM 2025 AUC 0.938195600633217
#
# [mbo] 44: num_leaves=58; min_child_weight=3.05; min_data_in_leaf=174; min_gain_to_split=0.0725; lambda_l1=0.13; lambda_l2=0.0394; scale_pos_weight=4.87; learning_rate=0.0287; num_iterations=1845; early_stopping_rounds=371; feature_fraction=0.332; bagging_fraction=0.672 : y = 0.938 : 237.7 secs : infill_ei
#
# Saved the current state after iteration 45 in the file HT.RDATA.
#
# Tue Nov 18 07:48:36 AM 2025 AUC 0.933325683194322
#
# [mbo] 45: num_leaves=63; min_child_weight=4.23; min_data_in_leaf=325; min_gain_to_split=0.0871; lambda_l1=0.0507; lambda_l2=0.00923; scale_pos_weight=3.19; learning_rate=0.0286; num_iterations=3035; early_stopping_rounds=341; feature_fraction=0.379; bagging_fraction=0.653 : y = 0.933 : 214.7 secs : infill_ei
#
# Tue Nov 18 07:50:49 AM 2025 AUC 0.927619283450401
#
# [mbo] 46: num_leaves=45; min_child_weight=4.34; min_data_in_leaf=2; min_gain_to_split=0.0963; lambda_l1=0.266; lambda_l2=0.39; scale_pos_weight=4.52; learning_rate=0.0193; num_iterations=2396; early_stopping_rounds=383; feature_fraction=0.306; bagging_fraction=0.713 : y = 0.928 : 131.6 secs : infill_ei
#
# Tue Nov 18 07:53:56 AM 2025 AUC 0.934708412267333
#
# [mbo] 47: num_leaves=47; min_child_weight=4.5; min_data_in_leaf=1671; min_gain_to_split=0.0143; lambda_l1=0.0236; lambda_l2=0.0115; scale_pos_weight=4.9; learning_rate=0.0402; num_iterations=1294; early_stopping_rounds=179; feature_fraction=0.356; bagging_fraction=0.673 : y = 0.935 : 185.3 secs : infill_ei
#
# Tue Nov 18 07:56:47 AM 2025 AUC 0.937288320989096
#
# [mbo] 48: num_leaves=58; min_child_weight=3.44; min_data_in_leaf=612; min_gain_to_split=0.0563; lambda_l1=0.106; lambda_l2=0.0517; scale_pos_weight=4.88; learning_rate=0.0293; num_iterations=3020; early_stopping_rounds=332; feature_fraction=0.315; bagging_fraction=0.84 : y = 0.937 : 169.2 secs : infill_ei
#
# Saved the current state after iteration 49 in the file HT.RDATA.
#
# Tue Nov 18 07:58:51 AM 2025 AUC 0.930599146808181
#
# [mbo] 49: num_leaves=63; min_child_weight=8.85; min_data_in_leaf=1302; min_gain_to_split=0.0702; lambda_l1=0.101; lambda_l2=0.0723; scale_pos_weight=4.98; learning_rate=0.0296; num_iterations=1659; early_stopping_rounds=224; feature_fraction=0.321; bagging_fraction=0.6 : y = 0.931 : 121.4 secs : infill_ei
#
# Tue Nov 18 08:02:16 AM 2025 AUC 0.930627667063266
#
# [mbo] 50: num_leaves=57; min_child_weight=2.88; min_data_in_leaf=888; min_gain_to_split=0.0819; lambda_l1=0.0554; lambda_l2=0.02; scale_pos_weight=4.87; learning_rate=0.0288; num_iterations=2151; early_stopping_rounds=379; feature_fraction=0.606; bagging_fraction=0.557 : y = 0.931 : 203.7 secs : infill_ei
#
# Tue Nov 18 08:05:17 AM 2025 AUC 0.934764781712678
#
# [mbo] 51: num_leaves=54; min_child_weight=6.33; min_data_in_leaf=679; min_gain_to_split=0.0819; lambda_l1=0.212; lambda_l2=0.0249; scale_pos_weight=4.44; learning_rate=0.0403; num_iterations=1744; early_stopping_rounds=189; feature_fraction=0.369; bagging_fraction=0.673 : y = 0.935 : 179.1 secs : infill_ei
#
# Tue Nov 18 08:09:25 AM 2025 AUC 0.934563126732605
#
# [mbo] 52: num_leaves=61; min_child_weight=3.96; min_data_in_leaf=158; min_gain_to_split=0.0662; lambda_l1=0.394; lambda_l2=0.109; scale_pos_weight=4.97; learning_rate=0.0292; num_iterations=1767; early_stopping_rounds=169; feature_fraction=0.446; bagging_fraction=0.66 : y = 0.935 : 246.0 secs : infill_ei
#
# Saved the current state after iteration 53 in the file HT.RDATA.
#
# Tue Nov 18 08:12:17 AM 2025 AUC 0.935218086002326
#
# [mbo] 53: num_leaves=63; min_child_weight=3.55; min_data_in_leaf=44; min_gain_to_split=0.077; lambda_l1=0.045; lambda_l2=0.00718; scale_pos_weight=4.93; learning_rate=0.0378; num_iterations=2802; early_stopping_rounds=192; feature_fraction=0.361; bagging_fraction=0.794 : y = 0.935 : 171.0 secs : infill_ei
#
# Tue Nov 18 08:13:42 AM 2025 AUC 0.932574426122138
#
# [mbo] 54: num_leaves=52; min_child_weight=2.44; min_data_in_leaf=85; min_gain_to_split=0.0696; lambda_l1=0.348; lambda_l2=0.0163; scale_pos_weight=4.84; learning_rate=0.0277; num_iterations=608; early_stopping_rounds=308; feature_fraction=0.364; bagging_fraction=0.807 : y = 0.933 : 82.7 secs : infill_ei
#
# Tue Nov 18 08:17:29 AM 2025 AUC 0.934756728934772
#
# [mbo] 55: num_leaves=61; min_child_weight=4.06; min_data_in_leaf=101; min_gain_to_split=0.0811; lambda_l1=0.162; lambda_l2=0.338; scale_pos_weight=3.58; learning_rate=0.0282; num_iterations=1347; early_stopping_rounds=361; feature_fraction=0.54; bagging_fraction=0.88 : y = 0.935 : 225.8 secs : infill_ei
#
# Tue Nov 18 08:21:08 AM 2025 AUC 0.926077176481325
#
# [mbo] 56: num_leaves=57; min_child_weight=3.73; min_data_in_leaf=4614; min_gain_to_split=0.0798; lambda_l1=0.117; lambda_l2=0.0366; scale_pos_weight=4.99; learning_rate=0.0413; num_iterations=1961; early_stopping_rounds=241; feature_fraction=0.3; bagging_fraction=0.573 : y = 0.926 : 216.1 secs : infill_ei
#
# Saved the current state after iteration 57 in the file HT.RDATA.
#
# Tue Nov 18 08:23:32 AM 2025 AUC 0.931253770545488
#
# [mbo] 57: num_leaves=58; min_child_weight=5.75; min_data_in_leaf=18; min_gain_to_split=0.0654; lambda_l1=0.0223; lambda_l2=0.0771; scale_pos_weight=4.44; learning_rate=0.0301; num_iterations=1059; early_stopping_rounds=342; feature_fraction=0.323; bagging_fraction=0.73 : y = 0.931 : 142.9 secs : infill_ei
#
# Tue Nov 18 08:25:51 AM 2025 AUC 0.931350068347953
#
# [mbo] 58: num_leaves=54; min_child_weight=5.72; min_data_in_leaf=382; min_gain_to_split=0.0738; lambda_l1=0.0368; lambda_l2=0.0117; scale_pos_weight=4.71; learning_rate=0.0413; num_iterations=2204; early_stopping_rounds=135; feature_fraction=0.321; bagging_fraction=0.84 : y = 0.931 : 136.9 secs : infill_ei
#
# Tue Nov 18 08:27:41 AM 2025 AUC 0.931833235022336
#
# [mbo] 59: num_leaves=57; min_child_weight=3.61; min_data_in_leaf=3; min_gain_to_split=0.0343; lambda_l1=0.156; lambda_l2=0.0795; scale_pos_weight=3.93; learning_rate=0.0382; num_iterations=1986; early_stopping_rounds=164; feature_fraction=0.605; bagging_fraction=0.667 : y = 0.932 : 108.3 secs : infill_ei
#
# Tue Nov 18 08:30:41 AM 2025 AUC 0.934732906133465
#
# [mbo] 60: num_leaves=60; min_child_weight=4.47; min_data_in_leaf=1573; min_gain_to_split=0.0276; lambda_l1=0.354; lambda_l2=0.00411; scale_pos_weight=4.51; learning_rate=0.0379; num_iterations=3715; early_stopping_rounds=126; feature_fraction=0.37; bagging_fraction=0.67 : y = 0.935 : 178.0 secs : infill_ei
#
# Tue Nov 18 08:32:56 AM 2025 AUC 0.929929088579886
#
# [mbo] 61: num_leaves=49; min_child_weight=2.9; min_data_in_leaf=1255; min_gain_to_split=0.06; lambda_l1=0.381; lambda_l2=0.0895; scale_pos_weight=4.77; learning_rate=0.0306; num_iterations=3167; early_stopping_rounds=191; feature_fraction=0.307; bagging_fraction=0.781 : y = 0.93 : 132.8 secs : infill_ei
#
# Saved the current state after iteration 62 in the file HT.RDATA.
#
# Tue Nov 18 08:36:40 AM 2025 AUC 0.93181310307757
#
# [mbo] 62: num_leaves=50; min_child_weight=2.27; min_data_in_leaf=605; min_gain_to_split=0.0351; lambda_l1=0.161; lambda_l2=0.102; scale_pos_weight=4.68; learning_rate=0.0392; num_iterations=3602; early_stopping_rounds=163; feature_fraction=0.381; bagging_fraction=0.871 : y = 0.932 : 221.4 secs : infill_ei
#
# Tue Nov 18 08:39:27 AM 2025 AUC 0.932670723924602
#
# [mbo] 63: num_leaves=62; min_child_weight=4.8; min_data_in_leaf=135; min_gain_to_split=0.0955; lambda_l1=0.227; lambda_l2=0.0562; scale_pos_weight=4.29; learning_rate=0.0301; num_iterations=2954; early_stopping_rounds=312; feature_fraction=0.31; bagging_fraction=0.625 : y = 0.933 : 165.8 secs : infill_ei
#
# Tue Nov 18 08:41:51 AM 2025 AUC 0.930393465439155
#
# [mbo] 64: num_leaves=63; min_child_weight=5.88; min_data_in_leaf=1047; min_gain_to_split=0.0207; lambda_l1=0.181; lambda_l2=0.0509; scale_pos_weight=4.23; learning_rate=0.0374; num_iterations=2620; early_stopping_rounds=82; feature_fraction=0.376; bagging_fraction=0.697 : y = 0.93 : 140.8 secs : infill_ei
#
# Tue Nov 18 08:46:48 AM 2025 AUC 0.93474800509204
#
# [mbo] 65: num_leaves=62; min_child_weight=3.13; min_data_in_leaf=1444; min_gain_to_split=0.0474; lambda_l1=0.0828; lambda_l2=0.3; scale_pos_weight=4.97; learning_rate=0.0285; num_iterations=1905; early_stopping_rounds=403; feature_fraction=0.469; bagging_fraction=0.784 : y = 0.935 : 294.9 secs : infill_ei
#
# Saved the current state after iteration 66 in the file HT.RDATA.
#
# Tue Nov 18 08:48:40 AM 2025 AUC 0.933818580308676
#
# [mbo] 66: num_leaves=50; min_child_weight=3.74; min_data_in_leaf=16; min_gain_to_split=0.0927; lambda_l1=0.136; lambda_l2=0.0157; scale_pos_weight=3.5; learning_rate=0.04; num_iterations=3452; early_stopping_rounds=220; feature_fraction=0.321; bagging_fraction=0.714 : y = 0.934 : 109.6 secs : infill_ei
#
# Tue Nov 18 08:51:20 AM 2025 AUC 0.933584714216978
#
# [mbo] 67: num_leaves=62; min_child_weight=2.42; min_data_in_leaf=243; min_gain_to_split=0.0397; lambda_l1=0.052; lambda_l2=0.296; scale_pos_weight=4.71; learning_rate=0.0284; num_iterations=2405; early_stopping_rounds=377; feature_fraction=0.681; bagging_fraction=0.807 : y = 0.934 : 156.9 secs : infill_ei
#
# Tue Nov 18 08:53:58 AM 2025 AUC 0.927445813193
#
# [mbo] 68: num_leaves=51; min_child_weight=4.89; min_data_in_leaf=820; min_gain_to_split=0.0464; lambda_l1=0.316; lambda_l2=0.0595; scale_pos_weight=4.78; learning_rate=0.0433; num_iterations=3049; early_stopping_rounds=209; feature_fraction=0.423; bagging_fraction=0.683 : y = 0.927 : 156.9 secs : infill_ei
#
# Tue Nov 18 08:57:29 AM 2025 AUC 0.93719537851076
#
# [mbo] 69: num_leaves=59; min_child_weight=4.64; min_data_in_leaf=240; min_gain_to_split=0.0412; lambda_l1=0.142; lambda_l2=0.475; scale_pos_weight=4.99; learning_rate=0.0273; num_iterations=2044; early_stopping_rounds=407; feature_fraction=0.357; bagging_fraction=0.715 : y = 0.937 : 209.0 secs : infill_ei
#
# Saved the current state after iteration 70 in the file HT.RDATA.
#
# Tue Nov 18 08:59:53 AM 2025 AUC 0.929812323300243
#
# [mbo] 70: num_leaves=35; min_child_weight=4.52; min_data_in_leaf=1222; min_gain_to_split=0.04; lambda_l1=0.00237; lambda_l2=0.0423; scale_pos_weight=4.44; learning_rate=0.0385; num_iterations=4037; early_stopping_rounds=208; feature_fraction=0.315; bagging_fraction=0.694 : y = 0.93 : 141.4 secs : infill_ei
#
# Tue Nov 18 09:02:50 AM 2025 AUC 0.935386187741122
#
# [mbo] 71: num_leaves=53; min_child_weight=3.96; min_data_in_leaf=148; min_gain_to_split=0.0151; lambda_l1=0.16; lambda_l2=0.111; scale_pos_weight=4.08; learning_rate=0.0279; num_iterations=1046; early_stopping_rounds=372; feature_fraction=0.54; bagging_fraction=0.651 : y = 0.935 : 174.4 secs : infill_ei
#
# Tue Nov 18 09:07:09 AM 2025 AUC 0.936057252566655
#
# [mbo] 72: num_leaves=60; min_child_weight=0.75; min_data_in_leaf=105; min_gain_to_split=0.0721; lambda_l1=0.172; lambda_l2=0.00896; scale_pos_weight=4.4; learning_rate=0.0287; num_iterations=1823; early_stopping_rounds=327; feature_fraction=0.408; bagging_fraction=0.827 : y = 0.936 : 256.2 secs : infill_ei
#
# Tue Nov 18 09:11:49 AM 2025 AUC 0.930511908380862
#
# [mbo] 73: num_leaves=61; min_child_weight=4.03; min_data_in_leaf=2605; min_gain_to_split=0.0572; lambda_l1=0.277; lambda_l2=0.0317; scale_pos_weight=4.18; learning_rate=0.027; num_iterations=3678; early_stopping_rounds=293; feature_fraction=0.382; bagging_fraction=0.798 : y = 0.931 : 277.0 secs : infill_ei
#
# Saved the current state after iteration 74 in the file HT.RDATA.
#
# Tue Nov 18 09:16:06 AM 2025 AUC 0.938347261283787
#
# [mbo] 74: num_leaves=52; min_child_weight=2.6; min_data_in_leaf=257; min_gain_to_split=0.0172; lambda_l1=0.154; lambda_l2=0.0122; scale_pos_weight=4.64; learning_rate=0.0286; num_iterations=4148; early_stopping_rounds=346; feature_fraction=0.362; bagging_fraction=0.615 : y = 0.938 : 253.3 secs : infill_ei
#
# Tue Nov 18 09:18:44 AM 2025 AUC 0.93212716141592
#
# [mbo] 75: num_leaves=50; min_child_weight=2.06; min_data_in_leaf=13; min_gain_to_split=0.0509; lambda_l1=0.351; lambda_l2=0.0364; scale_pos_weight=4.7; learning_rate=0.0289; num_iterations=4381; early_stopping_rounds=363; feature_fraction=0.364; bagging_fraction=0.727 : y = 0.932 : 156.5 secs : infill_ei
#
# Tue Nov 18 09:23:30 AM 2025 AUC 0.931927184097911
#
# [mbo] 76: num_leaves=51; min_child_weight=6.54; min_data_in_leaf=220; min_gain_to_split=0.0392; lambda_l1=0.152; lambda_l2=0.128; scale_pos_weight=4.49; learning_rate=0.0282; num_iterations=2414; early_stopping_rounds=478; feature_fraction=0.368; bagging_fraction=0.56 : y = 0.932 : 283.5 secs : infill_ei
#
# Saved the current state after iteration 77 in the file HT.RDATA.
#
# Tue Nov 18 09:25:55 AM 2025 AUC 0.935443563783705
#
# [mbo] 77: num_leaves=62; min_child_weight=7.01; min_data_in_leaf=26; min_gain_to_split=0.006; lambda_l1=0.465; lambda_l2=0.17; scale_pos_weight=4.07; learning_rate=0.0291; num_iterations=1779; early_stopping_rounds=88; feature_fraction=0.353; bagging_fraction=0.62 : y = 0.935 : 141.2 secs : infill_ei
#
# Tue Nov 18 09:28:01 AM 2025 AUC 0.931111169270063
#
# [mbo] 78: num_leaves=58; min_child_weight=7.3; min_data_in_leaf=9; min_gain_to_split=0.062; lambda_l1=0.46; lambda_l2=0.0415; scale_pos_weight=3.43; learning_rate=0.0365; num_iterations=1783; early_stopping_rounds=150; feature_fraction=0.355; bagging_fraction=0.658 : y = 0.931 : 124.4 secs : infill_ei
#
# Tue Nov 18 09:30:59 AM 2025 AUC 0.935633475129331
#
# [mbo] 79: num_leaves=61; min_child_weight=4.21; min_data_in_leaf=184; min_gain_to_split=0.00226; lambda_l1=0.38; lambda_l2=0.369; scale_pos_weight=3.8; learning_rate=0.0284; num_iterations=3535; early_stopping_rounds=150; feature_fraction=0.404; bagging_fraction=0.669 : y = 0.936 : 175.6 secs : infill_ei
#
# Tue Nov 18 09:33:01 AM 2025 AUC 0.930717589749887
#
# [mbo] 80: num_leaves=59; min_child_weight=5.12; min_data_in_leaf=25; min_gain_to_split=0.014; lambda_l1=0.46; lambda_l2=0.388; scale_pos_weight=4.65; learning_rate=0.0295; num_iterations=4669; early_stopping_rounds=99; feature_fraction=0.453; bagging_fraction=0.597 : y = 0.931 : 119.7 secs : infill_ei
#
# Tue Nov 18 09:37:06 AM 2025 AUC 0.932476786190023
#
# [mbo] 81: num_leaves=62; min_child_weight=7.39; min_data_in_leaf=474; min_gain_to_split=0.0409; lambda_l1=0.431; lambda_l2=0.282; scale_pos_weight=2.17; learning_rate=0.0277; num_iterations=1781; early_stopping_rounds=405; feature_fraction=0.376; bagging_fraction=0.691 : y = 0.932 : 243.3 secs : infill_ei
#
# Saved the current state after iteration 82 in the file HT.RDATA.
#
# Tue Nov 18 09:41:07 AM 2025 AUC 0.934870138890287
#
# [mbo] 82: num_leaves=52; min_child_weight=2.47; min_data_in_leaf=367; min_gain_to_split=0.0113; lambda_l1=0.133; lambda_l2=0.0266; scale_pos_weight=4.99; learning_rate=0.0286; num_iterations=3255; early_stopping_rounds=394; feature_fraction=0.308; bagging_fraction=0.678 : y = 0.935 : 238.0 secs : infill_ei
#
# Tue Nov 18 09:44:59 AM 2025 AUC 0.934192698948911
#
# [mbo] 83: num_leaves=59; min_child_weight=2.93; min_data_in_leaf=452; min_gain_to_split=0.0257; lambda_l1=0.179; lambda_l2=0.305; scale_pos_weight=3.89; learning_rate=0.0273; num_iterations=1532; early_stopping_rounds=310; feature_fraction=0.405; bagging_fraction=0.843 : y = 0.934 : 230.4 secs : infill_ei
#
# Tue Nov 18 09:46:27 AM 2025 AUC 0.933345144074263
#
# [mbo] 84: num_leaves=61; min_child_weight=3.64; min_data_in_leaf=61; min_gain_to_split=0.0289; lambda_l1=0.233; lambda_l2=0.0506; scale_pos_weight=4.81; learning_rate=0.0385; num_iterations=655; early_stopping_rounds=252; feature_fraction=0.322; bagging_fraction=0.726 : y = 0.933 : 85.0 secs : infill_ei
#
# Tue Nov 18 09:50:07 AM 2025 AUC 0.937940931531927
#
# [mbo] 85: num_leaves=62; min_child_weight=3.31; min_data_in_leaf=31; min_gain_to_split=0.0359; lambda_l1=0.102; lambda_l2=0.0695; scale_pos_weight=4.98; learning_rate=0.0293; num_iterations=4576; early_stopping_rounds=283; feature_fraction=0.373; bagging_fraction=0.635 : y = 0.938 : 217.8 secs : infill_ei
#
# Saved the current state after iteration 86 in the file HT.RDATA.
#
# Tue Nov 18 09:55:40 AM 2025 AUC 0.933246833077322
#
# [mbo] 86: num_leaves=61; min_child_weight=2.66; min_data_in_leaf=27; min_gain_to_split=0.0695; lambda_l1=0.113; lambda_l2=0.498; scale_pos_weight=4.95; learning_rate=0.0243; num_iterations=3906; early_stopping_rounds=407; feature_fraction=0.552; bagging_fraction=0.888 : y = 0.933 : 329.9 secs : infill_ei
#
# Tue Nov 18 10:00:35 AM 2025 AUC 0.933895081698787
#
# [mbo] 87: num_leaves=59; min_child_weight=3.52; min_data_in_leaf=1175; min_gain_to_split=0.00438; lambda_l1=0.151; lambda_l2=0.154; scale_pos_weight=4.89; learning_rate=0.0293; num_iterations=4161; early_stopping_rounds=312; feature_fraction=0.372; bagging_fraction=0.649 : y = 0.934 : 292.3 secs : infill_ei
#
# Saved the current state after iteration 88 in the file HT.RDATA.
#
# Tue Nov 18 10:05:39 AM 2025 AUC 0.933739394659263
#
# [mbo] 88: num_leaves=59; min_child_weight=0.769; min_data_in_leaf=36; min_gain_to_split=0.0113; lambda_l1=0.385; lambda_l2=0.0233; scale_pos_weight=3.01; learning_rate=0.0291; num_iterations=3538; early_stopping_rounds=333; feature_fraction=0.473; bagging_fraction=0.574 : y = 0.934 : 301.1 secs : infill_ei
#
# Tue Nov 18 10:08:22 AM 2025 AUC 0.935898210203004
#
# [mbo] 89: num_leaves=60; min_child_weight=3.58; min_data_in_leaf=169; min_gain_to_split=0.0148; lambda_l1=0.341; lambda_l2=0.00845; scale_pos_weight=3.01; learning_rate=0.03; num_iterations=4073; early_stopping_rounds=167; feature_fraction=0.328; bagging_fraction=0.631 : y = 0.936 : 161.2 secs : infill_ei
#
# Tue Nov 18 10:11:46 AM 2025 AUC 0.93626159180603
#
# [mbo] 90: num_leaves=51; min_child_weight=3.41; min_data_in_leaf=18; min_gain_to_split=0.0783; lambda_l1=0.165; lambda_l2=0.00954; scale_pos_weight=4.18; learning_rate=0.0297; num_iterations=2215; early_stopping_rounds=168; feature_fraction=0.365; bagging_fraction=0.595 : y = 0.936 : 200.9 secs : infill_ei
#
# Saved the current state after iteration 91 in the file HT.RDATA.
#
# Tue Nov 18 10:14:26 AM 2025 AUC 0.93436717580355
#
# [mbo] 91: num_leaves=53; min_child_weight=1.06; min_data_in_leaf=24; min_gain_to_split=0.0644; lambda_l1=0.102; lambda_l2=0.324; scale_pos_weight=4.99; learning_rate=0.0281; num_iterations=1191; early_stopping_rounds=310; feature_fraction=0.364; bagging_fraction=0.804 : y = 0.934 : 157.5 secs : infill_ei
#
# Tue Nov 18 10:17:07 AM 2025 AUC 0.930894079799003
#
# [mbo] 92: num_leaves=60; min_child_weight=4.48; min_data_in_leaf=1047; min_gain_to_split=9.6e-05; lambda_l1=0.426; lambda_l2=0.0226; scale_pos_weight=3.71; learning_rate=0.0339; num_iterations=3238; early_stopping_rounds=220; feature_fraction=0.365; bagging_fraction=0.675 : y = 0.931 : 157.3 secs : infill_ei
#
# Tue Nov 18 10:20:38 AM 2025 AUC 0.935830097123212
#
# [mbo] 93: num_leaves=63; min_child_weight=0.866; min_data_in_leaf=164; min_gain_to_split=0.0389; lambda_l1=0.304; lambda_l2=0.248; scale_pos_weight=4.73; learning_rate=0.0303; num_iterations=1904; early_stopping_rounds=376; feature_fraction=0.333; bagging_fraction=0.611 : y = 0.936 : 208.2 secs : infill_ei
#
# Tue Nov 18 10:23:34 AM 2025 AUC 0.934796321759478
#
# [mbo] 94: num_leaves=58; min_child_weight=2.74; min_data_in_leaf=112; min_gain_to_split=0.0235; lambda_l1=0.21; lambda_l2=0.124; scale_pos_weight=1.38; learning_rate=0.0301; num_iterations=4725; early_stopping_rounds=390; feature_fraction=0.411; bagging_fraction=0.617 : y = 0.935 : 172.9 secs : infill_ei
#
# Saved the current state after iteration 95 in the file HT.RDATA.
#
# Tue Nov 18 10:25:52 AM 2025 AUC 0.932524767325048
#
# [mbo] 95: num_leaves=60; min_child_weight=7.44; min_data_in_leaf=1954; min_gain_to_split=0.0857; lambda_l1=0.429; lambda_l2=0.0459; scale_pos_weight=4.02; learning_rate=0.0404; num_iterations=1082; early_stopping_rounds=143; feature_fraction=0.335; bagging_fraction=0.554 : y = 0.933 : 135.5 secs : infill_ei
#
# Tue Nov 18 10:28:46 AM 2025 AUC 0.93890189636209
#
# [mbo] 96: num_leaves=63; min_child_weight=5.68; min_data_in_leaf=187; min_gain_to_split=0.00147; lambda_l1=0.373; lambda_l2=0.444; scale_pos_weight=4.56; learning_rate=0.0289; num_iterations=2416; early_stopping_rounds=205; feature_fraction=0.376; bagging_fraction=0.588 : y = 0.939 : 171.1 secs : infill_ei
#
# Tue Nov 18 10:30:29 AM 2025 AUC 0.9307494653291
#
# [mbo] 97: num_leaves=61; min_child_weight=7.67; min_data_in_leaf=137; min_gain_to_split=0.0426; lambda_l1=0.311; lambda_l2=0.444; scale_pos_weight=4.26; learning_rate=0.0284; num_iterations=654; early_stopping_rounds=256; feature_fraction=0.406; bagging_fraction=0.628 : y = 0.931 : 99.9 secs : infill_ei
#
# Tue Nov 18 10:33:59 AM 2025 AUC 0.934017215497034
#
# [mbo] 98: num_leaves=59; min_child_weight=2.99; min_data_in_leaf=5; min_gain_to_split=0.081; lambda_l1=0.152; lambda_l2=0.404; scale_pos_weight=2.21; learning_rate=0.0274; num_iterations=3954; early_stopping_rounds=229; feature_fraction=0.362; bagging_fraction=0.56 : y = 0.934 : 207.5 secs : infill_ei
#
# Saved the current state after iteration 99 in the file HT.RDATA.
#
# Tue Nov 18 10:37:25 AM 2025 AUC 0.931964428195728
#
# [mbo] 99: num_leaves=61; min_child_weight=3.61; min_data_in_leaf=132; min_gain_to_split=0.0013; lambda_l1=0.338; lambda_l2=0.398; scale_pos_weight=3.6; learning_rate=0.0278; num_iterations=1857; early_stopping_rounds=281; feature_fraction=0.325; bagging_fraction=0.535 : y = 0.932 : 202.4 secs : infill_ei
#
# Tue Nov 18 10:40:40 AM 2025 AUC 0.930024379785112
#
# [mbo] 100: num_leaves=63; min_child_weight=5.44; min_data_in_leaf=2293; min_gain_to_split=0.052; lambda_l1=0.39; lambda_l2=0.208; scale_pos_weight=4.58; learning_rate=0.0308; num_iterations=1636; early_stopping_rounds=162; feature_fraction=0.334; bagging_fraction=0.651 : y = 0.93 : 191.1 secs : infill_ei
#
# Saved the final state in the file HT.RDATA

# %% [markdown]
# la bayesian optimization ha corrido, extraigo los mejores hiperparametros

# %%
# almaceno los resultados de la Bayesian Optimization
# y capturo los mejores hiperparametros encontrados

tb_bayesiana <- as.data.table(bayesiana_salida$opt.path)

# ordeno en forma descendente por AUC = y
setorder(tb_bayesiana, -y, -num_iterations)

# grabo para eventualmente poder utilizarlos en OTRA corrida
fwrite( tb_bayesiana,
  file="BO_log.txt",
  sep="\t"
)

# los mejores hiperparámetros son los que quedaron en el registro 1 de la tabla
PARAM$out$lgbm$mejores_hiperparametros <- tb_bayesiana[
  1, # el primero es el de mejor AUC
  setdiff(colnames(tb_bayesiana),
    c("y","dob","eol","error.message","exec.time","ei","error.model",
      "train.time","prop.type","propose.time","se","mean","iter")),
  with= FALSE
]

print(PARAM$out$lgbm$mejores_hiperparametros)
# Out:
#    num_leaves min_child_weight min_data_in_leaf min_gain_to_split lambda_l1
#         <int>            <num>            <int>             <num>     <num>
# 1:         63         5.677395              187       0.001467995 0.3733978
#    lambda_l2 scale_pos_weight learning_rate num_iterations
#        <num>            <num>         <num>          <int>
# 1:  0.444067         4.557165    0.02886678           2416
#    early_stopping_rounds feature_fraction bagging_fraction
#                    <int>            <num>            <num>
# 1:                   205        0.3758544        0.5876591

# %% [markdown]
# ### 6.3.3 Produccion

# %% [markdown]
# #### Final Training
# Construyo el modelo final, que es uno solo, no hace ningun tipo de particion < training, validation, testing>]

# %% [markdown]
# ##### Final Training Dataset
#
# Aqui esta la gran decision de en qué meses hago el Final Training
# <br> debo utilizar los mejores hiperparámetros que encontré en la optimización bayesiana

# %%
PARAM$trainingstrategy$final_train <- c(
  202105, 202104, 202103, 202102, 202101,
  202012, 202011, 202010, 202009, 202008, 202007,
  202006, 202005
)

dataset[, fold_final_train := foto_mes %in% PARAM$trainingstrategy$final_train ]

# creo el dfinal_train en formato  LightGBM
dfinal_train <- lgb.Dataset(
  data= data.matrix(dataset[fold_final_train == TRUE, campos_buenos, with= FALSE]),
  label= dataset[fold_final_train == TRUE, clase01],
  free_raw_data= TRUE
)

nrow( dfinal_train) # verifico el tamaño
# Out:
# [1] 207504

# %% [markdown]
# ##### Final Training Hyperparameters

# %%
# uno los parametros fijos y los mejores encontrados de los variables
fijos <- copy(PARAM$lgbm$param_fijos)

# quito lo que optimice en la Bayesian Optimization
fijos$num_iterations <- NULL
fijos$early_stopping_rounds <- NULL

# agrego a los hiperparametros fijos los que encontre con la Bayesian Optimization
param_final <- c(fijos, PARAM$out$lgbm$mejores_hiperparametros)

# Para el entrenamiento final, removemos early_stopping_rounds
# ya que se entrena con todos los datos disponibles y la cantidad de iteraciones
# ya está optimizada en 'num_iterations'.
param_final$early_stopping_rounds <- NULL

# %% [markdown]
# ##### Training
# Genero el modelo final, siempre sobre TODOS los datos de  final_train, sin hacer ningun tipo de undersampling de la clase mayoritaria

# %%
final_model <- lgb.train(
  data= dfinal_train,
  param= param_final,
  verbose= -100
)

# %%
# grabo a disco el modelo en un formato para seres humanos ... ponele ...

lgb.save(final_model, "modelo.txt")

# %%
# ahora imprimo la importancia de variables

tb_importancia <- as.data.table(lgb.importance(final_model))
archivo_importancia <- "impo.txt"

fwrite( tb_importancia,
  file= archivo_importancia,
  sep= "\t"
)

# %% [markdown]
# #### Scoring

# %% [markdown]
# Aplico el modelo final a los datos del futuro

# %%
PARAM$trainingstrategy$future <- c(202107)

dfuture <- dataset[ foto_mes %in% PARAM$trainingstrategy$future ]

# %%
# aplico final_model   a dfuture

prediccion <- predict(
  final_model,
  data.matrix(dfuture[, campos_buenos, with= FALSE])
)

# %% [markdown]
# ##### Tabla Prediccion

# %%
tb_prediccion <- dfuture[, list(numero_de_cliente)]
tb_prediccion[, prob := prediccion]

# grabo las probabilidad del modelo
#  me va a ser util para hacer Ensembles de modelos
fwrite(tb_prediccion,
  file= "prediccion.txt",
  sep= "\t"
)

# %% [markdown]
# #### Curva de Ganancia

# %% [markdown]
# Genero las salidas

# %%
# asigno clase ternaria
tb_prediccion[, clase_ternaria := dfuture$clase_ternaria ]

# asigno ganancias
tb_prediccion[, ganancia := -3000.0 ]
tb_prediccion[clase_ternaria=="BAJA+2", ganancia := 117000.0 ]

# reordeno, y acumulada
setorder( tb_prediccion, -prob )
tb_prediccion[, gan_acum := cumsum(ganancia)]

# media movil de ancho 400
tb_prediccion[,
  gan_suavizada := frollmean(
    x= gan_acum,
    n= 400,
    align= "center",
    na.rm= TRUE,
    hasNA= TRUE
  )
]

# %%
tb_prediccion[, sum(!is.na(gan_suavizada) )]
tb_prediccion[, .N]
# Out:
# [1] 16152
# [1] 16551

# %%
# Este es la ganancia a reportar
resultado <- list()
resultado$ganancia_suavizada_max <- max( tb_prediccion$gan_suavizada, na.rm=TRUE )
options(digits= 8)
resultado$envios <- which.max( tb_prediccion$gan_suavizada)
resultado
# Out:
# $ganancia_suavizada_max
# [1] 5847900
#
# $envios
# [1] 1087

# %%
# grabo las ganancias
fwrite( tb_prediccion,
  file= "ganancias.txt",
  sep= "\t"
)

# %%
# genero el grafico

tb_prediccion[, envios:= .I]

pdf("curva_de_ganancia.pdf")

plot(
  x= tb_prediccion$envios,
  y= tb_prediccion$gan_acum,
  type= "l",
  col= "gray",
  xlim= c(0, 6000),
  ylim= c(0, 8000000),
  main= paste0("Mejor gan prom= ", as.integer(resultado$ganancia_suavizada_max), " envios= ", resultado$envios),
  xlab= "Envios",
  ylab= "Ganancia",
  panel.first= grid()
)

dev.off()
# Out:
# agg_record_1976824002
#                     2

# %%
# grabo los parametros
if( !require("yaml")) install.packages("yaml")
require("yaml")

PARAM$resultado <- resultado

write_yaml( PARAM, file="PARAM.yml")
# Out:
# Loading required package: yaml

# %%
format(Sys.time(), "%a %b %d %X %Y")
fin <- Sys.time()

# Duración en segundos
secs <- as.numeric(difftime(fin, principio, units = "secs"))
secs <- round(secs)

# A hh:mm:ss
h <- secs %/% 3600
m <- (secs %% 3600) %/% 60
s <- secs %% 60
dur_hms <- sprintf("%02d:%02d:%02d", h, m, s)

cat(
  "Inicio: ", format(principio, "%a %b %d %X %Y"), "\n",
  "Fin:    ", format(fin,       "%a %b %d %X %Y"), "\n",
  "Duración (hh:mm:ss): ", dur_hms, "\n",
  sep = ""
)
# Out:
# [1] "Tue Nov 18 10:47:44 AM 2025"
# Inicio: Tue Nov 18 03:00:52 AM 2025
# Fin:    Tue Nov 18 10:47:44 AM 2025
# Duración (hh:mm:ss): 07:46:52
