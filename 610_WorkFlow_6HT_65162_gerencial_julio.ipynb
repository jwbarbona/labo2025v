# %% [markdown]
# <a href="https://colab.research.google.com/github/jwbarbona/labo2025v/blob/main/610_WorkFlow_6HT_65162_gerencial_julio.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # 6 WorkFlow  Gerencial, futuro=JULIO

# %% [markdown]
# ### 6.1 Objetivo

# %% [markdown]
# Presentar un workflow/pipeline completo al que los estudiantes deberán enriquecer

# %% [markdown]
# #### 6.2  Seteo del ambiente en Google Colab

# %% [markdown]
# Esta parte se debe correr con el runtime en Python3
# <br>Ir al menu, Runtime -> Change Runtime Type -> Runtime type ->  **Python 3**

# %% [markdown]
# Conectar la virtual machine donde esta corriendo Google Colab con el  Google Drive, para poder tener persistencia de archivos

# %%
# primero establecer el Runtime de Python 3
from google.colab import drive
drive.mount('/content/.drive')
# Out:
# Mounted at /content/.drive

# %% [markdown]
# Para correr la siguiente celda es fundamental en Arranque en Frio haber copiado el archivo kaggle.json al Google Drive, en la carpeta indicada en el instructivo
#
# <br>los siguientes comando estan en shell script de Linux
# *   Crear las carpetas en el Google Drive
# *   "instalar" el archivo kaggle.json desde el Google Drive a la virtual machine para que pueda ser utilizado por la libreria  kaggle de Python
# *   Bajar el  **dataset_pequeno**  al  Google Drive  y tambien al disco local de la virtual machine que esta corriendo Google Colab
# *   Bajar el **dataset_historico** al Google Drive y tambien al disco local de la virtual machine que esta corriendo Google Colab

# %%
%%shell

mkdir -p "/content/.drive/My Drive/labo1"
mkdir -p "/content/buckets"
ln -s "/content/.drive/My Drive/labo1" /content/buckets/b1

mkdir -p ~/.kaggle
cp /content/buckets/b1/kaggle/kaggle.json  ~/.kaggle
chmod 600 ~/.kaggle/kaggle.json


mkdir -p /content/buckets/b1/exp
mkdir -p /content/buckets/b1/datasets
mkdir -p /content/datasets


webfiles="https://storage.googleapis.com/open-courses/austral2025-af91/"
destino_local="/content/datasets"
destino_bucket="/content/buckets/b1/datasets"


archivo="dataset_pequeno.csv"

if ! test -f $destino_bucket/$archivo; then
  wget  $webfiles/$archivo  -O $destino_bucket/$archivo
fi


if ! test -f $destino_local/$pequeno; then
  cp  $destino_bucket/$archivo  $destino_local/$archivo
fi

#-------

archivo="gerencial_competencia_2025.csv.gz"

if ! test -f $destino_bucket/$archivo; then
  wget  $webfiles/$archivo  -O $destino_bucket/$archivo
fi


if ! test -f $destino_local/$pequeno; then
  cp  $destino_bucket/$archivo  $destino_local/$archivo
fi

# %% [markdown]
# ## 6.3  Workflow

# %% [markdown]
# ## Inicializacion

# %% [markdown]
# Esta parte se debe correr con el runtime en lenguaje **R** Ir al menu, Runtime -> Change Runtime Type -> Runtime type -> R

# %% [markdown]
# limpio el ambiente de R

# %%
format(Sys.time(), "%a %b %d %X %Y")
# Out:
# [1] "Thu Nov 20 06:32:04 PM 2025"

# %%
# limpio la memoria
rm(list=ls(all.names=TRUE)) # remove all objects
gc(full=TRUE, verbose=FALSE) # garbage collection
# Out:
#        used    (Mb) gc trigger (Mb) max used (Mb)
# Ncells  660367 35.3 1454502    77.7 1454502  77.7
# Vcells 1226551  9.4 8388608    64.0 1975136  15.1

# %%
principio <- Sys.time()

# %%
require("data.table")

if( !require("R.utils")) install.packages("R.utils")
require("R.utils")
# Out:
# Loading required package: data.table
#
# Loading required package: R.utils
#
# Warning message in library(package, lib.loc = lib.loc, character.only = TRUE, logical.return = TRUE, :
# “there is no package called ‘R.utils’”
# Installing package into ‘/usr/local/lib/R/site-library’
# (as ‘lib’ is unspecified)
#
# also installing the dependencies ‘R.oo’, ‘R.methodsS3’
#
#
# Loading required package: R.utils
#
# Loading required package: R.oo
#
# Loading required package: R.methodsS3
#
# R.methodsS3 v1.8.2 (2022-06-13 22:00:14 UTC) successfully loaded. See ?R.methodsS3 for help.
#
# R.oo v1.27.1 (2025-05-02 21:00:05 UTC) successfully loaded. See ?R.oo for help.
#
#
# Attaching package: ‘R.oo’
#
#
# The following object is masked from ‘package:R.methodsS3’:
#
#     throw
#
#
# The following objects are masked from ‘package:methods’:
#
#     getClasses, getMethods
#
#
# The following objects are masked from ‘package:base’:
#
#     attach, detach, load, save
#
#
# R.utils v2.13.0 (2025-02-24 21:20:02 UTC) successfully loaded. See ?R.utils for help.
#
#
# Attaching package: ‘R.utils’
#
#
# The following object is masked from ‘package:utils’:
#
#     timestamp
#
#
# The following objects are masked from ‘package:base’:
#
#     cat, commandArgs, getOption, isOpen, nullfile, parse, use, warnings

# %% [markdown]
# #### Parametros
# Si es gerente, no cambie nada
# <br>Si es Analista, cambie el nombre del dataset

# %%
PARAM <- list()
PARAM$semilla_primigenia <- PARAM$semilla_primigenia <- 200003 # 100009, 200003, 499999, 700009, 999983

PARAM$experimento <- 65162 # 6 HT
PARAM$dataset <- "gerencial_competencia_2025.csv.gz"

# %% [markdown]
# #### Carpeta del Experimento

# %%
# carpeta de trabajo

setwd("/content/buckets/b1/exp")
experimento_folder <- paste0("WF", PARAM$experimento)
dir.create(experimento_folder, showWarnings=FALSE)
setwd( paste0("/content/buckets/b1/exp/", experimento_folder ))

# %% [markdown]
# ### 6.3.1   Preprocesamiento del dataset

# %% [markdown]
# #### 6.3.1.1  DT incorporar dataset

# %%
# lectura del dataset
dataset <- fread(paste0("/content/datasets/", PARAM$dataset))

# %% [markdown]
# #### 6.3.1.2  CA  Catastrophe Analysis
# Se intentan reparar las variables que para un mes están con todos los valores en cero.

# %% [markdown]
# El método que se utiliza es **Machine Learning** se asigna NA also valores, si ha leido bien, es la "anti imputación de valores faltantes"
# <br> Usted podrá aplicar aquí otros métodos

# %%
dataset[ foto_mes==202006, internet:=NA]
dataset[ foto_mes==202006, mrentabilidad:=NA]
dataset[ foto_mes==202006, mrentabilidad_annual:=NA]
dataset[ foto_mes==202006, mcomisiones:=NA]
dataset[ foto_mes==202006, mactivos_margen:=NA]
dataset[ foto_mes==202006, mpasivos_margen:=NA]
dataset[ foto_mes==202006, mcuentas_saldo:=NA]
dataset[ foto_mes==202006, ctarjeta_visa_transacciones:=NA]
dataset[ foto_mes==202006, mtarjeta_visa_consumo:=NA]
dataset[ foto_mes==202006, mtarjeta_master_consumo:=NA]
dataset[ foto_mes==202006, ccallcenter_transacciones:=NA]
dataset[ foto_mes==202006, chomebanking_transacciones:=NA]
dataset[ foto_mes==202006, chomebanking_transacciones:=NA]

# %% [markdown]
# #### 6.3.1.3  DR  Data Drifting
# Se intenta corregir el data drifting, quizas ajustando por IPC ...
# <br>Esta parte podrá ser abordada por todos los Analistas y también la Gerenciapero se decide pedagogicamente no incluirla en esta primer version para reducir la carga cognitiva

# %%
# sin codigo en esta primera version del workflow

# %% [markdown]
# #### 6.3.1.3  FE_intra_manual Feature Engineering intra-mes
#
# Agrego campos nuevos dentro del mismo mes, SIN considerar la historia.

# %%
# esta funcion atributos presentes existe debido a que las modalidades poseen datasets con distinta cantidad de campos
atributos_presentes <- function( patributos )
{
  atributos <- unique( patributos )
  comun <- intersect( atributos, colnames(dataset) )

  return(  length( atributos ) == length( comun ) )
}

# el mes 1,2, ..12
if( atributos_presentes( c("foto_mes") ))
  dataset[, kmes := foto_mes %% 100]

# variable extraida de una tesis de maestria de Irlanda
if( atributos_presentes( c("mpayroll", "cliente_edad") ))
  dataset[, mpayroll_sobre_edad := mpayroll / cliente_edad]

# %%
# visualizo las columas del dataset a esta etapa
colnames(dataset)
# Out:
#  [1] "numero_de_cliente"           "foto_mes"
#  [3] "internet"                    "cliente_edad"
#  [5] "cliente_antiguedad"          "mrentabilidad"
#  [7] "mrentabilidad_annual"        "mcomisiones"
#  [9] "mactivos_margen"             "mpasivos_margen"
# [11] "cproductos"                  "mcuenta_corriente"
# [13] "mcaja_ahorro"                "cdescubierto_preacordado"
# [15] "mcuentas_saldo"              "ctarjeta_visa_transacciones"
# [17] "mtarjeta_visa_consumo"       "mtarjeta_master_consumo"
# [19] "mprestamos_personales"       "cpayroll_trx"
# [21] "mpayroll"                    "ccomisiones_mantenimiento"
# [23] "ccallcenter_transacciones"   "chomebanking_transacciones"
# [25] "ctrx_quarter"                "Master_status"
# [27] "Master_fechaalta"            "Master_mpagominimo"
# [29] "Visa_status"                 "Visa_fechaalta"
# [31] "Visa_mpagominimo"            "clase_ternaria"
# [33] "kmes"                        "mpayroll_sobre_edad"

# %% [markdown]
# #### 6.3.1.4  FE_rf Feature Engineering de nuevas variables a partir de hojas de Random Forest
#
# Esto se mostrará unicamente a la *modalidad Analista Sr*

# %%
# No se implementa Feature Engineering a partir de Random Forest

# %% [markdown]
# #### 6.3.1.5  FEhist Feature Engineering historico
#
# El Fature Engineering Histórico es la etapa que más aporta a la ganancia final, ya que enriquece cada registro del dataset con su historia.

# %% [markdown]
# Para cada campo del dataset original (*)
# se crean lo siguientes campos de a partir de la historia
# * lag1  lags de orden 1
# * delta1  =  valor actual - lag1
# * lag2  lags de orden 2
# * delta2  = valor actual - lag2
#
#
# (*) Excepto para los campos  <numero_de_cliente,  foto_mes,  clase_ternaria>

# %%
# Feature Engineering Historico

# todo es lagueable, menos la primary key y la clase
cols_lagueables <- copy( setdiff(
    colnames(dataset),
    c("numero_de_cliente", "foto_mes", "clase_ternaria")
) )

# https://rdrr.io/cran/data.table/man/shift.html

# lags de orden 1
dataset[,
    paste0(cols_lagueables, "_lag1") := shift(.SD, 1, NA, "lag"),
    by = numero_de_cliente,
    .SDcols = cols_lagueables
]

# lags de orden 2
dataset[,
    paste0(cols_lagueables, "_lag2") := shift(.SD, 2, NA, "lag"),
    by = numero_de_cliente,
    .SDcols = cols_lagueables
]

# agrego los delta lags
for (vcol in cols_lagueables)
{
    dataset[, paste0(vcol, "_delta1") := get(vcol) - get(paste0(vcol, "_lag1"))]
    dataset[, paste0(vcol, "_delta2") := get(vcol) - get(paste0(vcol, "_lag2"))]
}

# %% [markdown]
# Verificacion de los campos recien creados

# %%
ncol(dataset)
colnames(dataset)
# Out:
# [1] 158
#   [1] "numero_de_cliente"                  "foto_mes"
#   [3] "internet"                           "cliente_edad"
#   [5] "cliente_antiguedad"                 "mrentabilidad"
#   [7] "mrentabilidad_annual"               "mcomisiones"
#   [9] "mactivos_margen"                    "mpasivos_margen"
#  [11] "cproductos"                         "mcuenta_corriente"
#  [13] "mcaja_ahorro"                       "cdescubierto_preacordado"
#  [15] "mcuentas_saldo"                     "ctarjeta_visa_transacciones"
#  [17] "mtarjeta_visa_consumo"              "mtarjeta_master_consumo"
#  [19] "mprestamos_personales"              "cpayroll_trx"
#  [21] "mpayroll"                           "ccomisiones_mantenimiento"
#  [23] "ccallcenter_transacciones"          "chomebanking_transacciones"
#  [25] "ctrx_quarter"                       "Master_status"
#  [27] "Master_fechaalta"                   "Master_mpagominimo"
#  [29] "Visa_status"                        "Visa_fechaalta"
#  [31] "Visa_mpagominimo"                   "clase_ternaria"
#  [33] "kmes"                               "mpayroll_sobre_edad"
#  [35] "internet_lag1"                      "cliente_edad_lag1"
#  [37] "cliente_antiguedad_lag1"            "mrentabilidad_lag1"
#  [39] "mrentabilidad_annual_lag1"          "mcomisiones_lag1"
#  [41] "mactivos_margen_lag1"               "mpasivos_margen_lag1"
#  [43] "cproductos_lag1"                    "mcuenta_corriente_lag1"
#  [45] "mcaja_ahorro_lag1"                  "cdescubierto_preacordado_lag1"
#  [47] "mcuentas_saldo_lag1"                "ctarjeta_visa_transacciones_lag1"
#  [49] "mtarjeta_visa_consumo_lag1"         "mtarjeta_master_consumo_lag1"
#  [51] "mprestamos_personales_lag1"         "cpayroll_trx_lag1"
#  [53] "mpayroll_lag1"                      "ccomisiones_mantenimiento_lag1"
#  [55] "ccallcenter_transacciones_lag1"     "chomebanking_transacciones_lag1"
#  [57] "ctrx_quarter_lag1"                  "Master_status_lag1"
#  [59] "Master_fechaalta_lag1"              "Master_mpagominimo_lag1"
#  [61] "Visa_status_lag1"                   "Visa_fechaalta_lag1"
#  [63] "Visa_mpagominimo_lag1"              "kmes_lag1"
#  [65] "mpayroll_sobre_edad_lag1"           "internet_lag2"
#  [67] "cliente_edad_lag2"                  "cliente_antiguedad_lag2"
#  [69] "mrentabilidad_lag2"                 "mrentabilidad_annual_lag2"
#  [71] "mcomisiones_lag2"                   "mactivos_margen_lag2"
#  [73] "mpasivos_margen_lag2"               "cproductos_lag2"
#  [75] "mcuenta_corriente_lag2"             "mcaja_ahorro_lag2"
#  [77] "cdescubierto_preacordado_lag2"      "mcuentas_saldo_lag2"
#  [79] "ctarjeta_visa_transacciones_lag2"   "mtarjeta_visa_consumo_lag2"
#  [81] "mtarjeta_master_consumo_lag2"       "mprestamos_personales_lag2"
#  [83] "cpayroll_trx_lag2"                  "mpayroll_lag2"
#  [85] "ccomisiones_mantenimiento_lag2"     "ccallcenter_transacciones_lag2"
#  [87] "chomebanking_transacciones_lag2"    "ctrx_quarter_lag2"
#  [89] "Master_status_lag2"                 "Master_fechaalta_lag2"
#  [91] "Master_mpagominimo_lag2"            "Visa_status_lag2"
#  [93] "Visa_fechaalta_lag2"                "Visa_mpagominimo_lag2"
#  [95] "kmes_lag2"                          "mpayroll_sobre_edad_lag2"
#  [97] "internet_delta1"                    "internet_delta2"
#  [99] "cliente_edad_delta1"                "cliente_edad_delta2"
# [101] "cliente_antiguedad_delta1"          "cliente_antiguedad_delta2"
# [103] "mrentabilidad_delta1"               "mrentabilidad_delta2"
# [105] "mrentabilidad_annual_delta1"        "mrentabilidad_annual_delta2"
# [107] "mcomisiones_delta1"                 "mcomisiones_delta2"
# [109] "mactivos_margen_delta1"             "mactivos_margen_delta2"
# [111] "mpasivos_margen_delta1"             "mpasivos_margen_delta2"
# [113] "cproductos_delta1"                  "cproductos_delta2"
# [115] "mcuenta_corriente_delta1"           "mcuenta_corriente_delta2"
# [117] "mcaja_ahorro_delta1"                "mcaja_ahorro_delta2"
# [119] "cdescubierto_preacordado_delta1"    "cdescubierto_preacordado_delta2"
# [121] "mcuentas_saldo_delta1"              "mcuentas_saldo_delta2"
# [123] "ctarjeta_visa_transacciones_delta1" "ctarjeta_visa_transacciones_delta2"
# [125] "mtarjeta_visa_consumo_delta1"       "mtarjeta_visa_consumo_delta2"
# [127] "mtarjeta_master_consumo_delta1"     "mtarjeta_master_consumo_delta2"
# [129] "mprestamos_personales_delta1"       "mprestamos_personales_delta2"
# [131] "cpayroll_trx_delta1"                "cpayroll_trx_delta2"
# [133] "mpayroll_delta1"                    "mpayroll_delta2"
# [135] "ccomisiones_mantenimiento_delta1"   "ccomisiones_mantenimiento_delta2"
# [137] "ccallcenter_transacciones_delta1"   "ccallcenter_transacciones_delta2"
# [139] "chomebanking_transacciones_delta1"  "chomebanking_transacciones_delta2"
# [141] "ctrx_quarter_delta1"                "ctrx_quarter_delta2"
# [143] "Master_status_delta1"               "Master_status_delta2"
# [145] "Master_fechaalta_delta1"            "Master_fechaalta_delta2"
# [147] "Master_mpagominimo_delta1"          "Master_mpagominimo_delta2"
# [149] "Visa_status_delta1"                 "Visa_status_delta2"
# [151] "Visa_fechaalta_delta1"              "Visa_fechaalta_delta2"
# [153] "Visa_mpagominimo_delta1"            "Visa_mpagominimo_delta2"
# [155] "kmes_delta1"                        "kmes_delta2"
# [157] "mpayroll_sobre_edad_delta1"         "mpayroll_sobre_edad_delta2"

# %% [markdown]
# #### 6.3.1.6  FEhist Reduccion dimensionalidad con canaritos
#
# Esta etapa solo se mostrará a la *modalidad Anlista Sr* por algun canal secreto de forma de no confundir a los *Analista Jr*  nni distraer con detalles operativos a la estratégica *Modalidad Gerencial*

# %%
# No se implementa la reduccion de la dimensionalidad con canaritos

# %% [markdown]
# ### 6.3.2 Modelado

# %% [markdown]
# #### 6.3.2.1 Training Strategy
#
# Esta etapa de Workflow de  Training Strategy esta pensada para la *Modalidad Gerencial* que posee el dataset de [202005, 202109]
# <br> Si usted es un Analista, posee el periodo de [201901, 202109] y deberá experimentar en que meses le conviene experimentar
#
# <br> A la *Modalidad Gerencial* no se le complicada la vida con el undersampling de los continua, por eso PARAM$trainingstrategy$training_pct <- 1.0
# <br> Sin embargo, si usted es  *Analista SR* posee un dataset 50 veces ( filas x columnas) más grande que la *Modalidad Gerencial*  y por un tema de velocidad y experimentación más rápida puede llegar a necesitar activar el undersampling de la clase mayoritaria, a pesar de estar corriendo en Google Cloud.

# %% [markdown]
# Se hace una estrategia de entrenamiento muy sencilla, tomando todos los meses posibles, SIN eliminar nada x pandemia ni por ningun otro motivo
#
# * future = 202107  obviamente completo
#
# * final_train =  [ 202005, 202105 ]  SIN undersampling
#
# * training
#    * testing = NO HAY
#    * validation =  202105   completo, sin undersampling
#    * training = [ 202005, 202104 ]  donde se consideran el 100% de los CONTINUA

# %%
PARAM$trainingstrategy$validate <- c(202105)

PARAM$trainingstrategy$training <- c(
  202104, 202103, 202102, 202101,
  202012, 202011, 202010, 202009, 202008, 202007,
  202006, 202005
)

PARAM$trainingstrategy$training_pct <- 1.0


PARAM$trainingstrategy$positivos <- c( "BAJA+1", "BAJA+2")

# %%
# seteo la clase01   1={BAJA+1, BAJA+2}   0={CONTINUA}
dataset[, clase01 := ifelse( clase_ternaria %in% PARAM$trainingstrategy$positivos, 1, 0 )]

# %%
# los campos en los que se entrena
campos_buenos <- copy( setdiff(
    colnames(dataset), c("clase_ternaria","clase01","azar"))
)

# %%
# preparo para que se puede hacer undersampling de los CONTINUA
#  solamente por un tema de VELOCIDAD
set.seed(PARAM$semilla_primigenia, kind = "L'Ecuyer-CMRG")
dataset[, azar:=runif(nrow(dataset))]

# undersampling de los CONTINUA
dataset[, fold_train :=  foto_mes %in%  PARAM$trainingstrategy$training &
    (clase_ternaria %in% c("BAJA+1", "BAJA+2") |
     azar < PARAM$trainingstrategy$training_pct ) ]


if( !require("lightgbm")) install.packages("lightgbm")
require("lightgbm")

dtrain <- lgb.Dataset(
  data= data.matrix(dataset[fold_train == TRUE, campos_buenos, with = FALSE]),
  label= dataset[fold_train == TRUE, clase01],
  free_raw_data= TRUE
)
# Out:
# Loading required package: lightgbm
#
# Warning message in library(package, lib.loc = lib.loc, character.only = TRUE, logical.return = TRUE, :
# “there is no package called ‘lightgbm’”
# Installing package into ‘/usr/local/lib/R/site-library’
# (as ‘lib’ is unspecified)
#
# Loading required package: lightgbm

# %%
# datos de validation
dvalidate <- lgb.Dataset(
  data= data.matrix(dataset[foto_mes %in% PARAM$trainingstrategy$validate, campos_buenos, with = FALSE]),
  label= dataset[foto_mes %in% PARAM$trainingstrategy$validate, clase01],
  free_raw_data= TRUE
)

nrow(dvalidate)
# Out:
# [1] 16469

# %% [markdown]
# ####  6.3.2.2. Hyperparameter Tuning

# %% [markdown]
# * Clase binaria que se optimiza :  positivos = [ BAJA+1, BAJA+2 ]

# %% [markdown]
# * Metrica que se optimiza **AUC** Area Under Curve de la  ROC Curve
#
# es muy importante notar que intencionalmente  **NO** se está optimizando la funcion de ganancia del problema

# %% [markdown]
# * Cantidad de iteraciones inteligentes de la Optimizacion Bayesiana = **10**

# %% [markdown]
# * Parametros no default, fijos de LightGBM que no se optimizan
#   * max_bin = 31 , Alienigenas Ancestrales contruyeron las pirámides y dejaron a la humanidad en un jeroglifico  *max_bin=31*
#   * feature_fraction = 0.5  para poner algo que generalmente no falla
#   * learning_rate = 0.03  para que aprenda lento

# %% [markdown]
# * Parametros que se optimizan en la Bayesian Optimization
#   * num_leaves  [8, 256]
#   * min_data_in_leaf  [8, 8192]

# %%
# paquetes necesarios para la Bayesian Optimization
if(!require("DiceKriging")) install.packages("DiceKriging")
require("DiceKriging")

if(!require("mlrMBO")) install.packages("mlrMBO")
require("mlrMBO")
# Out:
# Loading required package: DiceKriging
#
# Warning message in library(package, lib.loc = lib.loc, character.only = TRUE, logical.return = TRUE, :
# “there is no package called ‘DiceKriging’”
# Installing package into ‘/usr/local/lib/R/site-library’
# (as ‘lib’ is unspecified)
#
# Loading required package: DiceKriging
#
# Loading required package: mlrMBO
#
# Warning message in library(package, lib.loc = lib.loc, character.only = TRUE, logical.return = TRUE, :
# “there is no package called ‘mlrMBO’”
# Installing package into ‘/usr/local/lib/R/site-library’
# (as ‘lib’ is unspecified)
#
# also installing the dependencies ‘XML’, ‘fastmatch’, ‘RcppArmadillo’, ‘mlr’, ‘ParamHelpers’, ‘smoof’, ‘BBmisc’, ‘checkmate’, ‘lhs’, ‘parallelMap’
#
#
# Loading required package: mlrMBO
#
# Loading required package: mlr
#
# Loading required package: ParamHelpers
#
#
# Attaching package: ‘ParamHelpers’
#
#
# The following object is masked from ‘package:R.utils’:
#
#     isVector
#
#
#
# Attaching package: ‘mlr’
#
#
# The following objects are masked from ‘package:R.utils’:
#
#     resample, setThreshold
#
#
# Loading required package: smoof
#
# Loading required package: checkmate
#
#
# Attaching package: ‘checkmate’
#
#
# The following object is masked from ‘package:DiceKriging’:
#
#     checkNames
#
#
# The following object is masked from ‘package:R.utils’:
#
#     asInt
#
#
#
# Attaching package: ‘smoof’
#
#
# The following objects are masked from ‘package:R.oo’:
#
#     getDescription, getName

# %% [markdown]
# Definición de la Bayesian Optimization
# <br> Si se desea optimizar un hiperparámetro que esta como fijo, debe QUITARSE de param_fijos y agregarse a PARAM$hipeparametertuning$hs

# %%
# valor ridiculamente bajo para que corra rapido en el aula y no molestar a la *Modalidad Gerencial*
PARAM$hipeparametertuning$num_interations <- 60

# parametros fijos del LightGBM
PARAM$lgbm$param_fijos <- list(
  objective= "binary",
  metric= "auc",
  first_metric_only= TRUE,
  boost_from_average= TRUE,
  feature_pre_filter= FALSE,
  verbosity= -100,
  force_row_wise= TRUE, # para evitar warning
  max_bin= 31,
  seed= PARAM$semilla_primigenia
  # learning_rate= 0.03,
  # feature_fraction= 0.5,
  # num_iterations= 2048,  # valor grande, lo limita early_stopping_rounds
  # early_stopping_rounds= 200
)


PARAM$hipeparametertuning$hs <- makeParamSet(
  # Núcleo del modelo (estructura de árboles)
  makeIntegerParam("num_leaves", lower = 2L, upper = 8192L),
  #makeIntegerParam("max_depth", lower = 3L, upper = 30L),
  #makeNumericParam("min_child_weight", lower = 0.001, upper = 10.0),
  makeIntegerParam("min_data_in_leaf", lower = 2L, upper = 8192L),
  #makeNumericParam("min_gain_to_split", lower = 0.0, upper = 0.1),

  # Regularización
  #makeNumericParam("lambda_l1", lower = 0.0, upper = 1000L),
  makeNumericParam("lambda_l2", lower = 0.0, upper = 1000L),
  #makeNumericParam("scale_pos_weight", lower = 1.0, upper = 5.0),  # útil en desequilibrio

  # Control del aprendizaje
  makeNumericParam("learning_rate", lower = 0.005, upper = 0.1),
  makeIntegerParam("num_iterations", lower = 100L, upper = 5000L),
  #makeIntegerParam("early_stopping_rounds", lower = 50L, upper = 500L),

  # Submuestreo
  makeNumericParam("feature_fraction", lower = 0.05, upper = 1L)   # columnas
  #makeNumericParam("bagging_fraction", lower = 0.5, upper = 1L)   # filas
  #makeIntegerParam("bagging_freq", lower = 0L, upper = 5L),         # cada N iteraciones

  # Opcionales útiles
  #makeNumericParam("max_delta_step", lower = 0.0, upper = 10.0),
  #makeNumericParam("path_smooth", lower = 0.0, upper = 10.0)
)
# Total: 6 hT

# %% [markdown]
# Función "señora caja negra"  que es llamada para verificar la realidad por la Bayesian Optimization

# %%
# En  x llegan los parmaetros de la bayesiana
#  devuelve la AUC en validate del modelo entrenado
#  en el parametro x llegan los hiperparámetros que se estan optimizando

EstimarGanancia_AUC_lightgbm <- function(x) {

  # x pisa (o agrega) a param_fijos
  param_completo <- modifyList(PARAM$lgbm$param_fijos, x)

  # entreno LightGBM
  modelo_train <- lgb.train(
    data= dtrain,
    valids= list(valid = dvalidate),
    eval= "auc",
    param= param_completo,
    verbose= -100
  )

  # recupero la AUC en validation
  AUC <- modelo_train$record_evals$valid$auc$eval[[modelo_train$best_iter]]

  # esta es la forma de devolver un parametro extra
  attr(AUC, "extras") <- list("num_iterations"= modelo_train$best_iter)

  # hago espacio en la memoria
  rm(modelo_train)
  gc(full= TRUE, verbose= FALSE)

  message(format(Sys.time(), "%a %b %d %X %Y"), " AUC ", AUC)

  return(AUC)
}

# %% [markdown]
# seteo de la Bayesian Optimization (complejo)
# <br> copiado y pegado de la documentación de la librería

# %%
configureMlr(show.learner.output = FALSE)

# configuro la busqueda bayesiana,  los hiperparametros que se van a optimizar
# por favor, no desesperarse por lo complejo
obj.fun <- makeSingleObjectiveFunction(
    fn= EstimarGanancia_AUC_lightgbm, # la funcion que voy a maximizar
    minimize= FALSE, # estoy Maximizando AUC
    noisy= FALSE,
    par.set= PARAM$hipeparametertuning$hs,
    has.simple.signature= FALSE # paso los parametros en una lista
)

# cada 600 segundos guardo el resultado intermedio
ctrl <- makeMBOControl(
    save.on.disk.at.time= 600,
    save.file.path= "HT.RDATA"
)

# indico la cantidad de iteraciones que va a tener la Bayesian Optimization
ctrl <- setMBOControlTermination(
    ctrl,
    iters= PARAM$hipeparametertuning$num_interations  # cantidad de iteraciones inteligentes
)

# defino el método estandar para la creacion de los puntos iniciales
#   los "No Inteligentes"
ctrl <- setMBOControlInfill(ctrl, crit = makeMBOInfillCritEI())

# mas configuraciones
surr.km <- makeLearner(
    "regr.km",
    predict.type= "se",
    covtype= "matern3_2",
    control= list(trace = TRUE)
)

# %% [markdown]
# Corrida de la Bayesian Optimization,  aqui se hace el trabajo pesado
# <br> por favor no se asuste con los warnings que pudieran aparecer
#
# Si corrío a medias y llegó a las iteraciones inteligentes, en el archivo binario HT.RDATA quedó lo ya procesado y es utilizado para retomar la corrida desde lo último que llegó a grabar.

# %%
# inicio la optimizacion bayesiana

if (!file.exists("HT.RDATA")) {
  bayesiana_salida <- mbo(obj.fun, learner= surr.km, control= ctrl)
} else {
  bayesiana_salida <- mboContinue("HT.RDATA") # retomo en caso que ya exista
}
# Out:
# Computing y column(s) for design. Not provided.
#
# Thu Nov 20 06:49:46 PM 2025 AUC 0.924048547513738
#
# Thu Nov 20 06:53:50 PM 2025 AUC 0.925424230406081
#
# Thu Nov 20 07:01:07 PM 2025 AUC 0.919252782738065
#
# Thu Nov 20 07:04:44 PM 2025 AUC 0.923258704214086
#
# Thu Nov 20 07:08:33 PM 2025 AUC 0.91968025103193
#
# Thu Nov 20 07:11:48 PM 2025 AUC 0.921001242140992
#
# Thu Nov 20 07:17:12 PM 2025 AUC 0.924847785720948
#
# Thu Nov 20 07:21:59 PM 2025 AUC 0.91833409499191
#
# Thu Nov 20 07:32:22 PM 2025 AUC 0.923441904911456
#
# Thu Nov 20 07:34:30 PM 2025 AUC 0.923320777710448
#
# Thu Nov 20 07:39:23 PM 2025 AUC 0.919802049297764
#
# Thu Nov 20 07:42:30 PM 2025 AUC 0.920320111343076
#
# Thu Nov 20 07:47:37 PM 2025 AUC 0.923691205494142
#
# Thu Nov 20 07:54:53 PM 2025 AUC 0.914701285558886
#
# Thu Nov 20 07:58:43 PM 2025 AUC 0.916176621577821
#
# Thu Nov 20 07:58:55 PM 2025 AUC 0.9017708729681
#
# Thu Nov 20 08:06:37 PM 2025 AUC 0.923508004796771
#
# Thu Nov 20 08:13:47 PM 2025 AUC 0.924058949018534
#
# Thu Nov 20 08:15:31 PM 2025 AUC 0.92683212441005
#
# Thu Nov 20 08:18:55 PM 2025 AUC 0.915260953623381
#
# Thu Nov 20 08:21:55 PM 2025 AUC 0.923028193446515
#
# Thu Nov 20 08:23:39 PM 2025 AUC 0.912516969551776
#
# Thu Nov 20 08:25:00 PM 2025 AUC 0.925740973003733
#
# Thu Nov 20 08:26:21 PM 2025 AUC 0.919644684596177
#
# Thu Nov 20 08:28:55 PM 2025 AUC 0.915480056288918
#
# Thu Nov 20 08:32:47 PM 2025 AUC 0.91218277926866
#
# Thu Nov 20 08:39:20 PM 2025 AUC 0.920107048260969
#
# Thu Nov 20 08:47:40 PM 2025 AUC 0.913736629872182
#
# Thu Nov 20 08:48:35 PM 2025 AUC 0.911528491063765
#
# Thu Nov 20 08:50:31 PM 2025 AUC 0.913096769561036
#
# Thu Nov 20 08:57:42 PM 2025 AUC 0.92453876036879
#
# Thu Nov 20 08:59:10 PM 2025 AUC 0.91953597209444
#
# Thu Nov 20 09:04:23 PM 2025 AUC 0.925171238966855
#
# Thu Nov 20 09:05:18 PM 2025 AUC 0.916370894844813
#
# Thu Nov 20 09:08:57 PM 2025 AUC 0.923301987895333
#
# Thu Nov 20 09:13:06 PM 2025 AUC 0.913121934491994
#
# Thu Nov 20 09:13:33 PM 2025 AUC 0.911958643616932
#
# Thu Nov 20 09:24:47 PM 2025 AUC 0.922758089854238
#
# Thu Nov 20 09:26:25 PM 2025 AUC 0.910660804244351
#
# Thu Nov 20 09:28:54 PM 2025 AUC 0.914441583471405
#
# [mbo] 0: num_leaves=3610; min_child_weight=5.27; min_data_in_leaf=5423; lambda_l2=328; scale_pos_weight=2.42; learning_rate=0.0676; num_iterations=3017; early_stopping_rounds=261; feature_fraction=0.225; bagging_fraction=0.581 : y = 0.924 : 302.8 secs : initdesign
#
# [mbo] 0: num_leaves=1661; min_child_weight=4.86; min_data_in_leaf=3200; lambda_l2=158; scale_pos_weight=3.01; learning_rate=0.0403; num_iterations=1704; early_stopping_rounds=353; feature_fraction=0.376; bagging_fraction=0.785 : y = 0.925 : 244.3 secs : initdesign
#
# [mbo] 0: num_leaves=5515; min_child_weight=3.45; min_data_in_leaf=8129; lambda_l2=722; scale_pos_weight=4.83; learning_rate=0.0367; num_iterations=3082; early_stopping_rounds=271; feature_fraction=0.424; bagging_fraction=0.759 : y = 0.919 : 436.8 secs : initdesign
#
# [mbo] 0: num_leaves=5924; min_child_weight=3.7; min_data_in_leaf=3746; lambda_l2=485; scale_pos_weight=2.95; learning_rate=0.0694; num_iterations=3447; early_stopping_rounds=240; feature_fraction=0.0768; bagging_fraction=0.767 : y = 0.923 : 217.0 secs : initdesign
#
# [mbo] 0: num_leaves=4613; min_child_weight=6.67; min_data_in_leaf=1852; lambda_l2=726; scale_pos_weight=3.42; learning_rate=0.0458; num_iterations=1265; early_stopping_rounds=462; feature_fraction=0.554; bagging_fraction=0.658 : y = 0.92 : 229.0 secs : initdesign
#
# [mbo] 0: num_leaves=2139; min_child_weight=4.68; min_data_in_leaf=1577; lambda_l2=413; scale_pos_weight=3.64; learning_rate=0.058; num_iterations=2226; early_stopping_rounds=243; feature_fraction=0.918; bagging_fraction=0.62 : y = 0.921 : 195.1 secs : initdesign
#
# [mbo] 0: num_leaves=6825; min_child_weight=6.93; min_data_in_leaf=2589; lambda_l2=857; scale_pos_weight=2.64; learning_rate=0.0797; num_iterations=2429; early_stopping_rounds=398; feature_fraction=0.323; bagging_fraction=0.862 : y = 0.925 : 324.2 secs : initdesign
#
# [mbo] 0: num_leaves=864; min_child_weight=7.25; min_data_in_leaf=4002; lambda_l2=437; scale_pos_weight=1.8; learning_rate=0.0218; num_iterations=2760; early_stopping_rounds=115; feature_fraction=0.208; bagging_fraction=0.893 : y = 0.918 : 287.3 secs : initdesign
#
# [mbo] 0: num_leaves=4342; min_child_weight=7.02; min_data_in_leaf=1246; lambda_l2=695; scale_pos_weight=2.3; learning_rate=0.0494; num_iterations=4783; early_stopping_rounds=289; feature_fraction=0.482; bagging_fraction=0.802 : y = 0.923 : 622.8 secs : initdesign
#
# [mbo] 0: num_leaves=72; min_child_weight=2.86; min_data_in_leaf=4501; lambda_l2=300; scale_pos_weight=4.4; learning_rate=0.0881; num_iterations=1972; early_stopping_rounds=64; feature_fraction=0.449; bagging_fraction=0.816 : y = 0.923 : 127.6 secs : initdesign
#
# [mbo] 0: num_leaves=5074; min_child_weight=5.98; min_data_in_leaf=7371; lambda_l2=646; scale_pos_weight=3.73; learning_rate=0.0421; num_iterations=3652; early_stopping_rounds=415; feature_fraction=0.109; bagging_fraction=0.631 : y = 0.92 : 292.6 secs : initdesign
#
# [mbo] 0: num_leaves=4775; min_child_weight=0.142; min_data_in_leaf=5561; lambda_l2=239; scale_pos_weight=2.02; learning_rate=0.0502; num_iterations=1669; early_stopping_rounds=443; feature_fraction=0.671; bagging_fraction=0.566 : y = 0.92 : 187.4 secs : initdesign
#
# [mbo] 0: num_leaves=3925; min_child_weight=8.79; min_data_in_leaf=2265; lambda_l2=793; scale_pos_weight=4.72; learning_rate=0.0756; num_iterations=4102; early_stopping_rounds=180; feature_fraction=0.522; bagging_fraction=0.611 : y = 0.924 : 306.8 secs : initdesign
#
# [mbo] 0: num_leaves=5164; min_child_weight=1.79; min_data_in_leaf=6901; lambda_l2=569; scale_pos_weight=2.54; learning_rate=0.0153; num_iterations=4204; early_stopping_rounds=483; feature_fraction=0.775; bagging_fraction=0.97 : y = 0.915 : 436.0 secs : initdesign
#
# [mbo] 0: num_leaves=5962; min_child_weight=1.57; min_data_in_leaf=5756; lambda_l2=608; scale_pos_weight=1.72; learning_rate=0.0856; num_iterations=4681; early_stopping_rounds=161; feature_fraction=0.592; bagging_fraction=0.989 : y = 0.916 : 230.3 secs : initdesign
#
# [mbo] 0: num_leaves=267; min_child_weight=8.08; min_data_in_leaf=2721; lambda_l2=841; scale_pos_weight=4.53; learning_rate=0.0253; num_iterations=103; early_stopping_rounds=186; feature_fraction=0.7; bagging_fraction=0.832 : y = 0.902 : 11.6 secs : initdesign
#
# [mbo] 0: num_leaves=2610; min_child_weight=1.04; min_data_in_leaf=1054; lambda_l2=879; scale_pos_weight=1.91; learning_rate=0.0562; num_iterations=3267; early_stopping_rounds=431; feature_fraction=0.803; bagging_fraction=0.848 : y = 0.924 : 462.2 secs : initdesign
#
# [mbo] 0: num_leaves=1435; min_child_weight=9.92; min_data_in_leaf=6230; lambda_l2=15.1; scale_pos_weight=1.67; learning_rate=0.0626; num_iterations=3673; early_stopping_rounds=382; feature_fraction=0.394; bagging_fraction=0.682 : y = 0.924 : 430.6 secs : initdesign
#
# [mbo] 0: num_leaves=2887; min_child_weight=3.93; min_data_in_leaf=2223; lambda_l2=47; scale_pos_weight=2.88; learning_rate=0.0356; num_iterations=814; early_stopping_rounds=360; feature_fraction=0.267; bagging_fraction=0.72 : y = 0.927 : 103.2 secs : initdesign
#
# [mbo] 0: num_leaves=6694; min_child_weight=9.26; min_data_in_leaf=4707; lambda_l2=665; scale_pos_weight=1.47; learning_rate=0.077; num_iterations=1818; early_stopping_rounds=335; feature_fraction=0.732; bagging_fraction=0.667 : y = 0.915 : 204.5 secs : initdesign
#
# [mbo] 0: num_leaves=3481; min_child_weight=6.33; min_data_in_leaf=551; lambda_l2=110; scale_pos_weight=2.75; learning_rate=0.0906; num_iterations=2354; early_stopping_rounds=405; feature_fraction=0.984; bagging_fraction=0.869 : y = 0.923 : 180.2 secs : initdesign
#
# [mbo] 0: num_leaves=1322; min_child_weight=4.16; min_data_in_leaf=6546; lambda_l2=770; scale_pos_weight=3.37; learning_rate=0.0438; num_iterations=3850; early_stopping_rounds=85; feature_fraction=0.828; bagging_fraction=0.746 : y = 0.913 : 103.5 secs : initdesign
#
# [mbo] 0: num_leaves=6454; min_child_weight=7.73; min_data_in_leaf=5321; lambda_l2=98.4; scale_pos_weight=3.5; learning_rate=0.0949; num_iterations=2145; early_stopping_rounds=129; feature_fraction=0.0616; bagging_fraction=0.591 : y = 0.926 : 80.8 secs : initdesign
#
# [mbo] 0: num_leaves=7236; min_child_weight=2.71; min_data_in_leaf=702; lambda_l2=467; scale_pos_weight=3.26; learning_rate=0.0716; num_iterations=514; early_stopping_rounds=313; feature_fraction=0.837; bagging_fraction=0.502 : y = 0.92 : 81.2 secs : initdesign
#
# [mbo] 0: num_leaves=6229; min_child_weight=0.47; min_data_in_leaf=6983; lambda_l2=920; scale_pos_weight=3.18; learning_rate=0.0833; num_iterations=2854; early_stopping_rounds=308; feature_fraction=0.612; bagging_fraction=0.549 : y = 0.915 : 153.9 secs : initdesign
#
# [mbo] 0: num_leaves=2258; min_child_weight=8.75; min_data_in_leaf=7444; lambda_l2=57.4; scale_pos_weight=4.28; learning_rate=0.00527; num_iterations=1442; early_stopping_rounds=366; feature_fraction=0.543; bagging_fraction=0.558 : y = 0.912 : 232.7 secs : initdesign
#
# [mbo] 0: num_leaves=2759; min_child_weight=5.7; min_data_in_leaf=6727; lambda_l2=390; scale_pos_weight=4.01; learning_rate=0.0133; num_iterations=4395; early_stopping_rounds=204; feature_fraction=0.132; bagging_fraction=0.917 : y = 0.92 : 392.5 secs : initdesign
#
# [mbo] 0: num_leaves=8050; min_child_weight=3.13; min_data_in_leaf=4841; lambda_l2=587; scale_pos_weight=1.33; learning_rate=0.0115; num_iterations=3985; early_stopping_rounds=452; feature_fraction=0.337; bagging_fraction=0.707 : y = 0.914 : 500.1 secs : initdesign
#
# [mbo] 0: num_leaves=1853; min_child_weight=2.11; min_data_in_leaf=5121; lambda_l2=277; scale_pos_weight=1.59; learning_rate=0.0997; num_iterations=1512; early_stopping_rounds=103; feature_fraction=0.969; bagging_fraction=0.909 : y = 0.912 : 54.7 secs : initdesign
#
# [mbo] 0: num_leaves=4291; min_child_weight=9.54; min_data_in_leaf=918; lambda_l2=819; scale_pos_weight=2.13; learning_rate=0.0181; num_iterations=1151; early_stopping_rounds=220; feature_fraction=0.17; bagging_fraction=0.793 : y = 0.913 : 116.6 secs : initdesign
#
# [mbo] 0: num_leaves=7428; min_child_weight=6.03; min_data_in_leaf=6041; lambda_l2=212; scale_pos_weight=3.81; learning_rate=0.0532; num_iterations=4550; early_stopping_rounds=283; feature_fraction=0.9; bagging_fraction=0.519 : y = 0.925 : 430.9 secs : initdesign
#
# [mbo] 0: num_leaves=7663; min_child_weight=8.38; min_data_in_leaf=3040; lambda_l2=185; scale_pos_weight=4.94; learning_rate=0.0299; num_iterations=676; early_stopping_rounds=173; feature_fraction=0.651; bagging_fraction=0.934 : y = 0.92 : 88.2 secs : initdesign
#
# [mbo] 0: num_leaves=7093; min_child_weight=4.39; min_data_in_leaf=106; lambda_l2=963; scale_pos_weight=4.61; learning_rate=0.0323; num_iterations=4321; early_stopping_rounds=79; feature_fraction=0.292; bagging_fraction=0.948 : y = 0.925 : 312.3 secs : initdesign
#
# [mbo] 0: num_leaves=3155; min_child_weight=1.49; min_data_in_leaf=1775; lambda_l2=979; scale_pos_weight=4.47; learning_rate=0.0655; num_iterations=430; early_stopping_rounds=57; feature_fraction=0.93; bagging_fraction=0.639 : y = 0.916 : 54.9 secs : initdesign
#
# [mbo] 0: num_leaves=540; min_child_weight=2.41; min_data_in_leaf=3301; lambda_l2=543; scale_pos_weight=3.92; learning_rate=0.0903; num_iterations=3345; early_stopping_rounds=326; feature_fraction=0.151; bagging_fraction=0.699 : y = 0.923 : 219.7 secs : initdesign
#
# [mbo] 0: num_leaves=1118; min_child_weight=9.24; min_data_in_leaf=7910; lambda_l2=504; scale_pos_weight=1.3; learning_rate=0.0286; num_iterations=2572; early_stopping_rounds=476; feature_fraction=0.742; bagging_fraction=0.982 : y = 0.913 : 248.9 secs : initdesign
#
# [mbo] 0: num_leaves=7947; min_child_weight=0.855; min_data_in_leaf=4291; lambda_l2=144; scale_pos_weight=1.17; learning_rate=0.0597; num_iterations=236; early_stopping_rounds=209; feature_fraction=0.248; bagging_fraction=0.887 : y = 0.912 : 27.1 secs : initdesign
#
# [mbo] 0: num_leaves=3714; min_child_weight=5.14; min_data_in_leaf=229; lambda_l2=252; scale_pos_weight=2.32; learning_rate=0.00827; num_iterations=4990; early_stopping_rounds=128; feature_fraction=0.876; bagging_fraction=0.728 : y = 0.923 : 673.7 secs : initdesign
#
# [mbo] 0: num_leaves=5583; min_child_weight=0.626; min_data_in_leaf=3649; lambda_l2=936; scale_pos_weight=4.16; learning_rate=0.0209; num_iterations=845; early_stopping_rounds=496; feature_fraction=0.627; bagging_fraction=0.962 : y = 0.911 : 98.4 secs : initdesign
#
# [mbo] 0: num_leaves=659; min_child_weight=7.98; min_data_in_leaf=7649; lambda_l2=366; scale_pos_weight=1.06; learning_rate=0.0975; num_iterations=1026; early_stopping_rounds=146; feature_fraction=0.466; bagging_fraction=0.537 : y = 0.914 : 149.0 secs : initdesign
#
# Saved the current state after iteration 1 in the file HT.RDATA.
#
# Thu Nov 20 09:31:55 PM 2025 AUC 0.928465831727811
#
# [mbo] 1: num_leaves=3527; min_child_weight=5.46; min_data_in_leaf=1361; lambda_l2=0.972; scale_pos_weight=2.89; learning_rate=0.0554; num_iterations=2669; early_stopping_rounds=445; feature_fraction=0.169; bagging_fraction=0.665 : y = 0.928 : 179.7 secs : infill_ei
#
# Thu Nov 20 09:35:15 PM 2025 AUC 0.928944636480829
#
# [mbo] 2: num_leaves=6260; min_child_weight=7.75; min_data_in_leaf=1318; lambda_l2=171; scale_pos_weight=4.47; learning_rate=0.0667; num_iterations=3090; early_stopping_rounds=333; feature_fraction=0.267; bagging_fraction=0.84 : y = 0.929 : 198.4 secs : infill_ei
#
# Thu Nov 20 09:40:17 PM 2025 AUC 0.930466275972725
#
# [mbo] 3: num_leaves=5017; min_child_weight=5.38; min_data_in_leaf=2797; lambda_l2=21.8; scale_pos_weight=4.4; learning_rate=0.0607; num_iterations=3443; early_stopping_rounds=319; feature_fraction=0.259; bagging_fraction=0.662 : y = 0.93 : 301.4 secs : infill_ei
#
# Saved the current state after iteration 4 in the file HT.RDATA.
#
# Thu Nov 20 09:44:11 PM 2025 AUC 0.926689187602212
#
# [mbo] 4: num_leaves=3913; min_child_weight=7.18; min_data_in_leaf=3184; lambda_l2=121; scale_pos_weight=4.24; learning_rate=0.0768; num_iterations=3512; early_stopping_rounds=361; feature_fraction=0.22; bagging_fraction=0.676 : y = 0.927 : 233.1 secs : infill_ei
#
# Thu Nov 20 09:46:24 PM 2025 AUC 0.925659438627431
#
# [mbo] 5: num_leaves=5680; min_child_weight=5.05; min_data_in_leaf=1855; lambda_l2=4.38; scale_pos_weight=4.57; learning_rate=0.0608; num_iterations=3797; early_stopping_rounds=167; feature_fraction=0.396; bagging_fraction=0.687 : y = 0.926 : 131.7 secs : infill_ei
#
# Thu Nov 20 09:50:28 PM 2025 AUC 0.928127615055742
#
# [mbo] 6: num_leaves=6380; min_child_weight=5.1; min_data_in_leaf=2810; lambda_l2=27.9; scale_pos_weight=4.56; learning_rate=0.0505; num_iterations=2736; early_stopping_rounds=360; feature_fraction=0.229; bagging_fraction=0.676 : y = 0.928 : 243.6 secs : infill_ei
#
# Saved the current state after iteration 7 in the file HT.RDATA.
#
# Thu Nov 20 09:56:38 PM 2025 AUC 0.929113744816863
#
# [mbo] 7: num_leaves=4282; min_child_weight=4.8; min_data_in_leaf=2355; lambda_l2=169; scale_pos_weight=4.56; learning_rate=0.0594; num_iterations=4205; early_stopping_rounds=429; feature_fraction=0.275; bagging_fraction=0.925 : y = 0.929 : 369.2 secs : infill_ei
#
# Thu Nov 20 09:59:41 PM 2025 AUC 0.927833017597333
#
# [mbo] 8: num_leaves=3159; min_child_weight=2.74; min_data_in_leaf=924; lambda_l2=3.65; scale_pos_weight=4.06; learning_rate=0.0565; num_iterations=2552; early_stopping_rounds=348; feature_fraction=0.284; bagging_fraction=0.726 : y = 0.928 : 181.7 secs : infill_ei
#
# Thu Nov 20 10:02:34 PM 2025 AUC 0.931957717547473
#
# [mbo] 9: num_leaves=4213; min_child_weight=5.53; min_data_in_leaf=2584; lambda_l2=15.3; scale_pos_weight=3.26; learning_rate=0.058; num_iterations=4938; early_stopping_rounds=352; feature_fraction=0.299; bagging_fraction=0.884 : y = 0.932 : 172.7 secs : infill_ei
#
# Saved the current state after iteration 10 in the file HT.RDATA.
#
# Thu Nov 20 10:05:11 PM 2025 AUC 0.933053566407569
#
# [mbo] 10: num_leaves=5967; min_child_weight=9.4; min_data_in_leaf=2299; lambda_l2=29.2; scale_pos_weight=3.47; learning_rate=0.0561; num_iterations=4140; early_stopping_rounds=330; feature_fraction=0.251; bagging_fraction=0.87 : y = 0.933 : 155.8 secs : infill_ei
#
# Thu Nov 20 10:09:25 PM 2025 AUC 0.931398385015391
#
# [mbo] 11: num_leaves=4852; min_child_weight=9.38; min_data_in_leaf=2244; lambda_l2=23.6; scale_pos_weight=3.42; learning_rate=0.048; num_iterations=4509; early_stopping_rounds=316; feature_fraction=0.199; bagging_fraction=0.815 : y = 0.931 : 253.3 secs : infill_ei
#
# Thu Nov 20 10:12:39 PM 2025 AUC 0.929136561020931
#
# [mbo] 12: num_leaves=5836; min_child_weight=8.39; min_data_in_leaf=4147; lambda_l2=2.16; scale_pos_weight=3.69; learning_rate=0.0595; num_iterations=4347; early_stopping_rounds=350; feature_fraction=0.119; bagging_fraction=0.893 : y = 0.929 : 193.4 secs : infill_ei
#
# Saved the current state after iteration 13 in the file HT.RDATA.
#
# Thu Nov 20 10:16:19 PM 2025 AUC 0.928152444454287
#
# [mbo] 13: num_leaves=5740; min_child_weight=5.93; min_data_in_leaf=637; lambda_l2=74.1; scale_pos_weight=3.23; learning_rate=0.0552; num_iterations=4048; early_stopping_rounds=346; feature_fraction=0.396; bagging_fraction=0.903 : y = 0.928 : 218.2 secs : infill_ei
#
# Thu Nov 20 10:19:53 PM 2025 AUC 0.926634160286518
#
# [mbo] 14: num_leaves=4520; min_child_weight=7.38; min_data_in_leaf=2922; lambda_l2=10.2; scale_pos_weight=3.42; learning_rate=0.0555; num_iterations=3873; early_stopping_rounds=315; feature_fraction=0.274; bagging_fraction=0.553 : y = 0.927 : 213.9 secs : infill_ei
#
# Thu Nov 20 10:22:54 PM 2025 AUC 0.929960628626686
#
# [mbo] 15: num_leaves=5009; min_child_weight=9.36; min_data_in_leaf=1915; lambda_l2=1.98; scale_pos_weight=3.13; learning_rate=0.0592; num_iterations=3967; early_stopping_rounds=443; feature_fraction=0.257; bagging_fraction=0.868 : y = 0.93 : 179.8 secs : infill_ei
#
# Saved the current state after iteration 16 in the file HT.RDATA.
#
# Thu Nov 20 10:25:25 PM 2025 AUC 0.930776307922122
#
# [mbo] 16: num_leaves=2535; min_child_weight=7.46; min_data_in_leaf=2388; lambda_l2=8.93; scale_pos_weight=3.69; learning_rate=0.0601; num_iterations=3509; early_stopping_rounds=313; feature_fraction=0.127; bagging_fraction=0.912 : y = 0.931 : 150.5 secs : infill_ei
#
# Thu Nov 20 10:30:13 PM 2025 AUC 0.930865559543917
#
# [mbo] 17: num_leaves=6967; min_child_weight=9.7; min_data_in_leaf=2487; lambda_l2=38.3; scale_pos_weight=3.71; learning_rate=0.0561; num_iterations=4858; early_stopping_rounds=244; feature_fraction=0.282; bagging_fraction=0.939 : y = 0.931 : 286.5 secs : infill_ei
#
# Thu Nov 20 10:32:49 PM 2025 AUC 0.926104019074347
#
# [mbo] 18: num_leaves=5565; min_child_weight=7.9; min_data_in_leaf=2571; lambda_l2=38.9; scale_pos_weight=4; learning_rate=0.0658; num_iterations=4722; early_stopping_rounds=321; feature_fraction=0.361; bagging_fraction=0.894 : y = 0.926 : 155.2 secs : infill_ei
#
# Thu Nov 20 10:37:13 PM 2025 AUC 0.930773623662819
#
# [mbo] 19: num_leaves=4310; min_child_weight=2.64; min_data_in_leaf=2380; lambda_l2=68.7; scale_pos_weight=3.38; learning_rate=0.0543; num_iterations=3681; early_stopping_rounds=318; feature_fraction=0.23; bagging_fraction=0.959 : y = 0.931 : 263.2 secs : infill_ei
#
# Saved the current state after iteration 20 in the file HT.RDATA.
#
# Thu Nov 20 10:39:47 PM 2025 AUC 0.92820747176998
#
# [mbo] 20: num_leaves=3655; min_child_weight=4.75; min_data_in_leaf=2567; lambda_l2=37.3; scale_pos_weight=3.7; learning_rate=0.0567; num_iterations=3633; early_stopping_rounds=347; feature_fraction=0.217; bagging_fraction=0.822 : y = 0.928 : 152.7 secs : infill_ei
#
# Thu Nov 20 10:40:53 PM 2025 AUC 0.926808637141156
#
# [mbo] 21: num_leaves=2094; min_child_weight=8.39; min_data_in_leaf=1266; lambda_l2=2.57; scale_pos_weight=3.36; learning_rate=0.0615; num_iterations=2018; early_stopping_rounds=250; feature_fraction=0.233; bagging_fraction=0.99 : y = 0.927 : 64.9 secs : infill_ei
#
# Thu Nov 20 10:42:47 PM 2025 AUC 0.929190246206974
#
# [mbo] 22: num_leaves=6830; min_child_weight=9.52; min_data_in_leaf=2164; lambda_l2=33.2; scale_pos_weight=3.46; learning_rate=0.0592; num_iterations=3860; early_stopping_rounds=205; feature_fraction=0.083; bagging_fraction=0.922 : y = 0.929 : 113.4 secs : infill_ei
#
# Thu Nov 20 10:50:21 PM 2025 AUC 0.927046529621808
#
# [mbo] 23: num_leaves=7598; min_child_weight=8.2; min_data_in_leaf=3968; lambda_l2=181; scale_pos_weight=3.28; learning_rate=0.0536; num_iterations=4821; early_stopping_rounds=313; feature_fraction=0.242; bagging_fraction=0.927 : y = 0.927 : 452.7 secs : infill_ei
#
# Saved the current state after iteration 24 in the file HT.RDATA.
#
# Thu Nov 20 10:52:30 PM 2025 AUC 0.933020348698705
#
# [mbo] 24: num_leaves=5869; min_child_weight=6.44; min_data_in_leaf=1961; lambda_l2=18.4; scale_pos_weight=3.47; learning_rate=0.0547; num_iterations=1327; early_stopping_rounds=97; feature_fraction=0.285; bagging_fraction=0.906 : y = 0.933 : 127.6 secs : infill_ei
#
# Thu Nov 20 10:54:29 PM 2025 AUC 0.931819813725826
#
# [mbo] 25: num_leaves=5286; min_child_weight=6.32; min_data_in_leaf=2303; lambda_l2=24.3; scale_pos_weight=3.74; learning_rate=0.0606; num_iterations=1502; early_stopping_rounds=164; feature_fraction=0.174; bagging_fraction=0.977 : y = 0.932 : 117.8 secs : infill_ei
#
# Thu Nov 20 10:55:40 PM 2025 AUC 0.9242525512207
#
# [mbo] 26: num_leaves=6939; min_child_weight=6.55; min_data_in_leaf=946; lambda_l2=129; scale_pos_weight=4.2; learning_rate=0.0585; num_iterations=3190; early_stopping_rounds=54; feature_fraction=0.228; bagging_fraction=0.957 : y = 0.924 : 70.3 secs : infill_ei
#
# Thu Nov 20 10:57:18 PM 2025 AUC 0.931115195659016
#
# [mbo] 27: num_leaves=6161; min_child_weight=8.67; min_data_in_leaf=1719; lambda_l2=32; scale_pos_weight=3.52; learning_rate=0.065; num_iterations=680; early_stopping_rounds=266; feature_fraction=0.242; bagging_fraction=0.78 : y = 0.931 : 97.8 secs : infill_ei
#
# Thu Nov 20 11:02:27 PM 2025 AUC 0.925509455638924
#
# [mbo] 28: num_leaves=7373; min_child_weight=5.59; min_data_in_leaf=2225; lambda_l2=471; scale_pos_weight=3.41; learning_rate=0.0636; num_iterations=2929; early_stopping_rounds=150; feature_fraction=0.299; bagging_fraction=0.922 : y = 0.926 : 307.8 secs : infill_ei
#
# Saved the current state after iteration 29 in the file HT.RDATA.
#
# Thu Nov 20 11:05:20 PM 2025 AUC 0.930666588823147
#
# [mbo] 29: num_leaves=5146; min_child_weight=5.79; min_data_in_leaf=2520; lambda_l2=0.431; scale_pos_weight=2.59; learning_rate=0.0601; num_iterations=1175; early_stopping_rounds=344; feature_fraction=0.278; bagging_fraction=0.979 : y = 0.931 : 171.1 secs : infill_ei
#
# Thu Nov 20 11:08:53 PM 2025 AUC 0.931531255850846
#
# [mbo] 30: num_leaves=5952; min_child_weight=8.95; min_data_in_leaf=2353; lambda_l2=14.6; scale_pos_weight=3.4; learning_rate=0.046; num_iterations=1948; early_stopping_rounds=206; feature_fraction=0.267; bagging_fraction=0.915 : y = 0.932 : 211.8 secs : infill_ei
#
# Thu Nov 20 11:11:45 PM 2025 AUC 0.933957490727562
#
# [mbo] 31: num_leaves=5678; min_child_weight=8.38; min_data_in_leaf=2671; lambda_l2=1.67; scale_pos_weight=3.4; learning_rate=0.0564; num_iterations=4367; early_stopping_rounds=243; feature_fraction=0.259; bagging_fraction=0.935 : y = 0.934 : 170.6 secs : infill_ei
#
# Thu Nov 20 11:13:18 PM 2025 AUC 0.926783472210199
#
# [mbo] 32: num_leaves=5621; min_child_weight=4.5; min_data_in_leaf=2248; lambda_l2=31.6; scale_pos_weight=3.2; learning_rate=0.0673; num_iterations=4013; early_stopping_rounds=138; feature_fraction=0.268; bagging_fraction=0.871 : y = 0.927 : 92.3 secs : infill_ei
#
# Saved the current state after iteration 33 in the file HT.RDATA.
#
# Thu Nov 20 11:15:21 PM 2025 AUC 0.930064979207056
#
# [mbo] 33: num_leaves=3014; min_child_weight=5.74; min_data_in_leaf=2035; lambda_l2=111; scale_pos_weight=4.43; learning_rate=0.0626; num_iterations=1236; early_stopping_rounds=236; feature_fraction=0.0857; bagging_fraction=0.772 : y = 0.93 : 121.6 secs : infill_ei
#
# Thu Nov 20 11:19:33 PM 2025 AUC 0.928516832654551
#
# [mbo] 34: num_leaves=3688; min_child_weight=6.98; min_data_in_leaf=2318; lambda_l2=2.25; scale_pos_weight=2.72; learning_rate=0.0537; num_iterations=3121; early_stopping_rounds=311; feature_fraction=0.367; bagging_fraction=0.83 : y = 0.929 : 249.9 secs : infill_ei
#
# Thu Nov 20 11:22:46 PM 2025 AUC 0.932170445097167
#
# [mbo] 35: num_leaves=5645; min_child_weight=6.24; min_data_in_leaf=2587; lambda_l2=4.89; scale_pos_weight=3.3; learning_rate=0.0567; num_iterations=1378; early_stopping_rounds=278; feature_fraction=0.246; bagging_fraction=0.784 : y = 0.932 : 191.3 secs : infill_ei
#
# Thu Nov 20 11:23:40 PM 2025 AUC 0.920952254408728
#
# [mbo] 36: num_leaves=5494; min_child_weight=9; min_data_in_leaf=3042; lambda_l2=15.1; scale_pos_weight=3.52; learning_rate=0.0574; num_iterations=354; early_stopping_rounds=254; feature_fraction=0.267; bagging_fraction=0.887 : y = 0.921 : 52.9 secs : infill_ei
#
# Saved the current state after iteration 37 in the file HT.RDATA.
#
# Thu Nov 20 11:27:17 PM 2025 AUC 0.927054246867302
#
# [mbo] 37: num_leaves=6166; min_child_weight=8.66; min_data_in_leaf=1489; lambda_l2=89.1; scale_pos_weight=3.34; learning_rate=0.0516; num_iterations=3684; early_stopping_rounds=197; feature_fraction=0.222; bagging_fraction=0.655 : y = 0.927 : 215.7 secs : infill_ei
#
# Thu Nov 20 11:29:23 PM 2025 AUC 0.927533722685145
#
# [mbo] 38: num_leaves=6934; min_child_weight=6.72; min_data_in_leaf=2082; lambda_l2=3.12; scale_pos_weight=3.45; learning_rate=0.0617; num_iterations=1475; early_stopping_rounds=411; feature_fraction=0.258; bagging_fraction=0.916 : y = 0.928 : 124.3 secs : infill_ei
#
# Thu Nov 20 11:31:48 PM 2025 AUC 0.930155237426091
#
# [mbo] 39: num_leaves=5649; min_child_weight=8.11; min_data_in_leaf=2141; lambda_l2=28; scale_pos_weight=4.17; learning_rate=0.0649; num_iterations=1038; early_stopping_rounds=135; feature_fraction=0.25; bagging_fraction=0.552 : y = 0.93 : 144.7 secs : infill_ei
#
# Thu Nov 20 11:35:06 PM 2025 AUC 0.931184986400871
#
# [mbo] 40: num_leaves=5483; min_child_weight=7.76; min_data_in_leaf=804; lambda_l2=23.5; scale_pos_weight=3.54; learning_rate=0.0675; num_iterations=1345; early_stopping_rounds=217; feature_fraction=0.248; bagging_fraction=0.71 : y = 0.931 : 195.9 secs : infill_ei
#
# Saved the current state after iteration 41 in the file HT.RDATA.
#
# Thu Nov 20 11:36:14 PM 2025 AUC 0.925601727052435
#
# [mbo] 41: num_leaves=4856; min_child_weight=5.99; min_data_in_leaf=1776; lambda_l2=7.74; scale_pos_weight=2.8; learning_rate=0.052; num_iterations=4825; early_stopping_rounds=95; feature_fraction=0.173; bagging_fraction=0.92 : y = 0.926 : 67.3 secs : infill_ei
#
# Thu Nov 20 11:38:20 PM 2025 AUC 0.931224579225578
#
# [mbo] 42: num_leaves=5411; min_child_weight=7.97; min_data_in_leaf=2103; lambda_l2=8.65; scale_pos_weight=3.17; learning_rate=0.0476; num_iterations=1603; early_stopping_rounds=109; feature_fraction=0.111; bagging_fraction=0.694 : y = 0.931 : 124.6 secs : infill_ei
#
# Thu Nov 20 11:43:38 PM 2025 AUC 0.930395143101219
#
# [mbo] 43: num_leaves=3516; min_child_weight=9.8; min_data_in_leaf=2599; lambda_l2=22.7; scale_pos_weight=3.65; learning_rate=0.049; num_iterations=4292; early_stopping_rounds=269; feature_fraction=0.507; bagging_fraction=0.984 : y = 0.93 : 316.0 secs : infill_ei
#
# Thu Nov 20 11:46:02 PM 2025 AUC 0.931332956194901
#
# [mbo] 44: num_leaves=5234; min_child_weight=1.78; min_data_in_leaf=1428; lambda_l2=3.41; scale_pos_weight=2.9; learning_rate=0.0461; num_iterations=1327; early_stopping_rounds=217; feature_fraction=0.192; bagging_fraction=0.974 : y = 0.931 : 143.5 secs : infill_ei
#
# Saved the current state after iteration 45 in the file HT.RDATA.
#
# Thu Nov 20 11:49:18 PM 2025 AUC 0.93093736348025
#
# [mbo] 45: num_leaves=3683; min_child_weight=7.88; min_data_in_leaf=4754; lambda_l2=13.6; scale_pos_weight=4.46; learning_rate=0.0619; num_iterations=4139; early_stopping_rounds=290; feature_fraction=0.0952; bagging_fraction=0.621 : y = 0.931 : 193.9 secs : infill_ei
#
# Thu Nov 20 11:50:38 PM 2025 AUC 0.926008727869121
#
# [mbo] 46: num_leaves=3475; min_child_weight=9.52; min_data_in_leaf=2631; lambda_l2=1.81; scale_pos_weight=3.5; learning_rate=0.065; num_iterations=4591; early_stopping_rounds=235; feature_fraction=0.147; bagging_fraction=0.98 : y = 0.926 : 78.0 secs : infill_ei
#
# Thu Nov 20 11:52:58 PM 2025 AUC 0.9318664527312
#
# [mbo] 47: num_leaves=5115; min_child_weight=4.09; min_data_in_leaf=1382; lambda_l2=14.4; scale_pos_weight=2.78; learning_rate=0.0579; num_iterations=1035; early_stopping_rounds=142; feature_fraction=0.189; bagging_fraction=0.78 : y = 0.932 : 138.8 secs : infill_ei
#
# Thu Nov 20 11:54:20 PM 2025 AUC 0.926422774866475
#
# [mbo] 48: num_leaves=6122; min_child_weight=7.69; min_data_in_leaf=2110; lambda_l2=42.1; scale_pos_weight=4.52; learning_rate=0.0694; num_iterations=1343; early_stopping_rounds=85; feature_fraction=0.147; bagging_fraction=0.762 : y = 0.926 : 81.2 secs : infill_ei
#
# Thu Nov 20 11:56:59 PM 2025 AUC 0.92717537406831
#
# [mbo] 49: num_leaves=5369; min_child_weight=5.29; min_data_in_leaf=1479; lambda_l2=16.9; scale_pos_weight=2.94; learning_rate=0.0628; num_iterations=1564; early_stopping_rounds=301; feature_fraction=0.125; bagging_fraction=0.676 : y = 0.927 : 157.1 secs : infill_ei
#
# Saved the current state after iteration 50 in the file HT.RDATA.
#
# Fri Nov 21 12:00:11 AM 2025 AUC 0.928080304985542
#
# [mbo] 50: num_leaves=5011; min_child_weight=3.6; min_data_in_leaf=2039; lambda_l2=46; scale_pos_weight=2.98; learning_rate=0.0498; num_iterations=963; early_stopping_rounds=140; feature_fraction=0.557; bagging_fraction=0.79 : y = 0.928 : 190.2 secs : infill_ei
#
# Fri Nov 21 12:02:27 AM 2025 AUC 0.935089912620649
#
# [mbo] 51: num_leaves=5004; min_child_weight=7.88; min_data_in_leaf=682; lambda_l2=6.3; scale_pos_weight=2.08; learning_rate=0.055; num_iterations=1175; early_stopping_rounds=214; feature_fraction=0.271; bagging_fraction=0.983 : y = 0.935 : 134.9 secs : infill_ei
#
# Fri Nov 21 12:06:46 AM 2025 AUC 0.927358574765681
#
# [mbo] 52: num_leaves=4886; min_child_weight=8.19; min_data_in_leaf=492; lambda_l2=159; scale_pos_weight=1.48; learning_rate=0.0538; num_iterations=1845; early_stopping_rounds=141; feature_fraction=0.295; bagging_fraction=0.958 : y = 0.927 : 257.5 secs : infill_ei
#
# Fri Nov 21 12:09:01 AM 2025 AUC 0.928645341568641
#
# [mbo] 53: num_leaves=4860; min_child_weight=8.7; min_data_in_leaf=744; lambda_l2=25; scale_pos_weight=4.33; learning_rate=0.0542; num_iterations=885; early_stopping_rounds=358; feature_fraction=0.245; bagging_fraction=0.671 : y = 0.929 : 134.0 secs : infill_ei
#
# Saved the current state after iteration 54 in the file HT.RDATA.
#
# Fri Nov 21 12:10:53 AM 2025 AUC 0.931026950634458
#
# [mbo] 54: num_leaves=5256; min_child_weight=9.7; min_data_in_leaf=1531; lambda_l2=36.1; scale_pos_weight=3.9; learning_rate=0.0524; num_iterations=1177; early_stopping_rounds=187; feature_fraction=0.241; bagging_fraction=0.885 : y = 0.931 : 109.8 secs : infill_ei
#
# Fri Nov 21 12:12:55 AM 2025 AUC 0.936645776418648
#
# [mbo] 55: num_leaves=5103; min_child_weight=1.42; min_data_in_leaf=651; lambda_l2=0.129; scale_pos_weight=4.68; learning_rate=0.0548; num_iterations=4357; early_stopping_rounds=262; feature_fraction=0.265; bagging_fraction=0.979 : y = 0.937 : 121.4 secs : infill_ei
#
# Fri Nov 21 12:15:25 AM 2025 AUC 0.929090257547969
#
# [mbo] 56: num_leaves=4345; min_child_weight=0.53; min_data_in_leaf=1899; lambda_l2=0.37; scale_pos_weight=4.07; learning_rate=0.0524; num_iterations=4581; early_stopping_rounds=298; feature_fraction=0.264; bagging_fraction=0.967 : y = 0.929 : 148.4 secs : infill_ei
#
# Fri Nov 21 12:18:40 AM 2025 AUC 0.929798902003732
#
# [mbo] 57: num_leaves=6146; min_child_weight=9.81; min_data_in_leaf=1406; lambda_l2=14.5; scale_pos_weight=4.66; learning_rate=0.0493; num_iterations=4248; early_stopping_rounds=248; feature_fraction=0.281; bagging_fraction=0.964 : y = 0.93 : 193.8 secs : infill_ei
#
# Fri Nov 21 12:20:03 AM 2025 AUC 0.932389883295116
#
# [mbo] 58: num_leaves=5174; min_child_weight=4.46; min_data_in_leaf=683; lambda_l2=2.67; scale_pos_weight=3.88; learning_rate=0.0559; num_iterations=1075; early_stopping_rounds=250; feature_fraction=0.269; bagging_fraction=0.995 : y = 0.932 : 82.0 secs : infill_ei
#
# Saved the current state after iteration 59 in the file HT.RDATA.
#
# Fri Nov 21 12:23:58 AM 2025 AUC 0.933204220460901
#
# [mbo] 59: num_leaves=4423; min_child_weight=1.9; min_data_in_leaf=1094; lambda_l2=18.6; scale_pos_weight=2; learning_rate=0.0563; num_iterations=4281; early_stopping_rounds=209; feature_fraction=0.244; bagging_fraction=0.654 : y = 0.933 : 233.6 secs : infill_ei
#
# Fri Nov 21 12:25:59 AM 2025 AUC 0.932303651465035
#
# [mbo] 60: num_leaves=6511; min_child_weight=6.26; min_data_in_leaf=618; lambda_l2=1.56; scale_pos_weight=1.67; learning_rate=0.0461; num_iterations=1182; early_stopping_rounds=208; feature_fraction=0.106; bagging_fraction=0.815 : y = 0.932 : 120.0 secs : infill_ei
#
# Fri Nov 21 12:28:13 AM 2025 AUC 0.929407335678034
#
# [mbo] 61: num_leaves=5958; min_child_weight=1.72; min_data_in_leaf=685; lambda_l2=6.37; scale_pos_weight=4.41; learning_rate=0.0564; num_iterations=4496; early_stopping_rounds=348; feature_fraction=0.165; bagging_fraction=0.903 : y = 0.929 : 132.6 secs : infill_ei
#
# Fri Nov 21 12:29:57 AM 2025 AUC 0.928431942954121
#
# [mbo] 62: num_leaves=5766; min_child_weight=4.31; min_data_in_leaf=761; lambda_l2=0.608; scale_pos_weight=2.15; learning_rate=0.0537; num_iterations=1608; early_stopping_rounds=210; feature_fraction=0.301; bagging_fraction=0.861 : y = 0.928 : 102.1 secs : infill_ei
#
# Fri Nov 21 12:31:59 AM 2025 AUC 0.933047191291726
#
# [mbo] 63: num_leaves=4361; min_child_weight=1.18; min_data_in_leaf=332; lambda_l2=29.1; scale_pos_weight=3.5; learning_rate=0.0555; num_iterations=4137; early_stopping_rounds=195; feature_fraction=0.318; bagging_fraction=0.885 : y = 0.933 : 120.0 secs : infill_ei
#
# Saved the current state after iteration 64 in the file HT.RDATA.
#
# Fri Nov 21 12:35:42 AM 2025 AUC 0.927581368287758
#
# [mbo] 64: num_leaves=5160; min_child_weight=8.75; min_data_in_leaf=2635; lambda_l2=60.6; scale_pos_weight=1.45; learning_rate=0.0579; num_iterations=2888; early_stopping_rounds=297; feature_fraction=0.148; bagging_fraction=0.952 : y = 0.928 : 221.7 secs : infill_ei
#
# Fri Nov 21 12:37:20 AM 2025 AUC 0.932069785373337
#
# [mbo] 65: num_leaves=4917; min_child_weight=1.64; min_data_in_leaf=355; lambda_l2=10.5; scale_pos_weight=4.16; learning_rate=0.0547; num_iterations=4378; early_stopping_rounds=209; feature_fraction=0.427; bagging_fraction=0.619 : y = 0.932 : 97.7 secs : infill_ei
#
# Fri Nov 21 12:40:51 AM 2025 AUC 0.928482272816036
#
# [mbo] 66: num_leaves=3043; min_child_weight=1.8; min_data_in_leaf=2924; lambda_l2=28.5; scale_pos_weight=4.77; learning_rate=0.0574; num_iterations=4282; early_stopping_rounds=248; feature_fraction=0.26; bagging_fraction=0.888 : y = 0.928 : 209.1 secs : infill_ei
#
# Fri Nov 21 12:42:53 AM 2025 AUC 0.933551160975701
#
# [mbo] 67: num_leaves=5853; min_child_weight=1.85; min_data_in_leaf=359; lambda_l2=8.49; scale_pos_weight=2.55; learning_rate=0.0559; num_iterations=4315; early_stopping_rounds=246; feature_fraction=0.419; bagging_fraction=0.987 : y = 0.934 : 120.6 secs : infill_ei
#
# Saved the current state after iteration 68 in the file HT.RDATA.
#
# Fri Nov 21 12:44:13 AM 2025 AUC 0.931130965682416
#
# [mbo] 68: num_leaves=3232; min_child_weight=8.39; min_data_in_leaf=484; lambda_l2=4.78; scale_pos_weight=3.16; learning_rate=0.0649; num_iterations=709; early_stopping_rounds=102; feature_fraction=0.292; bagging_fraction=0.927 : y = 0.931 : 78.6 secs : infill_ei
#
# Fri Nov 21 12:46:18 AM 2025 AUC 0.931434286983557
#
# [mbo] 69: num_leaves=2653; min_child_weight=6.41; min_data_in_leaf=1789; lambda_l2=35.6; scale_pos_weight=2.46; learning_rate=0.0555; num_iterations=1250; early_stopping_rounds=472; feature_fraction=0.133; bagging_fraction=0.961 : y = 0.931 : 122.7 secs : infill_ei
#
# Fri Nov 21 12:47:59 AM 2025 AUC 0.932349283873171
#
# [mbo] 70: num_leaves=3170; min_child_weight=3.03; min_data_in_leaf=165; lambda_l2=1.59; scale_pos_weight=3.08; learning_rate=0.054; num_iterations=4360; early_stopping_rounds=258; feature_fraction=0.278; bagging_fraction=0.896 : y = 0.932 : 100.2 secs : infill_ei
#
# Fri Nov 21 12:49:55 AM 2025 AUC 0.935063405560041
#
# [mbo] 71: num_leaves=3755; min_child_weight=6.41; min_data_in_leaf=203; lambda_l2=8; scale_pos_weight=3.6; learning_rate=0.048; num_iterations=1208; early_stopping_rounds=170; feature_fraction=0.208; bagging_fraction=0.946 : y = 0.935 : 115.0 secs : infill_ei
#
# Fri Nov 21 12:51:38 AM 2025 AUC 0.929749243206643
#
# [mbo] 72: num_leaves=3808; min_child_weight=6.18; min_data_in_leaf=1774; lambda_l2=76.4; scale_pos_weight=2.61; learning_rate=0.0476; num_iterations=1174; early_stopping_rounds=245; feature_fraction=0.0802; bagging_fraction=0.997 : y = 0.93 : 100.4 secs : infill_ei
#
# Fri Nov 21 12:54:04 AM 2025 AUC 0.924156588950649
#
# [mbo] 73: num_leaves=2446; min_child_weight=4.73; min_data_in_leaf=29; lambda_l2=383; scale_pos_weight=1.68; learning_rate=0.061; num_iterations=1194; early_stopping_rounds=191; feature_fraction=0.213; bagging_fraction=0.885 : y = 0.924 : 144.6 secs : infill_ei
#
# Saved the current state after iteration 74 in the file HT.RDATA.
#
# Fri Nov 21 12:56:31 AM 2025 AUC 0.932904925548713
#
# [mbo] 74: num_leaves=5253; min_child_weight=2.25; min_data_in_leaf=913; lambda_l2=2.39; scale_pos_weight=3.14; learning_rate=0.0464; num_iterations=4391; early_stopping_rounds=234; feature_fraction=0.284; bagging_fraction=0.911 : y = 0.933 : 145.9 secs : infill_ei
#
# Fri Nov 21 12:58:31 AM 2025 AUC 0.934930870256998
#
# [mbo] 75: num_leaves=3665; min_child_weight=6.89; min_data_in_leaf=238; lambda_l2=1.02; scale_pos_weight=1.77; learning_rate=0.0468; num_iterations=934; early_stopping_rounds=428; feature_fraction=0.25; bagging_fraction=0.982 : y = 0.935 : 118.3 secs : infill_ei
#
# Fri Nov 21 01:02:58 AM 2025 AUC 0.927197519207553
#
# [mbo] 76: num_leaves=5044; min_child_weight=1.66; min_data_in_leaf=927; lambda_l2=235; scale_pos_weight=3.32; learning_rate=0.055; num_iterations=4251; early_stopping_rounds=272; feature_fraction=0.384; bagging_fraction=0.997 : y = 0.927 : 264.5 secs : infill_ei
#
# Fri Nov 21 01:04:12 AM 2025 AUC 0.939992041171169
#
# [mbo] 77: num_leaves=5013; min_child_weight=4; min_data_in_leaf=24; lambda_l2=0.7; scale_pos_weight=1.27; learning_rate=0.0455; num_iterations=4319; early_stopping_rounds=236; feature_fraction=0.298; bagging_fraction=0.783 : y = 0.94 : 72.7 secs : infill_ei
#
# Saved the current state after iteration 78 in the file HT.RDATA.
#
# Fri Nov 21 01:06:52 AM 2025 AUC 0.934935903243189
#
# [mbo] 78: num_leaves=4870; min_child_weight=4.18; min_data_in_leaf=137; lambda_l2=5.66; scale_pos_weight=1.47; learning_rate=0.0444; num_iterations=3495; early_stopping_rounds=439; feature_fraction=0.324; bagging_fraction=0.652 : y = 0.935 : 158.4 secs : infill_ei
#
# Fri Nov 21 01:09:34 AM 2025 AUC 0.932494904940312
#
# [mbo] 79: num_leaves=6215; min_child_weight=7.44; min_data_in_leaf=728; lambda_l2=0.936; scale_pos_weight=1.46; learning_rate=0.0443; num_iterations=4333; early_stopping_rounds=342; feature_fraction=0.361; bagging_fraction=0.684 : y = 0.932 : 160.9 secs : infill_ei
#
# Fri Nov 21 01:10:21 AM 2025 AUC 0.935817346891527
#
# [mbo] 80: num_leaves=5014; min_child_weight=2.26; min_data_in_leaf=19; lambda_l2=0.39; scale_pos_weight=1.23; learning_rate=0.0442; num_iterations=4124; early_stopping_rounds=81; feature_fraction=0.304; bagging_fraction=0.746 : y = 0.936 : 45.3 secs : infill_ei
#
# Fri Nov 21 01:12:22 AM 2025 AUC 0.933643767921625
#
# [mbo] 81: num_leaves=5837; min_child_weight=0.511; min_data_in_leaf=807; lambda_l2=6.89; scale_pos_weight=1.23; learning_rate=0.0474; num_iterations=3510; early_stopping_rounds=284; feature_fraction=0.33; bagging_fraction=0.819 : y = 0.934 : 119.5 secs : infill_ei
#
# Fri Nov 21 01:16:16 AM 2025 AUC 0.932619722997861
#
# [mbo] 82: num_leaves=3394; min_child_weight=3.12; min_data_in_leaf=87; lambda_l2=13.1; scale_pos_weight=1.04; learning_rate=0.0422; num_iterations=4143; early_stopping_rounds=207; feature_fraction=0.386; bagging_fraction=0.637 : y = 0.933 : 232.8 secs : infill_ei
#
# Saved the current state after iteration 83 in the file HT.RDATA.
#
# Fri Nov 21 01:18:38 AM 2025 AUC 0.930200198769401
#
# [mbo] 83: num_leaves=5573; min_child_weight=3.01; min_data_in_leaf=55; lambda_l2=9.62; scale_pos_weight=1.4; learning_rate=0.0477; num_iterations=4251; early_stopping_rounds=414; feature_fraction=0.275; bagging_fraction=0.987 : y = 0.93 : 141.1 secs : infill_ei
#
# Fri Nov 21 01:20:03 AM 2025 AUC 0.935895525943702
#
# [mbo] 84: num_leaves=3778; min_child_weight=2.49; min_data_in_leaf=10; lambda_l2=5.7; scale_pos_weight=1.51; learning_rate=0.0451; num_iterations=3570; early_stopping_rounds=301; feature_fraction=0.127; bagging_fraction=0.76 : y = 0.936 : 82.0 secs : infill_ei
#
# Fri Nov 21 01:21:38 AM 2025 AUC 0.930597469146117
#
# [mbo] 85: num_leaves=2569; min_child_weight=3.42; min_data_in_leaf=6; lambda_l2=6.44; scale_pos_weight=4.93; learning_rate=0.0469; num_iterations=3995; early_stopping_rounds=264; feature_fraction=0.292; bagging_fraction=0.994 : y = 0.931 : 93.7 secs : infill_ei
#
# Fri Nov 21 01:24:55 AM 2025 AUC 0.929847889735996
#
# [mbo] 86: num_leaves=4087; min_child_weight=5.83; min_data_in_leaf=8; lambda_l2=36.2; scale_pos_weight=1.11; learning_rate=0.0462; num_iterations=2619; early_stopping_rounds=197; feature_fraction=0.605; bagging_fraction=0.97 : y = 0.93 : 195.6 secs : infill_ei
#
# Fri Nov 21 01:26:45 AM 2025 AUC 0.933337091296356
#
# [mbo] 87: num_leaves=3553; min_child_weight=9.07; min_data_in_leaf=696; lambda_l2=1.8; scale_pos_weight=1.16; learning_rate=0.0532; num_iterations=4333; early_stopping_rounds=190; feature_fraction=0.33; bagging_fraction=0.681 : y = 0.933 : 108.8 secs : infill_ei
#
# Saved the current state after iteration 88 in the file HT.RDATA.
#
# Fri Nov 21 01:28:57 AM 2025 AUC 0.931142709316863
#
# [mbo] 88: num_leaves=4662; min_child_weight=6.02; min_data_in_leaf=80; lambda_l2=0.876; scale_pos_weight=1.6; learning_rate=0.0444; num_iterations=3759; early_stopping_rounds=263; feature_fraction=0.25; bagging_fraction=0.782 : y = 0.931 : 130.3 secs : infill_ei
#
# Fri Nov 21 01:33:31 AM 2025 AUC 0.929481488341255
#
# [mbo] 89: num_leaves=6213; min_child_weight=3.79; min_data_in_leaf=1416; lambda_l2=29.9; scale_pos_weight=2; learning_rate=0.0461; num_iterations=4272; early_stopping_rounds=212; feature_fraction=0.516; bagging_fraction=0.592 : y = 0.929 : 272.0 secs : infill_ei
#
# Fri Nov 21 01:35:17 AM 2025 AUC 0.935642198972063
#
# [mbo] 90: num_leaves=5041; min_child_weight=2.74; min_data_in_leaf=46; lambda_l2=1.31; scale_pos_weight=1.08; learning_rate=0.0446; num_iterations=3014; early_stopping_rounds=293; feature_fraction=0.195; bagging_fraction=0.749 : y = 0.936 : 103.5 secs : infill_ei
#
# Saved the final state in the file HT.RDATA

# %% [markdown]
# la bayesian optimization ha corrido, extraigo los mejores hiperparametros

# %%
# almaceno los resultados de la Bayesian Optimization
# y capturo los mejores hiperparametros encontrados

tb_bayesiana <- as.data.table(bayesiana_salida$opt.path)

# ordeno en forma descendente por AUC = y
setorder(tb_bayesiana, -y, -num_iterations)

# grabo para eventualmente poder utilizarlos en OTRA corrida
fwrite( tb_bayesiana,
  file="BO_log.txt",
  sep="\t"
)

# los mejores hiperparámetros son los que quedaron en el registro 1 de la tabla
PARAM$out$lgbm$mejores_hiperparametros <- tb_bayesiana[
  1, # el primero es el de mejor AUC
  setdiff(colnames(tb_bayesiana),
    c("y","dob","eol","error.message","exec.time","ei","error.model",
      "train.time","prop.type","propose.time","se","mean","iter")),
  with= FALSE
]

print(PARAM$out$lgbm$mejores_hiperparametros)
# Out:
#    num_leaves min_child_weight min_data_in_leaf lambda_l2 scale_pos_weight
#         <int>            <num>            <int>     <num>            <num>
# 1:       5013         4.002726               24 0.6996995         1.265274
#    learning_rate num_iterations early_stopping_rounds feature_fraction
#            <num>          <int>                 <int>            <num>
# 1:    0.04552285           4319                   236         0.298484
#    bagging_fraction
#               <num>
# 1:        0.7834382

# %% [markdown]
# ### 6.3.3 Produccion

# %% [markdown]
# #### Final Training
# Construyo el modelo final, que es uno solo, no hace ningun tipo de particion < training, validation, testing>]

# %% [markdown]
# ##### Final Training Dataset
#
# Aqui esta la gran decision de en qué meses hago el Final Training
# <br> debo utilizar los mejores hiperparámetros que encontré en la optimización bayesiana

# %%
PARAM$trainingstrategy$final_train <- c(
  202105, 202104, 202103, 202102, 202101,
  202012, 202011, 202010, 202009, 202008, 202007,
  202006, 202005
)

dataset[, fold_final_train := foto_mes %in% PARAM$trainingstrategy$final_train ]

# creo el dfinal_train en formato  LightGBM
dfinal_train <- lgb.Dataset(
  data= data.matrix(dataset[fold_final_train == TRUE, campos_buenos, with= FALSE]),
  label= dataset[fold_final_train == TRUE, clase01],
  free_raw_data= TRUE
)

nrow( dfinal_train) # verifico el tamaño
# Out:
# [1] 207504

# %% [markdown]
# ##### Final Training Hyperparameters

# %%
# uno los parametros fijos y los mejores encontrados de los variables
fijos <- copy(PARAM$lgbm$param_fijos)

# quito lo que optimice en la Bayesian Optimization
fijos$num_iterations <- NULL
fijos$early_stopping_rounds <- NULL

# agrego a los hiperparametros fijos los que encontre con la Bayesian Optimization
param_final <- c(fijos, PARAM$out$lgbm$mejores_hiperparametros)

# Para el entrenamiento final, removemos early_stopping_rounds
# ya que se entrena con todos los datos disponibles y la cantidad de iteraciones
# ya está optimizada en 'num_iterations'.
param_final$early_stopping_rounds <- NULL

# %% [markdown]
# ##### Training
# Genero el modelo final, siempre sobre TODOS los datos de  final_train, sin hacer ningun tipo de undersampling de la clase mayoritaria

# %%
final_model <- lgb.train(
  data= dfinal_train,
  param= param_final,
  verbose= -100
)

# %%
# grabo a disco el modelo en un formato para seres humanos ... ponele ...

lgb.save(final_model, "modelo.txt")

# %%
# ahora imprimo la importancia de variables

tb_importancia <- as.data.table(lgb.importance(final_model))
archivo_importancia <- "impo.txt"

fwrite( tb_importancia,
  file= archivo_importancia,
  sep= "\t"
)

# %% [markdown]
# #### Scoring

# %% [markdown]
# Aplico el modelo final a los datos del futuro

# %%
PARAM$trainingstrategy$future <- c(202107)

dfuture <- dataset[ foto_mes %in% PARAM$trainingstrategy$future ]

# %%
# aplico final_model   a dfuture

prediccion <- predict(
  final_model,
  data.matrix(dfuture[, campos_buenos, with= FALSE])
)

# %% [markdown]
# ##### Tabla Prediccion

# %%
tb_prediccion <- dfuture[, list(numero_de_cliente)]
tb_prediccion[, prob := prediccion]

# grabo las probabilidad del modelo
#  me va a ser util para hacer Ensembles de modelos
fwrite(tb_prediccion,
  file= "prediccion.txt",
  sep= "\t"
)

# %% [markdown]
# #### Curva de Ganancia

# %% [markdown]
# Genero las salidas

# %%
# asigno clase ternaria
tb_prediccion[, clase_ternaria := dfuture$clase_ternaria ]

# asigno ganancias
tb_prediccion[, ganancia := -3000.0 ]
tb_prediccion[clase_ternaria=="BAJA+2", ganancia := 117000.0 ]

# reordeno, y acumulada
setorder( tb_prediccion, -prob )
tb_prediccion[, gan_acum := cumsum(ganancia)]

# media movil de ancho 400
tb_prediccion[,
  gan_suavizada := frollmean(
    x= gan_acum,
    n= 400,
    align= "center",
    na.rm= TRUE,
    hasNA= TRUE
  )
]

# %%
tb_prediccion[, sum(!is.na(gan_suavizada) )]
tb_prediccion[, .N]
# Out:
# [1] 16152
# [1] 16551

# %%
# Este es la ganancia a reportar
resultado <- list()
resultado$ganancia_suavizada_max <- max( tb_prediccion$gan_suavizada, na.rm=TRUE )
options(digits= 8)
resultado$envios <- which.max( tb_prediccion$gan_suavizada)
resultado
# Out:
# $ganancia_suavizada_max
# [1] 6473100
#
# $envios
# [1] 1288

# %%
# grabo las ganancias
fwrite( tb_prediccion,
  file= "ganancias.txt",
  sep= "\t"
)

# %%
# genero el grafico

tb_prediccion[, envios:= .I]

pdf("curva_de_ganancia.pdf")

plot(
  x= tb_prediccion$envios,
  y= tb_prediccion$gan_acum,
  type= "l",
  col= "gray",
  xlim= c(0, 6000),
  ylim= c(0, 8000000),
  main= paste0("Mejor gan prom= ", as.integer(resultado$ganancia_suavizada_max), " envios= ", resultado$envios),
  xlab= "Envios",
  ylab= "Ganancia",
  panel.first= grid()
)

dev.off()
# Out:
# agg_record_554338955
#                    2

# %%
# grabo los parametros
if( !require("yaml")) install.packages("yaml")
require("yaml")

PARAM$resultado <- resultado

write_yaml( PARAM, file="PARAM.yml")
# Out:
# Loading required package: yaml

# %%
format(Sys.time(), "%a %b %d %X %Y")
fin <- Sys.time()

# Duración en segundos
secs <- as.numeric(difftime(fin, principio, units = "secs"))
secs <- round(secs)

# A hh:mm:ss
h <- secs %/% 3600
m <- (secs %% 3600) %/% 60
s <- secs %% 60
dur_hms <- sprintf("%02d:%02d:%02d", h, m, s)

cat(
  "Inicio: ", format(principio, "%a %b %d %X %Y"), "\n",
  "Fin:    ", format(fin,       "%a %b %d %X %Y"), "\n",
  "Duración (hh:mm:ss): ", dur_hms, "\n",
  sep = ""
)
# Out:
# [1] "Fri Nov 21 01:46:06 AM 2025"
# Inicio: Thu Nov 20 06:32:04 PM 2025
# Fin:    Fri Nov 21 01:46:06 AM 2025
# Duración (hh:mm:ss): 07:14:02
