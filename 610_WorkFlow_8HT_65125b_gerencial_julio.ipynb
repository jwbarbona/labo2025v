# %% [markdown]
# <a href="https://colab.research.google.com/github/jwbarbona/labo2025v/blob/main/610_WorkFlow_8HT_65125b_gerencial_julio.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # 6 WorkFlow  Gerencial, futuro=JULIO

# %% [markdown]
# ### 6.1 Objetivo

# %% [markdown]
# Presentar un workflow/pipeline completo al que los estudiantes deberán enriquecer

# %% [markdown]
# #### 6.2  Seteo del ambiente en Google Colab

# %% [markdown]
# Esta parte se debe correr con el runtime en Python3
# <br>Ir al menu, Runtime -> Change Runtime Type -> Runtime type ->  **Python 3**

# %% [markdown]
# Conectar la virtual machine donde esta corriendo Google Colab con el  Google Drive, para poder tener persistencia de archivos

# %%
# primero establecer el Runtime de Python 3
from google.colab import drive
drive.mount('/content/.drive')
# Out:
# Mounted at /content/.drive

# %% [markdown]
# Para correr la siguiente celda es fundamental en Arranque en Frio haber copiado el archivo kaggle.json al Google Drive, en la carpeta indicada en el instructivo
#
# <br>los siguientes comando estan en shell script de Linux
# *   Crear las carpetas en el Google Drive
# *   "instalar" el archivo kaggle.json desde el Google Drive a la virtual machine para que pueda ser utilizado por la libreria  kaggle de Python
# *   Bajar el  **dataset_pequeno**  al  Google Drive  y tambien al disco local de la virtual machine que esta corriendo Google Colab
# *   Bajar el **dataset_historico** al Google Drive y tambien al disco local de la virtual machine que esta corriendo Google Colab

# %%
%%shell

mkdir -p "/content/.drive/My Drive/labo1"
mkdir -p "/content/buckets"
ln -s "/content/.drive/My Drive/labo1" /content/buckets/b1

mkdir -p ~/.kaggle
cp /content/buckets/b1/kaggle/kaggle.json  ~/.kaggle
chmod 600 ~/.kaggle/kaggle.json


mkdir -p /content/buckets/b1/exp
mkdir -p /content/buckets/b1/datasets
mkdir -p /content/datasets


webfiles="https://storage.googleapis.com/open-courses/austral2025-af91/"
destino_local="/content/datasets"
destino_bucket="/content/buckets/b1/datasets"


archivo="dataset_pequeno.csv"

if ! test -f $destino_bucket/$archivo; then
  wget  $webfiles/$archivo  -O $destino_bucket/$archivo
fi


if ! test -f $destino_local/$pequeno; then
  cp  $destino_bucket/$archivo  $destino_local/$archivo
fi

#-------

archivo="gerencial_competencia_2025.csv.gz"

if ! test -f $destino_bucket/$archivo; then
  wget  $webfiles/$archivo  -O $destino_bucket/$archivo
fi


if ! test -f $destino_local/$pequeno; then
  cp  $destino_bucket/$archivo  $destino_local/$archivo
fi
# Out:
# cp: cannot stat '/content/buckets/b1/kaggle/kaggle.json': No such file or directory
# chmod: cannot access '/root/.kaggle/kaggle.json': No such file or directory

# %% [markdown]
# ## 6.3  Workflow

# %% [markdown]
# ## Inicializacion

# %% [markdown]
# Esta parte se debe correr con el runtime en lenguaje **R** Ir al menu, Runtime -> Change Runtime Type -> Runtime type -> R

# %% [markdown]
# limpio el ambiente de R

# %%
format(Sys.time(), "%a %b %d %X %Y")
# Out:
# [1] "Wed Nov 19 02:47:20 AM 2025"

# %%
# limpio la memoria
rm(list=ls(all.names=TRUE)) # remove all objects
gc(full=TRUE, verbose=FALSE) # garbage collection
# Out:
#        used    (Mb) gc trigger (Mb) max used (Mb)
# Ncells  660442 35.3 1454500    77.7 1437482  76.8
# Vcells 1226661  9.4 8388608    64.0 1975136  15.1

# %%
principio <- Sys.time()

# %%
require("data.table")

if( !require("R.utils")) install.packages("R.utils")
require("R.utils")
# Out:
# Loading required package: data.table
#
# Loading required package: R.utils
#
# Warning message in library(package, lib.loc = lib.loc, character.only = TRUE, logical.return = TRUE, :
# “there is no package called ‘R.utils’”
# Installing package into ‘/usr/local/lib/R/site-library’
# (as ‘lib’ is unspecified)
#
# also installing the dependencies ‘R.oo’, ‘R.methodsS3’
#
#
# Loading required package: R.utils
#
# Loading required package: R.oo
#
# Loading required package: R.methodsS3
#
# R.methodsS3 v1.8.2 (2022-06-13 22:00:14 UTC) successfully loaded. See ?R.methodsS3 for help.
#
# R.oo v1.27.1 (2025-05-02 21:00:05 UTC) successfully loaded. See ?R.oo for help.
#
#
# Attaching package: ‘R.oo’
#
#
# The following object is masked from ‘package:R.methodsS3’:
#
#     throw
#
#
# The following objects are masked from ‘package:methods’:
#
#     getClasses, getMethods
#
#
# The following objects are masked from ‘package:base’:
#
#     attach, detach, load, save
#
#
# R.utils v2.13.0 (2025-02-24 21:20:02 UTC) successfully loaded. See ?R.utils for help.
#
#
# Attaching package: ‘R.utils’
#
#
# The following object is masked from ‘package:utils’:
#
#     timestamp
#
#
# The following objects are masked from ‘package:base’:
#
#     cat, commandArgs, getOption, isOpen, nullfile, parse, use, warnings

# %% [markdown]
# #### Parametros
# Si es gerente, no cambie nada
# <br>Si es Analista, cambie el nombre del dataset

# %%
PARAM <- list()
PARAM$semilla_primigenia <- 999983 # 100009, 200003, 499999, 700009, 999983

PARAM$experimento <- 65125
PARAM$dataset <- "gerencial_competencia_2025.csv.gz"

# %% [markdown]
# #### Carpeta del Experimento

# %%
# carpeta de trabajo

setwd("/content/buckets/b1/exp")
experimento_folder <- paste0("WF", PARAM$experimento)
dir.create(experimento_folder, showWarnings=FALSE)
setwd( paste0("/content/buckets/b1/exp/", experimento_folder ))

# %% [markdown]
# ### 6.3.1   Preprocesamiento del dataset

# %% [markdown]
# #### 6.3.1.1  DT incorporar dataset

# %%
# lectura del dataset
dataset <- fread(paste0("/content/datasets/", PARAM$dataset))

# %% [markdown]
# #### 6.3.1.2  CA  Catastrophe Analysis
# Se intentan reparar las variables que para un mes están con todos los valores en cero.

# %% [markdown]
# El método que se utiliza es **Machine Learning** se asigna NA also valores, si ha leido bien, es la "anti imputación de valores faltantes"
# <br> Usted podrá aplicar aquí otros métodos

# %%
dataset[ foto_mes==202006, internet:=NA]
dataset[ foto_mes==202006, mrentabilidad:=NA]
dataset[ foto_mes==202006, mrentabilidad_annual:=NA]
dataset[ foto_mes==202006, mcomisiones:=NA]
dataset[ foto_mes==202006, mactivos_margen:=NA]
dataset[ foto_mes==202006, mpasivos_margen:=NA]
dataset[ foto_mes==202006, mcuentas_saldo:=NA]
dataset[ foto_mes==202006, ctarjeta_visa_transacciones:=NA]
dataset[ foto_mes==202006, mtarjeta_visa_consumo:=NA]
dataset[ foto_mes==202006, mtarjeta_master_consumo:=NA]
dataset[ foto_mes==202006, ccallcenter_transacciones:=NA]
dataset[ foto_mes==202006, chomebanking_transacciones:=NA]
dataset[ foto_mes==202006, chomebanking_transacciones:=NA]

# %% [markdown]
# #### 6.3.1.3  DR  Data Drifting
# Se intenta corregir el data drifting, quizas ajustando por IPC ...
# <br>Esta parte podrá ser abordada por todos los Analistas y también la Gerenciapero se decide pedagogicamente no incluirla en esta primer version para reducir la carga cognitiva

# %%
# sin codigo en esta primera version del workflow

# %% [markdown]
# #### 6.3.1.3  FE_intra_manual Feature Engineering intra-mes
#
# Agrego campos nuevos dentro del mismo mes, SIN considerar la historia.

# %%
# esta funcion atributos presentes existe debido a que las modalidades poseen datasets con distinta cantidad de campos
atributos_presentes <- function( patributos )
{
  atributos <- unique( patributos )
  comun <- intersect( atributos, colnames(dataset) )

  return(  length( atributos ) == length( comun ) )
}

# el mes 1,2, ..12
if( atributos_presentes( c("foto_mes") ))
  dataset[, kmes := foto_mes %% 100]

# variable extraida de una tesis de maestria de Irlanda
if( atributos_presentes( c("mpayroll", "cliente_edad") ))
  dataset[, mpayroll_sobre_edad := mpayroll / cliente_edad]

# %%
# visualizo las columas del dataset a esta etapa
colnames(dataset)
# Out:
#  [1] "numero_de_cliente"           "foto_mes"
#  [3] "internet"                    "cliente_edad"
#  [5] "cliente_antiguedad"          "mrentabilidad"
#  [7] "mrentabilidad_annual"        "mcomisiones"
#  [9] "mactivos_margen"             "mpasivos_margen"
# [11] "cproductos"                  "mcuenta_corriente"
# [13] "mcaja_ahorro"                "cdescubierto_preacordado"
# [15] "mcuentas_saldo"              "ctarjeta_visa_transacciones"
# [17] "mtarjeta_visa_consumo"       "mtarjeta_master_consumo"
# [19] "mprestamos_personales"       "cpayroll_trx"
# [21] "mpayroll"                    "ccomisiones_mantenimiento"
# [23] "ccallcenter_transacciones"   "chomebanking_transacciones"
# [25] "ctrx_quarter"                "Master_status"
# [27] "Master_fechaalta"            "Master_mpagominimo"
# [29] "Visa_status"                 "Visa_fechaalta"
# [31] "Visa_mpagominimo"            "clase_ternaria"
# [33] "kmes"                        "mpayroll_sobre_edad"

# %% [markdown]
# #### 6.3.1.4  FE_rf Feature Engineering de nuevas variables a partir de hojas de Random Forest
#
# Esto se mostrará unicamente a la *modalidad Analista Sr*

# %%
# No se implementa Feature Engineering a partir de Random Forest

# %% [markdown]
# #### 6.3.1.5  FEhist Feature Engineering historico
#
# El Fature Engineering Histórico es la etapa que más aporta a la ganancia final, ya que enriquece cada registro del dataset con su historia.

# %% [markdown]
# Para cada campo del dataset original (*)
# se crean lo siguientes campos de a partir de la historia
# * lag1  lags de orden 1
# * delta1  =  valor actual - lag1
# * lag2  lags de orden 2
# * delta2  = valor actual - lag2
#
#
# (*) Excepto para los campos  <numero_de_cliente,  foto_mes,  clase_ternaria>

# %%
# Feature Engineering Historico

# todo es lagueable, menos la primary key y la clase
cols_lagueables <- copy( setdiff(
    colnames(dataset),
    c("numero_de_cliente", "foto_mes", "clase_ternaria")
) )

# https://rdrr.io/cran/data.table/man/shift.html

# lags de orden 1
dataset[,
    paste0(cols_lagueables, "_lag1") := shift(.SD, 1, NA, "lag"),
    by = numero_de_cliente,
    .SDcols = cols_lagueables
]

# lags de orden 2
dataset[,
    paste0(cols_lagueables, "_lag2") := shift(.SD, 2, NA, "lag"),
    by = numero_de_cliente,
    .SDcols = cols_lagueables
]

# agrego los delta lags
for (vcol in cols_lagueables)
{
    dataset[, paste0(vcol, "_delta1") := get(vcol) - get(paste0(vcol, "_lag1"))]
    dataset[, paste0(vcol, "_delta2") := get(vcol) - get(paste0(vcol, "_lag2"))]
}

# %% [markdown]
# Verificacion de los campos recien creados

# %%
ncol(dataset)
colnames(dataset)
# Out:
# [1] 158
#   [1] "numero_de_cliente"                  "foto_mes"
#   [3] "internet"                           "cliente_edad"
#   [5] "cliente_antiguedad"                 "mrentabilidad"
#   [7] "mrentabilidad_annual"               "mcomisiones"
#   [9] "mactivos_margen"                    "mpasivos_margen"
#  [11] "cproductos"                         "mcuenta_corriente"
#  [13] "mcaja_ahorro"                       "cdescubierto_preacordado"
#  [15] "mcuentas_saldo"                     "ctarjeta_visa_transacciones"
#  [17] "mtarjeta_visa_consumo"              "mtarjeta_master_consumo"
#  [19] "mprestamos_personales"              "cpayroll_trx"
#  [21] "mpayroll"                           "ccomisiones_mantenimiento"
#  [23] "ccallcenter_transacciones"          "chomebanking_transacciones"
#  [25] "ctrx_quarter"                       "Master_status"
#  [27] "Master_fechaalta"                   "Master_mpagominimo"
#  [29] "Visa_status"                        "Visa_fechaalta"
#  [31] "Visa_mpagominimo"                   "clase_ternaria"
#  [33] "kmes"                               "mpayroll_sobre_edad"
#  [35] "internet_lag1"                      "cliente_edad_lag1"
#  [37] "cliente_antiguedad_lag1"            "mrentabilidad_lag1"
#  [39] "mrentabilidad_annual_lag1"          "mcomisiones_lag1"
#  [41] "mactivos_margen_lag1"               "mpasivos_margen_lag1"
#  [43] "cproductos_lag1"                    "mcuenta_corriente_lag1"
#  [45] "mcaja_ahorro_lag1"                  "cdescubierto_preacordado_lag1"
#  [47] "mcuentas_saldo_lag1"                "ctarjeta_visa_transacciones_lag1"
#  [49] "mtarjeta_visa_consumo_lag1"         "mtarjeta_master_consumo_lag1"
#  [51] "mprestamos_personales_lag1"         "cpayroll_trx_lag1"
#  [53] "mpayroll_lag1"                      "ccomisiones_mantenimiento_lag1"
#  [55] "ccallcenter_transacciones_lag1"     "chomebanking_transacciones_lag1"
#  [57] "ctrx_quarter_lag1"                  "Master_status_lag1"
#  [59] "Master_fechaalta_lag1"              "Master_mpagominimo_lag1"
#  [61] "Visa_status_lag1"                   "Visa_fechaalta_lag1"
#  [63] "Visa_mpagominimo_lag1"              "kmes_lag1"
#  [65] "mpayroll_sobre_edad_lag1"           "internet_lag2"
#  [67] "cliente_edad_lag2"                  "cliente_antiguedad_lag2"
#  [69] "mrentabilidad_lag2"                 "mrentabilidad_annual_lag2"
#  [71] "mcomisiones_lag2"                   "mactivos_margen_lag2"
#  [73] "mpasivos_margen_lag2"               "cproductos_lag2"
#  [75] "mcuenta_corriente_lag2"             "mcaja_ahorro_lag2"
#  [77] "cdescubierto_preacordado_lag2"      "mcuentas_saldo_lag2"
#  [79] "ctarjeta_visa_transacciones_lag2"   "mtarjeta_visa_consumo_lag2"
#  [81] "mtarjeta_master_consumo_lag2"       "mprestamos_personales_lag2"
#  [83] "cpayroll_trx_lag2"                  "mpayroll_lag2"
#  [85] "ccomisiones_mantenimiento_lag2"     "ccallcenter_transacciones_lag2"
#  [87] "chomebanking_transacciones_lag2"    "ctrx_quarter_lag2"
#  [89] "Master_status_lag2"                 "Master_fechaalta_lag2"
#  [91] "Master_mpagominimo_lag2"            "Visa_status_lag2"
#  [93] "Visa_fechaalta_lag2"                "Visa_mpagominimo_lag2"
#  [95] "kmes_lag2"                          "mpayroll_sobre_edad_lag2"
#  [97] "internet_delta1"                    "internet_delta2"
#  [99] "cliente_edad_delta1"                "cliente_edad_delta2"
# [101] "cliente_antiguedad_delta1"          "cliente_antiguedad_delta2"
# [103] "mrentabilidad_delta1"               "mrentabilidad_delta2"
# [105] "mrentabilidad_annual_delta1"        "mrentabilidad_annual_delta2"
# [107] "mcomisiones_delta1"                 "mcomisiones_delta2"
# [109] "mactivos_margen_delta1"             "mactivos_margen_delta2"
# [111] "mpasivos_margen_delta1"             "mpasivos_margen_delta2"
# [113] "cproductos_delta1"                  "cproductos_delta2"
# [115] "mcuenta_corriente_delta1"           "mcuenta_corriente_delta2"
# [117] "mcaja_ahorro_delta1"                "mcaja_ahorro_delta2"
# [119] "cdescubierto_preacordado_delta1"    "cdescubierto_preacordado_delta2"
# [121] "mcuentas_saldo_delta1"              "mcuentas_saldo_delta2"
# [123] "ctarjeta_visa_transacciones_delta1" "ctarjeta_visa_transacciones_delta2"
# [125] "mtarjeta_visa_consumo_delta1"       "mtarjeta_visa_consumo_delta2"
# [127] "mtarjeta_master_consumo_delta1"     "mtarjeta_master_consumo_delta2"
# [129] "mprestamos_personales_delta1"       "mprestamos_personales_delta2"
# [131] "cpayroll_trx_delta1"                "cpayroll_trx_delta2"
# [133] "mpayroll_delta1"                    "mpayroll_delta2"
# [135] "ccomisiones_mantenimiento_delta1"   "ccomisiones_mantenimiento_delta2"
# [137] "ccallcenter_transacciones_delta1"   "ccallcenter_transacciones_delta2"
# [139] "chomebanking_transacciones_delta1"  "chomebanking_transacciones_delta2"
# [141] "ctrx_quarter_delta1"                "ctrx_quarter_delta2"
# [143] "Master_status_delta1"               "Master_status_delta2"
# [145] "Master_fechaalta_delta1"            "Master_fechaalta_delta2"
# [147] "Master_mpagominimo_delta1"          "Master_mpagominimo_delta2"
# [149] "Visa_status_delta1"                 "Visa_status_delta2"
# [151] "Visa_fechaalta_delta1"              "Visa_fechaalta_delta2"
# [153] "Visa_mpagominimo_delta1"            "Visa_mpagominimo_delta2"
# [155] "kmes_delta1"                        "kmes_delta2"
# [157] "mpayroll_sobre_edad_delta1"         "mpayroll_sobre_edad_delta2"

# %% [markdown]
# #### 6.3.1.6  FEhist Reduccion dimensionalidad con canaritos
#
# Esta etapa solo se mostrará a la *modalidad Anlista Sr* por algun canal secreto de forma de no confundir a los *Analista Jr*  nni distraer con detalles operativos a la estratégica *Modalidad Gerencial*

# %%
# No se implementa la reduccion de la dimensionalidad con canaritos

# %% [markdown]
# ### 6.3.2 Modelado

# %% [markdown]
# #### 6.3.2.1 Training Strategy
#
# Esta etapa de Workflow de  Training Strategy esta pensada para la *Modalidad Gerencial* que posee el dataset de [202005, 202109]
# <br> Si usted es un Analista, posee el periodo de [201901, 202109] y deberá experimentar en que meses le conviene experimentar
#
# <br> A la *Modalidad Gerencial* no se le complicada la vida con el undersampling de los continua, por eso PARAM$trainingstrategy$training_pct <- 1.0
# <br> Sin embargo, si usted es  *Analista SR* posee un dataset 50 veces ( filas x columnas) más grande que la *Modalidad Gerencial*  y por un tema de velocidad y experimentación más rápida puede llegar a necesitar activar el undersampling de la clase mayoritaria, a pesar de estar corriendo en Google Cloud.

# %% [markdown]
# Se hace una estrategia de entrenamiento muy sencilla, tomando todos los meses posibles, SIN eliminar nada x pandemia ni por ningun otro motivo
#
# * future = 202107  obviamente completo
#
# * final_train =  [ 202005, 202105 ]  SIN undersampling
#
# * training
#    * testing = NO HAY
#    * validation =  202105   completo, sin undersampling
#    * training = [ 202005, 202104 ]  donde se consideran el 100% de los CONTINUA

# %%
PARAM$trainingstrategy$validate <- c(202105)

PARAM$trainingstrategy$training <- c(
  202104, 202103, 202102, 202101,
  202012, 202011, 202010, 202009, 202008, 202007,
  202006, 202005
)

PARAM$trainingstrategy$training_pct <- 1.0


PARAM$trainingstrategy$positivos <- c( "BAJA+1", "BAJA+2")

# %%
# seteo la clase01   1={BAJA+1, BAJA+2}   0={CONTINUA}
dataset[, clase01 := ifelse( clase_ternaria %in% PARAM$trainingstrategy$positivos, 1, 0 )]

# %%
# los campos en los que se entrena
campos_buenos <- copy( setdiff(
    colnames(dataset), c("clase_ternaria","clase01","azar"))
)

# %%
# preparo para que se puede hacer undersampling de los CONTINUA
#  solamente por un tema de VELOCIDAD
set.seed(PARAM$semilla_primigenia, kind = "L'Ecuyer-CMRG")
dataset[, azar:=runif(nrow(dataset))]

# undersampling de los CONTINUA
dataset[, fold_train :=  foto_mes %in%  PARAM$trainingstrategy$training &
    (clase_ternaria %in% c("BAJA+1", "BAJA+2") |
     azar < PARAM$trainingstrategy$training_pct ) ]


if( !require("lightgbm")) install.packages("lightgbm")
require("lightgbm")

dtrain <- lgb.Dataset(
  data= data.matrix(dataset[fold_train == TRUE, campos_buenos, with = FALSE]),
  label= dataset[fold_train == TRUE, clase01],
  free_raw_data= TRUE
)
# Out:
# Loading required package: lightgbm
#
# Warning message in library(package, lib.loc = lib.loc, character.only = TRUE, logical.return = TRUE, :
# “there is no package called ‘lightgbm’”
# Installing package into ‘/usr/local/lib/R/site-library’
# (as ‘lib’ is unspecified)
#
# Loading required package: lightgbm

# %%
# datos de validation
dvalidate <- lgb.Dataset(
  data= data.matrix(dataset[foto_mes %in% PARAM$trainingstrategy$validate, campos_buenos, with = FALSE]),
  label= dataset[foto_mes %in% PARAM$trainingstrategy$validate, clase01],
  free_raw_data= TRUE
)

nrow(dvalidate)
# Out:
# [1] 16469

# %% [markdown]
# ####  6.3.2.2. Hyperparameter Tuning

# %% [markdown]
# * Clase binaria que se optimiza :  positivos = [ BAJA+1, BAJA+2 ]

# %% [markdown]
# * Metrica que se optimiza **AUC** Area Under Curve de la  ROC Curve
#
# es muy importante notar que intencionalmente  **NO** se está optimizando la funcion de ganancia del problema

# %% [markdown]
# * Cantidad de iteraciones inteligentes de la Optimizacion Bayesiana = **10**

# %% [markdown]
# * Parametros no default, fijos de LightGBM que no se optimizan
#   * max_bin = 31 , Alienigenas Ancestrales contruyeron las pirámides y dejaron a la humanidad en un jeroglifico  *max_bin=31*
#   * feature_fraction = 0.5  para poner algo que generalmente no falla
#   * learning_rate = 0.03  para que aprenda lento

# %% [markdown]
# * Parametros que se optimizan en la Bayesian Optimization
#   * num_leaves  [8, 256]
#   * min_data_in_leaf  [8, 8192]

# %%
# paquetes necesarios para la Bayesian Optimization
if(!require("DiceKriging")) install.packages("DiceKriging")
require("DiceKriging")

if(!require("mlrMBO")) install.packages("mlrMBO")
require("mlrMBO")
# Out:
# Loading required package: DiceKriging
#
# Warning message in library(package, lib.loc = lib.loc, character.only = TRUE, logical.return = TRUE, :
# “there is no package called ‘DiceKriging’”
# Installing package into ‘/usr/local/lib/R/site-library’
# (as ‘lib’ is unspecified)
#
# Loading required package: DiceKriging
#
# Loading required package: mlrMBO
#
# Warning message in library(package, lib.loc = lib.loc, character.only = TRUE, logical.return = TRUE, :
# “there is no package called ‘mlrMBO’”
# Installing package into ‘/usr/local/lib/R/site-library’
# (as ‘lib’ is unspecified)
#
# also installing the dependencies ‘XML’, ‘fastmatch’, ‘RcppArmadillo’, ‘mlr’, ‘ParamHelpers’, ‘smoof’, ‘BBmisc’, ‘checkmate’, ‘lhs’, ‘parallelMap’
#
#
# Loading required package: mlrMBO
#
# Loading required package: mlr
#
# Loading required package: ParamHelpers
#
#
# Attaching package: ‘ParamHelpers’
#
#
# The following object is masked from ‘package:R.utils’:
#
#     isVector
#
#
#
# Attaching package: ‘mlr’
#
#
# The following objects are masked from ‘package:R.utils’:
#
#     resample, setThreshold
#
#
# Loading required package: smoof
#
# Loading required package: checkmate
#
#
# Attaching package: ‘checkmate’
#
#
# The following object is masked from ‘package:DiceKriging’:
#
#     checkNames
#
#
# The following object is masked from ‘package:R.utils’:
#
#     asInt
#
#
#
# Attaching package: ‘smoof’
#
#
# The following objects are masked from ‘package:R.oo’:
#
#     getDescription, getName

# %% [markdown]
# Definición de la Bayesian Optimization
# <br> Si se desea optimizar un hiperparámetro que esta como fijo, debe QUITARSE de param_fijos y agregarse a PARAM$hipeparametertuning$hs

# %%
# valor ridiculamente bajo para que corra rapido en el aula y no molestar a la *Modalidad Gerencial*
PARAM$hipeparametertuning$num_interations <- 80

# parametros fijos del LightGBM
PARAM$lgbm$param_fijos <- list(
  objective= "binary",
  metric= "auc",
  first_metric_only= TRUE,
  boost_from_average= TRUE,
  feature_pre_filter= FALSE,
  verbosity= -100,
  force_row_wise= TRUE, # para evitar warning
  max_bin= 31,
  seed= PARAM$semilla_primigenia
  # learning_rate= 0.03,
  # feature_fraction= 0.5,
  # num_iterations= 2048,  # valor grande, lo limita early_stopping_rounds
  # early_stopping_rounds= 200
)


PARAM$hipeparametertuning$hs <- makeParamSet(
  # Núcleo del modelo (estructura de árboles)
  makeIntegerParam("num_leaves", lower = 2L, upper = 8192L),
  #makeIntegerParam("max_depth", lower = 3L, upper = 30L),
  makeNumericParam("min_child_weight", lower = 0.001, upper = 10.0),
  makeIntegerParam("min_data_in_leaf", lower = 2L, upper = 8192L),
  #makeNumericParam("min_gain_to_split", lower = 0.0, upper = 0.1),

  # Regularización
  #makeNumericParam("lambda_l1", lower = 0.0, upper = 1000L),
  makeNumericParam("lambda_l2", lower = 0.0, upper = 1000L),
  #makeNumericParam("scale_pos_weight", lower = 1.0, upper = 5.0),  # útil en desequilibrio

  # Control del aprendizaje
  makeNumericParam("learning_rate", lower = 0.005, upper = 0.1),
  makeIntegerParam("num_iterations", lower = 100L, upper = 5000L),
  #makeIntegerParam("early_stopping_rounds", lower = 50L, upper = 500L),

  # Submuestreo
  makeNumericParam("feature_fraction", lower = 0.05, upper = 1L),   # columnas
  makeNumericParam("bagging_fraction", lower = 0.5, upper = 1L)   # filas
  #makeIntegerParam("bagging_freq", lower = 0L, upper = 5L),         # cada N iteraciones

  # Opcionales útiles
  #makeNumericParam("max_delta_step", lower = 0.0, upper = 10.0),
  #makeNumericParam("path_smooth", lower = 0.0, upper = 10.0)
)
# Total: 8 hT

# %% [markdown]
# Función "señora caja negra"  que es llamada para verificar la realidad por la Bayesian Optimization

# %%
# En  x llegan los parmaetros de la bayesiana
#  devuelve la AUC en validate del modelo entrenado
#  en el parametro x llegan los hiperparámetros que se estan optimizando

EstimarGanancia_AUC_lightgbm <- function(x) {

  # x pisa (o agrega) a param_fijos
  param_completo <- modifyList(PARAM$lgbm$param_fijos, x)

  # entreno LightGBM
  modelo_train <- lgb.train(
    data= dtrain,
    valids= list(valid = dvalidate),
    eval= "auc",
    param= param_completo,
    verbose= -100
  )

  # recupero la AUC en validation
  AUC <- modelo_train$record_evals$valid$auc$eval[[modelo_train$best_iter]]

  # esta es la forma de devolver un parametro extra
  attr(AUC, "extras") <- list("num_iterations"= modelo_train$best_iter)

  # hago espacio en la memoria
  rm(modelo_train)
  gc(full= TRUE, verbose= FALSE)

  message(format(Sys.time(), "%a %b %d %X %Y"), " AUC ", AUC)

  return(AUC)
}

# %% [markdown]
# seteo de la Bayesian Optimization (complejo)
# <br> copiado y pegado de la documentación de la librería

# %%
configureMlr(show.learner.output = FALSE)

# configuro la busqueda bayesiana,  los hiperparametros que se van a optimizar
# por favor, no desesperarse por lo complejo
obj.fun <- makeSingleObjectiveFunction(
    fn= EstimarGanancia_AUC_lightgbm, # la funcion que voy a maximizar
    minimize= FALSE, # estoy Maximizando AUC
    noisy= FALSE,
    par.set= PARAM$hipeparametertuning$hs,
    has.simple.signature= FALSE # paso los parametros en una lista
)

# cada 600 segundos guardo el resultado intermedio
ctrl <- makeMBOControl(
    save.on.disk.at.time= 600,
    save.file.path= "HT.RDATA"
)

# indico la cantidad de iteraciones que va a tener la Bayesian Optimization
ctrl <- setMBOControlTermination(
    ctrl,
    iters= PARAM$hipeparametertuning$num_interations  # cantidad de iteraciones inteligentes
)

# defino el método estandar para la creacion de los puntos iniciales
#   los "No Inteligentes"
ctrl <- setMBOControlInfill(ctrl, crit = makeMBOInfillCritEI())

# mas configuraciones
surr.km <- makeLearner(
    "regr.km",
    predict.type= "se",
    covtype= "matern3_2",
    control= list(trace = TRUE)
)

# %% [markdown]
# Corrida de la Bayesian Optimization,  aqui se hace el trabajo pesado
# <br> por favor no se asuste con los warnings que pudieran aparecer
#
# Si corrío a medias y llegó a las iteraciones inteligentes, en el archivo binario HT.RDATA quedó lo ya procesado y es utilizado para retomar la corrida desde lo último que llegó a grabar.

# %%
# inicio la optimizacion bayesiana

if (!file.exists("HT.RDATA")) {
  bayesiana_salida <- mbo(obj.fun, learner= surr.km, control= ctrl)
} else {
  bayesiana_salida <- mboContinue("HT.RDATA") # retomo en caso que ya exista
}
# Out:
# Computing y column(s) for design. Not provided.
#
# Wed Nov 19 03:05:07 AM 2025 AUC 0.919990954046152
#
# Wed Nov 19 03:12:23 AM 2025 AUC 0.917871731327118
#
# Wed Nov 19 03:21:21 AM 2025 AUC 0.918045201584518
#
# Wed Nov 19 03:26:18 AM 2025 AUC 0.915381409759564
#
# Wed Nov 19 03:29:49 AM 2025 AUC 0.91411477490137
#
# Wed Nov 19 03:37:38 AM 2025 AUC 0.915321684990092
#
# Wed Nov 19 03:42:12 AM 2025 AUC 0.913008189004066
#
# Wed Nov 19 03:51:52 AM 2025 AUC 0.916007177709374
#
# Wed Nov 19 03:52:45 AM 2025 AUC 0.918235112930144
#
# Wed Nov 19 03:55:53 AM 2025 AUC 0.915691777241373
#
# Wed Nov 19 04:03:23 AM 2025 AUC 0.918583395574596
#
# Wed Nov 19 04:06:12 AM 2025 AUC 0.913527257646616
#
# Wed Nov 19 04:11:50 AM 2025 AUC 0.910137373680435
#
# Wed Nov 19 04:19:57 AM 2025 AUC 0.922830900387808
#
# Wed Nov 19 04:22:55 AM 2025 AUC 0.918021714315625
#
# Wed Nov 19 04:26:40 AM 2025 AUC 0.918516960156868
#
# Wed Nov 19 04:28:56 AM 2025 AUC 0.914224494000345
#
# Wed Nov 19 04:37:42 AM 2025 AUC 0.914823419357133
#
# Wed Nov 19 04:39:33 AM 2025 AUC 0.912969938309011
#
# Wed Nov 19 04:42:59 AM 2025 AUC 0.912177075217643
#
# Wed Nov 19 04:50:37 AM 2025 AUC 0.916342039057315
#
# Wed Nov 19 04:54:04 AM 2025 AUC 0.924516615229548
#
# Wed Nov 19 04:55:10 AM 2025 AUC 0.912468652884337
#
# Wed Nov 19 04:55:20 AM 2025 AUC 0.901507480024078
#
# Wed Nov 19 05:00:46 AM 2025 AUC 0.912487442699452
#
# Wed Nov 19 05:11:13 AM 2025 AUC 0.92892416900365
#
# Wed Nov 19 05:19:29 AM 2025 AUC 0.916318887320834
#
# Wed Nov 19 05:28:06 AM 2025 AUC 0.92475819856674
#
# Wed Nov 19 05:28:45 AM 2025 AUC 0.907202807198378
#
# Wed Nov 19 05:35:20 AM 2025 AUC 0.918913223936345
#
# Wed Nov 19 05:37:23 AM 2025 AUC 0.914145643883345
#
# Wed Nov 19 05:45:58 AM 2025 AUC 0.912072724637273
#
# [mbo] 0: num_leaves=5689; min_child_weight=4.73; min_data_in_leaf=2112; lambda_l2=244; learning_rate=0.0568; num_iterations=1410; feature_fraction=0.531; bagging_fraction=0.77 : y = 0.92 : 264.6 secs : initdesign
#
# [mbo] 0: num_leaves=3030; min_child_weight=1.92; min_data_in_leaf=5880; lambda_l2=637; learning_rate=0.0629; num_iterations=3120; feature_fraction=0.38; bagging_fraction=0.884 : y = 0.918 : 436.2 secs : initdesign
#
# [mbo] 0: num_leaves=2640; min_child_weight=5.53; min_data_in_leaf=3543; lambda_l2=612; learning_rate=0.0513; num_iterations=3285; feature_fraction=0.495; bagging_fraction=0.658 : y = 0.918 : 537.8 secs : initdesign
#
# [mbo] 0: num_leaves=6856; min_child_weight=2.87; min_data_in_leaf=5340; lambda_l2=415; learning_rate=0.0486; num_iterations=2681; feature_fraction=0.662; bagging_fraction=0.748 : y = 0.915 : 297.3 secs : initdesign
#
# [mbo] 0: num_leaves=1498; min_child_weight=3.53; min_data_in_leaf=3733; lambda_l2=827; learning_rate=0.0591; num_iterations=1912; feature_fraction=0.79; bagging_fraction=0.808 : y = 0.914 : 210.5 secs : initdesign
#
# [mbo] 0: num_leaves=2037; min_child_weight=2.19; min_data_in_leaf=5594; lambda_l2=203; learning_rate=0.0226; num_iterations=2876; feature_fraction=0.507; bagging_fraction=0.9 : y = 0.915 : 469.3 secs : initdesign
#
# [mbo] 0: num_leaves=3671; min_child_weight=4.08; min_data_in_leaf=5020; lambda_l2=312; learning_rate=0.032; num_iterations=2420; feature_fraction=0.855; bagging_fraction=0.642 : y = 0.913 : 274.3 secs : initdesign
#
# [mbo] 0: num_leaves=4865; min_child_weight=0.49; min_data_in_leaf=6506; lambda_l2=456; learning_rate=0.0392; num_iterations=4084; feature_fraction=0.6; bagging_fraction=0.95 : y = 0.916 : 579.7 secs : initdesign
#
# [mbo] 0: num_leaves=3312; min_child_weight=5.84; min_data_in_leaf=763; lambda_l2=166; learning_rate=0.0816; num_iterations=459; feature_fraction=0.204; bagging_fraction=0.732 : y = 0.918 : 53.6 secs : initdesign
#
# [mbo] 0: num_leaves=464; min_child_weight=3.29; min_data_in_leaf=4242; lambda_l2=658; learning_rate=0.0915; num_iterations=1550; feature_fraction=0.298; bagging_fraction=0.918 : y = 0.916 : 187.6 secs : initdesign
#
# [mbo] 0: num_leaves=1226; min_child_weight=9.28; min_data_in_leaf=6199; lambda_l2=252; learning_rate=0.0651; num_iterations=4079; feature_fraction=0.733; bagging_fraction=0.756 : y = 0.919 : 449.5 secs : initdesign
#
# [mbo] 0: num_leaves=6287; min_child_weight=7.78; min_data_in_leaf=6748; lambda_l2=854; learning_rate=0.0742; num_iterations=1201; feature_fraction=0.418; bagging_fraction=0.992 : y = 0.914 : 169.9 secs : initdesign
#
# [mbo] 0: num_leaves=6504; min_child_weight=6.79; min_data_in_leaf=7620; lambda_l2=583; learning_rate=0.0106; num_iterations=3502; feature_fraction=0.807; bagging_fraction=0.503 : y = 0.91 : 337.5 secs : initdesign
#
# [mbo] 0: num_leaves=6122; min_child_weight=9.65; min_data_in_leaf=2445; lambda_l2=319; learning_rate=0.0444; num_iterations=3916; feature_fraction=0.264; bagging_fraction=0.712 : y = 0.923 : 486.8 secs : initdesign
#
# [mbo] 0: num_leaves=1660; min_child_weight=8.27; min_data_in_leaf=4730; lambda_l2=487; learning_rate=0.0694; num_iterations=2059; feature_fraction=0.113; bagging_fraction=0.571 : y = 0.918 : 178.3 secs : initdesign
#
# [mbo] 0: num_leaves=3392; min_child_weight=0.816; min_data_in_leaf=1075; lambda_l2=783; learning_rate=0.086; num_iterations=1660; feature_fraction=0.916; bagging_fraction=0.626 : y = 0.919 : 225.3 secs : initdesign
#
# [mbo] 0: num_leaves=7498; min_child_weight=3.8; min_data_in_leaf=2682; lambda_l2=552; learning_rate=0.0554; num_iterations=902; feature_fraction=0.441; bagging_fraction=0.624 : y = 0.914 : 136.0 secs : initdesign
#
# [mbo] 0: num_leaves=4749; min_child_weight=5.03; min_data_in_leaf=3236; lambda_l2=770; learning_rate=0.041; num_iterations=4421; feature_fraction=0.998; bagging_fraction=0.855 : y = 0.915 : 525.3 secs : initdesign
#
# [mbo] 0: num_leaves=4290; min_child_weight=4.61; min_data_in_leaf=157; lambda_l2=523; learning_rate=0.027; num_iterations=771; feature_fraction=0.37; bagging_fraction=0.959 : y = 0.913 : 110.9 secs : initdesign
#
# [mbo] 0: num_leaves=2163; min_child_weight=6.31; min_data_in_leaf=7374; lambda_l2=988; learning_rate=0.0257; num_iterations=2302; feature_fraction=0.761; bagging_fraction=0.86 : y = 0.912 : 206.3 secs : initdesign
#
# [mbo] 0: num_leaves=4398; min_child_weight=7.15; min_data_in_leaf=8061; lambda_l2=699; learning_rate=0.0999; num_iterations=4272; feature_fraction=0.621; bagging_fraction=0.552 : y = 0.916 : 457.7 secs : initdesign
#
# [mbo] 0: num_leaves=8057; min_child_weight=6.16; min_data_in_leaf=5894; lambda_l2=107; learning_rate=0.0822; num_iterations=2706; feature_fraction=0.0596; bagging_fraction=0.981 : y = 0.925 : 207.3 secs : initdesign
#
# [mbo] 0: num_leaves=2412; min_child_weight=8.95; min_data_in_leaf=3897; lambda_l2=140; learning_rate=0.0374; num_iterations=559; feature_fraction=0.702; bagging_fraction=0.675 : y = 0.912 : 65.4 secs : initdesign
#
# [mbo] 0: num_leaves=4085; min_child_weight=2.65; min_data_in_leaf=834; lambda_l2=884; learning_rate=0.0956; num_iterations=141; feature_fraction=0.0896; bagging_fraction=0.537 : y = 0.902 : 10.8 secs : initdesign
#
# [mbo] 0: num_leaves=7925; min_child_weight=8.54; min_data_in_leaf=409; lambda_l2=919; learning_rate=0.0115; num_iterations=3406; feature_fraction=0.149; bagging_fraction=0.828 : y = 0.912 : 326.1 secs : initdesign
#
# [mbo] 0: num_leaves=5517; min_child_weight=7.39; min_data_in_leaf=1597; lambda_l2=27.3; learning_rate=0.0714; num_iterations=4959; feature_fraction=0.903; bagging_fraction=0.786 : y = 0.929 : 626.8 secs : initdesign
#
# [mbo] 0: num_leaves=5223; min_child_weight=0.0616; min_data_in_leaf=3051; lambda_l2=738; learning_rate=0.0304; num_iterations=4627; feature_fraction=0.19; bagging_fraction=0.522 : y = 0.916 : 495.3 secs : initdesign
#
# [mbo] 0: num_leaves=799; min_child_weight=1.12; min_data_in_leaf=1829; lambda_l2=76; learning_rate=0.015; num_iterations=3644; feature_fraction=0.958; bagging_fraction=0.688 : y = 0.925 : 517.7 secs : initdesign
#
# [mbo] 0: num_leaves=7097; min_child_weight=1.56; min_data_in_leaf=6944; lambda_l2=41; learning_rate=0.0187; num_iterations=294; feature_fraction=0.335; bagging_fraction=0.581 : y = 0.907 : 38.8 secs : initdesign
#
# [mbo] 0: num_leaves=235; min_child_weight=9.78; min_data_in_leaf=1319; lambda_l2=951; learning_rate=0.0784; num_iterations=2228; feature_fraction=0.569; bagging_fraction=0.832 : y = 0.919 : 394.6 secs : initdesign
#
# [mbo] 0: num_leaves=7235; min_child_weight=1.61; min_data_in_leaf=4524; lambda_l2=383; learning_rate=0.0893; num_iterations=1065; feature_fraction=0.829; bagging_fraction=0.928 : y = 0.914 : 123.6 secs : initdesign
#
# [mbo] 0: num_leaves=757; min_child_weight=7.93; min_data_in_leaf=7718; lambda_l2=366; learning_rate=0.00698; num_iterations=4813; feature_fraction=0.245; bagging_fraction=0.596 : y = 0.912 : 514.8 secs : initdesign
#
# Saved the current state after iteration 1 in the file HT.RDATA.
#
# Wed Nov 19 05:56:36 AM 2025 AUC 0.933659537945025
#
# [mbo] 1: num_leaves=2983; min_child_weight=0.372; min_data_in_leaf=14; lambda_l2=2.56; learning_rate=0.0877; num_iterations=4746; feature_fraction=0.949; bagging_fraction=0.72 : y = 0.934 : 636.9 secs : infill_ei
#
# Saved the current state after iteration 2 in the file HT.RDATA.
#
# Wed Nov 19 06:10:47 AM 2025 AUC 0.929569733365813
#
# [mbo] 2: num_leaves=180; min_child_weight=0.116; min_data_in_leaf=187; lambda_l2=41.1; learning_rate=0.0944; num_iterations=4994; feature_fraction=0.724; bagging_fraction=0.822 : y = 0.93 : 850.2 secs : infill_ei
#
# Saved the current state after iteration 3 in the file HT.RDATA.
#
# Wed Nov 19 06:18:01 AM 2025 AUC 0.931975836297762
#
# [mbo] 3: num_leaves=2538; min_child_weight=2.89; min_data_in_leaf=3; lambda_l2=0.581; learning_rate=0.0909; num_iterations=4117; feature_fraction=0.99; bagging_fraction=0.519 : y = 0.932 : 433.0 secs : infill_ei
#
# Wed Nov 19 06:26:44 AM 2025 AUC 0.93184699185126
#
# [mbo] 4: num_leaves=6836; min_child_weight=2.52; min_data_in_leaf=34; lambda_l2=0.0508; learning_rate=0.0822; num_iterations=4999; feature_fraction=0.724; bagging_fraction=0.576 : y = 0.932 : 522.7 secs : infill_ei
#
# Saved the current state after iteration 5 in the file HT.RDATA.
#
# Wed Nov 19 06:37:11 AM 2025 AUC 0.930042498535401
#
# [mbo] 5: num_leaves=6293; min_child_weight=0.107; min_data_in_leaf=11; lambda_l2=0.797; learning_rate=0.0803; num_iterations=4393; feature_fraction=0.999; bagging_fraction=0.678 : y = 0.93 : 625.9 secs : infill_ei
#
# Saved the current state after iteration 6 in the file HT.RDATA.
#
# Wed Nov 19 06:50:26 AM 2025 AUC 0.933905818735996
#
# [mbo] 6: num_leaves=3959; min_child_weight=3.66; min_data_in_leaf=7; lambda_l2=1.2; learning_rate=0.0985; num_iterations=4877; feature_fraction=0.528; bagging_fraction=0.693 : y = 0.934 : 794.7 secs : infill_ei
#
# Saved the current state after iteration 7 in the file HT.RDATA.
#
# Wed Nov 19 06:58:54 AM 2025 AUC 0.927904150468839
#
# [mbo] 7: num_leaves=2766; min_child_weight=6.99; min_data_in_leaf=16; lambda_l2=1.44; learning_rate=0.0928; num_iterations=4946; feature_fraction=0.845; bagging_fraction=0.64 : y = 0.928 : 506.9 secs : infill_ei
#
# Wed Nov 19 07:08:21 AM 2025 AUC 0.927687732062605
#
# [mbo] 8: num_leaves=3715; min_child_weight=1.82; min_data_in_leaf=1060; lambda_l2=0.649; learning_rate=0.0943; num_iterations=4997; feature_fraction=0.625; bagging_fraction=0.697 : y = 0.928 : 566.0 secs : infill_ei
#
# Saved the current state after iteration 9 in the file HT.RDATA.
#
# Wed Nov 19 07:22:11 AM 2025 AUC 0.929236885212348
#
# [mbo] 9: num_leaves=7395; min_child_weight=4.95; min_data_in_leaf=5; lambda_l2=12.7; learning_rate=0.093; num_iterations=4984; feature_fraction=0.484; bagging_fraction=0.825 : y = 0.929 : 829.5 secs : infill_ei
#
# Saved the current state after iteration 10 in the file HT.RDATA.
#
# Wed Nov 19 07:33:50 AM 2025 AUC 0.924776988381855
#
# [mbo] 10: num_leaves=5116; min_child_weight=3.87; min_data_in_leaf=5; lambda_l2=52.7; learning_rate=0.0785; num_iterations=4942; feature_fraction=0.881; bagging_fraction=0.64 : y = 0.925 : 698.1 secs : infill_ei
#
# Saved the current state after iteration 11 in the file HT.RDATA.
#
# Wed Nov 19 07:47:08 AM 2025 AUC 0.928226261585095
#
# [mbo] 11: num_leaves=3122; min_child_weight=2.93; min_data_in_leaf=3; lambda_l2=20.4; learning_rate=0.0948; num_iterations=4314; feature_fraction=0.541; bagging_fraction=0.581 : y = 0.928 : 797.1 secs : infill_ei
#
# Saved the current state after iteration 12 in the file HT.RDATA.
#
# Wed Nov 19 07:55:30 AM 2025 AUC 0.933470633196637
#
# [mbo] 12: num_leaves=1734; min_child_weight=1.94; min_data_in_leaf=93; lambda_l2=0.0241; learning_rate=0.0849; num_iterations=4981; feature_fraction=0.739; bagging_fraction=0.78 : y = 0.933 : 501.6 secs : infill_ei
#
# Wed Nov 19 08:03:52 AM 2025 AUC 0.92964220836697
#
# [mbo] 13: num_leaves=4492; min_child_weight=3.47; min_data_in_leaf=4; lambda_l2=0.804; learning_rate=0.0999; num_iterations=4893; feature_fraction=0.861; bagging_fraction=0.804 : y = 0.93 : 500.9 secs : infill_ei
#
# Saved the current state after iteration 14 in the file HT.RDATA.
#
# Wed Nov 19 08:09:45 AM 2025 AUC 0.934163507629
#
# [mbo] 14: num_leaves=1565; min_child_weight=0.285; min_data_in_leaf=12; lambda_l2=2.97; learning_rate=0.0864; num_iterations=2314; feature_fraction=0.777; bagging_fraction=0.72 : y = 0.934 : 351.8 secs : infill_ei
#
# Wed Nov 19 08:15:34 AM 2025 AUC 0.928001119336129
#
# [mbo] 15: num_leaves=1781; min_child_weight=1.73; min_data_in_leaf=648; lambda_l2=0.119; learning_rate=0.095; num_iterations=3181; feature_fraction=0.97; bagging_fraction=0.812 : y = 0.928 : 348.9 secs : infill_ei
#
# Saved the current state after iteration 16 in the file HT.RDATA.
#
# Wed Nov 19 08:32:44 AM 2025 AUC 0.924072370315045
#
# [mbo] 16: num_leaves=1630; min_child_weight=0.0131; min_data_in_leaf=5; lambda_l2=201; learning_rate=0.0648; num_iterations=4128; feature_fraction=0.819; bagging_fraction=0.705 : y = 0.924 : 1028.6 secs : infill_ei
#
# Saved the current state after iteration 17 in the file HT.RDATA.
#
# Wed Nov 19 08:44:48 AM 2025 AUC 0.931270211633714
#
# [mbo] 17: num_leaves=831; min_child_weight=5.1; min_data_in_leaf=23; lambda_l2=0.325; learning_rate=0.0369; num_iterations=4161; feature_fraction=0.541; bagging_fraction=0.735 : y = 0.931 : 723.9 secs : infill_ei
#
# Saved the current state after iteration 18 in the file HT.RDATA.
#
# Wed Nov 19 08:51:41 AM 2025 AUC 0.935337535541271
#
# [mbo] 18: num_leaves=1121; min_child_weight=3.76; min_data_in_leaf=5; lambda_l2=0.117; learning_rate=0.0906; num_iterations=3719; feature_fraction=0.623; bagging_fraction=0.727 : y = 0.935 : 411.8 secs : infill_ei
#
# Wed Nov 19 09:00:40 AM 2025 AUC 0.929282517620485
#
# [mbo] 19: num_leaves=4605; min_child_weight=8.86; min_data_in_leaf=2; lambda_l2=1.25; learning_rate=0.0884; num_iterations=4534; feature_fraction=0.277; bagging_fraction=0.733 : y = 0.929 : 538.2 secs : infill_ei
#
# Saved the current state after iteration 20 in the file HT.RDATA.
#
# Wed Nov 19 09:06:06 AM 2025 AUC 0.93169667333034
#
# [mbo] 20: num_leaves=2738; min_child_weight=4.89; min_data_in_leaf=6; lambda_l2=0.615; learning_rate=0.081; num_iterations=3647; feature_fraction=0.102; bagging_fraction=0.724 : y = 0.932 : 325.3 secs : infill_ei
#
# Wed Nov 19 09:15:07 AM 2025 AUC 0.927032101728059
#
# [mbo] 21: num_leaves=6772; min_child_weight=8.25; min_data_in_leaf=212; lambda_l2=2.02; learning_rate=0.0722; num_iterations=4965; feature_fraction=0.658; bagging_fraction=0.902 : y = 0.927 : 539.3 secs : infill_ei
#
# Saved the current state after iteration 22 in the file HT.RDATA.
#
# Wed Nov 19 09:23:23 AM 2025 AUC 0.930312937660091
#
# [mbo] 22: num_leaves=7365; min_child_weight=7.86; min_data_in_leaf=47; lambda_l2=0.28; learning_rate=0.0378; num_iterations=4196; feature_fraction=0.765; bagging_fraction=0.703 : y = 0.93 : 495.0 secs : infill_ei
#
# Wed Nov 19 09:29:08 AM 2025 AUC 0.930020017863746
#
# [mbo] 23: num_leaves=6989; min_child_weight=3.79; min_data_in_leaf=14; lambda_l2=0.501; learning_rate=0.0924; num_iterations=3142; feature_fraction=0.926; bagging_fraction=0.539 : y = 0.93 : 344.2 secs : infill_ei
#
# Saved the current state after iteration 24 in the file HT.RDATA.
#
# Wed Nov 19 09:38:24 AM 2025 AUC 0.92787630127858
#
# [mbo] 24: num_leaves=63; min_child_weight=0.293; min_data_in_leaf=1534; lambda_l2=0.452; learning_rate=0.0568; num_iterations=4284; feature_fraction=0.91; bagging_fraction=0.72 : y = 0.928 : 555.4 secs : infill_ei
#
# Wed Nov 19 09:47:01 AM 2025 AUC 0.933278037591709
#
# [mbo] 25: num_leaves=2849; min_child_weight=0.179; min_data_in_leaf=4; lambda_l2=2.57; learning_rate=0.0956; num_iterations=3561; feature_fraction=0.8; bagging_fraction=0.753 : y = 0.933 : 516.0 secs : infill_ei
#
# Saved the current state after iteration 26 in the file HT.RDATA.
#
# Wed Nov 19 09:59:40 AM 2025 AUC 0.923577795538627
#
# [mbo] 26: num_leaves=1943; min_child_weight=9.04; min_data_in_leaf=7; lambda_l2=0.00913; learning_rate=0.0971; num_iterations=4740; feature_fraction=0.526; bagging_fraction=0.746 : y = 0.924 : 757.9 secs : infill_ei
#
# Saved the current state after iteration 27 in the file HT.RDATA.
#
# Wed Nov 19 10:07:13 AM 2025 AUC 0.93324414881802
#
# [mbo] 27: num_leaves=269; min_child_weight=0.965; min_data_in_leaf=6; lambda_l2=0.744; learning_rate=0.0621; num_iterations=3861; feature_fraction=0.858; bagging_fraction=0.7 : y = 0.933 : 452.5 secs : infill_ei
#
# Wed Nov 19 10:10:47 AM 2025 AUC 0.930859184428075
#
# [mbo] 28: num_leaves=6296; min_child_weight=6.92; min_data_in_leaf=119; lambda_l2=4.95; learning_rate=0.0552; num_iterations=1452; feature_fraction=0.327; bagging_fraction=0.713 : y = 0.931 : 212.8 secs : infill_ei
#
# Saved the current state after iteration 29 in the file HT.RDATA.
#
# Wed Nov 19 10:21:23 AM 2025 AUC 0.924078409898475
#
# [mbo] 29: num_leaves=6795; min_child_weight=6.68; min_data_in_leaf=1119; lambda_l2=0.358; learning_rate=0.0626; num_iterations=4719; feature_fraction=0.335; bagging_fraction=0.643 : y = 0.924 : 634.6 secs : infill_ei
#
# Saved the current state after iteration 30 in the file HT.RDATA.
#
# Wed Nov 19 10:29:15 AM 2025 AUC 0.933216635160173
#
# [mbo] 30: num_leaves=2687; min_child_weight=2.63; min_data_in_leaf=26; lambda_l2=0.829; learning_rate=0.044; num_iterations=2557; feature_fraction=0.576; bagging_fraction=0.73 : y = 0.933 : 471.1 secs : infill_ei
#
# Wed Nov 19 10:36:41 AM 2025 AUC 0.929248628846795
#
# [mbo] 31: num_leaves=6449; min_child_weight=8.21; min_data_in_leaf=4; lambda_l2=35.9; learning_rate=0.0258; num_iterations=2824; feature_fraction=0.347; bagging_fraction=0.801 : y = 0.929 : 445.4 secs : infill_ei
#
# Saved the current state after iteration 32 in the file HT.RDATA.
#
# Wed Nov 19 10:44:20 AM 2025 AUC 0.932065758984384
#
# [mbo] 32: num_leaves=5920; min_child_weight=3.82; min_data_in_leaf=11; lambda_l2=3.22; learning_rate=0.0789; num_iterations=3932; feature_fraction=0.708; bagging_fraction=0.731 : y = 0.932 : 457.8 secs : infill_ei
#
# Wed Nov 19 10:50:48 AM 2025 AUC 0.926234541182913
#
# [mbo] 33: num_leaves=7927; min_child_weight=8.23; min_data_in_leaf=75; lambda_l2=213; learning_rate=0.0948; num_iterations=4779; feature_fraction=0.0523; bagging_fraction=0.873 : y = 0.926 : 386.6 secs : infill_ei
#
# Saved the current state after iteration 34 in the file HT.RDATA.
#
# Wed Nov 19 10:58:03 AM 2025 AUC 0.932828088626189
#
# [mbo] 34: num_leaves=894; min_child_weight=2.72; min_data_in_leaf=7; lambda_l2=0.148; learning_rate=0.0844; num_iterations=2859; feature_fraction=0.431; bagging_fraction=0.726 : y = 0.933 : 434.1 secs : infill_ei
#
# Wed Nov 19 11:09:33 AM 2025 AUC 0.935388872000424
#
# [mbo] 35: num_leaves=1755; min_child_weight=3.01; min_data_in_leaf=24; lambda_l2=0.0245; learning_rate=0.0118; num_iterations=4907; feature_fraction=0.648; bagging_fraction=0.736 : y = 0.935 : 688.6 secs : infill_ei
#
# Saved the current state after iteration 36 in the file HT.RDATA.
#
# Wed Nov 19 11:15:41 AM 2025 AUC 0.93084039461296
#
# [mbo] 36: num_leaves=2797; min_child_weight=0.355; min_data_in_leaf=21; lambda_l2=0.954; learning_rate=0.0167; num_iterations=1842; feature_fraction=0.952; bagging_fraction=0.742 : y = 0.931 : 367.3 secs : infill_ei
#
# Wed Nov 19 11:20:34 AM 2025 AUC 0.933854482276842
#
# [mbo] 37: num_leaves=2981; min_child_weight=3.59; min_data_in_leaf=18; lambda_l2=0.383; learning_rate=0.0133; num_iterations=1734; feature_fraction=0.701; bagging_fraction=0.657 : y = 0.934 : 292.0 secs : infill_ei
#
# Saved the current state after iteration 38 in the file HT.RDATA.
#
# Wed Nov 19 11:27:06 AM 2025 AUC 0.935574085892271
#
# [mbo] 38: num_leaves=1648; min_child_weight=3.57; min_data_in_leaf=4; lambda_l2=0.0405; learning_rate=0.0124; num_iterations=2488; feature_fraction=0.821; bagging_fraction=0.701 : y = 0.936 : 390.9 secs : infill_ei
#
# Wed Nov 19 11:31:41 AM 2025 AUC 0.931508775179191
#
# [mbo] 39: num_leaves=5001; min_child_weight=6.7; min_data_in_leaf=22; lambda_l2=0.231; learning_rate=0.02; num_iterations=1791; feature_fraction=0.843; bagging_fraction=0.786 : y = 0.932 : 273.1 secs : infill_ei
#
# Saved the current state after iteration 40 in the file HT.RDATA.
#
# Wed Nov 19 11:38:15 AM 2025 AUC 0.934774512152649
#
# [mbo] 40: num_leaves=819; min_child_weight=3.35; min_data_in_leaf=2; lambda_l2=0.833; learning_rate=0.009; num_iterations=2313; feature_fraction=0.735; bagging_fraction=0.735 : y = 0.935 : 393.4 secs : infill_ei
#
# Wed Nov 19 11:40:08 AM 2025 AUC 0.924735382362672
#
# [mbo] 41: num_leaves=7739; min_child_weight=8.18; min_data_in_leaf=16; lambda_l2=0.301; learning_rate=0.0868; num_iterations=1305; feature_fraction=0.0591; bagging_fraction=0.817 : y = 0.925 : 112.2 secs : infill_ei
#
# Wed Nov 19 11:43:54 AM 2025 AUC 0.927926966672908
#
# [mbo] 42: num_leaves=6922; min_child_weight=7.88; min_data_in_leaf=1254; lambda_l2=0.834; learning_rate=0.0335; num_iterations=1614; feature_fraction=0.982; bagging_fraction=0.705 : y = 0.928 : 225.3 secs : infill_ei
#
# Saved the current state after iteration 43 in the file HT.RDATA.
#
# Wed Nov 19 11:53:43 AM 2025 AUC 0.931630908977438
#
# [mbo] 43: num_leaves=1525; min_child_weight=3.34; min_data_in_leaf=305; lambda_l2=0.621; learning_rate=0.02; num_iterations=4443; feature_fraction=0.841; bagging_fraction=0.71 : y = 0.932 : 587.5 secs : infill_ei
#
# Wed Nov 19 12:05:09 PM 2025 AUC 0.922055484981905
#
# [mbo] 44: num_leaves=7745; min_child_weight=7.79; min_data_in_leaf=2386; lambda_l2=172; learning_rate=0.0552; num_iterations=4949; feature_fraction=0.991; bagging_fraction=0.983 : y = 0.922 : 685.1 secs : infill_ei
#
# Saved the current state after iteration 45 in the file HT.RDATA.
#
# Wed Nov 19 12:11:55 PM 2025 AUC 0.926953251611059
#
# [mbo] 45: num_leaves=7289; min_child_weight=7.87; min_data_in_leaf=1941; lambda_l2=64.1; learning_rate=0.0936; num_iterations=2953; feature_fraction=0.827; bagging_fraction=0.906 : y = 0.927 : 405.0 secs : infill_ei
#
# Wed Nov 19 12:20:25 PM 2025 AUC 0.935966994347621
#
# [mbo] 46: num_leaves=1413; min_child_weight=3.28; min_data_in_leaf=5; lambda_l2=0.893; learning_rate=0.027; num_iterations=4987; feature_fraction=0.146; bagging_fraction=0.852 : y = 0.936 : 509.3 secs : infill_ei
#
# Saved the current state after iteration 47 in the file HT.RDATA.
#
# Wed Nov 19 12:29:19 PM 2025 AUC 0.937615800623956
#
# [mbo] 47: num_leaves=4518; min_child_weight=4.04; min_data_in_leaf=8; lambda_l2=0.0234; learning_rate=0.0221; num_iterations=3836; feature_fraction=0.298; bagging_fraction=0.989 : y = 0.938 : 532.4 secs : infill_ei
#
# Wed Nov 19 12:36:56 PM 2025 AUC 0.929726762534988
#
# [mbo] 48: num_leaves=2174; min_child_weight=3.86; min_data_in_leaf=260; lambda_l2=0.481; learning_rate=0.0627; num_iterations=3465; feature_fraction=0.298; bagging_fraction=0.959 : y = 0.93 : 456.0 secs : infill_ei
#
# Saved the current state after iteration 49 in the file HT.RDATA.
#
# Wed Nov 19 12:44:19 PM 2025 AUC 0.937003118438244
#
# [mbo] 49: num_leaves=4278; min_child_weight=3.86; min_data_in_leaf=2; lambda_l2=0.392; learning_rate=0.00527; num_iterations=3145; feature_fraction=0.206; bagging_fraction=0.863 : y = 0.937 : 441.0 secs : infill_ei
#
# Wed Nov 19 12:51:22 PM 2025 AUC 0.934954357525891
#
# [mbo] 50: num_leaves=3582; min_child_weight=4.62; min_data_in_leaf=6; lambda_l2=24.4; learning_rate=0.016; num_iterations=4760; feature_fraction=0.0573; bagging_fraction=0.976 : y = 0.935 : 422.1 secs : infill_ei
#
# Saved the current state after iteration 51 in the file HT.RDATA.
#
# Wed Nov 19 01:02:34 PM 2025 AUC 0.938809960480992
#
# [mbo] 51: num_leaves=4416; min_child_weight=1.33; min_data_in_leaf=11; lambda_l2=0.391; learning_rate=0.0112; num_iterations=4953; feature_fraction=0.244; bagging_fraction=0.982 : y = 0.939 : 670.6 secs : infill_ei
#
# Saved the current state after iteration 52 in the file HT.RDATA.
#
# Wed Nov 19 01:17:39 PM 2025 AUC 0.936299842501085
#
# [mbo] 52: num_leaves=7995; min_child_weight=2.41; min_data_in_leaf=8; lambda_l2=1.57; learning_rate=0.00548; num_iterations=4654; feature_fraction=0.413; bagging_fraction=0.89 : y = 0.936 : 903.0 secs : infill_ei
#
# Saved the current state after iteration 53 in the file HT.RDATA.
#
# Wed Nov 19 01:26:51 PM 2025 AUC 0.930243482450648
#
# [mbo] 53: num_leaves=4987; min_child_weight=3.63; min_data_in_leaf=18; lambda_l2=22.9; learning_rate=0.00697; num_iterations=3945; feature_fraction=0.227; bagging_fraction=0.999 : y = 0.93 : 549.9 secs : infill_ei
#
# Wed Nov 19 01:39:02 PM 2025 AUC 0.940128267330752
#
# [mbo] 54: num_leaves=5932; min_child_weight=1.21; min_data_in_leaf=5; lambda_l2=0.58; learning_rate=0.0255; num_iterations=4570; feature_fraction=0.381; bagging_fraction=0.886 : y = 0.94 : 729.5 secs : infill_ei
#
# Saved the current state after iteration 55 in the file HT.RDATA.
#
# Wed Nov 19 01:46:56 PM 2025 AUC 0.938943502381274
#
# [mbo] 55: num_leaves=2271; min_child_weight=0.357; min_data_in_leaf=2; lambda_l2=0.342; learning_rate=0.0186; num_iterations=4685; feature_fraction=0.0894; bagging_fraction=0.668 : y = 0.939 : 473.2 secs : infill_ei
#
# Wed Nov 19 01:54:49 PM 2025 AUC 0.938680109437252
#
# [mbo] 56: num_leaves=6001; min_child_weight=1.19; min_data_in_leaf=16; lambda_l2=0.072; learning_rate=0.0195; num_iterations=3563; feature_fraction=0.237; bagging_fraction=0.855 : y = 0.939 : 471.3 secs : infill_ei
#
# Saved the current state after iteration 57 in the file HT.RDATA.
#
# Wed Nov 19 02:02:52 PM 2025 AUC 0.937852015442544
#
# [mbo] 57: num_leaves=4996; min_child_weight=1.42; min_data_in_leaf=14; lambda_l2=0.224; learning_rate=0.0236; num_iterations=4248; feature_fraction=0.157; bagging_fraction=0.593 : y = 0.938 : 482.4 secs : infill_ei
#
# Wed Nov 19 02:15:09 PM 2025 AUC 0.927094510756834
#
# [mbo] 58: num_leaves=6454; min_child_weight=8.1; min_data_in_leaf=3; lambda_l2=31; learning_rate=0.0257; num_iterations=4991; feature_fraction=0.644; bagging_fraction=0.842 : y = 0.927 : 735.0 secs : infill_ei
#
# Saved the current state after iteration 59 in the file HT.RDATA.
#
# Wed Nov 19 02:24:02 PM 2025 AUC 0.939661541744594
#
# [mbo] 59: num_leaves=2749; min_child_weight=0.704; min_data_in_leaf=6; lambda_l2=0.0872; learning_rate=0.00571; num_iterations=4534; feature_fraction=0.107; bagging_fraction=0.859 : y = 0.94 : 532.0 secs : infill_ei
#
# Wed Nov 19 02:30:35 PM 2025 AUC 0.926141934236989
#
# [mbo] 60: num_leaves=4057; min_child_weight=4.28; min_data_in_leaf=2134; lambda_l2=5.07; learning_rate=0.00741; num_iterations=2672; feature_fraction=0.927; bagging_fraction=0.66 : y = 0.926 : 391.7 secs : infill_ei
#
# Saved the current state after iteration 61 in the file HT.RDATA.
#
# Wed Nov 19 02:44:39 PM 2025 AUC 0.938554284782464
#
# [mbo] 61: num_leaves=2111; min_child_weight=0.671; min_data_in_leaf=14; lambda_l2=0.684; learning_rate=0.0212; num_iterations=4722; feature_fraction=0.478; bagging_fraction=0.943 : y = 0.939 : 842.5 secs : infill_ei
#
# Saved the current state after iteration 62 in the file HT.RDATA.

# %% [markdown]
# la bayesian optimization ha corrido, extraigo los mejores hiperparametros

# %%
# almaceno los resultados de la Bayesian Optimization
# y capturo los mejores hiperparametros encontrados

tb_bayesiana <- as.data.table(bayesiana_salida$opt.path)

# ordeno en forma descendente por AUC = y
setorder(tb_bayesiana, -y, -num_iterations)

# grabo para eventualmente poder utilizarlos en OTRA corrida
fwrite( tb_bayesiana,
  file="BO_log.txt",
  sep="\t"
)

# los mejores hiperparámetros son los que quedaron en el registro 1 de la tabla
PARAM$out$lgbm$mejores_hiperparametros <- tb_bayesiana[
  1, # el primero es el de mejor AUC
  setdiff(colnames(tb_bayesiana),
    c("y","dob","eol","error.message","exec.time","ei","error.model",
      "train.time","prop.type","propose.time","se","mean","iter")),
  with= FALSE
]

print(PARAM$out$lgbm$mejores_hiperparametros)

# %% [markdown]
# ### 6.3.3 Produccion

# %% [markdown]
# #### Final Training
# Construyo el modelo final, que es uno solo, no hace ningun tipo de particion < training, validation, testing>]

# %% [markdown]
# ##### Final Training Dataset
#
# Aqui esta la gran decision de en qué meses hago el Final Training
# <br> debo utilizar los mejores hiperparámetros que encontré en la optimización bayesiana

# %%
PARAM$trainingstrategy$final_train <- c(
  202105, 202104, 202103, 202102, 202101,
  202012, 202011, 202010, 202009, 202008, 202007,
  202006, 202005
)

dataset[, fold_final_train := foto_mes %in% PARAM$trainingstrategy$final_train ]

# creo el dfinal_train en formato  LightGBM
dfinal_train <- lgb.Dataset(
  data= data.matrix(dataset[fold_final_train == TRUE, campos_buenos, with= FALSE]),
  label= dataset[fold_final_train == TRUE, clase01],
  free_raw_data= TRUE
)

nrow( dfinal_train) # verifico el tamaño

# %% [markdown]
# ##### Final Training Hyperparameters

# %%
# uno los parametros fijos y los mejores encontrados de los variables
fijos <- copy(PARAM$lgbm$param_fijos)

# quito lo que optimice en la Bayesian Optimization
fijos$num_iterations <- NULL
fijos$early_stopping_rounds <- NULL

# agrego a los hiperparametros fijos los que encontre con la Bayesian Optimization
param_final <- c(fijos, PARAM$out$lgbm$mejores_hiperparametros)

# Para el entrenamiento final, removemos early_stopping_rounds
# ya que se entrena con todos los datos disponibles y la cantidad de iteraciones
# ya está optimizada en 'num_iterations'.
param_final$early_stopping_rounds <- NULL

# %% [markdown]
# ##### Training
# Genero el modelo final, siempre sobre TODOS los datos de  final_train, sin hacer ningun tipo de undersampling de la clase mayoritaria

# %%
final_model <- lgb.train(
  data= dfinal_train,
  param= param_final,
  verbose= -100
)

# %%
# grabo a disco el modelo en un formato para seres humanos ... ponele ...

lgb.save(final_model, "modelo.txt")

# %%
# ahora imprimo la importancia de variables

tb_importancia <- as.data.table(lgb.importance(final_model))
archivo_importancia <- "impo.txt"

fwrite( tb_importancia,
  file= archivo_importancia,
  sep= "\t"
)

# %% [markdown]
# #### Scoring

# %% [markdown]
# Aplico el modelo final a los datos del futuro

# %%
PARAM$trainingstrategy$future <- c(202107)

dfuture <- dataset[ foto_mes %in% PARAM$trainingstrategy$future ]

# %%
# aplico final_model   a dfuture

prediccion <- predict(
  final_model,
  data.matrix(dfuture[, campos_buenos, with= FALSE])
)

# %% [markdown]
# ##### Tabla Prediccion

# %%
tb_prediccion <- dfuture[, list(numero_de_cliente)]
tb_prediccion[, prob := prediccion]

# grabo las probabilidad del modelo
#  me va a ser util para hacer Ensembles de modelos
fwrite(tb_prediccion,
  file= "prediccion.txt",
  sep= "\t"
)

# %% [markdown]
# #### Curva de Ganancia

# %% [markdown]
# Genero las salidas

# %%
# asigno clase ternaria
tb_prediccion[, clase_ternaria := dfuture$clase_ternaria ]

# asigno ganancias
tb_prediccion[, ganancia := -3000.0 ]
tb_prediccion[clase_ternaria=="BAJA+2", ganancia := 117000.0 ]

# reordeno, y acumulada
setorder( tb_prediccion, -prob )
tb_prediccion[, gan_acum := cumsum(ganancia)]

# media movil de ancho 400
tb_prediccion[,
  gan_suavizada := frollmean(
    x= gan_acum,
    n= 400,
    align= "center",
    na.rm= TRUE,
    hasNA= TRUE
  )
]

# %%
tb_prediccion[, sum(!is.na(gan_suavizada) )]
tb_prediccion[, .N]

# %%
# Este es la ganancia a reportar
resultado <- list()
resultado$ganancia_suavizada_max <- max( tb_prediccion$gan_suavizada, na.rm=TRUE )
options(digits= 8)
resultado$envios <- which.max( tb_prediccion$gan_suavizada)
resultado

# %%
# grabo las ganancias
fwrite( tb_prediccion,
  file= "ganancias.txt",
  sep= "\t"
)

# %%
# genero el grafico

tb_prediccion[, envios:= .I]

pdf("curva_de_ganancia.pdf")

plot(
  x= tb_prediccion$envios,
  y= tb_prediccion$gan_acum,
  type= "l",
  col= "gray",
  xlim= c(0, 6000),
  ylim= c(0, 8000000),
  main= paste0("Mejor gan prom= ", as.integer(resultado$ganancia_suavizada_max), " envios= ", resultado$envios),
  xlab= "Envios",
  ylab= "Ganancia",
  panel.first= grid()
)

dev.off()

# %%
# grabo los parametros
if( !require("yaml")) install.packages("yaml")
require("yaml")

PARAM$resultado <- resultado

write_yaml( PARAM, file="PARAM.yml")

# %%
format(Sys.time(), "%a %b %d %X %Y")
fin <- Sys.time()

# Duración en segundos
secs <- as.numeric(difftime(fin, principio, units = "secs"))
secs <- round(secs)

# A hh:mm:ss
h <- secs %/% 3600
m <- (secs %% 3600) %/% 60
s <- secs %% 60
dur_hms <- sprintf("%02d:%02d:%02d", h, m, s)

cat(
  "Inicio: ", format(principio, "%a %b %d %X %Y"), "\n",
  "Fin:    ", format(fin,       "%a %b %d %X %Y"), "\n",
  "Duración (hh:mm:ss): ", dur_hms, "\n",
  sep = ""
)
