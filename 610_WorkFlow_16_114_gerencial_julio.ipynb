# %% [markdown]
# <a href="https://colab.research.google.com/github/jwbarbona/labo2025v/blob/main/610_WorkFlow_16_114_gerencial_julio.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # 6 WorkFlow  Gerencial, futuro=JULIO

# %% [markdown]
# ### 6.1 Objetivo

# %% [markdown]
# Presentar un workflow/pipeline completo al que los estudiantes deberán enriquecer

# %% [markdown]
# #### 6.2  Seteo del ambiente en Google Colab

# %% [markdown]
# Esta parte se debe correr con el runtime en Python3
# <br>Ir al menu, Runtime -> Change Runtime Type -> Runtime type ->  **Python 3**

# %% [markdown]
# Conectar la virtual machine donde esta corriendo Google Colab con el  Google Drive, para poder tener persistencia de archivos

# %%
# primero establecer el Runtime de Python 3
from google.colab import drive
drive.mount('/content/.drive')
# Out:
# Mounted at /content/.drive

# %% [markdown]
# Para correr la siguiente celda es fundamental en Arranque en Frio haber copiado el archivo kaggle.json al Google Drive, en la carpeta indicada en el instructivo
#
# <br>los siguientes comando estan en shell script de Linux
# *   Crear las carpetas en el Google Drive
# *   "instalar" el archivo kaggle.json desde el Google Drive a la virtual machine para que pueda ser utilizado por la libreria  kaggle de Python
# *   Bajar el  **dataset_pequeno**  al  Google Drive  y tambien al disco local de la virtual machine que esta corriendo Google Colab
# *   Bajar el **dataset_historico** al Google Drive y tambien al disco local de la virtual machine que esta corriendo Google Colab

# %%
%%shell

mkdir -p "/content/.drive/My Drive/labo1"
mkdir -p "/content/buckets"
ln -s "/content/.drive/My Drive/labo1" /content/buckets/b1

mkdir -p ~/.kaggle
cp /content/buckets/b1/kaggle/kaggle.json  ~/.kaggle
chmod 600 ~/.kaggle/kaggle.json


mkdir -p /content/buckets/b1/exp
mkdir -p /content/buckets/b1/datasets
mkdir -p /content/datasets


webfiles="https://storage.googleapis.com/open-courses/austral2025-af91/"
destino_local="/content/datasets"
destino_bucket="/content/buckets/b1/datasets"


archivo="dataset_pequeno.csv"

if ! test -f $destino_bucket/$archivo; then
  wget  $webfiles/$archivo  -O $destino_bucket/$archivo
fi


if ! test -f $destino_local/$pequeno; then
  cp  $destino_bucket/$archivo  $destino_local/$archivo
fi

#-------

archivo="gerencial_competencia_2025.csv.gz"

if ! test -f $destino_bucket/$archivo; then
  wget  $webfiles/$archivo  -O $destino_bucket/$archivo
fi


if ! test -f $destino_local/$pequeno; then
  cp  $destino_bucket/$archivo  $destino_local/$archivo
fi
# Out:
# cp: cannot stat '/content/buckets/b1/kaggle/kaggle.json': No such file or directory
# chmod: cannot access '/root/.kaggle/kaggle.json': No such file or directory

# %% [markdown]
# ## 6.3  Workflow

# %% [markdown]
# ## Inicializacion

# %% [markdown]
# Esta parte se debe correr con el runtime en lenguaje **R** Ir al menu, Runtime -> Change Runtime Type -> Runtime type -> R

# %% [markdown]
# limpio el ambiente de R

# %%
format(Sys.time(), "%a %b %d %X %Y")
# Out:
# [1] "Mon Nov 17 09:36:33 PM 2025"

# %%
# limpio la memoria
rm(list=ls(all.names=TRUE)) # remove all objects
gc(full=TRUE, verbose=FALSE) # garbage collection
# Out:
#        used    (Mb) gc trigger (Mb) max used (Mb)
# Ncells  660443 35.3 1454482    77.7 1438382  76.9
# Vcells 1226662  9.4 8388608    64.0 1975136  15.1

# %%
principio <- Sys.time()

# %%
require("data.table")

if( !require("R.utils")) install.packages("R.utils")
require("R.utils")
# Out:
# Loading required package: data.table
#
# Loading required package: R.utils
#
# Warning message in library(package, lib.loc = lib.loc, character.only = TRUE, logical.return = TRUE, :
# “there is no package called ‘R.utils’”
# Installing package into ‘/usr/local/lib/R/site-library’
# (as ‘lib’ is unspecified)
#
# also installing the dependencies ‘R.oo’, ‘R.methodsS3’
#
#
# Loading required package: R.utils
#
# Loading required package: R.oo
#
# Loading required package: R.methodsS3
#
# R.methodsS3 v1.8.2 (2022-06-13 22:00:14 UTC) successfully loaded. See ?R.methodsS3 for help.
#
# R.oo v1.27.1 (2025-05-02 21:00:05 UTC) successfully loaded. See ?R.oo for help.
#
#
# Attaching package: ‘R.oo’
#
#
# The following object is masked from ‘package:R.methodsS3’:
#
#     throw
#
#
# The following objects are masked from ‘package:methods’:
#
#     getClasses, getMethods
#
#
# The following objects are masked from ‘package:base’:
#
#     attach, detach, load, save
#
#
# R.utils v2.13.0 (2025-02-24 21:20:02 UTC) successfully loaded. See ?R.utils for help.
#
#
# Attaching package: ‘R.utils’
#
#
# The following object is masked from ‘package:utils’:
#
#     timestamp
#
#
# The following objects are masked from ‘package:base’:
#
#     cat, commandArgs, getOption, isOpen, nullfile, parse, use, warnings

# %% [markdown]
# #### Parametros
# Si es gerente, no cambie nada
# <br>Si es Analista, cambie el nombre del dataset

# %%
PARAM <- list()
PARAM$semilla_primigenia <- 700009 # 100009, 200003, 499999, 700009, 999983

PARAM$experimento <- 63114
PARAM$dataset <- "gerencial_competencia_2025.csv.gz"

# %% [markdown]
# #### Carpeta del Experimento

# %%
# carpeta de trabajo

setwd("/content/buckets/b1/exp")
experimento_folder <- paste0("WF", PARAM$experimento)
dir.create(experimento_folder, showWarnings=FALSE)
setwd( paste0("/content/buckets/b1/exp/", experimento_folder ))

# %% [markdown]
# ### 6.3.1   Preprocesamiento del dataset

# %% [markdown]
# #### 6.3.1.1  DT incorporar dataset

# %%
# lectura del dataset
dataset <- fread(paste0("/content/datasets/", PARAM$dataset))

# %% [markdown]
# #### 6.3.1.2  CA  Catastrophe Analysis
# Se intentan reparar las variables que para un mes están con todos los valores en cero.

# %% [markdown]
# El método que se utiliza es **Machine Learning** se asigna NA also valores, si ha leido bien, es la "anti imputación de valores faltantes"
# <br> Usted podrá aplicar aquí otros métodos

# %%
dataset[ foto_mes==202006, internet:=NA]
dataset[ foto_mes==202006, mrentabilidad:=NA]
dataset[ foto_mes==202006, mrentabilidad_annual:=NA]
dataset[ foto_mes==202006, mcomisiones:=NA]
dataset[ foto_mes==202006, mactivos_margen:=NA]
dataset[ foto_mes==202006, mpasivos_margen:=NA]
dataset[ foto_mes==202006, mcuentas_saldo:=NA]
dataset[ foto_mes==202006, ctarjeta_visa_transacciones:=NA]
dataset[ foto_mes==202006, mtarjeta_visa_consumo:=NA]
dataset[ foto_mes==202006, mtarjeta_master_consumo:=NA]
dataset[ foto_mes==202006, ccallcenter_transacciones:=NA]
dataset[ foto_mes==202006, chomebanking_transacciones:=NA]
dataset[ foto_mes==202006, chomebanking_transacciones:=NA]

# %% [markdown]
# #### 6.3.1.3  DR  Data Drifting
# Se intenta corregir el data drifting, quizas ajustando por IPC ...
# <br>Esta parte podrá ser abordada por todos los Analistas y también la Gerenciapero se decide pedagogicamente no incluirla en esta primer version para reducir la carga cognitiva

# %%
# sin codigo en esta primera version del workflow

# %% [markdown]
# #### 6.3.1.3  FE_intra_manual Feature Engineering intra-mes
#
# Agrego campos nuevos dentro del mismo mes, SIN considerar la historia.

# %%
# esta funcion atributos presentes existe debido a que las modalidades poseen datasets con distinta cantidad de campos
atributos_presentes <- function( patributos )
{
  atributos <- unique( patributos )
  comun <- intersect( atributos, colnames(dataset) )

  return(  length( atributos ) == length( comun ) )
}

# el mes 1,2, ..12
if( atributos_presentes( c("foto_mes") ))
  dataset[, kmes := foto_mes %% 100]

# variable extraida de una tesis de maestria de Irlanda
if( atributos_presentes( c("mpayroll", "cliente_edad") ))
  dataset[, mpayroll_sobre_edad := mpayroll / cliente_edad]

# %%
# visualizo las columas del dataset a esta etapa
colnames(dataset)
# Out:
#  [1] "numero_de_cliente"           "foto_mes"
#  [3] "internet"                    "cliente_edad"
#  [5] "cliente_antiguedad"          "mrentabilidad"
#  [7] "mrentabilidad_annual"        "mcomisiones"
#  [9] "mactivos_margen"             "mpasivos_margen"
# [11] "cproductos"                  "mcuenta_corriente"
# [13] "mcaja_ahorro"                "cdescubierto_preacordado"
# [15] "mcuentas_saldo"              "ctarjeta_visa_transacciones"
# [17] "mtarjeta_visa_consumo"       "mtarjeta_master_consumo"
# [19] "mprestamos_personales"       "cpayroll_trx"
# [21] "mpayroll"                    "ccomisiones_mantenimiento"
# [23] "ccallcenter_transacciones"   "chomebanking_transacciones"
# [25] "ctrx_quarter"                "Master_status"
# [27] "Master_fechaalta"            "Master_mpagominimo"
# [29] "Visa_status"                 "Visa_fechaalta"
# [31] "Visa_mpagominimo"            "clase_ternaria"
# [33] "kmes"                        "mpayroll_sobre_edad"

# %% [markdown]
# #### 6.3.1.4  FE_rf Feature Engineering de nuevas variables a partir de hojas de Random Forest
#
# Esto se mostrará unicamente a la *modalidad Analista Sr*

# %%
# No se implementa Feature Engineering a partir de Random Forest

# %% [markdown]
# #### 6.3.1.5  FEhist Feature Engineering historico
#
# El Fature Engineering Histórico es la etapa que más aporta a la ganancia final, ya que enriquece cada registro del dataset con su historia.

# %% [markdown]
# Para cada campo del dataset original (*)
# se crean lo siguientes campos de a partir de la historia
# * lag1  lags de orden 1
# * delta1  =  valor actual - lag1
# * lag2  lags de orden 2
# * delta2  = valor actual - lag2
#
#
# (*) Excepto para los campos  <numero_de_cliente,  foto_mes,  clase_ternaria>

# %%
# Feature Engineering Historico

# todo es lagueable, menos la primary key y la clase
cols_lagueables <- copy( setdiff(
    colnames(dataset),
    c("numero_de_cliente", "foto_mes", "clase_ternaria")
) )

# https://rdrr.io/cran/data.table/man/shift.html

# lags de orden 1
dataset[,
    paste0(cols_lagueables, "_lag1") := shift(.SD, 1, NA, "lag"),
    by = numero_de_cliente,
    .SDcols = cols_lagueables
]

# lags de orden 2
dataset[,
    paste0(cols_lagueables, "_lag2") := shift(.SD, 2, NA, "lag"),
    by = numero_de_cliente,
    .SDcols = cols_lagueables
]

# agrego los delta lags
for (vcol in cols_lagueables)
{
    dataset[, paste0(vcol, "_delta1") := get(vcol) - get(paste0(vcol, "_lag1"))]
    dataset[, paste0(vcol, "_delta2") := get(vcol) - get(paste0(vcol, "_lag2"))]
}

# %% [markdown]
# Verificacion de los campos recien creados

# %%
ncol(dataset)
colnames(dataset)
# Out:
# [1] 158
#   [1] "numero_de_cliente"                  "foto_mes"
#   [3] "internet"                           "cliente_edad"
#   [5] "cliente_antiguedad"                 "mrentabilidad"
#   [7] "mrentabilidad_annual"               "mcomisiones"
#   [9] "mactivos_margen"                    "mpasivos_margen"
#  [11] "cproductos"                         "mcuenta_corriente"
#  [13] "mcaja_ahorro"                       "cdescubierto_preacordado"
#  [15] "mcuentas_saldo"                     "ctarjeta_visa_transacciones"
#  [17] "mtarjeta_visa_consumo"              "mtarjeta_master_consumo"
#  [19] "mprestamos_personales"              "cpayroll_trx"
#  [21] "mpayroll"                           "ccomisiones_mantenimiento"
#  [23] "ccallcenter_transacciones"          "chomebanking_transacciones"
#  [25] "ctrx_quarter"                       "Master_status"
#  [27] "Master_fechaalta"                   "Master_mpagominimo"
#  [29] "Visa_status"                        "Visa_fechaalta"
#  [31] "Visa_mpagominimo"                   "clase_ternaria"
#  [33] "kmes"                               "mpayroll_sobre_edad"
#  [35] "internet_lag1"                      "cliente_edad_lag1"
#  [37] "cliente_antiguedad_lag1"            "mrentabilidad_lag1"
#  [39] "mrentabilidad_annual_lag1"          "mcomisiones_lag1"
#  [41] "mactivos_margen_lag1"               "mpasivos_margen_lag1"
#  [43] "cproductos_lag1"                    "mcuenta_corriente_lag1"
#  [45] "mcaja_ahorro_lag1"                  "cdescubierto_preacordado_lag1"
#  [47] "mcuentas_saldo_lag1"                "ctarjeta_visa_transacciones_lag1"
#  [49] "mtarjeta_visa_consumo_lag1"         "mtarjeta_master_consumo_lag1"
#  [51] "mprestamos_personales_lag1"         "cpayroll_trx_lag1"
#  [53] "mpayroll_lag1"                      "ccomisiones_mantenimiento_lag1"
#  [55] "ccallcenter_transacciones_lag1"     "chomebanking_transacciones_lag1"
#  [57] "ctrx_quarter_lag1"                  "Master_status_lag1"
#  [59] "Master_fechaalta_lag1"              "Master_mpagominimo_lag1"
#  [61] "Visa_status_lag1"                   "Visa_fechaalta_lag1"
#  [63] "Visa_mpagominimo_lag1"              "kmes_lag1"
#  [65] "mpayroll_sobre_edad_lag1"           "internet_lag2"
#  [67] "cliente_edad_lag2"                  "cliente_antiguedad_lag2"
#  [69] "mrentabilidad_lag2"                 "mrentabilidad_annual_lag2"
#  [71] "mcomisiones_lag2"                   "mactivos_margen_lag2"
#  [73] "mpasivos_margen_lag2"               "cproductos_lag2"
#  [75] "mcuenta_corriente_lag2"             "mcaja_ahorro_lag2"
#  [77] "cdescubierto_preacordado_lag2"      "mcuentas_saldo_lag2"
#  [79] "ctarjeta_visa_transacciones_lag2"   "mtarjeta_visa_consumo_lag2"
#  [81] "mtarjeta_master_consumo_lag2"       "mprestamos_personales_lag2"
#  [83] "cpayroll_trx_lag2"                  "mpayroll_lag2"
#  [85] "ccomisiones_mantenimiento_lag2"     "ccallcenter_transacciones_lag2"
#  [87] "chomebanking_transacciones_lag2"    "ctrx_quarter_lag2"
#  [89] "Master_status_lag2"                 "Master_fechaalta_lag2"
#  [91] "Master_mpagominimo_lag2"            "Visa_status_lag2"
#  [93] "Visa_fechaalta_lag2"                "Visa_mpagominimo_lag2"
#  [95] "kmes_lag2"                          "mpayroll_sobre_edad_lag2"
#  [97] "internet_delta1"                    "internet_delta2"
#  [99] "cliente_edad_delta1"                "cliente_edad_delta2"
# [101] "cliente_antiguedad_delta1"          "cliente_antiguedad_delta2"
# [103] "mrentabilidad_delta1"               "mrentabilidad_delta2"
# [105] "mrentabilidad_annual_delta1"        "mrentabilidad_annual_delta2"
# [107] "mcomisiones_delta1"                 "mcomisiones_delta2"
# [109] "mactivos_margen_delta1"             "mactivos_margen_delta2"
# [111] "mpasivos_margen_delta1"             "mpasivos_margen_delta2"
# [113] "cproductos_delta1"                  "cproductos_delta2"
# [115] "mcuenta_corriente_delta1"           "mcuenta_corriente_delta2"
# [117] "mcaja_ahorro_delta1"                "mcaja_ahorro_delta2"
# [119] "cdescubierto_preacordado_delta1"    "cdescubierto_preacordado_delta2"
# [121] "mcuentas_saldo_delta1"              "mcuentas_saldo_delta2"
# [123] "ctarjeta_visa_transacciones_delta1" "ctarjeta_visa_transacciones_delta2"
# [125] "mtarjeta_visa_consumo_delta1"       "mtarjeta_visa_consumo_delta2"
# [127] "mtarjeta_master_consumo_delta1"     "mtarjeta_master_consumo_delta2"
# [129] "mprestamos_personales_delta1"       "mprestamos_personales_delta2"
# [131] "cpayroll_trx_delta1"                "cpayroll_trx_delta2"
# [133] "mpayroll_delta1"                    "mpayroll_delta2"
# [135] "ccomisiones_mantenimiento_delta1"   "ccomisiones_mantenimiento_delta2"
# [137] "ccallcenter_transacciones_delta1"   "ccallcenter_transacciones_delta2"
# [139] "chomebanking_transacciones_delta1"  "chomebanking_transacciones_delta2"
# [141] "ctrx_quarter_delta1"                "ctrx_quarter_delta2"
# [143] "Master_status_delta1"               "Master_status_delta2"
# [145] "Master_fechaalta_delta1"            "Master_fechaalta_delta2"
# [147] "Master_mpagominimo_delta1"          "Master_mpagominimo_delta2"
# [149] "Visa_status_delta1"                 "Visa_status_delta2"
# [151] "Visa_fechaalta_delta1"              "Visa_fechaalta_delta2"
# [153] "Visa_mpagominimo_delta1"            "Visa_mpagominimo_delta2"
# [155] "kmes_delta1"                        "kmes_delta2"
# [157] "mpayroll_sobre_edad_delta1"         "mpayroll_sobre_edad_delta2"

# %% [markdown]
# #### 6.3.1.6  FEhist Reduccion dimensionalidad con canaritos
#
# Esta etapa solo se mostrará a la *modalidad Anlista Sr* por algun canal secreto de forma de no confundir a los *Analista Jr*  nni distraer con detalles operativos a la estratégica *Modalidad Gerencial*

# %%
# No se implementa la reduccion de la dimensionalidad con canaritos

# %% [markdown]
# ### 6.3.2 Modelado

# %% [markdown]
# #### 6.3.2.1 Training Strategy
#
# Esta etapa de Workflow de  Training Strategy esta pensada para la *Modalidad Gerencial* que posee el dataset de [202005, 202109]
# <br> Si usted es un Analista, posee el periodo de [201901, 202109] y deberá experimentar en que meses le conviene experimentar
#
# <br> A la *Modalidad Gerencial* no se le complicada la vida con el undersampling de los continua, por eso PARAM$trainingstrategy$training_pct <- 1.0
# <br> Sin embargo, si usted es  *Analista SR* posee un dataset 50 veces ( filas x columnas) más grande que la *Modalidad Gerencial*  y por un tema de velocidad y experimentación más rápida puede llegar a necesitar activar el undersampling de la clase mayoritaria, a pesar de estar corriendo en Google Cloud.

# %% [markdown]
# Se hace una estrategia de entrenamiento muy sencilla, tomando todos los meses posibles, SIN eliminar nada x pandemia ni por ningun otro motivo
#
# * future = 202107  obviamente completo
#
# * final_train =  [ 202005, 202105 ]  SIN undersampling
#
# * training
#    * testing = NO HAY
#    * validation =  202105   completo, sin undersampling
#    * training = [ 202005, 202104 ]  donde se consideran el 100% de los CONTINUA

# %%
PARAM$trainingstrategy$validate <- c(202105)

PARAM$trainingstrategy$training <- c(
  202104, 202103, 202102, 202101,
  202012, 202011, 202010, 202009, 202008, 202007,
  202006, 202005
)

PARAM$trainingstrategy$training_pct <- 1.0


PARAM$trainingstrategy$positivos <- c( "BAJA+1", "BAJA+2")

# %%
# seteo la clase01   1={BAJA+1, BAJA+2}   0={CONTINUA}
dataset[, clase01 := ifelse( clase_ternaria %in% PARAM$trainingstrategy$positivos, 1, 0 )]

# %%
# los campos en los que se entrena
campos_buenos <- copy( setdiff(
    colnames(dataset), c("clase_ternaria","clase01","azar"))
)

# %%
# preparo para que se puede hacer undersampling de los CONTINUA
#  solamente por un tema de VELOCIDAD
set.seed(PARAM$semilla_primigenia, kind = "L'Ecuyer-CMRG")
dataset[, azar:=runif(nrow(dataset))]

# undersampling de los CONTINUA
dataset[, fold_train :=  foto_mes %in%  PARAM$trainingstrategy$training &
    (clase_ternaria %in% c("BAJA+1", "BAJA+2") |
     azar < PARAM$trainingstrategy$training_pct ) ]


if( !require("lightgbm")) install.packages("lightgbm")
require("lightgbm")

dtrain <- lgb.Dataset(
  data= data.matrix(dataset[fold_train == TRUE, campos_buenos, with = FALSE]),
  label= dataset[fold_train == TRUE, clase01],
  free_raw_data= TRUE
)
# Out:
# Loading required package: lightgbm
#
# Warning message in library(package, lib.loc = lib.loc, character.only = TRUE, logical.return = TRUE, :
# “there is no package called ‘lightgbm’”
# Installing package into ‘/usr/local/lib/R/site-library’
# (as ‘lib’ is unspecified)
#
# Loading required package: lightgbm

# %%
# datos de validation
dvalidate <- lgb.Dataset(
  data= data.matrix(dataset[foto_mes %in% PARAM$trainingstrategy$validate, campos_buenos, with = FALSE]),
  label= dataset[foto_mes %in% PARAM$trainingstrategy$validate, clase01],
  free_raw_data= TRUE
)

nrow(dvalidate)
# Out:
# [1] 16469

# %% [markdown]
# ####  6.3.2.2. Hyperparameter Tuning

# %% [markdown]
# * Clase binaria que se optimiza :  positivos = [ BAJA+1, BAJA+2 ]

# %% [markdown]
# * Metrica que se optimiza **AUC** Area Under Curve de la  ROC Curve
#
# es muy importante notar que intencionalmente  **NO** se está optimizando la funcion de ganancia del problema

# %% [markdown]
# * Cantidad de iteraciones inteligentes de la Optimizacion Bayesiana = **10**

# %% [markdown]
# * Parametros no default, fijos de LightGBM que no se optimizan
#   * max_bin = 31 , Alienigenas Ancestrales contruyeron las pirámides y dejaron a la humanidad en un jeroglifico  *max_bin=31*
#   * feature_fraction = 0.5  para poner algo que generalmente no falla
#   * learning_rate = 0.03  para que aprenda lento

# %% [markdown]
# * Parametros que se optimizan en la Bayesian Optimization
#   * num_leaves  [8, 256]
#   * min_data_in_leaf  [8, 8192]

# %%
# paquetes necesarios para la Bayesian Optimization
if(!require("DiceKriging")) install.packages("DiceKriging")
require("DiceKriging")

if(!require("mlrMBO")) install.packages("mlrMBO")
require("mlrMBO")
# Out:
# Loading required package: DiceKriging
#
# Warning message in library(package, lib.loc = lib.loc, character.only = TRUE, logical.return = TRUE, :
# “there is no package called ‘DiceKriging’”
# Installing package into ‘/usr/local/lib/R/site-library’
# (as ‘lib’ is unspecified)
#
# Loading required package: DiceKriging
#
# Loading required package: mlrMBO
#
# Warning message in library(package, lib.loc = lib.loc, character.only = TRUE, logical.return = TRUE, :
# “there is no package called ‘mlrMBO’”
# Installing package into ‘/usr/local/lib/R/site-library’
# (as ‘lib’ is unspecified)
#
# also installing the dependencies ‘XML’, ‘fastmatch’, ‘RcppArmadillo’, ‘mlr’, ‘ParamHelpers’, ‘smoof’, ‘BBmisc’, ‘checkmate’, ‘lhs’, ‘parallelMap’
#
#
# Loading required package: mlrMBO
#
# Loading required package: mlr
#
# Loading required package: ParamHelpers
#
#
# Attaching package: ‘ParamHelpers’
#
#
# The following object is masked from ‘package:R.utils’:
#
#     isVector
#
#
#
# Attaching package: ‘mlr’
#
#
# The following objects are masked from ‘package:R.utils’:
#
#     resample, setThreshold
#
#
# Loading required package: smoof
#
# Loading required package: checkmate
#
#
# Attaching package: ‘checkmate’
#
#
# The following object is masked from ‘package:DiceKriging’:
#
#     checkNames
#
#
# The following object is masked from ‘package:R.utils’:
#
#     asInt
#
#
#
# Attaching package: ‘smoof’
#
#
# The following objects are masked from ‘package:R.oo’:
#
#     getDescription, getName

# %% [markdown]
# Definición de la Bayesian Optimization
# <br> Si se desea optimizar un hiperparámetro que esta como fijo, debe QUITARSE de param_fijos y agregarse a PARAM$hipeparametertuning$hs

# %%
# valor ridiculamente bajo para que corra rapido en el aula y no molestar a la *Modalidad Gerencial*
PARAM$hipeparametertuning$num_interations <- 100

# parametros fijos del LightGBM
PARAM$lgbm$param_fijos <- list(
  objective= "binary",
  metric= "auc",
  first_metric_only= TRUE,
  boost_from_average= TRUE,
  feature_pre_filter= FALSE,
  verbosity= -100,
  force_row_wise= TRUE, # para evitar warning
  max_bin= 31,
  top_k= 20,
  min_data_in_bin= 3,
  seed= PARAM$semilla_primigenia
  # learning_rate= 0.03,
  # feature_fraction= 0.5,
  # num_iterations= 2048,  # valor grande, lo limita early_stopping_rounds
  # early_stopping_rounds= 200
)

PARAM$hipeparametertuning$hs <- makeParamSet(
  # Núcleo del modelo (estructura de árboles)
  makeIntegerParam("num_leaves", lower = 2L, upper = 63L),
  makeIntegerParam("max_depth", lower = 3L, upper = 30L),
  makeNumericParam("min_child_weight", lower = 0.001, upper = 10.0),
  makeIntegerParam("min_data_in_leaf", lower = 2L, upper = 8192L),
  makeNumericParam("min_gain_to_split", lower = 0.0, upper = 0.1),

  # Regularización
  makeNumericParam("lambda_l1", lower = 0.0, upper = 0.5),
  makeNumericParam("lambda_l2", lower = 0.0, upper = 0.5),
  makeNumericParam("scale_pos_weight", lower = 1.0, upper = 5.0),  # útil en desequilibrio

  # Control del aprendizaje
  makeNumericParam("learning_rate", lower = 0.005, upper = 0.1),
  makeIntegerParam("num_iterations", lower = 100L, upper = 5000L),
  makeIntegerParam("early_stopping_rounds", lower = 50L, upper = 500L),

  # Submuestreo
  makeNumericParam("feature_fraction", lower = 0.3, upper = 0.8),   # columnas
  makeNumericParam("bagging_fraction", lower = 0.5, upper = 0.9),   # filas
  makeIntegerParam("bagging_freq", lower = 1L, upper = 5L),         # cada N iteraciones

  # Opcionales útiles
  makeNumericParam("max_delta_step", lower = 0.0, upper = 10.0),
  makeNumericParam("path_smooth", lower = 0.0, upper = 10.0)
)
# Total: 16 hT

# %% [markdown]
# Función "señora caja negra"  que es llamada para verificar la realidad por la Bayesian Optimization

# %%
# En  x llegan los parmaetros de la bayesiana
#  devuelve la AUC en validate del modelo entrenado
#  en el parametro x llegan los hiperparámetros que se estan optimizando

EstimarGanancia_AUC_lightgbm <- function(x) {

  # x pisa (o agrega) a param_fijos
  param_completo <- modifyList(PARAM$lgbm$param_fijos, x)

  # entreno LightGBM
  modelo_train <- lgb.train(
    data= dtrain,
    valids= list(valid = dvalidate),
    eval= "auc",
    param= param_completo,
    verbose= -100
  )

  # recupero la AUC en validation
  AUC <- modelo_train$record_evals$valid$auc$eval[[modelo_train$best_iter]]

  # esta es la forma de devolver un parametro extra
  attr(AUC, "extras") <- list("num_iterations"= modelo_train$best_iter)

  # hago espacio en la memoria
  rm(modelo_train)
  gc(full= TRUE, verbose= FALSE)

  message(format(Sys.time(), "%a %b %d %X %Y"), " AUC ", AUC)

  return(AUC)
}

# %% [markdown]
# seteo de la Bayesian Optimization (complejo)
# <br> copiado y pegado de la documentación de la librería

# %%
configureMlr(show.learner.output = FALSE)

# configuro la busqueda bayesiana,  los hiperparametros que se van a optimizar
# por favor, no desesperarse por lo complejo
obj.fun <- makeSingleObjectiveFunction(
    fn= EstimarGanancia_AUC_lightgbm, # la funcion que voy a maximizar
    minimize= FALSE, # estoy Maximizando AUC
    noisy= FALSE,
    par.set= PARAM$hipeparametertuning$hs,
    has.simple.signature= FALSE # paso los parametros en una lista
)

# cada 600 segundos guardo el resultado intermedio
ctrl <- makeMBOControl(
    save.on.disk.at.time= 600,
    save.file.path= "HT.RDATA"
)

# indico la cantidad de iteraciones que va a tener la Bayesian Optimization
ctrl <- setMBOControlTermination(
    ctrl,
    iters= PARAM$hipeparametertuning$num_interations  # cantidad de iteraciones inteligentes
)

# defino el método estandar para la creacion de los puntos iniciales
#   los "No Inteligentes"
ctrl <- setMBOControlInfill(ctrl, crit = makeMBOInfillCritEI())

# mas configuraciones
surr.km <- makeLearner(
    "regr.km",
    predict.type= "se",
    covtype= "matern3_2",
    control= list(trace = TRUE)
)

# %% [markdown]
# Corrida de la Bayesian Optimization,  aqui se hace el trabajo pesado
# <br> por favor no se asuste con los warnings que pudieran aparecer
#
# Si corrío a medias y llegó a las iteraciones inteligentes, en el archivo binario HT.RDATA quedó lo ya procesado y es utilizado para retomar la corrida desde lo último que llegó a grabar.

# %%
# inicio la optimizacion bayesiana

if (!file.exists("HT.RDATA")) {
  bayesiana_salida <- mbo(obj.fun, learner= surr.km, control= ctrl)
} else {
  bayesiana_salida <- mboContinue("HT.RDATA") # retomo en caso que ya exista
}
# Out:
# Computing y column(s) for design. Not provided.
#
# Mon Nov 17 09:46:22 PM 2025 AUC 0.9231040237718
#
# Mon Nov 17 09:47:35 PM 2025 AUC 0.928731573398722
#
# Mon Nov 17 09:49:05 PM 2025 AUC 0.925140705517294
#
# Mon Nov 17 09:50:56 PM 2025 AUC 0.924992064658438
#
# Mon Nov 17 09:52:19 PM 2025 AUC 0.924133101681756
#
# Mon Nov 17 09:54:51 PM 2025 AUC 0.921303221312482
#
# Mon Nov 17 09:55:34 PM 2025 AUC 0.923890511747325
#
# Mon Nov 17 09:57:29 PM 2025 AUC 0.918288462583774
#
# Mon Nov 17 09:59:45 PM 2025 AUC 0.92466122969945
#
# Mon Nov 17 10:02:13 PM 2025 AUC 0.925601391520022
#
# Mon Nov 17 10:03:37 PM 2025 AUC 0.920290920023165
#
# Mon Nov 17 10:05:12 PM 2025 AUC 0.922232646095846
#
# Mon Nov 17 10:07:18 PM 2025 AUC 0.925235661190107
#
# Mon Nov 17 10:08:56 PM 2025 AUC 0.925175600888221
#
# Mon Nov 17 10:10:18 PM 2025 AUC 0.924093844389462
#
# Mon Nov 17 10:11:07 PM 2025 AUC 0.917541567432956
#
# Mon Nov 17 10:11:30 PM 2025 AUC 0.91979668077916
#
# Mon Nov 17 10:13:11 PM 2025 AUC 0.919302441535155
#
# Mon Nov 17 10:15:23 PM 2025 AUC 0.921664925253444
#
# Mon Nov 17 10:16:28 PM 2025 AUC 0.909888408630162
#
# Mon Nov 17 10:18:56 PM 2025 AUC 0.931782569628009
#
# Mon Nov 17 10:20:52 PM 2025 AUC 0.922811103975455
#
# Mon Nov 17 10:23:37 PM 2025 AUC 0.937644320879041
#
# Mon Nov 17 10:25:09 PM 2025 AUC 0.911998236441638
#
# Mon Nov 17 10:25:40 PM 2025 AUC 0.917652964193994
#
# Mon Nov 17 10:26:41 PM 2025 AUC 0.923935808623049
#
# Mon Nov 17 10:27:37 PM 2025 AUC 0.918142505984221
#
# Mon Nov 17 10:29:19 PM 2025 AUC 0.924397836755428
#
# Mon Nov 17 10:30:07 PM 2025 AUC 0.922240363341339
#
# Mon Nov 17 10:30:52 PM 2025 AUC 0.917629812457513
#
# Mon Nov 17 10:32:02 PM 2025 AUC 0.924432732126356
#
# Mon Nov 17 10:32:51 PM 2025 AUC 0.920736171534906
#
# Mon Nov 17 10:33:37 PM 2025 AUC 0.920977754872098
#
# Mon Nov 17 10:34:16 PM 2025 AUC 0.919941630781475
#
# Mon Nov 17 10:39:46 PM 2025 AUC 0.91583572064645
#
# Mon Nov 17 10:41:02 PM 2025 AUC 0.929849902930473
#
# Mon Nov 17 10:43:11 PM 2025 AUC 0.925960746734095
#
# Mon Nov 17 10:44:04 PM 2025 AUC 0.925254451005222
#
# Mon Nov 17 10:45:25 PM 2025 AUC 0.923313060464954
#
# Mon Nov 17 10:47:58 PM 2025 AUC 0.931377917538212
#
# Mon Nov 17 10:48:14 PM 2025 AUC 0.91164794060271
#
# Mon Nov 17 10:49:09 PM 2025 AUC 0.919107497203337
#
# Mon Nov 17 10:50:53 PM 2025 AUC 0.918383082724174
#
# Mon Nov 17 10:57:25 PM 2025 AUC 0.924826647178944
#
# Mon Nov 17 10:58:03 PM 2025 AUC 0.918632047774447
#
# Mon Nov 17 10:58:16 PM 2025 AUC 0.915523004437752
#
# Mon Nov 17 11:00:02 PM 2025 AUC 0.925556430176712
#
# Mon Nov 17 11:00:30 PM 2025 AUC 0.916380960817196
#
# Mon Nov 17 11:02:41 PM 2025 AUC 0.92511352739186
#
# Mon Nov 17 11:03:59 PM 2025 AUC 0.922243047600641
#
# Mon Nov 17 11:05:57 PM 2025 AUC 0.914750608823563
#
# Mon Nov 17 11:07:26 PM 2025 AUC 0.922245060795118
#
# Mon Nov 17 11:09:11 PM 2025 AUC 0.915198209062194
#
# Mon Nov 17 11:09:32 PM 2025 AUC 0.916322242644962
#
# Mon Nov 17 11:10:42 PM 2025 AUC 0.924602511527216
#
# Mon Nov 17 11:11:28 PM 2025 AUC 0.916944319738231
#
# Mon Nov 17 11:11:36 PM 2025 AUC 0.911249999161169
#
# Mon Nov 17 11:12:52 PM 2025 AUC 0.914031562863004
#
# Mon Nov 17 11:13:17 PM 2025 AUC 0.914705647480252
#
# Mon Nov 17 11:13:59 PM 2025 AUC 0.923237230139669
#
# Mon Nov 17 11:14:15 PM 2025 AUC 0.913996331959664
#
# Mon Nov 17 11:14:51 PM 2025 AUC 0.916319893918072
#
# Mon Nov 17 11:15:37 PM 2025 AUC 0.913767498854157
#
# Mon Nov 17 11:19:32 PM 2025 AUC 0.926384524171419
#
# [mbo] 0: num_leaves=17; max_depth=22; min_child_weight=4.8; min_data_in_leaf=2637; min_gain_to_split=0.0258; lambda_l1=0.171; lambda_l2=0.384; scale_pos_weight=4.62; learning_rate=0.077; num_iterations=4484; early_stopping_rounds=362; feature_fraction=0.614; bagging_fraction=0.564; bagging_freq=3; max_delta_step=2.05; path_smooth=2.07 : y = 0.923 : 43.3 secs : initdesign
#
# [mbo] 0: num_leaves=26; max_depth=24; min_child_weight=3.88; min_data_in_leaf=1147; min_gain_to_split=0.0405; lambda_l1=0.156; lambda_l2=0.403; scale_pos_weight=3.81; learning_rate=0.0831; num_iterations=2025; early_stopping_rounds=262; feature_fraction=0.418; bagging_fraction=0.777; bagging_freq=5; max_delta_step=5.33; path_smooth=5.36 : y = 0.929 : 73.2 secs : initdesign
#
# [mbo] 0: num_leaves=42; max_depth=27; min_child_weight=7.47; min_data_in_leaf=3112; min_gain_to_split=0.0927; lambda_l1=0.229; lambda_l2=0.13; scale_pos_weight=2.64; learning_rate=0.0524; num_iterations=2291; early_stopping_rounds=337; feature_fraction=0.454; bagging_fraction=0.642; bagging_freq=4; max_delta_step=3.47; path_smooth=6.57 : y = 0.925 : 89.8 secs : initdesign
#
# [mbo] 0: num_leaves=17; max_depth=20; min_child_weight=3.18; min_data_in_leaf=3411; min_gain_to_split=0.0387; lambda_l1=0.175; lambda_l2=0.305; scale_pos_weight=4.1; learning_rate=0.0602; num_iterations=2156; early_stopping_rounds=390; feature_fraction=0.585; bagging_fraction=0.758; bagging_freq=2; max_delta_step=9.34; path_smooth=3.65 : y = 0.925 : 110.8 secs : initdesign
#
# [mbo] 0: num_leaves=25; max_depth=15; min_child_weight=4.38; min_data_in_leaf=4269; min_gain_to_split=0.0363; lambda_l1=0.35; lambda_l2=0.0992; scale_pos_weight=3.89; learning_rate=0.0564; num_iterations=3130; early_stopping_rounds=437; feature_fraction=0.743; bagging_fraction=0.579; bagging_freq=2; max_delta_step=1.95; path_smooth=7.17 : y = 0.924 : 83.2 secs : initdesign
#
# [mbo] 0: num_leaves=10; max_depth=16; min_child_weight=2.82; min_data_in_leaf=3010; min_gain_to_split=0.0678; lambda_l1=0.248; lambda_l2=0.422; scale_pos_weight=3.2; learning_rate=0.0186; num_iterations=3533; early_stopping_rounds=202; feature_fraction=0.371; bagging_fraction=0.558; bagging_freq=3; max_delta_step=6.13; path_smooth=6.85 : y = 0.921 : 152.5 secs : initdesign
#
# [mbo] 0: num_leaves=40; max_depth=19; min_child_weight=6.23; min_data_in_leaf=3640; min_gain_to_split=0.0432; lambda_l1=0.424; lambda_l2=0.264; scale_pos_weight=4.32; learning_rate=0.0921; num_iterations=884; early_stopping_rounds=181; feature_fraction=0.703; bagging_fraction=0.836; bagging_freq=2; max_delta_step=8.69; path_smooth=2.98 : y = 0.924 : 43.1 secs : initdesign
#
# [mbo] 0: num_leaves=4; max_depth=16; min_child_weight=5.44; min_data_in_leaf=7244; min_gain_to_split=0.0724; lambda_l1=0.288; lambda_l2=0.231; scale_pos_weight=4.63; learning_rate=0.0393; num_iterations=4038; early_stopping_rounds=145; feature_fraction=0.497; bagging_fraction=0.774; bagging_freq=1; max_delta_step=5.18; path_smooth=2.68 : y = 0.918 : 115.0 secs : initdesign
#
# [mbo] 0: num_leaves=42; max_depth=9; min_child_weight=4.17; min_data_in_leaf=4372; min_gain_to_split=0.0456; lambda_l1=0.0667; lambda_l2=0.238; scale_pos_weight=2.97; learning_rate=0.0377; num_iterations=2975; early_stopping_rounds=280; feature_fraction=0.461; bagging_fraction=0.881; bagging_freq=1; max_delta_step=3.31; path_smooth=8.49 : y = 0.925 : 136.1 secs : initdesign
#
# [mbo] 0: num_leaves=16; max_depth=26; min_child_weight=6.7; min_data_in_leaf=572; min_gain_to_split=0.0407; lambda_l1=0.3; lambda_l2=0.29; scale_pos_weight=3.12; learning_rate=0.0647; num_iterations=3322; early_stopping_rounds=359; feature_fraction=0.54; bagging_fraction=0.727; bagging_freq=5; max_delta_step=2.86; path_smooth=2.41 : y = 0.926 : 147.5 secs : initdesign
#
# [mbo] 0: num_leaves=31; max_depth=19; min_child_weight=1.8; min_data_in_leaf=5988; min_gain_to_split=0.0578; lambda_l1=0.412; lambda_l2=0.0209; scale_pos_weight=3.32; learning_rate=0.0641; num_iterations=3449; early_stopping_rounds=160; feature_fraction=0.589; bagging_fraction=0.767; bagging_freq=1; max_delta_step=4.84; path_smooth=6.88 : y = 0.92 : 84.2 secs : initdesign
#
# [mbo] 0: num_leaves=49; max_depth=14; min_child_weight=2.23; min_data_in_leaf=4750; min_gain_to_split=0.0233; lambda_l1=0.484; lambda_l2=0.191; scale_pos_weight=2.1; learning_rate=0.0152; num_iterations=1658; early_stopping_rounds=168; feature_fraction=0.756; bagging_fraction=0.611; bagging_freq=2; max_delta_step=5.15; path_smooth=7.5 : y = 0.922 : 95.0 secs : initdesign
#
# [mbo] 0: num_leaves=55; max_depth=16; min_child_weight=6.45; min_data_in_leaf=3266; min_gain_to_split=0.0491; lambda_l1=0.393; lambda_l2=0.456; scale_pos_weight=2.29; learning_rate=0.0286; num_iterations=4351; early_stopping_rounds=377; feature_fraction=0.643; bagging_fraction=0.676; bagging_freq=2; max_delta_step=3.72; path_smooth=4.35 : y = 0.925 : 125.5 secs : initdesign
#
# [mbo] 0: num_leaves=45; max_depth=14; min_child_weight=0.822; min_data_in_leaf=7710; min_gain_to_split=0.0319; lambda_l1=0.112; lambda_l2=0.304; scale_pos_weight=4.9; learning_rate=0.0622; num_iterations=1615; early_stopping_rounds=270; feature_fraction=0.362; bagging_fraction=0.711; bagging_freq=4; max_delta_step=7.57; path_smooth=6.31 : y = 0.925 : 98.0 secs : initdesign
#
# [mbo] 0: num_leaves=28; max_depth=11; min_child_weight=8.73; min_data_in_leaf=4621; min_gain_to_split=0.0711; lambda_l1=0.0065; lambda_l2=0.32; scale_pos_weight=3.61; learning_rate=0.046; num_iterations=2549; early_stopping_rounds=233; feature_fraction=0.566; bagging_fraction=0.653; bagging_freq=3; max_delta_step=7.95; path_smooth=1.13 : y = 0.924 : 82.5 secs : initdesign
#
# [mbo] 0: num_leaves=6; max_depth=28; min_child_weight=8.28; min_data_in_leaf=5203; min_gain_to_split=0.0116; lambda_l1=0.459; lambda_l2=0.147; scale_pos_weight=2.49; learning_rate=0.082; num_iterations=3768; early_stopping_rounds=129; feature_fraction=0.39; bagging_fraction=0.754; bagging_freq=2; max_delta_step=6.56; path_smooth=2.52 : y = 0.918 : 48.5 secs : initdesign
#
# [mbo] 0: num_leaves=58; max_depth=19; min_child_weight=6.8; min_data_in_leaf=4565; min_gain_to_split=0.02; lambda_l1=0.121; lambda_l2=0.341; scale_pos_weight=3.65; learning_rate=0.0321; num_iterations=412; early_stopping_rounds=92; feature_fraction=0.77; bagging_fraction=0.66; bagging_freq=2; max_delta_step=8.31; path_smooth=6.55 : y = 0.92 : 23.9 secs : initdesign
#
# [mbo] 0: num_leaves=9; max_depth=6; min_child_weight=3.38; min_data_in_leaf=5008; min_gain_to_split=0.0873; lambda_l1=0.432; lambda_l2=0.244; scale_pos_weight=1.98; learning_rate=0.0366; num_iterations=2809; early_stopping_rounds=344; feature_fraction=0.338; bagging_fraction=0.629; bagging_freq=2; max_delta_step=4.43; path_smooth=3.92 : y = 0.919 : 100.4 secs : initdesign
#
# [mbo] 0: num_leaves=51; max_depth=7; min_child_weight=5.12; min_data_in_leaf=7820; min_gain_to_split=0.00791; lambda_l1=0.195; lambda_l2=0.182; scale_pos_weight=1.63; learning_rate=0.0493; num_iterations=3268; early_stopping_rounds=347; feature_fraction=0.522; bagging_fraction=0.605; bagging_freq=3; max_delta_step=2.38; path_smooth=8.02 : y = 0.922 : 132.3 secs : initdesign
#
# [mbo] 0: num_leaves=2; max_depth=28; min_child_weight=5.65; min_data_in_leaf=443; min_gain_to_split=0.0941; lambda_l1=0.128; lambda_l2=0.219; scale_pos_weight=2.86; learning_rate=0.0232; num_iterations=2555; early_stopping_rounds=304; feature_fraction=0.765; bagging_fraction=0.805; bagging_freq=2; max_delta_step=9.22; path_smooth=3.19 : y = 0.91 : 64.8 secs : initdesign
#
# [mbo] 0: num_leaves=44; max_depth=20; min_child_weight=4.63; min_data_in_leaf=1285; min_gain_to_split=0.0207; lambda_l1=0.342; lambda_l2=0.211; scale_pos_weight=1.82; learning_rate=0.0217; num_iterations=2184; early_stopping_rounds=87; feature_fraction=0.351; bagging_fraction=0.808; bagging_freq=5; max_delta_step=4.12; path_smooth=1.33 : y = 0.932 : 148.0 secs : initdesign
#
# [mbo] 0: num_leaves=14; max_depth=23; min_child_weight=4.85; min_data_in_leaf=7411; min_gain_to_split=0.0302; lambda_l1=0.327; lambda_l2=0.466; scale_pos_weight=1.29; learning_rate=0.0704; num_iterations=1189; early_stopping_rounds=429; feature_fraction=0.556; bagging_fraction=0.715; bagging_freq=2; max_delta_step=6.57; path_smooth=5.47 : y = 0.923 : 115.6 secs : initdesign
#
# [mbo] 0: num_leaves=55; max_depth=10; min_child_weight=4.37; min_data_in_leaf=929; min_gain_to_split=0.0692; lambda_l1=0.219; lambda_l2=0.16; scale_pos_weight=4.13; learning_rate=0.0583; num_iterations=3987; early_stopping_rounds=498; feature_fraction=0.476; bagging_fraction=0.796; bagging_freq=5; max_delta_step=3.05; path_smooth=8.38 : y = 0.938 : 165.8 secs : initdesign
#
# [mbo] 0: num_leaves=3; max_depth=12; min_child_weight=7.51; min_data_in_leaf=213; min_gain_to_split=0.0602; lambda_l1=0.138; lambda_l2=0.444; scale_pos_weight=1.36; learning_rate=0.0254; num_iterations=1253; early_stopping_rounds=171; feature_fraction=0.53; bagging_fraction=0.685; bagging_freq=4; max_delta_step=7.24; path_smooth=1.8 : y = 0.912 : 91.1 secs : initdesign
#
# [mbo] 0: num_leaves=13; max_depth=11; min_child_weight=1.45; min_data_in_leaf=1772; min_gain_to_split=0.0509; lambda_l1=0.194; lambda_l2=0.256; scale_pos_weight=3.38; learning_rate=0.0867; num_iterations=3560; early_stopping_rounds=153; feature_fraction=0.604; bagging_fraction=0.749; bagging_freq=3; max_delta_step=4.37; path_smooth=8.6 : y = 0.918 : 31.6 secs : initdesign
#
# [mbo] 0: num_leaves=29; max_depth=15; min_child_weight=6.09; min_data_in_leaf=5871; min_gain_to_split=0.0806; lambda_l1=0.389; lambda_l2=0.0247; scale_pos_weight=2.73; learning_rate=0.0733; num_iterations=1880; early_stopping_rounds=381; feature_fraction=0.752; bagging_fraction=0.537; bagging_freq=5; max_delta_step=7.17; path_smooth=7.29 : y = 0.924 : 60.5 secs : initdesign
#
# [mbo] 0: num_leaves=51; max_depth=7; min_child_weight=3.46; min_data_in_leaf=2236; min_gain_to_split=0.0826; lambda_l1=0.162; lambda_l2=0.413; scale_pos_weight=2.13; learning_rate=0.0965; num_iterations=1152; early_stopping_rounds=431; feature_fraction=0.718; bagging_fraction=0.634; bagging_freq=1; max_delta_step=1.28; path_smooth=7.87 : y = 0.918 : 55.9 secs : initdesign
#
# [mbo] 0: num_leaves=46; max_depth=8; min_child_weight=7.69; min_data_in_leaf=1443; min_gain_to_split=0.0765; lambda_l1=0.468; lambda_l2=0.391; scale_pos_weight=4.3; learning_rate=0.0268; num_iterations=1483; early_stopping_rounds=448; feature_fraction=0.682; bagging_fraction=0.818; bagging_freq=4; max_delta_step=9.5; path_smooth=3.33 : y = 0.924 : 102.2 secs : initdesign
#
# [mbo] 0: num_leaves=38; max_depth=26; min_child_weight=3.66; min_data_in_leaf=4040; min_gain_to_split=0.0661; lambda_l1=0.448; lambda_l2=0.273; scale_pos_weight=3.03; learning_rate=0.0798; num_iterations=637; early_stopping_rounds=293; feature_fraction=0.32; bagging_fraction=0.663; bagging_freq=3; max_delta_step=1.1; path_smooth=4.77 : y = 0.922 : 47.8 secs : initdesign
#
# [mbo] 0: num_leaves=32; max_depth=20; min_child_weight=1.19; min_data_in_leaf=6466; min_gain_to_split=0.00498; lambda_l1=0.317; lambda_l2=0.0715; scale_pos_weight=1.42; learning_rate=0.0548; num_iterations=4727; early_stopping_rounds=288; feature_fraction=0.669; bagging_fraction=0.646; bagging_freq=4; max_delta_step=8.77; path_smooth=2.28 : y = 0.918 : 45.0 secs : initdesign
#
# [mbo] 0: num_leaves=20; max_depth=29; min_child_weight=8.59; min_data_in_leaf=2037; min_gain_to_split=0.0075; lambda_l1=0.254; lambda_l2=0.334; scale_pos_weight=3.97; learning_rate=0.0686; num_iterations=4963; early_stopping_rounds=297; feature_fraction=0.347; bagging_fraction=0.53; bagging_freq=1; max_delta_step=7.42; path_smooth=5.23 : y = 0.924 : 70.3 secs : initdesign
#
# [mbo] 0: num_leaves=25; max_depth=22; min_child_weight=8.88; min_data_in_leaf=5342; min_gain_to_split=0.0358; lambda_l1=0.0556; lambda_l2=0.275; scale_pos_weight=4.5; learning_rate=0.0429; num_iterations=1465; early_stopping_rounds=135; feature_fraction=0.511; bagging_fraction=0.732; bagging_freq=5; max_delta_step=1.64; path_smooth=3.51 : y = 0.921 : 49.2 secs : initdesign
#
# [mbo] 0: num_leaves=48; max_depth=9; min_child_weight=7.89; min_data_in_leaf=7482; min_gain_to_split=0.079; lambda_l1=0.142; lambda_l2=0.0914; scale_pos_weight=1.24; learning_rate=0.0503; num_iterations=3916; early_stopping_rounds=227; feature_fraction=0.726; bagging_fraction=0.617; bagging_freq=4; max_delta_step=3.26; path_smooth=1.52 : y = 0.921 : 45.9 secs : initdesign
#
# [mbo] 0: num_leaves=49; max_depth=24; min_child_weight=9.86; min_data_in_leaf=6977; min_gain_to_split=0.0242; lambda_l1=0.0928; lambda_l2=0.472; scale_pos_weight=1.49; learning_rate=0.0907; num_iterations=3775; early_stopping_rounds=109; feature_fraction=0.442; bagging_fraction=0.701; bagging_freq=4; max_delta_step=4.85; path_smooth=5.84 : y = 0.92 : 38.8 secs : initdesign
#
# [mbo] 0: num_leaves=35; max_depth=3; min_child_weight=0.701; min_data_in_leaf=2163; min_gain_to_split=0.0633; lambda_l1=0.184; lambda_l2=0.14; scale_pos_weight=1.13; learning_rate=0.00645; num_iterations=4283; early_stopping_rounds=492; feature_fraction=0.504; bagging_fraction=0.849; bagging_freq=3; max_delta_step=7.72; path_smooth=2.01 : y = 0.916 : 330.4 secs : initdesign
#
# [mbo] 0: num_leaves=57; max_depth=23; min_child_weight=7.27; min_data_in_leaf=704; min_gain_to_split=0.00943; lambda_l1=0.289; lambda_l2=0.352; scale_pos_weight=4.05; learning_rate=0.0778; num_iterations=766; early_stopping_rounds=482; feature_fraction=0.437; bagging_fraction=0.57; bagging_freq=3; max_delta_step=8.12; path_smooth=8.89 : y = 0.93 : 76.2 secs : initdesign
#
# [mbo] 0: num_leaves=34; max_depth=21; min_child_weight=5.58; min_data_in_leaf=2442; min_gain_to_split=0.0526; lambda_l1=0.352; lambda_l2=0.169; scale_pos_weight=2.54; learning_rate=0.0133; num_iterations=2748; early_stopping_rounds=101; feature_fraction=0.786; bagging_fraction=0.898; bagging_freq=5; max_delta_step=6.03; path_smooth=7.63 : y = 0.926 : 128.9 secs : initdesign
#
# [mbo] 0: num_leaves=30; max_depth=8; min_child_weight=9.19; min_data_in_leaf=1555; min_gain_to_split=0.0293; lambda_l1=0.331; lambda_l2=0.206; scale_pos_weight=1.6; learning_rate=0.0345; num_iterations=1049; early_stopping_rounds=67; feature_fraction=0.366; bagging_fraction=0.867; bagging_freq=1; max_delta_step=1.42; path_smooth=9.54 : y = 0.925 : 52.9 secs : initdesign
#
# [mbo] 0: num_leaves=47; max_depth=12; min_child_weight=5.26; min_data_in_leaf=6188; min_gain_to_split=0.0911; lambda_l1=0.498; lambda_l2=0.499; scale_pos_weight=2.61; learning_rate=0.0863; num_iterations=1852; early_stopping_rounds=328; feature_fraction=0.575; bagging_fraction=0.721; bagging_freq=1; max_delta_step=8.53; path_smooth=0.738 : y = 0.923 : 81.1 secs : initdesign
#
# [mbo] 0: num_leaves=60; max_depth=27; min_child_weight=2.18; min_data_in_leaf=1908; min_gain_to_split=0.00299; lambda_l1=0.28; lambda_l2=0.0473; scale_pos_weight=2.88; learning_rate=0.0719; num_iterations=4783; early_stopping_rounds=456; feature_fraction=0.649; bagging_fraction=0.784; bagging_freq=4; max_delta_step=5.85; path_smooth=9.51 : y = 0.931 : 153.0 secs : initdesign
#
# [mbo] 0: num_leaves=41; max_depth=4; min_child_weight=9.06; min_data_in_leaf=2325; min_gain_to_split=0.000908; lambda_l1=0.0773; lambda_l2=0.108; scale_pos_weight=4.85; learning_rate=0.0948; num_iterations=221; early_stopping_rounds=77; feature_fraction=0.417; bagging_fraction=0.7; bagging_freq=5; max_delta_step=9.04; path_smooth=9.28 : y = 0.912 : 15.8 secs : initdesign
#
# [mbo] 0: num_leaves=5; max_depth=18; min_child_weight=1.35; min_data_in_leaf=3903; min_gain_to_split=0.0901; lambda_l1=0.366; lambda_l2=0.351; scale_pos_weight=4.41; learning_rate=0.0598; num_iterations=4135; early_stopping_rounds=403; feature_fraction=0.689; bagging_fraction=0.67; bagging_freq=4; max_delta_step=9.64; path_smooth=3.88 : y = 0.919 : 54.5 secs : initdesign
#
# [mbo] 0: num_leaves=33; max_depth=25; min_child_weight=9.45; min_data_in_leaf=7085; min_gain_to_split=0.0542; lambda_l1=0.378; lambda_l2=0.435; scale_pos_weight=3.47; learning_rate=0.0106; num_iterations=2345; early_stopping_rounds=318; feature_fraction=0.698; bagging_fraction=0.586; bagging_freq=4; max_delta_step=4.68; path_smooth=9 : y = 0.918 : 104.1 secs : initdesign
#
# [mbo] 0: num_leaves=63; max_depth=30; min_child_weight=8; min_data_in_leaf=4151; min_gain_to_split=0.0973; lambda_l1=0.263; lambda_l2=0.203; scale_pos_weight=2.34; learning_rate=0.00826; num_iterations=4218; early_stopping_rounds=245; feature_fraction=0.481; bagging_fraction=0.859; bagging_freq=1; max_delta_step=0.881; path_smooth=9.17 : y = 0.925 : 392.1 secs : initdesign
#
# [mbo] 0: num_leaves=23; max_depth=7; min_child_weight=4.04; min_data_in_leaf=1184; min_gain_to_split=0.0339; lambda_l1=0.42; lambda_l2=0.0556; scale_pos_weight=1.74; learning_rate=0.0664; num_iterations=4449; early_stopping_rounds=209; feature_fraction=0.71; bagging_fraction=0.54; bagging_freq=1; max_delta_step=9.91; path_smooth=7.67 : y = 0.919 : 37.9 secs : initdesign
#
# [mbo] 0: num_leaves=24; max_depth=25; min_child_weight=2.73; min_data_in_leaf=6857; min_gain_to_split=0.0847; lambda_l1=0.0181; lambda_l2=0.317; scale_pos_weight=3.74; learning_rate=0.0886; num_iterations=163; early_stopping_rounds=220; feature_fraction=0.394; bagging_fraction=0.688; bagging_freq=1; max_delta_step=6.38; path_smooth=0.869 : y = 0.916 : 13.0 secs : initdesign
#
# [mbo] 0: num_leaves=13; max_depth=13; min_child_weight=6.33; min_data_in_leaf=6598; min_gain_to_split=0.0477; lambda_l1=0.0333; lambda_l2=0.0328; scale_pos_weight=2.79; learning_rate=0.0755; num_iterations=4874; early_stopping_rounds=215; feature_fraction=0.305; bagging_fraction=0.888; bagging_freq=4; max_delta_step=5.53; path_smooth=4.46 : y = 0.926 : 106.1 secs : initdesign
#
# [mbo] 0: num_leaves=62; max_depth=18; min_child_weight=2.43; min_data_in_leaf=7985; min_gain_to_split=0.0445; lambda_l1=0.215; lambda_l2=0.0819; scale_pos_weight=4.47; learning_rate=0.0411; num_iterations=520; early_stopping_rounds=412; feature_fraction=0.611; bagging_fraction=0.593; bagging_freq=2; max_delta_step=0.497; path_smooth=9.71 : y = 0.916 : 28.3 secs : initdesign
#
# [mbo] 0: num_leaves=11; max_depth=17; min_child_weight=1.61; min_data_in_leaf=3539; min_gain_to_split=0.0271; lambda_l1=0.401; lambda_l2=0.364; scale_pos_weight=3.83; learning_rate=0.0979; num_iterations=3665; early_stopping_rounds=459; feature_fraction=0.494; bagging_fraction=0.841; bagging_freq=2; max_delta_step=1.8; path_smooth=0.215 : y = 0.925 : 131.0 secs : initdesign
#
# [mbo] 0: num_leaves=20; max_depth=25; min_child_weight=1.9; min_data_in_leaf=8167; min_gain_to_split=0.088; lambda_l1=0.473; lambda_l2=0.12; scale_pos_weight=3.52; learning_rate=0.0355; num_iterations=4552; early_stopping_rounds=258; feature_fraction=0.385; bagging_fraction=0.502; bagging_freq=3; max_delta_step=2.61; path_smooth=0.415 : y = 0.922 : 78.3 secs : initdesign
#
# [mbo] 0: num_leaves=56; max_depth=4; min_child_weight=8.26; min_data_in_leaf=5512; min_gain_to_split=0.0127; lambda_l1=0.0499; lambda_l2=0.488; scale_pos_weight=4.75; learning_rate=0.00766; num_iterations=2667; early_stopping_rounds=190; feature_fraction=0.799; bagging_fraction=0.869; bagging_freq=5; max_delta_step=1.02; path_smooth=6.15 : y = 0.915 : 117.8 secs : initdesign
#
# [mbo] 0: num_leaves=21; max_depth=10; min_child_weight=0.236; min_data_in_leaf=2870; min_gain_to_split=0.0622; lambda_l1=0.0114; lambda_l2=0.37; scale_pos_weight=1.53; learning_rate=0.0111; num_iterations=3198; early_stopping_rounds=115; feature_fraction=0.635; bagging_fraction=0.598; bagging_freq=2; max_delta_step=3.89; path_smooth=2.82 : y = 0.922 : 88.6 secs : initdesign
#
# [mbo] 0: num_leaves=61; max_depth=22; min_child_weight=6.94; min_data_in_leaf=6744; min_gain_to_split=0.0653; lambda_l1=0.0995; lambda_l2=0.478; scale_pos_weight=3.16; learning_rate=0.0174; num_iterations=1356; early_stopping_rounds=466; feature_fraction=0.466; bagging_fraction=0.555; bagging_freq=2; max_delta_step=0.329; path_smooth=0.1 : y = 0.915 : 105.2 secs : initdesign
#
# [mbo] 0: num_leaves=52; max_depth=10; min_child_weight=0.447; min_data_in_leaf=5471; min_gain_to_split=0.057; lambda_l1=0.108; lambda_l2=0.451; scale_pos_weight=1.78; learning_rate=0.0316; num_iterations=289; early_stopping_rounds=476; feature_fraction=0.661; bagging_fraction=0.879; bagging_freq=4; max_delta_step=8.2; path_smooth=5.71 : y = 0.916 : 21.0 secs : initdesign
#
# [mbo] 0: num_leaves=10; max_depth=13; min_child_weight=9.33; min_data_in_leaf=285; min_gain_to_split=0.0832; lambda_l1=0.0271; lambda_l2=0.0454; scale_pos_weight=4.78; learning_rate=0.0295; num_iterations=1989; early_stopping_rounds=399; feature_fraction=0.732; bagging_fraction=0.622; bagging_freq=3; max_delta_step=2.32; path_smooth=5.08 : y = 0.925 : 70.0 secs : initdesign
#
# [mbo] 0: num_leaves=27; max_depth=6; min_child_weight=0.145; min_data_in_leaf=5683; min_gain_to_split=0.0776; lambda_l1=0.268; lambda_l2=0.15; scale_pos_weight=5; learning_rate=0.0206; num_iterations=593; early_stopping_rounds=51; feature_fraction=0.406; bagging_fraction=0.856; bagging_freq=3; max_delta_step=6.73; path_smooth=4.86 : y = 0.917 : 45.7 secs : initdesign
#
# [mbo] 0: num_leaves=39; max_depth=6; min_child_weight=3.12; min_data_in_leaf=7655; min_gain_to_split=0.00449; lambda_l1=0.208; lambda_l2=0.287; scale_pos_weight=4.22; learning_rate=0.0937; num_iterations=2878; early_stopping_rounds=64; feature_fraction=0.624; bagging_fraction=0.511; bagging_freq=4; max_delta_step=5.65; path_smooth=4.59 : y = 0.911 : 8.1 secs : initdesign
#
# [mbo] 0: num_leaves=37; max_depth=28; min_child_weight=9.79; min_data_in_leaf=6127; min_gain_to_split=0.0155; lambda_l1=0.237; lambda_l2=0.117; scale_pos_weight=1.06; learning_rate=0.0437; num_iterations=972; early_stopping_rounds=418; feature_fraction=0.427; bagging_fraction=0.831; bagging_freq=5; max_delta_step=0.152; path_smooth=6.03 : y = 0.914 : 76.4 secs : initdesign
#
# [mbo] 0: num_leaves=53; max_depth=4; min_child_weight=2.56; min_data_in_leaf=2756; min_gain_to_split=0.099; lambda_l1=0.0842; lambda_l2=0.000994; scale_pos_weight=1.9; learning_rate=0.0536; num_iterations=364; early_stopping_rounds=316; feature_fraction=0.313; bagging_fraction=0.518; bagging_freq=3; max_delta_step=6.93; path_smooth=9.88 : y = 0.915 : 24.6 secs : initdesign
#
# [mbo] 0: num_leaves=8; max_depth=17; min_child_weight=7.1; min_data_in_leaf=88; min_gain_to_split=0.0737; lambda_l1=0.31; lambda_l2=0.42; scale_pos_weight=2.2; learning_rate=0.0696; num_iterations=4624; early_stopping_rounds=196; feature_fraction=0.33; bagging_fraction=0.545; bagging_freq=5; max_delta_step=4.02; path_smooth=8.23 : y = 0.923 : 42.4 secs : initdesign
#
# [mbo] 0: num_leaves=19; max_depth=30; min_child_weight=1.07; min_data_in_leaf=4978; min_gain_to_split=0.0179; lambda_l1=0.0408; lambda_l2=0.381; scale_pos_weight=1.11; learning_rate=0.0993; num_iterations=1721; early_stopping_rounds=78; feature_fraction=0.782; bagging_fraction=0.819; bagging_freq=5; max_delta_step=0.763; path_smooth=1.06 : y = 0.914 : 15.3 secs : initdesign
#
# [mbo] 0: num_leaves=6; max_depth=5; min_child_weight=9.63; min_data_in_leaf=6293; min_gain_to_split=0.0965; lambda_l1=0.489; lambda_l2=0.0642; scale_pos_weight=2.03; learning_rate=0.0839; num_iterations=830; early_stopping_rounds=123; feature_fraction=0.549; bagging_fraction=0.519; bagging_freq=1; max_delta_step=2.7; path_smooth=1.67 : y = 0.916 : 36.1 secs : initdesign
#
# [mbo] 0: num_leaves=59; max_depth=3; min_child_weight=0.578; min_data_in_leaf=824; min_gain_to_split=0.0557; lambda_l1=0.439; lambda_l2=0.0125; scale_pos_weight=2.42; learning_rate=0.0469; num_iterations=3052; early_stopping_rounds=370; feature_fraction=0.656; bagging_fraction=0.74; bagging_freq=5; max_delta_step=0.236; path_smooth=0.533 : y = 0.914 : 46.3 secs : initdesign
#
# [mbo] 0: num_leaves=35; max_depth=30; min_child_weight=5.9; min_data_in_leaf=3813; min_gain_to_split=0.016; lambda_l1=0.375; lambda_l2=0.178; scale_pos_weight=3.3; learning_rate=0.0161; num_iterations=2405; early_stopping_rounds=248; feature_fraction=0.565; bagging_fraction=0.791; bagging_freq=1; max_delta_step=9.71; path_smooth=4.08 : y = 0.926 : 234.7 secs : initdesign
#
# Saved the current state after iteration 1 in the file HT.RDATA.
#
# Mon Nov 17 11:21:30 PM 2025 AUC 0.926827762488684
#
# [mbo] 1: num_leaves=52; max_depth=17; min_child_weight=4.82; min_data_in_leaf=526; min_gain_to_split=0.0447; lambda_l1=0.276; lambda_l2=0.296; scale_pos_weight=4.14; learning_rate=0.053; num_iterations=3876; early_stopping_rounds=496; feature_fraction=0.423; bagging_fraction=0.769; bagging_freq=4; max_delta_step=2.32; path_smooth=9.12 : y = 0.927 : 115.3 secs : infill_ei
#
# Mon Nov 17 11:23:03 PM 2025 AUC 0.92946269852614
#
# [mbo] 2: num_leaves=53; max_depth=11; min_child_weight=3.23; min_data_in_leaf=1206; min_gain_to_split=0.0917; lambda_l1=0.22; lambda_l2=0.292; scale_pos_weight=3.7; learning_rate=0.0635; num_iterations=3376; early_stopping_rounds=466; feature_fraction=0.405; bagging_fraction=0.755; bagging_freq=5; max_delta_step=8.49; path_smooth=8.51 : y = 0.929 : 92.4 secs : infill_ei
#
# Mon Nov 17 11:24:18 PM 2025 AUC 0.929372104774693
#
# [mbo] 3: num_leaves=61; max_depth=11; min_child_weight=6.5; min_data_in_leaf=1203; min_gain_to_split=0.088; lambda_l1=0.217; lambda_l2=0.0425; scale_pos_weight=3.22; learning_rate=0.0605; num_iterations=4203; early_stopping_rounds=464; feature_fraction=0.48; bagging_fraction=0.698; bagging_freq=5; max_delta_step=2.15; path_smooth=6.51 : y = 0.929 : 73.8 secs : infill_ei
#
# Mon Nov 17 11:25:50 PM 2025 AUC 0.925724531915508
#
# [mbo] 4: num_leaves=52; max_depth=10; min_child_weight=7.1; min_data_in_leaf=1391; min_gain_to_split=0.0736; lambda_l1=0.0868; lambda_l2=0.199; scale_pos_weight=4.28; learning_rate=0.0788; num_iterations=3935; early_stopping_rounds=487; feature_fraction=0.561; bagging_fraction=0.873; bagging_freq=5; max_delta_step=4.1; path_smooth=7.96 : y = 0.926 : 90.9 secs : infill_ei
#
# Mon Nov 17 11:28:11 PM 2025 AUC 0.928485628140164
#
# [mbo] 5: num_leaves=49; max_depth=11; min_child_weight=1.88; min_data_in_leaf=955; min_gain_to_split=0.0897; lambda_l1=0.209; lambda_l2=0.153; scale_pos_weight=4.65; learning_rate=0.058; num_iterations=3921; early_stopping_rounds=449; feature_fraction=0.331; bagging_fraction=0.812; bagging_freq=2; max_delta_step=3.1; path_smooth=7.27 : y = 0.928 : 140.1 secs : infill_ei
#
# Mon Nov 17 11:30:43 PM 2025 AUC 0.923127175508281
#
# [mbo] 6: num_leaves=53; max_depth=13; min_child_weight=4.71; min_data_in_leaf=1773; min_gain_to_split=0.0467; lambda_l1=0.235; lambda_l2=0.162; scale_pos_weight=4.22; learning_rate=0.0636; num_iterations=3580; early_stopping_rounds=500; feature_fraction=0.612; bagging_fraction=0.779; bagging_freq=2; max_delta_step=2.29; path_smooth=9.52 : y = 0.923 : 149.7 secs : infill_ei
#
# Saved the current state after iteration 7 in the file HT.RDATA.
#
# Mon Nov 17 11:31:53 PM 2025 AUC 0.924254564415177
#
# [mbo] 7: num_leaves=58; max_depth=12; min_child_weight=3.39; min_data_in_leaf=886; min_gain_to_split=0.0726; lambda_l1=0.222; lambda_l2=0.161; scale_pos_weight=4.27; learning_rate=0.0604; num_iterations=4554; early_stopping_rounds=452; feature_fraction=0.377; bagging_fraction=0.725; bagging_freq=5; max_delta_step=5.02; path_smooth=5.62 : y = 0.924 : 68.1 secs : infill_ei
#
# Mon Nov 17 11:33:35 PM 2025 AUC 0.926403649518947
#
# [mbo] 8: num_leaves=55; max_depth=15; min_child_weight=4.16; min_data_in_leaf=731; min_gain_to_split=0.0718; lambda_l1=0.224; lambda_l2=0.118; scale_pos_weight=2.25; learning_rate=0.0655; num_iterations=1171; early_stopping_rounds=333; feature_fraction=0.42; bagging_fraction=0.805; bagging_freq=5; max_delta_step=3.16; path_smooth=6.21 : y = 0.926 : 101.2 secs : infill_ei
#
# Mon Nov 17 11:37:20 PM 2025 AUC 0.932146286763448
#
# [mbo] 9: num_leaves=61; max_depth=10; min_child_weight=3.91; min_data_in_leaf=1097; min_gain_to_split=0.0548; lambda_l1=0.458; lambda_l2=0.0985; scale_pos_weight=3.03; learning_rate=0.0237; num_iterations=4044; early_stopping_rounds=456; feature_fraction=0.581; bagging_fraction=0.79; bagging_freq=5; max_delta_step=1.3; path_smooth=7.72 : y = 0.932 : 222.8 secs : infill_ei
#
# Mon Nov 17 11:39:12 PM 2025 AUC 0.927528354166541
#
# [mbo] 10: num_leaves=55; max_depth=25; min_child_weight=5.2; min_data_in_leaf=1337; min_gain_to_split=0.0424; lambda_l1=0.324; lambda_l2=0.283; scale_pos_weight=3.28; learning_rate=0.0727; num_iterations=3013; early_stopping_rounds=423; feature_fraction=0.438; bagging_fraction=0.739; bagging_freq=4; max_delta_step=3.9; path_smooth=8.63 : y = 0.928 : 110.5 secs : infill_ei
#
# Mon Nov 17 11:42:36 PM 2025 AUC 0.926151664676959
#
# [mbo] 11: num_leaves=52; max_depth=23; min_child_weight=4.47; min_data_in_leaf=2596; min_gain_to_split=0.075; lambda_l1=0.213; lambda_l2=0.398; scale_pos_weight=3.95; learning_rate=0.0464; num_iterations=4151; early_stopping_rounds=493; feature_fraction=0.473; bagging_fraction=0.811; bagging_freq=2; max_delta_step=4.2; path_smooth=7.85 : y = 0.926 : 203.1 secs : infill_ei
#
# Saved the current state after iteration 12 in the file HT.RDATA.
#
# Mon Nov 17 11:43:39 PM 2025 AUC 0.921707873402279
#
# [mbo] 12: num_leaves=51; max_depth=9; min_child_weight=4.43; min_data_in_leaf=4603; min_gain_to_split=0.0722; lambda_l1=0.38; lambda_l2=0.151; scale_pos_weight=3.31; learning_rate=0.056; num_iterations=716; early_stopping_rounds=488; feature_fraction=0.499; bagging_fraction=0.806; bagging_freq=5; max_delta_step=5.36; path_smooth=8.76 : y = 0.922 : 61.7 secs : infill_ei
#
# Mon Nov 17 11:46:14 PM 2025 AUC 0.93142254334911
#
# [mbo] 13: num_leaves=59; max_depth=12; min_child_weight=5.21; min_data_in_leaf=760; min_gain_to_split=0.0241; lambda_l1=0.256; lambda_l2=0.274; scale_pos_weight=3.69; learning_rate=0.0221; num_iterations=4606; early_stopping_rounds=333; feature_fraction=0.374; bagging_fraction=0.755; bagging_freq=4; max_delta_step=4.74; path_smooth=8.33 : y = 0.931 : 153.7 secs : infill_ei
#
# Mon Nov 17 11:49:10 PM 2025 AUC 0.930665246693496
#
# [mbo] 14: num_leaves=54; max_depth=10; min_child_weight=7.12; min_data_in_leaf=405; min_gain_to_split=0.0414; lambda_l1=0.266; lambda_l2=0.0372; scale_pos_weight=3.33; learning_rate=0.0286; num_iterations=4075; early_stopping_rounds=397; feature_fraction=0.453; bagging_fraction=0.775; bagging_freq=4; max_delta_step=1.1; path_smooth=8.43 : y = 0.931 : 174.2 secs : infill_ei
#
# Mon Nov 17 11:51:16 PM 2025 AUC 0.92988714702829
#
# [mbo] 15: num_leaves=50; max_depth=17; min_child_weight=4.87; min_data_in_leaf=1248; min_gain_to_split=0.057; lambda_l1=0.211; lambda_l2=0.0991; scale_pos_weight=3.54; learning_rate=0.0251; num_iterations=4591; early_stopping_rounds=294; feature_fraction=0.411; bagging_fraction=0.802; bagging_freq=5; max_delta_step=3.68; path_smooth=7.52 : y = 0.93 : 125.3 secs : infill_ei
#
# Mon Nov 17 11:53:49 PM 2025 AUC 0.933040480643471
#
# [mbo] 16: num_leaves=57; max_depth=9; min_child_weight=4.16; min_data_in_leaf=438; min_gain_to_split=0.0847; lambda_l1=0.222; lambda_l2=0.293; scale_pos_weight=3.53; learning_rate=0.036; num_iterations=4002; early_stopping_rounds=399; feature_fraction=0.427; bagging_fraction=0.59; bagging_freq=5; max_delta_step=2.83; path_smooth=8.22 : y = 0.933 : 152.2 secs : infill_ei
#
# Saved the current state after iteration 17 in the file HT.RDATA.
#
# Mon Nov 17 11:56:36 PM 2025 AUC 0.929604964269153
#
# [mbo] 17: num_leaves=59; max_depth=16; min_child_weight=9.58; min_data_in_leaf=819; min_gain_to_split=0.0562; lambda_l1=0.227; lambda_l2=0.00935; scale_pos_weight=2.77; learning_rate=0.028; num_iterations=4012; early_stopping_rounds=489; feature_fraction=0.472; bagging_fraction=0.757; bagging_freq=5; max_delta_step=6.29; path_smooth=8.18 : y = 0.93 : 165.0 secs : infill_ei
#
# Mon Nov 17 11:59:50 PM 2025 AUC 0.930489763241619
#
# [mbo] 18: num_leaves=57; max_depth=7; min_child_weight=4.75; min_data_in_leaf=1287; min_gain_to_split=0.0696; lambda_l1=0.241; lambda_l2=0.1; scale_pos_weight=4.93; learning_rate=0.0307; num_iterations=4513; early_stopping_rounds=483; feature_fraction=0.391; bagging_fraction=0.606; bagging_freq=5; max_delta_step=1.69; path_smooth=8.19 : y = 0.93 : 192.7 secs : infill_ei
#
# Tue Nov 18 12:01:15 AM 2025 AUC 0.926140256574925
#
# [mbo] 19: num_leaves=56; max_depth=12; min_child_weight=3.53; min_data_in_leaf=2622; min_gain_to_split=0.0854; lambda_l1=0.356; lambda_l2=0.3; scale_pos_weight=2.7; learning_rate=0.0664; num_iterations=4141; early_stopping_rounds=352; feature_fraction=0.472; bagging_fraction=0.848; bagging_freq=5; max_delta_step=5.57; path_smooth=8.33 : y = 0.926 : 83.6 secs : infill_ei
#
# Tue Nov 18 12:02:36 AM 2025 AUC 0.928984564837948
#
# [mbo] 20: num_leaves=38; max_depth=10; min_child_weight=2.59; min_data_in_leaf=1069; min_gain_to_split=0.0591; lambda_l1=0.25; lambda_l2=0.15; scale_pos_weight=4.04; learning_rate=0.0454; num_iterations=3378; early_stopping_rounds=486; feature_fraction=0.653; bagging_fraction=0.831; bagging_freq=5; max_delta_step=3.49; path_smooth=7.74 : y = 0.929 : 79.9 secs : infill_ei
#
# Tue Nov 18 12:04:08 AM 2025 AUC 0.925937594997614
#
# [mbo] 21: num_leaves=56; max_depth=20; min_child_weight=6.83; min_data_in_leaf=1594; min_gain_to_split=0.0368; lambda_l1=0.329; lambda_l2=0.422; scale_pos_weight=3.48; learning_rate=0.0584; num_iterations=2173; early_stopping_rounds=384; feature_fraction=0.478; bagging_fraction=0.754; bagging_freq=5; max_delta_step=5.69; path_smooth=4.42 : y = 0.926 : 90.1 secs : infill_ei
#
# Saved the current state after iteration 22 in the file HT.RDATA.
#
# Tue Nov 18 12:05:42 AM 2025 AUC 0.931077616028786
#
# [mbo] 22: num_leaves=50; max_depth=10; min_child_weight=4.15; min_data_in_leaf=822; min_gain_to_split=0.0824; lambda_l1=0.226; lambda_l2=0.0448; scale_pos_weight=2.68; learning_rate=0.0619; num_iterations=4584; early_stopping_rounds=481; feature_fraction=0.476; bagging_fraction=0.823; bagging_freq=5; max_delta_step=3.84; path_smooth=8.42 : y = 0.931 : 93.0 secs : infill_ei
#
# Tue Nov 18 12:06:56 AM 2025 AUC 0.925442013623958
#
# [mbo] 23: num_leaves=59; max_depth=19; min_child_weight=0.603; min_data_in_leaf=725; min_gain_to_split=0.0953; lambda_l1=0.239; lambda_l2=0.147; scale_pos_weight=3.36; learning_rate=0.0652; num_iterations=4043; early_stopping_rounds=453; feature_fraction=0.505; bagging_fraction=0.68; bagging_freq=5; max_delta_step=5.93; path_smooth=8.14 : y = 0.925 : 72.3 secs : infill_ei
#
# Tue Nov 18 12:08:46 AM 2025 AUC 0.928958728842165
#
# [mbo] 24: num_leaves=56; max_depth=26; min_child_weight=5.28; min_data_in_leaf=1246; min_gain_to_split=0.00566; lambda_l1=0.299; lambda_l2=0.111; scale_pos_weight=2.4; learning_rate=0.0263; num_iterations=4514; early_stopping_rounds=478; feature_fraction=0.595; bagging_fraction=0.738; bagging_freq=5; max_delta_step=4.13; path_smooth=7.76 : y = 0.929 : 109.2 secs : infill_ei
#
# Tue Nov 18 12:09:57 AM 2025 AUC 0.929117771205816
#
# [mbo] 25: num_leaves=47; max_depth=21; min_child_weight=2.76; min_data_in_leaf=633; min_gain_to_split=0.0098; lambda_l1=0.305; lambda_l2=0.28; scale_pos_weight=3.19; learning_rate=0.0495; num_iterations=3678; early_stopping_rounds=386; feature_fraction=0.42; bagging_fraction=0.781; bagging_freq=3; max_delta_step=6.89; path_smooth=8.57 : y = 0.929 : 69.6 secs : infill_ei
#
# Tue Nov 18 12:12:28 AM 2025 AUC 0.931750358516383
#
# [mbo] 26: num_leaves=58; max_depth=12; min_child_weight=8.25; min_data_in_leaf=1518; min_gain_to_split=0.0753; lambda_l1=0.218; lambda_l2=0.105; scale_pos_weight=4.11; learning_rate=0.0399; num_iterations=2967; early_stopping_rounds=200; feature_fraction=0.509; bagging_fraction=0.778; bagging_freq=5; max_delta_step=2.93; path_smooth=8.4 : y = 0.932 : 149.0 secs : infill_ei
#
# Tue Nov 18 12:16:08 AM 2025 AUC 0.932545234802227
#
# [mbo] 27: num_leaves=46; max_depth=10; min_child_weight=4.71; min_data_in_leaf=969; min_gain_to_split=0.0709; lambda_l1=0.356; lambda_l2=0.354; scale_pos_weight=4.33; learning_rate=0.0355; num_iterations=3772; early_stopping_rounds=459; feature_fraction=0.474; bagging_fraction=0.725; bagging_freq=5; max_delta_step=4.51; path_smooth=8.31 : y = 0.933 : 219.0 secs : infill_ei
#
# Saved the current state after iteration 28 in the file HT.RDATA.
#
# Tue Nov 18 12:17:30 AM 2025 AUC 0.929990491011422
#
# [mbo] 28: num_leaves=49; max_depth=15; min_child_weight=8.53; min_data_in_leaf=168; min_gain_to_split=0.0637; lambda_l1=0.257; lambda_l2=0.0347; scale_pos_weight=4.46; learning_rate=0.0696; num_iterations=3699; early_stopping_rounds=419; feature_fraction=0.489; bagging_fraction=0.842; bagging_freq=5; max_delta_step=7.51; path_smooth=8.31 : y = 0.93 : 80.0 secs : infill_ei
#
# Tue Nov 18 12:19:16 AM 2025 AUC 0.926983785060621
#
# [mbo] 29: num_leaves=52; max_depth=10; min_child_weight=5.72; min_data_in_leaf=889; min_gain_to_split=0.0648; lambda_l1=0.255; lambda_l2=0.3; scale_pos_weight=4.54; learning_rate=0.0593; num_iterations=4078; early_stopping_rounds=457; feature_fraction=0.469; bagging_fraction=0.782; bagging_freq=5; max_delta_step=1.17; path_smooth=8.12 : y = 0.927 : 104.2 secs : infill_ei
#
# Tue Nov 18 12:22:06 AM 2025 AUC 0.9305917650951
#
# [mbo] 30: num_leaves=42; max_depth=9; min_child_weight=2.53; min_data_in_leaf=1040; min_gain_to_split=0.0369; lambda_l1=0.186; lambda_l2=0.0519; scale_pos_weight=4.3; learning_rate=0.0331; num_iterations=4012; early_stopping_rounds=455; feature_fraction=0.441; bagging_fraction=0.786; bagging_freq=5; max_delta_step=3.08; path_smooth=8.9 : y = 0.931 : 168.2 secs : infill_ei
#
# Tue Nov 18 12:25:04 AM 2025 AUC 0.928778212404096
#
# [mbo] 31: num_leaves=23; max_depth=10; min_child_weight=6.75; min_data_in_leaf=407; min_gain_to_split=0.0767; lambda_l1=0.276; lambda_l2=0.167; scale_pos_weight=3.02; learning_rate=0.0322; num_iterations=3187; early_stopping_rounds=370; feature_fraction=0.463; bagging_fraction=0.699; bagging_freq=5; max_delta_step=5.82; path_smooth=8.17 : y = 0.929 : 176.2 secs : infill_ei
#
# Tue Nov 18 12:26:20 AM 2025 AUC 0.927015996172246
#
# [mbo] 32: num_leaves=45; max_depth=22; min_child_weight=6.37; min_data_in_leaf=1305; min_gain_to_split=0.0412; lambda_l1=0.458; lambda_l2=0.0866; scale_pos_weight=3.91; learning_rate=0.0563; num_iterations=2264; early_stopping_rounds=356; feature_fraction=0.428; bagging_fraction=0.802; bagging_freq=4; max_delta_step=7.78; path_smooth=7.59 : y = 0.927 : 74.8 secs : infill_ei
#
# Saved the current state after iteration 33 in the file HT.RDATA.
#
# Tue Nov 18 12:27:24 AM 2025 AUC 0.927788391786435
#
# [mbo] 33: num_leaves=58; max_depth=6; min_child_weight=6.37; min_data_in_leaf=924; min_gain_to_split=0.00499; lambda_l1=0.228; lambda_l2=0.093; scale_pos_weight=3.41; learning_rate=0.0356; num_iterations=3616; early_stopping_rounds=419; feature_fraction=0.656; bagging_fraction=0.65; bagging_freq=5; max_delta_step=3.14; path_smooth=8.32 : y = 0.928 : 62.3 secs : infill_ei
#
# Tue Nov 18 12:32:58 AM 2025 AUC 0.932508326236823
#
# [mbo] 34: num_leaves=57; max_depth=10; min_child_weight=4.76; min_data_in_leaf=876; min_gain_to_split=0.0685; lambda_l1=0.242; lambda_l2=0.0971; scale_pos_weight=3.96; learning_rate=0.00788; num_iterations=3562; early_stopping_rounds=441; feature_fraction=0.446; bagging_fraction=0.802; bagging_freq=5; max_delta_step=4.63; path_smooth=8.44 : y = 0.933 : 331.9 secs : infill_ei
#
# Tue Nov 18 12:34:51 AM 2025 AUC 0.926668720125033
#
# [mbo] 35: num_leaves=48; max_depth=9; min_child_weight=4.55; min_data_in_leaf=686; min_gain_to_split=0.0407; lambda_l1=0.355; lambda_l2=0.153; scale_pos_weight=4.05; learning_rate=0.0549; num_iterations=3985; early_stopping_rounds=353; feature_fraction=0.462; bagging_fraction=0.765; bagging_freq=3; max_delta_step=2.91; path_smooth=8.09 : y = 0.927 : 111.5 secs : infill_ei
#
# Tue Nov 18 12:36:37 AM 2025 AUC 0.928100772462721
#
# [mbo] 36: num_leaves=49; max_depth=12; min_child_weight=4.38; min_data_in_leaf=1487; min_gain_to_split=0.0745; lambda_l1=0.228; lambda_l2=0.0698; scale_pos_weight=3.87; learning_rate=0.0468; num_iterations=3805; early_stopping_rounds=437; feature_fraction=0.463; bagging_fraction=0.637; bagging_freq=5; max_delta_step=2.19; path_smooth=8.58 : y = 0.928 : 103.4 secs : infill_ei
#
# Saved the current state after iteration 37 in the file HT.RDATA.
#
# Tue Nov 18 12:39:35 AM 2025 AUC 0.930305891479423
#
# [mbo] 37: num_leaves=61; max_depth=17; min_child_weight=7.27; min_data_in_leaf=1591; min_gain_to_split=0.0397; lambda_l1=0.43; lambda_l2=0.208; scale_pos_weight=4.33; learning_rate=0.0213; num_iterations=3678; early_stopping_rounds=222; feature_fraction=0.497; bagging_fraction=0.735; bagging_freq=4; max_delta_step=6.38; path_smooth=9 : y = 0.93 : 176.9 secs : infill_ei
#
# Tue Nov 18 12:44:06 AM 2025 AUC 0.930258581409223
#
# [mbo] 38: num_leaves=63; max_depth=9; min_child_weight=3.79; min_data_in_leaf=2618; min_gain_to_split=0.0714; lambda_l1=0.206; lambda_l2=0.164; scale_pos_weight=4.78; learning_rate=0.0344; num_iterations=3970; early_stopping_rounds=441; feature_fraction=0.447; bagging_fraction=0.78; bagging_freq=5; max_delta_step=2.71; path_smooth=8.67 : y = 0.93 : 269.0 secs : infill_ei
#
# Tue Nov 18 12:48:23 AM 2025 AUC 0.930427018680432
#
# [mbo] 39: num_leaves=63; max_depth=14; min_child_weight=8.02; min_data_in_leaf=514; min_gain_to_split=0.0606; lambda_l1=0.29; lambda_l2=0.113; scale_pos_weight=2.82; learning_rate=0.0113; num_iterations=4014; early_stopping_rounds=340; feature_fraction=0.34; bagging_fraction=0.596; bagging_freq=5; max_delta_step=5.17; path_smooth=7.93 : y = 0.93 : 255.8 secs : infill_ei
#
# Saved the current state after iteration 40 in the file HT.RDATA.
#
# Tue Nov 18 12:50:14 AM 2025 AUC 0.928348730915755
#
# [mbo] 40: num_leaves=55; max_depth=12; min_child_weight=4.53; min_data_in_leaf=1297; min_gain_to_split=0.0558; lambda_l1=0.156; lambda_l2=0.325; scale_pos_weight=1.12; learning_rate=0.0297; num_iterations=3196; early_stopping_rounds=346; feature_fraction=0.393; bagging_fraction=0.822; bagging_freq=5; max_delta_step=3.62; path_smooth=8.03 : y = 0.928 : 109.3 secs : infill_ei
#
# Tue Nov 18 12:52:07 AM 2025 AUC 0.924131088487279
#
# [mbo] 41: num_leaves=53; max_depth=25; min_child_weight=4.56; min_data_in_leaf=324; min_gain_to_split=0.0743; lambda_l1=0.422; lambda_l2=0.167; scale_pos_weight=2.93; learning_rate=0.0674; num_iterations=3883; early_stopping_rounds=441; feature_fraction=0.343; bagging_fraction=0.817; bagging_freq=5; max_delta_step=3.02; path_smooth=8.47 : y = 0.924 : 110.6 secs : infill_ei
#
# Tue Nov 18 12:54:47 AM 2025 AUC 0.932681796494223
#
# [mbo] 42: num_leaves=60; max_depth=17; min_child_weight=5.69; min_data_in_leaf=729; min_gain_to_split=0.0373; lambda_l1=0.321; lambda_l2=0.125; scale_pos_weight=3.45; learning_rate=0.0236; num_iterations=3017; early_stopping_rounds=195; feature_fraction=0.444; bagging_fraction=0.76; bagging_freq=4; max_delta_step=4.35; path_smooth=3.4 : y = 0.933 : 158.4 secs : infill_ei
#
# Tue Nov 18 12:55:59 AM 2025 AUC 0.927227717124702
#
# [mbo] 43: num_leaves=49; max_depth=16; min_child_weight=9.55; min_data_in_leaf=1118; min_gain_to_split=0.0346; lambda_l1=0.407; lambda_l2=0.404; scale_pos_weight=3.89; learning_rate=0.0158; num_iterations=3770; early_stopping_rounds=112; feature_fraction=0.607; bagging_fraction=0.798; bagging_freq=5; max_delta_step=4.28; path_smooth=5.05 : y = 0.927 : 70.6 secs : infill_ei
#
# Tue Nov 18 12:59:19 AM 2025 AUC 0.933872936559545
#
# [mbo] 44: num_leaves=55; max_depth=19; min_child_weight=5.16; min_data_in_leaf=250; min_gain_to_split=0.0516; lambda_l1=0.284; lambda_l2=0.248; scale_pos_weight=2.76; learning_rate=0.0149; num_iterations=3128; early_stopping_rounds=202; feature_fraction=0.429; bagging_fraction=0.745; bagging_freq=5; max_delta_step=2.91; path_smooth=6.72 : y = 0.934 : 198.5 secs : infill_ei
#
# Saved the current state after iteration 45 in the file HT.RDATA.
#
# Tue Nov 18 01:00:57 AM 2025 AUC 0.92910736970102
#
# [mbo] 45: num_leaves=53; max_depth=17; min_child_weight=7.15; min_data_in_leaf=1445; min_gain_to_split=0.034; lambda_l1=0.277; lambda_l2=0.0827; scale_pos_weight=3.25; learning_rate=0.0176; num_iterations=2469; early_stopping_rounds=164; feature_fraction=0.357; bagging_fraction=0.805; bagging_freq=3; max_delta_step=4.02; path_smooth=6.42 : y = 0.929 : 95.6 secs : infill_ei
#
# Tue Nov 18 01:02:34 AM 2025 AUC 0.929010736366144
#
# [mbo] 46: num_leaves=45; max_depth=21; min_child_weight=4.28; min_data_in_leaf=440; min_gain_to_split=0.0521; lambda_l1=0.306; lambda_l2=0.266; scale_pos_weight=2.9; learning_rate=0.0209; num_iterations=2786; early_stopping_rounds=193; feature_fraction=0.427; bagging_fraction=0.813; bagging_freq=4; max_delta_step=4.12; path_smooth=3.71 : y = 0.929 : 95.0 secs : infill_ei
#
# Tue Nov 18 01:03:26 AM 2025 AUC 0.92808366030967
#
# ...
#
# Tue Nov 18 02:05:22 AM 2025 AUC 0.930005925502409
#
# [mbo] 66: num_leaves=60; max_depth=19; min_child_weight=7.89; min_data_in_leaf=521; min_gain_to_split=0.0327; lambda_l1=0.282; lambda_l2=0.276; scale_pos_weight=1.85; learning_rate=0.00862; num_iterations=3292; early_stopping_rounds=289; feature_fraction=0.438; bagging_fraction=0.577; bagging_freq=4; max_delta_step=2.91; path_smooth=2.78 : y = 0.93 : 238.3 secs : infill_ei
#
# Tue Nov 18 02:07:50 AM 2025 AUC 0.931020575518616
#
# [mbo] 67: num_leaves=58; max_depth=10; min_child_weight=5.25; min_data_in_leaf=940; min_gain_to_split=0.0455; lambda_l1=0.348; lambda_l2=0.084; scale_pos_weight=3.83; learning_rate=0.0274; num_iterations=2331; early_stopping_rounds=266; feature_fraction=0.342; bagging_fraction=0.852; bagging_freq=5; max_delta_step=3.04; path_smooth=8.95 : y = 0.931 : 145.9 secs : infill_ei
#
# Saved the current state after iteration 68 in the file HT.RDATA.
#
# Tue Nov 18 02:10:34 AM 2025 AUC 0.926001010623627
#
# [mbo] 68: num_leaves=55; max_depth=26; min_child_weight=2.81; min_data_in_leaf=937; min_gain_to_split=0.0294; lambda_l1=0.275; lambda_l2=0.147; scale_pos_weight=2.42; learning_rate=0.0065; num_iterations=3168; early_stopping_rounds=109; feature_fraction=0.43; bagging_fraction=0.789; bagging_freq=2; max_delta_step=2.91; path_smooth=1.3 : y = 0.926 : 161.9 secs : infill_ei
#
# Tue Nov 18 02:12:21 AM 2025 AUC 0.933189121502326
#
# [mbo] 69: num_leaves=60; max_depth=19; min_child_weight=4.72; min_data_in_leaf=592; min_gain_to_split=0.0475; lambda_l1=0.264; lambda_l2=0.0701; scale_pos_weight=4.53; learning_rate=0.0302; num_iterations=1638; early_stopping_rounds=232; feature_fraction=0.432; bagging_fraction=0.734; bagging_freq=5; max_delta_step=2.74; path_smooth=1.88 : y = 0.933 : 103.9 secs : infill_ei
#
# Tue Nov 18 02:14:22 AM 2025 AUC 0.929338887065829
#
# [mbo] 70: num_leaves=51; max_depth=15; min_child_weight=4.16; min_data_in_leaf=709; min_gain_to_split=0.0502; lambda_l1=0.336; lambda_l2=0.0976; scale_pos_weight=3.56; learning_rate=0.0154; num_iterations=1342; early_stopping_rounds=248; feature_fraction=0.597; bagging_fraction=0.75; bagging_freq=5; max_delta_step=2.04; path_smooth=3.7 : y = 0.929 : 118.8 secs : infill_ei
#
# Tue Nov 18 02:18:33 AM 2025 AUC 0.932361027507618
#
# [mbo] 71: num_leaves=57; max_depth=20; min_child_weight=8.3; min_data_in_leaf=707; min_gain_to_split=0.00667; lambda_l1=0.242; lambda_l2=0.253; scale_pos_weight=4.71; learning_rate=0.0107; num_iterations=2496; early_stopping_rounds=309; feature_fraction=0.455; bagging_fraction=0.774; bagging_freq=5; max_delta_step=3.07; path_smooth=7.53 : y = 0.932 : 248.4 secs : infill_ei
#
# Saved the current state after iteration 72 in the file HT.RDATA.
#
# Tue Nov 18 02:22:04 AM 2025 AUC 0.931590309555493
#
# [mbo] 72: num_leaves=55; max_depth=10; min_child_weight=4.87; min_data_in_leaf=21; min_gain_to_split=0.023; lambda_l1=0.315; lambda_l2=0.0401; scale_pos_weight=4.88; learning_rate=0.0172; num_iterations=4819; early_stopping_rounds=496; feature_fraction=0.527; bagging_fraction=0.752; bagging_freq=5; max_delta_step=2.85; path_smooth=5.95 : y = 0.932 : 208.1 secs : infill_ei
#
# Tue Nov 18 02:24:45 AM 2025 AUC 0.932713672073436
#
# [mbo] 73: num_leaves=61; max_depth=18; min_child_weight=6.57; min_data_in_leaf=336; min_gain_to_split=0.0414; lambda_l1=0.264; lambda_l2=0.308; scale_pos_weight=4.15; learning_rate=0.0144; num_iterations=2016; early_stopping_rounds=440; feature_fraction=0.675; bagging_fraction=0.802; bagging_freq=5; max_delta_step=4.36; path_smooth=8.52 : y = 0.933 : 158.3 secs : infill_ei
#
# Tue Nov 18 02:27:28 AM 2025 AUC 0.934822828820087
#
# [mbo] 74: num_leaves=63; max_depth=19; min_child_weight=7.11; min_data_in_leaf=42; min_gain_to_split=0.0303; lambda_l1=0.0464; lambda_l2=0.033; scale_pos_weight=3.58; learning_rate=0.0215; num_iterations=2610; early_stopping_rounds=311; feature_fraction=0.415; bagging_fraction=0.708; bagging_freq=5; max_delta_step=3.15; path_smooth=5.27 : y = 0.935 : 161.3 secs : infill_ei
#
# Tue Nov 18 02:32:58 AM 2025 AUC 0.932329487460818
#
# [mbo] 75: num_leaves=57; max_depth=26; min_child_weight=4.79; min_data_in_leaf=662; min_gain_to_split=0.0338; lambda_l1=0.361; lambda_l2=0.18; scale_pos_weight=3.62; learning_rate=0.00759; num_iterations=4278; early_stopping_rounds=433; feature_fraction=0.495; bagging_fraction=0.561; bagging_freq=5; max_delta_step=5.56; path_smooth=9.26 : y = 0.932 : 327.3 secs : infill_ei
#
# Saved the current state after iteration 76 in the file HT.RDATA.
#
# Tue Nov 18 02:36:32 AM 2025 AUC 0.932334184914597
#
# [mbo] 76: num_leaves=61; max_depth=21; min_child_weight=3.29; min_data_in_leaf=636; min_gain_to_split=0.0224; lambda_l1=0.111; lambda_l2=0.0983; scale_pos_weight=4.29; learning_rate=0.0162; num_iterations=2293; early_stopping_rounds=338; feature_fraction=0.421; bagging_fraction=0.672; bagging_freq=5; max_delta_step=4.82; path_smooth=4.02 : y = 0.932 : 211.5 secs : infill_ei
#
# Tue Nov 18 02:38:24 AM 2025 AUC 0.92961301704706
#
# [mbo] 77: num_leaves=57; max_depth=27; min_child_weight=7.93; min_data_in_leaf=667; min_gain_to_split=0.0297; lambda_l1=0.117; lambda_l2=0.086; scale_pos_weight=4.42; learning_rate=0.0208; num_iterations=2555; early_stopping_rounds=225; feature_fraction=0.552; bagging_fraction=0.836; bagging_freq=5; max_delta_step=2.88; path_smooth=3.76 : y = 0.93 : 109.0 secs : infill_ei
#
# Tue Nov 18 02:41:51 AM 2025 AUC 0.931995632710115
#
# [mbo] 78: num_leaves=62; max_depth=18; min_child_weight=7.67; min_data_in_leaf=859; min_gain_to_split=0.0402; lambda_l1=0.0536; lambda_l2=0.0884; scale_pos_weight=2.73; learning_rate=0.0113; num_iterations=3818; early_stopping_rounds=340; feature_fraction=0.466; bagging_fraction=0.833; bagging_freq=5; max_delta_step=2.63; path_smooth=8.97 : y = 0.932 : 204.4 secs : infill_ei
#
# Tue Nov 18 02:44:19 AM 2025 AUC 0.930940718804377
#
# [mbo] 79: num_leaves=59; max_depth=19; min_child_weight=7.97; min_data_in_leaf=364; min_gain_to_split=0.0212; lambda_l1=0.406; lambda_l2=0.132; scale_pos_weight=2.7; learning_rate=0.0113; num_iterations=1446; early_stopping_rounds=258; feature_fraction=0.517; bagging_fraction=0.665; bagging_freq=5; max_delta_step=4.87; path_smooth=8.19 : y = 0.931 : 145.3 secs : infill_ei
#
# Saved the current state after iteration 80 in the file HT.RDATA.
#
# Tue Nov 18 02:47:03 AM 2025 AUC 0.936039133816366
#
# [mbo] 80: num_leaves=58; max_depth=19; min_child_weight=7.38; min_data_in_leaf=35; min_gain_to_split=0.0566; lambda_l1=0.0808; lambda_l2=0.355; scale_pos_weight=4.37; learning_rate=0.0212; num_iterations=3177; early_stopping_rounds=401; feature_fraction=0.402; bagging_fraction=0.685; bagging_freq=5; max_delta_step=2.86; path_smooth=1.98 : y = 0.936 : 161.5 secs : infill_ei
#
# Tue Nov 18 02:49:37 AM 2025 AUC 0.931698686524817
#
# [mbo] 81: num_leaves=58; max_depth=17; min_child_weight=0.979; min_data_in_leaf=1327; min_gain_to_split=0.0501; lambda_l1=0.343; lambda_l2=0.324; scale_pos_weight=3.95; learning_rate=0.0138; num_iterations=1484; early_stopping_rounds=381; feature_fraction=0.504; bagging_fraction=0.812; bagging_freq=5; max_delta_step=2.87; path_smooth=4.74 : y = 0.932 : 152.0 secs : infill_ei
#
# Tue Nov 18 02:52:17 AM 2025 AUC 0.929196956855229
#
# [mbo] 82: num_leaves=21; max_depth=25; min_child_weight=4.98; min_data_in_leaf=1588; min_gain_to_split=0.036; lambda_l1=0.166; lambda_l2=0.295; scale_pos_weight=4.11; learning_rate=0.0713; num_iterations=2855; early_stopping_rounds=419; feature_fraction=0.485; bagging_fraction=0.881; bagging_freq=5; max_delta_step=7.05; path_smooth=9.69 : y = 0.929 : 156.2 secs : infill_ei
#
# Tue Nov 18 02:55:36 AM 2025 AUC 0.934154448253856
#
# [mbo] 83: num_leaves=55; max_depth=23; min_child_weight=0.591; min_data_in_leaf=136; min_gain_to_split=0.025; lambda_l1=0.326; lambda_l2=0.233; scale_pos_weight=4.34; learning_rate=0.0208; num_iterations=3767; early_stopping_rounds=471; feature_fraction=0.514; bagging_fraction=0.886; bagging_freq=5; max_delta_step=6.62; path_smooth=9.2 : y = 0.934 : 195.8 secs : infill_ei
#
# Saved the current state after iteration 84 in the file HT.RDATA.
#
# Tue Nov 18 02:57:27 AM 2025 AUC 0.929462362993728
#
# [mbo] 84: num_leaves=62; max_depth=12; min_child_weight=3.65; min_data_in_leaf=63; min_gain_to_split=0.0591; lambda_l1=0.147; lambda_l2=0.204; scale_pos_weight=3.37; learning_rate=0.0262; num_iterations=3635; early_stopping_rounds=458; feature_fraction=0.518; bagging_fraction=0.549; bagging_freq=5; max_delta_step=2.76; path_smooth=7.53 : y = 0.929 : 108.5 secs : infill_ei
#
# Tue Nov 18 03:00:16 AM 2025 AUC 0.931688285020021
#
# [mbo] 85: num_leaves=61; max_depth=22; min_child_weight=3.49; min_data_in_leaf=840; min_gain_to_split=0.0362; lambda_l1=0.154; lambda_l2=0.281; scale_pos_weight=3.69; learning_rate=0.0176; num_iterations=4127; early_stopping_rounds=407; feature_fraction=0.437; bagging_fraction=0.864; bagging_freq=5; max_delta_step=3.13; path_smooth=0.671 : y = 0.932 : 166.4 secs : infill_ei
#
# Tue Nov 18 03:04:05 AM 2025 AUC 0.932164069981324
#
# [mbo] 86: num_leaves=56; max_depth=20; min_child_weight=9.06; min_data_in_leaf=1055; min_gain_to_split=0.0606; lambda_l1=0.469; lambda_l2=0.252; scale_pos_weight=4.07; learning_rate=0.0149; num_iterations=3294; early_stopping_rounds=397; feature_fraction=0.435; bagging_fraction=0.769; bagging_freq=5; max_delta_step=3.16; path_smooth=6.58 : y = 0.932 : 226.3 secs : infill_ei
#
# Tue Nov 18 03:05:37 AM 2025 AUC 0.930515263704989
#
# [mbo] 87: num_leaves=60; max_depth=24; min_child_weight=1.15; min_data_in_leaf=836; min_gain_to_split=0.0417; lambda_l1=0.326; lambda_l2=0.133; scale_pos_weight=3.22; learning_rate=0.0249; num_iterations=3259; early_stopping_rounds=283; feature_fraction=0.366; bagging_fraction=0.75; bagging_freq=5; max_delta_step=5.92; path_smooth=9.4 : y = 0.931 : 89.7 secs : infill_ei
#
# Saved the current state after iteration 88 in the file HT.RDATA.
#
# Tue Nov 18 03:09:02 AM 2025 AUC 0.929971365663894
#
# [mbo] 88: num_leaves=60; max_depth=22; min_child_weight=6.66; min_data_in_leaf=119; min_gain_to_split=0.0308; lambda_l1=0.409; lambda_l2=0.277; scale_pos_weight=3.93; learning_rate=0.0117; num_iterations=4787; early_stopping_rounds=487; feature_fraction=0.592; bagging_fraction=0.642; bagging_freq=2; max_delta_step=5.93; path_smooth=8.26 : y = 0.93 : 202.4 secs : infill_ei
#
# Tue Nov 18 03:13:15 AM 2025 AUC 0.930020353396158
#
# [mbo] 89: num_leaves=31; max_depth=19; min_child_weight=1.87; min_data_in_leaf=51; min_gain_to_split=0.0083; lambda_l1=0.37; lambda_l2=0.0574; scale_pos_weight=3.81; learning_rate=0.014; num_iterations=3701; early_stopping_rounds=298; feature_fraction=0.501; bagging_fraction=0.852; bagging_freq=5; max_delta_step=5.76; path_smooth=8.97 : y = 0.93 : 250.2 secs : infill_ei
#
# Tue Nov 18 03:17:08 AM 2025 AUC 0.927413266548962
#
# [mbo] 90: num_leaves=58; max_depth=20; min_child_weight=6.26; min_data_in_leaf=2152; min_gain_to_split=0.0267; lambda_l1=0.356; lambda_l2=0.148; scale_pos_weight=4.91; learning_rate=0.0187; num_iterations=4093; early_stopping_rounds=436; feature_fraction=0.456; bagging_fraction=0.823; bagging_freq=5; max_delta_step=5.64; path_smooth=5.13 : y = 0.927 : 230.6 secs : infill_ei
#
# Saved the current state after iteration 91 in the file HT.RDATA.
#
# Tue Nov 18 03:20:18 AM 2025 AUC 0.925465836425264
#
# [mbo] 91: num_leaves=14; max_depth=15; min_child_weight=1.53; min_data_in_leaf=799; min_gain_to_split=0.0679; lambda_l1=0.459; lambda_l2=0.0801; scale_pos_weight=3.65; learning_rate=0.0608; num_iterations=3709; early_stopping_rounds=500; feature_fraction=0.489; bagging_fraction=0.808; bagging_freq=5; max_delta_step=5.55; path_smooth=9.19 : y = 0.925 : 186.5 secs : infill_ei
#
# Tue Nov 18 03:23:20 AM 2025 AUC 0.929100323520352
#
# [mbo] 92: num_leaves=41; max_depth=13; min_child_weight=4.67; min_data_in_leaf=103; min_gain_to_split=0.0293; lambda_l1=0.21; lambda_l2=0.113; scale_pos_weight=4.87; learning_rate=0.0226; num_iterations=2720; early_stopping_rounds=399; feature_fraction=0.468; bagging_fraction=0.768; bagging_freq=5; max_delta_step=3.28; path_smooth=1.71 : y = 0.929 : 177.7 secs : infill_ei
#
# Tue Nov 18 03:27:02 AM 2025 AUC 0.932038245326537
#
# [mbo] 93: num_leaves=57; max_depth=15; min_child_weight=6.5; min_data_in_leaf=83; min_gain_to_split=0.0701; lambda_l1=0.143; lambda_l2=0.321; scale_pos_weight=4.22; learning_rate=0.0115; num_iterations=2273; early_stopping_rounds=380; feature_fraction=0.409; bagging_fraction=0.741; bagging_freq=4; max_delta_step=3; path_smooth=6.35 : y = 0.932 : 219.1 secs : infill_ei
#
# Tue Nov 18 03:30:50 AM 2025 AUC 0.931749016386732
#
# [mbo] 94: num_leaves=51; max_depth=20; min_child_weight=8.01; min_data_in_leaf=122; min_gain_to_split=0.0269; lambda_l1=0.173; lambda_l2=0.0782; scale_pos_weight=4.07; learning_rate=0.0265; num_iterations=3447; early_stopping_rounds=442; feature_fraction=0.426; bagging_fraction=0.737; bagging_freq=5; max_delta_step=6.68; path_smooth=7.48 : y = 0.932 : 224.3 secs : infill_ei
#
# Saved the current state after iteration 95 in the file HT.RDATA.
#
# Tue Nov 18 03:33:49 AM 2025 AUC 0.93303678978693
#
# [mbo] 95: num_leaves=60; max_depth=13; min_child_weight=7.49; min_data_in_leaf=261; min_gain_to_split=0.0613; lambda_l1=0.0195; lambda_l2=0.391; scale_pos_weight=4.71; learning_rate=0.0203; num_iterations=3647; early_stopping_rounds=327; feature_fraction=0.404; bagging_fraction=0.719; bagging_freq=5; max_delta_step=2.32; path_smooth=4.35 : y = 0.933 : 176.7 secs : infill_ei
#
# Tue Nov 18 03:37:33 AM 2025 AUC 0.9284524104313
#
# [mbo] 96: num_leaves=51; max_depth=27; min_child_weight=3.17; min_data_in_leaf=2149; min_gain_to_split=0.0541; lambda_l1=0.419; lambda_l2=0.136; scale_pos_weight=3.45; learning_rate=0.0183; num_iterations=3818; early_stopping_rounds=485; feature_fraction=0.628; bagging_fraction=0.734; bagging_freq=5; max_delta_step=6.37; path_smooth=9.79 : y = 0.928 : 221.1 secs : infill_ei
#
# Tue Nov 18 03:42:55 AM 2025 AUC 0.932994512702922
#
# [mbo] 97: num_leaves=53; max_depth=15; min_child_weight=3.85; min_data_in_leaf=225; min_gain_to_split=0.0307; lambda_l1=0.223; lambda_l2=0.305; scale_pos_weight=4.28; learning_rate=0.0105; num_iterations=3480; early_stopping_rounds=462; feature_fraction=0.582; bagging_fraction=0.648; bagging_freq=5; max_delta_step=6.09; path_smooth=9.76 : y = 0.933 : 319.3 secs : infill_ei
#
# Saved the current state after iteration 98 in the file HT.RDATA.
#
# Tue Nov 18 03:47:09 AM 2025 AUC 0.929838159296026
#
# [mbo] 98: num_leaves=62; max_depth=20; min_child_weight=8.61; min_data_in_leaf=949; min_gain_to_split=0.0569; lambda_l1=0.154; lambda_l2=0.0288; scale_pos_weight=2.03; learning_rate=0.0213; num_iterations=3182; early_stopping_rounds=354; feature_fraction=0.535; bagging_fraction=0.709; bagging_freq=5; max_delta_step=3.32; path_smooth=2.05 : y = 0.93 : 249.1 secs : infill_ei
#
# Tue Nov 18 03:50:24 AM 2025 AUC 0.9305602250483
#
# [mbo] 99: num_leaves=54; max_depth=10; min_child_weight=0.539; min_data_in_leaf=2267; min_gain_to_split=0.0858; lambda_l1=0.133; lambda_l2=0.326; scale_pos_weight=3.51; learning_rate=0.0309; num_iterations=4543; early_stopping_rounds=450; feature_fraction=0.488; bagging_fraction=0.889; bagging_freq=5; max_delta_step=2.83; path_smooth=5.88 : y = 0.931 : 192.2 secs : infill_ei
#
# Tue Nov 18 03:54:43 AM 2025 AUC 0.933892061907072
#
# [mbo] 100: num_leaves=52; max_depth=19; min_child_weight=3.92; min_data_in_leaf=166; min_gain_to_split=0.0833; lambda_l1=0.0802; lambda_l2=0.142; scale_pos_weight=4.67; learning_rate=0.00913; num_iterations=2616; early_stopping_rounds=401; feature_fraction=0.504; bagging_fraction=0.706; bagging_freq=5; max_delta_step=2.54; path_smooth=3.14 : y = 0.934 : 256.2 secs : infill_ei
#
# Saved the final state in the file HT.RDATA
#
# Saved the final state in the file HT.RDATA

# %% [markdown]
# la bayesian optimization ha corrido, extraigo los mejores hiperparametros

# %%
# almaceno los resultados de la Bayesian Optimization
# y capturo los mejores hiperparametros encontrados

tb_bayesiana <- as.data.table(bayesiana_salida$opt.path)

# ordeno en forma descendente por AUC = y
setorder(tb_bayesiana, -y, -num_iterations)

# grabo para eventualmente poder utilizarlos en OTRA corrida
fwrite( tb_bayesiana,
  file="BO_log.txt",
  sep="\t"
)

# los mejores hiperparámetros son los que quedaron en el registro 1 de la tabla
PARAM$out$lgbm$mejores_hiperparametros <- tb_bayesiana[
  1, # el primero es el de mejor AUC
  setdiff(colnames(tb_bayesiana),
    c("y","dob","eol","error.message","exec.time","ei","error.model",
      "train.time","prop.type","propose.time","se","mean","iter")),
  with= FALSE
]

print(PARAM$out$lgbm$mejores_hiperparametros)
# Out:
#    num_leaves max_depth min_child_weight min_data_in_leaf min_gain_to_split
#         <int>     <int>            <num>            <int>             <num>
# 1:         55        10         4.367893              929        0.06923395
#    lambda_l1 lambda_l2 scale_pos_weight learning_rate num_iterations
#        <num>     <num>            <num>         <num>          <int>
# 1: 0.2190095 0.1596201         4.132753     0.0582758           3987
#    early_stopping_rounds feature_fraction bagging_fraction bagging_freq
#                    <int>            <num>            <num>        <int>
# 1:                   498        0.4761197        0.7955275            5
#    max_delta_step path_smooth
#             <num>       <num>
# 1:       3.051562    8.377384

# %% [markdown]
# ### 6.3.3 Produccion

# %% [markdown]
# #### Final Training
# Construyo el modelo final, que es uno solo, no hace ningun tipo de particion < training, validation, testing>]

# %% [markdown]
# ##### Final Training Dataset
#
# Aqui esta la gran decision de en qué meses hago el Final Training
# <br> debo utilizar los mejores hiperparámetros que encontré en la optimización bayesiana

# %%
PARAM$trainingstrategy$final_train <- c(
  202105, 202104, 202103, 202102, 202101,
  202012, 202011, 202010, 202009, 202008, 202007,
  202006, 202005
)

dataset[, fold_final_train := foto_mes %in% PARAM$trainingstrategy$final_train ]

# creo el dfinal_train en formato  LightGBM
dfinal_train <- lgb.Dataset(
  data= data.matrix(dataset[fold_final_train == TRUE, campos_buenos, with= FALSE]),
  label= dataset[fold_final_train == TRUE, clase01],
  free_raw_data= TRUE
)

nrow( dfinal_train) # verifico el tamaño
# Out:
# [1] 207504

# %% [markdown]
# ##### Final Training Hyperparameters

# %%
# uno los parametros fijos y los mejores encontrados de los variables
fijos <- copy(PARAM$lgbm$param_fijos)

# quito lo que optimice en la Bayesian Optimization
fijos$num_iterations <- NULL
fijos$early_stopping_rounds <- NULL

# agrego a los hiperparametros fijos los que encontre con la Bayesian Optimization
param_final <- c(fijos, PARAM$out$lgbm$mejores_hiperparametros)

# Para el entrenamiento final, removemos early_stopping_rounds
# ya que se entrena con todos los datos disponibles y la cantidad de iteraciones
# ya está optimizada en 'num_iterations'.
param_final$early_stopping_rounds <- NULL

# %% [markdown]
# ##### Training
# Genero el modelo final, siempre sobre TODOS los datos de  final_train, sin hacer ningun tipo de undersampling de la clase mayoritaria

# %%
final_model <- lgb.train(
  data= dfinal_train,
  param= param_final,
  verbose= -100
)

# %%
# grabo a disco el modelo en un formato para seres humanos ... ponele ...

lgb.save(final_model, "modelo.txt")

# %%
# ahora imprimo la importancia de variables

tb_importancia <- as.data.table(lgb.importance(final_model))
archivo_importancia <- "impo.txt"

fwrite( tb_importancia,
  file= archivo_importancia,
  sep= "\t"
)

# %% [markdown]
# #### Scoring

# %% [markdown]
# Aplico el modelo final a los datos del futuro

# %%
PARAM$trainingstrategy$future <- c(202107)

dfuture <- dataset[ foto_mes %in% PARAM$trainingstrategy$future ]

# %%
# aplico final_model   a dfuture

prediccion <- predict(
  final_model,
  data.matrix(dfuture[, campos_buenos, with= FALSE])
)

# %% [markdown]
# ##### Tabla Prediccion

# %%
tb_prediccion <- dfuture[, list(numero_de_cliente)]
tb_prediccion[, prob := prediccion]

# grabo las probabilidad del modelo
#  me va a ser util para hacer Ensembles de modelos
fwrite(tb_prediccion,
  file= "prediccion.txt",
  sep= "\t"
)

# %% [markdown]
# #### Curva de Ganancia

# %% [markdown]
# Genero las salidas

# %%
# asigno clase ternaria
tb_prediccion[, clase_ternaria := dfuture$clase_ternaria ]

# asigno ganancias
tb_prediccion[, ganancia := -3000.0 ]
tb_prediccion[clase_ternaria=="BAJA+2", ganancia := 117000.0 ]

# reordeno, y acumulada
setorder( tb_prediccion, -prob )
tb_prediccion[, gan_acum := cumsum(ganancia)]

# media movil de ancho 400
tb_prediccion[,
  gan_suavizada := frollmean(
    x= gan_acum,
    n= 400,
    align= "center",
    na.rm= TRUE,
    hasNA= TRUE
  )
]

# %%
tb_prediccion[, sum(!is.na(gan_suavizada) )]
tb_prediccion[, .N]
# Out:
# [1] 16152
# [1] 16551

# %%
# Este es la ganancia a reportar
resultado <- list()
resultado$ganancia_suavizada_max <- max( tb_prediccion$gan_suavizada, na.rm=TRUE )
options(digits= 8)
resultado$envios <- which.max( tb_prediccion$gan_suavizada)
resultado
# Out:
# $ganancia_suavizada_max
# [1] 5907000
#
# $envios
# [1] 1017

# %%
# grabo las ganancias
fwrite( tb_prediccion,
  file= "ganancias.txt",
  sep= "\t"
)

# %%
# genero el grafico

tb_prediccion[, envios:= .I]

pdf("curva_de_ganancia.pdf")

plot(
  x= tb_prediccion$envios,
  y= tb_prediccion$gan_acum,
  type= "l",
  col= "gray",
  xlim= c(0, 6000),
  ylim= c(0, 8000000),
  main= paste0("Mejor gan prom= ", as.integer(resultado$ganancia_suavizada_max), " envios= ", resultado$envios),
  xlab= "Envios",
  ylab= "Ganancia",
  panel.first= grid()
)

dev.off()
# Out:
# agg_record_847869220
#                    2

# %%
# grabo los parametros
if( !require("yaml")) install.packages("yaml")
require("yaml")

PARAM$resultado <- resultado

write_yaml( PARAM, file="PARAM.yml")
# Out:
# Loading required package: yaml

# %%
format(Sys.time(), "%a %b %d %X %Y")
fin <- Sys.time()

# Duración en segundos
secs <- as.numeric(difftime(fin, principio, units = "secs"))
secs <- round(secs)

# A hh:mm:ss
h <- secs %/% 3600
m <- (secs %% 3600) %/% 60
s <- secs %% 60
dur_hms <- sprintf("%02d:%02d:%02d", h, m, s)

cat(
  "Inicio: ", format(principio, "%a %b %d %X %Y"), "\n",
  "Fin:    ", format(fin,       "%a %b %d %X %Y"), "\n",
  "Duración (hh:mm:ss): ", dur_hms, "\n",
  sep = ""
)
# Out:
# [1] "Tue Nov 18 04:00:55 AM 2025"
# Inicio: Mon Nov 17 09:36:33 PM 2025
# Fin:    Tue Nov 18 04:00:55 AM 2025
# Duración (hh:mm:ss): 06:24:22
