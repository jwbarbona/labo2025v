# %% [markdown]
# <a href="https://colab.research.google.com/github/jwbarbona/labo2025v/blob/main/610_WorkFlow_16HT_65104_gerencial_julio.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # 6 WorkFlow  Gerencial, futuro=JULIO

# %% [markdown]
# ### 6.1 Objetivo

# %% [markdown]
# Presentar un workflow/pipeline completo al que los estudiantes deberán enriquecer

# %% [markdown]
# #### 6.2  Seteo del ambiente en Google Colab

# %% [markdown]
# Esta parte se debe correr con el runtime en Python3
# <br>Ir al menu, Runtime -> Change Runtime Type -> Runtime type ->  **Python 3**

# %% [markdown]
# Conectar la virtual machine donde esta corriendo Google Colab con el  Google Drive, para poder tener persistencia de archivos

# %%
# primero establecer el Runtime de Python 3
from google.colab import drive
drive.mount('/content/.drive')
# Out:
# Mounted at /content/.drive

# %% [markdown]
# Para correr la siguiente celda es fundamental en Arranque en Frio haber copiado el archivo kaggle.json al Google Drive, en la carpeta indicada en el instructivo
#
# <br>los siguientes comando estan en shell script de Linux
# *   Crear las carpetas en el Google Drive
# *   "instalar" el archivo kaggle.json desde el Google Drive a la virtual machine para que pueda ser utilizado por la libreria  kaggle de Python
# *   Bajar el  **dataset_pequeno**  al  Google Drive  y tambien al disco local de la virtual machine que esta corriendo Google Colab
# *   Bajar el **dataset_historico** al Google Drive y tambien al disco local de la virtual machine que esta corriendo Google Colab

# %%
%%shell

mkdir -p "/content/.drive/My Drive/labo1"
mkdir -p "/content/buckets"
ln -s "/content/.drive/My Drive/labo1" /content/buckets/b1

mkdir -p ~/.kaggle
cp /content/buckets/b1/kaggle/kaggle.json  ~/.kaggle
chmod 600 ~/.kaggle/kaggle.json


mkdir -p /content/buckets/b1/exp
mkdir -p /content/buckets/b1/datasets
mkdir -p /content/datasets


webfiles="https://storage.googleapis.com/open-courses/austral2025-af91/"
destino_local="/content/datasets"
destino_bucket="/content/buckets/b1/datasets"


archivo="dataset_pequeno.csv"

if ! test -f $destino_bucket/$archivo; then
  wget  $webfiles/$archivo  -O $destino_bucket/$archivo
fi


if ! test -f $destino_local/$pequeno; then
  cp  $destino_bucket/$archivo  $destino_local/$archivo
fi

#-------

archivo="gerencial_competencia_2025.csv.gz"

if ! test -f $destino_bucket/$archivo; then
  wget  $webfiles/$archivo  -O $destino_bucket/$archivo
fi


if ! test -f $destino_local/$pequeno; then
  cp  $destino_bucket/$archivo  $destino_local/$archivo
fi
# Out:
# cp: cannot stat '/content/buckets/b1/kaggle/kaggle.json': No such file or directory
# chmod: cannot access '/root/.kaggle/kaggle.json': No such file or directory

# %% [markdown]
# ## 6.3  Workflow

# %% [markdown]
# ## Inicializacion

# %% [markdown]
# Esta parte se debe correr con el runtime en lenguaje **R** Ir al menu, Runtime -> Change Runtime Type -> Runtime type -> R

# %% [markdown]
# limpio el ambiente de R

# %%
format(Sys.time(), "%a %b %d %X %Y")
# Out:
# [1] "Wed Nov 19 02:02:37 AM 2025"

# %%
# limpio la memoria
rm(list=ls(all.names=TRUE)) # remove all objects
gc(full=TRUE, verbose=FALSE) # garbage collection
# Out:
#        used    (Mb) gc trigger (Mb) max used (Mb)
# Ncells  660358 35.3 1454494    77.7 1454494  77.7
# Vcells 1226521  9.4 8388608    64.0 1975136  15.1

# %%
principio <- Sys.time()

# %%
require("data.table")

if( !require("R.utils")) install.packages("R.utils")
require("R.utils")
# Out:
# Loading required package: data.table
#
# Loading required package: R.utils
#
# Warning message in library(package, lib.loc = lib.loc, character.only = TRUE, logical.return = TRUE, :
# “there is no package called ‘R.utils’”
# Installing package into ‘/usr/local/lib/R/site-library’
# (as ‘lib’ is unspecified)
#
# also installing the dependencies ‘R.oo’, ‘R.methodsS3’
#
#
# Loading required package: R.utils
#
# Loading required package: R.oo
#
# Loading required package: R.methodsS3
#
# R.methodsS3 v1.8.2 (2022-06-13 22:00:14 UTC) successfully loaded. See ?R.methodsS3 for help.
#
# R.oo v1.27.1 (2025-05-02 21:00:05 UTC) successfully loaded. See ?R.oo for help.
#
#
# Attaching package: ‘R.oo’
#
#
# The following object is masked from ‘package:R.methodsS3’:
#
#     throw
#
#
# The following objects are masked from ‘package:methods’:
#
#     getClasses, getMethods
#
#
# The following objects are masked from ‘package:base’:
#
#     attach, detach, load, save
#
#
# R.utils v2.13.0 (2025-02-24 21:20:02 UTC) successfully loaded. See ?R.utils for help.
#
#
# Attaching package: ‘R.utils’
#
#
# The following object is masked from ‘package:utils’:
#
#     timestamp
#
#
# The following objects are masked from ‘package:base’:
#
#     cat, commandArgs, getOption, isOpen, nullfile, parse, use, warnings

# %% [markdown]
# #### Parametros
# Si es gerente, no cambie nada
# <br>Si es Analista, cambie el nombre del dataset

# %%
PARAM <- list()
PARAM$semilla_primigenia <- 700009 # 100009, 200003, 499999, 700009, 999983

PARAM$experimento <- 65104
PARAM$dataset <- "gerencial_competencia_2025.csv.gz"

# %% [markdown]
# #### Carpeta del Experimento

# %%
# carpeta de trabajo

setwd("/content/buckets/b1/exp")
experimento_folder <- paste0("WF", PARAM$experimento)
dir.create(experimento_folder, showWarnings=FALSE)
setwd( paste0("/content/buckets/b1/exp/", experimento_folder ))

# %% [markdown]
# ### 6.3.1   Preprocesamiento del dataset

# %% [markdown]
# #### 6.3.1.1  DT incorporar dataset

# %%
# lectura del dataset
dataset <- fread(paste0("/content/datasets/", PARAM$dataset))

# %% [markdown]
# #### 6.3.1.2  CA  Catastrophe Analysis
# Se intentan reparar las variables que para un mes están con todos los valores en cero.

# %% [markdown]
# El método que se utiliza es **Machine Learning** se asigna NA also valores, si ha leido bien, es la "anti imputación de valores faltantes"
# <br> Usted podrá aplicar aquí otros métodos

# %%
dataset[ foto_mes==202006, internet:=NA]
dataset[ foto_mes==202006, mrentabilidad:=NA]
dataset[ foto_mes==202006, mrentabilidad_annual:=NA]
dataset[ foto_mes==202006, mcomisiones:=NA]
dataset[ foto_mes==202006, mactivos_margen:=NA]
dataset[ foto_mes==202006, mpasivos_margen:=NA]
dataset[ foto_mes==202006, mcuentas_saldo:=NA]
dataset[ foto_mes==202006, ctarjeta_visa_transacciones:=NA]
dataset[ foto_mes==202006, mtarjeta_visa_consumo:=NA]
dataset[ foto_mes==202006, mtarjeta_master_consumo:=NA]
dataset[ foto_mes==202006, ccallcenter_transacciones:=NA]
dataset[ foto_mes==202006, chomebanking_transacciones:=NA]
dataset[ foto_mes==202006, chomebanking_transacciones:=NA]

# %% [markdown]
# #### 6.3.1.3  DR  Data Drifting
# Se intenta corregir el data drifting, quizas ajustando por IPC ...
# <br>Esta parte podrá ser abordada por todos los Analistas y también la Gerenciapero se decide pedagogicamente no incluirla en esta primer version para reducir la carga cognitiva

# %%
# sin codigo en esta primera version del workflow

# %% [markdown]
# #### 6.3.1.3  FE_intra_manual Feature Engineering intra-mes
#
# Agrego campos nuevos dentro del mismo mes, SIN considerar la historia.

# %%
# esta funcion atributos presentes existe debido a que las modalidades poseen datasets con distinta cantidad de campos
atributos_presentes <- function( patributos )
{
  atributos <- unique( patributos )
  comun <- intersect( atributos, colnames(dataset) )

  return(  length( atributos ) == length( comun ) )
}

# el mes 1,2, ..12
if( atributos_presentes( c("foto_mes") ))
  dataset[, kmes := foto_mes %% 100]

# variable extraida de una tesis de maestria de Irlanda
if( atributos_presentes( c("mpayroll", "cliente_edad") ))
  dataset[, mpayroll_sobre_edad := mpayroll / cliente_edad]

# %%
# visualizo las columas del dataset a esta etapa
colnames(dataset)
# Out:
#  [1] "numero_de_cliente"           "foto_mes"
#  [3] "internet"                    "cliente_edad"
#  [5] "cliente_antiguedad"          "mrentabilidad"
#  [7] "mrentabilidad_annual"        "mcomisiones"
#  [9] "mactivos_margen"             "mpasivos_margen"
# [11] "cproductos"                  "mcuenta_corriente"
# [13] "mcaja_ahorro"                "cdescubierto_preacordado"
# [15] "mcuentas_saldo"              "ctarjeta_visa_transacciones"
# [17] "mtarjeta_visa_consumo"       "mtarjeta_master_consumo"
# [19] "mprestamos_personales"       "cpayroll_trx"
# [21] "mpayroll"                    "ccomisiones_mantenimiento"
# [23] "ccallcenter_transacciones"   "chomebanking_transacciones"
# [25] "ctrx_quarter"                "Master_status"
# [27] "Master_fechaalta"            "Master_mpagominimo"
# [29] "Visa_status"                 "Visa_fechaalta"
# [31] "Visa_mpagominimo"            "clase_ternaria"
# [33] "kmes"                        "mpayroll_sobre_edad"

# %% [markdown]
# #### 6.3.1.4  FE_rf Feature Engineering de nuevas variables a partir de hojas de Random Forest
#
# Esto se mostrará unicamente a la *modalidad Analista Sr*

# %%
# No se implementa Feature Engineering a partir de Random Forest

# %% [markdown]
# #### 6.3.1.5  FEhist Feature Engineering historico
#
# El Fature Engineering Histórico es la etapa que más aporta a la ganancia final, ya que enriquece cada registro del dataset con su historia.

# %% [markdown]
# Para cada campo del dataset original (*)
# se crean lo siguientes campos de a partir de la historia
# * lag1  lags de orden 1
# * delta1  =  valor actual - lag1
# * lag2  lags de orden 2
# * delta2  = valor actual - lag2
#
#
# (*) Excepto para los campos  <numero_de_cliente,  foto_mes,  clase_ternaria>

# %%
# Feature Engineering Historico

# todo es lagueable, menos la primary key y la clase
cols_lagueables <- copy( setdiff(
    colnames(dataset),
    c("numero_de_cliente", "foto_mes", "clase_ternaria")
) )

# https://rdrr.io/cran/data.table/man/shift.html

# lags de orden 1
dataset[,
    paste0(cols_lagueables, "_lag1") := shift(.SD, 1, NA, "lag"),
    by = numero_de_cliente,
    .SDcols = cols_lagueables
]

# lags de orden 2
dataset[,
    paste0(cols_lagueables, "_lag2") := shift(.SD, 2, NA, "lag"),
    by = numero_de_cliente,
    .SDcols = cols_lagueables
]

# agrego los delta lags
for (vcol in cols_lagueables)
{
    dataset[, paste0(vcol, "_delta1") := get(vcol) - get(paste0(vcol, "_lag1"))]
    dataset[, paste0(vcol, "_delta2") := get(vcol) - get(paste0(vcol, "_lag2"))]
}

# %% [markdown]
# Verificacion de los campos recien creados

# %%
ncol(dataset)
colnames(dataset)
# Out:
# [1] 158
#   [1] "numero_de_cliente"                  "foto_mes"
#   [3] "internet"                           "cliente_edad"
#   [5] "cliente_antiguedad"                 "mrentabilidad"
#   [7] "mrentabilidad_annual"               "mcomisiones"
#   [9] "mactivos_margen"                    "mpasivos_margen"
#  [11] "cproductos"                         "mcuenta_corriente"
#  [13] "mcaja_ahorro"                       "cdescubierto_preacordado"
#  [15] "mcuentas_saldo"                     "ctarjeta_visa_transacciones"
#  [17] "mtarjeta_visa_consumo"              "mtarjeta_master_consumo"
#  [19] "mprestamos_personales"              "cpayroll_trx"
#  [21] "mpayroll"                           "ccomisiones_mantenimiento"
#  [23] "ccallcenter_transacciones"          "chomebanking_transacciones"
#  [25] "ctrx_quarter"                       "Master_status"
#  [27] "Master_fechaalta"                   "Master_mpagominimo"
#  [29] "Visa_status"                        "Visa_fechaalta"
#  [31] "Visa_mpagominimo"                   "clase_ternaria"
#  [33] "kmes"                               "mpayroll_sobre_edad"
#  [35] "internet_lag1"                      "cliente_edad_lag1"
#  [37] "cliente_antiguedad_lag1"            "mrentabilidad_lag1"
#  [39] "mrentabilidad_annual_lag1"          "mcomisiones_lag1"
#  [41] "mactivos_margen_lag1"               "mpasivos_margen_lag1"
#  [43] "cproductos_lag1"                    "mcuenta_corriente_lag1"
#  [45] "mcaja_ahorro_lag1"                  "cdescubierto_preacordado_lag1"
#  [47] "mcuentas_saldo_lag1"                "ctarjeta_visa_transacciones_lag1"
#  [49] "mtarjeta_visa_consumo_lag1"         "mtarjeta_master_consumo_lag1"
#  [51] "mprestamos_personales_lag1"         "cpayroll_trx_lag1"
#  [53] "mpayroll_lag1"                      "ccomisiones_mantenimiento_lag1"
#  [55] "ccallcenter_transacciones_lag1"     "chomebanking_transacciones_lag1"
#  [57] "ctrx_quarter_lag1"                  "Master_status_lag1"
#  [59] "Master_fechaalta_lag1"              "Master_mpagominimo_lag1"
#  [61] "Visa_status_lag1"                   "Visa_fechaalta_lag1"
#  [63] "Visa_mpagominimo_lag1"              "kmes_lag1"
#  [65] "mpayroll_sobre_edad_lag1"           "internet_lag2"
#  [67] "cliente_edad_lag2"                  "cliente_antiguedad_lag2"
#  [69] "mrentabilidad_lag2"                 "mrentabilidad_annual_lag2"
#  [71] "mcomisiones_lag2"                   "mactivos_margen_lag2"
#  [73] "mpasivos_margen_lag2"               "cproductos_lag2"
#  [75] "mcuenta_corriente_lag2"             "mcaja_ahorro_lag2"
#  [77] "cdescubierto_preacordado_lag2"      "mcuentas_saldo_lag2"
#  [79] "ctarjeta_visa_transacciones_lag2"   "mtarjeta_visa_consumo_lag2"
#  [81] "mtarjeta_master_consumo_lag2"       "mprestamos_personales_lag2"
#  [83] "cpayroll_trx_lag2"                  "mpayroll_lag2"
#  [85] "ccomisiones_mantenimiento_lag2"     "ccallcenter_transacciones_lag2"
#  [87] "chomebanking_transacciones_lag2"    "ctrx_quarter_lag2"
#  [89] "Master_status_lag2"                 "Master_fechaalta_lag2"
#  [91] "Master_mpagominimo_lag2"            "Visa_status_lag2"
#  [93] "Visa_fechaalta_lag2"                "Visa_mpagominimo_lag2"
#  [95] "kmes_lag2"                          "mpayroll_sobre_edad_lag2"
#  [97] "internet_delta1"                    "internet_delta2"
#  [99] "cliente_edad_delta1"                "cliente_edad_delta2"
# [101] "cliente_antiguedad_delta1"          "cliente_antiguedad_delta2"
# [103] "mrentabilidad_delta1"               "mrentabilidad_delta2"
# [105] "mrentabilidad_annual_delta1"        "mrentabilidad_annual_delta2"
# [107] "mcomisiones_delta1"                 "mcomisiones_delta2"
# [109] "mactivos_margen_delta1"             "mactivos_margen_delta2"
# [111] "mpasivos_margen_delta1"             "mpasivos_margen_delta2"
# [113] "cproductos_delta1"                  "cproductos_delta2"
# [115] "mcuenta_corriente_delta1"           "mcuenta_corriente_delta2"
# [117] "mcaja_ahorro_delta1"                "mcaja_ahorro_delta2"
# [119] "cdescubierto_preacordado_delta1"    "cdescubierto_preacordado_delta2"
# [121] "mcuentas_saldo_delta1"              "mcuentas_saldo_delta2"
# [123] "ctarjeta_visa_transacciones_delta1" "ctarjeta_visa_transacciones_delta2"
# [125] "mtarjeta_visa_consumo_delta1"       "mtarjeta_visa_consumo_delta2"
# [127] "mtarjeta_master_consumo_delta1"     "mtarjeta_master_consumo_delta2"
# [129] "mprestamos_personales_delta1"       "mprestamos_personales_delta2"
# [131] "cpayroll_trx_delta1"                "cpayroll_trx_delta2"
# [133] "mpayroll_delta1"                    "mpayroll_delta2"
# [135] "ccomisiones_mantenimiento_delta1"   "ccomisiones_mantenimiento_delta2"
# [137] "ccallcenter_transacciones_delta1"   "ccallcenter_transacciones_delta2"
# [139] "chomebanking_transacciones_delta1"  "chomebanking_transacciones_delta2"
# [141] "ctrx_quarter_delta1"                "ctrx_quarter_delta2"
# [143] "Master_status_delta1"               "Master_status_delta2"
# [145] "Master_fechaalta_delta1"            "Master_fechaalta_delta2"
# [147] "Master_mpagominimo_delta1"          "Master_mpagominimo_delta2"
# [149] "Visa_status_delta1"                 "Visa_status_delta2"
# [151] "Visa_fechaalta_delta1"              "Visa_fechaalta_delta2"
# [153] "Visa_mpagominimo_delta1"            "Visa_mpagominimo_delta2"
# [155] "kmes_delta1"                        "kmes_delta2"
# [157] "mpayroll_sobre_edad_delta1"         "mpayroll_sobre_edad_delta2"

# %% [markdown]
# #### 6.3.1.6  FEhist Reduccion dimensionalidad con canaritos
#
# Esta etapa solo se mostrará a la *modalidad Anlista Sr* por algun canal secreto de forma de no confundir a los *Analista Jr*  nni distraer con detalles operativos a la estratégica *Modalidad Gerencial*

# %%
# No se implementa la reduccion de la dimensionalidad con canaritos

# %% [markdown]
# ### 6.3.2 Modelado

# %% [markdown]
# #### 6.3.2.1 Training Strategy
#
# Esta etapa de Workflow de  Training Strategy esta pensada para la *Modalidad Gerencial* que posee el dataset de [202005, 202109]
# <br> Si usted es un Analista, posee el periodo de [201901, 202109] y deberá experimentar en que meses le conviene experimentar
#
# <br> A la *Modalidad Gerencial* no se le complicada la vida con el undersampling de los continua, por eso PARAM$trainingstrategy$training_pct <- 1.0
# <br> Sin embargo, si usted es  *Analista SR* posee un dataset 50 veces ( filas x columnas) más grande que la *Modalidad Gerencial*  y por un tema de velocidad y experimentación más rápida puede llegar a necesitar activar el undersampling de la clase mayoritaria, a pesar de estar corriendo en Google Cloud.

# %% [markdown]
# Se hace una estrategia de entrenamiento muy sencilla, tomando todos los meses posibles, SIN eliminar nada x pandemia ni por ningun otro motivo
#
# * future = 202107  obviamente completo
#
# * final_train =  [ 202005, 202105 ]  SIN undersampling
#
# * training
#    * testing = NO HAY
#    * validation =  202105   completo, sin undersampling
#    * training = [ 202005, 202104 ]  donde se consideran el 100% de los CONTINUA

# %%
PARAM$trainingstrategy$validate <- c(202105)

PARAM$trainingstrategy$training <- c(
  202104, 202103, 202102, 202101,
  202012, 202011, 202010, 202009, 202008, 202007,
  202006, 202005
)

PARAM$trainingstrategy$training_pct <- 1.0


PARAM$trainingstrategy$positivos <- c( "BAJA+1", "BAJA+2")

# %%
# seteo la clase01   1={BAJA+1, BAJA+2}   0={CONTINUA}
dataset[, clase01 := ifelse( clase_ternaria %in% PARAM$trainingstrategy$positivos, 1, 0 )]

# %%
# los campos en los que se entrena
campos_buenos <- copy( setdiff(
    colnames(dataset), c("clase_ternaria","clase01","azar"))
)

# %%
# preparo para que se puede hacer undersampling de los CONTINUA
#  solamente por un tema de VELOCIDAD
set.seed(PARAM$semilla_primigenia, kind = "L'Ecuyer-CMRG")
dataset[, azar:=runif(nrow(dataset))]

# undersampling de los CONTINUA
dataset[, fold_train :=  foto_mes %in%  PARAM$trainingstrategy$training &
    (clase_ternaria %in% c("BAJA+1", "BAJA+2") |
     azar < PARAM$trainingstrategy$training_pct ) ]


if( !require("lightgbm")) install.packages("lightgbm")
require("lightgbm")

dtrain <- lgb.Dataset(
  data= data.matrix(dataset[fold_train == TRUE, campos_buenos, with = FALSE]),
  label= dataset[fold_train == TRUE, clase01],
  free_raw_data= TRUE
)
# Out:
# Loading required package: lightgbm
#
# Warning message in library(package, lib.loc = lib.loc, character.only = TRUE, logical.return = TRUE, :
# “there is no package called ‘lightgbm’”
# Installing package into ‘/usr/local/lib/R/site-library’
# (as ‘lib’ is unspecified)
#
# Loading required package: lightgbm

# %%
# datos de validation
dvalidate <- lgb.Dataset(
  data= data.matrix(dataset[foto_mes %in% PARAM$trainingstrategy$validate, campos_buenos, with = FALSE]),
  label= dataset[foto_mes %in% PARAM$trainingstrategy$validate, clase01],
  free_raw_data= TRUE
)

nrow(dvalidate)
# Out:
# [1] 16469

# %% [markdown]
# ####  6.3.2.2. Hyperparameter Tuning

# %% [markdown]
# * Clase binaria que se optimiza :  positivos = [ BAJA+1, BAJA+2 ]

# %% [markdown]
# * Metrica que se optimiza **AUC** Area Under Curve de la  ROC Curve
#
# es muy importante notar que intencionalmente  **NO** se está optimizando la funcion de ganancia del problema

# %% [markdown]
# * Cantidad de iteraciones inteligentes de la Optimizacion Bayesiana = **10**

# %% [markdown]
# * Parametros no default, fijos de LightGBM que no se optimizan
#   * max_bin = 31 , Alienigenas Ancestrales contruyeron las pirámides y dejaron a la humanidad en un jeroglifico  *max_bin=31*
#   * feature_fraction = 0.5  para poner algo que generalmente no falla
#   * learning_rate = 0.03  para que aprenda lento

# %% [markdown]
# * Parametros que se optimizan en la Bayesian Optimization
#   * num_leaves  [8, 256]
#   * min_data_in_leaf  [8, 8192]

# %%
# paquetes necesarios para la Bayesian Optimization
if(!require("DiceKriging")) install.packages("DiceKriging")
require("DiceKriging")

if(!require("mlrMBO")) install.packages("mlrMBO")
require("mlrMBO")
# Out:
# Loading required package: DiceKriging
#
# Warning message in library(package, lib.loc = lib.loc, character.only = TRUE, logical.return = TRUE, :
# “there is no package called ‘DiceKriging’”
# Installing package into ‘/usr/local/lib/R/site-library’
# (as ‘lib’ is unspecified)
#
# Loading required package: DiceKriging
#
# Loading required package: mlrMBO
#
# Warning message in library(package, lib.loc = lib.loc, character.only = TRUE, logical.return = TRUE, :
# “there is no package called ‘mlrMBO’”
# Installing package into ‘/usr/local/lib/R/site-library’
# (as ‘lib’ is unspecified)
#
# also installing the dependencies ‘XML’, ‘fastmatch’, ‘RcppArmadillo’, ‘mlr’, ‘ParamHelpers’, ‘smoof’, ‘BBmisc’, ‘checkmate’, ‘lhs’, ‘parallelMap’
#
#
# Loading required package: mlrMBO
#
# Loading required package: mlr
#
# Loading required package: ParamHelpers
#
#
# Attaching package: ‘ParamHelpers’
#
#
# The following object is masked from ‘package:R.utils’:
#
#     isVector
#
#
#
# Attaching package: ‘mlr’
#
#
# The following objects are masked from ‘package:R.utils’:
#
#     resample, setThreshold
#
#
# Loading required package: smoof
#
# Loading required package: checkmate
#
#
# Attaching package: ‘checkmate’
#
#
# The following object is masked from ‘package:DiceKriging’:
#
#     checkNames
#
#
# The following object is masked from ‘package:R.utils’:
#
#     asInt
#
#
#
# Attaching package: ‘smoof’
#
#
# The following objects are masked from ‘package:R.oo’:
#
#     getDescription, getName

# %% [markdown]
# Definición de la Bayesian Optimization
# <br> Si se desea optimizar un hiperparámetro que esta como fijo, debe QUITARSE de param_fijos y agregarse a PARAM$hipeparametertuning$hs

# %%
# valor ridiculamente bajo para que corra rapido en el aula y no molestar a la *Modalidad Gerencial*
PARAM$hipeparametertuning$num_interations <- 120

# parametros fijos del LightGBM
PARAM$lgbm$param_fijos <- list(
  objective= "binary",
  metric= "auc",
  first_metric_only= TRUE,
  boost_from_average= TRUE,
  feature_pre_filter= FALSE,
  verbosity= -100,
  force_row_wise= TRUE, # para evitar warning
  max_bin= 31,
  seed= PARAM$semilla_primigenia
  # learning_rate= 0.03,
  # feature_fraction= 0.5,
  # num_iterations= 2048,  # valor grande, lo limita early_stopping_rounds
  # early_stopping_rounds= 200
)


PARAM$hipeparametertuning$hs <- makeParamSet(
  # Núcleo del modelo (estructura de árboles)
  makeIntegerParam("num_leaves", lower = 2L, upper = 8192L),
  makeIntegerParam("max_depth", lower = 3L, upper = 30L),
  makeNumericParam("min_child_weight", lower = 0.001, upper = 10.0),
  makeIntegerParam("min_data_in_leaf", lower = 2L, upper = 8192L),
  makeNumericParam("min_gain_to_split", lower = 0.0, upper = 0.1),

  # Regularización
  makeNumericParam("lambda_l1", lower = 0.0, upper = 1000L),
  makeNumericParam("lambda_l2", lower = 0.0, upper = 1000L),
  makeNumericParam("scale_pos_weight", lower = 1.0, upper = 5.0),  # útil en desequilibrio

  # Control del aprendizaje
  makeNumericParam("learning_rate", lower = 0.005, upper = 0.1),
  makeIntegerParam("num_iterations", lower = 100L, upper = 5000L),
  makeIntegerParam("early_stopping_rounds", lower = 50L, upper = 500L),

  # Submuestreo
  makeNumericParam("feature_fraction", lower = 0.05, upper = 1L),   # columnas
  makeNumericParam("bagging_fraction", lower = 0.5, upper = 1L),   # filas
  makeIntegerParam("bagging_freq", lower = 0L, upper = 5L),         # cada N iteraciones

  # Opcionales útiles
  makeNumericParam("max_delta_step", lower = 0.0, upper = 10.0),
  makeNumericParam("path_smooth", lower = 0.0, upper = 10.0)
)
# Total: 16 hT

# %% [markdown]
# Función "señora caja negra"  que es llamada para verificar la realidad por la Bayesian Optimization

# %%
# En  x llegan los parmaetros de la bayesiana
#  devuelve la AUC en validate del modelo entrenado
#  en el parametro x llegan los hiperparámetros que se estan optimizando

EstimarGanancia_AUC_lightgbm <- function(x) {

  # x pisa (o agrega) a param_fijos
  param_completo <- modifyList(PARAM$lgbm$param_fijos, x)

  # entreno LightGBM
  modelo_train <- lgb.train(
    data= dtrain,
    valids= list(valid = dvalidate),
    eval= "auc",
    param= param_completo,
    verbose= -100
  )

  # recupero la AUC en validation
  AUC <- modelo_train$record_evals$valid$auc$eval[[modelo_train$best_iter]]

  # esta es la forma de devolver un parametro extra
  attr(AUC, "extras") <- list("num_iterations"= modelo_train$best_iter)

  # hago espacio en la memoria
  rm(modelo_train)
  gc(full= TRUE, verbose= FALSE)

  message(format(Sys.time(), "%a %b %d %X %Y"), " AUC ", AUC)

  return(AUC)
}

# %% [markdown]
# seteo de la Bayesian Optimization (complejo)
# <br> copiado y pegado de la documentación de la librería

# %%
configureMlr(show.learner.output = FALSE)

# configuro la busqueda bayesiana,  los hiperparametros que se van a optimizar
# por favor, no desesperarse por lo complejo
obj.fun <- makeSingleObjectiveFunction(
    fn= EstimarGanancia_AUC_lightgbm, # la funcion que voy a maximizar
    minimize= FALSE, # estoy Maximizando AUC
    noisy= FALSE,
    par.set= PARAM$hipeparametertuning$hs,
    has.simple.signature= FALSE # paso los parametros en una lista
)

# cada 600 segundos guardo el resultado intermedio
ctrl <- makeMBOControl(
    save.on.disk.at.time= 600,
    save.file.path= "HT.RDATA"
)

# indico la cantidad de iteraciones que va a tener la Bayesian Optimization
ctrl <- setMBOControlTermination(
    ctrl,
    iters= PARAM$hipeparametertuning$num_interations  # cantidad de iteraciones inteligentes
)

# defino el método estandar para la creacion de los puntos iniciales
#   los "No Inteligentes"
ctrl <- setMBOControlInfill(ctrl, crit = makeMBOInfillCritEI())

# mas configuraciones
surr.km <- makeLearner(
    "regr.km",
    predict.type= "se",
    covtype= "matern3_2",
    control= list(trace = TRUE)
)

# %% [markdown]
# Corrida de la Bayesian Optimization,  aqui se hace el trabajo pesado
# <br> por favor no se asuste con los warnings que pudieran aparecer
#
# Si corrío a medias y llegó a las iteraciones inteligentes, en el archivo binario HT.RDATA quedó lo ya procesado y es utilizado para retomar la corrida desde lo último que llegó a grabar.

# %%
# inicio la optimizacion bayesiana

if (!file.exists("HT.RDATA")) {
  bayesiana_salida <- mbo(obj.fun, learner= surr.km, control= ctrl)
} else {
  bayesiana_salida <- mboContinue("HT.RDATA") # retomo en caso que ya exista
}
# Out:
# Computing y column(s) for design. Not provided.
#
# Wed Nov 19 02:18:22 AM 2025 AUC 0.892535175540492
#
# Wed Nov 19 02:19:26 AM 2025 AUC 0.883713357344033
#
# Wed Nov 19 02:20:31 AM 2025 AUC 0.888037531313562
#
# Wed Nov 19 02:21:39 AM 2025 AUC 0.888321559500969
#
# Wed Nov 19 02:22:48 AM 2025 AUC 0.89273196530058
#
# Wed Nov 19 02:23:32 AM 2025 AUC 0.879387673478646
#
# Wed Nov 19 02:24:27 AM 2025 AUC 0.879747028692719
#
# Wed Nov 19 02:25:22 AM 2025 AUC 0.8867480802513
#
# Wed Nov 19 02:27:32 AM 2025 AUC 0.89089089895173
#
# Wed Nov 19 02:28:18 AM 2025 AUC 0.908249332793797
#
# Wed Nov 19 02:28:47 AM 2025 AUC 0.888499223913529
#
# Wed Nov 19 02:31:27 AM 2025 AUC 0.910396404703091
#
# Wed Nov 19 02:32:27 AM 2025 AUC 0.881084460890006
#
# Wed Nov 19 02:32:44 AM 2025 AUC 0.883229351838617
#
# Wed Nov 19 02:33:28 AM 2025 AUC 0.86922926191593
#
# Wed Nov 19 02:33:56 AM 2025 AUC 0.888027800873592
#
# Wed Nov 19 02:34:11 AM 2025 AUC 0.891185496410139
#
# Wed Nov 19 02:34:24 AM 2025 AUC 0.890418133782142
#
# Wed Nov 19 02:36:27 AM 2025 AUC 0.914003042607919
#
# Wed Nov 19 02:36:45 AM 2025 AUC 0.893835866938582
#
# Wed Nov 19 02:37:05 AM 2025 AUC 0.866981362516601
#
# Wed Nov 19 02:38:11 AM 2025 AUC 0.900921137132768
#
# Wed Nov 19 02:38:31 AM 2025 AUC 0.871926439215955
#
# Wed Nov 19 02:39:08 AM 2025 AUC 0.895770546830594
#
# Wed Nov 19 02:40:13 AM 2025 AUC 0.899025043468224
#
# Wed Nov 19 02:40:31 AM 2025 AUC 0.868867222442555
#
# Wed Nov 19 02:40:58 AM 2025 AUC 0.883820559949912
#
# Wed Nov 19 02:41:32 AM 2025 AUC 0.883232036097919
#
# Wed Nov 19 02:41:58 AM 2025 AUC 0.909732386058226
#
# Wed Nov 19 02:42:16 AM 2025 AUC 0.895464541270151
#
# Wed Nov 19 02:43:01 AM 2025 AUC 0.908103040661831
#
# Wed Nov 19 02:43:30 AM 2025 AUC 0.888148257009775
#
# Wed Nov 19 02:44:01 AM 2025 AUC 0.911628815255182
#
# Wed Nov 19 02:44:22 AM 2025 AUC 0.892349458350026
#
# Wed Nov 19 02:45:01 AM 2025 AUC 0.886279005938253
#
# Wed Nov 19 02:45:45 AM 2025 AUC 0.882097601010355
#
# Wed Nov 19 02:46:23 AM 2025 AUC 0.896765400434447
#
# Wed Nov 19 02:47:07 AM 2025 AUC 0.906205437101429
#
# Wed Nov 19 02:47:47 AM 2025 AUC 0.874525641051451
#
# Wed Nov 19 02:47:53 AM 2025 AUC 0.83506602271286
#
# Wed Nov 19 02:48:07 AM 2025 AUC 0.5
#
# Wed Nov 19 02:49:20 AM 2025 AUC 0.882852716705286
#
# Wed Nov 19 02:49:59 AM 2025 AUC 0.907662822136281
#
# Wed Nov 19 02:50:21 AM 2025 AUC 0.889108886307526
#
# Wed Nov 19 02:51:28 AM 2025 AUC 0.906016364586835
#
# Wed Nov 19 02:52:09 AM 2025 AUC 0.888109335249894
#
# Wed Nov 19 02:56:28 AM 2025 AUC 0.897634429383513
#
# Wed Nov 19 02:56:43 AM 2025 AUC 0.886702951141783
#
# Wed Nov 19 03:02:43 AM 2025 AUC 0.894150596341757
#
# Wed Nov 19 03:03:37 AM 2025 AUC 0.909245864059714
#
# Wed Nov 19 03:03:56 AM 2025 AUC 0.885016397469012
#
# Wed Nov 19 03:05:17 AM 2025 AUC 0.892268259506137
#
# Wed Nov 19 03:06:11 AM 2025 AUC 0.893786711440112
#
# Wed Nov 19 03:06:51 AM 2025 AUC 0.892046808113711
#
# Wed Nov 19 03:07:10 AM 2025 AUC 0.893702492804507
#
# Wed Nov 19 03:07:24 AM 2025 AUC 0.883177008782225
#
# Wed Nov 19 03:12:08 AM 2025 AUC 0.914334884164145
#
# Wed Nov 19 03:13:18 AM 2025 AUC 0.893998264626361
#
# Wed Nov 19 03:15:12 AM 2025 AUC 0.912178752879707
#
# Wed Nov 19 03:15:27 AM 2025 AUC 0.884782531377314
#
# Wed Nov 19 03:15:39 AM 2025 AUC 0.883348298078943
#
# Wed Nov 19 03:16:33 AM 2025 AUC 0.890066495813562
#
# Wed Nov 19 03:16:54 AM 2025 AUC 0.894152106237615
#
# Wed Nov 19 03:17:08 AM 2025 AUC 0.88471777362165
#
# [mbo] 0: num_leaves=4608; max_depth=12; min_child_weight=4.07; min_data_in_leaf=2093; min_gain_to_split=0.0394; lambda_l1=778; lambda_l2=308; scale_pos_weight=4.52; learning_rate=0.0667; num_iterations=1751; early_stopping_rounds=184; feature_fraction=0.55; bagging_fraction=0.537; bagging_freq=3; max_delta_step=5.23; path_smooth=3.88 : y = 0.893 : 40.3 secs : initdesign
#
# [mbo] 0: num_leaves=2341; max_depth=21; min_child_weight=6.26; min_data_in_leaf=3394; min_gain_to_split=0.0615; lambda_l1=669; lambda_l2=953; scale_pos_weight=2.32; learning_rate=0.0513; num_iterations=2232; early_stopping_rounds=336; feature_fraction=0.481; bagging_fraction=0.784; bagging_freq=3; max_delta_step=5.04; path_smooth=4.03 : y = 0.884 : 64.5 secs : initdesign
#
# [mbo] 0: num_leaves=701; max_depth=25; min_child_weight=4.36; min_data_in_leaf=3640; min_gain_to_split=0.0854; lambda_l1=802; lambda_l2=387; scale_pos_weight=3.76; learning_rate=0.0267; num_iterations=1956; early_stopping_rounds=322; feature_fraction=0.429; bagging_fraction=0.78; bagging_freq=3; max_delta_step=5.72; path_smooth=3.45 : y = 0.888 : 64.8 secs : initdesign
#
# [mbo] 0: num_leaves=1530; max_depth=11; min_child_weight=5.6; min_data_in_leaf=3276; min_gain_to_split=0.0381; lambda_l1=591; lambda_l2=759; scale_pos_weight=3.57; learning_rate=0.0289; num_iterations=898; early_stopping_rounds=237; feature_fraction=0.572; bagging_fraction=0.648; bagging_freq=1; max_delta_step=2.21; path_smooth=3.3 : y = 0.888 : 67.7 secs : initdesign
#
# [mbo] 0: num_leaves=5157; max_depth=10; min_child_weight=5.26; min_data_in_leaf=6547; min_gain_to_split=0.0503; lambda_l1=243; lambda_l2=522; scale_pos_weight=2.16; learning_rate=0.0407; num_iterations=1290; early_stopping_rounds=329; feature_fraction=0.356; bagging_fraction=0.82; bagging_freq=4; max_delta_step=7.06; path_smooth=6.15 : y = 0.893 : 69.2 secs : initdesign
#
# [mbo] 0: num_leaves=2008; max_depth=8; min_child_weight=2.95; min_data_in_leaf=4412; min_gain_to_split=0.0141; lambda_l1=646; lambda_l2=736; scale_pos_weight=2.87; learning_rate=0.0692; num_iterations=3781; early_stopping_rounds=267; feature_fraction=0.506; bagging_fraction=0.76; bagging_freq=2; max_delta_step=3.48; path_smooth=5.22 : y = 0.879 : 44.4 secs : initdesign
#
# [mbo] 0: num_leaves=6730; max_depth=26; min_child_weight=1.96; min_data_in_leaf=6499; min_gain_to_split=0.0672; lambda_l1=934; lambda_l2=573; scale_pos_weight=2.38; learning_rate=0.0715; num_iterations=3219; early_stopping_rounds=420; feature_fraction=0.406; bagging_fraction=0.638; bagging_freq=5; max_delta_step=7.81; path_smooth=0.786 : y = 0.88 : 54.3 secs : initdesign
#
# [mbo] 0: num_leaves=6942; max_depth=28; min_child_weight=3.63; min_data_in_leaf=2959; min_gain_to_split=0.0201; lambda_l1=640; lambda_l2=695; scale_pos_weight=3.73; learning_rate=0.0627; num_iterations=2500; early_stopping_rounds=464; feature_fraction=0.604; bagging_fraction=0.772; bagging_freq=1; max_delta_step=2.5; path_smooth=1.71 : y = 0.887 : 55.7 secs : initdesign
#
# [mbo] 0: num_leaves=4714; max_depth=6; min_child_weight=8.33; min_data_in_leaf=5825; min_gain_to_split=0.0757; lambda_l1=568; lambda_l2=365; scale_pos_weight=4.79; learning_rate=0.0657; num_iterations=1517; early_stopping_rounds=300; feature_fraction=0.197; bagging_fraction=0.735; bagging_freq=1; max_delta_step=4.82; path_smooth=6.38 : y = 0.891 : 130.0 secs : initdesign
#
# [mbo] 0: num_leaves=3544; max_depth=19; min_child_weight=1.76; min_data_in_leaf=3870; min_gain_to_split=0.0475; lambda_l1=130; lambda_l2=92.5; scale_pos_weight=2.52; learning_rate=0.0726; num_iterations=2840; early_stopping_rounds=178; feature_fraction=0.405; bagging_fraction=0.904; bagging_freq=5; max_delta_step=5.86; path_smooth=8.5 : y = 0.908 : 46.2 secs : initdesign
#
# [mbo] 0: num_leaves=3435; max_depth=21; min_child_weight=7.95; min_data_in_leaf=1677; min_gain_to_split=0.018; lambda_l1=607; lambda_l2=281; scale_pos_weight=3.42; learning_rate=0.0149; num_iterations=1170; early_stopping_rounds=113; feature_fraction=0.852; bagging_fraction=0.519; bagging_freq=4; max_delta_step=7.64; path_smooth=6.45 : y = 0.888 : 28.6 secs : initdesign
#
# [mbo] 0: num_leaves=3735; max_depth=22; min_child_weight=5.63; min_data_in_leaf=5459; min_gain_to_split=0.00378; lambda_l1=121; lambda_l2=904; scale_pos_weight=2.99; learning_rate=0.0508; num_iterations=3768; early_stopping_rounds=136; feature_fraction=0.309; bagging_fraction=0.677; bagging_freq=3; max_delta_step=5.47; path_smooth=7.05 : y = 0.91 : 159.7 secs : initdesign
#
# [mbo] 0: num_leaves=5338; max_depth=19; min_child_weight=1.49; min_data_in_leaf=4181; min_gain_to_split=0.0434; lambda_l1=711; lambda_l2=854; scale_pos_weight=2.21; learning_rate=0.0454; num_iterations=2020; early_stopping_rounds=395; feature_fraction=0.378; bagging_fraction=0.848; bagging_freq=5; max_delta_step=2.68; path_smooth=6.86 : y = 0.881 : 59.8 secs : initdesign
#
# [mbo] 0: num_leaves=1602; max_depth=24; min_child_weight=0.0998; min_data_in_leaf=7184; min_gain_to_split=0.0451; lambda_l1=348; lambda_l2=348; scale_pos_weight=1.86; learning_rate=0.0604; num_iterations=2732; early_stopping_rounds=224; feature_fraction=0.687; bagging_fraction=0.81; bagging_freq=2; max_delta_step=2.55; path_smooth=1.42 : y = 0.883 : 17.0 secs : initdesign
#
# [mbo] 0: num_leaves=5060; max_depth=5; min_child_weight=5.9; min_data_in_leaf=5005; min_gain_to_split=0.0642; lambda_l1=719; lambda_l2=223; scale_pos_weight=1.88; learning_rate=0.0359; num_iterations=4493; early_stopping_rounds=284; feature_fraction=0.516; bagging_fraction=0.874; bagging_freq=1; max_delta_step=4.1; path_smooth=7.55 : y = 0.869 : 44.6 secs : initdesign
#
# [mbo] 0: num_leaves=7143; max_depth=26; min_child_weight=3.77; min_data_in_leaf=3771; min_gain_to_split=0.0301; lambda_l1=505; lambda_l2=94.7; scale_pos_weight=1.99; learning_rate=0.044; num_iterations=2249; early_stopping_rounds=226; feature_fraction=0.0881; bagging_fraction=0.819; bagging_freq=2; max_delta_step=4.06; path_smooth=1.16 : y = 0.888 : 27.7 secs : initdesign
#
# [mbo] 0: num_leaves=1275; max_depth=17; min_child_weight=4.94; min_data_in_leaf=773; min_gain_to_split=0.0785; lambda_l1=325; lambda_l2=172; scale_pos_weight=2.88; learning_rate=0.0573; num_iterations=4558; early_stopping_rounds=412; feature_fraction=0.74; bagging_fraction=0.564; bagging_freq=3; max_delta_step=6.46; path_smooth=2.73 : y = 0.891 : 14.8 secs : initdesign
#
# [mbo] 0: num_leaves=1811; max_depth=21; min_child_weight=2.04; min_data_in_leaf=3188; min_gain_to_split=0.063; lambda_l1=857; lambda_l2=620; scale_pos_weight=4.04; learning_rate=0.0793; num_iterations=2108; early_stopping_rounds=274; feature_fraction=0.759; bagging_fraction=0.605; bagging_freq=1; max_delta_step=4.85; path_smooth=4.22 : y = 0.89 : 13.7 secs : initdesign
#
# [mbo] 0: num_leaves=2570; max_depth=20; min_child_weight=3.27; min_data_in_leaf=7456; min_gain_to_split=0.0161; lambda_l1=63; lambda_l2=319; scale_pos_weight=4.2; learning_rate=0.0598; num_iterations=4294; early_stopping_rounds=245; feature_fraction=0.874; bagging_fraction=0.893; bagging_freq=3; max_delta_step=1.65; path_smooth=8.22 : y = 0.914 : 122.1 secs : initdesign
#
# [mbo] 0: num_leaves=5457; max_depth=28; min_child_weight=6.42; min_data_in_leaf=2900; min_gain_to_split=0.0555; lambda_l1=699; lambda_l2=873; scale_pos_weight=3.67; learning_rate=0.0788; num_iterations=640; early_stopping_rounds=171; feature_fraction=0.146; bagging_fraction=0.95; bagging_freq=2; max_delta_step=3.18; path_smooth=7.43 : y = 0.894 : 18.7 secs : initdesign
#
# [mbo] 0: num_leaves=5822; max_depth=20; min_child_weight=6.6; min_data_in_leaf=7019; min_gain_to_split=0.0806; lambda_l1=466; lambda_l2=888; scale_pos_weight=2; learning_rate=0.0303; num_iterations=3560; early_stopping_rounds=153; feature_fraction=0.791; bagging_fraction=0.561; bagging_freq=3; max_delta_step=0.309; path_smooth=5 : y = 0.867 : 20.2 secs : initdesign
#
# [mbo] 0: num_leaves=4931; max_depth=25; min_child_weight=1.25; min_data_in_leaf=5615; min_gain_to_split=0.0822; lambda_l1=404; lambda_l2=628; scale_pos_weight=4.98; learning_rate=0.0867; num_iterations=2569; early_stopping_rounds=311; feature_fraction=0.478; bagging_fraction=0.976; bagging_freq=3; max_delta_step=4.35; path_smooth=2.91 : y = 0.901 : 66.0 secs : initdesign
#
# [mbo] 0: num_leaves=2929; max_depth=19; min_child_weight=7.99; min_data_in_leaf=4284; min_gain_to_split=0.00294; lambda_l1=276; lambda_l2=514; scale_pos_weight=1.63; learning_rate=0.0935; num_iterations=3450; early_stopping_rounds=466; feature_fraction=0.948; bagging_fraction=0.511; bagging_freq=2; max_delta_step=6.13; path_smooth=5.84 : y = 0.872 : 19.7 secs : initdesign
#
# [mbo] 0: num_leaves=4337; max_depth=8; min_child_weight=6.91; min_data_in_leaf=1955; min_gain_to_split=0.0734; lambda_l1=623; lambda_l2=938; scale_pos_weight=4.43; learning_rate=0.0387; num_iterations=1790; early_stopping_rounds=384; feature_fraction=0.82; bagging_fraction=0.944; bagging_freq=4; max_delta_step=8.71; path_smooth=7.86 : y = 0.896 : 36.7 secs : initdesign
#
# [mbo] 0: num_leaves=1018; max_depth=10; min_child_weight=4.75; min_data_in_leaf=4808; min_gain_to_split=0.0411; lambda_l1=255; lambda_l2=921; scale_pos_weight=4.34; learning_rate=0.0487; num_iterations=1633; early_stopping_rounds=103; feature_fraction=0.459; bagging_fraction=0.524; bagging_freq=4; max_delta_step=7.19; path_smooth=3.68 : y = 0.899 : 65.5 secs : initdesign
#
# [mbo] 0: num_leaves=3933; max_depth=15; min_child_weight=0.561; min_data_in_leaf=7618; min_gain_to_split=0.0659; lambda_l1=977; lambda_l2=971; scale_pos_weight=1.6; learning_rate=0.0859; num_iterations=439; early_stopping_rounds=379; feature_fraction=0.692; bagging_fraction=0.831; bagging_freq=2; max_delta_step=6.9; path_smooth=8.84 : y = 0.869 : 18.0 secs : initdesign
#
# [mbo] 0: num_leaves=4106; max_depth=18; min_child_weight=9.68; min_data_in_leaf=1653; min_gain_to_split=0.0231; lambda_l1=367; lambda_l2=792; scale_pos_weight=1.41; learning_rate=0.0344; num_iterations=1211; early_stopping_rounds=248; feature_fraction=0.258; bagging_fraction=0.702; bagging_freq=1; max_delta_step=6.64; path_smooth=1.01 : y = 0.884 : 27.1 secs : initdesign
#
# [mbo] 0: num_leaves=1669; max_depth=27; min_child_weight=1.69; min_data_in_leaf=7774; min_gain_to_split=0.0218; lambda_l1=830; lambda_l2=721; scale_pos_weight=2.69; learning_rate=0.0369; num_iterations=3533; early_stopping_rounds=156; feature_fraction=0.0501; bagging_fraction=0.79; bagging_freq=3; max_delta_step=2.1; path_smooth=6.01 : y = 0.883 : 33.3 secs : initdesign
#
# [mbo] 0: num_leaves=2273; max_depth=22; min_child_weight=0.236; min_data_in_leaf=443; min_gain_to_split=0.0696; lambda_l1=160; lambda_l2=152; scale_pos_weight=3.56; learning_rate=0.0815; num_iterations=394; early_stopping_rounds=340; feature_fraction=0.904; bagging_fraction=0.92; bagging_freq=1; max_delta_step=1.08; path_smooth=7.3 : y = 0.91 : 26.8 secs : initdesign
#
# [mbo] 0: num_leaves=7538; max_depth=11; min_child_weight=3.3; min_data_in_leaf=6721; min_gain_to_split=0.0539; lambda_l1=342; lambda_l2=210; scale_pos_weight=4.12; learning_rate=0.0477; num_iterations=789; early_stopping_rounds=215; feature_fraction=0.661; bagging_fraction=0.548; bagging_freq=5; max_delta_step=3.6; path_smooth=5.37 : y = 0.895 : 17.6 secs : initdesign
#
# [mbo] 0: num_leaves=6902; max_depth=3; min_child_weight=7.57; min_data_in_leaf=4595; min_gain_to_split=0.0977; lambda_l1=87.3; lambda_l2=811; scale_pos_weight=2.25; learning_rate=0.0762; num_iterations=4743; early_stopping_rounds=358; feature_fraction=0.646; bagging_fraction=0.686; bagging_freq=0; max_delta_step=3.34; path_smooth=0.6 : y = 0.908 : 45.4 secs : initdesign
#
# [mbo] 0: num_leaves=4398; max_depth=3; min_child_weight=0.866; min_data_in_leaf=320; min_gain_to_split=0.0329; lambda_l1=750; lambda_l2=408; scale_pos_weight=3.36; learning_rate=0.0555; num_iterations=2375; early_stopping_rounds=193; feature_fraction=0.622; bagging_fraction=0.955; bagging_freq=1; max_delta_step=4.68; path_smooth=0.454 : y = 0.888 : 28.7 secs : initdesign
#
# [mbo] 0: num_leaves=3975; max_depth=5; min_child_weight=1.04; min_data_in_leaf=1802; min_gain_to_split=0.0839; lambda_l1=32.3; lambda_l2=603; scale_pos_weight=2.48; learning_rate=0.0949; num_iterations=298; early_stopping_rounds=200; feature_fraction=0.231; bagging_fraction=0.693; bagging_freq=3; max_delta_step=0.557; path_smooth=3.1 : y = 0.912 : 30.9 secs : initdesign
#
# [mbo] 0: num_leaves=3314; max_depth=13; min_child_weight=6.84; min_data_in_leaf=915; min_gain_to_split=0.0887; lambda_l1=881; lambda_l2=552; scale_pos_weight=3.92; learning_rate=0.0835; num_iterations=972; early_stopping_rounds=145; feature_fraction=0.205; bagging_fraction=0.709; bagging_freq=4; max_delta_step=8.92; path_smooth=9.38 : y = 0.892 : 21.3 secs : initdesign
#
# [mbo] 0: num_leaves=7400; max_depth=8; min_child_weight=3.08; min_data_in_leaf=7980; min_gain_to_split=0.00518; lambda_l1=917; lambda_l2=498; scale_pos_weight=4.3; learning_rate=0.0551; num_iterations=3919; early_stopping_rounds=391; feature_fraction=0.171; bagging_fraction=0.854; bagging_freq=0; max_delta_step=8.22; path_smooth=4.64 : y = 0.886 : 38.9 secs : initdesign
#
# [mbo] 0: num_leaves=779; max_depth=17; min_child_weight=2.49; min_data_in_leaf=6260; min_gain_to_split=0.0499; lambda_l1=686; lambda_l2=704; scale_pos_weight=3.13; learning_rate=0.0111; num_iterations=3098; early_stopping_rounds=477; feature_fraction=0.713; bagging_fraction=0.574; bagging_freq=2; max_delta_step=1.94; path_smooth=8.42 : y = 0.882 : 43.8 secs : initdesign
#
# [mbo] 0: num_leaves=7730; max_depth=4; min_child_weight=4.53; min_data_in_leaf=5268; min_gain_to_split=0.029; lambda_l1=389; lambda_l2=247; scale_pos_weight=3.22; learning_rate=0.0191; num_iterations=4433; early_stopping_rounds=91; feature_fraction=0.807; bagging_fraction=0.891; bagging_freq=5; max_delta_step=9.67; path_smooth=9.12 : y = 0.897 : 37.9 secs : initdesign
#
# [mbo] 0: num_leaves=624; max_depth=29; min_child_weight=6.19; min_data_in_leaf=2751; min_gain_to_split=0.0589; lambda_l1=185; lambda_l2=593; scale_pos_weight=3.85; learning_rate=0.0984; num_iterations=2987; early_stopping_rounds=128; feature_fraction=0.299; bagging_fraction=0.799; bagging_freq=0; max_delta_step=5.58; path_smooth=2 : y = 0.906 : 43.5 secs : initdesign
#
# [mbo] 0: num_leaves=7607; max_depth=23; min_child_weight=9.29; min_data_in_leaf=1069; min_gain_to_split=0.00737; lambda_l1=286; lambda_l2=543; scale_pos_weight=1.22; learning_rate=0.0432; num_iterations=4183; early_stopping_rounds=121; feature_fraction=0.568; bagging_fraction=0.724; bagging_freq=4; max_delta_step=3.11; path_smooth=6.97 : y = 0.875 : 40.7 secs : initdesign
#
# [mbo] 0: num_leaves=492; max_depth=28; min_child_weight=7.22; min_data_in_leaf=6839; min_gain_to_split=0.0364; lambda_l1=557; lambda_l2=437; scale_pos_weight=1.09; learning_rate=0.0201; num_iterations=1462; early_stopping_rounds=76; feature_fraction=0.913; bagging_fraction=0.933; bagging_freq=2; max_delta_step=2.91; path_smooth=4.95 : y = 0.835 : 5.4 secs : initdesign
#
# [mbo] 0: num_leaves=6395; max_depth=15; min_child_weight=7.17; min_data_in_leaf=672; min_gain_to_split=0.0526; lambda_l1=871; lambda_l2=48.8; scale_pos_weight=1.05; learning_rate=0.0842; num_iterations=2688; early_stopping_rounds=406; feature_fraction=0.992; bagging_fraction=0.62; bagging_freq=2; max_delta_step=1.31; path_smooth=7.98 : y = 0.5 : 14.4 secs : initdesign
#
# [mbo] 0: num_leaves=5757; max_depth=24; min_child_weight=6.01; min_data_in_leaf=2634; min_gain_to_split=0.0956; lambda_l1=302; lambda_l2=41.1; scale_pos_weight=1.36; learning_rate=0.0277; num_iterations=4835; early_stopping_rounds=453; feature_fraction=0.318; bagging_fraction=0.86; bagging_freq=2; max_delta_step=9.19; path_smooth=2.59 : y = 0.883 : 72.5 secs : initdesign
#
# [mbo] 0: num_leaves=1054; max_depth=3; min_child_weight=9.93; min_data_in_leaf=5958; min_gain_to_split=0.0133; lambda_l1=19.8; lambda_l2=191; scale_pos_weight=2.66; learning_rate=0.0176; num_iterations=585; early_stopping_rounds=306; feature_fraction=0.639; bagging_fraction=0.922; bagging_freq=4; max_delta_step=7.87; path_smooth=3.21 : y = 0.908 : 39.2 secs : initdesign
#
# [mbo] 0: num_leaves=6408; max_depth=26; min_child_weight=5.4; min_data_in_leaf=7089; min_gain_to_split=0.0866; lambda_l1=945; lambda_l2=23.2; scale_pos_weight=3.03; learning_rate=0.053; num_iterations=1056; early_stopping_rounds=426; feature_fraction=0.982; bagging_fraction=1; bagging_freq=0; max_delta_step=3.78; path_smooth=4.71 : y = 0.889 : 22.5 secs : initdesign
#
# [mbo] 0: num_leaves=5904; max_depth=30; min_child_weight=5.05; min_data_in_leaf=8146; min_gain_to_split=0.0317; lambda_l1=208; lambda_l2=9.79; scale_pos_weight=3.27; learning_rate=0.04; num_iterations=2899; early_stopping_rounds=106; feature_fraction=0.849; bagging_fraction=0.504; bagging_freq=1; max_delta_step=9.93; path_smooth=2.09 : y = 0.906 : 66.7 secs : initdesign
#
# [mbo] 0: num_leaves=214; max_depth=14; min_child_weight=7.37; min_data_in_leaf=2280; min_gain_to_split=0.0911; lambda_l1=789; lambda_l2=819; scale_pos_weight=2.58; learning_rate=0.0637; num_iterations=2408; early_stopping_rounds=96; feature_fraction=0.598; bagging_fraction=0.666; bagging_freq=4; max_delta_step=0.113; path_smooth=0.728 : y = 0.888 : 40.7 secs : initdesign
#
# [mbo] 0: num_leaves=3106; max_depth=6; min_child_weight=2.79; min_data_in_leaf=136; min_gain_to_split=0.0565; lambda_l1=490; lambda_l2=117; scale_pos_weight=4.5; learning_rate=0.0908; num_iterations=4658; early_stopping_rounds=281; feature_fraction=0.345; bagging_fraction=0.625; bagging_freq=1; max_delta_step=0.39; path_smooth=7.71 : y = 0.898 : 259.6 secs : initdesign
#
# [mbo] 0: num_leaves=5507; max_depth=6; min_child_weight=3.99; min_data_in_leaf=7350; min_gain_to_split=0.0607; lambda_l1=226; lambda_l2=677; scale_pos_weight=1.16; learning_rate=0.0883; num_iterations=4959; early_stopping_rounds=164; feature_fraction=0.123; bagging_fraction=0.967; bagging_freq=0; max_delta_step=8.89; path_smooth=5.48 : y = 0.887 : 14.6 secs : initdesign
#
# [mbo] 0: num_leaves=7834; max_depth=29; min_child_weight=9.12; min_data_in_leaf=4952; min_gain_to_split=0.0357; lambda_l1=543; lambda_l2=924; scale_pos_weight=4.73; learning_rate=0.099; num_iterations=3960; early_stopping_rounds=367; feature_fraction=0.276; bagging_fraction=0.6; bagging_freq=1; max_delta_step=6.27; path_smooth=8.69 : y = 0.894 : 359.8 secs : initdesign
#
# [mbo] 0: num_leaves=2693; max_depth=13; min_child_weight=0.447; min_data_in_leaf=5727; min_gain_to_split=0.0945; lambda_l1=60.5; lambda_l2=667; scale_pos_weight=4.9; learning_rate=0.0227; num_iterations=519; early_stopping_rounds=483; feature_fraction=0.721; bagging_fraction=0.911; bagging_freq=0; max_delta_step=8.04; path_smooth=4.46 : y = 0.909 : 54.3 secs : initdesign
#
# [mbo] 0: num_leaves=7222; max_depth=5; min_child_weight=8.55; min_data_in_leaf=30; min_gain_to_split=0.027; lambda_l1=992; lambda_l2=778; scale_pos_weight=2.78; learning_rate=0.077; num_iterations=4133; early_stopping_rounds=448; feature_fraction=0.768; bagging_fraction=0.652; bagging_freq=5; max_delta_step=9.35; path_smooth=1.33 : y = 0.885 : 18.8 secs : initdesign
#
# [mbo] 0: num_leaves=328; max_depth=16; min_child_weight=7.8; min_data_in_leaf=2356; min_gain_to_split=0.00889; lambda_l1=145; lambda_l2=128; scale_pos_weight=1.31; learning_rate=0.0919; num_iterations=3043; early_stopping_rounds=79; feature_fraction=0.132; bagging_fraction=0.758; bagging_freq=5; max_delta_step=8.45; path_smooth=5.64 : y = 0.892 : 80.9 secs : initdesign
#
# [mbo] 0: num_leaves=2090; max_depth=16; min_child_weight=9.84; min_data_in_leaf=2536; min_gain_to_split=0.00137; lambda_l1=901; lambda_l2=479; scale_pos_weight=4.16; learning_rate=0.0165; num_iterations=1882; early_stopping_rounds=261; feature_fraction=0.264; bagging_fraction=0.983; bagging_freq=0; max_delta_step=1.75; path_smooth=4.12 : y = 0.894 : 54.1 secs : initdesign
#
# [mbo] 0: num_leaves=4761; max_depth=9; min_child_weight=2.29; min_data_in_leaf=1519; min_gain_to_split=0.0108; lambda_l1=443; lambda_l2=1e+03; scale_pos_weight=3.5; learning_rate=0.0125; num_iterations=1354; early_stopping_rounds=66; feature_fraction=0.53; bagging_fraction=0.749; bagging_freq=5; max_delta_step=1.25; path_smooth=9 : y = 0.892 : 40.7 secs : initdesign
#
# [mbo] 0: num_leaves=6172; max_depth=30; min_child_weight=1.31; min_data_in_leaf=581; min_gain_to_split=0.024; lambda_l1=825; lambda_l2=393; scale_pos_weight=3.96; learning_rate=0.0684; num_iterations=3351; early_stopping_rounds=295; feature_fraction=0.892; bagging_fraction=0.843; bagging_freq=4; max_delta_step=8.33; path_smooth=9.88 : y = 0.894 : 18.1 secs : initdesign
#
# [mbo] 0: num_leaves=6601; max_depth=17; min_child_weight=8.97; min_data_in_leaf=5207; min_gain_to_split=0.0925; lambda_l1=197; lambda_l2=341; scale_pos_weight=1.51; learning_rate=0.0102; num_iterations=182; early_stopping_rounds=435; feature_fraction=0.106; bagging_fraction=0.611; bagging_freq=5; max_delta_step=9.49; path_smooth=9.79 : y = 0.883 : 14.7 secs : initdesign
#
# [mbo] 0: num_leaves=3069; max_depth=11; min_child_weight=0.755; min_data_in_leaf=3570; min_gain_to_split=0.0257; lambda_l1=3.38; lambda_l2=466; scale_pos_weight=1.74; learning_rate=0.0251; num_iterations=4860; early_stopping_rounds=346; feature_fraction=0.966; bagging_fraction=0.539; bagging_freq=0; max_delta_step=6.86; path_smooth=2.31 : y = 0.914 : 283.2 secs : initdesign
#
# [mbo] 0: num_leaves=7947; max_depth=12; min_child_weight=9.47; min_data_in_leaf=3990; min_gain_to_split=0.0996; lambda_l1=962; lambda_l2=253; scale_pos_weight=4.84; learning_rate=0.0231; num_iterations=754; early_stopping_rounds=363; feature_fraction=0.374; bagging_fraction=0.727; bagging_freq=5; max_delta_step=0.829; path_smooth=0.103 : y = 0.894 : 70.7 secs : initdesign
#
# [mbo] 0: num_leaves=2510; max_depth=27; min_child_weight=8.23; min_data_in_leaf=7863; min_gain_to_split=0.0463; lambda_l1=97.2; lambda_l2=71.9; scale_pos_weight=4.61; learning_rate=0.0321; num_iterations=4353; early_stopping_rounds=440; feature_fraction=0.221; bagging_fraction=0.582; bagging_freq=0; max_delta_step=0.704; path_smooth=9.28 : y = 0.912 : 113.5 secs : initdesign
#
# [mbo] 0: num_leaves=6026; max_depth=14; min_child_weight=4.65; min_data_in_leaf=6373; min_gain_to_split=0.0894; lambda_l1=437; lambda_l2=840; scale_pos_weight=2.11; learning_rate=0.0962; num_iterations=3630; early_stopping_rounds=206; feature_fraction=0.939; bagging_fraction=0.989; bagging_freq=4; max_delta_step=1.43; path_smooth=6.58 : y = 0.885 : 15.8 secs : initdesign
#
# [mbo] 0: num_leaves=8185; max_depth=9; min_child_weight=2.59; min_data_in_leaf=6079; min_gain_to_split=0.0748; lambda_l1=518; lambda_l2=169; scale_pos_weight=1.78; learning_rate=0.00537; num_iterations=1586; early_stopping_rounds=51; feature_fraction=0.0678; bagging_fraction=0.589; bagging_freq=1; max_delta_step=5.98; path_smooth=2.42 : y = 0.883 : 11.5 secs : initdesign
#
# [mbo] 0: num_leaves=24; max_depth=7; min_child_weight=8.74; min_data_in_leaf=1274; min_gain_to_split=0.0718; lambda_l1=743; lambda_l2=281; scale_pos_weight=1.47; learning_rate=0.00818; num_iterations=4019; early_stopping_rounds=494; feature_fraction=0.159; bagging_fraction=0.664; bagging_freq=0; max_delta_step=7.39; path_smooth=9.62 : y = 0.89 : 54.5 secs : initdesign
#
# [mbo] 0: num_leaves=3689; max_depth=15; min_child_weight=8.8; min_data_in_leaf=1324; min_gain_to_split=0.0771; lambda_l1=416; lambda_l2=644; scale_pos_weight=4.68; learning_rate=0.0074; num_iterations=3306; early_stopping_rounds=61; feature_fraction=0.834; bagging_fraction=0.876; bagging_freq=5; max_delta_step=9.7; path_smooth=0.174 : y = 0.894 : 20.1 secs : initdesign
#
# [mbo] 0: num_leaves=1368; max_depth=23; min_child_weight=3.54; min_data_in_leaf=4705; min_gain_to_split=0.0117; lambda_l1=469; lambda_l2=446; scale_pos_weight=3.07; learning_rate=0.0745; num_iterations=119; early_stopping_rounds=490; feature_fraction=0.44; bagging_fraction=0.713; bagging_freq=4; max_delta_step=4.43; path_smooth=1.76 : y = 0.885 : 14.7 secs : initdesign
#
# Saved the current state after iteration 1 in the file HT.RDATA.
#
# Wed Nov 19 03:26:23 AM 2025 AUC 0.921549837635866
#
# [mbo] 1: num_leaves=5253; max_depth=26; min_child_weight=8.17; min_data_in_leaf=3262; min_gain_to_split=0.00742; lambda_l1=8.18; lambda_l2=668; scale_pos_weight=2.4; learning_rate=0.0418; num_iterations=4267; early_stopping_rounds=139; feature_fraction=0.746; bagging_fraction=0.991; bagging_freq=1; max_delta_step=6.65; path_smooth=6.14 : y = 0.922 : 550.7 secs : infill_ei
#
# Wed Nov 19 03:31:38 AM 2025 AUC 0.915585077934113
#
# [mbo] 2: num_leaves=1091; max_depth=23; min_child_weight=7.09; min_data_in_leaf=3984; min_gain_to_split=0.00338; lambda_l1=1.85; lambda_l2=667; scale_pos_weight=1.93; learning_rate=0.0619; num_iterations=4289; early_stopping_rounds=334; feature_fraction=0.572; bagging_fraction=0.634; bagging_freq=3; max_delta_step=9.12; path_smooth=2.05 : y = 0.916 : 313.4 secs : infill_ei
#
# Saved the current state after iteration 3 in the file HT.RDATA.
#
# Wed Nov 19 03:38:31 AM 2025 AUC 0.911849931115196
#
# [mbo] 3: num_leaves=3420; max_depth=17; min_child_weight=7.32; min_data_in_leaf=4207; min_gain_to_split=0.0328; lambda_l1=53.7; lambda_l2=310; scale_pos_weight=2.11; learning_rate=0.00925; num_iterations=4999; early_stopping_rounds=289; feature_fraction=0.362; bagging_fraction=0.881; bagging_freq=0; max_delta_step=7.39; path_smooth=6.03 : y = 0.912 : 410.1 secs : infill_ei
#
# Wed Nov 19 03:40:42 AM 2025 AUC 0.917489224376564
#
# [mbo] 4: num_leaves=4056; max_depth=23; min_child_weight=5.14; min_data_in_leaf=3884; min_gain_to_split=0.0583; lambda_l1=2.61; lambda_l2=223; scale_pos_weight=3.69; learning_rate=0.0711; num_iterations=3083; early_stopping_rounds=340; feature_fraction=0.382; bagging_fraction=0.791; bagging_freq=1; max_delta_step=6.31; path_smooth=3.07 : y = 0.917 : 129.1 secs : infill_ei
#
# Wed Nov 19 03:45:34 AM 2025 AUC 0.917606996253445
#
# [mbo] 5: num_leaves=3672; max_depth=21; min_child_weight=0.94; min_data_in_leaf=5196; min_gain_to_split=0.0612; lambda_l1=0.462; lambda_l2=807; scale_pos_weight=3.14; learning_rate=0.0589; num_iterations=2815; early_stopping_rounds=248; feature_fraction=0.944; bagging_fraction=0.88; bagging_freq=0; max_delta_step=7.42; path_smooth=6.49 : y = 0.918 : 290.2 secs : infill_ei
#
# Saved the current state after iteration 6 in the file HT.RDATA.
#
# Wed Nov 19 03:47:45 AM 2025 AUC 0.918684726363251
#
# [mbo] 6: num_leaves=4879; max_depth=23; min_child_weight=8.75; min_data_in_leaf=2496; min_gain_to_split=0.0872; lambda_l1=6.29; lambda_l2=664; scale_pos_weight=3.16; learning_rate=0.0842; num_iterations=3635; early_stopping_rounds=189; feature_fraction=0.685; bagging_fraction=0.899; bagging_freq=4; max_delta_step=5.01; path_smooth=4.47 : y = 0.919 : 129.0 secs : infill_ei
#
# Wed Nov 19 03:51:00 AM 2025 AUC 0.915194518205653
#
# [mbo] 7: num_leaves=4396; max_depth=24; min_child_weight=8.89; min_data_in_leaf=1656; min_gain_to_split=0.0611; lambda_l1=14.3; lambda_l2=743; scale_pos_weight=2.07; learning_rate=0.0314; num_iterations=4808; early_stopping_rounds=68; feature_fraction=0.218; bagging_fraction=0.616; bagging_freq=4; max_delta_step=5.29; path_smooth=6.97 : y = 0.915 : 193.9 secs : infill_ei
#
# Wed Nov 19 03:56:47 AM 2025 AUC 0.916425251095681
#
# [mbo] 8: num_leaves=3004; max_depth=14; min_child_weight=6.73; min_data_in_leaf=3186; min_gain_to_split=0.0104; lambda_l1=5.3; lambda_l2=616; scale_pos_weight=2.86; learning_rate=0.0155; num_iterations=4111; early_stopping_rounds=225; feature_fraction=0.869; bagging_fraction=0.626; bagging_freq=3; max_delta_step=7.35; path_smooth=0.803 : y = 0.916 : 345.2 secs : infill_ei
#
# Saved the current state after iteration 9 in the file HT.RDATA.
#
# Wed Nov 19 03:58:16 AM 2025 AUC 0.916393039984056
#
# [mbo] 9: num_leaves=3239; max_depth=30; min_child_weight=7.74; min_data_in_leaf=5504; min_gain_to_split=0.0767; lambda_l1=34.2; lambda_l2=213; scale_pos_weight=4.12; learning_rate=0.0736; num_iterations=1168; early_stopping_rounds=284; feature_fraction=0.78; bagging_fraction=0.883; bagging_freq=0; max_delta_step=6.15; path_smooth=8.91 : y = 0.916 : 87.2 secs : infill_ei
#
# Wed Nov 19 04:00:47 AM 2025 AUC 0.918616277751047
#
# [mbo] 10: num_leaves=5610; max_depth=21; min_child_weight=6.32; min_data_in_leaf=1648; min_gain_to_split=0.00531; lambda_l1=25.9; lambda_l2=487; scale_pos_weight=2.62; learning_rate=0.0477; num_iterations=3596; early_stopping_rounds=158; feature_fraction=0.13; bagging_fraction=0.909; bagging_freq=5; max_delta_step=4.04; path_smooth=3.49 : y = 0.919 : 150.0 secs : infill_ei
#
# Wed Nov 19 04:04:42 AM 2025 AUC 0.923701942531351
#
# [mbo] 11: num_leaves=4908; max_depth=25; min_child_weight=1.19; min_data_in_leaf=2472; min_gain_to_split=0.0539; lambda_l1=6.03; lambda_l2=382; scale_pos_weight=4.26; learning_rate=0.0525; num_iterations=3746; early_stopping_rounds=242; feature_fraction=0.698; bagging_fraction=0.888; bagging_freq=0; max_delta_step=4.67; path_smooth=8.91 : y = 0.924 : 233.5 secs : infill_ei
#
# Wed Nov 19 04:10:12 AM 2025 AUC 0.924864562341587
#
# [mbo] 12: num_leaves=5568; max_depth=25; min_child_weight=1.85; min_data_in_leaf=415; min_gain_to_split=0.0102; lambda_l1=0.429; lambda_l2=576; scale_pos_weight=3.47; learning_rate=0.0651; num_iterations=3560; early_stopping_rounds=274; feature_fraction=0.635; bagging_fraction=0.834; bagging_freq=2; max_delta_step=9.36; path_smooth=7.12 : y = 0.925 : 327.5 secs : infill_ei
#
# Saved the current state after iteration 13 in the file HT.RDATA.
#
# Wed Nov 19 04:16:10 AM 2025 AUC 0.917458355394589
#
# [mbo] 13: num_leaves=5498; max_depth=26; min_child_weight=1.85; min_data_in_leaf=1686; min_gain_to_split=0.0581; lambda_l1=16.7; lambda_l2=598; scale_pos_weight=2.76; learning_rate=0.0304; num_iterations=2161; early_stopping_rounds=143; feature_fraction=0.577; bagging_fraction=0.776; bagging_freq=1; max_delta_step=6.07; path_smooth=2.38 : y = 0.917 : 355.2 secs : infill_ei
#
# Wed Nov 19 04:18:42 AM 2025 AUC 0.920595583453957
#
# [mbo] 14: num_leaves=4708; max_depth=18; min_child_weight=5.42; min_data_in_leaf=2155; min_gain_to_split=0.000748; lambda_l1=4.08; lambda_l2=981; scale_pos_weight=2.25; learning_rate=0.0985; num_iterations=4699; early_stopping_rounds=78; feature_fraction=0.668; bagging_fraction=0.816; bagging_freq=5; max_delta_step=6.86; path_smooth=5.17 : y = 0.921 : 150.0 secs : infill_ei
#
# Wed Nov 19 04:25:02 AM 2025 AUC 0.922925520528209
#
# [mbo] 15: num_leaves=1587; max_depth=23; min_child_weight=1.39; min_data_in_leaf=2331; min_gain_to_split=0.00183; lambda_l1=0.363; lambda_l2=314; scale_pos_weight=3.59; learning_rate=0.0374; num_iterations=4666; early_stopping_rounds=409; feature_fraction=0.777; bagging_fraction=0.613; bagging_freq=0; max_delta_step=7.06; path_smooth=8.4 : y = 0.923 : 379.2 secs : infill_ei
#
# Saved the current state after iteration 16 in the file HT.RDATA.
#
# Wed Nov 19 04:27:06 AM 2025 AUC 0.914078872933204
#
# [mbo] 16: num_leaves=5118; max_depth=25; min_child_weight=7.67; min_data_in_leaf=5560; min_gain_to_split=0.0281; lambda_l1=33.8; lambda_l2=565; scale_pos_weight=3.73; learning_rate=0.0855; num_iterations=4355; early_stopping_rounds=406; feature_fraction=0.919; bagging_fraction=0.555; bagging_freq=0; max_delta_step=6.74; path_smooth=4.78 : y = 0.914 : 121.5 secs : infill_ei
#
# Wed Nov 19 04:29:29 AM 2025 AUC 0.923363054794456
#
# [mbo] 17: num_leaves=2632; max_depth=18; min_child_weight=0.314; min_data_in_leaf=1717; min_gain_to_split=0.0148; lambda_l1=6.01; lambda_l2=344; scale_pos_weight=3.98; learning_rate=0.0663; num_iterations=1140; early_stopping_rounds=173; feature_fraction=0.725; bagging_fraction=0.83; bagging_freq=3; max_delta_step=7.8; path_smooth=7.53 : y = 0.923 : 142.2 secs : infill_ei
#
# Wed Nov 19 04:30:01 AM 2025 AUC 0.914094978489017
#
# [mbo] 18: num_leaves=3739; max_depth=25; min_child_weight=2.81; min_data_in_leaf=2413; min_gain_to_split=0.00309; lambda_l1=10.5; lambda_l2=393; scale_pos_weight=3.31; learning_rate=0.0663; num_iterations=4219; early_stopping_rounds=67; feature_fraction=0.638; bagging_fraction=0.512; bagging_freq=2; max_delta_step=6.52; path_smooth=8.52 : y = 0.914 : 29.7 secs : infill_ei
#
# Wed Nov 19 04:31:09 AM 2025 AUC 0.911962334473473
#
# [mbo] 19: num_leaves=5311; max_depth=26; min_child_weight=0.889; min_data_in_leaf=3782; min_gain_to_split=0.0421; lambda_l1=4.33; lambda_l2=216; scale_pos_weight=3.73; learning_rate=0.0363; num_iterations=510; early_stopping_rounds=181; feature_fraction=0.887; bagging_fraction=1; bagging_freq=1; max_delta_step=7.23; path_smooth=2.67 : y = 0.912 : 66.5 secs : infill_ei
#
# Wed Nov 19 04:39:31 AM 2025 AUC 0.923256355487196
#
# [mbo] 20: num_leaves=2755; max_depth=26; min_child_weight=7.07; min_data_in_leaf=252; min_gain_to_split=0.0181; lambda_l1=10.6; lambda_l2=561; scale_pos_weight=4.19; learning_rate=0.0348; num_iterations=2809; early_stopping_rounds=418; feature_fraction=0.463; bagging_fraction=0.832; bagging_freq=4; max_delta_step=1.59; path_smooth=8.06 : y = 0.923 : 500.1 secs : infill_ei
#
# Saved the current state after iteration 21 in the file HT.RDATA.
#
# Wed Nov 19 04:40:56 AM 2025 AUC 0.911204366753033
#
# [mbo] 21: num_leaves=7681; max_depth=29; min_child_weight=3.25; min_data_in_leaf=3506; min_gain_to_split=0.0422; lambda_l1=49.7; lambda_l2=723; scale_pos_weight=2; learning_rate=0.0698; num_iterations=4331; early_stopping_rounds=59; feature_fraction=0.235; bagging_fraction=0.78; bagging_freq=4; max_delta_step=7.39; path_smooth=4.24 : y = 0.911 : 82.9 secs : infill_ei
#
# Wed Nov 19 04:48:22 AM 2025 AUC 0.922164533016054
#
# [mbo] 22: num_leaves=2778; max_depth=15; min_child_weight=6.76; min_data_in_leaf=100; min_gain_to_split=0.00705; lambda_l1=23.1; lambda_l2=486; scale_pos_weight=3.82; learning_rate=0.0241; num_iterations=3225; early_stopping_rounds=295; feature_fraction=0.669; bagging_fraction=0.976; bagging_freq=0; max_delta_step=5.53; path_smooth=9.59 : y = 0.922 : 444.5 secs : infill_ei
#
# Wed Nov 19 04:52:40 AM 2025 AUC 0.923750259198789
#
# [mbo] 23: num_leaves=1593; max_depth=26; min_child_weight=1.59; min_data_in_leaf=867; min_gain_to_split=0.0205; lambda_l1=0.182; lambda_l2=544; scale_pos_weight=4.43; learning_rate=0.0678; num_iterations=2426; early_stopping_rounds=463; feature_fraction=0.854; bagging_fraction=0.768; bagging_freq=1; max_delta_step=6.89; path_smooth=9.26 : y = 0.924 : 256.1 secs : infill_ei
#
# Saved the current state after iteration 24 in the file HT.RDATA.
#
# Wed Nov 19 04:59:55 AM 2025 AUC 0.915388455940232
#
# [mbo] 24: num_leaves=2954; max_depth=24; min_child_weight=6.26; min_data_in_leaf=1521; min_gain_to_split=0.0204; lambda_l1=8.07; lambda_l2=978; scale_pos_weight=2.37; learning_rate=0.0104; num_iterations=3768; early_stopping_rounds=484; feature_fraction=0.648; bagging_fraction=0.889; bagging_freq=5; max_delta_step=6.34; path_smooth=9.37 : y = 0.915 : 431.6 secs : infill_ei
#
# Wed Nov 19 05:05:15 AM 2025 AUC 0.923688185702427
#
# [mbo] 25: num_leaves=2753; max_depth=21; min_child_weight=0.349; min_data_in_leaf=1769; min_gain_to_split=0.0381; lambda_l1=1.98; lambda_l2=845; scale_pos_weight=4.06; learning_rate=0.0723; num_iterations=3368; early_stopping_rounds=410; feature_fraction=0.669; bagging_fraction=0.619; bagging_freq=0; max_delta_step=0.601; path_smooth=6.95 : y = 0.924 : 317.1 secs : infill_ei
#
# Saved the current state after iteration 26 in the file HT.RDATA.
#
# Wed Nov 19 05:07:52 AM 2025 AUC 0.911574123471901
#
# [mbo] 26: num_leaves=2045; max_depth=4; min_child_weight=8.61; min_data_in_leaf=469; min_gain_to_split=0.0349; lambda_l1=89.6; lambda_l2=867; scale_pos_weight=2.71; learning_rate=0.0465; num_iterations=4207; early_stopping_rounds=230; feature_fraction=0.427; bagging_fraction=0.859; bagging_freq=4; max_delta_step=7.48; path_smooth=5.26 : y = 0.912 : 155.2 secs : infill_ei
#
# Wed Nov 19 05:10:47 AM 2025 AUC 0.926071472430308
#
# [mbo] 27: num_leaves=5361; max_depth=24; min_child_weight=2.79; min_data_in_leaf=754; min_gain_to_split=0.00334; lambda_l1=0.111; lambda_l2=549; scale_pos_weight=4.4; learning_rate=0.0696; num_iterations=1018; early_stopping_rounds=359; feature_fraction=0.385; bagging_fraction=0.876; bagging_freq=0; max_delta_step=2.14; path_smooth=7.5 : y = 0.926 : 172.3 secs : infill_ei
#
# Wed Nov 19 05:16:23 AM 2025 AUC 0.925008841279076
#
# [mbo] 28: num_leaves=3037; max_depth=21; min_child_weight=0.752; min_data_in_leaf=835; min_gain_to_split=0.0382; lambda_l1=2.04; lambda_l2=468; scale_pos_weight=4.22; learning_rate=0.0383; num_iterations=1916; early_stopping_rounds=381; feature_fraction=0.411; bagging_fraction=0.779; bagging_freq=0; max_delta_step=4.12; path_smooth=8.04 : y = 0.925 : 333.6 secs : infill_ei
#
# Saved the current state after iteration 29 in the file HT.RDATA.
#
# Wed Nov 19 05:18:43 AM 2025 AUC 0.918546487009192
#
# [mbo] 29: num_leaves=3574; max_depth=21; min_child_weight=2.74; min_data_in_leaf=1590; min_gain_to_split=0.0172; lambda_l1=29.1; lambda_l2=580; scale_pos_weight=3.96; learning_rate=0.0884; num_iterations=3786; early_stopping_rounds=477; feature_fraction=0.641; bagging_fraction=0.995; bagging_freq=2; max_delta_step=4.05; path_smooth=7.75 : y = 0.919 : 137.8 secs : infill_ei
#
# Wed Nov 19 05:22:47 AM 2025 AUC 0.91917326155624
#
# [mbo] 30: num_leaves=5698; max_depth=24; min_child_weight=4.27; min_data_in_leaf=2961; min_gain_to_split=3.58e-06; lambda_l1=6.51; lambda_l2=489; scale_pos_weight=4.33; learning_rate=0.0362; num_iterations=2560; early_stopping_rounds=354; feature_fraction=0.704; bagging_fraction=0.669; bagging_freq=1; max_delta_step=4.62; path_smooth=7.01 : y = 0.919 : 242.2 secs : infill_ei
#
# Wed Nov 19 05:23:42 AM 2025 AUC 0.916637978645375
#
# [mbo] 31: num_leaves=1571; max_depth=27; min_child_weight=4.72; min_data_in_leaf=313; min_gain_to_split=0.0163; lambda_l1=1.17; lambda_l2=856; scale_pos_weight=3.8; learning_rate=0.0829; num_iterations=306; early_stopping_rounds=314; feature_fraction=0.434; bagging_fraction=0.722; bagging_freq=1; max_delta_step=4; path_smooth=9.34 : y = 0.917 : 52.9 secs : infill_ei
#
# Wed Nov 19 05:27:23 AM 2025 AUC 0.923717377022338
#
# [mbo] 32: num_leaves=2343; max_depth=28; min_child_weight=8.79; min_data_in_leaf=406; min_gain_to_split=0.0141; lambda_l1=6.38; lambda_l2=411; scale_pos_weight=4.63; learning_rate=0.0561; num_iterations=1288; early_stopping_rounds=273; feature_fraction=0.617; bagging_fraction=0.789; bagging_freq=0; max_delta_step=2.57; path_smooth=4.23 : y = 0.924 : 218.9 secs : infill_ei
#
# Saved the current state after iteration 33 in the file HT.RDATA.
#
# Wed Nov 19 05:30:15 AM 2025 AUC 0.918752168378217
#
# [mbo] 33: num_leaves=1535; max_depth=26; min_child_weight=1.89; min_data_in_leaf=5240; min_gain_to_split=0.000925; lambda_l1=1.07; lambda_l2=688; scale_pos_weight=2.37; learning_rate=0.0797; num_iterations=4778; early_stopping_rounds=489; feature_fraction=0.989; bagging_fraction=0.523; bagging_freq=4; max_delta_step=9.1; path_smooth=6.05 : y = 0.919 : 170.1 secs : infill_ei
#
# Wed Nov 19 05:33:34 AM 2025 AUC 0.92667207544916
#
# [mbo] 34: num_leaves=6663; max_depth=23; min_child_weight=7.08; min_data_in_leaf=320; min_gain_to_split=0.0643; lambda_l1=0.177; lambda_l2=472; scale_pos_weight=4.57; learning_rate=0.0818; num_iterations=2628; early_stopping_rounds=186; feature_fraction=0.217; bagging_fraction=0.698; bagging_freq=3; max_delta_step=2.14; path_smooth=5.27 : y = 0.927 : 196.4 secs : infill_ei
#
# Wed Nov 19 05:37:20 AM 2025 AUC 0.924144174251377
#
# [mbo] 35: num_leaves=4130; max_depth=6; min_child_weight=6.26; min_data_in_leaf=186; min_gain_to_split=0.0716; lambda_l1=5; lambda_l2=532; scale_pos_weight=4.49; learning_rate=0.0879; num_iterations=2307; early_stopping_rounds=119; feature_fraction=0.571; bagging_fraction=0.87; bagging_freq=2; max_delta_step=0.187; path_smooth=6.1 : y = 0.924 : 223.3 secs : infill_ei
#
# Wed Nov 19 05:40:12 AM 2025 AUC 0.912619306937669
#
# [mbo] 36: num_leaves=7335; max_depth=24; min_child_weight=9.58; min_data_in_leaf=1071; min_gain_to_split=0.0665; lambda_l1=79.6; lambda_l2=854; scale_pos_weight=3.21; learning_rate=0.0452; num_iterations=4627; early_stopping_rounds=277; feature_fraction=0.493; bagging_fraction=0.929; bagging_freq=5; max_delta_step=8.94; path_smooth=1.8 : y = 0.913 : 169.1 secs : infill_ei
#
# Saved the current state after iteration 37 in the file HT.RDATA.
#
# Wed Nov 19 05:42:57 AM 2025 AUC 0.918975297432707
#
# [mbo] 37: num_leaves=4708; max_depth=29; min_child_weight=1.2; min_data_in_leaf=935; min_gain_to_split=0.0788; lambda_l1=5.77; lambda_l2=761; scale_pos_weight=4.49; learning_rate=0.0655; num_iterations=1571; early_stopping_rounds=146; feature_fraction=0.38; bagging_fraction=0.836; bagging_freq=2; max_delta_step=0.377; path_smooth=7.9 : y = 0.919 : 161.6 secs : infill_ei
#
# Wed Nov 19 05:43:50 AM 2025 AUC 0.905116298889589
#
# [mbo] 38: num_leaves=2711; max_depth=16; min_child_weight=0.364; min_data_in_leaf=1095; min_gain_to_split=0.0929; lambda_l1=5.03; lambda_l2=327; scale_pos_weight=4.18; learning_rate=0.0502; num_iterations=465; early_stopping_rounds=243; feature_fraction=0.646; bagging_fraction=0.98; bagging_freq=0; max_delta_step=0.133; path_smooth=2.53 : y = 0.905 : 51.4 secs : infill_ei
#
# Wed Nov 19 05:48:16 AM 2025 AUC 0.927834695259397
#
# [mbo] 39: num_leaves=4585; max_depth=29; min_child_weight=8.75; min_data_in_leaf=712; min_gain_to_split=0.0115; lambda_l1=4.38; lambda_l2=273; scale_pos_weight=4.31; learning_rate=0.0492; num_iterations=3265; early_stopping_rounds=260; feature_fraction=0.132; bagging_fraction=0.736; bagging_freq=1; max_delta_step=3.33; path_smooth=9.66 : y = 0.928 : 263.3 secs : infill_ei
#
# Wed Nov 19 05:49:51 AM 2025 AUC 0.917237239534576
#
# [mbo] 40: num_leaves=5461; max_depth=25; min_child_weight=6.64; min_data_in_leaf=40; min_gain_to_split=0.0234; lambda_l1=70.9; lambda_l2=454; scale_pos_weight=4.4; learning_rate=0.0791; num_iterations=3314; early_stopping_rounds=153; feature_fraction=0.677; bagging_fraction=0.778; bagging_freq=1; max_delta_step=2.31; path_smooth=9.53 : y = 0.917 : 92.9 secs : infill_ei
#
# Wed Nov 19 05:53:16 AM 2025 AUC 0.924149878302394
#
# [mbo] 41: num_leaves=5790; max_depth=10; min_child_weight=9.38; min_data_in_leaf=630; min_gain_to_split=0.0425; lambda_l1=1.94; lambda_l2=382; scale_pos_weight=4.59; learning_rate=0.0505; num_iterations=1796; early_stopping_rounds=393; feature_fraction=0.167; bagging_fraction=0.867; bagging_freq=2; max_delta_step=9.55; path_smooth=6.67 : y = 0.924 : 202.9 secs : infill_ei
#
# Saved the current state after iteration 42 in the file HT.RDATA.
#
# Wed Nov 19 05:56:06 AM 2025 AUC 0.926686838875322
#
# [mbo] 42: num_leaves=693; max_depth=14; min_child_weight=8.87; min_data_in_leaf=460; min_gain_to_split=0.0487; lambda_l1=0.143; lambda_l2=97.1; scale_pos_weight=4.85; learning_rate=0.0987; num_iterations=2572; early_stopping_rounds=247; feature_fraction=0.199; bagging_fraction=0.81; bagging_freq=3; max_delta_step=5.95; path_smooth=6.71 : y = 0.927 : 167.4 secs : infill_ei
#
# Wed Nov 19 05:57:35 AM 2025 AUC 0.925243713968013
#
# [mbo] 43: num_leaves=3256; max_depth=22; min_child_weight=9.7; min_data_in_leaf=73; min_gain_to_split=0.0247; lambda_l1=0.889; lambda_l2=169; scale_pos_weight=4.43; learning_rate=0.0722; num_iterations=1610; early_stopping_rounds=91; feature_fraction=0.0709; bagging_fraction=0.672; bagging_freq=3; max_delta_step=7.17; path_smooth=9.15 : y = 0.925 : 87.0 secs : infill_ei
#
# Wed Nov 19 06:01:38 AM 2025 AUC 0.927042838765268
#
# [mbo] 44: num_leaves=3366; max_depth=19; min_child_weight=8.28; min_data_in_leaf=504; min_gain_to_split=0.00726; lambda_l1=0.942; lambda_l2=511; scale_pos_weight=4.5; learning_rate=0.0844; num_iterations=2209; early_stopping_rounds=203; feature_fraction=0.217; bagging_fraction=0.962; bagging_freq=1; max_delta_step=5.54; path_smooth=8.04 : y = 0.927 : 239.7 secs : infill_ei
#
# Wed Nov 19 06:04:00 AM 2025 AUC 0.927852142944861
#
# [mbo] 45: num_leaves=4922; max_depth=13; min_child_weight=3.07; min_data_in_leaf=186; min_gain_to_split=0.0367; lambda_l1=2.93; lambda_l2=128; scale_pos_weight=4.94; learning_rate=0.0661; num_iterations=2405; early_stopping_rounds=246; feature_fraction=0.172; bagging_fraction=0.898; bagging_freq=3; max_delta_step=3.26; path_smooth=9.2 : y = 0.928 : 139.3 secs : infill_ei
#
# Saved the current state after iteration 46 in the file HT.RDATA.
#
# Wed Nov 19 06:05:29 AM 2025 AUC 0.871752968958554
#
# [mbo] 46: num_leaves=2; max_depth=12; min_child_weight=9.5; min_data_in_leaf=2822; min_gain_to_split=0.0874; lambda_l1=664; lambda_l2=101; scale_pos_weight=2.18; learning_rate=0.00586; num_iterations=4608; early_stopping_rounds=219; feature_fraction=0.107; bagging_fraction=0.967; bagging_freq=0; max_delta_step=9.8; path_smooth=1.82 : y = 0.872 : 86.5 secs : infill_ei
#
# Wed Nov 19 06:08:20 AM 2025 AUC 0.928258808229134
#
# ...
#
# Wed Nov 19 09:07:01 AM 2025 AUC 0.932631802164721
#
# [mbo] 86: num_leaves=2436; max_depth=12; min_child_weight=5.94; min_data_in_leaf=494; min_gain_to_split=0.0414; lambda_l1=0.281; lambda_l2=15.8; scale_pos_weight=4.39; learning_rate=0.0633; num_iterations=4805; early_stopping_rounds=243; feature_fraction=0.241; bagging_fraction=0.652; bagging_freq=0; max_delta_step=5.35; path_smooth=5.46 : y = 0.933 : 104.5 secs : infill_ei
#
# Wed Nov 19 09:11:41 AM 2025 AUC 0.922157822367799
#
# [mbo] 87: num_leaves=8092; max_depth=21; min_child_weight=6.83; min_data_in_leaf=1349; min_gain_to_split=0.00917; lambda_l1=0.0102; lambda_l2=636; scale_pos_weight=3.14; learning_rate=0.0585; num_iterations=1550; early_stopping_rounds=350; feature_fraction=0.416; bagging_fraction=0.928; bagging_freq=2; max_delta_step=4.05; path_smooth=8.24 : y = 0.922 : 274.5 secs : infill_ei
#
# Saved the current state after iteration 88 in the file HT.RDATA.
#
# Wed Nov 19 09:14:20 AM 2025 AUC 0.92802796192915
#
# [mbo] 88: num_leaves=6669; max_depth=5; min_child_weight=5.87; min_data_in_leaf=852; min_gain_to_split=0.0605; lambda_l1=0.0246; lambda_l2=72.3; scale_pos_weight=2.81; learning_rate=0.0518; num_iterations=4220; early_stopping_rounds=219; feature_fraction=0.718; bagging_fraction=0.849; bagging_freq=0; max_delta_step=5.06; path_smooth=9.16 : y = 0.928 : 155.6 secs : infill_ei
#
# Wed Nov 19 09:17:28 AM 2025 AUC 0.919023614100146
#
# [mbo] 89: num_leaves=7690; max_depth=13; min_child_weight=5.74; min_data_in_leaf=1733; min_gain_to_split=0.0759; lambda_l1=38.9; lambda_l2=59.7; scale_pos_weight=4.5; learning_rate=0.0239; num_iterations=3772; early_stopping_rounds=105; feature_fraction=0.114; bagging_fraction=0.711; bagging_freq=0; max_delta_step=3.91; path_smooth=5.5 : y = 0.919 : 184.1 secs : infill_ei
#
# Wed Nov 19 09:23:34 AM 2025 AUC 0.927761884725826
#
# [mbo] 90: num_leaves=932; max_depth=18; min_child_weight=1.1; min_data_in_leaf=115; min_gain_to_split=0.0131; lambda_l1=0.897; lambda_l2=641; scale_pos_weight=4.32; learning_rate=0.0536; num_iterations=4720; early_stopping_rounds=227; feature_fraction=0.195; bagging_fraction=0.66; bagging_freq=0; max_delta_step=9.17; path_smooth=7.59 : y = 0.928 : 362.6 secs : infill_ei
#
# Saved the current state after iteration 91 in the file HT.RDATA.
#
# Wed Nov 19 09:26:22 AM 2025 AUC 0.928064199429729
#
# [mbo] 91: num_leaves=6833; max_depth=13; min_child_weight=3.38; min_data_in_leaf=22; min_gain_to_split=0.0461; lambda_l1=1.91; lambda_l2=136; scale_pos_weight=4.73; learning_rate=0.0752; num_iterations=4305; early_stopping_rounds=288; feature_fraction=0.68; bagging_fraction=0.735; bagging_freq=0; max_delta_step=9.82; path_smooth=7.52 : y = 0.928 : 162.8 secs : infill_ei
#
# Wed Nov 19 09:31:32 AM 2025 AUC 0.921305905571784
#
# [mbo] 92: num_leaves=7177; max_depth=4; min_child_weight=4.35; min_data_in_leaf=2691; min_gain_to_split=0.0529; lambda_l1=0.866; lambda_l2=733; scale_pos_weight=2.79; learning_rate=0.0555; num_iterations=4463; early_stopping_rounds=191; feature_fraction=0.171; bagging_fraction=0.884; bagging_freq=0; max_delta_step=2.41; path_smooth=7.02 : y = 0.921 : 304.1 secs : infill_ei
#
# Wed Nov 19 09:34:32 AM 2025 AUC 0.927317639811323
#
# [mbo] 93: num_leaves=415; max_depth=10; min_child_weight=6.33; min_data_in_leaf=500; min_gain_to_split=0.0206; lambda_l1=0.323; lambda_l2=96.7; scale_pos_weight=3.6; learning_rate=0.066; num_iterations=4592; early_stopping_rounds=274; feature_fraction=0.264; bagging_fraction=0.816; bagging_freq=4; max_delta_step=4.84; path_smooth=9.06 : y = 0.927 : 176.0 secs : infill_ei
#
# Saved the current state after iteration 94 in the file HT.RDATA.
#
# Wed Nov 19 09:41:35 AM 2025 AUC 0.923619066025397
#
# [mbo] 94: num_leaves=426; max_depth=7; min_child_weight=5.63; min_data_in_leaf=1132; min_gain_to_split=0.0386; lambda_l1=1.18; lambda_l2=670; scale_pos_weight=2.28; learning_rate=0.0384; num_iterations=3645; early_stopping_rounds=490; feature_fraction=0.231; bagging_fraction=0.531; bagging_freq=0; max_delta_step=4.91; path_smooth=8.28 : y = 0.924 : 419.5 secs : infill_ei
#
# Wed Nov 19 09:47:06 AM 2025 AUC 0.928362823277091
#
# [mbo] 95: num_leaves=6901; max_depth=8; min_child_weight=9.53; min_data_in_leaf=631; min_gain_to_split=0.00493; lambda_l1=1.02; lambda_l2=39.5; scale_pos_weight=3.35; learning_rate=0.0621; num_iterations=2860; early_stopping_rounds=257; feature_fraction=0.562; bagging_fraction=0.626; bagging_freq=4; max_delta_step=7.69; path_smooth=6.84 : y = 0.928 : 326.4 secs : infill_ei
#
# Saved the current state after iteration 96 in the file HT.RDATA.
#
# Wed Nov 19 09:49:38 AM 2025 AUC 0.913444716673075
#
# [mbo] 96: num_leaves=787; max_depth=11; min_child_weight=0.638; min_data_in_leaf=1826; min_gain_to_split=0.0834; lambda_l1=66.6; lambda_l2=663; scale_pos_weight=3.31; learning_rate=0.0601; num_iterations=4610; early_stopping_rounds=453; feature_fraction=0.548; bagging_fraction=0.601; bagging_freq=0; max_delta_step=8.85; path_smooth=8.75 : y = 0.913 : 147.6 secs : infill_ei
#
# Wed Nov 19 09:52:26 AM 2025 AUC 0.920041954972892
#
# [mbo] 97: num_leaves=515; max_depth=18; min_child_weight=8.02; min_data_in_leaf=953; min_gain_to_split=0.0073; lambda_l1=0.0594; lambda_l2=86.8; scale_pos_weight=4.4; learning_rate=0.0727; num_iterations=3545; early_stopping_rounds=206; feature_fraction=0.504; bagging_fraction=0.561; bagging_freq=1; max_delta_step=0.644; path_smooth=8.12 : y = 0.92 : 164.4 secs : infill_ei
#
# Wed Nov 19 09:54:42 AM 2025 AUC 0.926559001026058
#
# [mbo] 98: num_leaves=7496; max_depth=7; min_child_weight=8.45; min_data_in_leaf=1907; min_gain_to_split=0.0195; lambda_l1=0.00202; lambda_l2=84.1; scale_pos_weight=3.93; learning_rate=0.0972; num_iterations=4233; early_stopping_rounds=321; feature_fraction=0.307; bagging_fraction=0.83; bagging_freq=0; max_delta_step=6.28; path_smooth=9.04 : y = 0.927 : 132.0 secs : infill_ei
#
# Wed Nov 19 09:56:52 AM 2025 AUC 0.924802824377638
#
# [mbo] 99: num_leaves=7566; max_depth=11; min_child_weight=9.8; min_data_in_leaf=454; min_gain_to_split=0.0279; lambda_l1=14.5; lambda_l2=83.9; scale_pos_weight=2.91; learning_rate=0.0551; num_iterations=4983; early_stopping_rounds=200; feature_fraction=0.833; bagging_fraction=0.902; bagging_freq=2; max_delta_step=9.65; path_smooth=6.22 : y = 0.925 : 125.0 secs : infill_ei
#
# Wed Nov 19 09:57:26 AM 2025 AUC 0.908630162082287
#
# [mbo] 100: num_leaves=5872; max_depth=9; min_child_weight=8.6; min_data_in_leaf=5401; min_gain_to_split=0.0414; lambda_l1=125; lambda_l2=188; scale_pos_weight=4.25; learning_rate=0.0791; num_iterations=2697; early_stopping_rounds=287; feature_fraction=0.883; bagging_fraction=0.842; bagging_freq=0; max_delta_step=7.78; path_smooth=6.65 : y = 0.909 : 30.5 secs : infill_ei
#
# Saved the current state after iteration 101 in the file HT.RDATA.
#
# Wed Nov 19 09:58:17 AM 2025 AUC 0.912805191894342
#
# [mbo] 101: num_leaves=2368; max_depth=23; min_child_weight=9.03; min_data_in_leaf=193; min_gain_to_split=0.0493; lambda_l1=53; lambda_l2=29.5; scale_pos_weight=2.81; learning_rate=0.0666; num_iterations=4192; early_stopping_rounds=424; feature_fraction=0.986; bagging_fraction=0.663; bagging_freq=5; max_delta_step=0.604; path_smooth=4.52 : y = 0.913 : 46.3 secs : infill_ei
#
# Wed Nov 19 10:03:49 AM 2025 AUC 0.926150993612134
#
# [mbo] 102: num_leaves=6225; max_depth=9; min_child_weight=0.867; min_data_in_leaf=64; min_gain_to_split=0.0279; lambda_l1=0.237; lambda_l2=483; scale_pos_weight=2.55; learning_rate=0.0646; num_iterations=3123; early_stopping_rounds=284; feature_fraction=0.198; bagging_fraction=0.52; bagging_freq=1; max_delta_step=7.2; path_smooth=7.27 : y = 0.926 : 327.0 secs : infill_ei
#
# Wed Nov 19 10:05:24 AM 2025 AUC 0.92540946697992
#
# [mbo] 103: num_leaves=5286; max_depth=12; min_child_weight=7.33; min_data_in_leaf=7; min_gain_to_split=0.036; lambda_l1=1.49; lambda_l2=402; scale_pos_weight=4.65; learning_rate=0.077; num_iterations=4880; early_stopping_rounds=103; feature_fraction=0.053; bagging_fraction=0.675; bagging_freq=0; max_delta_step=8.11; path_smooth=3.58 : y = 0.925 : 89.2 secs : infill_ei
#
# Wed Nov 19 10:08:13 AM 2025 AUC 0.917350313957679
#
# [mbo] 104: num_leaves=7280; max_depth=10; min_child_weight=6.51; min_data_in_leaf=5551; min_gain_to_split=0.0337; lambda_l1=0.441; lambda_l2=604; scale_pos_weight=2.52; learning_rate=0.0633; num_iterations=3141; early_stopping_rounds=113; feature_fraction=0.907; bagging_fraction=0.85; bagging_freq=3; max_delta_step=9.65; path_smooth=9.14 : y = 0.917 : 163.6 secs : infill_ei
#
# Saved the current state after iteration 105 in the file HT.RDATA.
#
# Wed Nov 19 10:12:03 AM 2025 AUC 0.932971025434028
#
# [mbo] 105: num_leaves=3933; max_depth=22; min_child_weight=9.42; min_data_in_leaf=209; min_gain_to_split=0.0145; lambda_l1=1.15; lambda_l2=41.2; scale_pos_weight=2.6; learning_rate=0.0596; num_iterations=1756; early_stopping_rounds=206; feature_fraction=0.252; bagging_fraction=0.719; bagging_freq=0; max_delta_step=4.74; path_smooth=4.3 : y = 0.933 : 225.0 secs : infill_ei
#
# Wed Nov 19 10:15:03 AM 2025 AUC 0.924926635837949
#
# [mbo] 106: num_leaves=6420; max_depth=19; min_child_weight=2.72; min_data_in_leaf=5347; min_gain_to_split=0.0168; lambda_l1=1.44; lambda_l2=112; scale_pos_weight=2.17; learning_rate=0.0971; num_iterations=1442; early_stopping_rounds=185; feature_fraction=0.233; bagging_fraction=0.703; bagging_freq=0; max_delta_step=0.782; path_smooth=9.64 : y = 0.925 : 176.3 secs : infill_ei
#
# Wed Nov 19 10:18:06 AM 2025 AUC 0.92867923034233
#
# [mbo] 107: num_leaves=7427; max_depth=22; min_child_weight=5.37; min_data_in_leaf=2274; min_gain_to_split=0.0103; lambda_l1=0.162; lambda_l2=72.7; scale_pos_weight=2.23; learning_rate=0.0834; num_iterations=1436; early_stopping_rounds=334; feature_fraction=0.362; bagging_fraction=0.647; bagging_freq=0; max_delta_step=4.07; path_smooth=7.25 : y = 0.929 : 177.0 secs : infill_ei
#
# Wed Nov 19 10:20:51 AM 2025 AUC 0.93242914058741
#
# [mbo] 108: num_leaves=6563; max_depth=29; min_child_weight=8.72; min_data_in_leaf=321; min_gain_to_split=0.0194; lambda_l1=1.19; lambda_l2=40; scale_pos_weight=2.77; learning_rate=0.0829; num_iterations=1181; early_stopping_rounds=138; feature_fraction=0.489; bagging_fraction=0.812; bagging_freq=0; max_delta_step=5.52; path_smooth=7.68 : y = 0.932 : 158.9 secs : infill_ei
#
# Saved the current state after iteration 109 in the file HT.RDATA.
#
# Wed Nov 19 10:22:42 AM 2025 AUC 0.930456881065168
#
# [mbo] 109: num_leaves=2466; max_depth=19; min_child_weight=5.01; min_data_in_leaf=266; min_gain_to_split=0.0466; lambda_l1=0.272; lambda_l2=56.8; scale_pos_weight=2.27; learning_rate=0.0836; num_iterations=1868; early_stopping_rounds=137; feature_fraction=0.058; bagging_fraction=0.801; bagging_freq=0; max_delta_step=7.45; path_smooth=8.31 : y = 0.93 : 107.1 secs : infill_ei
#
# Wed Nov 19 10:23:33 AM 2025 AUC 0.922290022138429
#
# [mbo] 110: num_leaves=7808; max_depth=21; min_child_weight=8.37; min_data_in_leaf=1934; min_gain_to_split=0.0281; lambda_l1=0.818; lambda_l2=37.8; scale_pos_weight=2.34; learning_rate=0.0961; num_iterations=275; early_stopping_rounds=113; feature_fraction=0.914; bagging_fraction=0.691; bagging_freq=0; max_delta_step=1.39; path_smooth=5.52 : y = 0.922 : 45.4 secs : infill_ei
#
# Wed Nov 19 10:26:02 AM 2025 AUC 0.930113631406908
#
# [mbo] 111: num_leaves=2843; max_depth=10; min_child_weight=3.93; min_data_in_leaf=1345; min_gain_to_split=0.0142; lambda_l1=1; lambda_l2=9.61; scale_pos_weight=2.84; learning_rate=0.0841; num_iterations=3141; early_stopping_rounds=261; feature_fraction=0.103; bagging_fraction=0.776; bagging_freq=0; max_delta_step=4.8; path_smooth=7.79 : y = 0.93 : 144.1 secs : infill_ei
#
# Wed Nov 19 10:30:20 AM 2025 AUC 0.924159944274777
#
# [mbo] 112: num_leaves=2343; max_depth=6; min_child_weight=9.73; min_data_in_leaf=135; min_gain_to_split=0.0853; lambda_l1=0.662; lambda_l2=958; scale_pos_weight=4.61; learning_rate=0.0763; num_iterations=4539; early_stopping_rounds=471; feature_fraction=0.697; bagging_fraction=0.609; bagging_freq=3; max_delta_step=0.983; path_smooth=5.97 : y = 0.924 : 253.5 secs : infill_ei
#
# Wed Nov 19 10:32:58 AM 2025 AUC 0.935945184740791
#
# [mbo] 113: num_leaves=2298; max_depth=7; min_child_weight=9.7; min_data_in_leaf=245; min_gain_to_split=0.066; lambda_l1=0.421; lambda_l2=82.5; scale_pos_weight=3.89; learning_rate=0.0872; num_iterations=3797; early_stopping_rounds=272; feature_fraction=0.0985; bagging_fraction=0.813; bagging_freq=1; max_delta_step=1.64; path_smooth=9.39 : y = 0.936 : 151.2 secs : infill_ei
#
# Saved the current state after iteration 114 in the file HT.RDATA.
#
# Wed Nov 19 10:38:11 AM 2025 AUC 0.931463142771055
#
# [mbo] 114: num_leaves=3186; max_depth=13; min_child_weight=9.77; min_data_in_leaf=12; min_gain_to_split=0.0684; lambda_l1=0.575; lambda_l2=56.3; scale_pos_weight=4.08; learning_rate=0.0204; num_iterations=3946; early_stopping_rounds=494; feature_fraction=0.087; bagging_fraction=0.625; bagging_freq=0; max_delta_step=3.08; path_smooth=8.28 : y = 0.931 : 306.0 secs : infill_ei
#
# Wed Nov 19 10:41:10 AM 2025 AUC 0.927843754634541
#
# [mbo] 115: num_leaves=6268; max_depth=9; min_child_weight=9.93; min_data_in_leaf=712; min_gain_to_split=0.0279; lambda_l1=0.663; lambda_l2=31.6; scale_pos_weight=2.94; learning_rate=0.0685; num_iterations=1190; early_stopping_rounds=465; feature_fraction=0.316; bagging_fraction=0.736; bagging_freq=0; max_delta_step=0.737; path_smooth=7.78 : y = 0.928 : 173.0 secs : infill_ei
#
# Wed Nov 19 10:46:03 AM 2025 AUC 0.924439107242199
#
# [mbo] 116: num_leaves=4613; max_depth=23; min_child_weight=9.66; min_data_in_leaf=141; min_gain_to_split=0.0339; lambda_l1=0.0549; lambda_l2=246; scale_pos_weight=1.44; learning_rate=0.0983; num_iterations=2251; early_stopping_rounds=266; feature_fraction=0.251; bagging_fraction=0.847; bagging_freq=2; max_delta_step=2.2; path_smooth=9.44 : y = 0.924 : 286.8 secs : infill_ei
#
# Saved the current state after iteration 117 in the file HT.RDATA.
#
# Wed Nov 19 10:50:34 AM 2025 AUC 0.922475571562689
#
# [mbo] 117: num_leaves=2989; max_depth=9; min_child_weight=7.59; min_data_in_leaf=174; min_gain_to_split=0.0843; lambda_l1=0.917; lambda_l2=978; scale_pos_weight=1.95; learning_rate=0.0739; num_iterations=2885; early_stopping_rounds=183; feature_fraction=0.0992; bagging_fraction=0.869; bagging_freq=0; max_delta_step=3.74; path_smooth=8.91 : y = 0.922 : 266.6 secs : infill_ei
#
# Wed Nov 19 10:57:26 AM 2025 AUC 0.931851018240213
#
# [mbo] 118: num_leaves=2314; max_depth=30; min_child_weight=0.684; min_data_in_leaf=129; min_gain_to_split=0.00692; lambda_l1=0.181; lambda_l2=114; scale_pos_weight=1.99; learning_rate=0.0385; num_iterations=2286; early_stopping_rounds=243; feature_fraction=0.319; bagging_fraction=0.857; bagging_freq=0; max_delta_step=5.72; path_smooth=8.52 : y = 0.932 : 404.6 secs : infill_ei
#
# Saved the current state after iteration 119 in the file HT.RDATA.
#
# Wed Nov 19 11:01:39 AM 2025 AUC 0.925477580059711
#
# [mbo] 119: num_leaves=2450; max_depth=27; min_child_weight=0.333; min_data_in_leaf=123; min_gain_to_split=0.0229; lambda_l1=0.817; lambda_l2=132; scale_pos_weight=1.98; learning_rate=0.0864; num_iterations=1776; early_stopping_rounds=448; feature_fraction=0.709; bagging_fraction=0.64; bagging_freq=3; max_delta_step=3.01; path_smooth=8.22 : y = 0.925 : 246.7 secs : infill_ei
#
# Wed Nov 19 11:02:05 AM 2025 AUC 0.893223688051489
#
# [mbo] 120: num_leaves=1725; max_depth=26; min_child_weight=0.267; min_data_in_leaf=1295; min_gain_to_split=0.0684; lambda_l1=840; lambda_l2=960; scale_pos_weight=4.86; learning_rate=0.0839; num_iterations=527; early_stopping_rounds=66; feature_fraction=0.34; bagging_fraction=0.654; bagging_freq=5; max_delta_step=9.77; path_smooth=3.07 : y = 0.893 : 18.9 secs : infill_ei
#
# Saved the final state in the file HT.RDATA

# %% [markdown]
# la bayesian optimization ha corrido, extraigo los mejores hiperparametros

# %%
# almaceno los resultados de la Bayesian Optimization
# y capturo los mejores hiperparametros encontrados

tb_bayesiana <- as.data.table(bayesiana_salida$opt.path)

# ordeno en forma descendente por AUC = y
setorder(tb_bayesiana, -y, -num_iterations)

# grabo para eventualmente poder utilizarlos en OTRA corrida
fwrite( tb_bayesiana,
  file="BO_log.txt",
  sep="\t"
)

# los mejores hiperparámetros son los que quedaron en el registro 1 de la tabla
PARAM$out$lgbm$mejores_hiperparametros <- tb_bayesiana[
  1, # el primero es el de mejor AUC
  setdiff(colnames(tb_bayesiana),
    c("y","dob","eol","error.message","exec.time","ei","error.model",
      "train.time","prop.type","propose.time","se","mean","iter")),
  with= FALSE
]

print(PARAM$out$lgbm$mejores_hiperparametros)
# Out:
#    num_leaves max_depth min_child_weight min_data_in_leaf min_gain_to_split
#         <int>     <int>            <num>            <int>             <num>
# 1:       2298         7         9.704525              245         0.0660459
#    lambda_l1 lambda_l2 scale_pos_weight learning_rate num_iterations
#        <num>     <num>            <num>         <num>          <int>
# 1: 0.4212403  82.48776         3.888737    0.08716312           3797
#    early_stopping_rounds feature_fraction bagging_fraction bagging_freq
#                    <int>            <num>            <num>        <int>
# 1:                   272       0.09845826        0.8126096            1
#    max_delta_step path_smooth
#             <num>       <num>
# 1:       1.642557    9.392506

# %% [markdown]
# ### 6.3.3 Produccion

# %% [markdown]
# #### Final Training
# Construyo el modelo final, que es uno solo, no hace ningun tipo de particion < training, validation, testing>]

# %% [markdown]
# ##### Final Training Dataset
#
# Aqui esta la gran decision de en qué meses hago el Final Training
# <br> debo utilizar los mejores hiperparámetros que encontré en la optimización bayesiana

# %%
PARAM$trainingstrategy$final_train <- c(
  202105, 202104, 202103, 202102, 202101,
  202012, 202011, 202010, 202009, 202008, 202007,
  202006, 202005
)

dataset[, fold_final_train := foto_mes %in% PARAM$trainingstrategy$final_train ]

# creo el dfinal_train en formato  LightGBM
dfinal_train <- lgb.Dataset(
  data= data.matrix(dataset[fold_final_train == TRUE, campos_buenos, with= FALSE]),
  label= dataset[fold_final_train == TRUE, clase01],
  free_raw_data= TRUE
)

nrow( dfinal_train) # verifico el tamaño
# Out:
# [1] 207504

# %% [markdown]
# ##### Final Training Hyperparameters

# %%
# uno los parametros fijos y los mejores encontrados de los variables
fijos <- copy(PARAM$lgbm$param_fijos)

# quito lo que optimice en la Bayesian Optimization
fijos$num_iterations <- NULL
fijos$early_stopping_rounds <- NULL

# agrego a los hiperparametros fijos los que encontre con la Bayesian Optimization
param_final <- c(fijos, PARAM$out$lgbm$mejores_hiperparametros)

# Para el entrenamiento final, removemos early_stopping_rounds
# ya que se entrena con todos los datos disponibles y la cantidad de iteraciones
# ya está optimizada en 'num_iterations'.
param_final$early_stopping_rounds <- NULL

# %% [markdown]
# ##### Training
# Genero el modelo final, siempre sobre TODOS los datos de  final_train, sin hacer ningun tipo de undersampling de la clase mayoritaria

# %%
final_model <- lgb.train(
  data= dfinal_train,
  param= param_final,
  verbose= -100
)

# %%
# grabo a disco el modelo en un formato para seres humanos ... ponele ...

lgb.save(final_model, "modelo.txt")

# %%
# ahora imprimo la importancia de variables

tb_importancia <- as.data.table(lgb.importance(final_model))
archivo_importancia <- "impo.txt"

fwrite( tb_importancia,
  file= archivo_importancia,
  sep= "\t"
)

# %% [markdown]
# #### Scoring

# %% [markdown]
# Aplico el modelo final a los datos del futuro

# %%
PARAM$trainingstrategy$future <- c(202107)

dfuture <- dataset[ foto_mes %in% PARAM$trainingstrategy$future ]

# %%
# aplico final_model   a dfuture

prediccion <- predict(
  final_model,
  data.matrix(dfuture[, campos_buenos, with= FALSE])
)

# %% [markdown]
# ##### Tabla Prediccion

# %%
tb_prediccion <- dfuture[, list(numero_de_cliente)]
tb_prediccion[, prob := prediccion]

# grabo las probabilidad del modelo
#  me va a ser util para hacer Ensembles de modelos
fwrite(tb_prediccion,
  file= "prediccion.txt",
  sep= "\t"
)

# %% [markdown]
# #### Curva de Ganancia

# %% [markdown]
# Genero las salidas

# %%
# asigno clase ternaria
tb_prediccion[, clase_ternaria := dfuture$clase_ternaria ]

# asigno ganancias
tb_prediccion[, ganancia := -3000.0 ]
tb_prediccion[clase_ternaria=="BAJA+2", ganancia := 117000.0 ]

# reordeno, y acumulada
setorder( tb_prediccion, -prob )
tb_prediccion[, gan_acum := cumsum(ganancia)]

# media movil de ancho 400
tb_prediccion[,
  gan_suavizada := frollmean(
    x= gan_acum,
    n= 400,
    align= "center",
    na.rm= TRUE,
    hasNA= TRUE
  )
]

# %%
tb_prediccion[, sum(!is.na(gan_suavizada) )]
tb_prediccion[, .N]
# Out:
# [1] 16152
# [1] 16551

# %%
# Este es la ganancia a reportar
resultado <- list()
resultado$ganancia_suavizada_max <- max( tb_prediccion$gan_suavizada, na.rm=TRUE )
options(digits= 8)
resultado$envios <- which.max( tb_prediccion$gan_suavizada)
resultado
# Out:
# $ganancia_suavizada_max
# [1] 5962800
#
# $envios
# [1] 1525

# %%
# grabo las ganancias
fwrite( tb_prediccion,
  file= "ganancias.txt",
  sep= "\t"
)

# %%
# genero el grafico

tb_prediccion[, envios:= .I]

pdf("curva_de_ganancia.pdf")

plot(
  x= tb_prediccion$envios,
  y= tb_prediccion$gan_acum,
  type= "l",
  col= "gray",
  xlim= c(0, 6000),
  ylim= c(0, 8000000),
  main= paste0("Mejor gan prom= ", as.integer(resultado$ganancia_suavizada_max), " envios= ", resultado$envios),
  xlab= "Envios",
  ylab= "Ganancia",
  panel.first= grid()
)

dev.off()
# Out:
# agg_record_1553752178
#                     2

# %%
# grabo los parametros
if( !require("yaml")) install.packages("yaml")
require("yaml")

PARAM$resultado <- resultado

write_yaml( PARAM, file="PARAM.yml")
# Out:
# Loading required package: yaml

# %%
format(Sys.time(), "%a %b %d %X %Y")
fin <- Sys.time()

# Duración en segundos
secs <- as.numeric(difftime(fin, principio, units = "secs"))
secs <- round(secs)

# A hh:mm:ss
h <- secs %/% 3600
m <- (secs %% 3600) %/% 60
s <- secs %% 60
dur_hms <- sprintf("%02d:%02d:%02d", h, m, s)

cat(
  "Inicio: ", format(principio, "%a %b %d %X %Y"), "\n",
  "Fin:    ", format(fin,       "%a %b %d %X %Y"), "\n",
  "Duración (hh:mm:ss): ", dur_hms, "\n",
  sep = ""
)
# Out:
# [1] "Wed Nov 19 11:09:32 AM 2025"
# Inicio: Wed Nov 19 02:02:40 AM 2025
# Fin:    Wed Nov 19 11:09:32 AM 2025
# Duración (hh:mm:ss): 09:06:51
